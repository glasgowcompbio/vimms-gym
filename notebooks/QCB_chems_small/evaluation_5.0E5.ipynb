# %% [markdown]
# # Evaluation using QCB chemicals (small)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns
import copy

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_small
alpha = 0.489231295
beta = 0.07277375
extract = False
params, max_peaks = preset_qcb_small(None, alpha=alpha, beta=beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2022-08-29 11:20:26.848 | INFO     | experiments:get_samplers:283 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_small_gaussian.p
# ({'chemical_creator': {'mz_range': (100, 110),
#    'rt_range': (400, 500),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (20, 50),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd77ab971f0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd77ab973a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fd77bfe97f0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 110)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 500),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.489231295,
#    'beta': 0.07277375}},
#  100)

# %%
# n_chemicals = (20, 50)
# mz_range = (100, 110)
# rt_range = (400, 500)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 100
in_dir = '../../tune/QCB_chems_small'
out_dir = 'evaluation_5.0E5'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 5
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 1
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 120
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_small.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 28
# 22
# 45
# 28
# 20
# 38
# 34
# 21
# 37
# 45
# 36
# 46
# 49
# 24
# 32
# 42
# 25
# 34
# 44
# 37
# 23
# 40
# 43
# 37
# 27
# 32
# 34
# 26
# 28
# 34

# %% [markdown]
# Generate new chemicals if not found

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    min_mz = mz_range[0]
    max_mz = mz_range[1]
    min_rt = rt_range[0]
    max_rt = rt_range[1]
    min_log_intensity = np.log(intensity_range[0])
    max_log_intensity = np.log(intensity_range[1])
    
    mzml_filename = '../fullscan_QCB.mzML'
    logger.info('Creating samplers from %s' % mzml_filename)
    mz_sampler = MZMLFormulaSampler(mzml_filename, min_mz=min_mz, max_mz=max_mz)
    ri_sampler = MZMLRTandIntensitySampler(mzml_filename, min_rt=min_rt, max_rt=max_rt,
                                           min_log_intensity=min_log_intensity,
                                           max_log_intensity=max_log_intensity)
    
    # roi_params = RoiBuilderParams(min_roi_length=3, at_least_one_point_above=1000)
    # cr_sampler = MZMLChromatogramSampler(mzml_filename, roi_params=roi_params)
    cr_sampler = GaussianChromatogramSampler()
    
    chemical_creator_params = {
        'mz_range': mz_range,
        'rt_range': rt_range,
        'intensity_range': intensity_range,
        'n_chemicals': n_chemicals,
        'mz_sampler': mz_sampler,
        'ri_sampler': ri_sampler,
        'cr_sampler': cr_sampler
    }

    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 110),
#   'rt_range': (400, 500),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (20, 50),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd77ab971f0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd77ab973a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fd77bfe97f0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 110)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 500),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.489231295,
#   'beta': 0.07277375}}

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)           
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        alpha = 0.489231295
        beta = 0.07277375
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_500000_alpha_auto_beta_auto', METHOD_DQN)
        fname = os.path.join(model_dir, 'best_model.zip')
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO:
        alpha = 0.50
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_reward_timesteps_200000_alpha_%.2f_beta_%.2f' % (alpha, beta), METHOD_PPO)        
        fname = os.path.join(model_dir, 'best_model.zip')
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO_RECURRENT:
        alpha = 0.50
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_reward_timesteps_200000_alpha_%.2f_beta_%.2f' % (alpha, beta), METHOD_PPO_RECURRENT)        
        fname = os.path.join(model_dir, 'best_model.zip')        
        model = RecurrentPPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method=%s max_peaks=%d N=%d rt_tol=%d alpha=%s beta=%s' % (
        method, max_peaks, N, copy_params['env']['rt_tol'], 
        str(copy_params['env']['alpha']), 
        str(copy_params['env']['beta']))
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method=random max_peaks=100 N=0 rt_tol=120 alpha=0.489231295 beta=0.07277375
#
#
# Episode 0 (28 chemicals)
# Finished after 498 timesteps with total reward -475.90197279999205
# {'coverage_prop': '0.714', 'intensity_prop': '0.528', 'ms1ms2_ratio': '0.006', 'efficiency': '0.040', 'TP': '15', 'FP': '5', 'FN': '8', 'precision': '0.750', 'recall': '0.652', 'f1': '0.698', 'total_rewards': -475.90197279999205, 'invalid_action_count': 481}
#
# Episode 1 (22 chemicals)
# Finished after 495 timesteps with total reward -465.9934575084685
# {'coverage_prop': '0.727', 'intensity_prop': '0.617', 'ms1ms2_ratio': '0.012', 'efficiency': '0.033', 'TP': '15', 'FP': '1', 'FN': '6', 'precision': '0.938', 'recall': '0.714', 'f1': '0.811', 'total_rewards': -465.9934575084685, 'invalid_action_count': 474}
#
# Episode 2 (45 chemicals)
# Finished after 492 timesteps with total reward -431.7560697352414
# {'coverage_prop': '0.867', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.019', 'efficiency': '0.081', 'TP': '33', 'FP': '6', 'FN': '6', 'precision': '0.846', 'recall': '0.846', 'f1': '0.846', 'total_rewards': -431.7560697352413, 'invalid_action_count': 446}
#
# Episode 3 (28 chemicals)
# Finished after 494 timesteps with total reward -460.62074458648715
# {'coverage_prop': '0.393', 'intensity_prop': '0.225', 'ms1ms2_ratio': '0.014', 'efficiency': '0.023', 'TP': '5', 'FP': '6', 'FN': '17', 'precision': '0.455', 'recall': '0.227', 'f1': '0.303', 'total_rewards': -460.62074458648715, 'invalid_action_count': 468}
#
# Episode 4 (20 chemicals)
# Finished after 497 timesteps with total reward -467.3273606242087
# {'coverage_prop': '0.900', 'intensity_prop': '0.646', 'ms1ms2_ratio': '0.008', 'efficiency': '0.037', 'TP': '13', 'FP': '5', 'FN': '2', 'precision': '0.722', 'recall': '0.867', 'f1': '0.788', 'total_rewards': -467.32736062420867, 'invalid_action_count': 475}
#
# Episode 5 (38 chemicals)
# Finished after 493 timesteps with total reward -431.55631977576047
# {'coverage_prop': '0.974', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.016', 'efficiency': '0.076', 'TP': '24', 'FP': '13', 'FN': '1', 'precision': '0.649', 'recall': '0.960', 'f1': '0.774', 'total_rewards': -431.5563197757603, 'invalid_action_count': 444}
#
# Episode 6 (34 chemicals)
# Finished after 498 timesteps with total reward -471.91258879161506
# {'coverage_prop': '0.765', 'intensity_prop': '0.495', 'ms1ms2_ratio': '0.006', 'efficiency': '0.053', 'TP': '17', 'FP': '9', 'FN': '8', 'precision': '0.654', 'recall': '0.680', 'f1': '0.667', 'total_rewards': -471.912588791615, 'invalid_action_count': 479}
#
# Episode 7 (21 chemicals)
# Finished after 494 timesteps with total reward -447.6698661033257
# {'coverage_prop': '0.905', 'intensity_prop': '0.662', 'ms1ms2_ratio': '0.014', 'efficiency': '0.039', 'TP': '15', 'FP': '4', 'FN': '2', 'precision': '0.789', 'recall': '0.882', 'f1': '0.833', 'total_rewards': -447.6698661033256, 'invalid_action_count': 459}
#
# Episode 8 (37 chemicals)
# Finished after 496 timesteps with total reward -474.19330928758893
# {'coverage_prop': '0.541', 'intensity_prop': '0.358', 'ms1ms2_ratio': '0.010', 'efficiency': '0.041', 'TP': '13', 'FP': '7', 'FN': '17', 'precision': '0.650', 'recall': '0.433', 'f1': '0.520', 'total_rewards': -474.1933092875889, 'invalid_action_count': 478}
#
# Episode 9 (45 chemicals)
# Finished after 491 timesteps with total reward -412.2636311193446
# {'coverage_prop': '0.933', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.021', 'efficiency': '0.087', 'TP': '34', 'FP': '8', 'FN': '3', 'precision': '0.810', 'recall': '0.919', 'f1': '0.861', 'total_rewards': -412.2636311193446, 'invalid_action_count': 430}
#
# Episode 10 (36 chemicals)
# Finished after 494 timesteps with total reward -433.61075633031203
# {'coverage_prop': '0.972', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.014', 'efficiency': '0.072', 'TP': '28', 'FP': '7', 'FN': '1', 'precision': '0.800', 'recall': '0.966', 'f1': '0.875', 'total_rewards': -433.6107563303121, 'invalid_action_count': 449}
#
# Episode 11 (46 chemicals)
# Finished after 498 timesteps with total reward -467.22670946272103
# {'coverage_prop': '0.739', 'intensity_prop': '0.398', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '21', 'FP': '13', 'FN': '12', 'precision': '0.618', 'recall': '0.636', 'f1': '0.627', 'total_rewards': -467.2267094627209, 'invalid_action_count': 476}
#
# Episode 12 (49 chemicals)
# Finished after 496 timesteps with total reward -433.8428899850344
# {'coverage_prop': '0.898', 'intensity_prop': '0.658', 'ms1ms2_ratio': '0.010', 'efficiency': '0.090', 'TP': '34', 'FP': '10', 'FN': '5', 'precision': '0.773', 'recall': '0.872', 'f1': '0.819', 'total_rewards': -433.8428899850341, 'invalid_action_count': 447}
#
# Episode 13 (24 chemicals)
# Finished after 498 timesteps with total reward -484.36357920050864
# {'coverage_prop': '0.583', 'intensity_prop': '0.353', 'ms1ms2_ratio': '0.006', 'efficiency': '0.028', 'TP': '9', 'FP': '5', 'FN': '10', 'precision': '0.643', 'recall': '0.474', 'f1': '0.545', 'total_rewards': -484.36357920050864, 'invalid_action_count': 488}
#
# Episode 14 (32 chemicals)
# Finished after 496 timesteps with total reward -461.53786219341686
# {'coverage_prop': '0.844', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.010', 'efficiency': '0.055', 'TP': '20', 'FP': '7', 'FN': '5', 'precision': '0.741', 'recall': '0.800', 'f1': '0.769', 'total_rewards': -461.53786219341686, 'invalid_action_count': 470}
#
# Episode 15 (42 chemicals)
# Finished after 498 timesteps with total reward -471.741513550548
# {'coverage_prop': '0.595', 'intensity_prop': '0.308', 'ms1ms2_ratio': '0.006', 'efficiency': '0.051', 'TP': '12', 'FP': '13', 'FN': '17', 'precision': '0.480', 'recall': '0.414', 'f1': '0.444', 'total_rewards': -471.74151355054795, 'invalid_action_count': 479}
#
# Episode 16 (25 chemicals)
# Finished after 494 timesteps with total reward -447.8650756958542
# {'coverage_prop': '0.880', 'intensity_prop': '0.638', 'ms1ms2_ratio': '0.014', 'efficiency': '0.045', 'TP': '16', 'FP': '6', 'FN': '3', 'precision': '0.727', 'recall': '0.842', 'f1': '0.780', 'total_rewards': -447.8650756958541, 'invalid_action_count': 459}
#
# Episode 17 (34 chemicals)
# Finished after 493 timesteps with total reward -443.1063566501478
# {'coverage_prop': '0.882', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.016', 'efficiency': '0.062', 'TP': '20', 'FP': '10', 'FN': '4', 'precision': '0.667', 'recall': '0.833', 'f1': '0.741', 'total_rewards': -443.10635665014775, 'invalid_action_count': 458}
#
# Episode 18 (44 chemicals)
# Finished after 496 timesteps with total reward -443.47061778770944
# {'coverage_prop': '0.795', 'intensity_prop': '0.565', 'ms1ms2_ratio': '0.010', 'efficiency': '0.071', 'TP': '25', 'FP': '10', 'FN': '9', 'precision': '0.714', 'recall': '0.735', 'f1': '0.725', 'total_rewards': -443.4706177877094, 'invalid_action_count': 457}
#
# Episode 19 (37 chemicals)
# Finished after 494 timesteps with total reward -449.1198366031309
# {'coverage_prop': '0.946', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.014', 'efficiency': '0.072', 'TP': '30', 'FP': '5', 'FN': '2', 'precision': '0.857', 'recall': '0.938', 'f1': '0.896', 'total_rewards': -449.1198366031309, 'invalid_action_count': 460}
#
# Episode 20 (23 chemicals)
# Finished after 496 timesteps with total reward -456.3708568333533
# {'coverage_prop': '0.913', 'intensity_prop': '0.622', 'ms1ms2_ratio': '0.010', 'efficiency': '0.043', 'TP': '15', 'FP': '6', 'FN': '2', 'precision': '0.714', 'recall': '0.882', 'f1': '0.789', 'total_rewards': -456.3708568333533, 'invalid_action_count': 468}
#
# Episode 21 (40 chemicals)
# Finished after 490 timesteps with total reward -417.6212324218987
# {'coverage_prop': '0.900', 'intensity_prop': '0.670', 'ms1ms2_ratio': '0.023', 'efficiency': '0.075', 'TP': '27', 'FP': '9', 'FN': '4', 'precision': '0.750', 'recall': '0.871', 'f1': '0.806', 'total_rewards': -417.6212324218986, 'invalid_action_count': 437}
#
# Episode 22 (43 chemicals)
# Finished after 493 timesteps with total reward -417.3944874803177
# {'coverage_prop': '0.953', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.016', 'efficiency': '0.085', 'TP': '34', 'FP': '7', 'FN': '2', 'precision': '0.829', 'recall': '0.944', 'f1': '0.883', 'total_rewards': -417.39448748031754, 'invalid_action_count': 436}
#
# Episode 23 (37 chemicals)
# Finished after 493 timesteps with total reward -445.8309472183597
# {'coverage_prop': '0.865', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.016', 'efficiency': '0.066', 'TP': '23', 'FP': '9', 'FN': '5', 'precision': '0.719', 'recall': '0.821', 'f1': '0.767', 'total_rewards': -445.83094721835977, 'invalid_action_count': 455}
#
# Episode 24 (27 chemicals)
# Finished after 495 timesteps with total reward -457.10345928846994
# {'coverage_prop': '0.852', 'intensity_prop': '0.493', 'ms1ms2_ratio': '0.012', 'efficiency': '0.047', 'TP': '14', 'FP': '9', 'FN': '4', 'precision': '0.609', 'recall': '0.778', 'f1': '0.683', 'total_rewards': -457.1034592884698, 'invalid_action_count': 467}
#
# Episode 25 (32 chemicals)
# Finished after 498 timesteps with total reward -474.8982819811712
# {'coverage_prop': '0.656', 'intensity_prop': '0.397', 'ms1ms2_ratio': '0.006', 'efficiency': '0.042', 'TP': '11', 'FP': '10', 'FN': '11', 'precision': '0.524', 'recall': '0.500', 'f1': '0.512', 'total_rewards': -474.898281981171, 'invalid_action_count': 481}
#
# Episode 26 (34 chemicals)
# Finished after 492 timesteps with total reward -423.8536864239552
# {'coverage_prop': '0.853', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.019', 'efficiency': '0.060', 'TP': '24', 'FP': '5', 'FN': '5', 'precision': '0.828', 'recall': '0.828', 'f1': '0.828', 'total_rewards': -423.8536864239551, 'invalid_action_count': 441}
#
# Episode 27 (26 chemicals)
# Finished after 496 timesteps with total reward -468.38249356743154
# {'coverage_prop': '0.885', 'intensity_prop': '0.588', 'ms1ms2_ratio': '0.010', 'efficiency': '0.047', 'TP': '15', 'FP': '8', 'FN': '3', 'precision': '0.652', 'recall': '0.833', 'f1': '0.732', 'total_rewards': -468.3824935674314, 'invalid_action_count': 474}
#
# Episode 28 (28 chemicals)
# Finished after 499 timesteps with total reward -488.76971979005214
# {'coverage_prop': '0.214', 'intensity_prop': '0.183', 'ms1ms2_ratio': '0.004', 'efficiency': '0.012', 'TP': '6', 'FP': '0', 'FN': '22', 'precision': '1.000', 'recall': '0.214', 'f1': '0.353', 'total_rewards': -488.76971979005214, 'invalid_action_count': 491}
#
# Episode 29 (34 chemicals)
# Finished after 494 timesteps with total reward -447.79574191002735
# {'coverage_prop': '0.794', 'intensity_prop': '0.515', 'ms1ms2_ratio': '0.014', 'efficiency': '0.055', 'TP': '19', 'FP': '8', 'FN': '7', 'precision': '0.704', 'recall': '0.731', 'f1': '0.717', 'total_rewards': -447.7957419100274, 'invalid_action_count': 460}
#
# method=DQN max_peaks=100 N=0 rt_tol=120 alpha=0.489231295 beta=0.07277375
#
#
# Episode 0 (28 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 0.65GB > 0.36GB
# Finished after 417 timesteps with total reward 94.20354832706923
# {'coverage_prop': '0.964', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.252', 'efficiency': '0.081', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 94.20354832706917, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 396 timesteps with total reward 90.85140164200581
# {'coverage_prop': '0.955', 'intensity_prop': '0.818', 'ms1ms2_ratio': '0.361', 'efficiency': '0.072', 'TP': '18', 'FP': '3', 'FN': '1', 'precision': '0.857', 'recall': '0.947', 'f1': '0.900', 'total_rewards': 90.85140164200573, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 386 timesteps with total reward 84.48339705686985
# {'coverage_prop': '0.978', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.430', 'efficiency': '0.163', 'TP': '37', 'FP': '7', 'FN': '1', 'precision': '0.841', 'recall': '0.974', 'f1': '0.902', 'total_rewards': 84.48339705686972, 'invalid_action_count': 1}
#
# Episode 3 (28 chemicals)
# Finished after 390 timesteps with total reward 94.29450595001205
# {'coverage_prop': '0.893', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.398', 'efficiency': '0.090', 'TP': '20', 'FP': '5', 'FN': '3', 'precision': '0.800', 'recall': '0.870', 'f1': '0.833', 'total_rewards': 94.29450595001208, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 401 timesteps with total reward 83.85298131433677
# {'coverage_prop': '1.000', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.332', 'efficiency': '0.066', 'TP': '17', 'FP': '3', 'FN': '0', 'precision': '0.850', 'recall': '1.000', 'f1': '0.919', 'total_rewards': 83.85298131433673, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 424 timesteps with total reward 88.98133596589179
# {'coverage_prop': '1.000', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.222', 'efficiency': '0.110', 'TP': '33', 'FP': '5', 'FN': '0', 'precision': '0.868', 'recall': '1.000', 'f1': '0.930', 'total_rewards': 88.9813359658918, 'invalid_action_count': 1}
#
# Episode 6 (34 chemicals)
# Finished after 411 timesteps with total reward 88.36491749675267
# {'coverage_prop': '0.971', 'intensity_prop': '0.824', 'ms1ms2_ratio': '0.280', 'efficiency': '0.103', 'TP': '29', 'FP': '4', 'FN': '1', 'precision': '0.879', 'recall': '0.967', 'f1': '0.921', 'total_rewards': 88.36491749675254, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 409 timesteps with total reward 93.60345860753444
# {'coverage_prop': '1.000', 'intensity_prop': '0.955', 'ms1ms2_ratio': '0.290', 'efficiency': '0.066', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 93.60345860753444, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 421 timesteps with total reward 91.67738636500161
# {'coverage_prop': '1.000', 'intensity_prop': '0.897', 'ms1ms2_ratio': '0.235', 'efficiency': '0.109', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958', 'total_rewards': 91.67738636500157, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 419 timesteps with total reward 57.27807770244573
# {'coverage_prop': '0.889', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.243', 'efficiency': '0.119', 'TP': '37', 'FP': '3', 'FN': '5', 'precision': '0.925', 'recall': '0.881', 'f1': '0.902', 'total_rewards': 57.27807770244567, 'invalid_action_count': 28}
#
# Episode 10 (36 chemicals)
# Finished after 421 timesteps with total reward 100.92420084920224
# {'coverage_prop': '1.000', 'intensity_prop': '0.914', 'ms1ms2_ratio': '0.235', 'efficiency': '0.106', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971', 'total_rewards': 100.92420084920224, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 397 timesteps with total reward 93.15948072145429
# {'coverage_prop': '1.000', 'intensity_prop': '0.837', 'ms1ms2_ratio': '0.355', 'efficiency': '0.157', 'TP': '40', 'FP': '6', 'FN': '0', 'precision': '0.870', 'recall': '1.000', 'f1': '0.930', 'total_rewards': 93.15948072145412, 'invalid_action_count': 0}
#
# Episode 12 (49 chemicals)
# Finished after 430 timesteps with total reward 101.8793931575005
# {'coverage_prop': '0.959', 'intensity_prop': '0.883', 'ms1ms2_ratio': '0.198', 'efficiency': '0.131', 'TP': '45', 'FP': '2', 'FN': '2', 'precision': '0.957', 'recall': '0.957', 'f1': '0.957', 'total_rewards': 101.87939315750043, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 387 timesteps with total reward 75.15788793472514
# {'coverage_prop': '1.000', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.418', 'efficiency': '0.088', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909', 'total_rewards': 75.1578879347251, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 412 timesteps with total reward 88.13181704834793
# {'coverage_prop': '0.938', 'intensity_prop': '0.850', 'ms1ms2_ratio': '0.280', 'efficiency': '0.093', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915', 'total_rewards': 88.13181704834784, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 432 timesteps with total reward 107.90384211195638
# {'coverage_prop': '1.000', 'intensity_prop': '0.898', 'ms1ms2_ratio': '0.190', 'efficiency': '0.116', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 107.90384211195631, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 399 timesteps with total reward 90.72540333156104
# {'coverage_prop': '1.000', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.343', 'efficiency': '0.084', 'TP': '20', 'FP': '5', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 90.72540333156095, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 410 timesteps with total reward 85.4100984872938
# {'coverage_prop': '1.000', 'intensity_prop': '0.820', 'ms1ms2_ratio': '0.285', 'efficiency': '0.107', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921', 'total_rewards': 85.41009848729381, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 418 timesteps with total reward 101.5544285825706
# {'coverage_prop': '0.977', 'intensity_prop': '0.844', 'ms1ms2_ratio': '0.248', 'efficiency': '0.128', 'TP': '38', 'FP': '5', 'FN': '1', 'precision': '0.884', 'recall': '0.974', 'f1': '0.927', 'total_rewards': 101.55442858257044, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 422 timesteps with total reward 89.19798427329364
# {'coverage_prop': '0.946', 'intensity_prop': '0.830', 'ms1ms2_ratio': '0.230', 'efficiency': '0.102', 'TP': '31', 'FP': '4', 'FN': '2', 'precision': '0.886', 'recall': '0.939', 'f1': '0.912', 'total_rewards': 89.19798427329347, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 403 timesteps with total reward 89.71921551620872
# {'coverage_prop': '0.957', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.321', 'efficiency': '0.072', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 89.71921551620866, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 424 timesteps with total reward 102.10669113384029
# {'coverage_prop': '0.950', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.222', 'efficiency': '0.110', 'TP': '32', 'FP': '6', 'FN': '2', 'precision': '0.842', 'recall': '0.941', 'f1': '0.889', 'total_rewards': 102.10669113384024, 'invalid_action_count': 1}
#
# Episode 22 (43 chemicals)
# Finished after 424 timesteps with total reward 90.2896991866229
# {'coverage_prop': '1.000', 'intensity_prop': '0.892', 'ms1ms2_ratio': '0.222', 'efficiency': '0.124', 'TP': '38', 'FP': '5', 'FN': '0', 'precision': '0.884', 'recall': '1.000', 'f1': '0.938', 'total_rewards': 90.28969918662288, 'invalid_action_count': 1}
#
# Episode 23 (37 chemicals)
# Finished after 416 timesteps with total reward 95.84113448788312
# {'coverage_prop': '0.973', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.257', 'efficiency': '0.109', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879', 'total_rewards': 95.84113448788315, 'invalid_action_count': 1}
#
# Episode 24 (27 chemicals)
# Finished after 400 timesteps with total reward 92.63818810815778
# {'coverage_prop': '0.963', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.338', 'efficiency': '0.087', 'TP': '21', 'FP': '5', 'FN': '1', 'precision': '0.808', 'recall': '0.955', 'f1': '0.875', 'total_rewards': 92.6381881081577, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 396 timesteps with total reward 81.13934568068328
# {'coverage_prop': '1.000', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.361', 'efficiency': '0.110', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 81.13934568068325, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 421 timesteps with total reward 101.52503588411483
# {'coverage_prop': '0.971', 'intensity_prop': '0.837', 'ms1ms2_ratio': '0.235', 'efficiency': '0.097', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903', 'total_rewards': 101.52503588411471, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 394 timesteps with total reward 79.47524325160295
# {'coverage_prop': '0.962', 'intensity_prop': '0.809', 'ms1ms2_ratio': '0.373', 'efficiency': '0.087', 'TP': '22', 'FP': '3', 'FN': '1', 'precision': '0.880', 'recall': '0.957', 'f1': '0.917', 'total_rewards': 79.47524325160289, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 407 timesteps with total reward 84.23142444825501
# {'coverage_prop': '0.964', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.300', 'efficiency': '0.086', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 84.23142444825498, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 393 timesteps with total reward 78.6252584293945
# {'coverage_prop': '0.971', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.379', 'efficiency': '0.116', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807', 'total_rewards': 78.62525842939446, 'invalid_action_count': 0}
#
# method=topN max_peaks=100 N=5 rt_tol=5 alpha=0.489231295 beta=0.07277375
#
#
# Episode 0 (28 chemicals)
# Finished after 315 timesteps with total reward 59.46619814027683
# {'coverage_prop': '0.929', 'intensity_prop': '0.841', 'ms1ms2_ratio': '1.442', 'efficiency': '0.202', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902', 'total_rewards': 59.46619814027696, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 300 timesteps with total reward 53.5138893310048
# {'coverage_prop': '1.000', 'intensity_prop': '0.811', 'ms1ms2_ratio': '2.030', 'efficiency': '0.222', 'TP': '18', 'FP': '4', 'FN': '0', 'precision': '0.818', 'recall': '1.000', 'f1': '0.900', 'total_rewards': 53.51388933100492, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 327 timesteps with total reward 63.6554854673349
# {'coverage_prop': '1.000', 'intensity_prop': '0.858', 'ms1ms2_ratio': '1.137', 'efficiency': '0.294', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 63.65548546733498, 'invalid_action_count': 0}
#
# Episode 3 (28 chemicals)
# Finished after 301 timesteps with total reward 55.5250626311525
# {'coverage_prop': '0.857', 'intensity_prop': '0.694', 'ms1ms2_ratio': '2.010', 'efficiency': '0.240', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857', 'total_rewards': 55.52506263115261, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 299 timesteps with total reward 48.40672245796188
# {'coverage_prop': '1.000', 'intensity_prop': '0.797', 'ms1ms2_ratio': '2.115', 'efficiency': '0.208', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 48.406722457962026, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 346 timesteps with total reward 66.75625959989551
# {'coverage_prop': '0.974', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.821', 'efficiency': '0.195', 'TP': '33', 'FP': '4', 'FN': '1', 'precision': '0.892', 'recall': '0.971', 'f1': '0.930', 'total_rewards': 66.75625959989559, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 336 timesteps with total reward 64.7655547196009
# {'coverage_prop': '0.971', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.965', 'efficiency': '0.193', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954', 'total_rewards': 64.76555471960103, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 316 timesteps with total reward 60.565990568711285
# {'coverage_prop': '1.000', 'intensity_prop': '0.931', 'ms1ms2_ratio': '1.431', 'efficiency': '0.162', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 60.56599056871141, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 348 timesteps with total reward 70.49563045569391
# {'coverage_prop': '1.000', 'intensity_prop': '0.894', 'ms1ms2_ratio': '0.794', 'efficiency': '0.191', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 70.49563045569393, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 351 timesteps with total reward 70.58105631968559
# {'coverage_prop': '1.000', 'intensity_prop': '0.846', 'ms1ms2_ratio': '0.746', 'efficiency': '0.224', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 70.58105631968563, 'invalid_action_count': 0}
#
# Episode 10 (36 chemicals)
# Finished after 346 timesteps with total reward 73.23628190803814
# {'coverage_prop': '1.000', 'intensity_prop': '0.912', 'ms1ms2_ratio': '0.812', 'efficiency': '0.188', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971', 'total_rewards': 73.23628190803818, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 340 timesteps with total reward 73.32440460334942
# {'coverage_prop': '0.978', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.899', 'efficiency': '0.251', 'TP': '41', 'FP': '4', 'FN': '1', 'precision': '0.911', 'recall': '0.976', 'f1': '0.943', 'total_rewards': 73.32440460334948, 'invalid_action_count': 0}
#
# Episode 12 (49 chemicals)
# Finished after 365 timesteps with total reward 79.1045959815902
# {'coverage_prop': '0.939', 'intensity_prop': '0.884', 'ms1ms2_ratio': '0.594', 'efficiency': '0.201', 'TP': '45', 'FP': '1', 'FN': '3', 'precision': '0.978', 'recall': '0.938', 'f1': '0.957', 'total_rewards': 79.10459598159024, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 306 timesteps with total reward 49.8315803697935
# {'coverage_prop': '1.000', 'intensity_prop': '0.787', 'ms1ms2_ratio': '1.782', 'efficiency': '0.218', 'TP': '19', 'FP': '5', 'FN': '0', 'precision': '0.792', 'recall': '1.000', 'f1': '0.884', 'total_rewards': 49.83158036979356, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 332 timesteps with total reward 58.444956154555754
# {'coverage_prop': '0.969', 'intensity_prop': '0.849', 'ms1ms2_ratio': '1.037', 'efficiency': '0.190', 'TP': '27', 'FP': '4', 'FN': '1', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915', 'total_rewards': 58.44495615455588, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 356 timesteps with total reward 84.87280864882888
# {'coverage_prop': '1.000', 'intensity_prop': '0.890', 'ms1ms2_ratio': '0.687', 'efficiency': '0.199', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 84.87280864882892, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 308 timesteps with total reward 55.3284299333765
# {'coverage_prop': '0.960', 'intensity_prop': '0.803', 'ms1ms2_ratio': '1.678', 'efficiency': '0.209', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889', 'total_rewards': 55.32842993337662, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 328 timesteps with total reward 61.28730769085853
# {'coverage_prop': '1.000', 'intensity_prop': '0.819', 'ms1ms2_ratio': '1.116', 'efficiency': '0.219', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 61.28730769085862, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 353 timesteps with total reward 81.26587761098504
# {'coverage_prop': '0.932', 'intensity_prop': '0.831', 'ms1ms2_ratio': '0.722', 'efficiency': '0.200', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927', 'total_rewards': 81.26587761098503, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 341 timesteps with total reward 63.08256686682545
# {'coverage_prop': '0.973', 'intensity_prop': '0.859', 'ms1ms2_ratio': '0.884', 'efficiency': '0.199', 'TP': '32', 'FP': '4', 'FN': '1', 'precision': '0.889', 'recall': '0.970', 'f1': '0.928', 'total_rewards': 63.082566866825545, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 307 timesteps with total reward 54.88477481376249
# {'coverage_prop': '0.957', 'intensity_prop': '0.781', 'ms1ms2_ratio': '1.717', 'efficiency': '0.195', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 54.88477481376264, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 343 timesteps with total reward 77.2752039898557
# {'coverage_prop': '0.925', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.854', 'efficiency': '0.200', 'TP': '32', 'FP': '5', 'FN': '3', 'precision': '0.865', 'recall': '0.914', 'f1': '0.889', 'total_rewards': 77.27520398985577, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 363 timesteps with total reward 76.57689173190468
# {'coverage_prop': '1.000', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.621', 'efficiency': '0.192', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951', 'total_rewards': 76.57689173190467, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 335 timesteps with total reward 64.51672595067845
# {'coverage_prop': '0.946', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.982', 'efficiency': '0.207', 'TP': '29', 'FP': '6', 'FN': '2', 'precision': '0.829', 'recall': '0.935', 'f1': '0.879', 'total_rewards': 64.51672595067852, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 306 timesteps with total reward 58.25991920660498
# {'coverage_prop': '0.963', 'intensity_prop': '0.760', 'ms1ms2_ratio': '1.757', 'efficiency': '0.234', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851', 'total_rewards': 58.25991920660513, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 317 timesteps with total reward 58.14292529692426
# {'coverage_prop': '1.000', 'intensity_prop': '0.853', 'ms1ms2_ratio': '1.383', 'efficiency': '0.241', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 58.14292529692437, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 345 timesteps with total reward 76.1222839716363
# {'coverage_prop': '0.941', 'intensity_prop': '0.824', 'ms1ms2_ratio': '0.825', 'efficiency': '0.169', 'TP': '28', 'FP': '4', 'FN': '2', 'precision': '0.875', 'recall': '0.933', 'f1': '0.903', 'total_rewards': 76.12228397163625, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 317 timesteps with total reward 54.503570366142945
# {'coverage_prop': '0.962', 'intensity_prop': '0.801', 'ms1ms2_ratio': '1.402', 'efficiency': '0.189', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870', 'total_rewards': 54.50357036614303, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 322 timesteps with total reward 59.8005759129908
# {'coverage_prop': '0.964', 'intensity_prop': '0.793', 'ms1ms2_ratio': '1.252', 'efficiency': '0.189', 'TP': '22', 'FP': '5', 'FN': '1', 'precision': '0.815', 'recall': '0.957', 'f1': '0.880', 'total_rewards': 59.800575912990915, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 311 timesteps with total reward 53.99749097445853
# {'coverage_prop': '0.971', 'intensity_prop': '0.689', 'ms1ms2_ratio': '1.592', 'efficiency': '0.275', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807', 'total_rewards': 53.99749097445859, 'invalid_action_count': 0}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 110),
#   'rt_range': (400, 500),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (20, 50),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd77ab971f0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd77ab973a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fd77bfe97f0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 110)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 500),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.489231295,
#   'beta': 0.07277375}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.836', 'ms1ms2_ratio': '1.504', 'efficiency': '0.208', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.828', 'ms1ms2_ratio': '2.082', 'efficiency': '0.216', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927'}
#
# Episode 2 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.859', 'ms1ms2_ratio': '1.159', 'efficiency': '0.298', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 3 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.695', 'ms1ms2_ratio': '2.030', 'efficiency': '0.242', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857'}
#
# Episode 4 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.799', 'ms1ms2_ratio': '2.194', 'efficiency': '0.215', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889'}
#
# Episode 5 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.798', 'efficiency': '0.192', 'TP': '34', 'FP': '3', 'FN': '1', 'precision': '0.919', 'recall': '0.971', 'f1': '0.944'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.863', 'ms1ms2_ratio': '1.000', 'efficiency': '0.198', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.934', 'ms1ms2_ratio': '1.442', 'efficiency': '0.163', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.900', 'ms1ms2_ratio': '0.812', 'efficiency': '0.194', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.851', 'ms1ms2_ratio': '0.772', 'efficiency': '0.228', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.911', 'ms1ms2_ratio': '0.869', 'efficiency': '0.197', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.931', 'efficiency': '0.257', 'TP': '41', 'FP': '4', 'FN': '1', 'precision': '0.911', 'recall': '0.976', 'f1': '0.943'}
#
# Episode 12 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.889', 'ms1ms2_ratio': '0.613', 'efficiency': '0.209', 'TP': '45', 'FP': '2', 'FN': '2', 'precision': '0.957', 'recall': '0.957', 'f1': '0.957'}
#
# Episode 13 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.786', 'ms1ms2_ratio': '1.841', 'efficiency': '0.224', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 14 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.848', 'ms1ms2_ratio': '1.075', 'efficiency': '0.189', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.890', 'ms1ms2_ratio': '0.722', 'efficiency': '0.205', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.803', 'ms1ms2_ratio': '1.782', 'efficiency': '0.218', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.827', 'ms1ms2_ratio': '1.181', 'efficiency': '0.228', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921'}
#
# Episode 18 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.836', 'ms1ms2_ratio': '0.734', 'efficiency': '0.202', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.931', 'efficiency': '0.206', 'TP': '31', 'FP': '5', 'FN': '1', 'precision': '0.861', 'recall': '0.969', 'f1': '0.912'}
#
# Episode 20 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.780', 'ms1ms2_ratio': '1.782', 'efficiency': '0.200', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850'}
#
# Episode 21 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.811', 'ms1ms2_ratio': '0.899', 'efficiency': '0.207', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.897', 'ms1ms2_ratio': '0.654', 'efficiency': '0.198', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951'}
#
# Episode 23 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.786', 'ms1ms2_ratio': '1.037', 'efficiency': '0.215', 'TP': '30', 'FP': '5', 'FN': '2', 'precision': '0.857', 'recall': '0.938', 'f1': '0.896'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.754', 'ms1ms2_ratio': '1.824', 'efficiency': '0.241', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.864', 'ms1ms2_ratio': '1.412', 'efficiency': '0.244', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.840', 'efficiency': '0.176', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.805', 'ms1ms2_ratio': '1.472', 'efficiency': '0.197', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.797', 'ms1ms2_ratio': '1.268', 'efficiency': '0.190', 'TP': '22', 'FP': '5', 'FN': '1', 'precision': '0.815', 'recall': '0.957', 'f1': '0.880'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.690', 'ms1ms2_ratio': '1.678', 'efficiency': '0.287', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.808', 'ms1ms2_ratio': '4.612', 'efficiency': '0.531', 'TP': '22', 'FP': '4', 'FN': '2', 'precision': '0.846', 'recall': '0.917', 'f1': '0.880'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.752', 'ms1ms2_ratio': '5.923', 'efficiency': '0.538', 'TP': '15', 'FP': '6', 'FN': '1', 'precision': '0.714', 'recall': '0.938', 'f1': '0.811'}
#
# Episode 2 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.825', 'ms1ms2_ratio': '2.892', 'efficiency': '0.595', 'TP': '37', 'FP': '7', 'FN': '1', 'precision': '0.841', 'recall': '0.974', 'f1': '0.902'}
#
# Episode 3 finished
# {'coverage_prop': '0.821', 'intensity_prop': '0.632', 'ms1ms2_ratio': '5.610', 'efficiency': '0.561', 'TP': '17', 'FP': '6', 'FN': '5', 'precision': '0.739', 'recall': '0.773', 'f1': '0.756'}
#
# Episode 4 finished
# {'coverage_prop': '0.850', 'intensity_prop': '0.730', 'ms1ms2_ratio': '6.105', 'efficiency': '0.447', 'TP': '14', 'FP': '3', 'FN': '3', 'precision': '0.824', 'recall': '0.824', 'f1': '0.824'}
#
# Episode 5 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.807', 'ms1ms2_ratio': '2.803', 'efficiency': '0.487', 'TP': '30', 'FP': '7', 'FN': '1', 'precision': '0.811', 'recall': '0.968', 'f1': '0.882'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.819', 'ms1ms2_ratio': '3.191', 'efficiency': '0.485', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.925', 'ms1ms2_ratio': '4.612', 'efficiency': '0.429', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.877', 'ms1ms2_ratio': '2.753', 'efficiency': '0.481', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.844', 'ms1ms2_ratio': '2.447', 'efficiency': '0.529', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.902', 'ms1ms2_ratio': '2.840', 'efficiency': '0.480', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.848', 'ms1ms2_ratio': '2.671', 'efficiency': '0.582', 'TP': '40', 'FP': '6', 'FN': '0', 'precision': '0.870', 'recall': '1.000', 'f1': '0.930'}
#
# Episode 12 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.842', 'ms1ms2_ratio': '2.253', 'efficiency': '0.505', 'TP': '44', 'FP': '2', 'FN': '3', 'precision': '0.957', 'recall': '0.936', 'f1': '0.946'}
#
# Episode 13 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.742', 'ms1ms2_ratio': '5.326', 'efficiency': '0.535', 'TP': '19', 'FP': '4', 'FN': '1', 'precision': '0.826', 'recall': '0.950', 'f1': '0.884'}
#
# Episode 14 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.838', 'ms1ms2_ratio': '3.476', 'efficiency': '0.476', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.846', 'ms1ms2_ratio': '2.447', 'efficiency': '0.494', 'TP': '35', 'FP': '7', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.786', 'ms1ms2_ratio': '4.957', 'efficiency': '0.522', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.733', 'ms1ms2_ratio': '3.828', 'efficiency': '0.552', 'TP': '25', 'FP': '7', 'FN': '2', 'precision': '0.781', 'recall': '0.926', 'f1': '0.847'}
#
# Episode 18 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.772', 'ms1ms2_ratio': '2.593', 'efficiency': '0.519', 'TP': '35', 'FP': '7', 'FN': '2', 'precision': '0.833', 'recall': '0.946', 'f1': '0.886'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.795', 'ms1ms2_ratio': '3.130', 'efficiency': '0.522', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879'}
#
# Episode 20 finished
# {'coverage_prop': '0.913', 'intensity_prop': '0.695', 'ms1ms2_ratio': '5.476', 'efficiency': '0.500', 'TP': '15', 'FP': '6', 'FN': '2', 'precision': '0.714', 'recall': '0.882', 'f1': '0.789'}
#
# Episode 21 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.750', 'ms1ms2_ratio': '2.840', 'efficiency': '0.493', 'TP': '30', 'FP': '7', 'FN': '3', 'precision': '0.811', 'recall': '0.909', 'f1': '0.857'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.868', 'ms1ms2_ratio': '2.315', 'efficiency': '0.483', 'TP': '37', 'FP': '6', 'FN': '0', 'precision': '0.860', 'recall': '1.000', 'f1': '0.925'}
#
# Episode 23 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.765', 'ms1ms2_ratio': '3.239', 'efficiency': '0.537', 'TP': '28', 'FP': '8', 'FN': '1', 'precision': '0.778', 'recall': '0.966', 'f1': '0.862'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.717', 'ms1ms2_ratio': '5.205', 'efficiency': '0.591', 'TP': '19', 'FP': '7', 'FN': '1', 'precision': '0.731', 'recall': '0.950', 'f1': '0.826'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.826', 'ms1ms2_ratio': '3.828', 'efficiency': '0.552', 'TP': '25', 'FP': '7', 'FN': '0', 'precision': '0.781', 'recall': '1.000', 'f1': '0.877'}
#
# Episode 26 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.808', 'ms1ms2_ratio': '2.932', 'efficiency': '0.438', 'TP': '27', 'FP': '5', 'FN': '2', 'precision': '0.844', 'recall': '0.931', 'f1': '0.885'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.793', 'ms1ms2_ratio': '4.412', 'efficiency': '0.490', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.728', 'ms1ms2_ratio': '4.055', 'efficiency': '0.491', 'TP': '19', 'FP': '8', 'FN': '1', 'precision': '0.704', 'recall': '0.950', 'f1': '0.809'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.626', 'ms1ms2_ratio': '4.957', 'efficiency': '0.717', 'TP': '20', 'FP': '13', 'FN': '1', 'precision': '0.606', 'recall': '0.952', 'f1': '0.741'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.846', 'ms1ms2_ratio': '0.854', 'efficiency': '0.141', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.826', 'ms1ms2_ratio': '1.252', 'efficiency': '0.147', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927'}
#
# Episode 2 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.772', 'efficiency': '0.228', 'TP': '38', 'FP': '7', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.916'}
#
# Episode 3 finished
# {'coverage_prop': '0.893', 'intensity_prop': '0.702', 'ms1ms2_ratio': '1.277', 'efficiency': '0.177', 'TP': '20', 'FP': '5', 'FN': '3', 'precision': '0.800', 'recall': '0.870', 'f1': '0.833'}
#
# Episode 4 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.806', 'ms1ms2_ratio': '1.252', 'efficiency': '0.140', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889'}
#
# Episode 5 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.861', 'ms1ms2_ratio': '0.430', 'efficiency': '0.141', 'TP': '33', 'FP': '5', 'FN': '0', 'precision': '0.868', 'recall': '1.000', 'f1': '0.930'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.869', 'ms1ms2_ratio': '0.594', 'efficiency': '0.144', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.954', 'ms1ms2_ratio': '0.798', 'efficiency': '0.109', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.905', 'ms1ms2_ratio': '0.438', 'efficiency': '0.139', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.452', 'efficiency': '0.171', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.912', 'ms1ms2_ratio': '0.460', 'efficiency': '0.138', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.865', 'ms1ms2_ratio': '0.575', 'efficiency': '0.197', 'TP': '41', 'FP': '5', 'FN': '0', 'precision': '0.891', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 12 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.898', 'ms1ms2_ratio': '0.338', 'efficiency': '0.161', 'TP': '45', 'FP': '3', 'FN': '1', 'precision': '0.938', 'recall': '0.978', 'f1': '0.957'}
#
# Episode 13 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.788', 'ms1ms2_ratio': '1.075', 'efficiency': '0.151', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 14 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.604', 'efficiency': '0.137', 'TP': '27', 'FP': '4', 'FN': '1', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.398', 'efficiency': '0.151', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.812', 'ms1ms2_ratio': '1.018', 'efficiency': '0.145', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.836', 'ms1ms2_ratio': '0.676', 'efficiency': '0.160', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921'}
#
# Episode 18 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.834', 'ms1ms2_ratio': '0.416', 'efficiency': '0.150', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.539', 'efficiency': '0.149', 'TP': '32', 'FP': '4', 'FN': '1', 'precision': '0.889', 'recall': '0.970', 'f1': '0.928'}
#
# Episode 20 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.779', 'ms1ms2_ratio': '1.000', 'efficiency': '0.132', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850'}
#
# Episode 21 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.460', 'efficiency': '0.146', 'TP': '33', 'FP': '5', 'FN': '2', 'precision': '0.868', 'recall': '0.943', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.906', 'ms1ms2_ratio': '0.338', 'efficiency': '0.144', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951'}
#
# Episode 23 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.594', 'efficiency': '0.157', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.759', 'ms1ms2_ratio': '1.056', 'efficiency': '0.161', 'TP': '21', 'FP': '5', 'FN': '1', 'precision': '0.808', 'recall': '0.955', 'f1': '0.875'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.869', 'efficiency': '0.175', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.835', 'ms1ms2_ratio': '0.465', 'efficiency': '0.123', 'TP': '28', 'FP': '4', 'FN': '2', 'precision': '0.875', 'recall': '0.933', 'f1': '0.903'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.854', 'efficiency': '0.135', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.710', 'efficiency': '0.130', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.685', 'ms1ms2_ratio': '1.018', 'efficiency': '0.200', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    -475.901973                 481.0          0.714           0.528
# 1  random    -465.993458                 474.0          0.727           0.617
# 2  random    -431.756070                 446.0          0.867           0.710
# 3  random    -460.620745                 468.0          0.393           0.225
# 4  random    -467.327361                 475.0          0.900           0.646
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.040      0.750   0.652  0.698
# 1          0.012       0.033      0.938   0.714  0.811
# 2          0.019       0.081      0.846   0.846  0.846
# 3          0.014       0.023      0.455   0.227  0.303
# 4          0.008       0.037      0.722   0.867  0.788

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_5.0E5.p')

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_5.0E5.p')

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN      94.203548                   0.0          0.964           0.852
# 31    DQN      90.851402                   0.0          0.955           0.818
# 32    DQN      84.483397                   1.0          0.978           0.799
# 33    DQN      94.294506                   0.0          0.893           0.699
# 34    DQN      83.852981                   0.0          1.000           0.802
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.252       0.081      0.852   0.958  0.902
# 31          0.361       0.072      0.857   0.947  0.900
# 32          0.430       0.163      0.841   0.974  0.902
# 33          0.398       0.090      0.800   0.870  0.833
# 34          0.332       0.066      0.850   1.000  0.919

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
