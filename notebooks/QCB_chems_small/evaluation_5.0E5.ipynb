# %% [markdown]
# # Evaluation using QCB chemicals (small)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns
import copy

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_small
alpha = 0.50
beta = 0.00
extract = False
params, max_peaks = preset_qcb_small(None, alpha=alpha, beta=beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2022-09-05 21:33:22.208 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_small_gaussian.p
# ({'chemical_creator': {'mz_range': (100, 110),
#    'rt_range': (400, 500),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (20, 50),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb81d41ee50>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb81d41e9a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fb81fc6a820>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 110)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 500),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.0}},
#  100)

# %%
# n_chemicals = (20, 50)
# mz_range = (100, 110)
# rt_range = (400, 500)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 100
in_dir = '../../tune/QCB_chems_small'
out_dir = 'evaluation_5.0E5'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30
repeat = 5

# %%
# topN parameters
topN_N = 5
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 1
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 120
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_small.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 28
# 22
# 45
# 28
# 20
# 38
# 34
# 21
# 37
# 45
# 36
# 46
# 49
# 24
# 32
# 42
# 25
# 34
# 44
# 37
# 23
# 40
# 43
# 37
# 27
# 32
# 34
# 26
# 28
# 34

# %% [markdown]
# Generate new chemicals if not found

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    min_mz = mz_range[0]
    max_mz = mz_range[1]
    min_rt = rt_range[0]
    max_rt = rt_range[1]
    min_log_intensity = np.log(intensity_range[0])
    max_log_intensity = np.log(intensity_range[1])
    
    mzml_filename = '../fullscan_QCB.mzML'
    logger.info('Creating samplers from %s' % mzml_filename)
    mz_sampler = MZMLFormulaSampler(mzml_filename, min_mz=min_mz, max_mz=max_mz)
    ri_sampler = MZMLRTandIntensitySampler(mzml_filename, min_rt=min_rt, max_rt=max_rt,
                                           min_log_intensity=min_log_intensity,
                                           max_log_intensity=max_log_intensity)
    
    # roi_params = RoiBuilderParams(min_roi_length=3, at_least_one_point_above=1000)
    # cr_sampler = MZMLChromatogramSampler(mzml_filename, roi_params=roi_params)
    cr_sampler = GaussianChromatogramSampler()
    
    chemical_creator_params = {
        'mz_range': mz_range,
        'rt_range': rt_range,
        'intensity_range': intensity_range,
        'n_chemicals': n_chemicals,
        'mz_sampler': mz_sampler,
        'ri_sampler': ri_sampler,
        'cr_sampler': cr_sampler
    }

    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 110),
#   'rt_range': (400, 500),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (20, 50),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb81d41ee50>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb81d41e9a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fb81fc6a820>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 110)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 500),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.0}}

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)           
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        for i in range(repeat):
            alpha = 0.50
            beta = 0.00
            model_dir = os.path.join(METHOD_DQN)
            fname = os.path.join(model_dir, 'DDAEnv_DQN_Balanced_%d.zip' % i)
            model = DQN.load(fname, custom_objects=custom_objects)
            copy_params['env']['alpha'] = alpha
            copy_params['env']['beta'] = beta                

            banner = 'method=%s_%d max_peaks=%d N=%d rt_tol=%d alpha=%s beta=%s' % (
                method, i, max_peaks, N, copy_params['env']['rt_tol'], 
                str(copy_params['env']['alpha']), 
                str(copy_params['env']['beta']))
            print(banner)
            print()            

            episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                          N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                          print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                          mzml_prefix=method)
            eval_results = [er.eval_res for er in episodic_results]
            method_eval_results['%s_%d' % (method, i)] = eval_results
            print()
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params['env']['rt_tol'] = effective_rt_tol                        

        banner = 'method=%s max_peaks=%d N=%d rt_tol=%d alpha=%s beta=%s' % (
            method, max_peaks, N, copy_params['env']['rt_tol'], 
            str(copy_params['env']['alpha']), 
            str(copy_params['env']['beta']))
        print(banner)
        print()            

        episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                      N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                      print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                      mzml_prefix=method)
        eval_results = [er.eval_res for er in episodic_results]
        method_eval_results[method] = eval_results
        print()
# Out:
# method=random max_peaks=100 N=0 rt_tol=120 alpha=0.5 beta=0.0
#
#
# Episode 0 (28 chemicals)
# Finished after 496 timesteps with total reward -468.09129476933924
# {'coverage_prop': '0.786', 'intensity_prop': '0.501', 'ms1ms2_ratio': '0.010', 'efficiency': '0.045', 'TP': '13', 'FP': '9', 'FN': '6', 'precision': '0.591', 'recall': '0.684', 'f1': '0.634', 'total_rewards': -468.0912947693392, 'invalid_action_count': 476}
#
# Episode 1 (22 chemicals)
# Finished after 497 timesteps with total reward -464.8062751060641
# {'coverage_prop': '0.773', 'intensity_prop': '0.498', 'ms1ms2_ratio': '0.008', 'efficiency': '0.034', 'TP': '10', 'FP': '7', 'FN': '5', 'precision': '0.588', 'recall': '0.667', 'f1': '0.625', 'total_rewards': -464.8062751060641, 'invalid_action_count': 473}
#
# Episode 2 (45 chemicals)
# Finished after 496 timesteps with total reward -456.6409727536644
# {'coverage_prop': '0.822', 'intensity_prop': '0.653', 'ms1ms2_ratio': '0.010', 'efficiency': '0.075', 'TP': '30', 'FP': '7', 'FN': '8', 'precision': '0.811', 'recall': '0.789', 'f1': '0.800', 'total_rewards': -456.64097275366447, 'invalid_action_count': 468}
#
# Episode 3 (28 chemicals)
# Finished after 497 timesteps with total reward -481.17049545780037
# {'coverage_prop': '0.214', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.008', 'efficiency': '0.012', 'TP': '4', 'FP': '2', 'FN': '22', 'precision': '0.667', 'recall': '0.154', 'f1': '0.250', 'total_rewards': -481.1704954578004, 'invalid_action_count': 485}
#
# Episode 4 (20 chemicals)
# Finished after 495 timesteps with total reward -451.7618541322463
# {'coverage_prop': '0.850', 'intensity_prop': '0.661', 'ms1ms2_ratio': '0.012', 'efficiency': '0.035', 'TP': '13', 'FP': '4', 'FN': '3', 'precision': '0.765', 'recall': '0.812', 'f1': '0.788', 'total_rewards': -451.76185413224636, 'invalid_action_count': 462}
#
# Episode 5 (38 chemicals)
# Finished after 494 timesteps with total reward -449.3932147110327
# {'coverage_prop': '0.868', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.014', 'efficiency': '0.068', 'TP': '21', 'FP': '12', 'FN': '5', 'precision': '0.636', 'recall': '0.808', 'f1': '0.712', 'total_rewards': -449.39321471103267, 'invalid_action_count': 460}
#
# Episode 6 (34 chemicals)
# Finished after 489 timesteps with total reward -439.1640767181833
# {'coverage_prop': '0.824', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.025', 'efficiency': '0.059', 'TP': '27', 'FP': '1', 'FN': '6', 'precision': '0.964', 'recall': '0.818', 'f1': '0.885', 'total_rewards': -439.1640767181832, 'invalid_action_count': 450}
#
# Episode 7 (21 chemicals)
# Finished after 493 timesteps with total reward -445.4040282665468
# {'coverage_prop': '1.000', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.016', 'efficiency': '0.043', 'TP': '17', 'FP': '4', 'FN': '0', 'precision': '0.810', 'recall': '1.000', 'f1': '0.895', 'total_rewards': -445.4040282665467, 'invalid_action_count': 457}
#
# Episode 8 (37 chemicals)
# Finished after 497 timesteps with total reward -465.73716802931256
# {'coverage_prop': '0.892', 'intensity_prop': '0.503', 'ms1ms2_ratio': '0.008', 'efficiency': '0.067', 'TP': '19', 'FP': '14', 'FN': '4', 'precision': '0.576', 'recall': '0.826', 'f1': '0.679', 'total_rewards': -465.7371680293125, 'invalid_action_count': 475}
#
# Episode 9 (45 chemicals)
# Finished after 491 timesteps with total reward -420.21415610984116
# {'coverage_prop': '0.911', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.021', 'efficiency': '0.085', 'TP': '33', 'FP': '8', 'FN': '4', 'precision': '0.805', 'recall': '0.892', 'f1': '0.846', 'total_rewards': -420.214156109841, 'invalid_action_count': 437}
#
# Episode 10 (36 chemicals)
# Finished after 495 timesteps with total reward -438.7724796069233
# {'coverage_prop': '0.972', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.012', 'efficiency': '0.072', 'TP': '30', 'FP': '5', 'FN': '1', 'precision': '0.857', 'recall': '0.968', 'f1': '0.909', 'total_rewards': -438.77247960692324, 'invalid_action_count': 455}
#
# Episode 11 (46 chemicals)
# Finished after 495 timesteps with total reward -442.50584748849474
# {'coverage_prop': '0.891', 'intensity_prop': '0.621', 'ms1ms2_ratio': '0.012', 'efficiency': '0.084', 'TP': '31', 'FP': '10', 'FN': '5', 'precision': '0.756', 'recall': '0.861', 'f1': '0.805', 'total_rewards': -442.5058474884947, 'invalid_action_count': 457}
#
# Episode 12 (49 chemicals)
# Finished after 497 timesteps with total reward -456.79959361296767
# {'coverage_prop': '0.857', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.008', 'efficiency': '0.085', 'TP': '29', 'FP': '13', 'FN': '7', 'precision': '0.690', 'recall': '0.806', 'f1': '0.744', 'total_rewards': -456.7995936129675, 'invalid_action_count': 466}
#
# Episode 13 (24 chemicals)
# Finished after 496 timesteps with total reward -468.5677104785368
# {'coverage_prop': '0.875', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.010', 'efficiency': '0.043', 'TP': '15', 'FP': '6', 'FN': '3', 'precision': '0.714', 'recall': '0.833', 'f1': '0.769', 'total_rewards': -468.56771047853675, 'invalid_action_count': 476}
#
# Episode 14 (32 chemicals)
# Finished after 495 timesteps with total reward -434.0584189817854
# {'coverage_prop': '0.938', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.012', 'efficiency': '0.061', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915', 'total_rewards': -434.05841898178545, 'invalid_action_count': 448}
#
# Episode 15 (42 chemicals)
# Finished after 494 timesteps with total reward -412.361662921426
# {'coverage_prop': '0.952', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.014', 'efficiency': '0.082', 'TP': '33', 'FP': '7', 'FN': '2', 'precision': '0.825', 'recall': '0.943', 'f1': '0.880', 'total_rewards': -412.36166292142605, 'invalid_action_count': 434}
#
# Episode 16 (25 chemicals)
# Finished after 498 timesteps with total reward -467.7207643803394
# {'coverage_prop': '0.600', 'intensity_prop': '0.397', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '9', 'FP': '6', 'FN': '10', 'precision': '0.600', 'recall': '0.474', 'f1': '0.529', 'total_rewards': -467.72076438033946, 'invalid_action_count': 475}
#
# Episode 17 (34 chemicals)
# Finished after 496 timesteps with total reward -445.9547038470538
# {'coverage_prop': '0.853', 'intensity_prop': '0.682', 'ms1ms2_ratio': '0.010', 'efficiency': '0.059', 'TP': '23', 'FP': '6', 'FN': '5', 'precision': '0.793', 'recall': '0.821', 'f1': '0.807', 'total_rewards': -445.9547038470538, 'invalid_action_count': 460}
#
# Episode 18 (44 chemicals)
# Finished after 498 timesteps with total reward -453.59512439848265
# {'coverage_prop': '0.818', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.006', 'efficiency': '0.073', 'TP': '22', 'FP': '14', 'FN': '8', 'precision': '0.611', 'recall': '0.733', 'f1': '0.667', 'total_rewards': -453.59512439848265, 'invalid_action_count': 468}
#
# Episode 19 (37 chemicals)
# Finished after 499 timesteps with total reward -476.372244807823
# {'coverage_prop': '0.595', 'intensity_prop': '0.326', 'ms1ms2_ratio': '0.004', 'efficiency': '0.044', 'TP': '12', 'FP': '10', 'FN': '15', 'precision': '0.545', 'recall': '0.444', 'f1': '0.490', 'total_rewards': -476.37224480782294, 'invalid_action_count': 482}
#
# Episode 20 (23 chemicals)
# Finished after 495 timesteps with total reward -453.4269686274198
# {'coverage_prop': '0.826', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.012', 'efficiency': '0.039', 'TP': '12', 'FP': '7', 'FN': '4', 'precision': '0.632', 'recall': '0.750', 'f1': '0.686', 'total_rewards': -453.42696862741974, 'invalid_action_count': 464}
#
# Episode 21 (40 chemicals)
# Finished after 496 timesteps with total reward -438.01423053880876
# {'coverage_prop': '0.775', 'intensity_prop': '0.562', 'ms1ms2_ratio': '0.010', 'efficiency': '0.063', 'TP': '23', 'FP': '8', 'FN': '9', 'precision': '0.742', 'recall': '0.719', 'f1': '0.730', 'total_rewards': -438.01423053880876, 'invalid_action_count': 454}
#
# Episode 22 (43 chemicals)
# Finished after 492 timesteps with total reward -397.3987820493868
# {'coverage_prop': '0.953', 'intensity_prop': '0.813', 'ms1ms2_ratio': '0.019', 'efficiency': '0.085', 'TP': '37', 'FP': '4', 'FN': '2', 'precision': '0.902', 'recall': '0.949', 'f1': '0.925', 'total_rewards': -397.39878204938685, 'invalid_action_count': 423}
#
# Episode 23 (37 chemicals)
# Finished after 493 timesteps with total reward -445.34755540538487
# {'coverage_prop': '0.757', 'intensity_prop': '0.579', 'ms1ms2_ratio': '0.016', 'efficiency': '0.058', 'TP': '22', 'FP': '6', 'FN': '9', 'precision': '0.786', 'recall': '0.710', 'f1': '0.746', 'total_rewards': -445.34755540538487, 'invalid_action_count': 458}
#
# Episode 24 (27 chemicals)
# Finished after 493 timesteps with total reward -446.43672092774307
# {'coverage_prop': '0.741', 'intensity_prop': '0.508', 'ms1ms2_ratio': '0.016', 'efficiency': '0.041', 'TP': '13', 'FP': '7', 'FN': '7', 'precision': '0.650', 'recall': '0.650', 'f1': '0.650', 'total_rewards': -446.4367209277431, 'invalid_action_count': 459}
#
# Episode 25 (32 chemicals)
# Finished after 498 timesteps with total reward -468.321877665839
# {'coverage_prop': '0.781', 'intensity_prop': '0.545', 'ms1ms2_ratio': '0.006', 'efficiency': '0.051', 'TP': '19', 'FP': '6', 'FN': '7', 'precision': '0.760', 'recall': '0.731', 'f1': '0.745', 'total_rewards': -468.321877665839, 'invalid_action_count': 477}
#
# Episode 26 (34 chemicals)
# Finished after 491 timesteps with total reward -425.5518378242631
# {'coverage_prop': '0.882', 'intensity_prop': '0.678', 'ms1ms2_ratio': '0.021', 'efficiency': '0.062', 'TP': '25', 'FP': '5', 'FN': '4', 'precision': '0.833', 'recall': '0.862', 'f1': '0.847', 'total_rewards': -425.55183782426315, 'invalid_action_count': 442}
#
# Episode 27 (26 chemicals)
# Finished after 497 timesteps with total reward -476.4420642477304
# {'coverage_prop': '0.885', 'intensity_prop': '0.623', 'ms1ms2_ratio': '0.008', 'efficiency': '0.047', 'TP': '17', 'FP': '6', 'FN': '3', 'precision': '0.739', 'recall': '0.850', 'f1': '0.791', 'total_rewards': -476.4420642477305, 'invalid_action_count': 481}
#
# Episode 28 (28 chemicals)
# Finished after 494 timesteps with total reward -449.3401746486948
# {'coverage_prop': '0.571', 'intensity_prop': '0.399', 'ms1ms2_ratio': '0.014', 'efficiency': '0.033', 'TP': '11', 'FP': '5', 'FN': '12', 'precision': '0.688', 'recall': '0.478', 'f1': '0.564', 'total_rewards': -449.34017464869476, 'invalid_action_count': 458}
#
# Episode 29 (34 chemicals)
# Finished after 493 timesteps with total reward -437.0799734077269
# {'coverage_prop': '0.853', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.016', 'efficiency': '0.060', 'TP': '21', 'FP': '8', 'FN': '5', 'precision': '0.724', 'recall': '0.808', 'f1': '0.764', 'total_rewards': -437.079973407727, 'invalid_action_count': 451}
#
# method=DQN_0 max_peaks=100 N=0 rt_tol=120 alpha=0.5 beta=0.0
#
#
# Episode 0 (28 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 6.47GB > 0.61GB
# Finished after 416 timesteps with total reward 101.19397670531528
# {'coverage_prop': '0.964', 'intensity_prop': '0.847', 'ms1ms2_ratio': '0.257', 'efficiency': '0.082', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 101.19397670531524, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 395 timesteps with total reward 93.0827909061793
# {'coverage_prop': '0.955', 'intensity_prop': '0.834', 'ms1ms2_ratio': '0.367', 'efficiency': '0.073', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927', 'total_rewards': 93.0827909061793, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 404 timesteps with total reward 92.6319368846793
# {'coverage_prop': '0.978', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.316', 'efficiency': '0.143', 'TP': '40', 'FP': '4', 'FN': '1', 'precision': '0.909', 'recall': '0.976', 'f1': '0.941', 'total_rewards': 92.63193688467929, 'invalid_action_count': 2}
#
# Episode 3 (28 chemicals)
# Finished after 393 timesteps with total reward 99.89421422336216
# {'coverage_prop': '0.929', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.379', 'efficiency': '0.091', 'TP': '21', 'FP': '5', 'FN': '2', 'precision': '0.808', 'recall': '0.913', 'f1': '0.857', 'total_rewards': 99.89421422336208, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 403 timesteps with total reward 90.0738873307231
# {'coverage_prop': '1.000', 'intensity_prop': '0.809', 'ms1ms2_ratio': '0.321', 'efficiency': '0.066', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 90.07388733072291, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 430 timesteps with total reward 98.17459642896782
# {'coverage_prop': '0.974', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.198', 'efficiency': '0.103', 'TP': '33', 'FP': '4', 'FN': '1', 'precision': '0.892', 'recall': '0.971', 'f1': '0.930', 'total_rewards': 98.1745964289678, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 419 timesteps with total reward 93.04023799785864
# {'coverage_prop': '1.000', 'intensity_prop': '0.860', 'ms1ms2_ratio': '0.243', 'efficiency': '0.101', 'TP': '30', 'FP': '4', 'FN': '0', 'precision': '0.882', 'recall': '1.000', 'f1': '0.938', 'total_rewards': 93.04023799785861, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 407 timesteps with total reward 95.19638902349287
# {'coverage_prop': '1.000', 'intensity_prop': '0.917', 'ms1ms2_ratio': '0.300', 'efficiency': '0.067', 'TP': '19', 'FP': '2', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 95.19638902349271, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 419 timesteps with total reward 101.42601017515624
# {'coverage_prop': '1.000', 'intensity_prop': '0.902', 'ms1ms2_ratio': '0.243', 'efficiency': '0.110', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958', 'total_rewards': 101.42601017515625, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 416 timesteps with total reward 96.06487232918364
# {'coverage_prop': '1.000', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.257', 'efficiency': '0.136', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 96.0648723291836, 'invalid_action_count': 1}
#
# Episode 10 (36 chemicals)
# Finished after 417 timesteps with total reward 104.90434265711986
# {'coverage_prop': '1.000', 'intensity_prop': '0.905', 'ms1ms2_ratio': '0.252', 'efficiency': '0.108', 'TP': '33', 'FP': '3', 'FN': '0', 'precision': '0.917', 'recall': '1.000', 'f1': '0.957', 'total_rewards': 104.90434265711981, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 416 timesteps with total reward 91.78455983318676
# {'coverage_prop': '1.000', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.257', 'efficiency': '0.139', 'TP': '41', 'FP': '5', 'FN': '0', 'precision': '0.891', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 91.78455983318669, 'invalid_action_count': 10}
#
# Episode 12 (49 chemicals)
# Finished after 433 timesteps with total reward 100.36236235733747
# {'coverage_prop': '0.980', 'intensity_prop': '0.892', 'ms1ms2_ratio': '0.186', 'efficiency': '0.132', 'TP': '45', 'FP': '3', 'FN': '1', 'precision': '0.938', 'recall': '0.978', 'f1': '0.957', 'total_rewards': 100.36236235733739, 'invalid_action_count': 4}
#
# Episode 13 (24 chemicals)
# Finished after 396 timesteps with total reward 80.91575024866594
# {'coverage_prop': '1.000', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.361', 'efficiency': '0.082', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909', 'total_rewards': 80.91575024866589, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 419 timesteps with total reward 90.49836902638506
# {'coverage_prop': '1.000', 'intensity_prop': '0.858', 'ms1ms2_ratio': '0.247', 'efficiency': '0.095', 'TP': '27', 'FP': '5', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.915', 'total_rewards': 90.49836902638505, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 434 timesteps with total reward 116.71971068016461
# {'coverage_prop': '1.000', 'intensity_prop': '0.886', 'ms1ms2_ratio': '0.183', 'efficiency': '0.114', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 116.71971068016461, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 399 timesteps with total reward 91.7290088934734
# {'coverage_prop': '1.000', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.343', 'efficiency': '0.084', 'TP': '20', 'FP': '5', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 91.72900889347333, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 419 timesteps with total reward 93.31970617121108
# {'coverage_prop': '1.000', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.243', 'efficiency': '0.101', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 93.31970617121097, 'invalid_action_count': 1}
#
# Episode 18 (44 chemicals)
# Finished after 418 timesteps with total reward 109.07075366390379
# {'coverage_prop': '0.977', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.248', 'efficiency': '0.128', 'TP': '39', 'FP': '4', 'FN': '1', 'precision': '0.907', 'recall': '0.975', 'f1': '0.940', 'total_rewards': 109.07075366390367, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 425 timesteps with total reward 98.98366503271367
# {'coverage_prop': '0.973', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.218', 'efficiency': '0.103', 'TP': '33', 'FP': '3', 'FN': '1', 'precision': '0.917', 'recall': '0.971', 'f1': '0.943', 'total_rewards': 98.98366503271357, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 409 timesteps with total reward 97.21588027478758
# {'coverage_prop': '0.957', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.290', 'efficiency': '0.069', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 97.21588027478758, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 427 timesteps with total reward 107.93351872266236
# {'coverage_prop': '0.925', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.210', 'efficiency': '0.105', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904', 'total_rewards': 107.93351872266231, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 427 timesteps with total reward 98.1136946370217
# {'coverage_prop': '1.000', 'intensity_prop': '0.903', 'ms1ms2_ratio': '0.210', 'efficiency': '0.122', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951', 'total_rewards': 98.11369463702162, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 418 timesteps with total reward 104.1727374247935
# {'coverage_prop': '0.973', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.248', 'efficiency': '0.107', 'TP': '30', 'FP': '6', 'FN': '1', 'precision': '0.833', 'recall': '0.968', 'f1': '0.896', 'total_rewards': 104.17273742479343, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 401 timesteps with total reward 94.7797376532337
# {'coverage_prop': '1.000', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.332', 'efficiency': '0.090', 'TP': '20', 'FP': '7', 'FN': '0', 'precision': '0.741', 'recall': '1.000', 'f1': '0.851', 'total_rewards': 94.77973765323364, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 401 timesteps with total reward 89.44887722340242
# {'coverage_prop': '1.000', 'intensity_prop': '0.863', 'ms1ms2_ratio': '0.332', 'efficiency': '0.106', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 89.44887722340235, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 431 timesteps with total reward 113.78435597507928
# {'coverage_prop': '0.971', 'intensity_prop': '0.840', 'ms1ms2_ratio': '0.194', 'efficiency': '0.091', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903', 'total_rewards': 113.78435597507917, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 397 timesteps with total reward 84.0575634215607
# {'coverage_prop': '0.962', 'intensity_prop': '0.818', 'ms1ms2_ratio': '0.355', 'efficiency': '0.085', 'TP': '21', 'FP': '4', 'FN': '1', 'precision': '0.840', 'recall': '0.955', 'f1': '0.894', 'total_rewards': 84.0575634215606, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 408 timesteps with total reward 89.13211968976044
# {'coverage_prop': '0.964', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.295', 'efficiency': '0.086', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 89.13211968976042, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 398 timesteps with total reward 84.87024348627072
# {'coverage_prop': '0.941', 'intensity_prop': '0.681', 'ms1ms2_ratio': '0.349', 'efficiency': '0.108', 'TP': '24', 'FP': '8', 'FN': '2', 'precision': '0.750', 'recall': '0.923', 'f1': '0.828', 'total_rewards': 84.87024348627075, 'invalid_action_count': 0}
#
# method=DQN_1 max_peaks=100 N=0 rt_tol=120 alpha=0.5 beta=0.0
#
#
# Episode 0 (28 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 6.47GB > 0.58GB
# Finished after 405 timesteps with total reward 95.13748200516963
# {'coverage_prop': '0.964', 'intensity_prop': '0.843', 'ms1ms2_ratio': '0.311', 'efficiency': '0.087', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 95.1374820051696, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 381 timesteps with total reward 87.95733996109249
# {'coverage_prop': '0.955', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.460', 'efficiency': '0.080', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927', 'total_rewards': 87.95733996109244, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 394 timesteps with total reward 94.4983130467828
# {'coverage_prop': '1.000', 'intensity_prop': '0.850', 'ms1ms2_ratio': '0.373', 'efficiency': '0.157', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 94.49831304678281, 'invalid_action_count': 1}
#
# Episode 3 (28 chemicals)
# Finished after 387 timesteps with total reward 98.85183281181834
# {'coverage_prop': '0.893', 'intensity_prop': '0.692', 'ms1ms2_ratio': '0.418', 'efficiency': '0.092', 'TP': '21', 'FP': '4', 'FN': '3', 'precision': '0.840', 'recall': '0.875', 'f1': '0.857', 'total_rewards': 98.85183281181831, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 395 timesteps with total reward 89.12875360179709
# {'coverage_prop': '1.000', 'intensity_prop': '0.813', 'ms1ms2_ratio': '0.372', 'efficiency': '0.069', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 89.12875360179696, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 419 timesteps with total reward 97.31990179725965
# {'coverage_prop': '1.000', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.243', 'efficiency': '0.113', 'TP': '34', 'FP': '4', 'FN': '0', 'precision': '0.895', 'recall': '1.000', 'f1': '0.944', 'total_rewards': 97.31990179725963, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 412 timesteps with total reward 93.75916562001422
# {'coverage_prop': '1.000', 'intensity_prop': '0.864', 'ms1ms2_ratio': '0.276', 'efficiency': '0.105', 'TP': '31', 'FP': '3', 'FN': '0', 'precision': '0.912', 'recall': '1.000', 'f1': '0.954', 'total_rewards': 93.75916562001417, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 408 timesteps with total reward 96.50994108508844
# {'coverage_prop': '1.000', 'intensity_prop': '0.947', 'ms1ms2_ratio': '0.295', 'efficiency': '0.067', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 96.50994108508829, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 407 timesteps with total reward 98.46477215641795
# {'coverage_prop': '1.000', 'intensity_prop': '0.901', 'ms1ms2_ratio': '0.300', 'efficiency': '0.118', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958', 'total_rewards': 98.4647721564178, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 413 timesteps with total reward 95.95931279470773
# {'coverage_prop': '0.978', 'intensity_prop': '0.848', 'ms1ms2_ratio': '0.271', 'efficiency': '0.135', 'TP': '39', 'FP': '5', 'FN': '1', 'precision': '0.886', 'recall': '0.975', 'f1': '0.929', 'total_rewards': 95.95931279470771, 'invalid_action_count': 0}
#
# Episode 10 (36 chemicals)
# Finished after 408 timesteps with total reward 96.10835195065931
# {'coverage_prop': '1.000', 'intensity_prop': '0.909', 'ms1ms2_ratio': '0.295', 'efficiency': '0.114', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971', 'total_rewards': 96.1083519506592, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 406 timesteps with total reward 93.21635242270375
# {'coverage_prop': '1.000', 'intensity_prop': '0.871', 'ms1ms2_ratio': '0.305', 'efficiency': '0.148', 'TP': '41', 'FP': '5', 'FN': '0', 'precision': '0.891', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 93.21635242270366, 'invalid_action_count': 4}
#
# Episode 12 (49 chemicals)
# Finished after 417 timesteps with total reward 102.79443206729609
# {'coverage_prop': '0.939', 'intensity_prop': '0.887', 'ms1ms2_ratio': '0.252', 'efficiency': '0.138', 'TP': '45', 'FP': '1', 'FN': '3', 'precision': '0.978', 'recall': '0.938', 'f1': '0.957', 'total_rewards': 102.79443206729599, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 386 timesteps with total reward 77.76084359407673
# {'coverage_prop': '1.000', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.424', 'efficiency': '0.089', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909', 'total_rewards': 77.76084359407665, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 407 timesteps with total reward 89.48741859004741
# {'coverage_prop': '1.000', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.300', 'efficiency': '0.102', 'TP': '27', 'FP': '5', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.915', 'total_rewards': 89.48741859004743, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 426 timesteps with total reward 108.1260416051727
# {'coverage_prop': '1.000', 'intensity_prop': '0.884', 'ms1ms2_ratio': '0.214', 'efficiency': '0.120', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 108.12604160517257, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 394 timesteps with total reward 91.1110706524689
# {'coverage_prop': '1.000', 'intensity_prop': '0.811', 'ms1ms2_ratio': '0.373', 'efficiency': '0.087', 'TP': '20', 'FP': '5', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 91.11107065246891, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 410 timesteps with total reward 91.71900082912795
# {'coverage_prop': '0.971', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.285', 'efficiency': '0.103', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903', 'total_rewards': 91.71900082912782, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 408 timesteps with total reward 104.5440554911448
# {'coverage_prop': '0.977', 'intensity_prop': '0.833', 'ms1ms2_ratio': '0.295', 'efficiency': '0.137', 'TP': '38', 'FP': '5', 'FN': '1', 'precision': '0.884', 'recall': '0.974', 'f1': '0.927', 'total_rewards': 104.54405549114479, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 422 timesteps with total reward 90.16932487399436
# {'coverage_prop': '1.000', 'intensity_prop': '0.859', 'ms1ms2_ratio': '0.230', 'efficiency': '0.108', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 90.1693248739943, 'invalid_action_count': 1}
#
# Episode 20 (23 chemicals)
# Finished after 397 timesteps with total reward 91.44577553088047
# {'coverage_prop': '0.957', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.355', 'efficiency': '0.075', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 91.44577553088051, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 423 timesteps with total reward 106.04178212743514
# {'coverage_prop': '0.925', 'intensity_prop': '0.812', 'ms1ms2_ratio': '0.226', 'efficiency': '0.107', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904', 'total_rewards': 106.0417821274351, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 418 timesteps with total reward 93.4843794634871
# {'coverage_prop': '1.000', 'intensity_prop': '0.904', 'ms1ms2_ratio': '0.251', 'efficiency': '0.129', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951', 'total_rewards': 93.48437946348707, 'invalid_action_count': 1}
#
# Episode 23 (37 chemicals)
# Finished after 410 timesteps with total reward 95.84133810039594
# {'coverage_prop': '0.946', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.285', 'efficiency': '0.110', 'TP': '30', 'FP': '5', 'FN': '2', 'precision': '0.857', 'recall': '0.938', 'f1': '0.896', 'total_rewards': 95.8413381003959, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 391 timesteps with total reward 93.08249966504974
# {'coverage_prop': '0.963', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.391', 'efficiency': '0.093', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851', 'total_rewards': 93.08249966504977, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 393 timesteps with total reward 89.91154403041344
# {'coverage_prop': '1.000', 'intensity_prop': '0.860', 'ms1ms2_ratio': '0.379', 'efficiency': '0.112', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 89.91154403041335, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 417 timesteps with total reward 107.294875798839
# {'coverage_prop': '1.000', 'intensity_prop': '0.838', 'ms1ms2_ratio': '0.252', 'efficiency': '0.102', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 107.29487579883896, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 388 timesteps with total reward 82.48041563428869
# {'coverage_prop': '0.962', 'intensity_prop': '0.821', 'ms1ms2_ratio': '0.416', 'efficiency': '0.091', 'TP': '21', 'FP': '4', 'FN': '1', 'precision': '0.840', 'recall': '0.955', 'f1': '0.894', 'total_rewards': 82.48041563428862, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 394 timesteps with total reward 86.09228775500759
# {'coverage_prop': '1.000', 'intensity_prop': '0.832', 'ms1ms2_ratio': '0.373', 'efficiency': '0.098', 'TP': '24', 'FP': '4', 'FN': '0', 'precision': '0.857', 'recall': '1.000', 'f1': '0.923', 'total_rewards': 86.09228775500758, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 390 timesteps with total reward 78.94608171801448
# {'coverage_prop': '1.000', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.398', 'efficiency': '0.122', 'TP': '23', 'FP': '11', 'FN': '0', 'precision': '0.676', 'recall': '1.000', 'f1': '0.807', 'total_rewards': 78.94608171801448, 'invalid_action_count': 0}
#
# method=DQN_2 max_peaks=100 N=0 rt_tol=120 alpha=0.5 beta=0.0
#
#
# Episode 0 (28 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 6.47GB > 0.56GB
# Finished after 430 timesteps with total reward 100.55284273548142
# {'coverage_prop': '0.964', 'intensity_prop': '0.849', 'ms1ms2_ratio': '0.201', 'efficiency': '0.075', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 100.55284273548135, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 403 timesteps with total reward 96.59511851861959
# {'coverage_prop': '0.955', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.321', 'efficiency': '0.069', 'TP': '18', 'FP': '3', 'FN': '1', 'precision': '0.857', 'recall': '0.947', 'f1': '0.900', 'total_rewards': 96.59511851861963, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 404 timesteps with total reward 97.07477312902212
# {'coverage_prop': '0.978', 'intensity_prop': '0.840', 'ms1ms2_ratio': '0.316', 'efficiency': '0.143', 'TP': '37', 'FP': '7', 'FN': '1', 'precision': '0.841', 'recall': '0.974', 'f1': '0.902', 'total_rewards': 97.07477312902203, 'invalid_action_count': 0}
#
# Episode 3 (28 chemicals)
# Finished after 396 timesteps with total reward 104.3623051151304
# {'coverage_prop': '0.893', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.361', 'efficiency': '0.086', 'TP': '21', 'FP': '4', 'FN': '3', 'precision': '0.840', 'recall': '0.875', 'f1': '0.857', 'total_rewards': 104.3623051151304, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 410 timesteps with total reward 91.36167042982538
# {'coverage_prop': '1.000', 'intensity_prop': '0.820', 'ms1ms2_ratio': '0.285', 'efficiency': '0.063', 'TP': '17', 'FP': '3', 'FN': '0', 'precision': '0.850', 'recall': '1.000', 'f1': '0.919', 'total_rewards': 91.3616704298253, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 433 timesteps with total reward 98.24839200770442
# {'coverage_prop': '1.000', 'intensity_prop': '0.861', 'ms1ms2_ratio': '0.186', 'efficiency': '0.104', 'TP': '33', 'FP': '5', 'FN': '0', 'precision': '0.868', 'recall': '1.000', 'f1': '0.930', 'total_rewards': 98.2483920077044, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 422 timesteps with total reward 97.61405195026572
# {'coverage_prop': '0.971', 'intensity_prop': '0.869', 'ms1ms2_ratio': '0.230', 'efficiency': '0.096', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954', 'total_rewards': 97.61405195026573, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 419 timesteps with total reward 100.7388496416369
# {'coverage_prop': '1.000', 'intensity_prop': '0.952', 'ms1ms2_ratio': '0.243', 'efficiency': '0.062', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 100.73884964163679, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 425 timesteps with total reward 103.15639946752924
# {'coverage_prop': '1.000', 'intensity_prop': '0.898', 'ms1ms2_ratio': '0.218', 'efficiency': '0.106', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958', 'total_rewards': 103.15639946752917, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 425 timesteps with total reward 97.64232922317203
# {'coverage_prop': '1.000', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.218', 'efficiency': '0.129', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 97.64232922317206, 'invalid_action_count': 0}
#
# Episode 10 (36 chemicals)
# Finished after 423 timesteps with total reward 105.4268877188342
# {'coverage_prop': '0.972', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.226', 'efficiency': '0.101', 'TP': '33', 'FP': '2', 'FN': '1', 'precision': '0.943', 'recall': '0.971', 'f1': '0.957', 'total_rewards': 105.42688771883415, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 411 timesteps with total reward 106.89640276091643
# {'coverage_prop': '1.000', 'intensity_prop': '0.849', 'ms1ms2_ratio': '0.280', 'efficiency': '0.143', 'TP': '41', 'FP': '5', 'FN': '0', 'precision': '0.891', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 106.89640276091636, 'invalid_action_count': 0}
#
# Episode 12 (49 chemicals)
# Finished after 436 timesteps with total reward 109.8823668320075
# {'coverage_prop': '0.939', 'intensity_prop': '0.886', 'ms1ms2_ratio': '0.175', 'efficiency': '0.124', 'TP': '45', 'FP': '1', 'FN': '3', 'precision': '0.978', 'recall': '0.938', 'f1': '0.957', 'total_rewards': 109.88236683200742, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 397 timesteps with total reward 81.77889466805668
# {'coverage_prop': '1.000', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.355', 'efficiency': '0.082', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909', 'total_rewards': 81.77889466805662, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 422 timesteps with total reward 92.54736319628961
# {'coverage_prop': '0.938', 'intensity_prop': '0.850', 'ms1ms2_ratio': '0.230', 'efficiency': '0.087', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915', 'total_rewards': 92.54736319628961, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 437 timesteps with total reward 118.689050622399
# {'coverage_prop': '1.000', 'intensity_prop': '0.891', 'ms1ms2_ratio': '0.172', 'efficiency': '0.113', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 118.68905062239902, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 412 timesteps with total reward 95.12364111110827
# {'coverage_prop': '1.000', 'intensity_prop': '0.816', 'ms1ms2_ratio': '0.276', 'efficiency': '0.077', 'TP': '20', 'FP': '5', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 95.12364111110814, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 419 timesteps with total reward 93.71629193738892
# {'coverage_prop': '1.000', 'intensity_prop': '0.823', 'ms1ms2_ratio': '0.243', 'efficiency': '0.101', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 93.71629193738887, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 424 timesteps with total reward 110.98942576886259
# {'coverage_prop': '0.955', 'intensity_prop': '0.837', 'ms1ms2_ratio': '0.222', 'efficiency': '0.121', 'TP': '38', 'FP': '4', 'FN': '2', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927', 'total_rewards': 110.98942576886246, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 430 timesteps with total reward 96.90579979666737
# {'coverage_prop': '0.973', 'intensity_prop': '0.858', 'ms1ms2_ratio': '0.198', 'efficiency': '0.100', 'TP': '33', 'FP': '3', 'FN': '1', 'precision': '0.917', 'recall': '0.971', 'f1': '0.943', 'total_rewards': 96.90579979666734, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 416 timesteps with total reward 101.29626712757265
# {'coverage_prop': '0.957', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.257', 'efficiency': '0.066', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 101.2962671275726, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 431 timesteps with total reward 110.50007231053937
# {'coverage_prop': '0.925', 'intensity_prop': '0.813', 'ms1ms2_ratio': '0.194', 'efficiency': '0.102', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904', 'total_rewards': 110.50007231053925, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 430 timesteps with total reward 100.66627686110746
# {'coverage_prop': '1.000', 'intensity_prop': '0.888', 'ms1ms2_ratio': '0.198', 'efficiency': '0.120', 'TP': '38', 'FP': '5', 'FN': '0', 'precision': '0.884', 'recall': '1.000', 'f1': '0.938', 'total_rewards': 100.66627686110735, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 426 timesteps with total reward 106.08129950521834
# {'coverage_prop': '0.973', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.214', 'efficiency': '0.103', 'TP': '30', 'FP': '6', 'FN': '1', 'precision': '0.833', 'recall': '0.968', 'f1': '0.896', 'total_rewards': 106.08129950521825, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 409 timesteps with total reward 95.51507297751229
# {'coverage_prop': '0.963', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.290', 'efficiency': '0.082', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851', 'total_rewards': 95.51507297751225, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 402 timesteps with total reward 91.84572278156023
# {'coverage_prop': '1.000', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.327', 'efficiency': '0.106', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 91.84572278156011, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 429 timesteps with total reward 112.09221593230004
# {'coverage_prop': '1.000', 'intensity_prop': '0.842', 'ms1ms2_ratio': '0.202', 'efficiency': '0.095', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 112.09221593230001, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 403 timesteps with total reward 86.18730099461692
# {'coverage_prop': '0.962', 'intensity_prop': '0.813', 'ms1ms2_ratio': '0.321', 'efficiency': '0.082', 'TP': '21', 'FP': '4', 'FN': '1', 'precision': '0.840', 'recall': '0.955', 'f1': '0.894', 'total_rewards': 86.18730099461679, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 413 timesteps with total reward 93.99003600456021
# {'coverage_prop': '0.964', 'intensity_prop': '0.821', 'ms1ms2_ratio': '0.271', 'efficiency': '0.083', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902', 'total_rewards': 93.99003600456011, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 401 timesteps with total reward 82.75807208354829
# {'coverage_prop': '1.000', 'intensity_prop': '0.697', 'ms1ms2_ratio': '0.332', 'efficiency': '0.113', 'TP': '24', 'FP': '10', 'FN': '0', 'precision': '0.706', 'recall': '1.000', 'f1': '0.828', 'total_rewards': 82.75807208354831, 'invalid_action_count': 0}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 6.47GB > 0.55GB
# method=DQN_3 max_peaks=100 N=0 rt_tol=120 alpha=0.5 beta=0.0
#
#
# Episode 0 (28 chemicals)
# Finished after 415 timesteps with total reward 98.95836036999272
# {'coverage_prop': '0.964', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.261', 'efficiency': '0.082', 'TP': '24', 'FP': '3', 'FN': '1', 'precision': '0.889', 'recall': '0.960', 'f1': '0.923', 'total_rewards': 98.95836036999266, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 392 timesteps with total reward 87.45113831014811
# {'coverage_prop': '0.955', 'intensity_prop': '0.821', 'ms1ms2_ratio': '0.385', 'efficiency': '0.074', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927', 'total_rewards': 87.45113831014814, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 402 timesteps with total reward 95.60611257645141
# {'coverage_prop': '0.978', 'intensity_prop': '0.850', 'ms1ms2_ratio': '0.331', 'efficiency': '0.146', 'TP': '39', 'FP': '5', 'FN': '1', 'precision': '0.886', 'recall': '0.975', 'f1': '0.929', 'total_rewards': 95.60611257645135, 'invalid_action_count': 2}
#
# Episode 3 (28 chemicals)
# Finished after 388 timesteps with total reward 97.36509876747374
# {'coverage_prop': '0.857', 'intensity_prop': '0.704', 'ms1ms2_ratio': '0.411', 'efficiency': '0.087', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857', 'total_rewards': 97.36509876747373, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 400 timesteps with total reward 87.65326288970813
# {'coverage_prop': '1.000', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.338', 'efficiency': '0.067', 'TP': '17', 'FP': '3', 'FN': '0', 'precision': '0.850', 'recall': '1.000', 'f1': '0.919', 'total_rewards': 87.653262889708, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 424 timesteps with total reward 95.55987617181452
# {'coverage_prop': '0.974', 'intensity_prop': '0.844', 'ms1ms2_ratio': '0.222', 'efficiency': '0.107', 'TP': '33', 'FP': '4', 'FN': '1', 'precision': '0.892', 'recall': '0.971', 'f1': '0.930', 'total_rewards': 95.55987617181454, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 416 timesteps with total reward 96.01236555879069
# {'coverage_prop': '0.971', 'intensity_prop': '0.841', 'ms1ms2_ratio': '0.257', 'efficiency': '0.100', 'TP': '30', 'FP': '3', 'FN': '1', 'precision': '0.909', 'recall': '0.968', 'f1': '0.937', 'total_rewards': 96.01236555879069, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 406 timesteps with total reward 99.60082777606792
# {'coverage_prop': '1.000', 'intensity_prop': '0.956', 'ms1ms2_ratio': '0.305', 'efficiency': '0.068', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 99.60082777606787, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 421 timesteps with total reward 102.35554708600183
# {'coverage_prop': '1.000', 'intensity_prop': '0.905', 'ms1ms2_ratio': '0.235', 'efficiency': '0.109', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958', 'total_rewards': 102.35554708600178, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 420 timesteps with total reward 96.04301502203941
# {'coverage_prop': '1.000', 'intensity_prop': '0.845', 'ms1ms2_ratio': '0.239', 'efficiency': '0.133', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 96.04301502203944, 'invalid_action_count': 1}
#
# Episode 10 (36 chemicals)
# Finished after 413 timesteps with total reward 101.60788895920999
# {'coverage_prop': '1.000', 'intensity_prop': '0.898', 'ms1ms2_ratio': '0.271', 'efficiency': '0.111', 'TP': '33', 'FP': '3', 'FN': '0', 'precision': '0.917', 'recall': '1.000', 'f1': '0.957', 'total_rewards': 101.60788895920994, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 406 timesteps with total reward 93.75996434344361
# {'coverage_prop': '1.000', 'intensity_prop': '0.827', 'ms1ms2_ratio': '0.305', 'efficiency': '0.148', 'TP': '39', 'FP': '7', 'FN': '0', 'precision': '0.848', 'recall': '1.000', 'f1': '0.918', 'total_rewards': 93.75996434344351, 'invalid_action_count': 2}
#
# Episode 12 (49 chemicals)
# Finished after 428 timesteps with total reward 102.83408224904004
# {'coverage_prop': '0.939', 'intensity_prop': '0.881', 'ms1ms2_ratio': '0.206', 'efficiency': '0.130', 'TP': '45', 'FP': '1', 'FN': '3', 'precision': '0.978', 'recall': '0.938', 'f1': '0.957', 'total_rewards': 102.83408224903998, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 388 timesteps with total reward 78.0562381939396
# {'coverage_prop': '1.000', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.411', 'efficiency': '0.087', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909', 'total_rewards': 78.05623819393956, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 413 timesteps with total reward 88.7700515854268
# ...
# Finished after 406 timesteps with total reward 90.06600439971534
# {'coverage_prop': '1.000', 'intensity_prop': '0.855', 'ms1ms2_ratio': '0.310', 'efficiency': '0.103', 'TP': '27', 'FP': '5', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.915', 'total_rewards': 90.0660043997153, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 426 timesteps with total reward 105.33154461660547
# {'coverage_prop': '1.000', 'intensity_prop': '0.896', 'ms1ms2_ratio': '0.214', 'efficiency': '0.120', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 105.33154461660538, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 393 timesteps with total reward 88.75580536867793
# {'coverage_prop': '1.000', 'intensity_prop': '0.805', 'ms1ms2_ratio': '0.379', 'efficiency': '0.088', 'TP': '20', 'FP': '5', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 88.75580536867788, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 403 timesteps with total reward 90.95031410029462
# {'coverage_prop': '1.000', 'intensity_prop': '0.819', 'ms1ms2_ratio': '0.321', 'efficiency': '0.111', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 90.95031410029458, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 414 timesteps with total reward 104.92815063186511
# {'coverage_prop': '0.932', 'intensity_prop': '0.840', 'ms1ms2_ratio': '0.266', 'efficiency': '0.125', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927', 'total_rewards': 104.92815063186498, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 414 timesteps with total reward 88.62442082587151
# {'coverage_prop': '1.000', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.266', 'efficiency': '0.113', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 88.62442082587148, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 392 timesteps with total reward 95.54689465745874
# {'coverage_prop': '0.957', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.385', 'efficiency': '0.078', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 95.54689465745871, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 417 timesteps with total reward 103.07758303156963
# {'coverage_prop': '0.925', 'intensity_prop': '0.803', 'ms1ms2_ratio': '0.252', 'efficiency': '0.111', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904', 'total_rewards': 103.07758303156957, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 421 timesteps with total reward 93.61763317826802
# {'coverage_prop': '1.000', 'intensity_prop': '0.900', 'ms1ms2_ratio': '0.235', 'efficiency': '0.126', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951', 'total_rewards': 93.61763317826797, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 414 timesteps with total reward 102.61620592566257
# {'coverage_prop': '0.973', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.266', 'efficiency': '0.110', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879', 'total_rewards': 102.61620592566253, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 389 timesteps with total reward 95.39836259195545
# {'coverage_prop': '1.000', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.404', 'efficiency': '0.097', 'TP': '20', 'FP': '7', 'FN': '0', 'precision': '0.741', 'recall': '1.000', 'f1': '0.851', 'total_rewards': 95.3983625919554, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 389 timesteps with total reward 86.04553944685475
# {'coverage_prop': '1.000', 'intensity_prop': '0.860', 'ms1ms2_ratio': '0.404', 'efficiency': '0.116', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 86.04553944685469, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 418 timesteps with total reward 106.21423009445141
# {'coverage_prop': '0.971', 'intensity_prop': '0.835', 'ms1ms2_ratio': '0.248', 'efficiency': '0.099', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903', 'total_rewards': 106.21423009445125, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 386 timesteps with total reward 80.37087058539639
# {'coverage_prop': '0.962', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.424', 'efficiency': '0.092', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870', 'total_rewards': 80.37087058539636, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 391 timesteps with total reward 86.1169400970102
# {'coverage_prop': '1.000', 'intensity_prop': '0.803', 'ms1ms2_ratio': '0.391', 'efficiency': '0.100', 'TP': '23', 'FP': '5', 'FN': '0', 'precision': '0.821', 'recall': '1.000', 'f1': '0.902', 'total_rewards': 86.11694009701017, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 383 timesteps with total reward 82.78852576316685
# {'coverage_prop': '0.971', 'intensity_prop': '0.682', 'ms1ms2_ratio': '0.451', 'efficiency': '0.125', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807', 'total_rewards': 82.78852576316683, 'invalid_action_count': 0}
#
# method=topN max_peaks=100 N=5 rt_tol=5 alpha=0.5 beta=0.0
#
#
# Episode 0 (28 chemicals)
# Finished after 315 timesteps with total reward 61.17442287534608
# {'coverage_prop': '0.929', 'intensity_prop': '0.841', 'ms1ms2_ratio': '1.442', 'efficiency': '0.202', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902', 'total_rewards': 61.174422875346174, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 300 timesteps with total reward 54.93953816632201
# {'coverage_prop': '1.000', 'intensity_prop': '0.811', 'ms1ms2_ratio': '2.030', 'efficiency': '0.222', 'TP': '18', 'FP': '4', 'FN': '0', 'precision': '0.818', 'recall': '1.000', 'f1': '0.900', 'total_rewards': 54.939538166322166, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 327 timesteps with total reward 65.6026161560831
# {'coverage_prop': '1.000', 'intensity_prop': '0.858', 'ms1ms2_ratio': '1.137', 'efficiency': '0.294', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 65.60261615608319, 'invalid_action_count': 0}
#
# Episode 3 (28 chemicals)
# Finished after 301 timesteps with total reward 57.19257460733454
# {'coverage_prop': '0.857', 'intensity_prop': '0.694', 'ms1ms2_ratio': '2.010', 'efficiency': '0.240', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857', 'total_rewards': 57.19257460733465, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 299 timesteps with total reward 49.73472772476311
# {'coverage_prop': '1.000', 'intensity_prop': '0.797', 'ms1ms2_ratio': '2.115', 'efficiency': '0.208', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 49.734727724763275, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 346 timesteps with total reward 69.20031921121962
# {'coverage_prop': '0.974', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.821', 'efficiency': '0.195', 'TP': '33', 'FP': '4', 'FN': '1', 'precision': '0.892', 'recall': '0.971', 'f1': '0.930', 'total_rewards': 69.20031921121968, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 336 timesteps with total reward 67.0472612176383
# {'coverage_prop': '0.971', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.965', 'efficiency': '0.193', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954', 'total_rewards': 67.04726121763831, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 316 timesteps with total reward 62.43634859858056
# {'coverage_prop': '1.000', 'intensity_prop': '0.931', 'ms1ms2_ratio': '1.431', 'efficiency': '0.162', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 62.43634859858072, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 348 timesteps with total reward 73.0697614491364
# {'coverage_prop': '1.000', 'intensity_prop': '0.894', 'ms1ms2_ratio': '0.794', 'efficiency': '0.191', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 73.06976144913644, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 351 timesteps with total reward 73.25626014096987
# {'coverage_prop': '1.000', 'intensity_prop': '0.846', 'ms1ms2_ratio': '0.746', 'efficiency': '0.224', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 73.25626014096989, 'invalid_action_count': 0}
#
# Episode 10 (36 chemicals)
# Finished after 346 timesteps with total reward 75.92925596595795
# {'coverage_prop': '1.000', 'intensity_prop': '0.912', 'ms1ms2_ratio': '0.812', 'efficiency': '0.188', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971', 'total_rewards': 75.929255965958, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 340 timesteps with total reward 75.72104875321048
# {'coverage_prop': '0.978', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.899', 'efficiency': '0.251', 'TP': '41', 'FP': '4', 'FN': '1', 'precision': '0.911', 'recall': '0.976', 'f1': '0.943', 'total_rewards': 75.72104875321054, 'invalid_action_count': 0}
#
# Episode 12 (49 chemicals)
# Finished after 365 timesteps with total reward 82.40646181948064
# {'coverage_prop': '0.939', 'intensity_prop': '0.884', 'ms1ms2_ratio': '0.594', 'efficiency': '0.201', 'TP': '45', 'FP': '1', 'FN': '3', 'precision': '0.978', 'recall': '0.938', 'f1': '0.957', 'total_rewards': 82.40646181948068, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 306 timesteps with total reward 51.18142772051577
# {'coverage_prop': '1.000', 'intensity_prop': '0.787', 'ms1ms2_ratio': '1.782', 'efficiency': '0.218', 'TP': '19', 'FP': '5', 'FN': '0', 'precision': '0.792', 'recall': '1.000', 'f1': '0.884', 'total_rewards': 51.181427720515856, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 332 timesteps with total reward 60.36153904020036
# {'coverage_prop': '0.969', 'intensity_prop': '0.849', 'ms1ms2_ratio': '1.037', 'efficiency': '0.190', 'TP': '27', 'FP': '4', 'FN': '1', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915', 'total_rewards': 60.36153904020042, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 356 timesteps with total reward 88.03956793504261
# {'coverage_prop': '1.000', 'intensity_prop': '0.890', 'ms1ms2_ratio': '0.687', 'efficiency': '0.199', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 88.0395679350426, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 308 timesteps with total reward 56.93787348422798
# {'coverage_prop': '0.960', 'intensity_prop': '0.803', 'ms1ms2_ratio': '1.678', 'efficiency': '0.209', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889', 'total_rewards': 56.93787348422811, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 328 timesteps with total reward 62.922955539486274
# {'coverage_prop': '1.000', 'intensity_prop': '0.819', 'ms1ms2_ratio': '1.116', 'efficiency': '0.219', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 62.92295553948638, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 353 timesteps with total reward 84.40813593630972
# {'coverage_prop': '0.932', 'intensity_prop': '0.831', 'ms1ms2_ratio': '0.722', 'efficiency': '0.200', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927', 'total_rewards': 84.40813593630969, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 341 timesteps with total reward 65.12260898804507
# {'coverage_prop': '0.973', 'intensity_prop': '0.859', 'ms1ms2_ratio': '0.884', 'efficiency': '0.199', 'TP': '32', 'FP': '4', 'FN': '1', 'precision': '0.889', 'recall': '0.970', 'f1': '0.928', 'total_rewards': 65.12260898804513, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 307 timesteps with total reward 56.54268513002949
# {'coverage_prop': '0.957', 'intensity_prop': '0.781', 'ms1ms2_ratio': '1.717', 'efficiency': '0.195', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 56.542685130029625, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 343 timesteps with total reward 79.98383961183666
# {'coverage_prop': '0.925', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.854', 'efficiency': '0.200', 'TP': '32', 'FP': '5', 'FN': '3', 'precision': '0.865', 'recall': '0.914', 'f1': '0.889', 'total_rewards': 79.98383961183666, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 363 timesteps with total reward 79.44066215433402
# {'coverage_prop': '1.000', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.621', 'efficiency': '0.192', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951', 'total_rewards': 79.44066215433399, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 335 timesteps with total reward 66.73502580566459
# {'coverage_prop': '0.946', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.982', 'efficiency': '0.207', 'TP': '29', 'FP': '6', 'FN': '2', 'precision': '0.829', 'recall': '0.935', 'f1': '0.879', 'total_rewards': 66.7350258056646, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 306 timesteps with total reward 59.857298875125494
# {'coverage_prop': '0.963', 'intensity_prop': '0.760', 'ms1ms2_ratio': '1.757', 'efficiency': '0.234', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851', 'total_rewards': 59.85729887512564, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 317 timesteps with total reward 59.74569023030225
# {'coverage_prop': '1.000', 'intensity_prop': '0.853', 'ms1ms2_ratio': '1.383', 'efficiency': '0.241', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 59.745690230302365, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 345 timesteps with total reward 78.9015857642151
# {'coverage_prop': '0.941', 'intensity_prop': '0.824', 'ms1ms2_ratio': '0.825', 'efficiency': '0.169', 'TP': '28', 'FP': '4', 'FN': '2', 'precision': '0.875', 'recall': '0.933', 'f1': '0.903', 'total_rewards': 78.90158576421508, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 317 timesteps with total reward 56.174531186673136
# {'coverage_prop': '0.962', 'intensity_prop': '0.801', 'ms1ms2_ratio': '1.402', 'efficiency': '0.189', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870', 'total_rewards': 56.174531186673185, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 322 timesteps with total reward 61.77843915625374
# {'coverage_prop': '0.964', 'intensity_prop': '0.793', 'ms1ms2_ratio': '1.252', 'efficiency': '0.189', 'TP': '22', 'FP': '5', 'FN': '1', 'precision': '0.815', 'recall': '0.957', 'f1': '0.880', 'total_rewards': 61.77843915625384, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 311 timesteps with total reward 55.3513459443793
# {'coverage_prop': '0.971', 'intensity_prop': '0.689', 'ms1ms2_ratio': '1.592', 'efficiency': '0.275', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807', 'total_rewards': 55.351345944379396, 'invalid_action_count': 0}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 110),
#   'rt_range': (400, 500),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (20, 50),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb81d41ee50>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb81d41e9a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fb81fc6a820>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 110)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 500),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.836', 'ms1ms2_ratio': '1.504', 'efficiency': '0.208', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.828', 'ms1ms2_ratio': '2.082', 'efficiency': '0.216', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927'}
#
# Episode 2 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.859', 'ms1ms2_ratio': '1.159', 'efficiency': '0.298', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 3 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.695', 'ms1ms2_ratio': '2.030', 'efficiency': '0.242', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857'}
#
# Episode 4 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.799', 'ms1ms2_ratio': '2.194', 'efficiency': '0.215', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889'}
#
# Episode 5 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.798', 'efficiency': '0.192', 'TP': '34', 'FP': '3', 'FN': '1', 'precision': '0.919', 'recall': '0.971', 'f1': '0.944'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.863', 'ms1ms2_ratio': '1.000', 'efficiency': '0.198', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.934', 'ms1ms2_ratio': '1.442', 'efficiency': '0.163', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.900', 'ms1ms2_ratio': '0.812', 'efficiency': '0.194', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.851', 'ms1ms2_ratio': '0.772', 'efficiency': '0.228', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.911', 'ms1ms2_ratio': '0.869', 'efficiency': '0.197', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.931', 'efficiency': '0.257', 'TP': '41', 'FP': '4', 'FN': '1', 'precision': '0.911', 'recall': '0.976', 'f1': '0.943'}
#
# Episode 12 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.889', 'ms1ms2_ratio': '0.613', 'efficiency': '0.209', 'TP': '45', 'FP': '2', 'FN': '2', 'precision': '0.957', 'recall': '0.957', 'f1': '0.957'}
#
# Episode 13 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.786', 'ms1ms2_ratio': '1.841', 'efficiency': '0.224', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 14 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.848', 'ms1ms2_ratio': '1.075', 'efficiency': '0.189', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.890', 'ms1ms2_ratio': '0.722', 'efficiency': '0.205', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.803', 'ms1ms2_ratio': '1.782', 'efficiency': '0.218', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.827', 'ms1ms2_ratio': '1.181', 'efficiency': '0.228', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921'}
#
# Episode 18 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.836', 'ms1ms2_ratio': '0.734', 'efficiency': '0.202', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.931', 'efficiency': '0.206', 'TP': '31', 'FP': '5', 'FN': '1', 'precision': '0.861', 'recall': '0.969', 'f1': '0.912'}
#
# Episode 20 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.780', 'ms1ms2_ratio': '1.782', 'efficiency': '0.200', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850'}
#
# Episode 21 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.811', 'ms1ms2_ratio': '0.899', 'efficiency': '0.207', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.897', 'ms1ms2_ratio': '0.654', 'efficiency': '0.198', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951'}
#
# Episode 23 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.786', 'ms1ms2_ratio': '1.037', 'efficiency': '0.215', 'TP': '30', 'FP': '5', 'FN': '2', 'precision': '0.857', 'recall': '0.938', 'f1': '0.896'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.754', 'ms1ms2_ratio': '1.824', 'efficiency': '0.241', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.864', 'ms1ms2_ratio': '1.412', 'efficiency': '0.244', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.840', 'efficiency': '0.176', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.805', 'ms1ms2_ratio': '1.472', 'efficiency': '0.197', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.797', 'ms1ms2_ratio': '1.268', 'efficiency': '0.190', 'TP': '22', 'FP': '5', 'FN': '1', 'precision': '0.815', 'recall': '0.957', 'f1': '0.880'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.690', 'ms1ms2_ratio': '1.678', 'efficiency': '0.287', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.808', 'ms1ms2_ratio': '4.612', 'efficiency': '0.531', 'TP': '22', 'FP': '4', 'FN': '2', 'precision': '0.846', 'recall': '0.917', 'f1': '0.880'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.752', 'ms1ms2_ratio': '5.923', 'efficiency': '0.538', 'TP': '15', 'FP': '6', 'FN': '1', 'precision': '0.714', 'recall': '0.938', 'f1': '0.811'}
#
# Episode 2 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.825', 'ms1ms2_ratio': '2.892', 'efficiency': '0.595', 'TP': '37', 'FP': '7', 'FN': '1', 'precision': '0.841', 'recall': '0.974', 'f1': '0.902'}
#
# Episode 3 finished
# {'coverage_prop': '0.821', 'intensity_prop': '0.632', 'ms1ms2_ratio': '5.610', 'efficiency': '0.561', 'TP': '17', 'FP': '6', 'FN': '5', 'precision': '0.739', 'recall': '0.773', 'f1': '0.756'}
#
# Episode 4 finished
# {'coverage_prop': '0.850', 'intensity_prop': '0.730', 'ms1ms2_ratio': '6.105', 'efficiency': '0.447', 'TP': '14', 'FP': '3', 'FN': '3', 'precision': '0.824', 'recall': '0.824', 'f1': '0.824'}
#
# Episode 5 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.807', 'ms1ms2_ratio': '2.803', 'efficiency': '0.487', 'TP': '30', 'FP': '7', 'FN': '1', 'precision': '0.811', 'recall': '0.968', 'f1': '0.882'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.819', 'ms1ms2_ratio': '3.191', 'efficiency': '0.485', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.925', 'ms1ms2_ratio': '4.612', 'efficiency': '0.429', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.877', 'ms1ms2_ratio': '2.753', 'efficiency': '0.481', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.844', 'ms1ms2_ratio': '2.447', 'efficiency': '0.529', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.902', 'ms1ms2_ratio': '2.840', 'efficiency': '0.480', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.848', 'ms1ms2_ratio': '2.671', 'efficiency': '0.582', 'TP': '40', 'FP': '6', 'FN': '0', 'precision': '0.870', 'recall': '1.000', 'f1': '0.930'}
#
# Episode 12 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.842', 'ms1ms2_ratio': '2.253', 'efficiency': '0.505', 'TP': '44', 'FP': '2', 'FN': '3', 'precision': '0.957', 'recall': '0.936', 'f1': '0.946'}
#
# Episode 13 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.742', 'ms1ms2_ratio': '5.326', 'efficiency': '0.535', 'TP': '19', 'FP': '4', 'FN': '1', 'precision': '0.826', 'recall': '0.950', 'f1': '0.884'}
#
# Episode 14 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.838', 'ms1ms2_ratio': '3.476', 'efficiency': '0.476', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.846', 'ms1ms2_ratio': '2.447', 'efficiency': '0.494', 'TP': '35', 'FP': '7', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.786', 'ms1ms2_ratio': '4.957', 'efficiency': '0.522', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.733', 'ms1ms2_ratio': '3.828', 'efficiency': '0.552', 'TP': '25', 'FP': '7', 'FN': '2', 'precision': '0.781', 'recall': '0.926', 'f1': '0.847'}
#
# Episode 18 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.772', 'ms1ms2_ratio': '2.593', 'efficiency': '0.519', 'TP': '35', 'FP': '7', 'FN': '2', 'precision': '0.833', 'recall': '0.946', 'f1': '0.886'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.795', 'ms1ms2_ratio': '3.130', 'efficiency': '0.522', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879'}
#
# Episode 20 finished
# {'coverage_prop': '0.913', 'intensity_prop': '0.695', 'ms1ms2_ratio': '5.476', 'efficiency': '0.500', 'TP': '15', 'FP': '6', 'FN': '2', 'precision': '0.714', 'recall': '0.882', 'f1': '0.789'}
#
# Episode 21 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.750', 'ms1ms2_ratio': '2.840', 'efficiency': '0.493', 'TP': '30', 'FP': '7', 'FN': '3', 'precision': '0.811', 'recall': '0.909', 'f1': '0.857'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.868', 'ms1ms2_ratio': '2.315', 'efficiency': '0.483', 'TP': '37', 'FP': '6', 'FN': '0', 'precision': '0.860', 'recall': '1.000', 'f1': '0.925'}
#
# Episode 23 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.765', 'ms1ms2_ratio': '3.239', 'efficiency': '0.537', 'TP': '28', 'FP': '8', 'FN': '1', 'precision': '0.778', 'recall': '0.966', 'f1': '0.862'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.717', 'ms1ms2_ratio': '5.205', 'efficiency': '0.591', 'TP': '19', 'FP': '7', 'FN': '1', 'precision': '0.731', 'recall': '0.950', 'f1': '0.826'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.826', 'ms1ms2_ratio': '3.828', 'efficiency': '0.552', 'TP': '25', 'FP': '7', 'FN': '0', 'precision': '0.781', 'recall': '1.000', 'f1': '0.877'}
#
# Episode 26 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.808', 'ms1ms2_ratio': '2.932', 'efficiency': '0.438', 'TP': '27', 'FP': '5', 'FN': '2', 'precision': '0.844', 'recall': '0.931', 'f1': '0.885'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.793', 'ms1ms2_ratio': '4.412', 'efficiency': '0.490', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.728', 'ms1ms2_ratio': '4.055', 'efficiency': '0.491', 'TP': '19', 'FP': '8', 'FN': '1', 'precision': '0.704', 'recall': '0.950', 'f1': '0.809'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.626', 'ms1ms2_ratio': '4.957', 'efficiency': '0.717', 'TP': '20', 'FP': '13', 'FN': '1', 'precision': '0.606', 'recall': '0.952', 'f1': '0.741'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.846', 'ms1ms2_ratio': '0.854', 'efficiency': '0.141', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.826', 'ms1ms2_ratio': '1.252', 'efficiency': '0.147', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927'}
#
# Episode 2 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.772', 'efficiency': '0.228', 'TP': '38', 'FP': '7', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.916'}
#
# Episode 3 finished
# {'coverage_prop': '0.893', 'intensity_prop': '0.702', 'ms1ms2_ratio': '1.277', 'efficiency': '0.177', 'TP': '20', 'FP': '5', 'FN': '3', 'precision': '0.800', 'recall': '0.870', 'f1': '0.833'}
#
# Episode 4 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.806', 'ms1ms2_ratio': '1.252', 'efficiency': '0.140', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889'}
#
# Episode 5 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.861', 'ms1ms2_ratio': '0.430', 'efficiency': '0.141', 'TP': '33', 'FP': '5', 'FN': '0', 'precision': '0.868', 'recall': '1.000', 'f1': '0.930'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.869', 'ms1ms2_ratio': '0.594', 'efficiency': '0.144', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.954', 'ms1ms2_ratio': '0.798', 'efficiency': '0.109', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.905', 'ms1ms2_ratio': '0.438', 'efficiency': '0.139', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.452', 'efficiency': '0.171', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.912', 'ms1ms2_ratio': '0.460', 'efficiency': '0.138', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.865', 'ms1ms2_ratio': '0.575', 'efficiency': '0.197', 'TP': '41', 'FP': '5', 'FN': '0', 'precision': '0.891', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 12 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.898', 'ms1ms2_ratio': '0.338', 'efficiency': '0.161', 'TP': '45', 'FP': '3', 'FN': '1', 'precision': '0.938', 'recall': '0.978', 'f1': '0.957'}
#
# Episode 13 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.788', 'ms1ms2_ratio': '1.075', 'efficiency': '0.151', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 14 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.604', 'efficiency': '0.137', 'TP': '27', 'FP': '4', 'FN': '1', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.398', 'efficiency': '0.151', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.812', 'ms1ms2_ratio': '1.018', 'efficiency': '0.145', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.836', 'ms1ms2_ratio': '0.676', 'efficiency': '0.160', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921'}
#
# Episode 18 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.834', 'ms1ms2_ratio': '0.416', 'efficiency': '0.150', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.539', 'efficiency': '0.149', 'TP': '32', 'FP': '4', 'FN': '1', 'precision': '0.889', 'recall': '0.970', 'f1': '0.928'}
#
# Episode 20 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.779', 'ms1ms2_ratio': '1.000', 'efficiency': '0.132', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850'}
#
# Episode 21 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.460', 'efficiency': '0.146', 'TP': '33', 'FP': '5', 'FN': '2', 'precision': '0.868', 'recall': '0.943', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.906', 'ms1ms2_ratio': '0.338', 'efficiency': '0.144', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951'}
#
# Episode 23 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.594', 'efficiency': '0.157', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.759', 'ms1ms2_ratio': '1.056', 'efficiency': '0.161', 'TP': '21', 'FP': '5', 'FN': '1', 'precision': '0.808', 'recall': '0.955', 'f1': '0.875'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.869', 'efficiency': '0.175', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.835', 'ms1ms2_ratio': '0.465', 'efficiency': '0.123', 'TP': '28', 'FP': '4', 'FN': '2', 'precision': '0.875', 'recall': '0.933', 'f1': '0.903'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.854', 'efficiency': '0.135', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.710', 'efficiency': '0.130', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.685', 'ms1ms2_ratio': '1.018', 'efficiency': '0.200', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    if method == METHOD_DQN:
        for i in range(repeat):
            eval_results = method_eval_results['%s_%d' % (method, i)]
            for eval_res in eval_results:
                try:
                    total_rewards = float(eval_res['total_rewards'])       
                except KeyError:
                    total_rewards = 0.0

                try:
                    invalid_action_count = float(eval_res['invalid_action_count'])       
                except KeyError:
                    invalid_action_count = 0.0

                row = (
                    method, 
                    total_rewards, 
                    invalid_action_count,
                    float(eval_res['coverage_prop']), 
                    float(eval_res['intensity_prop']), 
                    float(eval_res['ms1ms2_ratio']), 
                    float(eval_res['efficiency']),
                    float(eval_res['precision']),
                    float(eval_res['recall']),
                    float(eval_res['f1']),            
                )
                data.append(row)        
    else:
        eval_results = method_eval_results[method]        
        for eval_res in eval_results:
            try:
                total_rewards = float(eval_res['total_rewards'])       
            except KeyError:
                total_rewards = 0.0

            try:
                invalid_action_count = float(eval_res['invalid_action_count'])       
            except KeyError:
                invalid_action_count = 0.0

            row = (
                method, 
                total_rewards, 
                invalid_action_count,
                float(eval_res['coverage_prop']), 
                float(eval_res['intensity_prop']), 
                float(eval_res['ms1ms2_ratio']), 
                float(eval_res['efficiency']),
                float(eval_res['precision']),
                float(eval_res['recall']),
                float(eval_res['f1']),            
            )
            data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    -468.091295                 476.0          0.786           0.501
# 1  random    -464.806275                 473.0          0.773           0.498
# 2  random    -456.640973                 468.0          0.822           0.653
# 3  random    -481.170495                 485.0          0.214           0.142
# 4  random    -451.761854                 462.0          0.850           0.661
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.010       0.045      0.591   0.684  0.634
# 1          0.008       0.034      0.588   0.667  0.625
# 2          0.010       0.075      0.811   0.789  0.800
# 3          0.008       0.012      0.667   0.154  0.250
# 4          0.012       0.035      0.765   0.812  0.788

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_5.0E5.p')

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_5.0E5.p')

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30  DQN_0     101.193977                   0.0          0.964           0.847
# 31  DQN_0      93.082791                   0.0          0.955           0.834
# 32  DQN_0      92.631937                   2.0          0.978           0.856
# 33  DQN_0      99.894214                   0.0          0.929           0.698
# 34  DQN_0      90.073887                   0.0          1.000           0.809
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.257       0.082      0.852   0.958  0.902
# 31          0.367       0.073      0.905   0.950  0.927
# 32          0.316       0.143      0.909   0.976  0.941
# 33          0.379       0.091      0.808   0.913  0.857
# 34          0.321       0.066      0.800   1.000  0.889

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
