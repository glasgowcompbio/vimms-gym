# %% [markdown]
# # Evaluation using QCB chemicals (small)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns
import copy

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_small
alpha = 0.17868516517536237
beta = 0.375606083656
extract = False
params, max_peaks = preset_qcb_small(None, alpha=alpha, beta=beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2022-08-29 11:20:14.472 | INFO     | experiments:get_samplers:283 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_small_gaussian.p
# ({'chemical_creator': {'mz_range': (100, 110),
#    'rt_range': (400, 500),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (20, 50),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd8ad6e1bb0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd8ad6e1370>,
#    'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fd8afc83790>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 110)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 500),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.17868516517536237,
#    'beta': 0.375606083656}},
#  100)

# %%
# n_chemicals = (20, 50)
# mz_range = (100, 110)
# rt_range = (400, 500)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 100
in_dir = '../../tune/QCB_chems_small'
out_dir = 'evaluation_2.5E5'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 5
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 1
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 120
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_small.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 28
# 22
# 45
# 28
# 20
# 38
# 34
# 21
# 37
# 45
# 36
# 46
# 49
# 24
# 32
# 42
# 25
# 34
# 44
# 37
# 23
# 40
# 43
# 37
# 27
# 32
# 34
# 26
# 28
# 34

# %% [markdown]
# Generate new chemicals if not found

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    min_mz = mz_range[0]
    max_mz = mz_range[1]
    min_rt = rt_range[0]
    max_rt = rt_range[1]
    min_log_intensity = np.log(intensity_range[0])
    max_log_intensity = np.log(intensity_range[1])
    
    mzml_filename = '../fullscan_QCB.mzML'
    logger.info('Creating samplers from %s' % mzml_filename)
    mz_sampler = MZMLFormulaSampler(mzml_filename, min_mz=min_mz, max_mz=max_mz)
    ri_sampler = MZMLRTandIntensitySampler(mzml_filename, min_rt=min_rt, max_rt=max_rt,
                                           min_log_intensity=min_log_intensity,
                                           max_log_intensity=max_log_intensity)
    
    # roi_params = RoiBuilderParams(min_roi_length=3, at_least_one_point_above=1000)
    # cr_sampler = MZMLChromatogramSampler(mzml_filename, roi_params=roi_params)
    cr_sampler = GaussianChromatogramSampler()
    
    chemical_creator_params = {
        'mz_range': mz_range,
        'rt_range': rt_range,
        'intensity_range': intensity_range,
        'n_chemicals': n_chemicals,
        'mz_sampler': mz_sampler,
        'ri_sampler': ri_sampler,
        'cr_sampler': cr_sampler
    }

    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 110),
#   'rt_range': (400, 500),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (20, 50),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd8ad6e1bb0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd8ad6e1370>,
#   'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fd8afc83790>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 110)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 500),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.17868516517536237,
#   'beta': 0.375606083656}}

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)           
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        alpha = 0.17868516517536237
        beta = 0.375606083656
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_250000_alpha_auto_beta_auto', METHOD_DQN)
        fname = os.path.join(model_dir, 'best_model.zip')
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO:
        alpha = 0.50
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_reward_timesteps_200000_alpha_%.2f_beta_%.2f' % (alpha, beta), METHOD_PPO)        
        fname = os.path.join(model_dir, 'best_model.zip')
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO_RECURRENT:
        alpha = 0.50
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_reward_timesteps_200000_alpha_%.2f_beta_%.2f' % (alpha, beta), METHOD_PPO_RECURRENT)        
        fname = os.path.join(model_dir, 'best_model.zip')        
        model = RecurrentPPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method=%s max_peaks=%d N=%d rt_tol=%d alpha=%s beta=%s' % (
        method, max_peaks, N, copy_params['env']['rt_tol'], 
        str(copy_params['env']['alpha']), 
        str(copy_params['env']['beta']))
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method=random max_peaks=100 N=0 rt_tol=120 alpha=0.17868516517536237 beta=0.375606083656
#
#
# Episode 0 (28 chemicals)
# Finished after 495 timesteps with total reward -440.23739520778696
# {'coverage_prop': '0.821', 'intensity_prop': '0.653', 'ms1ms2_ratio': '0.012', 'efficiency': '0.047', 'TP': '19', 'FP': '4', 'FN': '5', 'precision': '0.826', 'recall': '0.792', 'f1': '0.809', 'total_rewards': -440.2373952077869, 'invalid_action_count': 454}
#
# Episode 1 (22 chemicals)
# Finished after 493 timesteps with total reward -453.345433963067
# {'coverage_prop': '0.727', 'intensity_prop': '0.620', 'ms1ms2_ratio': '0.016', 'efficiency': '0.033', 'TP': '14', 'FP': '2', 'FN': '6', 'precision': '0.875', 'recall': '0.700', 'f1': '0.778', 'total_rewards': -453.3454339630669, 'invalid_action_count': 462}
#
# Episode 2 (45 chemicals)
# Finished after 496 timesteps with total reward -461.0322564013976
# {'coverage_prop': '0.911', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.010', 'efficiency': '0.084', 'TP': '33', 'FP': '8', 'FN': '4', 'precision': '0.805', 'recall': '0.892', 'f1': '0.846', 'total_rewards': -461.03225640139755, 'invalid_action_count': 469}
#
# Episode 3 (28 chemicals)
# Finished after 494 timesteps with total reward -468.95774650823415
# {'coverage_prop': '0.679', 'intensity_prop': '0.488', 'ms1ms2_ratio': '0.014', 'efficiency': '0.039', 'TP': '17', 'FP': '2', 'FN': '9', 'precision': '0.895', 'recall': '0.654', 'f1': '0.756', 'total_rewards': -468.9577465082342, 'invalid_action_count': 475}
#
# Episode 4 (20 chemicals)
# Finished after 492 timesteps with total reward -455.69006465315897
# {'coverage_prop': '0.900', 'intensity_prop': '0.686', 'ms1ms2_ratio': '0.019', 'efficiency': '0.037', 'TP': '14', 'FP': '4', 'FN': '2', 'precision': '0.778', 'recall': '0.875', 'f1': '0.824', 'total_rewards': -455.6900646531591, 'invalid_action_count': 463}
#
# Episode 5 (38 chemicals)
# Finished after 498 timesteps with total reward -476.70144737405576
# {'coverage_prop': '0.658', 'intensity_prop': '0.543', 'ms1ms2_ratio': '0.006', 'efficiency': '0.051', 'TP': '22', 'FP': '3', 'FN': '13', 'precision': '0.880', 'recall': '0.629', 'f1': '0.733', 'total_rewards': -476.70144737405576, 'invalid_action_count': 482}
#
# Episode 6 (34 chemicals)
# Finished after 498 timesteps with total reward -461.0759963807743
# {'coverage_prop': '0.882', 'intensity_prop': '0.647', 'ms1ms2_ratio': '0.006', 'efficiency': '0.061', 'TP': '23', 'FP': '7', 'FN': '4', 'precision': '0.767', 'recall': '0.852', 'f1': '0.807', 'total_rewards': -461.07599638077426, 'invalid_action_count': 469}
#
# Episode 7 (21 chemicals)
# Finished after 495 timesteps with total reward -462.39811766284976
# {'coverage_prop': '0.857', 'intensity_prop': '0.550', 'ms1ms2_ratio': '0.012', 'efficiency': '0.037', 'TP': '12', 'FP': '6', 'FN': '3', 'precision': '0.667', 'recall': '0.800', 'f1': '0.727', 'total_rewards': -462.39811766284976, 'invalid_action_count': 470}
#
# Episode 8 (37 chemicals)
# Finished after 492 timesteps with total reward -432.2069500747141
# {'coverage_prop': '0.919', 'intensity_prop': '0.647', 'ms1ms2_ratio': '0.019', 'efficiency': '0.070', 'TP': '24', 'FP': '10', 'FN': '3', 'precision': '0.706', 'recall': '0.889', 'f1': '0.787', 'total_rewards': -432.2069500747141, 'invalid_action_count': 444}
#
# Episode 9 (45 chemicals)
# Finished after 494 timesteps with total reward -428.9370223566051
# {'coverage_prop': '0.978', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.014', 'efficiency': '0.090', 'TP': '36', 'FP': '8', 'FN': '1', 'precision': '0.818', 'recall': '0.973', 'f1': '0.889', 'total_rewards': -428.937022356605, 'invalid_action_count': 444}
#
# Episode 10 (36 chemicals)
# Finished after 495 timesteps with total reward -443.3601694518028
# {'coverage_prop': '0.806', 'intensity_prop': '0.612', 'ms1ms2_ratio': '0.012', 'efficiency': '0.059', 'TP': '22', 'FP': '7', 'FN': '7', 'precision': '0.759', 'recall': '0.759', 'f1': '0.759', 'total_rewards': -443.36016945180296, 'invalid_action_count': 456}
#
# Episode 11 (46 chemicals)
# Finished after 494 timesteps with total reward -455.1824701841498
# {'coverage_prop': '0.783', 'intensity_prop': '0.485', 'ms1ms2_ratio': '0.014', 'efficiency': '0.074', 'TP': '22', 'FP': '14', 'FN': '10', 'precision': '0.611', 'recall': '0.688', 'f1': '0.647', 'total_rewards': -455.18247018414974, 'invalid_action_count': 464}
#
# Episode 12 (49 chemicals)
# Finished after 494 timesteps with total reward -422.4948122434315
# {'coverage_prop': '0.918', 'intensity_prop': '0.822', 'ms1ms2_ratio': '0.014', 'efficiency': '0.092', 'TP': '43', 'FP': '2', 'FN': '4', 'precision': '0.956', 'recall': '0.915', 'f1': '0.935', 'total_rewards': -422.4948122434315, 'invalid_action_count': 436}
#
# Episode 13 (24 chemicals)
# Finished after 496 timesteps with total reward -467.4032016851237
# {'coverage_prop': '0.833', 'intensity_prop': '0.450', 'ms1ms2_ratio': '0.010', 'efficiency': '0.041', 'TP': '12', 'FP': '8', 'FN': '4', 'precision': '0.600', 'recall': '0.750', 'f1': '0.667', 'total_rewards': -467.4032016851238, 'invalid_action_count': 472}
#
# Episode 14 (32 chemicals)
# Finished after 498 timesteps with total reward -491.28098741143924
# {'coverage_prop': '0.062', 'intensity_prop': '0.015', 'ms1ms2_ratio': '0.006', 'efficiency': '0.004', 'TP': '0', 'FP': '2', 'FN': '30', 'precision': '0.000', 'recall': '0.000', 'f1': '0.000', 'total_rewards': -491.28098741143924, 'invalid_action_count': 492}
#
# Episode 15 (42 chemicals)
# Finished after 496 timesteps with total reward -459.1851971800177
# {'coverage_prop': '0.786', 'intensity_prop': '0.481', 'ms1ms2_ratio': '0.010', 'efficiency': '0.067', 'TP': '21', 'FP': '12', 'FN': '9', 'precision': '0.636', 'recall': '0.700', 'f1': '0.667', 'total_rewards': -459.1851971800176, 'invalid_action_count': 467}
#
# Episode 16 (25 chemicals)
# Finished after 491 timesteps with total reward -447.86718895385286
# {'coverage_prop': '0.840', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.021', 'efficiency': '0.044', 'TP': '14', 'FP': '7', 'FN': '4', 'precision': '0.667', 'recall': '0.778', 'f1': '0.718', 'total_rewards': -447.86718895385286, 'invalid_action_count': 457}
#
# Episode 17 (34 chemicals)
# Finished after 494 timesteps with total reward -460.15284026269904
# {'coverage_prop': '0.765', 'intensity_prop': '0.453', 'ms1ms2_ratio': '0.014', 'efficiency': '0.053', 'TP': '15', 'FP': '11', 'FN': '8', 'precision': '0.577', 'recall': '0.652', 'f1': '0.612', 'total_rewards': -460.15284026269893, 'invalid_action_count': 469}
#
# Episode 18 (44 chemicals)
# Finished after 498 timesteps with total reward -447.44351183811284
# {'coverage_prop': '0.795', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.006', 'efficiency': '0.071', 'TP': '25', 'FP': '10', 'FN': '9', 'precision': '0.714', 'recall': '0.735', 'f1': '0.725', 'total_rewards': -447.44351183811295, 'invalid_action_count': 461}
#
# Episode 19 (37 chemicals)
# Finished after 494 timesteps with total reward -430.7567781622503
# {'coverage_prop': '0.946', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.014', 'efficiency': '0.072', 'TP': '30', 'FP': '5', 'FN': '2', 'precision': '0.857', 'recall': '0.938', 'f1': '0.896', 'total_rewards': -430.75677816225027, 'invalid_action_count': 444}
#
# Episode 20 (23 chemicals)
# Finished after 497 timesteps with total reward -470.38315829953297
# {'coverage_prop': '0.739', 'intensity_prop': '0.449', 'ms1ms2_ratio': '0.008', 'efficiency': '0.034', 'TP': '10', 'FP': '7', 'FN': '6', 'precision': '0.588', 'recall': '0.625', 'f1': '0.606', 'total_rewards': -470.3831582995331, 'invalid_action_count': 476}
#
# Episode 21 (40 chemicals)
# Finished after 494 timesteps with total reward -426.09472355694265
# {'coverage_prop': '0.825', 'intensity_prop': '0.635', 'ms1ms2_ratio': '0.014', 'efficiency': '0.068', 'TP': '25', 'FP': '8', 'FN': '7', 'precision': '0.758', 'recall': '0.781', 'f1': '0.769', 'total_rewards': -426.0947235569426, 'invalid_action_count': 442}
#
# Episode 22 (43 chemicals)
# Finished after 492 timesteps with total reward -399.7011602505249
# {'coverage_prop': '0.977', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.019', 'efficiency': '0.087', 'TP': '37', 'FP': '5', 'FN': '1', 'precision': '0.881', 'recall': '0.974', 'f1': '0.925', 'total_rewards': -399.7011602505249, 'invalid_action_count': 420}
#
# Episode 23 (37 chemicals)
# Finished after 494 timesteps with total reward -443.64415170461456
# {'coverage_prop': '0.892', 'intensity_prop': '0.664', 'ms1ms2_ratio': '0.014', 'efficiency': '0.068', 'TP': '26', 'FP': '7', 'FN': '4', 'precision': '0.788', 'recall': '0.867', 'f1': '0.825', 'total_rewards': -443.6441517046144, 'invalid_action_count': 454}
#
# Episode 24 (27 chemicals)
# Finished after 498 timesteps with total reward -474.18496892963486
# {'coverage_prop': '0.593', 'intensity_prop': '0.332', 'ms1ms2_ratio': '0.006', 'efficiency': '0.032', 'TP': '8', 'FP': '8', 'FN': '11', 'precision': '0.500', 'recall': '0.421', 'f1': '0.457', 'total_rewards': -474.1849689296348, 'invalid_action_count': 480}
#
# Episode 25 (32 chemicals)
# Finished after 493 timesteps with total reward -453.0153153913562
# {'coverage_prop': '0.906', 'intensity_prop': '0.666', 'ms1ms2_ratio': '0.016', 'efficiency': '0.060', 'TP': '23', 'FP': '6', 'FN': '3', 'precision': '0.793', 'recall': '0.885', 'f1': '0.836', 'total_rewards': -453.0153153913562, 'invalid_action_count': 462}
#
# Episode 26 (34 chemicals)
# Finished after 495 timesteps with total reward -425.64711341250893
# {'coverage_prop': '0.853', 'intensity_prop': '0.685', 'ms1ms2_ratio': '0.012', 'efficiency': '0.059', 'TP': '22', 'FP': '7', 'FN': '5', 'precision': '0.759', 'recall': '0.815', 'f1': '0.786', 'total_rewards': -425.64711341250876, 'invalid_action_count': 444}
#
# Episode 27 (26 chemicals)
# Finished after 494 timesteps with total reward -457.8451873477016
# {'coverage_prop': '0.962', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.014', 'efficiency': '0.051', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870', 'total_rewards': -457.8451873477017, 'invalid_action_count': 466}
#
# Episode 28 (28 chemicals)
# Finished after 494 timesteps with total reward -441.9116010203461
# {'coverage_prop': '0.893', 'intensity_prop': '0.670', 'ms1ms2_ratio': '0.014', 'efficiency': '0.051', 'TP': '19', 'FP': '6', 'FN': '3', 'precision': '0.760', 'recall': '0.864', 'f1': '0.809', 'total_rewards': -441.91160102034604, 'invalid_action_count': 452}
#
# Episode 29 (34 chemicals)
# Finished after 494 timesteps with total reward -459.5851696061953
# {'coverage_prop': '0.588', 'intensity_prop': '0.418', 'ms1ms2_ratio': '0.014', 'efficiency': '0.041', 'TP': '15', 'FP': '5', 'FN': '14', 'precision': '0.750', 'recall': '0.517', 'f1': '0.612', 'total_rewards': -459.5851696061952, 'invalid_action_count': 467}
#
# method=DQN max_peaks=100 N=0 rt_tol=120 alpha=0.17868516517536237 beta=0.375606083656
#
#
# Episode 0 (28 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 3.24GB > 0.35GB
# Finished after 359 timesteps with total reward 76.86733022935644
# {'coverage_prop': '0.964', 'intensity_prop': '0.849', 'ms1ms2_ratio': '0.654', 'efficiency': '0.124', 'TP': '24', 'FP': '3', 'FN': '1', 'precision': '0.889', 'recall': '0.960', 'f1': '0.923', 'total_rewards': 76.8673302293565, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 337 timesteps with total reward 72.97394066014438
# {'coverage_prop': '0.955', 'intensity_prop': '0.809', 'ms1ms2_ratio': '0.948', 'efficiency': '0.121', 'TP': '18', 'FP': '3', 'FN': '1', 'precision': '0.857', 'recall': '0.947', 'f1': '0.900', 'total_rewards': 72.97394066014445, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 357 timesteps with total reward 78.9936654147955
# {'coverage_prop': '1.000', 'intensity_prop': '0.831', 'ms1ms2_ratio': '0.684', 'efficiency': '0.212', 'TP': '37', 'FP': '8', 'FN': '0', 'precision': '0.822', 'recall': '1.000', 'f1': '0.902', 'total_rewards': 78.99366541479543, 'invalid_action_count': 0}
#
# Episode 3 (28 chemicals)
# Finished after 335 timesteps with total reward 74.15545635465044
# {'coverage_prop': '0.893', 'intensity_prop': '0.677', 'ms1ms2_ratio': '0.982', 'efficiency': '0.148', 'TP': '20', 'FP': '5', 'FN': '3', 'precision': '0.800', 'recall': '0.870', 'f1': '0.833', 'total_rewards': 74.1554563546505, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 347 timesteps with total reward 72.91603899454495
# {'coverage_prop': '0.950', 'intensity_prop': '0.803', 'ms1ms2_ratio': '0.798', 'efficiency': '0.098', 'TP': '17', 'FP': '2', 'FN': '1', 'precision': '0.895', 'recall': '0.944', 'f1': '0.919', 'total_rewards': 72.91603899454486, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 376 timesteps with total reward 76.30415317742596
# {'coverage_prop': '1.000', 'intensity_prop': '0.850', 'ms1ms2_ratio': '0.498', 'efficiency': '0.151', 'TP': '34', 'FP': '4', 'FN': '0', 'precision': '0.895', 'recall': '1.000', 'f1': '0.944', 'total_rewards': 76.30415317742586, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 361 timesteps with total reward 74.43698743308248
# {'coverage_prop': '0.971', 'intensity_prop': '0.849', 'ms1ms2_ratio': '0.633', 'efficiency': '0.149', 'TP': '30', 'FP': '3', 'FN': '1', 'precision': '0.909', 'recall': '0.968', 'f1': '0.937', 'total_rewards': 74.43698743308242, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 374 timesteps with total reward 88.50023994850494
# {'coverage_prop': '1.000', 'intensity_prop': '0.938', 'ms1ms2_ratio': '0.520', 'efficiency': '0.085', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 88.50023994850491, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 365 timesteps with total reward 76.47285953467313
# {'coverage_prop': '1.000', 'intensity_prop': '0.888', 'ms1ms2_ratio': '0.594', 'efficiency': '0.162', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 76.47285953467305, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 369 timesteps with total reward 75.21854973338475
# {'coverage_prop': '1.000', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.564', 'efficiency': '0.191', 'TP': '38', 'FP': '7', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.916', 'total_rewards': 75.21854973338472, 'invalid_action_count': 0}
#
# Episode 10 (36 chemicals)
# Finished after 369 timesteps with total reward 82.71568019914983
# {'coverage_prop': '1.000', 'intensity_prop': '0.893', 'ms1ms2_ratio': '0.557', 'efficiency': '0.152', 'TP': '33', 'FP': '3', 'FN': '0', 'precision': '0.917', 'recall': '1.000', 'f1': '0.957', 'total_rewards': 82.7156801991498, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 359 timesteps with total reward 78.35733109153739
# {'coverage_prop': '0.957', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.654', 'efficiency': '0.203', 'TP': '39', 'FP': '5', 'FN': '2', 'precision': '0.886', 'recall': '0.951', 'f1': '0.918', 'total_rewards': 78.35733109153729, 'invalid_action_count': 0}
#
# Episode 12 (49 chemicals)
# Finished after 368 timesteps with total reward 79.89348465749012
# {'coverage_prop': '0.939', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.566', 'efficiency': '0.196', 'TP': '43', 'FP': '3', 'FN': '3', 'precision': '0.935', 'recall': '0.935', 'f1': '0.935', 'total_rewards': 79.89348465749008, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 344 timesteps with total reward 65.79081361862683
# {'coverage_prop': '1.000', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.840', 'efficiency': '0.128', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909', 'total_rewards': 65.79081361862687, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 358 timesteps with total reward 70.10451398680638
# {'coverage_prop': '1.000', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.665', 'efficiency': '0.149', 'TP': '27', 'FP': '5', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.915', 'total_rewards': 70.10451398680642, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 373 timesteps with total reward 88.03376266678825
# {'coverage_prop': '1.000', 'intensity_prop': '0.885', 'ms1ms2_ratio': '0.522', 'efficiency': '0.171', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 88.0337626667883, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 356 timesteps with total reward 79.26417766276823
# {'coverage_prop': '1.000', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.687', 'efficiency': '0.118', 'TP': '20', 'FP': '5', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 79.26417766276826, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 359 timesteps with total reward 73.66120456640513
# {'coverage_prop': '1.000', 'intensity_prop': '0.807', 'ms1ms2_ratio': '0.654', 'efficiency': '0.157', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 73.66120456640515, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 368 timesteps with total reward 85.34574149869835
# {'coverage_prop': '0.955', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.573', 'efficiency': '0.179', 'TP': '37', 'FP': '5', 'FN': '2', 'precision': '0.881', 'recall': '0.949', 'f1': '0.914', 'total_rewards': 85.34574149869835, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 376 timesteps with total reward 74.2081834985278
# {'coverage_prop': '1.000', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.498', 'efficiency': '0.147', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 74.20818349852779, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 354 timesteps with total reward 83.73873110919436
# {'coverage_prop': '0.957', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.710', 'efficiency': '0.106', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 83.73873110919438, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 387 timesteps with total reward 90.8565387639287
# {'coverage_prop': '0.925', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.418', 'efficiency': '0.136', 'TP': '32', 'FP': '5', 'FN': '3', 'precision': '0.865', 'recall': '0.914', 'f1': '0.889', 'total_rewards': 90.85653876392864, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 371 timesteps with total reward 77.72461002066201
# {'coverage_prop': '1.000', 'intensity_prop': '0.881', 'ms1ms2_ratio': '0.539', 'efficiency': '0.178', 'TP': '38', 'FP': '5', 'FN': '0', 'precision': '0.884', 'recall': '1.000', 'f1': '0.938', 'total_rewards': 77.72461002066188, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 362 timesteps with total reward 81.92404722961236
# {'coverage_prop': '0.919', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.623', 'efficiency': '0.152', 'TP': '29', 'FP': '5', 'FN': '3', 'precision': '0.853', 'recall': '0.906', 'f1': '0.879', 'total_rewards': 81.92404722961226, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 351 timesteps with total reward 77.16333490886346
# {'coverage_prop': '0.963', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.746', 'efficiency': '0.129', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851', 'total_rewards': 77.1633349088635, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 351 timesteps with total reward 69.72006703231031
# {'coverage_prop': '1.000', 'intensity_prop': '0.845', 'ms1ms2_ratio': '0.746', 'efficiency': '0.159', 'TP': '27', 'FP': '5', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.915', 'total_rewards': 69.72006703231037, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 361 timesteps with total reward 85.47326456470451
# {'coverage_prop': '0.971', 'intensity_prop': '0.837', 'ms1ms2_ratio': '0.633', 'efficiency': '0.149', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903', 'total_rewards': 85.47326456470444, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 347 timesteps with total reward 67.62048721587325
# {'coverage_prop': '1.000', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.798', 'efficiency': '0.135', 'TP': '21', 'FP': '5', 'FN': '0', 'precision': '0.808', 'recall': '1.000', 'f1': '0.894', 'total_rewards': 67.62048721587327, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 346 timesteps with total reward 71.13566136978713
# {'coverage_prop': '1.000', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.812', 'efficiency': '0.147', 'TP': '22', 'FP': '6', 'FN': '0', 'precision': '0.786', 'recall': '1.000', 'f1': '0.880', 'total_rewards': 71.13566136978716, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 349 timesteps with total reward 65.46760591078376
# {'coverage_prop': '0.971', 'intensity_prop': '0.672', 'ms1ms2_ratio': '0.781', 'efficiency': '0.168', 'TP': '22', 'FP': '11', 'FN': '1', 'precision': '0.667', 'recall': '0.957', 'f1': '0.786', 'total_rewards': 65.46760591078383, 'invalid_action_count': 0}
#
# method=topN max_peaks=100 N=5 rt_tol=5 alpha=0.17868516517536237 beta=0.375606083656
#
#
# Episode 0 (28 chemicals)
# Finished after 315 timesteps with total reward 59.8350033430053
# {'coverage_prop': '0.929', 'intensity_prop': '0.841', 'ms1ms2_ratio': '1.442', 'efficiency': '0.202', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902', 'total_rewards': 59.83500334300538, 'invalid_action_count': 0}
#
# Episode 1 (22 chemicals)
# Finished after 300 timesteps with total reward 54.2127590303815
# {'coverage_prop': '1.000', 'intensity_prop': '0.811', 'ms1ms2_ratio': '2.030', 'efficiency': '0.222', 'TP': '18', 'FP': '4', 'FN': '0', 'precision': '0.818', 'recall': '1.000', 'f1': '0.900', 'total_rewards': 54.21275903038163, 'invalid_action_count': 0}
#
# Episode 2 (45 chemicals)
# Finished after 327 timesteps with total reward 63.499611800812104
# {'coverage_prop': '1.000', 'intensity_prop': '0.858', 'ms1ms2_ratio': '1.137', 'efficiency': '0.294', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 63.4996118008122, 'invalid_action_count': 0}
#
# Episode 3 (28 chemicals)
# Finished after 301 timesteps with total reward 56.431405907927235
# {'coverage_prop': '0.857', 'intensity_prop': '0.694', 'ms1ms2_ratio': '2.010', 'efficiency': '0.240', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857', 'total_rewards': 56.43140590792738, 'invalid_action_count': 0}
#
# Episode 4 (20 chemicals)
# Finished after 299 timesteps with total reward 48.70277328940337
# {'coverage_prop': '1.000', 'intensity_prop': '0.797', 'ms1ms2_ratio': '2.115', 'efficiency': '0.208', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889', 'total_rewards': 48.70277328940352, 'invalid_action_count': 0}
#
# Episode 5 (38 chemicals)
# Finished after 346 timesteps with total reward 67.3325751329235
# {'coverage_prop': '0.974', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.821', 'efficiency': '0.195', 'TP': '33', 'FP': '4', 'FN': '1', 'precision': '0.892', 'recall': '0.971', 'f1': '0.930', 'total_rewards': 67.33257513292355, 'invalid_action_count': 0}
#
# Episode 6 (34 chemicals)
# Finished after 336 timesteps with total reward 66.03844364127754
# {'coverage_prop': '0.971', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.965', 'efficiency': '0.193', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954', 'total_rewards': 66.03844364127758, 'invalid_action_count': 0}
#
# Episode 7 (21 chemicals)
# Finished after 316 timesteps with total reward 61.26448422105469
# {'coverage_prop': '1.000', 'intensity_prop': '0.931', 'ms1ms2_ratio': '1.431', 'efficiency': '0.162', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976', 'total_rewards': 61.26448422105483, 'invalid_action_count': 0}
#
# Episode 8 (37 chemicals)
# Finished after 348 timesteps with total reward 71.08249163087046
# {'coverage_prop': '1.000', 'intensity_prop': '0.894', 'ms1ms2_ratio': '0.794', 'efficiency': '0.191', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943', 'total_rewards': 71.0824916308705, 'invalid_action_count': 0}
#
# Episode 9 (45 chemicals)
# Finished after 351 timesteps with total reward 72.09387074320921
# {'coverage_prop': '1.000', 'intensity_prop': '0.846', 'ms1ms2_ratio': '0.746', 'efficiency': '0.224', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929', 'total_rewards': 72.09387074320922, 'invalid_action_count': 0}
#
# Episode 10 (36 chemicals)
# Finished after 346 timesteps with total reward 73.77186833181233
# {'coverage_prop': '1.000', 'intensity_prop': '0.912', 'ms1ms2_ratio': '0.812', 'efficiency': '0.188', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971', 'total_rewards': 73.77186833181231, 'invalid_action_count': 0}
#
# Episode 11 (46 chemicals)
# Finished after 340 timesteps with total reward 73.32867051143195
# {'coverage_prop': '0.978', 'intensity_prop': '0.853', 'ms1ms2_ratio': '0.899', 'efficiency': '0.251', 'TP': '41', 'FP': '4', 'FN': '1', 'precision': '0.911', 'recall': '0.976', 'f1': '0.943', 'total_rewards': 73.32867051143202, 'invalid_action_count': 0}
#
# Episode 12 (49 chemicals)
# Finished after 365 timesteps with total reward 82.32891002667554
# {'coverage_prop': '0.939', 'intensity_prop': '0.884', 'ms1ms2_ratio': '0.594', 'efficiency': '0.201', 'TP': '45', 'FP': '1', 'FN': '3', 'precision': '0.978', 'recall': '0.938', 'f1': '0.957', 'total_rewards': 82.32891002667556, 'invalid_action_count': 0}
#
# Episode 13 (24 chemicals)
# Finished after 306 timesteps with total reward 49.572366733385536
# {'coverage_prop': '1.000', 'intensity_prop': '0.787', 'ms1ms2_ratio': '1.782', 'efficiency': '0.218', 'TP': '19', 'FP': '5', 'FN': '0', 'precision': '0.792', 'recall': '1.000', 'f1': '0.884', 'total_rewards': 49.572366733385614, 'invalid_action_count': 0}
#
# Episode 14 (32 chemicals)
# Finished after 332 timesteps with total reward 58.63217116604309
# {'coverage_prop': '0.969', 'intensity_prop': '0.849', 'ms1ms2_ratio': '1.037', 'efficiency': '0.190', 'TP': '27', 'FP': '4', 'FN': '1', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915', 'total_rewards': 58.632171166043186, 'invalid_action_count': 0}
#
# Episode 15 (42 chemicals)
# Finished after 356 timesteps with total reward 86.64008535254158
# {'coverage_prop': '1.000', 'intensity_prop': '0.890', 'ms1ms2_ratio': '0.687', 'efficiency': '0.199', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950', 'total_rewards': 86.64008535254156, 'invalid_action_count': 0}
#
# Episode 16 (25 chemicals)
# Finished after 308 timesteps with total reward 55.51993868373941
# {'coverage_prop': '0.960', 'intensity_prop': '0.803', 'ms1ms2_ratio': '1.678', 'efficiency': '0.209', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889', 'total_rewards': 55.51993868373952, 'invalid_action_count': 0}
#
# Episode 17 (34 chemicals)
# Finished after 328 timesteps with total reward 60.816738819724506
# {'coverage_prop': '1.000', 'intensity_prop': '0.819', 'ms1ms2_ratio': '1.116', 'efficiency': '0.219', 'TP': '28', 'FP': '6', 'FN': '0', 'precision': '0.824', 'recall': '1.000', 'f1': '0.903', 'total_rewards': 60.81673881972458, 'invalid_action_count': 0}
#
# Episode 18 (44 chemicals)
# Finished after 353 timesteps with total reward 82.31603556546152
# {'coverage_prop': '0.932', 'intensity_prop': '0.831', 'ms1ms2_ratio': '0.722', 'efficiency': '0.200', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927', 'total_rewards': 82.31603556546145, 'invalid_action_count': 0}
#
# Episode 19 (37 chemicals)
# Finished after 341 timesteps with total reward 63.13915461731054
# {'coverage_prop': '0.973', 'intensity_prop': '0.859', 'ms1ms2_ratio': '0.884', 'efficiency': '0.199', 'TP': '32', 'FP': '4', 'FN': '1', 'precision': '0.889', 'recall': '0.970', 'f1': '0.928', 'total_rewards': 63.13915461731061, 'invalid_action_count': 0}
#
# Episode 20 (23 chemicals)
# Finished after 307 timesteps with total reward 55.4205657523344
# {'coverage_prop': '0.957', 'intensity_prop': '0.781', 'ms1ms2_ratio': '1.717', 'efficiency': '0.195', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850', 'total_rewards': 55.42056575233453, 'invalid_action_count': 0}
#
# Episode 21 (40 chemicals)
# Finished after 343 timesteps with total reward 78.04651033246904
# {'coverage_prop': '0.925', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.854', 'efficiency': '0.200', 'TP': '32', 'FP': '5', 'FN': '3', 'precision': '0.865', 'recall': '0.914', 'f1': '0.889', 'total_rewards': 78.04651033246908, 'invalid_action_count': 0}
#
# Episode 22 (43 chemicals)
# Finished after 363 timesteps with total reward 77.30910843496795
# {'coverage_prop': '1.000', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.621', 'efficiency': '0.192', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951', 'total_rewards': 77.30910843496792, 'invalid_action_count': 0}
#
# Episode 23 (37 chemicals)
# Finished after 335 timesteps with total reward 65.13344492387284
# {'coverage_prop': '0.946', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.982', 'efficiency': '0.207', 'TP': '29', 'FP': '6', 'FN': '2', 'precision': '0.829', 'recall': '0.935', 'f1': '0.879', 'total_rewards': 65.13344492387294, 'invalid_action_count': 0}
#
# Episode 24 (27 chemicals)
# Finished after 306 timesteps with total reward 57.94544882416727
# {'coverage_prop': '0.963', 'intensity_prop': '0.760', 'ms1ms2_ratio': '1.757', 'efficiency': '0.234', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851', 'total_rewards': 57.945448824167386, 'invalid_action_count': 0}
#
# Episode 25 (32 chemicals)
# Finished after 317 timesteps with total reward 58.24764451526846
# {'coverage_prop': '1.000', 'intensity_prop': '0.853', 'ms1ms2_ratio': '1.383', 'efficiency': '0.241', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933', 'total_rewards': 58.247644515268576, 'invalid_action_count': 0}
#
# Episode 26 (34 chemicals)
# Finished after 345 timesteps with total reward 77.3601618347852
# {'coverage_prop': '0.941', 'intensity_prop': '0.824', 'ms1ms2_ratio': '0.825', 'efficiency': '0.169', 'TP': '28', 'FP': '4', 'FN': '2', 'precision': '0.875', 'recall': '0.933', 'f1': '0.903', 'total_rewards': 77.36016183478516, 'invalid_action_count': 0}
#
# Episode 27 (26 chemicals)
# Finished after 317 timesteps with total reward 55.190815927394
# {'coverage_prop': '0.962', 'intensity_prop': '0.801', 'ms1ms2_ratio': '1.402', 'efficiency': '0.189', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870', 'total_rewards': 55.19081592739405, 'invalid_action_count': 0}
#
# Episode 28 (28 chemicals)
# Finished after 322 timesteps with total reward 60.197761712784434
# {'coverage_prop': '0.964', 'intensity_prop': '0.793', 'ms1ms2_ratio': '1.252', 'efficiency': '0.189', 'TP': '22', 'FP': '5', 'FN': '1', 'precision': '0.815', 'recall': '0.957', 'f1': '0.880', 'total_rewards': 60.19776171278454, 'invalid_action_count': 0}
#
# Episode 29 (34 chemicals)
# Finished after 311 timesteps with total reward 53.092021387015116
# {'coverage_prop': '0.971', 'intensity_prop': '0.689', 'ms1ms2_ratio': '1.592', 'efficiency': '0.275', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807', 'total_rewards': 53.09202138701518, 'invalid_action_count': 0}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 110),
#   'rt_range': (400, 500),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (20, 50),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd8ad6e1bb0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd8ad6e1370>,
#   'cr_sampler': <vimms.ChemicalSamplers.GaussianChromatogramSampler at 0x7fd8afc83790>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 110)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 500),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.17868516517536237,
#   'beta': 0.375606083656}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.836', 'ms1ms2_ratio': '1.504', 'efficiency': '0.208', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.828', 'ms1ms2_ratio': '2.082', 'efficiency': '0.216', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927'}
#
# Episode 2 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.859', 'ms1ms2_ratio': '1.159', 'efficiency': '0.298', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 3 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.695', 'ms1ms2_ratio': '2.030', 'efficiency': '0.242', 'TP': '21', 'FP': '3', 'FN': '4', 'precision': '0.875', 'recall': '0.840', 'f1': '0.857'}
#
# Episode 4 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.799', 'ms1ms2_ratio': '2.194', 'efficiency': '0.215', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889'}
#
# Episode 5 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.856', 'ms1ms2_ratio': '0.798', 'efficiency': '0.192', 'TP': '34', 'FP': '3', 'FN': '1', 'precision': '0.919', 'recall': '0.971', 'f1': '0.944'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.863', 'ms1ms2_ratio': '1.000', 'efficiency': '0.198', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.934', 'ms1ms2_ratio': '1.442', 'efficiency': '0.163', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.900', 'ms1ms2_ratio': '0.812', 'efficiency': '0.194', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.851', 'ms1ms2_ratio': '0.772', 'efficiency': '0.228', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.911', 'ms1ms2_ratio': '0.869', 'efficiency': '0.197', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.931', 'efficiency': '0.257', 'TP': '41', 'FP': '4', 'FN': '1', 'precision': '0.911', 'recall': '0.976', 'f1': '0.943'}
#
# Episode 12 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.889', 'ms1ms2_ratio': '0.613', 'efficiency': '0.209', 'TP': '45', 'FP': '2', 'FN': '2', 'precision': '0.957', 'recall': '0.957', 'f1': '0.957'}
#
# Episode 13 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.786', 'ms1ms2_ratio': '1.841', 'efficiency': '0.224', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 14 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.848', 'ms1ms2_ratio': '1.075', 'efficiency': '0.189', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.890', 'ms1ms2_ratio': '0.722', 'efficiency': '0.205', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.803', 'ms1ms2_ratio': '1.782', 'efficiency': '0.218', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.827', 'ms1ms2_ratio': '1.181', 'efficiency': '0.228', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921'}
#
# Episode 18 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.836', 'ms1ms2_ratio': '0.734', 'efficiency': '0.202', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.857', 'ms1ms2_ratio': '0.931', 'efficiency': '0.206', 'TP': '31', 'FP': '5', 'FN': '1', 'precision': '0.861', 'recall': '0.969', 'f1': '0.912'}
#
# Episode 20 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.780', 'ms1ms2_ratio': '1.782', 'efficiency': '0.200', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850'}
#
# Episode 21 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.811', 'ms1ms2_ratio': '0.899', 'efficiency': '0.207', 'TP': '33', 'FP': '4', 'FN': '3', 'precision': '0.892', 'recall': '0.917', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.897', 'ms1ms2_ratio': '0.654', 'efficiency': '0.198', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951'}
#
# Episode 23 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.786', 'ms1ms2_ratio': '1.037', 'efficiency': '0.215', 'TP': '30', 'FP': '5', 'FN': '2', 'precision': '0.857', 'recall': '0.938', 'f1': '0.896'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.754', 'ms1ms2_ratio': '1.824', 'efficiency': '0.241', 'TP': '20', 'FP': '6', 'FN': '1', 'precision': '0.769', 'recall': '0.952', 'f1': '0.851'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.864', 'ms1ms2_ratio': '1.412', 'efficiency': '0.244', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.840', 'efficiency': '0.176', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.805', 'ms1ms2_ratio': '1.472', 'efficiency': '0.197', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.797', 'ms1ms2_ratio': '1.268', 'efficiency': '0.190', 'TP': '22', 'FP': '5', 'FN': '1', 'precision': '0.815', 'recall': '0.957', 'f1': '0.880'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.690', 'ms1ms2_ratio': '1.678', 'efficiency': '0.287', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.808', 'ms1ms2_ratio': '4.612', 'efficiency': '0.531', 'TP': '22', 'FP': '4', 'FN': '2', 'precision': '0.846', 'recall': '0.917', 'f1': '0.880'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.752', 'ms1ms2_ratio': '5.923', 'efficiency': '0.538', 'TP': '15', 'FP': '6', 'FN': '1', 'precision': '0.714', 'recall': '0.938', 'f1': '0.811'}
#
# Episode 2 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.825', 'ms1ms2_ratio': '2.892', 'efficiency': '0.595', 'TP': '37', 'FP': '7', 'FN': '1', 'precision': '0.841', 'recall': '0.974', 'f1': '0.902'}
#
# Episode 3 finished
# {'coverage_prop': '0.821', 'intensity_prop': '0.632', 'ms1ms2_ratio': '5.610', 'efficiency': '0.561', 'TP': '17', 'FP': '6', 'FN': '5', 'precision': '0.739', 'recall': '0.773', 'f1': '0.756'}
#
# Episode 4 finished
# {'coverage_prop': '0.850', 'intensity_prop': '0.730', 'ms1ms2_ratio': '6.105', 'efficiency': '0.447', 'TP': '14', 'FP': '3', 'FN': '3', 'precision': '0.824', 'recall': '0.824', 'f1': '0.824'}
#
# Episode 5 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.807', 'ms1ms2_ratio': '2.803', 'efficiency': '0.487', 'TP': '30', 'FP': '7', 'FN': '1', 'precision': '0.811', 'recall': '0.968', 'f1': '0.882'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.819', 'ms1ms2_ratio': '3.191', 'efficiency': '0.485', 'TP': '28', 'FP': '5', 'FN': '1', 'precision': '0.848', 'recall': '0.966', 'f1': '0.903'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.925', 'ms1ms2_ratio': '4.612', 'efficiency': '0.429', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.877', 'ms1ms2_ratio': '2.753', 'efficiency': '0.481', 'TP': '33', 'FP': '4', 'FN': '0', 'precision': '0.892', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.844', 'ms1ms2_ratio': '2.447', 'efficiency': '0.529', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.902', 'ms1ms2_ratio': '2.840', 'efficiency': '0.480', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.848', 'ms1ms2_ratio': '2.671', 'efficiency': '0.582', 'TP': '40', 'FP': '6', 'FN': '0', 'precision': '0.870', 'recall': '1.000', 'f1': '0.930'}
#
# Episode 12 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.842', 'ms1ms2_ratio': '2.253', 'efficiency': '0.505', 'TP': '44', 'FP': '2', 'FN': '3', 'precision': '0.957', 'recall': '0.936', 'f1': '0.946'}
#
# Episode 13 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.742', 'ms1ms2_ratio': '5.326', 'efficiency': '0.535', 'TP': '19', 'FP': '4', 'FN': '1', 'precision': '0.826', 'recall': '0.950', 'f1': '0.884'}
#
# Episode 14 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.838', 'ms1ms2_ratio': '3.476', 'efficiency': '0.476', 'TP': '27', 'FP': '3', 'FN': '2', 'precision': '0.900', 'recall': '0.931', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.846', 'ms1ms2_ratio': '2.447', 'efficiency': '0.494', 'TP': '35', 'FP': '7', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.786', 'ms1ms2_ratio': '4.957', 'efficiency': '0.522', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.733', 'ms1ms2_ratio': '3.828', 'efficiency': '0.552', 'TP': '25', 'FP': '7', 'FN': '2', 'precision': '0.781', 'recall': '0.926', 'f1': '0.847'}
#
# Episode 18 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.772', 'ms1ms2_ratio': '2.593', 'efficiency': '0.519', 'TP': '35', 'FP': '7', 'FN': '2', 'precision': '0.833', 'recall': '0.946', 'f1': '0.886'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.795', 'ms1ms2_ratio': '3.130', 'efficiency': '0.522', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879'}
#
# Episode 20 finished
# {'coverage_prop': '0.913', 'intensity_prop': '0.695', 'ms1ms2_ratio': '5.476', 'efficiency': '0.500', 'TP': '15', 'FP': '6', 'FN': '2', 'precision': '0.714', 'recall': '0.882', 'f1': '0.789'}
#
# Episode 21 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.750', 'ms1ms2_ratio': '2.840', 'efficiency': '0.493', 'TP': '30', 'FP': '7', 'FN': '3', 'precision': '0.811', 'recall': '0.909', 'f1': '0.857'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.868', 'ms1ms2_ratio': '2.315', 'efficiency': '0.483', 'TP': '37', 'FP': '6', 'FN': '0', 'precision': '0.860', 'recall': '1.000', 'f1': '0.925'}
#
# Episode 23 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.765', 'ms1ms2_ratio': '3.239', 'efficiency': '0.537', 'TP': '28', 'FP': '8', 'FN': '1', 'precision': '0.778', 'recall': '0.966', 'f1': '0.862'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.717', 'ms1ms2_ratio': '5.205', 'efficiency': '0.591', 'TP': '19', 'FP': '7', 'FN': '1', 'precision': '0.731', 'recall': '0.950', 'f1': '0.826'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.826', 'ms1ms2_ratio': '3.828', 'efficiency': '0.552', 'TP': '25', 'FP': '7', 'FN': '0', 'precision': '0.781', 'recall': '1.000', 'f1': '0.877'}
#
# Episode 26 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.808', 'ms1ms2_ratio': '2.932', 'efficiency': '0.438', 'TP': '27', 'FP': '5', 'FN': '2', 'precision': '0.844', 'recall': '0.931', 'f1': '0.885'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.793', 'ms1ms2_ratio': '4.412', 'efficiency': '0.490', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.728', 'ms1ms2_ratio': '4.055', 'efficiency': '0.491', 'TP': '19', 'FP': '8', 'FN': '1', 'precision': '0.704', 'recall': '0.950', 'f1': '0.809'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.626', 'ms1ms2_ratio': '4.957', 'efficiency': '0.717', 'TP': '20', 'FP': '13', 'FN': '1', 'precision': '0.606', 'recall': '0.952', 'f1': '0.741'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.846', 'ms1ms2_ratio': '0.854', 'efficiency': '0.141', 'TP': '23', 'FP': '3', 'FN': '2', 'precision': '0.885', 'recall': '0.920', 'f1': '0.902'}
#
# Episode 1 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.826', 'ms1ms2_ratio': '1.252', 'efficiency': '0.147', 'TP': '19', 'FP': '2', 'FN': '1', 'precision': '0.905', 'recall': '0.950', 'f1': '0.927'}
#
# Episode 2 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.772', 'efficiency': '0.228', 'TP': '38', 'FP': '7', 'FN': '0', 'precision': '0.844', 'recall': '1.000', 'f1': '0.916'}
#
# Episode 3 finished
# {'coverage_prop': '0.893', 'intensity_prop': '0.702', 'ms1ms2_ratio': '1.277', 'efficiency': '0.177', 'TP': '20', 'FP': '5', 'FN': '3', 'precision': '0.800', 'recall': '0.870', 'f1': '0.833'}
#
# Episode 4 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.806', 'ms1ms2_ratio': '1.252', 'efficiency': '0.140', 'TP': '16', 'FP': '4', 'FN': '0', 'precision': '0.800', 'recall': '1.000', 'f1': '0.889'}
#
# Episode 5 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.861', 'ms1ms2_ratio': '0.430', 'efficiency': '0.141', 'TP': '33', 'FP': '5', 'FN': '0', 'precision': '0.868', 'recall': '1.000', 'f1': '0.930'}
#
# Episode 6 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.869', 'ms1ms2_ratio': '0.594', 'efficiency': '0.144', 'TP': '31', 'FP': '2', 'FN': '1', 'precision': '0.939', 'recall': '0.969', 'f1': '0.954'}
#
# Episode 7 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.954', 'ms1ms2_ratio': '0.798', 'efficiency': '0.109', 'TP': '20', 'FP': '1', 'FN': '0', 'precision': '0.952', 'recall': '1.000', 'f1': '0.976'}
#
# Episode 8 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.905', 'ms1ms2_ratio': '0.438', 'efficiency': '0.139', 'TP': '34', 'FP': '3', 'FN': '0', 'precision': '0.919', 'recall': '1.000', 'f1': '0.958'}
#
# Episode 9 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.852', 'ms1ms2_ratio': '0.452', 'efficiency': '0.171', 'TP': '39', 'FP': '6', 'FN': '0', 'precision': '0.867', 'recall': '1.000', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.912', 'ms1ms2_ratio': '0.460', 'efficiency': '0.138', 'TP': '34', 'FP': '2', 'FN': '0', 'precision': '0.944', 'recall': '1.000', 'f1': '0.971'}
#
# Episode 11 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.865', 'ms1ms2_ratio': '0.575', 'efficiency': '0.197', 'TP': '41', 'FP': '5', 'FN': '0', 'precision': '0.891', 'recall': '1.000', 'f1': '0.943'}
#
# Episode 12 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.898', 'ms1ms2_ratio': '0.338', 'efficiency': '0.161', 'TP': '45', 'FP': '3', 'FN': '1', 'precision': '0.938', 'recall': '0.978', 'f1': '0.957'}
#
# Episode 13 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.788', 'ms1ms2_ratio': '1.075', 'efficiency': '0.151', 'TP': '20', 'FP': '4', 'FN': '0', 'precision': '0.833', 'recall': '1.000', 'f1': '0.909'}
#
# Episode 14 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.604', 'efficiency': '0.137', 'TP': '27', 'FP': '4', 'FN': '1', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915'}
#
# Episode 15 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.899', 'ms1ms2_ratio': '0.398', 'efficiency': '0.151', 'TP': '38', 'FP': '4', 'FN': '0', 'precision': '0.905', 'recall': '1.000', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.812', 'ms1ms2_ratio': '1.018', 'efficiency': '0.145', 'TP': '20', 'FP': '4', 'FN': '1', 'precision': '0.833', 'recall': '0.952', 'f1': '0.889'}
#
# Episode 17 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.836', 'ms1ms2_ratio': '0.676', 'efficiency': '0.160', 'TP': '29', 'FP': '5', 'FN': '0', 'precision': '0.853', 'recall': '1.000', 'f1': '0.921'}
#
# Episode 18 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.834', 'ms1ms2_ratio': '0.416', 'efficiency': '0.150', 'TP': '38', 'FP': '3', 'FN': '3', 'precision': '0.927', 'recall': '0.927', 'f1': '0.927'}
#
# Episode 19 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.854', 'ms1ms2_ratio': '0.539', 'efficiency': '0.149', 'TP': '32', 'FP': '4', 'FN': '1', 'precision': '0.889', 'recall': '0.970', 'f1': '0.928'}
#
# Episode 20 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.779', 'ms1ms2_ratio': '1.000', 'efficiency': '0.132', 'TP': '17', 'FP': '5', 'FN': '1', 'precision': '0.773', 'recall': '0.944', 'f1': '0.850'}
#
# Episode 21 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.460', 'efficiency': '0.146', 'TP': '33', 'FP': '5', 'FN': '2', 'precision': '0.868', 'recall': '0.943', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.906', 'ms1ms2_ratio': '0.338', 'efficiency': '0.144', 'TP': '39', 'FP': '4', 'FN': '0', 'precision': '0.907', 'recall': '1.000', 'f1': '0.951'}
#
# Episode 23 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.594', 'efficiency': '0.157', 'TP': '29', 'FP': '7', 'FN': '1', 'precision': '0.806', 'recall': '0.967', 'f1': '0.879'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.759', 'ms1ms2_ratio': '1.056', 'efficiency': '0.161', 'TP': '21', 'FP': '5', 'FN': '1', 'precision': '0.808', 'recall': '0.955', 'f1': '0.875'}
#
# Episode 25 finished
# {'coverage_prop': '1.000', 'intensity_prop': '0.862', 'ms1ms2_ratio': '0.869', 'efficiency': '0.175', 'TP': '28', 'FP': '4', 'FN': '0', 'precision': '0.875', 'recall': '1.000', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.835', 'ms1ms2_ratio': '0.465', 'efficiency': '0.123', 'TP': '28', 'FP': '4', 'FN': '2', 'precision': '0.875', 'recall': '0.933', 'f1': '0.903'}
#
# Episode 27 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.854', 'efficiency': '0.135', 'TP': '20', 'FP': '5', 'FN': '1', 'precision': '0.800', 'recall': '0.952', 'f1': '0.870'}
#
# Episode 28 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.710', 'efficiency': '0.130', 'TP': '23', 'FP': '4', 'FN': '1', 'precision': '0.852', 'recall': '0.958', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.685', 'ms1ms2_ratio': '1.018', 'efficiency': '0.200', 'TP': '23', 'FP': '10', 'FN': '1', 'precision': '0.697', 'recall': '0.958', 'f1': '0.807'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    -440.237395                 454.0          0.821           0.653
# 1  random    -453.345434                 462.0          0.727           0.620
# 2  random    -461.032256                 469.0          0.911           0.675
# 3  random    -468.957747                 475.0          0.679           0.488
# 4  random    -455.690065                 463.0          0.900           0.686
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.012       0.047      0.826   0.792  0.809
# 1          0.016       0.033      0.875   0.700  0.778
# 2          0.010       0.084      0.805   0.892  0.846
# 3          0.014       0.039      0.895   0.654  0.756
# 4          0.019       0.037      0.778   0.875  0.824

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.5E5.p')

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.5E5.p')

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN      76.867330                   0.0          0.964           0.849
# 31    DQN      72.973941                   0.0          0.955           0.809
# 32    DQN      78.993665                   0.0          1.000           0.831
# 33    DQN      74.155456                   0.0          0.893           0.677
# 34    DQN      72.916039                   0.0          0.950           0.803
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.654       0.124      0.889   0.960  0.923
# 31          0.948       0.121      0.857   0.947  0.900
# 32          0.684       0.212      0.822   1.000  0.902
# 33          0.982       0.148      0.800   0.870  0.833
# 34          0.798       0.098      0.895   0.944  0.919

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
