# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from vimms_gym.experiments import preset_qcb_large
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_large(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-07 22:56:22.610 | INFO     | vimms_gym.experiments:get_samplers:295 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_large_extracted.p
# ({'chemical_creator': {'mz_range': (70, 1000),
#    'rt_range': (0, 1440),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (2000, 5000),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9718535a00>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f97089c1550>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9708a1ddf0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (70, 1000)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (0, 1440),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  200)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_10.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 15
topN_rt_tol = 15
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 240
weighteddew_N = 15

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_large.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 2599
# 4191
# 4880
# 3447
# 3722
# 2383
# 4001
# 3885
# 3295
# 2598
# 2013
# 4096
# 2826
# 4601
# 4042
# 4292
# 4929
# 3450
# 4241
# 4591
# 2400
# 4777
# 2012
# 4104
# 2521
# 2364
# 4850
# 4326
# 4153
# 3219

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (70, 1000),
#  'rt_range': (0, 1440),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (2000, 5000),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9718535a00>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f97089c1550>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9708a1ddf0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (70, 1000),
#   'rt_range': (0, 1440),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (2000, 5000),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9718535a00>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f97089c1550>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9708a1ddf0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (70, 1000)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (0, 1440),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_10.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_10.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=False, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, store_obs=False)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
# {'coverage_prop': '0.441', 'intensity_prop': '0.165', 'ms1ms2_ratio': '0.005', 'efficiency': '0.161', 'TP': '400', 'FP': '746', 'FN': '1453', 'precision': '0.349', 'recall': '0.216', 'f1': '0.267', 'total_rewards': -5930.176919385544, 'invalid_action_count': 6181, 'num_ms1_scans': 36, 'num_ms2_scans': 7128}
# {'coverage_prop': '0.500', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.004', 'efficiency': '0.293', 'TP': '793', 'FP': '1301', 'FN': '2097', 'precision': '0.379', 'recall': '0.274', 'f1': '0.318', 'total_rewards': -5339.250395927404, 'invalid_action_count': 5735, 'num_ms1_scans': 31, 'num_ms2_scans': 7138}
# {'coverage_prop': '0.564', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.005', 'efficiency': '0.386', 'TP': '1087', 'FP': '1666', 'FN': '2127', 'precision': '0.395', 'recall': '0.338', 'f1': '0.364', 'total_rewards': -4650.9371826043325, 'invalid_action_count': 5197, 'num_ms1_scans': 33, 'num_ms2_scans': 7134}
# {'coverage_prop': '0.455', 'intensity_prop': '0.179', 'ms1ms2_ratio': '0.004', 'efficiency': '0.220', 'TP': '580', 'FP': '990', 'FN': '1877', 'precision': '0.369', 'recall': '0.236', 'f1': '0.288', 'total_rewards': -5695.025849300875, 'invalid_action_count': 6015, 'num_ms1_scans': 30, 'num_ms2_scans': 7140}
# {'coverage_prop': '0.548', 'intensity_prop': '0.224', 'ms1ms2_ratio': '0.006', 'efficiency': '0.287', 'TP': '824', 'FP': '1216', 'FN': '1682', 'precision': '0.404', 'recall': '0.329', 'f1': '0.363', 'total_rewards': -5027.705410881567, 'invalid_action_count': 5479, 'num_ms1_scans': 44, 'num_ms2_scans': 7112}
# {'coverage_prop': '0.462', 'intensity_prop': '0.157', 'ms1ms2_ratio': '0.003', 'efficiency': '0.154', 'TP': '334', 'FP': '766', 'FN': '1283', 'precision': '0.304', 'recall': '0.207', 'f1': '0.246', 'total_rewards': -6158.942663659489, 'invalid_action_count': 6376, 'num_ms1_scans': 25, 'num_ms2_scans': 7150}
# {'coverage_prop': '0.566', 'intensity_prop': '0.236', 'ms1ms2_ratio': '0.006', 'efficiency': '0.318', 'TP': '924', 'FP': '1340', 'FN': '1737', 'precision': '0.408', 'recall': '0.347', 'f1': '0.375', 'total_rewards': -4906.602624692457, 'invalid_action_count': 5388, 'num_ms1_scans': 41, 'num_ms2_scans': 7118}
# {'coverage_prop': '0.418', 'intensity_prop': '0.146', 'ms1ms2_ratio': '0.004', 'efficiency': '0.227', 'TP': '511', 'FP': '1113', 'FN': '2261', 'precision': '0.315', 'recall': '0.184', 'f1': '0.232', 'total_rewards': -5757.556672748447, 'invalid_action_count': 6060, 'num_ms1_scans': 29, 'num_ms2_scans': 7142}
# {'coverage_prop': '0.512', 'intensity_prop': '0.209', 'ms1ms2_ratio': '0.005', 'efficiency': '0.237', 'TP': '671', 'FP': '1016', 'FN': '1608', 'precision': '0.398', 'recall': '0.294', 'f1': '0.338', 'total_rewards': -5492.225683314916, 'invalid_action_count': 5849, 'num_ms1_scans': 36, 'num_ms2_scans': 7128}
# {'coverage_prop': '0.450', 'intensity_prop': '0.159', 'ms1ms2_ratio': '0.005', 'efficiency': '0.164', 'TP': '372', 'FP': '796', 'FN': '1430', 'precision': '0.318', 'recall': '0.206', 'f1': '0.251', 'total_rewards': -5977.225257791031, 'invalid_action_count': 6232, 'num_ms1_scans': 33, 'num_ms2_scans': 7134}
# {'coverage_prop': '0.377', 'intensity_prop': '0.124', 'ms1ms2_ratio': '0.004', 'efficiency': '0.106', 'TP': '226', 'FP': '533', 'FN': '1254', 'precision': '0.298', 'recall': '0.153', 'f1': '0.202', 'total_rewards': -6340.347421585801, 'invalid_action_count': 6513, 'num_ms1_scans': 26, 'num_ms2_scans': 7148}
# {'coverage_prop': '0.510', 'intensity_prop': '0.203', 'ms1ms2_ratio': '0.006', 'efficiency': '0.294', 'TP': '792', 'FP': '1299', 'FN': '2005', 'precision': '0.379', 'recall': '0.283', 'f1': '0.324', 'total_rewards': -5173.616942430882, 'invalid_action_count': 5593, 'num_ms1_scans': 40, 'num_ms2_scans': 7120}
# {'coverage_prop': '0.507', 'intensity_prop': '0.211', 'ms1ms2_ratio': '0.006', 'efficiency': '0.202', 'TP': '593', 'FP': '841', 'FN': '1392', 'precision': '0.414', 'recall': '0.299', 'f1': '0.347', 'total_rewards': -5509.574348698213, 'invalid_action_count': 5841, 'num_ms1_scans': 42, 'num_ms2_scans': 7116}
# {'coverage_prop': '0.551', 'intensity_prop': '0.224', 'ms1ms2_ratio': '0.005', 'efficiency': '0.355', 'TP': '1010', 'FP': '1524', 'FN': '2067', 'precision': '0.399', 'recall': '0.328', 'f1': '0.360', 'total_rewards': -5024.095573675302, 'invalid_action_count': 5488, 'num_ms1_scans': 33, 'num_ms2_scans': 7134}
# {'coverage_prop': '0.509', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.004', 'efficiency': '0.288', 'TP': '774', 'FP': '1284', 'FN': '1984', 'precision': '0.376', 'recall': '0.281', 'f1': '0.321', 'total_rewards': -5368.534671431439, 'invalid_action_count': 5754, 'num_ms1_scans': 32, 'num_ms2_scans': 7136}
# {'coverage_prop': '0.527', 'intensity_prop': '0.211', 'ms1ms2_ratio': '0.005', 'efficiency': '0.317', 'TP': '893', 'FP': '1367', 'FN': '2032', 'precision': '0.395', 'recall': '0.305', 'f1': '0.344', 'total_rewards': -5014.873094736559, 'invalid_action_count': 5477, 'num_ms1_scans': 37, 'num_ms2_scans': 7126}
# {'coverage_prop': '0.458', 'intensity_prop': '0.170', 'ms1ms2_ratio': '0.006', 'efficiency': '0.317', 'TP': '795', 'FP': '1462', 'FN': '2672', 'precision': '0.352', 'recall': '0.229', 'f1': '0.278', 'total_rewards': -5179.372826732106, 'invalid_action_count': 5596, 'num_ms1_scans': 43, 'num_ms2_scans': 7114}
# {'coverage_prop': '0.487', 'intensity_prop': '0.188', 'ms1ms2_ratio': '0.005', 'efficiency': '0.235', 'TP': '633', 'FP': '1046', 'FN': '1771', 'precision': '0.377', 'recall': '0.263', 'f1': '0.310', 'total_rewards': -5622.344356566532, 'invalid_action_count': 5954, 'num_ms1_scans': 35, 'num_ms2_scans': 7130}
# {'coverage_prop': '0.549', 'intensity_prop': '0.224', 'ms1ms2_ratio': '0.005', 'efficiency': '0.327', 'TP': '920', 'FP': '1409', 'FN': '1912', 'precision': '0.395', 'recall': '0.325', 'f1': '0.357', 'total_rewards': -4971.67938339279, 'invalid_action_count': 5437, 'num_ms1_scans': 34, 'num_ms2_scans': 7132}
# {'coverage_prop': '0.526', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.003', 'efficiency': '0.338', 'TP': '880', 'FP': '1536', 'FN': '2175', 'precision': '0.364', 'recall': '0.288', 'f1': '0.322', 'total_rewards': -5243.12155970981, 'invalid_action_count': 5663, 'num_ms1_scans': 24, 'num_ms2_scans': 7152}
# {'coverage_prop': '0.509', 'intensity_prop': '0.207', 'ms1ms2_ratio': '0.007', 'efficiency': '0.172', 'TP': '489', 'FP': '733', 'FN': '1178', 'precision': '0.400', 'recall': '0.293', 'f1': '0.339', 'total_rewards': -5608.05456955715, 'invalid_action_count': 5917, 'num_ms1_scans': 48, 'num_ms2_scans': 7104}
# {'coverage_prop': '0.471', 'intensity_prop': '0.178', 'ms1ms2_ratio': '0.004', 'efficiency': '0.315', 'TP': '799', 'FP': '1452', 'FN': '2526', 'precision': '0.355', 'recall': '0.240', 'f1': '0.287', 'total_rewards': -5386.934941449621, 'invalid_action_count': 5774, 'num_ms1_scans': 31, 'num_ms2_scans': 7138}
# {'coverage_prop': '0.441', 'intensity_prop': '0.159', 'ms1ms2_ratio': '0.005', 'efficiency': '0.125', 'TP': '285', 'FP': '602', 'FN': '1125', 'precision': '0.321', 'recall': '0.202', 'f1': '0.248', 'total_rewards': -6083.384570567858, 'invalid_action_count': 6306, 'num_ms1_scans': 39, 'num_ms2_scans': 7122}
# {'coverage_prop': '0.509', 'intensity_prop': '0.209', 'ms1ms2_ratio': '0.004', 'efficiency': '0.292', 'TP': '826', 'FP': '1261', 'FN': '2017', 'precision': '0.396', 'recall': '0.291', 'f1': '0.335', 'total_rewards': -5304.421695609609, 'invalid_action_count': 5708, 'num_ms1_scans': 32, 'num_ms2_scans': 7136}
# {'coverage_prop': '0.442', 'intensity_prop': '0.156', 'ms1ms2_ratio': '0.005', 'efficiency': '0.156', 'TP': '359', 'FP': '755', 'FN': '1407', 'precision': '0.322', 'recall': '0.203', 'f1': '0.249', 'total_rewards': -5886.156103921123, 'invalid_action_count': 6147, 'num_ms1_scans': 37, 'num_ms2_scans': 7126}
# {'coverage_prop': '0.442', 'intensity_prop': '0.168', 'ms1ms2_ratio': '0.006', 'efficiency': '0.147', 'TP': '378', 'FP': '668', 'FN': '1318', 'precision': '0.361', 'recall': '0.223', 'f1': '0.276', 'total_rewards': -5938.9586608943655, 'invalid_action_count': 6185, 'num_ms1_scans': 46, 'num_ms2_scans': 7108}
# {'coverage_prop': '0.501', 'intensity_prop': '0.191', 'ms1ms2_ratio': '0.004', 'efficiency': '0.340', 'TP': '899', 'FP': '1531', 'FN': '2420', 'precision': '0.370', 'recall': '0.271', 'f1': '0.313', 'total_rewards': -5219.342370630668, 'invalid_action_count': 5642, 'num_ms1_scans': 29, 'num_ms2_scans': 7142}
# {'coverage_prop': '0.598', 'intensity_prop': '0.262', 'ms1ms2_ratio': '0.006', 'efficiency': '0.364', 'TP': '1148', 'FP': '1439', 'FN': '1739', 'precision': '0.444', 'recall': '0.398', 'f1': '0.419', 'total_rewards': -4631.975200113461, 'invalid_action_count': 5172, 'num_ms1_scans': 43, 'num_ms2_scans': 7114}
# {'coverage_prop': '0.536', 'intensity_prop': '0.225', 'ms1ms2_ratio': '0.007', 'efficiency': '0.314', 'TP': '927', 'FP': '1300', 'FN': '1926', 'precision': '0.416', 'recall': '0.325', 'f1': '0.365', 'total_rewards': -4715.379203964311, 'invalid_action_count': 5203, 'num_ms1_scans': 53, 'num_ms2_scans': 7094}
# {'coverage_prop': '0.522', 'intensity_prop': '0.194', 'ms1ms2_ratio': '0.006', 'efficiency': '0.236', 'TP': '596', 'FP': '1084', 'FN': '1539', 'precision': '0.355', 'recall': '0.279', 'f1': '0.312', 'total_rewards': -5477.792383873522, 'invalid_action_count': 5831, 'num_ms1_scans': 42, 'num_ms2_scans': 7116}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.33GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
# {'coverage_prop': '0.812', 'intensity_prop': '0.533', 'ms1ms2_ratio': '0.136', 'efficiency': '0.373', 'TP': '1567', 'FP': '543', 'FN': '489', 'precision': '0.743', 'recall': '0.762', 'f1': '0.752', 'total_rewards': 1050.231805643866, 'invalid_action_count': 45, 'num_ms1_scans': 770, 'num_ms2_scans': 5661}
# {'coverage_prop': '0.726', 'intensity_prop': '0.449', 'ms1ms2_ratio': '0.119', 'efficiency': '0.523', 'TP': '2099', 'FP': '942', 'FN': '1150', 'precision': '0.690', 'recall': '0.646', 'f1': '0.667', 'total_rewards': 1100.0939291450532, 'invalid_action_count': 98, 'num_ms1_scans': 690, 'num_ms2_scans': 5820}
# {'coverage_prop': '0.719', 'intensity_prop': '0.446', 'ms1ms2_ratio': '0.107', 'efficiency': '0.592', 'TP': '2407', 'FP': '1104', 'FN': '1369', 'precision': '0.686', 'recall': '0.637', 'f1': '0.661', 'total_rewards': 1201.9759553716356, 'invalid_action_count': 57, 'num_ms1_scans': 635, 'num_ms2_scans': 5930}
# {'coverage_prop': '0.768', 'intensity_prop': '0.498', 'ms1ms2_ratio': '0.122', 'efficiency': '0.457', 'TP': '1909', 'FP': '738', 'FN': '800', 'precision': '0.721', 'recall': '0.705', 'f1': '0.713', 'total_rewards': 1132.1032749373362, 'invalid_action_count': 30, 'num_ms1_scans': 705, 'num_ms2_scans': 5790}
# {'coverage_prop': '0.764', 'intensity_prop': '0.481', 'ms1ms2_ratio': '0.113', 'efficiency': '0.485', 'TP': '1966', 'FP': '878', 'FN': '878', 'precision': '0.691', 'recall': '0.691', 'f1': '0.691', 'total_rewards': 1155.264613378094, 'invalid_action_count': 38, 'num_ms1_scans': 666, 'num_ms2_scans': 5868}
# {'coverage_prop': '0.811', 'intensity_prop': '0.540', 'ms1ms2_ratio': '0.167', 'efficiency': '0.358', 'TP': '1433', 'FP': '499', 'FN': '451', 'precision': '0.742', 'recall': '0.761', 'f1': '0.751', 'total_rewards': 1014.1063011309949, 'invalid_action_count': 43, 'num_ms1_scans': 901, 'num_ms2_scans': 5398}
# {'coverage_prop': '0.752', 'intensity_prop': '0.472', 'ms1ms2_ratio': '0.116', 'efficiency': '0.515', 'TP': '2088', 'FP': '922', 'FN': '991', 'precision': '0.694', 'recall': '0.678', 'f1': '0.686', 'total_rewards': 1119.1317370199924, 'invalid_action_count': 76, 'num_ms1_scans': 677, 'num_ms2_scans': 5847}
# {'coverage_prop': '0.770', 'intensity_prop': '0.485', 'ms1ms2_ratio': '0.115', 'efficiency': '0.511', 'TP': '2095', 'FP': '895', 'FN': '895', 'precision': '0.701', 'recall': '0.701', 'f1': '0.701', 'total_rewards': 1200.2981507853644, 'invalid_action_count': 36, 'num_ms1_scans': 674, 'num_ms2_scans': 5852}
# {'coverage_prop': '0.776', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.134', 'efficiency': '0.450', 'TP': '1874', 'FP': '682', 'FN': '739', 'precision': '0.733', 'recall': '0.717', 'f1': '0.725', 'total_rewards': 1118.5722464921785, 'invalid_action_count': 47, 'num_ms1_scans': 761, 'num_ms2_scans': 5678}
# {'coverage_prop': '0.804', 'intensity_prop': '0.521', 'ms1ms2_ratio': '0.155', 'efficiency': '0.380', 'TP': '1506', 'FP': '583', 'FN': '509', 'precision': '0.721', 'recall': '0.747', 'f1': '0.734', 'total_rewards': 1031.7756116314865, 'invalid_action_count': 45, 'num_ms1_scans': 851, 'num_ms2_scans': 5498}
# {'coverage_prop': '0.806', 'intensity_prop': '0.543', 'ms1ms2_ratio': '0.177', 'efficiency': '0.305', 'TP': '1236', 'FP': '386', 'FN': '391', 'precision': '0.762', 'recall': '0.760', 'f1': '0.761', 'total_rewards': 965.9787798598463, 'invalid_action_count': 31, 'num_ms1_scans': 941, 'num_ms2_scans': 5318}
# {'coverage_prop': '0.739', 'intensity_prop': '0.466', 'ms1ms2_ratio': '0.119', 'efficiency': '0.520', 'TP': '2109', 'FP': '916', 'FN': '1071', 'precision': '0.697', 'recall': '0.663', 'f1': '0.680', 'total_rewards': 1154.858852389583, 'invalid_action_count': 32, 'num_ms1_scans': 693, 'num_ms2_scans': 5814}
# {'coverage_prop': '0.788', 'intensity_prop': '0.510', 'ms1ms2_ratio': '0.131', 'efficiency': '0.391', 'TP': '1597', 'FP': '631', 'FN': '598', 'precision': '0.717', 'recall': '0.728', 'f1': '0.722', 'total_rewards': 1081.626247858273, 'invalid_action_count': 35, 'num_ms1_scans': 749, 'num_ms2_scans': 5702}
# {'coverage_prop': '0.745', 'intensity_prop': '0.467', 'ms1ms2_ratio': '0.105', 'efficiency': '0.576', 'TP': '2391', 'FP': '1035', 'FN': '1175', 'precision': '0.698', 'recall': '0.670', 'f1': '0.684', 'total_rewards': 1081.8823056057124, 'invalid_action_count': 167, 'num_ms1_scans': 627, 'num_ms2_scans': 5946}
# {'coverage_prop': '0.755', 'intensity_prop': '0.477', 'ms1ms2_ratio': '0.112', 'efficiency': '0.519', 'TP': '2150', 'FP': '903', 'FN': '989', 'precision': '0.704', 'recall': '0.685', 'f1': '0.694', 'total_rewards': 1167.8407493622165, 'invalid_action_count': 45, 'num_ms1_scans': 661, 'num_ms2_scans': 5878}
# {'coverage_prop': '0.738', 'intensity_prop': '0.462', 'ms1ms2_ratio': '0.113', 'efficiency': '0.539', 'TP': '2211', 'FP': '958', 'FN': '1123', 'precision': '0.698', 'recall': '0.663', 'f1': '0.680', 'total_rewards': 1163.253097901167, 'invalid_action_count': 78, 'num_ms1_scans': 663, 'num_ms2_scans': 5874}
# {'coverage_prop': '0.706', 'intensity_prop': '0.425', 'ms1ms2_ratio': '0.111', 'efficiency': '0.590', 'TP': '2299', 'FP': '1180', 'FN': '1450', 'precision': '0.661', 'recall': '0.613', 'f1': '0.636', 'total_rewards': 1172.5125685895498, 'invalid_action_count': 77, 'num_ms1_scans': 653, 'num_ms2_scans': 5894}
# {'coverage_prop': '0.772', 'intensity_prop': '0.502', 'ms1ms2_ratio': '0.128', 'efficiency': '0.464', 'TP': '1924', 'FP': '738', 'FN': '788', 'precision': '0.723', 'recall': '0.709', 'f1': '0.716', 'total_rewards': 1118.6679555284281, 'invalid_action_count': 29, 'num_ms1_scans': 734, 'num_ms2_scans': 5732}
# {'coverage_prop': '0.751', 'intensity_prop': '0.464', 'ms1ms2_ratio': '0.115', 'efficiency': '0.545', 'TP': '2184', 'FP': '1003', 'FN': '1054', 'precision': '0.685', 'recall': '0.674', 'f1': '0.680', 'total_rewards': 1182.8645660130353, 'invalid_action_count': 49, 'num_ms1_scans': 675, 'num_ms2_scans': 5850}
# {'coverage_prop': '0.731', 'intensity_prop': '0.449', 'ms1ms2_ratio': '0.111', 'efficiency': '0.570', 'TP': '2314', 'FP': '1044', 'FN': '1233', 'precision': '0.689', 'recall': '0.652', 'f1': '0.670', 'total_rewards': 1163.5355888259608, 'invalid_action_count': 56, 'num_ms1_scans': 656, 'num_ms2_scans': 5888}
# {'coverage_prop': '0.806', 'intensity_prop': '0.530', 'ms1ms2_ratio': '0.136', 'efficiency': '0.342', 'TP': '1442', 'FP': '492', 'FN': '466', 'precision': '0.746', 'recall': '0.756', 'f1': '0.751', 'total_rewards': 1046.6231833202137, 'invalid_action_count': 43, 'num_ms1_scans': 769, 'num_ms2_scans': 5662}
# {'coverage_prop': '0.721', 'intensity_prop': '0.444', 'ms1ms2_ratio': '0.109', 'efficiency': '0.583', 'TP': '2352', 'FP': '1093', 'FN': '1332', 'precision': '0.683', 'recall': '0.638', 'f1': '0.660', 'total_rewards': 1175.0073255788436, 'invalid_action_count': 56, 'num_ms1_scans': 643, 'num_ms2_scans': 5914}
# {'coverage_prop': '0.828', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.171', 'efficiency': '0.310', 'TP': '1252', 'FP': '413', 'FN': '347', 'precision': '0.752', 'recall': '0.783', 'f1': '0.767', 'total_rewards': 896.4411715371033, 'invalid_action_count': 108, 'num_ms1_scans': 916, 'num_ms2_scans': 5368}
# {'coverage_prop': '0.759', 'intensity_prop': '0.480', 'ms1ms2_ratio': '0.111', 'efficiency': '0.528', 'TP': '2194', 'FP': '922', 'FN': '988', 'precision': '0.704', 'recall': '0.690', 'f1': '0.697', 'total_rewards': 1178.055717161255, 'invalid_action_count': 36, 'num_ms1_scans': 652, 'num_ms2_scans': 5896}
# {'coverage_prop': '0.793', 'intensity_prop': '0.521', 'ms1ms2_ratio': '0.154', 'efficiency': '0.363', 'TP': '1470', 'FP': '530', 'FN': '521', 'precision': '0.735', 'recall': '0.738', 'f1': '0.737', 'total_rewards': 1042.9177476699392, 'invalid_action_count': 40, 'num_ms1_scans': 848, 'num_ms2_scans': 5504}
# {'coverage_prop': '0.810', 'intensity_prop': '0.537', 'ms1ms2_ratio': '0.164', 'efficiency': '0.353', 'TP': '1402', 'FP': '512', 'FN': '450', 'precision': '0.732', 'recall': '0.757', 'f1': '0.745', 'total_rewards': 1001.6659476953184, 'invalid_action_count': 40, 'num_ms1_scans': 891, 'num_ms2_scans': 5418}
# {'coverage_prop': '0.718', 'intensity_prop': '0.444', 'ms1ms2_ratio': '0.115', 'efficiency': '0.594', 'TP': '2382', 'FP': '1098', 'FN': '1370', 'precision': '0.684', 'recall': '0.635', 'f1': '0.659', 'total_rewards': 1209.2564426583585, 'invalid_action_count': 43, 'num_ms1_scans': 671, 'num_ms2_scans': 5858}
# {'coverage_prop': '0.685', 'intensity_prop': '0.408', 'ms1ms2_ratio': '0.091', 'efficiency': '0.486', 'TP': '1953', 'FP': '1009', 'FN': '1364', 'precision': '0.659', 'recall': '0.589', 'f1': '0.622', 'total_rewards': -654.8936588449853, 'invalid_action_count': 1653, 'num_ms1_scans': 553, 'num_ms2_scans': 6094}
# {'coverage_prop': '0.604', 'intensity_prop': '0.366', 'ms1ms2_ratio': '0.080', 'efficiency': '0.404', 'TP': '1688', 'FP': '822', 'FN': '1643', 'precision': '0.673', 'recall': '0.507', 'f1': '0.578', 'total_rewards': -1635.005137136993, 'invalid_action_count': 2464, 'num_ms1_scans': 495, 'num_ms2_scans': 6210}
# {'coverage_prop': '0.779', 'intensity_prop': '0.498', 'ms1ms2_ratio': '0.122', 'efficiency': '0.433', 'TP': '1789', 'FP': '719', 'FN': '711', 'precision': '0.713', 'recall': '0.716', 'f1': '0.714', 'total_rewards': 1115.9113857593575, 'invalid_action_count': 40, 'num_ms1_scans': 706, 'num_ms2_scans': 5788}
#
# method = topN max_peaks = 200 N = 15 rt_tol = 15
#
# {'coverage_prop': '0.880', 'intensity_prop': '0.592', 'ms1ms2_ratio': '0.190', 'efficiency': '0.439', 'TP': '1762', 'FP': '525', 'FN': '312', 'precision': '0.770', 'recall': '0.850', 'f1': '0.808', 'total_rewards': 1055.2237616424225, 'invalid_action_count': 0, 'num_ms1_scans': 993, 'num_ms2_scans': 5214}
# {'coverage_prop': '0.783', 'intensity_prop': '0.509', 'ms1ms2_ratio': '0.148', 'efficiency': '0.590', 'TP': '2435', 'FP': '845', 'FN': '911', 'precision': '0.742', 'recall': '0.728', 'f1': '0.735', 'total_rewards': 1196.5626782451957, 'invalid_action_count': 0, 'num_ms1_scans': 822, 'num_ms2_scans': 5556}
# {'coverage_prop': '0.751', 'intensity_prop': '0.487', 'ms1ms2_ratio': '0.137', 'efficiency': '0.649', 'TP': '2688', 'FP': '975', 'FN': '1217', 'precision': '0.734', 'recall': '0.688', 'f1': '0.710', 'total_rewards': 1241.704702032651, 'invalid_action_count': 0, 'num_ms1_scans': 776, 'num_ms2_scans': 5648}
# {'coverage_prop': '0.813', 'intensity_prop': '0.539', 'ms1ms2_ratio': '0.172', 'efficiency': '0.523', 'TP': '2140', 'FP': '663', 'FN': '644', 'precision': '0.763', 'recall': '0.769', 'f1': '0.766', 'total_rewards': 1111.9347762277357, 'invalid_action_count': 0, 'num_ms1_scans': 921, 'num_ms2_scans': 5359}
# {'coverage_prop': '0.817', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.145', 'efficiency': '0.545', 'TP': '2234', 'FP': '808', 'FN': '680', 'precision': '0.734', 'recall': '0.767', 'f1': '0.750', 'total_rewards': 1174.4796060411977, 'invalid_action_count': 0, 'num_ms1_scans': 809, 'num_ms2_scans': 5582}
# {'coverage_prop': '0.872', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.327', 'efficiency': '0.477', 'TP': '1549', 'FP': '529', 'FN': '305', 'precision': '0.745', 'recall': '0.835', 'f1': '0.788', 'total_rewards': 906.8851126741607, 'invalid_action_count': 0, 'num_ms1_scans': 1423, 'num_ms2_scans': 4355}
# {'coverage_prop': '0.798', 'intensity_prop': '0.530', 'ms1ms2_ratio': '0.148', 'efficiency': '0.575', 'TP': '2412', 'FP': '782', 'FN': '807', 'precision': '0.755', 'recall': '0.749', 'f1': '0.752', 'total_rewards': 1198.1232164317598, 'invalid_action_count': 0, 'num_ms1_scans': 823, 'num_ms2_scans': 5554}
# {'coverage_prop': '0.802', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.151', 'efficiency': '0.564', 'TP': '2345', 'FP': '771', 'FN': '769', 'precision': '0.753', 'recall': '0.753', 'f1': '0.753', 'total_rewards': 1189.9004765274833, 'invalid_action_count': 0, 'num_ms1_scans': 837, 'num_ms2_scans': 5526}
# {'coverage_prop': '0.834', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.209', 'efficiency': '0.541', 'TP': '2073', 'FP': '674', 'FN': '548', 'precision': '0.755', 'recall': '0.791', 'f1': '0.772', 'total_rewards': 1079.5392601825283, 'invalid_action_count': 0, 'num_ms1_scans': 1063, 'num_ms2_scans': 5075}
# {'coverage_prop': '0.861', 'intensity_prop': '0.563', 'ms1ms2_ratio': '0.258', 'efficiency': '0.471', 'TP': '1653', 'FP': '583', 'FN': '362', 'precision': '0.739', 'recall': '0.820', 'f1': '0.778', 'total_rewards': 969.6735328199294, 'invalid_action_count': 0, 'num_ms1_scans': 1226, 'num_ms2_scans': 4748}
# {'coverage_prop': '0.889', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.304', 'efficiency': '0.400', 'TP': '1364', 'FP': '426', 'FN': '223', 'precision': '0.762', 'recall': '0.859', 'f1': '0.808', 'total_rewards': 893.4721186994552, 'invalid_action_count': 0, 'num_ms1_scans': 1362, 'num_ms2_scans': 4476}
# {'coverage_prop': '0.793', 'intensity_prop': '0.515', 'ms1ms2_ratio': '0.146', 'efficiency': '0.583', 'TP': '2399', 'FP': '851', 'FN': '846', 'precision': '0.738', 'recall': '0.739', 'f1': '0.739', 'total_rewards': 1189.9485330572631, 'invalid_action_count': 0, 'num_ms1_scans': 813, 'num_ms2_scans': 5574}
# {'coverage_prop': '0.845', 'intensity_prop': '0.561', 'ms1ms2_ratio': '0.194', 'efficiency': '0.460', 'TP': '1793', 'FP': '596', 'FN': '437', 'precision': '0.751', 'recall': '0.804', 'f1': '0.776', 'total_rewards': 1074.4657768975092, 'invalid_action_count': 0, 'num_ms1_scans': 1006, 'num_ms2_scans': 5188}
# {'coverage_prop': '0.797', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.140', 'efficiency': '0.651', 'TP': '2740', 'FP': '925', 'FN': '936', 'precision': '0.748', 'recall': '0.745', 'f1': '0.746', 'total_rewards': 1254.0388351413928, 'invalid_action_count': 0, 'num_ms1_scans': 787, 'num_ms2_scans': 5626}
# {'coverage_prop': '0.798', 'intensity_prop': '0.528', 'ms1ms2_ratio': '0.142', 'efficiency': '0.575', 'TP': '2417', 'FP': '808', 'FN': '817', 'precision': '0.749', 'recall': '0.747', 'f1': '0.748', 'total_rewards': 1195.5476230002462, 'invalid_action_count': 0, 'num_ms1_scans': 795, 'num_ms2_scans': 5610}
# {'coverage_prop': '0.796', 'intensity_prop': '0.520', 'ms1ms2_ratio': '0.150', 'efficiency': '0.616', 'TP': '2545', 'FP': '870', 'FN': '877', 'precision': '0.745', 'recall': '0.744', 'f1': '0.744', 'total_rewards': 1234.227894442583, 'invalid_action_count': 0, 'num_ms1_scans': 830, 'num_ms2_scans': 5540}
# {'coverage_prop': '0.755', 'intensity_prop': '0.487', 'ms1ms2_ratio': '0.141', 'efficiency': '0.662', 'TP': '2706', 'FP': '1016', 'FN': '1207', 'precision': '0.727', 'recall': '0.692', 'f1': '0.709', 'total_rewards': 1252.7995451592471, 'invalid_action_count': 0, 'num_ms1_scans': 790, 'num_ms2_scans': 5620}
# {'coverage_prop': '0.817', 'intensity_prop': '0.539', 'ms1ms2_ratio': '0.190', 'efficiency': '0.540', 'TP': '2124', 'FP': '694', 'FN': '632', 'precision': '0.754', 'recall': '0.771', 'f1': '0.762', 'total_rewards': 1102.9314167631383, 'invalid_action_count': 0, 'num_ms1_scans': 991, 'num_ms2_scans': 5218}
# {'coverage_prop': '0.788', 'intensity_prop': '0.517', 'ms1ms2_ratio': '0.138', 'efficiency': '0.592', 'TP': '2497', 'FP': '844', 'FN': '900', 'precision': '0.747', 'recall': '0.735', 'f1': '0.741', 'total_rewards': 1213.6967648828902, 'invalid_action_count': 0, 'num_ms1_scans': 780, 'num_ms2_scans': 5640}
# {'coverage_prop': '0.775', 'intensity_prop': '0.496', 'ms1ms2_ratio': '0.141', 'efficiency': '0.634', 'TP': '2567', 'FP': '992', 'FN': '1032', 'precision': '0.721', 'recall': '0.713', 'f1': '0.717', 'total_rewards': 1227.764493979787, 'invalid_action_count': 0, 'num_ms1_scans': 793, 'num_ms2_scans': 5614}
# {'coverage_prop': '0.875', 'intensity_prop': '0.576', 'ms1ms2_ratio': '0.217', 'efficiency': '0.418', 'TP': '1565', 'FP': '535', 'FN': '300', 'precision': '0.745', 'recall': '0.839', 'f1': '0.789', 'total_rewards': 998.7673646019791, 'invalid_action_count': 0, 'num_ms1_scans': 1091, 'num_ms2_scans': 5018}
# {'coverage_prop': '0.767', 'intensity_prop': '0.496', 'ms1ms2_ratio': '0.137', 'efficiency': '0.648', 'TP': '2673', 'FP': '990', 'FN': '1114', 'precision': '0.730', 'recall': '0.706', 'f1': '0.718', 'total_rewards': 1244.2654958503401, 'invalid_action_count': 0, 'num_ms1_scans': 775, 'num_ms2_scans': 5650}
# {'coverage_prop': '0.907', 'intensity_prop': '0.593', 'ms1ms2_ratio': '0.350', 'efficiency': '0.430', 'TP': '1328', 'FP': '496', 'FN': '188', 'precision': '0.728', 'recall': '0.876', 'f1': '0.795', 'total_rewards': 865.772956642795, 'invalid_action_count': 0, 'num_ms1_scans': 1482, 'num_ms2_scans': 4237}
# {'coverage_prop': '0.807', 'intensity_prop': '0.530', 'ms1ms2_ratio': '0.140', 'efficiency': '0.589', 'TP': '2465', 'FP': '847', 'FN': '792', 'precision': '0.744', 'recall': '0.757', 'f1': '0.750', 'total_rewards': 1204.3617372753124, 'invalid_action_count': 0, 'num_ms1_scans': 788, 'num_ms2_scans': 5624}
# {'coverage_prop': '0.853', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.239', 'efficiency': '0.441', 'TP': '1616', 'FP': '535', 'FN': '370', 'precision': '0.751', 'recall': '0.814', 'f1': '0.781', 'total_rewards': 985.6920882678257, 'invalid_action_count': 0, 'num_ms1_scans': 1163, 'num_ms2_scans': 4874}
# {'coverage_prop': '0.881', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.274', 'efficiency': '0.448', 'TP': '1564', 'FP': '519', 'FN': '281', 'precision': '0.751', 'recall': '0.848', 'f1': '0.796', 'total_rewards': 941.0514370670253, 'invalid_action_count': 0, 'num_ms1_scans': 1275, 'num_ms2_scans': 4651}
# {'coverage_prop': '0.754', 'intensity_prop': '0.483', 'ms1ms2_ratio': '0.136', 'efficiency': '0.646', 'TP': '2641', 'FP': '1014', 'FN': '1195', 'precision': '0.723', 'recall': '0.688', 'f1': '0.705', 'total_rewards': 1239.0036903097428, 'invalid_action_count': 0, 'num_ms1_scans': 772, 'num_ms2_scans': 5656}
# {'coverage_prop': '0.783', 'intensity_prop': '0.510', 'ms1ms2_ratio': '0.144', 'efficiency': '0.606', 'TP': '2518', 'FP': '870', 'FN': '938', 'precision': '0.743', 'recall': '0.729', 'f1': '0.736', 'total_rewards': 1210.2992760829886, 'invalid_action_count': 0, 'num_ms1_scans': 803, 'num_ms2_scans': 5594}
# {'coverage_prop': '0.772', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.144', 'efficiency': '0.574', 'TP': '2399', 'FP': '806', 'FN': '948', 'precision': '0.749', 'recall': '0.717', 'f1': '0.732', 'total_rewards': 1200.1941510800496, 'invalid_action_count': 0, 'num_ms1_scans': 806, 'num_ms2_scans': 5588}
# {'coverage_prop': '0.837', 'intensity_prop': '0.561', 'ms1ms2_ratio': '0.166', 'efficiency': '0.499', 'TP': '2072', 'FP': '621', 'FN': '526', 'precision': '0.769', 'recall': '0.798', 'f1': '0.783', 'total_rewards': 1120.3912499921048, 'invalid_action_count': 0, 'num_ms1_scans': 899, 'num_ms2_scans': 5402}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (70, 1000),
#   'rt_range': (0, 1440),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (2000, 5000),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9718535a00>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f97089c1550>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9708a1ddf0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (70, 1000)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (0, 1440),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 15,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.900', 'intensity_prop': '0.603', 'ms1ms2_ratio': '0.205', 'efficiency': '0.458', 'TP': '1775', 'FP': '563', 'FN': '261', 'precision': '0.759', 'recall': '0.872', 'f1': '0.812'}
#
# Episode 1 finished
# {'coverage_prop': '0.808', 'intensity_prop': '0.526', 'ms1ms2_ratio': '0.151', 'efficiency': '0.612', 'TP': '2507', 'FP': '881', 'FN': '803', 'precision': '0.740', 'recall': '0.757', 'f1': '0.749'}
#
# Episode 2 finished
# {'coverage_prop': '0.776', 'intensity_prop': '0.503', 'ms1ms2_ratio': '0.138', 'efficiency': '0.671', 'TP': '2806', 'FP': '982', 'FN': '1092', 'precision': '0.741', 'recall': '0.720', 'f1': '0.730'}
#
# Episode 3 finished
# {'coverage_prop': '0.845', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.183', 'efficiency': '0.552', 'TP': '2169', 'FP': '743', 'FN': '535', 'precision': '0.745', 'recall': '0.802', 'f1': '0.772'}
#
# Episode 4 finished
# {'coverage_prop': '0.845', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.151', 'efficiency': '0.569', 'TP': '2336', 'FP': '808', 'FN': '578', 'precision': '0.743', 'recall': '0.802', 'f1': '0.771'}
#
# Episode 5 finished
# {'coverage_prop': '0.903', 'intensity_prop': '0.588', 'ms1ms2_ratio': '0.336', 'efficiency': '0.500', 'TP': '1585', 'FP': '566', 'FN': '232', 'precision': '0.737', 'recall': '0.872', 'f1': '0.799'}
#
# Episode 6 finished
# {'coverage_prop': '0.821', 'intensity_prop': '0.544', 'ms1ms2_ratio': '0.152', 'efficiency': '0.595', 'TP': '2470', 'FP': '814', 'FN': '717', 'precision': '0.752', 'recall': '0.775', 'f1': '0.763'}
#
# Episode 7 finished
# {'coverage_prop': '0.829', 'intensity_prop': '0.547', 'ms1ms2_ratio': '0.157', 'efficiency': '0.588', 'TP': '2406', 'FP': '814', 'FN': '665', 'precision': '0.747', 'recall': '0.783', 'f1': '0.765'}
#
# Episode 8 finished
# {'coverage_prop': '0.858', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.220', 'efficiency': '0.565', 'TP': '2110', 'FP': '717', 'FN': '468', 'precision': '0.746', 'recall': '0.818', 'f1': '0.781'}
#
# Episode 9 finished
# {'coverage_prop': '0.880', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.273', 'efficiency': '0.491', 'TP': '1703', 'FP': '583', 'FN': '312', 'precision': '0.745', 'recall': '0.845', 'f1': '0.792'}
#
# Episode 10 finished
# {'coverage_prop': '0.912', 'intensity_prop': '0.607', 'ms1ms2_ratio': '0.318', 'efficiency': '0.417', 'TP': '1391', 'FP': '445', 'FN': '177', 'precision': '0.758', 'recall': '0.887', 'f1': '0.817'}
#
# Episode 11 finished
# {'coverage_prop': '0.821', 'intensity_prop': '0.536', 'ms1ms2_ratio': '0.149', 'efficiency': '0.606', 'TP': '2495', 'FP': '868', 'FN': '733', 'precision': '0.742', 'recall': '0.773', 'f1': '0.757'}
#
# Episode 12 finished
# {'coverage_prop': '0.865', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.208', 'efficiency': '0.481', 'TP': '1840', 'FP': '605', 'FN': '381', 'precision': '0.753', 'recall': '0.828', 'f1': '0.789'}
#
# Episode 13 finished
# {'coverage_prop': '0.820', 'intensity_prop': '0.539', 'ms1ms2_ratio': '0.141', 'efficiency': '0.672', 'TP': '2801', 'FP': '971', 'FN': '829', 'precision': '0.743', 'recall': '0.772', 'f1': '0.757'}
#
# Episode 14 finished
# {'coverage_prop': '0.824', 'intensity_prop': '0.547', 'ms1ms2_ratio': '0.148', 'efficiency': '0.599', 'TP': '2513', 'FP': '816', 'FN': '713', 'precision': '0.755', 'recall': '0.779', 'f1': '0.767'}
#
# Episode 15 finished
# {'coverage_prop': '0.818', 'intensity_prop': '0.538', 'ms1ms2_ratio': '0.153', 'efficiency': '0.637', 'TP': '2615', 'FP': '896', 'FN': '781', 'precision': '0.745', 'recall': '0.770', 'f1': '0.757'}
#
# Episode 16 finished
# {'coverage_prop': '0.784', 'intensity_prop': '0.503', 'ms1ms2_ratio': '0.143', 'efficiency': '0.690', 'TP': '2825', 'FP': '1038', 'FN': '1066', 'precision': '0.731', 'recall': '0.726', 'f1': '0.729'}
#
# Episode 17 finished
# {'coverage_prop': '0.841', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.201', 'efficiency': '0.565', 'TP': '2192', 'FP': '710', 'FN': '548', 'precision': '0.755', 'recall': '0.800', 'f1': '0.777'}
#
# Episode 18 finished
# {'coverage_prop': '0.818', 'intensity_prop': '0.534', 'ms1ms2_ratio': '0.140', 'efficiency': '0.616', 'TP': '2579', 'FP': '889', 'FN': '773', 'precision': '0.744', 'recall': '0.769', 'f1': '0.756'}
#
# Episode 19 finished
# {'coverage_prop': '0.797', 'intensity_prop': '0.516', 'ms1ms2_ratio': '0.143', 'efficiency': '0.654', 'TP': '2716', 'FP': '945', 'FN': '930', 'precision': '0.742', 'recall': '0.745', 'f1': '0.743'}
#
# Episode 20 finished
# {'coverage_prop': '0.902', 'intensity_prop': '0.589', 'ms1ms2_ratio': '0.235', 'efficiency': '0.442', 'TP': '1605', 'FP': '559', 'FN': '236', 'precision': '0.742', 'recall': '0.872', 'f1': '0.801'}
#
# Episode 21 finished
# {'coverage_prop': '0.789', 'intensity_prop': '0.509', 'ms1ms2_ratio': '0.138', 'efficiency': '0.668', 'TP': '2759', 'FP': '1008', 'FN': '1010', 'precision': '0.732', 'recall': '0.732', 'f1': '0.732'}
#
# Episode 22 finished
# {'coverage_prop': '0.919', 'intensity_prop': '0.607', 'ms1ms2_ratio': '0.363', 'efficiency': '0.443', 'TP': '1376', 'FP': '474', 'FN': '162', 'precision': '0.744', 'recall': '0.895', 'f1': '0.812'}
#
# Episode 23 finished
# {'coverage_prop': '0.829', 'intensity_prop': '0.546', 'ms1ms2_ratio': '0.144', 'efficiency': '0.608', 'TP': '2553', 'FP': '848', 'FN': '703', 'precision': '0.751', 'recall': '0.784', 'f1': '0.767'}
#
# Episode 24 finished
# {'coverage_prop': '0.881', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.253', 'efficiency': '0.465', 'TP': '1674', 'FP': '547', 'FN': '300', 'precision': '0.754', 'recall': '0.848', 'f1': '0.798'}
#
# Episode 25 finished
# {'coverage_prop': '0.901', 'intensity_prop': '0.589', 'ms1ms2_ratio': '0.288', 'efficiency': '0.466', 'TP': '1577', 'FP': '552', 'FN': '235', 'precision': '0.741', 'recall': '0.870', 'f1': '0.800'}
#
# Episode 26 finished
# {'coverage_prop': '0.788', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.137', 'efficiency': '0.676', 'TP': '2760', 'FP': '1063', 'FN': '1027', 'precision': '0.722', 'recall': '0.729', 'f1': '0.725'}
#
# Episode 27 finished
# {'coverage_prop': '0.813', 'intensity_prop': '0.539', 'ms1ms2_ratio': '0.147', 'efficiency': '0.633', 'TP': '2668', 'FP': '851', 'FN': '807', 'precision': '0.758', 'recall': '0.768', 'f1': '0.763'}
#
# Episode 28 finished
# {'coverage_prop': '0.795', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.145', 'efficiency': '0.591', 'TP': '2475', 'FP': '825', 'FN': '853', 'precision': '0.750', 'recall': '0.744', 'f1': '0.747'}
#
# Episode 29 finished
# {'coverage_prop': '0.863', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.181', 'efficiency': '0.525', 'TP': '2118', 'FP': '660', 'FN': '441', 'precision': '0.762', 'recall': '0.828', 'f1': '0.794'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (15, 15, 2, 0.5, 5)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.936', 'intensity_prop': '0.617', 'ms1ms2_ratio': '0.692', 'efficiency': '0.806', 'TP': '1782', 'FP': '651', 'FN': '166', 'precision': '0.732', 'recall': '0.915', 'f1': '0.814'}
#
# Episode 1 finished
# {'coverage_prop': '0.868', 'intensity_prop': '0.563', 'ms1ms2_ratio': '0.457', 'efficiency': '0.967', 'TP': '2670', 'FP': '966', 'FN': '555', 'precision': '0.734', 'recall': '0.828', 'f1': '0.778'}
#
# Episode 2 finished
# {'coverage_prop': '0.849', 'intensity_prop': '0.555', 'ms1ms2_ratio': '0.361', 'efficiency': '0.991', 'TP': '3074', 'FP': '1070', 'FN': '736', 'precision': '0.742', 'recall': '0.807', 'f1': '0.773'}
#
# Episode 3 finished
# {'coverage_prop': '0.904', 'intensity_prop': '0.595', 'ms1ms2_ratio': '0.526', 'efficiency': '0.888', 'TP': '2321', 'FP': '796', 'FN': '330', 'precision': '0.745', 'recall': '0.876', 'f1': '0.805'}
#
# Episode 4 finished
# {'coverage_prop': '0.898', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.490', 'efficiency': '0.919', 'TP': '2438', 'FP': '904', 'FN': '380', 'precision': '0.730', 'recall': '0.865', 'f1': '0.792'}
#
# Episode 5 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.811', 'efficiency': '0.816', 'TP': '1633', 'FP': '607', 'FN': '143', 'precision': '0.729', 'recall': '0.919', 'f1': '0.813'}
#
# Episode 6 finished
# {'coverage_prop': '0.882', 'intensity_prop': '0.576', 'ms1ms2_ratio': '0.447', 'efficiency': '0.927', 'TP': '2590', 'FP': '937', 'FN': '474', 'precision': '0.734', 'recall': '0.845', 'f1': '0.786'}
#
# Episode 7 finished
# {'coverage_prop': '0.894', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.457', 'efficiency': '0.923', 'TP': '2596', 'FP': '876', 'FN': '413', 'precision': '0.748', 'recall': '0.863', 'f1': '0.801'}
#
# Episode 8 finished
# {'coverage_prop': '0.910', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.582', 'efficiency': '0.901', 'TP': '2213', 'FP': '784', 'FN': '298', 'precision': '0.738', 'recall': '0.881', 'f1': '0.804'}
#
# Episode 9 finished
# {'coverage_prop': '0.926', 'intensity_prop': '0.607', 'ms1ms2_ratio': '0.727', 'efficiency': '0.820', 'TP': '1763', 'FP': '644', 'FN': '191', 'precision': '0.732', 'recall': '0.902', 'f1': '0.809'}
#
# Episode 10 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.957', 'efficiency': '0.775', 'TP': '1343', 'FP': '572', 'FN': '98', 'precision': '0.701', 'recall': '0.932', 'f1': '0.800'}
#
# Episode 11 finished
# {'coverage_prop': '0.880', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.445', 'efficiency': '0.946', 'TP': '2659', 'FP': '945', 'FN': '492', 'precision': '0.738', 'recall': '0.844', 'f1': '0.787'}
#
# Episode 12 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.611', 'ms1ms2_ratio': '0.644', 'efficiency': '0.830', 'TP': '1979', 'FP': '635', 'FN': '212', 'precision': '0.757', 'recall': '0.903', 'f1': '0.824'}
#
# Episode 13 finished
# {'coverage_prop': '0.873', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.391', 'efficiency': '0.994', 'TP': '3011', 'FP': '1004', 'FN': '586', 'precision': '0.750', 'recall': '0.837', 'f1': '0.791'}
#
# Episode 14 finished
# {'coverage_prop': '0.888', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.449', 'efficiency': '0.946', 'TP': '2683', 'FP': '907', 'FN': '452', 'precision': '0.747', 'recall': '0.856', 'f1': '0.798'}
#
# Episode 15 finished
# {'coverage_prop': '0.875', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.435', 'efficiency': '0.975', 'TP': '2756', 'FP': '1001', 'FN': '535', 'precision': '0.734', 'recall': '0.837', 'f1': '0.782'}
#
# Episode 16 finished
# {'coverage_prop': '0.850', 'intensity_prop': '0.549', 'ms1ms2_ratio': '0.390', 'efficiency': '1.036', 'TP': '3068', 'FP': '1122', 'FN': '739', 'precision': '0.732', 'recall': '0.806', 'f1': '0.767'}
#
# Episode 17 finished
# {'coverage_prop': '0.896', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.548', 'efficiency': '0.900', 'TP': '2292', 'FP': '798', 'FN': '360', 'precision': '0.742', 'recall': '0.864', 'f1': '0.798'}
#
# Episode 18 finished
# {'coverage_prop': '0.874', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.442', 'efficiency': '0.970', 'TP': '2723', 'FP': '983', 'FN': '535', 'precision': '0.735', 'recall': '0.836', 'f1': '0.782'}
#
# Episode 19 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.397', 'efficiency': '0.991', 'TP': '2899', 'FP': '1075', 'FN': '617', 'precision': '0.729', 'recall': '0.825', 'f1': '0.774'}
#
# Episode 20 finished
# {'coverage_prop': '0.945', 'intensity_prop': '0.614', 'ms1ms2_ratio': '0.769', 'efficiency': '0.799', 'TP': '1660', 'FP': '607', 'FN': '133', 'precision': '0.732', 'recall': '0.926', 'f1': '0.818'}
#
# Episode 21 finished
# {'coverage_prop': '0.858', 'intensity_prop': '0.554', 'ms1ms2_ratio': '0.388', 'efficiency': '1.011', 'TP': '3007', 'FP': '1092', 'FN': '678', 'precision': '0.734', 'recall': '0.816', 'f1': '0.773'}
#
# Episode 22 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.940', 'efficiency': '0.765', 'TP': '1352', 'FP': '560', 'FN': '100', 'precision': '0.707', 'recall': '0.931', 'f1': '0.804'}
#
# Episode 23 finished
# {'coverage_prop': '0.884', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.442', 'efficiency': '0.950', 'TP': '2716', 'FP': '912', 'FN': '476', 'precision': '0.749', 'recall': '0.851', 'f1': '0.796'}
#
# Episode 24 finished
# {'coverage_prop': '0.936', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.741', 'efficiency': '0.813', 'TP': '1780', 'FP': '579', 'FN': '162', 'precision': '0.755', 'recall': '0.917', 'f1': '0.828'}
#
# Episode 25 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.781', 'efficiency': '0.796', 'TP': '1693', 'FP': '544', 'FN': '127', 'precision': '0.757', 'recall': '0.930', 'f1': '0.835'}
#
# Episode 26 finished
# {'coverage_prop': '0.863', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.367', 'efficiency': '1.008', 'TP': '3050', 'FP': '1137', 'FN': '663', 'precision': '0.728', 'recall': '0.821', 'f1': '0.772'}
#
# Episode 27 finished
# {'coverage_prop': '0.876', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.416', 'efficiency': '0.964', 'TP': '2852', 'FP': '936', 'FN': '538', 'precision': '0.753', 'recall': '0.841', 'f1': '0.795'}
#
# Episode 28 finished
# {'coverage_prop': '0.873', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.439', 'efficiency': '0.945', 'TP': '2661', 'FP': '963', 'FN': '529', 'precision': '0.734', 'recall': '0.834', 'f1': '0.781'}
#
# Episode 29 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.567', 'efficiency': '0.874', 'TP': '2190', 'FP': '758', 'FN': '271', 'precision': '0.743', 'recall': '0.890', 'f1': '0.810'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.122', 'efficiency': '0.425', 'TP': '2027', 'FP': '435', 'FN': '137', 'precision': '0.823', 'recall': '0.937', 'f1': '0.876'}
#
# Episode 1 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.110', 'efficiency': '0.615', 'TP': '2788', 'FP': '841', 'FN': '562', 'precision': '0.768', 'recall': '0.832', 'f1': '0.799'}
#
# Episode 2 finished
# {'coverage_prop': '0.851', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.094', 'efficiency': '0.685', 'TP': '3101', 'FP': '1050', 'FN': '729', 'precision': '0.747', 'recall': '0.810', 'f1': '0.777'}
#
# Episode 3 finished
# {'coverage_prop': '0.903', 'intensity_prop': '0.609', 'ms1ms2_ratio': '0.098', 'efficiency': '0.517', 'TP': '2403', 'FP': '710', 'FN': '334', 'precision': '0.772', 'recall': '0.878', 'f1': '0.822'}
#
# Episode 4 finished
# {'coverage_prop': '0.898', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.096', 'efficiency': '0.554', 'TP': '2549', 'FP': '795', 'FN': '378', 'precision': '0.762', 'recall': '0.871', 'f1': '0.813'}
#
# Episode 5 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.671', 'ms1ms2_ratio': '0.115', 'efficiency': '0.383', 'TP': '1871', 'FP': '374', 'FN': '138', 'precision': '0.833', 'recall': '0.931', 'f1': '0.880'}
#
# Episode 6 finished
# {'coverage_prop': '0.889', 'intensity_prop': '0.595', 'ms1ms2_ratio': '0.108', 'efficiency': '0.600', 'TP': '2723', 'FP': '833', 'FN': '445', 'precision': '0.766', 'recall': '0.860', 'f1': '0.810'}
#
# Episode 7 finished
# {'coverage_prop': '0.893', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.108', 'efficiency': '0.586', 'TP': '2660', 'FP': '809', 'FN': '416', 'precision': '0.767', 'recall': '0.865', 'f1': '0.813'}
#
# Episode 8 finished
# {'coverage_prop': '0.912', 'intensity_prop': '0.627', 'ms1ms2_ratio': '0.112', 'efficiency': '0.511', 'TP': '2390', 'FP': '616', 'FN': '289', 'precision': '0.795', 'recall': '0.892', 'f1': '0.841'}
#
# Episode 9 finished
# {'coverage_prop': '0.938', 'intensity_prop': '0.654', 'ms1ms2_ratio': '0.118', 'efficiency': '0.418', 'TP': '1980', 'FP': '456', 'FN': '162', 'precision': '0.813', 'recall': '0.924', 'f1': '0.865'}
#
# Episode 10 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.130', 'efficiency': '0.334', 'TP': '1614', 'FP': '295', 'FN': '104', 'precision': '0.845', 'recall': '0.939', 'f1': '0.890'}
#
# Episode 11 finished
# {'coverage_prop': '0.879', 'intensity_prop': '0.585', 'ms1ms2_ratio': '0.110', 'efficiency': '0.610', 'TP': '2753', 'FP': '848', 'FN': '495', 'precision': '0.765', 'recall': '0.848', 'f1': '0.804'}
#
# Episode 12 finished
# {'coverage_prop': '0.924', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.119', 'efficiency': '0.449', 'TP': '2108', 'FP': '504', 'FN': '214', 'precision': '0.807', 'recall': '0.908', 'f1': '0.854'}
#
# Episode 13 finished
# {'coverage_prop': '0.878', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.095', 'efficiency': '0.667', 'TP': '3092', 'FP': '947', 'FN': '562', 'precision': '0.766', 'recall': '0.846', 'f1': '0.804'}
#
# Episode 14 finished
# {'coverage_prop': '0.890', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.100', 'efficiency': '0.599', 'TP': '2750', 'FP': '847', 'FN': '445', 'precision': '0.765', 'recall': '0.861', 'f1': '0.810'}
#
# Episode 15 finished
# {'coverage_prop': '0.877', 'intensity_prop': '0.584', 'ms1ms2_ratio': '0.107', 'efficiency': '0.635', 'TP': '2861', 'FP': '904', 'FN': '527', 'precision': '0.760', 'recall': '0.844', 'f1': '0.800'}
#
# Episode 16 finished
# {'coverage_prop': '0.850', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.096', 'efficiency': '0.694', 'TP': '3090', 'FP': '1101', 'FN': '738', 'precision': '0.737', 'recall': '0.807', 'f1': '0.771'}
#
# Episode 17 finished
# {'coverage_prop': '0.904', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.112', 'efficiency': '0.530', 'TP': '2431', 'FP': '687', 'FN': '332', 'precision': '0.780', 'recall': '0.880', 'f1': '0.827'}
#
# Episode 18 finished
# {'coverage_prop': '0.881', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.093', 'efficiency': '0.615', 'TP': '2827', 'FP': '910', 'FN': '504', 'precision': '0.756', 'recall': '0.849', 'f1': '0.800'}
#
# Episode 19 finished
# {'coverage_prop': '0.870', 'intensity_prop': '0.570', 'ms1ms2_ratio': '0.103', 'efficiency': '0.669', 'TP': '2989', 'FP': '1005', 'FN': '597', 'precision': '0.748', 'recall': '0.834', 'f1': '0.789'}
#
# Episode 20 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.660', 'ms1ms2_ratio': '0.121', 'efficiency': '0.392', 'TP': '1861', 'FP': '409', 'FN': '130', 'precision': '0.820', 'recall': '0.935', 'f1': '0.874'}
#
# Episode 21 finished
# {'coverage_prop': '0.852', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.091', 'efficiency': '0.668', 'TP': '3052', 'FP': '1017', 'FN': '708', 'precision': '0.750', 'recall': '0.812', 'f1': '0.780'}
#
# Episode 22 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.680', 'ms1ms2_ratio': '0.105', 'efficiency': '0.325', 'TP': '1589', 'FP': '341', 'FN': '82', 'precision': '0.823', 'recall': '0.951', 'f1': '0.883'}
#
# Episode 23 finished
# {'coverage_prop': '0.879', 'intensity_prop': '0.589', 'ms1ms2_ratio': '0.093', 'efficiency': '0.594', 'TP': '2740', 'FP': '867', 'FN': '497', 'precision': '0.760', 'recall': '0.846', 'f1': '0.801'}
#
# Episode 24 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.647', 'ms1ms2_ratio': '0.125', 'efficiency': '0.408', 'TP': '1887', 'FP': '465', 'FN': '169', 'precision': '0.802', 'recall': '0.918', 'f1': '0.856'}
#
# Episode 25 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.672', 'ms1ms2_ratio': '0.131', 'efficiency': '0.393', 'TP': '1863', 'FP': '383', 'FN': '118', 'precision': '0.829', 'recall': '0.940', 'f1': '0.881'}
#
# Episode 26 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.562', 'ms1ms2_ratio': '0.094', 'efficiency': '0.693', 'TP': '3094', 'FP': '1104', 'FN': '652', 'precision': '0.737', 'recall': '0.826', 'f1': '0.779'}
#
# Episode 27 finished
# {'coverage_prop': '0.875', 'intensity_prop': '0.583', 'ms1ms2_ratio': '0.101', 'efficiency': '0.631', 'TP': '2870', 'FP': '914', 'FN': '542', 'precision': '0.758', 'recall': '0.841', 'f1': '0.798'}
#
# Episode 28 finished
# {'coverage_prop': '0.865', 'intensity_prop': '0.570', 'ms1ms2_ratio': '0.106', 'efficiency': '0.605', 'TP': '2670', 'FP': '922', 'FN': '561', 'precision': '0.743', 'recall': '0.826', 'f1': '0.783'}
#
# Episode 29 finished
# {'coverage_prop': '0.912', 'intensity_prop': '0.628', 'ms1ms2_ratio': '0.108', 'efficiency': '0.496', 'TP': '2340', 'FP': '596', 'FN': '283', 'precision': '0.797', 'recall': '0.892', 'f1': '0.842'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -5930.176919                6181.0          0.441           0.165
# 1  random   -5339.250396                5735.0          0.500           0.201
# 2  random   -4650.937183                5197.0          0.564           0.230
# 3  random   -5695.025849                6015.0          0.455           0.179
# 4  random   -5027.705411                5479.0          0.548           0.224
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.161      0.349   0.216  0.267
# 1          0.004       0.293      0.379   0.274  0.318
# 2          0.005       0.386      0.395   0.338  0.364
# 3          0.004       0.220      0.369   0.236  0.288
# 4          0.006       0.287      0.404   0.329  0.363

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN    1050.231806                  45.0          0.812           0.533
# 31    DQN    1100.093929                  98.0          0.726           0.449
# 32    DQN    1201.975955                  57.0          0.719           0.446
# 33    DQN    1132.103275                  30.0          0.768           0.498
# 34    DQN    1155.264613                  38.0          0.764           0.481
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.136       0.373      0.743   0.762  0.752
# 31          0.119       0.523      0.690   0.646  0.667
# 32          0.107       0.592      0.686   0.637  0.661
# 33          0.122       0.457      0.721   0.705  0.713
# 34          0.113       0.485      0.691   0.691  0.691

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
