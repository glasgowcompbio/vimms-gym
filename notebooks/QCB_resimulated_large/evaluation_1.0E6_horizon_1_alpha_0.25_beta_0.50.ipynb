# %% [markdown]
# # Evaluation using QCB chemicals (large)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_large

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_large(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-04-04 16:31:57.319 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_large_extracted.p
# ({'chemical_creator': {'mz_range': (70, 1000),
#    'rt_range': (0, 1440),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (2000, 5000),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f99e2073550>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9a01999c30>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9a019f3190>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (70, 1000)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (0, 1440),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  100)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_1.0E6'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 15
topN_rt_tol = 15
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 240
weighteddew_N = 15

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_large.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 2151
# 4096
# 3307
# 3000
# 4490
# 2477
# 3302
# 2370
# 3021
# 3051
# 4873
# 3756
# 4904
# 3460
# 2023
# 4151
# 4326
# 4131
# 4881
# 3491
# 3674
# 4196
# 2541
# 3254
# 4358
# 3301
# 4916
# 2655
# 4538
# 3171

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (70, 1000),
#  'rt_range': (0, 1440),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (2000, 5000),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f99e2073550>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9a01999c30>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9a019f3190>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (70, 1000),
#   'rt_range': (0, 1440),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (2000, 5000),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f99e2073550>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9a01999c30>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9a019f3190>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (70, 1000)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (0, 1440),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 1
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E5_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 100 N = 0 rt_tol = 5
#
#
# Episode 0 (2151 chemicals)
# steps	 500 	total rewards	 42.2876080116953
# steps	 1000 	total rewards	 109.85814241740667
# steps	 1500 	total rewards	 180.91864670846104
# steps	 2000 	total rewards	 255.60456715589112
# steps	 2500 	total rewards	 344.0190415281822
# steps	 3000 	total rewards	 434.8740616566863
# steps	 3500 	total rewards	 508.140673062296
# steps	 4000 	total rewards	 567.7779261739036
# steps	 4500 	total rewards	 622.3278764837153
# steps	 5000 	total rewards	 681.1176759581508
# steps	 5500 	total rewards	 743.6792531664016
# steps	 6000 	total rewards	 801.3565457354911
# steps	 6500 	total rewards	 853.6988086424956
# Finished after 6605 timesteps (15.397120952606201 seconds) with total reward 864.0881813558653
# {'coverage_prop': '0.751', 'intensity_prop': '0.491', 'ms1ms2_ratio': '0.099', 'efficiency': '0.269', 'TP': '1189', 'FP': '427', 'FN': '535', 'precision': '0.736', 'recall': '0.690', 'f1': '0.712', 'total_rewards': 864.0881813558656, 'invalid_action_count': 0, 'num_ms1_scans': 595, 'num_ms2_scans': 6010}
#
# Episode 1 (4096 chemicals)
# steps	 500 	total rewards	 48.51045683176973
# steps	 1000 	total rewards	 118.5368546829796
# steps	 1500 	total rewards	 200.58819842682948
# steps	 2000 	total rewards	 285.4002799729151
# steps	 2500 	total rewards	 376.7195719374304
# steps	 3000 	total rewards	 468.50652960344496
# steps	 3500 	total rewards	 544.0641900259697
# steps	 4000 	total rewards	 615.8387697686469
# steps	 4500 	total rewards	 681.8090447867789
# steps	 5000 	total rewards	 742.6626156942032
# steps	 5500 	total rewards	 809.7318580708705
# steps	 6000 	total rewards	 867.394916107766
# steps	 6500 	total rewards	 930.8519464885707
# Finished after 6799 timesteps (21.317633628845215 seconds) with total reward 964.4531084719222
# {'coverage_prop': '0.678', 'intensity_prop': '0.386', 'ms1ms2_ratio': '0.063', 'efficiency': '0.434', 'TP': '1692', 'FP': '1085', 'FN': '1319', 'precision': '0.609', 'recall': '0.562', 'f1': '0.585', 'total_rewards': 964.4531084719229, 'invalid_action_count': 0, 'num_ms1_scans': 401, 'num_ms2_scans': 6398}
#
# Episode 2 (3307 chemicals)
# steps	 500 	total rewards	 49.91678576493965
# steps	 1000 	total rewards	 127.54859923707302
# steps	 1500 	total rewards	 212.75013234347003
# steps	 2000 	total rewards	 292.03408170245956
# steps	 2500 	total rewards	 374.01046354628187
# steps	 3000 	total rewards	 468.63876762376435
# steps	 3500 	total rewards	 546.141559264655
# steps	 4000 	total rewards	 617.392413445428
# steps	 4500 	total rewards	 684.3290143909524
# steps	 5000 	total rewards	 748.5099641658575
# steps	 5500 	total rewards	 812.1097372146239
# steps	 6000 	total rewards	 874.7441085874829
# steps	 6500 	total rewards	 939.2158338805887
# Finished after 6782 timesteps (11.936466932296753 seconds) with total reward 971.228675857587
# {'coverage_prop': '0.703', 'intensity_prop': '0.414', 'ms1ms2_ratio': '0.066', 'efficiency': '0.365', 'TP': '1475', 'FP': '851', 'FN': '981', 'precision': '0.634', 'recall': '0.601', 'f1': '0.617', 'total_rewards': 971.2286758575857, 'invalid_action_count': 0, 'num_ms1_scans': 418, 'num_ms2_scans': 6364}
#
# Episode 3 (3000 chemicals)
# steps	 500 	total rewards	 48.89440486080847
# steps	 1000 	total rewards	 122.84918935118381
# steps	 1500 	total rewards	 207.95569968377058
# steps	 2000 	total rewards	 287.96323517609915
# steps	 2500 	total rewards	 373.9048741273687
# steps	 3000 	total rewards	 467.6648006806244
# steps	 3500 	total rewards	 546.4671530485797
# steps	 4000 	total rewards	 608.813584333165
# steps	 4500 	total rewards	 669.1122678009732
# steps	 5000 	total rewards	 733.2655938405953
# steps	 5500 	total rewards	 800.0376855013033
# steps	 6000 	total rewards	 856.4099174293508
# steps	 6500 	total rewards	 912.8448645541838
# Finished after 6782 timesteps (19.15485429763794 seconds) with total reward 943.5571210129468
# {'coverage_prop': '0.734', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.066', 'efficiency': '0.346', 'TP': '1441', 'FP': '762', 'FN': '797', 'precision': '0.654', 'recall': '0.644', 'f1': '0.649', 'total_rewards': 943.5571210129484, 'invalid_action_count': 0, 'num_ms1_scans': 418, 'num_ms2_scans': 6364}
#
# Episode 4 (4490 chemicals)
# steps	 500 	total rewards	 56.031177978720926
# steps	 1000 	total rewards	 126.07945307424069
# steps	 1500 	total rewards	 211.660159641037
# steps	 2000 	total rewards	 294.64445408525916
# steps	 2500 	total rewards	 388.8658895587416
# steps	 3000 	total rewards	 477.1914747627899
# steps	 3500 	total rewards	 565.4412320835697
# steps	 4000 	total rewards	 641.8625723109051
# steps	 4500 	total rewards	 711.330522898106
# steps	 5000 	total rewards	 777.6225692066449
# steps	 5500 	total rewards	 843.8785759140846
# steps	 6000 	total rewards	 902.0396044440926
# steps	 6500 	total rewards	 963.9201776444153
# Finished after 6846 timesteps (16.60290503501892 seconds) with total reward 1007.6322830676821
# {'coverage_prop': '0.673', 'intensity_prop': '0.381', 'ms1ms2_ratio': '0.055', 'efficiency': '0.466', 'TP': '1872', 'FP': '1152', 'FN': '1466', 'precision': '0.619', 'recall': '0.561', 'f1': '0.588', 'total_rewards': 1007.6322830676783, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 6491}
#
# Episode 5 (2477 chemicals)
# steps	 500 	total rewards	 44.13380052801902
# steps	 1000 	total rewards	 109.10076691818587
# steps	 1500 	total rewards	 187.8990741679881
# steps	 2000 	total rewards	 264.52930947433333
# steps	 2500 	total rewards	 349.55699918276883
# steps	 3000 	total rewards	 441.9751331393844
# steps	 3500 	total rewards	 519.9115884382695
# steps	 4000 	total rewards	 579.3465132578887
# steps	 4500 	total rewards	 630.998079201249
# steps	 5000 	total rewards	 682.4312472805659
# steps	 5500 	total rewards	 745.5508618943486
# steps	 6000 	total rewards	 799.4221066533419
# steps	 6500 	total rewards	 853.9666394687584
# Finished after 6730 timesteps (18.39147400856018 seconds) with total reward 878.608581337164
# {'coverage_prop': '0.740', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.075', 'efficiency': '0.293', 'TP': '1186', 'FP': '646', 'FN': '645', 'precision': '0.647', 'recall': '0.648', 'f1': '0.648', 'total_rewards': 878.608581337164, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 6260}
#
# Episode 6 (3302 chemicals)
# steps	 500 	total rewards	 40.51253191870424
# steps	 1000 	total rewards	 102.86771415357148
# steps	 1500 	total rewards	 186.6833770594021
# steps	 2000 	total rewards	 261.4416887623785
# steps	 2500 	total rewards	 346.9850116865685
# steps	 3000 	total rewards	 436.73658368109477
# steps	 3500 	total rewards	 512.7662028506065
# steps	 4000 	total rewards	 583.7947224156176
# steps	 4500 	total rewards	 648.4881282263113
# steps	 5000 	total rewards	 706.7797661179238
# steps	 5500 	total rewards	 771.8950350795644
# steps	 6000 	total rewards	 823.1390544100241
# steps	 6500 	total rewards	 883.0104041557929
# Finished after 6789 timesteps (13.795175313949585 seconds) with total reward 917.8708357057396
# {'coverage_prop': '0.684', 'intensity_prop': '0.399', 'ms1ms2_ratio': '0.064', 'efficiency': '0.354', 'TP': '1406', 'FP': '852', 'FN': '1044', 'precision': '0.623', 'recall': '0.574', 'f1': '0.597', 'total_rewards': 917.870835705739, 'invalid_action_count': 0, 'num_ms1_scans': 411, 'num_ms2_scans': 6378}
#
# Episode 7 (2370 chemicals)
# steps	 500 	total rewards	 37.428922532999614
# steps	 1000 	total rewards	 92.64980807317485
# steps	 1500 	total rewards	 168.9918813368728
# steps	 2000 	total rewards	 245.33632516012878
# steps	 2500 	total rewards	 328.7479536846423
# steps	 3000 	total rewards	 418.15117980585916
# steps	 3500 	total rewards	 496.4238865295941
# steps	 4000 	total rewards	 562.4728318990279
# steps	 4500 	total rewards	 623.6417702046015
# steps	 5000 	total rewards	 684.2100915757819
# steps	 5500 	total rewards	 753.6025155832181
# steps	 6000 	total rewards	 813.3583413889355
# steps	 6500 	total rewards	 872.2965590733379
# Finished after 6724 timesteps (24.986418962478638 seconds) with total reward 898.7767215316835
# {'coverage_prop': '0.745', 'intensity_prop': '0.456', 'ms1ms2_ratio': '0.076', 'efficiency': '0.283', 'TP': '1213', 'FP': '553', 'FN': '604', 'precision': '0.687', 'recall': '0.668', 'f1': '0.677', 'total_rewards': 898.7767215316821, 'invalid_action_count': 0, 'num_ms1_scans': 476, 'num_ms2_scans': 6248}
#
# Episode 8 (3021 chemicals)
# steps	 500 	total rewards	 47.85480867372573
# steps	 1000 	total rewards	 111.92269471587822
# steps	 1500 	total rewards	 191.37104689187277
# steps	 2000 	total rewards	 267.7427201499184
# steps	 2500 	total rewards	 359.4044053837395
# steps	 3000 	total rewards	 453.62852845405484
# steps	 3500 	total rewards	 532.0546143279548
# steps	 4000 	total rewards	 604.3147331122768
# steps	 4500 	total rewards	 664.657393414393
# steps	 5000 	total rewards	 726.7386791475061
# steps	 5500 	total rewards	 797.6618561010899
# steps	 6000 	total rewards	 856.0927401699533
# steps	 6500 	total rewards	 916.1246855418356
# Finished after 6766 timesteps (13.281817197799683 seconds) with total reward 947.2095152004616
# {'coverage_prop': '0.720', 'intensity_prop': '0.432', 'ms1ms2_ratio': '0.069', 'efficiency': '0.343', 'TP': '1425', 'FP': '750', 'FN': '846', 'precision': '0.655', 'recall': '0.627', 'f1': '0.641', 'total_rewards': 947.2095152004616, 'invalid_action_count': 0, 'num_ms1_scans': 434, 'num_ms2_scans': 6332}
#
# Episode 9 (3051 chemicals)
# steps	 500 	total rewards	 53.49312006482698
# steps	 1000 	total rewards	 126.52935687596558
# steps	 1500 	total rewards	 210.22577593901326
# steps	 2000 	total rewards	 285.2088501986983
# steps	 2500 	total rewards	 375.0712953140812
# steps	 3000 	total rewards	 458.342246414551
# steps	 3500 	total rewards	 546.4682367535502
# steps	 4000 	total rewards	 617.9739433823027
# steps	 4500 	total rewards	 680.3950659119369
# steps	 5000 	total rewards	 744.4752269480107
# steps	 5500 	total rewards	 809.162030705704
# steps	 6000 	total rewards	 868.8469298273915
# steps	 6500 	total rewards	 929.7022465028381
# Finished after 6773 timesteps (26.683773279190063 seconds) with total reward 953.9155019620626
# {'coverage_prop': '0.726', 'intensity_prop': '0.433', 'ms1ms2_ratio': '0.067', 'efficiency': '0.349', 'TP': '1455', 'FP': '759', 'FN': '837', 'precision': '0.657', 'recall': '0.635', 'f1': '0.646', 'total_rewards': 953.9155019620639, 'invalid_action_count': 0, 'num_ms1_scans': 427, 'num_ms2_scans': 6346}
#
# Episode 10 (4873 chemicals)
# steps	 500 	total rewards	 51.885783561956345
# steps	 1000 	total rewards	 129.87904721416413
# steps	 1500 	total rewards	 214.40922226905093
# steps	 2000 	total rewards	 290.90916714680304
# steps	 2500 	total rewards	 377.40400227352524
# steps	 3000 	total rewards	 476.67948244722226
# steps	 3500 	total rewards	 565.1785443707931
# steps	 4000 	total rewards	 645.1521625600733
# steps	 4500 	total rewards	 715.2234672713134
# steps	 5000 	total rewards	 775.8684027639606
# steps	 5500 	total rewards	 846.3642454763982
# steps	 6000 	total rewards	 913.376814319385
# steps	 6500 	total rewards	 973.3633443478373
# Finished after 6861 timesteps (18.682018995285034 seconds) with total reward 1014.4764093875209
# {'coverage_prop': '0.658', 'intensity_prop': '0.364', 'ms1ms2_ratio': '0.052', 'efficiency': '0.492', 'TP': '1902', 'FP': '1306', 'FN': '1665', 'precision': '0.593', 'recall': '0.533', 'f1': '0.561', 'total_rewards': 1014.4764093875168, 'invalid_action_count': 0, 'num_ms1_scans': 339, 'num_ms2_scans': 6522}
#
# Episode 11 (3756 chemicals)
# steps	 500 	total rewards	 52.31223887465568
# steps	 1000 	total rewards	 115.36938179002271
# steps	 1500 	total rewards	 195.57728279093152
# steps	 2000 	total rewards	 270.3838635168318
# steps	 2500 	total rewards	 355.8452063173394
# steps	 3000 	total rewards	 450.6237015285393
# steps	 3500 	total rewards	 530.3393261429775
# steps	 4000 	total rewards	 609.9944622958117
# steps	 4500 	total rewards	 676.4334635247765
# steps	 5000 	total rewards	 744.3121401234758
# steps	 5500 	total rewards	 812.2538719320515
# steps	 6000 	total rewards	 872.624891372657
# steps	 6500 	total rewards	 938.0729053237178
# Finished after 6835 timesteps (31.7553870677948 seconds) with total reward 976.8500409193689
# {'coverage_prop': '0.689', 'intensity_prop': '0.402', 'ms1ms2_ratio': '0.057', 'efficiency': '0.400', 'TP': '1642', 'FP': '947', 'FN': '1167', 'precision': '0.634', 'recall': '0.585', 'f1': '0.608', 'total_rewards': 976.8500409193709, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 6469}
#
# Episode 12 (4904 chemicals)
# steps	 500 	total rewards	 59.619861538945834
# steps	 1000 	total rewards	 136.06254174844688
# steps	 1500 	total rewards	 219.43839319221448
# steps	 2000 	total rewards	 305.24827585769515
# steps	 2500 	total rewards	 398.01692017353855
# steps	 3000 	total rewards	 493.1969058517652
# steps	 3500 	total rewards	 585.9476272859844
# steps	 4000 	total rewards	 666.1788631610596
# steps	 4500 	total rewards	 735.5531180731009
# steps	 5000 	total rewards	 798.2486223435078
# steps	 5500 	total rewards	 874.1628258793378
# steps	 6000 	total rewards	 936.1164421680951
# steps	 6500 	total rewards	 1004.0183271485278
# Finished after 6869 timesteps (19.196173906326294 seconds) with total reward 1048.9588480055506
# {'coverage_prop': '0.665', 'intensity_prop': '0.384', 'ms1ms2_ratio': '0.051', 'efficiency': '0.499', 'TP': '2044', 'FP': '1216', 'FN': '1644', 'precision': '0.627', 'recall': '0.554', 'f1': '0.588', 'total_rewards': 1048.9588480055515, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 6538}
#
# Episode 13 (3460 chemicals)
# steps	 500 	total rewards	 50.832994297092895
# steps	 1000 	total rewards	 121.01307805402175
# steps	 1500 	total rewards	 203.6065022367529
# steps	 2000 	total rewards	 276.56563349105136
# steps	 2500 	total rewards	 368.6384074299457
# steps	 3000 	total rewards	 467.2545083708238
# steps	 3500 	total rewards	 556.2071870430111
# steps	 4000 	total rewards	 631.5682221296505
# steps	 4500 	total rewards	 695.2356586160153
# steps	 5000 	total rewards	 759.325971163444
# steps	 5500 	total rewards	 827.9075330025356
# steps	 6000 	total rewards	 891.2301010015065
# steps	 6500 	total rewards	 953.9692863465668
# Finished after 6794 timesteps (14.354597806930542 seconds) with total reward 989.8435909866116
# {'coverage_prop': '0.700', 'intensity_prop': '0.411', 'ms1ms2_ratio': '0.064', 'efficiency': '0.379', 'TP': '1552', 'FP': '871', 'FN': '1037', 'precision': '0.641', 'recall': '0.599', 'f1': '0.619', 'total_rewards': 989.8435909866113, 'invalid_action_count': 0, 'num_ms1_scans': 406, 'num_ms2_scans': 6388}
#
# Episode 14 (2023 chemicals)
# steps	 500 	total rewards	 36.89291341624921
# steps	 1000 	total rewards	 102.91027658471566
# steps	 1500 	total rewards	 176.13196200735155
# steps	 2000 	total rewards	 252.1878214932204
# steps	 2500 	total rewards	 338.79730046148245
# steps	 3000 	total rewards	 427.21070181141476
# steps	 3500 	total rewards	 503.7529897632743
# steps	 4000 	total rewards	 573.8085426179879
# steps	 4500 	total rewards	 634.7600238645257
# steps	 5000 	total rewards	 700.4327860803265
# steps	 5500 	total rewards	 763.3489777516887
# steps	 6000 	total rewards	 818.8523877848061
# steps	 6500 	total rewards	 872.1023746502748
# Finished after 6613 timesteps (12.409936904907227 seconds) with total reward 885.0160687564928
# {'coverage_prop': '0.761', 'intensity_prop': '0.484', 'ms1ms2_ratio': '0.097', 'efficiency': '0.256', 'TP': '1090', 'FP': '450', 'FN': '483', 'precision': '0.708', 'recall': '0.693', 'f1': '0.700', 'total_rewards': 885.0160687564918, 'invalid_action_count': 0, 'num_ms1_scans': 587, 'num_ms2_scans': 6026}
#
# Episode 15 (4151 chemicals)
# steps	 500 	total rewards	 52.45093269776886
# steps	 1000 	total rewards	 121.05346068570113
# steps	 1500 	total rewards	 206.69373166120008
# steps	 2000 	total rewards	 288.14285260663456
# steps	 2500 	total rewards	 385.2824526216822
# steps	 3000 	total rewards	 480.4508308123919
# steps	 3500 	total rewards	 569.4069213643133
# steps	 4000 	total rewards	 648.9441646860498
# steps	 4500 	total rewards	 707.4044255319266
# steps	 5000 	total rewards	 770.2485509600207
# steps	 5500 	total rewards	 844.1406043262265
# steps	 6000 	total rewards	 907.0970949354692
# steps	 6500 	total rewards	 970.098137256065
# Finished after 6840 timesteps (16.07172703742981 seconds) with total reward 1010.7902433078807
# {'coverage_prop': '0.685', 'intensity_prop': '0.389', 'ms1ms2_ratio': '0.056', 'efficiency': '0.439', 'TP': '1742', 'FP': '1103', 'FN': '1306', 'precision': '0.612', 'recall': '0.572', 'f1': '0.591', 'total_rewards': 1010.7902433078831, 'invalid_action_count': 0, 'num_ms1_scans': 360, 'num_ms2_scans': 6480}
#
# Episode 16 (4326 chemicals)
# steps	 500 	total rewards	 45.70207704293093
# steps	 1000 	total rewards	 108.99524880840289
# steps	 1500 	total rewards	 199.8629999555248
# steps	 2000 	total rewards	 278.28064374567606
# steps	 2500 	total rewards	 369.7845982206815
# steps	 3000 	total rewards	 467.73530075972633
# steps	 3500 	total rewards	 551.3904210609527
# steps	 4000 	total rewards	 627.1679915909644
# steps	 4500 	total rewards	 691.9879413007898
# steps	 5000 	total rewards	 761.5557241983821
# steps	 5500 	total rewards	 836.706628485561
# steps	 6000 	total rewards	 899.802755474376
# steps	 6500 	total rewards	 960.5639157456926
# Finished after 6844 timesteps (41.06010317802429 seconds) with total reward 1000.7780967159257
# {'coverage_prop': '0.666', 'intensity_prop': '0.381', 'ms1ms2_ratio': '0.055', 'efficiency': '0.444', 'TP': '1776', 'FP': '1104', 'FN': '1446', 'precision': '0.617', 'recall': '0.551', 'f1': '0.582', 'total_rewards': 1000.7780967159258, 'invalid_action_count': 0, 'num_ms1_scans': 356, 'num_ms2_scans': 6488}
#
# Episode 17 (4131 chemicals)
# steps	 500 	total rewards	 42.939464554415245
# steps	 1000 	total rewards	 109.49261927334987
# steps	 1500 	total rewards	 195.1777349205871
# steps	 2000 	total rewards	 272.19666374236914
# steps	 2500 	total rewards	 373.31559199030653
# steps	 3000 	total rewards	 468.14337072302965
# steps	 3500 	total rewards	 548.4359735706151
# steps	 4000 	total rewards	 619.7367144783564
# steps	 4500 	total rewards	 685.858217091535
# steps	 5000 	total rewards	 752.1569509551606
# steps	 5500 	total rewards	 826.2891841754109
# steps	 6000 	total rewards	 891.395499067109
# steps	 6500 	total rewards	 961.8553653568744
# Finished after 6794 timesteps (18.09711503982544 seconds) with total reward 998.5206511851536
# {'coverage_prop': '0.691', 'intensity_prop': '0.396', 'ms1ms2_ratio': '0.064', 'efficiency': '0.447', 'TP': '1759', 'FP': '1097', 'FN': '1275', 'precision': '0.616', 'recall': '0.580', 'f1': '0.597', 'total_rewards': 998.5206511851536, 'invalid_action_count': 0, 'num_ms1_scans': 406, 'num_ms2_scans': 6388}
#
# Episode 18 (4881 chemicals)
# steps	 500 	total rewards	 56.49312463272035
# steps	 1000 	total rewards	 130.28296145177526
# steps	 1500 	total rewards	 221.46122656211472
# steps	 2000 	total rewards	 300.5975256616257
# steps	 2500 	total rewards	 392.1369585609417
# steps	 3000 	total rewards	 485.82039231376854
# steps	 3500 	total rewards	 568.9813607067329
# steps	 4000 	total rewards	 644.9070963082827
# steps	 4500 	total rewards	 715.6325745475871
# steps	 5000 	total rewards	 784.1050444754899
# steps	 5500 	total rewards	 858.6418050661734
# steps	 6000 	total rewards	 926.3173272075323
# steps	 6500 	total rewards	 990.4514712405719
# Finished after 6901 timesteps (19.5716450214386 seconds) with total reward 1043.1120501261223
# {'coverage_prop': '0.668', 'intensity_prop': '0.369', 'ms1ms2_ratio': '0.045', 'efficiency': '0.494', 'TP': '1925', 'FP': '1336', 'FN': '1620', 'precision': '0.590', 'recall': '0.543', 'f1': '0.566', 'total_rewards': 1043.1120501261241, 'invalid_action_count': 0, 'num_ms1_scans': 299, 'num_ms2_scans': 6602}
#
# Episode 19 (3491 chemicals)
# steps	 500 	total rewards	 51.78037383133636
# steps	 1000 	total rewards	 116.18983195048787
# steps	 1500 	total rewards	 202.4520162607387
# steps	 2000 	total rewards	 277.5804656932034
# steps	 2500 	total rewards	 365.9115335668183
# steps	 3000 	total rewards	 465.88524702284644
# steps	 3500 	total rewards	 549.7067646747762
# steps	 4000 	total rewards	 623.1042243940774
# steps	 4500 	total rewards	 684.7961546185672
# steps	 5000 	total rewards	 746.3581341082614
# steps	 5500 	total rewards	 815.9856412100839
# steps	 6000 	total rewards	 875.4980489985933
# steps	 6500 	total rewards	 941.4120782148125
# Finished after 6773 timesteps (15.630514860153198 seconds) with total reward 972.64947107173
# {'coverage_prop': '0.712', 'intensity_prop': '0.411', 'ms1ms2_ratio': '0.067', 'efficiency': '0.391', 'TP': '1553', 'FP': '931', 'FN': '1007', 'precision': '0.625', 'recall': '0.607', 'f1': '0.616', 'total_rewards': 972.6494710717319, 'invalid_action_count': 0, 'num_ms1_scans': 427, 'num_ms2_scans': 6346}
#
# Episode 20 (3674 chemicals)
# steps	 500 	total rewards	 52.83766507062974
# steps	 1000 	total rewards	 125.6094733294236
# steps	 1500 	total rewards	 209.04380691410088
# steps	 2000 	total rewards	 291.9738592300431
# steps	 2500 	total rewards	 383.1237204464032
# steps	 3000 	total rewards	 473.22890881869887
# steps	 3500 	total rewards	 556.9587683373215
# steps	 4000 	total rewards	 627.4816736852397
# steps	 4500 	total rewards	 690.7184883796446
# steps	 5000 	total rewards	 756.77931400596
# steps	 5500 	total rewards	 827.2019417582729
# steps	 6000 	total rewards	 887.7281500406325
# steps	 6500 	total rewards	 952.3938137893997
# Finished after 6812 timesteps (15.06328797340393 seconds) with total reward 988.9605876297793
# {'coverage_prop': '0.698', 'intensity_prop': '0.406', 'ms1ms2_ratio': '0.060', 'efficiency': '0.399', 'TP': '1637', 'FP': '926', 'FN': '1111', 'precision': '0.639', 'recall': '0.596', 'f1': '0.616', 'total_rewards': 988.9605876297791, 'invalid_action_count': 0, 'num_ms1_scans': 388, 'num_ms2_scans': 6424}
#
# Episode 21 (4196 chemicals)
# steps	 500 	total rewards	 52.626344099050556
# steps	 1000 	total rewards	 124.80781368262822
# steps	 1500 	total rewards	 213.33726798304733
# steps	 2000 	total rewards	 292.264198377703
# steps	 2500 	total rewards	 385.2048052413475
# steps	 3000 	total rewards	 484.164046337312
# steps	 3500 	total rewards	 570.8077226805403
# steps	 4000 	total rewards	 644.6574981763736
# steps	 4500 	total rewards	 705.4675278372472
# steps	 5000 	total rewards	 765.8861221676013
# steps	 5500 	total rewards	 834.7452038228336
# steps	 6000 	total rewards	 898.5791471401519
# steps	 6500 	total rewards	 957.0839539160262
# Finished after 6874 timesteps (16.45063805580139 seconds) with total reward 1004.0329918839959
# {'coverage_prop': '0.676', 'intensity_prop': '0.385', 'ms1ms2_ratio': '0.050', 'efficiency': '0.433', 'TP': '1757', 'FP': '1081', 'FN': '1358', 'precision': '0.619', 'recall': '0.564', 'f1': '0.590', 'total_rewards': 1004.0329918839975, 'invalid_action_count': 0, 'num_ms1_scans': 326, 'num_ms2_scans': 6548}
#
# Episode 22 (2541 chemicals)
# steps	 500 	total rewards	 45.329446067551224
# steps	 1000 	total rewards	 112.37341807092582
# steps	 1500 	total rewards	 194.0230074478483
# steps	 2000 	total rewards	 271.76345136049747
# steps	 2500 	total rewards	 354.10979052328196
# steps	 3000 	total rewards	 447.5307602314924
# steps	 3500 	total rewards	 530.0887246799413
# steps	 4000 	total rewards	 594.4795150398095
# steps	 4500 	total rewards	 656.2051930145059
# steps	 5000 	total rewards	 718.716804200338
# steps	 5500 	total rewards	 784.5359444089456
# steps	 6000 	total rewards	 846.6520126557306
# steps	 6500 	total rewards	 904.846602374801
# Finished after 6742 timesteps (13.042603015899658 seconds) with total reward 932.251916679294
# {'coverage_prop': '0.730', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.073', 'efficiency': '0.295', 'TP': '1208', 'FP': '646', 'FN': '687', 'precision': '0.652', 'recall': '0.637', 'f1': '0.644', 'total_rewards': 932.2519166792936, 'invalid_action_count': 0, 'num_ms1_scans': 458, 'num_ms2_scans': 6284}
#
# Episode 23 (3254 chemicals)
# steps	 500 	total rewards	 51.39711147323189
# steps	 1000 	total rewards	 120.80799923834093
# steps	 1500 	total rewards	 205.49583771202174
# steps	 2000 	total rewards	 287.06741010341875
# steps	 2500 	total rewards	 373.9781983738493
# steps	 3000 	total rewards	 468.4458176558307
# steps	 3500 	total rewards	 551.7187957441809
# steps	 4000 	total rewards	 624.8557508349547
# steps	 4500 	total rewards	 689.4519031697611
# steps	 5000 	total rewards	 754.214498745366
# steps	 5500 	total rewards	 823.2239377008611
# steps	 6000 	total rewards	 888.5032404964202
# steps	 6500 	total rewards	 953.6705384006809
# Finished after 6778 timesteps (15.722111940383911 seconds) with total reward 985.1559886804748
# {'coverage_prop': '0.711', 'intensity_prop': '0.415', 'ms1ms2_ratio': '0.066', 'efficiency': '0.364', 'TP': '1455', 'FP': '859', 'FN': '940', 'precision': '0.629', 'recall': '0.608', 'f1': '0.618', 'total_rewards': 985.1559886804745, 'invalid_action_count': 0, 'num_ms1_scans': 422, 'num_ms2_scans': 6356}
#
# Episode 24 (4358 chemicals)
# steps	 500 	total rewards	 58.08595140463032
# steps	 1000 	total rewards	 126.74948759198242
# steps	 1500 	total rewards	 215.32136739731658
# steps	 2000 	total rewards	 296.22869736271116
# steps	 2500 	total rewards	 383.5260483982453
# steps	 3000 	total rewards	 480.3775625318639
# steps	 3500 	total rewards	 572.3747491025078
# steps	 4000 	total rewards	 648.5810118794377
# steps	 4500 	total rewards	 712.9912761346914
# steps	 5000 	total rewards	 775.8327508234097
# steps	 5500 	total rewards	 849.3523077053985
# steps	 6000 	total rewards	 912.0049490910222
# steps	 6500 	total rewards	 973.9233486019127
# Finished after 6896 timesteps (18.88774609565735 seconds) with total reward 1026.5244398075995
# {'coverage_prop': '0.677', 'intensity_prop': '0.377', 'ms1ms2_ratio': '0.046', 'efficiency': '0.448', 'TP': '1768', 'FP': '1183', 'FN': '1407', 'precision': '0.599', 'recall': '0.557', 'f1': '0.577', 'total_rewards': 1026.5244398075977, 'invalid_action_count': 0, 'num_ms1_scans': 304, 'num_ms2_scans': 6592}
#
# Episode 25 (3301 chemicals)
# steps	 500 	total rewards	 51.15838662435449
# steps	 1000 	total rewards	 120.97208594976513
# steps	 1500 	total rewards	 197.54011718030694
# steps	 2000 	total rewards	 275.4469818164796
# steps	 2500 	total rewards	 356.15123614003113
# steps	 3000 	total rewards	 450.9263903016187
# steps	 3500 	total rewards	 536.3574288495047
# steps	 4000 	total rewards	 609.8608245171391
# steps	 4500 	total rewards	 667.470671284078
# steps	 5000 	total rewards	 723.4069255635172
# steps	 5500 	total rewards	 783.0067444395065
# steps	 6000 	total rewards	 838.7345181125733
# steps	 6500 	total rewards	 890.004495730346
# Finished after 6761 timesteps (141.9895100593567 seconds) with total reward 916.6719465796334
# {'coverage_prop': '0.711', 'intensity_prop': '0.416', 'ms1ms2_ratio': '0.069', 'efficiency': '0.371', 'TP': '1484', 'FP': '864', 'FN': '953', 'precision': '0.632', 'recall': '0.609', 'f1': '0.620', 'total_rewards': 916.6719465796328, 'invalid_action_count': 0, 'num_ms1_scans': 439, 'num_ms2_scans': 6322}
#
# Episode 26 (4916 chemicals)
# steps	 500 	total rewards	 53.024626443748105
# steps	 1000 	total rewards	 126.2468557777936
# steps	 1500 	total rewards	 215.58945625809844
# steps	 2000 	total rewards	 299.6277734493005
# steps	 2500 	total rewards	 388.5940686945783
# steps	 3000 	total rewards	 486.1987828902271
# steps	 3500 	total rewards	 570.8421033959011
# steps	 4000 	total rewards	 648.9183459399485
# steps	 4500 	total rewards	 712.7384025696546
# steps	 5000 	total rewards	 776.1300465661758
# steps	 5500 	total rewards	 850.4068760413459
# steps	 6000 	total rewards	 911.0003141920515
# steps	 6500 	total rewards	 973.5708531654772
# Finished after 6868 timesteps (26.517811059951782 seconds) with total reward 1019.192782234586
# {'coverage_prop': '0.669', 'intensity_prop': '0.374', 'ms1ms2_ratio': '0.051', 'efficiency': '0.503', 'TP': '1972', 'FP': '1318', 'FN': '1626', 'precision': '0.599', 'recall': '0.548', 'f1': '0.573', 'total_rewards': 1019.1927822345878, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 6536}
#
# Episode 27 (2655 chemicals)
# steps	 500 	total rewards	 42.89481205939022
# steps	 1000 	total rewards	 109.57456618848539
# steps	 1500 	total rewards	 191.6455265908624
# steps	 2000 	total rewards	 267.95245872978074
# steps	 2500 	total rewards	 351.68290231992364
# steps	 3000 	total rewards	 446.1195448946561
# steps	 3500 	total rewards	 522.5877356671283
# steps	 4000 	total rewards	 589.00564938202
# steps	 4500 	total rewards	 651.1227680688224
# steps	 5000 	total rewards	 708.1856820120435
# steps	 5500 	total rewards	 770.7629121001262
# steps	 6000 	total rewards	 823.9632541190799
# steps	 6500 	total rewards	 876.351224039437
# Finished after 6713 timesteps (16.094511032104492 seconds) with total reward 896.633802049714
# {'coverage_prop': '0.734', 'intensity_prop': '0.431', 'ms1ms2_ratio': '0.078', 'efficiency': '0.313', 'TP': '1254', 'FP': '695', 'FN': '706', 'precision': '0.643', 'recall': '0.640', 'f1': '0.642', 'total_rewards': 896.6338020497121, 'invalid_action_count': 0, 'num_ms1_scans': 487, 'num_ms2_scans': 6226}
#
# Episode 28 (4538 chemicals)
# steps	 500 	total rewards	 58.55672771855519
# steps	 1000 	total rewards	 130.9620011951597
# steps	 1500 	total rewards	 217.2429441280721
# steps	 2000 	total rewards	 296.63464898194195
# steps	 2500 	total rewards	 387.62776581661956
# steps	 3000 	total rewards	 484.15698568330856
# steps	 3500 	total rewards	 576.0719136534207
# steps	 4000 	total rewards	 651.8623341558042
# steps	 4500 	total rewards	 717.3110891340109
# steps	 5000 	total rewards	 777.5163118719795
# steps	 5500 	total rewards	 850.795369484512
# steps	 6000 	total rewards	 914.8980364918161
# steps	 6500 	total rewards	 973.1547169076488
# Finished after 6875 timesteps (76.08228707313538 seconds) with total reward 1017.3266963147712
# {'coverage_prop': '0.667', 'intensity_prop': '0.374', 'ms1ms2_ratio': '0.050', 'efficiency': '0.462', 'TP': '1832', 'FP': '1195', 'FN': '1511', 'precision': '0.605', 'recall': '0.548', 'f1': '0.575', 'total_rewards': 1017.3266963147734, 'invalid_action_count': 0, 'num_ms1_scans': 325, 'num_ms2_scans': 6550}
#
# Episode 29 (3171 chemicals)
# steps	 500 	total rewards	 55.46335596890819
# steps	 1000 	total rewards	 126.16923511292413
# steps	 1500 	total rewards	 207.34971493664943
# steps	 2000 	total rewards	 285.9563502260121
# steps	 2500 	total rewards	 382.5801545592519
# steps	 3000 	total rewards	 472.02353318114126
# steps	 3500 	total rewards	 551.8406047251899
# steps	 4000 	total rewards	 620.4631357085643
# steps	 4500 	total rewards	 681.3034380580176
# steps	 5000 	total rewards	 741.4542500436651
# steps	 5500 	total rewards	 809.8618686950574
# steps	 6000 	total rewards	 865.7847170282053
# steps	 6500 	total rewards	 921.6932751392471
# Finished after 6773 timesteps (17.188676834106445 seconds) with total reward 954.6349997037258
# {'coverage_prop': '0.729', 'intensity_prop': '0.421', 'ms1ms2_ratio': '0.067', 'efficiency': '0.364', 'TP': '1463', 'FP': '849', 'FN': '859', 'precision': '0.633', 'recall': '0.630', 'f1': '0.631', 'total_rewards': 954.6349997037264, 'invalid_action_count': 0, 'num_ms1_scans': 427, 'num_ms2_scans': 6346}
#
# method = PPO max_peaks = 100 N = 0 rt_tol = 5
#
#
# Episode 0 (2151 chemicals)
# steps	 500 	total rewards	 48.72962133312856
# steps	 1000 	total rewards	 114.65325258221787
# steps	 1500 	total rewards	 188.68947750027849
# steps	 2000 	total rewards	 266.0667965271589
# steps	 2500 	total rewards	 348.1861926290077
# steps	 3000 	total rewards	 439.31554385681386
# steps	 3500 	total rewards	 517.8323117959408
# steps	 4000 	total rewards	 581.0094955617873
# steps	 4500 	total rewards	 637.0858705561117
# steps	 5000 	total rewards	 691.9453359550228
# steps	 5500 	total rewards	 756.99664452993
# steps	 6000 	total rewards	 818.607149082394
# steps	 6500 	total rewards	 877.151211671719
# Finished after 6760 timesteps (25.331562042236328 seconds) with total reward 902.714663085327
# {'coverage_prop': '0.755', 'intensity_prop': '0.489', 'ms1ms2_ratio': '0.070', 'efficiency': '0.257', 'TP': '1184', 'FP': '440', 'FN': '527', 'precision': '0.729', 'recall': '0.692', 'f1': '0.710', 'total_rewards': 902.7146630853275, 'invalid_action_count': 0, 'num_ms1_scans': 440, 'num_ms2_scans': 6320}
#
# Episode 1 (4096 chemicals)
# steps	 500 	total rewards	 57.5267078435385
# steps	 1000 	total rewards	 124.88891638053181
# steps	 1500 	total rewards	 213.72833487527188
# steps	 2000 	total rewards	 293.8530074704596
# steps	 2500 	total rewards	 388.07024222968516
# steps	 3000 	total rewards	 478.82123609047085
# steps	 3500 	total rewards	 563.1734429443853
# steps	 4000 	total rewards	 639.5590527216975
# steps	 4500 	total rewards	 704.7929082456637
# steps	 5000 	total rewards	 764.5407612429942
# steps	 5500 	total rewards	 829.9103581689737
# steps	 6000 	total rewards	 891.4152255068158
# steps	 6500 	total rewards	 951.9095874459316
# Finished after 6913 timesteps (30.793653964996338 seconds) with total reward 997.7674340499552
# {'coverage_prop': '0.685', 'intensity_prop': '0.397', 'ms1ms2_ratio': '0.043', 'efficiency': '0.423', 'TP': '1763', 'FP': '1043', 'FN': '1290', 'precision': '0.628', 'recall': '0.577', 'f1': '0.602', 'total_rewards': 997.767434049953, 'invalid_action_count': 0, 'num_ms1_scans': 287, 'num_ms2_scans': 6626}
#
# Episode 2 (3307 chemicals)
# steps	 500 	total rewards	 54.63409268338375
# steps	 1000 	total rewards	 130.62055031807287
# steps	 1500 	total rewards	 218.06998026084023
# steps	 2000 	total rewards	 299.7070733400029
# steps	 2500 	total rewards	 379.0822910157007
# steps	 3000 	total rewards	 471.37415336157744
# steps	 3500 	total rewards	 561.4288495577684
# steps	 4000 	total rewards	 634.3312310426896
# steps	 4500 	total rewards	 701.8343292821377
# steps	 5000 	total rewards	 770.2060494537668
# steps	 5500 	total rewards	 832.8091719661348
# steps	 6000 	total rewards	 899.2778715494877
# steps	 6500 	total rewards	 961.2230400476842
# Finished after 6877 timesteps (58.805152893066406 seconds) with total reward 1008.2947802727347
# {'coverage_prop': '0.715', 'intensity_prop': '0.417', 'ms1ms2_ratio': '0.049', 'efficiency': '0.361', 'TP': '1510', 'FP': '853', 'FN': '944', 'precision': '0.639', 'recall': '0.615', 'f1': '0.627', 'total_rewards': 1008.2947802727343, 'invalid_action_count': 0, 'num_ms1_scans': 323, 'num_ms2_scans': 6554}
#
# Episode 3 (3000 chemicals)
# steps	 500 	total rewards	 52.98211513085958
# steps	 1000 	total rewards	 124.88712253822118
# steps	 1500 	total rewards	 213.28008940561313
# steps	 2000 	total rewards	 295.9473433048106
# steps	 2500 	total rewards	 383.681274561587
# steps	 3000 	total rewards	 474.568335423391
# steps	 3500 	total rewards	 556.3276063434271
# steps	 4000 	total rewards	 623.3534131775293
# steps	 4500 	total rewards	 685.1161090020876
# steps	 5000 	total rewards	 749.0555808895459
# steps	 5500 	total rewards	 818.0359194160299
# steps	 6000 	total rewards	 873.7190397195558
# steps	 6500 	total rewards	 932.8847480698056
# Finished after 6880 timesteps (18.587112188339233 seconds) with total reward 972.6176860044551
# {'coverage_prop': '0.741', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.049', 'efficiency': '0.339', 'TP': '1436', 'FP': '788', 'FN': '776', 'precision': '0.646', 'recall': '0.649', 'f1': '0.647', 'total_rewards': 972.6176860044538, 'invalid_action_count': 0, 'num_ms1_scans': 320, 'num_ms2_scans': 6560}
#
# Episode 4 (4490 chemicals)
# steps	 500 	total rewards	 62.18836131570107
# steps	 1000 	total rewards	 129.58312229427798
# steps	 1500 	total rewards	 219.3518490104615
# steps	 2000 	total rewards	 304.9887546999078
# steps	 2500 	total rewards	 397.10561438508216
# steps	 3000 	total rewards	 488.96326966427705
# steps	 3500 	total rewards	 581.2826194338045
# steps	 4000 	total rewards	 659.5641042748291
# steps	 4500 	total rewards	 727.0331135790306
# steps	 5000 	total rewards	 790.0908263646693
# steps	 5500 	total rewards	 858.2506045940999
# steps	 6000 	total rewards	 922.6540096938543
# steps	 6500 	total rewards	 984.3019966183185
# Finished after 6942 timesteps (21.99035906791687 seconds) with total reward 1040.2322013492821
# {'coverage_prop': '0.677', 'intensity_prop': '0.384', 'ms1ms2_ratio': '0.039', 'efficiency': '0.455', 'TP': '1849', 'FP': '1191', 'FN': '1450', 'precision': '0.608', 'recall': '0.560', 'f1': '0.583', 'total_rewards': 1040.232201349282, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 6684}
#
# Episode 5 (2477 chemicals)
# steps	 500 	total rewards	 50.596236791932554
# steps	 1000 	total rewards	 118.75919359722639
# steps	 1500 	total rewards	 196.86686614701077
# steps	 2000 	total rewards	 272.5407879573481
# steps	 2500 	total rewards	 359.1486674311234
# steps	 3000 	total rewards	 451.1526536224194
# steps	 3500 	total rewards	 531.9634561421024
# steps	 4000 	total rewards	 594.4827281688492
# steps	 4500 	total rewards	 649.1816289054689
# steps	 5000 	total rewards	 701.6048682510653
# steps	 5500 	total rewards	 762.7086909049209
# steps	 6000 	total rewards	 818.0786669726556
# steps	 6500 	total rewards	 874.3420154145126
# Finished after 6827 timesteps (16.245092153549194 seconds) with total reward 909.9628948740318
# {'coverage_prop': '0.740', 'intensity_prop': '0.448', 'ms1ms2_ratio': '0.058', 'efficiency': '0.284', 'TP': '1222', 'FP': '611', 'FN': '644', 'precision': '0.667', 'recall': '0.655', 'f1': '0.661', 'total_rewards': 909.9628948740327, 'invalid_action_count': 0, 'num_ms1_scans': 374, 'num_ms2_scans': 6453}
#
# Episode 6 (3302 chemicals)
# steps	 500 	total rewards	 43.59092103679261
# steps	 1000 	total rewards	 108.29325600167523
# steps	 1500 	total rewards	 193.49418397271563
# steps	 2000 	total rewards	 271.06679816650467
# steps	 2500 	total rewards	 359.9890896206201
# steps	 3000 	total rewards	 461.18591375766425
# steps	 3500 	total rewards	 539.6641082785368
# steps	 4000 	total rewards	 608.8647571705544
# steps	 4500 	total rewards	 675.0181185133067
# steps	 5000 	total rewards	 735.8256926781614
# steps	 5500 	total rewards	 804.9367837612351
# steps	 6000 	total rewards	 861.6402982523853
# steps	 6500 	total rewards	 920.2122314700514
# Finished after 6889 timesteps (18.990355968475342 seconds) with total reward 967.3243663521401
# {'coverage_prop': '0.712', 'intensity_prop': '0.410', 'ms1ms2_ratio': '0.047', 'efficiency': '0.357', 'TP': '1468', 'FP': '882', 'FN': '952', 'precision': '0.625', 'recall': '0.607', 'f1': '0.616', 'total_rewards': 967.3243663521388, 'invalid_action_count': 0, 'num_ms1_scans': 311, 'num_ms2_scans': 6578}
#
# Episode 7 (2370 chemicals)
# steps	 500 	total rewards	 40.5666195377375
# steps	 1000 	total rewards	 96.67439507333387
# steps	 1500 	total rewards	 172.16155986845322
# steps	 2000 	total rewards	 242.25665274800457
# steps	 2500 	total rewards	 324.6001550915595
# steps	 3000 	total rewards	 411.1196456738894
# steps	 3500 	total rewards	 499.3968102405804
# steps	 4000 	total rewards	 569.62870935556
# steps	 4500 	total rewards	 629.3354035614695
# steps	 5000 	total rewards	 691.5356175499926
# steps	 5500 	total rewards	 759.1664223666571
# steps	 6000 	total rewards	 820.6824119167183
# steps	 6500 	total rewards	 879.4299153723885
# Finished after 6823 timesteps (53.33618116378784 seconds) with total reward 918.4410149018079
# {'coverage_prop': '0.754', 'intensity_prop': '0.463', 'ms1ms2_ratio': '0.058', 'efficiency': '0.277', 'TP': '1192', 'FP': '596', 'FN': '582', 'precision': '0.667', 'recall': '0.672', 'f1': '0.669', 'total_rewards': 918.4410149018069, 'invalid_action_count': 0, 'num_ms1_scans': 377, 'num_ms2_scans': 6446}
#
# Episode 8 (3021 chemicals)
# steps	 500 	total rewards	 51.763450545327316
# steps	 1000 	total rewards	 117.88075623676059
# steps	 1500 	total rewards	 200.1865613942398
# steps	 2000 	total rewards	 275.50708281732665
# steps	 2500 	total rewards	 364.6250901347056
# steps	 3000 	total rewards	 464.4711366725307
# steps	 3500 	total rewards	 546.3679717465421
# steps	 4000 	total rewards	 625.0893944397609
# steps	 4500 	total rewards	 689.0797576049534
# steps	 5000 	total rewards	 752.879643850333
# steps	 5500 	total rewards	 827.6895244924451
# steps	 6000 	total rewards	 887.9060437625478
# steps	 6500 	total rewards	 948.1956890444969
# Finished after 6875 timesteps (18.663982152938843 seconds) with total reward 991.4276405051552
# {'coverage_prop': '0.729', 'intensity_prop': '0.435', 'ms1ms2_ratio': '0.050', 'efficiency': '0.336', 'TP': '1425', 'FP': '776', 'FN': '820', 'precision': '0.647', 'recall': '0.635', 'f1': '0.641', 'total_rewards': 991.4276405051529, 'invalid_action_count': 0, 'num_ms1_scans': 325, 'num_ms2_scans': 6550}
#
# Episode 9 (3051 chemicals)
# steps	 500 	total rewards	 59.74477940781299
# steps	 1000 	total rewards	 132.6820441109938
# steps	 1500 	total rewards	 218.14572918533344
# steps	 2000 	total rewards	 290.43298198858116
# steps	 2500 	total rewards	 377.392577709175
# steps	 3000 	total rewards	 465.8480966981705
# steps	 3500 	total rewards	 555.6558852368115
# steps	 4000 	total rewards	 628.0124656306186
# steps	 4500 	total rewards	 691.0428330426698
# steps	 5000 	total rewards	 752.6657145437697
# steps	 5500 	total rewards	 819.9692350350174
# steps	 6000 	total rewards	 879.1234989955801
# steps	 6500 	total rewards	 939.994118923194
# Finished after 6882 timesteps (18.691468954086304 seconds) with total reward 977.9719310111253
# {'coverage_prop': '0.728', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.048', 'efficiency': '0.338', 'TP': '1466', 'FP': '754', 'FN': '831', 'precision': '0.660', 'recall': '0.638', 'f1': '0.649', 'total_rewards': 977.9719310111282, 'invalid_action_count': 0, 'num_ms1_scans': 318, 'num_ms2_scans': 6564}
#
# Episode 10 (4873 chemicals)
# steps	 500 	total rewards	 54.47825919447405
# steps	 1000 	total rewards	 132.01611686833485
# steps	 1500 	total rewards	 224.67078692651955
# steps	 2000 	total rewards	 299.27971408700466
# steps	 2500 	total rewards	 389.6301343319583
# steps	 3000 	total rewards	 484.624105913853
# steps	 3500 	total rewards	 574.2213393538567
# steps	 4000 	total rewards	 655.5537833690609
# steps	 4500 	total rewards	 726.277297040783
# steps	 5000 	total rewards	 788.1791653266037
# steps	 5500 	total rewards	 858.7300867051827
# steps	 6000 	total rewards	 928.4863320548718
# steps	 6500 	total rewards	 991.0948381213657
# Finished after 6948 timesteps (23.73550009727478 seconds) with total reward 1044.488378923937
# {'coverage_prop': '0.663', 'intensity_prop': '0.369', 'ms1ms2_ratio': '0.038', 'efficiency': '0.482', 'TP': '1919', 'FP': '1310', 'FN': '1644', 'precision': '0.594', 'recall': '0.539', 'f1': '0.565', 'total_rewards': 1044.4883789239384, 'invalid_action_count': 0, 'num_ms1_scans': 253, 'num_ms2_scans': 6695}
#
# Episode 11 (3756 chemicals)
# steps	 500 	total rewards	 54.32587046536706
# steps	 1000 	total rewards	 116.57092151203277
# steps	 1500 	total rewards	 199.61006339780124
# steps	 2000 	total rewards	 272.01285371947085
# steps	 2500 	total rewards	 362.3141621283806
# steps	 3000 	total rewards	 460.8958922955154
# steps	 3500 	total rewards	 547.5005059359946
# steps	 4000 	total rewards	 626.1730200223409
# steps	 4500 	total rewards	 695.4359872522473
# steps	 5000 	total rewards	 761.1660999004062
# steps	 5500 	total rewards	 830.3620256357541
# steps	 6000 	total rewards	 892.948330572375
# steps	 6500 	total rewards	 956.1331018093101
# Finished after 6929 timesteps (18.8806369304657 seconds) with total reward 1010.0362486152528
# {'coverage_prop': '0.698', 'intensity_prop': '0.415', 'ms1ms2_ratio': '0.041', 'efficiency': '0.394', 'TP': '1684', 'FP': '937', 'FN': '1135', 'precision': '0.643', 'recall': '0.597', 'f1': '0.619', 'total_rewards': 1010.036248615254, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 6658}
#
# Episode 12 (4904 chemicals)
# steps	 500 	total rewards	 63.42145667257701
# steps	 1000 	total rewards	 140.15565963497127
# steps	 1500 	total rewards	 226.5703684177493
# steps	 2000 	total rewards	 311.8524282181538
# steps	 2500 	total rewards	 405.04761213486097
# steps	 3000 	total rewards	 505.7909189902497
# steps	 3500 	total rewards	 595.6776894598811
# steps	 4000 	total rewards	 681.8658989365766
# steps	 4500 	total rewards	 752.5389657174675
# steps	 5000 	total rewards	 818.8429636111006
# steps	 5500 	total rewards	 890.3342718477898
# steps	 6000 	total rewards	 954.161813206426
# steps	 6500 	total rewards	 1019.9163536200946
# Finished after 6955 timesteps (58.7243709564209 seconds) with total reward 1078.7279320397265
# {'coverage_prop': '0.678', 'intensity_prop': '0.379', 'ms1ms2_ratio': '0.037', 'efficiency': '0.496', 'TP': '1988', 'FP': '1339', 'FN': '1577', 'precision': '0.598', 'recall': '0.558', 'f1': '0.577', 'total_rewards': 1078.7279320397279, 'invalid_action_count': 0, 'num_ms1_scans': 245, 'num_ms2_scans': 6710}
#
# Episode 13 (3460 chemicals)
# steps	 500 	total rewards	 57.707165818887596
# steps	 1000 	total rewards	 123.22265924332731
# steps	 1500 	total rewards	 209.47526882277776
# steps	 2000 	total rewards	 283.708305714524
# steps	 2500 	total rewards	 376.7553278033518
# steps	 3000 	total rewards	 470.8902397006305
# steps	 3500 	total rewards	 562.5763994471964
# steps	 4000 	total rewards	 641.2599907145409
# steps	 4500 	total rewards	 704.6734059376274
# steps	 5000 	total rewards	 769.8665298969946
# steps	 5500 	total rewards	 838.9904272818228
# steps	 6000 	total rewards	 901.4953353717067
# steps	 6500 	total rewards	 965.0838591165202
# Finished after 6901 timesteps (19.88623309135437 seconds) with total reward 1015.9740266227041
# {'coverage_prop': '0.710', 'intensity_prop': '0.412', 'ms1ms2_ratio': '0.045', 'efficiency': '0.372', 'TP': '1527', 'FP': '930', 'FN': '1003', 'precision': '0.621', 'recall': '0.604', 'f1': '0.612', 'total_rewards': 1015.9740266227011, 'invalid_action_count': 0, 'num_ms1_scans': 299, 'num_ms2_scans': 6602}
#
# Episode 14 (2023 chemicals)
# steps	 500 	total rewards	 39.891619161495235
# steps	 1000 	total rewards	 107.50959094497325
# steps	 1500 	total rewards	 185.46247118199952
# steps	 2000 	total rewards	 258.9361967949301
# steps	 2500 	total rewards	 343.22478754711244
# steps	 3000 	total rewards	 435.6902043876272
# steps	 3500 	total rewards	 512.8824791224947
# steps	 4000 	total rewards	 582.4772324500976
# steps	 4500 	total rewards	 650.4106442974835
# steps	 5000 	total rewards	 712.790748723593
# steps	 5500 	total rewards	 781.2760782960461
# steps	 6000 	total rewards	 838.1633188903138
# steps	 6500 	total rewards	 895.3328727164463
# Finished after 6722 timesteps (16.192137956619263 seconds) with total reward 919.4294926328548
# {'coverage_prop': '0.774', 'intensity_prop': '0.490', 'ms1ms2_ratio': '0.077', 'efficiency': '0.251', 'TP': '1101', 'FP': '464', 'FN': '458', 'precision': '0.704', 'recall': '0.706', 'f1': '0.705', 'total_rewards': 919.4294926328546, 'invalid_action_count': 0, 'num_ms1_scans': 478, 'num_ms2_scans': 6244}
#
# Episode 15 (4151 chemicals)
# steps	 500 	total rewards	 57.521017543555764
# steps	 1000 	total rewards	 125.47675593428622
# steps	 1500 	total rewards	 211.50702936065233
# steps	 2000 	total rewards	 294.8853975192503
# steps	 2500 	total rewards	 393.9184620249819
# steps	 3000 	total rewards	 495.68946143132416
# steps	 3500 	total rewards	 584.9363742590996
# steps	 4000 	total rewards	 667.2509642287462
# steps	 4500 	total rewards	 730.7444523495906
# steps	 5000 	total rewards	 793.5238045731459
# steps	 5500 	total rewards	 870.7180729545526
# steps	 6000 	total rewards	 936.2018035181687
# steps	 6500 	total rewards	 999.4615145991645
# Finished after 6926 timesteps (21.520614862442017 seconds) with total reward 1051.0057268468443
# {'coverage_prop': '0.702', 'intensity_prop': '0.401', 'ms1ms2_ratio': '0.041', 'efficiency': '0.438', 'TP': '1789', 'FP': '1126', 'FN': '1236', 'precision': '0.614', 'recall': '0.591', 'f1': '0.602', 'total_rewards': 1051.0057268468486, 'invalid_action_count': 0, 'num_ms1_scans': 274, 'num_ms2_scans': 6652}
#
# Episode 16 (4326 chemicals)
# steps	 500 	total rewards	 51.55280627921171
# steps	 1000 	total rewards	 113.80942950152638
# steps	 1500 	total rewards	 203.08970189836296
# steps	 2000 	total rewards	 282.3019048496597
# steps	 2500 	total rewards	 379.4381154532849
# steps	 3000 	total rewards	 476.118910966119
# steps	 3500 	total rewards	 561.7664601729854
# steps	 4000 	total rewards	 638.4515752143511
# steps	 4500 	total rewards	 707.6448955969004
# steps	 5000 	total rewards	 772.1084980950629
# steps	 5500 	total rewards	 844.1977452510695
# ...
# Finished after 6244 timesteps (35.37014389038086 seconds) with total reward 919.8251746511401
# {'coverage_prop': '0.740', 'intensity_prop': '0.487', 'ms1ms2_ratio': '0.181', 'efficiency': '0.484', 'TP': '1915', 'FP': '646', 'FN': '899', 'precision': '0.748', 'recall': '0.681', 'f1': '0.713', 'total_rewards': 919.8251746511405, 'invalid_action_count': 0, 'num_ms1_scans': 956, 'num_ms2_scans': 5288}
#
# Episode 14 (2023 chemicals)
# steps	 500 	total rewards	 12.475995799280767
# steps	 1000 	total rewards	 87.81215420393471
# steps	 1500 	total rewards	 158.41343673748605
# steps	 2000 	total rewards	 250.13891782387043
# steps	 2500 	total rewards	 343.14222069660667
# steps	 3000 	total rewards	 425.4975389042057
# steps	 3500 	total rewards	 497.1072425348082
# steps	 4000 	total rewards	 550.7588595833499
# steps	 4500 	total rewards	 612.475917751549
# steps	 5000 	total rewards	 663.4197465836362
# steps	 5500 	total rewards	 709.9773899927993
# Finished after 5726 timesteps (69.5190658569336 seconds) with total reward 728.4675518889799
# {'coverage_prop': '0.809', 'intensity_prop': '0.533', 'ms1ms2_ratio': '0.347', 'efficiency': '0.385', 'TP': '1225', 'FP': '412', 'FN': '386', 'precision': '0.748', 'recall': '0.760', 'f1': '0.754', 'total_rewards': 728.4675518889803, 'invalid_action_count': 0, 'num_ms1_scans': 1474, 'num_ms2_scans': 4252}
#
# Episode 15 (4151 chemicals)
# steps	 500 	total rewards	 28.44712690430546
# steps	 1000 	total rewards	 112.39686303769778
# steps	 1500 	total rewards	 206.14456702407455
# steps	 2000 	total rewards	 303.4281333868682
# steps	 2500 	total rewards	 404.1792097359397
# steps	 3000 	total rewards	 494.03094577179866
# steps	 3500 	total rewards	 577.4364690273986
# steps	 4000 	total rewards	 645.5958721542326
# steps	 4500 	total rewards	 710.3803784554672
# steps	 5000 	total rewards	 786.2152955638335
# steps	 5500 	total rewards	 853.404616853284
# steps	 6000 	total rewards	 918.0270460994817
# Finished after 6354 timesteps (40.29867911338806 seconds) with total reward 958.7882801547263
# {'coverage_prop': '0.717', 'intensity_prop': '0.469', 'ms1ms2_ratio': '0.154', 'efficiency': '0.541', 'TP': '2233', 'FP': '745', 'FN': '1173', 'precision': '0.750', 'recall': '0.656', 'f1': '0.700', 'total_rewards': 958.7882801547274, 'invalid_action_count': 0, 'num_ms1_scans': 846, 'num_ms2_scans': 5508}
#
# Episode 16 (4326 chemicals)
# steps	 500 	total rewards	 23.680261959474713
# steps	 1000 	total rewards	 116.16033718423897
# steps	 1500 	total rewards	 211.44578489876417
# steps	 2000 	total rewards	 306.96518371852085
# steps	 2500 	total rewards	 398.05023601885
# steps	 3000 	total rewards	 487.1038793112509
# steps	 3500 	total rewards	 571.6525483917255
# steps	 4000 	total rewards	 644.899251054883
# steps	 4500 	total rewards	 714.4975767390999
# steps	 5000 	total rewards	 794.6500217610476
# steps	 5500 	total rewards	 859.3637991663347
# steps	 6000 	total rewards	 922.0021548336493
# Finished after 6395 timesteps (38.75255990028381 seconds) with total reward 972.2754282281934
# {'coverage_prop': '0.699', 'intensity_prop': '0.452', 'ms1ms2_ratio': '0.144', 'efficiency': '0.541', 'TP': '2212', 'FP': '812', 'FN': '1302', 'precision': '0.731', 'recall': '0.629', 'f1': '0.677', 'total_rewards': 972.2754282281937, 'invalid_action_count': 0, 'num_ms1_scans': 805, 'num_ms2_scans': 5590}
#
# Episode 17 (4131 chemicals)
# steps	 500 	total rewards	 23.741084252732733
# steps	 1000 	total rewards	 108.39357572139083
# steps	 1500 	total rewards	 200.88567206425105
# steps	 2000 	total rewards	 296.57818068513666
# steps	 2500 	total rewards	 395.64106226456914
# steps	 3000 	total rewards	 477.3953438174939
# steps	 3500 	total rewards	 549.4189398093216
# steps	 4000 	total rewards	 619.6243557677076
# steps	 4500 	total rewards	 688.6147474424502
# steps	 5000 	total rewards	 764.7560701732673
# steps	 5500 	total rewards	 832.8613807459602
# steps	 6000 	total rewards	 905.9778087683259
# Finished after 6385 timesteps (42.40870213508606 seconds) with total reward 955.7012976561564
# {'coverage_prop': '0.717', 'intensity_prop': '0.469', 'ms1ms2_ratio': '0.147', 'efficiency': '0.532', 'TP': '2195', 'FP': '768', 'FN': '1168', 'precision': '0.741', 'recall': '0.653', 'f1': '0.694', 'total_rewards': 955.7012976561556, 'invalid_action_count': 0, 'num_ms1_scans': 816, 'num_ms2_scans': 5569}
#
# Episode 18 (4881 chemicals)
# steps	 500 	total rewards	 37.20183628378865
# steps	 1000 	total rewards	 131.84654853412894
# steps	 1500 	total rewards	 220.5953046073297
# steps	 2000 	total rewards	 311.78347441500665
# steps	 2500 	total rewards	 406.7301358219786
# steps	 3000 	total rewards	 491.5160443983981
# steps	 3500 	total rewards	 575.1865139782301
# steps	 4000 	total rewards	 651.4253154447908
# steps	 4500 	total rewards	 723.7659533034614
# steps	 5000 	total rewards	 800.2142117261316
# steps	 5500 	total rewards	 870.83122683804
# steps	 6000 	total rewards	 942.0348726565893
# Finished after 6440 timesteps (41.79368805885315 seconds) with total reward 1001.528741862286
# {'coverage_prop': '0.688', 'intensity_prop': '0.434', 'ms1ms2_ratio': '0.134', 'efficiency': '0.591', 'TP': '2391', 'FP': '967', 'FN': '1523', 'precision': '0.712', 'recall': '0.611', 'f1': '0.658', 'total_rewards': 1001.5287418622903, 'invalid_action_count': 0, 'num_ms1_scans': 760, 'num_ms2_scans': 5680}
#
# Episode 19 (3491 chemicals)
# steps	 500 	total rewards	 24.34979132467546
# steps	 1000 	total rewards	 109.65265103605012
# steps	 1500 	total rewards	 193.6264678680788
# steps	 2000 	total rewards	 282.2614712812689
# steps	 2500 	total rewards	 374.46329373990415
# steps	 3000 	total rewards	 466.54251793777
# steps	 3500 	total rewards	 547.51652502801
# steps	 4000 	total rewards	 613.2919843701541
# steps	 4500 	total rewards	 667.2760583195525
# steps	 5000 	total rewards	 742.9545900340066
# steps	 5500 	total rewards	 799.7985612511131
# steps	 6000 	total rewards	 863.9861930336494
# Finished after 6152 timesteps (36.40957021713257 seconds) with total reward 877.9107325468176
# {'coverage_prop': '0.731', 'intensity_prop': '0.478', 'ms1ms2_ratio': '0.206', 'efficiency': '0.500', 'TP': '1896', 'FP': '657', 'FN': '938', 'precision': '0.743', 'recall': '0.669', 'f1': '0.704', 'total_rewards': 877.9107325468186, 'invalid_action_count': 0, 'num_ms1_scans': 1049, 'num_ms2_scans': 5103}
#
# Episode 20 (3674 chemicals)
# steps	 500 	total rewards	 25.522473809645174
# steps	 1000 	total rewards	 114.15714056217602
# steps	 1500 	total rewards	 204.21580497927928
# steps	 2000 	total rewards	 299.3048742247922
# steps	 2500 	total rewards	 397.0701195312281
# steps	 3000 	total rewards	 487.29752422082356
# steps	 3500 	total rewards	 566.1202506251395
# steps	 4000 	total rewards	 637.7843502197575
# steps	 4500 	total rewards	 701.8564101383082
# steps	 5000 	total rewards	 778.0378238162646
# steps	 5500 	total rewards	 840.402015967561
# steps	 6000 	total rewards	 906.3074568906212
# Finished after 6351 timesteps (71.98861575126648 seconds) with total reward 949.2839395611363
# {'coverage_prop': '0.735', 'intensity_prop': '0.482', 'ms1ms2_ratio': '0.154', 'efficiency': '0.491', 'TP': '2018', 'FP': '682', 'FN': '974', 'precision': '0.747', 'recall': '0.674', 'f1': '0.709', 'total_rewards': 949.2839395611354, 'invalid_action_count': 0, 'num_ms1_scans': 849, 'num_ms2_scans': 5502}
#
# Episode 21 (4196 chemicals)
# steps	 500 	total rewards	 35.580446123868136
# steps	 1000 	total rewards	 118.02073260816766
# steps	 1500 	total rewards	 210.6515433457729
# steps	 2000 	total rewards	 306.4627596114047
# steps	 2500 	total rewards	 399.85432992597987
# steps	 3000 	total rewards	 496.6805391323618
# steps	 3500 	total rewards	 574.076779531043
# steps	 4000 	total rewards	 645.2307425467457
# steps	 4500 	total rewards	 705.0961123413338
# steps	 5000 	total rewards	 776.498555679455
# steps	 5500 	total rewards	 843.3676893599711
# steps	 6000 	total rewards	 901.9772995280539
# Finished after 6407 timesteps (41.21239686012268 seconds) with total reward 953.8485152250522
# {'coverage_prop': '0.701', 'intensity_prop': '0.456', 'ms1ms2_ratio': '0.141', 'efficiency': '0.524', 'TP': '2177', 'FP': '763', 'FN': '1256', 'precision': '0.740', 'recall': '0.634', 'f1': '0.683', 'total_rewards': 953.848515225053, 'invalid_action_count': 0, 'num_ms1_scans': 793, 'num_ms2_scans': 5614}
#
# Episode 22 (2541 chemicals)
# steps	 500 	total rewards	 22.93631777727024
# steps	 1000 	total rewards	 102.24648896469307
# steps	 1500 	total rewards	 181.5608285433433
# steps	 2000 	total rewards	 278.5686308025338
# steps	 2500 	total rewards	 379.089209787316
# steps	 3000 	total rewards	 466.8655872794144
# steps	 3500 	total rewards	 542.0221467583882
# steps	 4000 	total rewards	 599.2324670455757
# steps	 4500 	total rewards	 655.7073740788488
# steps	 5000 	total rewards	 720.5274707881622
# steps	 5500 	total rewards	 773.1337903575899
# Finished after 5970 timesteps (37.95428204536438 seconds) with total reward 821.1629177884647
# {'coverage_prop': '0.778', 'intensity_prop': '0.504', 'ms1ms2_ratio': '0.259', 'efficiency': '0.417', 'TP': '1443', 'FP': '535', 'FN': '563', 'precision': '0.730', 'recall': '0.719', 'f1': '0.724', 'total_rewards': 821.1629177884658, 'invalid_action_count': 0, 'num_ms1_scans': 1230, 'num_ms2_scans': 4740}
#
# Episode 23 (3254 chemicals)
# steps	 500 	total rewards	 23.50643195619583
# steps	 1000 	total rewards	 110.4573599536386
# steps	 1500 	total rewards	 199.0374814408289
# steps	 2000 	total rewards	 290.8732578731702
# steps	 2500 	total rewards	 383.8588614860797
# steps	 3000 	total rewards	 472.9639243482838
# steps	 3500 	total rewards	 550.308731000555
# steps	 4000 	total rewards	 619.0447113242788
# steps	 4500 	total rewards	 677.8191263604572
# steps	 5000 	total rewards	 746.3926308774944
# steps	 5500 	total rewards	 810.1205187418673
# steps	 6000 	total rewards	 868.8909355599333
# Finished after 6147 timesteps (83.65629720687866 seconds) with total reward 883.0397250357998
# {'coverage_prop': '0.734', 'intensity_prop': '0.477', 'ms1ms2_ratio': '0.207', 'efficiency': '0.469', 'TP': '1775', 'FP': '614', 'FN': '865', 'precision': '0.743', 'recall': '0.672', 'f1': '0.706', 'total_rewards': 883.0397250357997, 'invalid_action_count': 0, 'num_ms1_scans': 1053, 'num_ms2_scans': 5094}
#
# Episode 24 (4358 chemicals)
# steps	 500 	total rewards	 32.80661145931806
# steps	 1000 	total rewards	 124.33520060401716
# steps	 1500 	total rewards	 216.76434020758785
# steps	 2000 	total rewards	 308.18151230955925
# steps	 2500 	total rewards	 398.2199853457574
# steps	 3000 	total rewards	 496.9358737136362
# steps	 3500 	total rewards	 580.4920431923375
# steps	 4000 	total rewards	 652.9207790586877
# steps	 4500 	total rewards	 718.0350793784654
# steps	 5000 	total rewards	 795.6555361194843
# steps	 5500 	total rewards	 863.5419411138483
# steps	 6000 	total rewards	 928.7751749657796
# Finished after 6403 timesteps (54.20349884033203 seconds) with total reward 982.8124298961022
# {'coverage_prop': '0.705', 'intensity_prop': '0.451', 'ms1ms2_ratio': '0.142', 'efficiency': '0.548', 'TP': '2230', 'FP': '843', 'FN': '1285', 'precision': '0.726', 'recall': '0.634', 'f1': '0.677', 'total_rewards': 982.8124298961055, 'invalid_action_count': 0, 'num_ms1_scans': 797, 'num_ms2_scans': 5606}
#
# Episode 25 (3301 chemicals)
# steps	 500 	total rewards	 27.876440291699957
# steps	 1000 	total rewards	 110.49552012323267
# steps	 1500 	total rewards	 193.95082564684168
# steps	 2000 	total rewards	 280.90891684083357
# steps	 2500 	total rewards	 373.6913219383556
# steps	 3000 	total rewards	 471.96100555367315
# steps	 3500 	total rewards	 550.0375292323022
# steps	 4000 	total rewards	 616.1842007395633
# steps	 4500 	total rewards	 671.0321271941168
# steps	 5000 	total rewards	 733.9839777494549
# steps	 5500 	total rewards	 786.2613039736682
# steps	 6000 	total rewards	 836.6392565416168
# Finished after 6129 timesteps (39.65711998939514 seconds) with total reward 847.295500279519
# {'coverage_prop': '0.747', 'intensity_prop': '0.483', 'ms1ms2_ratio': '0.212', 'efficiency': '0.487', 'TP': '1800', 'FP': '665', 'FN': '836', 'precision': '0.730', 'recall': '0.683', 'f1': '0.706', 'total_rewards': 847.2955002795185, 'invalid_action_count': 0, 'num_ms1_scans': 1071, 'num_ms2_scans': 5058}
#
# Episode 26 (4916 chemicals)
# steps	 500 	total rewards	 33.480359508680394
# steps	 1000 	total rewards	 124.66254373127353
# steps	 1500 	total rewards	 217.65436885842254
# steps	 2000 	total rewards	 314.90523679883006
# steps	 2500 	total rewards	 405.3338504708408
# steps	 3000 	total rewards	 499.8264672544602
# steps	 3500 	total rewards	 578.5490269455277
# steps	 4000 	total rewards	 645.6881728328689
# steps	 4500 	total rewards	 713.6942634247368
# steps	 5000 	total rewards	 789.9998004801506
# steps	 5500 	total rewards	 851.9911046353927
# steps	 6000 	total rewards	 918.4632260579258
# Finished after 6427 timesteps (39.332579135894775 seconds) with total reward 973.5314678195409
# {'coverage_prop': '0.687', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.137', 'efficiency': '0.597', 'TP': '2427', 'FP': '951', 'FN': '1538', 'precision': '0.718', 'recall': '0.612', 'f1': '0.661', 'total_rewards': 973.5314678195418, 'invalid_action_count': 0, 'num_ms1_scans': 773, 'num_ms2_scans': 5654}
#
# Episode 27 (2655 chemicals)
# steps	 500 	total rewards	 20.946122411109517
# steps	 1000 	total rewards	 102.88690496892211
# steps	 1500 	total rewards	 182.92210636664734
# steps	 2000 	total rewards	 279.0609798851612
# steps	 2500 	total rewards	 370.8764974442345
# steps	 3000 	total rewards	 464.580013417696
# steps	 3500 	total rewards	 542.8577629224218
# steps	 4000 	total rewards	 605.8186616522189
# steps	 4500 	total rewards	 655.5944099885025
# steps	 5000 	total rewards	 716.7777236313693
# steps	 5500 	total rewards	 766.5101172214131
# Finished after 5951 timesteps (151.93454313278198 seconds) with total reward 805.7201696719218
# {'coverage_prop': '0.782', 'intensity_prop': '0.511', 'ms1ms2_ratio': '0.266', 'efficiency': '0.441', 'TP': '1550', 'FP': '525', 'FN': '580', 'precision': '0.747', 'recall': '0.728', 'f1': '0.737', 'total_rewards': 805.7201696719253, 'invalid_action_count': 0, 'num_ms1_scans': 1250, 'num_ms2_scans': 4701}
#
# Episode 28 (4538 chemicals)
# steps	 500 	total rewards	 35.13729597841574
# steps	 1000 	total rewards	 127.58015664994332
# steps	 1500 	total rewards	 219.45998303240356
# steps	 2000 	total rewards	 312.14814863309533
# steps	 2500 	total rewards	 407.7647235210786
# steps	 3000 	total rewards	 503.32241897604854
# steps	 3500 	total rewards	 578.078803014162
# steps	 4000 	total rewards	 648.5888537807327
# steps	 4500 	total rewards	 717.1931771814698
# steps	 5000 	total rewards	 793.4114192775373
# steps	 5500 	total rewards	 862.1131547777188
# steps	 6000 	total rewards	 922.8711251973718
# Finished after 6414 timesteps (41.725812911987305 seconds) with total reward 972.9670484257649
# {'coverage_prop': '0.688', 'intensity_prop': '0.445', 'ms1ms2_ratio': '0.140', 'efficiency': '0.554', 'TP': '2321', 'FP': '799', 'FN': '1418', 'precision': '0.744', 'recall': '0.621', 'f1': '0.677', 'total_rewards': 972.9670484257647, 'invalid_action_count': 0, 'num_ms1_scans': 786, 'num_ms2_scans': 5628}
#
# Episode 29 (3171 chemicals)
# steps	 500 	total rewards	 26.2722619403463
# steps	 1000 	total rewards	 111.92019045219611
# steps	 1500 	total rewards	 196.81452562937366
# steps	 2000 	total rewards	 296.20105079409694
# steps	 2500 	total rewards	 388.81862502509847
# steps	 3000 	total rewards	 475.9871888680429
# steps	 3500 	total rewards	 554.9796887025461
# steps	 4000 	total rewards	 617.0748739916565
# steps	 4500 	total rewards	 673.3262103257193
# steps	 5000 	total rewards	 743.9952081806816
# steps	 5500 	total rewards	 797.3029338662286
# steps	 6000 	total rewards	 856.7548623527033
# Finished after 6138 timesteps (40.191036224365234 seconds) with total reward 868.4996740260642
# {'coverage_prop': '0.758', 'intensity_prop': '0.497', 'ms1ms2_ratio': '0.209', 'efficiency': '0.474', 'TP': '1775', 'FP': '629', 'FN': '767', 'precision': '0.738', 'recall': '0.698', 'f1': '0.718', 'total_rewards': 868.4996740260643, 'invalid_action_count': 0, 'num_ms1_scans': 1062, 'num_ms2_scans': 5076}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (70, 1000),
#   'rt_range': (0, 1440),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (2000, 5000),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f99e2073550>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9a01999c30>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9a019f3190>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (70, 1000)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (0, 1440),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 15,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.418', 'efficiency': '0.499', 'TP': '1450', 'FP': '506', 'FN': '195', 'precision': '0.741', 'recall': '0.881', 'f1': '0.805'}
#
# Episode 1 finished
# {'coverage_prop': '0.801', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.149', 'efficiency': '0.592', 'TP': '2435', 'FP': '846', 'FN': '815', 'precision': '0.742', 'recall': '0.749', 'f1': '0.746'}
#
# Episode 2 finished
# {'coverage_prop': '0.858', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.185', 'efficiency': '0.540', 'TP': '2153', 'FP': '684', 'FN': '470', 'precision': '0.759', 'recall': '0.821', 'f1': '0.789'}
#
# Episode 3 finished
# {'coverage_prop': '0.871', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.214', 'efficiency': '0.518', 'TP': '1985', 'FP': '628', 'FN': '387', 'precision': '0.760', 'recall': '0.837', 'f1': '0.796'}
#
# Episode 4 finished
# {'coverage_prop': '0.804', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.144', 'efficiency': '0.646', 'TP': '2670', 'FP': '941', 'FN': '879', 'precision': '0.739', 'recall': '0.752', 'f1': '0.746'}
#
# Episode 5 finished
# {'coverage_prop': '0.898', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.256', 'efficiency': '0.467', 'TP': '1686', 'FP': '538', 'FN': '253', 'precision': '0.758', 'recall': '0.870', 'f1': '0.810'}
#
# Episode 6 finished
# {'coverage_prop': '0.843', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.182', 'efficiency': '0.528', 'TP': '2089', 'FP': '695', 'FN': '518', 'precision': '0.750', 'recall': '0.801', 'f1': '0.775'}
#
# Episode 7 finished
# {'coverage_prop': '0.904', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.257', 'efficiency': '0.450', 'TP': '1631', 'FP': '511', 'FN': '228', 'precision': '0.761', 'recall': '0.877', 'f1': '0.815'}
#
# Episode 8 finished
# {'coverage_prop': '0.869', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.215', 'efficiency': '0.521', 'TP': '1987', 'FP': '637', 'FN': '397', 'precision': '0.757', 'recall': '0.833', 'f1': '0.794'}
#
# Episode 9 finished
# {'coverage_prop': '0.861', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.193', 'efficiency': '0.506', 'TP': '1984', 'FP': '643', 'FN': '424', 'precision': '0.755', 'recall': '0.824', 'f1': '0.788'}
#
# Episode 10 finished
# {'coverage_prop': '0.779', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.143', 'efficiency': '0.678', 'TP': '2787', 'FP': '1010', 'FN': '1076', 'precision': '0.734', 'recall': '0.721', 'f1': '0.728'}
#
# Episode 11 finished
# {'coverage_prop': '0.823', 'intensity_prop': '0.541', 'ms1ms2_ratio': '0.178', 'efficiency': '0.583', 'TP': '2306', 'FP': '787', 'FN': '663', 'precision': '0.746', 'recall': '0.777', 'f1': '0.761'}
#
# Episode 12 finished
# {'coverage_prop': '0.808', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.141', 'efficiency': '0.705', 'TP': '2979', 'FP': '981', 'FN': '944', 'precision': '0.752', 'recall': '0.759', 'f1': '0.756'}
#
# Episode 13 finished
# {'coverage_prop': '0.851', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.180', 'efficiency': '0.557', 'TP': '2254', 'FP': '691', 'FN': '515', 'precision': '0.765', 'recall': '0.814', 'f1': '0.789'}
#
# Episode 14 finished
# {'coverage_prop': '0.920', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.348', 'efficiency': '0.438', 'TP': '1418', 'FP': '443', 'FN': '162', 'precision': '0.762', 'recall': '0.897', 'f1': '0.824'}
#
# Episode 15 finished
# {'coverage_prop': '0.820', 'intensity_prop': '0.543', 'ms1ms2_ratio': '0.153', 'efficiency': '0.618', 'TP': '2584', 'FP': '821', 'FN': '746', 'precision': '0.759', 'recall': '0.776', 'f1': '0.767'}
#
# Episode 16 finished
# {'coverage_prop': '0.811', 'intensity_prop': '0.532', 'ms1ms2_ratio': '0.144', 'efficiency': '0.627', 'TP': '2611', 'FP': '896', 'FN': '819', 'precision': '0.745', 'recall': '0.761', 'f1': '0.753'}
#
# Episode 17 finished
# {'coverage_prop': '0.820', 'intensity_prop': '0.542', 'ms1ms2_ratio': '0.146', 'efficiency': '0.608', 'TP': '2561', 'FP': '826', 'FN': '744', 'precision': '0.756', 'recall': '0.775', 'f1': '0.765'}
#
# Episode 18 finished
# {'coverage_prop': '0.792', 'intensity_prop': '0.508', 'ms1ms2_ratio': '0.134', 'efficiency': '0.680', 'TP': '2800', 'FP': '1065', 'FN': '1016', 'precision': '0.724', 'recall': '0.734', 'f1': '0.729'}
#
# Episode 19 finished
# {'coverage_prop': '0.840', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.206', 'efficiency': '0.575', 'TP': '2211', 'FP': '722', 'FN': '558', 'precision': '0.754', 'recall': '0.798', 'f1': '0.776'}
#
# Episode 20 finished
# {'coverage_prop': '0.834', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.153', 'efficiency': '0.555', 'TP': '2325', 'FP': '738', 'FN': '611', 'precision': '0.759', 'recall': '0.792', 'f1': '0.775'}
#
# Episode 21 finished
# {'coverage_prop': '0.811', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.141', 'efficiency': '0.606', 'TP': '2507', 'FP': '896', 'FN': '793', 'precision': '0.737', 'recall': '0.760', 'f1': '0.748'}
#
# Episode 22 finished
# {'coverage_prop': '0.884', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.258', 'efficiency': '0.473', 'TP': '1637', 'FP': '610', 'FN': '294', 'precision': '0.729', 'recall': '0.848', 'f1': '0.784'}
#
# Episode 23 finished
# {'coverage_prop': '0.845', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.206', 'efficiency': '0.540', 'TP': '2052', 'FP': '699', 'FN': '503', 'precision': '0.746', 'recall': '0.803', 'f1': '0.773'}
#
# Episode 24 finished
# {'coverage_prop': '0.814', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.142', 'efficiency': '0.632', 'TP': '2621', 'FP': '926', 'FN': '811', 'precision': '0.739', 'recall': '0.764', 'f1': '0.751'}
#
# Episode 25 finished
# {'coverage_prop': '0.859', 'intensity_prop': '0.562', 'ms1ms2_ratio': '0.211', 'efficiency': '0.560', 'TP': '2098', 'FP': '736', 'FN': '467', 'precision': '0.740', 'recall': '0.818', 'f1': '0.777'}
#
# Episode 26 finished
# {'coverage_prop': '0.790', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.137', 'efficiency': '0.687', 'TP': '2828', 'FP': '1056', 'FN': '1032', 'precision': '0.728', 'recall': '0.733', 'f1': '0.730'}
#
# Episode 27 finished
# {'coverage_prop': '0.888', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.265', 'efficiency': '0.501', 'TP': '1773', 'FP': '585', 'FN': '297', 'precision': '0.752', 'recall': '0.857', 'f1': '0.801'}
#
# Episode 28 finished
# {'coverage_prop': '0.796', 'intensity_prop': '0.519', 'ms1ms2_ratio': '0.140', 'efficiency': '0.642', 'TP': '2714', 'FP': '897', 'FN': '927', 'precision': '0.752', 'recall': '0.745', 'f1': '0.748'}
#
# Episode 29 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.209', 'efficiency': '0.536', 'TP': '2034', 'FP': '684', 'FN': '453', 'precision': '0.748', 'recall': '0.818', 'f1': '0.782'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (15, 15, 2, 0.5, 5)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.890', 'efficiency': '0.787', 'TP': '1525', 'FP': '513', 'FN': '113', 'precision': '0.748', 'recall': '0.931', 'f1': '0.830'}
#
# Episode 1 finished
# {'coverage_prop': '0.867', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.448', 'efficiency': '0.936', 'TP': '2605', 'FP': '947', 'FN': '544', 'precision': '0.733', 'recall': '0.827', 'f1': '0.777'}
#
# Episode 2 finished
# {'coverage_prop': '0.907', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.561', 'efficiency': '0.884', 'TP': '2266', 'FP': '732', 'FN': '309', 'precision': '0.756', 'recall': '0.880', 'f1': '0.813'}
#
# Episode 3 finished
# {'coverage_prop': '0.925', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.609', 'efficiency': '0.855', 'TP': '2077', 'FP': '699', 'FN': '224', 'precision': '0.748', 'recall': '0.903', 'f1': '0.818'}
#
# Episode 4 finished
# {'coverage_prop': '0.869', 'intensity_prop': '0.568', 'ms1ms2_ratio': '0.415', 'efficiency': '0.992', 'TP': '2908', 'FP': '994', 'FN': '588', 'precision': '0.745', 'recall': '0.832', 'f1': '0.786'}
#
# Episode 5 finished
# {'coverage_prop': '0.927', 'intensity_prop': '0.607', 'ms1ms2_ratio': '0.741', 'efficiency': '0.791', 'TP': '1693', 'FP': '603', 'FN': '181', 'precision': '0.737', 'recall': '0.903', 'f1': '0.812'}
#
# Episode 6 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.550', 'efficiency': '0.875', 'TP': '2254', 'FP': '747', 'FN': '301', 'precision': '0.751', 'recall': '0.882', 'f1': '0.811'}
#
# Episode 7 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.626', 'ms1ms2_ratio': '0.757', 'efficiency': '0.785', 'TP': '1669', 'FP': '578', 'FN': '123', 'precision': '0.743', 'recall': '0.931', 'f1': '0.826'}
#
# Episode 8 finished
# {'coverage_prop': '0.918', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.608', 'efficiency': '0.853', 'TP': '2044', 'FP': '730', 'FN': '247', 'precision': '0.737', 'recall': '0.892', 'f1': '0.807'}
#
# Episode 9 finished
# {'coverage_prop': '0.915', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.598', 'efficiency': '0.851', 'TP': '2111', 'FP': '681', 'FN': '259', 'precision': '0.756', 'recall': '0.891', 'f1': '0.818'}
#
# Episode 10 finished
# {'coverage_prop': '0.853', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.365', 'efficiency': '0.999', 'TP': '3081', 'FP': '1076', 'FN': '716', 'precision': '0.741', 'recall': '0.811', 'f1': '0.775'}
#
# Episode 11 finished
# {'coverage_prop': '0.880', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.499', 'efficiency': '0.917', 'TP': '2483', 'FP': '821', 'FN': '452', 'precision': '0.752', 'recall': '0.846', 'f1': '0.796'}
#
# Episode 12 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.565', 'ms1ms2_ratio': '0.365', 'efficiency': '1.021', 'TP': '3155', 'FP': '1091', 'FN': '658', 'precision': '0.743', 'recall': '0.827', 'f1': '0.783'}
#
# Episode 13 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.597', 'ms1ms2_ratio': '0.530', 'efficiency': '0.900', 'TP': '2320', 'FP': '825', 'FN': '315', 'precision': '0.738', 'recall': '0.880', 'f1': '0.803'}
#
# Episode 14 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.943', 'efficiency': '0.773', 'TP': '1397', 'FP': '532', 'FN': '94', 'precision': '0.724', 'recall': '0.937', 'f1': '0.817'}
#
# Episode 15 finished
# {'coverage_prop': '0.881', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.422', 'efficiency': '0.937', 'TP': '2728', 'FP': '930', 'FN': '493', 'precision': '0.746', 'recall': '0.847', 'f1': '0.793'}
#
# Episode 16 finished
# {'coverage_prop': '0.867', 'intensity_prop': '0.566', 'ms1ms2_ratio': '0.410', 'efficiency': '0.948', 'TP': '2791', 'FP': '960', 'FN': '575', 'precision': '0.744', 'recall': '0.829', 'f1': '0.784'}
#
# Episode 17 finished
# {'coverage_prop': '0.884', 'intensity_prop': '0.583', 'ms1ms2_ratio': '0.426', 'efficiency': '0.940', 'TP': '2727', 'FP': '924', 'FN': '480', 'precision': '0.747', 'recall': '0.850', 'f1': '0.795'}
#
# Episode 18 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.363', 'efficiency': '1.003', 'TP': '3038', 'FP': '1146', 'FN': '697', 'precision': '0.726', 'recall': '0.813', 'f1': '0.767'}
#
# Episode 19 finished
# {'coverage_prop': '0.901', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.515', 'efficiency': '0.886', 'TP': '2347', 'FP': '798', 'FN': '346', 'precision': '0.746', 'recall': '0.872', 'f1': '0.804'}
#
# Episode 20 finished
# {'coverage_prop': '0.904', 'intensity_prop': '0.593', 'ms1ms2_ratio': '0.488', 'efficiency': '0.912', 'TP': '2473', 'FP': '847', 'FN': '354', 'precision': '0.745', 'recall': '0.875', 'f1': '0.805'}
#
# Episode 21 finished
# {'coverage_prop': '0.875', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.423', 'efficiency': '0.942', 'TP': '2724', 'FP': '949', 'FN': '523', 'precision': '0.742', 'recall': '0.839', 'f1': '0.787'}
#
# Episode 22 finished
# {'coverage_prop': '0.934', 'intensity_prop': '0.609', 'ms1ms2_ratio': '0.717', 'efficiency': '0.803', 'TP': '1756', 'FP': '618', 'FN': '167', 'precision': '0.740', 'recall': '0.913', 'f1': '0.817'}
#
# Episode 23 finished
# {'coverage_prop': '0.911', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.563', 'efficiency': '0.875', 'TP': '2240', 'FP': '723', 'FN': '291', 'precision': '0.756', 'recall': '0.885', 'f1': '0.815'}
#
# Episode 24 finished
# {'coverage_prop': '0.875', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.403', 'efficiency': '0.957', 'TP': '2805', 'FP': '1010', 'FN': '543', 'precision': '0.735', 'recall': '0.838', 'f1': '0.783'}
#
# Episode 25 finished
# {'coverage_prop': '0.915', 'intensity_prop': '0.603', 'ms1ms2_ratio': '0.534', 'efficiency': '0.868', 'TP': '2259', 'FP': '763', 'FN': '279', 'precision': '0.748', 'recall': '0.890', 'f1': '0.813'}
#
# Episode 26 finished
# {'coverage_prop': '0.859', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.370', 'efficiency': '1.020', 'TP': '3104', 'FP': '1117', 'FN': '695', 'precision': '0.735', 'recall': '0.817', 'f1': '0.774'}
#
# Episode 27 finished
# {'coverage_prop': '0.930', 'intensity_prop': '0.615', 'ms1ms2_ratio': '0.676', 'efficiency': '0.806', 'TP': '1845', 'FP': '623', 'FN': '187', 'precision': '0.748', 'recall': '0.908', 'f1': '0.820'}
#
# Episode 28 finished
# {'coverage_prop': '0.869', 'intensity_prop': '0.568', 'ms1ms2_ratio': '0.381', 'efficiency': '0.966', 'TP': '2942', 'FP': '1003', 'FN': '593', 'precision': '0.746', 'recall': '0.832', 'f1': '0.787'}
#
# Episode 29 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.563', 'efficiency': '0.858', 'TP': '2172', 'FP': '733', 'FN': '266', 'precision': '0.748', 'recall': '0.891', 'f1': '0.813'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.122', 'efficiency': '0.353', 'TP': '1735', 'FP': '312', 'FN': '104', 'precision': '0.848', 'recall': '0.943', 'f1': '0.893'}
#
# Episode 1 finished
# {'coverage_prop': '0.870', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.113', 'efficiency': '0.608', 'TP': '2697', 'FP': '868', 'FN': '531', 'precision': '0.757', 'recall': '0.836', 'f1': '0.794'}
#
# Episode 2 finished
# {'coverage_prop': '0.917', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.113', 'efficiency': '0.516', 'TP': '2422', 'FP': '610', 'FN': '275', 'precision': '0.799', 'recall': '0.898', 'f1': '0.846'}
#
# Episode 3 finished
# {'coverage_prop': '0.930', 'intensity_prop': '0.650', 'ms1ms2_ratio': '0.103', 'efficiency': '0.467', 'TP': '2265', 'FP': '525', 'FN': '210', 'precision': '0.812', 'recall': '0.915', 'f1': '0.860'}
#
# Episode 4 finished
# {'coverage_prop': '0.874', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.099', 'efficiency': '0.653', 'TP': '2954', 'FP': '971', 'FN': '565', 'precision': '0.753', 'recall': '0.839', 'f1': '0.794'}
#
# Episode 5 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.656', 'ms1ms2_ratio': '0.122', 'efficiency': '0.403', 'TP': '1894', 'FP': '436', 'FN': '147', 'precision': '0.813', 'recall': '0.928', 'f1': '0.867'}
#
# Episode 6 finished
# {'coverage_prop': '0.910', 'intensity_prop': '0.626', 'ms1ms2_ratio': '0.114', 'efficiency': '0.512', 'TP': '2387', 'FP': '617', 'FN': '298', 'precision': '0.795', 'recall': '0.889', 'f1': '0.839'}
#
# Episode 7 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.676', 'ms1ms2_ratio': '0.123', 'efficiency': '0.391', 'TP': '1888', 'FP': '370', 'FN': '112', 'precision': '0.836', 'recall': '0.944', 'f1': '0.887'}
#
# Episode 8 finished
# {'coverage_prop': '0.931', 'intensity_prop': '0.639', 'ms1ms2_ratio': '0.116', 'efficiency': '0.481', 'TP': '2231', 'FP': '581', 'FN': '209', 'precision': '0.793', 'recall': '0.914', 'f1': '0.850'}
#
# Episode 9 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.641', 'ms1ms2_ratio': '0.110', 'efficiency': '0.476', 'TP': '2268', 'FP': '543', 'FN': '240', 'precision': '0.807', 'recall': '0.904', 'f1': '0.853'}
#
# Episode 10 finished
# {'coverage_prop': '0.849', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.104', 'efficiency': '0.694', 'TP': '3110', 'FP': '1026', 'FN': '737', 'precision': '0.752', 'recall': '0.808', 'f1': '0.779'}
#
# Episode 11 finished
# {'coverage_prop': '0.886', 'intensity_prop': '0.605', 'ms1ms2_ratio': '0.098', 'efficiency': '0.553', 'TP': '2610', 'FP': '717', 'FN': '429', 'precision': '0.784', 'recall': '0.859', 'f1': '0.820'}
#
# Episode 12 finished
# {'coverage_prop': '0.872', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.099', 'efficiency': '0.712', 'TP': '3200', 'FP': '1074', 'FN': '630', 'precision': '0.749', 'recall': '0.836', 'f1': '0.790'}
#
# Episode 13 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.105', 'efficiency': '0.529', 'TP': '2470', 'FP': '675', 'FN': '315', 'precision': '0.785', 'recall': '0.887', 'f1': '0.833'}
#
# Episode 14 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.134', 'efficiency': '0.342', 'TP': '1644', 'FP': '298', 'FN': '81', 'precision': '0.847', 'recall': '0.953', 'f1': '0.897'}
#
# Episode 15 finished
# {'coverage_prop': '0.880', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.108', 'efficiency': '0.617', 'TP': '2811', 'FP': '843', 'FN': '497', 'precision': '0.769', 'recall': '0.850', 'f1': '0.808'}
#
# Episode 16 finished
# {'coverage_prop': '0.868', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.104', 'efficiency': '0.630', 'TP': '2859', 'FP': '897', 'FN': '570', 'precision': '0.761', 'recall': '0.834', 'f1': '0.796'}
#
# Episode 17 finished
# {'coverage_prop': '0.884', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.113', 'efficiency': '0.622', 'TP': '2752', 'FP': '899', 'FN': '480', 'precision': '0.754', 'recall': '0.851', 'f1': '0.800'}
#
# Episode 18 finished
# {'coverage_prop': '0.849', 'intensity_prop': '0.550', 'ms1ms2_ratio': '0.088', 'efficiency': '0.677', 'TP': '3042', 'FP': '1102', 'FN': '737', 'precision': '0.734', 'recall': '0.805', 'f1': '0.768'}
#
# Episode 19 finished
# {'coverage_prop': '0.897', 'intensity_prop': '0.615', 'ms1ms2_ratio': '0.108', 'efficiency': '0.529', 'TP': '2500', 'FP': '633', 'FN': '358', 'precision': '0.798', 'recall': '0.875', 'f1': '0.835'}
#
# Episode 20 finished
# {'coverage_prop': '0.902', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.109', 'efficiency': '0.561', 'TP': '2530', 'FP': '784', 'FN': '360', 'precision': '0.763', 'recall': '0.875', 'f1': '0.816'}
#
# Episode 21 finished
# {'coverage_prop': '0.877', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.094', 'efficiency': '0.607', 'TP': '2777', 'FP': '902', 'FN': '517', 'precision': '0.755', 'recall': '0.843', 'f1': '0.797'}
#
# Episode 22 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.657', 'ms1ms2_ratio': '0.112', 'efficiency': '0.408', 'TP': '1930', 'FP': '469', 'FN': '142', 'precision': '0.805', 'recall': '0.931', 'f1': '0.863'}
#
# Episode 23 finished
# {'coverage_prop': '0.912', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.112', 'efficiency': '0.505', 'TP': '2356', 'FP': '611', 'FN': '287', 'precision': '0.794', 'recall': '0.891', 'f1': '0.840'}
#
# Episode 24 finished
# {'coverage_prop': '0.885', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.092', 'efficiency': '0.635', 'TP': '2867', 'FP': '990', 'FN': '501', 'precision': '0.743', 'recall': '0.851', 'f1': '0.794'}
#
# Episode 25 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.627', 'ms1ms2_ratio': '0.107', 'efficiency': '0.510', 'TP': '2386', 'FP': '638', 'FN': '277', 'precision': '0.789', 'recall': '0.896', 'f1': '0.839'}
#
# Episode 26 finished
# {'coverage_prop': '0.860', 'intensity_prop': '0.561', 'ms1ms2_ratio': '0.093', 'efficiency': '0.697', 'TP': '3127', 'FP': '1103', 'FN': '686', 'precision': '0.739', 'recall': '0.820', 'f1': '0.778'}
#
# Episode 27 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.659', 'ms1ms2_ratio': '0.119', 'efficiency': '0.429', 'TP': '2041', 'FP': '455', 'FN': '159', 'precision': '0.818', 'recall': '0.928', 'f1': '0.869'}
#
# Episode 28 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.095', 'efficiency': '0.650', 'TP': '2972', 'FP': '956', 'FN': '610', 'precision': '0.757', 'recall': '0.830', 'f1': '0.791'}
#
# Episode 29 finished
# {'coverage_prop': '0.918', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.112', 'efficiency': '0.495', 'TP': '2314', 'FP': '598', 'FN': '259', 'precision': '0.795', 'recall': '0.899', 'f1': '0.844'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     864.088181                   0.0          0.751           0.491
# 1  random     964.453108                   0.0          0.678           0.386
# 2  random     971.228676                   0.0          0.703           0.414
# 3  random     943.557121                   0.0          0.734           0.437
# 4  random    1007.632283                   0.0          0.673           0.381
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.099       0.269      0.736   0.690  0.712
# 1          0.063       0.434      0.609   0.562  0.585
# 2          0.066       0.365      0.634   0.601  0.617
# 3          0.066       0.346      0.654   0.644  0.649
# 4          0.055       0.466      0.619   0.561  0.588

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'DQN'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'DQN']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     864.088181                   0.0          0.751           0.491
# 1  random     964.453108                   0.0          0.678           0.386
# 2  random     971.228676                   0.0          0.703           0.414
# 3  random     943.557121                   0.0          0.734           0.437
# 4  random    1007.632283                   0.0          0.673           0.381
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.099       0.269      0.736   0.690  0.712
# 1          0.063       0.434      0.609   0.562  0.585
# 2          0.066       0.365      0.634   0.601  0.617
# 3          0.066       0.346      0.654   0.644  0.649
# 4          0.055       0.466      0.619   0.561  0.588

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
