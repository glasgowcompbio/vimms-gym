# %% [markdown]
# # Evaluation using QCB chemicals (large)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_large

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_large(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-04-05 23:55:43.703 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_large_extracted.p
# ({'chemical_creator': {'mz_range': (70, 1000),
#    'rt_range': (0, 1440),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (2000, 5000),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f987086f0d0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f98708f2020>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f987094f580>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (70, 1000)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (0, 1440),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  100)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5

dqn_in_dir = 'DQN_10.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_10.0E6'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 15
topN_rt_tol = 15
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 240
weighteddew_N = 15

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_large.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 2151
# 4096
# 3307
# 3000
# 4490
# 2477
# 3302
# 2370
# 3021
# 3051
# 4873
# 3756
# 4904
# 3460
# 2023
# 4151
# 4326
# 4131
# 4881
# 3491
# 3674
# 4196
# 2541
# 3254
# 4358
# 3301
# 4916
# 2655
# 4538
# 3171

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (70, 1000),
#  'rt_range': (0, 1440),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (2000, 5000),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f987086f0d0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f98708f2020>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f987094f580>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (70, 1000),
#   'rt_range': (0, 1440),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (2000, 5000),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f987086f0d0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f98708f2020>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f987094f580>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (70, 1000)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (0, 1440),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 1
out_dir = 'evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E5_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 100 N = 0 rt_tol = 5
#
#
# Episode 0 (2151 chemicals)
# steps	 500 	total rewards	 42.34707721168558
# steps	 1000 	total rewards	 107.95326314449254
# steps	 1500 	total rewards	 179.77363970541325
# steps	 2000 	total rewards	 255.66084181150921
# steps	 2500 	total rewards	 336.83490834407337
# steps	 3000 	total rewards	 422.9751071608089
# steps	 3500 	total rewards	 495.57526955799835
# steps	 4000 	total rewards	 554.5891922010785
# steps	 4500 	total rewards	 608.9859348747661
# steps	 5000 	total rewards	 667.4574677464858
# steps	 5500 	total rewards	 729.6000762856636
# steps	 6000 	total rewards	 787.296720133433
# steps	 6500 	total rewards	 840.9604874699793
# Finished after 6616 timesteps (9.259168863296509 seconds) with total reward 851.499567672495
# {'coverage_prop': '0.748', 'intensity_prop': '0.474', 'ms1ms2_ratio': '0.097', 'efficiency': '0.267', 'TP': '1138', 'FP': '471', 'FN': '542', 'precision': '0.707', 'recall': '0.677', 'f1': '0.692', 'total_rewards': 851.4995676724978, 'invalid_action_count': 0, 'num_ms1_scans': 584, 'num_ms2_scans': 6032}
#
# Episode 1 (4096 chemicals)
# steps	 500 	total rewards	 50.297843716929236
# steps	 1000 	total rewards	 124.11723108127238
# steps	 1500 	total rewards	 208.38725329581672
# steps	 2000 	total rewards	 294.5540097601403
# steps	 2500 	total rewards	 385.9982717273476
# steps	 3000 	total rewards	 477.1025371636882
# steps	 3500 	total rewards	 563.935518247117
# steps	 4000 	total rewards	 629.5780386582946
# steps	 4500 	total rewards	 692.0647872659895
# steps	 5000 	total rewards	 751.528235867335
# steps	 5500 	total rewards	 816.9762331123281
# steps	 6000 	total rewards	 874.5566198328304
# steps	 6500 	total rewards	 937.1159922482622
# Finished after 6814 timesteps (12.260329961776733 seconds) with total reward 972.7311847227915
# {'coverage_prop': '0.680', 'intensity_prop': '0.392', 'ms1ms2_ratio': '0.060', 'efficiency': '0.433', 'TP': '1741', 'FP': '1043', 'FN': '1312', 'precision': '0.625', 'recall': '0.570', 'f1': '0.597', 'total_rewards': 972.7311847227908, 'invalid_action_count': 0, 'num_ms1_scans': 386, 'num_ms2_scans': 6428}
#
# Episode 2 (3307 chemicals)
# steps	 500 	total rewards	 48.90592888079921
# steps	 1000 	total rewards	 123.70875267501502
# steps	 1500 	total rewards	 208.8186099846176
# steps	 2000 	total rewards	 287.34489629519516
# steps	 2500 	total rewards	 367.41399107408216
# steps	 3000 	total rewards	 459.38231997380933
# steps	 3500 	total rewards	 541.1910227508647
# steps	 4000 	total rewards	 613.9554089999987
# steps	 4500 	total rewards	 679.7398473961792
# steps	 5000 	total rewards	 744.1502920480123
# steps	 5500 	total rewards	 808.1294538478119
# steps	 6000 	total rewards	 873.525115546378
# steps	 6500 	total rewards	 936.2693539716764
# Finished after 6786 timesteps (8.655380964279175 seconds) with total reward 968.6662276952457
# {'coverage_prop': '0.702', 'intensity_prop': '0.413', 'ms1ms2_ratio': '0.065', 'efficiency': '0.365', 'TP': '1505', 'FP': '818', 'FN': '984', 'precision': '0.648', 'recall': '0.605', 'f1': '0.626', 'total_rewards': 968.6662276952436, 'invalid_action_count': 0, 'num_ms1_scans': 414, 'num_ms2_scans': 6372}
#
# Episode 3 (3000 chemicals)
# steps	 500 	total rewards	 48.37930913663092
# steps	 1000 	total rewards	 120.71529487904942
# steps	 1500 	total rewards	 207.1031479053378
# steps	 2000 	total rewards	 290.93292063804745
# steps	 2500 	total rewards	 374.9399365253749
# steps	 3000 	total rewards	 471.490308305227
# steps	 3500 	total rewards	 547.5521917922149
# steps	 4000 	total rewards	 612.1930337684735
# steps	 4500 	total rewards	 673.6277368060037
# steps	 5000 	total rewards	 735.7286333179771
# steps	 5500 	total rewards	 801.4319941912802
# steps	 6000 	total rewards	 856.9434896596957
# steps	 6500 	total rewards	 914.0894572962796
# Finished after 6787 timesteps (11.050519943237305 seconds) with total reward 946.4556062724148
# {'coverage_prop': '0.723', 'intensity_prop': '0.445', 'ms1ms2_ratio': '0.065', 'efficiency': '0.340', 'TP': '1464', 'FP': '706', 'FN': '830', 'precision': '0.675', 'recall': '0.638', 'f1': '0.656', 'total_rewards': 946.4556062724165, 'invalid_action_count': 0, 'num_ms1_scans': 413, 'num_ms2_scans': 6374}
#
# Episode 4 (4490 chemicals)
# steps	 500 	total rewards	 56.99070452019782
# steps	 1000 	total rewards	 124.97503746604369
# steps	 1500 	total rewards	 209.67982406214497
# steps	 2000 	total rewards	 297.10230337912526
# steps	 2500 	total rewards	 387.0991414872225
# steps	 3000 	total rewards	 473.53513223856015
# steps	 3500 	total rewards	 563.1574209223503
# steps	 4000 	total rewards	 642.5250588828344
# steps	 4500 	total rewards	 710.9993504253579
# steps	 5000 	total rewards	 776.2906854209502
# steps	 5500 	total rewards	 839.7440505347209
# steps	 6000 	total rewards	 902.7954622152896
# steps	 6500 	total rewards	 964.3561380301376
# Finished after 6846 timesteps (10.587360858917236 seconds) with total reward 1004.923250910209
# {'coverage_prop': '0.665', 'intensity_prop': '0.377', 'ms1ms2_ratio': '0.055', 'efficiency': '0.460', 'TP': '1838', 'FP': '1147', 'FN': '1505', 'precision': '0.616', 'recall': '0.550', 'f1': '0.581', 'total_rewards': 1004.9232509102076, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 6491}
#
# Episode 5 (2477 chemicals)
# steps	 500 	total rewards	 45.35688355254272
# steps	 1000 	total rewards	 110.18486871481586
# steps	 1500 	total rewards	 187.76058337742995
# steps	 2000 	total rewards	 266.08812215762026
# steps	 2500 	total rewards	 350.1921902911638
# steps	 3000 	total rewards	 441.4771022291915
# steps	 3500 	total rewards	 519.3756310692281
# steps	 4000 	total rewards	 579.459829372166
# steps	 4500 	total rewards	 631.4431355095027
# steps	 5000 	total rewards	 683.0706183478217
# steps	 5500 	total rewards	 745.0986275984687
# steps	 6000 	total rewards	 797.8167856489281
# steps	 6500 	total rewards	 851.8548669783911
# Finished after 6727 timesteps (11.142539739608765 seconds) with total reward 876.6545698072334
# {'coverage_prop': '0.735', 'intensity_prop': '0.455', 'ms1ms2_ratio': '0.076', 'efficiency': '0.291', 'TP': '1243', 'FP': '578', 'FN': '656', 'precision': '0.683', 'recall': '0.655', 'f1': '0.668', 'total_rewards': 876.6545698072332, 'invalid_action_count': 0, 'num_ms1_scans': 473, 'num_ms2_scans': 6254}
#
# Episode 6 (3302 chemicals)
# steps	 500 	total rewards	 40.62436015665409
# steps	 1000 	total rewards	 103.35491546110856
# steps	 1500 	total rewards	 185.6625535133442
# steps	 2000 	total rewards	 261.77228282719636
# steps	 2500 	total rewards	 343.78219550671224
# steps	 3000 	total rewards	 438.83939491100375
# steps	 3500 	total rewards	 517.5016537317978
# steps	 4000 	total rewards	 586.8397111789562
# steps	 4500 	total rewards	 651.4909411514268
# steps	 5000 	total rewards	 713.4459228637123
# steps	 5500 	total rewards	 778.7953807792287
# steps	 6000 	total rewards	 836.8383926355202
# steps	 6500 	total rewards	 893.4068212392709
# Finished after 6800 timesteps (8.831907033920288 seconds) with total reward 929.5620899975854
# {'coverage_prop': '0.688', 'intensity_prop': '0.402', 'ms1ms2_ratio': '0.062', 'efficiency': '0.355', 'TP': '1446', 'FP': '826', 'FN': '1030', 'precision': '0.636', 'recall': '0.584', 'f1': '0.609', 'total_rewards': 929.5620899975855, 'invalid_action_count': 0, 'num_ms1_scans': 400, 'num_ms2_scans': 6400}
#
# Episode 7 (2370 chemicals)
# steps	 500 	total rewards	 35.28531895346114
# steps	 1000 	total rewards	 90.21403961122483
# steps	 1500 	total rewards	 167.06016622520642
# steps	 2000 	total rewards	 241.37993457112367
# steps	 2500 	total rewards	 325.6323259662781
# steps	 3000 	total rewards	 418.7061896547037
# steps	 3500 	total rewards	 497.63123149914964
# steps	 4000 	total rewards	 564.3502905388671
# steps	 4500 	total rewards	 626.1839869638394
# steps	 5000 	total rewards	 686.0572645745717
# steps	 5500 	total rewards	 756.024831640638
# steps	 6000 	total rewards	 815.4867987953216
# steps	 6500 	total rewards	 875.8423356533333
# Finished after 6720 timesteps (11.565040826797485 seconds) with total reward 901.672007127875
# {'coverage_prop': '0.754', 'intensity_prop': '0.460', 'ms1ms2_ratio': '0.077', 'efficiency': '0.287', 'TP': '1190', 'FP': '598', 'FN': '582', 'precision': '0.666', 'recall': '0.672', 'f1': '0.669', 'total_rewards': 901.6720071278754, 'invalid_action_count': 0, 'num_ms1_scans': 480, 'num_ms2_scans': 6240}
#
# Episode 8 (3021 chemicals)
# steps	 500 	total rewards	 47.16153104917568
# steps	 1000 	total rewards	 110.82437182355424
# steps	 1500 	total rewards	 189.21333395672588
# steps	 2000 	total rewards	 267.5938773801766
# steps	 2500 	total rewards	 359.45370626155596
# steps	 3000 	total rewards	 449.99010715740667
# steps	 3500 	total rewards	 530.1594448536176
# steps	 4000 	total rewards	 601.1414315808606
# steps	 4500 	total rewards	 662.9188692859842
# steps	 5000 	total rewards	 724.7251373697532
# steps	 5500 	total rewards	 793.5635283851334
# steps	 6000 	total rewards	 854.2214324421151
# steps	 6500 	total rewards	 914.4898028470751
# Finished after 6765 timesteps (8.506585836410522 seconds) with total reward 945.4179430663204
# {'coverage_prop': '0.720', 'intensity_prop': '0.428', 'ms1ms2_ratio': '0.069', 'efficiency': '0.343', 'TP': '1410', 'FP': '764', 'FN': '847', 'precision': '0.649', 'recall': '0.625', 'f1': '0.636', 'total_rewards': 945.4179430663181, 'invalid_action_count': 0, 'num_ms1_scans': 435, 'num_ms2_scans': 6330}
#
# Episode 9 (3051 chemicals)
# steps	 500 	total rewards	 54.605401226982416
# steps	 1000 	total rewards	 127.33774547020823
# steps	 1500 	total rewards	 206.8831509243642
# steps	 2000 	total rewards	 282.35338956672325
# steps	 2500 	total rewards	 372.34400965574434
# steps	 3000 	total rewards	 462.80253357379024
# steps	 3500 	total rewards	 548.7728603141461
# steps	 4000 	total rewards	 616.8971989281008
# steps	 4500 	total rewards	 681.0789913441745
# steps	 5000 	total rewards	 745.3706254224148
# steps	 5500 	total rewards	 810.8046753165149
# steps	 6000 	total rewards	 869.232690345721
# steps	 6500 	total rewards	 931.5368254029438
# Finished after 6787 timesteps (14.293386936187744 seconds) with total reward 959.3364303015301
# {'coverage_prop': '0.717', 'intensity_prop': '0.429', 'ms1ms2_ratio': '0.065', 'efficiency': '0.343', 'TP': '1425', 'FP': '764', 'FN': '862', 'precision': '0.651', 'recall': '0.623', 'f1': '0.637', 'total_rewards': 959.3364303015308, 'invalid_action_count': 0, 'num_ms1_scans': 413, 'num_ms2_scans': 6374}
#
# Episode 10 (4873 chemicals)
# steps	 500 	total rewards	 50.60436783482878
# steps	 1000 	total rewards	 125.96063578492941
# steps	 1500 	total rewards	 214.75581909815654
# steps	 2000 	total rewards	 293.17278650085956
# steps	 2500 	total rewards	 380.4752436061134
# steps	 3000 	total rewards	 483.1935626230928
# steps	 3500 	total rewards	 575.1962678159524
# steps	 4000 	total rewards	 651.5159443486803
# steps	 4500 	total rewards	 720.9128869741108
# steps	 5000 	total rewards	 782.9165952372655
# steps	 5500 	total rewards	 851.6446422882408
# steps	 6000 	total rewards	 918.2541551338883
# steps	 6500 	total rewards	 979.1649342426126
# Finished after 6848 timesteps (11.406322956085205 seconds) with total reward 1018.7139453868613
# {'coverage_prop': '0.664', 'intensity_prop': '0.361', 'ms1ms2_ratio': '0.054', 'efficiency': '0.498', 'TP': '1870', 'FP': '1366', 'FN': '1637', 'precision': '0.578', 'recall': '0.533', 'f1': '0.555', 'total_rewards': 1018.7139453868613, 'invalid_action_count': 0, 'num_ms1_scans': 352, 'num_ms2_scans': 6496}
#
# Episode 11 (3756 chemicals)
# steps	 500 	total rewards	 51.735617847711474
# steps	 1000 	total rewards	 116.57861963320636
# steps	 1500 	total rewards	 199.13050154885272
# steps	 2000 	total rewards	 274.5116571014761
# steps	 2500 	total rewards	 364.5762519371579
# steps	 3000 	total rewards	 461.5912452987867
# steps	 3500 	total rewards	 550.3700461837129
# steps	 4000 	total rewards	 625.078581651129
# steps	 4500 	total rewards	 692.9083802273819
# steps	 5000 	total rewards	 763.2881607231877
# steps	 5500 	total rewards	 828.5302868656356
# steps	 6000 	total rewards	 889.2267348872176
# steps	 6500 	total rewards	 954.9527687401761
# Finished after 6838 timesteps (15.268857955932617 seconds) with total reward 995.5895332286318
# {'coverage_prop': '0.699', 'intensity_prop': '0.402', 'ms1ms2_ratio': '0.056', 'efficiency': '0.405', 'TP': '1628', 'FP': '997', 'FN': '1131', 'precision': '0.620', 'recall': '0.590', 'f1': '0.605', 'total_rewards': 995.589533228633, 'invalid_action_count': 0, 'num_ms1_scans': 362, 'num_ms2_scans': 6476}
#
# Episode 12 (4904 chemicals)
# steps	 500 	total rewards	 57.668501450252506
# steps	 1000 	total rewards	 134.7245855355738
# steps	 1500 	total rewards	 216.94144090709364
# steps	 2000 	total rewards	 299.3608664312286
# steps	 2500 	total rewards	 392.11084033021257
# steps	 3000 	total rewards	 488.56107098353596
# steps	 3500 	total rewards	 574.7042582831195
# steps	 4000 	total rewards	 656.5198246450663
# steps	 4500 	total rewards	 724.1351870752055
# steps	 5000 	total rewards	 786.3033485795722
# steps	 5500 	total rewards	 857.4150387765683
# steps	 6000 	total rewards	 920.7319415273441
# steps	 6500 	total rewards	 988.1080524702711
# Finished after 6875 timesteps (11.169157028198242 seconds) with total reward 1035.569100631917
# {'coverage_prop': '0.657', 'intensity_prop': '0.372', 'ms1ms2_ratio': '0.050', 'efficiency': '0.492', 'TP': '1969', 'FP': '1255', 'FN': '1680', 'precision': '0.611', 'recall': '0.540', 'f1': '0.573', 'total_rewards': 1035.5691006319178, 'invalid_action_count': 0, 'num_ms1_scans': 325, 'num_ms2_scans': 6550}
#
# Episode 13 (3460 chemicals)
# steps	 500 	total rewards	 51.442609406459454
# steps	 1000 	total rewards	 118.69538293401206
# steps	 1500 	total rewards	 204.39717356420448
# steps	 2000 	total rewards	 277.8120901524806
# steps	 2500 	total rewards	 370.23340792311876
# steps	 3000 	total rewards	 463.29961495987436
# steps	 3500 	total rewards	 549.4254343077552
# steps	 4000 	total rewards	 626.3873479628892
# steps	 4500 	total rewards	 691.1549018882644
# steps	 5000 	total rewards	 754.3740005205723
# steps	 5500 	total rewards	 825.1720942598231
# steps	 6000 	total rewards	 886.83013351825
# steps	 6500 	total rewards	 951.9843349628909
# Finished after 6803 timesteps (8.921078205108643 seconds) with total reward 989.5365585570739
# {'coverage_prop': '0.704', 'intensity_prop': '0.399', 'ms1ms2_ratio': '0.062', 'efficiency': '0.380', 'TP': '1483', 'FP': '952', 'FN': '1025', 'precision': '0.609', 'recall': '0.591', 'f1': '0.600', 'total_rewards': 989.5365585570712, 'invalid_action_count': 0, 'num_ms1_scans': 397, 'num_ms2_scans': 6406}
#
# Episode 14 (2023 chemicals)
# steps	 500 	total rewards	 35.67449503462402
# steps	 1000 	total rewards	 101.4049037246442
# steps	 1500 	total rewards	 174.7558036153708
# steps	 2000 	total rewards	 252.08594580354082
# steps	 2500 	total rewards	 335.1992571718889
# steps	 3000 	total rewards	 423.6959337334746
# steps	 3500 	total rewards	 501.8854416958093
# steps	 4000 	total rewards	 571.1690271779178
# steps	 4500 	total rewards	 634.3749123799763
# steps	 5000 	total rewards	 699.0927531815477
# steps	 5500 	total rewards	 765.7375022239269
# steps	 6000 	total rewards	 821.6473171239278
# steps	 6500 	total rewards	 877.2235139680981
# Finished after 6625 timesteps (7.462875843048096 seconds) with total reward 890.2059618709284
# {'coverage_prop': '0.766', 'intensity_prop': '0.486', 'ms1ms2_ratio': '0.095', 'efficiency': '0.256', 'TP': '1091', 'FP': '458', 'FN': '474', 'precision': '0.704', 'recall': '0.697', 'f1': '0.701', 'total_rewards': 890.2059618709319, 'invalid_action_count': 0, 'num_ms1_scans': 576, 'num_ms2_scans': 6049}
#
# Episode 15 (4151 chemicals)
# steps	 500 	total rewards	 50.583060986256
# steps	 1000 	total rewards	 119.7864727087549
# steps	 1500 	total rewards	 203.2545489985933
# steps	 2000 	total rewards	 289.7461607251688
# steps	 2500 	total rewards	 383.8615316579445
# steps	 3000 	total rewards	 483.65436235112657
# steps	 3500 	total rewards	 572.4272343117324
# steps	 4000 	total rewards	 652.0308903687948
# steps	 4500 	total rewards	 713.2047676659348
# steps	 5000 	total rewards	 776.5424339126625
# steps	 5500 	total rewards	 849.2847878042109
# steps	 6000 	total rewards	 910.8680753724824
# steps	 6500 	total rewards	 972.1637769785199
# Finished after 6825 timesteps (10.05812692642212 seconds) with total reward 1009.4048482213891
# {'coverage_prop': '0.690', 'intensity_prop': '0.391', 'ms1ms2_ratio': '0.058', 'efficiency': '0.444', 'TP': '1756', 'FP': '1110', 'FN': '1285', 'precision': '0.613', 'recall': '0.577', 'f1': '0.595', 'total_rewards': 1009.4048482213884, 'invalid_action_count': 0, 'num_ms1_scans': 375, 'num_ms2_scans': 6450}
#
# Episode 16 (4326 chemicals)
# steps	 500 	total rewards	 47.561498767879755
# steps	 1000 	total rewards	 114.17898242905781
# steps	 1500 	total rewards	 206.8419241290283
# steps	 2000 	total rewards	 283.70760401250675
# steps	 2500 	total rewards	 376.0367354490045
# steps	 3000 	total rewards	 471.2237653953388
# steps	 3500 	total rewards	 558.1493194899792
# steps	 4000 	total rewards	 633.9105616033094
# steps	 4500 	total rewards	 700.487289232465
# steps	 5000 	total rewards	 765.4523181748398
# steps	 5500 	total rewards	 837.7467422403402
# steps	 6000 	total rewards	 900.0428053300222
# steps	 6500 	total rewards	 959.0660067659776
# Finished after 6852 timesteps (17.589772939682007 seconds) with total reward 999.3903186649084
# {'coverage_prop': '0.663', 'intensity_prop': '0.379', 'ms1ms2_ratio': '0.054', 'efficiency': '0.441', 'TP': '1772', 'FP': '1097', 'FN': '1457', 'precision': '0.618', 'recall': '0.549', 'f1': '0.581', 'total_rewards': 999.3903186649095, 'invalid_action_count': 0, 'num_ms1_scans': 348, 'num_ms2_scans': 6504}
#
# Episode 17 (4131 chemicals)
# steps	 500 	total rewards	 43.57809216645148
# steps	 1000 	total rewards	 111.79615047875211
# steps	 1500 	total rewards	 198.32523154543816
# steps	 2000 	total rewards	 277.70231274278444
# steps	 2500 	total rewards	 375.9023451743176
# steps	 3000 	total rewards	 469.34497314804634
# steps	 3500 	total rewards	 545.9577706678417
# steps	 4000 	total rewards	 616.016498442161
# steps	 4500 	total rewards	 679.5027678055355
# steps	 5000 	total rewards	 745.6019754077818
# steps	 5500 	total rewards	 816.327999473108
# steps	 6000 	total rewards	 881.4919328319988
# steps	 6500 	total rewards	 948.2369305265433
# Finished after 6803 timesteps (10.63873815536499 seconds) with total reward 986.6165571621773
# {'coverage_prop': '0.682', 'intensity_prop': '0.395', 'ms1ms2_ratio': '0.062', 'efficiency': '0.440', 'TP': '1764', 'FP': '1055', 'FN': '1312', 'precision': '0.626', 'recall': '0.573', 'f1': '0.598', 'total_rewards': 986.6165571621767, 'invalid_action_count': 0, 'num_ms1_scans': 397, 'num_ms2_scans': 6406}
#
# Episode 18 (4881 chemicals)
# steps	 500 	total rewards	 56.931050214308705
# steps	 1000 	total rewards	 130.46698490735923
# steps	 1500 	total rewards	 216.47834185552793
# steps	 2000 	total rewards	 299.90951091735576
# steps	 2500 	total rewards	 389.41062262322555
# steps	 3000 	total rewards	 482.9214542984939
# steps	 3500 	total rewards	 566.5906699672482
# steps	 4000 	total rewards	 643.9915004992085
# steps	 4500 	total rewards	 712.5281305243867
# steps	 5000 	total rewards	 777.9167466064087
# steps	 5500 	total rewards	 851.8680475216674
# steps	 6000 	total rewards	 918.6798280734283
# steps	 6500 	total rewards	 983.4443088974375
# Finished after 6903 timesteps (11.408123970031738 seconds) with total reward 1035.5882123614292
# {'coverage_prop': '0.667', 'intensity_prop': '0.368', 'ms1ms2_ratio': '0.045', 'efficiency': '0.493', 'TP': '1956', 'FP': '1300', 'FN': '1625', 'precision': '0.601', 'recall': '0.546', 'f1': '0.572', 'total_rewards': 1035.58821236143, 'invalid_action_count': 0, 'num_ms1_scans': 297, 'num_ms2_scans': 6606}
#
# Episode 19 (3491 chemicals)
# steps	 500 	total rewards	 53.42062033323381
# steps	 1000 	total rewards	 118.85688110247017
# steps	 1500 	total rewards	 201.0838804437155
# steps	 2000 	total rewards	 279.34861434079903
# steps	 2500 	total rewards	 363.13101973372466
# steps	 3000 	total rewards	 454.4526849241688
# steps	 3500 	total rewards	 540.9439561835519
# steps	 4000 	total rewards	 617.9158315771448
# steps	 4500 	total rewards	 680.4882112735769
# steps	 5000 	total rewards	 743.3956065241385
# steps	 5500 	total rewards	 816.1136804792519
# steps	 6000 	total rewards	 874.6052661904176
# steps	 6500 	total rewards	 941.4776786755315
# Finished after 6791 timesteps (17.09890389442444 seconds) with total reward 973.0959704296275
# {'coverage_prop': '0.710', 'intensity_prop': '0.415', 'ms1ms2_ratio': '0.064', 'efficiency': '0.389', 'TP': '1589', 'FP': '891', 'FN': '1011', 'precision': '0.641', 'recall': '0.611', 'f1': '0.626', 'total_rewards': 973.0959704296256, 'invalid_action_count': 0, 'num_ms1_scans': 409, 'num_ms2_scans': 6382}
#
# Episode 20 (3674 chemicals)
# steps	 500 	total rewards	 53.80234268388186
# steps	 1000 	total rewards	 126.17158308817415
# steps	 1500 	total rewards	 205.05129826079627
# steps	 2000 	total rewards	 289.0165636624694
# steps	 2500 	total rewards	 380.9957450606981
# steps	 3000 	total rewards	 469.7366927375447
# steps	 3500 	total rewards	 554.1976888029087
# steps	 4000 	total rewards	 626.5248329974044
# steps	 4500 	total rewards	 691.8334202271313
# steps	 5000 	total rewards	 754.4695149949983
# steps	 5500 	total rewards	 825.4465331343006
# steps	 6000 	total rewards	 884.8501092504189
# steps	 6500 	total rewards	 949.521298798785
# Finished after 6815 timesteps (9.503742218017578 seconds) with total reward 987.9256760051916
# {'coverage_prop': '0.693', 'intensity_prop': '0.401', 'ms1ms2_ratio': '0.060', 'efficiency': '0.396', 'TP': '1595', 'FP': '951', 'FN': '1128', 'precision': '0.626', 'recall': '0.586', 'f1': '0.605', 'total_rewards': 987.9256760051913, 'invalid_action_count': 0, 'num_ms1_scans': 385, 'num_ms2_scans': 6430}
#
# Episode 21 (4196 chemicals)
# steps	 500 	total rewards	 56.47748187787134
# steps	 1000 	total rewards	 126.51657934937907
# steps	 1500 	total rewards	 216.351807557222
# steps	 2000 	total rewards	 300.96779947068853
# steps	 2500 	total rewards	 388.651248945258
# steps	 3000 	total rewards	 487.2163439692599
# steps	 3500 	total rewards	 576.9778582060758
# steps	 4000 	total rewards	 650.5163063802777
# steps	 4500 	total rewards	 710.666158705769
# steps	 5000 	total rewards	 769.4268239126741
# steps	 5500 	total rewards	 835.6026669884441
# steps	 6000 	total rewards	 895.5625772921697
# steps	 6500 	total rewards	 954.3846794702589
# Finished after 6868 timesteps (10.501507997512817 seconds) with total reward 1000.3508396971765
# {'coverage_prop': '0.678', 'intensity_prop': '0.387', 'ms1ms2_ratio': '0.051', 'efficiency': '0.435', 'TP': '1771', 'FP': '1074', 'FN': '1351', 'precision': '0.622', 'recall': '0.567', 'f1': '0.594', 'total_rewards': 1000.3508396971755, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 6536}
#
# Episode 22 (2541 chemicals)
# steps	 500 	total rewards	 43.38273696714067
# steps	 1000 	total rewards	 108.81408136698619
# steps	 1500 	total rewards	 190.70975447759093
# steps	 2000 	total rewards	 265.66708683405676
# steps	 2500 	total rewards	 351.97787868687305
# steps	 3000 	total rewards	 447.3823190767257
# steps	 3500 	total rewards	 527.8339148634143
# steps	 4000 	total rewards	 594.6708206608458
# steps	 4500 	total rewards	 654.7751704259329
# steps	 5000 	total rewards	 716.8591861828455
# steps	 5500 	total rewards	 783.7695856445245
# steps	 6000 	total rewards	 842.9712149174638
# steps	 6500 	total rewards	 902.0353151936819
# Finished after 6725 timesteps (18.596230268478394 seconds) with total reward 929.2799333855244
# {'coverage_prop': '0.733', 'intensity_prop': '0.432', 'ms1ms2_ratio': '0.076', 'efficiency': '0.298', 'TP': '1199', 'FP': '664', 'FN': '678', 'precision': '0.644', 'recall': '0.639', 'f1': '0.641', 'total_rewards': 929.2799333855229, 'invalid_action_count': 0, 'num_ms1_scans': 475, 'num_ms2_scans': 6250}
#
# Episode 23 (3254 chemicals)
# steps	 500 	total rewards	 49.86888453283987
# steps	 1000 	total rewards	 120.17622801175607
# steps	 1500 	total rewards	 208.0372387908299
# steps	 2000 	total rewards	 287.3405041389956
# steps	 2500 	total rewards	 378.80878031667834
# steps	 3000 	total rewards	 471.79324054317783
# steps	 3500 	total rewards	 553.5472823599378
# steps	 4000 	total rewards	 624.7321241264863
# steps	 4500 	total rewards	 690.1402756535174
# steps	 5000 	total rewards	 753.9106043483871
# steps	 5500 	total rewards	 820.6654167729093
# steps	 6000 	total rewards	 885.8447869978312
# steps	 6500 	total rewards	 952.0764180208523
# Finished after 6765 timesteps (8.930307865142822 seconds) with total reward 981.9567425169703
# {'coverage_prop': '0.698', 'intensity_prop': '0.409', 'ms1ms2_ratio': '0.069', 'efficiency': '0.359', 'TP': '1455', 'FP': '815', 'FN': '984', 'precision': '0.641', 'recall': '0.597', 'f1': '0.618', 'total_rewards': 981.9567425169697, 'invalid_action_count': 0, 'num_ms1_scans': 435, 'num_ms2_scans': 6330}
#
# Episode 24 (4358 chemicals)
# steps	 500 	total rewards	 58.82495314596303
# steps	 1000 	total rewards	 126.88236874040945
# steps	 1500 	total rewards	 217.18066589907156
# steps	 2000 	total rewards	 294.6092542719207
# steps	 2500 	total rewards	 385.76618291678244
# steps	 3000 	total rewards	 479.73831217502095
# steps	 3500 	total rewards	 569.1047035021282
# steps	 4000 	total rewards	 649.0193738739899
# steps	 4500 	total rewards	 714.0532433666526
# steps	 5000 	total rewards	 777.4426186150811
# steps	 5500 	total rewards	 849.7351931344812
# steps	 6000 	total rewards	 913.5985523226809
# steps	 6500 	total rewards	 976.465523721509
# Finished after 6873 timesteps (10.625847101211548 seconds) with total reward 1025.1313843170542
# {'coverage_prop': '0.670', 'intensity_prop': '0.379', 'ms1ms2_ratio': '0.050', 'efficiency': '0.446', 'TP': '1788', 'FP': '1133', 'FN': '1437', 'precision': '0.612', 'recall': '0.554', 'f1': '0.582', 'total_rewards': 1025.131384317051, 'invalid_action_count': 0, 'num_ms1_scans': 327, 'num_ms2_scans': 6546}
#
# Episode 25 (3301 chemicals)
# steps	 500 	total rewards	 52.270460006055515
# steps	 1000 	total rewards	 123.27350530907012
# steps	 1500 	total rewards	 200.30578417517486
# steps	 2000 	total rewards	 276.73894473214955
# steps	 2500 	total rewards	 357.7419599095798
# steps	 3000 	total rewards	 454.3704700375529
# steps	 3500 	total rewards	 539.8157937884049
# steps	 4000 	total rewards	 610.9028145762587
# steps	 4500 	total rewards	 673.2363160823448
# steps	 5000 	total rewards	 727.0748495465799
# steps	 5500 	total rewards	 786.9153790387431
# steps	 6000 	total rewards	 842.3523852079295
# steps	 6500 	total rewards	 894.1307657025918
# Finished after 6799 timesteps (18.672649145126343 seconds) with total reward 925.2207300478212
# {'coverage_prop': '0.714', 'intensity_prop': '0.411', 'ms1ms2_ratio': '0.063', 'efficiency': '0.368', 'TP': '1462', 'FP': '895', 'FN': '944', 'precision': '0.620', 'recall': '0.608', 'f1': '0.614', 'total_rewards': 925.22073004782, 'invalid_action_count': 0, 'num_ms1_scans': 402, 'num_ms2_scans': 6397}
#
# Episode 26 (4916 chemicals)
# steps	 500 	total rewards	 52.676687500699856
# steps	 1000 	total rewards	 127.01849051815746
# steps	 1500 	total rewards	 216.93184466432444
# steps	 2000 	total rewards	 304.4983126925362
# steps	 2500 	total rewards	 394.24447928151096
# steps	 3000 	total rewards	 490.095151694942
# steps	 3500 	total rewards	 577.3541430733343
# steps	 4000 	total rewards	 657.0902738091629
# steps	 4500 	total rewards	 721.0406255538851
# steps	 5000 	total rewards	 783.2783709454038
# steps	 5500 	total rewards	 857.3693724507493
# steps	 6000 	total rewards	 919.7945259152834
# steps	 6500 	total rewards	 981.8714984132787
# Finished after 6893 timesteps (11.557605743408203 seconds) with total reward 1033.3388545178188
# {'coverage_prop': '0.674', 'intensity_prop': '0.373', 'ms1ms2_ratio': '0.047', 'efficiency': '0.503', 'TP': '1978', 'FP': '1333', 'FN': '1605', 'precision': '0.597', 'recall': '0.552', 'f1': '0.574', 'total_rewards': 1033.338854517817, 'invalid_action_count': 0, 'num_ms1_scans': 307, 'num_ms2_scans': 6586}
#
# Episode 27 (2655 chemicals)
# steps	 500 	total rewards	 41.90046585078804
# steps	 1000 	total rewards	 109.40779611804905
# steps	 1500 	total rewards	 188.15795257527645
# steps	 2000 	total rewards	 262.375715869774
# steps	 2500 	total rewards	 348.45232723111576
# steps	 3000 	total rewards	 436.8589181553833
# steps	 3500 	total rewards	 518.2858456897268
# steps	 4000 	total rewards	 583.6556331770337
# steps	 4500 	total rewards	 644.1287537939227
# steps	 5000 	total rewards	 702.6878194362732
# steps	 5500 	total rewards	 768.5225445257181
# steps	 6000 	total rewards	 822.590712061245
# steps	 6500 	total rewards	 874.8553287391298
# Finished after 6719 timesteps (7.9691619873046875 seconds) with total reward 896.0147156851465
# {'coverage_prop': '0.730', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.077', 'efficiency': '0.311', 'TP': '1268', 'FP': '671', 'FN': '716', 'precision': '0.654', 'recall': '0.639', 'f1': '0.646', 'total_rewards': 896.0147156851476, 'invalid_action_count': 0, 'num_ms1_scans': 481, 'num_ms2_scans': 6238}
#
# Episode 28 (4538 chemicals)
# steps	 500 	total rewards	 59.37502291953022
# steps	 1000 	total rewards	 131.62064865780417
# steps	 1500 	total rewards	 220.80431514213282
# steps	 2000 	total rewards	 305.7976692525579
# steps	 2500 	total rewards	 395.1025480397349
# steps	 3000 	total rewards	 488.45747042747746
# steps	 3500 	total rewards	 577.564305817163
# steps	 4000 	total rewards	 652.3216696997526
# steps	 4500 	total rewards	 717.2419325327729
# steps	 5000 	total rewards	 780.2582572056374
# steps	 5500 	total rewards	 851.552274819778
# steps	 6000 	total rewards	 915.9482813719067
# steps	 6500 	total rewards	 975.8115963696063
# Finished after 6862 timesteps (21.069287061691284 seconds) with total reward 1016.468793418658
# {'coverage_prop': '0.669', 'intensity_prop': '0.367', 'ms1ms2_ratio': '0.052', 'efficiency': '0.466', 'TP': '1793', 'FP': '1245', 'FN': '1500', 'precision': '0.590', 'recall': '0.544', 'f1': '0.566', 'total_rewards': 1016.4687934186584, 'invalid_action_count': 0, 'num_ms1_scans': 338, 'num_ms2_scans': 6524}
#
# Episode 29 (3171 chemicals)
# steps	 500 	total rewards	 55.15834880944024
# steps	 1000 	total rewards	 126.23737843437567
# steps	 1500 	total rewards	 209.08018372527752
# steps	 2000 	total rewards	 290.12938443653337
# steps	 2500 	total rewards	 386.8996853708878
# steps	 3000 	total rewards	 470.2617995234091
# steps	 3500 	total rewards	 548.0983196678362
# steps	 4000 	total rewards	 621.9307485887584
# steps	 4500 	total rewards	 682.0068667885375
# steps	 5000 	total rewards	 743.038151967899
# steps	 5500 	total rewards	 811.1915633509052
# steps	 6000 	total rewards	 868.6875602696032
# steps	 6500 	total rewards	 923.5407883372252
# Finished after 6766 timesteps (9.095423221588135 seconds) with total reward 955.1286232374619
# {'coverage_prop': '0.723', 'intensity_prop': '0.430', 'ms1ms2_ratio': '0.069', 'efficiency': '0.362', 'TP': '1491', 'FP': '802', 'FN': '878', 'precision': '0.650', 'recall': '0.629', 'f1': '0.640', 'total_rewards': 955.1286232374626, 'invalid_action_count': 0, 'num_ms1_scans': 434, 'num_ms2_scans': 6332}
#
# method = PPO max_peaks = 100 N = 0 rt_tol = 5
#
#
# Episode 0 (2151 chemicals)
# steps	 500 	total rewards	 48.62671823042165
# steps	 1000 	total rewards	 115.3183170648664
# steps	 1500 	total rewards	 191.71648436240315
# steps	 2000 	total rewards	 266.2756343001149
# steps	 2500 	total rewards	 349.99031971055877
# steps	 3000 	total rewards	 439.24172872431564
# steps	 3500 	total rewards	 521.6953760778246
# steps	 4000 	total rewards	 585.876325417873
# steps	 4500 	total rewards	 640.818654041779
# steps	 5000 	total rewards	 699.9013559489578
# steps	 5500 	total rewards	 762.93759157003
# steps	 6000 	total rewards	 821.642617672047
# steps	 6500 	total rewards	 880.9045412021056
# Finished after 6847 timesteps (10.444528818130493 seconds) with total reward 916.3529960991759
# {'coverage_prop': '0.778', 'intensity_prop': '0.501', 'ms1ms2_ratio': '0.054', 'efficiency': '0.258', 'TP': '1204', 'FP': '470', 'FN': '477', 'precision': '0.719', 'recall': '0.716', 'f1': '0.718', 'total_rewards': 916.3529960991774, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 6494}
#
# Episode 1 (4096 chemicals)
# steps	 500 	total rewards	 57.076145691571604
# steps	 1000 	total rewards	 125.37305707344143
# steps	 1500 	total rewards	 212.1424820435832
# steps	 2000 	total rewards	 293.8104456549255
# steps	 2500 	total rewards	 387.72347280734334
# steps	 3000 	total rewards	 483.6046765220489
# steps	 3500 	total rewards	 569.1758331440128
# steps	 4000 	total rewards	 643.6255617246409
# steps	 4500 	total rewards	 710.7841180535377
# steps	 5000 	total rewards	 771.0695766247096
# steps	 5500 	total rewards	 838.9208205169614
# steps	 6000 	total rewards	 902.1963715788286
# steps	 6500 	total rewards	 964.2999200111486
# Finished after 6954 timesteps (14.060503005981445 seconds) with total reward 1018.6053743717845
# {'coverage_prop': '0.704', 'intensity_prop': '0.394', 'ms1ms2_ratio': '0.037', 'efficiency': '0.430', 'TP': '1744', 'FP': '1141', 'FN': '1211', 'precision': '0.605', 'recall': '0.590', 'f1': '0.597', 'total_rewards': 1018.6053743717862, 'invalid_action_count': 0, 'num_ms1_scans': 246, 'num_ms2_scans': 6708}
#
# Episode 2 (3307 chemicals)
# steps	 500 	total rewards	 54.648245651365585
# steps	 1000 	total rewards	 132.42796408870538
# steps	 1500 	total rewards	 218.75851367229382
# steps	 2000 	total rewards	 301.1820128899894
# steps	 2500 	total rewards	 384.2835951356254
# steps	 3000 	total rewards	 479.7211731732304
# steps	 3500 	total rewards	 566.1516841892525
# steps	 4000 	total rewards	 641.6493506938332
# steps	 4500 	total rewards	 705.8577203695372
# steps	 5000 	total rewards	 777.6645114606099
# steps	 5500 	total rewards	 841.2384450353301
# steps	 6000 	total rewards	 904.2846383412868
# steps	 6500 	total rewards	 967.3258099444192
# Finished after 6935 timesteps (12.315021991729736 seconds) with total reward 1020.978951918097
# {'coverage_prop': '0.725', 'intensity_prop': '0.420', 'ms1ms2_ratio': '0.040', 'efficiency': '0.360', 'TP': '1488', 'FP': '911', 'FN': '908', 'precision': '0.620', 'recall': '0.621', 'f1': '0.621', 'total_rewards': 1020.9789519180996, 'invalid_action_count': 0, 'num_ms1_scans': 265, 'num_ms2_scans': 6670}
#
# Episode 3 (3000 chemicals)
# steps	 500 	total rewards	 53.8082672518533
# steps	 1000 	total rewards	 122.47757477501095
# steps	 1500 	total rewards	 211.40206656164978
# steps	 2000 	total rewards	 294.60565850334405
# steps	 2500 	total rewards	 382.0393664585689
# steps	 3000 	total rewards	 475.9383179015862
# steps	 3500 	total rewards	 560.8213380609558
# steps	 4000 	total rewards	 628.6840708716941
# steps	 4500 	total rewards	 689.5075067999121
# steps	 5000 	total rewards	 753.1536659184443
# steps	 5500 	total rewards	 822.1325156629864
# steps	 6000 	total rewards	 878.7808210875476
# steps	 6500 	total rewards	 937.9932388549437
# Finished after 6946 timesteps (11.915961027145386 seconds) with total reward 987.5822554569535
# {'coverage_prop': '0.757', 'intensity_prop': '0.444', 'ms1ms2_ratio': '0.038', 'efficiency': '0.340', 'TP': '1412', 'FP': '860', 'FN': '728', 'precision': '0.621', 'recall': '0.660', 'f1': '0.640', 'total_rewards': 987.5822554569536, 'invalid_action_count': 0, 'num_ms1_scans': 254, 'num_ms2_scans': 6692}
#
# Episode 4 (4490 chemicals)
# steps	 500 	total rewards	 63.28537399507471
# steps	 1000 	total rewards	 130.72580000035245
# steps	 1500 	total rewards	 215.4650855300518
# steps	 2000 	total rewards	 303.00752533626905
# steps	 2500 	total rewards	 395.5296636066072
# steps	 3000 	total rewards	 492.88358563257515
# steps	 3500 	total rewards	 585.3700305819752
# steps	 4000 	total rewards	 662.0764131116013
# steps	 4500 	total rewards	 729.5092868586685
# steps	 5000 	total rewards	 795.9339689716019
# steps	 5500 	total rewards	 863.5225114273949
# steps	 6000 	total rewards	 927.9152961038865
# steps	 6500 	total rewards	 988.7633246924056
# Finished after 6986 timesteps (14.382362842559814 seconds) with total reward 1050.6081467699582
# {'coverage_prop': '0.690', 'intensity_prop': '0.382', 'ms1ms2_ratio': '0.032', 'efficiency': '0.457', 'TP': '1852', 'FP': '1245', 'FN': '1393', 'precision': '0.598', 'recall': '0.571', 'f1': '0.584', 'total_rewards': 1050.60814676996, 'invalid_action_count': 0, 'num_ms1_scans': 214, 'num_ms2_scans': 6772}
#
# Episode 5 (2477 chemicals)
# steps	 500 	total rewards	 51.04238265688044
# steps	 1000 	total rewards	 119.10318356684829
# steps	 1500 	total rewards	 198.4719599752084
# steps	 2000 	total rewards	 275.0842361600984
# steps	 2500 	total rewards	 357.66392346135825
# steps	 3000 	total rewards	 448.3784444144869
# steps	 3500 	total rewards	 530.4856515665908
# steps	 4000 	total rewards	 597.9836892733462
# steps	 4500 	total rewards	 651.0692522953461
# steps	 5000 	total rewards	 702.3639933225921
# steps	 5500 	total rewards	 765.0668376003705
# steps	 6000 	total rewards	 819.4345330179195
# steps	 6500 	total rewards	 873.4218874265139
# Finished after 6900 timesteps (11.103893041610718 seconds) with total reward 916.0682128023695
# {'coverage_prop': '0.756', 'intensity_prop': '0.455', 'ms1ms2_ratio': '0.045', 'efficiency': '0.284', 'TP': '1239', 'FP': '634', 'FN': '604', 'precision': '0.662', 'recall': '0.672', 'f1': '0.667', 'total_rewards': 916.0682128023672, 'invalid_action_count': 0, 'num_ms1_scans': 300, 'num_ms2_scans': 6600}
#
# Episode 6 (3302 chemicals)
# steps	 500 	total rewards	 43.977334866152745
# steps	 1000 	total rewards	 108.51760282344108
# steps	 1500 	total rewards	 193.27672147610554
# steps	 2000 	total rewards	 270.0775813964815
# steps	 2500 	total rewards	 359.27704947892323
# steps	 3000 	total rewards	 458.00551824315505
# steps	 3500 	total rewards	 540.0679949981165
# steps	 4000 	total rewards	 612.3986333200854
# steps	 4500 	total rewards	 678.4753890837167
# steps	 5000 	total rewards	 740.4055437983076
# steps	 5500 	total rewards	 809.4495696972606
# steps	 6000 	total rewards	 865.6032480238185
# steps	 6500 	total rewards	 926.2251706368431
# Finished after 6944 timesteps (12.40194296836853 seconds) with total reward 981.338142168395
# {'coverage_prop': '0.718', 'intensity_prop': '0.407', 'ms1ms2_ratio': '0.038', 'efficiency': '0.355', 'TP': '1443', 'FP': '929', 'FN': '930', 'precision': '0.608', 'recall': '0.608', 'f1': '0.608', 'total_rewards': 981.3381421683933, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 6688}
#
# Episode 7 (2370 chemicals)
# steps	 500 	total rewards	 40.410606450938715
# steps	 1000 	total rewards	 96.98114183714065
# steps	 1500 	total rewards	 173.41370187210518
# steps	 2000 	total rewards	 242.7003408058434
# steps	 2500 	total rewards	 326.8439126206973
# steps	 3000 	total rewards	 416.33545095224963
# steps	 3500 	total rewards	 501.2238809323072
# steps	 4000 	total rewards	 569.7413883484713
# steps	 4500 	total rewards	 632.2257677633343
# steps	 5000 	total rewards	 693.8590264257357
# steps	 5500 	total rewards	 764.060946818827
# steps	 6000 	total rewards	 828.6799538419801
# steps	 6500 	total rewards	 890.4342023293616
# Finished after 6897 timesteps (10.840901851654053 seconds) with total reward 936.3719768389062
# {'coverage_prop': '0.769', 'intensity_prop': '0.461', 'ms1ms2_ratio': '0.046', 'efficiency': '0.276', 'TP': '1200', 'FP': '622', 'FN': '548', 'precision': '0.659', 'recall': '0.686', 'f1': '0.672', 'total_rewards': 936.3719768389076, 'invalid_action_count': 0, 'num_ms1_scans': 303, 'num_ms2_scans': 6594}
#
# Episode 8 (3021 chemicals)
# steps	 500 	total rewards	 52.128808733459124
# steps	 1000 	total rewards	 116.10293108338811
# steps	 1500 	total rewards	 199.25866366271404
# steps	 2000 	total rewards	 277.4940327626045
# steps	 2500 	total rewards	 367.40161420025294
# steps	 3000 	total rewards	 459.92827988658985
# steps	 3500 	total rewards	 539.4794743664088
# steps	 4000 	total rewards	 615.8529533866497
# steps	 4500 	total rewards	 679.5607465972646
# steps	 5000 	total rewards	 741.2799376525932
# steps	 5500 	total rewards	 815.3160497127567
# steps	 6000 	total rewards	 876.0383146515726
# steps	 6500 	total rewards	 935.3444991059911
# Finished after 6938 timesteps (24.639432907104492 seconds) with total reward 988.4013056227034
# {'coverage_prop': '0.742', 'intensity_prop': '0.442', 'ms1ms2_ratio': '0.039', 'efficiency': '0.336', 'TP': '1461', 'FP': '780', 'FN': '780', 'precision': '0.652', 'recall': '0.652', 'f1': '0.652', 'total_rewards': 988.401305622703, 'invalid_action_count': 0, 'num_ms1_scans': 262, 'num_ms2_scans': 6676}
#
# Episode 9 (3051 chemicals)
# steps	 500 	total rewards	 60.268085169573084
# steps	 1000 	total rewards	 131.9694138261643
# steps	 1500 	total rewards	 218.39752905332944
# steps	 2000 	total rewards	 295.27277315620626
# steps	 2500 	total rewards	 385.6394116456685
# steps	 3000 	total rewards	 475.23920032808513
# steps	 3500 	total rewards	 569.0798240694531
# steps	 4000 	total rewards	 642.9865076059434
# steps	 4500 	total rewards	 709.330724440198
# steps	 5000 	total rewards	 769.621846829355
# steps	 5500 	total rewards	 837.8032135619898
# steps	 6000 	total rewards	 898.1785451181408
# steps	 6500 	total rewards	 960.2854143593262
# Finished after 6942 timesteps (12.255870819091797 seconds) with total reward 1004.3918675955626
# {'coverage_prop': '0.752', 'intensity_prop': '0.438', 'ms1ms2_ratio': '0.039', 'efficiency': '0.343', 'TP': '1441', 'FP': '854', 'FN': '756', 'precision': '0.628', 'recall': '0.656', 'f1': '0.642', 'total_rewards': 1004.3918675955628, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 6684}
#
# Episode 10 (4873 chemicals)
# steps	 500 	total rewards	 55.08791307052746
# steps	 1000 	total rewards	 130.44635347421112
# steps	 1500 	total rewards	 223.5269027273833
# steps	 2000 	total rewards	 301.23163463295407
# steps	 2500 	total rewards	 390.7294105897729
# steps	 3000 	total rewards	 484.60846911670615
# steps	 3500 	total rewards	 577.1561810485857
# steps	 4000 	total rewards	 657.7899941977694
# steps	 4500 	total rewards	 727.1589183019107
# steps	 5000 	total rewards	 790.1055254727178
# steps	 5500 	total rewards	 862.7300086187223
# steps	 6000 	total rewards	 929.5392868168806
# steps	 6500 	total rewards	 990.5754539241902
# Finished after 6983 timesteps (15.523879289627075 seconds) with total reward 1049.9304523857122
# {'coverage_prop': '0.676', 'intensity_prop': '0.366', 'ms1ms2_ratio': '0.032', 'efficiency': '0.487', 'TP': '1884', 'FP': '1411', 'FN': '1578', 'precision': '0.572', 'recall': '0.544', 'f1': '0.558', 'total_rewards': 1049.930452385715, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 6766}
#
# Episode 11 (3756 chemicals)
# steps	 500 	total rewards	 54.73402482429847
# steps	 1000 	total rewards	 116.07215140217835
# steps	 1500 	total rewards	 197.9677076871443
# steps	 2000 	total rewards	 271.7557450379484
# steps	 2500 	total rewards	 361.2478986844825
# steps	 3000 	total rewards	 458.14151770394926
# steps	 3500 	total rewards	 548.4803533295529
# steps	 4000 	total rewards	 628.0735099133128
# steps	 4500 	total rewards	 697.6397665949021
# steps	 5000 	total rewards	 764.0741405295296
# steps	 5500 	total rewards	 833.6788602827112
# steps	 6000 	total rewards	 896.1574474250184
# steps	 6500 	total rewards	 961.2236357383356
# Finished after 6986 timesteps (12.860615968704224 seconds) with total reward 1021.5539299813062
# {'coverage_prop': '0.714', 'intensity_prop': '0.412', 'ms1ms2_ratio': '0.032', 'efficiency': '0.396', 'TP': '1673', 'FP': '1010', 'FN': '1073', 'precision': '0.624', 'recall': '0.609', 'f1': '0.616', 'total_rewards': 1021.5539299813059, 'invalid_action_count': 0, 'num_ms1_scans': 214, 'num_ms2_scans': 6772}
#
# Episode 12 (4904 chemicals)
# steps	 500 	total rewards	 63.982639194637706
# steps	 1000 	total rewards	 138.83079668290813
# steps	 1500 	total rewards	 229.1226534096546
# steps	 2000 	total rewards	 311.74503718178323
# steps	 2500 	total rewards	 403.91658489456574
# steps	 3000 	total rewards	 504.85615583151264
# steps	 3500 	total rewards	 598.3635663537542
# steps	 4000 	total rewards	 682.8322753879074
# steps	 4500 	total rewards	 753.2214875621662
# steps	 5000 	total rewards	 819.0032167789884
# steps	 5500 	total rewards	 893.1284753131924
# steps	 6000 	total rewards	 960.0348897843617
# steps	 6500 	total rewards	 1027.7079875069878
# Finished after 6993 timesteps (14.997568130493164 seconds) with total reward 1094.6526614248357
# {'coverage_prop': '0.686', 'intensity_prop': '0.381', 'ms1ms2_ratio': '0.031', 'efficiency': '0.495', 'TP': '2010', 'FP': '1352', 'FN': '1542', 'precision': '0.598', 'recall': '0.566', 'f1': '0.581', 'total_rewards': 1094.6526614248348, 'invalid_action_count': 0, 'num_ms1_scans': 207, 'num_ms2_scans': 6786}
#
# Episode 13 (3460 chemicals)
# steps	 500 	total rewards	 57.31158359230146
# steps	 1000 	total rewards	 125.61854869017388
# steps	 1500 	total rewards	 207.5328488163799
# steps	 2000 	total rewards	 284.59651039582343
# steps	 2500 	total rewards	 376.31265188353495
# steps	 3000 	total rewards	 472.69784426986797
# steps	 3500 	total rewards	 562.7322421915011
# steps	 4000 	total rewards	 641.6305290632312
# steps	 4500 	total rewards	 707.4730247716905
# steps	 5000 	total rewards	 773.8391963983327
# steps	 5500 	total rewards	 844.6541644148815
# steps	 6000 	total rewards	 911.8096389567913
# steps	 6500 	total rewards	 974.4275855317092
# Finished after 6960 timesteps (12.662757158279419 seconds) with total reward 1034.5405072079807
# {'coverage_prop': '0.726', 'intensity_prop': '0.409', 'ms1ms2_ratio': '0.036', 'efficiency': '0.374', 'TP': '1527', 'FP': '984', 'FN': '949', 'precision': '0.608', 'recall': '0.617', 'f1': '0.612', 'total_rewards': 1034.5405072079793, 'invalid_action_count': 0, 'num_ms1_scans': 240, 'num_ms2_scans': 6720}
#
# Episode 14 (2023 chemicals)
# steps	 500 	total rewards	 39.64546317492339
# steps	 1000 	total rewards	 106.60745571828643
# steps	 1500 	total rewards	 184.51060065613598
# steps	 2000 	total rewards	 256.4819423648102
# steps	 2500 	total rewards	 342.4218702096056
# steps	 3000 	total rewards	 431.6175366572678
# steps	 3500 	total rewards	 507.86198850497306
# steps	 4000 	total rewards	 579.8808868185795
# steps	 4500 	total rewards	 644.5226852038641
# steps	 5000 	total rewards	 706.8269151783483
# steps	 5500 	total rewards	 774.0866194790452
# steps	 6000 	total rewards	 830.4955529654982
# steps	 6500 	total rewards	 888.2399793414723
# Finished after 6811 timesteps (10.69818377494812 seconds) with total reward 922.256768632114
# {'coverage_prop': '0.783', 'intensity_prop': '0.498', 'ms1ms2_ratio': '0.061', 'efficiency': '0.247', 'TP': '1125', 'FP': '459', 'FN': '439', 'precision': '0.710', 'recall': '0.719', 'f1': '0.715', 'total_rewards': 922.2567686321129, 'invalid_action_count': 0, 'num_ms1_scans': 389, 'num_ms2_scans': 6422}
#
# Episode 15 (4151 chemicals)
# steps	 500 	total rewards	 58.36227856136919
# steps	 1000 	total rewards	 124.01316072496087
# steps	 1500 	total rewards	 211.67705047592813
# steps	 2000 	total rewards	 294.54970560166464
# steps	 2500 	total rewards	 389.7520097916235
# steps	 3000 	total rewards	 490.4618164962434
# steps	 3500 	total rewards	 582.5282420432943
# steps	 4000 	total rewards	 665.0223713523292
# steps	 4500 	total rewards	 728.4939204669528
# steps	 5000 	total rewards	 791.2351576343164
# steps	 5500 	total rewards	 864.9108292699218
# steps	 6000 	total rewards	 927.2383837606245
# steps	 6500 	total rewards	 991.7623310096078
# Finished after 6974 timesteps (13.715605974197388 seconds) with total reward 1050.2668160318979
# {'coverage_prop': '0.707', 'intensity_prop': '0.399', 'ms1ms2_ratio': '0.033', 'efficiency': '0.435', 'TP': '1786', 'FP': '1148', 'FN': '1217', 'precision': '0.609', 'recall': '0.595', 'f1': '0.602', 'total_rewards': 1050.2668160318992, 'invalid_action_count': 0, 'num_ms1_scans': 226, 'num_ms2_scans': 6748}
#
# Episode 16 (4326 chemicals)
# steps	 500 	total rewards	 51.39010180162391
# steps	 1000 	total rewards	 114.17971609911413
# steps	 1500 	total rewards	 208.616248723864
# steps	 2000 	total rewards	 287.6740977003078
# steps	 2500 	total rewards	 381.16637007946747
# steps	 3000 	total rewards	 481.5357764200618
# steps	 3500 	total rewards	 572.6439033434873
# steps	 4000 	total rewards	 651.4715950887326
# steps	 4500 	total rewards	 720.0796851598257
# steps	 5000 	total rewards	 786.3786701540305
# ...
# Finished after 6246 timesteps (48.25389099121094 seconds) with total reward 923.8811491022046
# {'coverage_prop': '0.741', 'intensity_prop': '0.489', 'ms1ms2_ratio': '0.180', 'efficiency': '0.484', 'TP': '1931', 'FP': '632', 'FN': '897', 'precision': '0.753', 'recall': '0.683', 'f1': '0.716', 'total_rewards': 923.8811491022037, 'invalid_action_count': 0, 'num_ms1_scans': 954, 'num_ms2_scans': 5292}
#
# Episode 14 (2023 chemicals)
# steps	 500 	total rewards	 12.475995799280767
# steps	 1000 	total rewards	 88.18762210834132
# steps	 1500 	total rewards	 159.82295706598185
# steps	 2000 	total rewards	 252.0030227387556
# steps	 2500 	total rewards	 347.3870589896972
# steps	 3000 	total rewards	 428.39117855602854
# steps	 3500 	total rewards	 500.3527061112482
# steps	 4000 	total rewards	 554.2479101920853
# steps	 4500 	total rewards	 614.7534231112832
# steps	 5000 	total rewards	 665.2482430259054
# steps	 5500 	total rewards	 710.0262559693165
# Finished after 5717 timesteps (30.357720851898193 seconds) with total reward 727.7750178318861
# {'coverage_prop': '0.810', 'intensity_prop': '0.536', 'ms1ms2_ratio': '0.350', 'efficiency': '0.387', 'TP': '1231', 'FP': '407', 'FN': '385', 'precision': '0.752', 'recall': '0.762', 'f1': '0.757', 'total_rewards': 727.7750178318873, 'invalid_action_count': 0, 'num_ms1_scans': 1483, 'num_ms2_scans': 4234}
#
# Episode 15 (4151 chemicals)
# steps	 500 	total rewards	 28.44712690430546
# steps	 1000 	total rewards	 112.39686303769778
# steps	 1500 	total rewards	 206.14120980597727
# steps	 2000 	total rewards	 303.4233906905432
# steps	 2500 	total rewards	 404.1744670396148
# steps	 3000 	total rewards	 494.02620307547363
# steps	 3500 	total rewards	 577.4317263310736
# steps	 4000 	total rewards	 645.5911294579075
# steps	 4500 	total rewards	 710.3756357591421
# steps	 5000 	total rewards	 786.2105528675086
# steps	 5500 	total rewards	 853.399874156959
# steps	 6000 	total rewards	 917.8680400292756
# Finished after 6353 timesteps (31.37019181251526 seconds) with total reward 958.1964505120075
# {'coverage_prop': '0.717', 'intensity_prop': '0.468', 'ms1ms2_ratio': '0.154', 'efficiency': '0.541', 'TP': '2229', 'FP': '749', 'FN': '1173', 'precision': '0.748', 'recall': '0.655', 'f1': '0.699', 'total_rewards': 958.1964505120087, 'invalid_action_count': 0, 'num_ms1_scans': 847, 'num_ms2_scans': 5506}
#
# Episode 16 (4326 chemicals)
# steps	 500 	total rewards	 23.680261959474713
# steps	 1000 	total rewards	 116.16033718423897
# steps	 1500 	total rewards	 211.44578489876417
# steps	 2000 	total rewards	 306.96518371852085
# steps	 2500 	total rewards	 398.05023601885
# steps	 3000 	total rewards	 487.1038793112509
# steps	 3500 	total rewards	 571.6525483917255
# steps	 4000 	total rewards	 644.899251054883
# steps	 4500 	total rewards	 714.4975767390999
# steps	 5000 	total rewards	 794.6500217610476
# steps	 5500 	total rewards	 859.3637991663347
# steps	 6000 	total rewards	 922.0021548336493
# Finished after 6395 timesteps (50.90054202079773 seconds) with total reward 972.2754282281934
# {'coverage_prop': '0.699', 'intensity_prop': '0.452', 'ms1ms2_ratio': '0.144', 'efficiency': '0.541', 'TP': '2212', 'FP': '812', 'FN': '1302', 'precision': '0.731', 'recall': '0.629', 'f1': '0.677', 'total_rewards': 972.2754282281937, 'invalid_action_count': 0, 'num_ms1_scans': 805, 'num_ms2_scans': 5590}
#
# Episode 17 (4131 chemicals)
# steps	 500 	total rewards	 23.741084252732733
# steps	 1000 	total rewards	 108.39357572139083
# steps	 1500 	total rewards	 200.88567206425105
# steps	 2000 	total rewards	 296.57818068513666
# steps	 2500 	total rewards	 395.63554067930846
# steps	 3000 	total rewards	 477.3898222322332
# steps	 3500 	total rewards	 549.4134182240609
# steps	 4000 	total rewards	 620.1000728070977
# steps	 4500 	total rewards	 689.0840864727277
# steps	 5000 	total rewards	 765.2805987903937
# steps	 5500 	total rewards	 833.1280592956637
# steps	 6000 	total rewards	 906.2444873180293
# Finished after 6385 timesteps (31.838534116744995 seconds) with total reward 955.9679762058598
# {'coverage_prop': '0.718', 'intensity_prop': '0.469', 'ms1ms2_ratio': '0.147', 'efficiency': '0.532', 'TP': '2195', 'FP': '770', 'FN': '1166', 'precision': '0.740', 'recall': '0.653', 'f1': '0.694', 'total_rewards': 955.9679762058588, 'invalid_action_count': 0, 'num_ms1_scans': 816, 'num_ms2_scans': 5569}
#
# Episode 18 (4881 chemicals)
# steps	 500 	total rewards	 37.20183628378865
# steps	 1000 	total rewards	 132.68496626609559
# steps	 1500 	total rewards	 221.17558627526702
# steps	 2000 	total rewards	 312.6255713362358
# steps	 2500 	total rewards	 408.24331774828136
# steps	 3000 	total rewards	 493.24207066506585
# steps	 3500 	total rewards	 576.909114378307
# steps	 4000 	total rewards	 653.1511810236392
# steps	 4500 	total rewards	 725.3522851902958
# steps	 5000 	total rewards	 801.800543612966
# steps	 5500 	total rewards	 872.4175587248745
# steps	 6000 	total rewards	 943.6212045434237
# Finished after 6440 timesteps (33.43510890007019 seconds) with total reward 1003.1150737491205
# {'coverage_prop': '0.689', 'intensity_prop': '0.435', 'ms1ms2_ratio': '0.134', 'efficiency': '0.592', 'TP': '2398', 'FP': '965', 'FN': '1518', 'precision': '0.713', 'recall': '0.612', 'f1': '0.659', 'total_rewards': 1003.115073749125, 'invalid_action_count': 0, 'num_ms1_scans': 760, 'num_ms2_scans': 5680}
#
# Episode 19 (3491 chemicals)
# steps	 500 	total rewards	 24.34979132467546
# steps	 1000 	total rewards	 109.65265103605012
# steps	 1500 	total rewards	 193.6264678680788
# steps	 2000 	total rewards	 282.2614712812689
# steps	 2500 	total rewards	 374.46329373990415
# steps	 3000 	total rewards	 466.54251793777
# steps	 3500 	total rewards	 548.1609991975091
# steps	 4000 	total rewards	 613.9179521839728
# steps	 4500 	total rewards	 667.9020261333712
# steps	 5000 	total rewards	 743.5805578478254
# steps	 5500 	total rewards	 800.4245290649319
# steps	 6000 	total rewards	 864.6121608474682
# Finished after 6152 timesteps (50.50904607772827 seconds) with total reward 878.5367003606364
# {'coverage_prop': '0.732', 'intensity_prop': '0.479', 'ms1ms2_ratio': '0.206', 'efficiency': '0.501', 'TP': '1896', 'FP': '659', 'FN': '936', 'precision': '0.742', 'recall': '0.669', 'f1': '0.704', 'total_rewards': 878.5367003606372, 'invalid_action_count': 0, 'num_ms1_scans': 1049, 'num_ms2_scans': 5103}
#
# Episode 20 (3674 chemicals)
# steps	 500 	total rewards	 25.522473809645174
# steps	 1000 	total rewards	 114.15714056217602
# steps	 1500 	total rewards	 204.21580497927928
# steps	 2000 	total rewards	 299.3048742247922
# steps	 2500 	total rewards	 396.7045500886137
# steps	 3000 	total rewards	 487.26387046120635
# steps	 3500 	total rewards	 566.0864235212412
# steps	 4000 	total rewards	 637.7504001896741
# steps	 4500 	total rewards	 702.110344298723
# steps	 5000 	total rewards	 777.0195909450114
# steps	 5500 	total rewards	 840.1788370071224
# steps	 6000 	total rewards	 905.737195413543
# Finished after 6352 timesteps (30.50305485725403 seconds) with total reward 948.2257307102025
# {'coverage_prop': '0.737', 'intensity_prop': '0.483', 'ms1ms2_ratio': '0.154', 'efficiency': '0.492', 'TP': '2033', 'FP': '673', 'FN': '968', 'precision': '0.751', 'recall': '0.677', 'f1': '0.712', 'total_rewards': 948.2257307102033, 'invalid_action_count': 0, 'num_ms1_scans': 848, 'num_ms2_scans': 5504}
#
# Episode 21 (4196 chemicals)
# steps	 500 	total rewards	 35.58050260032893
# steps	 1000 	total rewards	 118.02078908462846
# steps	 1500 	total rewards	 210.38531499817128
# steps	 2000 	total rewards	 305.6979841582589
# steps	 2500 	total rewards	 398.8539966540481
# steps	 3000 	total rewards	 495.6655764607369
# steps	 3500 	total rewards	 572.8933085981498
# steps	 4000 	total rewards	 644.1772152912893
# steps	 4500 	total rewards	 704.3257480413712
# steps	 5000 	total rewards	 775.601066662985
# steps	 5500 	total rewards	 842.8960557987252
# steps	 6000 	total rewards	 900.3631370135361
# Finished after 6406 timesteps (31.426873207092285 seconds) with total reward 953.6206503761351
# {'coverage_prop': '0.700', 'intensity_prop': '0.455', 'ms1ms2_ratio': '0.142', 'efficiency': '0.523', 'TP': '2183', 'FP': '754', 'FN': '1259', 'precision': '0.743', 'recall': '0.634', 'f1': '0.684', 'total_rewards': 953.6206503761382, 'invalid_action_count': 0, 'num_ms1_scans': 795, 'num_ms2_scans': 5611}
#
# Episode 22 (2541 chemicals)
# steps	 500 	total rewards	 22.93631777727024
# steps	 1000 	total rewards	 102.24648896469307
# steps	 1500 	total rewards	 181.5608285433433
# steps	 2000 	total rewards	 278.5686308025338
# steps	 2500 	total rewards	 379.089209787316
# steps	 3000 	total rewards	 466.8655872794144
# steps	 3500 	total rewards	 542.0221467583882
# steps	 4000 	total rewards	 599.2324670455757
# steps	 4500 	total rewards	 655.7073740788488
# steps	 5000 	total rewards	 720.5274707881622
# steps	 5500 	total rewards	 773.1337903575899
# Finished after 5970 timesteps (51.11135697364807 seconds) with total reward 821.1629177884647
# {'coverage_prop': '0.778', 'intensity_prop': '0.504', 'ms1ms2_ratio': '0.259', 'efficiency': '0.417', 'TP': '1443', 'FP': '535', 'FN': '563', 'precision': '0.730', 'recall': '0.719', 'f1': '0.724', 'total_rewards': 821.1629177884658, 'invalid_action_count': 0, 'num_ms1_scans': 1230, 'num_ms2_scans': 4740}
#
# Episode 23 (3254 chemicals)
# steps	 500 	total rewards	 23.50643195619583
# steps	 1000 	total rewards	 110.45193310794247
# steps	 1500 	total rewards	 199.38838247902999
# steps	 2000 	total rewards	 293.44085503091515
# steps	 2500 	total rewards	 384.11777572164374
# steps	 3000 	total rewards	 474.93922514510683
# steps	 3500 	total rewards	 553.0677602823355
# steps	 4000 	total rewards	 621.9725856664188
# steps	 4500 	total rewards	 680.5053282242752
# steps	 5000 	total rewards	 749.3829341020495
# steps	 5500 	total rewards	 811.6773644371438
# steps	 6000 	total rewards	 869.8313093536788
# Finished after 6146 timesteps (30.4213969707489 seconds) with total reward 884.2596340066611
# {'coverage_prop': '0.731', 'intensity_prop': '0.472', 'ms1ms2_ratio': '0.207', 'efficiency': '0.467', 'TP': '1755', 'FP': '623', 'FN': '876', 'precision': '0.738', 'recall': '0.667', 'f1': '0.701', 'total_rewards': 884.2596340066592, 'invalid_action_count': 0, 'num_ms1_scans': 1054, 'num_ms2_scans': 5092}
#
# Episode 24 (4358 chemicals)
# steps	 500 	total rewards	 32.80661145931806
# steps	 1000 	total rewards	 124.33520060401716
# steps	 1500 	total rewards	 216.76434020758785
# steps	 2000 	total rewards	 308.18151230955925
# steps	 2500 	total rewards	 398.2199853457574
# steps	 3000 	total rewards	 496.9358737136362
# steps	 3500 	total rewards	 580.4920431923375
# steps	 4000 	total rewards	 652.7827296011917
# steps	 4500 	total rewards	 717.8970299209693
# steps	 5000 	total rewards	 795.5174866619882
# steps	 5500 	total rewards	 863.4038916563524
# steps	 6000 	total rewards	 928.6371255082836
# Finished after 6403 timesteps (32.43097996711731 seconds) with total reward 982.6743804386062
# {'coverage_prop': '0.705', 'intensity_prop': '0.451', 'ms1ms2_ratio': '0.142', 'efficiency': '0.548', 'TP': '2230', 'FP': '843', 'FN': '1285', 'precision': '0.726', 'recall': '0.634', 'f1': '0.677', 'total_rewards': 982.6743804386093, 'invalid_action_count': 0, 'num_ms1_scans': 797, 'num_ms2_scans': 5606}
#
# Episode 25 (3301 chemicals)
# steps	 500 	total rewards	 27.876440291699957
# steps	 1000 	total rewards	 110.49552012323267
# steps	 1500 	total rewards	 193.9562250867428
# steps	 2000 	total rewards	 281.1944037318394
# steps	 2500 	total rewards	 373.5688779569542
# steps	 3000 	total rewards	 472.0925068643392
# steps	 3500 	total rewards	 550.1690305429684
# steps	 4000 	total rewards	 616.3157020502294
# steps	 4500 	total rewards	 671.163628504783
# steps	 5000 	total rewards	 734.0795063560296
# steps	 5500 	total rewards	 786.9527775664028
# steps	 6000 	total rewards	 836.8482204621671
# Finished after 6130 timesteps (30.547626972198486 seconds) with total reward 847.0076311785913
# {'coverage_prop': '0.748', 'intensity_prop': '0.482', 'ms1ms2_ratio': '0.211', 'efficiency': '0.488', 'TP': '1797', 'FP': '671', 'FN': '833', 'precision': '0.728', 'recall': '0.683', 'f1': '0.705', 'total_rewards': 847.0076311785916, 'invalid_action_count': 0, 'num_ms1_scans': 1070, 'num_ms2_scans': 5060}
#
# Episode 26 (4916 chemicals)
# steps	 500 	total rewards	 33.480359508680394
# steps	 1000 	total rewards	 124.66254373127353
# steps	 1500 	total rewards	 217.65436885842254
# steps	 2000 	total rewards	 314.90523679883006
# steps	 2500 	total rewards	 405.3338504708408
# steps	 3000 	total rewards	 499.8264672544602
# steps	 3500 	total rewards	 578.5490269455277
# steps	 4000 	total rewards	 645.6881728328689
# steps	 4500 	total rewards	 713.6942634247368
# steps	 5000 	total rewards	 789.9998004801506
# steps	 5500 	total rewards	 851.9649432281491
# steps	 6000 	total rewards	 918.437064650682
# Finished after 6427 timesteps (56.4105019569397 seconds) with total reward 973.5053064122973
# {'coverage_prop': '0.687', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.137', 'efficiency': '0.597', 'TP': '2427', 'FP': '951', 'FN': '1538', 'precision': '0.718', 'recall': '0.612', 'f1': '0.661', 'total_rewards': 973.5053064122982, 'invalid_action_count': 0, 'num_ms1_scans': 773, 'num_ms2_scans': 5654}
#
# Episode 27 (2655 chemicals)
# steps	 500 	total rewards	 20.946122411109517
# steps	 1000 	total rewards	 102.88690496892211
# steps	 1500 	total rewards	 182.92210636664734
# steps	 2000 	total rewards	 278.96455301919383
# steps	 2500 	total rewards	 370.7800705782671
# steps	 3000 	total rewards	 464.20650662922606
# steps	 3500 	total rewards	 542.4846132977467
# steps	 4000 	total rewards	 605.445512027544
# steps	 4500 	total rewards	 654.6637411100894
# steps	 5000 	total rewards	 716.4579239944261
# steps	 5500 	total rewards	 765.0155571744947
# Finished after 5952 timesteps (29.433727979660034 seconds) with total reward 805.3261761594565
# {'coverage_prop': '0.781', 'intensity_prop': '0.509', 'ms1ms2_ratio': '0.265', 'efficiency': '0.441', 'TP': '1546', 'FP': '527', 'FN': '582', 'precision': '0.746', 'recall': '0.727', 'f1': '0.736', 'total_rewards': 805.326176159456, 'invalid_action_count': 0, 'num_ms1_scans': 1248, 'num_ms2_scans': 4704}
#
# Episode 28 (4538 chemicals)
# steps	 500 	total rewards	 35.13729597841574
# steps	 1000 	total rewards	 127.07207131930863
# steps	 1500 	total rewards	 218.72732105812224
# steps	 2000 	total rewards	 311.4154866588141
# steps	 2500 	total rewards	 407.0320615467973
# steps	 3000 	total rewards	 502.5897570017673
# steps	 3500 	total rewards	 577.3461410398806
# steps	 4000 	total rewards	 647.8561918064514
# steps	 4500 	total rewards	 716.4605152071885
# steps	 5000 	total rewards	 792.6787573032561
# steps	 5500 	total rewards	 861.3804928034376
# steps	 6000 	total rewards	 920.9776154522085
# Finished after 6414 timesteps (31.803463220596313 seconds) with total reward 970.8878514986429
# {'coverage_prop': '0.687', 'intensity_prop': '0.444', 'ms1ms2_ratio': '0.140', 'efficiency': '0.554', 'TP': '2318', 'FP': '801', 'FN': '1419', 'precision': '0.743', 'recall': '0.620', 'f1': '0.676', 'total_rewards': 970.887851498642, 'invalid_action_count': 0, 'num_ms1_scans': 786, 'num_ms2_scans': 5628}
#
# Episode 29 (3171 chemicals)
# steps	 500 	total rewards	 26.273857173316422
# steps	 1000 	total rewards	 111.9256800448578
# steps	 1500 	total rewards	 196.81944686140756
# steps	 2000 	total rewards	 296.20597202613084
# steps	 2500 	total rewards	 388.82354625713236
# steps	 3000 	total rewards	 475.99211010007684
# steps	 3500 	total rewards	 554.9846099345801
# steps	 4000 	total rewards	 616.5861578641395
# steps	 4500 	total rewards	 673.6241268013665
# steps	 5000 	total rewards	 744.5971721858914
# steps	 5500 	total rewards	 798.0914813708464
# steps	 6000 	total rewards	 856.6976876364774
# Finished after 6138 timesteps (29.24184513092041 seconds) with total reward 868.7876339582626
# {'coverage_prop': '0.759', 'intensity_prop': '0.500', 'ms1ms2_ratio': '0.209', 'efficiency': '0.474', 'TP': '1790', 'FP': '616', 'FN': '765', 'precision': '0.744', 'recall': '0.701', 'f1': '0.722', 'total_rewards': 868.7876339582633, 'invalid_action_count': 0, 'num_ms1_scans': 1062, 'num_ms2_scans': 5076}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (70, 1000),
#   'rt_range': (0, 1440),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (2000, 5000),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f987086f0d0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f98708f2020>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f987094f580>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (70, 1000)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (0, 1440),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 15,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.418', 'efficiency': '0.499', 'TP': '1450', 'FP': '506', 'FN': '195', 'precision': '0.741', 'recall': '0.881', 'f1': '0.805'}
#
# Episode 1 finished
# {'coverage_prop': '0.801', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.149', 'efficiency': '0.592', 'TP': '2435', 'FP': '846', 'FN': '815', 'precision': '0.742', 'recall': '0.749', 'f1': '0.746'}
#
# Episode 2 finished
# {'coverage_prop': '0.858', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.185', 'efficiency': '0.540', 'TP': '2153', 'FP': '684', 'FN': '470', 'precision': '0.759', 'recall': '0.821', 'f1': '0.789'}
#
# Episode 3 finished
# {'coverage_prop': '0.871', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.214', 'efficiency': '0.518', 'TP': '1985', 'FP': '628', 'FN': '387', 'precision': '0.760', 'recall': '0.837', 'f1': '0.796'}
#
# Episode 4 finished
# {'coverage_prop': '0.804', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.144', 'efficiency': '0.646', 'TP': '2670', 'FP': '941', 'FN': '879', 'precision': '0.739', 'recall': '0.752', 'f1': '0.746'}
#
# Episode 5 finished
# {'coverage_prop': '0.898', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.256', 'efficiency': '0.467', 'TP': '1686', 'FP': '538', 'FN': '253', 'precision': '0.758', 'recall': '0.870', 'f1': '0.810'}
#
# Episode 6 finished
# {'coverage_prop': '0.843', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.182', 'efficiency': '0.528', 'TP': '2089', 'FP': '695', 'FN': '518', 'precision': '0.750', 'recall': '0.801', 'f1': '0.775'}
#
# Episode 7 finished
# {'coverage_prop': '0.904', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.257', 'efficiency': '0.450', 'TP': '1631', 'FP': '511', 'FN': '228', 'precision': '0.761', 'recall': '0.877', 'f1': '0.815'}
#
# Episode 8 finished
# {'coverage_prop': '0.869', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.215', 'efficiency': '0.521', 'TP': '1987', 'FP': '637', 'FN': '397', 'precision': '0.757', 'recall': '0.833', 'f1': '0.794'}
#
# Episode 9 finished
# {'coverage_prop': '0.861', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.193', 'efficiency': '0.506', 'TP': '1984', 'FP': '643', 'FN': '424', 'precision': '0.755', 'recall': '0.824', 'f1': '0.788'}
#
# Episode 10 finished
# {'coverage_prop': '0.779', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.143', 'efficiency': '0.678', 'TP': '2787', 'FP': '1010', 'FN': '1076', 'precision': '0.734', 'recall': '0.721', 'f1': '0.728'}
#
# Episode 11 finished
# {'coverage_prop': '0.823', 'intensity_prop': '0.541', 'ms1ms2_ratio': '0.178', 'efficiency': '0.583', 'TP': '2306', 'FP': '787', 'FN': '663', 'precision': '0.746', 'recall': '0.777', 'f1': '0.761'}
#
# Episode 12 finished
# {'coverage_prop': '0.808', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.141', 'efficiency': '0.705', 'TP': '2979', 'FP': '981', 'FN': '944', 'precision': '0.752', 'recall': '0.759', 'f1': '0.756'}
#
# Episode 13 finished
# {'coverage_prop': '0.851', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.180', 'efficiency': '0.557', 'TP': '2254', 'FP': '691', 'FN': '515', 'precision': '0.765', 'recall': '0.814', 'f1': '0.789'}
#
# Episode 14 finished
# {'coverage_prop': '0.920', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.348', 'efficiency': '0.438', 'TP': '1418', 'FP': '443', 'FN': '162', 'precision': '0.762', 'recall': '0.897', 'f1': '0.824'}
#
# Episode 15 finished
# {'coverage_prop': '0.820', 'intensity_prop': '0.543', 'ms1ms2_ratio': '0.153', 'efficiency': '0.618', 'TP': '2584', 'FP': '821', 'FN': '746', 'precision': '0.759', 'recall': '0.776', 'f1': '0.767'}
#
# Episode 16 finished
# {'coverage_prop': '0.811', 'intensity_prop': '0.532', 'ms1ms2_ratio': '0.144', 'efficiency': '0.627', 'TP': '2611', 'FP': '896', 'FN': '819', 'precision': '0.745', 'recall': '0.761', 'f1': '0.753'}
#
# Episode 17 finished
# {'coverage_prop': '0.820', 'intensity_prop': '0.542', 'ms1ms2_ratio': '0.146', 'efficiency': '0.608', 'TP': '2561', 'FP': '826', 'FN': '744', 'precision': '0.756', 'recall': '0.775', 'f1': '0.765'}
#
# Episode 18 finished
# {'coverage_prop': '0.792', 'intensity_prop': '0.508', 'ms1ms2_ratio': '0.134', 'efficiency': '0.680', 'TP': '2800', 'FP': '1065', 'FN': '1016', 'precision': '0.724', 'recall': '0.734', 'f1': '0.729'}
#
# Episode 19 finished
# {'coverage_prop': '0.840', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.206', 'efficiency': '0.575', 'TP': '2211', 'FP': '722', 'FN': '558', 'precision': '0.754', 'recall': '0.798', 'f1': '0.776'}
#
# Episode 20 finished
# {'coverage_prop': '0.834', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.153', 'efficiency': '0.555', 'TP': '2325', 'FP': '738', 'FN': '611', 'precision': '0.759', 'recall': '0.792', 'f1': '0.775'}
#
# Episode 21 finished
# {'coverage_prop': '0.811', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.141', 'efficiency': '0.606', 'TP': '2507', 'FP': '896', 'FN': '793', 'precision': '0.737', 'recall': '0.760', 'f1': '0.748'}
#
# Episode 22 finished
# {'coverage_prop': '0.884', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.258', 'efficiency': '0.473', 'TP': '1637', 'FP': '610', 'FN': '294', 'precision': '0.729', 'recall': '0.848', 'f1': '0.784'}
#
# Episode 23 finished
# {'coverage_prop': '0.845', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.206', 'efficiency': '0.540', 'TP': '2052', 'FP': '699', 'FN': '503', 'precision': '0.746', 'recall': '0.803', 'f1': '0.773'}
#
# Episode 24 finished
# {'coverage_prop': '0.814', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.142', 'efficiency': '0.632', 'TP': '2621', 'FP': '926', 'FN': '811', 'precision': '0.739', 'recall': '0.764', 'f1': '0.751'}
#
# Episode 25 finished
# {'coverage_prop': '0.859', 'intensity_prop': '0.562', 'ms1ms2_ratio': '0.211', 'efficiency': '0.560', 'TP': '2098', 'FP': '736', 'FN': '467', 'precision': '0.740', 'recall': '0.818', 'f1': '0.777'}
#
# Episode 26 finished
# {'coverage_prop': '0.790', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.137', 'efficiency': '0.687', 'TP': '2828', 'FP': '1056', 'FN': '1032', 'precision': '0.728', 'recall': '0.733', 'f1': '0.730'}
#
# Episode 27 finished
# {'coverage_prop': '0.888', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.265', 'efficiency': '0.501', 'TP': '1773', 'FP': '585', 'FN': '297', 'precision': '0.752', 'recall': '0.857', 'f1': '0.801'}
#
# Episode 28 finished
# {'coverage_prop': '0.796', 'intensity_prop': '0.519', 'ms1ms2_ratio': '0.140', 'efficiency': '0.642', 'TP': '2714', 'FP': '897', 'FN': '927', 'precision': '0.752', 'recall': '0.745', 'f1': '0.748'}
#
# Episode 29 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.209', 'efficiency': '0.536', 'TP': '2034', 'FP': '684', 'FN': '453', 'precision': '0.748', 'recall': '0.818', 'f1': '0.782'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (15, 15, 2, 0.5, 5)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.883', 'efficiency': '0.783', 'TP': '1514', 'FP': '523', 'FN': '114', 'precision': '0.743', 'recall': '0.930', 'f1': '0.826'}
#
# Episode 1 finished
# {'coverage_prop': '0.867', 'intensity_prop': '0.561', 'ms1ms2_ratio': '0.446', 'efficiency': '0.933', 'TP': '2601', 'FP': '949', 'FN': '546', 'precision': '0.733', 'recall': '0.827', 'f1': '0.777'}
#
# Episode 2 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.556', 'efficiency': '0.882', 'TP': '2253', 'FP': '754', 'FN': '300', 'precision': '0.749', 'recall': '0.882', 'f1': '0.810'}
#
# Episode 3 finished
# {'coverage_prop': '0.926', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.606', 'efficiency': '0.853', 'TP': '2082', 'FP': '696', 'FN': '222', 'precision': '0.749', 'recall': '0.904', 'f1': '0.819'}
#
# Episode 4 finished
# {'coverage_prop': '0.869', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.415', 'efficiency': '0.992', 'TP': '2906', 'FP': '997', 'FN': '587', 'precision': '0.745', 'recall': '0.832', 'f1': '0.786'}
#
# Episode 5 finished
# {'coverage_prop': '0.931', 'intensity_prop': '0.603', 'ms1ms2_ratio': '0.758', 'efficiency': '0.805', 'TP': '1669', 'FP': '636', 'FN': '172', 'precision': '0.724', 'recall': '0.907', 'f1': '0.805'}
#
# Episode 6 finished
# {'coverage_prop': '0.910', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.548', 'efficiency': '0.875', 'TP': '2254', 'FP': '752', 'FN': '296', 'precision': '0.750', 'recall': '0.884', 'f1': '0.811'}
#
# Episode 7 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.623', 'ms1ms2_ratio': '0.759', 'efficiency': '0.787', 'TP': '1657', 'FP': '595', 'FN': '118', 'precision': '0.736', 'recall': '0.934', 'f1': '0.823'}
#
# Episode 8 finished
# {'coverage_prop': '0.919', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.606', 'efficiency': '0.852', 'TP': '2043', 'FP': '732', 'FN': '246', 'precision': '0.736', 'recall': '0.893', 'f1': '0.807'}
#
# Episode 9 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.595', 'efficiency': '0.850', 'TP': '2110', 'FP': '685', 'FN': '256', 'precision': '0.755', 'recall': '0.892', 'f1': '0.818'}
#
# Episode 10 finished
# {'coverage_prop': '0.853', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.366', 'efficiency': '1.000', 'TP': '3088', 'FP': '1067', 'FN': '718', 'precision': '0.743', 'recall': '0.811', 'f1': '0.776'}
#
# Episode 11 finished
# {'coverage_prop': '0.878', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.499', 'efficiency': '0.916', 'TP': '2506', 'FP': '792', 'FN': '458', 'precision': '0.760', 'recall': '0.845', 'f1': '0.800'}
#
# Episode 12 finished
# {'coverage_prop': '0.867', 'intensity_prop': '0.566', 'ms1ms2_ratio': '0.363', 'efficiency': '1.020', 'TP': '3160', 'FP': '1093', 'FN': '651', 'precision': '0.743', 'recall': '0.829', 'f1': '0.784'}
#
# Episode 13 finished
# {'coverage_prop': '0.907', 'intensity_prop': '0.597', 'ms1ms2_ratio': '0.529', 'efficiency': '0.897', 'TP': '2338', 'FP': '801', 'FN': '321', 'precision': '0.745', 'recall': '0.879', 'f1': '0.806'}
#
# Episode 14 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.937', 'efficiency': '0.771', 'TP': '1398', 'FP': '533', 'FN': '92', 'precision': '0.724', 'recall': '0.938', 'f1': '0.817'}
#
# Episode 15 finished
# {'coverage_prop': '0.883', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.421', 'efficiency': '0.937', 'TP': '2730', 'FP': '935', 'FN': '486', 'precision': '0.745', 'recall': '0.849', 'f1': '0.793'}
#
# Episode 16 finished
# {'coverage_prop': '0.867', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.410', 'efficiency': '0.948', 'TP': '2813', 'FP': '938', 'FN': '575', 'precision': '0.750', 'recall': '0.830', 'f1': '0.788'}
#
# Episode 17 finished
# {'coverage_prop': '0.883', 'intensity_prop': '0.585', 'ms1ms2_ratio': '0.423', 'efficiency': '0.935', 'TP': '2743', 'FP': '905', 'FN': '483', 'precision': '0.752', 'recall': '0.850', 'f1': '0.798'}
#
# Episode 18 finished
# {'coverage_prop': '0.857', 'intensity_prop': '0.554', 'ms1ms2_ratio': '0.364', 'efficiency': '1.004', 'TP': '3060', 'FP': '1124', 'FN': '697', 'precision': '0.731', 'recall': '0.814', 'f1': '0.771'}
#
# Episode 19 finished
# {'coverage_prop': '0.898', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.515', 'efficiency': '0.883', 'TP': '2314', 'FP': '820', 'FN': '357', 'precision': '0.738', 'recall': '0.866', 'f1': '0.797'}
#
# Episode 20 finished
# {'coverage_prop': '0.903', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.491', 'efficiency': '0.913', 'TP': '2485', 'FP': '833', 'FN': '356', 'precision': '0.749', 'recall': '0.875', 'f1': '0.807'}
#
# Episode 21 finished
# {'coverage_prop': '0.873', 'intensity_prop': '0.573', 'ms1ms2_ratio': '0.425', 'efficiency': '0.941', 'TP': '2746', 'FP': '917', 'FN': '533', 'precision': '0.750', 'recall': '0.837', 'f1': '0.791'}
#
# Episode 22 finished
# {'coverage_prop': '0.932', 'intensity_prop': '0.608', 'ms1ms2_ratio': '0.712', 'efficiency': '0.798', 'TP': '1744', 'FP': '625', 'FN': '172', 'precision': '0.736', 'recall': '0.910', 'f1': '0.814'}
#
# Episode 23 finished
# {'coverage_prop': '0.906', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.557', 'efficiency': '0.865', 'TP': '2227', 'FP': '720', 'FN': '307', 'precision': '0.756', 'recall': '0.879', 'f1': '0.813'}
#
# Episode 24 finished
# {'coverage_prop': '0.873', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.405', 'efficiency': '0.956', 'TP': '2791', 'FP': '1013', 'FN': '554', 'precision': '0.734', 'recall': '0.834', 'f1': '0.781'}
#
# Episode 25 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.531', 'efficiency': '0.866', 'TP': '2268', 'FP': '755', 'FN': '278', 'precision': '0.750', 'recall': '0.891', 'f1': '0.815'}
#
# Episode 26 finished
# {'coverage_prop': '0.859', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.368', 'efficiency': '1.018', 'TP': '3097', 'FP': '1127', 'FN': '692', 'precision': '0.733', 'recall': '0.817', 'f1': '0.773'}
#
# Episode 27 finished
# {'coverage_prop': '0.934', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.673', 'efficiency': '0.808', 'TP': '1857', 'FP': '622', 'FN': '176', 'precision': '0.749', 'recall': '0.913', 'f1': '0.823'}
#
# Episode 28 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.568', 'ms1ms2_ratio': '0.382', 'efficiency': '0.962', 'TP': '2918', 'FP': '1010', 'FN': '610', 'precision': '0.743', 'recall': '0.827', 'f1': '0.783'}
#
# Episode 29 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.563', 'efficiency': '0.858', 'TP': '2177', 'FP': '729', 'FN': '265', 'precision': '0.749', 'recall': '0.891', 'f1': '0.814'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.122', 'efficiency': '0.353', 'TP': '1735', 'FP': '312', 'FN': '104', 'precision': '0.848', 'recall': '0.943', 'f1': '0.893'}
#
# Episode 1 finished
# {'coverage_prop': '0.870', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.113', 'efficiency': '0.608', 'TP': '2697', 'FP': '868', 'FN': '531', 'precision': '0.757', 'recall': '0.836', 'f1': '0.794'}
#
# Episode 2 finished
# {'coverage_prop': '0.917', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.113', 'efficiency': '0.516', 'TP': '2422', 'FP': '610', 'FN': '275', 'precision': '0.799', 'recall': '0.898', 'f1': '0.846'}
#
# Episode 3 finished
# {'coverage_prop': '0.930', 'intensity_prop': '0.650', 'ms1ms2_ratio': '0.103', 'efficiency': '0.467', 'TP': '2265', 'FP': '525', 'FN': '210', 'precision': '0.812', 'recall': '0.915', 'f1': '0.860'}
#
# Episode 4 finished
# {'coverage_prop': '0.874', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.099', 'efficiency': '0.653', 'TP': '2954', 'FP': '971', 'FN': '565', 'precision': '0.753', 'recall': '0.839', 'f1': '0.794'}
#
# Episode 5 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.656', 'ms1ms2_ratio': '0.122', 'efficiency': '0.403', 'TP': '1894', 'FP': '436', 'FN': '147', 'precision': '0.813', 'recall': '0.928', 'f1': '0.867'}
#
# Episode 6 finished
# {'coverage_prop': '0.910', 'intensity_prop': '0.626', 'ms1ms2_ratio': '0.114', 'efficiency': '0.512', 'TP': '2387', 'FP': '617', 'FN': '298', 'precision': '0.795', 'recall': '0.889', 'f1': '0.839'}
#
# Episode 7 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.676', 'ms1ms2_ratio': '0.123', 'efficiency': '0.391', 'TP': '1888', 'FP': '370', 'FN': '112', 'precision': '0.836', 'recall': '0.944', 'f1': '0.887'}
#
# Episode 8 finished
# {'coverage_prop': '0.931', 'intensity_prop': '0.639', 'ms1ms2_ratio': '0.116', 'efficiency': '0.481', 'TP': '2231', 'FP': '581', 'FN': '209', 'precision': '0.793', 'recall': '0.914', 'f1': '0.850'}
#
# Episode 9 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.641', 'ms1ms2_ratio': '0.110', 'efficiency': '0.476', 'TP': '2268', 'FP': '543', 'FN': '240', 'precision': '0.807', 'recall': '0.904', 'f1': '0.853'}
#
# Episode 10 finished
# {'coverage_prop': '0.849', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.104', 'efficiency': '0.694', 'TP': '3110', 'FP': '1026', 'FN': '737', 'precision': '0.752', 'recall': '0.808', 'f1': '0.779'}
#
# Episode 11 finished
# {'coverage_prop': '0.886', 'intensity_prop': '0.605', 'ms1ms2_ratio': '0.098', 'efficiency': '0.553', 'TP': '2610', 'FP': '717', 'FN': '429', 'precision': '0.784', 'recall': '0.859', 'f1': '0.820'}
#
# Episode 12 finished
# {'coverage_prop': '0.872', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.099', 'efficiency': '0.712', 'TP': '3200', 'FP': '1074', 'FN': '630', 'precision': '0.749', 'recall': '0.836', 'f1': '0.790'}
#
# Episode 13 finished
# {'coverage_prop': '0.909', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.105', 'efficiency': '0.529', 'TP': '2470', 'FP': '675', 'FN': '315', 'precision': '0.785', 'recall': '0.887', 'f1': '0.833'}
#
# Episode 14 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.134', 'efficiency': '0.342', 'TP': '1644', 'FP': '298', 'FN': '81', 'precision': '0.847', 'recall': '0.953', 'f1': '0.897'}
#
# Episode 15 finished
# {'coverage_prop': '0.880', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.108', 'efficiency': '0.617', 'TP': '2811', 'FP': '843', 'FN': '497', 'precision': '0.769', 'recall': '0.850', 'f1': '0.808'}
#
# Episode 16 finished
# {'coverage_prop': '0.868', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.104', 'efficiency': '0.630', 'TP': '2859', 'FP': '897', 'FN': '570', 'precision': '0.761', 'recall': '0.834', 'f1': '0.796'}
#
# Episode 17 finished
# {'coverage_prop': '0.884', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.113', 'efficiency': '0.622', 'TP': '2752', 'FP': '899', 'FN': '480', 'precision': '0.754', 'recall': '0.851', 'f1': '0.800'}
#
# Episode 18 finished
# {'coverage_prop': '0.849', 'intensity_prop': '0.550', 'ms1ms2_ratio': '0.088', 'efficiency': '0.677', 'TP': '3042', 'FP': '1102', 'FN': '737', 'precision': '0.734', 'recall': '0.805', 'f1': '0.768'}
#
# Episode 19 finished
# {'coverage_prop': '0.897', 'intensity_prop': '0.615', 'ms1ms2_ratio': '0.108', 'efficiency': '0.529', 'TP': '2500', 'FP': '633', 'FN': '358', 'precision': '0.798', 'recall': '0.875', 'f1': '0.835'}
#
# Episode 20 finished
# {'coverage_prop': '0.902', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.109', 'efficiency': '0.561', 'TP': '2530', 'FP': '784', 'FN': '360', 'precision': '0.763', 'recall': '0.875', 'f1': '0.816'}
#
# Episode 21 finished
# {'coverage_prop': '0.877', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.094', 'efficiency': '0.607', 'TP': '2777', 'FP': '902', 'FN': '517', 'precision': '0.755', 'recall': '0.843', 'f1': '0.797'}
#
# Episode 22 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.657', 'ms1ms2_ratio': '0.112', 'efficiency': '0.408', 'TP': '1930', 'FP': '469', 'FN': '142', 'precision': '0.805', 'recall': '0.931', 'f1': '0.863'}
#
# Episode 23 finished
# {'coverage_prop': '0.912', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.112', 'efficiency': '0.505', 'TP': '2356', 'FP': '611', 'FN': '287', 'precision': '0.794', 'recall': '0.891', 'f1': '0.840'}
#
# Episode 24 finished
# {'coverage_prop': '0.885', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.092', 'efficiency': '0.635', 'TP': '2867', 'FP': '990', 'FN': '501', 'precision': '0.743', 'recall': '0.851', 'f1': '0.794'}
#
# Episode 25 finished
# {'coverage_prop': '0.916', 'intensity_prop': '0.627', 'ms1ms2_ratio': '0.107', 'efficiency': '0.510', 'TP': '2386', 'FP': '638', 'FN': '277', 'precision': '0.789', 'recall': '0.896', 'f1': '0.839'}
#
# Episode 26 finished
# {'coverage_prop': '0.860', 'intensity_prop': '0.561', 'ms1ms2_ratio': '0.093', 'efficiency': '0.697', 'TP': '3127', 'FP': '1103', 'FN': '686', 'precision': '0.739', 'recall': '0.820', 'f1': '0.778'}
#
# Episode 27 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.659', 'ms1ms2_ratio': '0.119', 'efficiency': '0.429', 'TP': '2041', 'FP': '455', 'FN': '159', 'precision': '0.818', 'recall': '0.928', 'f1': '0.869'}
#
# Episode 28 finished
# {'coverage_prop': '0.866', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.095', 'efficiency': '0.650', 'TP': '2972', 'FP': '956', 'FN': '610', 'precision': '0.757', 'recall': '0.830', 'f1': '0.791'}
#
# Episode 29 finished
# {'coverage_prop': '0.918', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.112', 'efficiency': '0.495', 'TP': '2314', 'FP': '598', 'FN': '259', 'precision': '0.795', 'recall': '0.899', 'f1': '0.844'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     851.499568                   0.0          0.748           0.474
# 1  random     972.731185                   0.0          0.680           0.392
# 2  random     968.666228                   0.0          0.702           0.413
# 3  random     946.455606                   0.0          0.723           0.445
# 4  random    1004.923251                   0.0          0.665           0.377
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.097       0.267      0.707   0.677  0.692
# 1          0.060       0.433      0.625   0.570  0.597
# 2          0.065       0.365      0.648   0.605  0.626
# 3          0.065       0.340      0.675   0.638  0.656
# 4          0.055       0.460      0.616   0.550  0.581

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'DQN'

# %%
df = pd.read_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'DQN']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     851.499568                   0.0          0.748           0.474
# 1  random     972.731185                   0.0          0.680           0.392
# 2  random     968.666228                   0.0          0.702           0.413
# 3  random     946.455606                   0.0          0.723           0.445
# 4  random    1004.923251                   0.0          0.665           0.377
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.097       0.267      0.707   0.677  0.692
# 1          0.060       0.433      0.625   0.570  0.597
# 2          0.065       0.365      0.648   0.605  0.626
# 3          0.065       0.340      0.675   0.638  0.656
# 4          0.055       0.460      0.616   0.550  0.581

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
