# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-06 00:48:03.524 | INFO     | experiments:get_samplers:267 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf395a4b50>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf4d65d3d0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf4d679670>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf395a4b50>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf4d65d3d0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf4d679670>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf395a4b50>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf4d65d3d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf4d679670>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -483.22866852496816
# steps	 1000 	total rewards	 -970.795661778182
# steps	 1500 	total rewards	 -1448.8517743903562
# Finished after 1990 timesteps (1.7901623249053955 seconds) with total reward -1882.628629975629
# {'coverage_prop': '0.258', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.005', 'efficiency': '0.056', 'TP': '22', 'FP': '88', 'FN': '316', 'precision': '0.200', 'recall': '0.065', 'f1': '0.098', 'total_rewards': -1882.6286299756289, 'invalid_action_count': 1914, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -485.3086421335659
# steps	 1000 	total rewards	 -971.3294370341512
# steps	 1500 	total rewards	 -1470.3294370341514
# Finished after 1993 timesteps (0.9151887893676758 seconds) with total reward -1948.7218991801137
# {'coverage_prop': '0.092', 'intensity_prop': '0.033', 'ms1ms2_ratio': '0.004', 'efficiency': '0.012', 'TP': '8', 'FP': '16', 'FN': '238', 'precision': '0.333', 'recall': '0.033', 'f1': '0.059', 'total_rewards': -1948.721899180114, 'invalid_action_count': 1960, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -960.4008528561944
# steps	 1500 	total rewards	 -1401.023235060541
# Finished after 1990 timesteps (1.3783340454101562 seconds) with total reward -1843.6237658780049
# {'coverage_prop': '0.381', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.005', 'efficiency': '0.076', 'TP': '33', 'FP': '117', 'FN': '244', 'precision': '0.220', 'recall': '0.119', 'f1': '0.155', 'total_rewards': -1843.6237658780049, 'invalid_action_count': 1888, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -477.50676237845613
# steps	 1000 	total rewards	 -941.0416287375065
# steps	 1500 	total rewards	 -1430.5153270125634
# Finished after 1991 timesteps (1.4096479415893555 seconds) with total reward -1863.5266165951125
# {'coverage_prop': '0.277', 'intensity_prop': '0.072', 'ms1ms2_ratio': '0.005', 'efficiency': '0.063', 'TP': '28', 'FP': '97', 'FN': '327', 'precision': '0.224', 'recall': '0.079', 'f1': '0.117', 'total_rewards': -1863.526616595112, 'invalid_action_count': 1903, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -481.764735318144
# steps	 1000 	total rewards	 -973.5130546441696
# steps	 1500 	total rewards	 -1403.5887998594012
# Finished after 1987 timesteps (1.437063217163086 seconds) with total reward -1827.0564434095827
# {'coverage_prop': '0.364', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.007', 'efficiency': '0.081', 'TP': '44', 'FP': '115', 'FN': '278', 'precision': '0.277', 'recall': '0.137', 'f1': '0.183', 'total_rewards': -1827.0564434095827, 'invalid_action_count': 1874, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -482.2541642586311
# steps	 1000 	total rewards	 -962.9780170503336
# steps	 1500 	total rewards	 -1439.1245692152163
# Finished after 1989 timesteps (0.8740179538726807 seconds) with total reward -1905.8463337677215
# {'coverage_prop': '0.350', 'intensity_prop': '0.098', 'ms1ms2_ratio': '0.006', 'efficiency': '0.035', 'TP': '18', 'FP': '52', 'FN': '130', 'precision': '0.257', 'recall': '0.122', 'f1': '0.165', 'total_rewards': -1905.8463337677215, 'invalid_action_count': 1928, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -497.0
# steps	 1000 	total rewards	 -970.4042383625397
# steps	 1500 	total rewards	 -1386.34007496636
# Finished after 1990 timesteps (1.4959049224853516 seconds) with total reward -1841.9571660674467
# {'coverage_prop': '0.295', 'intensity_prop': '0.068', 'ms1ms2_ratio': '0.005', 'efficiency': '0.071', 'TP': '26', 'FP': '115', 'FN': '337', 'precision': '0.184', 'recall': '0.072', 'f1': '0.103', 'total_rewards': -1841.957166067447, 'invalid_action_count': 1885, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -497.388649278928
# steps	 1000 	total rewards	 -964.3911857968965
# steps	 1500 	total rewards	 -1442.4698709561965
# Finished after 1989 timesteps (0.9163799285888672 seconds) with total reward -1905.8702330098115
# {'coverage_prop': '0.279', 'intensity_prop': '0.069', 'ms1ms2_ratio': '0.006', 'efficiency': '0.029', 'TP': '13', 'FP': '44', 'FN': '147', 'precision': '0.228', 'recall': '0.081', 'f1': '0.120', 'total_rewards': -1905.8702330098117, 'invalid_action_count': 1929, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -485.90955287176035
# steps	 1000 	total rewards	 -939.038096634757
# steps	 1500 	total rewards	 -1351.282310771786
# Finished after 1989 timesteps (1.8390491008758545 seconds) with total reward -1825.8659611768358
# {'coverage_prop': '0.368', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.006', 'efficiency': '0.079', 'TP': '27', 'FP': '129', 'FN': '268', 'precision': '0.173', 'recall': '0.092', 'f1': '0.120', 'total_rewards': -1825.8659611768353, 'invalid_action_count': 1872, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -483.27771082952995
# steps	 1000 	total rewards	 -948.1131976554357
# steps	 1500 	total rewards	 -1391.92350833567
# Finished after 1989 timesteps (1.22481107711792 seconds) with total reward -1833.5797237470865
# {'coverage_prop': '0.409', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.006', 'efficiency': '0.079', 'TP': '34', 'FP': '123', 'FN': '227', 'precision': '0.217', 'recall': '0.130', 'f1': '0.163', 'total_rewards': -1833.579723747086, 'invalid_action_count': 1878, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -486.2172277707567
# steps	 1000 	total rewards	 -935.9559034439615
# steps	 1500 	total rewards	 -1355.6806076820799
# Finished after 1992 timesteps (1.425464153289795 seconds) with total reward -1800.1255476837869
# {'coverage_prop': '0.429', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.004', 'efficiency': '0.096', 'TP': '49', 'FP': '141', 'FN': '253', 'precision': '0.258', 'recall': '0.162', 'f1': '0.199', 'total_rewards': -1800.1255476837866, 'invalid_action_count': 1859, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -489.17997103932606
# steps	 1000 	total rewards	 -948.9986402328016
# steps	 1500 	total rewards	 -1437.0283535257688
# Finished after 1990 timesteps (0.967531681060791 seconds) with total reward -1923.0283535257688
# {'coverage_prop': '0.209', 'intensity_prop': '0.047', 'ms1ms2_ratio': '0.005', 'efficiency': '0.026', 'TP': '12', 'FP': '40', 'FN': '197', 'precision': '0.231', 'recall': '0.057', 'f1': '0.092', 'total_rewards': -1923.0283535257688, 'invalid_action_count': 1941, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -971.6089507790767
# steps	 1500 	total rewards	 -1424.0789551209282
# Finished after 1994 timesteps (1.0151269435882568 seconds) with total reward -1901.5042315695882
# {'coverage_prop': '0.319', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.003', 'efficiency': '0.040', 'TP': '18', 'FP': '62', 'FN': '171', 'precision': '0.225', 'recall': '0.095', 'f1': '0.134', 'total_rewards': -1901.5042315695885, 'invalid_action_count': 1929, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -491.54463515918246
# steps	 1000 	total rewards	 -983.8600232166925
# steps	 1500 	total rewards	 -1422.5357839066219
# Finished after 1992 timesteps (1.6598100662231445 seconds) with total reward -1876.470724696494
# {'coverage_prop': '0.333', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.004', 'efficiency': '0.050', 'TP': '21', 'FP': '79', 'FN': '200', 'precision': '0.210', 'recall': '0.095', 'f1': '0.131', 'total_rewards': -1876.4707246964938, 'invalid_action_count': 1909, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -491.8537166578328
# steps	 1000 	total rewards	 -950.7995279286408
# steps	 1500 	total rewards	 -1436.865688346584
# Finished after 1987 timesteps (1.559314250946045 seconds) with total reward -1899.4874895889363
# {'coverage_prop': '0.257', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.007', 'efficiency': '0.027', 'TP': '14', 'FP': '39', 'FN': '153', 'precision': '0.264', 'recall': '0.084', 'f1': '0.127', 'total_rewards': -1899.4874895889366, 'invalid_action_count': 1921, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -478.104201733151
# steps	 1000 	total rewards	 -920.4829582987711
# steps	 1500 	total rewards	 -1340.8483923139004
# Finished after 1981 timesteps (1.4571049213409424 seconds) with total reward -1775.3925687873357
# {'coverage_prop': '0.472', 'intensity_prop': '0.146', 'ms1ms2_ratio': '0.010', 'efficiency': '0.098', 'TP': '57', 'FP': '135', 'FN': '215', 'precision': '0.297', 'recall': '0.210', 'f1': '0.246', 'total_rewards': -1775.3925687873364, 'invalid_action_count': 1836, 'num_ms1_scans': 19, 'num_ms2_scans': 1962}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -481.57532657891056
# steps	 1000 	total rewards	 -928.6488737032173
# steps	 1500 	total rewards	 -1334.5180066232595
# Finished after 1990 timesteps (1.6899309158325195 seconds) with total reward -1791.5993814903138
# {'coverage_prop': '0.406', 'intensity_prop': '0.105', 'ms1ms2_ratio': '0.005', 'efficiency': '0.102', 'TP': '48', 'FP': '154', 'FN': '296', 'precision': '0.238', 'recall': '0.140', 'f1': '0.176', 'total_rewards': -1791.5993814903138, 'invalid_action_count': 1850, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -480.04418070812693
# steps	 1000 	total rewards	 -952.0766577508431
# steps	 1500 	total rewards	 -1415.8971483452435
# Finished after 1989 timesteps (1.2972080707550049 seconds) with total reward -1876.3328276692546
# {'coverage_prop': '0.269', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.006', 'efficiency': '0.051', 'TP': '24', 'FP': '76', 'FN': '272', 'precision': '0.240', 'recall': '0.081', 'f1': '0.121', 'total_rewards': -1876.3328276692544, 'invalid_action_count': 1908, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -483.2138048644286
# steps	 1000 	total rewards	 -953.7332500649784
# steps	 1500 	total rewards	 -1414.4042912368873
# Finished after 1991 timesteps (1.1519060134887695 seconds) with total reward -1896.6092843787703
# {'coverage_prop': '0.258', 'intensity_prop': '0.058', 'ms1ms2_ratio': '0.005', 'efficiency': '0.039', 'TP': '14', 'FP': '64', 'FN': '224', 'precision': '0.179', 'recall': '0.059', 'f1': '0.089', 'total_rewards': -1896.609284378771, 'invalid_action_count': 1924, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -491.589534337548
# steps	 1000 	total rewards	 -967.9614850926777
# steps	 1500 	total rewards	 -1410.917077103969
# Finished after 1989 timesteps (2.04998517036438 seconds) with total reward -1867.490994847586
# {'coverage_prop': '0.351', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.006', 'efficiency': '0.047', 'TP': '20', 'FP': '73', 'FN': '172', 'precision': '0.215', 'recall': '0.104', 'f1': '0.140', 'total_rewards': -1867.4909948475863, 'invalid_action_count': 1900, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -491.6910507943235
# steps	 1000 	total rewards	 -947.519595279759
# steps	 1500 	total rewards	 -1384.7220069038415
# Finished after 1993 timesteps (1.616570234298706 seconds) with total reward -1831.8194823630683
# {'coverage_prop': '0.380', 'intensity_prop': '0.086', 'ms1ms2_ratio': '0.004', 'efficiency': '0.090', 'TP': '35', 'FP': '143', 'FN': '290', 'precision': '0.197', 'recall': '0.108', 'f1': '0.139', 'total_rewards': -1831.819482363068, 'invalid_action_count': 1882, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -483.24282013969116
# steps	 1000 	total rewards	 -957.6239315127937
# steps	 1500 	total rewards	 -1437.7849326952596
# Finished after 1991 timesteps (1.0255908966064453 seconds) with total reward -1897.9747064137916
# {'coverage_prop': '0.316', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.005', 'efficiency': '0.037', 'TP': '14', 'FP': '60', 'FN': '160', 'precision': '0.189', 'recall': '0.080', 'f1': '0.113', 'total_rewards': -1897.9747064137914, 'invalid_action_count': 1926, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -492.160574136447
# steps	 1000 	total rewards	 -976.648813285913
# steps	 1500 	total rewards	 -1439.2984224358943
# Finished after 1991 timesteps (1.2351868152618408 seconds) with total reward -1892.081778656197
# {'coverage_prop': '0.273', 'intensity_prop': '0.067', 'ms1ms2_ratio': '0.005', 'efficiency': '0.044', 'TP': '21', 'FP': '67', 'FN': '234', 'precision': '0.239', 'recall': '0.082', 'f1': '0.122', 'total_rewards': -1892.0817786561963, 'invalid_action_count': 1920, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -971.8398653410104
# steps	 1500 	total rewards	 -1426.7947273219597
# Finished after 1992 timesteps (1.3419609069824219 seconds) with total reward -1896.7948155501133
# {'coverage_prop': '0.258', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.004', 'efficiency': '0.040', 'TP': '19', 'FP': '61', 'FN': '230', 'precision': '0.237', 'recall': '0.076', 'f1': '0.116', 'total_rewards': -1896.7948155501133, 'invalid_action_count': 1924, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -471.6273638845022
# steps	 1000 	total rewards	 -953.0782759954086
# steps	 1500 	total rewards	 -1393.5337013167443
# Finished after 1989 timesteps (1.4285821914672852 seconds) with total reward -1842.0526087857784
# {'coverage_prop': '0.359', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.006', 'efficiency': '0.063', 'TP': '20', 'FP': '104', 'FN': '221', 'precision': '0.161', 'recall': '0.083', 'f1': '0.110', 'total_rewards': -1842.0526087857781, 'invalid_action_count': 1886, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -490.54088703889926
# steps	 1000 	total rewards	 -950.7047109494417
# steps	 1500 	total rewards	 -1438.7022806810614
# Finished after 1994 timesteps (1.9695978164672852 seconds) with total reward -1906.7108055650162
# {'coverage_prop': '0.247', 'intensity_prop': '0.047', 'ms1ms2_ratio': '0.003', 'efficiency': '0.049', 'TP': '13', 'FP': '85', 'FN': '298', 'precision': '0.133', 'recall': '0.042', 'f1': '0.064', 'total_rewards': -1906.7108055650162, 'invalid_action_count': 1934, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -487.4692647814918
# steps	 1000 	total rewards	 -986.4692647814918
# steps	 1500 	total rewards	 -1446.6031734307694
# Finished after 1991 timesteps (1.2449452877044678 seconds) with total reward -1911.2180302244913
# {'coverage_prop': '0.330', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.005', 'efficiency': '0.034', 'TP': '15', 'FP': '52', 'FN': '136', 'precision': '0.224', 'recall': '0.099', 'f1': '0.138', 'total_rewards': -1911.2180302244915, 'invalid_action_count': 1934, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -487.62923452679127
# steps	 1000 	total rewards	 -969.2935673335857
# steps	 1500 	total rewards	 -1426.8740559657306
# Finished after 1990 timesteps (1.168748140335083 seconds) with total reward -1891.730468927982
# {'coverage_prop': '0.292', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.005', 'efficiency': '0.041', 'TP': '17', 'FP': '65', 'FN': '199', 'precision': '0.207', 'recall': '0.079', 'f1': '0.114', 'total_rewards': -1891.7304689279815, 'invalid_action_count': 1922, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -482.1136794108623
# steps	 1000 	total rewards	 -906.6330341707426
# steps	 1500 	total rewards	 -1318.1357162876352
# Finished after 1990 timesteps (1.8864328861236572 seconds) with total reward -1746.538121295448
# {'coverage_prop': '0.428', 'intensity_prop': '0.137', 'ms1ms2_ratio': '0.005', 'efficiency': '0.107', 'TP': '70', 'FP': '141', 'FN': '282', 'precision': '0.332', 'recall': '0.199', 'f1': '0.249', 'total_rewards': -1746.5381212954478, 'invalid_action_count': 1819, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -489.00945852420773
# steps	 1000 	total rewards	 -949.0367085252959
# steps	 1500 	total rewards	 -1401.069012818725
# Finished after 1988 timesteps (1.4647080898284912 seconds) with total reward -1846.2628522725631
# {'coverage_prop': '0.408', 'intensity_prop': '0.106', 'ms1ms2_ratio': '0.006', 'efficiency': '0.063', 'TP': '31', 'FP': '93', 'FN': '180', 'precision': '0.250', 'recall': '0.147', 'f1': '0.185', 'total_rewards': -1846.2628522725631, 'invalid_action_count': 1888, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.34GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 70.07092937570438
# steps	 1000 	total rewards	 164.19339950461682
# steps	 1500 	total rewards	 250.94253969276213
# Finished after 1695 timesteps (6.293052911758423 seconds) with total reward 274.39080835095217
# {'coverage_prop': '0.955', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.219', 'efficiency': '0.293', 'TP': '332', 'FP': '75', 'FN': '19', 'precision': '0.816', 'recall': '0.946', 'f1': '0.876', 'total_rewards': 274.39080835095194, 'invalid_action_count': 6, 'num_ms1_scans': 305, 'num_ms2_scans': 1390}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 60.26758515611918
# steps	 1000 	total rewards	 135.75445409131552
# steps	 1500 	total rewards	 205.66018481781563
# Finished after 1646 timesteps (4.353474855422974 seconds) with total reward 221.03951984986816
# {'coverage_prop': '0.954', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.274', 'efficiency': '0.193', 'TP': '234', 'FP': '16', 'FN': '12', 'precision': '0.936', 'recall': '0.951', 'f1': '0.944', 'total_rewards': 221.03951984986796, 'invalid_action_count': 3, 'num_ms1_scans': 354, 'num_ms2_scans': 1292}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 60.59975975790698
# steps	 1000 	total rewards	 150.61867063598248
# steps	 1500 	total rewards	 234.08327587390244
# Finished after 1616 timesteps (6.9728381633758545 seconds) with total reward 245.5262692703355
# {'coverage_prop': '0.957', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.312', 'efficiency': '0.306', 'TP': '306', 'FP': '71', 'FN': '17', 'precision': '0.812', 'recall': '0.947', 'f1': '0.874', 'total_rewards': 245.5262692703357, 'invalid_action_count': 8, 'num_ms1_scans': 384, 'num_ms2_scans': 1232}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 73.75501680636185
# steps	 1000 	total rewards	 162.9708283266715
# steps	 1500 	total rewards	 243.7605231724092
# Finished after 1698 timesteps (5.786926984786987 seconds) with total reward 274.89744936176623
# {'coverage_prop': '0.954', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.216', 'efficiency': '0.309', 'TP': '384', 'FP': '47', 'FN': '21', 'precision': '0.891', 'recall': '0.948', 'f1': '0.919', 'total_rewards': 274.89744936176606, 'invalid_action_count': 7, 'num_ms1_scans': 302, 'num_ms2_scans': 1396}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 63.90197583684802
# steps	 1000 	total rewards	 162.59296795181965
# steps	 1500 	total rewards	 246.67036122307059
# Finished after 1646 timesteps (5.873642921447754 seconds) with total reward 262.7882563135804
# {'coverage_prop': '0.966', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.274', 'efficiency': '0.327', 'TP': '351', 'FP': '71', 'FN': '15', 'precision': '0.832', 'recall': '0.959', 'f1': '0.891', 'total_rewards': 262.78825631358, 'invalid_action_count': 6, 'num_ms1_scans': 354, 'num_ms2_scans': 1292}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 46.45461731308974
# steps	 1000 	total rewards	 112.6318611128803
# steps	 1500 	total rewards	 164.22147604077975
# Finished after 1596 timesteps (6.986584901809692 seconds) with total reward 172.02563138151186
# {'coverage_prop': '0.960', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.340', 'efficiency': '0.161', 'TP': '179', 'FP': '13', 'FN': '8', 'precision': '0.932', 'recall': '0.957', 'f1': '0.945', 'total_rewards': 172.02563138151183, 'invalid_action_count': 7, 'num_ms1_scans': 405, 'num_ms2_scans': 1191}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 70.09158429818464
# steps	 1000 	total rewards	 170.26334586200176
# steps	 1500 	total rewards	 251.638280464595
# Finished after 1674 timesteps (5.6656811237335205 seconds) with total reward 275.8663368806657
# {'coverage_prop': '0.937', 'intensity_prop': '0.666', 'ms1ms2_ratio': '0.242', 'efficiency': '0.332', 'TP': '370', 'FP': '78', 'FN': '30', 'precision': '0.826', 'recall': '0.925', 'f1': '0.873', 'total_rewards': 275.86633688066536, 'invalid_action_count': 6, 'num_ms1_scans': 326, 'num_ms2_scans': 1348}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 45.40770142989277
# steps	 1000 	total rewards	 120.90809452238713
# steps	 1500 	total rewards	 175.88589798147106
# Finished after 1562 timesteps (4.562541961669922 seconds) with total reward 179.60130051971942
# {'coverage_prop': '0.956', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.390', 'efficiency': '0.173', 'TP': '178', 'FP': '17', 'FN': '9', 'precision': '0.913', 'recall': '0.952', 'f1': '0.932', 'total_rewards': 179.60130051971942, 'invalid_action_count': 5, 'num_ms1_scans': 438, 'num_ms2_scans': 1124}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.95116800672241
# steps	 1000 	total rewards	 152.48403839375618
# steps	 1500 	total rewards	 230.20211768245875
# Finished after 1685 timesteps (6.181617021560669 seconds) with total reward 254.60038483333014
# {'coverage_prop': '0.943', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.230', 'efficiency': '0.292', 'TP': '346', 'FP': '54', 'FN': '24', 'precision': '0.865', 'recall': '0.935', 'f1': '0.899', 'total_rewards': 254.6003848333304, 'invalid_action_count': 13, 'num_ms1_scans': 315, 'num_ms2_scans': 1370}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 62.544323034238445
# steps	 1000 	total rewards	 150.39866223686357
# steps	 1500 	total rewards	 234.5775418624957
# Finished after 1695 timesteps (5.656612873077393 seconds) with total reward 256.9343998788046
# {'coverage_prop': '0.958', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.220', 'efficiency': '0.265', 'TP': '318', 'FP': '50', 'FN': '16', 'precision': '0.864', 'recall': '0.952', 'f1': '0.906', 'total_rewards': 256.9343998788047, 'invalid_action_count': 3, 'num_ms1_scans': 306, 'num_ms2_scans': 1389}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 67.29194217288256
# steps	 1000 	total rewards	 156.52251680287623
# steps	 1500 	total rewards	 242.89120533140013
# Finished after 1682 timesteps (7.837728023529053 seconds) with total reward 262.06139781617765
# {'coverage_prop': '0.939', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.233', 'efficiency': '0.305', 'TP': '358', 'FP': '58', 'FN': '27', 'precision': '0.861', 'recall': '0.930', 'f1': '0.894', 'total_rewards': 262.0613978161779, 'invalid_action_count': 14, 'num_ms1_scans': 318, 'num_ms2_scans': 1364}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 56.44779930367515
# steps	 1000 	total rewards	 130.78253039193035
# steps	 1500 	total rewards	 185.40701857449903
# Finished after 1628 timesteps (4.113869905471802 seconds) with total reward 199.01274208237786
# {'coverage_prop': '0.948', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.296', 'efficiency': '0.188', 'TP': '221', 'FP': '15', 'FN': '13', 'precision': '0.936', 'recall': '0.944', 'f1': '0.940', 'total_rewards': 199.012742082378, 'invalid_action_count': 4, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 57.11367528246882
# steps	 1000 	total rewards	 122.20752669234416
# steps	 1500 	total rewards	 187.837193899123
# Finished after 1661 timesteps (4.243192911148071 seconds) with total reward 206.91915728823105
# {'coverage_prop': '0.948', 'intensity_prop': '0.739', 'ms1ms2_ratio': '0.256', 'efficiency': '0.180', 'TP': '207', 'FP': '31', 'FN': '13', 'precision': '0.870', 'recall': '0.941', 'f1': '0.904', 'total_rewards': 206.91915728823102, 'invalid_action_count': 4, 'num_ms1_scans': 339, 'num_ms2_scans': 1322}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 56.99508656538393
# steps	 1000 	total rewards	 123.32563362817832
# steps	 1500 	total rewards	 197.8011164266253
# Finished after 1685 timesteps (5.229506015777588 seconds) with total reward 214.3938802751393
# {'coverage_prop': '0.960', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.230', 'efficiency': '0.210', 'TP': '242', 'FP': '46', 'FN': '12', 'precision': '0.840', 'recall': '0.953', 'f1': '0.893', 'total_rewards': 214.39388027513905, 'invalid_action_count': 13, 'num_ms1_scans': 315, 'num_ms2_scans': 1370}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 50.619089632782604
# steps	 1000 	total rewards	 120.143067604463
# steps	 1500 	total rewards	 177.04389982657966
# Finished after 1604 timesteps (4.428256988525391 seconds) with total reward 186.35188833257035
# {'coverage_prop': '0.947', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.329', 'efficiency': '0.162', 'TP': '173', 'FP': '22', 'FN': '11', 'precision': '0.887', 'recall': '0.940', 'f1': '0.913', 'total_rewards': 186.3518883325704, 'invalid_action_count': 2, 'num_ms1_scans': 397, 'num_ms2_scans': 1207}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 59.95203031688361
# steps	 1000 	total rewards	 151.5137090692274
# steps	 1500 	total rewards	 233.08325830849395
# Finished after 1666 timesteps (7.039060115814209 seconds) with total reward 258.98606576384105
# {'coverage_prop': '0.956', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.251', 'efficiency': '0.292', 'TP': '348', 'FP': '41', 'FN': '18', 'precision': '0.895', 'recall': '0.951', 'f1': '0.922', 'total_rewards': 258.9860657638412, 'invalid_action_count': 4, 'num_ms1_scans': 334, 'num_ms2_scans': 1332}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 75.95716289201174
# steps	 1000 	total rewards	 179.9430395559117
# steps	 1500 	total rewards	 268.264414430724
# Finished after 1669 timesteps (6.564893960952759 seconds) with total reward 289.2828668156372
# {'coverage_prop': '0.962', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.248', 'efficiency': '0.358', 'TP': '406', 'FP': '73', 'FN': '19', 'precision': '0.848', 'recall': '0.955', 'f1': '0.898', 'total_rewards': 289.28286681563696, 'invalid_action_count': 8, 'num_ms1_scans': 332, 'num_ms2_scans': 1337}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 66.19296862040171
# steps	 1000 	total rewards	 151.06238319957822
# steps	 1500 	total rewards	 226.02629563905987
# Finished after 1658 timesteps (5.7058939933776855 seconds) with total reward 245.3254546141844
# {'coverage_prop': '0.960', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.260', 'efficiency': '0.271', 'TP': '315', 'FP': '42', 'FN': '15', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917', 'total_rewards': 245.3254546141841, 'invalid_action_count': 8, 'num_ms1_scans': 342, 'num_ms2_scans': 1316}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 57.43537506336196
# steps	 1000 	total rewards	 133.69191834687666
# steps	 1500 	total rewards	 206.2906817790455
# Finished after 1670 timesteps (13.10709285736084 seconds) with total reward 221.65635267963367
# {'coverage_prop': '0.960', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.246', 'efficiency': '0.216', 'TP': '260', 'FP': '30', 'FN': '12', 'precision': '0.897', 'recall': '0.956', 'f1': '0.925', 'total_rewards': 221.65635267963384, 'invalid_action_count': 10, 'num_ms1_scans': 330, 'num_ms2_scans': 1340}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 56.50331172757484
# steps	 1000 	total rewards	 132.28575395161175
# steps	 1500 	total rewards	 194.78649311505592
# Finished after 1638 timesteps (5.027033090591431 seconds) with total reward 208.77962454064195
# {'coverage_prop': '0.974', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.284', 'efficiency': '0.202', 'TP': '225', 'FP': '33', 'FN': '7', 'precision': '0.872', 'recall': '0.970', 'f1': '0.918', 'total_rewards': 208.77962454064206, 'invalid_action_count': 2, 'num_ms1_scans': 362, 'num_ms2_scans': 1276}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.56014653454065
# steps	 1000 	total rewards	 171.36949167081264
# steps	 1500 	total rewards	 253.65316105416696
# Finished after 1681 timesteps (6.36323094367981 seconds) with total reward 279.63609652131856
# {'coverage_prop': '0.923', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.234', 'efficiency': '0.317', 'TP': '374', 'FP': '58', 'FN': '36', 'precision': '0.866', 'recall': '0.912', 'f1': '0.888', 'total_rewards': 279.63609652131817, 'invalid_action_count': 4, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 51.56750064792783
# steps	 1000 	total rewards	 119.87165994664774
# steps	 1500 	total rewards	 180.20339052928577
# Finished after 1610 timesteps (9.434232950210571 seconds) with total reward 184.10793645843205
# {'coverage_prop': '0.949', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.320', 'efficiency': '0.182', 'TP': '199', 'FP': '23', 'FN': '12', 'precision': '0.896', 'recall': '0.943', 'f1': '0.919', 'total_rewards': 184.10793645843228, 'invalid_action_count': 12, 'num_ms1_scans': 390, 'num_ms2_scans': 1220}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 59.723786317581755
# steps	 1000 	total rewards	 142.80249069234065
# steps	 1500 	total rewards	 217.54669522195374
# Finished after 1667 timesteps (4.756069898605347 seconds) with total reward 237.54786170548118
# {'coverage_prop': '0.950', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.251', 'efficiency': '0.230', 'TP': '270', 'FP': '36', 'FN': '16', 'precision': '0.882', 'recall': '0.944', 'f1': '0.912', 'total_rewards': 237.54786170548107, 'invalid_action_count': 4, 'num_ms1_scans': 334, 'num_ms2_scans': 1333}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 61.46449825919976
# steps	 1000 	total rewards	 142.3109143661361
# steps	 1500 	total rewards	 211.4234214898923
# Finished after 1617 timesteps (5.3133769035339355 seconds) with total reward 223.87815479493548
# {'coverage_prop': '0.945', 'intensity_prop': '0.739', 'ms1ms2_ratio': '0.310', 'efficiency': '0.237', 'TP': '259', 'FP': '34', 'FN': '17', 'precision': '0.884', 'recall': '0.938', 'f1': '0.910', 'total_rewards': 223.87815479493548, 'invalid_action_count': 5, 'num_ms1_scans': 383, 'num_ms2_scans': 1234}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 59.877094391137646
# steps	 1000 	total rewards	 151.17383876926445
# steps	 1500 	total rewards	 227.50112771597205
# Finished after 1667 timesteps (5.423955202102661 seconds) with total reward 250.6329548950697
# {'coverage_prop': '0.965', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.250', 'efficiency': '0.250', 'TP': '288', 'FP': '45', 'FN': '12', 'precision': '0.865', 'recall': '0.960', 'f1': '0.910', 'total_rewards': 250.63295489506976, 'invalid_action_count': 3, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 65.16750460783057
# steps	 1000 	total rewards	 147.0156954991241
# steps	 1500 	total rewards	 232.06711111677618
# Finished after 1669 timesteps (10.44209885597229 seconds) with total reward 255.80428520091587
# {'coverage_prop': '0.970', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.247', 'efficiency': '0.287', 'TP': '333', 'FP': '51', 'FN': '12', 'precision': '0.867', 'recall': '0.965', 'f1': '0.914', 'total_rewards': 255.8042852009156, 'invalid_action_count': 1, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 43.95564114744103
# steps	 1000 	total rewards	 114.7880146304301
# steps	 1500 	total rewards	 168.7283737958194
# Finished after 1597 timesteps (5.135500192642212 seconds) with total reward 175.20821435683257
# {'coverage_prop': '0.970', 'intensity_prop': '0.813', 'ms1ms2_ratio': '0.338', 'efficiency': '0.165', 'TP': '188', 'FP': '9', 'FN': '6', 'precision': '0.954', 'recall': '0.969', 'f1': '0.962', 'total_rewards': 175.20821435683266, 'invalid_action_count': 4, 'num_ms1_scans': 403, 'num_ms2_scans': 1194}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 55.18195878492393
# steps	 1000 	total rewards	 130.84176837561355
# steps	 1500 	total rewards	 203.16621553249902
# Finished after 1657 timesteps (4.741002082824707 seconds) with total reward 226.86506944007
# {'coverage_prop': '0.964', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.262', 'efficiency': '0.206', 'TP': '242', 'FP': '29', 'FN': '10', 'precision': '0.893', 'recall': '0.960', 'f1': '0.925', 'total_rewards': 226.86506944007, 'invalid_action_count': 4, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 76.06191292958079
# steps	 1000 	total rewards	 166.5093616790478
# steps	 1500 	total rewards	 258.6470610967817
# Finished after 1662 timesteps (9.025399208068848 seconds) with total reward 280.04467586239815
# {'coverage_prop': '0.919', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.255', 'efficiency': '0.342', 'TP': '364', 'FP': '89', 'FN': '40', 'precision': '0.804', 'recall': '0.901', 'f1': '0.849', 'total_rewards': 280.0446758623982, 'invalid_action_count': 12, 'num_ms1_scans': 338, 'num_ms2_scans': 1324}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 57.300396387837125
# steps	 1000 	total rewards	 137.5681762486567
# steps	 1500 	total rewards	 207.98627031078456
# Finished after 1664 timesteps (5.614684104919434 seconds) with total reward 227.0976611402466
# {'coverage_prop': '0.961', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.253', 'efficiency': '0.220', 'TP': '265', 'FP': '27', 'FN': '12', 'precision': '0.908', 'recall': '0.957', 'f1': '0.931', 'total_rewards': 227.09766114024657, 'invalid_action_count': 3, 'num_ms1_scans': 336, 'num_ms2_scans': 1328}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 64.2654546074735
# steps	 1000 	total rewards	 153.04802361768873
# steps	 1500 	total rewards	 242.67154511152393
# Finished after 1722 timesteps (13.78006887435913 seconds) with total reward 274.38094621838866
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 274.3809462183884, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 56.53441275069887
# steps	 1000 	total rewards	 133.44353713101043
# steps	 1500 	total rewards	 194.26613921470476
# Finished after 1556 timesteps (13.280199766159058 seconds) with total reward 198.80142796822798
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 198.8014279682283, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 57.86200989608058
# steps	 1000 	total rewards	 141.51209662324754
# steps	 1500 	total rewards	 225.9068017910975
# Finished after 1669 timesteps (18.940439701080322 seconds) with total reward 246.6178714019398
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 246.61787140193985, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 71.12814612435277
# steps	 1000 	total rewards	 157.62727339419465
# steps	 1500 	total rewards	 238.78056886179576
# Finished after 1717 timesteps (14.199969053268433 seconds) with total reward 272.3235910501669
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 272.323591050167, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 61.90389809276462
# steps	 1000 	total rewards	 157.856811245934
# steps	 1500 	total rewards	 243.79212098759848
# Finished after 1704 timesteps (14.425372123718262 seconds) with total reward 273.0181148295186
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 273.0181148295187, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 39.90651559499652
# steps	 1000 	total rewards	 106.83331788373015
# Finished after 1408 timesteps (13.671565771102905 seconds) with total reward 143.2474579291325
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 143.24745792913245, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.22043408731386
# steps	 1000 	total rewards	 162.04397467383103
# steps	 1500 	total rewards	 244.55745713793698
# Finished after 1744 timesteps (14.78258466720581 seconds) with total reward 280.3023687938845
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 280.3023687938843, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.4779426031164
# steps	 1000 	total rewards	 116.36859205738139
# Finished after 1468 timesteps (11.057009935379028 seconds) with total reward 161.92295578814017
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 161.92295578814014, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.46621454358737
# steps	 1000 	total rewards	 149.00350104084623
# steps	 1500 	total rewards	 234.0142896045665
# Finished after 1736 timesteps (15.68857216835022 seconds) with total reward 265.5548286824893
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 265.5548286824895, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 57.43385139963196
# steps	 1000 	total rewards	 140.79893242513924
# steps	 1500 	total rewards	 223.46853854724827
# Finished after 1667 timesteps (19.021365880966187 seconds) with total reward 241.12161582599146
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 241.1216158259913, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 63.48883485609902
# steps	 1000 	total rewards	 148.03351769555485
# steps	 1500 	total rewards	 236.5520895809973
# Finished after 1737 timesteps (15.242110013961792 seconds) with total reward 267.3066297171516
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 267.30662971715145, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 50.65368156509129
# steps	 1000 	total rewards	 120.84480189877293
# steps	 1500 	total rewards	 172.70179872343084
# Finished after 1530 timesteps (12.425992012023926 seconds) with total reward 175.162963401381
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 175.1629634013811, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 48.92835278179824
# steps	 1000 	total rewards	 119.1495853267179
# steps	 1500 	total rewards	 182.89427536782864
# Finished after 1602 timesteps (13.473906993865967 seconds) with total reward 193.71436944682134
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 193.71436944682102, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 51.102405475232786
# steps	 1000 	total rewards	 126.40211968727175
# steps	 1500 	total rewards	 196.43919744732793
# Finished after 1645 timesteps (21.4952552318573 seconds) with total reward 210.5440874069469
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 210.544087406947, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 42.10725329655742
# steps	 1000 	total rewards	 109.41532611939553
# Finished after 1497 timesteps (13.674332857131958 seconds) with total reward 162.4041913682973
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 162.40419136829735, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 56.96509366792624
# steps	 1000 	total rewards	 147.2095569715228
# steps	 1500 	total rewards	 226.3392432649163
# Finished after 1655 timesteps (17.372768878936768 seconds) with total reward 248.9212535879875
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 248.92125358798705, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.46974393432068
# steps	 1000 	total rewards	 159.8630857893615
# steps	 1500 	total rewards	 249.45187485282867
# Finished after 1729 timesteps (20.213851928710938 seconds) with total reward 282.33596729180294
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 282.33596729180283, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 65.28295924656409
# steps	 1000 	total rewards	 152.99159947570973
# steps	 1500 	total rewards	 227.85174096808055
# Finished after 1681 timesteps (15.69972276687622 seconds) with total reward 248.71724564061213
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 248.71724564061182, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.80527834803058
# steps	 1000 	total rewards	 131.25379282029033
# steps	 1500 	total rewards	 201.63169124775385
# Finished after 1621 timesteps (20.812747955322266 seconds) with total reward 213.3962276951981
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 213.39622769519795, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 51.64710716074973
# steps	 1000 	total rewards	 127.8682486554507
# steps	 1500 	total rewards	 190.93867231139512
# Finished after 1634 timesteps (14.235764980316162 seconds) with total reward 206.05567977408612
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 206.05567977408612, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.50994950851643
# steps	 1000 	total rewards	 155.90074680539868
# steps	 1500 	total rewards	 237.04838387022266
# Finished after 1726 timesteps (17.313386917114258 seconds) with total reward 269.74024806514274
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 269.7402480651435, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 42.922449440035635
# steps	 1000 	total rewards	 117.47735795416574
# Finished after 1475 timesteps (21.345927715301514 seconds) with total reward 167.46987873772915
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 167.46987873772926, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 58.07428174764222
# steps	 1000 	total rewards	 137.84913832412306
# steps	 1500 	total rewards	 209.9889884762968
# Finished after 1636 timesteps (15.13022518157959 seconds) with total reward 225.08898203089467
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 225.08898203089467, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 59.55579530112928
# steps	 1000 	total rewards	 139.27168276735108
# steps	 1500 	total rewards	 204.99301908857169
# Finished after 1575 timesteps (15.663385152816772 seconds) with total reward 212.0487707936014
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 212.04877079360148, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 55.90621614718264
# steps	 1000 	total rewards	 142.4674826906643
# steps	 1500 	total rewards	 218.74431307077577
# Finished after 1681 timesteps (17.872629165649414 seconds) with total reward 241.10125347896678
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 241.10125347896698, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 58.65795180800854
# steps	 1000 	total rewards	 136.8820258148469
# steps	 1500 	total rewards	 223.03824969963966
# Finished after 1679 timesteps (28.372663974761963 seconds) with total reward 244.79886972933062
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 244.79886972933082, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 38.93346073831778
# steps	 1000 	total rewards	 108.52782812655937
# Finished after 1465 timesteps (15.394483089447021 seconds) with total reward 154.60987323663102
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 154.60987323663082, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 51.766444526594
# steps	 1000 	total rewards	 130.46357019586054
# steps	 1500 	total rewards	 197.8870026055789
# Finished after 1564 timesteps (14.715310096740723 seconds) with total reward 206.49333367236034
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 206.4933336723603, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 74.33673783003661
# steps	 1000 	total rewards	 151.64147482739267
# steps	 1500 	total rewards	 238.19314377272508
# Finished after 1749 timesteps (18.53354287147522 seconds) with total reward 277.638109251984
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 277.63810925198385, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 56.98398947393331
# steps	 1000 	total rewards	 133.73469321594888
# steps	 1500 	total rewards	 202.51030010488844
# Finished after 1657 timesteps (16.63163113594055 seconds) with total reward 218.42816542635472
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 218.42816542635472, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf395a4b50>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf4d65d3d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf4d679670>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.466', 'efficiency': '0.745', 'TP': '191', 'FP': '188', 'FN': '15', 'precision': '0.504', 'recall': '0.927', 'f1': '0.653'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.530', 'ms1ms2_ratio': '1.279', 'efficiency': '0.769', 'TP': '246', 'FP': '186', 'FN': '20', 'precision': '0.569', 'recall': '0.925', 'f1': '0.705'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.533', 'ms1ms2_ratio': '3.247', 'efficiency': '0.723', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.524', 'ms1ms2_ratio': '1.538', 'efficiency': '0.747', 'TP': '202', 'FP': '165', 'FN': '17', 'precision': '0.550', 'recall': '0.922', 'f1': '0.689'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '243', 'FP': '183', 'FN': '17', 'precision': '0.570', 'recall': '0.935', 'f1': '0.708'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.484', 'ms1ms2_ratio': '2.523', 'efficiency': '0.716', 'TP': '108', 'FP': '129', 'FN': '14', 'precision': '0.456', 'recall': '0.885', 'f1': '0.602'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.488', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '98', 'FP': '96', 'FN': '12', 'precision': '0.505', 'recall': '0.891', 'f1': '0.645'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.503', 'ms1ms2_ratio': '1.667', 'efficiency': '0.766', 'TP': '182', 'FP': '172', 'FN': '18', 'precision': '0.514', 'recall': '0.910', 'f1': '0.657'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.154', 'efficiency': '0.737', 'TP': '267', 'FP': '179', 'FN': '22', 'precision': '0.599', 'recall': '0.924', 'f1': '0.727'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.990', 'efficiency': '0.759', 'TP': '161', 'FP': '144', 'FN': '17', 'precision': '0.528', 'recall': '0.904', 'f1': '0.667'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.493', 'ms1ms2_ratio': '3.304', 'efficiency': '0.734', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.509', 'ms1ms2_ratio': '2.250', 'efficiency': '0.739', 'TP': '143', 'FP': '126', 'FN': '12', 'precision': '0.532', 'recall': '0.923', 'f1': '0.675'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.521', 'ms1ms2_ratio': '1.038', 'efficiency': '0.722', 'TP': '249', 'FP': '220', 'FN': '24', 'precision': '0.531', 'recall': '0.912', 'f1': '0.671'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1882.628630                1914.0          0.258           0.059
# 1  random   -1948.721899                1960.0          0.092           0.033
# 2  random   -1843.623766                1888.0          0.381           0.089
# 3  random   -1863.526617                1903.0          0.277           0.072
# 4  random   -1827.056443                1874.0          0.364           0.109
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.056      0.200   0.065  0.098
# 1          0.004       0.012      0.333   0.033  0.059
# 2          0.005       0.076      0.220   0.119  0.155
# 3          0.005       0.063      0.224   0.079  0.117
# 4          0.007       0.081      0.277   0.137  0.183

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     274.390808                   6.0          0.955           0.689
# 31    DQN     221.039520                   3.0          0.954           0.781
# 32    DQN     245.526269                   8.0          0.957           0.689
# 33    DQN     274.897449                   7.0          0.954           0.728
# 34    DQN     262.788256                   6.0          0.966           0.708
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.219       0.293      0.816   0.946  0.876
# 31          0.274       0.193      0.936   0.951  0.944
# 32          0.312       0.306      0.812   0.947  0.874
# 33          0.216       0.309      0.891   0.948  0.919
# 34          0.274       0.327      0.832   0.959  0.891

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
