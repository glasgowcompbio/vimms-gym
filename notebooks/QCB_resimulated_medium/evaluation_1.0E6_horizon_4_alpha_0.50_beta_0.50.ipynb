# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-07 14:27:08.600 | INFO     | vimms_gym.experiments:get_samplers:295 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9d5daaa6d0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9d3842f2e0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9d3844c580>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9d5daaa6d0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9d3842f2e0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9d3844c580>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9d5daaa6d0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9d3842f2e0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9d3844c580>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -482.02103066860445
# steps	 1000 	total rewards	 -912.4183416730448
# steps	 1500 	total rewards	 -1342.2062191403925
# Finished after 1987 timesteps (1.7706611156463623 seconds) with total reward -1780.8262782694574
# {'coverage_prop': '0.394', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.007', 'efficiency': '0.085', 'TP': '40', 'FP': '128', 'FN': '258', 'precision': '0.238', 'recall': '0.134', 'f1': '0.172', 'total_rewards': -1780.8262782694565, 'invalid_action_count': 1839, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -484.8377625718876
# steps	 1000 	total rewards	 -968.1657137545803
# steps	 1500 	total rewards	 -1418.3432589817307
# Finished after 1988 timesteps (0.9296760559082031 seconds) with total reward -1877.6955199605143
# {'coverage_prop': '0.294', 'intensity_prop': '0.067', 'ms1ms2_ratio': '0.006', 'efficiency': '0.039', 'TP': '14', 'FP': '63', 'FN': '185', 'precision': '0.182', 'recall': '0.070', 'f1': '0.101', 'total_rewards': -1877.6955199605138, 'invalid_action_count': 1907, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -490.2115132102473
# steps	 1000 	total rewards	 -988.64906756355
# steps	 1500 	total rewards	 -1466.163936394109
# Finished after 1994 timesteps (1.230053186416626 seconds) with total reward -1911.1406568229127
# {'coverage_prop': '0.216', 'intensity_prop': '0.035', 'ms1ms2_ratio': '0.003', 'efficiency': '0.043', 'TP': '9', 'FP': '76', 'FN': '309', 'precision': '0.106', 'recall': '0.028', 'f1': '0.045', 'total_rewards': -1911.1406568229118, 'invalid_action_count': 1937, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -481.0464687296638
# steps	 1000 	total rewards	 -965.5745899853343
# steps	 1500 	total rewards	 -1400.620008829114
# Finished after 1990 timesteps (1.6111259460449219 seconds) with total reward -1848.9186511863395
# {'coverage_prop': '0.354', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.005', 'efficiency': '0.081', 'TP': '38', 'FP': '122', 'FN': '292', 'precision': '0.237', 'recall': '0.115', 'f1': '0.155', 'total_rewards': -1848.91865118634, 'invalid_action_count': 1892, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -478.55256700305733
# steps	 1000 	total rewards	 -956.8011667637345
# steps	 1500 	total rewards	 -1417.4155711790504
# Finished after 1990 timesteps (1.2913649082183838 seconds) with total reward -1846.6636837005728
# {'coverage_prop': '0.314', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.005', 'efficiency': '0.069', 'TP': '25', 'FP': '112', 'FN': '300', 'precision': '0.182', 'recall': '0.077', 'f1': '0.108', 'total_rewards': -1846.6636837005728, 'invalid_action_count': 1889, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -489.7135285004066
# steps	 1000 	total rewards	 -942.0611979965105
# steps	 1500 	total rewards	 -1433.1818918906106
# Finished after 1987 timesteps (0.8299858570098877 seconds) with total reward -1904.8035956275462
# {'coverage_prop': '0.340', 'intensity_prop': '0.072', 'ms1ms2_ratio': '0.007', 'efficiency': '0.034', 'TP': '9', 'FP': '59', 'FN': '132', 'precision': '0.132', 'recall': '0.064', 'f1': '0.086', 'total_rewards': -1904.8035956275457, 'invalid_action_count': 1928, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -469.4779566909573
# steps	 1000 	total rewards	 -898.6523526298348
# steps	 1500 	total rewards	 -1343.705377851652
# Finished after 1981 timesteps (1.3752458095550537 seconds) with total reward -1770.5640707299594
# {'coverage_prop': '0.395', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.010', 'efficiency': '0.096', 'TP': '41', 'FP': '148', 'FN': '289', 'precision': '0.217', 'recall': '0.124', 'f1': '0.158', 'total_rewards': -1770.56407072996, 'invalid_action_count': 1830, 'num_ms1_scans': 19, 'num_ms2_scans': 1962}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -991.2360924409968
# steps	 1500 	total rewards	 -1472.8178047105796
# Finished after 1995 timesteps (0.815903902053833 seconds) with total reward -1948.305533799885
# {'coverage_prop': '0.186', 'intensity_prop': '0.045', 'ms1ms2_ratio': '0.003', 'efficiency': '0.019', 'TP': '8', 'FP': '30', 'FN': '166', 'precision': '0.211', 'recall': '0.046', 'f1': '0.075', 'total_rewards': -1948.305533799885, 'invalid_action_count': 1962, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -480.6923178267592
# steps	 1000 	total rewards	 -947.1073081116689
# steps	 1500 	total rewards	 -1390.0172171925299
# Finished after 1990 timesteps (1.7008168697357178 seconds) with total reward -1848.761707083223
# {'coverage_prop': '0.328', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.005', 'efficiency': '0.070', 'TP': '27', 'FP': '112', 'FN': '285', 'precision': '0.194', 'recall': '0.087', 'f1': '0.120', 'total_rewards': -1848.761707083223, 'invalid_action_count': 1890, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -488.53812313106687
# steps	 1000 	total rewards	 -960.7021566114007
# steps	 1500 	total rewards	 -1390.0883757103798
# Finished after 1989 timesteps (1.1600661277770996 seconds) with total reward -1846.96221505856
# {'coverage_prop': '0.344', 'intensity_prop': '0.088', 'ms1ms2_ratio': '0.006', 'efficiency': '0.067', 'TP': '31', 'FP': '101', 'FN': '252', 'precision': '0.235', 'recall': '0.110', 'f1': '0.149', 'total_rewards': -1846.9622150585603, 'invalid_action_count': 1888, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -492.1904546250779
# steps	 1000 	total rewards	 -906.1649688129373
# steps	 1500 	total rewards	 -1337.271404525067
# Finished after 1985 timesteps (1.3303627967834473 seconds) with total reward -1780.9751858880272
# {'coverage_prop': '0.418', 'intensity_prop': '0.118', 'ms1ms2_ratio': '0.008', 'efficiency': '0.094', 'TP': '51', 'FP': '134', 'FN': '258', 'precision': '0.276', 'recall': '0.165', 'f1': '0.206', 'total_rewards': -1780.975185888027, 'invalid_action_count': 1839, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -493.84181925127865
# steps	 1000 	total rewards	 -965.0852692042545
# steps	 1500 	total rewards	 -1441.8050393644387
# Finished after 1989 timesteps (0.9105541706085205 seconds) with total reward -1906.046353594224
# {'coverage_prop': '0.241', 'intensity_prop': '0.055', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '12', 'FP': '48', 'FN': '189', 'precision': '0.200', 'recall': '0.060', 'f1': '0.092', 'total_rewards': -1906.0463535942242, 'invalid_action_count': 1926, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -491.03351281273603
# steps	 1000 	total rewards	 -970.8111407540898
# steps	 1500 	total rewards	 -1400.7537941171702
# Finished after 1987 timesteps (0.9734208583831787 seconds) with total reward -1849.4032957539785
# {'coverage_prop': '0.371', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.007', 'efficiency': '0.047', 'TP': '22', 'FP': '71', 'FN': '158', 'precision': '0.237', 'recall': '0.122', 'f1': '0.161', 'total_rewards': -1849.4032957539785, 'invalid_action_count': 1887, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -482.25542958264924
# steps	 1000 	total rewards	 -954.427096766246
# steps	 1500 	total rewards	 -1425.9510410945938
# Finished after 1989 timesteps (1.5782508850097656 seconds) with total reward -1881.0176703551156
# {'coverage_prop': '0.370', 'intensity_prop': '0.070', 'ms1ms2_ratio': '0.006', 'efficiency': '0.056', 'TP': '18', 'FP': '93', 'FN': '189', 'precision': '0.162', 'recall': '0.087', 'f1': '0.113', 'total_rewards': -1881.0176703551158, 'invalid_action_count': 1913, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -481.8171002614441
# steps	 1000 	total rewards	 -959.9468162617101
# steps	 1500 	total rewards	 -1420.054566405967
# Finished after 1983 timesteps (0.9129841327667236 seconds) with total reward -1885.0057843621657
# {'coverage_prop': '0.325', 'intensity_prop': '0.092', 'ms1ms2_ratio': '0.009', 'efficiency': '0.034', 'TP': '20', 'FP': '47', 'FN': '139', 'precision': '0.299', 'recall': '0.126', 'f1': '0.177', 'total_rewards': -1885.0057843621662, 'invalid_action_count': 1909, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -951.2184143193917
# steps	 1500 	total rewards	 -1390.166732843522
# Finished after 1994 timesteps (1.180830955505371 seconds) with total reward -1860.8629388918991
# {'coverage_prop': '0.376', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.003', 'efficiency': '0.077', 'TP': '39', 'FP': '114', 'FN': '254', 'precision': '0.255', 'recall': '0.133', 'f1': '0.175', 'total_rewards': -1860.8629388918987, 'invalid_action_count': 1902, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -468.43319280968376
# steps	 1000 	total rewards	 -945.4254324859955
# steps	 1500 	total rewards	 -1398.841597549159
# Finished after 1993 timesteps (1.324153184890747 seconds) with total reward -1845.5346423068415
# {'coverage_prop': '0.325', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.004', 'efficiency': '0.082', 'TP': '33', 'FP': '129', 'FN': '336', 'precision': '0.204', 'recall': '0.089', 'f1': '0.124', 'total_rewards': -1845.5346423068415, 'invalid_action_count': 1889, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -480.0669555246682
# steps	 1000 	total rewards	 -972.3512761326401
# steps	 1500 	total rewards	 -1449.9144858433676
# Finished after 1993 timesteps (1.113523006439209 seconds) with total reward -1889.043037920945
# {'coverage_prop': '0.277', 'intensity_prop': '0.055', 'ms1ms2_ratio': '0.004', 'efficiency': '0.052', 'TP': '14', 'FP': '89', 'FN': '269', 'precision': '0.136', 'recall': '0.049', 'f1': '0.073', 'total_rewards': -1889.043037920945, 'invalid_action_count': 1920, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -491.20537350129075
# steps	 1000 	total rewards	 -969.4378537225905
# steps	 1500 	total rewards	 -1409.360144728384
# Finished after 1989 timesteps (1.0466878414154053 seconds) with total reward -1872.3888342521652
# {'coverage_prop': '0.341', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.006', 'efficiency': '0.052', 'TP': '20', 'FP': '83', 'FN': '199', 'precision': '0.194', 'recall': '0.091', 'f1': '0.124', 'total_rewards': -1872.3888342521655, 'invalid_action_count': 1905, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -498.0
# steps	 1000 	total rewards	 -968.3355362201372
# steps	 1500 	total rewards	 -1452.1744543349205
# Finished after 1992 timesteps (0.9775979518890381 seconds) with total reward -1921.0436534811806
# {'coverage_prop': '0.189', 'intensity_prop': '0.035', 'ms1ms2_ratio': '0.004', 'efficiency': '0.025', 'TP': '6', 'FP': '44', 'FN': '215', 'precision': '0.120', 'recall': '0.027', 'f1': '0.044', 'total_rewards': -1921.0436534811809, 'invalid_action_count': 1939, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -482.21478383942184
# steps	 1000 	total rewards	 -941.9861421499671
# steps	 1500 	total rewards	 -1338.4231784338158
# Finished after 1988 timesteps (1.3599700927734375 seconds) with total reward -1798.9608621586453
# {'coverage_prop': '0.387', 'intensity_prop': '0.122', 'ms1ms2_ratio': '0.006', 'efficiency': '0.092', 'TP': '52', 'FP': '129', 'FN': '287', 'precision': '0.287', 'recall': '0.153', 'f1': '0.200', 'total_rewards': -1798.960862158646, 'invalid_action_count': 1853, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -491.1720297460269
# steps	 1000 	total rewards	 -982.2527807016652
# steps	 1500 	total rewards	 -1462.057887371531
# Finished after 1997 timesteps (0.8739142417907715 seconds) with total reward -1958.0578873715308
# {'coverage_prop': '0.141', 'intensity_prop': '0.017', 'ms1ms2_ratio': '0.002', 'efficiency': '0.017', 'TP': '3', 'FP': '30', 'FN': '201', 'precision': '0.091', 'recall': '0.015', 'f1': '0.025', 'total_rewards': -1958.0578873715313, 'invalid_action_count': 1970, 'num_ms1_scans': 3, 'num_ms2_scans': 1994}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -492.2669739667438
# steps	 1000 	total rewards	 -967.5401812655841
# steps	 1500 	total rewards	 -1444.3272816535145
# Finished after 1990 timesteps (1.0487439632415771 seconds) with total reward -1893.4445721731017
# {'coverage_prop': '0.280', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.005', 'efficiency': '0.045', 'TP': '17', 'FP': '73', 'FN': '232', 'precision': '0.189', 'recall': '0.068', 'f1': '0.100', 'total_rewards': -1893.444572173101, 'invalid_action_count': 1921, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -490.63766684983796
# steps	 1000 	total rewards	 -977.6007619378317
# steps	 1500 	total rewards	 -1455.5360928874468
# Finished after 1989 timesteps (0.9722659587860107 seconds) with total reward -1909.5734292815043
# {'coverage_prop': '0.194', 'intensity_prop': '0.048', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '16', 'FP': '44', 'FN': '250', 'precision': '0.267', 'recall': '0.060', 'f1': '0.098', 'total_rewards': -1909.5734292815039, 'invalid_action_count': 1930, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -493.79899113864377
# steps	 1000 	total rewards	 -952.4999646991241
# steps	 1500 	total rewards	 -1374.265173586417
# Finished after 1987 timesteps (1.1219007968902588 seconds) with total reward -1807.5127146533523
# {'coverage_prop': '0.423', 'intensity_prop': '0.130', 'ms1ms2_ratio': '0.007', 'efficiency': '0.074', 'TP': '42', 'FP': '104', 'FN': '199', 'precision': '0.288', 'recall': '0.174', 'f1': '0.217', 'total_rewards': -1807.5127146533523, 'invalid_action_count': 1863, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -483.79633152880734
# steps	 1000 	total rewards	 -959.7159909373456
# steps	 1500 	total rewards	 -1441.5153649746135
# Finished after 1989 timesteps (1.8121211528778076 seconds) with total reward -1885.9657710755157
# {'coverage_prop': '0.250', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.006', 'efficiency': '0.050', 'TP': '19', 'FP': '80', 'FN': '297', 'precision': '0.192', 'recall': '0.060', 'f1': '0.092', 'total_rewards': -1885.9657710755157, 'invalid_action_count': 1915, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -491.2376632067065
# steps	 1000 	total rewards	 -947.7817883185821
# steps	 1500 	total rewards	 -1413.1509104629047
# Finished after 1988 timesteps (0.8642139434814453 seconds) with total reward -1881.857019880471
# {'coverage_prop': '0.414', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.006', 'efficiency': '0.043', 'TP': '22', 'FP': '62', 'FN': '119', 'precision': '0.262', 'recall': '0.156', 'f1': '0.196', 'total_rewards': -1881.8570198804712, 'invalid_action_count': 1913, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -490.0948269077859
# steps	 1000 	total rewards	 -950.0139132369814
# steps	 1500 	total rewards	 -1398.1853671728309
# Finished after 1990 timesteps (0.9511549472808838 seconds) with total reward -1867.4844104636586
# {'coverage_prop': '0.320', 'intensity_prop': '0.088', 'ms1ms2_ratio': '0.005', 'efficiency': '0.045', 'TP': '22', 'FP': '68', 'FN': '191', 'precision': '0.244', 'recall': '0.103', 'f1': '0.145', 'total_rewards': -1867.484410463659, 'invalid_action_count': 1905, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -492.6970373312789
# steps	 1000 	total rewards	 -932.2047220189224
# steps	 1500 	total rewards	 -1372.3037940237982
# Finished after 1990 timesteps (1.3689680099487305 seconds) with total reward -1789.3933707758717
# {'coverage_prop': '0.371', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.005', 'efficiency': '0.092', 'TP': '45', 'FP': '138', 'FN': '310', 'precision': '0.246', 'recall': '0.127', 'f1': '0.167', 'total_rewards': -1789.3933707758722, 'invalid_action_count': 1847, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -495.43323985621026
# steps	 1000 	total rewards	 -958.6835090414507
# steps	 1500 	total rewards	 -1388.3355266659364
# Finished after 1979 timesteps (1.1127679347991943 seconds) with total reward -1823.9975161193024
# {'coverage_prop': '0.372', 'intensity_prop': '0.126', 'ms1ms2_ratio': '0.011', 'efficiency': '0.058', 'TP': '35', 'FP': '78', 'FN': '191', 'precision': '0.310', 'recall': '0.155', 'f1': '0.206', 'total_rewards': -1823.9975161193024, 'invalid_action_count': 1866, 'num_ms1_scans': 21, 'num_ms2_scans': 1958}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.31GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 69.39380574518462
# steps	 1000 	total rewards	 164.39149120810202
# steps	 1500 	total rewards	 249.91550443629006
# Finished after 1705 timesteps (4.693556070327759 seconds) with total reward 277.830182003393
# {'coverage_prop': '0.955', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.209', 'efficiency': '0.289', 'TP': '336', 'FP': '71', 'FN': '19', 'precision': '0.826', 'recall': '0.946', 'f1': '0.882', 'total_rewards': 277.8301820033934, 'invalid_action_count': 5, 'num_ms1_scans': 295, 'num_ms2_scans': 1410}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 60.52227400472177
# steps	 1000 	total rewards	 134.33231807618205
# steps	 1500 	total rewards	 206.40933184548317
# Finished after 1630 timesteps (3.1726222038269043 seconds) with total reward 216.4635189973065
# {'coverage_prop': '0.958', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.294', 'efficiency': '0.199', 'TP': '231', 'FP': '20', 'FN': '11', 'precision': '0.920', 'recall': '0.955', 'f1': '0.937', 'total_rewards': 216.46351899730658, 'invalid_action_count': 6, 'num_ms1_scans': 370, 'num_ms2_scans': 1260}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 57.36081709470028
# steps	 1000 	total rewards	 149.71562924591473
# steps	 1500 	total rewards	 228.16775811996683
# Finished after 1619 timesteps (5.054303884506226 seconds) with total reward 239.38436371271337
# {'coverage_prop': '0.942', 'intensity_prop': '0.679', 'ms1ms2_ratio': '0.308', 'efficiency': '0.300', 'TP': '306', 'FP': '65', 'FN': '23', 'precision': '0.825', 'recall': '0.930', 'f1': '0.874', 'total_rewards': 239.38436371271305, 'invalid_action_count': 9, 'num_ms1_scans': 381, 'num_ms2_scans': 1238}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 74.93097336795654
# steps	 1000 	total rewards	 169.75636848713572
# steps	 1500 	total rewards	 247.2757037752164
# Finished after 1687 timesteps (4.752820014953613 seconds) with total reward 275.21027796570985
# {'coverage_prop': '0.954', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.228', 'efficiency': '0.314', 'TP': '373', 'FP': '58', 'FN': '21', 'precision': '0.865', 'recall': '0.947', 'f1': '0.904', 'total_rewards': 275.2102779657099, 'invalid_action_count': 8, 'num_ms1_scans': 313, 'num_ms2_scans': 1374}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 65.16359128238666
# steps	 1000 	total rewards	 160.8355081631933
# steps	 1500 	total rewards	 24.07295136230256
# Finished after 1689 timesteps (3.878075122833252 seconds) with total reward -163.9270486376974
# {'coverage_prop': '0.879', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.226', 'efficiency': '0.279', 'TP': '306', 'FP': '78', 'FN': '53', 'precision': '0.797', 'recall': '0.852', 'f1': '0.824', 'total_rewards': -163.92704863769734, 'invalid_action_count': 387, 'num_ms1_scans': 311, 'num_ms2_scans': 1378}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 48.303565012102524
# steps	 1000 	total rewards	 114.84698956381264
# steps	 1500 	total rewards	 167.83428836875493
# Finished after 1600 timesteps (4.185529947280884 seconds) with total reward 175.56239755149898
# {'coverage_prop': '0.955', 'intensity_prop': '0.807', 'ms1ms2_ratio': '0.333', 'efficiency': '0.159', 'TP': '180', 'FP': '11', 'FN': '9', 'precision': '0.942', 'recall': '0.952', 'f1': '0.947', 'total_rewards': 175.56239755149926, 'invalid_action_count': 4, 'num_ms1_scans': 400, 'num_ms2_scans': 1200}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 72.10844494430474
# steps	 1000 	total rewards	 173.0427084880768
# steps	 1500 	total rewards	 252.78053124656145
# Finished after 1683 timesteps (4.145947217941284 seconds) with total reward 277.55191406225174
# {'coverage_prop': '0.937', 'intensity_prop': '0.685', 'ms1ms2_ratio': '0.232', 'efficiency': '0.328', 'TP': '368', 'FP': '80', 'FN': '30', 'precision': '0.821', 'recall': '0.925', 'f1': '0.870', 'total_rewards': 277.551914062252, 'invalid_action_count': 8, 'num_ms1_scans': 317, 'num_ms2_scans': 1366}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 43.333656769805245
# steps	 1000 	total rewards	 119.36151650884219
# steps	 1500 	total rewards	 173.77760543343632
# Finished after 1564 timesteps (3.2193102836608887 seconds) with total reward 178.04761577919516
# {'coverage_prop': '0.951', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.387', 'efficiency': '0.172', 'TP': '184', 'FP': '10', 'FN': '10', 'precision': '0.948', 'recall': '0.948', 'f1': '0.948', 'total_rewards': 178.047615779195, 'invalid_action_count': 8, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 72.87876060062331
# steps	 1000 	total rewards	 156.10658256126737
# steps	 1500 	total rewards	 230.1845432546695
# Finished after 1704 timesteps (3.9962313175201416 seconds) with total reward 258.035132398191
# {'coverage_prop': '0.936', 'intensity_prop': '0.705', 'ms1ms2_ratio': '0.210', 'efficiency': '0.282', 'TP': '345', 'FP': '52', 'FN': '27', 'precision': '0.869', 'recall': '0.927', 'f1': '0.897', 'total_rewards': 258.0351323981909, 'invalid_action_count': 12, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 62.70239785615797
# steps	 1000 	total rewards	 148.3125222645235
# steps	 1500 	total rewards	 234.05187871500414
# Finished after 1693 timesteps (3.757063865661621 seconds) with total reward 256.2270255377533
# {'coverage_prop': '0.951', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.222', 'efficiency': '0.263', 'TP': '316', 'FP': '49', 'FN': '19', 'precision': '0.866', 'recall': '0.943', 'f1': '0.903', 'total_rewards': 256.2270255377534, 'invalid_action_count': 1, 'num_ms1_scans': 307, 'num_ms2_scans': 1386}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 65.0397037644409
# steps	 1000 	total rewards	 156.54782882772918
# steps	 1500 	total rewards	 248.96774538226117
# Finished after 1687 timesteps (5.1956751346588135 seconds) with total reward 271.4441925032844
# {'coverage_prop': '0.941', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.228', 'efficiency': '0.303', 'TP': '357', 'FP': '60', 'FN': '26', 'precision': '0.856', 'recall': '0.932', 'f1': '0.893', 'total_rewards': 271.44419250328485, 'invalid_action_count': 8, 'num_ms1_scans': 313, 'num_ms2_scans': 1374}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 58.20032084869348
# steps	 1000 	total rewards	 128.83212397201433
# steps	 1500 	total rewards	 182.47080383789825
# Finished after 1628 timesteps (3.334172010421753 seconds) with total reward 197.8840572662109
# {'coverage_prop': '0.948', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.296', 'efficiency': '0.188', 'TP': '219', 'FP': '17', 'FN': '13', 'precision': '0.928', 'recall': '0.944', 'f1': '0.936', 'total_rewards': 197.88405726621093, 'invalid_action_count': 4, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 56.11597159224049
# steps	 1000 	total rewards	 124.16768179885202
# steps	 1500 	total rewards	 190.26695070851582
# Finished after 1654 timesteps (3.27436900138855 seconds) with total reward 208.32705433222284
# {'coverage_prop': '0.948', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.265', 'efficiency': '0.182', 'TP': '204', 'FP': '34', 'FN': '13', 'precision': '0.857', 'recall': '0.940', 'f1': '0.897', 'total_rewards': 208.32705433222293, 'invalid_action_count': 1, 'num_ms1_scans': 346, 'num_ms2_scans': 1308}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 54.32774651516425
# steps	 1000 	total rewards	 129.20824745921843
# steps	 1500 	total rewards	 200.25722457462984
# Finished after 1680 timesteps (3.73163104057312 seconds) with total reward 216.7806712198195
# {'coverage_prop': '0.953', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.236', 'efficiency': '0.210', 'TP': '240', 'FP': '46', 'FN': '14', 'precision': '0.839', 'recall': '0.945', 'f1': '0.889', 'total_rewards': 216.78067121981934, 'invalid_action_count': 8, 'num_ms1_scans': 321, 'num_ms2_scans': 1359}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 50.475559380386585
# steps	 1000 	total rewards	 119.33779433970932
# steps	 1500 	total rewards	 173.78981601450317
# Finished after 1590 timesteps (3.1125998497009277 seconds) with total reward 182.78951725126447
# {'coverage_prop': '0.951', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.349', 'efficiency': '0.166', 'TP': '174', 'FP': '22', 'FN': '10', 'precision': '0.888', 'recall': '0.946', 'f1': '0.916', 'total_rewards': 182.78951725126458, 'invalid_action_count': 4, 'num_ms1_scans': 411, 'num_ms2_scans': 1179}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 58.576753562653884
# steps	 1000 	total rewards	 157.48002365993767
# steps	 1500 	total rewards	 239.02535098254435
# Finished after 1663 timesteps (5.129208087921143 seconds) with total reward 261.64785824480293
# {'coverage_prop': '0.968', 'intensity_prop': '0.737', 'ms1ms2_ratio': '0.255', 'efficiency': '0.297', 'TP': '343', 'FP': '51', 'FN': '13', 'precision': '0.871', 'recall': '0.963', 'f1': '0.915', 'total_rewards': 261.6478582448029, 'invalid_action_count': 6, 'num_ms1_scans': 338, 'num_ms2_scans': 1325}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 77.62313426552137
# steps	 1000 	total rewards	 175.4601855307356
# steps	 1500 	total rewards	 256.88910809199393
# Finished after 1678 timesteps (4.306644916534424 seconds) with total reward 276.8547977729216
# {'coverage_prop': '0.952', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.238', 'efficiency': '0.350', 'TP': '406', 'FP': '68', 'FN': '24', 'precision': '0.857', 'recall': '0.944', 'f1': '0.898', 'total_rewards': 276.85479777292153, 'invalid_action_count': 14, 'num_ms1_scans': 323, 'num_ms2_scans': 1355}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 70.22278594951594
# steps	 1000 	total rewards	 158.669736099131
# steps	 1500 	total rewards	 229.9941969739143
# Finished after 1651 timesteps (3.7642362117767334 seconds) with total reward 245.53783221159225
# {'coverage_prop': '0.949', 'intensity_prop': '0.718', 'ms1ms2_ratio': '0.268', 'efficiency': '0.271', 'TP': '304', 'FP': '49', 'FN': '19', 'precision': '0.861', 'recall': '0.941', 'f1': '0.899', 'total_rewards': 245.53783221159242, 'invalid_action_count': 6, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 60.323122104876404
# steps	 1000 	total rewards	 138.25092127775633
# steps	 1500 	total rewards	 213.42974423929837
# Finished after 1664 timesteps (5.014341115951538 seconds) with total reward 228.95786620180138
# {'coverage_prop': '0.967', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.253', 'efficiency': '0.220', 'TP': '257', 'FP': '35', 'FN': '10', 'precision': '0.880', 'recall': '0.963', 'f1': '0.919', 'total_rewards': 228.95786620180132, 'invalid_action_count': 4, 'num_ms1_scans': 336, 'num_ms2_scans': 1328}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 56.9801224105767
# steps	 1000 	total rewards	 128.58469782322385
# steps	 1500 	total rewards	 190.77651835859297
# Finished after 1647 timesteps (3.2948200702667236 seconds) with total reward 206.68346900623328
# {'coverage_prop': '0.974', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.273', 'efficiency': '0.199', 'TP': '227', 'FP': '31', 'FN': '7', 'precision': '0.880', 'recall': '0.970', 'f1': '0.923', 'total_rewards': 206.6834690062334, 'invalid_action_count': 7, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 72.1604990849633
# steps	 1000 	total rewards	 172.0481943253547
# steps	 1500 	total rewards	 251.38971874419116
# Finished after 1671 timesteps (4.188179969787598 seconds) with total reward 277.2282167655972
# {'coverage_prop': '0.923', 'intensity_prop': '0.693', 'ms1ms2_ratio': '0.245', 'efficiency': '0.322', 'TP': '367', 'FP': '65', 'FN': '36', 'precision': '0.850', 'recall': '0.911', 'f1': '0.879', 'total_rewards': 277.2282167655972, 'invalid_action_count': 5, 'num_ms1_scans': 329, 'num_ms2_scans': 1342}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 49.72583888426246
# steps	 1000 	total rewards	 119.48739474963304
# steps	 1500 	total rewards	 181.30356718676325
# Finished after 1611 timesteps (4.608690023422241 seconds) with total reward 187.85019386200418
# {'coverage_prop': '0.949', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.319', 'efficiency': '0.182', 'TP': '204', 'FP': '18', 'FN': '12', 'precision': '0.919', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 187.8501938620044, 'invalid_action_count': 9, 'num_ms1_scans': 390, 'num_ms2_scans': 1221}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 61.069631269077526
# steps	 1000 	total rewards	 143.935369778951
# steps	 1500 	total rewards	 215.13995292542984
# Finished after 1671 timesteps (3.5424509048461914 seconds) with total reward 233.9093167071553
# {'coverage_prop': '0.957', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.245', 'efficiency': '0.230', 'TP': '273', 'FP': '35', 'FN': '14', 'precision': '0.886', 'recall': '0.951', 'f1': '0.918', 'total_rewards': 233.90931670715548, 'invalid_action_count': 8, 'num_ms1_scans': 329, 'num_ms2_scans': 1342}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 61.39517955244568
# steps	 1000 	total rewards	 140.5581259351977
# steps	 1500 	total rewards	 207.5532734525989
# Finished after 1631 timesteps (3.4893600940704346 seconds) with total reward 222.42842908894465
# {'coverage_prop': '0.952', 'intensity_prop': '0.739', 'ms1ms2_ratio': '0.292', 'efficiency': '0.234', 'TP': '255', 'FP': '40', 'FN': '15', 'precision': '0.864', 'recall': '0.944', 'f1': '0.903', 'total_rewards': 222.42842908894494, 'invalid_action_count': 7, 'num_ms1_scans': 369, 'num_ms2_scans': 1262}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 60.33047762938933
# steps	 1000 	total rewards	 151.37291506510994
# steps	 1500 	total rewards	 227.6093803252517
# Finished after 1669 timesteps (3.5895659923553467 seconds) with total reward 248.476038637356
# {'coverage_prop': '0.974', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.247', 'efficiency': '0.251', 'TP': '293', 'FP': '43', 'FN': '9', 'precision': '0.872', 'recall': '0.970', 'f1': '0.918', 'total_rewards': 248.4760386373557, 'invalid_action_count': 3, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 65.44654975682008
# steps	 1000 	total rewards	 146.93793140093902
# steps	 1500 	total rewards	 229.96680804397622
# Finished after 1670 timesteps (5.474490165710449 seconds) with total reward 250.0247146160911
# {'coverage_prop': '0.977', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.247', 'efficiency': '0.289', 'TP': '328', 'FP': '59', 'FN': '9', 'precision': '0.848', 'recall': '0.973', 'f1': '0.906', 'total_rewards': 250.02471461609096, 'invalid_action_count': 7, 'num_ms1_scans': 331, 'num_ms2_scans': 1339}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 44.19411640982712
# steps	 1000 	total rewards	 112.17866408067941
# steps	 1500 	total rewards	 164.67321090317336
# Finished after 1602 timesteps (3.2612688541412354 seconds) with total reward 165.43619168698942
# {'coverage_prop': '0.961', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.331', 'efficiency': '0.162', 'TP': '180', 'FP': '15', 'FN': '8', 'precision': '0.923', 'recall': '0.957', 'f1': '0.940', 'total_rewards': 165.43619168698953, 'invalid_action_count': 13, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 57.346874359343445
# steps	 1000 	total rewards	 132.94648710878934
# steps	 1500 	total rewards	 204.046284456267
# Finished after 1651 timesteps (3.2422969341278076 seconds) with total reward 225.4113667557622
# {'coverage_prop': '0.968', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.268', 'efficiency': '0.209', 'TP': '242', 'FP': '30', 'FN': '9', 'precision': '0.890', 'recall': '0.964', 'f1': '0.925', 'total_rewards': 225.4113667557621, 'invalid_action_count': 3, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 78.51859433967029
# steps	 1000 	total rewards	 162.99013915595498
# steps	 1500 	total rewards	 254.19709847730064
# Finished after 1676 timesteps (4.287758827209473 seconds) with total reward 279.45156329769407
# {'coverage_prop': '0.909', 'intensity_prop': '0.650', 'ms1ms2_ratio': '0.240', 'efficiency': '0.331', 'TP': '358', 'FP': '90', 'FN': '45', 'precision': '0.799', 'recall': '0.888', 'f1': '0.841', 'total_rewards': 279.45156329769367, 'invalid_action_count': 10, 'num_ms1_scans': 324, 'num_ms2_scans': 1352}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 59.539389036582854
# steps	 1000 	total rewards	 139.13018202135717
# steps	 1500 	total rewards	 207.65084751117212
# Finished after 1675 timesteps (3.441390037536621 seconds) with total reward 229.28294738587124
# {'coverage_prop': '0.964', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.241', 'efficiency': '0.217', 'TP': '258', 'FP': '35', 'FN': '11', 'precision': '0.881', 'recall': '0.959', 'f1': '0.918', 'total_rewards': 229.28294738587113, 'invalid_action_count': 2, 'num_ms1_scans': 325, 'num_ms2_scans': 1350}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 64.2654546074735
# steps	 1000 	total rewards	 153.04802361768873
# steps	 1500 	total rewards	 242.67154511152393
# Finished after 1722 timesteps (9.353523969650269 seconds) with total reward 274.38094621838866
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 274.3809462183884, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 56.53441275069887
# steps	 1000 	total rewards	 133.44353713101043
# steps	 1500 	total rewards	 194.26613921470476
# Finished after 1556 timesteps (7.904489994049072 seconds) with total reward 198.80142796822798
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 198.8014279682283, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 57.86200989608058
# steps	 1000 	total rewards	 141.51209662324754
# steps	 1500 	total rewards	 225.9068017910975
# Finished after 1669 timesteps (10.861586809158325 seconds) with total reward 246.6178714019398
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 246.61787140193985, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 71.12814612435277
# steps	 1000 	total rewards	 157.62727339419465
# steps	 1500 	total rewards	 238.78056886179576
# Finished after 1717 timesteps (9.612363815307617 seconds) with total reward 272.3235910501669
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 272.323591050167, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 61.90389809276462
# steps	 1000 	total rewards	 157.856811245934
# steps	 1500 	total rewards	 243.79212098759848
# Finished after 1704 timesteps (9.501055002212524 seconds) with total reward 273.0181148295186
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 273.0181148295187, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 39.90651559499652
# steps	 1000 	total rewards	 106.83331788373015
# Finished after 1408 timesteps (9.230387926101685 seconds) with total reward 143.2474579291325
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 143.24745792913245, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.22043408731386
# steps	 1000 	total rewards	 162.04397467383103
# steps	 1500 	total rewards	 244.55745713793698
# Finished after 1744 timesteps (9.933144092559814 seconds) with total reward 280.3023687938845
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 280.3023687938843, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.4779426031164
# steps	 1000 	total rewards	 116.36859205738139
# Finished after 1468 timesteps (7.7900779247283936 seconds) with total reward 161.92295578814017
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 161.92295578814014, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.46621454358737
# steps	 1000 	total rewards	 149.00350104084623
# steps	 1500 	total rewards	 234.0142896045665
# Finished after 1736 timesteps (10.16744089126587 seconds) with total reward 265.5548286824893
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 265.5548286824895, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 57.43385139963196
# steps	 1000 	total rewards	 140.79893242513924
# steps	 1500 	total rewards	 223.46853854724827
# Finished after 1667 timesteps (11.014931917190552 seconds) with total reward 241.12161582599146
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 241.1216158259913, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 63.48883485609902
# steps	 1000 	total rewards	 148.03351769555485
# steps	 1500 	total rewards	 236.5520895809973
# Finished after 1737 timesteps (9.563688039779663 seconds) with total reward 267.3066297171516
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 267.30662971715145, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 50.65368156509129
# steps	 1000 	total rewards	 120.84480189877293
# steps	 1500 	total rewards	 172.70179872343084
# Finished after 1530 timesteps (8.27036738395691 seconds) with total reward 175.162963401381
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 175.1629634013811, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 48.92835278179824
# steps	 1000 	total rewards	 119.1495853267179
# steps	 1500 	total rewards	 182.89427536782864
# Finished after 1602 timesteps (9.09973669052124 seconds) with total reward 193.71436944682134
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 193.71436944682102, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 51.102405475232786
# steps	 1000 	total rewards	 126.40211968727175
# steps	 1500 	total rewards	 196.43919744732793
# Finished after 1645 timesteps (11.010917901992798 seconds) with total reward 210.5440874069469
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 210.544087406947, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 42.10725329655742
# steps	 1000 	total rewards	 109.41532611939553
# Finished after 1497 timesteps (7.864317893981934 seconds) with total reward 162.4041913682973
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 162.40419136829735, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 56.96509366792624
# steps	 1000 	total rewards	 147.2095569715228
# steps	 1500 	total rewards	 226.3392432649163
# Finished after 1655 timesteps (9.155660152435303 seconds) with total reward 248.9212535879875
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 248.92125358798705, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.46974393432068
# steps	 1000 	total rewards	 159.8630857893615
# steps	 1500 	total rewards	 249.45187485282867
# Finished after 1729 timesteps (12.162816047668457 seconds) with total reward 282.33596729180294
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 282.33596729180283, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 65.28295924656409
# steps	 1000 	total rewards	 152.99159947570973
# steps	 1500 	total rewards	 227.85174096808055
# Finished after 1681 timesteps (8.95749306678772 seconds) with total reward 248.71724564061213
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 248.71724564061182, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.80527834803058
# steps	 1000 	total rewards	 131.25379282029033
# steps	 1500 	total rewards	 201.63169124775385
# Finished after 1621 timesteps (8.506139278411865 seconds) with total reward 213.3962276951981
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 213.39622769519795, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 51.64710716074973
# steps	 1000 	total rewards	 127.8682486554507
# steps	 1500 	total rewards	 190.93867231139512
# Finished after 1634 timesteps (8.188117027282715 seconds) with total reward 206.05567977408612
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 206.05567977408612, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.50994950851643
# steps	 1000 	total rewards	 155.90074680539868
# steps	 1500 	total rewards	 237.04838387022266
# Finished after 1726 timesteps (9.539586067199707 seconds) with total reward 269.74024806514274
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 269.7402480651435, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 42.922449440035635
# steps	 1000 	total rewards	 117.47735795416574
# Finished after 1475 timesteps (11.304960012435913 seconds) with total reward 167.46987873772915
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 167.46987873772926, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 58.07428174764222
# steps	 1000 	total rewards	 137.84913832412306
# steps	 1500 	total rewards	 209.9889884762968
# Finished after 1636 timesteps (9.47627592086792 seconds) with total reward 225.08898203089467
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 225.08898203089467, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 59.55579530112928
# steps	 1000 	total rewards	 139.27168276735108
# steps	 1500 	total rewards	 204.99301908857169
# Finished after 1575 timesteps (8.21023178100586 seconds) with total reward 212.0487707936014
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 212.04877079360148, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 55.90621614718264
# steps	 1000 	total rewards	 142.4674826906643
# steps	 1500 	total rewards	 218.74431307077577
# Finished after 1681 timesteps (8.629731178283691 seconds) with total reward 241.10125347896678
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 241.10125347896698, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 58.65795180800854
# steps	 1000 	total rewards	 136.8820258148469
# steps	 1500 	total rewards	 223.03824969963966
# Finished after 1679 timesteps (12.369795799255371 seconds) with total reward 244.79886972933062
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 244.79886972933082, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 38.93346073831778
# steps	 1000 	total rewards	 108.52782812655937
# Finished after 1465 timesteps (7.918186902999878 seconds) with total reward 154.60987323663102
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 154.60987323663082, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 51.766444526594
# steps	 1000 	total rewards	 130.46357019586054
# steps	 1500 	total rewards	 197.8870026055789
# Finished after 1564 timesteps (8.152777910232544 seconds) with total reward 206.49333367236034
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 206.4933336723603, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 74.33673783003661
# steps	 1000 	total rewards	 151.64147482739267
# steps	 1500 	total rewards	 238.19314377272508
# Finished after 1749 timesteps (9.763535022735596 seconds) with total reward 277.638109251984
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 277.63810925198385, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 56.98398947393331
# steps	 1000 	total rewards	 133.73469321594888
# steps	 1500 	total rewards	 202.51030010488844
# Finished after 1657 timesteps (8.422067880630493 seconds) with total reward 218.42816542635472
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 218.42816542635472, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9d5daaa6d0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9d3842f2e0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9d3844c580>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.795', 'efficiency': '0.539', 'TP': '360', 'FP': '56', 'FN': '10', 'precision': '0.865', 'recall': '0.973', 'f1': '0.916'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.735', 'efficiency': '0.543', 'TP': '379', 'FP': '61', 'FN': '12', 'precision': '0.861', 'recall': '0.969', 'f1': '0.912'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.772', 'efficiency': '0.551', 'TP': '369', 'FP': '64', 'FN': '4', 'precision': '0.852', 'recall': '0.989', 'f1': '0.916'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.700', 'ms1ms2_ratio': '0.674', 'efficiency': '0.539', 'TP': '400', 'FP': '59', 'FN': '19', 'precision': '0.871', 'recall': '0.955', 'f1': '0.911'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.720', 'ms1ms2_ratio': '2.080', 'efficiency': '0.505', 'TP': '179', 'FP': '17', 'FN': '8', 'precision': '0.913', 'recall': '0.957', 'f1': '0.935'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.687', 'efficiency': '0.508', 'TP': '378', 'FP': '50', 'FN': '15', 'precision': '0.883', 'recall': '0.962', 'f1': '0.921'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.669', 'ms1ms2_ratio': '1.606', 'efficiency': '0.501', 'TP': '198', 'FP': '40', 'FN': '13', 'precision': '0.832', 'recall': '0.938', 'f1': '0.882'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.686', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.850', 'efficiency': '0.537', 'TP': '350', 'FP': '48', 'FN': '9', 'precision': '0.879', 'recall': '0.975', 'f1': '0.925'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '425', 'FP': '62', 'FN': '11', 'precision': '0.873', 'recall': '0.975', 'f1': '0.921'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.700', 'ms1ms2_ratio': '0.979', 'efficiency': '0.533', 'TP': '308', 'FP': '52', 'FN': '12', 'precision': '0.856', 'recall': '0.963', 'f1': '0.906'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.703', 'ms1ms2_ratio': '1.236', 'efficiency': '0.507', 'TP': '246', 'FP': '46', 'FN': '10', 'precision': '0.842', 'recall': '0.961', 'f1': '0.898'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.702', 'ms1ms2_ratio': '1.252', 'efficiency': '0.518', 'TP': '248', 'FP': '48', 'FN': '14', 'precision': '0.838', 'recall': '0.947', 'f1': '0.889'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.973', 'efficiency': '0.499', 'TP': '296', 'FP': '43', 'FN': '6', 'precision': '0.873', 'recall': '0.980', 'f1': '0.924'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.855', 'efficiency': '0.530', 'TP': '337', 'FP': '54', 'FN': '5', 'precision': '0.862', 'recall': '0.985', 'f1': '0.920'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.370', 'efficiency': '0.508', 'TP': '239', 'FP': '33', 'FN': '9', 'precision': '0.879', 'recall': '0.964', 'f1': '0.919'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.589', 'efficiency': '0.521', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.732', 'ms1ms2_ratio': '1.204', 'efficiency': '0.503', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1780.826278                1839.0          0.394           0.112
# 1  random   -1877.695520                1907.0          0.294           0.067
# 2  random   -1911.140657                1937.0          0.216           0.035
# 3  random   -1848.918651                1892.0          0.354           0.093
# 4  random   -1846.663684                1889.0          0.314           0.074
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.007       0.085      0.238   0.134  0.172
# 1          0.006       0.039      0.182   0.070  0.101
# 2          0.003       0.043      0.106   0.028  0.045
# 3          0.005       0.081      0.237   0.115  0.155
# 4          0.005       0.069      0.182   0.077  0.108

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     277.830182                   5.0          0.955           0.698
# 31    DQN     216.463519                   6.0          0.958           0.770
# 32    DQN     239.384364                   9.0          0.942           0.679
# 33    DQN     275.210278                   8.0          0.954           0.723
# 34    DQN    -163.927049                 387.0          0.879           0.619
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.209       0.289      0.826   0.946  0.882
# 31          0.294       0.199      0.920   0.955  0.937
# 32          0.308       0.300      0.825   0.930  0.874
# 33          0.228       0.314      0.865   0.947  0.904
# 34          0.226       0.279      0.797   0.852  0.824

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
