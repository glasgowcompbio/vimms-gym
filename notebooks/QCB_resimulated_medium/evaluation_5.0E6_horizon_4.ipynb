# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-08 01:18:08.226 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8010648910>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8047e96670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8030902910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8010648910>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8047e96670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8030902910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8010648910>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8047e96670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8030902910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_5.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_5.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -452.4770406151884
# steps	 1000 	total rewards	 -950.4770406151883
# steps	 1500 	total rewards	 -1091.3673882920557
# Finished after 1995 timesteps (3.9599452018737793 seconds) with total reward -1382.8774670418443
# {'coverage_prop': '0.563', 'intensity_prop': '0.169', 'ms1ms2_ratio': '0.003', 'efficiency': '0.121', 'TP': '64', 'FP': '176', 'FN': '186', 'precision': '0.267', 'recall': '0.256', 'f1': '0.261', 'total_rewards': -1382.8774670418452, 'invalid_action_count': 1482, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -368.56058901612295
# steps	 1000 	total rewards	 -735.5523426042264
# steps	 1500 	total rewards	 -998.3012539449992
# Finished after 1990 timesteps (2.589951992034912 seconds) with total reward -1337.8671726986313
# {'coverage_prop': '0.668', 'intensity_prop': '0.192', 'ms1ms2_ratio': '0.005', 'efficiency': '0.088', 'TP': '47', 'FP': '128', 'FN': '87', 'precision': '0.269', 'recall': '0.351', 'f1': '0.304', 'total_rewards': -1337.867172698631, 'invalid_action_count': 1429, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -410.89903270826
# steps	 1000 	total rewards	 -707.5993149863154
# steps	 1500 	total rewards	 -949.1218368045173
# Finished after 1994 timesteps (3.7294719219207764 seconds) with total reward -1244.0574196275438
# {'coverage_prop': '0.718', 'intensity_prop': '0.215', 'ms1ms2_ratio': '0.003', 'efficiency': '0.142', 'TP': '78', 'FP': '205', 'FN': '111', 'precision': '0.276', 'recall': '0.413', 'f1': '0.331', 'total_rewards': -1244.0574196275445, 'invalid_action_count': 1376, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -366.38795091762034
# steps	 1000 	total rewards	 -610.878783602116
# steps	 1500 	total rewards	 -943.293819352302
# Finished after 1988 timesteps (4.104349136352539 seconds) with total reward -1087.3065381597544
# {'coverage_prop': '0.712', 'intensity_prop': '0.219', 'ms1ms2_ratio': '0.006', 'efficiency': '0.163', 'TP': '92', 'FP': '230', 'FN': '130', 'precision': '0.286', 'recall': '0.414', 'f1': '0.338', 'total_rewards': -1087.3065381597544, 'invalid_action_count': 1230, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -353.81025458513875
# steps	 1000 	total rewards	 -487.62571144430945
# steps	 1500 	total rewards	 -687.0483013135278
# Finished after 1989 timesteps (4.132375001907349 seconds) with total reward -973.096030075792
# {'coverage_prop': '0.808', 'intensity_prop': '0.274', 'ms1ms2_ratio': '0.006', 'efficiency': '0.178', 'TP': '113', 'FP': '240', 'FN': '84', 'precision': '0.320', 'recall': '0.574', 'f1': '0.411', 'total_rewards': -973.0960300757907, 'invalid_action_count': 1137, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -390.49085964238463
# steps	 1000 	total rewards	 -714.7619334862599
# steps	 1500 	total rewards	 -1032.9450716465465
# Finished after 1988 timesteps (2.315009117126465 seconds) with total reward -1416.688383131415
# {'coverage_prop': '0.665', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.006', 'efficiency': '0.067', 'TP': '42', 'FP': '91', 'FN': '67', 'precision': '0.316', 'recall': '0.385', 'f1': '0.347', 'total_rewards': -1416.6883831314158, 'invalid_action_count': 1484, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -456.4940538844107
# steps	 1000 	total rewards	 -645.1495913096451
# steps	 1500 	total rewards	 -695.5843344679834
# Finished after 1987 timesteps (4.036623001098633 seconds) with total reward -843.489780723832
# {'coverage_prop': '0.755', 'intensity_prop': '0.271', 'ms1ms2_ratio': '0.007', 'efficiency': '0.183', 'TP': '127', 'FP': '234', 'FN': '117', 'precision': '0.352', 'recall': '0.520', 'f1': '0.420', 'total_rewards': -843.4897807238301, 'invalid_action_count': 1025, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -410.53861557089556
# steps	 1000 	total rewards	 -783.6090165631316
# steps	 1500 	total rewards	 -1080.2101629647004
# Finished after 1990 timesteps (2.376195192337036 seconds) with total reward -1357.3292753087053
# {'coverage_prop': '0.662', 'intensity_prop': '0.194', 'ms1ms2_ratio': '0.005', 'efficiency': '0.068', 'TP': '37', 'FP': '98', 'FN': '69', 'precision': '0.274', 'recall': '0.349', 'f1': '0.307', 'total_rewards': -1357.3292753087062, 'invalid_action_count': 1426, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -327.8582070174549
# steps	 1000 	total rewards	 -566.2914008544506
# steps	 1500 	total rewards	 -860.283918840282
# Finished after 1985 timesteps (3.7130239009857178 seconds) with total reward -1001.013923519113
# {'coverage_prop': '0.759', 'intensity_prop': '0.222', 'ms1ms2_ratio': '0.008', 'efficiency': '0.163', 'TP': '86', 'FP': '236', 'FN': '102', 'precision': '0.267', 'recall': '0.457', 'f1': '0.337', 'total_rewards': -1001.0139235191128, 'invalid_action_count': 1156, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -422.73546368165285
# steps	 1000 	total rewards	 -808.4101519700516
# steps	 1500 	total rewards	 -1031.07997620421
# Finished after 1992 timesteps (3.2224650382995605 seconds) with total reward -1263.7535765547532
# {'coverage_prop': '0.648', 'intensity_prop': '0.204', 'ms1ms2_ratio': '0.004', 'efficiency': '0.126', 'TP': '77', 'FP': '172', 'FN': '135', 'precision': '0.309', 'recall': '0.363', 'f1': '0.334', 'total_rewards': -1263.7535765547525, 'invalid_action_count': 1374, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -388.7597507073555
# steps	 1000 	total rewards	 -614.7701164618866
# steps	 1500 	total rewards	 -685.3789232242849
# Finished after 1990 timesteps (4.109485864639282 seconds) with total reward -1060.6289097691833
# {'coverage_prop': '0.731', 'intensity_prop': '0.243', 'ms1ms2_ratio': '0.005', 'efficiency': '0.164', 'TP': '107', 'FP': '217', 'FN': '119', 'precision': '0.330', 'recall': '0.473', 'f1': '0.389', 'total_rewards': -1060.6289097691836, 'invalid_action_count': 1212, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -452.49050960006326
# steps	 1000 	total rewards	 -790.7450033232876
# steps	 1500 	total rewards	 -1020.7210255486078
# Finished after 1986 timesteps (3.0525429248809814 seconds) with total reward -1257.0517057160737
# {'coverage_prop': '0.695', 'intensity_prop': '0.248', 'ms1ms2_ratio': '0.007', 'efficiency': '0.088', 'TP': '60', 'FP': '113', 'FN': '76', 'precision': '0.347', 'recall': '0.441', 'f1': '0.388', 'total_rewards': -1257.0517057160725, 'invalid_action_count': 1344, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -387.57126822507337
# steps	 1000 	total rewards	 -753.4023172894049
# steps	 1500 	total rewards	 -969.5911110127182
# Finished after 1988 timesteps (2.569483995437622 seconds) with total reward -1205.4717828377238
# {'coverage_prop': '0.745', 'intensity_prop': '0.253', 'ms1ms2_ratio': '0.006', 'efficiency': '0.095', 'TP': '61', 'FP': '126', 'FN': '64', 'precision': '0.326', 'recall': '0.488', 'f1': '0.391', 'total_rewards': -1205.471782837725, 'invalid_action_count': 1304, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -430.0717036548325
# steps	 1000 	total rewards	 -781.1481939524929
# steps	 1500 	total rewards	 -1086.6292488565232
# Finished after 1991 timesteps (3.1912777423858643 seconds) with total reward -1392.6609270832419
# {'coverage_prop': '0.693', 'intensity_prop': '0.176', 'ms1ms2_ratio': '0.005', 'efficiency': '0.105', 'TP': '51', 'FP': '157', 'FN': '92', 'precision': '0.245', 'recall': '0.357', 'f1': '0.291', 'total_rewards': -1392.660927083241, 'invalid_action_count': 1485, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -418.6563592595371
# steps	 1000 	total rewards	 -869.4341507017472
# steps	 1500 	total rewards	 -1290.6987669482698
# Finished after 1992 timesteps (2.433932065963745 seconds) with total reward -1564.4791344031364
# {'coverage_prop': '0.505', 'intensity_prop': '0.118', 'ms1ms2_ratio': '0.004', 'efficiency': '0.052', 'TP': '22', 'FP': '82', 'FN': '102', 'precision': '0.212', 'recall': '0.177', 'f1': '0.193', 'total_rewards': -1564.4791344031378, 'invalid_action_count': 1615, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -380.6457188867686
# steps	 1000 	total rewards	 -758.1269659685116
# steps	 1500 	total rewards	 -1021.7542283020332
# Finished after 1989 timesteps (3.6522738933563232 seconds) with total reward -1254.0357917196202
# {'coverage_prop': '0.629', 'intensity_prop': '0.176', 'ms1ms2_ratio': '0.006', 'efficiency': '0.129', 'TP': '65', 'FP': '191', 'FN': '151', 'precision': '0.254', 'recall': '0.301', 'f1': '0.275', 'total_rewards': -1254.0357917196218, 'invalid_action_count': 1364, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -415.17443786586597
# steps	 1000 	total rewards	 -561.5940804347554
# steps	 1500 	total rewards	 -641.340753364153
# Finished after 1986 timesteps (5.2221879959106445 seconds) with total reward -805.061319761283
# {'coverage_prop': '0.789', 'intensity_prop': '0.268', 'ms1ms2_ratio': '0.007', 'efficiency': '0.199', 'TP': '132', 'FP': '261', 'FN': '105', 'precision': '0.336', 'recall': '0.557', 'f1': '0.419', 'total_rewards': -805.0613197612817, 'invalid_action_count': 990, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -350.8239421282883
# steps	 1000 	total rewards	 -697.200242785116
# steps	 1500 	total rewards	 -895.9268889068333
# Finished after 1990 timesteps (3.694540023803711 seconds) with total reward -1344.2744825027683
# {'coverage_prop': '0.613', 'intensity_prop': '0.170', 'ms1ms2_ratio': '0.005', 'efficiency': '0.115', 'TP': '56', 'FP': '172', 'FN': '144', 'precision': '0.246', 'recall': '0.280', 'f1': '0.262', 'total_rewards': -1344.2744825027683, 'invalid_action_count': 1445, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -397.568278381313
# steps	 1000 	total rewards	 -748.0752749235436
# steps	 1500 	total rewards	 -986.7687254470596
# Finished after 1988 timesteps (3.075515031814575 seconds) with total reward -1158.8504098296983
# {'coverage_prop': '0.712', 'intensity_prop': '0.215', 'ms1ms2_ratio': '0.006', 'efficiency': '0.109', 'TP': '62', 'FP': '153', 'FN': '87', 'precision': '0.288', 'recall': '0.416', 'f1': '0.341', 'total_rewards': -1158.8504098296987, 'invalid_action_count': 1267, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -389.5603585588555
# steps	 1000 	total rewards	 -627.0602954025046
# steps	 1500 	total rewards	 -888.5195736351479
# Finished after 1990 timesteps (3.1379451751708984 seconds) with total reward -1345.8567553966016
# {'coverage_prop': '0.672', 'intensity_prop': '0.196', 'ms1ms2_ratio': '0.005', 'efficiency': '0.090', 'TP': '50', 'FP': '128', 'FN': '87', 'precision': '0.281', 'recall': '0.365', 'f1': '0.317', 'total_rewards': -1345.856755396601, 'invalid_action_count': 1434, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -405.12091439628966
# steps	 1000 	total rewards	 -800.7167535649361
# steps	 1500 	total rewards	 -1085.071307976471
# Finished after 1996 timesteps (4.486184120178223 seconds) with total reward -1568.4910950076694
# {'coverage_prop': '0.468', 'intensity_prop': '0.119', 'ms1ms2_ratio': '0.002', 'efficiency': '0.110', 'TP': '50', 'FP': '169', 'FN': '249', 'precision': '0.228', 'recall': '0.167', 'f1': '0.193', 'total_rewards': -1568.4910950076692, 'invalid_action_count': 1644, 'num_ms1_scans': 4, 'num_ms2_scans': 1992}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -363.8396993254012
# steps	 1000 	total rewards	 -719.1553153699974
# steps	 1500 	total rewards	 -948.2898059947639
# Finished after 1990 timesteps (2.4977710247039795 seconds) with total reward -1286.3538818687643
# {'coverage_prop': '0.709', 'intensity_prop': '0.186', 'ms1ms2_ratio': '0.005', 'efficiency': '0.084', 'TP': '43', 'FP': '123', 'FN': '68', 'precision': '0.259', 'recall': '0.387', 'f1': '0.310', 'total_rewards': -1286.3538818687643, 'invalid_action_count': 1371, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -453.077041943047
# steps	 1000 	total rewards	 -783.8210324595714
# steps	 1500 	total rewards	 -1150.1170341759062
# Finished after 1994 timesteps (3.2397892475128174 seconds) with total reward -1410.5988355837012
# {'coverage_prop': '0.609', 'intensity_prop': '0.160', 'ms1ms2_ratio': '0.003', 'efficiency': '0.099', 'TP': '46', 'FP': '150', 'FN': '126', 'precision': '0.235', 'recall': '0.267', 'f1': '0.250', 'total_rewards': -1410.5988355837007, 'invalid_action_count': 1501, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -362.0680283670372
# steps	 1000 	total rewards	 -601.6033288152463
# steps	 1500 	total rewards	 -1001.5918006854711
# Finished after 1989 timesteps (2.9584848880767822 seconds) with total reward -1289.0140476472886
# {'coverage_prop': '0.668', 'intensity_prop': '0.179', 'ms1ms2_ratio': '0.006', 'efficiency': '0.105', 'TP': '52', 'FP': '155', 'FN': '103', 'precision': '0.251', 'recall': '0.335', 'f1': '0.287', 'total_rewards': -1289.0140476472884, 'invalid_action_count': 1390, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -398.39484536247153
# steps	 1000 	total rewards	 -597.3483435556518
# steps	 1500 	total rewards	 -708.666640944272
# Finished after 1984 timesteps (3.3594818115234375 seconds) with total reward -956.1685623456493
# {'coverage_prop': '0.786', 'intensity_prop': '0.296', 'ms1ms2_ratio': '0.008', 'efficiency': '0.138', 'TP': '102', 'FP': '169', 'FN': '74', 'precision': '0.376', 'recall': '0.580', 'f1': '0.456', 'total_rewards': -956.1685623456493, 'invalid_action_count': 1104, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -342.18263976910487
# steps	 1000 	total rewards	 -611.3489550016373
# steps	 1500 	total rewards	 -744.9847457491073
# Finished after 1984 timesteps (3.4272358417510986 seconds) with total reward -937.3776383018088
# {'coverage_prop': '0.806', 'intensity_prop': '0.246', 'ms1ms2_ratio': '0.008', 'efficiency': '0.162', 'TP': '86', 'FP': '233', 'FN': '77', 'precision': '0.270', 'recall': '0.528', 'f1': '0.357', 'total_rewards': -937.3776383018087, 'invalid_action_count': 1090, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -404.0884253835727
# steps	 1000 	total rewards	 -807.2817562115713
# steps	 1500 	total rewards	 -1217.8774512257276
# Finished after 1990 timesteps (2.3623061180114746 seconds) with total reward -1577.4314421458557
# {'coverage_prop': '0.596', 'intensity_prop': '0.123', 'ms1ms2_ratio': '0.005', 'efficiency': '0.061', 'TP': '21', 'FP': '100', 'FN': '82', 'precision': '0.174', 'recall': '0.204', 'f1': '0.188', 'total_rewards': -1577.4314421458557, 'invalid_action_count': 1636, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -451.498338710977
# steps	 1000 	total rewards	 -850.2075309490567
# steps	 1500 	total rewards	 -1199.4085523308495
# Finished after 1995 timesteps (2.656809091567993 seconds) with total reward -1544.98377916947
# {'coverage_prop': '0.569', 'intensity_prop': '0.127', 'ms1ms2_ratio': '0.003', 'efficiency': '0.080', 'TP': '31', 'FP': '129', 'FN': '121', 'precision': '0.194', 'recall': '0.204', 'f1': '0.199', 'total_rewards': -1544.9837791694706, 'invalid_action_count': 1619, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -320.3902202590227
# steps	 1000 	total rewards	 -626.7617413021906
# steps	 1500 	total rewards	 -668.7555231874201
# Finished after 1988 timesteps (4.061980724334717 seconds) with total reward -946.5681768677453
# {'coverage_prop': '0.753', 'intensity_prop': '0.255', 'ms1ms2_ratio': '0.006', 'efficiency': '0.188', 'TP': '122', 'FP': '249', 'FN': '122', 'precision': '0.329', 'recall': '0.500', 'f1': '0.397', 'total_rewards': -946.5681768677455, 'invalid_action_count': 1124, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -369.7925722228265
# steps	 1000 	total rewards	 -653.9340991749264
# steps	 1500 	total rewards	 -968.8785056820104
# Finished after 1989 timesteps (3.131988048553467 seconds) with total reward -1262.8127198847797
# {'coverage_prop': '0.734', 'intensity_prop': '0.219', 'ms1ms2_ratio': '0.006', 'efficiency': '0.113', 'TP': '63', 'FP': '160', 'FN': '81', 'precision': '0.283', 'recall': '0.438', 'f1': '0.343', 'total_rewards': -1262.8127198847815, 'invalid_action_count': 1368, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.00GB > 0.36GB
# steps	 500 	total rewards	 84.92805072288633
# steps	 1000 	total rewards	 192.51690336954888
# steps	 1500 	total rewards	 270.45655392017295
# Finished after 1639 timesteps (6.119385242462158 seconds) with total reward 289.93189559891755
# {'coverage_prop': '0.930', 'intensity_prop': '0.525', 'ms1ms2_ratio': '0.282', 'efficiency': '0.310', 'TP': '244', 'FP': '152', 'FN': '30', 'precision': '0.616', 'recall': '0.891', 'f1': '0.728', 'total_rewards': 289.93189559891675, 'invalid_action_count': 5, 'num_ms1_scans': 361, 'num_ms2_scans': 1278}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 82.28351238919794
# steps	 1000 	total rewards	 173.13036222112862
# steps	 1500 	total rewards	 251.14737880527935
# Finished after 1611 timesteps (4.202795743942261 seconds) with total reward 264.4611880542299
# {'coverage_prop': '0.966', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.318', 'efficiency': '0.207', 'TP': '193', 'FP': '60', 'FN': '9', 'precision': '0.763', 'recall': '0.955', 'f1': '0.848', 'total_rewards': 264.46118805422935, 'invalid_action_count': 5, 'num_ms1_scans': 389, 'num_ms2_scans': 1222}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 85.6160280123809
# steps	 1000 	total rewards	 180.0145615278704
# steps	 1500 	total rewards	 252.93872025772382
# Finished after 1649 timesteps (6.3999552726745605 seconds) with total reward 269.8204799701917
# {'coverage_prop': '0.937', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.270', 'efficiency': '0.284', 'TP': '220', 'FP': '149', 'FN': '25', 'precision': '0.596', 'recall': '0.898', 'f1': '0.717', 'total_rewards': 269.82047997019066, 'invalid_action_count': 22, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 97.93771472948755
# steps	 1000 	total rewards	 192.55564926797337
# steps	 1500 	total rewards	 273.0994064512671
# Finished after 1642 timesteps (5.313269138336182 seconds) with total reward 293.0787027694506
# {'coverage_prop': '0.923', 'intensity_prop': '0.540', 'ms1ms2_ratio': '0.279', 'efficiency': '0.325', 'TP': '265', 'FP': '152', 'FN': '35', 'precision': '0.635', 'recall': '0.883', 'f1': '0.739', 'total_rewards': 293.0787027694509, 'invalid_action_count': 7, 'num_ms1_scans': 358, 'num_ms2_scans': 1284}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 87.75530358049946
# steps	 1000 	total rewards	 185.9734426430608
# steps	 1500 	total rewards	 264.8757858815334
# Finished after 1627 timesteps (6.320262908935547 seconds) with total reward 282.0070899939298
# {'coverage_prop': '0.913', 'intensity_prop': '0.514', 'ms1ms2_ratio': '0.297', 'efficiency': '0.318', 'TP': '240', 'FP': '159', 'FN': '38', 'precision': '0.602', 'recall': '0.863', 'f1': '0.709', 'total_rewards': 282.0070899939299, 'invalid_action_count': 6, 'num_ms1_scans': 373, 'num_ms2_scans': 1254}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 67.9641454045621
# steps	 1000 	total rewards	 152.59863100706926
# steps	 1500 	total rewards	 221.22223264768965
# Finished after 1613 timesteps (3.806838035583496 seconds) with total reward 231.24927144975024
# {'coverage_prop': '0.985', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.316', 'efficiency': '0.161', 'TP': '164', 'FP': '33', 'FN': '3', 'precision': '0.832', 'recall': '0.982', 'f1': '0.901', 'total_rewards': 231.24927144974924, 'invalid_action_count': 9, 'num_ms1_scans': 387, 'num_ms2_scans': 1226}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 95.17978256869836
# steps	 1000 	total rewards	 194.71631770339388
# steps	 1500 	total rewards	 274.5227990041722
# Finished after 1619 timesteps (6.27836275100708 seconds) with total reward 295.5625339676748
# {'coverage_prop': '0.912', 'intensity_prop': '0.489', 'ms1ms2_ratio': '0.309', 'efficiency': '0.352', 'TP': '244', 'FP': '192', 'FN': '42', 'precision': '0.560', 'recall': '0.853', 'f1': '0.676', 'total_rewards': 295.56253396767426, 'invalid_action_count': 7, 'num_ms1_scans': 382, 'num_ms2_scans': 1237}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 57.721531151190796
# steps	 1000 	total rewards	 154.5934881767835
# steps	 1500 	total rewards	 229.9105193576487
# Finished after 1626 timesteps (3.790156126022339 seconds) with total reward 248.61531007870826
# {'coverage_prop': '0.980', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.299', 'efficiency': '0.160', 'TP': '164', 'FP': '36', 'FN': '4', 'precision': '0.820', 'recall': '0.976', 'f1': '0.891', 'total_rewards': 248.61531007870732, 'invalid_action_count': 2, 'num_ms1_scans': 374, 'num_ms2_scans': 1252}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 90.84681303246872
# steps	 1000 	total rewards	 182.64980149160772
# steps	 1500 	total rewards	 278.7859612979193
# Finished after 1653 timesteps (6.044545888900757 seconds) with total reward 301.84158536811645
# {'coverage_prop': '0.922', 'intensity_prop': '0.555', 'ms1ms2_ratio': '0.266', 'efficiency': '0.299', 'TP': '257', 'FP': '134', 'FN': '33', 'precision': '0.657', 'recall': '0.886', 'f1': '0.755', 'total_rewards': 301.84158536811645, 'invalid_action_count': 2, 'num_ms1_scans': 347, 'num_ms2_scans': 1306}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 84.6632366223823
# steps	 1000 	total rewards	 179.55916372925236
# steps	 1500 	total rewards	 266.681305220018
# Finished after 1623 timesteps (5.243887901306152 seconds) with total reward 282.94925630446585
# {'coverage_prop': '0.927', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.304', 'efficiency': '0.286', 'TP': '239', 'FP': '117', 'FN': '28', 'precision': '0.671', 'recall': '0.895', 'f1': '0.767', 'total_rewards': 282.94925630446596, 'invalid_action_count': 1, 'num_ms1_scans': 378, 'num_ms2_scans': 1245}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 86.76842472769066
# steps	 1000 	total rewards	 179.4653995966271
# steps	 1500 	total rewards	 253.88379308357685
# Finished after 1645 timesteps (6.425264120101929 seconds) with total reward 271.8458335900976
# {'coverage_prop': '0.907', 'intensity_prop': '0.516', 'ms1ms2_ratio': '0.275', 'efficiency': '0.312', 'TP': '256', 'FP': '146', 'FN': '41', 'precision': '0.637', 'recall': '0.862', 'f1': '0.732', 'total_rewards': 271.84583359009685, 'invalid_action_count': 23, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 81.51164620078171
# steps	 1000 	total rewards	 168.77612115255863
# steps	 1500 	total rewards	 230.44787490364703
# Finished after 1624 timesteps (4.366442918777466 seconds) with total reward 249.00410176007458
# {'coverage_prop': '0.964', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.301', 'efficiency': '0.192', 'TP': '188', 'FP': '52', 'FN': '9', 'precision': '0.783', 'recall': '0.954', 'f1': '0.860', 'total_rewards': 249.00410176007307, 'invalid_action_count': 4, 'num_ms1_scans': 376, 'num_ms2_scans': 1248}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 82.43493814703444
# steps	 1000 	total rewards	 169.67716155070218
# steps	 1500 	total rewards	 244.63566610608223
# Finished after 1609 timesteps (5.438824892044067 seconds) with total reward 260.11397969021755
# {'coverage_prop': '0.952', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.321', 'efficiency': '0.196', 'TP': '183', 'FP': '56', 'FN': '12', 'precision': '0.766', 'recall': '0.938', 'f1': '0.843', 'total_rewards': 260.11397969021624, 'invalid_action_count': 1, 'num_ms1_scans': 391, 'num_ms2_scans': 1218}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 75.59484949242601
# steps	 1000 	total rewards	 160.15723429294675
# steps	 1500 	total rewards	 240.91874997169757
# Finished after 1603 timesteps (4.86934494972229 seconds) with total reward 252.92314526597693
# {'coverage_prop': '0.950', 'intensity_prop': '0.608', 'ms1ms2_ratio': '0.329', 'efficiency': '0.236', 'TP': '200', 'FP': '85', 'FN': '15', 'precision': '0.702', 'recall': '0.930', 'f1': '0.800', 'total_rewards': 252.92314526597568, 'invalid_action_count': 0, 'num_ms1_scans': 397, 'num_ms2_scans': 1206}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 65.87705243191907
# steps	 1000 	total rewards	 146.70354454153994
# steps	 1500 	total rewards	 214.5945525783657
# Finished after 1626 timesteps (3.851797103881836 seconds) with total reward 230.6532003541172
# {'coverage_prop': '0.951', 'intensity_prop': '0.682', 'ms1ms2_ratio': '0.299', 'efficiency': '0.157', 'TP': '158', 'FP': '38', 'FN': '10', 'precision': '0.806', 'recall': '0.940', 'f1': '0.868', 'total_rewards': 230.65320035411588, 'invalid_action_count': 3, 'num_ms1_scans': 374, 'num_ms2_scans': 1252}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 77.36100915674064
# steps	 1000 	total rewards	 169.3119687002014
# steps	 1500 	total rewards	 258.92355013183544
# Finished after 1647 timesteps (6.372020959854126 seconds) with total reward 283.5290993124221
# {'coverage_prop': '0.936', 'intensity_prop': '0.545', 'ms1ms2_ratio': '0.274', 'efficiency': '0.295', 'TP': '244', 'FP': '137', 'FN': '26', 'precision': '0.640', 'recall': '0.904', 'f1': '0.750', 'total_rewards': 283.5290993124217, 'invalid_action_count': 4, 'num_ms1_scans': 354, 'num_ms2_scans': 1293}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 92.65719334425042
# steps	 1000 	total rewards	 196.91062111187458
# steps	 1500 	total rewards	 283.54432089781346
# Finished after 1651 timesteps (5.949364900588989 seconds) with total reward 307.3041994028308
# {'coverage_prop': '0.908', 'intensity_prop': '0.521', 'ms1ms2_ratio': '0.268', 'efficiency': '0.347', 'TP': '290', 'FP': '162', 'FN': '46', 'precision': '0.642', 'recall': '0.863', 'f1': '0.736', 'total_rewards': 307.3041994028311, 'invalid_action_count': 3, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 93.77900068210916
# steps	 1000 	total rewards	 187.94335931729984
# steps	 1500 	total rewards	 266.09874864228834
# Finished after 1655 timesteps (5.017939805984497 seconds) with total reward 285.6177894845215
# {'coverage_prop': '0.957', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.264', 'efficiency': '0.272', 'TP': '241', 'FP': '115', 'FN': '16', 'precision': '0.677', 'recall': '0.938', 'f1': '0.786', 'total_rewards': 285.61778948452144, 'invalid_action_count': 5, 'num_ms1_scans': 346, 'num_ms2_scans': 1309}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 82.41927285118246
# steps	 1000 	total rewards	 174.80789268633174
# steps	 1500 	total rewards	 251.55497675486134
# Finished after 1645 timesteps (4.695570945739746 seconds) with total reward 273.33902149696775
# {'coverage_prop': '0.967', 'intensity_prop': '0.647', 'ms1ms2_ratio': '0.275', 'efficiency': '0.226', 'TP': '215', 'FP': '77', 'FN': '10', 'precision': '0.736', 'recall': '0.956', 'f1': '0.832', 'total_rewards': 273.3390214969676, 'invalid_action_count': 4, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 76.4630062195169
# steps	 1000 	total rewards	 176.569201949354
# steps	 1500 	total rewards	 258.6438685032978
# Finished after 1620 timesteps (4.320242881774902 seconds) with total reward 274.74988516211647
# {'coverage_prop': '0.996', 'intensity_prop': '0.670', 'ms1ms2_ratio': '0.306', 'efficiency': '0.213', 'TP': '198', 'FP': '66', 'FN': '1', 'precision': '0.750', 'recall': '0.995', 'f1': '0.855', 'total_rewards': 274.7498851621156, 'invalid_action_count': 0, 'num_ms1_scans': 380, 'num_ms2_scans': 1240}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 88.48127187985428
# steps	 1000 	total rewards	 188.51151916790684
# steps	 1500 	total rewards	 277.34989915708667
# Finished after 1644 timesteps (5.438372850418091 seconds) with total reward 299.62316352712196
# {'coverage_prop': '0.882', 'intensity_prop': '0.516', 'ms1ms2_ratio': '0.276', 'efficiency': '0.321', 'TP': '268', 'FP': '145', 'FN': '55', 'precision': '0.649', 'recall': '0.830', 'f1': '0.728', 'total_rewards': 299.62316352712185, 'invalid_action_count': 4, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 69.3633963203367
# steps	 1000 	total rewards	 160.707057705923
# steps	 1500 	total rewards	 238.9989797604361
# Finished after 1605 timesteps (5.405288219451904 seconds) with total reward 249.22565150882534
# {'coverage_prop': '0.949', 'intensity_prop': '0.650', 'ms1ms2_ratio': '0.328', 'efficiency': '0.184', 'TP': '170', 'FP': '52', 'FN': '12', 'precision': '0.766', 'recall': '0.934', 'f1': '0.842', 'total_rewards': 249.2256515088239, 'invalid_action_count': 2, 'num_ms1_scans': 396, 'num_ms2_scans': 1209}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 78.53488661633516
# steps	 1000 	total rewards	 173.21991995534376
# steps	 1500 	total rewards	 260.7097827624747
# Finished after 1621 timesteps (4.704202890396118 seconds) with total reward 280.21611878545184
# {'coverage_prop': '0.953', 'intensity_prop': '0.614', 'ms1ms2_ratio': '0.305', 'efficiency': '0.247', 'TP': '222', 'FP': '85', 'FN': '15', 'precision': '0.723', 'recall': '0.937', 'f1': '0.816', 'total_rewards': 280.2161187854519, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 85.3912950556552
# steps	 1000 	total rewards	 181.2151860219862
# steps	 1500 	total rewards	 261.6947426633742
# Finished after 1644 timesteps (4.591511011123657 seconds) with total reward 284.83890131121615
# {'coverage_prop': '0.955', 'intensity_prop': '0.663', 'ms1ms2_ratio': '0.276', 'efficiency': '0.230', 'TP': '231', 'FP': '65', 'FN': '14', 'precision': '0.780', 'recall': '0.943', 'f1': '0.854', 'total_rewards': 284.83890131121603, 'invalid_action_count': 1, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 85.31724228397249
# steps	 1000 	total rewards	 181.87564273188735
# steps	 1500 	total rewards	 267.89044582192633
# Finished after 1628 timesteps (6.411689043045044 seconds) with total reward 285.99800660633923
# {'coverage_prop': '0.945', 'intensity_prop': '0.568', 'ms1ms2_ratio': '0.296', 'efficiency': '0.260', 'TP': '215', 'FP': '111', 'FN': '19', 'precision': '0.660', 'recall': '0.919', 'f1': '0.768', 'total_rewards': 285.99800660633935, 'invalid_action_count': 2, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 83.02185806302867
# steps	 1000 	total rewards	 181.45423638746274
# steps	 1500 	total rewards	 259.4518570390448
# Finished after 1643 timesteps (5.3197832107543945 seconds) with total reward 278.1693748304384
# {'coverage_prop': '0.944', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.278', 'efficiency': '0.291', 'TP': '246', 'FP': '128', 'FN': '22', 'precision': '0.658', 'recall': '0.918', 'f1': '0.766', 'total_rewards': 278.1693748304379, 'invalid_action_count': 10, 'num_ms1_scans': 357, 'num_ms2_scans': 1286}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 62.4919966450951
# steps	 1000 	total rewards	 155.37573327705985
# steps	 1500 	total rewards	 224.4497823922726
# Finished after 1610 timesteps (3.955063819885254 seconds) with total reward 238.11680006635152
# {'coverage_prop': '0.966', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.321', 'efficiency': '0.161', 'TP': '164', 'FP': '32', 'FN': '7', 'precision': '0.837', 'recall': '0.959', 'f1': '0.894', 'total_rewards': 238.11680006634995, 'invalid_action_count': 6, 'num_ms1_scans': 391, 'num_ms2_scans': 1219}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 78.30572922696037
# steps	 1000 	total rewards	 180.5864618462502
# steps	 1500 	total rewards	 271.75382409271845
# Finished after 1632 timesteps (4.3160340785980225 seconds) with total reward 291.2698798915874
# {'coverage_prop': '0.972', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.291', 'efficiency': '0.216', 'TP': '214', 'FP': '59', 'FN': '8', 'precision': '0.784', 'recall': '0.964', 'f1': '0.865', 'total_rewards': 291.26987989158675, 'invalid_action_count': 3, 'num_ms1_scans': 368, 'num_ms2_scans': 1264}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 98.97289061835437
# steps	 1000 	total rewards	 201.07923460250566
# steps	 1500 	total rewards	 279.93028155334116
# Finished after 1617 timesteps (8.261404275894165 seconds) with total reward 297.98914360021183
# {'coverage_prop': '0.886', 'intensity_prop': '0.458', 'ms1ms2_ratio': '0.310', 'efficiency': '0.354', 'TP': '245', 'FP': '192', 'FN': '56', 'precision': '0.561', 'recall': '0.814', 'f1': '0.664', 'total_rewards': 297.9891436002117, 'invalid_action_count': 11, 'num_ms1_scans': 383, 'num_ms2_scans': 1234}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 81.21941879278245
# steps	 1000 	total rewards	 176.6084161490059
# steps	 1500 	total rewards	 257.33088491218984
# Finished after 1637 timesteps (4.547343730926514 seconds) with total reward 273.5941757675533
# {'coverage_prop': '0.970', 'intensity_prop': '0.659', 'ms1ms2_ratio': '0.285', 'efficiency': '0.232', 'TP': '216', 'FP': '79', 'FN': '9', 'precision': '0.732', 'recall': '0.960', 'f1': '0.831', 'total_rewards': 273.59417576755294, 'invalid_action_count': 0, 'num_ms1_scans': 363, 'num_ms2_scans': 1274}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 92.5276178076839
# steps	 1000 	total rewards	 205.25382864627784
# steps	 1500 	total rewards	 312.7588878054987
# Finished after 1722 timesteps (9.825931072235107 seconds) with total reward 350.1583925147164
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 350.15839251471635, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.19223993264903
# steps	 1000 	total rewards	 200.01185786399162
# steps	 1500 	total rewards	 278.69251864828544
# Finished after 1556 timesteps (9.202692985534668 seconds) with total reward 286.42041452327317
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 286.42041452327345, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.09810262952533
# steps	 1000 	total rewards	 204.55175528344176
# steps	 1500 	total rewards	 311.70589197292
# Finished after 1669 timesteps (9.004181146621704 seconds) with total reward 335.8567231016701
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 335.856723101671, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.75112549735738
# steps	 1000 	total rewards	 222.260470162795
# steps	 1500 	total rewards	 321.6296912754646
# Finished after 1717 timesteps (9.861031770706177 seconds) with total reward 364.78676992745324
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 364.7867699274535, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.88207661824359
# steps	 1000 	total rewards	 225.03458447204991
# steps	 1500 	total rewards	 333.40644054419124
# Finished after 1704 timesteps (9.536840915679932 seconds) with total reward 368.54312915676854
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 368.54312915676945, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.95053041210245
# steps	 1000 	total rewards	 176.02517486243747
# Finished after 1408 timesteps (9.465204000473022 seconds) with total reward 238.71804354506358
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 238.7180435450617, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.04778207928516
# steps	 1000 	total rewards	 216.92306176316305
# steps	 1500 	total rewards	 317.03297009874126
# Finished after 1744 timesteps (10.214078903198242 seconds) with total reward 357.54143159354504
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 357.54143159354567, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.27568189026226
# steps	 1000 	total rewards	 178.89586218914897
# Finished after 1468 timesteps (7.351734161376953 seconds) with total reward 248.8792687394992
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 248.87926873949786, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 102.06959352333683
# steps	 1000 	total rewards	 203.76934731050875
# steps	 1500 	total rewards	 314.6913157438472
# Finished after 1736 timesteps (12.09569501876831 seconds) with total reward 352.8683422368248
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 352.8683422368253, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 90.74138548172694
# steps	 1000 	total rewards	 200.31290144512386
# steps	 1500 	total rewards	 301.1097996085705
# Finished after 1667 timesteps (9.40189790725708 seconds) with total reward 323.768416073993
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 323.7684160739943, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.23962533608534
# steps	 1000 	total rewards	 197.16226995805556
# steps	 1500 	total rewards	 303.39580167752945
# Finished after 1737 timesteps (10.229676008224487 seconds) with total reward 344.057804535654
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 344.05780453565535, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.76014323446897
# steps	 1000 	total rewards	 182.82317997694054
# steps	 1500 	total rewards	 254.1775526296638
# Finished after 1530 timesteps (7.868841886520386 seconds) with total reward 257.90826139058424
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 257.9082613905829, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.09788008205047
# steps	 1000 	total rewards	 173.34530752343633
# steps	 1500 	total rewards	 250.4027444407447
# Finished after 1602 timesteps (12.54788613319397 seconds) with total reward 265.8130372865816
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 265.8130372865811, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 81.87979467550704
# steps	 1000 	total rewards	 176.3296676850765
# steps	 1500 	total rewards	 264.5543538505019
# Finished after 1645 timesteps (9.831390142440796 seconds) with total reward 281.66421220903726
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 281.6642122090379, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 77.69553492222708
# steps	 1000 	total rewards	 165.92205077135358
# Finished after 1497 timesteps (7.7549262046813965 seconds) with total reward 238.86550329561172
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 238.86550329561047, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.05709360186964
# steps	 1000 	total rewards	 202.35383743309467
# steps	 1500 	total rewards	 309.4258646878863
# Finished after 1655 timesteps (9.262544870376587 seconds) with total reward 340.11849111963613
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 340.118491119637, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 105.80378017337763
# steps	 1000 	total rewards	 218.16501246190484
# steps	 1500 	total rewards	 323.99517148498575
# Finished after 1729 timesteps (12.028014183044434 seconds) with total reward 365.3798953710612
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 365.3798953710626, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.86888851189178
# steps	 1000 	total rewards	 210.73859611594213
# steps	 1500 	total rewards	 300.65131585356136
# Finished after 1681 timesteps (9.030080080032349 seconds) with total reward 326.453219442385
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 326.45321944238583, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.55640776019361
# steps	 1000 	total rewards	 192.1170010832405
# steps	 1500 	total rewards	 282.6369316315453
# Finished after 1621 timesteps (13.247442960739136 seconds) with total reward 301.02243270902477
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 301.022432709025, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.8961989902214
# steps	 1000 	total rewards	 183.76704030525036
# steps	 1500 	total rewards	 264.106842989171
# Finished after 1634 timesteps (13.182115077972412 seconds) with total reward 282.8349639496908
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 282.8349639496904, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.82872862229425
# steps	 1000 	total rewards	 205.4574323828516
# steps	 1500 	total rewards	 298.0440315538605
# Finished after 1726 timesteps (10.12168288230896 seconds) with total reward 339.6563370807766
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 339.65633708077706, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 78.8765952264226
# steps	 1000 	total rewards	 180.8121218448101
# Finished after 1475 timesteps (10.111891984939575 seconds) with total reward 259.5886548759064
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 259.5886548759048, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 90.37844742158512
# steps	 1000 	total rewards	 195.95932027941527
# steps	 1500 	total rewards	 283.3609709366841
# Finished after 1636 timesteps (9.081195831298828 seconds) with total reward 305.03129962834686
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 305.03129962834777, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.58010974902588
# steps	 1000 	total rewards	 199.06887434647197
# steps	 1500 	total rewards	 285.5523492877917
# Finished after 1575 timesteps (8.01981806755066 seconds) with total reward 296.6703624144893
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 296.67036241449057, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 90.58123202962977
# steps	 1000 	total rewards	 201.86616968777264
# steps	 1500 	total rewards	 295.787668388372
# Finished after 1681 timesteps (8.922031879425049 seconds) with total reward 324.2819674955664
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 324.28196749556696, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.78144021754095
# steps	 1000 	total rewards	 188.87430385569195
# steps	 1500 	total rewards	 297.86842274642567
# Finished after 1679 timesteps (11.68656587600708 seconds) with total reward 329.2116800669655
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 329.21168006696644, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 71.98194223405334
# steps	 1000 	total rewards	 170.41017366979133
# Finished after 1465 timesteps (7.825959920883179 seconds) with total reward 242.86558010739546
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 242.86558010739404, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 87.80052172308895
# steps	 1000 	total rewards	 195.50633781024922
# steps	 1500 	total rewards	 294.00010247549244
# Finished after 1564 timesteps (8.369482040405273 seconds) with total reward 304.0900195549617
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 304.09001955496166, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.17309733822901
# steps	 1000 	total rewards	 195.47739728296165
# steps	 1500 	total rewards	 298.6482177897861
# Finished after 1749 timesteps (9.8052818775177 seconds) with total reward 346.2046795612188
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 346.20467956121945, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.33998672596451
# steps	 1000 	total rewards	 192.64754247155082
# steps	 1500 	total rewards	 274.80651079438553
# Finished after 1657 timesteps (8.359896898269653 seconds) with total reward 293.02734741027416
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 293.02734741027416, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8010648910>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8047e96670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8030902910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '240', 'FP': '186', 'FN': '17', 'precision': '0.563', 'recall': '0.934', 'f1': '0.703'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.477', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '105', 'FP': '132', 'FN': '14', 'precision': '0.443', 'recall': '0.882', 'f1': '0.590'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.072', 'efficiency': '0.756', 'TP': '278', 'FP': '203', 'FN': '17', 'precision': '0.578', 'recall': '0.942', 'f1': '0.716'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '190', 'FP': '164', 'FN': '18', 'precision': '0.537', 'recall': '0.913', 'f1': '0.676'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.488', 'ms1ms2_ratio': '2.350', 'efficiency': '0.738', 'TP': '120', 'FP': '139', 'FN': '6', 'precision': '0.463', 'recall': '0.952', 'f1': '0.623'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.514', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '146', 'FP': '123', 'FN': '12', 'precision': '0.543', 'recall': '0.924', 'f1': '0.684'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.034', 'efficiency': '0.719', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.008', 'efficiency': '0.727', 'TP': '149', 'FP': '141', 'FN': '14', 'precision': '0.514', 'recall': '0.914', 'f1': '0.658'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1382.877467                1482.0          0.563           0.169
# 1  random   -1337.867173                1429.0          0.668           0.192
# 2  random   -1244.057420                1376.0          0.718           0.215
# 3  random   -1087.306538                1230.0          0.712           0.219
# 4  random    -973.096030                1137.0          0.808           0.274
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.003       0.121      0.267   0.256  0.261
# 1          0.005       0.088      0.269   0.351  0.304
# 2          0.003       0.142      0.276   0.413  0.331
# 3          0.006       0.163      0.286   0.414  0.338
# 4          0.006       0.178      0.320   0.574  0.411

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_5.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_5.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     289.931896                   5.0          0.930           0.525
# 31    DQN     264.461188                   5.0          0.966           0.669
# 32    DQN     269.820480                  22.0          0.937           0.527
# 33    DQN     293.078703                   7.0          0.923           0.540
# 34    DQN     282.007090                   6.0          0.913           0.514
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.282       0.310      0.616   0.891  0.728
# 31          0.318       0.207      0.763   0.955  0.848
# 32          0.270       0.284      0.596   0.898  0.717
# 33          0.279       0.325      0.635   0.883  0.739
# 34          0.297       0.318      0.602   0.863  0.709

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
