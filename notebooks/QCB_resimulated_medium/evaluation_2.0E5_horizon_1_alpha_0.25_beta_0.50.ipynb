# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-04-04 16:31:25.100 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa5d3f3f7c0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa5f3844cd0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa5f3861e70>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  30)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5

dqn_in_dir = 'DQN_2.0E5'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_2.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa5d3f3f7c0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa5f3844cd0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa5f3861e70>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa5d3f3f7c0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa5f3844cd0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa5f3861e70>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 1
out_dir = 'evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 65.05381641877035
# steps	 1000 	total rewards	 138.9031942351194
# steps	 1500 	total rewards	 211.1880744801266
# Finished after 1788 timesteps (2.1345317363739014 seconds) with total reward 248.18706587915582
# {'coverage_prop': '0.930', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.135', 'efficiency': '0.251', 'TP': '325', 'FP': '71', 'FN': '30', 'precision': '0.821', 'recall': '0.915', 'f1': '0.866', 'total_rewards': 248.1870658791557, 'invalid_action_count': 0, 'num_ms1_scans': 212, 'num_ms2_scans': 1576}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 61.106551839496916
# steps	 1000 	total rewards	 127.38207743513104
# steps	 1500 	total rewards	 197.09357589488377
# Finished after 1702 timesteps (1.515519142150879 seconds) with total reward 223.00871414229815
# {'coverage_prop': '0.947', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.212', 'efficiency': '0.177', 'TP': '233', 'FP': '15', 'FN': '14', 'precision': '0.940', 'recall': '0.943', 'f1': '0.941', 'total_rewards': 223.0087141422986, 'invalid_action_count': 0, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 58.32324098482296
# steps	 1000 	total rewards	 132.90326684865522
# steps	 1500 	total rewards	 204.13066173624904
# Finished after 1760 timesteps (1.6797971725463867 seconds) with total reward 236.52957685717396
# {'coverage_prop': '0.937', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.158', 'efficiency': '0.243', 'TP': '309', 'FP': '60', 'FN': '25', 'precision': '0.837', 'recall': '0.925', 'f1': '0.879', 'total_rewards': 236.52957685717413, 'invalid_action_count': 0, 'num_ms1_scans': 240, 'num_ms2_scans': 1520}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 67.45059657005521
# steps	 1000 	total rewards	 142.1029616085986
# steps	 1500 	total rewards	 204.33613969651873
# Finished after 1777 timesteps (2.1927032470703125 seconds) with total reward 237.4923547878455
# {'coverage_prop': '0.934', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.144', 'efficiency': '0.272', 'TP': '373', 'FP': '49', 'FN': '30', 'precision': '0.884', 'recall': '0.926', 'f1': '0.904', 'total_rewards': 237.49235478784553, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 62.126485305156734
# steps	 1000 	total rewards	 138.7034601181553
# steps	 1500 	total rewards	 211.80259199191005
# Finished after 1779 timesteps (1.7927589416503906 seconds) with total reward 249.0385204585462
# {'coverage_prop': '0.959', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.142', 'efficiency': '0.269', 'TP': '344', 'FP': '75', 'FN': '18', 'precision': '0.821', 'recall': '0.950', 'f1': '0.881', 'total_rewards': 249.03852045854663, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 50.923355008076754
# steps	 1000 	total rewards	 113.1415901941655
# steps	 1500 	total rewards	 166.91542904605387
# Finished after 1624 timesteps (2.028855800628662 seconds) with total reward 180.0793950538113
# {'coverage_prop': '0.940', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.301', 'efficiency': '0.151', 'TP': '178', 'FP': '10', 'FN': '12', 'precision': '0.947', 'recall': '0.937', 'f1': '0.942', 'total_rewards': 180.07939505381165, 'invalid_action_count': 0, 'num_ms1_scans': 376, 'num_ms2_scans': 1248}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 64.27567050202602
# steps	 1000 	total rewards	 143.28123179008418
# steps	 1500 	total rewards	 206.94935466935988
# Finished after 1787 timesteps (2.172395944595337 seconds) with total reward 240.14042531438452
# {'coverage_prop': '0.927', 'intensity_prop': '0.676', 'ms1ms2_ratio': '0.135', 'efficiency': '0.281', 'TP': '365', 'FP': '78', 'FN': '35', 'precision': '0.824', 'recall': '0.912', 'f1': '0.866', 'total_rewards': 240.14042531438437, 'invalid_action_count': 0, 'num_ms1_scans': 213, 'num_ms2_scans': 1574}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 50.4601477930742
# steps	 1000 	total rewards	 120.80148652437985
# steps	 1500 	total rewards	 179.94424150889395
# Finished after 1660 timesteps (1.4077210426330566 seconds) with total reward 200.48639219630846
# {'coverage_prop': '0.956', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.258', 'efficiency': '0.148', 'TP': '180', 'FP': '15', 'FN': '9', 'precision': '0.923', 'recall': '0.952', 'f1': '0.938', 'total_rewards': 200.48639219630826, 'invalid_action_count': 0, 'num_ms1_scans': 340, 'num_ms2_scans': 1320}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 65.00623045955086
# steps	 1000 	total rewards	 136.85305637266958
# steps	 1500 	total rewards	 205.14615568410164
# Finished after 1791 timesteps (2.22603178024292 seconds) with total reward 244.1334323003892
# {'coverage_prop': '0.936', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.132', 'efficiency': '0.251', 'TP': '340', 'FP': '57', 'FN': '27', 'precision': '0.856', 'recall': '0.926', 'f1': '0.890', 'total_rewards': 244.13343230038922, 'invalid_action_count': 0, 'num_ms1_scans': 209, 'num_ms2_scans': 1582}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 62.91163368171607
# steps	 1000 	total rewards	 137.1021654184039
# steps	 1500 	total rewards	 208.677673442559
# Finished after 1768 timesteps (1.5899910926818848 seconds) with total reward 241.54876173800463
# {'coverage_prop': '0.940', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.152', 'efficiency': '0.235', 'TP': '311', 'FP': '50', 'FN': '23', 'precision': '0.861', 'recall': '0.931', 'f1': '0.895', 'total_rewards': 241.5487617380048, 'invalid_action_count': 0, 'num_ms1_scans': 233, 'num_ms2_scans': 1535}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 64.1949508686039
# steps	 1000 	total rewards	 139.31078201737742
# steps	 1500 	total rewards	 218.13566968190736
# Finished after 1798 timesteps (2.3824338912963867 seconds) with total reward 259.10642542356436
# {'coverage_prop': '0.923', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.127', 'efficiency': '0.256', 'TP': '344', 'FP': '65', 'FN': '34', 'precision': '0.841', 'recall': '0.910', 'f1': '0.874', 'total_rewards': 259.1064254235648, 'invalid_action_count': 0, 'num_ms1_scans': 202, 'num_ms2_scans': 1596}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 57.05403277105314
# steps	 1000 	total rewards	 127.11631318571794
# steps	 1500 	total rewards	 182.01819517081242
# Finished after 1685 timesteps (1.6439752578735352 seconds) with total reward 200.05083741320286
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.230', 'efficiency': '0.172', 'TP': '213', 'FP': '23', 'FN': '13', 'precision': '0.903', 'recall': '0.942', 'f1': '0.922', 'total_rewards': 200.0508374132029, 'invalid_action_count': 0, 'num_ms1_scans': 315, 'num_ms2_scans': 1370}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 65.8533620290557
# steps	 1000 	total rewards	 134.21558584123142
# steps	 1500 	total rewards	 195.1692783750408
# Finished after 1741 timesteps (2.2839059829711914 seconds) with total reward 225.9420493993848
# {'coverage_prop': '0.940', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.175', 'efficiency': '0.159', 'TP': '209', 'FP': '27', 'FN': '15', 'precision': '0.886', 'recall': '0.933', 'f1': '0.909', 'total_rewards': 225.94204939938496, 'invalid_action_count': 0, 'num_ms1_scans': 259, 'num_ms2_scans': 1482}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 58.86645866875631
# steps	 1000 	total rewards	 127.85557939236962
# steps	 1500 	total rewards	 197.30142479729633
# Finished after 1750 timesteps (1.933851957321167 seconds) with total reward 224.40197151670608
# {'coverage_prop': '0.937', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.167', 'efficiency': '0.187', 'TP': '247', 'FP': '34', 'FN': '19', 'precision': '0.879', 'recall': '0.929', 'f1': '0.903', 'total_rewards': 224.40197151670597, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1499}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 56.825408888884496
# steps	 1000 	total rewards	 124.60364269245869
# steps	 1500 	total rewards	 180.0614238200407
# Finished after 1674 timesteps (1.611649751663208 seconds) with total reward 198.7222754273914
# {'coverage_prop': '0.927', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.242', 'efficiency': '0.142', 'TP': '175', 'FP': '16', 'FN': '15', 'precision': '0.916', 'recall': '0.921', 'f1': '0.919', 'total_rewards': 198.7222754273916, 'invalid_action_count': 0, 'num_ms1_scans': 326, 'num_ms2_scans': 1348}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 58.55173389411482
# steps	 1000 	total rewards	 133.37699348568518
# steps	 1500 	total rewards	 195.09402784031872
# Finished after 1761 timesteps (4.189331293106079 seconds) with total reward 229.93674789770557
# {'coverage_prop': '0.941', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.157', 'efficiency': '0.252', 'TP': '337', 'FP': '46', 'FN': '24', 'precision': '0.880', 'recall': '0.934', 'f1': '0.906', 'total_rewards': 229.93674789770535, 'invalid_action_count': 0, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 67.00095177126519
# steps	 1000 	total rewards	 145.88032340427483
# steps	 1500 	total rewards	 218.49299564989514
# Finished after 1794 timesteps (2.7270350456237793 seconds) with total reward 255.9750423429452
# {'coverage_prop': '0.942', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.130', 'efficiency': '0.295', 'TP': '406', 'FP': '63', 'FN': '29', 'precision': '0.866', 'recall': '0.933', 'f1': '0.898', 'total_rewards': 255.97504234294541, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 64.88190229096602
# steps	 1000 	total rewards	 137.15783490022494
# steps	 1500 	total rewards	 209.30602850068806
# Finished after 1762 timesteps (2.9644181728363037 seconds) with total reward 241.75833103137012
# {'coverage_prop': '0.946', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.156', 'efficiency': '0.231', 'TP': '303', 'FP': '49', 'FN': '20', 'precision': '0.861', 'recall': '0.938', 'f1': '0.898', 'total_rewards': 241.7583310313706, 'invalid_action_count': 0, 'num_ms1_scans': 238, 'num_ms2_scans': 1524}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 62.817197204175855
# steps	 1000 	total rewards	 133.46946973201747
# steps	 1500 	total rewards	 201.11056596109182
# Finished after 1728 timesteps (1.9462332725524902 seconds) with total reward 229.27799502333443
# {'coverage_prop': '0.954', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.188', 'efficiency': '0.198', 'TP': '250', 'FP': '38', 'FN': '14', 'precision': '0.868', 'recall': '0.947', 'f1': '0.906', 'total_rewards': 229.2779950233343, 'invalid_action_count': 0, 'num_ms1_scans': 273, 'num_ms2_scans': 1455}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 58.46563363733143
# steps	 1000 	total rewards	 131.18934933837585
# steps	 1500 	total rewards	 201.02588099944418
# Finished after 1733 timesteps (1.6935172080993652 seconds) with total reward 232.019920009469
# {'coverage_prop': '0.962', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.182', 'efficiency': '0.174', 'TP': '223', 'FP': '32', 'FN': '10', 'precision': '0.875', 'recall': '0.957', 'f1': '0.914', 'total_rewards': 232.01992000946908, 'invalid_action_count': 0, 'num_ms1_scans': 267, 'num_ms2_scans': 1466}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 65.46493577445926
# steps	 1000 	total rewards	 139.7990645248855
# steps	 1500 	total rewards	 211.3432549799309
# Finished after 1797 timesteps (3.2334883213043213 seconds) with total reward 250.41001457172965
# {'coverage_prop': '0.910', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.127', 'efficiency': '0.267', 'TP': '374', 'FP': '52', 'FN': '42', 'precision': '0.878', 'recall': '0.899', 'f1': '0.888', 'total_rewards': 250.41001457172962, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 57.946424613645874
# steps	 1000 	total rewards	 121.90781906751718
# steps	 1500 	total rewards	 180.8597627246137
# Finished after 1663 timesteps (1.9800148010253906 seconds) with total reward 199.51719480668103
# {'coverage_prop': '0.940', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.254', 'efficiency': '0.166', 'TP': '202', 'FP': '18', 'FN': '14', 'precision': '0.918', 'recall': '0.935', 'f1': '0.927', 'total_rewards': 199.51719480668118, 'invalid_action_count': 0, 'num_ms1_scans': 337, 'num_ms2_scans': 1326}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 60.29725654760462
# steps	 1000 	total rewards	 125.88450257577273
# steps	 1500 	total rewards	 189.90168370467393
# Finished after 1750 timesteps (1.9915649890899658 seconds) with total reward 225.15378323497808
# {'coverage_prop': '0.953', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.167', 'efficiency': '0.205', 'TP': '271', 'FP': '36', 'FN': '15', 'precision': '0.883', 'recall': '0.948', 'f1': '0.914', 'total_rewards': 225.15378323497833, 'invalid_action_count': 0, 'num_ms1_scans': 250, 'num_ms2_scans': 1500}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 60.568630991218214
# steps	 1000 	total rewards	 130.00115168203723
# steps	 1500 	total rewards	 195.3584344660114
# Finished after 1716 timesteps (3.1004478931427 seconds) with total reward 222.43100825239054
# {'coverage_prop': '0.929', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.198', 'efficiency': '0.201', 'TP': '261', 'FP': '27', 'FN': '22', 'precision': '0.906', 'recall': '0.922', 'f1': '0.914', 'total_rewards': 222.43100825239043, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1432}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 63.05695489513723
# steps	 1000 	total rewards	 140.2872517600564
# steps	 1500 	total rewards	 210.79437890798127
# Finished after 1770 timesteps (1.9397740364074707 seconds) with total reward 248.51408587098564
# {'coverage_prop': '0.977', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.150', 'efficiency': '0.219', 'TP': '290', 'FP': '47', 'FN': '8', 'precision': '0.861', 'recall': '0.973', 'f1': '0.913', 'total_rewards': 248.51408587098555, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1539}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 61.664508787944136
# steps	 1000 	total rewards	 130.58760389484814
# steps	 1500 	total rewards	 204.61636816711467
# Finished after 1769 timesteps (1.9781618118286133 seconds) with total reward 239.0162375982769
# {'coverage_prop': '0.949', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.150', 'efficiency': '0.244', 'TP': '328', 'FP': '48', 'FN': '20', 'precision': '0.872', 'recall': '0.943', 'f1': '0.906', 'total_rewards': 239.0162375982766, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 47.9006479871044
# steps	 1000 	total rewards	 117.07283937649873
# steps	 1500 	total rewards	 178.1779636757456
# Finished after 1666 timesteps (4.985343933105469 seconds) with total reward 195.04046575823472
# {'coverage_prop': '0.946', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.251', 'efficiency': '0.144', 'TP': '181', 'FP': '11', 'FN': '11', 'precision': '0.943', 'recall': '0.943', 'f1': '0.943', 'total_rewards': 195.04046575823492, 'invalid_action_count': 0, 'num_ms1_scans': 334, 'num_ms2_scans': 1332}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 56.48922586531542
# steps	 1000 	total rewards	 122.94551475902384
# steps	 1500 	total rewards	 187.23074302235494
# Finished after 1711 timesteps (2.513788938522339 seconds) with total reward 217.62093766997128
# {'coverage_prop': '0.950', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.203', 'efficiency': '0.188', 'TP': '241', 'FP': '26', 'FN': '14', 'precision': '0.903', 'recall': '0.945', 'f1': '0.923', 'total_rewards': 217.62093766997134, 'invalid_action_count': 0, 'num_ms1_scans': 289, 'num_ms2_scans': 1422}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 68.05904208059135
# steps	 1000 	total rewards	 141.63968792780298
# steps	 1500 	total rewards	 218.70860395246677
# Finished after 1815 timesteps (2.346652030944824 seconds) with total reward 263.1318149652478
# {'coverage_prop': '0.909', 'intensity_prop': '0.659', 'ms1ms2_ratio': '0.113', 'efficiency': '0.275', 'TP': '366', 'FP': '82', 'FN': '45', 'precision': '0.817', 'recall': '0.891', 'f1': '0.852', 'total_rewards': 263.1318149652475, 'invalid_action_count': 0, 'num_ms1_scans': 185, 'num_ms2_scans': 1630}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 55.906221352691155
# steps	 1000 	total rewards	 122.70161112326743
# steps	 1500 	total rewards	 187.77769955097895
# Finished after 1729 timesteps (2.02205491065979 seconds) with total reward 216.0190724603645
# {'coverage_prop': '0.947', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.186', 'efficiency': '0.198', 'TP': '261', 'FP': '27', 'FN': '16', 'precision': '0.906', 'recall': '0.942', 'f1': '0.924', 'total_rewards': 216.0190724603643, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# method = PPO max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 68.58646461091425
# steps	 1000 	total rewards	 140.8779022815473
# steps	 1500 	total rewards	 218.38485171260476
# Finished after 1854 timesteps (4.676196813583374 seconds) with total reward 266.0140742298517
# {'coverage_prop': '0.937', 'intensity_prop': '0.695', 'ms1ms2_ratio': '0.085', 'efficiency': '0.234', 'TP': '332', 'FP': '67', 'FN': '27', 'precision': '0.832', 'recall': '0.925', 'f1': '0.876', 'total_rewards': 266.01407422985176, 'invalid_action_count': 0, 'num_ms1_scans': 146, 'num_ms2_scans': 1708}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 65.78345510531287
# steps	 1000 	total rewards	 135.60559246842408
# steps	 1500 	total rewards	 207.23966678764344
# Finished after 1801 timesteps (2.6458020210266113 seconds) with total reward 248.30548997449512
# {'coverage_prop': '0.954', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.124', 'efficiency': '0.156', 'TP': '237', 'FP': '13', 'FN': '12', 'precision': '0.948', 'recall': '0.952', 'f1': '0.950', 'total_rewards': 248.30548997449534, 'invalid_action_count': 0, 'num_ms1_scans': 199, 'num_ms2_scans': 1602}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 63.63513483737777
# steps	 1000 	total rewards	 136.88990933830564
# steps	 1500 	total rewards	 213.27302830449378
# Finished after 1835 timesteps (3.330796003341675 seconds) with total reward 258.65966786866994
# {'coverage_prop': '0.957', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.099', 'efficiency': '0.226', 'TP': '316', 'FP': '61', 'FN': '17', 'precision': '0.838', 'recall': '0.949', 'f1': '0.890', 'total_rewards': 258.65966786866994, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 70.8684794216699
# steps	 1000 	total rewards	 145.39199740169056
# steps	 1500 	total rewards	 209.90195411316878
# Finished after 1851 timesteps (3.290174961090088 seconds) with total reward 252.8218875369479
# {'coverage_prop': '0.938', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.088', 'efficiency': '0.249', 'TP': '372', 'FP': '52', 'FN': '28', 'precision': '0.877', 'recall': '0.930', 'f1': '0.903', 'total_rewards': 252.8218875369479, 'invalid_action_count': 0, 'num_ms1_scans': 150, 'num_ms2_scans': 1701}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 65.15031644833911
# steps	 1000 	total rewards	 143.8228528877859
# steps	 1500 	total rewards	 217.57209032397128
# Finished after 1843 timesteps (3.1118757724761963 seconds) with total reward 263.56377014769714
# {'coverage_prop': '0.973', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.093', 'efficiency': '0.252', 'TP': '360', 'FP': '65', 'FN': '12', 'precision': '0.847', 'recall': '0.968', 'f1': '0.903', 'total_rewards': 263.5637701476968, 'invalid_action_count': 0, 'num_ms1_scans': 157, 'num_ms2_scans': 1686}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 57.96579660619521
# steps	 1000 	total rewards	 122.6732118875219
# steps	 1500 	total rewards	 182.77835450218183
# Finished after 1755 timesteps (2.6499240398406982 seconds) with total reward 210.82459752961762
# {'coverage_prop': '0.950', 'intensity_prop': '0.822', 'ms1ms2_ratio': '0.162', 'efficiency': '0.126', 'TP': '184', 'FP': '6', 'FN': '10', 'precision': '0.968', 'recall': '0.948', 'f1': '0.958', 'total_rewards': 210.8245975296179, 'invalid_action_count': 0, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 65.35515063816236
# steps	 1000 	total rewards	 146.1366523670364
# steps	 1500 	total rewards	 213.1374431768461
# Finished after 1852 timesteps (3.812835693359375 seconds) with total reward 254.6418814974545
# {'coverage_prop': '0.923', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.087', 'efficiency': '0.259', 'TP': '376', 'FP': '65', 'FN': '37', 'precision': '0.853', 'recall': '0.910', 'f1': '0.881', 'total_rewards': 254.64188149745453, 'invalid_action_count': 0, 'num_ms1_scans': 148, 'num_ms2_scans': 1704}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 57.04682714323394
# steps	 1000 	total rewards	 127.79038557597998
# steps	 1500 	total rewards	 191.82774701135259
# Finished after 1768 timesteps (3.4695820808410645 seconds) with total reward 227.8907571382794
# {'coverage_prop': '0.951', 'intensity_prop': '0.818', 'ms1ms2_ratio': '0.151', 'efficiency': '0.126', 'TP': '186', 'FP': '8', 'FN': '10', 'precision': '0.959', 'recall': '0.949', 'f1': '0.954', 'total_rewards': 227.89075713827953, 'invalid_action_count': 0, 'num_ms1_scans': 232, 'num_ms2_scans': 1536}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 67.4985424319333
# steps	 1000 	total rewards	 139.77825310912257
# steps	 1500 	total rewards	 212.56259219676252
# Finished after 1864 timesteps (3.2541749477386475 seconds) with total reward 259.41929726364157
# {'coverage_prop': '0.939', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.079', 'efficiency': '0.230', 'TP': '340', 'FP': '58', 'FN': '26', 'precision': '0.854', 'recall': '0.929', 'f1': '0.890', 'total_rewards': 259.4192972636413, 'invalid_action_count': 0, 'num_ms1_scans': 136, 'num_ms2_scans': 1728}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 65.02801588651086
# steps	 1000 	total rewards	 138.09458529651067
# steps	 1500 	total rewards	 211.41090865991583
# Finished after 1844 timesteps (2.971834897994995 seconds) with total reward 256.52794602202584
# {'coverage_prop': '0.945', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.092', 'efficiency': '0.215', 'TP': '314', 'FP': '49', 'FN': '21', 'precision': '0.865', 'recall': '0.937', 'f1': '0.900', 'total_rewards': 256.5279460220257, 'invalid_action_count': 0, 'num_ms1_scans': 156, 'num_ms2_scans': 1688}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 68.91480716091593
# steps	 1000 	total rewards	 142.53262650923722
# steps	 1500 	total rewards	 223.65606301547768
# Finished after 1865 timesteps (5.26181697845459 seconds) with total reward 275.79843529985925
# {'coverage_prop': '0.939', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.078', 'efficiency': '0.240', 'TP': '364', 'FP': '52', 'FN': '27', 'precision': '0.875', 'recall': '0.931', 'f1': '0.902', 'total_rewards': 275.79843529985914, 'invalid_action_count': 0, 'num_ms1_scans': 135, 'num_ms2_scans': 1730}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 62.711493007118456
# steps	 1000 	total rewards	 132.9077132776896
# steps	 1500 	total rewards	 194.01899344473225
# Finished after 1795 timesteps (2.907191038131714 seconds) with total reward 225.86731412969797
# {'coverage_prop': '0.948', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.129', 'efficiency': '0.148', 'TP': '217', 'FP': '19', 'FN': '13', 'precision': '0.919', 'recall': '0.943', 'f1': '0.931', 'total_rewards': 225.86731412969806, 'invalid_action_count': 0, 'num_ms1_scans': 205, 'num_ms2_scans': 1590}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 72.81907484525247
# steps	 1000 	total rewards	 142.3059591723499
# steps	 1500 	total rewards	 205.47611576028123
# Finished after 1831 timesteps (3.002600908279419 seconds) with total reward 248.37523423569624
# {'coverage_prop': '0.948', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.102', 'efficiency': '0.143', 'TP': '212', 'FP': '26', 'FN': '13', 'precision': '0.891', 'recall': '0.942', 'f1': '0.916', 'total_rewards': 248.37523423569584, 'invalid_action_count': 0, 'num_ms1_scans': 170, 'num_ms2_scans': 1661}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 64.1145210303517
# steps	 1000 	total rewards	 134.43077600725582
# steps	 1500 	total rewards	 206.16386058707064
# Finished after 1830 timesteps (3.0482990741729736 seconds) with total reward 245.92172114175142
# {'coverage_prop': '0.947', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.102', 'efficiency': '0.171', 'TP': '248', 'FP': '36', 'FN': '16', 'precision': '0.873', 'recall': '0.939', 'f1': '0.905', 'total_rewards': 245.92172114175125, 'invalid_action_count': 0, 'num_ms1_scans': 170, 'num_ms2_scans': 1660}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 61.308348223269896
# steps	 1000 	total rewards	 133.77907176597162
# steps	 1500 	total rewards	 196.10599726361846
# Finished after 1789 timesteps (2.5499730110168457 seconds) with total reward 227.69776747558018
# {'coverage_prop': '0.956', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.134', 'efficiency': '0.125', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941', 'total_rewards': 227.69776747558026, 'invalid_action_count': 0, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 63.32244777106617
# steps	 1000 	total rewards	 137.5636151072478
# steps	 1500 	total rewards	 206.11521592134204
# Finished after 1835 timesteps (6.5997772216796875 seconds) with total reward 249.08650551476472
# {'coverage_prop': '0.971', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.099', 'efficiency': '0.237', 'TP': '349', 'FP': '46', 'FN': '12', 'precision': '0.884', 'recall': '0.967', 'f1': '0.923', 'total_rewards': 249.08650551476455, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.02718737521243
# steps	 1000 	total rewards	 150.9958372685967
# steps	 1500 	total rewards	 224.63742034749046
# Finished after 1857 timesteps (5.075355768203735 seconds) with total reward 271.2841249791615
# {'coverage_prop': '0.942', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.083', 'efficiency': '0.274', 'TP': '411', 'FP': '58', 'FN': '29', 'precision': '0.876', 'recall': '0.934', 'f1': '0.904', 'total_rewards': 271.2841249791615, 'invalid_action_count': 0, 'num_ms1_scans': 143, 'num_ms2_scans': 1714}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 67.75539551057909
# steps	 1000 	total rewards	 141.65674427725884
# steps	 1500 	total rewards	 214.11229562847336
# Finished after 1844 timesteps (3.905367851257324 seconds) with total reward 259.7354477840086
# {'coverage_prop': '0.946', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.092', 'efficiency': '0.209', 'TP': '306', 'FP': '46', 'FN': '20', 'precision': '0.869', 'recall': '0.939', 'f1': '0.903', 'total_rewards': 259.73544778400833, 'invalid_action_count': 0, 'num_ms1_scans': 156, 'num_ms2_scans': 1688}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 67.53764256757019
# steps	 1000 	total rewards	 137.92101725539032
# steps	 1500 	total rewards	 208.6026021780404
# Finished after 1822 timesteps (3.1322038173675537 seconds) with total reward 251.67183612969677
# {'coverage_prop': '0.964', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.108', 'efficiency': '0.177', 'TP': '258', 'FP': '33', 'FN': '11', 'precision': '0.887', 'recall': '0.959', 'f1': '0.921', 'total_rewards': 251.67183612969663, 'invalid_action_count': 0, 'num_ms1_scans': 178, 'num_ms2_scans': 1644}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 64.37307011169831
# steps	 1000 	total rewards	 137.37248713477257
# steps	 1500 	total rewards	 210.78288063375334
# Finished after 1827 timesteps (2.7849090099334717 seconds) with total reward 256.77074551204987
# {'coverage_prop': '0.974', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.105', 'efficiency': '0.156', 'TP': '231', 'FP': '27', 'FN': '7', 'precision': '0.895', 'recall': '0.971', 'f1': '0.931', 'total_rewards': 256.7707455120502, 'invalid_action_count': 0, 'num_ms1_scans': 173, 'num_ms2_scans': 1654}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 67.72019915060095
# steps	 1000 	total rewards	 140.7513758174764
# steps	 1500 	total rewards	 211.9108255053065
# Finished after 1854 timesteps (3.255229949951172 seconds) with total reward 259.1020196051574
# {'coverage_prop': '0.908', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.085', 'efficiency': '0.249', 'TP': '365', 'FP': '60', 'FN': '43', 'precision': '0.859', 'recall': '0.895', 'f1': '0.876', 'total_rewards': 259.1020196051573, 'invalid_action_count': 0, 'num_ms1_scans': 146, 'num_ms2_scans': 1708}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 63.84234747672861
# steps	 1000 	total rewards	 129.85330468149587
# steps	 1500 	total rewards	 196.30462254208823
# Finished after 1780 timesteps (2.915179967880249 seconds) with total reward 227.1470007968813
# {'coverage_prop': '0.957', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.141', 'efficiency': '0.144', 'TP': '205', 'FP': '19', 'FN': '10', 'precision': '0.915', 'recall': '0.953', 'f1': '0.934', 'total_rewards': 227.14700079688146, 'invalid_action_count': 0, 'num_ms1_scans': 220, 'num_ms2_scans': 1560}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 64.12685452185225
# steps	 1000 	total rewards	 128.35353142251722
# steps	 1500 	total rewards	 196.2533745964381
# Finished after 1831 timesteps (3.047571897506714 seconds) with total reward 244.56969388786808
# {'coverage_prop': '0.944', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.102', 'efficiency': '0.183', 'TP': '268', 'FP': '36', 'FN': '18', 'precision': '0.882', 'recall': '0.937', 'f1': '0.908', 'total_rewards': 244.5696938878681, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1662}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 63.56450664443056
# steps	 1000 	total rewards	 134.2380705070579
# steps	 1500 	total rewards	 204.82614602554122
# Finished after 1806 timesteps (3.398635149002075 seconds) with total reward 242.96555172143184
# {'coverage_prop': '0.952', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.120', 'efficiency': '0.183', 'TP': '265', 'FP': '30', 'FN': '15', 'precision': '0.898', 'recall': '0.946', 'f1': '0.922', 'total_rewards': 242.9655517214321, 'invalid_action_count': 0, 'num_ms1_scans': 194, 'num_ms2_scans': 1612}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 65.81289411272499
# steps	 1000 	total rewards	 143.07323090171798
# steps	 1500 	total rewards	 215.24887740647273
# Finished after 1831 timesteps (2.8628182411193848 seconds) with total reward 262.7012884159708
# {'coverage_prop': '0.968', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.102', 'efficiency': '0.201', 'TP': '298', 'FP': '36', 'FN': '11', 'precision': '0.892', 'recall': '0.964', 'f1': '0.927', 'total_rewards': 262.70128841597034, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1662}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 66.11695459026464
# steps	 1000 	total rewards	 135.39549370186498
# steps	 1500 	total rewards	 211.54650730504306
# Finished after 1857 timesteps (3.4129998683929443 seconds) with total reward 259.35899305252406
# {'coverage_prop': '0.972', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.083', 'efficiency': '0.225', 'TP': '330', 'FP': '55', 'FN': '11', 'precision': '0.857', 'recall': '0.968', 'f1': '0.909', 'total_rewards': 259.35899305252406, 'invalid_action_count': 0, 'num_ms1_scans': 143, 'num_ms2_scans': 1714}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 52.49294712253989
# steps	 1000 	total rewards	 123.41937662745264
# steps	 1500 	total rewards	 189.3460026836545
# Finished after 1775 timesteps (4.101976156234741 seconds) with total reward 222.69849207277525
# {'coverage_prop': '0.966', 'intensity_prop': '0.823', 'ms1ms2_ratio': '0.145', 'efficiency': '0.126', 'TP': '190', 'FP': '6', 'FN': '7', 'precision': '0.969', 'recall': '0.964', 'f1': '0.967', 'total_rewards': 222.69849207277517, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 61.20920864191446
# steps	 1000 	total rewards	 127.35928134105203
# steps	 1500 	total rewards	 194.38094413912054
# Finished after 1805 timesteps (3.19545316696167 seconds) with total reward 238.07435275619545
# {'coverage_prop': '0.957', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.121', 'efficiency': '0.167', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 238.07435275619525, 'invalid_action_count': 0, 'num_ms1_scans': 195, 'num_ms2_scans': 1610}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 70.62708186841778
# steps	 1000 	total rewards	 142.86459066783544
# steps	 1500 	total rewards	 221.29290249368913
# Finished after 1866 timesteps (7.557582139968872 seconds) with total reward 274.64361352874585
# {'coverage_prop': '0.923', 'intensity_prop': '0.678', 'ms1ms2_ratio': '0.077', 'efficiency': '0.263', 'TP': '380', 'FP': '75', 'FN': '38', 'precision': '0.835', 'recall': '0.909', 'f1': '0.871', 'total_rewards': 274.64361352874556, 'invalid_action_count': 0, 'num_ms1_scans': 134, 'num_ms2_scans': 1732}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 59.03755626066677
# steps	 1000 	total rewards	 125.54668230938034
# steps	 1500 	total rewards	 194.44445290986823
# Finished after 1826 timesteps (2.9393250942230225 seconds) with total reward 237.3230152042293
# {'coverage_prop': '0.957', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.105', 'efficiency': '0.176', 'TP': '267', 'FP': '24', 'FN': '13', 'precision': '0.918', 'recall': '0.954', 'f1': '0.935', 'total_rewards': 237.32301520422976, 'invalid_action_count': 0, 'num_ms1_scans': 174, 'num_ms2_scans': 1652}
#
# method = topN max_peaks = 30 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 58.0980159303038
# steps	 1000 	total rewards	 134.88361163849396
# steps	 1500 	total rewards	 206.6352088550439
# Finished after 1700 timesteps (10.304009914398193 seconds) with total reward 231.4035844575007
# {'coverage_prop': '0.960', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.214', 'efficiency': '0.292', 'TP': '365', 'FP': '44', 'FN': '17', 'precision': '0.892', 'recall': '0.955', 'f1': '0.923', 'total_rewards': 231.40358445750056, 'invalid_action_count': 0, 'num_ms1_scans': 300, 'num_ms2_scans': 1400}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 50.91512482728492
# steps	 1000 	total rewards	 114.44605470188691
# steps	 1500 	total rewards	 174.24367590664266
# Finished after 1529 timesteps (8.775309085845947 seconds) with total reward 176.45761023671412
# {'coverage_prop': '0.962', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.447', 'efficiency': '0.238', 'TP': '237', 'FP': '15', 'FN': '10', 'precision': '0.940', 'recall': '0.960', 'f1': '0.950', 'total_rewards': 176.45761023671406, 'invalid_action_count': 0, 'num_ms1_scans': 472, 'num_ms2_scans': 1057}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 48.37986124941685
# steps	 1000 	total rewards	 125.10691162326256
# steps	 1500 	total rewards	 196.3983027789958
# Finished after 1647 timesteps (8.72416090965271 seconds) with total reward 213.0841157828942
# {'coverage_prop': '0.967', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.273', 'efficiency': '0.294', 'TP': '346', 'FP': '35', 'FN': '13', 'precision': '0.908', 'recall': '0.964', 'f1': '0.935', 'total_rewards': 213.08411578289446, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 62.75241057701375
# steps	 1000 	total rewards	 138.3267774518631
# steps	 1500 	total rewards	 199.3637417058816
# Finished after 1690 timesteps (11.730130910873413 seconds) with total reward 222.35378614638586
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933', 'total_rewards': 222.35378614638563, 'invalid_action_count': 0, 'num_ms1_scans': 311, 'num_ms2_scans': 1379}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 53.158355988432625
# steps	 1000 	total rewards	 132.6833599242256
# steps	 1500 	total rewards	 203.00962799597625
# Finished after 1678 timesteps (12.959644317626953 seconds) with total reward 225.69622255079594
# {'coverage_prop': '0.982', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.237', 'efficiency': '0.316', 'TP': '380', 'FP': '49', 'FN': '8', 'precision': '0.886', 'recall': '0.979', 'f1': '0.930', 'total_rewards': 225.69622255079614, 'invalid_action_count': 0, 'num_ms1_scans': 322, 'num_ms2_scans': 1356}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 35.1301670934532
# steps	 1000 	total rewards	 91.13172260312638
# Finished after 1385 timesteps (10.798155069351196 seconds) with total reward 119.40676470088061
# {'coverage_prop': '0.955', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.799', 'efficiency': '0.248', 'TP': '182', 'FP': '9', 'FN': '9', 'precision': '0.953', 'recall': '0.953', 'f1': '0.953', 'total_rewards': 119.4067647008807, 'invalid_action_count': 0, 'num_ms1_scans': 615, 'num_ms2_scans': 770}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 59.27982289451647
# steps	 1000 	total rewards	 141.78790636731858
# steps	 1500 	total rewards	 201.5985119113608
# Finished after 1720 timesteps (9.513628959655762 seconds) with total reward 228.61879102243836
# {'coverage_prop': '0.935', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.194', 'efficiency': '0.310', 'TP': '395', 'FP': '52', 'FN': '31', 'precision': '0.884', 'recall': '0.927', 'f1': '0.905', 'total_rewards': 228.6187910224385, 'invalid_action_count': 0, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 37.770725196990455
# steps	 1000 	total rewards	 103.64726639206368
# Finished after 1444 timesteps (8.80503511428833 seconds) with total reward 145.8921697454636
# {'coverage_prop': '0.966', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.626', 'efficiency': '0.222', 'TP': '187', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.957', 'total_rewards': 145.89216974546363, 'invalid_action_count': 0, 'num_ms1_scans': 556, 'num_ms2_scans': 888}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 60.32845892994011
# steps	 1000 	total rewards	 131.95662455031805
# steps	 1500 	total rewards	 197.8192224673003
# Finished after 1702 timesteps (12.539329051971436 seconds) with total reward 223.2817312201342
# {'coverage_prop': '0.946', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.212', 'efficiency': '0.286', 'TP': '364', 'FP': '37', 'FN': '23', 'precision': '0.908', 'recall': '0.941', 'f1': '0.924', 'total_rewards': 223.28173122013447, 'invalid_action_count': 0, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 51.4214813998091
# steps	 1000 	total rewards	 128.8803476650376
# steps	 1500 	total rewards	 196.0110756412563
# Finished after 1644 timesteps (8.504544019699097 seconds) with total reward 211.93867612692554
# {'coverage_prop': '0.958', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.276', 'efficiency': '0.286', 'TP': '339', 'FP': '29', 'FN': '16', 'precision': '0.921', 'recall': '0.955', 'f1': '0.938', 'total_rewards': 211.93867612692563, 'invalid_action_count': 0, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 59.100288674790576
# steps	 1000 	total rewards	 137.37670235206264
# steps	 1500 	total rewards	 209.64399646264604
# Finished after 1723 timesteps (9.685178756713867 seconds) with total reward 239.9468082674191
# {'coverage_prop': '0.948', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.192', 'efficiency': '0.290', 'TP': '382', 'FP': '38', 'FN': '23', 'precision': '0.910', 'recall': '0.943', 'f1': '0.926', 'total_rewards': 239.94680826741927, 'invalid_action_count': 0, 'num_ms1_scans': 277, 'num_ms2_scans': 1446}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 44.35940214265456
# steps	 1000 	total rewards	 110.10794688729146
# steps	 1500 	total rewards	 153.86566369408916
# Finished after 1501 timesteps (11.361043930053711 seconds) with total reward 153.86566369408916
# {'coverage_prop': '0.960', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '226', 'FP': '13', 'FN': '10', 'precision': '0.946', 'recall': '0.958', 'f1': '0.952', 'total_rewards': 153.86566369408916, 'invalid_action_count': 0, 'num_ms1_scans': 500, 'num_ms2_scans': 1001}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 49.108414438313055
# steps	 1000 	total rewards	 118.17971866399677
# steps	 1500 	total rewards	 173.7175628638629
# Finished after 1577 timesteps (10.268151044845581 seconds) with total reward 180.15310738587556
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.367', 'efficiency': '0.206', 'TP': '215', 'FP': '23', 'FN': '13', 'precision': '0.903', 'recall': '0.943', 'f1': '0.923', 'total_rewards': 180.1531073858755, 'invalid_action_count': 0, 'num_ms1_scans': 423, 'num_ms2_scans': 1154}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 47.8968341659953
# steps	 1000 	total rewards	 116.44033156263103
# steps	 1500 	total rewards	 181.1803318923745
# Finished after 1621 timesteps (11.848098039627075 seconds) with total reward 194.63507713479586
# {'coverage_prop': '0.963', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '263', 'FP': '26', 'FN': '11', 'precision': '0.910', 'recall': '0.960', 'f1': '0.934', 'total_rewards': 194.63507713479592, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 40.742314583343344
# steps	 1000 	total rewards	 108.77304941077138
# Finished after 1472 timesteps (12.393778800964355 seconds) with total reward 149.94932782780498
# {'coverage_prop': '0.956', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941', 'total_rewards': 149.94932782780504, 'invalid_action_count': 0, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 51.43564436787591
# steps	 1000 	total rewards	 126.4917073405878
# steps	 1500 	total rewards	 185.60522443286987
# Finished after 1626 timesteps (9.864467144012451 seconds) with total reward 201.59805655276983
# {'coverage_prop': '0.963', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.299', 'efficiency': '0.313', 'TP': '365', 'FP': '27', 'FN': '15', 'precision': '0.931', 'recall': '0.961', 'f1': '0.946', 'total_rewards': 201.59805655276938, 'invalid_action_count': 0, 'num_ms1_scans': 374, 'num_ms2_scans': 1252}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 64.57955206319701
# steps	 1000 	total rewards	 143.39025750927652
# steps	 1500 	total rewards	 214.46117055238315
# Finished after 1712 timesteps (10.401843070983887 seconds) with total reward 241.00364830229134
# {'coverage_prop': '0.958', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.202', 'efficiency': '0.335', 'TP': '437', 'FP': '40', 'FN': '21', 'precision': '0.916', 'recall': '0.954', 'f1': '0.935', 'total_rewards': 241.00364830229137, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 56.641319639303276
# steps	 1000 	total rewards	 132.36808642046597
# steps	 1500 	total rewards	 198.11993126279177
# Finished after 1654 timesteps (12.091954946517944 seconds) with total reward 214.4012049357918
# {'coverage_prop': '0.965', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.265', 'efficiency': '0.274', 'TP': '329', 'FP': '30', 'FN': '13', 'precision': '0.916', 'recall': '0.962', 'f1': '0.939', 'total_rewards': 214.4012049357921, 'invalid_action_count': 0, 'num_ms1_scans': 346, 'num_ms2_scans': 1308}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 47.44526495876334
# steps	 1000 	total rewards	 120.24411887528734
# steps	 1500 	total rewards	 183.55691747243526
# Finished after 1584 timesteps (8.954386949539185 seconds) with total reward 190.62207748730253
# {'coverage_prop': '0.967', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940', 'total_rewards': 190.6220774873023, 'invalid_action_count': 0, 'num_ms1_scans': 416, 'num_ms2_scans': 1168}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 48.31416800887003
# steps	 1000 	total rewards	 119.02006090163849
# steps	 1500 	total rewards	 187.82818515513097
# Finished after 1604 timesteps (10.702782154083252 seconds) with total reward 198.33457603650436
# {'coverage_prop': '0.977', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.329', 'efficiency': '0.215', 'TP': '238', 'FP': '21', 'FN': '6', 'precision': '0.919', 'recall': '0.975', 'f1': '0.946', 'total_rewards': 198.33457603650447, 'invalid_action_count': 0, 'num_ms1_scans': 397, 'num_ms2_scans': 1207}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 60.482645635157624
# steps	 1000 	total rewards	 135.02830743852059
# steps	 1500 	total rewards	 201.1789644365163
# Finished after 1704 timesteps (13.244930028915405 seconds) with total reward 228.0527776621726
# {'coverage_prop': '0.923', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.210', 'efficiency': '0.307', 'TP': '400', 'FP': '32', 'FN': '36', 'precision': '0.926', 'recall': '0.917', 'f1': '0.922', 'total_rewards': 228.0527776621721, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 40.59183279821073
# steps	 1000 	total rewards	 103.74522746216871
# Finished after 1444 timesteps (13.292946100234985 seconds) with total reward 142.93694753383602
# {'coverage_prop': '0.957', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.628', 'efficiency': '0.253', 'TP': '200', 'FP': '24', 'FN': '10', 'precision': '0.893', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 142.93694753383593, 'invalid_action_count': 0, 'num_ms1_scans': 557, 'num_ms2_scans': 887}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 48.18873196230159
# steps	 1000 	total rewards	 115.81793426878693
# steps	 1500 	total rewards	 179.9226425063179
# Finished after 1609 timesteps (9.096166133880615 seconds) with total reward 191.9803745892945
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949', 'total_rewards': 191.98037458929448, 'invalid_action_count': 0, 'num_ms1_scans': 392, 'num_ms2_scans': 1217}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 50.93490614364585
# steps	 1000 	total rewards	 118.05611221988669
# steps	 1500 	total rewards	 173.26005859583984
# Finished after 1543 timesteps (10.172384977340698 seconds) with total reward 176.6688830163665
# {'coverage_prop': '0.948', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.422', 'efficiency': '0.271', 'TP': '267', 'FP': '27', 'FN': '16', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925', 'total_rewards': 176.66888301636652, 'invalid_action_count': 0, 'num_ms1_scans': 458, 'num_ms2_scans': 1085}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 53.04725540965746
# steps	 1000 	total rewards	 130.6755703041167
# steps	 1500 	total rewards	 199.52507612852355
# Finished after 1655 timesteps (12.270781993865967 seconds) with total reward 218.3642131544893
# {'coverage_prop': '0.980', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.264', 'efficiency': '0.258', 'TP': '314', 'FP': '24', 'FN': '7', 'precision': '0.929', 'recall': '0.978', 'f1': '0.953', 'total_rewards': 218.36421315448936, 'invalid_action_count': 0, 'num_ms1_scans': 346, 'num_ms2_scans': 1309}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 54.50498641008634
# steps	 1000 	total rewards	 122.34140573530945
# steps	 1500 	total rewards	 195.09730635111202
# Finished after 1649 timesteps (8.590996980667114 seconds) with total reward 211.02157806418083
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944', 'total_rewards': 211.0215780641807, 'invalid_action_count': 0, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 35.36993884287257
# steps	 1000 	total rewards	 102.03300219479618
# Finished after 1434 timesteps (9.310365200042725 seconds) with total reward 138.52505990199327
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.652', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948', 'total_rewards': 138.52505990199327, 'invalid_action_count': 0, 'num_ms1_scans': 566, 'num_ms2_scans': 868}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 45.254971965066275
# steps	 1000 	total rewards	 111.1925052560875
# steps	 1500 	total rewards	 168.81658460565768
# Finished after 1527 timesteps (8.87192988395691 seconds) with total reward 172.06095045861963
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948', 'total_rewards': 172.0609504586197, 'invalid_action_count': 0, 'num_ms1_scans': 473, 'num_ms2_scans': 1054}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 64.12880365977713
# steps	 1000 	total rewards	 137.67170999567605
# steps	 1500 	total rewards	 214.10351961124343
# Finished after 1729 timesteps (11.897470951080322 seconds) with total reward 245.15698472664872
# {'coverage_prop': '0.933', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902', 'total_rewards': 245.1569847266487, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 48.57463721349342
# steps	 1000 	total rewards	 115.21349150356069
# steps	 1500 	total rewards	 176.99619135078333
# Finished after 1609 timesteps (11.933228015899658 seconds) with total reward 188.6073420486521
# {'coverage_prop': '0.967', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.322', 'efficiency': '0.242', 'TP': '274', 'FP': '20', 'FN': '10', 'precision': '0.932', 'recall': '0.965', 'f1': '0.948', 'total_rewards': 188.6073420486518, 'invalid_action_count': 0, 'num_ms1_scans': 392, 'num_ms2_scans': 1217}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa5d3f3f7c0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa5f3844cd0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa5f3861e70>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.795', 'efficiency': '0.539', 'TP': '360', 'FP': '56', 'FN': '10', 'precision': '0.865', 'recall': '0.973', 'f1': '0.916'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.505', 'efficiency': '0.505', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.858', 'efficiency': '0.518', 'TP': '326', 'FP': '56', 'FN': '12', 'precision': '0.853', 'recall': '0.964', 'f1': '0.906'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '368', 'FP': '65', 'FN': '4', 'precision': '0.850', 'recall': '0.989', 'f1': '0.914'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.721', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '173', 'FP': '18', 'FN': '9', 'precision': '0.906', 'recall': '0.951', 'f1': '0.928'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.668', 'efficiency': '0.536', 'TP': '404', 'FP': '55', 'FN': '19', 'precision': '0.880', 'recall': '0.955', 'f1': '0.916'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.720', 'ms1ms2_ratio': '2.059', 'efficiency': '0.501', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.693', 'efficiency': '0.510', 'TP': '379', 'FP': '48', 'FN': '16', 'precision': '0.888', 'recall': '0.959', 'f1': '0.922'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.665', 'ms1ms2_ratio': '1.624', 'efficiency': '0.505', 'TP': '194', 'FP': '44', 'FN': '13', 'precision': '0.815', 'recall': '0.937', 'f1': '0.872'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.687', 'ms1ms2_ratio': '1.267', 'efficiency': '0.512', 'TP': '235', 'FP': '55', 'FN': '10', 'precision': '0.810', 'recall': '0.959', 'f1': '0.879'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.702', 'ms1ms2_ratio': '1.958', 'efficiency': '0.482', 'TP': '173', 'FP': '23', 'FN': '10', 'precision': '0.883', 'recall': '0.945', 'f1': '0.913'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.858', 'efficiency': '0.540', 'TP': '355', 'FP': '43', 'FN': '9', 'precision': '0.892', 'recall': '0.975', 'f1': '0.932'}
#
# Episode 16 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.598', 'efficiency': '0.533', 'TP': '432', 'FP': '54', 'FN': '12', 'precision': '0.889', 'recall': '0.973', 'f1': '0.929'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '310', 'FP': '50', 'FN': '12', 'precision': '0.861', 'recall': '0.963', 'f1': '0.909'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.178', 'efficiency': '0.523', 'TP': '275', 'FP': '37', 'FN': '10', 'precision': '0.881', 'recall': '0.965', 'f1': '0.921'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.971', 'efficiency': '0.499', 'TP': '298', 'FP': '41', 'FN': '6', 'precision': '0.879', 'recall': '0.980', 'f1': '0.927'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.851', 'efficiency': '0.528', 'TP': '339', 'FP': '52', 'FN': '5', 'precision': '0.867', 'recall': '0.985', 'f1': '0.922'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.370', 'efficiency': '0.508', 'TP': '241', 'FP': '31', 'FN': '9', 'precision': '0.886', 'recall': '0.964', 'f1': '0.923'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.599', 'efficiency': '0.526', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     248.187066                   0.0          0.930           0.683
# 1  random     223.008714                   0.0          0.947           0.775
# 2  random     236.529577                   0.0          0.937           0.698
# 3  random     237.492355                   0.0          0.934           0.715
# 4  random     249.038520                   0.0          0.959           0.707
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.135       0.251      0.821   0.915  0.866
# 1          0.212       0.177      0.940   0.943  0.941
# 2          0.158       0.243      0.837   0.925  0.879
# 3          0.144       0.272      0.884   0.926  0.904
# 4          0.142       0.269      0.821   0.950  0.881

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'DQN'

# %%
df = pd.read_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'DQN']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     248.187066                   0.0          0.930           0.683
# 1  random     223.008714                   0.0          0.947           0.775
# 2  random     236.529577                   0.0          0.937           0.698
# 3  random     237.492355                   0.0          0.934           0.715
# 4  random     249.038520                   0.0          0.959           0.707
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.135       0.251      0.821   0.915  0.866
# 1          0.212       0.177      0.940   0.943  0.941
# 2          0.158       0.243      0.837   0.925  0.879
# 3          0.144       0.272      0.884   0.926  0.904
# 4          0.142       0.269      0.821   0.950  0.881

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
