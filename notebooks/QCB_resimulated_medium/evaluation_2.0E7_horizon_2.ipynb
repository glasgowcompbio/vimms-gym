# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-07 01:16:59.079 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7facb1ab1280>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7face3ae3610>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7facd29e88b0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7facb1ab1280>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7face3ae3610>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7facd29e88b0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7facb1ab1280>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7face3ae3610>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7facd29e88b0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 2
out_dir = 'evaluation_2.0E7_horizon_%d'

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join(model_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, METHOD_DQN, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -388.13596297108165
# steps	 1000 	total rewards	 -677.6948280114214
# steps	 1500 	total rewards	 -878.7738107777388
# Finished after 1989 timesteps (4.591130256652832 seconds) with total reward -1087.7864488075543
# {'coverage_prop': '0.721', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.006', 'efficiency': '0.155', 'TP': '95', 'FP': '212', 'FN': '119', 'precision': '0.309', 'recall': '0.444', 'f1': '0.365', 'total_rewards': -1087.7864488075538, 'invalid_action_count': 1231, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -402.407174049247
# steps	 1000 	total rewards	 -723.4231588851642
# steps	 1500 	total rewards	 -1054.587722532107
# Finished after 1991 timesteps (2.789026975631714 seconds) with total reward -1432.9968784753376
# {'coverage_prop': '0.611', 'intensity_prop': '0.172', 'ms1ms2_ratio': '0.005', 'efficiency': '0.081', 'TP': '41', 'FP': '119', 'FN': '102', 'precision': '0.256', 'recall': '0.287', 'f1': '0.271', 'total_rewards': -1432.9968784753376, 'invalid_action_count': 1511, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -416.4471306573788
# steps	 1000 	total rewards	 -723.852547798095
# steps	 1500 	total rewards	 -1065.2636728188793
# Finished after 1988 timesteps (4.051011085510254 seconds) with total reward -1215.8969292961465
# {'coverage_prop': '0.655', 'intensity_prop': '0.187', 'ms1ms2_ratio': '0.006', 'efficiency': '0.131', 'TP': '61', 'FP': '197', 'FN': '136', 'precision': '0.236', 'recall': '0.310', 'f1': '0.268', 'total_rewards': -1215.8969292961472, 'invalid_action_count': 1334, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -388.6012980722678
# steps	 1000 	total rewards	 -799.0411971900105
# steps	 1500 	total rewards	 -907.635944115733
# Finished after 1992 timesteps (4.663441896438599 seconds) with total reward -1360.9217799888456
# {'coverage_prop': '0.588', 'intensity_prop': '0.170', 'ms1ms2_ratio': '0.004', 'efficiency': '0.134', 'TP': '70', 'FP': '196', 'FN': '186', 'precision': '0.263', 'recall': '0.273', 'f1': '0.268', 'total_rewards': -1360.921779988845, 'invalid_action_count': 1471, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -383.9474358013779
# steps	 1000 	total rewards	 -684.5761465303743
# steps	 1500 	total rewards	 -837.2208391174973
# Finished after 1991 timesteps (3.99257493019104 seconds) with total reward -1123.1449893324814
# {'coverage_prop': '0.693', 'intensity_prop': '0.208', 'ms1ms2_ratio': '0.005', 'efficiency': '0.153', 'TP': '89', 'FP': '214', 'FN': '134', 'precision': '0.294', 'recall': '0.399', 'f1': '0.338', 'total_rewards': -1123.1449893324811, 'invalid_action_count': 1262, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -366.458529667116
# steps	 1000 	total rewards	 -766.8397290298367
# steps	 1500 	total rewards	 -1010.1305429725873
# Finished after 1987 timesteps (2.3734042644500732 seconds) with total reward -1398.0685749108088
# {'coverage_prop': '0.725', 'intensity_prop': '0.221', 'ms1ms2_ratio': '0.007', 'efficiency': '0.073', 'TP': '44', 'FP': '101', 'FN': '55', 'precision': '0.303', 'recall': '0.444', 'f1': '0.361', 'total_rewards': -1398.068574910809, 'invalid_action_count': 1472, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -397.75605060076145
# steps	 1000 	total rewards	 -605.3757869657886
# steps	 1500 	total rewards	 -821.615222703251
# Finished after 1990 timesteps (4.336359739303589 seconds) with total reward -988.9550170001975
# {'coverage_prop': '0.755', 'intensity_prop': '0.214', 'ms1ms2_ratio': '0.005', 'efficiency': '0.182', 'TP': '96', 'FP': '265', 'FN': '117', 'precision': '0.266', 'recall': '0.451', 'f1': '0.334', 'total_rewards': -988.9550170001982, 'invalid_action_count': 1156, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -412.10107942429306
# steps	 1000 	total rewards	 -782.5128553961983
# steps	 1500 	total rewards	 -1040.997384293029
# Finished after 1989 timesteps (2.9552040100097656 seconds) with total reward -1344.7039922406002
# {'coverage_prop': '0.725', 'intensity_prop': '0.185', 'ms1ms2_ratio': '0.006', 'efficiency': '0.075', 'TP': '37', 'FP': '111', 'FN': '56', 'precision': '0.250', 'recall': '0.398', 'f1': '0.307', 'total_rewards': -1344.7039922406, 'invalid_action_count': 1419, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -362.3419957598363
# steps	 1000 	total rewards	 -601.6927524401888
# steps	 1500 	total rewards	 -835.0812031106075
# Finished after 1987 timesteps (4.231990814208984 seconds) with total reward -987.4336985085808
# {'coverage_prop': '0.769', 'intensity_prop': '0.240', 'ms1ms2_ratio': '0.007', 'efficiency': '0.165', 'TP': '94', 'FP': '232', 'FN': '98', 'precision': '0.288', 'recall': '0.490', 'f1': '0.363', 'total_rewards': -987.4336985085808, 'invalid_action_count': 1149, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -377.4867145950992
# steps	 1000 	total rewards	 -858.4446752685867
# steps	 1500 	total rewards	 -1286.9204065825606
# Finished after 1991 timesteps (3.576047897338867 seconds) with total reward -1565.382959550972
# {'coverage_prop': '0.438', 'intensity_prop': '0.086', 'ms1ms2_ratio': '0.005', 'efficiency': '0.085', 'TP': '28', 'FP': '140', 'FN': '216', 'precision': '0.167', 'recall': '0.115', 'f1': '0.136', 'total_rewards': -1565.3829595509728, 'invalid_action_count': 1629, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -344.2662130881939
# steps	 1000 	total rewards	 -649.8200416470539
# steps	 1500 	total rewards	 -867.2382390567714
# Finished after 1987 timesteps (4.751604795455933 seconds) with total reward -983.6719279542548
# {'coverage_prop': '0.772', 'intensity_prop': '0.258', 'ms1ms2_ratio': '0.007', 'efficiency': '0.173', 'TP': '106', 'FP': '236', 'FN': '101', 'precision': '0.310', 'recall': '0.512', 'f1': '0.386', 'total_rewards': -983.6719279542548, 'invalid_action_count': 1148, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -350.3761191088049
# steps	 1000 	total rewards	 -668.0901103082871
# steps	 1500 	total rewards	 -940.6243263878762
# Finished after 1987 timesteps (3.623832941055298 seconds) with total reward -1187.2753315396187
# {'coverage_prop': '0.751', 'intensity_prop': '0.268', 'ms1ms2_ratio': '0.007', 'efficiency': '0.095', 'TP': '65', 'FP': '122', 'FN': '62', 'precision': '0.348', 'recall': '0.512', 'f1': '0.414', 'total_rewards': -1187.2753315396178, 'invalid_action_count': 1282, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -402.43295117473605
# steps	 1000 	total rewards	 -787.088523103489
# steps	 1500 	total rewards	 -1041.3335339695768
# Finished after 1992 timesteps (3.3328299522399902 seconds) with total reward -1340.5682015787988
# {'coverage_prop': '0.733', 'intensity_prop': '0.177', 'ms1ms2_ratio': '0.004', 'efficiency': '0.093', 'TP': '41', 'FP': '143', 'FN': '67', 'precision': '0.223', 'recall': '0.380', 'f1': '0.281', 'total_rewards': -1340.5682015788007, 'invalid_action_count': 1431, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -392.51710136812295
# steps	 1000 	total rewards	 -648.1141213617267
# steps	 1500 	total rewards	 -871.9130567300997
# Finished after 1987 timesteps (4.370791912078857 seconds) with total reward -1093.9006683023233
# {'coverage_prop': '0.787', 'intensity_prop': '0.264', 'ms1ms2_ratio': '0.007', 'efficiency': '0.120', 'TP': '76', 'FP': '160', 'FN': '64', 'precision': '0.322', 'recall': '0.543', 'f1': '0.404', 'total_rewards': -1093.900668302324, 'invalid_action_count': 1207, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -415.3020714863852
# steps	 1000 	total rewards	 -789.391518388783
# steps	 1500 	total rewards	 -1023.0357916622595
# Finished after 1988 timesteps (2.8114562034606934 seconds) with total reward -1323.385060245723
# {'coverage_prop': '0.777', 'intensity_prop': '0.227', 'ms1ms2_ratio': '0.006', 'efficiency': '0.081', 'TP': '43', 'FP': '117', 'FN': '46', 'precision': '0.269', 'recall': '0.483', 'f1': '0.345', 'total_rewards': -1323.3850602457235, 'invalid_action_count': 1407, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -396.1303841956568
# steps	 1000 	total rewards	 -671.6602672339524
# steps	 1500 	total rewards	 -784.1614966513829
# Finished after 1987 timesteps (4.581807851791382 seconds) with total reward -969.0510102372143
# {'coverage_prop': '0.767', 'intensity_prop': '0.269', 'ms1ms2_ratio': '0.007', 'efficiency': '0.158', 'TP': '111', 'FP': '201', 'FN': '95', 'precision': '0.356', 'recall': '0.539', 'f1': '0.429', 'total_rewards': -969.0510102372156, 'invalid_action_count': 1118, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -309.2898906424406
# steps	 1000 	total rewards	 -517.202715730661
# steps	 1500 	total rewards	 -869.3315277947297
# Finished after 1986 timesteps (6.070652961730957 seconds) with total reward -959.4725816479877
# {'coverage_prop': '0.767', 'intensity_prop': '0.259', 'ms1ms2_ratio': '0.007', 'efficiency': '0.194', 'TP': '134', 'FP': '248', 'FN': '116', 'precision': '0.351', 'recall': '0.536', 'f1': '0.424', 'total_rewards': -959.4725816479878, 'invalid_action_count': 1130, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -381.043903432015
# steps	 1000 	total rewards	 -775.9966559428548
# steps	 1500 	total rewards	 -975.63759470355
# Finished after 1987 timesteps (4.263567209243774 seconds) with total reward -1146.8209027311875
# {'coverage_prop': '0.734', 'intensity_prop': '0.223', 'ms1ms2_ratio': '0.007', 'efficiency': '0.138', 'TP': '82', 'FP': '191', 'FN': '99', 'precision': '0.300', 'recall': '0.453', 'f1': '0.361', 'total_rewards': -1146.8209027311889, 'invalid_action_count': 1276, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -411.42344142486024
# steps	 1000 	total rewards	 -782.6096083202106
# steps	 1500 	total rewards	 -1120.5218344129353
# Finished after 1990 timesteps (3.6747169494628906 seconds) with total reward -1428.2950385101835
# {'coverage_prop': '0.603', 'intensity_prop': '0.129', 'ms1ms2_ratio': '0.005', 'efficiency': '0.092', 'TP': '32', 'FP': '150', 'FN': '120', 'precision': '0.176', 'recall': '0.211', 'f1': '0.192', 'total_rewards': -1428.2950385101826, 'invalid_action_count': 1511, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -412.377623207047
# steps	 1000 	total rewards	 -775.555897250578
# steps	 1500 	total rewards	 -1030.8793547769542
# Finished after 1994 timesteps (3.4073069095611572 seconds) with total reward -1358.565048278645
# {'coverage_prop': '0.702', 'intensity_prop': '0.187', 'ms1ms2_ratio': '0.003', 'efficiency': '0.094', 'TP': '44', 'FP': '142', 'FN': '79', 'precision': '0.237', 'recall': '0.358', 'f1': '0.285', 'total_rewards': -1358.5650482786461, 'invalid_action_count': 1453, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -437.4549327018332
# steps	 1000 	total rewards	 -801.241964764331
# steps	 1500 	total rewards	 -897.9441952407351
# Finished after 1993 timesteps (4.585360050201416 seconds) with total reward -1157.0175979017233
# {'coverage_prop': '0.669', 'intensity_prop': '0.192', 'ms1ms2_ratio': '0.004', 'efficiency': '0.158', 'TP': '83', 'FP': '230', 'FN': '155', 'precision': '0.265', 'recall': '0.349', 'f1': '0.301', 'total_rewards': -1157.0175979017226, 'invalid_action_count': 1296, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -455.355122402314
# steps	 1000 	total rewards	 -865.5809677027257
# steps	 1500 	total rewards	 -1138.0079534570116
# Finished after 1992 timesteps (3.0614171028137207 seconds) with total reward -1421.7974367912302
# {'coverage_prop': '0.632', 'intensity_prop': '0.178', 'ms1ms2_ratio': '0.004', 'efficiency': '0.075', 'TP': '35', 'FP': '113', 'FN': '86', 'precision': '0.236', 'recall': '0.289', 'f1': '0.260', 'total_rewards': -1421.7974367912313, 'invalid_action_count': 1496, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -342.64016944840967
# steps	 1000 	total rewards	 -697.86473548264
# steps	 1500 	total rewards	 -1036.8739105565892
# Finished after 1990 timesteps (3.8658411502838135 seconds) with total reward -1347.3236502082764
# {'coverage_prop': '0.634', 'intensity_prop': '0.171', 'ms1ms2_ratio': '0.005', 'efficiency': '0.103', 'TP': '50', 'FP': '154', 'FN': '118', 'precision': '0.245', 'recall': '0.298', 'f1': '0.269', 'total_rewards': -1347.3236502082743, 'invalid_action_count': 1443, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -362.86230360089127
# steps	 1000 	total rewards	 -669.8863563418522
# steps	 1500 	total rewards	 -917.7790576159308
# Finished after 1991 timesteps (3.5876500606536865 seconds) with total reward -1226.7182385215851
# {'coverage_prop': '0.700', 'intensity_prop': '0.228', 'ms1ms2_ratio': '0.005', 'efficiency': '0.109', 'TP': '68', 'FP': '149', 'FN': '93', 'precision': '0.313', 'recall': '0.422', 'f1': '0.360', 'total_rewards': -1226.718238521585, 'invalid_action_count': 1337, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -387.84336105682075
# steps	 1000 	total rewards	 -638.4159027095877
# steps	 1500 	total rewards	 -858.9223232334776
# Finished after 1989 timesteps (4.255192041397095 seconds) with total reward -1122.8532926959892
# {'coverage_prop': '0.748', 'intensity_prop': '0.248', 'ms1ms2_ratio': '0.006', 'efficiency': '0.130', 'TP': '84', 'FP': '174', 'FN': '87', 'precision': '0.326', 'recall': '0.491', 'f1': '0.392', 'total_rewards': -1122.8532926959897, 'invalid_action_count': 1252, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -333.6772269588298
# steps	 1000 	total rewards	 -569.8144635749935
# steps	 1500 	total rewards	 -750.0575403618088
# Finished after 1985 timesteps (4.588229179382324 seconds) with total reward -938.6657853402462
# {'coverage_prop': '0.859', 'intensity_prop': '0.300', 'ms1ms2_ratio': '0.008', 'efficiency': '0.173', 'TP': '113', 'FP': '227', 'FN': '56', 'precision': '0.332', 'recall': '0.669', 'f1': '0.444', 'total_rewards': -938.6657853402467, 'invalid_action_count': 1104, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -434.23500799736564
# steps	 1000 	total rewards	 -656.0494447002745
# steps	 1500 	total rewards	 -968.3034246527673
# Finished after 1983 timesteps (3.37273907661438 seconds) with total reward -1269.6450209970103
# {'coverage_prop': '0.759', 'intensity_prop': '0.249', 'ms1ms2_ratio': '0.009', 'efficiency': '0.078', 'TP': '44', 'FP': '110', 'FN': '49', 'precision': '0.286', 'recall': '0.473', 'f1': '0.356', 'total_rewards': -1269.6450209970108, 'invalid_action_count': 1355, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -446.3683980333909
# steps	 1000 	total rewards	 -754.8268047644859
# steps	 1500 	total rewards	 -1038.583338957231
# Finished after 1991 timesteps (3.340592861175537 seconds) with total reward -1322.74295463652
# {'coverage_prop': '0.673', 'intensity_prop': '0.209', 'ms1ms2_ratio': '0.005', 'efficiency': '0.095', 'TP': '60', 'FP': '129', 'FN': '92', 'precision': '0.317', 'recall': '0.395', 'f1': '0.352', 'total_rewards': -1322.7429546365195, 'invalid_action_count': 1421, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -296.0649714589635
# steps	 1000 	total rewards	 -468.3676531081898
# steps	 1500 	total rewards	 -751.9473733001798
# Finished after 1989 timesteps (5.880819082260132 seconds) with total reward -1049.3812096248716
# {'coverage_prop': '0.694', 'intensity_prop': '0.207', 'ms1ms2_ratio': '0.006', 'efficiency': '0.173', 'TP': '92', 'FP': '250', 'FN': '151', 'precision': '0.269', 'recall': '0.379', 'f1': '0.315', 'total_rewards': -1049.3812096248714, 'invalid_action_count': 1203, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -360.72394114215365
# steps	 1000 	total rewards	 -602.9066992783532
# steps	 1500 	total rewards	 -858.848511918332
# Finished after 1990 timesteps (4.48683500289917 seconds) with total reward -1161.505429012675
# {'coverage_prop': '0.770', 'intensity_prop': '0.295', 'ms1ms2_ratio': '0.005', 'efficiency': '0.118', 'TP': '92', 'FP': '142', 'FN': '70', 'precision': '0.393', 'recall': '0.568', 'f1': '0.465', 'total_rewards': -1161.505429012675, 'invalid_action_count': 1278, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 4.50GB > 0.35GB
# steps	 500 	total rewards	 91.26992002263293
# steps	 1000 	total rewards	 215.6860907670624
# steps	 1500 	total rewards	 312.6772959790012
# Finished after 1645 timesteps (7.821781873703003 seconds) with total reward 333.1858094811774
# {'coverage_prop': '0.974', 'intensity_prop': '0.617', 'ms1ms2_ratio': '0.275', 'efficiency': '0.322', 'TP': '295', 'FP': '120', 'FN': '11', 'precision': '0.711', 'recall': '0.964', 'f1': '0.818', 'total_rewards': 333.1858094811783, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 86.93478419757048
# steps	 1000 	total rewards	 178.02197960899727
# steps	 1500 	total rewards	 263.3249141597265
# Finished after 1642 timesteps (5.452690839767456 seconds) with total reward 283.3069517972365
# {'coverage_prop': '0.966', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.279', 'efficiency': '0.197', 'TP': '195', 'FP': '58', 'FN': '9', 'precision': '0.771', 'recall': '0.956', 'f1': '0.853', 'total_rewards': 283.30695179723625, 'invalid_action_count': 0, 'num_ms1_scans': 358, 'num_ms2_scans': 1284}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 88.27742626151472
# steps	 1000 	total rewards	 203.8061902432807
# steps	 1500 	total rewards	 302.0479668221193
# Finished after 1642 timesteps (8.156149864196777 seconds) with total reward 321.00203608452375
# {'coverage_prop': '0.982', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.279', 'efficiency': '0.301', 'TP': '252', 'FP': '135', 'FN': '7', 'precision': '0.651', 'recall': '0.973', 'f1': '0.780', 'total_rewards': 321.00203608452495, 'invalid_action_count': 0, 'num_ms1_scans': 358, 'num_ms2_scans': 1284}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 100.31985357763402
# steps	 1000 	total rewards	 210.4935936705293
# steps	 1500 	total rewards	 301.98926696088773
# Finished after 1661 timesteps (6.896785020828247 seconds) with total reward 330.3723103812879
# {'coverage_prop': '0.967', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.256', 'efficiency': '0.331', 'TP': '299', 'FP': '138', 'FN': '15', 'precision': '0.684', 'recall': '0.952', 'f1': '0.796', 'total_rewards': 330.37231038128897, 'invalid_action_count': 1, 'num_ms1_scans': 339, 'num_ms2_scans': 1322}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 94.93226492847732
# steps	 1000 	total rewards	 203.79918926823993
# steps	 1500 	total rewards	 302.4709482335028
# Finished after 1649 timesteps (8.648874998092651 seconds) with total reward 324.0844725261587
# {'coverage_prop': '0.968', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.270', 'efficiency': '0.326', 'TP': '276', 'FP': '147', 'FN': '14', 'precision': '0.652', 'recall': '0.952', 'f1': '0.774', 'total_rewards': 324.0844725261601, 'invalid_action_count': 0, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 72.91231460356232
# steps	 1000 	total rewards	 156.95579557095238
# steps	 1500 	total rewards	 230.87730850822834
# Finished after 1609 timesteps (5.471290111541748 seconds) with total reward 244.3433446314313
# {'coverage_prop': '0.990', 'intensity_prop': '0.680', 'ms1ms2_ratio': '0.322', 'efficiency': '0.163', 'TP': '148', 'FP': '50', 'FN': '2', 'precision': '0.747', 'recall': '0.987', 'f1': '0.851', 'total_rewards': 244.34334463142972, 'invalid_action_count': 0, 'num_ms1_scans': 392, 'num_ms2_scans': 1217}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 93.14807494295243
# steps	 1000 	total rewards	 207.109571752938
# steps	 1500 	total rewards	 302.28085222853963
# Finished after 1673 timesteps (9.211490631103516 seconds) with total reward 329.6587597431543
# {'coverage_prop': '0.946', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.243', 'efficiency': '0.336', 'TP': '303', 'FP': '149', 'FN': '26', 'precision': '0.670', 'recall': '0.921', 'f1': '0.776', 'total_rewards': 329.65875974315486, 'invalid_action_count': 9, 'num_ms1_scans': 327, 'num_ms2_scans': 1346}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 65.52023609448682
# steps	 1000 	total rewards	 168.41200504679506
# steps	 1500 	total rewards	 239.70443376119812
# Finished after 1623 timesteps (5.658398151397705 seconds) with total reward 253.06896071238174
# {'coverage_prop': '0.980', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.303', 'efficiency': '0.161', 'TP': '159', 'FP': '41', 'FN': '4', 'precision': '0.795', 'recall': '0.975', 'f1': '0.876', 'total_rewards': 253.06896071238054, 'invalid_action_count': 0, 'num_ms1_scans': 377, 'num_ms2_scans': 1246}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 98.45104265286109
# steps	 1000 	total rewards	 205.88754910489473
# steps	 1500 	total rewards	 307.4266680319572
# Finished after 1665 timesteps (8.534884691238403 seconds) with total reward 332.79422689293244
# {'coverage_prop': '0.976', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.252', 'efficiency': '0.311', 'TP': '272', 'FP': '142', 'FN': '10', 'precision': '0.657', 'recall': '0.965', 'f1': '0.782', 'total_rewards': 332.7942268929336, 'invalid_action_count': 0, 'num_ms1_scans': 335, 'num_ms2_scans': 1330}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 86.03058637306769
# steps	 1000 	total rewards	 187.98440218941712
# steps	 1500 	total rewards	 286.59569199816775
# Finished after 1641 timesteps (6.773948907852173 seconds) with total reward 302.55043283558666
# {'coverage_prop': '0.966', 'intensity_prop': '0.599', 'ms1ms2_ratio': '0.280', 'efficiency': '0.289', 'TP': '249', 'FP': '122', 'FN': '13', 'precision': '0.671', 'recall': '0.950', 'f1': '0.787', 'total_rewards': 302.5504328355867, 'invalid_action_count': 1, 'num_ms1_scans': 359, 'num_ms2_scans': 1282}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.08399170061168
# steps	 1000 	total rewards	 197.57437633346643
# steps	 1500 	total rewards	 309.86662951902167
# Finished after 1651 timesteps (9.70715594291687 seconds) with total reward 330.5293083867414
# {'coverage_prop': '0.955', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.268', 'efficiency': '0.325', 'TP': '301', 'FP': '122', 'FN': '20', 'precision': '0.712', 'recall': '0.938', 'f1': '0.809', 'total_rewards': 330.52930838674246, 'invalid_action_count': 5, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 82.48928039043702
# steps	 1000 	total rewards	 165.99185292957804
# steps	 1500 	total rewards	 230.34052663501546
# Finished after 1632 timesteps (5.549946069717407 seconds) with total reward 248.31398230699455
# {'coverage_prop': '0.980', 'intensity_prop': '0.648', 'ms1ms2_ratio': '0.291', 'efficiency': '0.193', 'TP': '176', 'FP': '68', 'FN': '5', 'precision': '0.721', 'recall': '0.972', 'f1': '0.828', 'total_rewards': 248.31398230699347, 'invalid_action_count': 0, 'num_ms1_scans': 368, 'num_ms2_scans': 1264}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 89.26225277049093
# steps	 1000 	total rewards	 176.20770287831584
# steps	 1500 	total rewards	 247.90844848973535
# Finished after 1626 timesteps (5.887192249298096 seconds) with total reward 264.4809889835964
# {'coverage_prop': '0.964', 'intensity_prop': '0.638', 'ms1ms2_ratio': '0.299', 'efficiency': '0.193', 'TP': '177', 'FP': '65', 'FN': '9', 'precision': '0.731', 'recall': '0.952', 'f1': '0.827', 'total_rewards': 264.4809889835959, 'invalid_action_count': 0, 'num_ms1_scans': 374, 'num_ms2_scans': 1252}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 79.05251932489996
# steps	 1000 	total rewards	 172.07699851797275
# steps	 1500 	total rewards	 256.31928815135666
# Finished after 1615 timesteps (8.078224897384644 seconds) with total reward 267.40002878431534
# {'coverage_prop': '0.973', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.313', 'efficiency': '0.237', 'TP': '195', 'FP': '97', 'FN': '8', 'precision': '0.668', 'recall': '0.961', 'f1': '0.788', 'total_rewards': 267.4000287843149, 'invalid_action_count': 0, 'num_ms1_scans': 385, 'num_ms2_scans': 1230}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 75.989558432569
# steps	 1000 	total rewards	 166.1540515900988
# steps	 1500 	total rewards	 239.42539383769991
# Finished after 1605 timesteps (5.422061920166016 seconds) with total reward 252.09516831506693
# {'coverage_prop': '0.976', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.328', 'efficiency': '0.166', 'TP': '152', 'FP': '49', 'FN': '5', 'precision': '0.756', 'recall': '0.968', 'f1': '0.849', 'total_rewards': 252.09516831506562, 'invalid_action_count': 0, 'num_ms1_scans': 396, 'num_ms2_scans': 1209}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 82.07150016255912
# steps	 1000 	total rewards	 192.0349156437905
# steps	 1500 	total rewards	 287.3734017714911
# Finished after 1655 timesteps (6.823783874511719 seconds) with total reward 312.5074637246818
# {'coverage_prop': '0.973', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.263', 'efficiency': '0.302', 'TP': '265', 'FP': '131', 'FN': '11', 'precision': '0.669', 'recall': '0.960', 'f1': '0.789', 'total_rewards': 312.5074637246821, 'invalid_action_count': 1, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 103.42745792474125
# steps	 1000 	total rewards	 227.58958780524608
# steps	 1500 	total rewards	 330.94891768485144
# Finished after 1668 timesteps (10.6021888256073 seconds) with total reward 357.58370705792436
# {'coverage_prop': '0.966', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.249', 'efficiency': '0.360', 'TP': '337', 'FP': '144', 'FN': '17', 'precision': '0.701', 'recall': '0.952', 'f1': '0.807', 'total_rewards': 357.5837070579268, 'invalid_action_count': 1, 'num_ms1_scans': 332, 'num_ms2_scans': 1336}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.27316077988209
# steps	 1000 	total rewards	 208.74379442799892
# steps	 1500 	total rewards	 287.6832132347233
# Finished after 1658 timesteps (6.888100862503052 seconds) with total reward 308.6758850380037
# {'coverage_prop': '0.970', 'intensity_prop': '0.612', 'ms1ms2_ratio': '0.261', 'efficiency': '0.275', 'TP': '250', 'FP': '111', 'FN': '11', 'precision': '0.693', 'recall': '0.958', 'f1': '0.804', 'total_rewards': 308.6758850380036, 'invalid_action_count': 1, 'num_ms1_scans': 343, 'num_ms2_scans': 1315}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 86.65598879763024
# steps	 1000 	total rewards	 185.04230983219566
# steps	 1500 	total rewards	 267.7507409569123
# Finished after 1651 timesteps (6.5357160568237305 seconds) with total reward 291.25331370729975
# {'coverage_prop': '0.987', 'intensity_prop': '0.636', 'ms1ms2_ratio': '0.269', 'efficiency': '0.229', 'TP': '210', 'FP': '88', 'FN': '4', 'precision': '0.705', 'recall': '0.981', 'f1': '0.820', 'total_rewards': 291.25331370729987, 'invalid_action_count': 0, 'num_ms1_scans': 350, 'num_ms2_scans': 1301}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 82.27108496224504
# steps	 1000 	total rewards	 180.31062290368803
# steps	 1500 	total rewards	 264.03660738896497
# Finished after 1633 timesteps (9.49687671661377 seconds) with total reward 278.6674847671294
# {'coverage_prop': '0.989', 'intensity_prop': '0.636', 'ms1ms2_ratio': '0.290', 'efficiency': '0.207', 'TP': '184', 'FP': '78', 'FN': '3', 'precision': '0.702', 'recall': '0.984', 'f1': '0.820', 'total_rewards': 278.66748476712905, 'invalid_action_count': 1, 'num_ms1_scans': 367, 'num_ms2_scans': 1266}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 98.72073086053697
# steps	 1000 	total rewards	 214.37549313015512
# steps	 1500 	total rewards	 307.57949322393506
# Finished after 1650 timesteps (7.972394943237305 seconds) with total reward 335.6663994868665
# {'coverage_prop': '0.940', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.269', 'efficiency': '0.338', 'TP': '291', 'FP': '149', 'FN': '28', 'precision': '0.661', 'recall': '0.912', 'f1': '0.767', 'total_rewards': 335.6663994868671, 'invalid_action_count': 2, 'num_ms1_scans': 350, 'num_ms2_scans': 1300}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 76.84005868554128
# steps	 1000 	total rewards	 169.57753626639223
# steps	 1500 	total rewards	 237.68571062741546
# Finished after 1614 timesteps (6.4562718868255615 seconds) with total reward 249.42558813920385
# {'coverage_prop': '0.979', 'intensity_prop': '0.644', 'ms1ms2_ratio': '0.314', 'efficiency': '0.186', 'TP': '165', 'FP': '64', 'FN': '5', 'precision': '0.721', 'recall': '0.971', 'f1': '0.827', 'total_rewards': 249.42558813920277, 'invalid_action_count': 0, 'num_ms1_scans': 386, 'num_ms2_scans': 1228}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 85.8727543985716
# steps	 1000 	total rewards	 188.8390445573565
# steps	 1500 	total rewards	 271.9026476136637
# Finished after 1641 timesteps (9.64088487625122 seconds) with total reward 291.97949392694886
# {'coverage_prop': '0.981', 'intensity_prop': '0.640', 'ms1ms2_ratio': '0.280', 'efficiency': '0.246', 'TP': '223', 'FP': '93', 'FN': '6', 'precision': '0.706', 'recall': '0.974', 'f1': '0.818', 'total_rewards': 291.9794939269481, 'invalid_action_count': 0, 'num_ms1_scans': 359, 'num_ms2_scans': 1282}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 90.51473656823255
# steps	 1000 	total rewards	 189.6098169615248
# steps	 1500 	total rewards	 275.97007767430443
# Finished after 1642 timesteps (6.269775867462158 seconds) with total reward 296.5300150436084
# {'coverage_prop': '0.977', 'intensity_prop': '0.646', 'ms1ms2_ratio': '0.279', 'efficiency': '0.236', 'TP': '217', 'FP': '86', 'FN': '7', 'precision': '0.716', 'recall': '0.969', 'f1': '0.824', 'total_rewards': 296.5300150436079, 'invalid_action_count': 0, 'num_ms1_scans': 358, 'num_ms2_scans': 1284}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 93.67897741315599
# steps	 1000 	total rewards	 201.7908938461633
# steps	 1500 	total rewards	 292.04843733034915
# Finished after 1650 timesteps (7.543332099914551 seconds) with total reward 311.564895424315
# {'coverage_prop': '0.974', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.269', 'efficiency': '0.258', 'TP': '227', 'FP': '109', 'FN': '9', 'precision': '0.676', 'recall': '0.962', 'f1': '0.794', 'total_rewards': 311.56489542431456, 'invalid_action_count': 0, 'num_ms1_scans': 350, 'num_ms2_scans': 1300}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 91.70592089193582
# steps	 1000 	total rewards	 191.79357438453576
# steps	 1500 	total rewards	 292.8653031750101
# Finished after 1655 timesteps (11.97420620918274 seconds) with total reward 315.87502811414436
# {'coverage_prop': '0.977', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.263', 'efficiency': '0.295', 'TP': '268', 'FP': '119', 'FN': '9', 'precision': '0.693', 'recall': '0.968', 'f1': '0.807', 'total_rewards': 315.8750281141448, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 69.79658736001633
# steps	 1000 	total rewards	 158.6088087474273
# steps	 1500 	total rewards	 234.7705210731909
# Finished after 1615 timesteps (5.842236042022705 seconds) with total reward 249.2895263565805
# {'coverage_prop': '0.985', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.313', 'efficiency': '0.163', 'TP': '155', 'FP': '45', 'FN': '3', 'precision': '0.775', 'recall': '0.981', 'f1': '0.866', 'total_rewards': 249.2895263565789, 'invalid_action_count': 0, 'num_ms1_scans': 385, 'num_ms2_scans': 1230}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 86.07915174316202
# steps	 1000 	total rewards	 184.04089326677655
# steps	 1500 	total rewards	 272.56573851716416
# Finished after 1644 timesteps (5.3435680866241455 seconds) with total reward 295.7046277835971
# {'coverage_prop': '0.979', 'intensity_prop': '0.662', 'ms1ms2_ratio': '0.276', 'efficiency': '0.214', 'TP': '204', 'FP': '71', 'FN': '6', 'precision': '0.742', 'recall': '0.971', 'f1': '0.841', 'total_rewards': 295.7046277835977, 'invalid_action_count': 0, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 102.75177456941645
# steps	 1000 	total rewards	 218.47684898646213
# steps	 1500 	total rewards	 333.3840856614527
# Finished after 1637 timesteps (7.6637139320373535 seconds) with total reward 356.22776191687547
# {'coverage_prop': '0.929', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.285', 'efficiency': '0.359', 'TP': '302', 'FP': '156', 'FN': '35', 'precision': '0.659', 'recall': '0.896', 'f1': '0.760', 'total_rewards': 356.2277619168762, 'invalid_action_count': 0, 'num_ms1_scans': 363, 'num_ms2_scans': 1274}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 87.6481948724355
# steps	 1000 	total rewards	 181.15650032695444
# steps	 1500 	total rewards	 265.52768616933395
# Finished after 1649 timesteps (8.230693817138672 seconds) with total reward 281.30348628176097
# {'coverage_prop': '0.980', 'intensity_prop': '0.665', 'ms1ms2_ratio': '0.270', 'efficiency': '0.230', 'TP': '218', 'FP': '80', 'FN': '6', 'precision': '0.732', 'recall': '0.973', 'f1': '0.835', 'total_rewards': 281.3034862817604, 'invalid_action_count': 0, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 92.5276178076839
# steps	 1000 	total rewards	 205.25382864627784
# steps	 1500 	total rewards	 312.7588878054987
# Finished after 1722 timesteps (15.111883878707886 seconds) with total reward 350.1583925147164
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 350.15839251471635, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.19223993264903
# steps	 1000 	total rewards	 200.01185786399162
# steps	 1500 	total rewards	 278.69251864828544
# Finished after 1556 timesteps (11.29030966758728 seconds) with total reward 286.42041452327317
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 286.42041452327345, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.09810262952533
# steps	 1000 	total rewards	 204.55175528344176
# steps	 1500 	total rewards	 311.70589197292
# Finished after 1669 timesteps (13.076576948165894 seconds) with total reward 335.8567231016701
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 335.856723101671, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.75112549735738
# steps	 1000 	total rewards	 222.260470162795
# steps	 1500 	total rewards	 321.6296912754646
# Finished after 1717 timesteps (13.74279499053955 seconds) with total reward 364.78676992745324
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 364.7867699274535, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.88207661824359
# steps	 1000 	total rewards	 225.03458447204991
# steps	 1500 	total rewards	 333.40644054419124
# Finished after 1704 timesteps (13.474638938903809 seconds) with total reward 368.54312915676854
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 368.54312915676945, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.95053041210245
# steps	 1000 	total rewards	 176.02517486243747
# Finished after 1408 timesteps (10.41871690750122 seconds) with total reward 238.71804354506358
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 238.7180435450617, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.04778207928516
# steps	 1000 	total rewards	 216.92306176316305
# steps	 1500 	total rewards	 317.03297009874126
# Finished after 1744 timesteps (15.738884925842285 seconds) with total reward 357.54143159354504
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 357.54143159354567, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.27568189026226
# steps	 1000 	total rewards	 178.89586218914897
# Finished after 1468 timesteps (11.46152400970459 seconds) with total reward 248.8792687394992
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 248.87926873949786, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 102.06959352333683
# steps	 1000 	total rewards	 203.76934731050875
# steps	 1500 	total rewards	 314.6913157438472
# Finished after 1736 timesteps (15.015843152999878 seconds) with total reward 352.8683422368248
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 352.8683422368253, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 90.74138548172694
# steps	 1000 	total rewards	 200.31290144512386
# steps	 1500 	total rewards	 301.1097996085705
# Finished after 1667 timesteps (15.789875030517578 seconds) with total reward 323.768416073993
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 323.7684160739943, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.23962533608534
# steps	 1000 	total rewards	 197.16226995805556
# steps	 1500 	total rewards	 303.39580167752945
# Finished after 1737 timesteps (15.455745935440063 seconds) with total reward 344.057804535654
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 344.05780453565535, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.76014323446897
# steps	 1000 	total rewards	 182.82317997694054
# steps	 1500 	total rewards	 254.1775526296638
# Finished after 1530 timesteps (12.730165004730225 seconds) with total reward 257.90826139058424
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 257.9082613905829, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.09788008205047
# steps	 1000 	total rewards	 173.34530752343633
# steps	 1500 	total rewards	 250.4027444407447
# Finished after 1602 timesteps (14.319815874099731 seconds) with total reward 265.8130372865816
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 265.8130372865811, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 81.87979467550704
# steps	 1000 	total rewards	 176.3296676850765
# steps	 1500 	total rewards	 264.5543538505019
# Finished after 1645 timesteps (17.217167854309082 seconds) with total reward 281.66421220903726
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 281.6642122090379, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 77.69553492222708
# steps	 1000 	total rewards	 165.92205077135358
# Finished after 1497 timesteps (12.855653047561646 seconds) with total reward 238.86550329561172
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 238.86550329561047, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.05709360186964
# steps	 1000 	total rewards	 202.35383743309467
# steps	 1500 	total rewards	 309.4258646878863
# Finished after 1655 timesteps (14.572227954864502 seconds) with total reward 340.11849111963613
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 340.118491119637, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 105.80378017337763
# steps	 1000 	total rewards	 218.16501246190484
# steps	 1500 	total rewards	 323.99517148498575
# Finished after 1729 timesteps (15.14184308052063 seconds) with total reward 365.3798953710612
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 365.3798953710626, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.86888851189178
# steps	 1000 	total rewards	 210.73859611594213
# steps	 1500 	total rewards	 300.65131585356136
# Finished after 1681 timesteps (16.733092069625854 seconds) with total reward 326.453219442385
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 326.45321944238583, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.55640776019361
# steps	 1000 	total rewards	 192.1170010832405
# steps	 1500 	total rewards	 282.6369316315453
# Finished after 1621 timesteps (15.799189805984497 seconds) with total reward 301.02243270902477
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 301.022432709025, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.8961989902214
# steps	 1000 	total rewards	 183.76704030525036
# steps	 1500 	total rewards	 264.106842989171
# Finished after 1634 timesteps (13.308672904968262 seconds) with total reward 282.8349639496908
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 282.8349639496904, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.82872862229425
# steps	 1000 	total rewards	 205.4574323828516
# steps	 1500 	total rewards	 298.0440315538605
# Finished after 1726 timesteps (16.96654200553894 seconds) with total reward 339.6563370807766
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 339.65633708077706, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 78.8765952264226
# steps	 1000 	total rewards	 180.8121218448101
# Finished after 1475 timesteps (18.569418907165527 seconds) with total reward 259.5886548759064
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 259.5886548759048, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 90.37844742158512
# steps	 1000 	total rewards	 195.95932027941527
# steps	 1500 	total rewards	 283.3609709366841
# Finished after 1636 timesteps (15.637786149978638 seconds) with total reward 305.03129962834686
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 305.03129962834777, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.58010974902588
# steps	 1000 	total rewards	 199.06887434647197
# steps	 1500 	total rewards	 285.5523492877917
# Finished after 1575 timesteps (13.447477102279663 seconds) with total reward 296.6703624144893
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 296.67036241449057, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 90.58123202962977
# steps	 1000 	total rewards	 201.86616968777264
# steps	 1500 	total rewards	 295.787668388372
# Finished after 1681 timesteps (16.214529037475586 seconds) with total reward 324.2819674955664
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 324.28196749556696, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.78144021754095
# steps	 1000 	total rewards	 188.87430385569195
# steps	 1500 	total rewards	 297.86842274642567
# Finished after 1679 timesteps (15.117521286010742 seconds) with total reward 329.2116800669655
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 329.21168006696644, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 71.98194223405334
# steps	 1000 	total rewards	 170.41017366979133
# Finished after 1465 timesteps (22.442190170288086 seconds) with total reward 242.86558010739546
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 242.86558010739404, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 87.80052172308895
# steps	 1000 	total rewards	 195.50633781024922
# steps	 1500 	total rewards	 294.00010247549244
# Finished after 1564 timesteps (18.085620880126953 seconds) with total reward 304.0900195549617
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 304.09001955496166, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.17309733822901
# steps	 1000 	total rewards	 195.47739728296165
# steps	 1500 	total rewards	 298.6482177897861
# Finished after 1749 timesteps (22.143723964691162 seconds) with total reward 346.2046795612188
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 346.20467956121945, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.33998672596451
# steps	 1000 	total rewards	 192.64754247155082
# steps	 1500 	total rewards	 274.80651079438553
# Finished after 1657 timesteps (15.597288131713867 seconds) with total reward 293.02734741027416
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 293.02734741027416, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7facb1ab1280>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7face3ae3610>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7facd29e88b0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.488', 'ms1ms2_ratio': '1.387', 'efficiency': '0.768', 'TP': '205', 'FP': '202', 'FN': '19', 'precision': '0.504', 'recall': '0.915', 'f1': '0.650'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '256', 'FP': '198', 'FN': '24', 'precision': '0.564', 'recall': '0.914', 'f1': '0.698'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.473', 'ms1ms2_ratio': '2.154', 'efficiency': '0.772', 'TP': '136', 'FP': '155', 'FN': '19', 'precision': '0.467', 'recall': '0.877', 'f1': '0.610'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.508', 'ms1ms2_ratio': '1.610', 'efficiency': '0.707', 'TP': '170', 'FP': '165', 'FN': '10', 'precision': '0.507', 'recall': '0.944', 'f1': '0.660'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.250', 'efficiency': '0.739', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '251', 'FP': '218', 'FN': '24', 'precision': '0.535', 'recall': '0.913', 'f1': '0.675'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1087.786449                1231.0          0.721           0.230
# 1  random   -1432.996878                1511.0          0.611           0.172
# 2  random   -1215.896929                1334.0          0.655           0.187
# 3  random   -1360.921780                1471.0          0.588           0.170
# 4  random   -1123.144989                1262.0          0.693           0.208
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.155      0.309   0.444  0.365
# 1          0.005       0.081      0.256   0.287  0.271
# 2          0.006       0.131      0.236   0.310  0.268
# 3          0.004       0.134      0.263   0.273  0.268
# 4          0.005       0.153      0.294   0.399  0.338

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E7_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E7_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     333.185809                   0.0          0.974           0.617
# 31    DQN     283.306952                   0.0          0.966           0.675
# 32    DQN     321.002036                   0.0          0.982           0.591
# 33    DQN     330.372310                   1.0          0.967           0.600
# 34    DQN     324.084473                   0.0          0.968           0.586
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.275       0.322      0.711   0.964  0.818
# 31          0.279       0.197      0.771   0.956  0.853
# 32          0.279       0.301      0.651   0.973  0.780
# 33          0.256       0.331      0.684   0.952  0.796
# 34          0.270       0.326      0.652   0.952  0.774

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
