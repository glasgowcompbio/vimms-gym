# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
alpha = 0.25
beta = 0.75
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=alpha, beta=beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2022-09-14 13:57:11.471 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc25519aa30>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc256607280>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc23060b520>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.25,
#    'beta': 0.75}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = '../../tune/QCB_resimulated_medium'
out_dir = 'evaluation_2.0E6'
methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 265
# 352
# 460
# 402
# 456
# 494
# 450
# 228
# 442
# 354
# 299
# 264
# 335
# 295
# 416
# 334
# 275
# 244
# 392
# 290
# 441
# 411
# 433
# 386
# 245
# 261
# 436
# 494
# 246
# 256

# %% [markdown]
# Generate new chemicals if not found

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    min_mz = mz_range[0]
    max_mz = mz_range[1]
    min_rt = rt_range[0]
    max_rt = rt_range[1]
    min_log_intensity = np.log(intensity_range[0])
    max_log_intensity = np.log(intensity_range[1])
    
    mzml_filename = '../fullscan_QCB.mzML'
    samplers_pickle = 'samplers_QCB_medium.p'
    if exists(samplers_pickle):
        logger.info('Loaded %s' % samplers_pickle)
        samplers = load_obj(samplers_pickle)
        mz_sampler = samplers['mz']
        ri_sampler = samplers['rt_intensity']
        cr_sampler = samplers['chromatogram']
    else:
        logger.info('Creating samplers from %s' % mzml_filename)
        mz_sampler = MZMLFormulaSampler(mzml_filename, min_mz=min_mz, max_mz=max_mz)
        ri_sampler = MZMLRTandIntensitySampler(mzml_filename, min_rt=min_rt, max_rt=max_rt,
                                               min_log_intensity=min_log_intensity,
                                               max_log_intensity=max_log_intensity)
        roi_params = RoiBuilderParams(min_roi_length=3, at_least_one_point_above=5E5)
        cr_sampler = MZMLChromatogramSampler(mzml_filename, roi_params=roi_params)
        samplers = {
            'mz': mz_sampler,
            'rt_intensity': ri_sampler,
            'chromatogram': cr_sampler
        }
        save_obj(samplers, samplers_pickle)
    
    chemical_creator_params = {
        'mz_range': mz_range,
        'rt_range': rt_range,
        'intensity_range': intensity_range,
        'n_chemicals': n_chemicals,
        'mz_sampler': mz_sampler,
        'ri_sampler': ri_sampler,
        'cr_sampler': cr_sampler
    }

    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc25519aa30>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc256607280>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc23060b520>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.25,
#   'beta': 0.75}}

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = dict(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        alpha = 0.201200737
        beta = 0.526891524
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_2000000_alpha_auto_beta_auto', METHOD_DQN)
        fname = os.path.join(model_dir, 'best_model.zip')
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO:
        alpha = 0.72626536
        beta = 0.020056458
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_2000000_alpha_auto_beta_auto', METHOD_PPO)
        fname = os.path.join(model_dir, 'best_model.zip')
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO_RECURRENT:
        alpha = 0.25
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_2000000_alpha_auto_beta_auto', METHOD_PPO_RECURRENT)        
        fname = os.path.join(model_dir, 'best_model.zip')
        model = RecurrentPPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (265 chemicals)
# steps	 500 	total rewards	 -455.0
# steps	 1000 	total rewards	 -803.2233449692044
# steps	 1500 	total rewards	 -1019.5165869122255
# Finished after 1993 timesteps with total reward -1404.6567761355689
# {'coverage_prop': '0.679', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.004', 'efficiency': '0.091', 'TP': '58', 'FP': '122', 'FN': '85', 'precision': '0.322', 'recall': '0.406', 'f1': '0.359', 'total_rewards': -1404.6567761355702, 'invalid_action_count': 1453}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 -413.85239416315085
# steps	 1000 	total rewards	 -781.3598581365324
# steps	 1500 	total rewards	 -1053.4177893396472
# Finished after 1989 timesteps with total reward -1285.8534712868131
# {'coverage_prop': '0.679', 'intensity_prop': '0.205', 'ms1ms2_ratio': '0.006', 'efficiency': '0.121', 'TP': '69', 'FP': '170', 'FN': '113', 'precision': '0.289', 'recall': '0.379', 'f1': '0.328', 'total_rewards': -1285.853471286814, 'invalid_action_count': 1350}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 -450.493254343995
# steps	 1000 	total rewards	 -632.1463118860528
# steps	 1500 	total rewards	 -828.3666203008461
# Finished after 1989 timesteps with total reward -1024.5685221612102
# {'coverage_prop': '0.746', 'intensity_prop': '0.275', 'ms1ms2_ratio': '0.006', 'efficiency': '0.173', 'TP': '127', 'FP': '216', 'FN': '117', 'precision': '0.370', 'recall': '0.520', 'f1': '0.433', 'total_rewards': -1024.5685221612107, 'invalid_action_count': 1112}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 -339.0916814871757
# steps	 1000 	total rewards	 -724.7877146931148
# steps	 1500 	total rewards	 -1217.5339857201163
# Finished after 1992 timesteps with total reward -1526.6681948684982
# {'coverage_prop': '0.525', 'intensity_prop': '0.122', 'ms1ms2_ratio': '0.004', 'efficiency': '0.106', 'TP': '44', 'FP': '167', 'FN': '191', 'precision': '0.209', 'recall': '0.187', 'f1': '0.197', 'total_rewards': -1526.668194868498, 'invalid_action_count': 1570}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 -395.7031071521345
# steps	 1000 	total rewards	 -624.604848857304
# steps	 1500 	total rewards	 -880.8722085508526
# Finished after 1990 timesteps with total reward -1147.7425848180676
# {'coverage_prop': '0.748', 'intensity_prop': '0.265', 'ms1ms2_ratio': '0.005', 'efficiency': '0.172', 'TP': '121', 'FP': '220', 'FN': '115', 'precision': '0.355', 'recall': '0.513', 'f1': '0.419', 'total_rewards': -1147.7425848180676, 'invalid_action_count': 1232}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 -433.0517192521394
# steps	 1000 	total rewards	 -720.4096096798858
# steps	 1500 	total rewards	 -1062.4878024618981
# Finished after 1993 timesteps with total reward -1322.0019075839596
# {'coverage_prop': '0.636', 'intensity_prop': '0.177', 'ms1ms2_ratio': '0.004', 'efficiency': '0.158', 'TP': '77', 'FP': '237', 'FN': '180', 'precision': '0.245', 'recall': '0.300', 'f1': '0.270', 'total_rewards': -1322.001907583962, 'invalid_action_count': 1392}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 -330.1608760101725
# steps	 1000 	total rewards	 -653.4985235112047
# steps	 1500 	total rewards	 -819.1012749562246
# Finished after 1987 timesteps with total reward -1038.4615732501866
# {'coverage_prop': '0.744', 'intensity_prop': '0.225', 'ms1ms2_ratio': '0.007', 'efficiency': '0.170', 'TP': '88', 'FP': '247', 'FN': '115', 'precision': '0.263', 'recall': '0.433', 'f1': '0.327', 'total_rewards': -1038.4615732501877, 'invalid_action_count': 1130}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 -452.5929114905822
# steps	 1000 	total rewards	 -828.8906854194067
# steps	 1500 	total rewards	 -1094.7294249372196
# Finished after 1990 timesteps with total reward -1400.2112515467861
# {'coverage_prop': '0.693', 'intensity_prop': '0.233', 'ms1ms2_ratio': '0.005', 'efficiency': '0.080', 'TP': '50', 'FP': '108', 'FN': '70', 'precision': '0.316', 'recall': '0.417', 'f1': '0.360', 'total_rewards': -1400.211251546787, 'invalid_action_count': 1443}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 -382.6075881905233
# steps	 1000 	total rewards	 -596.4234507222351
# steps	 1500 	total rewards	 -740.4307030636016
# Finished after 1985 timesteps with total reward -873.190346681245
# {'coverage_prop': '0.805', 'intensity_prop': '0.302', 'ms1ms2_ratio': '0.008', 'efficiency': '0.181', 'TP': '127', 'FP': '229', 'FN': '86', 'precision': '0.357', 'recall': '0.596', 'f1': '0.446', 'total_rewards': -873.1903466812453, 'invalid_action_count': 964}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 -412.26137821456393
# steps	 1000 	total rewards	 -847.548586031852
# steps	 1500 	total rewards	 -1024.204558428186
# Finished after 1988 timesteps with total reward -1256.9548974650988
# {'coverage_prop': '0.616', 'intensity_prop': '0.181', 'ms1ms2_ratio': '0.006', 'efficiency': '0.110', 'TP': '61', 'FP': '157', 'FN': '136', 'precision': '0.280', 'recall': '0.310', 'f1': '0.294', 'total_rewards': -1256.9548974651, 'invalid_action_count': 1315}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 -414.25374610690494
# steps	 1000 	total rewards	 -790.7859403666577
# steps	 1500 	total rewards	 -1065.5604741617094
# Finished after 1992 timesteps with total reward -1346.1264305123964
# {'coverage_prop': '0.709', 'intensity_prop': '0.138', 'ms1ms2_ratio': '0.004', 'efficiency': '0.107', 'TP': '33', 'FP': '179', 'FN': '87', 'precision': '0.156', 'recall': '0.275', 'f1': '0.199', 'total_rewards': -1346.1264305123975, 'invalid_action_count': 1399}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 -397.71242647942444
# steps	 1000 	total rewards	 -792.2424870701655
# steps	 1500 	total rewards	 -1111.7345192496477
# Finished after 1989 timesteps with total reward -1421.9573131158343
# {'coverage_prop': '0.648', 'intensity_prop': '0.190', 'ms1ms2_ratio': '0.006', 'efficiency': '0.086', 'TP': '50', 'FP': '121', 'FN': '93', 'precision': '0.292', 'recall': '0.350', 'f1': '0.318', 'total_rewards': -1421.957313115835, 'invalid_action_count': 1468}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 -350.29350052377026
# steps	 1000 	total rewards	 -639.7963379544417
# steps	 1500 	total rewards	 -901.5604277861682
# Finished after 1987 timesteps with total reward -1192.3122154548876
# {'coverage_prop': '0.779', 'intensity_prop': '0.222', 'ms1ms2_ratio': '0.007', 'efficiency': '0.132', 'TP': '67', 'FP': '194', 'FN': '74', 'precision': '0.257', 'recall': '0.475', 'f1': '0.333', 'total_rewards': -1192.3122154548876, 'invalid_action_count': 1258}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 -358.1132332203158
# steps	 1000 	total rewards	 -679.9416563651099
# steps	 1500 	total rewards	 -1021.3984029005683
# Finished after 1985 timesteps with total reward -1245.7655021530236
# {'coverage_prop': '0.746', 'intensity_prop': '0.194', 'ms1ms2_ratio': '0.008', 'efficiency': '0.112', 'TP': '49', 'FP': '171', 'FN': '75', 'precision': '0.223', 'recall': '0.395', 'f1': '0.285', 'total_rewards': -1245.7655021530238, 'invalid_action_count': 1301}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 -365.8423171116502
# steps	 1000 	total rewards	 -716.8755626271046
# steps	 1500 	total rewards	 -937.298366206302
# Finished after 1981 timesteps with total reward -1096.571353512069
# {'coverage_prop': '0.688', 'intensity_prop': '0.232', 'ms1ms2_ratio': '0.010', 'efficiency': '0.146', 'TP': '92', 'FP': '194', 'FN': '130', 'precision': '0.322', 'recall': '0.414', 'f1': '0.362', 'total_rewards': -1096.5713535120688, 'invalid_action_count': 1169}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 -451.0
# steps	 1000 	total rewards	 -836.4919675340059
# steps	 1500 	total rewards	 -961.2146934755488
# Finished after 1988 timesteps with total reward -1170.2529589212395
# {'coverage_prop': '0.695', 'intensity_prop': '0.250', 'ms1ms2_ratio': '0.006', 'efficiency': '0.117', 'TP': '81', 'FP': '151', 'FN': '102', 'precision': '0.349', 'recall': '0.443', 'f1': '0.390', 'total_rewards': -1170.2529589212381, 'invalid_action_count': 1232}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 -374.42844078363714
# steps	 1000 	total rewards	 -682.0547915840631
# steps	 1500 	total rewards	 -1059.785074557777
# Finished after 1987 timesteps with total reward -1320.3627249981575
# {'coverage_prop': '0.742', 'intensity_prop': '0.209', 'ms1ms2_ratio': '0.007', 'efficiency': '0.103', 'TP': '51', 'FP': '153', 'FN': '71', 'precision': '0.250', 'recall': '0.418', 'f1': '0.313', 'total_rewards': -1320.3627249981562, 'invalid_action_count': 1376}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 -411.2000518052082
# steps	 1000 	total rewards	 -727.4954393365815
# steps	 1500 	total rewards	 -1008.3245797567766
# Finished after 1991 timesteps with total reward -1445.8659818580536
# {'coverage_prop': '0.639', 'intensity_prop': '0.180', 'ms1ms2_ratio': '0.005', 'efficiency': '0.079', 'TP': '41', 'FP': '115', 'FN': '88', 'precision': '0.263', 'recall': '0.318', 'f1': '0.288', 'total_rewards': -1445.865981858054, 'invalid_action_count': 1490}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 -451.0975755962537
# steps	 1000 	total rewards	 -799.0041674650429
# steps	 1500 	total rewards	 -1019.3785182688672
# Finished after 1992 timesteps with total reward -1262.0959381530274
# {'coverage_prop': '0.676', 'intensity_prop': '0.237', 'ms1ms2_ratio': '0.004', 'efficiency': '0.134', 'TP': '91', 'FP': '174', 'FN': '127', 'precision': '0.343', 'recall': '0.417', 'f1': '0.377', 'total_rewards': -1262.0959381530265, 'invalid_action_count': 1323}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 -376.11545848036405
# steps	 1000 	total rewards	 -647.1822975539749
# steps	 1500 	total rewards	 -866.2439635512873
# Finished after 1987 timesteps with total reward -1307.1708251829757
# {'coverage_prop': '0.655', 'intensity_prop': '0.215', 'ms1ms2_ratio': '0.007', 'efficiency': '0.096', 'TP': '62', 'FP': '128', 'FN': '100', 'precision': '0.326', 'recall': '0.383', 'f1': '0.352', 'total_rewards': -1307.1708251829746, 'invalid_action_count': 1360}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 -328.1593405134013
# steps	 1000 	total rewards	 -513.1919897984008
# steps	 1500 	total rewards	 -744.0186227374263
# Finished after 1984 timesteps with total reward -916.0835526547512
# {'coverage_prop': '0.789', 'intensity_prop': '0.273', 'ms1ms2_ratio': '0.008', 'efficiency': '0.177', 'TP': '120', 'FP': '228', 'FN': '93', 'precision': '0.345', 'recall': '0.563', 'f1': '0.428', 'total_rewards': -916.0835526547518, 'invalid_action_count': 1012}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 -361.6762213620587
# steps	 1000 	total rewards	 -641.786914162403
# steps	 1500 	total rewards	 -837.2492405868236
# Finished after 1987 timesteps with total reward -1036.1823437018638
# {'coverage_prop': '0.779', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.007', 'efficiency': '0.162', 'TP': '72', 'FP': '248', 'FN': '91', 'precision': '0.225', 'recall': '0.442', 'f1': '0.298', 'total_rewards': -1036.1823437018634, 'invalid_action_count': 1112}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 -292.2531603791949
# steps	 1000 	total rewards	 -710.8454803666505
# steps	 1500 	total rewards	 -945.7868882357113
# Finished after 1988 timesteps with total reward -1183.9106218628513
# {'coverage_prop': '0.686', 'intensity_prop': '0.183', 'ms1ms2_ratio': '0.006', 'efficiency': '0.150', 'TP': '69', 'FP': '228', 'FN': '136', 'precision': '0.232', 'recall': '0.337', 'f1': '0.275', 'total_rewards': -1183.9106218628522, 'invalid_action_count': 1257}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 -377.5734132201753
# steps	 1000 	total rewards	 -592.9971073576025
# steps	 1500 	total rewards	 -772.0415712233719
# Finished after 1987 timesteps with total reward -1092.2784759177905
# {'coverage_prop': '0.754', 'intensity_prop': '0.220', 'ms1ms2_ratio': '0.007', 'efficiency': '0.147', 'TP': '79', 'FP': '212', 'FN': '95', 'precision': '0.271', 'recall': '0.454', 'f1': '0.340', 'total_rewards': -1092.2784759177912, 'invalid_action_count': 1166}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 -412.2808543981641
# steps	 1000 	total rewards	 -711.2649595212763
# steps	 1500 	total rewards	 -1067.0477141777
# Finished after 1992 timesteps with total reward -1397.8586934470395
# {'coverage_prop': '0.743', 'intensity_prop': '0.212', 'ms1ms2_ratio': '0.004', 'efficiency': '0.092', 'TP': '52', 'FP': '130', 'FN': '63', 'precision': '0.286', 'recall': '0.452', 'f1': '0.350', 'total_rewards': -1397.8586934470404, 'invalid_action_count': 1450}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 -394.4370135035461
# steps	 1000 	total rewards	 -712.889892746427
# steps	 1500 	total rewards	 -996.7467186398749
# Finished after 1987 timesteps with total reward -1265.4440221406537
# {'coverage_prop': '0.793', 'intensity_prop': '0.217', 'ms1ms2_ratio': '0.007', 'efficiency': '0.105', 'TP': '54', 'FP': '153', 'FN': '54', 'precision': '0.261', 'recall': '0.500', 'f1': '0.343', 'total_rewards': -1265.4440221406535, 'invalid_action_count': 1322}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 -415.501137226418
# steps	 1000 	total rewards	 -617.239852858009
# steps	 1500 	total rewards	 -842.2403301232018
# Finished after 1988 timesteps with total reward -1126.121449389111
# {'coverage_prop': '0.752', 'intensity_prop': '0.243', 'ms1ms2_ratio': '0.006', 'efficiency': '0.166', 'TP': '99', 'FP': '229', 'FN': '108', 'precision': '0.302', 'recall': '0.478', 'f1': '0.370', 'total_rewards': -1126.1214493891118, 'invalid_action_count': 1211}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 -327.336378793593
# steps	 1000 	total rewards	 -735.2412542901329
# steps	 1500 	total rewards	 -878.1991956089898
# Finished after 1988 timesteps with total reward -1103.1221731380797
# {'coverage_prop': '0.729', 'intensity_prop': '0.200', 'ms1ms2_ratio': '0.006', 'efficiency': '0.182', 'TP': '91', 'FP': '269', 'FN': '134', 'precision': '0.253', 'recall': '0.404', 'f1': '0.311', 'total_rewards': -1103.122173138079, 'invalid_action_count': 1197}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 -389.3562414895726
# steps	 1000 	total rewards	 -691.6035615327608
# steps	 1500 	total rewards	 -995.2242731399174
# Finished after 1986 timesteps with total reward -1287.8945165378207
# {'coverage_prop': '0.711', 'intensity_prop': '0.216', 'ms1ms2_ratio': '0.007', 'efficiency': '0.089', 'TP': '51', 'FP': '124', 'FN': '71', 'precision': '0.291', 'recall': '0.418', 'f1': '0.343', 'total_rewards': -1287.894516537822, 'invalid_action_count': 1337}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 -384.0381063469255
# steps	 1000 	total rewards	 -677.3318875141384
# steps	 1500 	total rewards	 -1051.0101619662112
# Finished after 1991 timesteps with total reward -1365.4005948017966
# {'coverage_prop': '0.734', 'intensity_prop': '0.244', 'ms1ms2_ratio': '0.005', 'efficiency': '0.095', 'TP': '64', 'FP': '124', 'FN': '68', 'precision': '0.340', 'recall': '0.485', 'f1': '0.400', 'total_rewards': -1365.4005948017982, 'invalid_action_count': 1416}
#
# method = PPO max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (265 chemicals)
# steps	 500 	total rewards	 89.34360335757356
# steps	 1000 	total rewards	 187.14797490478287
# steps	 1500 	total rewards	 243.55456259664197
# Finished after 1504 timesteps with total reward 243.9279900984489
# {'coverage_prop': '0.943', 'intensity_prop': '0.558', 'ms1ms2_ratio': '0.492', 'efficiency': '0.248', 'TP': '156', 'FP': '94', 'FN': '15', 'precision': '0.624', 'recall': '0.912', 'f1': '0.741', 'total_rewards': 243.927990098447, 'invalid_action_count': 12}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 95.7851788158539
# steps	 1000 	total rewards	 175.39198403682082
# steps	 1500 	total rewards	 258.5994632694221
# Finished after 1539 timesteps with total reward 265.3747888254562
# {'coverage_prop': '0.918', 'intensity_prop': '0.555', 'ms1ms2_ratio': '0.428', 'efficiency': '0.300', 'TP': '209', 'FP': '114', 'FN': '29', 'precision': '0.647', 'recall': '0.878', 'f1': '0.745', 'total_rewards': 265.3747888254551, 'invalid_action_count': 35}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 108.19335685522904
# steps	 1000 	total rewards	 233.97568771627408
# steps	 1500 	total rewards	 325.42373106943063
# Finished after 1558 timesteps with total reward 334.9253011836744
# {'coverage_prop': '0.909', 'intensity_prop': '0.554', 'ms1ms2_ratio': '0.396', 'efficiency': '0.375', 'TP': '276', 'FP': '142', 'FN': '42', 'precision': '0.660', 'recall': '0.868', 'f1': '0.750', 'total_rewards': 334.92530118367756, 'invalid_action_count': 6}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 92.52462896929178
# steps	 1000 	total rewards	 196.94513912943046
# steps	 1500 	total rewards	 207.01310561527623
# Finished after 1550 timesteps with total reward 216.12928494794056
# {'coverage_prop': '0.903', 'intensity_prop': '0.510', 'ms1ms2_ratio': '0.409', 'efficiency': '0.330', 'TP': '223', 'FP': '140', 'FN': '39', 'precision': '0.614', 'recall': '0.851', 'f1': '0.714', 'total_rewards': 216.12928494793903, 'invalid_action_count': 74}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 99.97060370220586
# steps	 1000 	total rewards	 -169.81293967745157
# steps	 1500 	total rewards	 -202.14917003221746
# Finished after 1664 timesteps with total reward -175.52637251746927
# {'coverage_prop': '0.765', 'intensity_prop': '0.407', 'ms1ms2_ratio': '0.253', 'efficiency': '0.263', 'TP': '200', 'FP': '149', 'FN': '107', 'precision': '0.573', 'recall': '0.651', 'f1': '0.610', 'total_rewards': -175.52637251746992, 'invalid_action_count': 437}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 105.35747527455213
# steps	 1000 	total rewards	 215.42549929042946
# steps	 1500 	total rewards	 313.8615329614615
# Finished after 1568 timesteps with total reward 281.37499201598916
# {'coverage_prop': '0.870', 'intensity_prop': '0.512', 'ms1ms2_ratio': '0.381', 'efficiency': '0.379', 'TP': '275', 'FP': '155', 'FN': '64', 'precision': '0.640', 'recall': '0.811', 'f1': '0.715', 'total_rewards': 281.374992015991, 'invalid_action_count': 50}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 103.90780581064779
# steps	 1000 	total rewards	 227.94055336528297
# steps	 1500 	total rewards	 278.93313167459434
# Finished after 1561 timesteps with total reward 288.4093446872703
# {'coverage_prop': '0.889', 'intensity_prop': '0.507', 'ms1ms2_ratio': '0.391', 'efficiency': '0.357', 'TP': '241', 'FP': '159', 'FN': '50', 'precision': '0.603', 'recall': '0.828', 'f1': '0.698', 'total_rewards': 288.4093446872705, 'invalid_action_count': 45}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 80.58782657350346
# steps	 1000 	total rewards	 184.0249288344911
# Finished after 1496 timesteps with total reward 242.15730000882718
# {'coverage_prop': '0.965', 'intensity_prop': '0.614', 'ms1ms2_ratio': '0.510', 'efficiency': '0.222', 'TP': '151', 'FP': '69', 'FN': '8', 'precision': '0.686', 'recall': '0.950', 'f1': '0.797', 'total_rewards': 242.15730000882567, 'invalid_action_count': 4}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 103.5485465236845
# steps	 1000 	total rewards	 114.36551234359548
# steps	 1500 	total rewards	 211.29870419530917
# Finished after 1566 timesteps with total reward 220.4965362548428
# {'coverage_prop': '0.907', 'intensity_prop': '0.512', 'ms1ms2_ratio': '0.385', 'efficiency': '0.355', 'TP': '250', 'FP': '151', 'FN': '41', 'precision': '0.623', 'recall': '0.859', 'f1': '0.723', 'total_rewards': 220.49653625484126, 'invalid_action_count': 87}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 105.50555901301237
# steps	 1000 	total rewards	 -202.7990056049055
# steps	 1500 	total rewards	 -261.8366655301088
# Finished after 1638 timesteps with total reward -244.28848640418698
# {'coverage_prop': '0.811', 'intensity_prop': '0.388', 'ms1ms2_ratio': '0.284', 'efficiency': '0.225', 'TP': '138', 'FP': '149', 'FN': '67', 'precision': '0.481', 'recall': '0.673', 'f1': '0.561', 'total_rewards': -244.28848640418582, 'invalid_action_count': 490}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 88.23419309667804
# steps	 1000 	total rewards	 200.89135561027115
# steps	 1500 	total rewards	 288.9442934380102
# Finished after 1518 timesteps with total reward 285.9525060883152
# {'coverage_prop': '0.946', 'intensity_prop': '0.538', 'ms1ms2_ratio': '0.465', 'efficiency': '0.273', 'TP': '175', 'FP': '108', 'FN': '16', 'precision': '0.618', 'recall': '0.916', 'f1': '0.738', 'total_rewards': 285.95250608831606, 'invalid_action_count': 6}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 87.27716187311663
# steps	 1000 	total rewards	 186.2551318750413
# Finished after 1484 timesteps with total reward 228.1262338797884
# {'coverage_prop': '0.936', 'intensity_prop': '0.588', 'ms1ms2_ratio': '0.533', 'efficiency': '0.255', 'TP': '168', 'FP': '79', 'FN': '17', 'precision': '0.680', 'recall': '0.908', 'f1': '0.778', 'total_rewards': 228.12623387978658, 'invalid_action_count': 26}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 99.89343821281716
# steps	 1000 	total rewards	 200.7130865058592
# steps	 1500 	total rewards	 287.795633911149
# Finished after 1524 timesteps with total reward 290.56504443714607
# {'coverage_prop': '0.955', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.454', 'efficiency': '0.305', 'TP': '210', 'FP': '110', 'FN': '15', 'precision': '0.656', 'recall': '0.933', 'f1': '0.771', 'total_rewards': 290.5650444371461, 'invalid_action_count': 2}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 92.89258450012619
# steps	 1000 	total rewards	 196.15736787273892
# steps	 1500 	total rewards	 268.3606009013007
# Finished after 1523 timesteps with total reward 270.3118920911359
# {'coverage_prop': '0.953', 'intensity_prop': '0.565', 'ms1ms2_ratio': '0.457', 'efficiency': '0.269', 'TP': '182', 'FP': '99', 'FN': '14', 'precision': '0.648', 'recall': '0.929', 'f1': '0.763', 'total_rewards': 270.3118920911349, 'invalid_action_count': 4}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 93.01715159076626
# steps	 1000 	total rewards	 197.11922835703209
# steps	 1500 	total rewards	 283.42382110075715
# Finished after 1543 timesteps with total reward 286.79324759573706
# {'coverage_prop': '0.916', 'intensity_prop': '0.548', 'ms1ms2_ratio': '0.421', 'efficiency': '0.351', 'TP': '244', 'FP': '137', 'FN': '35', 'precision': '0.640', 'recall': '0.875', 'f1': '0.739', 'total_rewards': 286.79324759573706, 'invalid_action_count': 15}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 85.54217450002024
# steps	 1000 	total rewards	 186.49658714277274
# steps	 1500 	total rewards	 239.02055986544616
# Finished after 1531 timesteps with total reward 242.5156525046098
# {'coverage_prop': '0.925', 'intensity_prop': '0.540', 'ms1ms2_ratio': '0.442', 'efficiency': '0.291', 'TP': '191', 'FP': '118', 'FN': '25', 'precision': '0.618', 'recall': '0.884', 'f1': '0.728', 'total_rewards': 242.5156525046079, 'invalid_action_count': 22}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 86.28930440967846
# steps	 1000 	total rewards	 192.0481107298393
# steps	 1500 	total rewards	 266.8880151289856
# Finished after 1500 timesteps with total reward 266.8880151289856
# {'coverage_prop': '0.953', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.502', 'efficiency': '0.262', 'TP': '182', 'FP': '80', 'FN': '13', 'precision': '0.695', 'recall': '0.933', 'f1': '0.796', 'total_rewards': 266.88801512898397, 'invalid_action_count': 5}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 79.18172174107511
# steps	 1000 	total rewards	 177.53823826766182
# Finished after 1457 timesteps with total reward 246.39599400302222
# {'coverage_prop': '0.934', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.594', 'efficiency': '0.249', 'TP': '148', 'FP': '80', 'FN': '16', 'precision': '0.649', 'recall': '0.902', 'f1': '0.755', 'total_rewards': 246.3959940030205, 'invalid_action_count': 1}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 100.08913429624207
# steps	 1000 	total rewards	 92.75268384207237
# steps	 1500 	total rewards	 172.00065394368087
# Finished after 1568 timesteps with total reward 182.88871247238635
# {'coverage_prop': '0.913', 'intensity_prop': '0.545', 'ms1ms2_ratio': '0.380', 'efficiency': '0.315', 'TP': '237', 'FP': '121', 'FN': '34', 'precision': '0.662', 'recall': '0.875', 'f1': '0.754', 'total_rewards': 182.888712472385, 'invalid_action_count': 98}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 84.87339237816336
# steps	 1000 	total rewards	 185.87975949164604
# steps	 1500 	total rewards	 268.4869831257581
# Finished after 1500 timesteps with total reward 268.4869831257581
# {'coverage_prop': '0.934', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.500', 'efficiency': '0.271', 'TP': '181', 'FP': '90', 'FN': '19', 'precision': '0.668', 'recall': '0.905', 'f1': '0.769', 'total_rewards': 268.4869831257574, 'invalid_action_count': 4}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 109.18625362676083
# steps	 1000 	total rewards	 -193.0609313084153
# steps	 1500 	total rewards	 -211.44238894509232
# Finished after 1658 timesteps with total reward -189.81024306138355
# {'coverage_prop': '0.766', 'intensity_prop': '0.363', 'ms1ms2_ratio': '0.260', 'efficiency': '0.257', 'TP': '165', 'FP': '173', 'FN': '103', 'precision': '0.488', 'recall': '0.616', 'f1': '0.545', 'total_rewards': -189.81024306138414, 'invalid_action_count': 450}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 106.2971376755197
# steps	 1000 	total rewards	 -243.91271843712013
# steps	 1500 	total rewards	 -270.8894452994158
# Finished after 1713 timesteps with total reward -455.2827257352693
# {'coverage_prop': '0.723', 'intensity_prop': '0.355', 'ms1ms2_ratio': '0.202', 'efficiency': '0.208', 'TP': '155', 'FP': '142', 'FN': '114', 'precision': '0.522', 'recall': '0.576', 'f1': '0.548', 'total_rewards': -455.28272573526783, 'invalid_action_count': 677}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 106.77904534307393
# steps	 1000 	total rewards	 219.42847857952998
# steps	 1500 	total rewards	 301.9776000291711
# Finished after 1569 timesteps with total reward 311.6588096458062
# {'coverage_prop': '0.891', 'intensity_prop': '0.513', 'ms1ms2_ratio': '0.380', 'efficiency': '0.339', 'TP': '235', 'FP': '151', 'FN': '47', 'precision': '0.609', 'recall': '0.833', 'f1': '0.704', 'total_rewards': 311.6588096458066, 'invalid_action_count': 17}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 102.84213285365425
# steps	 1000 	total rewards	 215.04128391926884
# steps	 1500 	total rewards	 284.72898613282644
# Finished after 1541 timesteps with total reward 288.26922853073825
# {'coverage_prop': '0.935', 'intensity_prop': '0.548', 'ms1ms2_ratio': '0.424', 'efficiency': '0.334', 'TP': '227', 'FP': '134', 'FN': '25', 'precision': '0.629', 'recall': '0.901', 'f1': '0.741', 'total_rewards': 288.26922853073887, 'invalid_action_count': 25}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 77.86105236532649
# steps	 1000 	total rewards	 169.0727476039141
# steps	 1500 	total rewards	 74.83602401172327
# Finished after 1542 timesteps with total reward 33.836024011723254
# {'coverage_prop': '0.918', 'intensity_prop': '0.532', 'ms1ms2_ratio': '0.423', 'efficiency': '0.208', 'TP': '140', 'FP': '85', 'FN': '20', 'precision': '0.622', 'recall': '0.875', 'f1': '0.727', 'total_rewards': 33.8360240117222, 'invalid_action_count': 191}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 92.0459333012443
# steps	 1000 	total rewards	 71.37306990259425
# steps	 1500 	total rewards	 143.21757765175744
# Finished after 1500 timesteps with total reward 143.21757765175744
# {'coverage_prop': '0.935', 'intensity_prop': '0.528', 'ms1ms2_ratio': '0.500', 'efficiency': '0.244', 'TP': '144', 'FP': '100', 'FN': '17', 'precision': '0.590', 'recall': '0.894', 'f1': '0.711', 'total_rewards': 143.21757765175633, 'invalid_action_count': 104}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 100.57535163098763
# steps	 1000 	total rewards	 123.14706180834966
# steps	 1500 	total rewards	 84.3035712867414
# Finished after 1597 timesteps with total reward 102.8903237072715
# {'coverage_prop': '0.878', 'intensity_prop': '0.499', 'ms1ms2_ratio': '0.338', 'efficiency': '0.321', 'TP': '229', 'FP': '154', 'FN': '53', 'precision': '0.598', 'recall': '0.812', 'f1': '0.689', 'total_rewards': 102.89032370727023, 'invalid_action_count': 198}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 97.85587604814376
# steps	 1000 	total rewards	 -133.55879904961685
# steps	 1500 	total rewards	 -63.07590531537154
# Finished after 1652 timesteps with total reward -204.9996439001379
# {'coverage_prop': '0.759', 'intensity_prop': '0.358', 'ms1ms2_ratio': '0.267', 'efficiency': '0.288', 'TP': '178', 'FP': '197', 'FN': '119', 'precision': '0.475', 'recall': '0.599', 'f1': '0.530', 'total_rewards': -204.9996439001388, 'invalid_action_count': 474}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 84.53168702167152
# steps	 1000 	total rewards	 117.90563051911779
# Finished after 1485 timesteps with total reward 169.0822161910038
# {'coverage_prop': '0.898', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.531', 'efficiency': '0.228', 'TP': '149', 'FP': '72', 'FN': '25', 'precision': '0.674', 'recall': '0.856', 'f1': '0.754', 'total_rewards': 169.08221619100226, 'invalid_action_count': 72}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 91.29289005357035
# steps	 1000 	total rewards	 184.8536606105431
# Finished after 1486 timesteps with total reward 175.82776621372562
# {'coverage_prop': '0.961', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.529', 'efficiency': '0.253', 'TP': '155', 'FP': '91', 'FN': '10', 'precision': '0.630', 'recall': '0.939', 'f1': '0.754', 'total_rewards': 175.82776621372398, 'invalid_action_count': 69}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (265 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 44.99GB > 0.35GB
# steps	 500 	total rewards	 96.54002306589004
# steps	 1000 	total rewards	 186.8158067001125
# steps	 1500 	total rewards	 271.51028636702364
# Finished after 1655 timesteps with total reward 292.409133807237
# {'coverage_prop': '0.853', 'intensity_prop': '0.673', 'ms1ms2_ratio': '0.263', 'efficiency': '0.173', 'TP': '198', 'FP': '28', 'FN': '39', 'precision': '0.876', 'recall': '0.835', 'f1': '0.855', 'total_rewards': 292.40913380723686, 'invalid_action_count': 0}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 87.87507333997303
# steps	 1000 	total rewards	 191.75074181831192
# steps	 1500 	total rewards	 295.8315958771075
# Finished after 1695 timesteps with total reward 334.04853188968815
# {'coverage_prop': '0.875', 'intensity_prop': '0.667', 'ms1ms2_ratio': '0.219', 'efficiency': '0.222', 'TP': '258', 'FP': '50', 'FN': '44', 'precision': '0.838', 'recall': '0.854', 'f1': '0.846', 'total_rewards': 334.0485318896895, 'invalid_action_count': 2}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 101.79664538152191
# steps	 1000 	total rewards	 219.2995475419291
# steps	 1500 	total rewards	 307.3196377342057
# Finished after 1677 timesteps with total reward 340.1569940163698
# {'coverage_prop': '0.867', 'intensity_prop': '0.646', 'ms1ms2_ratio': '0.239', 'efficiency': '0.295', 'TP': '330', 'FP': '69', 'FN': '61', 'precision': '0.827', 'recall': '0.844', 'f1': '0.835', 'total_rewards': 340.15699401637215, 'invalid_action_count': 1}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 96.2155599958113
# steps	 1000 	total rewards	 192.12771760340644
# steps	 1500 	total rewards	 274.75572646527775
# Finished after 1701 timesteps with total reward 313.8697595492855
# {'coverage_prop': '0.871', 'intensity_prop': '0.657', 'ms1ms2_ratio': '0.213', 'efficiency': '0.250', 'TP': '296', 'FP': '54', 'FN': '52', 'precision': '0.846', 'recall': '0.851', 'f1': '0.848', 'total_rewards': 313.86975954928647, 'invalid_action_count': 2}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 98.89452986032346
# steps	 1000 	total rewards	 208.23528975118944
# steps	 1500 	total rewards	 295.08872651231303
# Finished after 1679 timesteps with total reward 328.1183071330953
# {'coverage_prop': '0.818', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.236', 'efficiency': '0.275', 'TP': '305', 'FP': '68', 'FN': '83', 'precision': '0.818', 'recall': '0.786', 'f1': '0.802', 'total_rewards': 328.1183071330957, 'invalid_action_count': 7}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 100.86156948663906
# steps	 1000 	total rewards	 193.09804049170506
# steps	 1500 	total rewards	 277.0490733575377
# Finished after 1666 timesteps with total reward 305.9620139578034
# {'coverage_prop': '0.838', 'intensity_prop': '0.607', 'ms1ms2_ratio': '0.251', 'efficiency': '0.311', 'TP': '329', 'FP': '85', 'FN': '80', 'precision': '0.795', 'recall': '0.804', 'f1': '0.800', 'total_rewards': 305.96201395780366, 'invalid_action_count': 14}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 108.50087643468785
# steps	 1000 	total rewards	 220.8402050173876
# steps	 1500 	total rewards	 321.56114639631903
# Finished after 1711 timesteps with total reward 359.15402350592785
# {'coverage_prop': '0.867', 'intensity_prop': '0.654', 'ms1ms2_ratio': '0.203', 'efficiency': '0.274', 'TP': '323', 'FP': '67', 'FN': '60', 'precision': '0.828', 'recall': '0.843', 'f1': '0.836', 'total_rewards': 359.1540235059294, 'invalid_action_count': 1}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 93.33649192718056
# steps	 1000 	total rewards	 177.91647895587394
# steps	 1500 	total rewards	 256.2746492006262
# Finished after 1628 timesteps with total reward 269.3181405854972
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.296', 'efficiency': '0.155', 'TP': '167', 'FP': '28', 'FN': '33', 'precision': '0.856', 'recall': '0.835', 'f1': '0.846', 'total_rewards': 269.31814058549804, 'invalid_action_count': 0}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 98.71418687559685
# steps	 1000 	total rewards	 199.38596894565694
# steps	 1500 	total rewards	 300.1543309321503
# Finished after 1698 timesteps with total reward 332.746814695522
# {'coverage_prop': '0.876', 'intensity_prop': '0.663', 'ms1ms2_ratio': '0.216', 'efficiency': '0.277', 'TP': '333', 'FP': '54', 'FN': '55', 'precision': '0.860', 'recall': '0.858', 'f1': '0.859', 'total_rewards': 332.7468146955231, 'invalid_action_count': 2}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 106.97671751525318
# steps	 1000 	total rewards	 221.66677371136998
# steps	 1500 	total rewards	 304.05788572149095
# Finished after 1710 timesteps with total reward 339.3036347126128
# {'coverage_prop': '0.887', 'intensity_prop': '0.673', 'ms1ms2_ratio': '0.204', 'efficiency': '0.221', 'TP': '262', 'FP': '52', 'FN': '40', 'precision': '0.834', 'recall': '0.868', 'f1': '0.851', 'total_rewards': 339.303634712614, 'invalid_action_count': 2}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 98.68038905929563
# steps	 1000 	total rewards	 193.59498990544742
# steps	 1500 	total rewards	 304.76066477185475
# Finished after 1694 timesteps with total reward 333.7556836275885
# {'coverage_prop': '0.903', 'intensity_prop': '0.704', 'ms1ms2_ratio': '0.220', 'efficiency': '0.195', 'TP': '237', 'FP': '33', 'FN': '29', 'precision': '0.878', 'recall': '0.891', 'f1': '0.884', 'total_rewards': 333.7556836275897, 'invalid_action_count': 0}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 91.33477926566593
# steps	 1000 	total rewards	 180.51609316676485
# steps	 1500 	total rewards	 257.1131443416689
# Finished after 1670 timesteps with total reward 286.7994650307145
# {'coverage_prop': '0.894', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.246', 'efficiency': '0.176', 'TP': '199', 'FP': '37', 'FN': '28', 'precision': '0.843', 'recall': '0.877', 'f1': '0.860', 'total_rewards': 286.7994650307142, 'invalid_action_count': 5}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 110.63182013207907
# steps	 1000 	total rewards	 203.9349011505978
# steps	 1500 	total rewards	 293.11642741613355
# Finished after 1693 timesteps with total reward 332.80412134448386
# {'coverage_prop': '0.928', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.222', 'efficiency': '0.224', 'TP': '274', 'FP': '37', 'FN': '24', 'precision': '0.881', 'recall': '0.919', 'f1': '0.900', 'total_rewards': 332.804121344485, 'invalid_action_count': 0}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 103.74516592043865
# steps	 1000 	total rewards	 204.58593134753127
# steps	 1500 	total rewards	 283.26440937774856
# Finished after 1692 timesteps with total reward 320.33514572184913
# {'coverage_prop': '0.936', 'intensity_prop': '0.717', 'ms1ms2_ratio': '0.223', 'efficiency': '0.199', 'TP': '234', 'FP': '42', 'FN': '19', 'precision': '0.848', 'recall': '0.925', 'f1': '0.885', 'total_rewards': 320.3351457218498, 'invalid_action_count': 0}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 93.77330562933005
# steps	 1000 	total rewards	 192.49075335822837
# steps	 1500 	total rewards	 284.54197508485447
# Finished after 1685 timesteps with total reward 314.9869965254511
# {'coverage_prop': '0.851', 'intensity_prop': '0.629', 'ms1ms2_ratio': '0.230', 'efficiency': '0.258', 'TP': '285', 'FP': '69', 'FN': '62', 'precision': '0.805', 'recall': '0.821', 'f1': '0.813', 'total_rewards': 314.9869965254512, 'invalid_action_count': 1}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 89.37916646386182
# steps	 1000 	total rewards	 184.85108505909852
# steps	 1500 	total rewards	 265.19746422094266
# Finished after 1660 timesteps with total reward 288.81351399336654
# {'coverage_prop': '0.859', 'intensity_prop': '0.653', 'ms1ms2_ratio': '0.258', 'efficiency': '0.217', 'TP': '247', 'FP': '40', 'FN': '47', 'precision': '0.861', 'recall': '0.840', 'f1': '0.850', 'total_rewards': 288.813513993367, 'invalid_action_count': 2}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 102.198841314669
# steps	 1000 	total rewards	 205.0184535321148
# steps	 1500 	total rewards	 304.0999412926772
# Finished after 1689 timesteps with total reward 337.1183068857007
# {'coverage_prop': '0.905', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.226', 'efficiency': '0.181', 'TP': '220', 'FP': '29', 'FN': '26', 'precision': '0.884', 'recall': '0.894', 'f1': '0.889', 'total_rewards': 337.118306885702, 'invalid_action_count': 0}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 79.00125346730246
# steps	 1000 	total rewards	 172.60418850750102
# steps	 1500 	total rewards	 265.7322912665576
# Finished after 1676 timesteps with total reward 298.39140844035416
# {'coverage_prop': '0.934', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.241', 'efficiency': '0.169', 'TP': '207', 'FP': '21', 'FN': '16', 'precision': '0.908', 'recall': '0.928', 'f1': '0.918', 'total_rewards': 298.3914084403546, 'invalid_action_count': 0}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 96.26385103731712
# steps	 1000 	total rewards	 185.41009896453767
# steps	 1500 	total rewards	 270.81585250734395
# Finished after 1724 timesteps with total reward 302.02746301536394
# {'coverage_prop': '0.911', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.191', 'efficiency': '0.247', 'TP': '310', 'FP': '47', 'FN': '35', 'precision': '0.868', 'recall': '0.899', 'f1': '0.883', 'total_rewards': 302.0274630153637, 'invalid_action_count': 2}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 92.68777944802153
# steps	 1000 	total rewards	 188.5928086519988
# steps	 1500 	total rewards	 288.89573044706515
# Finished after 1693 timesteps with total reward 322.7782883797589
# {'coverage_prop': '0.917', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.222', 'efficiency': '0.192', 'TP': '238', 'FP': '28', 'FN': '24', 'precision': '0.895', 'recall': '0.908', 'f1': '0.902', 'total_rewards': 322.77828837975983, 'invalid_action_count': 0}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 115.49253113619696
# steps	 1000 	total rewards	 212.5128539962655
# steps	 1500 	total rewards	 307.2903857041362
# Finished after 1696 timesteps with total reward 341.3320279102528
# {'coverage_prop': '0.868', 'intensity_prop': '0.634', 'ms1ms2_ratio': '0.219', 'efficiency': '0.275', 'TP': '311', 'FP': '72', 'FN': '58', 'precision': '0.812', 'recall': '0.843', 'f1': '0.827', 'total_rewards': 341.33202791025394, 'invalid_action_count': 7}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 98.17744620800238
# steps	 1000 	total rewards	 191.19774504336704
# steps	 1500 	total rewards	 277.42432320157945
# Finished after 1664 timesteps with total reward 297.95276038516704
# {'coverage_prop': '0.871', 'intensity_prop': '0.642', 'ms1ms2_ratio': '0.253', 'efficiency': '0.270', 'TP': '295', 'FP': '63', 'FN': '53', 'precision': '0.824', 'recall': '0.848', 'f1': '0.836', 'total_rewards': 297.95276038516715, 'invalid_action_count': 9}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 110.79174034962608
# steps	 1000 	total rewards	 222.44564675356284
# steps	 1500 	total rewards	 320.9446625224263
# Finished after 1704 timesteps with total reward 363.527837515099
# {'coverage_prop': '0.903', 'intensity_prop': '0.681', 'ms1ms2_ratio': '0.210', 'efficiency': '0.278', 'TP': '332', 'FP': '59', 'FN': '42', 'precision': '0.849', 'recall': '0.888', 'f1': '0.868', 'total_rewards': 363.5278375151007, 'invalid_action_count': 0}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 103.8299759011968
# steps	 1000 	total rewards	 219.71383113576636
# steps	 1500 	total rewards	 320.09923201685604
# Finished after 1698 timesteps with total reward 353.0193043478799
# {'coverage_prop': '0.909', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.216', 'efficiency': '0.251', 'TP': '303', 'FP': '48', 'FN': '35', 'precision': '0.863', 'recall': '0.896', 'f1': '0.880', 'total_rewards': 353.0193043478821, 'invalid_action_count': 0}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 79.44333073367252
# steps	 1000 	total rewards	 178.1924162098739
# steps	 1500 	total rewards	 252.16396505749992
# Finished after 1677 timesteps with total reward 277.2140193877698
# {'coverage_prop': '0.927', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.239', 'efficiency': '0.168', 'TP': '194', 'FP': '33', 'FN': '18', 'precision': '0.855', 'recall': '0.915', 'f1': '0.884', 'total_rewards': 277.214019387769, 'invalid_action_count': 3}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 93.82090085397462
# steps	 1000 	total rewards	 187.3407656873161
# steps	 1500 	total rewards	 271.5535965770383
# Finished after 1679 timesteps with total reward 293.66751771369445
# {'coverage_prop': '0.900', 'intensity_prop': '0.695', 'ms1ms2_ratio': '0.237', 'efficiency': '0.173', 'TP': '200', 'FP': '35', 'FN': '26', 'precision': '0.851', 'recall': '0.885', 'f1': '0.868', 'total_rewards': 293.6675177136949, 'invalid_action_count': 0}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 94.17015583470359
# steps	 1000 	total rewards	 205.7292409299717
# steps	 1500 	total rewards	 300.92047318496554
# Finished after 1699 timesteps with total reward 340.0979564075167
# {'coverage_prop': '0.867', 'intensity_prop': '0.661', 'ms1ms2_ratio': '0.215', 'efficiency': '0.270', 'TP': '315', 'FP': '63', 'FN': '58', 'precision': '0.833', 'recall': '0.845', 'f1': '0.839', 'total_rewards': 340.09795640751787, 'invalid_action_count': 1}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 97.58914228500794
# steps	 1000 	total rewards	 205.6748779877737
# steps	 1500 	total rewards	 303.7709608031441
# Finished after 1695 timesteps with total reward 333.30014140641276
# {'coverage_prop': '0.818', 'intensity_prop': '0.593', 'ms1ms2_ratio': '0.219', 'efficiency': '0.291', 'TP': '328', 'FP': '76', 'FN': '90', 'precision': '0.812', 'recall': '0.785', 'f1': '0.798', 'total_rewards': 333.30014140641435, 'invalid_action_count': 3}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 96.84383485267051
# steps	 1000 	total rewards	 207.51635302979463
# steps	 1500 	total rewards	 285.08182570155793
# Finished after 1681 timesteps with total reward 314.65841586328327
# {'coverage_prop': '0.898', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.234', 'efficiency': '0.162', 'TP': '201', 'FP': '20', 'FN': '25', 'precision': '0.910', 'recall': '0.889', 'f1': '0.899', 'total_rewards': 314.6584158632843, 'invalid_action_count': 1}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 93.92223815515209
# steps	 1000 	total rewards	 194.68247534954935
# steps	 1500 	total rewards	 273.199541617902
# Finished after 1647 timesteps with total reward 296.42348983978064
# {'coverage_prop': '0.938', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.274', 'efficiency': '0.186', 'TP': '207', 'FP': '33', 'FN': '16', 'precision': '0.863', 'recall': '0.928', 'f1': '0.894', 'total_rewards': 296.4234898397816, 'invalid_action_count': 0}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (265 chemicals)
# steps	 500 	total rewards	 84.40444724971594
# steps	 1000 	total rewards	 179.48884765946482
# steps	 1500 	total rewards	 263.81482212942166
# Finished after 1625 timesteps with total reward 277.53526826451576
# {'coverage_prop': '0.947', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.300', 'efficiency': '0.201', 'TP': '231', 'FP': '20', 'FN': '14', 'precision': '0.920', 'recall': '0.943', 'f1': '0.931', 'total_rewards': 277.535268264516, 'invalid_action_count': 0}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 88.1996547982206
# steps	 1000 	total rewards	 197.067217244932
# steps	 1500 	total rewards	 290.1731526005748
# Finished after 1671 timesteps with total reward 321.0625840462101
# {'coverage_prop': '0.955', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.245', 'efficiency': '0.250', 'TP': '306', 'FP': '30', 'FN': '16', 'precision': '0.911', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 321.0625840462113, 'invalid_action_count': 0}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 96.71854842998286
# steps	 1000 	total rewards	 212.95158754773814
# steps	 1500 	total rewards	 292.39227795450813
# Finished after 1736 timesteps with total reward 333.0572083292425
# {'coverage_prop': '0.920', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.180', 'efficiency': '0.288', 'TP': '375', 'FP': '48', 'FN': '37', 'precision': '0.887', 'recall': '0.910', 'f1': '0.898', 'total_rewards': 333.0572083292442, 'invalid_action_count': 0}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 91.57898509339613
# steps	 1000 	total rewards	 192.59697963653778
# steps	 1500 	total rewards	 272.0186797061748
# Finished after 1696 timesteps with total reward 309.5881072800538
# {'coverage_prop': '0.928', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.218', 'efficiency': '0.268', 'TP': '347', 'FP': '26', 'FN': '29', 'precision': '0.930', 'recall': '0.923', 'f1': '0.927', 'total_rewards': 309.5881072800541, 'invalid_action_count': 0}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 90.31968561369159
# steps	 1000 	total rewards	 195.99016310408678
# steps	 1500 	total rewards	 291.42450128483233
# Finished after 1739 timesteps with total reward 330.2736171632383
# {'coverage_prop': '0.877', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.177', 'efficiency': '0.271', 'TP': '361', 'FP': '39', 'FN': '56', 'precision': '0.902', 'recall': '0.866', 'f1': '0.884', 'total_rewards': 330.2736171632391, 'invalid_action_count': 0}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 97.16402099621615
# steps	 1000 	total rewards	 200.16997365064825
# steps	 1500 	total rewards	 298.9647837761067
# Finished after 1746 timesteps with total reward 337.2728118504457
# {'coverage_prop': '0.887', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.170', 'efficiency': '0.294', 'TP': '397', 'FP': '41', 'FN': '56', 'precision': '0.906', 'recall': '0.876', 'f1': '0.891', 'total_rewards': 337.2728118504469, 'invalid_action_count': 0}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 99.89278579741502
# steps	 1000 	total rewards	 220.41170530885353
# steps	 1500 	total rewards	 322.0388704443162
# Finished after 1713 timesteps with total reward 353.0875898734331
# {'coverage_prop': '0.913', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.201', 'efficiency': '0.288', 'TP': '375', 'FP': '36', 'FN': '39', 'precision': '0.912', 'recall': '0.906', 'f1': '0.909', 'total_rewards': 353.0875898734345, 'invalid_action_count': 0}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 76.58520390710655
# steps	 1000 	total rewards	 162.43875097161686
# steps	 1500 	total rewards	 233.1857722056754
# Finished after 1608 timesteps with total reward 244.72388310671553
# {'coverage_prop': '0.961', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.322', 'efficiency': '0.180', 'TP': '198', 'FP': '21', 'FN': '9', 'precision': '0.904', 'recall': '0.957', 'f1': '0.930', 'total_rewards': 244.72388310671394, 'invalid_action_count': 0}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 99.3336642029553
# steps	 1000 	total rewards	 205.07857703358434
# steps	 1500 	total rewards	 301.9623092488347
# Finished after 1722 timesteps with total reward 337.0159419744165
# {'coverage_prop': '0.930', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.193', 'efficiency': '0.285', 'TP': '378', 'FP': '33', 'FN': '31', 'precision': '0.920', 'recall': '0.924', 'f1': '0.922', 'total_rewards': 337.01594197441744, 'invalid_action_count': 0}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 96.78232613841496
# steps	 1000 	total rewards	 209.01779725780142
# steps	 1500 	total rewards	 291.76030672639837
# Finished after 1688 timesteps with total reward 320.3937546118078
# {'coverage_prop': '0.963', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.228', 'efficiency': '0.248', 'TP': '310', 'FP': '31', 'FN': '13', 'precision': '0.909', 'recall': '0.960', 'f1': '0.934', 'total_rewards': 320.39375461180805, 'invalid_action_count': 0}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 86.1136078003871
# steps	 1000 	total rewards	 186.18480774057738
# steps	 1500 	total rewards	 283.30103530235095
# Finished after 1564 timesteps with total reward 291.30020845226113
# {'coverage_prop': '0.953', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.387', 'efficiency': '0.253', 'TP': '267', 'FP': '18', 'FN': '14', 'precision': '0.937', 'recall': '0.950', 'f1': '0.943', 'total_rewards': 291.3002084522623, 'invalid_action_count': 0}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 81.63713860006267
# steps	 1000 	total rewards	 167.88084964041494
# steps	 1500 	total rewards	 239.1365346214986
# Finished after 1604 timesteps with total reward 255.44896732909967
# {'coverage_prop': '0.951', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.328', 'efficiency': '0.208', 'TP': '233', 'FP': '18', 'FN': '13', 'precision': '0.928', 'recall': '0.947', 'f1': '0.938', 'total_rewards': 255.4489673290987, 'invalid_action_count': 0}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 96.01290693592098
# steps	 1000 	total rewards	 191.45627078393173
# steps	 1500 	total rewards	 278.1474351823415
# Finished after 1630 timesteps with total reward 303.3210629153816
# {'coverage_prop': '0.961', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.294', 'efficiency': '0.256', 'TP': '301', 'FP': '21', 'FN': '13', 'precision': '0.935', 'recall': '0.959', 'f1': '0.947', 'total_rewards': 303.3210629153828, 'invalid_action_count': 0}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 91.1696442264135
# steps	 1000 	total rewards	 184.13230124952418
# steps	 1500 	total rewards	 256.38555013225266
# Finished after 1626 timesteps with total reward 277.619124641094
# {'coverage_prop': '0.969', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.300', 'efficiency': '0.229', 'TP': '262', 'FP': '24', 'FN': '9', 'precision': '0.916', 'recall': '0.967', 'f1': '0.941', 'total_rewards': 277.61912464109366, 'invalid_action_count': 0}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 90.91635304298063
# steps	 1000 	total rewards	 194.11415525395938
# steps	 1500 	total rewards	 289.52731331669395
# Finished after 1699 timesteps with total reward 317.8029188124516
# {'coverage_prop': '0.916', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.215', 'efficiency': '0.273', 'TP': '346', 'FP': '35', 'FN': '35', 'precision': '0.908', 'recall': '0.908', 'f1': '0.908', 'total_rewards': 317.8029188124526, 'invalid_action_count': 0}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 80.95375143308591
# steps	 1000 	total rewards	 178.76449387881803
# steps	 1500 	total rewards	 256.1201763551277
# Finished after 1686 timesteps with total reward 277.1701106120855
# {'coverage_prop': '0.928', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.229', 'efficiency': '0.226', 'TP': '288', 'FP': '22', 'FN': '24', 'precision': '0.929', 'recall': '0.923', 'f1': '0.926', 'total_rewards': 277.1701106120852, 'invalid_action_count': 0}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 86.80098129383305
# steps	 1000 	total rewards	 184.9129168395125
# steps	 1500 	total rewards	 276.7411609230096
# Finished after 1562 timesteps with total reward 284.5676534265299
# {'coverage_prop': '0.953', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.390', 'efficiency': '0.233', 'TP': '239', 'FP': '23', 'FN': '13', 'precision': '0.912', 'recall': '0.948', 'f1': '0.930', 'total_rewards': 284.56765342653034, 'invalid_action_count': 0}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 74.82644749079674
# steps	 1000 	total rewards	 167.72452013141907
# Finished after 1489 timesteps with total reward 254.00050718207336
# {'coverage_prop': '0.963', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.524', 'efficiency': '0.241', 'TP': '214', 'FP': '21', 'FN': '9', 'precision': '0.911', 'recall': '0.960', 'f1': '0.934', 'total_rewards': 254.00050718207208, 'invalid_action_count': 0}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 91.34805876969571
# steps	 1000 	total rewards	 182.96856667922708
# steps	 1500 	total rewards	 271.6582946340628
# Finished after 1706 timesteps with total reward 300.88384469020207
# {'coverage_prop': '0.949', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.209', 'efficiency': '0.264', 'TP': '342', 'FP': '30', 'FN': '20', 'precision': '0.919', 'recall': '0.945', 'f1': '0.932', 'total_rewards': 300.883844690203, 'invalid_action_count': 0}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 86.93792589544941
# steps	 1000 	total rewards	 179.39679225511017
# steps	 1500 	total rewards	 267.4789050572998
# Finished after 1611 timesteps with total reward 282.62310403417865
# {'coverage_prop': '0.969', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.318', 'efficiency': '0.230', 'TP': '256', 'FP': '25', 'FN': '9', 'precision': '0.911', 'recall': '0.966', 'f1': '0.938', 'total_rewards': 282.6231040341785, 'invalid_action_count': 0}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 105.28874244875716
# steps	 1000 	total rewards	 215.15351189721827
# steps	 1500 	total rewards	 312.97032009529
# Finished after 1707 timesteps with total reward 345.0042519785896
# {'coverage_prop': '0.934', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.207', 'efficiency': '0.291', 'TP': '369', 'FP': '43', 'FN': '29', 'precision': '0.896', 'recall': '0.927', 'f1': '0.911', 'total_rewards': 345.0042519785905, 'invalid_action_count': 0}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 102.33840611049465
# steps	 1000 	total rewards	 204.88474529176187
# steps	 1500 	total rewards	 293.1608720357374
# Finished after 1718 timesteps with total reward 325.7397748659379
# {'coverage_prop': '0.939', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.196', 'efficiency': '0.269', 'TP': '353', 'FP': '33', 'FN': '25', 'precision': '0.915', 'recall': '0.934', 'f1': '0.924', 'total_rewards': 325.7397748659385, 'invalid_action_count': 0}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 101.48826163597646
# steps	 1000 	total rewards	 209.1956746156089
# steps	 1500 	total rewards	 306.8960011615297
# Finished after 1718 timesteps with total reward 345.8352582443598
# {'coverage_prop': '0.938', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.196', 'efficiency': '0.283', 'TP': '361', 'FP': '45', 'FN': '27', 'precision': '0.889', 'recall': '0.930', 'f1': '0.909', 'total_rewards': 345.83525824436106, 'invalid_action_count': 0}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 93.18571370870868
# steps	 1000 	total rewards	 210.8194369717836
# steps	 1500 	total rewards	 307.3283599636675
# Finished after 1734 timesteps with total reward 337.8200396844298
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.181', 'efficiency': '0.254', 'TP': '343', 'FP': '30', 'FN': '13', 'precision': '0.920', 'recall': '0.963', 'f1': '0.941', 'total_rewards': 337.82003968443115, 'invalid_action_count': 0}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 80.15669822756136
# steps	 1000 	total rewards	 168.2332497741034
# steps	 1500 	total rewards	 237.0262321725451
# Finished after 1552 timesteps with total reward 243.85197890413824
# {'coverage_prop': '0.955', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.407', 'efficiency': '0.212', 'TP': '212', 'FP': '22', 'FN': '11', 'precision': '0.906', 'recall': '0.951', 'f1': '0.928', 'total_rewards': 243.85197890413733, 'invalid_action_count': 0}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 85.57187157000826
# steps	 1000 	total rewards	 167.05928749204372
# steps	 1500 	total rewards	 242.44642653311686
# Finished after 1620 timesteps with total reward 257.5133590886412
# {'coverage_prop': '0.966', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.306', 'efficiency': '0.203', 'TP': '228', 'FP': '24', 'FN': '9', 'precision': '0.905', 'recall': '0.962', 'f1': '0.933', 'total_rewards': 257.51335908864, 'invalid_action_count': 0}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 93.74601540480725
# steps	 1000 	total rewards	 193.87888707204593
# steps	 1500 	total rewards	 290.09863110026754
# Finished after 1735 timesteps with total reward 333.00877461243283
# {'coverage_prop': '0.922', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.180', 'efficiency': '0.273', 'TP': '365', 'FP': '37', 'FN': '34', 'precision': '0.908', 'recall': '0.915', 'f1': '0.911', 'total_rewards': 333.00877461243334, 'invalid_action_count': 0}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 92.36891149737941
# steps	 1000 	total rewards	 198.73490848891566
# steps	 1500 	total rewards	 301.30781365133134
# Finished after 1738 timesteps with total reward 343.16737862295963
# {'coverage_prop': '0.891', 'intensity_prop': '0.692', 'ms1ms2_ratio': '0.178', 'efficiency': '0.298', 'TP': '392', 'FP': '48', 'FN': '54', 'precision': '0.891', 'recall': '0.879', 'f1': '0.885', 'total_rewards': 343.1673786229596, 'invalid_action_count': 0}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 85.15667369927628
# steps	 1000 	total rewards	 182.35165620514655
# steps	 1500 	total rewards	 256.8632808782286
# Finished after 1541 timesteps with total reward 262.3531949979997
# {'coverage_prop': '0.943', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.426', 'efficiency': '0.215', 'TP': '218', 'FP': '14', 'FN': '14', 'precision': '0.940', 'recall': '0.940', 'f1': '0.940', 'total_rewards': 262.353194997999, 'invalid_action_count': 0}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 83.65060696704832
# steps	 1000 	total rewards	 180.73120423017988
# steps	 1500 	total rewards	 249.5326959592678
# Finished after 1528 timesteps with total reward 252.1871761546833
# {'coverage_prop': '0.973', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.447', 'efficiency': '0.236', 'TP': '226', 'FP': '23', 'FN': '7', 'precision': '0.908', 'recall': '0.970', 'f1': '0.938', 'total_rewards': 252.18717615468177, 'invalid_action_count': 0}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc25519aa30>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc256607280>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc23060b520>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.201200737,
#   'beta': 0.526891524}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.342', 'efficiency': '0.214', 'TP': '235', 'FP': '19', 'FN': '11', 'precision': '0.925', 'recall': '0.955', 'f1': '0.940'}
#
# Episode 1 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.284', 'efficiency': '0.265', 'TP': '306', 'FP': '32', 'FN': '14', 'precision': '0.905', 'recall': '0.956', 'f1': '0.930'}
#
# Episode 2 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.212', 'efficiency': '0.313', 'TP': '400', 'FP': '39', 'FN': '21', 'precision': '0.911', 'recall': '0.950', 'f1': '0.930'}
#
# Episode 3 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.240', 'efficiency': '0.287', 'TP': '359', 'FP': '29', 'FN': '14', 'precision': '0.925', 'recall': '0.962', 'f1': '0.943'}
#
# Episode 4 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.199', 'efficiency': '0.303', 'TP': '396', 'FP': '37', 'FN': '23', 'precision': '0.915', 'recall': '0.945', 'f1': '0.930'}
#
# Episode 5 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.193', 'efficiency': '0.320', 'TP': '421', 'FP': '40', 'FN': '33', 'precision': '0.913', 'recall': '0.927', 'f1': '0.920'}
#
# Episode 6 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.226', 'efficiency': '0.307', 'TP': '395', 'FP': '28', 'FN': '27', 'precision': '0.934', 'recall': '0.936', 'f1': '0.935'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.376', 'efficiency': '0.192', 'TP': '198', 'FP': '21', 'FN': '9', 'precision': '0.904', 'recall': '0.957', 'f1': '0.930'}
#
# Episode 8 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.223', 'efficiency': '0.304', 'TP': '386', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.948', 'f1': '0.932'}
#
# Episode 9 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.266', 'efficiency': '0.265', 'TP': '315', 'FP': '31', 'FN': '8', 'precision': '0.910', 'recall': '0.975', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.424', 'efficiency': '0.267', 'TP': '273', 'FP': '16', 'FN': '10', 'precision': '0.945', 'recall': '0.965', 'f1': '0.955'}
#
# Episode 11 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.364', 'efficiency': '0.221', 'TP': '238', 'FP': '18', 'FN': '8', 'precision': '0.930', 'recall': '0.967', 'f1': '0.948'}
#
# Episode 12 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.335', 'efficiency': '0.271', 'TP': '306', 'FP': '19', 'FN': '10', 'precision': '0.942', 'recall': '0.968', 'f1': '0.955'}
#
# Episode 13 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.332', 'efficiency': '0.241', 'TP': '268', 'FP': '22', 'FN': '5', 'precision': '0.924', 'recall': '0.982', 'f1': '0.952'}
#
# Episode 14 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.232', 'efficiency': '0.294', 'TP': '372', 'FP': '29', 'FN': '15', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}
#
# Episode 15 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.258', 'efficiency': '0.243', 'TP': '299', 'FP': '22', 'FN': '13', 'precision': '0.931', 'recall': '0.958', 'f1': '0.945'}
#
# Episode 16 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.433', 'efficiency': '0.247', 'TP': '247', 'FP': '18', 'FN': '10', 'precision': '0.932', 'recall': '0.961', 'f1': '0.946'}
#
# Episode 17 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.592', 'efficiency': '0.257', 'TP': '215', 'FP': '20', 'FN': '9', 'precision': '0.915', 'recall': '0.960', 'f1': '0.937'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.246', 'efficiency': '0.283', 'TP': '351', 'FP': '28', 'FN': '13', 'precision': '0.926', 'recall': '0.964', 'f1': '0.945'}
#
# Episode 19 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.367', 'efficiency': '0.244', 'TP': '258', 'FP': '23', 'FN': '9', 'precision': '0.918', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 20 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.235', 'efficiency': '0.313', 'TP': '378', 'FP': '48', 'FN': '15', 'precision': '0.887', 'recall': '0.962', 'f1': '0.923'}
#
# Episode 21 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.217', 'efficiency': '0.283', 'TP': '362', 'FP': '32', 'FN': '17', 'precision': '0.919', 'recall': '0.955', 'f1': '0.937'}
#
# Episode 22 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.226', 'efficiency': '0.302', 'TP': '382', 'FP': '34', 'FN': '17', 'precision': '0.918', 'recall': '0.957', 'f1': '0.937'}
#
# Episode 23 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.204', 'efficiency': '0.266', 'TP': '347', 'FP': '31', 'FN': '8', 'precision': '0.918', 'recall': '0.977', 'f1': '0.947'}
#
# Episode 24 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.456', 'efficiency': '0.227', 'TP': '215', 'FP': '22', 'FN': '8', 'precision': '0.907', 'recall': '0.964', 'f1': '0.935'}
#
# Episode 25 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.353', 'efficiency': '0.215', 'TP': '228', 'FP': '24', 'FN': '9', 'precision': '0.905', 'recall': '0.962', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '385', 'FP': '34', 'FN': '17', 'precision': '0.919', 'recall': '0.958', 'f1': '0.938'}
#
# Episode 27 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.192', 'efficiency': '0.322', 'TP': '421', 'FP': '44', 'FN': '29', 'precision': '0.905', 'recall': '0.936', 'f1': '0.920'}
#
# Episode 28 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.492', 'efficiency': '0.230', 'TP': '215', 'FP': '17', 'FN': '14', 'precision': '0.927', 'recall': '0.939', 'f1': '0.933'}
#
# Episode 29 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.496', 'efficiency': '0.250', 'TP': '227', 'FP': '24', 'FN': '5', 'precision': '0.904', 'recall': '0.978', 'f1': '0.940'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.538', 'ms1ms2_ratio': '1.349', 'efficiency': '0.466', 'TP': '143', 'FP': '109', 'FN': '13', 'precision': '0.567', 'recall': '0.917', 'f1': '0.701'}
#
# Episode 1 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.540', 'ms1ms2_ratio': '1.118', 'efficiency': '0.540', 'TP': '195', 'FP': '139', 'FN': '18', 'precision': '0.584', 'recall': '0.915', 'f1': '0.713'}
#
# Episode 2 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.749', 'efficiency': '0.552', 'TP': '269', 'FP': '173', 'FN': '18', 'precision': '0.609', 'recall': '0.937', 'f1': '0.738'}
#
# Episode 3 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.541', 'ms1ms2_ratio': '0.876', 'efficiency': '0.532', 'TP': '228', 'FP': '159', 'FN': '15', 'precision': '0.589', 'recall': '0.938', 'f1': '0.724'}
#
# Episode 4 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.663', 'efficiency': '0.506', 'TP': '290', 'FP': '145', 'FN': '21', 'precision': '0.667', 'recall': '0.932', 'f1': '0.777'}
#
# Episode 5 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.657', 'efficiency': '0.543', 'TP': '300', 'FP': '169', 'FN': '25', 'precision': '0.640', 'recall': '0.923', 'f1': '0.756'}
#
# Episode 6 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.788', 'efficiency': '0.550', 'TP': '263', 'FP': '164', 'FN': '23', 'precision': '0.616', 'recall': '0.920', 'f1': '0.738'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.580', 'efficiency': '0.453', 'TP': '122', 'FP': '96', 'FN': '10', 'precision': '0.560', 'recall': '0.924', 'f1': '0.697'}
#
# Episode 8 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.832', 'efficiency': '0.565', 'TP': '267', 'FP': '157', 'FN': '18', 'precision': '0.630', 'recall': '0.937', 'f1': '0.753'}
#
# Episode 9 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.547', 'ms1ms2_ratio': '1.051', 'efficiency': '0.535', 'TP': '202', 'FP': '143', 'FN': '9', 'precision': '0.586', 'recall': '0.957', 'f1': '0.727'}
#
# Episode 10 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.495', 'ms1ms2_ratio': '1.549', 'efficiency': '0.582', 'TP': '154', 'FP': '130', 'FN': '15', 'precision': '0.542', 'recall': '0.911', 'f1': '0.680'}
#
# Episode 11 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.561', 'ms1ms2_ratio': '1.366', 'efficiency': '0.474', 'TP': '158', 'FP': '96', 'FN': '10', 'precision': '0.622', 'recall': '0.940', 'f1': '0.749'}
#
# Episode 12 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.236', 'efficiency': '0.559', 'TP': '192', 'FP': '130', 'FN': '13', 'precision': '0.596', 'recall': '0.937', 'f1': '0.729'}
#
# Episode 13 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.305', 'efficiency': '0.520', 'TP': '167', 'FP': '121', 'FN': '7', 'precision': '0.580', 'recall': '0.960', 'f1': '0.723'}
#
# Episode 14 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.570', 'ms1ms2_ratio': '0.823', 'efficiency': '0.538', 'TP': '255', 'FP': '152', 'FN': '9', 'precision': '0.627', 'recall': '0.966', 'f1': '0.760'}
#
# Episode 15 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.564', 'ms1ms2_ratio': '1.029', 'efficiency': '0.486', 'TP': '205', 'FP': '113', 'FN': '16', 'precision': '0.645', 'recall': '0.928', 'f1': '0.761'}
#
# Episode 16 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.540', 'ms1ms2_ratio': '1.533', 'efficiency': '0.539', 'TP': '149', 'FP': '116', 'FN': '10', 'precision': '0.562', 'recall': '0.937', 'f1': '0.703'}
#
# Episode 17 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.504', 'ms1ms2_ratio': '2.112', 'efficiency': '0.606', 'TP': '121', 'FP': '111', 'FN': '12', 'precision': '0.522', 'recall': '0.910', 'f1': '0.663'}
#
# Episode 18 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.993', 'efficiency': '0.560', 'TP': '224', 'FP': '151', 'FN': '17', 'precision': '0.597', 'recall': '0.929', 'f1': '0.727'}
#
# Episode 19 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.504', 'ms1ms2_ratio': '1.481', 'efficiency': '0.549', 'TP': '155', 'FP': '122', 'FN': '13', 'precision': '0.560', 'recall': '0.923', 'f1': '0.697'}
#
# Episode 20 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.539', 'ms1ms2_ratio': '0.818', 'efficiency': '0.561', 'TP': '247', 'FP': '179', 'FN': '15', 'precision': '0.580', 'recall': '0.943', 'f1': '0.718'}
#
# Episode 21 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.538', 'ms1ms2_ratio': '0.907', 'efficiency': '0.551', 'TP': '237', 'FP': '155', 'FN': '19', 'precision': '0.605', 'recall': '0.926', 'f1': '0.731'}
#
# Episode 22 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.836', 'efficiency': '0.555', 'TP': '239', 'FP': '177', 'FN': '17', 'precision': '0.575', 'recall': '0.934', 'f1': '0.711'}
#
# Episode 23 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.865', 'efficiency': '0.516', 'TP': '228', 'FP': '150', 'FN': '8', 'precision': '0.603', 'recall': '0.966', 'f1': '0.743'}
#
# Episode 24 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.510', 'ms1ms2_ratio': '1.670', 'efficiency': '0.510', 'TP': '119', 'FP': '116', 'FN': '10', 'precision': '0.506', 'recall': '0.922', 'f1': '0.654'}
#
# Episode 25 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.482', 'ms1ms2_ratio': '1.508', 'efficiency': '0.496', 'TP': '118', 'FP': '129', 'FN': '14', 'precision': '0.478', 'recall': '0.894', 'f1': '0.623'}
#
# Episode 26 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.769', 'efficiency': '0.532', 'TP': '256', 'FP': '163', 'FN': '17', 'precision': '0.611', 'recall': '0.938', 'f1': '0.740'}
#
# Episode 27 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.563', 'ms1ms2_ratio': '0.644', 'efficiency': '0.540', 'TP': '305', 'FP': '167', 'FN': '22', 'precision': '0.646', 'recall': '0.933', 'f1': '0.763'}
#
# Episode 28 finished
# {'coverage_prop': '0.927', 'intensity_prop': '0.494', 'ms1ms2_ratio': '1.811', 'efficiency': '0.527', 'TP': '121', 'FP': '107', 'FN': '18', 'precision': '0.531', 'recall': '0.871', 'f1': '0.659'}
#
# Episode 29 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.517', 'ms1ms2_ratio': '1.709', 'efficiency': '0.547', 'TP': '134', 'FP': '114', 'FN': '8', 'precision': '0.540', 'recall': '0.944', 'f1': '0.687'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.215', 'efficiency': '0.181', 'TP': '235', 'FP': '18', 'FN': '12', 'precision': '0.929', 'recall': '0.951', 'f1': '0.940'}
#
# Episode 1 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.189', 'efficiency': '0.236', 'TP': '313', 'FP': '29', 'FN': '10', 'precision': '0.915', 'recall': '0.969', 'f1': '0.941'}
#
# Episode 2 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.155', 'efficiency': '0.292', 'TP': '406', 'FP': '39', 'FN': '15', 'precision': '0.912', 'recall': '0.964', 'f1': '0.938'}
#
# Episode 3 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.176', 'efficiency': '0.261', 'TP': '363', 'FP': '24', 'FN': '15', 'precision': '0.938', 'recall': '0.960', 'f1': '0.949'}
#
# Episode 4 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.145', 'efficiency': '0.279', 'TP': '395', 'FP': '37', 'FN': '24', 'precision': '0.914', 'recall': '0.943', 'f1': '0.928'}
#
# Episode 5 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.145', 'efficiency': '0.302', 'TP': '425', 'FP': '43', 'FN': '26', 'precision': '0.908', 'recall': '0.942', 'f1': '0.925'}
#
# Episode 6 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.161', 'efficiency': '0.282', 'TP': '389', 'FP': '37', 'FN': '24', 'precision': '0.913', 'recall': '0.942', 'f1': '0.927'}
#
# Episode 7 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.205', 'efficiency': '0.156', 'TP': '197', 'FP': '24', 'FN': '7', 'precision': '0.891', 'recall': '0.966', 'f1': '0.927'}
#
# Episode 8 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.161', 'efficiency': '0.282', 'TP': '395', 'FP': '32', 'FN': '15', 'precision': '0.925', 'recall': '0.963', 'f1': '0.944'}
#
# Episode 9 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.184', 'efficiency': '0.237', 'TP': '320', 'FP': '27', 'FN': '7', 'precision': '0.922', 'recall': '0.979', 'f1': '0.950'}
#
# Episode 10 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.252', 'efficiency': '0.216', 'TP': '271', 'FP': '17', 'FN': '11', 'precision': '0.941', 'recall': '0.961', 'f1': '0.951'}
#
# Episode 11 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.251', 'efficiency': '0.192', 'TP': '241', 'FP': '15', 'FN': '8', 'precision': '0.941', 'recall': '0.968', 'f1': '0.954'}
#
# Episode 12 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.205', 'efficiency': '0.229', 'TP': '307', 'FP': '18', 'FN': '10', 'precision': '0.945', 'recall': '0.968', 'f1': '0.956'}
#
# Episode 13 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.214', 'efficiency': '0.206', 'TP': '267', 'FP': '21', 'FN': '7', 'precision': '0.927', 'recall': '0.974', 'f1': '0.950'}
#
# Episode 14 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.168', 'efficiency': '0.270', 'TP': '380', 'FP': '24', 'FN': '12', 'precision': '0.941', 'recall': '0.969', 'f1': '0.955'}
#
# Episode 15 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.174', 'efficiency': '0.216', 'TP': '296', 'FP': '24', 'FN': '14', 'precision': '0.925', 'recall': '0.955', 'f1': '0.940'}
#
# Episode 16 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.797', 'ms1ms2_ratio': '0.263', 'efficiency': '0.202', 'TP': '252', 'FP': '13', 'FN': '10', 'precision': '0.951', 'recall': '0.962', 'f1': '0.956'}
#
# Episode 17 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.335', 'efficiency': '0.198', 'TP': '222', 'FP': '15', 'FN': '7', 'precision': '0.937', 'recall': '0.969', 'f1': '0.953'}
#
# Episode 18 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.161', 'efficiency': '0.251', 'TP': '350', 'FP': '30', 'FN': '12', 'precision': '0.921', 'recall': '0.967', 'f1': '0.943'}
#
# Episode 19 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.223', 'efficiency': '0.204', 'TP': '257', 'FP': '25', 'FN': '8', 'precision': '0.911', 'recall': '0.970', 'f1': '0.940'}
#
# Episode 20 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.168', 'efficiency': '0.286', 'TP': '387', 'FP': '41', 'FN': '13', 'precision': '0.904', 'recall': '0.968', 'f1': '0.935'}
#
# Episode 21 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.160', 'efficiency': '0.261', 'TP': '364', 'FP': '32', 'FN': '15', 'precision': '0.919', 'recall': '0.960', 'f1': '0.939'}
#
# Episode 22 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.154', 'efficiency': '0.273', 'TP': '382', 'FP': '35', 'FN': '16', 'precision': '0.916', 'recall': '0.960', 'f1': '0.937'}
#
# Episode 23 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.153', 'efficiency': '0.247', 'TP': '353', 'FP': '25', 'FN': '8', 'precision': '0.934', 'recall': '0.978', 'f1': '0.955'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.266', 'efficiency': '0.181', 'TP': '217', 'FP': '19', 'FN': '9', 'precision': '0.919', 'recall': '0.960', 'f1': '0.939'}
#
# Episode 25 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.198', 'efficiency': '0.175', 'TP': '226', 'FP': '24', 'FN': '11', 'precision': '0.904', 'recall': '0.954', 'f1': '0.928'}
#
# Episode 26 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.158', 'efficiency': '0.278', 'TP': '390', 'FP': '32', 'FN': '14', 'precision': '0.924', 'recall': '0.965', 'f1': '0.944'}
#
# Episode 27 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.152', 'efficiency': '0.306', 'TP': '424', 'FP': '46', 'FN': '24', 'precision': '0.902', 'recall': '0.946', 'f1': '0.924'}
#
# Episode 28 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.292', 'efficiency': '0.184', 'TP': '221', 'FP': '11', 'FN': '14', 'precision': '0.953', 'recall': '0.940', 'f1': '0.946'}
#
# Episode 29 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.305', 'efficiency': '0.201', 'TP': '229', 'FP': '21', 'FN': '6', 'precision': '0.916', 'recall': '0.974', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1404.656776                1453.0          0.679           0.230
# 1  random   -1285.853471                1350.0          0.679           0.205
# 2  random   -1024.568522                1112.0          0.746           0.275
# 3  random   -1526.668195                1570.0          0.525           0.122
# 4  random   -1147.742585                1232.0          0.748           0.265
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.004       0.091      0.322   0.406  0.359
# 1          0.006       0.121      0.289   0.379  0.328
# 2          0.006       0.173      0.370   0.520  0.433
# 3          0.004       0.106      0.209   0.187  0.197
# 4          0.005       0.172      0.355   0.513  0.419

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E6.p')

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E6.p')

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    PPO     243.927990                  12.0          0.943           0.558
# 31    PPO     265.374789                  35.0          0.918           0.555
# 32    PPO     334.925301                   6.0          0.909           0.554
# 33    PPO     216.129285                  74.0          0.903           0.510
# 34    PPO    -175.526373                 437.0          0.765           0.407
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.492       0.248      0.624   0.912  0.741
# 31          0.428       0.300      0.647   0.878  0.745
# 32          0.396       0.375      0.660   0.868  0.750
# 33          0.409       0.330      0.614   0.851  0.714
# 34          0.253       0.263      0.573   0.651  0.610

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
