# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.00
env_beta = 0.00
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-04-01 13:38:38.349 | INFO     | vimms_gym.experiments:get_samplers:298 - Loaded /notebooks/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f6caec5ad90>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f6ca52b00a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f6ca52cc340>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.0,
#    'beta': 0.0}},
#  30)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 30

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_2.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f6caec5ad90>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f6ca52b00a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f6ca52cc340>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f6caec5ad90>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f6ca52b00a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f6ca52cc340>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
horizon = 1
out_dir = 'evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 331.28613847340284
# steps	 1000 	total rewards	 685.8945096826276
# steps	 1500 	total rewards	 1063.9775991180595
# Finished after 1788 timesteps (5.443183898925781 seconds) with total reward 1269.0019872151556
# {'coverage_prop': '0.932', 'intensity_prop': '0.687', 'ms1ms2_ratio': '0.135', 'efficiency': '0.252', 'TP': '341', 'FP': '56', 'FN': '29', 'precision': '0.859', 'recall': '0.922', 'f1': '0.889', 'total_rewards': 1269.001987215154, 'invalid_action_count': 0, 'num_ms1_scans': 212, 'num_ms2_scans': 1576}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 309.7535753704316
# steps	 1000 	total rewards	 659.9947304154039
# steps	 1500 	total rewards	 1010.2637975757946
# Finished after 1705 timesteps (4.391655921936035 seconds) with total reward 1170.4172897337087
# {'coverage_prop': '0.939', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.209', 'efficiency': '0.174', 'TP': '226', 'FP': '20', 'FN': '16', 'precision': '0.919', 'recall': '0.934', 'f1': '0.926', 'total_rewards': 1170.4172897337103, 'invalid_action_count': 0, 'num_ms1_scans': 295, 'num_ms2_scans': 1410}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 316.7547244164447
# steps	 1000 	total rewards	 692.3435404347933
# steps	 1500 	total rewards	 1077.9819822626173
# Finished after 1771 timesteps (6.429280996322632 seconds) with total reward 1286.3410887159469
# {'coverage_prop': '0.944', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.149', 'efficiency': '0.241', 'TP': '314', 'FP': '58', 'FN': '22', 'precision': '0.844', 'recall': '0.935', 'f1': '0.887', 'total_rewards': 1286.3410887159469, 'invalid_action_count': 0, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 331.46467085120946
# steps	 1000 	total rewards	 688.0666315276849
# steps	 1500 	total rewards	 1045.722314575582
# Finished after 1784 timesteps (4.651594877243042 seconds) with total reward 1253.4454600672957
# {'coverage_prop': '0.942', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.138', 'efficiency': '0.272', 'TP': '372', 'FP': '54', 'FN': '26', 'precision': '0.873', 'recall': '0.935', 'f1': '0.903', 'total_rewards': 1253.445460067296, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1567}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 300.3622726306004
# steps	 1000 	total rewards	 661.4779474786874
# steps	 1500 	total rewards	 1002.4975267012356
# Finished after 1775 timesteps (4.795620679855347 seconds) with total reward 1184.8771616270092
# {'coverage_prop': '0.950', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.145', 'efficiency': '0.268', 'TP': '350', 'FP': '65', 'FN': '22', 'precision': '0.843', 'recall': '0.941', 'f1': '0.889', 'total_rewards': 1184.8771616270096, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 290.7293719860502
# steps	 1000 	total rewards	 629.4073016444255
# steps	 1500 	total rewards	 974.0323513643918
# Finished after 1636 timesteps (4.788104772567749 seconds) with total reward 1055.8916956910848
# {'coverage_prop': '0.955', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.286', 'efficiency': '0.150', 'TP': '182', 'FP': '9', 'FN': '9', 'precision': '0.953', 'recall': '0.953', 'f1': '0.953', 'total_rewards': 1055.8916956910855, 'invalid_action_count': 0, 'num_ms1_scans': 364, 'num_ms2_scans': 1272}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 317.281390086673
# steps	 1000 	total rewards	 684.8501305661165
# steps	 1500 	total rewards	 1049.6857650351137
# Finished after 1787 timesteps (5.148195028305054 seconds) with total reward 1234.7402492310873
# {'coverage_prop': '0.910', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.135', 'efficiency': '0.276', 'TP': '359', 'FP': '76', 'FN': '43', 'precision': '0.825', 'recall': '0.893', 'f1': '0.858', 'total_rewards': 1234.7402492310887, 'invalid_action_count': 0, 'num_ms1_scans': 213, 'num_ms2_scans': 1574}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 253.4954363274829
# steps	 1000 	total rewards	 614.8938055135794
# steps	 1500 	total rewards	 968.981045955252
# Finished after 1651 timesteps (4.9961137771606445 seconds) with total reward 1072.2130380003405
# {'coverage_prop': '0.946', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.268', 'efficiency': '0.148', 'TP': '183', 'FP': '10', 'FN': '11', 'precision': '0.948', 'recall': '0.943', 'f1': '0.946', 'total_rewards': 1072.2130380003396, 'invalid_action_count': 0, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 342.70548675041346
# steps	 1500 	total rewards	 1068.227729296312
# Finished after 1807 timesteps (5.358434677124023 seconds) with total reward 1287.8248678858681
# {'coverage_prop': '0.935', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.216', 'efficiency': '0.208', 'TP': '252', 'FP': '38', 'FN': '20', 'precision': '0.869', 'recall': '0.926', 'f1': '0.897', 'total_rewards': 1168.0687658708416, 'invalid_action_count': 0, 'num_ms1_scans': 302, 'num_ms2_scans': 1396}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 300.5864311200316
# steps	 1000 	total rewards	 680.3286711620358
# steps	 1500 	total rewards	 1043.7312875971706
# Finished after 1753 timesteps (4.842843294143677 seconds) with total reward 1244.009327289085
# {'coverage_prop': '0.971', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.164', 'efficiency': '0.222', 'TP': '293', 'FP': '42', 'FN': '10', 'precision': '0.875', 'recall': '0.967', 'f1': '0.918', 'total_rewards': 1244.0093272890838, 'invalid_action_count': 0, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 327.9533998753657
# steps	 1000 	total rewards	 688.5437084143068
# steps	 1500 	total rewards	 1078.012522063461
# Finished after 1773 timesteps (5.086765289306641 seconds) with total reward 1276.3443174101233
# {'coverage_prop': '0.947', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.147', 'efficiency': '0.243', 'TP': '330', 'FP': '45', 'FN': '21', 'precision': '0.880', 'recall': '0.940', 'f1': '0.909', 'total_rewards': 1276.3443174101224, 'invalid_action_count': 0, 'num_ms1_scans': 227, 'num_ms2_scans': 1546}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 269.207521727771
# steps	 1000 	total rewards	 638.9228094039811
# steps	 1500 	total rewards	 990.6907779365519
# Finished after 1662 timesteps (4.83465051651001 seconds) with total reward 1099.7644649496797
# {'coverage_prop': '0.961', 'intensity_prop': '0.812', 'ms1ms2_ratio': '0.255', 'efficiency': '0.147', 'TP': '188', 'FP': '7', 'FN': '8', 'precision': '0.964', 'recall': '0.959', 'f1': '0.962', 'total_rewards': 1099.7644649496801, 'invalid_action_count': 0, 'num_ms1_scans': 338, 'num_ms2_scans': 1324}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 295.34136380788163
# steps	 1000 	total rewards	 653.2110772134694
# steps	 1500 	total rewards	 1018.1872491375846
# Finished after 1706 timesteps (2.725031614303589 seconds) with total reward 1173.6688582980075
# {'coverage_prop': '0.957', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.208', 'efficiency': '0.191', 'TP': '243', 'FP': '26', 'FN': '12', 'precision': '0.903', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 1173.6688582980084, 'invalid_action_count': 0, 'num_ms1_scans': 294, 'num_ms2_scans': 1412}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 316.8890182137161
# steps	 1000 	total rewards	 666.2413283036191
# steps	 1500 	total rewards	 1051.8890546342386
# Finished after 1808 timesteps (4.172486066818237 seconds) with total reward 1278.3846371077425
# {'coverage_prop': '0.907', 'intensity_prop': '0.654', 'ms1ms2_ratio': '0.119', 'efficiency': '0.277', 'TP': '367', 'FP': '80', 'FN': '46', 'precision': '0.821', 'recall': '0.889', 'f1': '0.853', 'total_rewards': 1278.3846371077423, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1616}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 285.1426882209154
# steps	 1000 	total rewards	 663.6798281005804
# steps	 1500 	total rewards	 1036.1561926310114
# Finished after 1742 timesteps (5.376051902770996 seconds) with total reward 1208.060859982114
# {'coverage_prop': '0.961', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.174', 'efficiency': '0.197', 'TP': '263', 'FP': '29', 'FN': '12', 'precision': '0.901', 'recall': '0.956', 'f1': '0.928', 'total_rewards': 1208.0608599821123, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 1484}
#
# method = PPO max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 358.06142377123984
# steps	 1000 	total rewards	 730.6905997115259
# steps	 1500 	total rewards	 1119.4651900293131
# Finished after 1861 timesteps (9.03839898109436 seconds) with total reward 1389.0030822429542
# {'coverage_prop': '0.946', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.081', 'efficiency': '0.234', 'TP': '352', 'FP': '51', 'FN': '23', 'precision': '0.873', 'recall': '0.939', 'f1': '0.905', 'total_rewards': 1389.0030822429558, 'invalid_action_count': 0, 'num_ms1_scans': 139, 'num_ms2_scans': 1722}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 342.78784510663195
# steps	 1000 	total rewards	 724.6402123353048
# steps	 1500 	total rewards	 1099.3236046956063
# Finished after 1802 timesteps (7.363485813140869 seconds) with total reward 1335.7123788299623
# {'coverage_prop': '0.954', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.123', 'efficiency': '0.156', 'TP': '235', 'FP': '15', 'FN': '12', 'precision': '0.940', 'recall': '0.951', 'f1': '0.946', 'total_rewards': 1335.7123788299616, 'invalid_action_count': 0, 'num_ms1_scans': 198, 'num_ms2_scans': 1604}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 351.53782276910397
# steps	 1000 	total rewards	 740.1310582840078
# steps	 1500 	total rewards	 1139.7076623271269
# Finished after 1842 timesteps (7.665389537811279 seconds) with total reward 1415.8902484684088
# {'coverage_prop': '0.959', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.094', 'efficiency': '0.224', 'TP': '330', 'FP': '48', 'FN': '16', 'precision': '0.873', 'recall': '0.954', 'f1': '0.912', 'total_rewards': 1415.8902484684106, 'invalid_action_count': 0, 'num_ms1_scans': 158, 'num_ms2_scans': 1684}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 351.5886646265753
# steps	 1000 	total rewards	 729.2101701585988
# steps	 1500 	total rewards	 1101.382597096293
# Finished after 1859 timesteps (11.274165868759155 seconds) with total reward 1371.334778945802
# {'coverage_prop': '0.947', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.083', 'efficiency': '0.249', 'TP': '381', 'FP': '47', 'FN': '24', 'precision': '0.890', 'recall': '0.941', 'f1': '0.915', 'total_rewards': 1371.3347789458012, 'invalid_action_count': 0, 'num_ms1_scans': 142, 'num_ms2_scans': 1717}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 329.9457679140987
# steps	 1000 	total rewards	 705.5554816243902
# steps	 1500 	total rewards	 1059.5077313523643
# Finished after 1852 timesteps (9.762218952178955 seconds) with total reward 1304.715557713504
# {'coverage_prop': '0.966', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.087', 'efficiency': '0.248', 'TP': '365', 'FP': '57', 'FN': '15', 'precision': '0.865', 'recall': '0.961', 'f1': '0.910', 'total_rewards': 1304.7155577135054, 'invalid_action_count': 0, 'num_ms1_scans': 148, 'num_ms2_scans': 1704}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 339.4401270508008
# steps	 1000 	total rewards	 703.313859955804
# steps	 1500 	total rewards	 1088.1578835997188
# Finished after 1759 timesteps (7.118573188781738 seconds) with total reward 1266.6710714117803
# {'coverage_prop': '0.955', 'intensity_prop': '0.826', 'ms1ms2_ratio': '0.159', 'efficiency': '0.126', 'TP': '183', 'FP': '8', 'FN': '9', 'precision': '0.958', 'recall': '0.953', 'f1': '0.956', 'total_rewards': 1266.6710714117808, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 343.22304527765516
# steps	 1000 	total rewards	 720.9297927795192
# steps	 1500 	total rewards	 1098.97539781296
# Finished after 1861 timesteps (8.858372449874878 seconds) with total reward 1348.9285043654272
# {'coverage_prop': '0.929', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.081', 'efficiency': '0.258', 'TP': '381', 'FP': '63', 'FN': '34', 'precision': '0.858', 'recall': '0.918', 'f1': '0.887', 'total_rewards': 1348.928504365425, 'invalid_action_count': 0, 'num_ms1_scans': 139, 'num_ms2_scans': 1722}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 303.6119844072808
# steps	 1000 	total rewards	 680.4890384743003
# steps	 1500 	total rewards	 1070.8779068444169
# Finished after 1769 timesteps (6.981291055679321 seconds) with total reward 1268.71644838994
# {'coverage_prop': '0.946', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.150', 'efficiency': '0.125', 'TP': '185', 'FP': '8', 'FN': '11', 'precision': '0.959', 'recall': '0.944', 'f1': '0.951', 'total_rewards': 1268.7164483899394, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 361.51683604173274
# steps	 1000 	total rewards	 740.4973678584284
# steps	 1500 	total rewards	 1118.5085307786223
# Finished after 1871 timesteps (11.349493026733398 seconds) with total reward 1395.4292366522436
# {'coverage_prop': '0.941', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.074', 'efficiency': '0.229', 'TP': '348', 'FP': '51', 'FN': '25', 'precision': '0.872', 'recall': '0.933', 'f1': '0.902', 'total_rewards': 1395.4292366522463, 'invalid_action_count': 0, 'num_ms1_scans': 129, 'num_ms2_scans': 1742}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 342.21298130396184
# steps	 1000 	total rewards	 718.8067089501362
# steps	 1500 	total rewards	 1110.8950579532684
# Finished after 1851 timesteps (8.093185424804688 seconds) with total reward 1375.1236797675397
# {'coverage_prop': '0.958', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.088', 'efficiency': '0.216', 'TP': '325', 'FP': '43', 'FN': '16', 'precision': '0.883', 'recall': '0.953', 'f1': '0.917', 'total_rewards': 1375.123679767539, 'invalid_action_count': 0, 'num_ms1_scans': 149, 'num_ms2_scans': 1702}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 349.687770056197
# steps	 1000 	total rewards	 742.8100247000173
# steps	 1500 	total rewards	 1120.1479703830114
# Finished after 1874 timesteps (8.48569941520691 seconds) with total reward 1398.3467977357395
# {'coverage_prop': '0.941', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.072', 'efficiency': '0.239', 'TP': '362', 'FP': '55', 'FN': '26', 'precision': '0.868', 'recall': '0.933', 'f1': '0.899', 'total_rewards': 1398.346797735742, 'invalid_action_count': 0, 'num_ms1_scans': 126, 'num_ms2_scans': 1748}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 349.92117135236697
# steps	 1000 	total rewards	 714.7202127810377
# steps	 1500 	total rewards	 1084.1956437745473
# Finished after 1797 timesteps (6.992459297180176 seconds) with total reward 1291.0872101714442
# {'coverage_prop': '0.952', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.127', 'efficiency': '0.149', 'TP': '222', 'FP': '15', 'FN': '12', 'precision': '0.937', 'recall': '0.949', 'f1': '0.943', 'total_rewards': 1291.087210171443, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 328.2472573699185
# steps	 1000 	total rewards	 707.6243361872683
# steps	 1500 	total rewards	 1088.8925261452373
# Finished after 1834 timesteps (7.066577434539795 seconds) with total reward 1332.364700756452
# {'coverage_prop': '0.944', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.100', 'efficiency': '0.142', 'TP': '209', 'FP': '28', 'FN': '14', 'precision': '0.882', 'recall': '0.937', 'f1': '0.909', 'total_rewards': 1332.364700756452, 'invalid_action_count': 0, 'num_ms1_scans': 167, 'num_ms2_scans': 1667}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 324.99677897510537
# steps	 1000 	total rewards	 695.5664345504936
# steps	 1500 	total rewards	 1045.7249897846118
# Finished after 1836 timesteps (12.398526191711426 seconds) with total reward 1216.2064526822269
# {'coverage_prop': '0.957', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.098', 'efficiency': '0.172', 'TP': '253', 'FP': '34', 'FN': '13', 'precision': '0.882', 'recall': '0.951', 'f1': '0.915', 'total_rewards': 1216.2064526822273, 'invalid_action_count': 0, 'num_ms1_scans': 164, 'num_ms2_scans': 1672}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 312.0103889891232
# steps	 1000 	total rewards	 691.3496640967394
# steps	 1500 	total rewards	 1057.1538551810863
# Finished after 1791 timesteps (6.895953416824341 seconds) with total reward 1237.2864787298504
# {'coverage_prop': '0.947', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.132', 'efficiency': '0.123', 'TP': '180', 'FP': '15', 'FN': '11', 'precision': '0.923', 'recall': '0.942', 'f1': '0.933', 'total_rewards': 1237.2864787298508, 'invalid_action_count': 0, 'num_ms1_scans': 209, 'num_ms2_scans': 1582}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 334.7934146990691
# steps	 1000 	total rewards	 728.5594339876768
# steps	 1500 	total rewards	 1110.396514303418
# Finished after 1841 timesteps (8.89837384223938 seconds) with total reward 1393.3919463955676
# {'coverage_prop': '0.961', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.095', 'efficiency': '0.232', 'TP': '356', 'FP': '35', 'FN': '16', 'precision': '0.910', 'recall': '0.957', 'f1': '0.933', 'total_rewards': 1393.3919463955667, 'invalid_action_count': 0, 'num_ms1_scans': 159, 'num_ms2_scans': 1682}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 342.94887997209094
# steps	 1000 	total rewards	 729.4288437656579
# steps	 1500 	total rewards	 1102.8444792690163
# Finished after 1864 timesteps (9.101304292678833 seconds) with total reward 1374.2422248255357
# {'coverage_prop': '0.962', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.079', 'efficiency': '0.277', 'TP': '419', 'FP': '60', 'FN': '19', 'precision': '0.875', 'recall': '0.957', 'f1': '0.914', 'total_rewards': 1374.2422248255345, 'invalid_action_count': 0, 'num_ms1_scans': 136, 'num_ms2_scans': 1728}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 361.96320584789817
# steps	 1000 	total rewards	 729.6669855780715
# steps	 1500 	total rewards	 1106.2802706978114
# Finished after 1849 timesteps (9.756603240966797 seconds) with total reward 1366.5600383971523
# {'coverage_prop': '0.946', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.089', 'efficiency': '0.207', 'TP': '309', 'FP': '43', 'FN': '20', 'precision': '0.878', 'recall': '0.939', 'f1': '0.907', 'total_rewards': 1366.560038397153, 'invalid_action_count': 0, 'num_ms1_scans': 151, 'num_ms2_scans': 1698}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 352.2398910796768
# steps	 1000 	total rewards	 734.700985385722
# steps	 1500 	total rewards	 1115.8516525118112
# Finished after 1826 timesteps (8.939993381500244 seconds) with total reward 1369.13467450175
# {'coverage_prop': '0.960', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.105', 'efficiency': '0.176', 'TP': '265', 'FP': '25', 'FN': '12', 'precision': '0.914', 'recall': '0.957', 'f1': '0.935', 'total_rewards': 1369.134674501752, 'invalid_action_count': 0, 'num_ms1_scans': 174, 'num_ms2_scans': 1652}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 341.1505066153492
# steps	 1000 	total rewards	 713.512041057621
# steps	 1500 	total rewards	 1100.1731264707596
# Finished after 1831 timesteps (12.179111242294312 seconds) with total reward 1349.6543403093747
# {'coverage_prop': '0.966', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.102', 'efficiency': '0.154', 'TP': '231', 'FP': '25', 'FN': '9', 'precision': '0.902', 'recall': '0.963', 'f1': '0.931', 'total_rewards': 1349.654340309376, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1662}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 324.6852061491593
# steps	 1000 	total rewards	 694.8060365461197
# steps	 1500 	total rewards	 1045.7477158960187
# Finished after 1862 timesteps (8.546248197555542 seconds) with total reward 1304.3434324345653
# {'coverage_prop': '0.910', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.080', 'efficiency': '0.247', 'TP': '365', 'FP': '61', 'FN': '42', 'precision': '0.857', 'recall': '0.897', 'f1': '0.876', 'total_rewards': 1304.343432434568, 'invalid_action_count': 0, 'num_ms1_scans': 138, 'num_ms2_scans': 1724}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 359.35570215744326
# steps	 1000 	total rewards	 741.1333269401093
# steps	 1500 	total rewards	 1136.1073048442522
# Finished after 1781 timesteps (6.2220139503479 seconds) with total reward 1328.4517174108883
# {'coverage_prop': '0.953', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.140', 'efficiency': '0.143', 'TP': '202', 'FP': '21', 'FN': '11', 'precision': '0.906', 'recall': '0.948', 'f1': '0.927', 'total_rewards': 1328.4517174108887, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 347.7695235392061
# steps	 1000 	total rewards	 735.2283511823613
# steps	 1500 	total rewards	 1092.1554959572081
# Finished after 1837 timesteps (7.65151572227478 seconds) with total reward 1353.8447255209385
# {'coverage_prop': '0.960', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.097', 'efficiency': '0.185', 'TP': '276', 'FP': '33', 'FN': '13', 'precision': '0.893', 'recall': '0.955', 'f1': '0.923', 'total_rewards': 1353.8447255209371, 'invalid_action_count': 0, 'num_ms1_scans': 163, 'num_ms2_scans': 1674}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 338.58317689621913
# steps	 1000 	total rewards	 716.1736527643975
# steps	 1500 	total rewards	 1115.5842027873337
# Finished after 1809 timesteps (7.346350908279419 seconds) with total reward 1344.465197734019
# {'coverage_prop': '0.948', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.118', 'efficiency': '0.182', 'TP': '270', 'FP': '24', 'FN': '16', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931', 'total_rewards': 1344.4651977340175, 'invalid_action_count': 0, 'num_ms1_scans': 191, 'num_ms2_scans': 1618}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 335.9156887737278
# steps	 1000 	total rewards	 721.2939922997916
# steps	 1500 	total rewards	 1099.2066414629044
# Finished after 1838 timesteps (7.925188302993774 seconds) with total reward 1377.694555292559
# {'coverage_prop': '0.983', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.097', 'efficiency': '0.202', 'TP': '301', 'FP': '38', 'FN': '6', 'precision': '0.888', 'recall': '0.980', 'f1': '0.932', 'total_rewards': 1377.6945552925597, 'invalid_action_count': 0, 'num_ms1_scans': 162, 'num_ms2_scans': 1676}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 368.0881008739908
# steps	 1000 	total rewards	 746.4778417764744
# steps	 1500 	total rewards	 1149.3879632525332
# Finished after 1862 timesteps (10.913277864456177 seconds) with total reward 1430.4838981396895
# {'coverage_prop': '0.970', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.080', 'efficiency': '0.223', 'TP': '336', 'FP': '48', 'FN': '12', 'precision': '0.875', 'recall': '0.966', 'f1': '0.918', 'total_rewards': 1430.4838981396915, 'invalid_action_count': 0, 'num_ms1_scans': 138, 'num_ms2_scans': 1724}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 298.98897529543405
# steps	 1000 	total rewards	 703.7257304013452
# steps	 1500 	total rewards	 1089.9991512497631
# Finished after 1777 timesteps (7.6258978843688965 seconds) with total reward 1284.8049043223773
# {'coverage_prop': '0.966', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.144', 'efficiency': '0.126', 'TP': '190', 'FP': '6', 'FN': '7', 'precision': '0.969', 'recall': '0.964', 'f1': '0.967', 'total_rewards': 1284.804904322377, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 327.7678673783249
# steps	 1000 	total rewards	 707.2126188226914
# steps	 1500 	total rewards	 1095.368122820553
# Finished after 1807 timesteps (6.920832872390747 seconds) with total reward 1336.9198809580257
# {'coverage_prop': '0.957', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.120', 'efficiency': '0.167', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 1336.9198809580223, 'invalid_action_count': 0, 'num_ms1_scans': 193, 'num_ms2_scans': 1614}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 340.20204650217227
# steps	 1000 	total rewards	 696.7135709106262
# steps	 1500 	total rewards	 1085.1832062018984
# Finished after 1875 timesteps (7.778220176696777 seconds) with total reward 1378.4187693987856
# {'coverage_prop': '0.921', 'intensity_prop': '0.671', 'ms1ms2_ratio': '0.071', 'efficiency': '0.259', 'TP': '374', 'FP': '80', 'FN': '39', 'precision': '0.824', 'recall': '0.906', 'f1': '0.863', 'total_rewards': 1378.4187693987878, 'invalid_action_count': 0, 'num_ms1_scans': 125, 'num_ms2_scans': 1750}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 312.02463285799513
# steps	 1000 	total rewards	 715.5692226743929
# steps	 1500 	total rewards	 1098.7303347804777
# Finished after 1829 timesteps (7.016654014587402 seconds) with total reward 1346.8463415868946
# {'coverage_prop': '0.957', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.103', 'efficiency': '0.176', 'TP': '268', 'FP': '23', 'FN': '13', 'precision': '0.921', 'recall': '0.954', 'f1': '0.937', 'total_rewards': 1346.8463415868935, 'invalid_action_count': 0, 'num_ms1_scans': 171, 'num_ms2_scans': 1658}
#
# method = topN max_peaks = 30 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 273.95025783299354
# steps	 1000 	total rewards	 632.1464291944101
# steps	 1500 	total rewards	 996.1909912893768
# Finished after 1699 timesteps (21.353776454925537 seconds) with total reward 1129.4559194046046
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924', 'total_rewards': 1129.455919404605, 'invalid_action_count': 0, 'num_ms1_scans': 301, 'num_ms2_scans': 1398}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 229.41260629078988
# steps	 1000 	total rewards	 537.8474471440331
# steps	 1500 	total rewards	 859.104856125048
# Finished after 1531 timesteps (23.575324058532715 seconds) with total reward 875.1487018021043
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948', 'total_rewards': 875.1487018021055, 'invalid_action_count': 0, 'num_ms1_scans': 469, 'num_ms2_scans': 1062}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 232.52164002907313
# steps	 1000 	total rewards	 603.282574436139
# steps	 1500 	total rewards	 982.0575141362696
# Finished after 1647 timesteps (21.622499227523804 seconds) with total reward 1088.847145169489
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932', 'total_rewards': 1088.8471451694882, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 293.01178590688176
# steps	 1000 	total rewards	 633.0618939387339
# steps	 1500 	total rewards	 973.8004080911539
# Finished after 1690 timesteps (25.767733573913574 seconds) with total reward 1106.633292921459
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933', 'total_rewards': 1106.6332929214584, 'invalid_action_count': 0, 'num_ms1_scans': 311, 'num_ms2_scans': 1379}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 250.48286926358855
# steps	 1000 	total rewards	 601.8008851041303
# steps	 1500 	total rewards	 923.3407304474767
# Finished after 1681 timesteps (21.752550840377808 seconds) with total reward 1041.364537664559
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935', 'total_rewards': 1041.3645376645588, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 180.3370440427603
# steps	 1000 	total rewards	 472.83849707742047
# Finished after 1388 timesteps (22.353023052215576 seconds) with total reward 640.8094336577385
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 640.8094336577382, 'invalid_action_count': 0, 'num_ms1_scans': 613, 'num_ms2_scans': 775}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 286.79863036335075
# steps	 1000 	total rewards	 643.8975364547225
# steps	 1500 	total rewards	 992.5907361644537
# Finished after 1722 timesteps (22.64973759651184 seconds) with total reward 1133.8704034766927
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904', 'total_rewards': 1133.8704034766915, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 166.2177974106953
# steps	 1000 	total rewards	 508.8608803706294
# Finished after 1447 timesteps (19.198517560958862 seconds) with total reward 739.4865394398873
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954', 'total_rewards': 739.4865394398869, 'invalid_action_count': 0, 'num_ms1_scans': 554, 'num_ms2_scans': 893}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 290.07035162729187
# steps	 1000 	total rewards	 640.511504451742
# steps	 1500 	total rewards	 983.8297958372451
# Finished after 1706 timesteps (22.32265567779541 seconds) with total reward 1124.8872199096352
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931', 'total_rewards': 1124.8872199096359, 'invalid_action_count': 0, 'num_ms1_scans': 294, 'num_ms2_scans': 1412}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 237.66200436002654
# steps	 1000 	total rewards	 596.5950581667582
# steps	 1500 	total rewards	 949.3700267224782
# Finished after 1644 timesteps (19.197539567947388 seconds) with total reward 1046.6538825288776
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929', 'total_rewards': 1046.6538825288783, 'invalid_action_count': 0, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 284.1591672431688
# steps	 1000 	total rewards	 651.4149860821037
# steps	 1500 	total rewards	 1003.8139510175297
# Finished after 1724 timesteps (15.367745637893677 seconds) with total reward 1164.2018874007351
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933', 'total_rewards': 1164.2018874007363, 'invalid_action_count': 0, 'num_ms1_scans': 277, 'num_ms2_scans': 1447}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 210.4301499718107
# steps	 1000 	total rewards	 539.2086151863671
# steps	 1500 	total rewards	 806.9223387092374
# Finished after 1500 timesteps (18.807986974716187 seconds) with total reward 806.9223387092374
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949', 'total_rewards': 806.9223387092364, 'invalid_action_count': 0, 'num_ms1_scans': 500, 'num_ms2_scans': 1000}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 219.42721308277726
# steps	 1000 	total rewards	 576.6818897260625
# steps	 1500 	total rewards	 891.7348388407922
# Finished after 1576 timesteps (16.290677309036255 seconds) with total reward 928.611505545015
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925', 'total_rewards': 928.6115055450151, 'invalid_action_count': 0, 'num_ms1_scans': 424, 'num_ms2_scans': 1152}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 232.8997076159785
# steps	 1000 	total rewards	 552.7277136137202
# steps	 1500 	total rewards	 857.2373415865738
# Finished after 1625 timesteps (16.63387632369995 seconds) with total reward 908.4190260861494
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934', 'total_rewards': 908.419026086151, 'invalid_action_count': 0, 'num_ms1_scans': 375, 'num_ms2_scans': 1250}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 176.94465309654305
# steps	 1000 	total rewards	 521.1157531123847
# Finished after 1472 timesteps (18.795961141586304 seconds) with total reward 748.3655912749783
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933', 'total_rewards': 748.3655912749776, 'invalid_action_count': 0, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 242.57262333120983
# steps	 1000 	total rewards	 600.8591232382702
# steps	 1500 	total rewards	 946.8365730937314
# Finished after 1627 timesteps (16.991976976394653 seconds) with total reward 1038.425052288804
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946', 'total_rewards': 1038.4250522888037, 'invalid_action_count': 0, 'num_ms1_scans': 374, 'num_ms2_scans': 1253}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 277.9967487857566
# steps	 1000 	total rewards	 656.5298707756369
# steps	 1500 	total rewards	 1005.1777558423712
# Finished after 1713 timesteps (17.338030338287354 seconds) with total reward 1148.210952900043
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935', 'total_rewards': 1148.210952900043, 'invalid_action_count': 0, 'num_ms1_scans': 287, 'num_ms2_scans': 1426}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 267.7540753310658
# steps	 1000 	total rewards	 608.4749146642903
# steps	 1500 	total rewards	 959.3968384929846
# Finished after 1657 timesteps (19.149052619934082 seconds) with total reward 1053.2617090952754
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943', 'total_rewards': 1053.2617090952751, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 227.4007235814671
# steps	 1000 	total rewards	 568.8444502075228
# steps	 1500 	total rewards	 915.9377582601041
# Finished after 1584 timesteps (15.330319881439209 seconds) with total reward 961.9850385919359
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940', 'total_rewards': 961.9850385919358, 'invalid_action_count': 0, 'num_ms1_scans': 416, 'num_ms2_scans': 1168}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 231.13276137982427
# steps	 1000 	total rewards	 581.2849058827447
# steps	 1500 	total rewards	 927.7457523969252
# Finished after 1606 timesteps (14.772100925445557 seconds) with total reward 986.361947759094
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955', 'total_rewards': 986.3619477590938, 'invalid_action_count': 0, 'num_ms1_scans': 395, 'num_ms2_scans': 1211}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 264.8554662985558
# steps	 1000 	total rewards	 608.5559027013494
# steps	 1500 	total rewards	 935.5140051023509
# Finished after 1705 timesteps (15.120500087738037 seconds) with total reward 1077.773216986045
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918', 'total_rewards': 1077.773216986045, 'invalid_action_count': 0, 'num_ms1_scans': 295, 'num_ms2_scans': 1410}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 200.0228694404588
# steps	 1000 	total rewards	 534.2374239600695
# Finished after 1442 timesteps (17.97449493408203 seconds) with total reward 753.9558111216897
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 753.9558111216891, 'invalid_action_count': 0, 'num_ms1_scans': 559, 'num_ms2_scans': 883}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 247.2113048677188
# steps	 1000 	total rewards	 592.3884848395044
# steps	 1500 	total rewards	 916.7489256144869
# Finished after 1609 timesteps (16.309873580932617 seconds) with total reward 980.7288185819509
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949', 'total_rewards': 980.7288185819507, 'invalid_action_count': 0, 'num_ms1_scans': 392, 'num_ms2_scans': 1217}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 236.12529755345412
# steps	 1000 	total rewards	 582.8692972464917
# steps	 1500 	total rewards	 884.1165320688208
# Finished after 1544 timesteps (16.057997941970825 seconds) with total reward 903.7980074800669
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935', 'total_rewards': 903.7980074800685, 'invalid_action_count': 0, 'num_ms1_scans': 457, 'num_ms2_scans': 1087}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 227.45483048867385
# steps	 1000 	total rewards	 604.6411472730465
# steps	 1500 	total rewards	 963.4289705170956
# Finished after 1657 timesteps (18.49846839904785 seconds) with total reward 1080.724721715695
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955', 'total_rewards': 1080.7247217156958, 'invalid_action_count': 0, 'num_ms1_scans': 343, 'num_ms2_scans': 1314}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 268.9181255070283
# steps	 1000 	total rewards	 606.431335732239
# steps	 1500 	total rewards	 971.9742005483918
# Finished after 1649 timesteps (16.43222141265869 seconds) with total reward 1073.9913779072194
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944', 'total_rewards': 1073.9913779072178, 'invalid_action_count': 0, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 185.20689384030436
# steps	 1000 	total rewards	 518.1006628111029
# Finished after 1435 timesteps (16.017616033554077 seconds) with total reward 725.9977355275353
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948', 'total_rewards': 725.9977355275349, 'invalid_action_count': 0, 'num_ms1_scans': 566, 'num_ms2_scans': 869}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 215.59085943539807
# steps	 1000 	total rewards	 549.1684160021534
# steps	 1500 	total rewards	 852.854824248654
# Finished after 1527 timesteps (15.098341941833496 seconds) with total reward 871.4582136011659
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948', 'total_rewards': 871.4582136011664, 'invalid_action_count': 0, 'num_ms1_scans': 473, 'num_ms2_scans': 1054}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 281.5979299404295
# steps	 1000 	total rewards	 619.2953424014826
# steps	 1500 	total rewards	 991.5134985563226
# Finished after 1729 timesteps (21.138537168502808 seconds) with total reward 1161.5917866925693
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902', 'total_rewards': 1161.5917866925668, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 235.17939026197917
# steps	 1000 	total rewards	 586.6139463625948
# steps	 1500 	total rewards	 938.3909389232779
# Finished after 1612 timesteps (14.891380310058594 seconds) with total reward 1004.2240914801285
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950', 'total_rewards': 1004.2240914801279, 'invalid_action_count': 0, 'num_ms1_scans': 388, 'num_ms2_scans': 1224}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f6caec5ad90>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f6ca52b00a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f6ca52cc340>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.795', 'efficiency': '0.539', 'TP': '358', 'FP': '58', 'FN': '10', 'precision': '0.861', 'recall': '0.973', 'f1': '0.913'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.847', 'efficiency': '0.514', 'TP': '323', 'FP': '59', 'FN': '12', 'precision': '0.846', 'recall': '0.964', 'f1': '0.901'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.734', 'efficiency': '0.543', 'TP': '381', 'FP': '59', 'FN': '12', 'precision': '0.866', 'recall': '0.969', 'f1': '0.915'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '368', 'FP': '65', 'FN': '4', 'precision': '0.850', 'recall': '0.989', 'f1': '0.914'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.679', 'efficiency': '0.541', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.718', 'ms1ms2_ratio': '2.080', 'efficiency': '0.505', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.681', 'ms1ms2_ratio': '0.826', 'efficiency': '0.536', 'TP': '338', 'FP': '66', 'FN': '20', 'precision': '0.837', 'recall': '0.944', 'f1': '0.887'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.688', 'efficiency': '0.508', 'TP': '384', 'FP': '44', 'FN': '15', 'precision': '0.897', 'recall': '0.962', 'f1': '0.929'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.667', 'ms1ms2_ratio': '1.615', 'efficiency': '0.503', 'TP': '195', 'FP': '43', 'FN': '13', 'precision': '0.819', 'recall': '0.938', 'f1': '0.874'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.689', 'ms1ms2_ratio': '1.267', 'efficiency': '0.512', 'TP': '234', 'FP': '56', 'FN': '10', 'precision': '0.807', 'recall': '0.959', 'f1': '0.876'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.858', 'efficiency': '0.540', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '428', 'FP': '59', 'FN': '11', 'precision': '0.879', 'recall': '0.975', 'f1': '0.924'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '310', 'FP': '50', 'FN': '12', 'precision': '0.861', 'recall': '0.963', 'f1': '0.909'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.246', 'efficiency': '0.510', 'TP': '254', 'FP': '38', 'FN': '10', 'precision': '0.870', 'recall': '0.962', 'f1': '0.914'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.715', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '223', 'FP': '37', 'FN': '5', 'precision': '0.858', 'recall': '0.978', 'f1': '0.914'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.176', 'efficiency': '0.523', 'TP': '274', 'FP': '38', 'FN': '10', 'precision': '0.878', 'recall': '0.965', 'f1': '0.919'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.973', 'efficiency': '0.499', 'TP': '292', 'FP': '47', 'FN': '6', 'precision': '0.861', 'recall': '0.980', 'f1': '0.917'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.851', 'efficiency': '0.528', 'TP': '339', 'FP': '52', 'FN': '5', 'precision': '0.867', 'recall': '0.985', 'f1': '0.922'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.720', 'ms1ms2_ratio': '1.363', 'efficiency': '0.507', 'TP': '239', 'FP': '33', 'FN': '9', 'precision': '0.879', 'recall': '0.964', 'f1': '0.919'}
#
# Episode 28 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.713', 'ms1ms2_ratio': '0.589', 'efficiency': '0.520', 'TP': '412', 'FP': '65', 'FN': '16', 'precision': '0.864', 'recall': '0.963', 'f1': '0.910'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    1269.001987                   0.0          0.932           0.687
# 1  random    1170.417290                   0.0          0.939           0.765
# 2  random    1286.341089                   0.0          0.944           0.702
# 3  random    1253.445460                   0.0          0.942           0.723
# 4  random    1184.877162                   0.0          0.950           0.708
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.135       0.252      0.859   0.922  0.889
# 1          0.209       0.174      0.919   0.934  0.926
# 2          0.149       0.241      0.844   0.935  0.887
# 3          0.138       0.272      0.873   0.935  0.903
# 4          0.145       0.268      0.843   0.941  0.889

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'DQN'

# %%
df = pd.read_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'DQN']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    1269.001987                   0.0          0.932           0.687
# 1  random    1170.417290                   0.0          0.939           0.765
# 2  random    1286.341089                   0.0          0.944           0.702
# 3  random    1253.445460                   0.0          0.942           0.723
# 4  random    1184.877162                   0.0          0.950           0.708
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.135       0.252      0.859   0.922  0.889
# 1          0.209       0.174      0.919   0.934  0.926
# 2          0.149       0.241      0.844   0.935  0.887
# 3          0.138       0.272      0.873   0.935  0.903
# 4          0.145       0.268      0.843   0.941  0.889

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
