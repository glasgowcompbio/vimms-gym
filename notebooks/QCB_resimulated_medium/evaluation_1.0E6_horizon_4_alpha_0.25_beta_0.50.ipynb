# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-07 13:49:07.153 | INFO     | vimms_gym.experiments:get_samplers:295 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ad5e69df0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7aa0766310>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7aa07835b0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ad5e69df0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7aa0766310>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7aa07835b0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ad5e69df0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7aa0766310>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7aa07835b0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        # fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -479.52389774485744
# steps	 1000 	total rewards	 -931.332077438582
# steps	 1500 	total rewards	 -1357.79037389748
# Finished after 1990 timesteps (1.7261760234832764 seconds) with total reward -1843.1376728027312
# {'coverage_prop': '0.376', 'intensity_prop': '0.105', 'ms1ms2_ratio': '0.005', 'efficiency': '0.081', 'TP': '41', 'FP': '119', 'FN': '266', 'precision': '0.256', 'recall': '0.134', 'f1': '0.176', 'total_rewards': -1843.1376728027312, 'invalid_action_count': 1874, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -963.1078276858243
# steps	 1500 	total rewards	 -1449.8124736782486
# Finished after 1991 timesteps (0.9149582386016846 seconds) with total reward -1901.0824371539597
# {'coverage_prop': '0.309', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.005', 'efficiency': '0.041', 'TP': '18', 'FP': '63', 'FN': '181', 'precision': '0.222', 'recall': '0.090', 'f1': '0.129', 'total_rewards': -1901.08243715396, 'invalid_action_count': 1920, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -480.5927713334984
# steps	 1000 	total rewards	 -937.9426061508743
# steps	 1500 	total rewards	 -1376.6918182996408
# Finished after 1986 timesteps (1.2273709774017334 seconds) with total reward -1815.5762438595234
# {'coverage_prop': '0.439', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.007', 'efficiency': '0.088', 'TP': '36', 'FP': '137', 'FN': '221', 'precision': '0.208', 'recall': '0.140', 'f1': '0.167', 'total_rewards': -1815.5762438595232, 'invalid_action_count': 1852, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -486.5515180248621
# steps	 1000 	total rewards	 -963.3273350533732
# steps	 1500 	total rewards	 -1437.0310104852172
# Finished after 1992 timesteps (1.5114550590515137 seconds) with total reward -1890.6731234689673
# {'coverage_prop': '0.277', 'intensity_prop': '0.072', 'ms1ms2_ratio': '0.004', 'efficiency': '0.063', 'TP': '32', 'FP': '93', 'FN': '327', 'precision': '0.256', 'recall': '0.089', 'f1': '0.132', 'total_rewards': -1890.6731234689678, 'invalid_action_count': 1911, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -485.67842445650655
# steps	 1000 	total rewards	 -961.5753830469888
# steps	 1500 	total rewards	 -1418.6517454092475
# Finished after 1992 timesteps (1.2823431491851807 seconds) with total reward -1863.3681745030453
# {'coverage_prop': '0.366', 'intensity_prop': '0.088', 'ms1ms2_ratio': '0.005', 'efficiency': '0.081', 'TP': '35', 'FP': '125', 'FN': '277', 'precision': '0.219', 'recall': '0.112', 'f1': '0.148', 'total_rewards': -1863.3681745030449, 'invalid_action_count': 1890, 'num_ms1_scans': 9, 'num_ms2_scans': 1983}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -487.6580623870989
# steps	 1000 	total rewards	 -969.76704405034
# steps	 1500 	total rewards	 -1450.3967188237484
# Finished after 1982 timesteps (0.8382198810577393 seconds) with total reward -1915.1539054301863
# {'coverage_prop': '0.295', 'intensity_prop': '0.078', 'ms1ms2_ratio': '0.009', 'efficiency': '0.030', 'TP': '16', 'FP': '43', 'FN': '141', 'precision': '0.271', 'recall': '0.102', 'f1': '0.148', 'total_rewards': -1915.1539054301866, 'invalid_action_count': 1926, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -488.1244343270082
# steps	 1000 	total rewards	 -950.0152391819574
# steps	 1500 	total rewards	 -1357.288230993099
# Finished after 1984 timesteps (1.360325813293457 seconds) with total reward -1800.5226126630319
# {'coverage_prop': '0.370', 'intensity_prop': '0.102', 'ms1ms2_ratio': '0.008', 'efficiency': '0.090', 'TP': '43', 'FP': '134', 'FN': '301', 'precision': '0.243', 'recall': '0.125', 'f1': '0.165', 'total_rewards': -1800.5226126630325, 'invalid_action_count': 1838, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -496.67620568505265
# steps	 1000 	total rewards	 -989.8761765800784
# steps	 1500 	total rewards	 -1460.015879012723
# Finished after 1991 timesteps (0.8182830810546875 seconds) with total reward -1945.6896834460126
# {'coverage_prop': '0.152', 'intensity_prop': '0.036', 'ms1ms2_ratio': '0.005', 'efficiency': '0.016', 'TP': '5', 'FP': '26', 'FN': '173', 'precision': '0.161', 'recall': '0.028', 'f1': '0.048', 'total_rewards': -1945.6896834460126, 'invalid_action_count': 1954, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -494.19023920316647
# steps	 1000 	total rewards	 -974.2188359349129
# steps	 1500 	total rewards	 -1434.495909657082
# Finished after 1993 timesteps (1.6091971397399902 seconds) with total reward -1900.2488615801508
# {'coverage_prop': '0.241', 'intensity_prop': '0.039', 'ms1ms2_ratio': '0.004', 'efficiency': '0.051', 'TP': '15', 'FP': '87', 'FN': '322', 'precision': '0.147', 'recall': '0.045', 'f1': '0.068', 'total_rewards': -1900.2488615801512, 'invalid_action_count': 1919, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -488.21078705089616
# steps	 1000 	total rewards	 -957.438364215624
# steps	 1500 	total rewards	 -1379.250765106142
# Finished after 1989 timesteps (1.2267920970916748 seconds) with total reward -1834.0129382814875
# {'coverage_prop': '0.427', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.006', 'efficiency': '0.083', 'TP': '35', 'FP': '129', 'FN': '220', 'precision': '0.213', 'recall': '0.137', 'f1': '0.167', 'total_rewards': -1834.0129382814887, 'invalid_action_count': 1868, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -476.83352498583037
# steps	 1000 	total rewards	 -939.9924102540588
# steps	 1500 	total rewards	 -1391.0363002257218
# Finished after 1986 timesteps (1.3101019859313965 seconds) with total reward -1830.6240059649463
# {'coverage_prop': '0.323', 'intensity_prop': '0.066', 'ms1ms2_ratio': '0.007', 'efficiency': '0.073', 'TP': '23', 'FP': '120', 'FN': '300', 'precision': '0.161', 'recall': '0.071', 'f1': '0.099', 'total_rewards': -1830.6240059649463, 'invalid_action_count': 1861, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -969.7494773947482
# steps	 1500 	total rewards	 -1440.8943488643786
# Finished after 1991 timesteps (0.9133119583129883 seconds) with total reward -1915.3295439048302
# {'coverage_prop': '0.305', 'intensity_prop': '0.071', 'ms1ms2_ratio': '0.005', 'efficiency': '0.038', 'TP': '14', 'FP': '62', 'FN': '173', 'precision': '0.184', 'recall': '0.075', 'f1': '0.106', 'total_rewards': -1915.3295439048295, 'invalid_action_count': 1931, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -489.32672606945806
# steps	 1000 	total rewards	 -969.6091085389878
# steps	 1500 	total rewards	 -1433.0957478914593
# Finished after 1993 timesteps (0.9491879940032959 seconds) with total reward -1893.3916022942794
# {'coverage_prop': '0.331', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.004', 'efficiency': '0.042', 'TP': '11', 'FP': '72', 'FN': '168', 'precision': '0.133', 'recall': '0.061', 'f1': '0.084', 'total_rewards': -1893.3916022942794, 'invalid_action_count': 1914, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -486.8350076063525
# steps	 1000 	total rewards	 -962.4152092196198
# steps	 1500 	total rewards	 -1406.1342121452708
# Finished after 1988 timesteps (1.5503289699554443 seconds) with total reward -1848.2880891683426
# {'coverage_prop': '0.417', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.006', 'efficiency': '0.063', 'TP': '41', 'FP': '84', 'FN': '175', 'precision': '0.328', 'recall': '0.190', 'f1': '0.240', 'total_rewards': -1848.2880891683428, 'invalid_action_count': 1876, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -486.0388860042889
# steps	 1000 	total rewards	 -947.653870240126
# steps	 1500 	total rewards	 -1413.687754498777
# Finished after 1987 timesteps (0.8672080039978027 seconds) with total reward -1882.13240900263
# {'coverage_prop': '0.422', 'intensity_prop': '0.105', 'ms1ms2_ratio': '0.007', 'efficiency': '0.044', 'TP': '18', 'FP': '69', 'FN': '119', 'precision': '0.207', 'recall': '0.131', 'f1': '0.161', 'total_rewards': -1882.1324090026308, 'invalid_action_count': 1904, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -493.40989650720655
# steps	 1000 	total rewards	 -948.7415283057671
# steps	 1500 	total rewards	 -1373.5128580836204
# Finished after 1987 timesteps (1.2547669410705566 seconds) with total reward -1834.1123022807035
# {'coverage_prop': '0.405', 'intensity_prop': '0.125', 'ms1ms2_ratio': '0.007', 'efficiency': '0.084', 'TP': '51', 'FP': '114', 'FN': '242', 'precision': '0.309', 'recall': '0.174', 'f1': '0.223', 'total_rewards': -1834.1123022807035, 'invalid_action_count': 1866, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -954.2694899510079
# steps	 1500 	total rewards	 -1396.0378780319195
# Finished after 1989 timesteps (1.361259937286377 seconds) with total reward -1827.2385991994552
# {'coverage_prop': '0.353', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.006', 'efficiency': '0.089', 'TP': '52', 'FP': '124', 'FN': '322', 'precision': '0.295', 'recall': '0.139', 'f1': '0.189', 'total_rewards': -1827.2385991994554, 'invalid_action_count': 1861, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -494.7959167291333
# steps	 1000 	total rewards	 -953.0857598602901
# steps	 1500 	total rewards	 -1401.9046107097445
# Finished after 1988 timesteps (1.1306092739105225 seconds) with total reward -1854.2159508156542
# {'coverage_prop': '0.374', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.006', 'efficiency': '0.070', 'TP': '35', 'FP': '104', 'FN': '233', 'precision': '0.252', 'recall': '0.131', 'f1': '0.172', 'total_rewards': -1854.2159508156544, 'invalid_action_count': 1884, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -480.07580706996873
# steps	 1000 	total rewards	 -943.6622156569136
# steps	 1500 	total rewards	 -1397.065116302476
# Finished after 1989 timesteps (1.548246145248413 seconds) with total reward -1861.3898696935162
# {'coverage_prop': '0.407', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.006', 'efficiency': '0.062', 'TP': '23', 'FP': '100', 'FN': '179', 'precision': '0.187', 'recall': '0.114', 'f1': '0.142', 'total_rewards': -1861.3898696935164, 'invalid_action_count': 1888, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -488.21488385921066
# steps	 1000 	total rewards	 -951.247661819958
# steps	 1500 	total rewards	 -1396.2085246300117
# Finished after 1987 timesteps (0.9885990619659424 seconds) with total reward -1868.0673744002581
# {'coverage_prop': '0.374', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.007', 'efficiency': '0.050', 'TP': '27', 'FP': '72', 'FN': '166', 'precision': '0.273', 'recall': '0.140', 'f1': '0.185', 'total_rewards': -1868.0673744002584, 'invalid_action_count': 1893, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -487.5442434178002
# steps	 1000 	total rewards	 -955.7626383545571
# steps	 1500 	total rewards	 -1361.6266102503882
# Finished after 1991 timesteps (1.317274808883667 seconds) with total reward -1818.8551836548781
# {'coverage_prop': '0.393', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.005', 'efficiency': '0.093', 'TP': '41', 'FP': '143', 'FN': '284', 'precision': '0.223', 'recall': '0.126', 'f1': '0.161', 'total_rewards': -1818.8551836548784, 'invalid_action_count': 1854, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -489.734005958043
# steps	 1000 	total rewards	 -965.1132552961308
# steps	 1500 	total rewards	 -1419.7508205263773
# Finished after 1988 timesteps (0.9060952663421631 seconds) with total reward -1886.6953586406273
# {'coverage_prop': '0.389', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.006', 'efficiency': '0.046', 'TP': '25', 'FP': '66', 'FN': '143', 'precision': '0.275', 'recall': '0.149', 'f1': '0.193', 'total_rewards': -1886.6953586406273, 'invalid_action_count': 1908, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -983.5780711409939
# steps	 1500 	total rewards	 -1413.4279405616007
# Finished after 1989 timesteps (1.0522079467773438 seconds) with total reward -1860.6142405766316
# {'coverage_prop': '0.342', 'intensity_prop': '0.098', 'ms1ms2_ratio': '0.006', 'efficiency': '0.056', 'TP': '29', 'FP': '81', 'FN': '212', 'precision': '0.264', 'recall': '0.120', 'f1': '0.165', 'total_rewards': -1860.6142405766323, 'invalid_action_count': 1886, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -491.96734959372225
# steps	 1000 	total rewards	 -934.0320599693721
# steps	 1500 	total rewards	 -1393.997454846471
# Finished after 1987 timesteps (0.9899823665618896 seconds) with total reward -1850.8010143917477
# {'coverage_prop': '0.374', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.007', 'efficiency': '0.059', 'TP': '32', 'FP': '84', 'FN': '194', 'precision': '0.276', 'recall': '0.142', 'f1': '0.187', 'total_rewards': -1850.8010143917481, 'invalid_action_count': 1880, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -483.45225842179207
# steps	 1000 	total rewards	 -949.3967331743203
# steps	 1500 	total rewards	 -1379.7635687623201
# Finished after 1988 timesteps (1.0941009521484375 seconds) with total reward -1841.356682154862
# {'coverage_prop': '0.388', 'intensity_prop': '0.115', 'ms1ms2_ratio': '0.006', 'efficiency': '0.068', 'TP': '37', 'FP': '97', 'FN': '211', 'precision': '0.276', 'recall': '0.149', 'f1': '0.194', 'total_rewards': -1841.3566821548618, 'invalid_action_count': 1871, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -483.36772211409095
# steps	 1000 	total rewards	 -921.1950582974139
# steps	 1500 	total rewards	 -1385.1811714216062
# Finished after 1989 timesteps (1.1564338207244873 seconds) with total reward -1855.4925484235423
# {'coverage_prop': '0.341', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.006', 'efficiency': '0.068', 'TP': '32', 'FP': '103', 'FN': '261', 'precision': '0.237', 'recall': '0.109', 'f1': '0.150', 'total_rewards': -1855.492548423543, 'invalid_action_count': 1883, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -495.3376388308194
# steps	 1000 	total rewards	 -978.9507407961034
# steps	 1500 	total rewards	 -1441.4133115750642
# Finished after 1993 timesteps (0.8438470363616943 seconds) with total reward -1925.868519393082
# {'coverage_prop': '0.291', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.004', 'efficiency': '0.030', 'TP': '19', 'FP': '40', 'FN': '144', 'precision': '0.322', 'recall': '0.117', 'f1': '0.171', 'total_rewards': -1925.8685193930821, 'invalid_action_count': 1939, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -491.34934345852395
# steps	 1000 	total rewards	 -963.184019153025
# steps	 1500 	total rewards	 -1425.2537513454436
# Finished after 1985 timesteps (0.9414410591125488 seconds) with total reward -1882.5072052419732
# {'coverage_prop': '0.324', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.008', 'efficiency': '0.046', 'TP': '25', 'FP': '66', 'FN': '190', 'precision': '0.275', 'recall': '0.116', 'f1': '0.163', 'total_rewards': -1882.5072052419735, 'invalid_action_count': 1904, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -482.9775974275981
# steps	 1000 	total rewards	 -947.2929485583301
# steps	 1500 	total rewards	 -1344.4876116065006
# Finished after 1988 timesteps (1.3800299167633057 seconds) with total reward -1768.617989292667
# {'coverage_prop': '0.422', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.006', 'efficiency': '0.105', 'TP': '47', 'FP': '161', 'FN': '285', 'precision': '0.226', 'recall': '0.142', 'f1': '0.174', 'total_rewards': -1768.6179892926673, 'invalid_action_count': 1816, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -490.40841346752404
# steps	 1000 	total rewards	 -958.7512409180621
# steps	 1500 	total rewards	 -1425.5035781129477
# Finished after 1989 timesteps (1.0286052227020264 seconds) with total reward -1885.2157115689433
# {'coverage_prop': '0.326', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.006', 'efficiency': '0.050', 'TP': '19', 'FP': '80', 'FN': '205', 'precision': '0.192', 'recall': '0.085', 'f1': '0.118', 'total_rewards': -1885.2157115689436, 'invalid_action_count': 1907, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.33GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 72.19522172969239
# steps	 1000 	total rewards	 151.71837721779727
# steps	 1500 	total rewards	 228.52997338140577
# Finished after 1775 timesteps (4.0308380126953125 seconds) with total reward 264.49790118588874
# {'coverage_prop': '0.937', 'intensity_prop': '0.717', 'ms1ms2_ratio': '0.145', 'efficiency': '0.257', 'TP': '344', 'FP': '55', 'FN': '27', 'precision': '0.862', 'recall': '0.927', 'f1': '0.894', 'total_rewards': 264.4979011858887, 'invalid_action_count': 11, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 65.48793494396925
# steps	 1000 	total rewards	 135.78312305881863
# steps	 1500 	total rewards	 209.56524152543605
# Finished after 1720 timesteps (2.7991127967834473 seconds) with total reward 236.10703704300204
# {'coverage_prop': '0.958', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.194', 'efficiency': '0.174', 'TP': '232', 'FP': '19', 'FN': '11', 'precision': '0.924', 'recall': '0.955', 'f1': '0.939', 'total_rewards': 236.1070370430017, 'invalid_action_count': 11, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 62.27747246120746
# steps	 1000 	total rewards	 144.45194181905563
# steps	 1500 	total rewards	 211.13567214835894
# Finished after 1750 timesteps (6.35086727142334 seconds) with total reward 247.04854219722316
# {'coverage_prop': '0.954', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.167', 'efficiency': '0.251', 'TP': '326', 'FP': '50', 'FN': '18', 'precision': '0.867', 'recall': '0.948', 'f1': '0.906', 'total_rewards': 247.04854219722296, 'invalid_action_count': 9, 'num_ms1_scans': 250, 'num_ms2_scans': 1500}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 75.0506933664397
# steps	 1000 	total rewards	 151.84498109041374
# steps	 1500 	total rewards	 225.01740366683833
# Finished after 1769 timesteps (5.951980113983154 seconds) with total reward 261.9813189242286
# {'coverage_prop': '0.947', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.150', 'efficiency': '0.278', 'TP': '383', 'FP': '45', 'FN': '24', 'precision': '0.895', 'recall': '0.941', 'f1': '0.917', 'total_rewards': 261.98131892422873, 'invalid_action_count': 6, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 68.5108800374498
# steps	 1000 	total rewards	 147.1545376116984
# steps	 1500 	total rewards	 225.7622821818802
# Finished after 1767 timesteps (4.8775599002838135 seconds) with total reward 262.07537727430207
# {'coverage_prop': '0.973', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.152', 'efficiency': '0.277', 'TP': '359', 'FP': '66', 'FN': '12', 'precision': '0.845', 'recall': '0.968', 'f1': '0.902', 'total_rewards': 262.0753772743021, 'invalid_action_count': 10, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 54.55266528127804
# steps	 1000 	total rewards	 121.62502907364441
# steps	 1500 	total rewards	 179.5313679071055
# Finished after 1683 timesteps (4.18123197555542 seconds) with total reward 199.7507297527631
# {'coverage_prop': '0.955', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.233', 'efficiency': '0.140', 'TP': '180', 'FP': '11', 'FN': '9', 'precision': '0.942', 'recall': '0.952', 'f1': '0.947', 'total_rewards': 199.7507297527636, 'invalid_action_count': 7, 'num_ms1_scans': 318, 'num_ms2_scans': 1365}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 66.34615521312388
# steps	 1000 	total rewards	 151.0355163173669
# steps	 1500 	total rewards	 221.49066404248904
# Finished after 1776 timesteps (5.096922874450684 seconds) with total reward 256.1182604532688
# {'coverage_prop': '0.916', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.144', 'efficiency': '0.282', 'TP': '378', 'FP': '60', 'FN': '40', 'precision': '0.863', 'recall': '0.904', 'f1': '0.883', 'total_rewards': 256.11826045326893, 'invalid_action_count': 12, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 54.69874211647763
# steps	 1000 	total rewards	 126.9514708484804
# steps	 1500 	total rewards	 196.74863053650313
# Finished after 1681 timesteps (5.081316232681274 seconds) with total reward 218.8724113999042
# {'coverage_prop': '0.956', 'intensity_prop': '0.807', 'ms1ms2_ratio': '0.234', 'efficiency': '0.143', 'TP': '189', 'FP': '6', 'FN': '9', 'precision': '0.969', 'recall': '0.955', 'f1': '0.962', 'total_rewards': 218.8724113999043, 'invalid_action_count': 6, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 74.93986811918973
# steps	 1000 	total rewards	 149.99450524551045
# steps	 1500 	total rewards	 225.32469448303956
# Finished after 1785 timesteps (4.52891206741333 seconds) with total reward 263.9569734274969
# {'coverage_prop': '0.939', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.137', 'efficiency': '0.254', 'TP': '350', 'FP': '48', 'FN': '26', 'precision': '0.879', 'recall': '0.931', 'f1': '0.904', 'total_rewards': 263.9569734274971, 'invalid_action_count': 8, 'num_ms1_scans': 215, 'num_ms2_scans': 1570}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 66.51153648424025
# steps	 1000 	total rewards	 141.8583400970802
# steps	 1500 	total rewards	 222.7777518141435
# Finished after 1761 timesteps (6.8464179039001465 seconds) with total reward 256.00789988458575
# {'coverage_prop': '0.943', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.157', 'efficiency': '0.238', 'TP': '324', 'FP': '38', 'FN': '22', 'precision': '0.895', 'recall': '0.936', 'f1': '0.915', 'total_rewards': 256.0078998845857, 'invalid_action_count': 6, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 69.89967357003809
# steps	 1000 	total rewards	 149.2887236830897
# steps	 1500 	total rewards	 226.0402889165136
# Finished after 1784 timesteps (3.6183600425720215 seconds) with total reward 265.6348778537169
# {'coverage_prop': '0.923', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.138', 'efficiency': '0.261', 'TP': '362', 'FP': '47', 'FN': '34', 'precision': '0.885', 'recall': '0.914', 'f1': '0.899', 'total_rewards': 265.63487785371683, 'invalid_action_count': 5, 'num_ms1_scans': 216, 'num_ms2_scans': 1568}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 65.01188114404133
# steps	 1000 	total rewards	 138.62096358560424
# steps	 1500 	total rewards	 197.0514849288307
# Finished after 1717 timesteps (2.9801530838012695 seconds) with total reward 222.42570046812244
# {'coverage_prop': '0.956', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.197', 'efficiency': '0.166', 'TP': '223', 'FP': '15', 'FN': '11', 'precision': '0.937', 'recall': '0.953', 'f1': '0.945', 'total_rewards': 222.42570046812276, 'invalid_action_count': 4, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 64.88252739713673
# steps	 1000 	total rewards	 129.13232115483075
# steps	 1500 	total rewards	 195.35151927481206
# Finished after 1745 timesteps (4.187448024749756 seconds) with total reward 230.40453739312795
# {'coverage_prop': '0.948', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.171', 'efficiency': '0.160', 'TP': '214', 'FP': '24', 'FN': '13', 'precision': '0.899', 'recall': '0.943', 'f1': '0.920', 'total_rewards': 230.4045373931279, 'invalid_action_count': 6, 'num_ms1_scans': 255, 'num_ms2_scans': 1490}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 62.211359674228945
# steps	 1000 	total rewards	 136.2621416434039
# steps	 1500 	total rewards	 203.88488658422264
# Finished after 1752 timesteps (3.3552379608154297 seconds) with total reward 229.35960187984188
# {'coverage_prop': '0.963', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.166', 'efficiency': '0.192', 'TP': '252', 'FP': '37', 'FN': '11', 'precision': '0.872', 'recall': '0.958', 'f1': '0.913', 'total_rewards': 229.35960187984185, 'invalid_action_count': 7, 'num_ms1_scans': 249, 'num_ms2_scans': 1503}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 60.090471307149286
# steps	 1000 	total rewards	 131.55728784006163
# steps	 1500 	total rewards	 192.85070386803415
# Finished after 1702 timesteps (2.8331499099731445 seconds) with total reward 216.41229195533424
# {'coverage_prop': '0.951', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.212', 'efficiency': '0.140', 'TP': '172', 'FP': '24', 'FN': '10', 'precision': '0.878', 'recall': '0.945', 'f1': '0.910', 'total_rewards': 216.41229195533455, 'invalid_action_count': 5, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 65.83221338708174
# steps	 1000 	total rewards	 148.4556878340602
# steps	 1500 	total rewards	 224.93397413290353
# Finished after 1753 timesteps (3.412365198135376 seconds) with total reward 260.7371382709248
# {'coverage_prop': '0.953', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.164', 'efficiency': '0.258', 'TP': '351', 'FP': '37', 'FN': '19', 'precision': '0.905', 'recall': '0.949', 'f1': '0.926', 'total_rewards': 260.73713827092473, 'invalid_action_count': 3, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 72.72055512673586
# steps	 1000 	total rewards	 158.5126517392267
# steps	 1500 	total rewards	 234.03620187034676
# Finished after 1779 timesteps (3.7714879512786865 seconds) with total reward 267.48971274973076
# {'coverage_prop': '0.954', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.142', 'efficiency': '0.305', 'TP': '422', 'FP': '53', 'FN': '23', 'precision': '0.888', 'recall': '0.948', 'f1': '0.917', 'total_rewards': 267.4897127497306, 'invalid_action_count': 11, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 71.04252413970845
# steps	 1000 	total rewards	 148.41588517391773
# steps	 1500 	total rewards	 221.86464934038116
# Finished after 1756 timesteps (3.457568645477295 seconds) with total reward 254.2508966638664
# {'coverage_prop': '0.941', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.161', 'efficiency': '0.231', 'TP': '309', 'FP': '41', 'FN': '22', 'precision': '0.883', 'recall': '0.934', 'f1': '0.907', 'total_rewards': 254.25089666386626, 'invalid_action_count': 2, 'num_ms1_scans': 244, 'num_ms2_scans': 1512}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 64.6536239141161
# steps	 1000 	total rewards	 135.2965274922986
# steps	 1500 	total rewards	 203.85049483363974
# Finished after 1745 timesteps (3.17414927482605 seconds) with total reward 237.30654082982875
# {'coverage_prop': '0.964', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.171', 'efficiency': '0.195', 'TP': '266', 'FP': '25', 'FN': '11', 'precision': '0.914', 'recall': '0.960', 'f1': '0.937', 'total_rewards': 237.3065408298288, 'invalid_action_count': 9, 'num_ms1_scans': 255, 'num_ms2_scans': 1490}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 64.71455213424377
# steps	 1000 	total rewards	 136.1965001397366
# steps	 1500 	total rewards	 196.6416233129279
# Finished after 1742 timesteps (4.225741147994995 seconds) with total reward 228.19652141645383
# {'coverage_prop': '0.977', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.174', 'efficiency': '0.175', 'TP': '232', 'FP': '27', 'FN': '6', 'precision': '0.896', 'recall': '0.975', 'f1': '0.934', 'total_rewards': 228.19652141645355, 'invalid_action_count': 7, 'num_ms1_scans': 258, 'num_ms2_scans': 1484}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 69.85400754391287
# steps	 1000 	total rewards	 155.7547996054648
# steps	 1500 	total rewards	 231.09259512236105
# Finished after 1772 timesteps (3.7721121311187744 seconds) with total reward 271.59440406485095
# {'coverage_prop': '0.904', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.148', 'efficiency': '0.274', 'TP': '369', 'FP': '54', 'FN': '45', 'precision': '0.872', 'recall': '0.891', 'f1': '0.882', 'total_rewards': 271.5944040648507, 'invalid_action_count': 2, 'num_ms1_scans': 228, 'num_ms2_scans': 1544}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 59.206899067087505
# steps	 1000 	total rewards	 125.61368263266394
# steps	 1500 	total rewards	 188.90928634827503
# Finished after 1699 timesteps (2.964982032775879 seconds) with total reward 207.06272919287423
# {'coverage_prop': '0.949', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.215', 'efficiency': '0.159', 'TP': '202', 'FP': '20', 'FN': '12', 'precision': '0.910', 'recall': '0.944', 'f1': '0.927', 'total_rewards': 207.06272919287426, 'invalid_action_count': 16, 'num_ms1_scans': 301, 'num_ms2_scans': 1398}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 68.52642378536027
# steps	 1000 	total rewards	 142.39659604184146
# steps	 1500 	total rewards	 213.84077681226933
# Finished after 1751 timesteps (3.1397743225097656 seconds) with total reward 250.5368689993736
# {'coverage_prop': '0.966', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.166', 'efficiency': '0.207', 'TP': '282', 'FP': '29', 'FN': '11', 'precision': '0.907', 'recall': '0.962', 'f1': '0.934', 'total_rewards': 250.53686899937327, 'invalid_action_count': 3, 'num_ms1_scans': 249, 'num_ms2_scans': 1502}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 62.77801354543939
# steps	 1000 	total rewards	 137.38734344650703
# steps	 1500 	total rewards	 207.2869579503984
# Finished after 1729 timesteps (4.604088068008423 seconds) with total reward 238.78274464551123
# {'coverage_prop': '0.945', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.186', 'efficiency': '0.201', 'TP': '263', 'FP': '30', 'FN': '17', 'precision': '0.898', 'recall': '0.939', 'f1': '0.918', 'total_rewards': 238.78274464551134, 'invalid_action_count': 6, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 65.73098744625437
# steps	 1000 	total rewards	 147.43897024854118
# steps	 1500 	total rewards	 216.4659603247982
# Finished after 1746 timesteps (3.3303680419921875 seconds) with total reward 253.05828566653742
# {'coverage_prop': '0.962', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.170', 'efficiency': '0.223', 'TP': '293', 'FP': '39', 'FN': '13', 'precision': '0.883', 'recall': '0.958', 'f1': '0.918', 'total_rewards': 253.05828566653736, 'invalid_action_count': 2, 'num_ms1_scans': 254, 'num_ms2_scans': 1492}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 69.51456820669544
# steps	 1000 	total rewards	 140.4058180371143
# steps	 1500 	total rewards	 219.297435135292
# Finished after 1773 timesteps (3.729526996612549 seconds) with total reward 257.41763828553337
# {'coverage_prop': '0.967', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.147', 'efficiency': '0.248', 'TP': '338', 'FP': '45', 'FN': '13', 'precision': '0.883', 'recall': '0.963', 'f1': '0.921', 'total_rewards': 257.4176382855329, 'invalid_action_count': 4, 'num_ms1_scans': 227, 'num_ms2_scans': 1546}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 53.22014212579916
# steps	 1000 	total rewards	 113.47589413559642
# steps	 1500 	total rewards	 170.94476192094368
# Finished after 1698 timesteps (3.353111982345581 seconds) with total reward 192.08169588873687
# {'coverage_prop': '0.956', 'intensity_prop': '0.803', 'ms1ms2_ratio': '0.216', 'efficiency': '0.139', 'TP': '184', 'FP': '10', 'FN': '9', 'precision': '0.948', 'recall': '0.953', 'f1': '0.951', 'total_rewards': 192.08169588873722, 'invalid_action_count': 13, 'num_ms1_scans': 302, 'num_ms2_scans': 1396}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 62.416679656476454
# steps	 1000 	total rewards	 132.37737389266638
# steps	 1500 	total rewards	 200.15724266327283
# Finished after 1724 timesteps (3.9973630905151367 seconds) with total reward 235.91738514705202
# {'coverage_prop': '0.961', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.191', 'efficiency': '0.186', 'TP': '252', 'FP': '18', 'FN': '11', 'precision': '0.933', 'recall': '0.958', 'f1': '0.946', 'total_rewards': 235.91738514705213, 'invalid_action_count': 7, 'num_ms1_scans': 276, 'num_ms2_scans': 1448}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 79.12791944678236
# steps	 1000 	total rewards	 159.93760173506166
# steps	 1500 	total rewards	 238.76418370670356
# Finished after 1782 timesteps (4.194809913635254 seconds) with total reward 279.8500215476286
# {'coverage_prop': '0.895', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.139', 'efficiency': '0.282', 'TP': '367', 'FP': '74', 'FN': '52', 'precision': '0.832', 'recall': '0.876', 'f1': '0.853', 'total_rewards': 279.85002154762896, 'invalid_action_count': 4, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 62.04490058372941
# steps	 1000 	total rewards	 136.76357621067913
# steps	 1500 	total rewards	 202.28209310411097
# Finished after 1745 timesteps (3.394927978515625 seconds) with total reward 235.20837298561517
# {'coverage_prop': '0.954', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.171', 'efficiency': '0.195', 'TP': '263', 'FP': '27', 'FN': '14', 'precision': '0.907', 'recall': '0.949', 'f1': '0.928', 'total_rewards': 235.2083729856152, 'invalid_action_count': 7, 'num_ms1_scans': 255, 'num_ms2_scans': 1490}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 59.39818191121025
# steps	 1000 	total rewards	 138.5720354265331
# steps	 1500 	total rewards	 216.50731766728592
# Finished after 1722 timesteps (9.31814694404602 seconds) with total reward 246.07141932758293
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 246.0714193275831, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 49.80161912604831
# steps	 1000 	total rewards	 119.66530569651563
# steps	 1500 	total rewards	 182.3992088220571
# Finished after 1556 timesteps (8.09772801399231 seconds) with total reward 187.702141952342
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 187.70214195234212, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 51.29301484412087
# steps	 1000 	total rewards	 125.26814493487129
# steps	 1500 	total rewards	 199.36020268664623
# Finished after 1669 timesteps (9.052872896194458 seconds) with total reward 220.9268071029097
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 220.92680710290975, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 64.69221918652914
# steps	 1000 	total rewards	 139.94091009129198
# steps	 1500 	total rewards	 210.17085329269364
# Finished after 1717 timesteps (10.768533945083618 seconds) with total reward 241.4853865752503
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 241.48538657525012, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 56.35584713914693
# steps	 1000 	total rewards	 137.785216868901
# steps	 1500 	total rewards	 214.6881814813977
# Finished after 1704 timesteps (9.244370937347412 seconds) with total reward 243.52717224427786
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 243.52717224427778, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 36.85977339249479
# steps	 1000 	total rewards	 97.24997682559521
# Finished after 1408 timesteps (7.325623035430908 seconds) with total reward 130.37118689369876
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 130.37118689369868, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 61.83065113097078
# steps	 1000 	total rewards	 142.56596201074652
# steps	 1500 	total rewards	 214.3361857069055
# Finished after 1744 timesteps (11.11838412284851 seconds) with total reward 247.45355319082682
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 247.45355319082682, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 36.7169139046746
# steps	 1000 	total rewards	 107.55288808607207
# Finished after 1468 timesteps (7.759747266769409 seconds) with total reward 154.88443368221024
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 154.88443368221022, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 63.69932181538106
# steps	 1000 	total rewards	 135.50525156126935
# steps	 1500 	total rewards	 209.02143440684972
# Finished after 1736 timesteps (10.004841089248657 seconds) with total reward 240.33224302373395
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 240.3322430237338, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 51.650777099447936
# steps	 1000 	total rewards	 125.19839863770888
# steps	 1500 	total rewards	 199.70280782087247
# Finished after 1667 timesteps (14.98177170753479 seconds) with total reward 217.68242373898718
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 217.68242373898724, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 58.73325228414852
# steps	 1000 	total rewards	 135.05027654333225
# steps	 1500 	total rewards	 210.82813437149593
# Finished after 1737 timesteps (9.787112951278687 seconds) with total reward 242.4599445757275
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 242.45994457572795, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 44.480522347636935
# steps	 1000 	total rewards	 111.26720284815937
# steps	 1500 	total rewards	 159.55269808514626
# Finished after 1530 timesteps (7.898222923278809 seconds) with total reward 162.24444510207155
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 162.24444510207155, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 45.39252917269736
# steps	 1000 	total rewards	 111.72437799007685
# steps	 1500 	total rewards	 174.84141305174293
# Finished after 1602 timesteps (10.435180902481079 seconds) with total reward 186.07155417023205
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 186.07155417023196, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 49.15360821284917
# steps	 1000 	total rewards	 119.6031795309076
# steps	 1500 	total rewards	 184.6587961709919
# Finished after 1645 timesteps (8.87674593925476 seconds) with total reward 198.81613111042032
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 198.81613111042054, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 38.660879944836125
# steps	 1000 	total rewards	 104.6229891790933
# Finished after 1497 timesteps (7.516690254211426 seconds) with total reward 155.6062870524459
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 155.60628705244605, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 51.44764050188936
# steps	 1000 	total rewards	 128.8143354572842
# steps	 1500 	total rewards	 198.00886489737445
# Finished after 1655 timesteps (10.85332989692688 seconds) with total reward 218.38188038198132
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 218.3818803819814, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 62.70461590148102
# steps	 1000 	total rewards	 139.29462868404227
# steps	 1500 	total rewards	 216.17781227924297
# Finished after 1729 timesteps (9.57499384880066 seconds) with total reward 246.00395093770442
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 246.00395093770413, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 58.42443886984613
# steps	 1000 	total rewards	 134.48739921356457
# steps	 1500 	total rewards	 203.27761145212088
# Finished after 1681 timesteps (8.76989197731018 seconds) with total reward 224.5758684609182
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 224.57586846091846, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 46.70791752204587
# steps	 1000 	total rewards	 119.38068923043548
# steps	 1500 	total rewards	 187.44753687163077
# Finished after 1621 timesteps (8.39835810661316 seconds) with total reward 200.0943415427971
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 200.09434154279748, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 47.97066074112459
# steps	 1000 	total rewards	 117.80237298317604
# steps	 1500 	total rewards	 180.4080084670927
# Finished after 1634 timesteps (9.934736013412476 seconds) with total reward 196.08351966112917
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 196.0835196611289, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 62.264924262774656
# steps	 1000 	total rewards	 139.851120208098
# steps	 1500 	total rewards	 213.07257580533394
# Finished after 1726 timesteps (9.507129192352295 seconds) with total reward 245.11037209771413
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 245.11037209771456, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 39.38367416005345
# steps	 1000 	total rewards	 106.71603693124862
# Finished after 1475 timesteps (7.695505142211914 seconds) with total reward 153.20481810659373
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 153.2048181065938, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 53.11142262146333
# steps	 1000 	total rewards	 124.27370748618455
# steps	 1500 	total rewards	 193.48348271444524
# Finished after 1636 timesteps (8.2826988697052 seconds) with total reward 209.13347304634203
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 209.13347304634198, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 52.33369295169392
# steps	 1000 	total rewards	 125.90752415102662
# steps	 1500 	total rewards	 185.4895286328575
# Finished after 1575 timesteps (10.369323968887329 seconds) with total reward 192.07315619040207
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 192.07315619040207, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 51.359324220773956
# steps	 1000 	total rewards	 128.20122403599643
# steps	 1500 	total rewards	 199.61646960616366
# Finished after 1681 timesteps (8.740149736404419 seconds) with total reward 222.65188021845023
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 222.65188021845015, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 53.486927712012815
# steps	 1000 	total rewards	 122.3230387222704
# steps	 1500 	total rewards	 197.5573745494595
# Finished after 1679 timesteps (8.988255023956299 seconds) with total reward 218.69830459399594
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 218.69830459399566, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 36.900191107476665
# steps	 1000 	total rewards	 100.79174218983904
# Finished after 1465 timesteps (7.559606075286865 seconds) with total reward 144.91480985494655
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 144.9148098549467, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 48.149666789891
# steps	 1000 	total rewards	 118.19535529379077
# steps	 1500 	total rewards	 180.83050390836837
# Finished after 1564 timesteps (10.121047973632812 seconds) with total reward 188.7400005085405
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 188.74000050854016, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 67.50510674505492
# steps	 1000 	total rewards	 139.962212241089
# steps	 1500 	total rewards	 216.28971565908762
# Finished after 1749 timesteps (10.137259006500244 seconds) with total reward 252.95716387797603
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 252.95716387797603, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 51.975984210899966
# steps	 1000 	total rewards	 123.10203982392332
# steps	 1500 	total rewards	 187.76545015733265
# Finished after 1657 timesteps (8.512562274932861 seconds) with total reward 206.1422481395321
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 206.14224813953206, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ad5e69df0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7aa0766310>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7aa07835b0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.791', 'efficiency': '0.537', 'TP': '357', 'FP': '59', 'FN': '10', 'precision': '0.858', 'recall': '0.973', 'f1': '0.912'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '221', 'FP': '31', 'FN': '10', 'precision': '0.877', 'recall': '0.957', 'f1': '0.915'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.858', 'efficiency': '0.518', 'TP': '326', 'FP': '56', 'FN': '12', 'precision': '0.853', 'recall': '0.964', 'f1': '0.906'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '367', 'FP': '66', 'FN': '4', 'precision': '0.848', 'recall': '0.989', 'f1': '0.913'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.685', 'efficiency': '0.544', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.719', 'ms1ms2_ratio': '2.080', 'efficiency': '0.505', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.718', 'ms1ms2_ratio': '0.901', 'efficiency': '0.521', 'TP': '324', 'FP': '48', 'FN': '12', 'precision': '0.871', 'recall': '0.964', 'f1': '0.915'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.688', 'efficiency': '0.508', 'TP': '384', 'FP': '44', 'FN': '15', 'precision': '0.897', 'recall': '0.962', 'f1': '0.929'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.665', 'ms1ms2_ratio': '1.615', 'efficiency': '0.503', 'TP': '196', 'FP': '42', 'FN': '13', 'precision': '0.824', 'recall': '0.938', 'f1': '0.877'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.686', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.861', 'efficiency': '0.541', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.737', 'ms1ms2_ratio': '0.598', 'efficiency': '0.535', 'TP': '430', 'FP': '57', 'FN': '11', 'precision': '0.883', 'recall': '0.975', 'f1': '0.927'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '310', 'FP': '50', 'FN': '12', 'precision': '0.861', 'recall': '0.963', 'f1': '0.909'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.704', 'ms1ms2_ratio': '1.254', 'efficiency': '0.512', 'TP': '246', 'FP': '46', 'FN': '10', 'precision': '0.842', 'recall': '0.961', 'f1': '0.898'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.828', 'efficiency': '0.519', 'TP': '193', 'FP': '30', 'FN': '11', 'precision': '0.865', 'recall': '0.946', 'f1': '0.904'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.965', 'efficiency': '0.496', 'TP': '300', 'FP': '39', 'FN': '6', 'precision': '0.885', 'recall': '0.980', 'f1': '0.930'}
#
# Episode 25 finished
# {'coverage_prop': '0.990', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.859', 'efficiency': '0.533', 'TP': '330', 'FP': '62', 'FN': '4', 'precision': '0.842', 'recall': '0.988', 'f1': '0.909'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.711', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '169', 'FP': '28', 'FN': '6', 'precision': '0.858', 'recall': '0.966', 'f1': '0.909'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.721', 'ms1ms2_ratio': '1.370', 'efficiency': '0.508', 'TP': '243', 'FP': '29', 'FN': '9', 'precision': '0.893', 'recall': '0.964', 'f1': '0.927'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.586', 'efficiency': '0.520', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.728', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '266', 'FP': '29', 'FN': '9', 'precision': '0.902', 'recall': '0.967', 'f1': '0.933'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1843.137673                1874.0          0.376           0.105
# 1  random   -1901.082437                1920.0          0.309           0.074
# 2  random   -1815.576244                1852.0          0.439           0.110
# 3  random   -1890.673123                1911.0          0.277           0.072
# 4  random   -1863.368175                1890.0          0.366           0.088
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.081      0.256   0.134  0.176
# 1          0.005       0.041      0.222   0.090  0.129
# 2          0.007       0.088      0.208   0.140  0.167
# 3          0.004       0.063      0.256   0.089  0.132
# 4          0.005       0.081      0.219   0.112  0.148

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     264.497901                  11.0          0.937           0.717
# 31    DQN     236.107037                  11.0          0.958           0.801
# 32    DQN     247.048542                   9.0          0.954           0.725
# 33    DQN     261.981319                   6.0          0.947           0.732
# 34    DQN     262.075377                  10.0          0.973           0.733
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.145       0.257      0.862   0.927  0.894
# 31          0.194       0.174      0.924   0.955  0.939
# 32          0.167       0.251      0.867   0.948  0.906
# 33          0.150       0.278      0.895   0.941  0.917
# 34          0.152       0.277      0.845   0.968  0.902

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
