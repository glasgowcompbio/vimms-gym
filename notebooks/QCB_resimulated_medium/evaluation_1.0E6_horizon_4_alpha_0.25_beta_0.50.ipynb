# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-06 00:47:55.004 | INFO     | experiments:get_samplers:267 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9a1847df70>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f99f80eb3d0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f99f8107670>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9a1847df70>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f99f80eb3d0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f99f8107670>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9a1847df70>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f99f80eb3d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f99f8107670>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        # fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -982.3384000726594
# steps	 1500 	total rewards	 -1423.0783044560055
# Finished after 1992 timesteps (1.8731787204742432 seconds) with total reward -1852.0650676555292
# {'coverage_prop': '0.338', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.004', 'efficiency': '0.073', 'TP': '27', 'FP': '117', 'FN': '282', 'precision': '0.188', 'recall': '0.087', 'f1': '0.119', 'total_rewards': -1852.0650676555301, 'invalid_action_count': 1882, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -486.9828675439439
# steps	 1000 	total rewards	 -962.0584689889658
# steps	 1500 	total rewards	 -1437.655339952507
# Finished after 1990 timesteps (0.9821040630340576 seconds) with total reward -1907.4519218048026
# {'coverage_prop': '0.244', 'intensity_prop': '0.057', 'ms1ms2_ratio': '0.005', 'efficiency': '0.032', 'TP': '13', 'FP': '51', 'FN': '198', 'precision': '0.203', 'recall': '0.062', 'f1': '0.095', 'total_rewards': -1907.4519218048026, 'invalid_action_count': 1924, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -497.60202908309134
# steps	 1000 	total rewards	 -950.7688994729956
# steps	 1500 	total rewards	 -1385.4434948457122
# Finished after 1987 timesteps (1.4612791538238525 seconds) with total reward -1835.7146154976435
# {'coverage_prop': '0.409', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.007', 'efficiency': '0.082', 'TP': '34', 'FP': '127', 'FN': '233', 'precision': '0.211', 'recall': '0.127', 'f1': '0.159', 'total_rewards': -1835.7146154976435, 'invalid_action_count': 1867, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -487.9195966998759
# steps	 1000 	total rewards	 -964.8790245604728
# steps	 1500 	total rewards	 -1458.5522228689074
# Finished after 1994 timesteps (1.678002119064331 seconds) with total reward -1913.7595939256175
# {'coverage_prop': '0.219', 'intensity_prop': '0.052', 'ms1ms2_ratio': '0.003', 'efficiency': '0.050', 'TP': '22', 'FP': '77', 'FN': '353', 'precision': '0.222', 'recall': '0.059', 'f1': '0.093', 'total_rewards': -1913.7595939256178, 'invalid_action_count': 1930, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -492.0135091273153
# steps	 1000 	total rewards	 -936.9029627314962
# steps	 1500 	total rewards	 -1376.9452452379523
# Finished after 1985 timesteps (1.4367132186889648 seconds) with total reward -1814.5872843222369
# {'coverage_prop': '0.432', 'intensity_prop': '0.113', 'ms1ms2_ratio': '0.008', 'efficiency': '0.096', 'TP': '42', 'FP': '147', 'FN': '248', 'precision': '0.222', 'recall': '0.145', 'f1': '0.175', 'total_rewards': -1814.587284322237, 'invalid_action_count': 1852, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -969.5123931584822
# steps	 1500 	total rewards	 -1434.9848022494452
# Finished after 1987 timesteps (0.8922719955444336 seconds) with total reward -1903.553461797465
# {'coverage_prop': '0.365', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.007', 'efficiency': '0.037', 'TP': '20', 'FP': '53', 'FN': '127', 'precision': '0.274', 'recall': '0.136', 'f1': '0.182', 'total_rewards': -1903.553461797465, 'invalid_action_count': 1920, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -491.050925667664
# steps	 1000 	total rewards	 -928.957096328413
# steps	 1500 	total rewards	 -1379.4636571774265
# Finished after 1990 timesteps (1.459733009338379 seconds) with total reward -1832.5487954492044
# {'coverage_prop': '0.379', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.005', 'efficiency': '0.091', 'TP': '35', 'FP': '146', 'FN': '297', 'precision': '0.193', 'recall': '0.105', 'f1': '0.136', 'total_rewards': -1832.5487954492035, 'invalid_action_count': 1867, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -490.3752458012199
# steps	 1000 	total rewards	 -958.6733280621224
# steps	 1500 	total rewards	 -1442.2022247578725
# Finished after 1984 timesteps (0.908146858215332 seconds) with total reward -1903.439225152329
# {'coverage_prop': '0.255', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.008', 'efficiency': '0.026', 'TP': '10', 'FP': '42', 'FN': '152', 'precision': '0.192', 'recall': '0.062', 'f1': '0.093', 'total_rewards': -1903.4392251523288, 'invalid_action_count': 1918, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -488.1663856918666
# steps	 1000 	total rewards	 -962.1124052764942
# steps	 1500 	total rewards	 -1390.5244794198716
# Finished after 1985 timesteps (1.4837050437927246 seconds) with total reward -1835.2016303080445
# {'coverage_prop': '0.328', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.008', 'efficiency': '0.071', 'TP': '28', 'FP': '111', 'FN': '285', 'precision': '0.201', 'recall': '0.089', 'f1': '0.124', 'total_rewards': -1835.2016303080445, 'invalid_action_count': 1866, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -489.62837146014607
# steps	 1000 	total rewards	 -950.4658668630992
# steps	 1500 	total rewards	 -1379.5379772107808
# Finished after 1989 timesteps (1.3447718620300293 seconds) with total reward -1828.8656901805023
# {'coverage_prop': '0.411', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.006', 'efficiency': '0.080', 'TP': '38', 'FP': '120', 'FN': '226', 'precision': '0.241', 'recall': '0.144', 'f1': '0.180', 'total_rewards': -1828.8656901805023, 'invalid_action_count': 1864, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -491.10372359839835
# steps	 1000 	total rewards	 -963.9903854750953
# steps	 1500 	total rewards	 -1435.1693312941375
# Finished after 1993 timesteps (1.4174349308013916 seconds) with total reward -1893.0660080944663
# {'coverage_prop': '0.278', 'intensity_prop': '0.069', 'ms1ms2_ratio': '0.004', 'efficiency': '0.062', 'TP': '28', 'FP': '95', 'FN': '320', 'precision': '0.228', 'recall': '0.080', 'f1': '0.119', 'total_rewards': -1893.0660080944665, 'invalid_action_count': 1914, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -482.4046808926456
# steps	 1000 	total rewards	 -949.4902393297771
# steps	 1500 	total rewards	 -1407.9304151344918
# Finished after 1986 timesteps (1.007767915725708 seconds) with total reward -1875.5332098744884
# {'coverage_prop': '0.369', 'intensity_prop': '0.131', 'ms1ms2_ratio': '0.007', 'efficiency': '0.047', 'TP': '33', 'FP': '59', 'FN': '157', 'precision': '0.359', 'recall': '0.174', 'f1': '0.234', 'total_rewards': -1875.5332098744893, 'invalid_action_count': 1897, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -488.18398469883095
# steps	 1000 	total rewards	 -965.0387881705417
# steps	 1500 	total rewards	 -1436.678281602636
# Finished after 1990 timesteps (1.0397372245788574 seconds) with total reward -1901.1127421167648
# {'coverage_prop': '0.299', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.005', 'efficiency': '0.038', 'TP': '13', 'FP': '62', 'FN': '176', 'precision': '0.173', 'recall': '0.069', 'f1': '0.098', 'total_rewards': -1901.1127421167648, 'invalid_action_count': 1918, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -491.1864503147423
# steps	 1000 	total rewards	 -981.0839456161984
# steps	 1500 	total rewards	 -1431.216727272344
# Finished after 1992 timesteps (1.1648919582366943 seconds) with total reward -1877.5024599383075
# {'coverage_prop': '0.397', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.004', 'efficiency': '0.060', 'TP': '28', 'FP': '91', 'FN': '181', 'precision': '0.235', 'recall': '0.134', 'f1': '0.171', 'total_rewards': -1877.5024599383073, 'invalid_action_count': 1901, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -480.7307043101803
# steps	 1000 	total rewards	 -953.0297214135007
# steps	 1500 	total rewards	 -1410.2176585571456
# Finished after 1982 timesteps (0.9542241096496582 seconds) with total reward -1881.2293912858813
# {'coverage_prop': '0.306', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.009', 'efficiency': '0.032', 'TP': '22', 'FP': '41', 'FN': '143', 'precision': '0.349', 'recall': '0.133', 'f1': '0.193', 'total_rewards': -1881.2293912858813, 'invalid_action_count': 1898, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -487.887768892815
# steps	 1000 	total rewards	 -956.1273659598387
# steps	 1500 	total rewards	 -1394.4441785654135
# Finished after 1988 timesteps (1.323826789855957 seconds) with total reward -1854.1019823026854
# {'coverage_prop': '0.386', 'intensity_prop': '0.106', 'ms1ms2_ratio': '0.006', 'efficiency': '0.079', 'TP': '45', 'FP': '112', 'FN': '250', 'precision': '0.287', 'recall': '0.153', 'f1': '0.199', 'total_rewards': -1854.101982302686, 'invalid_action_count': 1882, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -468.8378201587375
# steps	 1000 	total rewards	 -938.5629566441136
# steps	 1500 	total rewards	 -1356.902623149111
# Finished after 1985 timesteps (1.7731800079345703 seconds) with total reward -1791.6838373609949
# {'coverage_prop': '0.442', 'intensity_prop': '0.121', 'ms1ms2_ratio': '0.008', 'efficiency': '0.112', 'TP': '53', 'FP': '167', 'FN': '278', 'precision': '0.241', 'recall': '0.160', 'f1': '0.192', 'total_rewards': -1791.683837360995, 'invalid_action_count': 1833, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -477.95095864411485
# steps	 1000 	total rewards	 -950.9269457287721
# steps	 1500 	total rewards	 -1385.9999158378478
# Finished after 1989 timesteps (1.4306559562683105 seconds) with total reward -1829.4038280121931
# {'coverage_prop': '0.414', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.006', 'efficiency': '0.078', 'TP': '29', 'FP': '125', 'FN': '218', 'precision': '0.188', 'recall': '0.117', 'f1': '0.145', 'total_rewards': -1829.4038280121927, 'invalid_action_count': 1863, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -482.5618961950066
# steps	 1000 	total rewards	 -953.3987077334721
# steps	 1500 	total rewards	 -1396.4650589658104
# Finished after 1982 timesteps (1.9723429679870605 seconds) with total reward -1828.489591400641
# {'coverage_prop': '0.457', 'intensity_prop': '0.134', 'ms1ms2_ratio': '0.009', 'efficiency': '0.070', 'TP': '36', 'FP': '102', 'FN': '164', 'precision': '0.261', 'recall': '0.180', 'f1': '0.213', 'total_rewards': -1828.489591400641, 'invalid_action_count': 1862, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -484.83612750469837
# steps	 1000 	total rewards	 -947.782151859049
# steps	 1500 	total rewards	 -1401.1550020151112
# Finished after 1985 timesteps (1.2249679565429688 seconds) with total reward -1855.7112931193658
# {'coverage_prop': '0.381', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.008', 'efficiency': '0.051', 'TP': '24', 'FP': '77', 'FN': '164', 'precision': '0.238', 'recall': '0.128', 'f1': '0.166', 'total_rewards': -1855.7112931193658, 'invalid_action_count': 1882, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -463.89087633215587
# steps	 1000 	total rewards	 -921.5493793515982
# steps	 1500 	total rewards	 -1409.9711770152153
# Finished after 1988 timesteps (2.0244617462158203 seconds) with total reward -1859.1499437948312
# {'coverage_prop': '0.316', 'intensity_prop': '0.071', 'ms1ms2_ratio': '0.006', 'efficiency': '0.075', 'TP': '30', 'FP': '118', 'FN': '320', 'precision': '0.203', 'recall': '0.086', 'f1': '0.120', 'total_rewards': -1859.1499437948314, 'invalid_action_count': 1887, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -479.14331302620616
# steps	 1000 	total rewards	 -958.6093490012216
# steps	 1500 	total rewards	 -1441.2075162525434
# Finished after 1986 timesteps (1.2316920757293701 seconds) with total reward -1900.2448209794316
# {'coverage_prop': '0.303', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.007', 'efficiency': '0.036', 'TP': '19', 'FP': '52', 'FN': '163', 'precision': '0.268', 'recall': '0.104', 'f1': '0.150', 'total_rewards': -1900.2448209794316, 'invalid_action_count': 1918, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -959.5544776556297
# steps	 1500 	total rewards	 -1405.9943100087667
# Finished after 1989 timesteps (1.4874110221862793 seconds) with total reward -1864.5595668516235
# {'coverage_prop': '0.391', 'intensity_prop': '0.098', 'ms1ms2_ratio': '0.006', 'efficiency': '0.064', 'TP': '27', 'FP': '99', 'FN': '196', 'precision': '0.214', 'recall': '0.121', 'f1': '0.155', 'total_rewards': -1864.5595668516235, 'invalid_action_count': 1891, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -487.4648502993342
# steps	 1000 	total rewards	 -981.0068607506545
# steps	 1500 	total rewards	 -1436.5994309100602
# Finished after 1992 timesteps (1.1784019470214844 seconds) with total reward -1904.8958056010651
# {'coverage_prop': '0.271', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.004', 'efficiency': '0.042', 'TP': '18', 'FP': '66', 'FN': '226', 'precision': '0.214', 'recall': '0.074', 'f1': '0.110', 'total_rewards': -1904.895805601065, 'invalid_action_count': 1923, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -493.855174243515
# steps	 1000 	total rewards	 -943.8636647990829
# steps	 1500 	total rewards	 -1377.8211629777516
# Finished after 1988 timesteps (1.3960812091827393 seconds) with total reward -1830.3132046187197
# {'coverage_prop': '0.412', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.006', 'efficiency': '0.072', 'TP': '34', 'FP': '108', 'FN': '203', 'precision': '0.239', 'recall': '0.143', 'f1': '0.179', 'total_rewards': -1830.3132046187193, 'invalid_action_count': 1863, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -492.47977628877095
# steps	 1000 	total rewards	 -949.1588657238171
# steps	 1500 	total rewards	 -1391.9256071247069
# Finished after 1987 timesteps (2.0142438411712646 seconds) with total reward -1831.3312866500587
# {'coverage_prop': '0.419', 'intensity_prop': '0.122', 'ms1ms2_ratio': '0.007', 'efficiency': '0.084', 'TP': '46', 'FP': '120', 'FN': '230', 'precision': '0.277', 'recall': '0.167', 'f1': '0.208', 'total_rewards': -1831.3312866500585, 'invalid_action_count': 1865, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -493.9198624970361
# steps	 1000 	total rewards	 -993.9198624970361
# steps	 1500 	total rewards	 -1472.2735539425657
# Finished after 1991 timesteps (1.1454529762268066 seconds) with total reward -1939.9001776131888
# {'coverage_prop': '0.207', 'intensity_prop': '0.038', 'ms1ms2_ratio': '0.005', 'efficiency': '0.021', 'TP': '6', 'FP': '36', 'FN': '161', 'precision': '0.143', 'recall': '0.036', 'f1': '0.057', 'total_rewards': -1939.900177613189, 'invalid_action_count': 1950, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -495.2656367678999
# steps	 1000 	total rewards	 -961.7750685170744
# steps	 1500 	total rewards	 -1401.1818920703492
# Finished after 1987 timesteps (1.5166800022125244 seconds) with total reward -1869.3974794558167
# {'coverage_prop': '0.352', 'intensity_prop': '0.087', 'ms1ms2_ratio': '0.007', 'efficiency': '0.050', 'TP': '21', 'FP': '78', 'FN': '182', 'precision': '0.212', 'recall': '0.103', 'f1': '0.139', 'total_rewards': -1869.3974794558167, 'invalid_action_count': 1895, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -497.61566036177226
# steps	 1000 	total rewards	 -958.5609305565231
# steps	 1500 	total rewards	 -1395.961687580208
# Finished after 1988 timesteps (1.7616429328918457 seconds) with total reward -1819.4609233152805
# {'coverage_prop': '0.355', 'intensity_prop': '0.102', 'ms1ms2_ratio': '0.006', 'efficiency': '0.089', 'TP': '43', 'FP': '132', 'FN': '318', 'precision': '0.246', 'recall': '0.119', 'f1': '0.160', 'total_rewards': -1819.4609233152805, 'invalid_action_count': 1856, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -1000.0
# steps	 1500 	total rewards	 -1470.08552922898
# Finished after 1994 timesteps (1.3259930610656738 seconds) with total reward -1921.1552874450176
# {'coverage_prop': '0.243', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.003', 'efficiency': '0.037', 'TP': '21', 'FP': '53', 'FN': '230', 'precision': '0.284', 'recall': '0.084', 'f1': '0.129', 'total_rewards': -1921.155287445018, 'invalid_action_count': 1937, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.39GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 73.02641870240038
# steps	 1000 	total rewards	 152.98028533260594
# steps	 1500 	total rewards	 226.1615897296702
# Finished after 1780 timesteps (5.474840879440308 seconds) with total reward 263.328169681718
# {'coverage_prop': '0.948', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.141', 'efficiency': '0.259', 'TP': '343', 'FP': '61', 'FN': '22', 'precision': '0.849', 'recall': '0.940', 'f1': '0.892', 'total_rewards': 263.32816968171835, 'invalid_action_count': 14, 'num_ms1_scans': 220, 'num_ms2_scans': 1560}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 65.70835608734258
# steps	 1000 	total rewards	 141.35152949711872
# steps	 1500 	total rewards	 215.71771510206256
# Finished after 1720 timesteps (4.132112979888916 seconds) with total reward 245.82319020926508
# {'coverage_prop': '0.958', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.194', 'efficiency': '0.174', 'TP': '232', 'FP': '19', 'FN': '11', 'precision': '0.924', 'recall': '0.955', 'f1': '0.939', 'total_rewards': 245.82319020926502, 'invalid_action_count': 2, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 61.79443607714025
# steps	 1000 	total rewards	 141.82318992233985
# steps	 1500 	total rewards	 214.606894096514
# Finished after 1747 timesteps (5.770755052566528 seconds) with total reward 251.58286308814132
# {'coverage_prop': '0.954', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.169', 'efficiency': '0.252', 'TP': '319', 'FP': '57', 'FN': '18', 'precision': '0.848', 'recall': '0.947', 'f1': '0.895', 'total_rewards': 251.58286308814152, 'invalid_action_count': 5, 'num_ms1_scans': 253, 'num_ms2_scans': 1494}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 73.91612236964541
# steps	 1000 	total rewards	 154.98664159071416
# steps	 1500 	total rewards	 225.80534583133317
# Finished after 1774 timesteps (5.497663974761963 seconds) with total reward 265.6415775466569
# {'coverage_prop': '0.938', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.146', 'efficiency': '0.274', 'TP': '381', 'FP': '43', 'FN': '28', 'precision': '0.899', 'recall': '0.932', 'f1': '0.915', 'total_rewards': 265.6415775466569, 'invalid_action_count': 4, 'num_ms1_scans': 226, 'num_ms2_scans': 1548}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 66.96065007217067
# steps	 1000 	total rewards	 148.30232920441637
# steps	 1500 	total rewards	 229.78801606282335
# Finished after 1765 timesteps (6.467495918273926 seconds) with total reward 264.0174172502177
# {'coverage_prop': '0.963', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.154', 'efficiency': '0.275', 'TP': '357', 'FP': '64', 'FN': '16', 'precision': '0.848', 'recall': '0.957', 'f1': '0.899', 'total_rewards': 264.01741725021793, 'invalid_action_count': 7, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 53.758840069319184
# steps	 1000 	total rewards	 121.33734035646594
# steps	 1500 	total rewards	 179.08668730196166
# Finished after 1680 timesteps (4.424466848373413 seconds) with total reward 199.63020944930605
# {'coverage_prop': '0.955', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.235', 'efficiency': '0.140', 'TP': '183', 'FP': '8', 'FN': '9', 'precision': '0.958', 'recall': '0.953', 'f1': '0.956', 'total_rewards': 199.63020944930608, 'invalid_action_count': 7, 'num_ms1_scans': 320, 'num_ms2_scans': 1360}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 67.48390100197201
# steps	 1000 	total rewards	 150.48145748489912
# steps	 1500 	total rewards	 222.06938200110358
# Finished after 1781 timesteps (7.009555816650391 seconds) with total reward 263.1316315729689
# {'coverage_prop': '0.927', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.141', 'efficiency': '0.284', 'TP': '373', 'FP': '70', 'FN': '35', 'precision': '0.842', 'recall': '0.914', 'f1': '0.877', 'total_rewards': 263.13163157296907, 'invalid_action_count': 7, 'num_ms1_scans': 220, 'num_ms2_scans': 1561}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 55.436527863661496
# steps	 1000 	total rewards	 132.61396638278896
# steps	 1500 	total rewards	 199.5730446002598
# Finished after 1691 timesteps (5.034727096557617 seconds) with total reward 223.09158704264573
# {'coverage_prop': '0.956', 'intensity_prop': '0.805', 'ms1ms2_ratio': '0.224', 'efficiency': '0.141', 'TP': '184', 'FP': '11', 'FN': '9', 'precision': '0.944', 'recall': '0.953', 'f1': '0.948', 'total_rewards': 223.09158704264593, 'invalid_action_count': 4, 'num_ms1_scans': 309, 'num_ms2_scans': 1382}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 77.26528189546133
# steps	 1000 	total rewards	 152.74682658999393
# steps	 1500 	total rewards	 231.4750758771335
# Finished after 1789 timesteps (4.289277076721191 seconds) with total reward 266.0747615740345
# {'coverage_prop': '0.943', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.134', 'efficiency': '0.253', 'TP': '351', 'FP': '49', 'FN': '24', 'precision': '0.877', 'recall': '0.936', 'f1': '0.906', 'total_rewards': 266.07476157403454, 'invalid_action_count': 8, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 66.13477374904357
# steps	 1000 	total rewards	 144.17381801162156
# steps	 1500 	total rewards	 220.28848309294716
# Finished after 1761 timesteps (5.897495746612549 seconds) with total reward 251.14251625228488
# {'coverage_prop': '0.945', 'intensity_prop': '0.737', 'ms1ms2_ratio': '0.157', 'efficiency': '0.239', 'TP': '321', 'FP': '42', 'FN': '21', 'precision': '0.884', 'recall': '0.939', 'f1': '0.911', 'total_rewards': 251.1425162522849, 'invalid_action_count': 8, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 67.78336925366123
# steps	 1000 	total rewards	 147.32676604249698
# steps	 1500 	total rewards	 230.38564869266455
# Finished after 1789 timesteps (6.776398181915283 seconds) with total reward 270.8986218140525
# {'coverage_prop': '0.935', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.134', 'efficiency': '0.262', 'TP': '373', 'FP': '41', 'FN': '29', 'precision': '0.901', 'recall': '0.928', 'f1': '0.914', 'total_rewards': 270.8986218140524, 'invalid_action_count': 4, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 64.32485343192904
# steps	 1000 	total rewards	 136.74153165286003
# steps	 1500 	total rewards	 192.3899321453036
# Finished after 1712 timesteps (4.831423997879028 seconds) with total reward 219.11992903189702
# {'coverage_prop': '0.948', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.202', 'efficiency': '0.166', 'TP': '218', 'FP': '18', 'FN': '13', 'precision': '0.924', 'recall': '0.944', 'f1': '0.934', 'total_rewards': 219.11992903189665, 'invalid_action_count': 6, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 62.09169070981892
# steps	 1000 	total rewards	 127.05409844540999
# steps	 1500 	total rewards	 191.27217099947603
# Finished after 1741 timesteps (4.0971739292144775 seconds) with total reward 225.73883717481706
# {'coverage_prop': '0.948', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.175', 'efficiency': '0.161', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925', 'total_rewards': 225.7388371748169, 'invalid_action_count': 9, 'num_ms1_scans': 259, 'num_ms2_scans': 1482}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 62.99253727907655
# steps	 1000 	total rewards	 138.79723619602615
# steps	 1500 	total rewards	 209.1292796803682
# Finished after 1751 timesteps (4.699480056762695 seconds) with total reward 234.2255032776551
# {'coverage_prop': '0.950', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.166', 'efficiency': '0.190', 'TP': '248', 'FP': '37', 'FN': '15', 'precision': '0.870', 'recall': '0.943', 'f1': '0.905', 'total_rewards': 234.22550327765478, 'invalid_action_count': 3, 'num_ms1_scans': 249, 'num_ms2_scans': 1502}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 59.24856847437607
# steps	 1000 	total rewards	 132.2897951734263
# steps	 1500 	total rewards	 192.78586957130972
# Finished after 1701 timesteps (4.957657098770142 seconds) with total reward 215.03506689109162
# {'coverage_prop': '0.947', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.213', 'efficiency': '0.139', 'TP': '178', 'FP': '17', 'FN': '11', 'precision': '0.913', 'recall': '0.942', 'f1': '0.927', 'total_rewards': 215.03506689109187, 'invalid_action_count': 6, 'num_ms1_scans': 299, 'num_ms2_scans': 1402}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 65.3544374772617
# steps	 1000 	total rewards	 147.9107628888989
# steps	 1500 	total rewards	 224.80672368760128
# Finished after 1752 timesteps (5.099424123764038 seconds) with total reward 261.60724103324344
# {'coverage_prop': '0.963', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.165', 'efficiency': '0.261', 'TP': '354', 'FP': '38', 'FN': '15', 'precision': '0.903', 'recall': '0.959', 'f1': '0.930', 'total_rewards': 261.6072410332435, 'invalid_action_count': 4, 'num_ms1_scans': 248, 'num_ms2_scans': 1504}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 72.67789626776617
# steps	 1000 	total rewards	 151.0348103567527
# steps	 1500 	total rewards	 231.00159846623552
# Finished after 1777 timesteps (7.317651748657227 seconds) with total reward 265.9067336837342
# {'coverage_prop': '0.926', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.144', 'efficiency': '0.297', 'TP': '413', 'FP': '48', 'FN': '37', 'precision': '0.896', 'recall': '0.918', 'f1': '0.907', 'total_rewards': 265.9067336837346, 'invalid_action_count': 7, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 70.39080632995118
# steps	 1000 	total rewards	 147.6932038492088
# steps	 1500 	total rewards	 220.65076993197894
# Finished after 1756 timesteps (5.463258981704712 seconds) with total reward 252.36744451642815
# {'coverage_prop': '0.949', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.161', 'efficiency': '0.233', 'TP': '315', 'FP': '38', 'FN': '19', 'precision': '0.892', 'recall': '0.943', 'f1': '0.917', 'total_rewards': 252.3674445164281, 'invalid_action_count': 5, 'num_ms1_scans': 244, 'num_ms2_scans': 1512}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 65.42632655137625
# steps	 1000 	total rewards	 140.11799377859361
# steps	 1500 	total rewards	 211.39924737082802
# Finished after 1739 timesteps (4.488950729370117 seconds) with total reward 241.62727589139973
# {'coverage_prop': '0.957', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.177', 'efficiency': '0.196', 'TP': '259', 'FP': '30', 'FN': '13', 'precision': '0.896', 'recall': '0.952', 'f1': '0.923', 'total_rewards': 241.6272758913997, 'invalid_action_count': 5, 'num_ms1_scans': 261, 'num_ms2_scans': 1478}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 62.30803698487402
# steps	 1000 	total rewards	 135.95409959795256
# steps	 1500 	total rewards	 201.33857670405814
# Finished after 1736 timesteps (6.990244150161743 seconds) with total reward 232.2749522890632
# {'coverage_prop': '0.977', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.179', 'efficiency': '0.176', 'TP': '234', 'FP': '25', 'FN': '6', 'precision': '0.903', 'recall': '0.975', 'f1': '0.938', 'total_rewards': 232.27495228906307, 'invalid_action_count': 3, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 69.74224962550372
# steps	 1000 	total rewards	 154.63250470566445
# steps	 1500 	total rewards	 226.48650580803402
# Finished after 1773 timesteps (8.616483211517334 seconds) with total reward 265.5960906842876
# {'coverage_prop': '0.908', 'intensity_prop': '0.687', 'ms1ms2_ratio': '0.147', 'efficiency': '0.275', 'TP': '361', 'FP': '64', 'FN': '43', 'precision': '0.849', 'recall': '0.894', 'f1': '0.871', 'total_rewards': 265.5960906842876, 'invalid_action_count': 8, 'num_ms1_scans': 227, 'num_ms2_scans': 1546}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 59.707128920513355
# steps	 1000 	total rewards	 128.1514486227261
# steps	 1500 	total rewards	 195.41703084465505
# Finished after 1695 timesteps (5.239375114440918 seconds) with total reward 210.1775681930619
# {'coverage_prop': '0.953', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.219', 'efficiency': '0.160', 'TP': '201', 'FP': '22', 'FN': '11', 'precision': '0.901', 'recall': '0.948', 'f1': '0.924', 'total_rewards': 210.17756819306192, 'invalid_action_count': 11, 'num_ms1_scans': 305, 'num_ms2_scans': 1390}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 68.86988952969526
# steps	 1000 	total rewards	 144.44251231085187
# steps	 1500 	total rewards	 217.22586389476987
# Finished after 1753 timesteps (4.7732930183410645 seconds) with total reward 254.4557618592226
# {'coverage_prop': '0.957', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.164', 'efficiency': '0.205', 'TP': '285', 'FP': '23', 'FN': '14', 'precision': '0.925', 'recall': '0.953', 'f1': '0.939', 'total_rewards': 254.45576185922232, 'invalid_action_count': 2, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 65.62629281724963
# steps	 1000 	total rewards	 141.7748119552826
# steps	 1500 	total rewards	 210.95112721716674
# Finished after 1728 timesteps (5.234386205673218 seconds) with total reward 239.64720464637367
# {'coverage_prop': '0.942', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.188', 'efficiency': '0.201', 'TP': '264', 'FP': '28', 'FN': '18', 'precision': '0.904', 'recall': '0.936', 'f1': '0.920', 'total_rewards': 239.6472046463736, 'invalid_action_count': 5, 'num_ms1_scans': 273, 'num_ms2_scans': 1455}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 66.8562994730284
# steps	 1000 	total rewards	 147.1531515948012
# steps	 1500 	total rewards	 220.62702799304924
# Finished after 1751 timesteps (4.484586000442505 seconds) with total reward 256.8967577063503
# {'coverage_prop': '0.968', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.166', 'efficiency': '0.222', 'TP': '302', 'FP': '32', 'FN': '11', 'precision': '0.904', 'recall': '0.965', 'f1': '0.934', 'total_rewards': 256.89675770635034, 'invalid_action_count': 2, 'num_ms1_scans': 249, 'num_ms2_scans': 1502}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 67.9954205848396
# steps	 1000 	total rewards	 139.6089005202881
# steps	 1500 	total rewards	 216.82239233722026
# Finished after 1770 timesteps (5.359372854232788 seconds) with total reward 256.30064378583353
# {'coverage_prop': '0.975', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.149', 'efficiency': '0.251', 'TP': '333', 'FP': '53', 'FN': '10', 'precision': '0.863', 'recall': '0.971', 'f1': '0.914', 'total_rewards': 256.3006437858332, 'invalid_action_count': 1, 'num_ms1_scans': 230, 'num_ms2_scans': 1540}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 55.71183337784721
# steps	 1000 	total rewards	 120.48630919317829
# steps	 1500 	total rewards	 179.94752581061374
# Finished after 1697 timesteps (4.449119806289673 seconds) with total reward 202.57017185722714
# {'coverage_prop': '0.956', 'intensity_prop': '0.805', 'ms1ms2_ratio': '0.217', 'efficiency': '0.139', 'TP': '183', 'FP': '11', 'FN': '9', 'precision': '0.943', 'recall': '0.953', 'f1': '0.948', 'total_rewards': 202.5701718572272, 'invalid_action_count': 4, 'num_ms1_scans': 303, 'num_ms2_scans': 1394}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 62.589578947389874
# steps	 1000 	total rewards	 133.8277280144191
# steps	 1500 	total rewards	 205.39853910295938
# Finished after 1723 timesteps (8.721551179885864 seconds) with total reward 239.97400224077214
# {'coverage_prop': '0.957', 'intensity_prop': '0.806', 'ms1ms2_ratio': '0.192', 'efficiency': '0.186', 'TP': '253', 'FP': '16', 'FN': '12', 'precision': '0.941', 'recall': '0.955', 'f1': '0.948', 'total_rewards': 239.97400224077225, 'invalid_action_count': 2, 'num_ms1_scans': 277, 'num_ms2_scans': 1446}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 78.90487309599251
# steps	 1000 	total rewards	 158.05784875383625
# steps	 1500 	total rewards	 239.6211464392206
# Finished after 1784 timesteps (6.4567790031433105 seconds) with total reward 282.8964137618871
# {'coverage_prop': '0.909', 'intensity_prop': '0.666', 'ms1ms2_ratio': '0.138', 'efficiency': '0.286', 'TP': '379', 'FP': '69', 'FN': '45', 'precision': '0.846', 'recall': '0.894', 'f1': '0.869', 'total_rewards': 282.896413761887, 'invalid_action_count': 4, 'num_ms1_scans': 217, 'num_ms2_scans': 1567}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 61.503741798889706
# steps	 1000 	total rewards	 139.09838867009557
# steps	 1500 	total rewards	 204.97075912695618
# Finished after 1744 timesteps (4.858484983444214 seconds) with total reward 241.06893944951966
# {'coverage_prop': '0.961', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.172', 'efficiency': '0.196', 'TP': '255', 'FP': '37', 'FN': '12', 'precision': '0.873', 'recall': '0.955', 'f1': '0.912', 'total_rewards': 241.0689394495193, 'invalid_action_count': 2, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 59.39818191121025
# steps	 1000 	total rewards	 138.5720354265331
# steps	 1500 	total rewards	 216.50731766728592
# Finished after 1722 timesteps (18.712910890579224 seconds) with total reward 246.07141932758293
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 246.0714193275831, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 49.80161912604831
# steps	 1000 	total rewards	 119.66530569651563
# steps	 1500 	total rewards	 182.3992088220571
# Finished after 1556 timesteps (11.844454765319824 seconds) with total reward 187.702141952342
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 187.70214195234212, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 51.29301484412087
# steps	 1000 	total rewards	 125.26814493487129
# steps	 1500 	total rewards	 199.36020268664623
# Finished after 1669 timesteps (15.01928997039795 seconds) with total reward 220.9268071029097
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 220.92680710290975, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 64.69221918652914
# steps	 1000 	total rewards	 139.94091009129198
# steps	 1500 	total rewards	 210.17085329269364
# Finished after 1717 timesteps (18.625114917755127 seconds) with total reward 241.4853865752503
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 241.48538657525012, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 56.35584713914693
# steps	 1000 	total rewards	 137.785216868901
# steps	 1500 	total rewards	 214.6881814813977
# Finished after 1704 timesteps (14.060981273651123 seconds) with total reward 243.52717224427786
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 243.52717224427778, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 36.85977339249479
# steps	 1000 	total rewards	 97.24997682559521
# Finished after 1408 timesteps (11.57300615310669 seconds) with total reward 130.37118689369876
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 130.37118689369868, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 61.83065113097078
# steps	 1000 	total rewards	 142.56596201074652
# steps	 1500 	total rewards	 214.3361857069055
# Finished after 1744 timesteps (17.896852016448975 seconds) with total reward 247.45355319082682
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 247.45355319082682, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 36.7169139046746
# steps	 1000 	total rewards	 107.55288808607207
# Finished after 1468 timesteps (11.158686876296997 seconds) with total reward 154.88443368221024
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 154.88443368221022, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 63.69932181538106
# steps	 1000 	total rewards	 135.50525156126935
# steps	 1500 	total rewards	 209.02143440684972
# Finished after 1736 timesteps (14.672637939453125 seconds) with total reward 240.33224302373395
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 240.3322430237338, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 51.650777099447936
# steps	 1000 	total rewards	 125.19839863770888
# steps	 1500 	total rewards	 199.70280782087247
# Finished after 1667 timesteps (16.286657094955444 seconds) with total reward 217.68242373898718
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 217.68242373898724, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 58.73325228414852
# steps	 1000 	total rewards	 135.05027654333225
# steps	 1500 	total rewards	 210.82813437149593
# Finished after 1737 timesteps (16.60421395301819 seconds) with total reward 242.4599445757275
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 242.45994457572795, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 44.480522347636935
# steps	 1000 	total rewards	 111.26720284815937
# steps	 1500 	total rewards	 159.55269808514626
# Finished after 1530 timesteps (12.903872966766357 seconds) with total reward 162.24444510207155
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 162.24444510207155, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 45.39252917269736
# steps	 1000 	total rewards	 111.72437799007685
# steps	 1500 	total rewards	 174.84141305174293
# Finished after 1602 timesteps (18.8330340385437 seconds) with total reward 186.07155417023205
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 186.07155417023196, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 49.15360821284917
# steps	 1000 	total rewards	 119.6031795309076
# steps	 1500 	total rewards	 184.6587961709919
# Finished after 1645 timesteps (13.444390058517456 seconds) with total reward 198.81613111042032
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 198.81613111042054, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 38.660879944836125
# steps	 1000 	total rewards	 104.6229891790933
# Finished after 1497 timesteps (13.977343082427979 seconds) with total reward 155.6062870524459
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 155.60628705244605, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 51.44764050188936
# steps	 1000 	total rewards	 128.8143354572842
# steps	 1500 	total rewards	 198.00886489737445
# Finished after 1655 timesteps (20.211894989013672 seconds) with total reward 218.38188038198132
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 218.3818803819814, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 62.70461590148102
# steps	 1000 	total rewards	 139.29462868404227
# steps	 1500 	total rewards	 216.17781227924297
# Finished after 1729 timesteps (17.755668878555298 seconds) with total reward 246.00395093770442
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 246.00395093770413, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 58.42443886984613
# steps	 1000 	total rewards	 134.48739921356457
# steps	 1500 	total rewards	 203.27761145212088
# Finished after 1681 timesteps (19.565033197402954 seconds) with total reward 224.5758684609182
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 224.57586846091846, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 46.70791752204587
# steps	 1000 	total rewards	 119.38068923043548
# steps	 1500 	total rewards	 187.44753687163077
# Finished after 1621 timesteps (14.59087586402893 seconds) with total reward 200.0943415427971
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 200.09434154279748, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 47.97066074112459
# steps	 1000 	total rewards	 117.80237298317604
# steps	 1500 	total rewards	 180.4080084670927
# Finished after 1634 timesteps (27.59136414527893 seconds) with total reward 196.08351966112917
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 196.0835196611289, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 62.264924262774656
# steps	 1000 	total rewards	 139.851120208098
# steps	 1500 	total rewards	 213.07257580533394
# Finished after 1726 timesteps (16.913233280181885 seconds) with total reward 245.11037209771413
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 245.11037209771456, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 39.38367416005345
# steps	 1000 	total rewards	 106.71603693124862
# Finished after 1475 timesteps (14.251348972320557 seconds) with total reward 153.20481810659373
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 153.2048181065938, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 53.11142262146333
# steps	 1000 	total rewards	 124.27370748618455
# steps	 1500 	total rewards	 193.48348271444524
# Finished after 1636 timesteps (16.02366805076599 seconds) with total reward 209.13347304634203
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 209.13347304634198, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 52.33369295169392
# steps	 1000 	total rewards	 125.90752415102662
# steps	 1500 	total rewards	 185.4895286328575
# Finished after 1575 timesteps (19.550945043563843 seconds) with total reward 192.07315619040207
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 192.07315619040207, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 51.359324220773956
# steps	 1000 	total rewards	 128.20122403599643
# steps	 1500 	total rewards	 199.61646960616366
# Finished after 1681 timesteps (15.885912895202637 seconds) with total reward 222.65188021845023
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 222.65188021845015, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 53.486927712012815
# steps	 1000 	total rewards	 122.3230387222704
# steps	 1500 	total rewards	 197.5573745494595
# Finished after 1679 timesteps (18.459268808364868 seconds) with total reward 218.69830459399594
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 218.69830459399566, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 36.900191107476665
# steps	 1000 	total rewards	 100.79174218983904
# Finished after 1465 timesteps (16.075253009796143 seconds) with total reward 144.91480985494655
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 144.9148098549467, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 48.149666789891
# steps	 1000 	total rewards	 118.19535529379077
# steps	 1500 	total rewards	 180.83050390836837
# Finished after 1564 timesteps (24.236127138137817 seconds) with total reward 188.7400005085405
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 188.74000050854016, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 67.50510674505492
# steps	 1000 	total rewards	 139.962212241089
# steps	 1500 	total rewards	 216.28971565908762
# Finished after 1749 timesteps (17.936748027801514 seconds) with total reward 252.95716387797603
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 252.95716387797603, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 51.975984210899966
# steps	 1000 	total rewards	 123.10203982392332
# steps	 1500 	total rewards	 187.76545015733265
# Finished after 1657 timesteps (15.7741219997406 seconds) with total reward 206.1422481395321
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 206.14224813953206, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9a1847df70>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f99f80eb3d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f99f8107670>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.498', 'ms1ms2_ratio': '1.373', 'efficiency': '0.762', 'TP': '209', 'FP': '198', 'FN': '19', 'precision': '0.514', 'recall': '0.917', 'f1': '0.658'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.489', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '125', 'FP': '123', 'FN': '14', 'precision': '0.504', 'recall': '0.899', 'f1': '0.646'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.530', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.516', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '122', 'FP': '117', 'FN': '10', 'precision': '0.510', 'recall': '0.924', 'f1': '0.658'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.477', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '107', 'FP': '130', 'FN': '14', 'precision': '0.451', 'recall': '0.884', 'f1': '0.598'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.535', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '277', 'FP': '204', 'FN': '17', 'precision': '0.576', 'recall': '0.942', 'f1': '0.715'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.504', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '183', 'FP': '171', 'FN': '18', 'precision': '0.517', 'recall': '0.910', 'f1': '0.659'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.159', 'efficiency': '0.740', 'TP': '270', 'FP': '176', 'FN': '22', 'precision': '0.605', 'recall': '0.925', 'f1': '0.732'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.148', 'efficiency': '0.770', 'TP': '138', 'FP': '153', 'FN': '19', 'precision': '0.474', 'recall': '0.879', 'f1': '0.616'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1852.065068                1882.0          0.338           0.077
# 1  random   -1907.451922                1924.0          0.244           0.057
# 2  random   -1835.714615                1867.0          0.409           0.110
# 3  random   -1913.759594                1930.0          0.219           0.052
# 4  random   -1814.587284                1852.0          0.432           0.113
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.004       0.073      0.188   0.087  0.119
# 1          0.005       0.032      0.203   0.062  0.095
# 2          0.007       0.082      0.211   0.127  0.159
# 3          0.003       0.050      0.222   0.059  0.093
# 4          0.008       0.096      0.222   0.145  0.175

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     263.328170                  14.0          0.948           0.712
# 31    DQN     245.823190                   2.0          0.958           0.786
# 32    DQN     251.582863                   5.0          0.954           0.724
# 33    DQN     265.641578                   4.0          0.938           0.744
# 34    DQN     264.017417                   7.0          0.963           0.727
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.141       0.259      0.849   0.940  0.892
# 31          0.194       0.174      0.924   0.955  0.939
# 32          0.169       0.252      0.848   0.947  0.895
# 33          0.146       0.274      0.899   0.932  0.915
# 34          0.154       0.275      0.848   0.957  0.899

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
