# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-06 10:43:55.545 | INFO     | experiments:get_samplers:267 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd93d6cfb50>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd93ffdd3a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fd9189a2640>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_10.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd93d6cfb50>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd93ffdd3a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fd9189a2640>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd93d6cfb50>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd93ffdd3a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fd9189a2640>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_10.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_10.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -487.31516133277614
# steps	 1000 	total rewards	 -962.5353884986491
# steps	 1500 	total rewards	 -1440.6854524270123
# Finished after 1992 timesteps (1.7787070274353027 seconds) with total reward -1888.2644425360074
# {'coverage_prop': '0.254', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.004', 'efficiency': '0.054', 'TP': '20', 'FP': '88', 'FN': '318', 'precision': '0.185', 'recall': '0.059', 'f1': '0.090', 'total_rewards': -1888.2644425360077, 'invalid_action_count': 1909, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -489.50938479951367
# steps	 1000 	total rewards	 -965.666156337865
# steps	 1500 	total rewards	 -1444.6645089973072
# Finished after 1987 timesteps (0.9426839351654053 seconds) with total reward -1894.402435353381
# {'coverage_prop': '0.263', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.007', 'efficiency': '0.035', 'TP': '14', 'FP': '55', 'FN': '193', 'precision': '0.203', 'recall': '0.068', 'f1': '0.101', 'total_rewards': -1894.4024353533807, 'invalid_action_count': 1912, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -492.4841660541258
# steps	 1000 	total rewards	 -938.2881122138631
# steps	 1500 	total rewards	 -1381.0529210337734
# Finished after 1991 timesteps (1.218662977218628 seconds) with total reward -1855.1753466675796
# {'coverage_prop': '0.383', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.005', 'efficiency': '0.076', 'TP': '32', 'FP': '119', 'FN': '243', 'precision': '0.212', 'recall': '0.116', 'f1': '0.150', 'total_rewards': -1855.1753466675805, 'invalid_action_count': 1885, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -480.5829375676695
# steps	 1000 	total rewards	 -926.9108478974244
# steps	 1500 	total rewards	 -1373.0230516810425
# Finished after 1990 timesteps (1.2733256816864014 seconds) with total reward -1825.3356586215416
# {'coverage_prop': '0.418', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.005', 'efficiency': '0.095', 'TP': '42', 'FP': '147', 'FN': '263', 'precision': '0.222', 'recall': '0.138', 'f1': '0.170', 'total_rewards': -1825.3356586215423, 'invalid_action_count': 1862, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -974.8370275504788
# steps	 1500 	total rewards	 -1427.3423495189695
# Finished after 1993 timesteps (1.3899688720703125 seconds) with total reward -1865.374501448764
# {'coverage_prop': '0.332', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.004', 'efficiency': '0.073', 'TP': '26', 'FP': '119', 'FN': '292', 'precision': '0.179', 'recall': '0.082', 'f1': '0.112', 'total_rewards': -1865.3745014487642, 'invalid_action_count': 1892, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -492.484285233719
# steps	 1000 	total rewards	 -992.484285233719
# steps	 1500 	total rewards	 -1491.484285233719
# Finished after 1994 timesteps (0.7975380420684814 seconds) with total reward -1960.5788827758397
# {'coverage_prop': '0.120', 'intensity_prop': '0.033', 'ms1ms2_ratio': '0.003', 'efficiency': '0.012', 'TP': '5', 'FP': '19', 'FN': '176', 'precision': '0.208', 'recall': '0.028', 'f1': '0.049', 'total_rewards': -1960.5788827758392, 'invalid_action_count': 1967, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -471.93436981160346
# steps	 1000 	total rewards	 -925.7550537078381
# steps	 1500 	total rewards	 -1357.8591774586
# Finished after 1985 timesteps (1.3602702617645264 seconds) with total reward -1803.524655353422
# {'coverage_prop': '0.402', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.008', 'efficiency': '0.097', 'TP': '49', 'FP': '143', 'FN': '286', 'precision': '0.255', 'recall': '0.146', 'f1': '0.186', 'total_rewards': -1803.5246553534225, 'invalid_action_count': 1842, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -971.371459027213
# steps	 1500 	total rewards	 -1445.695212288651
# Finished after 1988 timesteps (0.8367722034454346 seconds) with total reward -1908.6071775496785
# {'coverage_prop': '0.294', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '17', 'FP': '43', 'FN': '144', 'precision': '0.283', 'recall': '0.106', 'f1': '0.154', 'total_rewards': -1908.6071775496787, 'invalid_action_count': 1925, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -466.6936289787344
# steps	 1000 	total rewards	 -918.9605577577606
# steps	 1500 	total rewards	 -1401.2644292662944
# Finished after 1989 timesteps (1.7123363018035889 seconds) with total reward -1841.1728681873865
# {'coverage_prop': '0.370', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.006', 'efficiency': '0.079', 'TP': '25', 'FP': '132', 'FN': '267', 'precision': '0.159', 'recall': '0.086', 'f1': '0.111', 'total_rewards': -1841.1728681873872, 'invalid_action_count': 1873, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -479.40189697724486
# steps	 1000 	total rewards	 -925.4795265040891
# steps	 1500 	total rewards	 -1370.4361957280637
# Finished after 1987 timesteps (1.1676959991455078 seconds) with total reward -1815.9619387512712
# {'coverage_prop': '0.456', 'intensity_prop': '0.128', 'ms1ms2_ratio': '0.007', 'efficiency': '0.089', 'TP': '46', 'FP': '129', 'FN': '209', 'precision': '0.263', 'recall': '0.180', 'f1': '0.214', 'total_rewards': -1815.961938751271, 'invalid_action_count': 1853, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -491.02857359745406
# steps	 1000 	total rewards	 -953.4097998823478
# steps	 1500 	total rewards	 -1394.742976100985
# Finished after 1988 timesteps (1.415405035018921 seconds) with total reward -1833.2976259079269
# {'coverage_prop': '0.332', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.006', 'efficiency': '0.074', 'TP': '37', 'FP': '110', 'FN': '296', 'precision': '0.252', 'recall': '0.111', 'f1': '0.154', 'total_rewards': -1833.2976259079262, 'invalid_action_count': 1866, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -492.01043011239244
# steps	 1000 	total rewards	 -970.4289102795137
# steps	 1500 	total rewards	 -1440.393466094818
# Finished after 1992 timesteps (0.9711000919342041 seconds) with total reward -1922.0023955353613
# {'coverage_prop': '0.273', 'intensity_prop': '0.038', 'ms1ms2_ratio': '0.004', 'efficiency': '0.034', 'TP': '7', 'FP': '61', 'FN': '181', 'precision': '0.103', 'recall': '0.037', 'f1': '0.055', 'total_rewards': -1922.0023955353606, 'invalid_action_count': 1935, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -482.79834205771857
# steps	 1000 	total rewards	 -951.4475496655461
# steps	 1500 	total rewards	 -1412.9708110815632
# Finished after 1985 timesteps (1.0605461597442627 seconds) with total reward -1865.0809613655315
# {'coverage_prop': '0.382', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.008', 'efficiency': '0.049', 'TP': '21', 'FP': '75', 'FN': '155', 'precision': '0.219', 'recall': '0.119', 'f1': '0.154', 'total_rewards': -1865.0809613655324, 'invalid_action_count': 1890, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -999.0
# steps	 1500 	total rewards	 -1449.360716527446
# Finished after 1989 timesteps (1.6974499225616455 seconds) with total reward -1887.9616912428023
# {'coverage_prop': '0.333', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.006', 'efficiency': '0.051', 'TP': '26', 'FP': '74', 'FN': '200', 'precision': '0.260', 'recall': '0.115', 'f1': '0.160', 'total_rewards': -1887.9616912428025, 'invalid_action_count': 1909, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -485.1914983762199
# steps	 1000 	total rewards	 -959.0028497029668
# steps	 1500 	total rewards	 -1418.4286497967228
# Finished after 1985 timesteps (1.0266411304473877 seconds) with total reward -1863.9660864100604
# {'coverage_prop': '0.413', 'intensity_prop': '0.119', 'ms1ms2_ratio': '0.008', 'efficiency': '0.043', 'TP': '24', 'FP': '61', 'FN': '121', 'precision': '0.282', 'recall': '0.166', 'f1': '0.209', 'total_rewards': -1863.9660864100606, 'invalid_action_count': 1887, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -490.4157610394474
# steps	 1000 	total rewards	 -962.7524114853684
# steps	 1500 	total rewards	 -1420.745622856191
# Finished after 1988 timesteps (1.2371890544891357 seconds) with total reward -1876.2214407152046
# {'coverage_prop': '0.351', 'intensity_prop': '0.086', 'ms1ms2_ratio': '0.006', 'efficiency': '0.072', 'TP': '35', 'FP': '108', 'FN': '264', 'precision': '0.245', 'recall': '0.117', 'f1': '0.158', 'total_rewards': -1876.2214407152044, 'invalid_action_count': 1899, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -489.43586797197275
# steps	 1000 	total rewards	 -935.9969494597906
# steps	 1500 	total rewards	 -1370.1523244513487
# Finished after 1988 timesteps (1.4219732284545898 seconds) with total reward -1812.2173298321604
# {'coverage_prop': '0.398', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.006', 'efficiency': '0.100', 'TP': '55', 'FP': '143', 'FN': '300', 'precision': '0.278', 'recall': '0.155', 'f1': '0.199', 'total_rewards': -1812.2173298321607, 'invalid_action_count': 1851, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -494.79155092362123
# steps	 1000 	total rewards	 -958.5598272760448
# steps	 1500 	total rewards	 -1413.2346635042784
# Finished after 1991 timesteps (1.1461801528930664 seconds) with total reward -1867.50166487311
# {'coverage_prop': '0.360', 'intensity_prop': '0.082', 'ms1ms2_ratio': '0.005', 'efficiency': '0.068', 'TP': '26', 'FP': '108', 'FN': '238', 'precision': '0.194', 'recall': '0.098', 'f1': '0.131', 'total_rewards': -1867.5016648731096, 'invalid_action_count': 1894, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -496.2632736436699
# steps	 1000 	total rewards	 -972.8609838108435
# steps	 1500 	total rewards	 -1428.7547498632703
# Finished after 1991 timesteps (1.0418040752410889 seconds) with total reward -1879.0870562699256
# {'coverage_prop': '0.364', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.005', 'efficiency': '0.055', 'TP': '26', 'FP': '84', 'FN': '192', 'precision': '0.236', 'recall': '0.119', 'f1': '0.159', 'total_rewards': -1879.0870562699263, 'invalid_action_count': 1903, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -493.2136542587515
# steps	 1000 	total rewards	 -949.0637461782934
# steps	 1500 	total rewards	 -1399.0093678117537
# Finished after 1983 timesteps (1.0038440227508545 seconds) with total reward -1845.7945226568763
# {'coverage_prop': '0.396', 'intensity_prop': '0.115', 'ms1ms2_ratio': '0.009', 'efficiency': '0.053', 'TP': '24', 'FP': '81', 'FN': '160', 'precision': '0.229', 'recall': '0.130', 'f1': '0.166', 'total_rewards': -1845.7945226568766, 'invalid_action_count': 1873, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -482.80602299861005
# steps	 1000 	total rewards	 -924.5363809978023
# steps	 1500 	total rewards	 -1340.2312332430154
# Finished after 1988 timesteps (1.3621199131011963 seconds) with total reward -1806.6877769844978
# {'coverage_prop': '0.423', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.006', 'efficiency': '0.100', 'TP': '47', 'FP': '151', 'FN': '270', 'precision': '0.237', 'recall': '0.148', 'f1': '0.183', 'total_rewards': -1806.6877769844982, 'invalid_action_count': 1848, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -484.61086331682674
# steps	 1000 	total rewards	 -954.6071125182043
# steps	 1500 	total rewards	 -1428.5993457345714
# Finished after 1989 timesteps (0.9032788276672363 seconds) with total reward -1894.2050639504982
# {'coverage_prop': '0.338', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.006', 'efficiency': '0.040', 'TP': '24', 'FP': '55', 'FN': '155', 'precision': '0.304', 'recall': '0.134', 'f1': '0.186', 'total_rewards': -1894.2050639504987, 'invalid_action_count': 1912, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -488.47591055097456
# steps	 1000 	total rewards	 -983.0842454341009
# steps	 1500 	total rewards	 -1421.7156287424823
# Finished after 1990 timesteps (1.0531010627746582 seconds) with total reward -1870.7490395938526
# {'coverage_prop': '0.329', 'intensity_prop': '0.082', 'ms1ms2_ratio': '0.005', 'efficiency': '0.054', 'TP': '22', 'FP': '84', 'FN': '216', 'precision': '0.208', 'recall': '0.092', 'f1': '0.128', 'total_rewards': -1870.7490395938528, 'invalid_action_count': 1895, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -496.181949608022
# steps	 1000 	total rewards	 -958.5127459667688
# steps	 1500 	total rewards	 -1433.2657064417308
# Finished after 1987 timesteps (0.9949171543121338 seconds) with total reward -1884.7703892449206
# {'coverage_prop': '0.319', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.007', 'efficiency': '0.050', 'TP': '18', 'FP': '81', 'FN': '211', 'precision': '0.182', 'recall': '0.079', 'f1': '0.110', 'total_rewards': -1884.7703892449204, 'invalid_action_count': 1906, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -491.6918513072733
# steps	 1000 	total rewards	 -959.3651147627273
# steps	 1500 	total rewards	 -1390.1041482025194
# Finished after 1988 timesteps (1.1387841701507568 seconds) with total reward -1834.0875677855765
# {'coverage_prop': '0.406', 'intensity_prop': '0.106', 'ms1ms2_ratio': '0.006', 'efficiency': '0.071', 'TP': '28', 'FP': '112', 'FN': '205', 'precision': '0.200', 'recall': '0.120', 'f1': '0.150', 'total_rewards': -1834.0875677855765, 'invalid_action_count': 1868, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -478.65512732481426
# steps	 1000 	total rewards	 -944.4791952010708
# steps	 1500 	total rewards	 -1404.6827033956179
# Finished after 1988 timesteps (1.160794973373413 seconds) with total reward -1866.360604664618
# {'coverage_prop': '0.328', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.006', 'efficiency': '0.066', 'TP': '29', 'FP': '101', 'FN': '266', 'precision': '0.223', 'recall': '0.098', 'f1': '0.136', 'total_rewards': -1866.3606046646182, 'invalid_action_count': 1891, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -489.32498341609073
# steps	 1000 	total rewards	 -970.7712480452568
# steps	 1500 	total rewards	 -1440.6648088275297
# Finished after 1986 timesteps (0.8767132759094238 seconds) with total reward -1915.2823481649866
# {'coverage_prop': '0.335', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.007', 'efficiency': '0.034', 'TP': '18', 'FP': '50', 'FN': '135', 'precision': '0.265', 'recall': '0.118', 'f1': '0.163', 'total_rewards': -1915.2823481649868, 'invalid_action_count': 1928, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -492.40809524809254
# steps	 1000 	total rewards	 -956.4947151792198
# steps	 1500 	total rewards	 -1426.8198234202678
# Finished after 1990 timesteps (0.9399740695953369 seconds) with total reward -1892.3953675552998
# {'coverage_prop': '0.310', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.005', 'efficiency': '0.044', 'TP': '15', 'FP': '72', 'FN': '194', 'precision': '0.172', 'recall': '0.072', 'f1': '0.101', 'total_rewards': -1892.3953675552996, 'invalid_action_count': 1913, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -487.796922176637
# steps	 1000 	total rewards	 -945.6191336041791
# steps	 1500 	total rewards	 -1365.1543794002057
# Finished after 1988 timesteps (1.3783917427062988 seconds) with total reward -1780.8130710836892
# {'coverage_prop': '0.426', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.006', 'efficiency': '0.106', 'TP': '44', 'FP': '166', 'FN': '283', 'precision': '0.210', 'recall': '0.135', 'f1': '0.164', 'total_rewards': -1780.8130710836883, 'invalid_action_count': 1827, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -484.201210532108
# steps	 1000 	total rewards	 -959.1035044600359
# steps	 1500 	total rewards	 -1410.2793343183826
# Finished after 1986 timesteps (1.042257308959961 seconds) with total reward -1849.9929950589585
# {'coverage_prop': '0.385', 'intensity_prop': '0.116', 'ms1ms2_ratio': '0.007', 'efficiency': '0.059', 'TP': '30', 'FP': '87', 'FN': '187', 'precision': '0.256', 'recall': '0.138', 'f1': '0.180', 'total_rewards': -1849.9929950589583, 'invalid_action_count': 1878, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 8.35GB > 0.33GB
# steps	 500 	total rewards	 73.44228901613513
# steps	 1000 	total rewards	 155.12688840974778
# steps	 1500 	total rewards	 239.4107856471369
# Finished after 1782 timesteps (3.4408087730407715 seconds) with total reward 279.23675988713995
# {'coverage_prop': '0.962', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.139', 'efficiency': '0.262', 'TP': '361', 'FP': '49', 'FN': '16', 'precision': '0.880', 'recall': '0.958', 'f1': '0.917', 'total_rewards': 279.2367598871402, 'invalid_action_count': 0, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 64.83853460119563
# steps	 1000 	total rewards	 139.0452699981208
# steps	 1500 	total rewards	 215.92365845895026
# Finished after 1734 timesteps (2.195953130722046 seconds) with total reward 248.94542364243654
# {'coverage_prop': '0.958', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.181', 'efficiency': '0.171', 'TP': '232', 'FP': '19', 'FN': '11', 'precision': '0.924', 'recall': '0.955', 'f1': '0.939', 'total_rewards': 248.94542364243662, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1468}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 63.75297725689917
# steps	 1000 	total rewards	 145.3171238792707
# steps	 1500 	total rewards	 220.88352512043235
# Finished after 1758 timesteps (3.471987009048462 seconds) with total reward 256.2696164397454
# {'coverage_prop': '0.964', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.160', 'efficiency': '0.251', 'TP': '330', 'FP': '50', 'FN': '14', 'precision': '0.868', 'recall': '0.959', 'f1': '0.912', 'total_rewards': 256.26961643974533, 'invalid_action_count': 0, 'num_ms1_scans': 243, 'num_ms2_scans': 1515}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 74.02560360029909
# steps	 1000 	total rewards	 155.06475814526755
# steps	 1500 	total rewards	 231.48110639118747
# Finished after 1771 timesteps (3.0356411933898926 seconds) with total reward 270.4825192348711
# {'coverage_prop': '0.956', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.149', 'efficiency': '0.280', 'TP': '390', 'FP': '42', 'FN': '20', 'precision': '0.903', 'recall': '0.951', 'f1': '0.926', 'total_rewards': 270.48251923487163, 'invalid_action_count': 0, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 67.9992498090896
# steps	 1000 	total rewards	 152.0377359920005
# steps	 1500 	total rewards	 233.7542982920818
# Finished after 1759 timesteps (3.726062774658203 seconds) with total reward 273.3378637141983
# {'coverage_prop': '0.986', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.159', 'efficiency': '0.284', 'TP': '373', 'FP': '58', 'FN': '6', 'precision': '0.865', 'recall': '0.984', 'f1': '0.921', 'total_rewards': 273.3378637141987, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 57.397787059612014
# steps	 1000 	total rewards	 126.91852941445565
# steps	 1500 	total rewards	 185.98559766892208
# Finished after 1706 timesteps (2.2156968116760254 seconds) with total reward 208.21530406968066
# {'coverage_prop': '0.955', 'intensity_prop': '0.823', 'ms1ms2_ratio': '0.209', 'efficiency': '0.135', 'TP': '183', 'FP': '8', 'FN': '9', 'precision': '0.958', 'recall': '0.953', 'f1': '0.956', 'total_rewards': 208.21530406968077, 'invalid_action_count': 1, 'num_ms1_scans': 295, 'num_ms2_scans': 1411}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 68.8364857502442
# steps	 1000 	total rewards	 154.4783103974942
# steps	 1500 	total rewards	 231.3980561689462
# Finished after 1778 timesteps (3.054111957550049 seconds) with total reward 270.96770908718736
# {'coverage_prop': '0.931', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.143', 'efficiency': '0.286', 'TP': '380', 'FP': '65', 'FN': '33', 'precision': '0.854', 'recall': '0.920', 'f1': '0.886', 'total_rewards': 270.96770908718764, 'invalid_action_count': 0, 'num_ms1_scans': 222, 'num_ms2_scans': 1556}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 53.88974798749851
# steps	 1000 	total rewards	 131.27615596294095
# steps	 1500 	total rewards	 200.48362205987593
# Finished after 1702 timesteps (3.2182672023773193 seconds) with total reward 228.09657124805497
# {'coverage_prop': '0.961', 'intensity_prop': '0.814', 'ms1ms2_ratio': '0.212', 'efficiency': '0.140', 'TP': '187', 'FP': '9', 'FN': '8', 'precision': '0.954', 'recall': '0.959', 'f1': '0.957', 'total_rewards': 228.09657124805503, 'invalid_action_count': 0, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 75.2376023545804
# steps	 1000 	total rewards	 154.48325635104885
# steps	 1500 	total rewards	 233.04558996180253
# Finished after 1788 timesteps (2.79170298576355 seconds) with total reward 273.5928227944632
# {'coverage_prop': '0.946', 'intensity_prop': '0.739', 'ms1ms2_ratio': '0.135', 'efficiency': '0.254', 'TP': '352', 'FP': '49', 'FN': '23', 'precision': '0.878', 'recall': '0.939', 'f1': '0.907', 'total_rewards': 273.5928227944628, 'invalid_action_count': 0, 'num_ms1_scans': 212, 'num_ms2_scans': 1576}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 68.2259005005482
# steps	 1000 	total rewards	 147.51023511095116
# steps	 1500 	total rewards	 228.44391015738404
# Finished after 1769 timesteps (2.626156806945801 seconds) with total reward 264.5460949130704
# {'coverage_prop': '0.958', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.151', 'efficiency': '0.239', 'TP': '332', 'FP': '36', 'FN': '16', 'precision': '0.902', 'recall': '0.954', 'f1': '0.927', 'total_rewards': 264.5460949130705, 'invalid_action_count': 0, 'num_ms1_scans': 232, 'num_ms2_scans': 1537}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 69.98014045231454
# steps	 1000 	total rewards	 149.7617413862984
# steps	 1500 	total rewards	 236.0856310981563
# Finished after 1786 timesteps (3.860123872756958 seconds) with total reward 276.49255855693343
# {'coverage_prop': '0.948', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.137', 'efficiency': '0.267', 'TP': '375', 'FP': '45', 'FN': '23', 'precision': '0.893', 'recall': '0.942', 'f1': '0.917', 'total_rewards': 276.49255855693366, 'invalid_action_count': 1, 'num_ms1_scans': 215, 'num_ms2_scans': 1571}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 63.23984055022029
# steps	 1000 	total rewards	 135.92875511257688
# steps	 1500 	total rewards	 195.19328608970346
# Finished after 1730 timesteps (2.3590526580810547 seconds) with total reward 222.6198645666214
# {'coverage_prop': '0.952', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.186', 'efficiency': '0.162', 'TP': '223', 'FP': '14', 'FN': '12', 'precision': '0.941', 'recall': '0.949', 'f1': '0.945', 'total_rewards': 222.61986456662143, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1459}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 64.7492222651426
# steps	 1000 	total rewards	 130.0393683149751
# steps	 1500 	total rewards	 199.99707109642483
# Finished after 1758 timesteps (2.30578875541687 seconds) with total reward 239.16303912749538
# {'coverage_prop': '0.948', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.160', 'efficiency': '0.157', 'TP': '215', 'FP': '23', 'FN': '13', 'precision': '0.903', 'recall': '0.943', 'f1': '0.923', 'total_rewards': 239.16303912749524, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 63.02585591180137
# steps	 1000 	total rewards	 137.7506829568469
# steps	 1500 	total rewards	 211.49353073429612
# Finished after 1754 timesteps (3.675070285797119 seconds) with total reward 239.87607920332454
# {'coverage_prop': '0.957', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.163', 'efficiency': '0.190', 'TP': '251', 'FP': '36', 'FN': '13', 'precision': '0.875', 'recall': '0.951', 'f1': '0.911', 'total_rewards': 239.87607920332476, 'invalid_action_count': 0, 'num_ms1_scans': 246, 'num_ms2_scans': 1508}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 59.423360870651145
# steps	 1000 	total rewards	 132.11911641258564
# steps	 1500 	total rewards	 196.6234452920728
# Finished after 1726 timesteps (2.336388111114502 seconds) with total reward 223.87422756043992
# {'coverage_prop': '0.951', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.189', 'efficiency': '0.135', 'TP': '176', 'FP': '20', 'FN': '10', 'precision': '0.898', 'recall': '0.946', 'f1': '0.921', 'total_rewards': 223.87422756043975, 'invalid_action_count': 0, 'num_ms1_scans': 274, 'num_ms2_scans': 1452}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 63.67089809073925
# steps	 1000 	total rewards	 144.3068036363849
# steps	 1500 	total rewards	 226.34569063603215
# Finished after 1765 timesteps (2.952486038208008 seconds) with total reward 263.2028691767483
# {'coverage_prop': '0.958', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.154', 'efficiency': '0.255', 'TP': '353', 'FP': '37', 'FN': '17', 'precision': '0.905', 'recall': '0.954', 'f1': '0.929', 'total_rewards': 263.2028691767484, 'invalid_action_count': 0, 'num_ms1_scans': 236, 'num_ms2_scans': 1529}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 73.70491865613883
# steps	 1000 	total rewards	 158.79158738251857
# steps	 1500 	total rewards	 240.1746901869086
# Finished after 1782 timesteps (5.333236932754517 seconds) with total reward 278.7609302228319
# {'coverage_prop': '0.958', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.139', 'efficiency': '0.305', 'TP': '430', 'FP': '47', 'FN': '21', 'precision': '0.901', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 278.7609302228321, 'invalid_action_count': 0, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 69.88544719148184
# steps	 1000 	total rewards	 147.95730455411967
# steps	 1500 	total rewards	 222.9735463439988
# Finished after 1773 timesteps (3.2255499362945557 seconds) with total reward 260.20282476909415
# {'coverage_prop': '0.960', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.147', 'efficiency': '0.231', 'TP': '317', 'FP': '40', 'FN': '15', 'precision': '0.888', 'recall': '0.955', 'f1': '0.920', 'total_rewards': 260.20282476909404, 'invalid_action_count': 0, 'num_ms1_scans': 227, 'num_ms2_scans': 1546}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 68.04048730896534
# steps	 1000 	total rewards	 141.1717238608901
# steps	 1500 	total rewards	 216.2675400361826
# Finished after 1749 timesteps (3.034609317779541 seconds) with total reward 250.7106747701298
# {'coverage_prop': '0.960', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.168', 'efficiency': '0.194', 'TP': '265', 'FP': '25', 'FN': '12', 'precision': '0.914', 'recall': '0.957', 'f1': '0.935', 'total_rewards': 250.71067477012997, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 64.32900442745148
# steps	 1000 	total rewards	 138.54164296274388
# steps	 1500 	total rewards	 203.58286637950593
# Finished after 1752 timesteps (5.135173082351685 seconds) with total reward 238.91340149466387
# {'coverage_prop': '0.981', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.165', 'efficiency': '0.173', 'TP': '233', 'FP': '27', 'FN': '5', 'precision': '0.896', 'recall': '0.979', 'f1': '0.936', 'total_rewards': 238.9134014946639, 'invalid_action_count': 0, 'num_ms1_scans': 248, 'num_ms2_scans': 1504}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.64380191292035
# steps	 1000 	total rewards	 155.56927271865666
# steps	 1500 	total rewards	 234.5503903490162
# Finished after 1775 timesteps (3.861232280731201 seconds) with total reward 274.5983985879559
# {'coverage_prop': '0.915', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.145', 'efficiency': '0.276', 'TP': '381', 'FP': '47', 'FN': '40', 'precision': '0.890', 'recall': '0.905', 'f1': '0.898', 'total_rewards': 274.5983985879561, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 62.31865055430243
# steps	 1000 	total rewards	 132.87347298982382
# steps	 1500 	total rewards	 203.62466611150307
# Finished after 1717 timesteps (2.425992965698242 seconds) with total reward 224.91921898015664
# {'coverage_prop': '0.953', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.197', 'efficiency': '0.156', 'TP': '207', 'FP': '16', 'FN': '11', 'precision': '0.928', 'recall': '0.950', 'f1': '0.939', 'total_rewards': 224.91921898015704, 'invalid_action_count': 3, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 67.73906581226656
# steps	 1000 	total rewards	 144.6789854108394
# steps	 1500 	total rewards	 216.73656425950003
# Finished after 1756 timesteps (2.4564013481140137 seconds) with total reward 253.99298045614952
# {'coverage_prop': '0.953', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.161', 'efficiency': '0.203', 'TP': '281', 'FP': '26', 'FN': '15', 'precision': '0.915', 'recall': '0.949', 'f1': '0.932', 'total_rewards': 253.99298045615015, 'invalid_action_count': 0, 'num_ms1_scans': 244, 'num_ms2_scans': 1512}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 66.29497299332354
# steps	 1000 	total rewards	 141.63062398574067
# steps	 1500 	total rewards	 214.615959397838
# Finished after 1738 timesteps (4.565155029296875 seconds) with total reward 246.77901903922077
# {'coverage_prop': '0.939', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.178', 'efficiency': '0.197', 'TP': '272', 'FP': '19', 'FN': '19', 'precision': '0.935', 'recall': '0.935', 'f1': '0.935', 'total_rewards': 246.77901903922063, 'invalid_action_count': 0, 'num_ms1_scans': 262, 'num_ms2_scans': 1476}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 66.02639944195332
# steps	 1000 	total rewards	 148.2714242351978
# steps	 1500 	total rewards	 223.45282244031102
# Finished after 1758 timesteps (3.311174154281616 seconds) with total reward 260.71081565060865
# {'coverage_prop': '0.980', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.160', 'efficiency': '0.223', 'TP': '299', 'FP': '39', 'FN': '7', 'precision': '0.885', 'recall': '0.977', 'f1': '0.929', 'total_rewards': 260.710815650609, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 68.44675680602664
# steps	 1000 	total rewards	 141.65687641050903
# steps	 1500 	total rewards	 221.86722114044238
# Finished after 1779 timesteps (3.1572279930114746 seconds) with total reward 262.207388043128
# {'coverage_prop': '0.980', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.142', 'efficiency': '0.249', 'TP': '347', 'FP': '41', 'FN': '8', 'precision': '0.894', 'recall': '0.977', 'f1': '0.934', 'total_rewards': 262.20738804312793, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 54.89928742645923
# steps	 1000 	total rewards	 124.90797338206573
# steps	 1500 	total rewards	 186.34206524615814
# Finished after 1717 timesteps (3.0325539112091064 seconds) with total reward 213.14637583339675
# {'coverage_prop': '0.966', 'intensity_prop': '0.834', 'ms1ms2_ratio': '0.198', 'efficiency': '0.137', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962', 'total_rewards': 213.14637583339652, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 64.16825335900621
# steps	 1000 	total rewards	 135.31551208614331
# steps	 1500 	total rewards	 207.73163029486818
# Finished after 1736 timesteps (4.772619962692261 seconds) with total reward 245.0933870893603
# {'coverage_prop': '0.968', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.179', 'efficiency': '0.185', 'TP': '247', 'FP': '25', 'FN': '9', 'precision': '0.908', 'recall': '0.965', 'f1': '0.936', 'total_rewards': 245.09338708936053, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 78.74815408745721
# steps	 1000 	total rewards	 160.19628589805262
# steps	 1500 	total rewards	 240.65108653784912
# Finished after 1780 timesteps (3.1171960830688477 seconds) with total reward 284.06631186445213
# {'coverage_prop': '0.927', 'intensity_prop': '0.686', 'ms1ms2_ratio': '0.141', 'efficiency': '0.293', 'TP': '388', 'FP': '69', 'FN': '36', 'precision': '0.849', 'recall': '0.915', 'f1': '0.881', 'total_rewards': 284.0663118644517, 'invalid_action_count': 0, 'num_ms1_scans': 220, 'num_ms2_scans': 1560}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 61.615593077171695
# steps	 1000 	total rewards	 137.59988159312957
# steps	 1500 	total rewards	 206.20481743117165
# Finished after 1747 timesteps (2.607667922973633 seconds) with total reward 243.10181528377188
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.169', 'efficiency': '0.195', 'TP': '256', 'FP': '35', 'FN': '13', 'precision': '0.880', 'recall': '0.952', 'f1': '0.914', 'total_rewards': 243.10181528377208, 'invalid_action_count': 0, 'num_ms1_scans': 253, 'num_ms2_scans': 1494}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 59.39818191121025
# steps	 1000 	total rewards	 138.5720354265331
# steps	 1500 	total rewards	 216.50731766728592
# Finished after 1722 timesteps (9.83912992477417 seconds) with total reward 246.07141932758293
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 246.0714193275831, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 49.80161912604831
# steps	 1000 	total rewards	 119.66530569651563
# steps	 1500 	total rewards	 182.3992088220571
# Finished after 1556 timesteps (9.774649143218994 seconds) with total reward 187.702141952342
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 187.70214195234212, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 51.29301484412087
# steps	 1000 	total rewards	 125.26814493487129
# steps	 1500 	total rewards	 199.36020268664623
# Finished after 1669 timesteps (9.650362968444824 seconds) with total reward 220.9268071029097
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 220.92680710290975, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 64.69221918652914
# steps	 1000 	total rewards	 139.94091009129198
# steps	 1500 	total rewards	 210.17085329269364
# Finished after 1717 timesteps (12.149727821350098 seconds) with total reward 241.4853865752503
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 241.48538657525012, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 56.35584713914693
# steps	 1000 	total rewards	 137.785216868901
# steps	 1500 	total rewards	 214.6881814813977
# Finished after 1704 timesteps (9.882838010787964 seconds) with total reward 243.52717224427786
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 243.52717224427778, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 36.85977339249479
# steps	 1000 	total rewards	 97.24997682559521
# Finished after 1408 timesteps (7.808206081390381 seconds) with total reward 130.37118689369876
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 130.37118689369868, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 61.83065113097078
# steps	 1000 	total rewards	 142.56596201074652
# steps	 1500 	total rewards	 214.3361857069055
# Finished after 1744 timesteps (12.083945035934448 seconds) with total reward 247.45355319082682
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 247.45355319082682, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 36.7169139046746
# steps	 1000 	total rewards	 107.55288808607207
# Finished after 1468 timesteps (7.850497007369995 seconds) with total reward 154.88443368221024
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 154.88443368221022, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 63.69932181538106
# steps	 1000 	total rewards	 135.50525156126935
# steps	 1500 	total rewards	 209.02143440684972
# Finished after 1736 timesteps (10.706753969192505 seconds) with total reward 240.33224302373395
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 240.3322430237338, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 51.650777099447936
# steps	 1000 	total rewards	 125.19839863770888
# steps	 1500 	total rewards	 199.70280782087247
# Finished after 1667 timesteps (11.569234848022461 seconds) with total reward 217.68242373898718
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 217.68242373898724, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 58.73325228414852
# steps	 1000 	total rewards	 135.05027654333225
# steps	 1500 	total rewards	 210.82813437149593
# Finished after 1737 timesteps (10.3038330078125 seconds) with total reward 242.4599445757275
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 242.45994457572795, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 44.480522347636935
# steps	 1000 	total rewards	 111.26720284815937
# steps	 1500 	total rewards	 159.55269808514626
# Finished after 1530 timesteps (8.511698007583618 seconds) with total reward 162.24444510207155
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 162.24444510207155, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 45.39252917269736
# steps	 1000 	total rewards	 111.72437799007685
# steps	 1500 	total rewards	 174.84141305174293
# Finished after 1602 timesteps (11.279382228851318 seconds) with total reward 186.07155417023205
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 186.07155417023196, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 49.15360821284917
# steps	 1000 	total rewards	 119.6031795309076
# steps	 1500 	total rewards	 184.6587961709919
# Finished after 1645 timesteps (24.18358588218689 seconds) with total reward 198.81613111042032
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 198.81613111042054, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 38.660879944836125
# steps	 1000 	total rewards	 104.6229891790933
# Finished after 1497 timesteps (8.481619119644165 seconds) with total reward 155.6062870524459
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 155.60628705244605, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 51.44764050188936
# steps	 1000 	total rewards	 128.8143354572842
# steps	 1500 	total rewards	 198.00886489737445
# Finished after 1655 timesteps (9.464837074279785 seconds) with total reward 218.38188038198132
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 218.3818803819814, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 62.70461590148102
# steps	 1000 	total rewards	 139.29462868404227
# steps	 1500 	total rewards	 216.17781227924297
# Finished after 1729 timesteps (12.343522787094116 seconds) with total reward 246.00395093770442
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 246.00395093770413, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 58.42443886984613
# steps	 1000 	total rewards	 134.48739921356457
# steps	 1500 	total rewards	 203.27761145212088
# Finished after 1681 timesteps (10.063005924224854 seconds) with total reward 224.5758684609182
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 224.57586846091846, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 46.70791752204587
# steps	 1000 	total rewards	 119.38068923043548
# steps	 1500 	total rewards	 187.44753687163077
# Finished after 1621 timesteps (9.283313989639282 seconds) with total reward 200.0943415427971
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 200.09434154279748, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 47.97066074112459
# steps	 1000 	total rewards	 117.80237298317604
# steps	 1500 	total rewards	 180.4080084670927
# Finished after 1634 timesteps (12.19443678855896 seconds) with total reward 196.08351966112917
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 196.0835196611289, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 62.264924262774656
# steps	 1000 	total rewards	 139.851120208098
# steps	 1500 	total rewards	 213.07257580533394
# Finished after 1726 timesteps (12.839390993118286 seconds) with total reward 245.11037209771413
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 245.11037209771456, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 39.38367416005345
# steps	 1000 	total rewards	 106.71603693124862
# Finished after 1475 timesteps (11.40103793144226 seconds) with total reward 153.20481810659373
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 153.2048181065938, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 53.11142262146333
# steps	 1000 	total rewards	 124.27370748618455
# steps	 1500 	total rewards	 193.48348271444524
# Finished after 1636 timesteps (8.993458986282349 seconds) with total reward 209.13347304634203
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 209.13347304634198, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 52.33369295169392
# steps	 1000 	total rewards	 125.90752415102662
# steps	 1500 	total rewards	 185.4895286328575
# Finished after 1575 timesteps (11.554918766021729 seconds) with total reward 192.07315619040207
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 192.07315619040207, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 51.359324220773956
# steps	 1000 	total rewards	 128.20122403599643
# steps	 1500 	total rewards	 199.61646960616366
# Finished after 1681 timesteps (9.745455741882324 seconds) with total reward 222.65188021845023
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 222.65188021845015, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 53.486927712012815
# steps	 1000 	total rewards	 122.3230387222704
# steps	 1500 	total rewards	 197.5573745494595
# Finished after 1679 timesteps (10.106497049331665 seconds) with total reward 218.69830459399594
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 218.69830459399566, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 36.900191107476665
# steps	 1000 	total rewards	 100.79174218983904
# Finished after 1465 timesteps (8.250304937362671 seconds) with total reward 144.91480985494655
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 144.9148098549467, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 48.149666789891
# steps	 1000 	total rewards	 118.19535529379077
# steps	 1500 	total rewards	 180.83050390836837
# Finished after 1564 timesteps (12.318187713623047 seconds) with total reward 188.7400005085405
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 188.74000050854016, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 67.50510674505492
# steps	 1000 	total rewards	 139.962212241089
# steps	 1500 	total rewards	 216.28971565908762
# Finished after 1749 timesteps (11.48298192024231 seconds) with total reward 252.95716387797603
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 252.95716387797603, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 51.975984210899966
# steps	 1000 	total rewards	 123.10203982392332
# steps	 1500 	total rewards	 187.76545015733265
# Finished after 1657 timesteps (9.81667709350586 seconds) with total reward 206.1422481395321
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 206.14224813953206, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fd93d6cfb50>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fd93ffdd3a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fd9189a2640>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.494', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.132', 'efficiency': '0.741', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.532', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '120', 'FP': '73', 'FN': '11', 'precision': '0.622', 'recall': '0.916', 'f1': '0.741'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.490', 'ms1ms2_ratio': '1.428', 'efficiency': '0.771', 'TP': '202', 'FP': '198', 'FN': '24', 'precision': '0.505', 'recall': '0.894', 'f1': '0.645'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.516', 'ms1ms2_ratio': '2.676', 'efficiency': '0.759', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.480', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '108', 'FP': '129', 'FN': '14', 'precision': '0.456', 'recall': '0.885', 'f1': '0.602'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.990', 'efficiency': '0.709', 'TP': '151', 'FP': '134', 'FN': '15', 'precision': '0.530', 'recall': '0.910', 'f1': '0.670'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '190', 'FP': '164', 'FN': '18', 'precision': '0.537', 'recall': '0.913', 'f1': '0.676'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.547', 'ms1ms2_ratio': '1.154', 'efficiency': '0.737', 'TP': '265', 'FP': '181', 'FN': '22', 'precision': '0.594', 'recall': '0.923', 'f1': '0.723'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.492', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '107', 'FP': '113', 'FN': '14', 'precision': '0.486', 'recall': '0.884', 'f1': '0.628'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '162', 'FP': '143', 'FN': '17', 'precision': '0.531', 'recall': '0.905', 'f1': '0.669'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.521', 'ms1ms2_ratio': '1.042', 'efficiency': '0.723', 'TP': '249', 'FP': '220', 'FN': '24', 'precision': '0.531', 'recall': '0.912', 'f1': '0.671'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.514', 'ms1ms2_ratio': '2.002', 'efficiency': '0.725', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1888.264443                1909.0          0.254           0.059
# 1  random   -1894.402435                1912.0          0.263           0.061
# 2  random   -1855.175347                1885.0          0.383           0.090
# 3  random   -1825.335659                1862.0          0.418           0.108
# 4  random   -1865.374501                1892.0          0.332           0.073
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.004       0.054      0.185   0.059  0.090
# 1          0.007       0.035      0.203   0.068  0.101
# 2          0.005       0.076      0.212   0.116  0.150
# 3          0.005       0.095      0.222   0.138  0.170
# 4          0.004       0.073      0.179   0.082  0.112

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     279.236760                   0.0          0.962           0.740
# 31    DQN     248.945424                   0.0          0.958           0.794
# 32    DQN     256.269616                   0.0          0.964           0.740
# 33    DQN     270.482519                   0.0          0.956           0.751
# 34    DQN     273.337864                   0.0          0.986           0.751
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.139       0.262      0.880   0.958  0.917
# 31          0.181       0.171      0.924   0.955  0.939
# 32          0.160       0.251      0.868   0.959  0.912
# 33          0.149       0.280      0.903   0.951  0.926
# 34          0.159       0.284      0.865   0.984  0.921

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
