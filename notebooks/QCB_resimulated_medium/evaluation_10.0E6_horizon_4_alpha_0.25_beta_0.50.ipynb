# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-07 16:26:20.002 | INFO     | vimms_gym.experiments:get_samplers:295 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fda4cfe3df0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fda4f6162e0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fda2896b580>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_10.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fda4cfe3df0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fda4f6162e0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fda2896b580>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fda4cfe3df0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fda4f6162e0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fda2896b580>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_10.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_10.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -484.85902919254755
# steps	 1000 	total rewards	 -957.3837303032906
# steps	 1500 	total rewards	 -1376.1146111370977
# Finished after 1991 timesteps (2.090273141860962 seconds) with total reward -1836.195851912863
# {'coverage_prop': '0.394', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.005', 'efficiency': '0.085', 'TP': '36', 'FP': '132', 'FN': '258', 'precision': '0.214', 'recall': '0.122', 'f1': '0.156', 'total_rewards': -1836.1958519128632, 'invalid_action_count': 1867, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -492.3887961197896
# steps	 1000 	total rewards	 -952.4897665046843
# steps	 1500 	total rewards	 -1419.402920393647
# Finished after 1988 timesteps (0.9068009853363037 seconds) with total reward -1868.8809556434103
# {'coverage_prop': '0.393', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.006', 'efficiency': '0.052', 'TP': '26', 'FP': '77', 'FN': '159', 'precision': '0.252', 'recall': '0.141', 'f1': '0.181', 'total_rewards': -1868.8809556434114, 'invalid_action_count': 1895, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -486.83723354462
# steps	 1000 	total rewards	 -972.0049755065039
# steps	 1500 	total rewards	 -1422.2981348076053
# Finished after 1988 timesteps (1.2198078632354736 seconds) with total reward -1865.7383791208304
# {'coverage_prop': '0.348', 'intensity_prop': '0.070', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '20', 'FP': '117', 'FN': '257', 'precision': '0.146', 'recall': '0.072', 'f1': '0.097', 'total_rewards': -1865.7383791208304, 'invalid_action_count': 1891, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -476.5234116587591
# steps	 1000 	total rewards	 -939.4747300351293
# steps	 1500 	total rewards	 -1389.3845056035848
# Finished after 1988 timesteps (1.4730839729309082 seconds) with total reward -1824.1488948726962
# {'coverage_prop': '0.396', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.006', 'efficiency': '0.091', 'TP': '44', 'FP': '135', 'FN': '273', 'precision': '0.246', 'recall': '0.139', 'f1': '0.177', 'total_rewards': -1824.1488948726965, 'invalid_action_count': 1858, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -488.07084068383205
# steps	 1000 	total rewards	 -943.2569273942929
# steps	 1500 	total rewards	 -1412.1109892352536
# Finished after 1989 timesteps (1.2666947841644287 seconds) with total reward -1855.8786600673438
# {'coverage_prop': '0.332', 'intensity_prop': '0.094', 'ms1ms2_ratio': '0.006', 'efficiency': '0.073', 'TP': '36', 'FP': '109', 'FN': '292', 'precision': '0.248', 'recall': '0.110', 'f1': '0.152', 'total_rewards': -1855.8786600673443, 'invalid_action_count': 1884, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -490.06744141621846
# steps	 1000 	total rewards	 -980.351914715315
# steps	 1500 	total rewards	 -1458.3626133535504
# Finished after 1985 timesteps (0.8696260452270508 seconds) with total reward -1917.672817038596
# {'coverage_prop': '0.305', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.008', 'efficiency': '0.031', 'TP': '16', 'FP': '45', 'FN': '139', 'precision': '0.262', 'recall': '0.103', 'f1': '0.148', 'total_rewards': -1917.6728170385961, 'invalid_action_count': 1930, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -472.1365117213856
# steps	 1000 	total rewards	 -930.9281617561483
# steps	 1500 	total rewards	 -1421.2515293681483
# Finished after 1989 timesteps (1.3389911651611328 seconds) with total reward -1870.8524109138984
# {'coverage_prop': '0.293', 'intensity_prop': '0.070', 'ms1ms2_ratio': '0.006', 'efficiency': '0.071', 'TP': '30', 'FP': '110', 'FN': '338', 'precision': '0.214', 'recall': '0.082', 'f1': '0.118', 'total_rewards': -1870.8524109138987, 'invalid_action_count': 1896, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -496.1822809261134
# steps	 1000 	total rewards	 -960.8704629164097
# steps	 1500 	total rewards	 -1423.8864650684504
# Finished after 1985 timesteps (0.8411331176757812 seconds) with total reward -1890.6576310205755
# {'coverage_prop': '0.279', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.008', 'efficiency': '0.029', 'TP': '20', 'FP': '37', 'FN': '147', 'precision': '0.351', 'recall': '0.120', 'f1': '0.179', 'total_rewards': -1890.6576310205755, 'invalid_action_count': 1909, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -466.04320891584257
# steps	 1000 	total rewards	 -929.0458151755981
# steps	 1500 	total rewards	 -1372.0058029118522
# Finished after 1988 timesteps (1.2248320579528809 seconds) with total reward -1822.371830364812
# {'coverage_prop': '0.375', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.006', 'efficiency': '0.080', 'TP': '32', 'FP': '127', 'FN': '265', 'precision': '0.201', 'recall': '0.108', 'f1': '0.140', 'total_rewards': -1822.3718303648118, 'invalid_action_count': 1858, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -479.13439085917366
# steps	 1000 	total rewards	 -940.3190904388417
# steps	 1500 	total rewards	 -1361.2691871327634
# Finished after 1987 timesteps (1.1328051090240479 seconds) with total reward -1818.7650200139815
# {'coverage_prop': '0.456', 'intensity_prop': '0.140', 'ms1ms2_ratio': '0.007', 'efficiency': '0.089', 'TP': '51', 'FP': '124', 'FN': '209', 'precision': '0.291', 'recall': '0.196', 'f1': '0.234', 'total_rewards': -1818.765020013981, 'invalid_action_count': 1854, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -486.55701491073046
# steps	 1000 	total rewards	 -932.8419932461454
# steps	 1500 	total rewards	 -1376.2360328117984
# Finished after 1993 timesteps (1.2666411399841309 seconds) with total reward -1839.5720752668606
# {'coverage_prop': '0.361', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.004', 'efficiency': '0.081', 'TP': '39', 'FP': '121', 'FN': '283', 'precision': '0.244', 'recall': '0.121', 'f1': '0.162', 'total_rewards': -1839.57207526686, 'invalid_action_count': 1872, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -487.3828852115845
# steps	 1000 	total rewards	 -959.8279717809639
# steps	 1500 	total rewards	 -1423.803180815939
# Finished after 1986 timesteps (0.9865190982818604 seconds) with total reward -1888.8225595964507
# {'coverage_prop': '0.361', 'intensity_prop': '0.085', 'ms1ms2_ratio': '0.007', 'efficiency': '0.046', 'TP': '17', 'FP': '73', 'FN': '159', 'precision': '0.189', 'recall': '0.097', 'f1': '0.128', 'total_rewards': -1888.8225595964507, 'invalid_action_count': 1907, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -484.64740461233123
# steps	 1000 	total rewards	 -961.8082917189261
# steps	 1500 	total rewards	 -1424.4315066004192
# Finished after 1991 timesteps (0.9183981418609619 seconds) with total reward -1882.8765187509746
# {'coverage_prop': '0.359', 'intensity_prop': '0.086', 'ms1ms2_ratio': '0.005', 'efficiency': '0.045', 'TP': '18', 'FP': '72', 'FN': '161', 'precision': '0.200', 'recall': '0.101', 'f1': '0.134', 'total_rewards': -1882.8765187509746, 'invalid_action_count': 1906, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -482.4785705478203
# steps	 1000 	total rewards	 -958.2329581789643
# steps	 1500 	total rewards	 -1430.4190896789744
# Finished after 1991 timesteps (1.0400371551513672 seconds) with total reward -1878.5796924546944
# {'coverage_prop': '0.423', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.005', 'efficiency': '0.064', 'TP': '33', 'FP': '94', 'FN': '173', 'precision': '0.260', 'recall': '0.160', 'f1': '0.198', 'total_rewards': -1878.5796924546937, 'invalid_action_count': 1902, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -492.57328161585724
# steps	 1000 	total rewards	 -981.7417774858543
# steps	 1500 	total rewards	 -1451.3595901137423
# Finished after 1991 timesteps (0.8152799606323242 seconds) with total reward -1923.6918884262684
# {'coverage_prop': '0.218', 'intensity_prop': '0.053', 'ms1ms2_ratio': '0.005', 'efficiency': '0.023', 'TP': '7', 'FP': '38', 'FN': '161', 'precision': '0.156', 'recall': '0.042', 'f1': '0.066', 'total_rewards': -1923.6918884262686, 'invalid_action_count': 1937, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -975.9817971976306
# steps	 1500 	total rewards	 -1416.9163352498072
# Finished after 1994 timesteps (1.1619582176208496 seconds) with total reward -1897.3695850844185
# {'coverage_prop': '0.322', 'intensity_prop': '0.065', 'ms1ms2_ratio': '0.003', 'efficiency': '0.066', 'TP': '23', 'FP': '108', 'FN': '276', 'precision': '0.176', 'recall': '0.077', 'f1': '0.107', 'total_rewards': -1897.369585084419, 'invalid_action_count': 1919, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -487.92570133077845
# steps	 1000 	total rewards	 -944.2437985439756
# steps	 1500 	total rewards	 -1397.4629427979219
# Finished after 1993 timesteps (1.462752103805542 seconds) with total reward -1847.3225151381
# {'coverage_prop': '0.367', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.004', 'efficiency': '0.092', 'TP': '46', 'FP': '137', 'FN': '315', 'precision': '0.251', 'recall': '0.127', 'f1': '0.169', 'total_rewards': -1847.3225151381002, 'invalid_action_count': 1879, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -480.8030265231618
# steps	 1000 	total rewards	 -930.4945449414768
# steps	 1500 	total rewards	 -1398.8526784093747
# Finished after 1989 timesteps (1.1309771537780762 seconds) with total reward -1857.0250955209938
# {'coverage_prop': '0.366', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '31', 'FP': '105', 'FN': '236', 'precision': '0.228', 'recall': '0.116', 'f1': '0.154', 'total_rewards': -1857.0250955209942, 'invalid_action_count': 1886, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -966.1589216121773
# steps	 1500 	total rewards	 -1435.660838595767
# Finished after 1993 timesteps (1.0033440589904785 seconds) with total reward -1911.0318469283884
# {'coverage_prop': '0.308', 'intensity_prop': '0.065', 'ms1ms2_ratio': '0.004', 'efficiency': '0.047', 'TP': '15', 'FP': '78', 'FN': '209', 'precision': '0.161', 'recall': '0.067', 'f1': '0.095', 'total_rewards': -1911.0318469283884, 'invalid_action_count': 1929, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -498.0
# steps	 1000 	total rewards	 -982.6979749060492
# steps	 1500 	total rewards	 -1449.981640132396
# Finished after 1991 timesteps (0.9438340663909912 seconds) with total reward -1911.99668989782
# {'coverage_prop': '0.253', 'intensity_prop': '0.065', 'ms1ms2_ratio': '0.005', 'efficiency': '0.034', 'TP': '14', 'FP': '53', 'FN': '198', 'precision': '0.209', 'recall': '0.066', 'f1': '0.100', 'total_rewards': -1911.9966898978198, 'invalid_action_count': 1927, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -914.1652016957889
# steps	 1500 	total rewards	 -1340.5424912338685
# Finished after 1987 timesteps (1.3232851028442383 seconds) with total reward -1775.5680523177698
# {'coverage_prop': '0.442', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.007', 'efficiency': '0.105', 'TP': '42', 'FP': '165', 'FN': '261', 'precision': '0.203', 'recall': '0.139', 'f1': '0.165', 'total_rewards': -1775.5680523177698, 'invalid_action_count': 1820, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -480.0665072413557
# steps	 1000 	total rewards	 -965.3018031616971
# steps	 1500 	total rewards	 -1440.9910765223158
# Finished after 1986 timesteps (0.8807029724121094 seconds) with total reward -1897.778844507313
# {'coverage_prop': '0.346', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.007', 'efficiency': '0.041', 'TP': '10', 'FP': '71', 'FN': '153', 'precision': '0.123', 'recall': '0.061', 'f1': '0.082', 'total_rewards': -1897.7788445073134, 'invalid_action_count': 1916, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -972.4461354990024
# steps	 1500 	total rewards	 -1439.807958048851
# Finished after 1994 timesteps (0.9892439842224121 seconds) with total reward -1918.3063757119521
# {'coverage_prop': '0.248', 'intensity_prop': '0.057', 'ms1ms2_ratio': '0.003', 'efficiency': '0.040', 'TP': '18', 'FP': '62', 'FN': '242', 'precision': '0.225', 'recall': '0.069', 'f1': '0.106', 'total_rewards': -1918.3063757119523, 'invalid_action_count': 1933, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -490.2235291297004
# steps	 1000 	total rewards	 -963.876256848771
# steps	 1500 	total rewards	 -1431.516245559908
# Finished after 1989 timesteps (0.9530911445617676 seconds) with total reward -1912.0027366835236
# {'coverage_prop': '0.245', 'intensity_prop': '0.054', 'ms1ms2_ratio': '0.006', 'efficiency': '0.038', 'TP': '13', 'FP': '63', 'FN': '234', 'precision': '0.171', 'recall': '0.053', 'f1': '0.080', 'total_rewards': -1912.0027366835234, 'invalid_action_count': 1927, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -491.0545828558457
# steps	 1000 	total rewards	 -953.6133403581508
# steps	 1500 	total rewards	 -1395.596150198443
# Finished after 1989 timesteps (1.1029391288757324 seconds) with total reward -1872.112599536889
# {'coverage_prop': '0.330', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.006', 'efficiency': '0.058', 'TP': '22', 'FP': '92', 'FN': '231', 'precision': '0.193', 'recall': '0.087', 'f1': '0.120', 'total_rewards': -1872.1125995368898, 'invalid_action_count': 1897, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -493.4219670212544
# steps	 1000 	total rewards	 -958.9112384804387
# steps	 1500 	total rewards	 -1432.2093559688637
# Finished after 1994 timesteps (1.6163382530212402 seconds) with total reward -1917.7963907820217
# {'coverage_prop': '0.212', 'intensity_prop': '0.038', 'ms1ms2_ratio': '0.003', 'efficiency': '0.042', 'TP': '10', 'FP': '74', 'FN': '312', 'precision': '0.119', 'recall': '0.031', 'f1': '0.049', 'total_rewards': -1917.7963907820222, 'invalid_action_count': 1935, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -494.2436195945386
# steps	 1000 	total rewards	 -965.7540587718092
# steps	 1500 	total rewards	 -1440.4921356551445
# Finished after 1987 timesteps (0.8359391689300537 seconds) with total reward -1913.836902438107
# {'coverage_prop': '0.315', 'intensity_prop': '0.098', 'ms1ms2_ratio': '0.007', 'efficiency': '0.032', 'TP': '18', 'FP': '46', 'FN': '139', 'precision': '0.281', 'recall': '0.115', 'f1': '0.163', 'total_rewards': -1913.836902438107, 'invalid_action_count': 1929, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -478.29311531333724
# steps	 1000 	total rewards	 -963.4797766141613
# steps	 1500 	total rewards	 -1406.976151570228
# Finished after 1988 timesteps (0.9198579788208008 seconds) with total reward -1866.0905861925853
# {'coverage_prop': '0.381', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.006', 'efficiency': '0.054', 'TP': '29', 'FP': '78', 'FN': '174', 'precision': '0.271', 'recall': '0.143', 'f1': '0.187', 'total_rewards': -1866.0905861925855, 'invalid_action_count': 1893, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -477.2553851269877
# steps	 1000 	total rewards	 -895.5030580802306
# steps	 1500 	total rewards	 -1309.5086602407514
# Finished after 1979 timesteps (1.4109899997711182 seconds) with total reward -1705.7417347054802
# {'coverage_prop': '0.467', 'intensity_prop': '0.176', 'ms1ms2_ratio': '0.011', 'efficiency': '0.117', 'TP': '84', 'FP': '146', 'FN': '263', 'precision': '0.365', 'recall': '0.242', 'f1': '0.291', 'total_rewards': -1705.7417347054811, 'invalid_action_count': 1761, 'num_ms1_scans': 21, 'num_ms2_scans': 1958}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -491.8299379584547
# steps	 1000 	total rewards	 -952.8668123599201
# steps	 1500 	total rewards	 -1414.65446574949
# Finished after 1990 timesteps (1.0064387321472168 seconds) with total reward -1879.9978790118066
# {'coverage_prop': '0.336', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.005', 'efficiency': '0.052', 'TP': '25', 'FP': '77', 'FN': '202', 'precision': '0.245', 'recall': '0.110', 'f1': '0.152', 'total_rewards': -1879.997879011806, 'invalid_action_count': 1903, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 8.35GB > 0.57GB
# steps	 500 	total rewards	 73.63897139449091
# steps	 1000 	total rewards	 156.5847879275713
# steps	 1500 	total rewards	 239.7784581912824
# Finished after 1779 timesteps (3.0779662132263184 seconds) with total reward 279.95437047578207
# {'coverage_prop': '0.955', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.143', 'efficiency': '0.261', 'TP': '355', 'FP': '52', 'FN': '19', 'precision': '0.872', 'recall': '0.949', 'f1': '0.909', 'total_rewards': 279.95437047578224, 'invalid_action_count': 0, 'num_ms1_scans': 222, 'num_ms2_scans': 1557}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 65.10471994659721
# steps	 1000 	total rewards	 138.81383420427943
# steps	 1500 	total rewards	 216.06299107138975
# Finished after 1733 timesteps (2.820384979248047 seconds) with total reward 248.6723997980052
# {'coverage_prop': '0.958', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.182', 'efficiency': '0.171', 'TP': '235', 'FP': '16', 'FN': '11', 'precision': '0.936', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 248.67239979800524, 'invalid_action_count': 0, 'num_ms1_scans': 267, 'num_ms2_scans': 1466}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 64.67134617669394
# steps	 1000 	total rewards	 145.3577825265866
# steps	 1500 	total rewards	 220.27197558494282
# Finished after 1755 timesteps (3.61674427986145 seconds) with total reward 256.9128491733596
# {'coverage_prop': '0.959', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.162', 'efficiency': '0.250', 'TP': '324', 'FP': '54', 'FN': '16', 'precision': '0.857', 'recall': '0.953', 'f1': '0.903', 'total_rewards': 256.91284917335975, 'invalid_action_count': 0, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 74.76441314846177
# steps	 1000 	total rewards	 156.0465076413435
# steps	 1500 	total rewards	 230.4797767098662
# Finished after 1774 timesteps (2.7732439041137695 seconds) with total reward 270.55514288805625
# {'coverage_prop': '0.965', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.146', 'efficiency': '0.282', 'TP': '395', 'FP': '41', 'FN': '16', 'precision': '0.906', 'recall': '0.961', 'f1': '0.933', 'total_rewards': 270.55514288805676, 'invalid_action_count': 0, 'num_ms1_scans': 226, 'num_ms2_scans': 1548}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 68.53314700996206
# steps	 1000 	total rewards	 150.08318963185934
# steps	 1500 	total rewards	 231.48811360117753
# Finished after 1763 timesteps (2.802598237991333 seconds) with total reward 271.33243258214804
# {'coverage_prop': '0.970', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.155', 'efficiency': '0.278', 'TP': '365', 'FP': '59', 'FN': '13', 'precision': '0.861', 'recall': '0.966', 'f1': '0.910', 'total_rewards': 271.3324325821482, 'invalid_action_count': 0, 'num_ms1_scans': 237, 'num_ms2_scans': 1526}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 56.89891973159586
# steps	 1000 	total rewards	 126.31479425193012
# steps	 1500 	total rewards	 185.57390834441478
# Finished after 1704 timesteps (2.095761775970459 seconds) with total reward 209.00696877928635
# {'coverage_prop': '0.955', 'intensity_prop': '0.823', 'ms1ms2_ratio': '0.210', 'efficiency': '0.136', 'TP': '185', 'FP': '6', 'FN': '9', 'precision': '0.969', 'recall': '0.954', 'f1': '0.961', 'total_rewards': 209.0069687792864, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 68.38049425855621
# steps	 1000 	total rewards	 153.7680141166418
# steps	 1500 	total rewards	 230.24561299015534
# Finished after 1773 timesteps (2.8044826984405518 seconds) with total reward 268.7514783275982
# {'coverage_prop': '0.935', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.147', 'efficiency': '0.289', 'TP': '388', 'FP': '59', 'FN': '31', 'precision': '0.868', 'recall': '0.926', 'f1': '0.896', 'total_rewards': 268.7514783275985, 'invalid_action_count': 0, 'num_ms1_scans': 227, 'num_ms2_scans': 1546}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 54.855879585915154
# steps	 1000 	total rewards	 132.56740444910355
# steps	 1500 	total rewards	 200.44230993358678
# Finished after 1702 timesteps (2.7661561965942383 seconds) with total reward 227.74043666856716
# {'coverage_prop': '0.956', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.212', 'efficiency': '0.139', 'TP': '184', 'FP': '11', 'FN': '9', 'precision': '0.944', 'recall': '0.953', 'f1': '0.948', 'total_rewards': 227.74043666856693, 'invalid_action_count': 0, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 75.21414382829744
# steps	 1000 	total rewards	 153.63636461463688
# steps	 1500 	total rewards	 231.21733378466172
# Finished after 1788 timesteps (2.5518991947174072 seconds) with total reward 271.34147537498177
# {'coverage_prop': '0.948', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.135', 'efficiency': '0.255', 'TP': '354', 'FP': '48', 'FN': '22', 'precision': '0.881', 'recall': '0.941', 'f1': '0.910', 'total_rewards': 271.34147537498166, 'invalid_action_count': 0, 'num_ms1_scans': 213, 'num_ms2_scans': 1575}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 68.94220517049285
# steps	 1000 	total rewards	 147.27478371071754
# steps	 1500 	total rewards	 226.52775636503173
# Finished after 1771 timesteps (2.4611737728118896 seconds) with total reward 262.37466973745643
# {'coverage_prop': '0.953', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.149', 'efficiency': '0.237', 'TP': '329', 'FP': '37', 'FN': '18', 'precision': '0.899', 'recall': '0.948', 'f1': '0.923', 'total_rewards': 262.37466973745614, 'invalid_action_count': 0, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 69.35112193517408
# steps	 1000 	total rewards	 147.4272963461849
# steps	 1500 	total rewards	 234.24517408923134
# Finished after 1783 timesteps (3.3631107807159424 seconds) with total reward 274.21026620612184
# {'coverage_prop': '0.946', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.139', 'efficiency': '0.268', 'TP': '378', 'FP': '41', 'FN': '24', 'precision': '0.902', 'recall': '0.940', 'f1': '0.921', 'total_rewards': 274.2102662061216, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 63.72898956525328
# steps	 1000 	total rewards	 138.17983520491504
# steps	 1500 	total rewards	 199.03988059021822
# Finished after 1728 timesteps (2.185360908508301 seconds) with total reward 226.78191158369037
# {'coverage_prop': '0.956', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.187', 'efficiency': '0.163', 'TP': '221', 'FP': '17', 'FN': '11', 'precision': '0.929', 'recall': '0.953', 'f1': '0.940', 'total_rewards': 226.7819115836898, 'invalid_action_count': 0, 'num_ms1_scans': 272, 'num_ms2_scans': 1456}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 66.18105517680635
# steps	 1000 	total rewards	 130.95609784856447
# steps	 1500 	total rewards	 199.80954389931713
# Finished after 1759 timesteps (2.1446211338043213 seconds) with total reward 238.1106788838124
# {'coverage_prop': '0.948', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.159', 'efficiency': '0.157', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925', 'total_rewards': 238.1106788838126, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 62.17974700474889
# steps	 1000 	total rewards	 138.09467994796785
# steps	 1500 	total rewards	 211.32671699616373
# Finished after 1753 timesteps (3.1779367923736572 seconds) with total reward 239.6886570392661
# {'coverage_prop': '0.963', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.164', 'efficiency': '0.192', 'TP': '249', 'FP': '40', 'FN': '11', 'precision': '0.862', 'recall': '0.958', 'f1': '0.907', 'total_rewards': 239.6886570392664, 'invalid_action_count': 0, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 59.51469103653514
# steps	 1000 	total rewards	 132.98539362954705
# steps	 1500 	total rewards	 197.56410302503156
# Finished after 1726 timesteps (1.9998788833618164 seconds) with total reward 225.1067321913451
# {'coverage_prop': '0.951', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.189', 'efficiency': '0.135', 'TP': '180', 'FP': '16', 'FN': '10', 'precision': '0.918', 'recall': '0.947', 'f1': '0.933', 'total_rewards': 225.1067321913451, 'invalid_action_count': 0, 'num_ms1_scans': 274, 'num_ms2_scans': 1452}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 63.997570277925426
# steps	 1000 	total rewards	 145.09378296857903
# steps	 1500 	total rewards	 225.64309965281615
# Finished after 1763 timesteps (2.575531005859375 seconds) with total reward 263.70571808716784
# {'coverage_prop': '0.961', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.155', 'efficiency': '0.256', 'TP': '360', 'FP': '31', 'FN': '16', 'precision': '0.921', 'recall': '0.957', 'f1': '0.939', 'total_rewards': 263.7057180871684, 'invalid_action_count': 0, 'num_ms1_scans': 237, 'num_ms2_scans': 1526}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 73.00976655238702
# steps	 1000 	total rewards	 157.7238261616643
# steps	 1500 	total rewards	 238.75331500070564
# Finished after 1781 timesteps (3.6931779384613037 seconds) with total reward 277.1728891220866
# {'coverage_prop': '0.956', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.141', 'efficiency': '0.305', 'TP': '430', 'FP': '46', 'FN': '22', 'precision': '0.903', 'recall': '0.951', 'f1': '0.927', 'total_rewards': 277.1728891220867, 'invalid_action_count': 0, 'num_ms1_scans': 220, 'num_ms2_scans': 1561}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 69.89401339725977
# steps	 1000 	total rewards	 147.66618925800645
# steps	 1500 	total rewards	 223.59738994086484
# Finished after 1769 timesteps (2.4616336822509766 seconds) with total reward 259.7618506963339
# {'coverage_prop': '0.954', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.150', 'efficiency': '0.231', 'TP': '323', 'FP': '32', 'FN': '17', 'precision': '0.910', 'recall': '0.950', 'f1': '0.929', 'total_rewards': 259.7618506963341, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 66.57269318684715
# steps	 1000 	total rewards	 139.12197025891473
# steps	 1500 	total rewards	 214.49347212392064
# Finished after 1750 timesteps (2.3212897777557373 seconds) with total reward 249.21608583277035
# {'coverage_prop': '0.964', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.167', 'efficiency': '0.194', 'TP': '264', 'FP': '27', 'FN': '11', 'precision': '0.907', 'recall': '0.960', 'f1': '0.933', 'total_rewards': 249.21608583277018, 'invalid_action_count': 0, 'num_ms1_scans': 250, 'num_ms2_scans': 1500}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 64.62794126884508
# steps	 1000 	total rewards	 138.31710601385242
# steps	 1500 	total rewards	 204.0383589942611
# Finished after 1754 timesteps (3.1458680629730225 seconds) with total reward 240.17623046243898
# {'coverage_prop': '0.977', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.163', 'efficiency': '0.172', 'TP': '234', 'FP': '25', 'FN': '6', 'precision': '0.903', 'recall': '0.975', 'f1': '0.938', 'total_rewards': 240.176230462439, 'invalid_action_count': 0, 'num_ms1_scans': 246, 'num_ms2_scans': 1508}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.49377361076907
# steps	 1000 	total rewards	 155.59035015385575
# steps	 1500 	total rewards	 233.70369511965214
# Finished after 1772 timesteps (2.7867770195007324 seconds) with total reward 274.03908536958534
# {'coverage_prop': '0.910', 'intensity_prop': '0.717', 'ms1ms2_ratio': '0.148', 'efficiency': '0.276', 'TP': '389', 'FP': '37', 'FN': '42', 'precision': '0.913', 'recall': '0.903', 'f1': '0.908', 'total_rewards': 274.0390853695853, 'invalid_action_count': 0, 'num_ms1_scans': 228, 'num_ms2_scans': 1544}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 62.3377614735141
# steps	 1000 	total rewards	 132.15792018133118
# steps	 1500 	total rewards	 203.19800136224364
# Finished after 1722 timesteps (2.1366770267486572 seconds) with total reward 227.73816849025536
# {'coverage_prop': '0.957', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.193', 'efficiency': '0.155', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 227.73816849025533, 'invalid_action_count': 1, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 67.86614207684919
# steps	 1000 	total rewards	 144.49262990179557
# steps	 1500 	total rewards	 218.25762317045397
# Finished after 1758 timesteps (2.3152730464935303 seconds) with total reward 256.16591578689076
# {'coverage_prop': '0.963', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.160', 'efficiency': '0.204', 'TP': '287', 'FP': '23', 'FN': '12', 'precision': '0.926', 'recall': '0.960', 'f1': '0.943', 'total_rewards': 256.1659157868903, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 66.93461333317185
# steps	 1000 	total rewards	 143.57383704146116
# steps	 1500 	total rewards	 216.5339994719524
# Finished after 1738 timesteps (3.5083377361297607 seconds) with total reward 248.37693929051613
# {'coverage_prop': '0.942', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.178', 'efficiency': '0.198', 'TP': '266', 'FP': '26', 'FN': '18', 'precision': '0.911', 'recall': '0.937', 'f1': '0.924', 'total_rewards': 248.37693929051653, 'invalid_action_count': 0, 'num_ms1_scans': 262, 'num_ms2_scans': 1476}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 66.62968214116717
# steps	 1000 	total rewards	 147.97935622150294
# steps	 1500 	total rewards	 221.6661314918906
# Finished after 1758 timesteps (2.370837926864624 seconds) with total reward 260.628602300543
# {'coverage_prop': '0.977', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.160', 'efficiency': '0.222', 'TP': '298', 'FP': '39', 'FN': '8', 'precision': '0.884', 'recall': '0.974', 'f1': '0.927', 'total_rewards': 260.62860230054315, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 67.7261739667351
# steps	 1000 	total rewards	 139.96639043213372
# steps	 1500 	total rewards	 217.9088741036539
# Finished after 1779 timesteps (2.491248846054077 seconds) with total reward 258.85386828386356
# {'coverage_prop': '0.977', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.142', 'efficiency': '0.248', 'TP': '348', 'FP': '39', 'FN': '9', 'precision': '0.899', 'recall': '0.975', 'f1': '0.935', 'total_rewards': 258.8538682838635, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 53.567388131079596
# steps	 1000 	total rewards	 122.50938950048855
# steps	 1500 	total rewards	 185.5203759357658
# Finished after 1717 timesteps (2.036156177520752 seconds) with total reward 212.735617415666
# {'coverage_prop': '0.966', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.197', 'efficiency': '0.137', 'TP': '187', 'FP': '9', 'FN': '7', 'precision': '0.954', 'recall': '0.964', 'f1': '0.959', 'total_rewards': 212.73561741566567, 'invalid_action_count': 1, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 64.52149927568911
# steps	 1000 	total rewards	 134.79374505401603
# steps	 1500 	total rewards	 206.5603590878937
# Finished after 1740 timesteps (3.3985939025878906 seconds) with total reward 243.77762170788333
# {'coverage_prop': '0.964', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.176', 'efficiency': '0.183', 'TP': '250', 'FP': '21', 'FN': '10', 'precision': '0.923', 'recall': '0.962', 'f1': '0.942', 'total_rewards': 243.77762170788336, 'invalid_action_count': 0, 'num_ms1_scans': 261, 'num_ms2_scans': 1479}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 78.32144931137353
# steps	 1000 	total rewards	 158.77502815652542
# steps	 1500 	total rewards	 239.3157500713539
# Finished after 1784 timesteps (2.8173987865448 seconds) with total reward 283.27405227835106
# {'coverage_prop': '0.921', 'intensity_prop': '0.686', 'ms1ms2_ratio': '0.138', 'efficiency': '0.290', 'TP': '391', 'FP': '63', 'FN': '39', 'precision': '0.861', 'recall': '0.909', 'f1': '0.885', 'total_rewards': 283.2740522783504, 'invalid_action_count': 0, 'num_ms1_scans': 216, 'num_ms2_scans': 1568}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 62.97562326261573
# steps	 1000 	total rewards	 139.31410871988615
# steps	 1500 	total rewards	 206.86072031529937
# Finished after 1743 timesteps (2.3689041137695312 seconds) with total reward 243.174418405685
# {'coverage_prop': '0.957', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.173', 'efficiency': '0.196', 'TP': '256', 'FP': '35', 'FN': '13', 'precision': '0.880', 'recall': '0.952', 'f1': '0.914', 'total_rewards': 243.17441840568526, 'invalid_action_count': 0, 'num_ms1_scans': 257, 'num_ms2_scans': 1486}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 59.39818191121025
# steps	 1000 	total rewards	 138.5720354265331
# steps	 1500 	total rewards	 216.50731766728592
# Finished after 1722 timesteps (9.030270338058472 seconds) with total reward 246.07141932758293
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 246.0714193275831, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 49.80161912604831
# steps	 1000 	total rewards	 119.66530569651563
# steps	 1500 	total rewards	 182.3992088220571
# Finished after 1556 timesteps (8.73668384552002 seconds) with total reward 187.702141952342
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 187.70214195234212, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 51.29301484412087
# steps	 1000 	total rewards	 125.26814493487129
# steps	 1500 	total rewards	 199.36020268664623
# Finished after 1669 timesteps (8.794636011123657 seconds) with total reward 220.9268071029097
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 220.92680710290975, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 64.69221918652914
# steps	 1000 	total rewards	 139.94091009129198
# steps	 1500 	total rewards	 210.17085329269364
# Finished after 1717 timesteps (10.387435913085938 seconds) with total reward 241.4853865752503
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 241.48538657525012, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 56.35584713914693
# steps	 1000 	total rewards	 137.785216868901
# steps	 1500 	total rewards	 214.6881814813977
# Finished after 1704 timesteps (8.969834089279175 seconds) with total reward 243.52717224427786
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 243.52717224427778, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 36.85977339249479
# steps	 1000 	total rewards	 97.24997682559521
# Finished after 1408 timesteps (7.157737970352173 seconds) with total reward 130.37118689369876
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 130.37118689369868, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 61.83065113097078
# steps	 1000 	total rewards	 142.56596201074652
# steps	 1500 	total rewards	 214.3361857069055
# Finished after 1744 timesteps (10.439449071884155 seconds) with total reward 247.45355319082682
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 247.45355319082682, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 36.7169139046746
# steps	 1000 	total rewards	 107.55288808607207
# Finished after 1468 timesteps (7.272509813308716 seconds) with total reward 154.88443368221024
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 154.88443368221022, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 63.69932181538106
# steps	 1000 	total rewards	 135.50525156126935
# steps	 1500 	total rewards	 209.02143440684972
# Finished after 1736 timesteps (10.07099175453186 seconds) with total reward 240.33224302373395
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 240.3322430237338, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 51.650777099447936
# steps	 1000 	total rewards	 125.19839863770888
# steps	 1500 	total rewards	 199.70280782087247
# Finished after 1667 timesteps (10.193905115127563 seconds) with total reward 217.68242373898718
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 217.68242373898724, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 58.73325228414852
# steps	 1000 	total rewards	 135.05027654333225
# steps	 1500 	total rewards	 210.82813437149593
# Finished after 1737 timesteps (9.184119939804077 seconds) with total reward 242.4599445757275
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 242.45994457572795, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 44.480522347636935
# steps	 1000 	total rewards	 111.26720284815937
# steps	 1500 	total rewards	 159.55269808514626
# Finished after 1530 timesteps (7.720874071121216 seconds) with total reward 162.24444510207155
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 162.24444510207155, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 45.39252917269736
# steps	 1000 	total rewards	 111.72437799007685
# steps	 1500 	total rewards	 174.84141305174293
# Finished after 1602 timesteps (10.659876108169556 seconds) with total reward 186.07155417023205
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 186.07155417023196, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 49.15360821284917
# steps	 1000 	total rewards	 119.6031795309076
# steps	 1500 	total rewards	 184.6587961709919
# Finished after 1645 timesteps (8.619267702102661 seconds) with total reward 198.81613111042032
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 198.81613111042054, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 38.660879944836125
# steps	 1000 	total rewards	 104.6229891790933
# Finished after 1497 timesteps (7.336181879043579 seconds) with total reward 155.6062870524459
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 155.60628705244605, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 51.44764050188936
# steps	 1000 	total rewards	 128.8143354572842
# steps	 1500 	total rewards	 198.00886489737445
# Finished after 1655 timesteps (8.730731010437012 seconds) with total reward 218.38188038198132
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 218.3818803819814, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 62.70461590148102
# steps	 1000 	total rewards	 139.29462868404227
# steps	 1500 	total rewards	 216.17781227924297
# Finished after 1729 timesteps (11.124279022216797 seconds) with total reward 246.00395093770442
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 246.00395093770413, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 58.42443886984613
# steps	 1000 	total rewards	 134.48739921356457
# steps	 1500 	total rewards	 203.27761145212088
# Finished after 1681 timesteps (8.636227130889893 seconds) with total reward 224.5758684609182
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 224.57586846091846, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 46.70791752204587
# steps	 1000 	total rewards	 119.38068923043548
# steps	 1500 	total rewards	 187.44753687163077
# Finished after 1621 timesteps (8.248084783554077 seconds) with total reward 200.0943415427971
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 200.09434154279748, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 47.97066074112459
# steps	 1000 	total rewards	 117.80237298317604
# steps	 1500 	total rewards	 180.4080084670927
# Finished after 1634 timesteps (9.758381843566895 seconds) with total reward 196.08351966112917
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 196.0835196611289, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 62.264924262774656
# steps	 1000 	total rewards	 139.851120208098
# steps	 1500 	total rewards	 213.07257580533394
# Finished after 1726 timesteps (9.542535066604614 seconds) with total reward 245.11037209771413
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 245.11037209771456, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 39.38367416005345
# steps	 1000 	total rewards	 106.71603693124862
# Finished after 1475 timesteps (7.774716854095459 seconds) with total reward 153.20481810659373
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 153.2048181065938, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 53.11142262146333
# steps	 1000 	total rewards	 124.27370748618455
# steps	 1500 	total rewards	 193.48348271444524
# Finished after 1636 timesteps (8.242507934570312 seconds) with total reward 209.13347304634203
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 209.13347304634198, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 52.33369295169392
# steps	 1000 	total rewards	 125.90752415102662
# steps	 1500 	total rewards	 185.4895286328575
# Finished after 1575 timesteps (9.936499118804932 seconds) with total reward 192.07315619040207
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 192.07315619040207, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 51.359324220773956
# steps	 1000 	total rewards	 128.20122403599643
# steps	 1500 	total rewards	 199.61646960616366
# Finished after 1681 timesteps (8.564095973968506 seconds) with total reward 222.65188021845023
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 222.65188021845015, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 53.486927712012815
# steps	 1000 	total rewards	 122.3230387222704
# steps	 1500 	total rewards	 197.5573745494595
# Finished after 1679 timesteps (8.909321069717407 seconds) with total reward 218.69830459399594
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 218.69830459399566, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 36.900191107476665
# steps	 1000 	total rewards	 100.79174218983904
# Finished after 1465 timesteps (7.3636579513549805 seconds) with total reward 144.91480985494655
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 144.9148098549467, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 48.149666789891
# steps	 1000 	total rewards	 118.19535529379077
# steps	 1500 	total rewards	 180.83050390836837
# Finished after 1564 timesteps (10.050938844680786 seconds) with total reward 188.7400005085405
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 188.74000050854016, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 67.50510674505492
# steps	 1000 	total rewards	 139.962212241089
# steps	 1500 	total rewards	 216.28971565908762
# Finished after 1749 timesteps (9.355896949768066 seconds) with total reward 252.95716387797603
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 252.95716387797603, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 51.975984210899966
# steps	 1000 	total rewards	 123.10203982392332
# steps	 1500 	total rewards	 187.76545015733265
# Finished after 1657 timesteps (8.227950096130371 seconds) with total reward 206.1422481395321
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 206.14224813953206, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fda4cfe3df0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fda4f6162e0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fda2896b580>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.795', 'efficiency': '0.539', 'TP': '360', 'FP': '56', 'FN': '10', 'precision': '0.865', 'recall': '0.973', 'f1': '0.916'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.855', 'efficiency': '0.518', 'TP': '328', 'FP': '54', 'FN': '12', 'precision': '0.859', 'recall': '0.965', 'f1': '0.909'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.713', 'ms1ms2_ratio': '0.741', 'efficiency': '0.546', 'TP': '382', 'FP': '58', 'FN': '12', 'precision': '0.868', 'recall': '0.970', 'f1': '0.916'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.772', 'efficiency': '0.551', 'TP': '366', 'FP': '67', 'FN': '4', 'precision': '0.845', 'recall': '0.989', 'f1': '0.912'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.679', 'efficiency': '0.541', 'TP': '400', 'FP': '59', 'FN': '19', 'precision': '0.871', 'recall': '0.955', 'f1': '0.911'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.718', 'ms1ms2_ratio': '2.080', 'efficiency': '0.505', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.717', 'ms1ms2_ratio': '0.690', 'efficiency': '0.508', 'TP': '372', 'FP': '55', 'FN': '16', 'precision': '0.871', 'recall': '0.959', 'f1': '0.913'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.671', 'ms1ms2_ratio': '1.606', 'efficiency': '0.501', 'TP': '198', 'FP': '40', 'FN': '13', 'precision': '0.832', 'recall': '0.938', 'f1': '0.882'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.686', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.861', 'efficiency': '0.541', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.606', 'efficiency': '0.537', 'TP': '421', 'FP': '65', 'FN': '12', 'precision': '0.866', 'recall': '0.972', 'f1': '0.916'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '310', 'FP': '50', 'FN': '12', 'precision': '0.861', 'recall': '0.963', 'f1': '0.909'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.695', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '195', 'FP': '28', 'FN': '11', 'precision': '0.874', 'recall': '0.947', 'f1': '0.909'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '275', 'FP': '37', 'FN': '10', 'precision': '0.881', 'recall': '0.965', 'f1': '0.921'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.973', 'efficiency': '0.499', 'TP': '297', 'FP': '42', 'FN': '6', 'precision': '0.876', 'recall': '0.980', 'f1': '0.925'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.855', 'efficiency': '0.530', 'TP': '338', 'FP': '53', 'FN': '5', 'precision': '0.864', 'recall': '0.985', 'f1': '0.921'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.722', 'ms1ms2_ratio': '1.370', 'efficiency': '0.508', 'TP': '240', 'FP': '32', 'FN': '9', 'precision': '0.882', 'recall': '0.964', 'f1': '0.921'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.591', 'efficiency': '0.522', 'TP': '405', 'FP': '74', 'FN': '14', 'precision': '0.846', 'recall': '0.967', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1836.195852                1867.0          0.394           0.097
# 1  random   -1868.880956                1895.0          0.393           0.093
# 2  random   -1865.738379                1891.0          0.348           0.070
# 3  random   -1824.148895                1858.0          0.396           0.107
# 4  random   -1855.878660                1884.0          0.332           0.094
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.085      0.214   0.122  0.156
# 1          0.006       0.052      0.252   0.141  0.181
# 2          0.006       0.069      0.146   0.072  0.097
# 3          0.006       0.091      0.246   0.139  0.177
# 4          0.006       0.073      0.248   0.110  0.152

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     279.954370                   0.0          0.955           0.722
# 31    DQN     248.672400                   0.0          0.958           0.794
# 32    DQN     256.912849                   0.0          0.959           0.733
# 33    DQN     270.555143                   0.0          0.965           0.766
# 34    DQN     271.332433                   0.0          0.970           0.749
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.143       0.261      0.872   0.949  0.909
# 31          0.182       0.171      0.936   0.955  0.946
# 32          0.162       0.250      0.857   0.953  0.903
# 33          0.146       0.282      0.906   0.961  0.933
# 34          0.155       0.278      0.861   0.966  0.910

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
