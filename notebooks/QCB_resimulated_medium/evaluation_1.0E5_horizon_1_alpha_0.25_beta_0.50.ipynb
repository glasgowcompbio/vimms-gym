# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-04-09 23:57:08.084 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f80457db970>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f80217c9150>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f80217e22f0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.5}},
#  30)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5

dqn_in_dir = 'DQN_1.0E5'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_1.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f80457db970>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f80217c9150>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f80217e22f0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f80457db970>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f80217c9150>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f80217e22f0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
horizon = 1
out_dir = 'evaluation_1.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    model = None
    if method == METHOD_TOPN:
        N = topN_N
        effective_rt_tol = topN_rt_tol
        copy_params['env']['use_dew'] = True
        copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 101.64298000944727
# steps	 1000 	total rewards	 112.42891604469918
# steps	 1500 	total rewards	 94.54567315746533
# Finished after 1786 timesteps (1.916954755783081 seconds) with total reward 72.55259408503191
# {'coverage_prop': '0.939', 'intensity_prop': '0.697', 'ms1ms2_ratio': '0.136', 'efficiency': '0.254', 'TP': '340', 'FP': '60', 'FN': '26', 'precision': '0.850', 'recall': '0.929', 'f1': '0.888', 'total_rewards': 72.55259408503177, 'invalid_action_count': 0, 'num_ms1_scans': 214, 'num_ms2_scans': 1572}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 133.72585971984898
# steps	 1000 	total rewards	 187.3981585452707
# steps	 1500 	total rewards	 160.19172419743518
# Finished after 1707 timesteps (1.2396349906921387 seconds) with total reward 148.0355808610537
# {'coverage_prop': '0.939', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.207', 'efficiency': '0.174', 'TP': '229', 'FP': '17', 'FN': '16', 'precision': '0.931', 'recall': '0.935', 'f1': '0.933', 'total_rewards': 148.03558086105332, 'invalid_action_count': 0, 'num_ms1_scans': 293, 'num_ms2_scans': 1414}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 113.7622526863129
# steps	 1000 	total rewards	 154.067001447239
# steps	 1500 	total rewards	 215.58261770159078
# Finished after 1768 timesteps (1.4786288738250732 seconds) with total reward 221.17706875591875
# {'coverage_prop': '0.934', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.151', 'efficiency': '0.240', 'TP': '307', 'FP': '61', 'FN': '26', 'precision': '0.834', 'recall': '0.922', 'f1': '0.876', 'total_rewards': 221.1770687559188, 'invalid_action_count': 0, 'num_ms1_scans': 232, 'num_ms2_scans': 1536}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 112.15967453170842
# steps	 1000 	total rewards	 206.76724949371715
# steps	 1500 	total rewards	 212.09047494396575
# Finished after 1786 timesteps (1.8315541744232178 seconds) with total reward 240.5194546820002
# {'coverage_prop': '0.945', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.136', 'efficiency': '0.272', 'TP': '376', 'FP': '51', 'FN': '25', 'precision': '0.881', 'recall': '0.938', 'f1': '0.908', 'total_rewards': 240.5194546820001, 'invalid_action_count': 0, 'num_ms1_scans': 214, 'num_ms2_scans': 1572}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 33.51636934819894
# steps	 1000 	total rewards	 121.52210927419699
# steps	 1500 	total rewards	 139.88644766079403
# Finished after 1784 timesteps (1.5148930549621582 seconds) with total reward 122.39941806323485
# {'coverage_prop': '0.961', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.138', 'efficiency': '0.268', 'TP': '356', 'FP': '64', 'FN': '17', 'precision': '0.848', 'recall': '0.954', 'f1': '0.898', 'total_rewards': 122.39941806323489, 'invalid_action_count': 0, 'num_ms1_scans': 216, 'num_ms2_scans': 1568}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 57.9976797660321
# steps	 1000 	total rewards	 115.65132584082991
# steps	 1500 	total rewards	 87.64816125906307
# Finished after 1631 timesteps (1.614426851272583 seconds) with total reward 87.97857092438534
# {'coverage_prop': '0.945', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.292', 'efficiency': '0.150', 'TP': '179', 'FP': '10', 'FN': '11', 'precision': '0.947', 'recall': '0.942', 'f1': '0.945', 'total_rewards': 87.97857092438521, 'invalid_action_count': 0, 'num_ms1_scans': 369, 'num_ms2_scans': 1262}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 120.85012645492318
# steps	 1000 	total rewards	 199.8543303641622
# steps	 1500 	total rewards	 128.17722679939524
# Finished after 1796 timesteps (1.9066591262817383 seconds) with total reward 79.18612609603312
# {'coverage_prop': '0.916', 'intensity_prop': '0.674', 'ms1ms2_ratio': '0.128', 'efficiency': '0.275', 'TP': '357', 'FP': '81', 'FN': '40', 'precision': '0.815', 'recall': '0.899', 'f1': '0.855', 'total_rewards': 79.18612609603335, 'invalid_action_count': 0, 'num_ms1_scans': 204, 'num_ms2_scans': 1592}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 28.216653592162075
# steps	 1000 	total rewards	 40.79269113723718
# steps	 1500 	total rewards	 -26.062101851101453
# Finished after 1655 timesteps (1.2208471298217773 seconds) with total reward -26.417769800907998
# {'coverage_prop': '0.951', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.263', 'efficiency': '0.148', 'TP': '179', 'FP': '15', 'FN': '10', 'precision': '0.923', 'recall': '0.947', 'f1': '0.935', 'total_rewards': -26.417769800908008, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 94.58722333609957
# steps	 1000 	total rewards	 145.45742461125192
# steps	 1500 	total rewards	 167.77417333155307
# Finished after 1799 timesteps (1.8461577892303467 seconds) with total reward 174.44911526330034
# {'coverage_prop': '0.934', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.126', 'efficiency': '0.248', 'TP': '332', 'FP': '64', 'FN': '28', 'precision': '0.838', 'recall': '0.922', 'f1': '0.878', 'total_rewards': 174.44911526330048, 'invalid_action_count': 0, 'num_ms1_scans': 201, 'num_ms2_scans': 1598}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 104.1486379648205
# steps	 1000 	total rewards	 154.40259608234248
# steps	 1500 	total rewards	 156.25012612131508
# Finished after 1759 timesteps (1.4247550964355469 seconds) with total reward 112.90028732316107
# {'coverage_prop': '0.924', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.159', 'efficiency': '0.234', 'TP': '297', 'FP': '58', 'FN': '29', 'precision': '0.837', 'recall': '0.911', 'f1': '0.872', 'total_rewards': 112.90028732316107, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 101.63175293971531
# steps	 1000 	total rewards	 151.64654516680747
# steps	 1500 	total rewards	 196.1338430086637
# Finished after 1797 timesteps (1.517876148223877 seconds) with total reward 159.28227174938831
# {'coverage_prop': '0.919', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.127', 'efficiency': '0.255', 'TP': '346', 'FP': '61', 'FN': '36', 'precision': '0.850', 'recall': '0.906', 'f1': '0.877', 'total_rewards': 159.28227174938843, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 105.59065306681578
# steps	 1000 	total rewards	 144.07870558473988
# steps	 1500 	total rewards	 102.13211481344365
# Finished after 1701 timesteps (1.2866461277008057 seconds) with total reward 75.16798197605796
# {'coverage_prop': '0.948', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.213', 'efficiency': '0.168', 'TP': '216', 'FP': '20', 'FN': '13', 'precision': '0.915', 'recall': '0.943', 'f1': '0.929', 'total_rewards': 75.1679819760577, 'invalid_action_count': 0, 'num_ms1_scans': 299, 'num_ms2_scans': 1402}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 13.88345368957225
# steps	 1000 	total rewards	 19.027566814406647
# steps	 1500 	total rewards	 -33.690867455095784
# Finished after 1731 timesteps (1.260453701019287 seconds) with total reward -82.30413082830837
# {'coverage_prop': '0.940', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.184', 'efficiency': '0.161', 'TP': '199', 'FP': '37', 'FN': '15', 'precision': '0.843', 'recall': '0.930', 'f1': '0.884', 'total_rewards': -82.30413082830835, 'invalid_action_count': 0, 'num_ms1_scans': 269, 'num_ms2_scans': 1462}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 26.22466267011398
# steps	 1000 	total rewards	 -2.2079871526046375
# steps	 1500 	total rewards	 -7.765513689951993
# Finished after 1770 timesteps (1.833083152770996 seconds) with total reward -95.34906161902255
# {'coverage_prop': '0.943', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.149', 'efficiency': '0.184', 'TP': '252', 'FP': '31', 'FN': '17', 'precision': '0.890', 'recall': '0.937', 'f1': '0.913', 'total_rewards': -95.34906161902254, 'invalid_action_count': 0, 'num_ms1_scans': 230, 'num_ms2_scans': 1540}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 13.745009029331026
# steps	 1000 	total rewards	 -8.91697627664325
# steps	 1500 	total rewards	 -70.0339147214548
# Finished after 1685 timesteps (1.2244110107421875 seconds) with total reward -78.785026406656
# {'coverage_prop': '0.951', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.231', 'efficiency': '0.143', 'TP': '178', 'FP': '18', 'FN': '10', 'precision': '0.908', 'recall': '0.947', 'f1': '0.927', 'total_rewards': -78.7850264066561, 'invalid_action_count': 0, 'num_ms1_scans': 316, 'num_ms2_scans': 1369}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 69.11243236706875
# steps	 1000 	total rewards	 110.00050842619765
# steps	 1500 	total rewards	 158.13299654570844
# Finished after 1750 timesteps (2.0228559970855713 seconds) with total reward 170.873539829062
# {'coverage_prop': '0.946', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.167', 'efficiency': '0.257', 'TP': '332', 'FP': '53', 'FN': '22', 'precision': '0.862', 'recall': '0.938', 'f1': '0.899', 'total_rewards': 170.87353982906188, 'invalid_action_count': 0, 'num_ms1_scans': 250, 'num_ms2_scans': 1500}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 133.3605203877064
# steps	 1000 	total rewards	 199.2163480018983
# steps	 1500 	total rewards	 199.78931660685964
# Finished after 1794 timesteps (1.5858428478240967 seconds) with total reward 209.27966617363467
# {'coverage_prop': '0.942', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.130', 'efficiency': '0.295', 'TP': '403', 'FP': '66', 'FN': '29', 'precision': '0.859', 'recall': '0.933', 'f1': '0.895', 'total_rewards': 209.27966617363475, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 137.0180421892499
# steps	 1000 	total rewards	 201.7501579809537
# steps	 1500 	total rewards	 187.95255734095525
# Finished after 1775 timesteps (1.5449931621551514 seconds) with total reward 162.2224024180453
# {'coverage_prop': '0.944', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.145', 'efficiency': '0.226', 'TP': '299', 'FP': '52', 'FN': '21', 'precision': '0.852', 'recall': '0.934', 'f1': '0.891', 'total_rewards': 162.22240241804485, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 106.45244824847398
# steps	 1000 	total rewards	 173.9011694178593
# steps	 1500 	total rewards	 213.99853286373713
# Finished after 1742 timesteps (2.2043819427490234 seconds) with total reward 229.80621585047837
# {'coverage_prop': '0.940', 'intensity_prop': '0.739', 'ms1ms2_ratio': '0.174', 'efficiency': '0.191', 'TP': '253', 'FP': '31', 'FN': '18', 'precision': '0.891', 'recall': '0.934', 'f1': '0.912', 'total_rewards': 229.80621585047822, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 1484}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 81.0115836642453
# steps	 1000 	total rewards	 126.1888018391219
# steps	 1500 	total rewards	 91.57673905252332
# Finished after 1739 timesteps (1.2806520462036133 seconds) with total reward 30.506906435784572
# {'coverage_prop': '0.966', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.177', 'efficiency': '0.173', 'TP': '227', 'FP': '29', 'FN': '9', 'precision': '0.887', 'recall': '0.962', 'f1': '0.923', 'total_rewards': 30.506906435784526, 'invalid_action_count': 0, 'num_ms1_scans': 261, 'num_ms2_scans': 1478}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 64.21613003956035
# steps	 1000 	total rewards	 57.32607055256108
# steps	 1500 	total rewards	 64.11939845538363
# Finished after 1797 timesteps (1.5362470149993896 seconds) with total reward 40.260021122413534
# {'coverage_prop': '0.900', 'intensity_prop': '0.678', 'ms1ms2_ratio': '0.127', 'efficiency': '0.264', 'TP': '358', 'FP': '63', 'FN': '47', 'precision': '0.850', 'recall': '0.884', 'f1': '0.867', 'total_rewards': 40.2600211224135, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 85.00813410831239
# steps	 1000 	total rewards	 119.0017464532456
# steps	 1500 	total rewards	 161.0259784807601
# Finished after 1673 timesteps (1.2909340858459473 seconds) with total reward 192.49974299977885
# {'coverage_prop': '0.949', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.244', 'efficiency': '0.165', 'TP': '199', 'FP': '23', 'FN': '12', 'precision': '0.896', 'recall': '0.943', 'f1': '0.919', 'total_rewards': 192.4997429997785, 'invalid_action_count': 0, 'num_ms1_scans': 328, 'num_ms2_scans': 1345}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 48.90290200135489
# steps	 1000 	total rewards	 96.36022773105731
# steps	 1500 	total rewards	 98.57363077503658
# Finished after 1736 timesteps (1.3535428047180176 seconds) with total reward 90.77320352050643
# {'coverage_prop': '0.957', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.179', 'efficiency': '0.209', 'TP': '268', 'FP': '40', 'FN': '14', 'precision': '0.870', 'recall': '0.950', 'f1': '0.908', 'total_rewards': 90.7732035205064, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 103.30920438959059
# steps	 1000 	total rewards	 157.8583642419781
# steps	 1500 	total rewards	 197.36023923615875
# Finished after 1720 timesteps (1.9879422187805176 seconds) with total reward 207.939279275798
# {'coverage_prop': '0.932', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.195', 'efficiency': '0.201', 'TP': '257', 'FP': '32', 'FN': '21', 'precision': '0.889', 'recall': '0.924', 'f1': '0.907', 'total_rewards': 207.93927927579813, 'invalid_action_count': 0, 'num_ms1_scans': 281, 'num_ms2_scans': 1439}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 119.2411212032413
# steps	 1000 	total rewards	 201.16616716154402
# steps	 1500 	total rewards	 147.84248018856658
# Finished after 1757 timesteps (1.3356070518493652 seconds) with total reward 160.6581760186011
# {'coverage_prop': '0.962', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.161', 'efficiency': '0.219', 'TP': '288', 'FP': '44', 'FN': '13', 'precision': '0.867', 'recall': '0.957', 'f1': '0.910', 'total_rewards': 160.65817601860059, 'invalid_action_count': 0, 'num_ms1_scans': 243, 'num_ms2_scans': 1514}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 75.17930856515162
# steps	 1000 	total rewards	 141.15949121096241
# steps	 1500 	total rewards	 220.5510226930856
# Finished after 1773 timesteps (1.406527042388916 seconds) with total reward 236.73491115850246
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.147', 'efficiency': '0.246', 'TP': '318', 'FP': '63', 'FN': '15', 'precision': '0.835', 'recall': '0.955', 'f1': '0.891', 'total_rewards': 236.73491115850246, 'invalid_action_count': 0, 'num_ms1_scans': 227, 'num_ms2_scans': 1546}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -22.89144859406284
# steps	 1000 	total rewards	 66.47962325389257
# steps	 1500 	total rewards	 55.62825050896635
# Finished after 1652 timesteps (1.2480602264404297 seconds) with total reward 39.612202626076645
# {'coverage_prop': '0.956', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.267', 'efficiency': '0.149', 'TP': '186', 'FP': '8', 'FN': '9', 'precision': '0.959', 'recall': '0.954', 'f1': '0.956', 'total_rewards': 39.61220262607666, 'invalid_action_count': 0, 'num_ms1_scans': 348, 'num_ms2_scans': 1304}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 17.719072503039115
# steps	 1000 	total rewards	 43.05648959931531
# steps	 1500 	total rewards	 154.40416655502207
# Finished after 1710 timesteps (2.042368173599243 seconds) with total reward 187.72766094778376
# {'coverage_prop': '0.954', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.204', 'efficiency': '0.189', 'TP': '243', 'FP': '25', 'FN': '13', 'precision': '0.907', 'recall': '0.949', 'f1': '0.927', 'total_rewards': 187.72766094778373, 'invalid_action_count': 0, 'num_ms1_scans': 290, 'num_ms2_scans': 1420}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 98.07283134002526
# steps	 1000 	total rewards	 85.90302044255914
# steps	 1500 	total rewards	 78.70280474428154
# Finished after 1807 timesteps (1.5825910568237305 seconds) with total reward 72.37891653288958
# {'coverage_prop': '0.913', 'intensity_prop': '0.670', 'ms1ms2_ratio': '0.120', 'efficiency': '0.279', 'TP': '372', 'FP': '78', 'FN': '43', 'precision': '0.827', 'recall': '0.896', 'f1': '0.860', 'total_rewards': 72.37891653288963, 'invalid_action_count': 0, 'num_ms1_scans': 193, 'num_ms2_scans': 1614}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 45.364591438910864
# steps	 1000 	total rewards	 54.50579053020442
# steps	 1500 	total rewards	 22.296044561200134
# Finished after 1746 timesteps (1.3400380611419678 seconds) with total reward -21.710750415140758
# {'coverage_prop': '0.941', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.170', 'efficiency': '0.192', 'TP': '255', 'FP': '31', 'FN': '18', 'precision': '0.892', 'recall': '0.934', 'f1': '0.912', 'total_rewards': -21.710750415140804, 'invalid_action_count': 0, 'num_ms1_scans': 254, 'num_ms2_scans': 1492}
#
# method = topN max_peaks = 30 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 106.63395611197905
# steps	 1000 	total rewards	 142.22504470688082
# steps	 1500 	total rewards	 153.8717033119445
# Finished after 1700 timesteps (6.7180750370025635 seconds) with total reward 141.71527200394175
# {'coverage_prop': '0.960', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.214', 'efficiency': '0.292', 'TP': '369', 'FP': '40', 'FN': '17', 'precision': '0.902', 'recall': '0.956', 'f1': '0.928', 'total_rewards': 141.7152720039416, 'invalid_action_count': 0, 'num_ms1_scans': 300, 'num_ms2_scans': 1400}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 106.47072854015892
# steps	 1000 	total rewards	 190.2799660643697
# steps	 1500 	total rewards	 206.54252507372235
# Finished after 1529 timesteps (5.1073009967803955 seconds) with total reward 203.13244432874072
# {'coverage_prop': '0.962', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.447', 'efficiency': '0.238', 'TP': '237', 'FP': '15', 'FN': '10', 'precision': '0.940', 'recall': '0.960', 'f1': '0.950', 'total_rewards': 203.13244432874046, 'invalid_action_count': 0, 'num_ms1_scans': 472, 'num_ms2_scans': 1057}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 95.94991021355071
# steps	 1000 	total rewards	 174.12264118316764
# steps	 1500 	total rewards	 243.8528458544992
# Finished after 1647 timesteps (5.465996026992798 seconds) with total reward 246.96616174019184
# {'coverage_prop': '0.967', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.273', 'efficiency': '0.294', 'TP': '346', 'FP': '35', 'FN': '13', 'precision': '0.908', 'recall': '0.964', 'f1': '0.935', 'total_rewards': 246.9661617401918, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 118.24176273793861
# steps	 1000 	total rewards	 216.14584966299995
# steps	 1500 	total rewards	 235.72085464746826
# Finished after 1690 timesteps (6.904745101928711 seconds) with total reward 248.02031688258552
# {'coverage_prop': '0.956', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '397', 'FP': '35', 'FN': '20', 'precision': '0.919', 'recall': '0.952', 'f1': '0.935', 'total_rewards': 248.0203168825854, 'invalid_action_count': 0, 'num_ms1_scans': 311, 'num_ms2_scans': 1379}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 63.98571740381488
# steps	 1000 	total rewards	 189.32487638972523
# steps	 1500 	total rewards	 193.75670199450286
# Finished after 1678 timesteps (5.602336168289185 seconds) with total reward 198.31886484405882
# {'coverage_prop': '0.982', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.237', 'efficiency': '0.316', 'TP': '380', 'FP': '49', 'FN': '8', 'precision': '0.886', 'recall': '0.979', 'f1': '0.930', 'total_rewards': 198.3188648440588, 'invalid_action_count': 0, 'num_ms1_scans': 322, 'num_ms2_scans': 1356}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 69.4231243993963
# steps	 1000 	total rewards	 127.55050800948555
# Finished after 1385 timesteps (6.163918972015381 seconds) with total reward 143.8716462524361
# {'coverage_prop': '0.955', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.799', 'efficiency': '0.248', 'TP': '182', 'FP': '9', 'FN': '9', 'precision': '0.953', 'recall': '0.953', 'f1': '0.953', 'total_rewards': 143.87164625243634, 'invalid_action_count': 0, 'num_ms1_scans': 615, 'num_ms2_scans': 770}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 107.18192404779646
# steps	 1000 	total rewards	 206.7486026165886
# steps	 1500 	total rewards	 167.03411244735258
# Finished after 1720 timesteps (5.862917900085449 seconds) with total reward 143.05655593542036
# {'coverage_prop': '0.933', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.194', 'efficiency': '0.310', 'TP': '395', 'FP': '51', 'FN': '32', 'precision': '0.886', 'recall': '0.925', 'f1': '0.905', 'total_rewards': 143.05655593542056, 'invalid_action_count': 0, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 43.123855574065644
# steps	 1000 	total rewards	 93.5990444616398
# Finished after 1444 timesteps (4.916741847991943 seconds) with total reward 121.22961857942408
# {'coverage_prop': '0.966', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.626', 'efficiency': '0.222', 'TP': '187', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.957', 'total_rewards': 121.22961857942413, 'invalid_action_count': 0, 'num_ms1_scans': 556, 'num_ms2_scans': 888}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 107.89165241681005
# steps	 1000 	total rewards	 179.0563390797976
# steps	 1500 	total rewards	 228.55540401276957
# Finished after 1706 timesteps (5.529949188232422 seconds) with total reward 224.8844046600393
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931', 'total_rewards': 224.88440466003973, 'invalid_action_count': 0, 'num_ms1_scans': 294, 'num_ms2_scans': 1412}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 95.73317664764349
# steps	 1000 	total rewards	 194.82581203854554
# steps	 1500 	total rewards	 213.156767948048
# Finished after 1644 timesteps (5.527151107788086 seconds) with total reward 201.11911565403594
# {'coverage_prop': '0.958', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.276', 'efficiency': '0.286', 'TP': '339', 'FP': '29', 'FN': '16', 'precision': '0.921', 'recall': '0.955', 'f1': '0.938', 'total_rewards': 201.1191156540358, 'invalid_action_count': 0, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 102.89822018128486
# steps	 1000 	total rewards	 176.38810813652077
# steps	 1500 	total rewards	 209.0357100147038
# Finished after 1723 timesteps (5.642319202423096 seconds) with total reward 193.93840326079146
# {'coverage_prop': '0.948', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.192', 'efficiency': '0.290', 'TP': '382', 'FP': '38', 'FN': '23', 'precision': '0.910', 'recall': '0.943', 'f1': '0.926', 'total_rewards': 193.93840326079152, 'invalid_action_count': 0, 'num_ms1_scans': 277, 'num_ms2_scans': 1446}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 100.0753051474233
# steps	 1000 	total rewards	 168.7307317305142
# steps	 1500 	total rewards	 148.39381079124163
# Finished after 1501 timesteps (5.216678142547607 seconds) with total reward 148.39381079124163
# {'coverage_prop': '0.960', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '226', 'FP': '13', 'FN': '10', 'precision': '0.946', 'recall': '0.958', 'f1': '0.952', 'total_rewards': 148.39381079124155, 'invalid_action_count': 0, 'num_ms1_scans': 500, 'num_ms2_scans': 1001}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 58.061741097780704
# steps	 1000 	total rewards	 103.3674711827552
# steps	 1500 	total rewards	 65.8542643903648
# Finished after 1577 timesteps (6.9498631954193115 seconds) with total reward 58.142444704216004
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.367', 'efficiency': '0.206', 'TP': '215', 'FP': '23', 'FN': '13', 'precision': '0.903', 'recall': '0.943', 'f1': '0.923', 'total_rewards': 58.142444704215876, 'invalid_action_count': 0, 'num_ms1_scans': 423, 'num_ms2_scans': 1154}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 67.16011229573786
# steps	 1000 	total rewards	 56.803225004549404
# steps	 1500 	total rewards	 58.286271949146155
# Finished after 1621 timesteps (5.669341325759888 seconds) with total reward 29.981226421518343
# {'coverage_prop': '0.963', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '263', 'FP': '26', 'FN': '11', 'precision': '0.910', 'recall': '0.960', 'f1': '0.934', 'total_rewards': 29.981226421518205, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 58.213202925174215
# steps	 1000 	total rewards	 80.48045301767098
# Finished after 1472 timesteps (5.055171966552734 seconds) with total reward 75.6975516124117
# {'coverage_prop': '0.956', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941', 'total_rewards': 75.69755161241169, 'invalid_action_count': 0, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 80.84462422312731
# steps	 1000 	total rewards	 152.3604207223952
# steps	 1500 	total rewards	 225.83135010016989
# Finished after 1627 timesteps (7.121583938598633 seconds) with total reward 240.35221120839293
# {'coverage_prop': '0.966', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.297', 'efficiency': '0.313', 'TP': '366', 'FP': '27', 'FN': '14', 'precision': '0.931', 'recall': '0.963', 'f1': '0.947', 'total_rewards': 240.3522112083933, 'invalid_action_count': 0, 'num_ms1_scans': 373, 'num_ms2_scans': 1254}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 129.15626583952684
# steps	 1000 	total rewards	 206.04640002606615
# steps	 1500 	total rewards	 222.9443079327113
# Finished after 1712 timesteps (5.7056097984313965 seconds) with total reward 239.2181830313522
# {'coverage_prop': '0.958', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.202', 'efficiency': '0.335', 'TP': '437', 'FP': '40', 'FN': '21', 'precision': '0.916', 'recall': '0.954', 'f1': '0.935', 'total_rewards': 239.21818303135225, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 119.63824849090636
# steps	 1000 	total rewards	 186.300945158268
# steps	 1500 	total rewards	 189.33646026711898
# Finished after 1654 timesteps (5.6113197803497314 seconds) with total reward 183.31214633915857
# {'coverage_prop': '0.965', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.265', 'efficiency': '0.274', 'TP': '329', 'FP': '30', 'FN': '13', 'precision': '0.916', 'recall': '0.962', 'f1': '0.939', 'total_rewards': 183.3121463391587, 'invalid_action_count': 0, 'num_ms1_scans': 346, 'num_ms2_scans': 1308}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 105.66331721673217
# steps	 1000 	total rewards	 205.8929349635462
# steps	 1500 	total rewards	 251.99311207657985
# Finished after 1584 timesteps (5.368063926696777 seconds) with total reward 256.97339959829037
# {'coverage_prop': '0.967', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940', 'total_rewards': 256.9733995982904, 'invalid_action_count': 0, 'num_ms1_scans': 416, 'num_ms2_scans': 1168}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 75.9107994036902
# steps	 1000 	total rewards	 150.35247709078396
# steps	 1500 	total rewards	 118.82879254618646
# Finished after 1601 timesteps (7.541696071624756 seconds) with total reward 105.53086652615613
# {'coverage_prop': '0.977', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.333', 'efficiency': '0.216', 'TP': '240', 'FP': '19', 'FN': '6', 'precision': '0.927', 'recall': '0.976', 'f1': '0.950', 'total_rewards': 105.53086652615627, 'invalid_action_count': 0, 'num_ms1_scans': 400, 'num_ms2_scans': 1201}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 102.77002708015581
# steps	 1000 	total rewards	 124.15303743755163
# steps	 1500 	total rewards	 139.53870681225789
# Finished after 1704 timesteps (5.711984872817993 seconds) with total reward 143.8711312642993
# {'coverage_prop': '0.925', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.210', 'efficiency': '0.308', 'TP': '400', 'FP': '33', 'FN': '35', 'precision': '0.924', 'recall': '0.920', 'f1': '0.922', 'total_rewards': 143.87113126429895, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 82.0681644151673
# steps	 1000 	total rewards	 178.34558703492834
# Finished after 1444 timesteps (5.0981340408325195 seconds) with total reward 223.4441740128919
# {'coverage_prop': '0.957', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.628', 'efficiency': '0.253', 'TP': '200', 'FP': '24', 'FN': '10', 'precision': '0.893', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 223.44417401289135, 'invalid_action_count': 0, 'num_ms1_scans': 557, 'num_ms2_scans': 887}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 71.39015463320771
# steps	 1000 	total rewards	 144.31301621553303
# steps	 1500 	total rewards	 165.83991518882294
# Finished after 1609 timesteps (5.3054358959198 seconds) with total reward 171.94561324580988
# {'coverage_prop': '0.966', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949', 'total_rewards': 171.94561324581002, 'invalid_action_count': 0, 'num_ms1_scans': 392, 'num_ms2_scans': 1217}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 84.70601807878572
# steps	 1000 	total rewards	 176.48997216630414
# steps	 1500 	total rewards	 233.62332405449246
# Finished after 1544 timesteps (7.232457876205444 seconds) with total reward 240.44831801952333
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935', 'total_rewards': 240.44831801952336, 'invalid_action_count': 0, 'num_ms1_scans': 457, 'num_ms2_scans': 1087}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 94.2047248713349
# steps	 1000 	total rewards	 207.74696660807663
# steps	 1500 	total rewards	 194.39414920266043
# Finished after 1655 timesteps (5.308476209640503 seconds) with total reward 205.94540074792764
# {'coverage_prop': '0.980', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.264', 'efficiency': '0.258', 'TP': '314', 'FP': '24', 'FN': '7', 'precision': '0.929', 'recall': '0.978', 'f1': '0.953', 'total_rewards': 205.94540074792766, 'invalid_action_count': 0, 'num_ms1_scans': 346, 'num_ms2_scans': 1309}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 99.50579064109368
# steps	 1000 	total rewards	 191.70262232407802
# steps	 1500 	total rewards	 293.10007768785147
# Finished after 1649 timesteps (5.47552490234375 seconds) with total reward 311.69119037341534
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944', 'total_rewards': 311.69119037341574, 'invalid_action_count': 0, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 24.333131481536846
# steps	 1000 	total rewards	 131.88458675676515
# Finished after 1434 timesteps (5.084731101989746 seconds) with total reward 146.29758840523235
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.652', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948', 'total_rewards': 146.29758840523226, 'invalid_action_count': 0, 'num_ms1_scans': 566, 'num_ms2_scans': 868}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 70.02772397903182
# steps	 1000 	total rewards	 160.6727061798964
# steps	 1500 	total rewards	 260.0920366825926
# Finished after 1527 timesteps (7.289285182952881 seconds) with total reward 262.46144688463835
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948', 'total_rewards': 262.4614468846381, 'invalid_action_count': 0, 'num_ms1_scans': 473, 'num_ms2_scans': 1054}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 91.02221976370261
# steps	 1000 	total rewards	 117.2208278275491
# steps	 1500 	total rewards	 140.53852676569636
# Finished after 1729 timesteps (5.824233055114746 seconds) with total reward 144.48736318134377
# {'coverage_prop': '0.933', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902', 'total_rewards': 144.48736318134394, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 71.12560289021108
# steps	 1000 	total rewards	 110.06398332504591
# steps	 1500 	total rewards	 102.23232911662592
# Finished after 1612 timesteps (5.463814973831177 seconds) with total reward 81.95581759651515
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950', 'total_rewards': 81.9558175965154, 'invalid_action_count': 0, 'num_ms1_scans': 388, 'num_ms2_scans': 1224}

# %% [markdown]
# #### DQN

# %%
import argparse
import os
import random
import socket
import time
from datetime import datetime
from distutils.util import strtobool
from typing import Callable

import gymnasium as gym
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from gymnasium.utils.env_checker import check_env
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter
from vimms.Common import load_obj
from vimms.Evaluation import EvaluationData

from vimms_gym.common import METHOD_DQN, evaluate
from vimms_gym.env import DDAEnv
from vimms_gym.experiments import preset_qcb_medium
from vimms_gym.wrappers import custom_flatten_dict_observations
from model.DQN import QNetwork, make_env, masked_epsilon_greedy

# %%
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
model_path = os.path.join(dqn_in_dir, 'DQN.model')
model_path
# Out:
# 'DQN_1.0E5/DQN.model'

# %%
env_id = 'DDAEnv'
Model = QNetwork

# %%
envs = gym.vector.SyncVectorEnv([make_env(env_id, 0, max_peaks, params)])
model = Model(envs).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()
# Out:
# /opt/anaconda3/envs/vimms-gym/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:42: UserWarning:
#
# WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (30, 10)
#
# /opt/anaconda3/envs/vimms-gym/lib/python3.10/site-packages/gymnasium/utils/env_checker.py:317: UserWarning:
#
# WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantialising the environment through gymnasium.make
# QNetwork(
#   (roi_network): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv1d(32, 64, kernel_size=(3,), stride=(1,))
#     (4): ReLU()
#     (5): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=64, out_features=64, bias=True)
#     (8): ReLU()
#   )
#   (output_layer): Linear(in_features=1984, out_features=31, bias=True)
#   (other_network): Sequential(
#     (0): Linear(in_features=277, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ReLU()
#   )
# )

# %%
eval_episodes = n_eval_episodes
eval_episodes, len(chem_list)
# Out:
# (30, 30)

# %%
episodic_returns = []
evaluation_results = []
for i in range(len(chem_list)):
    if i >= eval_episodes:
        break

    chems = chem_list[i]

    obs, info = envs.reset(options={'chems': chems})
    done = False
    eval_data = None
    while not done:
        env = envs.envs[0].env
        actions = masked_epsilon_greedy(device, max_peaks, None, obs, model,
                                        deterministic=True)

        next_obs, rewards, terminateds, truncateds, infos = envs.step(actions)
        dones = terminateds

        if 'final_info' in infos:
            final_infos = infos['final_info']
            assert len(final_infos) == 1
            info = final_infos[0]
            episodic_return = info['episode']['r'][0]
            episodic_length = info['episode']['l'][0]

            eval_res = evaluate(eval_data)
            eval_res['invalid_action_count'] = env.invalid_action_count
            eval_res['total_rewards'] = episodic_return
            eval_res['episodic_length'] = episodic_length
            eval_res['num_ms1_scans'] = len(eval_data.controller.scans[1])
            eval_res['num_ms2_scans'] = len(eval_data.controller.scans[2])
            evaluation_results.append(eval_res)

            print(
                f'Episode {i} ({len(chems)} chemicals) return {episodic_return} length {episodic_length}')
            print(eval_res)

            episodic_returns += [episodic_return]
            
            mzml_name = METHOD_DQN
            out_file = '%s_%d.mzML' % (mzml_name, i)
            vimms_env.write_mzML(out_dir, out_file)            

        obs = next_obs
        done = dones[0]

        # store previous results for evaluation before 'done'
        # this needs to be here, because VecEnv is automatically reset when done
        vimms_env = env.env.vimms_env
        eval_data = EvaluationData(vimms_env)
# Out:
# [W NNPACK.cpp:51] Could not initialize NNPACK! Reason: Unsupported hardware.
# Episode 0 (426 chemicals) return 398.32879638671875 length 1698
# {'coverage_prop': '0.937', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.216', 'efficiency': '0.286', 'TP': '345', 'FP': '54', 'FN': '27', 'precision': '0.865', 'recall': '0.927', 'f1': '0.895', 'invalid_action_count': 0, 'total_rewards': 398.3288, 'episodic_length': 1698, 'num_ms1_scans': 302, 'num_ms2_scans': 1396}
# Episode 1 (262 chemicals) return 463.41827392578125 length 1590
# {'coverage_prop': '0.943', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.349', 'efficiency': '0.209', 'TP': '228', 'FP': '19', 'FN': '15', 'precision': '0.923', 'recall': '0.938', 'f1': '0.931', 'invalid_action_count': 0, 'total_rewards': 463.41827, 'episodic_length': 1590, 'num_ms1_scans': 411, 'num_ms2_scans': 1179}
# Episode 2 (394 chemicals) return 407.6769104003906 length 1680
# {'coverage_prop': '0.934', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.235', 'efficiency': '0.271', 'TP': '317', 'FP': '51', 'FN': '26', 'precision': '0.861', 'recall': '0.924', 'f1': '0.892', 'invalid_action_count': 0, 'total_rewards': 407.6769, 'episodic_length': 1680, 'num_ms1_scans': 320, 'num_ms2_scans': 1360}
# Episode 3 (452 chemicals) return 416.4366455078125 length 1701
# {'coverage_prop': '0.934', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.213', 'efficiency': '0.301', 'TP': '376', 'FP': '46', 'FN': '30', 'precision': '0.891', 'recall': '0.926', 'f1': '0.908', 'invalid_action_count': 0, 'total_rewards': 416.43665, 'episodic_length': 1701, 'num_ms1_scans': 299, 'num_ms2_scans': 1402}
# Episode 4 (437 chemicals) return 318.88739013671875 length 1695
# {'coverage_prop': '0.952', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.220', 'efficiency': '0.299', 'TP': '368', 'FP': '48', 'FN': '21', 'precision': '0.885', 'recall': '0.946', 'f1': '0.914', 'invalid_action_count': 0, 'total_rewards': 318.8874, 'episodic_length': 1695, 'num_ms1_scans': 306, 'num_ms2_scans': 1389}
# Episode 5 (200 chemicals) return 235.41482543945312 length 1457
# {'coverage_prop': '0.945', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.594', 'efficiency': '0.207', 'TP': '172', 'FP': '17', 'FN': '11', 'precision': '0.910', 'recall': '0.940', 'f1': '0.925', 'invalid_action_count': 0, 'total_rewards': 235.41483, 'episodic_length': 1457, 'num_ms1_scans': 543, 'num_ms2_scans': 914}
# Episode 6 (478 chemicals) return 372.583984375 length 1722
# {'coverage_prop': '0.914', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.193', 'efficiency': '0.303', 'TP': '372', 'FP': '65', 'FN': '41', 'precision': '0.851', 'recall': '0.901', 'f1': '0.875', 'invalid_action_count': 0, 'total_rewards': 372.58398, 'episodic_length': 1722, 'num_ms1_scans': 279, 'num_ms2_scans': 1443}
# Episode 7 (204 chemicals) return 322.00811767578125 length 1497
# {'coverage_prop': '0.946', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.506', 'efficiency': '0.194', 'TP': '178', 'FP': '15', 'FN': '11', 'precision': '0.922', 'recall': '0.942', 'f1': '0.932', 'invalid_action_count': 0, 'total_rewards': 322.00812, 'episodic_length': 1497, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
# Episode 8 (424 chemicals) return 438.2086486816406 length 1707
# {'coverage_prop': '0.922', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.207', 'efficiency': '0.277', 'TP': '338', 'FP': '53', 'FN': '33', 'precision': '0.864', 'recall': '0.911', 'f1': '0.887', 'invalid_action_count': 0, 'total_rewards': 438.20865, 'episodic_length': 1707, 'num_ms1_scans': 293, 'num_ms2_scans': 1414}
# Episode 9 (384 chemicals) return 375.84637451171875 length 1669
# {'coverage_prop': '0.948', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.248', 'efficiency': '0.272', 'TP': '311', 'FP': '53', 'FN': '20', 'precision': '0.854', 'recall': '0.940', 'f1': '0.895', 'invalid_action_count': 0, 'total_rewards': 375.84637, 'episodic_length': 1669, 'num_ms1_scans': 332, 'num_ms2_scans': 1337}
# Episode 10 (443 chemicals) return 447.23443603515625 length 1725
# {'coverage_prop': '0.923', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.190', 'efficiency': '0.282', 'TP': '362', 'FP': '47', 'FN': '34', 'precision': '0.885', 'recall': '0.914', 'f1': '0.899', 'invalid_action_count': 0, 'total_rewards': 447.23444, 'episodic_length': 1725, 'num_ms1_scans': 276, 'num_ms2_scans': 1449}
# Episode 11 (249 chemicals) return 288.5887756347656 length 1566
# {'coverage_prop': '0.956', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.383', 'efficiency': '0.210', 'TP': '218', 'FP': '20', 'FN': '11', 'precision': '0.916', 'recall': '0.952', 'f1': '0.934', 'invalid_action_count': 0, 'total_rewards': 288.58878, 'episodic_length': 1566, 'num_ms1_scans': 434, 'num_ms2_scans': 1132}
# Episode 12 (251 chemicals) return 330.2148742675781 length 1544
# {'coverage_prop': '0.928', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.419', 'efficiency': '0.214', 'TP': '208', 'FP': '25', 'FN': '18', 'precision': '0.893', 'recall': '0.920', 'f1': '0.906', 'invalid_action_count': 0, 'total_rewards': 330.21487, 'episodic_length': 1544, 'num_ms1_scans': 456, 'num_ms2_scans': 1088}
# Episode 13 (300 chemicals) return 244.68179321289062 length 1634
# {'coverage_prop': '0.947', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.290', 'efficiency': '0.224', 'TP': '252', 'FP': '32', 'FN': '16', 'precision': '0.887', 'recall': '0.940', 'f1': '0.913', 'invalid_action_count': 0, 'total_rewards': 244.6818, 'episodic_length': 1634, 'num_ms1_scans': 367, 'num_ms2_scans': 1267}
# Episode 14 (206 chemicals) return 320.27215576171875 length 1512
# {'coverage_prop': '0.937', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.477', 'efficiency': '0.188', 'TP': '180', 'FP': '13', 'FN': '13', 'precision': '0.933', 'recall': '0.933', 'f1': '0.933', 'invalid_action_count': 0, 'total_rewards': 320.27216, 'episodic_length': 1512, 'num_ms1_scans': 488, 'num_ms2_scans': 1024}
# Episode 15 (407 chemicals) return 311.931396484375 length 1644
# {'coverage_prop': '0.926', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.276', 'efficiency': '0.293', 'TP': '330', 'FP': '47', 'FN': '30', 'precision': '0.875', 'recall': '0.917', 'f1': '0.896', 'invalid_action_count': 0, 'total_rewards': 311.9314, 'episodic_length': 1644, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
# Episode 16 (498 chemicals) return 433.5713195800781 length 1706
# {'coverage_prop': '0.922', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.209', 'efficiency': '0.325', 'TP': '408', 'FP': '51', 'FN': '39', 'precision': '0.889', 'recall': '0.913', 'f1': '0.901', 'invalid_action_count': 0, 'total_rewards': 433.57132, 'episodic_length': 1706, 'num_ms1_scans': 295, 'num_ms2_scans': 1411}
# Episode 17 (372 chemicals) return 375.811279296875 length 1683
# {'coverage_prop': '0.941', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.232', 'efficiency': '0.256', 'TP': '313', 'FP': '37', 'FN': '22', 'precision': '0.894', 'recall': '0.934', 'f1': '0.914', 'invalid_action_count': 0, 'total_rewards': 375.81128, 'episodic_length': 1683, 'num_ms1_scans': 317, 'num_ms2_scans': 1366}
# Episode 18 (302 chemicals) return 444.1238708496094 length 1620
# {'coverage_prop': '0.954', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.306', 'efficiency': '0.232', 'TP': '264', 'FP': '24', 'FN': '14', 'precision': '0.917', 'recall': '0.950', 'f1': '0.933', 'invalid_action_count': 0, 'total_rewards': 444.12387, 'episodic_length': 1620, 'num_ms1_scans': 380, 'num_ms2_scans': 1240}
# Episode 19 (265 chemicals) return 407.1777038574219 length 1597
# {'coverage_prop': '0.970', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.338', 'efficiency': '0.215', 'TP': '230', 'FP': '27', 'FN': '8', 'precision': '0.895', 'recall': '0.966', 'f1': '0.929', 'invalid_action_count': 0, 'total_rewards': 407.1777, 'episodic_length': 1597, 'num_ms1_scans': 403, 'num_ms2_scans': 1194}
# Episode 20 (468 chemicals) return 357.502197265625 length 1702
# {'coverage_prop': '0.891', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.212', 'efficiency': '0.297', 'TP': '369', 'FP': '48', 'FN': '51', 'precision': '0.885', 'recall': '0.879', 'f1': '0.882', 'invalid_action_count': 0, 'total_rewards': 357.5022, 'episodic_length': 1702, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
# Episode 21 (234 chemicals) return 357.1800842285156 length 1490
# {'coverage_prop': '0.923', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.522', 'efficiency': '0.221', 'TP': '192', 'FP': '24', 'FN': '18', 'precision': '0.889', 'recall': '0.914', 'f1': '0.901', 'invalid_action_count': 0, 'total_rewards': 357.18008, 'episodic_length': 1490, 'num_ms1_scans': 511, 'num_ms2_scans': 979}
# Episode 22 (322 chemicals) return 337.5881652832031 length 1648
# {'coverage_prop': '0.957', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.272', 'efficiency': '0.238', 'TP': '277', 'FP': '31', 'FN': '14', 'precision': '0.899', 'recall': '0.952', 'f1': '0.925', 'invalid_action_count': 0, 'total_rewards': 337.58817, 'episodic_length': 1648, 'num_ms1_scans': 352, 'num_ms2_scans': 1296}
# Episode 23 (310 chemicals) return 454.1400146484375 length 1588
# {'coverage_prop': '0.942', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.351', 'efficiency': '0.249', 'TP': '259', 'FP': '33', 'FN': '18', 'precision': '0.887', 'recall': '0.935', 'f1': '0.910', 'invalid_action_count': 0, 'total_rewards': 454.14, 'episodic_length': 1588, 'num_ms1_scans': 413, 'num_ms2_scans': 1175}
# Episode 24 (345 chemicals) return 418.908203125 length 1670
# {'coverage_prop': '0.957', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.246', 'efficiency': '0.246', 'TP': '293', 'FP': '37', 'FN': '15', 'precision': '0.888', 'recall': '0.951', 'f1': '0.918', 'invalid_action_count': 0, 'total_rewards': 418.9082, 'episodic_length': 1670, 'num_ms1_scans': 330, 'num_ms2_scans': 1340}
# Episode 25 (396 chemicals) return 434.8055419921875 length 1677
# {'coverage_prop': '0.947', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.239', 'efficiency': '0.277', 'TP': '331', 'FP': '44', 'FN': '21', 'precision': '0.883', 'recall': '0.940', 'f1': '0.911', 'invalid_action_count': 0, 'total_rewards': 434.80554, 'episodic_length': 1677, 'num_ms1_scans': 323, 'num_ms2_scans': 1354}
# Episode 26 (203 chemicals) return 320.3268127441406 length 1490
# {'coverage_prop': '0.961', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.522', 'efficiency': '0.199', 'TP': '178', 'FP': '17', 'FN': '8', 'precision': '0.913', 'recall': '0.957', 'f1': '0.934', 'invalid_action_count': 0, 'total_rewards': 320.3268, 'episodic_length': 1490, 'num_ms1_scans': 511, 'num_ms2_scans': 979}
# Episode 27 (281 chemicals) return 368.3766784667969 length 1568
# {'coverage_prop': '0.936', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.380', 'efficiency': '0.232', 'TP': '238', 'FP': '25', 'FN': '18', 'precision': '0.905', 'recall': '0.930', 'f1': '0.917', 'invalid_action_count': 0, 'total_rewards': 368.37668, 'episodic_length': 1568, 'num_ms1_scans': 432, 'num_ms2_scans': 1136}
# Episode 28 (493 chemicals) return 364.1819763183594 length 1722
# {'coverage_prop': '0.901', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '378', 'FP': '66', 'FN': '49', 'precision': '0.851', 'recall': '0.885', 'f1': '0.868', 'invalid_action_count': 0, 'total_rewards': 364.18198, 'episodic_length': 1722, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
# Episode 29 (304 chemicals) return 270.4471130371094 length 1641
# {'coverage_prop': '0.941', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.281', 'efficiency': '0.223', 'TP': '262', 'FP': '24', 'FN': '18', 'precision': '0.916', 'recall': '0.936', 'f1': '0.926', 'invalid_action_count': 0, 'total_rewards': 270.4471, 'episodic_length': 1641, 'num_ms1_scans': 360, 'num_ms2_scans': 1281}

# %%
method_eval_results[METHOD_DQN] = evaluation_results

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f80457db970>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f80217c9150>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f80217e22f0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.809', 'efficiency': '0.546', 'TP': '363', 'FP': '54', 'FN': '9', 'precision': '0.871', 'recall': '0.976', 'f1': '0.920'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.744', 'efficiency': '0.547', 'TP': '385', 'FP': '55', 'FN': '12', 'precision': '0.875', 'recall': '0.970', 'f1': '0.920'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '368', 'FP': '65', 'FN': '4', 'precision': '0.850', 'recall': '0.989', 'f1': '0.914'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.679', 'efficiency': '0.541', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.713', 'ms1ms2_ratio': '2.072', 'efficiency': '0.504', 'TP': '177', 'FP': '19', 'FN': '8', 'precision': '0.903', 'recall': '0.957', 'f1': '0.929'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.688', 'efficiency': '0.508', 'TP': '384', 'FP': '44', 'FN': '15', 'precision': '0.897', 'recall': '0.962', 'f1': '0.929'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.662', 'ms1ms2_ratio': '1.612', 'efficiency': '0.502', 'TP': '197', 'FP': '41', 'FN': '13', 'precision': '0.828', 'recall': '0.938', 'f1': '0.879'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.686', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.692', 'ms1ms2_ratio': '1.958', 'efficiency': '0.482', 'TP': '168', 'FP': '28', 'FN': '10', 'precision': '0.857', 'recall': '0.944', 'f1': '0.898'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.858', 'efficiency': '0.540', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '427', 'FP': '60', 'FN': '11', 'precision': '0.877', 'recall': '0.975', 'f1': '0.923'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.956', 'efficiency': '0.524', 'TP': '312', 'FP': '48', 'FN': '12', 'precision': '0.867', 'recall': '0.963', 'f1': '0.912'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.690', 'efficiency': '0.536', 'TP': '388', 'FP': '62', 'FN': '18', 'precision': '0.862', 'recall': '0.956', 'f1': '0.907'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.695', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '247', 'FP': '49', 'FN': '14', 'precision': '0.834', 'recall': '0.946', 'f1': '0.887'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.973', 'efficiency': '0.499', 'TP': '294', 'FP': '45', 'FN': '6', 'precision': '0.867', 'recall': '0.980', 'f1': '0.920'}
#
# Episode 25 finished
# {'coverage_prop': '0.990', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.862', 'efficiency': '0.534', 'TP': '337', 'FP': '55', 'FN': '4', 'precision': '0.860', 'recall': '0.988', 'f1': '0.920'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.716', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.717', 'ms1ms2_ratio': '1.377', 'efficiency': '0.510', 'TP': '240', 'FP': '32', 'FN': '9', 'precision': '0.882', 'recall': '0.964', 'f1': '0.921'}
#
# Episode 28 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.594', 'efficiency': '0.522', 'TP': '405', 'FP': '72', 'FN': '16', 'precision': '0.849', 'recall': '0.962', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random      72.552594                   0.0          0.939           0.697
# 1  random     148.035581                   0.0          0.939           0.769
# 2  random     221.177069                   0.0          0.934           0.699
# 3  random     240.519455                   0.0          0.945           0.724
# 4  random     122.399418                   0.0          0.961           0.714
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.136       0.254      0.850   0.929  0.888
# 1          0.207       0.174      0.931   0.935  0.933
# 2          0.151       0.240      0.834   0.922  0.876
# 3          0.136       0.272      0.881   0.938  0.908
# 4          0.138       0.268      0.848   0.954  0.898

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))
