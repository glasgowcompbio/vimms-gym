# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-07 15:01:16.593 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc6985d6a90>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc688144670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc6986e9910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc6985d6a90>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc688144670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc6986e9910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc6985d6a90>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc688144670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc6986e9910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_2.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_2.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -338.53833878813066
# steps	 1000 	total rewards	 -600.3358175033025
# steps	 1500 	total rewards	 -956.2902759429446
# Finished after 1989 timesteps (4.202383041381836 seconds) with total reward -1090.2176426974133
# {'coverage_prop': '0.718', 'intensity_prop': '0.203', 'ms1ms2_ratio': '0.006', 'efficiency': '0.155', 'TP': '76', 'FP': '230', 'FN': '120', 'precision': '0.248', 'recall': '0.388', 'f1': '0.303', 'total_rewards': -1090.217642697413, 'invalid_action_count': 1235, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -427.2693700970729
# steps	 1000 	total rewards	 -791.3508690951478
# steps	 1500 	total rewards	 -1282.350924073466
# Finished after 1993 timesteps (2.759183883666992 seconds) with total reward -1621.1978418745232
# {'coverage_prop': '0.489', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.004', 'efficiency': '0.064', 'TP': '19', 'FP': '109', 'FN': '134', 'precision': '0.148', 'recall': '0.124', 'f1': '0.135', 'total_rewards': -1621.197841874524, 'invalid_action_count': 1678, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -411.48270464665313
# steps	 1000 	total rewards	 -624.9350521262013
# steps	 1500 	total rewards	 -821.9142047819053
# Finished after 1989 timesteps (3.488770008087158 seconds) with total reward -984.6699912908568
# {'coverage_prop': '0.756', 'intensity_prop': '0.227', 'ms1ms2_ratio': '0.006', 'efficiency': '0.151', 'TP': '80', 'FP': '218', 'FN': '96', 'precision': '0.268', 'recall': '0.455', 'f1': '0.338', 'total_rewards': -984.6699912908565, 'invalid_action_count': 1131, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -295.57237467845454
# steps	 1000 	total rewards	 -583.9163316565653
# steps	 1500 	total rewards	 -801.843838175829
# Finished after 1988 timesteps (4.2259228229522705 seconds) with total reward -1061.9502164470523
# {'coverage_prop': '0.759', 'intensity_prop': '0.243', 'ms1ms2_ratio': '0.006', 'efficiency': '0.174', 'TP': '104', 'FP': '239', 'FN': '109', 'precision': '0.303', 'recall': '0.488', 'f1': '0.374', 'total_rewards': -1061.950216447053, 'invalid_action_count': 1219, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -341.11636739281187
# steps	 1000 	total rewards	 -621.4490050799866
# steps	 1500 	total rewards	 -695.9284549697991
# Finished after 1989 timesteps (4.027908086776733 seconds) with total reward -894.0363266915908
# {'coverage_prop': '0.810', 'intensity_prop': '0.290', 'ms1ms2_ratio': '0.006', 'efficiency': '0.179', 'TP': '118', 'FP': '236', 'FN': '83', 'precision': '0.333', 'recall': '0.587', 'f1': '0.425', 'total_rewards': -894.0363266915917, 'invalid_action_count': 1064, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -375.5213399991983
# steps	 1000 	total rewards	 -748.3377171824529
# steps	 1500 	total rewards	 -985.4938072320551
# Finished after 1986 timesteps (2.3923709392547607 seconds) with total reward -1300.7859476640028
# {'coverage_prop': '0.790', 'intensity_prop': '0.275', 'ms1ms2_ratio': '0.007', 'efficiency': '0.080', 'TP': '58', 'FP': '100', 'FN': '42', 'precision': '0.367', 'recall': '0.580', 'f1': '0.450', 'total_rewards': -1300.7859476640028, 'invalid_action_count': 1386, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -389.30250339222107
# steps	 1000 	total rewards	 -560.3093577091279
# steps	 1500 	total rewards	 -864.6403107870091
# Finished after 1989 timesteps (4.042975902557373 seconds) with total reward -1100.7833596045828
# {'coverage_prop': '0.697', 'intensity_prop': '0.194', 'ms1ms2_ratio': '0.006', 'efficiency': '0.168', 'TP': '89', 'FP': '244', 'FN': '145', 'precision': '0.267', 'recall': '0.380', 'f1': '0.314', 'total_rewards': -1100.783359604584, 'invalid_action_count': 1253, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -404.3735727367692
# steps	 1000 	total rewards	 -737.3448528636757
# steps	 1500 	total rewards	 -970.984752406579
# Finished after 1986 timesteps (2.2911696434020996 seconds) with total reward -1268.895990106711
# {'coverage_prop': '0.721', 'intensity_prop': '0.214', 'ms1ms2_ratio': '0.007', 'efficiency': '0.075', 'TP': '45', 'FP': '102', 'FN': '57', 'precision': '0.306', 'recall': '0.441', 'f1': '0.361', 'total_rewards': -1268.895990106711, 'invalid_action_count': 1348, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -290.4345151862859
# steps	 1000 	total rewards	 -543.8301252410972
# steps	 1500 	total rewards	 -732.1607537911111
# Finished after 1986 timesteps (3.642493963241577 seconds) with total reward -982.339679207209
# {'coverage_prop': '0.778', 'intensity_prop': '0.242', 'ms1ms2_ratio': '0.007', 'efficiency': '0.167', 'TP': '89', 'FP': '241', 'FN': '94', 'precision': '0.270', 'recall': '0.486', 'f1': '0.347', 'total_rewards': -982.3396792072082, 'invalid_action_count': 1142, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -364.4289938921581
# steps	 1000 	total rewards	 -786.3228740023652
# steps	 1500 	total rewards	 -860.0811404075205
# Finished after 1988 timesteps (3.3612618446350098 seconds) with total reward -1084.849537599147
# {'coverage_prop': '0.724', 'intensity_prop': '0.242', 'ms1ms2_ratio': '0.006', 'efficiency': '0.141', 'TP': '91', 'FP': '187', 'FN': '106', 'precision': '0.327', 'recall': '0.462', 'f1': '0.383', 'total_rewards': -1084.8495375991474, 'invalid_action_count': 1219, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -367.82012761209035
# steps	 1000 	total rewards	 -567.1582098094348
# steps	 1500 	total rewards	 -895.7303992697696
# Finished after 1988 timesteps (3.9782919883728027 seconds) with total reward -1124.6394369414616
# {'coverage_prop': '0.716', 'intensity_prop': '0.199', 'ms1ms2_ratio': '0.006', 'efficiency': '0.160', 'TP': '76', 'FP': '241', 'FN': '126', 'precision': '0.240', 'recall': '0.376', 'f1': '0.293', 'total_rewards': -1124.6394369414606, 'invalid_action_count': 1263, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -382.2504623512234
# steps	 1000 	total rewards	 -731.4432017758721
# steps	 1500 	total rewards	 -1212.109599267152
# Finished after 1989 timesteps (2.413794755935669 seconds) with total reward -1461.2161650411863
# {'coverage_prop': '0.566', 'intensity_prop': '0.137', 'ms1ms2_ratio': '0.006', 'efficiency': '0.071', 'TP': '31', 'FP': '110', 'FN': '108', 'precision': '0.220', 'recall': '0.223', 'f1': '0.221', 'total_rewards': -1461.2161650411874, 'invalid_action_count': 1525, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -407.2527096767267
# steps	 1000 	total rewards	 -743.1998623710831
# steps	 1500 	total rewards	 -984.3592635689488
# Finished after 1991 timesteps (2.927978992462158 seconds) with total reward -1406.6633497024477
# {'coverage_prop': '0.681', 'intensity_prop': '0.166', 'ms1ms2_ratio': '0.005', 'efficiency': '0.086', 'TP': '35', 'FP': '136', 'FN': '80', 'precision': '0.205', 'recall': '0.304', 'f1': '0.245', 'total_rewards': -1406.663349702448, 'invalid_action_count': 1488, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -386.61541132955654
# steps	 1000 	total rewards	 -653.8405151284508
# steps	 1500 	total rewards	 -872.1616399652871
# Finished after 1985 timesteps (3.3324358463287354 seconds) with total reward -1134.9299777614465
# {'coverage_prop': '0.780', 'intensity_prop': '0.250', 'ms1ms2_ratio': '0.008', 'efficiency': '0.119', 'TP': '70', 'FP': '164', 'FN': '66', 'precision': '0.299', 'recall': '0.515', 'f1': '0.378', 'total_rewards': -1134.929977761445, 'invalid_action_count': 1245, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -386.7512970829784
# steps	 1000 	total rewards	 -720.8992486142633
# steps	 1500 	total rewards	 -1004.7697664554933
# Finished after 1988 timesteps (2.26723313331604 seconds) with total reward -1341.9255924303247
# {'coverage_prop': '0.723', 'intensity_prop': '0.190', 'ms1ms2_ratio': '0.006', 'efficiency': '0.075', 'TP': '35', 'FP': '114', 'FN': '57', 'precision': '0.235', 'recall': '0.380', 'f1': '0.290', 'total_rewards': -1341.9255924303234, 'invalid_action_count': 1417, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -389.66911478198654
# steps	 1000 	total rewards	 -637.0676657073496
# steps	 1500 	total rewards	 -770.5045373443511
# Finished after 1990 timesteps (3.8110220432281494 seconds) with total reward -1085.7905168191128
# {'coverage_prop': '0.781', 'intensity_prop': '0.265', 'ms1ms2_ratio': '0.005', 'efficiency': '0.161', 'TP': '103', 'FP': '215', 'FN': '89', 'precision': '0.324', 'recall': '0.536', 'f1': '0.404', 'total_rewards': -1085.7905168191128, 'invalid_action_count': 1233, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -364.28299488443406
# steps	 1000 	total rewards	 -633.4544314337629
# steps	 1500 	total rewards	 -1080.7746896847107
# Finished after 1992 timesteps (4.806271076202393 seconds) with total reward -1243.3652211658746
# {'coverage_prop': '0.616', 'intensity_prop': '0.156', 'ms1ms2_ratio': '0.004', 'efficiency': '0.155', 'TP': '73', 'FP': '234', 'FN': '191', 'precision': '0.238', 'recall': '0.277', 'f1': '0.256', 'total_rewards': -1243.365221165875, 'invalid_action_count': 1374, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -330.3624792406725
# steps	 1000 	total rewards	 -539.4654349330141
# steps	 1500 	total rewards	 -731.9946061810758
# Finished after 1983 timesteps (3.5757410526275635 seconds) with total reward -924.1904899186868
# {'coverage_prop': '0.809', 'intensity_prop': '0.283', 'ms1ms2_ratio': '0.009', 'efficiency': '0.153', 'TP': '102', 'FP': '199', 'FN': '71', 'precision': '0.339', 'recall': '0.590', 'f1': '0.430', 'total_rewards': -924.1904899186867, 'invalid_action_count': 1077, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -376.84241585839874
# steps	 1000 	total rewards	 -770.4433700097318
# steps	 1500 	total rewards	 -954.1198086151785
# Finished after 1991 timesteps (3.0881152153015137 seconds) with total reward -1221.9598474236182
# {'coverage_prop': '0.745', 'intensity_prop': '0.205', 'ms1ms2_ratio': '0.005', 'efficiency': '0.114', 'TP': '54', 'FP': '171', 'FN': '77', 'precision': '0.240', 'recall': '0.412', 'f1': '0.303', 'total_rewards': -1221.9598474236166, 'invalid_action_count': 1335, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -403.34147143659584
# steps	 1000 	total rewards	 -724.0055009178147
# steps	 1500 	total rewards	 -1182.0255558567605
# Finished after 1993 timesteps (2.9140942096710205 seconds) with total reward -1545.910992308778
# {'coverage_prop': '0.551', 'intensity_prop': '0.123', 'ms1ms2_ratio': '0.004', 'efficiency': '0.074', 'TP': '28', 'FP': '118', 'FN': '119', 'precision': '0.192', 'recall': '0.190', 'f1': '0.191', 'total_rewards': -1545.9109923087783, 'invalid_action_count': 1611, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -395.44435335738075
# steps	 1000 	total rewards	 -601.1118423646772
# steps	 1500 	total rewards	 -702.9740883193379
# Finished after 1986 timesteps (3.902212142944336 seconds) with total reward -875.5257162205987
# {'coverage_prop': '0.786', 'intensity_prop': '0.251', 'ms1ms2_ratio': '0.007', 'efficiency': '0.187', 'TP': '112', 'FP': '256', 'FN': '100', 'precision': '0.304', 'recall': '0.528', 'f1': '0.386', 'total_rewards': -875.5257162205977, 'invalid_action_count': 1044, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -381.1233931298397
# steps	 1000 	total rewards	 -723.3975701554905
# steps	 1500 	total rewards	 -1055.1217185268492
# Finished after 1991 timesteps (2.592677116394043 seconds) with total reward -1341.4713811431004
# {'coverage_prop': '0.692', 'intensity_prop': '0.183', 'ms1ms2_ratio': '0.005', 'efficiency': '0.082', 'TP': '42', 'FP': '120', 'FN': '72', 'precision': '0.259', 'recall': '0.368', 'f1': '0.304', 'total_rewards': -1341.4713811431004, 'invalid_action_count': 1426, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -413.20294237409996
# steps	 1000 	total rewards	 -892.6052091770289
# steps	 1500 	total rewards	 -1131.07141915095
# Finished after 1991 timesteps (3.195518970489502 seconds) with total reward -1324.2945746305188
# {'coverage_prop': '0.612', 'intensity_prop': '0.169', 'ms1ms2_ratio': '0.005', 'efficiency': '0.099', 'TP': '49', 'FP': '148', 'FN': '125', 'precision': '0.249', 'recall': '0.282', 'f1': '0.264', 'total_rewards': -1324.2945746305184, 'invalid_action_count': 1418, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -433.96169862000477
# steps	 1000 	total rewards	 -728.0045575986189
# steps	 1500 	total rewards	 -945.3643200612448
# Finished after 1990 timesteps (2.9867167472839355 seconds) with total reward -1195.0259859601933
# {'coverage_prop': '0.745', 'intensity_prop': '0.227', 'ms1ms2_ratio': '0.005', 'efficiency': '0.117', 'TP': '67', 'FP': '164', 'FN': '79', 'precision': '0.290', 'recall': '0.459', 'f1': '0.355', 'total_rewards': -1195.025985960195, 'invalid_action_count': 1313, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -353.6462073643189
# steps	 1000 	total rewards	 -689.6734047017782
# steps	 1500 	total rewards	 -974.3766380101966
# Finished after 1992 timesteps (3.881593942642212 seconds) with total reward -1316.4917743451078
# {'coverage_prop': '0.696', 'intensity_prop': '0.203', 'ms1ms2_ratio': '0.004', 'efficiency': '0.121', 'TP': '69', 'FP': '171', 'FN': '105', 'precision': '0.287', 'recall': '0.397', 'f1': '0.333', 'total_rewards': -1316.4917743451076, 'invalid_action_count': 1433, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -397.8036846318199
# steps	 1000 	total rewards	 -667.7750075799676
# steps	 1500 	total rewards	 -806.1392292553128
# Finished after 1990 timesteps (4.434481143951416 seconds) with total reward -1198.5489391377323
# {'coverage_prop': '0.682', 'intensity_prop': '0.223', 'ms1ms2_ratio': '0.005', 'efficiency': '0.136', 'TP': '86', 'FP': '184', 'FN': '126', 'precision': '0.319', 'recall': '0.406', 'f1': '0.357', 'total_rewards': -1198.548939137732, 'invalid_action_count': 1324, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -383.9025141950922
# steps	 1000 	total rewards	 -726.3213075132587
# steps	 1500 	total rewards	 -1054.629808618333
# Finished after 1989 timesteps (3.1934831142425537 seconds) with total reward -1353.0072314322506
# {'coverage_prop': '0.734', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.006', 'efficiency': '0.075', 'TP': '44', 'FP': '105', 'FN': '54', 'precision': '0.295', 'recall': '0.449', 'f1': '0.356', 'total_rewards': -1353.0072314322497, 'invalid_action_count': 1431, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -401.5019640114886
# steps	 1000 	total rewards	 -748.9592423791441
# steps	 1500 	total rewards	 -1070.6209808703306
# Finished after 1994 timesteps (2.838693857192993 seconds) with total reward -1433.8679755042206
# {'coverage_prop': '0.658', 'intensity_prop': '0.176', 'ms1ms2_ratio': '0.003', 'efficiency': '0.093', 'TP': '46', 'FP': '139', 'FN': '96', 'precision': '0.249', 'recall': '0.324', 'f1': '0.281', 'total_rewards': -1433.8679755042222, 'invalid_action_count': 1524, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -372.81356815454546
# steps	 1000 	total rewards	 -598.3256660072051
# steps	 1500 	total rewards	 -863.8261311603226
# Finished after 1993 timesteps (4.566443920135498 seconds) with total reward -1104.6473995239794
# {'coverage_prop': '0.704', 'intensity_prop': '0.215', 'ms1ms2_ratio': '0.004', 'efficiency': '0.175', 'TP': '100', 'FP': '247', 'FN': '146', 'precision': '0.288', 'recall': '0.407', 'f1': '0.337', 'total_rewards': -1104.6473995239792, 'invalid_action_count': 1258, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -399.1138179323729
# steps	 1000 	total rewards	 -648.1491365341532
# steps	 1500 	total rewards	 -886.5043968773432
# Finished after 1990 timesteps (3.572983980178833 seconds) with total reward -1230.5684576134756
# {'coverage_prop': '0.724', 'intensity_prop': '0.237', 'ms1ms2_ratio': '0.005', 'efficiency': '0.111', 'TP': '73', 'FP': '147', 'FN': '84', 'precision': '0.332', 'recall': '0.465', 'f1': '0.387', 'total_rewards': -1230.5684576134759, 'invalid_action_count': 1337, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.00GB > 0.32GB
# steps	 500 	total rewards	 85.76518357713208
# steps	 1000 	total rewards	 176.99780036729504
# steps	 1500 	total rewards	 258.3410768729374
# Finished after 1637 timesteps (8.011196851730347 seconds) with total reward 277.79835268291436
# {'coverage_prop': '0.904', 'intensity_prop': '0.554', 'ms1ms2_ratio': '0.286', 'efficiency': '0.302', 'TP': '259', 'FP': '126', 'FN': '41', 'precision': '0.673', 'recall': '0.863', 'f1': '0.756', 'total_rewards': 277.7983526829138, 'invalid_action_count': 26, 'num_ms1_scans': 364, 'num_ms2_scans': 1273}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 75.9821962403365
# steps	 1000 	total rewards	 159.58479346022654
# steps	 1500 	total rewards	 235.56050463325306
# Finished after 1578 timesteps (4.776814699172974 seconds) with total reward 242.4581204804807
# {'coverage_prop': '0.954', 'intensity_prop': '0.570', 'ms1ms2_ratio': '0.365', 'efficiency': '0.216', 'TP': '160', 'FP': '90', 'FN': '12', 'precision': '0.640', 'recall': '0.930', 'f1': '0.758', 'total_rewards': 242.45812048047864, 'invalid_action_count': 3, 'num_ms1_scans': 422, 'num_ms2_scans': 1156}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 79.125915088639
# steps	 1000 	total rewards	 168.87551294096602
# steps	 1500 	total rewards	 250.04700126699743
# Finished after 1628 timesteps (7.11935019493103 seconds) with total reward 256.6486910648449
# {'coverage_prop': '0.937', 'intensity_prop': '0.532', 'ms1ms2_ratio': '0.296', 'efficiency': '0.294', 'TP': '228', 'FP': '141', 'FN': '25', 'precision': '0.618', 'recall': '0.901', 'f1': '0.733', 'total_rewards': 256.6486910648435, 'invalid_action_count': 33, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 89.83766752819588
# steps	 1000 	total rewards	 179.71687646245434
# steps	 1500 	total rewards	 239.64453409542122
# Finished after 1632 timesteps (6.895515203475952 seconds) with total reward 255.477836790999
# {'coverage_prop': '0.916', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.291', 'efficiency': '0.328', 'TP': '260', 'FP': '154', 'FN': '38', 'precision': '0.628', 'recall': '0.872', 'f1': '0.730', 'total_rewards': 255.47783679099754, 'invalid_action_count': 48, 'num_ms1_scans': 368, 'num_ms2_scans': 1264}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 80.68085395231965
# steps	 1000 	total rewards	 184.7909498680131
# steps	 1500 	total rewards	 272.567098429838
# Finished after 1607 timesteps (8.594706296920776 seconds) with total reward 281.65281467865094
# {'coverage_prop': '0.924', 'intensity_prop': '0.547', 'ms1ms2_ratio': '0.324', 'efficiency': '0.333', 'TP': '267', 'FP': '137', 'FN': '33', 'precision': '0.661', 'recall': '0.890', 'f1': '0.759', 'total_rewards': 281.65281467865134, 'invalid_action_count': 18, 'num_ms1_scans': 393, 'num_ms2_scans': 1214}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 64.88788406935078
# steps	 1000 	total rewards	 142.18470732585484
# steps	 1500 	total rewards	 205.17642553717923
# Finished after 1551 timesteps (7.200315952301025 seconds) with total reward 212.22531991563852
# {'coverage_prop': '0.980', 'intensity_prop': '0.662', 'ms1ms2_ratio': '0.407', 'efficiency': '0.178', 'TP': '150', 'FP': '46', 'FN': '4', 'precision': '0.765', 'recall': '0.974', 'f1': '0.857', 'total_rewards': 212.22531991563704, 'invalid_action_count': 2, 'num_ms1_scans': 449, 'num_ms2_scans': 1102}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 86.11433573868746
# steps	 1000 	total rewards	 202.78664863007657
# steps	 1500 	total rewards	 282.7535637265885
# Finished after 1609 timesteps (7.0121729373931885 seconds) with total reward 301.452908747627
# {'coverage_prop': '0.904', 'intensity_prop': '0.502', 'ms1ms2_ratio': '0.321', 'efficiency': '0.355', 'TP': '258', 'FP': '174', 'FN': '46', 'precision': '0.597', 'recall': '0.849', 'f1': '0.701', 'total_rewards': 301.45290874762753, 'invalid_action_count': 11, 'num_ms1_scans': 391, 'num_ms2_scans': 1218}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 57.766906570400764
# steps	 1000 	total rewards	 144.14715400986944
# steps	 1500 	total rewards	 209.25690128084244
# Finished after 1554 timesteps (4.779771089553833 seconds) with total reward 214.1253951325201
# {'coverage_prop': '0.975', 'intensity_prop': '0.634', 'ms1ms2_ratio': '0.404', 'efficiency': '0.180', 'TP': '146', 'FP': '53', 'FN': '5', 'precision': '0.734', 'recall': '0.967', 'f1': '0.834', 'total_rewards': 214.12539513251866, 'invalid_action_count': 3, 'num_ms1_scans': 447, 'num_ms2_scans': 1107}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 91.69926122105832
# steps	 1000 	total rewards	 180.13015443803994
# steps	 1500 	total rewards	 275.18395321746675
# Finished after 1639 timesteps (5.342508792877197 seconds) with total reward 289.8148355523657
# {'coverage_prop': '0.929', 'intensity_prop': '0.548', 'ms1ms2_ratio': '0.282', 'efficiency': '0.308', 'TP': '244', 'FP': '150', 'FN': '30', 'precision': '0.619', 'recall': '0.891', 'f1': '0.731', 'total_rewards': 289.81483555236565, 'invalid_action_count': 16, 'num_ms1_scans': 361, 'num_ms2_scans': 1278}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 81.68282420098777
# steps	 1000 	total rewards	 180.83638757624158
# steps	 1500 	total rewards	 262.1211285343693
# Finished after 1606 timesteps (5.744086027145386 seconds) with total reward 276.04277120333063
# {'coverage_prop': '0.943', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.325', 'efficiency': '0.299', 'TP': '237', 'FP': '125', 'FN': '22', 'precision': '0.655', 'recall': '0.915', 'f1': '0.763', 'total_rewards': 276.04277120333, 'invalid_action_count': 14, 'num_ms1_scans': 394, 'num_ms2_scans': 1212}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 86.4967735595683
# steps	 1000 	total rewards	 192.45132917192788
# steps	 1500 	total rewards	 282.0370274274032
# Finished after 1626 timesteps (5.447342872619629 seconds) with total reward 293.8753850222573
# {'coverage_prop': '0.905', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.299', 'efficiency': '0.320', 'TP': '269', 'FP': '132', 'FN': '42', 'precision': '0.671', 'recall': '0.865', 'f1': '0.756', 'total_rewards': 293.8753850222572, 'invalid_action_count': 16, 'num_ms1_scans': 374, 'num_ms2_scans': 1252}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 73.93252905873317
# steps	 1000 	total rewards	 151.1886156536591
# steps	 1500 	total rewards	 215.07722387670333
# Finished after 1570 timesteps (4.150514125823975 seconds) with total reward 224.63501300517296
# {'coverage_prop': '0.972', 'intensity_prop': '0.610', 'ms1ms2_ratio': '0.377', 'efficiency': '0.212', 'TP': '163', 'FP': '79', 'FN': '7', 'precision': '0.674', 'recall': '0.959', 'f1': '0.791', 'total_rewards': 224.6350130051717, 'invalid_action_count': 3, 'num_ms1_scans': 430, 'num_ms2_scans': 1140}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 71.20545770349231
# steps	 1000 	total rewards	 150.9394346117034
# steps	 1500 	total rewards	 221.62349694143666
# Finished after 1553 timesteps (5.3143181800842285 seconds) with total reward 226.04025698662642
# {'coverage_prop': '0.956', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.405', 'efficiency': '0.217', 'TP': '151', 'FP': '89', 'FN': '11', 'precision': '0.629', 'recall': '0.932', 'f1': '0.751', 'total_rewards': 226.0402569866248, 'invalid_action_count': 0, 'num_ms1_scans': 448, 'num_ms2_scans': 1105}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 69.18414842889129
# steps	 1000 	total rewards	 144.00640460294295
# steps	 1500 	total rewards	 226.88092255608439
# Finished after 1576 timesteps (5.012163877487183 seconds) with total reward 235.10788895156085
# {'coverage_prop': '0.920', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.369', 'efficiency': '0.240', 'TP': '187', 'FP': '89', 'FN': '24', 'precision': '0.678', 'recall': '0.886', 'f1': '0.768', 'total_rewards': 235.1078889515595, 'invalid_action_count': 5, 'num_ms1_scans': 425, 'num_ms2_scans': 1151}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 66.16587999086025
# steps	 1000 	total rewards	 143.83927181388964
# steps	 1500 	total rewards	 210.5902290608238
# Finished after 1543 timesteps (5.068347215652466 seconds) with total reward 216.38158707710076
# {'coverage_prop': '0.947', 'intensity_prop': '0.588', 'ms1ms2_ratio': '0.421', 'efficiency': '0.180', 'TP': '133', 'FP': '62', 'FN': '11', 'precision': '0.682', 'recall': '0.924', 'f1': '0.785', 'total_rewards': 216.3815870770993, 'invalid_action_count': 0, 'num_ms1_scans': 457, 'num_ms2_scans': 1086}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 70.95749308796687
# steps	 1000 	total rewards	 163.63945817279748
# steps	 1500 	total rewards	 250.48603352678683
# Finished after 1631 timesteps (5.201128959655762 seconds) with total reward 268.8547467434739
# {'coverage_prop': '0.951', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.292', 'efficiency': '0.307', 'TP': '244', 'FP': '143', 'FN': '20', 'precision': '0.630', 'recall': '0.924', 'f1': '0.750', 'total_rewards': 268.85474674347313, 'invalid_action_count': 22, 'num_ms1_scans': 369, 'num_ms2_scans': 1262}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 87.15947437339449
# steps	 1000 	total rewards	 179.16919517527074
# steps	 1500 	total rewards	 255.67693587469094
# Finished after 1641 timesteps (5.596919775009155 seconds) with total reward 271.22402953577074
# {'coverage_prop': '0.900', 'intensity_prop': '0.517', 'ms1ms2_ratio': '0.280', 'efficiency': '0.349', 'TP': '278', 'FP': '170', 'FN': '50', 'precision': '0.621', 'recall': '0.848', 'f1': '0.716', 'total_rewards': 271.22402953577034, 'invalid_action_count': 37, 'num_ms1_scans': 359, 'num_ms2_scans': 1282}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 88.3047122307036
# steps	 1000 	total rewards	 174.6403992784492
# steps	 1500 	total rewards	 245.5603742284055
# Finished after 1640 timesteps (6.377371788024902 seconds) with total reward 262.82400946534955
# {'coverage_prop': '0.949', 'intensity_prop': '0.572', 'ms1ms2_ratio': '0.281', 'efficiency': '0.276', 'TP': '237', 'FP': '116', 'FN': '19', 'precision': '0.671', 'recall': '0.926', 'f1': '0.778', 'total_rewards': 262.82400946534847, 'invalid_action_count': 23, 'num_ms1_scans': 360, 'num_ms2_scans': 1280}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 78.17305327596722
# steps	 1000 	total rewards	 168.96827387447482
# steps	 1500 	total rewards	 234.29364225108884
# Finished after 1603 timesteps (4.720209836959839 seconds) with total reward 244.842187227848
# {'coverage_prop': '0.980', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.329', 'efficiency': '0.245', 'TP': '182', 'FP': '114', 'FN': '6', 'precision': '0.615', 'recall': '0.968', 'f1': '0.752', 'total_rewards': 244.8421872278466, 'invalid_action_count': 13, 'num_ms1_scans': 397, 'num_ms2_scans': 1206}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 76.35934437115714
# steps	 1000 	total rewards	 159.48215524396196
# steps	 1500 	total rewards	 232.12367144314024
# Finished after 1578 timesteps (4.356604337692261 seconds) with total reward 237.14673717461875
# {'coverage_prop': '0.962', 'intensity_prop': '0.558', 'ms1ms2_ratio': '0.365', 'efficiency': '0.221', 'TP': '157', 'FP': '98', 'FN': '10', 'precision': '0.616', 'recall': '0.940', 'f1': '0.744', 'total_rewards': 237.14673717461716, 'invalid_action_count': 2, 'num_ms1_scans': 422, 'num_ms2_scans': 1156}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 85.77205678224418
# steps	 1000 	total rewards	 186.31630520620513
# steps	 1500 	total rewards	 270.4422117605146
# Finished after 1637 timesteps (5.788315057754517 seconds) with total reward 286.6329017088759
# {'coverage_prop': '0.885', 'intensity_prop': '0.513', 'ms1ms2_ratio': '0.285', 'efficiency': '0.325', 'TP': '257', 'FP': '157', 'FN': '54', 'precision': '0.621', 'recall': '0.826', 'f1': '0.709', 'total_rewards': 286.6329017088758, 'invalid_action_count': 15, 'num_ms1_scans': 363, 'num_ms2_scans': 1274}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 65.09083651444809
# steps	 1000 	total rewards	 149.62769073696282
# steps	 1500 	total rewards	 221.52178658399734
# Finished after 1552 timesteps (4.444777965545654 seconds) with total reward 227.3296555883802
# {'coverage_prop': '0.966', 'intensity_prop': '0.572', 'ms1ms2_ratio': '0.407', 'efficiency': '0.205', 'TP': '141', 'FP': '85', 'FN': '8', 'precision': '0.624', 'recall': '0.946', 'f1': '0.752', 'total_rewards': 227.3296555883786, 'invalid_action_count': 1, 'num_ms1_scans': 449, 'num_ms2_scans': 1103}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 77.79482717740791
# steps	 1000 	total rewards	 165.02792715030955
# steps	 1500 	total rewards	 240.7243009423498
# Finished after 1602 timesteps (4.820007085800171 seconds) with total reward 252.77275008583257
# {'coverage_prop': '0.947', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.331', 'efficiency': '0.253', 'TP': '201', 'FP': '104', 'FN': '17', 'precision': '0.659', 'recall': '0.922', 'f1': '0.769', 'total_rewards': 252.772750085831, 'invalid_action_count': 7, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 81.07113351158053
# steps	 1000 	total rewards	 167.55388369696547
# steps	 1500 	total rewards	 245.0896055662372
# Finished after 1600 timesteps (6.62400484085083 seconds) with total reward 255.13605214411928
# {'coverage_prop': '0.958', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.333', 'efficiency': '0.247', 'TP': '191', 'FP': '106', 'FN': '13', 'precision': '0.643', 'recall': '0.936', 'f1': '0.762', 'total_rewards': 255.13605214411788, 'invalid_action_count': 5, 'num_ms1_scans': 400, 'num_ms2_scans': 1200}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 81.42044438018539
# steps	 1000 	total rewards	 178.92038003785194
# steps	 1500 	total rewards	 258.983048015396
# Finished after 1611 timesteps (5.491353750228882 seconds) with total reward 270.44980030635395
# {'coverage_prop': '0.959', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.319', 'efficiency': '0.271', 'TP': '206', 'FP': '125', 'FN': '14', 'precision': '0.622', 'recall': '0.936', 'f1': '0.748', 'total_rewards': 270.4498003063528, 'invalid_action_count': 13, 'num_ms1_scans': 390, 'num_ms2_scans': 1221}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 85.40760852995567
# steps	 1000 	total rewards	 160.85594927422233
# steps	 1500 	total rewards	 243.93306304759284
# Finished after 1628 timesteps (6.487643241882324 seconds) with total reward 259.06948779153447
# {'coverage_prop': '0.949', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.296', 'efficiency': '0.299', 'TP': '233', 'FP': '143', 'FN': '20', 'precision': '0.620', 'recall': '0.921', 'f1': '0.741', 'total_rewards': 259.0694877915331, 'invalid_action_count': 28, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 62.296302621153245
# steps	 1000 	total rewards	 144.9523866145044
# steps	 1500 	total rewards	 208.0239697048057
# Finished after 1529 timesteps (6.622129917144775 seconds) with total reward 211.5506356729374
# {'coverage_prop': '0.975', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.445', 'efficiency': '0.187', 'TP': '142', 'FP': '56', 'FN': '5', 'precision': '0.717', 'recall': '0.966', 'f1': '0.823', 'total_rewards': 211.55063567293573, 'invalid_action_count': 0, 'num_ms1_scans': 471, 'num_ms2_scans': 1058}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 74.93480868621205
# steps	 1000 	total rewards	 166.59200032532996
# steps	 1500 	total rewards	 247.1880998848544
# Finished after 1580 timesteps (4.980197906494141 seconds) with total reward 257.8245817911451
# {'coverage_prop': '0.961', 'intensity_prop': '0.603', 'ms1ms2_ratio': '0.362', 'efficiency': '0.233', 'TP': '186', 'FP': '84', 'FN': '11', 'precision': '0.689', 'recall': '0.944', 'f1': '0.797', 'total_rewards': 257.82458179114354, 'invalid_action_count': 2, 'num_ms1_scans': 420, 'num_ms2_scans': 1160}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 93.35722002474577
# steps	 1000 	total rewards	 183.27731971086257
# steps	 1500 	total rewards	 287.23421418280793
# Finished after 1610 timesteps (7.060995101928711 seconds) with total reward 297.8959549480633
# {'coverage_prop': '0.864', 'intensity_prop': '0.477', 'ms1ms2_ratio': '0.320', 'efficiency': '0.349', 'TP': '247', 'FP': '179', 'FN': '67', 'precision': '0.580', 'recall': '0.787', 'f1': '0.668', 'total_rewards': 297.89595494806366, 'invalid_action_count': 13, 'num_ms1_scans': 390, 'num_ms2_scans': 1220}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 77.49935683008304
# steps	 1000 	total rewards	 168.14385880374698
# steps	 1500 	total rewards	 245.44977118264484
# Finished after 1591 timesteps (6.73744797706604 seconds) with total reward 254.27463189739404
# {'coverage_prop': '0.947', 'intensity_prop': '0.614', 'ms1ms2_ratio': '0.346', 'efficiency': '0.244', 'TP': '203', 'FP': '85', 'FN': '16', 'precision': '0.705', 'recall': '0.927', 'f1': '0.801', 'total_rewards': 254.27463189739242, 'invalid_action_count': 2, 'num_ms1_scans': 409, 'num_ms2_scans': 1182}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 92.5276178076839
# steps	 1000 	total rewards	 205.25382864627784
# steps	 1500 	total rewards	 312.7588878054987
# Finished after 1722 timesteps (11.097115993499756 seconds) with total reward 350.1583925147164
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 350.15839251471635, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.19223993264903
# steps	 1000 	total rewards	 200.01185786399162
# steps	 1500 	total rewards	 278.69251864828544
# Finished after 1556 timesteps (11.076883316040039 seconds) with total reward 286.42041452327317
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 286.42041452327345, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.09810262952533
# steps	 1000 	total rewards	 204.55175528344176
# steps	 1500 	total rewards	 311.70589197292
# Finished after 1669 timesteps (14.334845066070557 seconds) with total reward 335.8567231016701
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 335.856723101671, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.75112549735738
# steps	 1000 	total rewards	 222.260470162795
# steps	 1500 	total rewards	 321.6296912754646
# Finished after 1717 timesteps (11.605074882507324 seconds) with total reward 364.78676992745324
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 364.7867699274535, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.88207661824359
# steps	 1000 	total rewards	 225.03458447204991
# steps	 1500 	total rewards	 333.40644054419124
# Finished after 1704 timesteps (11.078466176986694 seconds) with total reward 368.54312915676854
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 368.54312915676945, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.95053041210245
# steps	 1000 	total rewards	 176.02517486243747
# Finished after 1408 timesteps (7.338088274002075 seconds) with total reward 238.71804354506358
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 238.7180435450617, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.04778207928516
# steps	 1000 	total rewards	 216.92306176316305
# steps	 1500 	total rewards	 317.03297009874126
# Finished after 1744 timesteps (9.758174896240234 seconds) with total reward 357.54143159354504
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 357.54143159354567, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.27568189026226
# steps	 1000 	total rewards	 178.89586218914897
# Finished after 1468 timesteps (8.950369834899902 seconds) with total reward 248.8792687394992
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 248.87926873949786, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 102.06959352333683
# steps	 1000 	total rewards	 203.76934731050875
# steps	 1500 	total rewards	 314.6913157438472
# Finished after 1736 timesteps (9.935272216796875 seconds) with total reward 352.8683422368248
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 352.8683422368253, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 90.74138548172694
# steps	 1000 	total rewards	 200.31290144512386
# steps	 1500 	total rewards	 301.1097996085705
# Finished after 1667 timesteps (9.407326221466064 seconds) with total reward 323.768416073993
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 323.7684160739943, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.23962533608534
# steps	 1000 	total rewards	 197.16226995805556
# steps	 1500 	total rewards	 303.39580167752945
# Finished after 1737 timesteps (11.354541063308716 seconds) with total reward 344.057804535654
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 344.05780453565535, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.76014323446897
# steps	 1000 	total rewards	 182.82317997694054
# steps	 1500 	total rewards	 254.1775526296638
# Finished after 1530 timesteps (13.012604236602783 seconds) with total reward 257.90826139058424
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 257.9082613905829, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.09788008205047
# steps	 1000 	total rewards	 173.34530752343633
# steps	 1500 	total rewards	 250.4027444407447
# Finished after 1602 timesteps (10.710197925567627 seconds) with total reward 265.8130372865816
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 265.8130372865811, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 81.87979467550704
# steps	 1000 	total rewards	 176.3296676850765
# steps	 1500 	total rewards	 264.5543538505019
# Finished after 1645 timesteps (10.829111099243164 seconds) with total reward 281.66421220903726
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 281.6642122090379, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 77.69553492222708
# steps	 1000 	total rewards	 165.92205077135358
# Finished after 1497 timesteps (11.582072019577026 seconds) with total reward 238.86550329561172
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 238.86550329561047, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.05709360186964
# steps	 1000 	total rewards	 202.35383743309467
# steps	 1500 	total rewards	 309.4258646878863
# Finished after 1655 timesteps (13.311759233474731 seconds) with total reward 340.11849111963613
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 340.118491119637, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 105.80378017337763
# steps	 1000 	total rewards	 218.16501246190484
# steps	 1500 	total rewards	 323.99517148498575
# Finished after 1729 timesteps (14.326751947402954 seconds) with total reward 365.3798953710612
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 365.3798953710626, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.86888851189178
# steps	 1000 	total rewards	 210.73859611594213
# steps	 1500 	total rewards	 300.65131585356136
# Finished after 1681 timesteps (14.809806108474731 seconds) with total reward 326.453219442385
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 326.45321944238583, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.55640776019361
# steps	 1000 	total rewards	 192.1170010832405
# steps	 1500 	total rewards	 282.6369316315453
# Finished after 1621 timesteps (13.36490797996521 seconds) with total reward 301.02243270902477
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 301.022432709025, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.8961989902214
# steps	 1000 	total rewards	 183.76704030525036
# steps	 1500 	total rewards	 264.106842989171
# Finished after 1634 timesteps (10.331034183502197 seconds) with total reward 282.8349639496908
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 282.8349639496904, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.82872862229425
# steps	 1000 	total rewards	 205.4574323828516
# steps	 1500 	total rewards	 298.0440315538605
# Finished after 1726 timesteps (12.049586296081543 seconds) with total reward 339.6563370807766
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 339.65633708077706, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 78.8765952264226
# steps	 1000 	total rewards	 180.8121218448101
# Finished after 1475 timesteps (8.429945230484009 seconds) with total reward 259.5886548759064
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 259.5886548759048, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 90.37844742158512
# steps	 1000 	total rewards	 195.95932027941527
# steps	 1500 	total rewards	 283.3609709366841
# Finished after 1636 timesteps (8.513224124908447 seconds) with total reward 305.03129962834686
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 305.03129962834777, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.58010974902588
# steps	 1000 	total rewards	 199.06887434647197
# steps	 1500 	total rewards	 285.5523492877917
# Finished after 1575 timesteps (8.066574096679688 seconds) with total reward 296.6703624144893
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 296.67036241449057, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 90.58123202962977
# steps	 1000 	total rewards	 201.86616968777264
# steps	 1500 	total rewards	 295.787668388372
# Finished after 1681 timesteps (8.838000059127808 seconds) with total reward 324.2819674955664
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 324.28196749556696, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.78144021754095
# steps	 1000 	total rewards	 188.87430385569195
# steps	 1500 	total rewards	 297.86842274642567
# Finished after 1679 timesteps (12.935847282409668 seconds) with total reward 329.2116800669655
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 329.21168006696644, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 71.98194223405334
# steps	 1000 	total rewards	 170.41017366979133
# Finished after 1465 timesteps (8.66590690612793 seconds) with total reward 242.86558010739546
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 242.86558010739404, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 87.80052172308895
# steps	 1000 	total rewards	 195.50633781024922
# steps	 1500 	total rewards	 294.00010247549244
# Finished after 1564 timesteps (8.883723974227905 seconds) with total reward 304.0900195549617
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 304.09001955496166, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.17309733822901
# steps	 1000 	total rewards	 195.47739728296165
# steps	 1500 	total rewards	 298.6482177897861
# Finished after 1749 timesteps (10.500219106674194 seconds) with total reward 346.2046795612188
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 346.20467956121945, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.33998672596451
# steps	 1000 	total rewards	 192.64754247155082
# steps	 1500 	total rewards	 274.80651079438553
# Finished after 1657 timesteps (8.948096990585327 seconds) with total reward 293.02734741027416
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 293.02734741027416, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc6985d6a90>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc688144670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc6986e9910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.275', 'efficiency': '0.728', 'TP': '118', 'FP': '75', 'FN': '11', 'precision': '0.611', 'recall': '0.915', 'f1': '0.733'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.206', 'efficiency': '0.727', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.983', 'efficiency': '0.710', 'TP': '147', 'FP': '139', 'FN': '14', 'precision': '0.514', 'recall': '0.913', 'f1': '0.658'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.491', 'ms1ms2_ratio': '3.153', 'efficiency': '0.708', 'TP': '100', 'FP': '94', 'FN': '12', 'precision': '0.515', 'recall': '0.893', 'f1': '0.654'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.504', 'ms1ms2_ratio': '1.689', 'efficiency': '0.775', 'TP': '185', 'FP': '169', 'FN': '18', 'precision': '0.523', 'recall': '0.911', 'f1': '0.664'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.504', 'ms1ms2_ratio': '2.080', 'efficiency': '0.750', 'TP': '142', 'FP': '149', 'FN': '11', 'precision': '0.488', 'recall': '0.928', 'f1': '0.640'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.928', 'efficiency': '0.753', 'TP': '110', 'FP': '110', 'FN': '14', 'precision': '0.500', 'recall': '0.887', 'f1': '0.640'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.491', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.522', 'ms1ms2_ratio': '1.034', 'efficiency': '0.719', 'TP': '258', 'FP': '211', 'FN': '24', 'precision': '0.550', 'recall': '0.915', 'f1': '0.687'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1090.217643                1235.0          0.718           0.203
# 1  random   -1621.197842                1678.0          0.489           0.089
# 2  random    -984.669991                1131.0          0.756           0.227
# 3  random   -1061.950216                1219.0          0.759           0.243
# 4  random    -894.036327                1064.0          0.810           0.290
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.155      0.248   0.388  0.303
# 1          0.004       0.064      0.148   0.124  0.135
# 2          0.006       0.151      0.268   0.455  0.338
# 3          0.006       0.174      0.303   0.488  0.374
# 4          0.006       0.179      0.333   0.587  0.425

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     277.798353                  26.0          0.904           0.554
# 31    DQN     242.458120                   3.0          0.954           0.570
# 32    DQN     256.648691                  33.0          0.937           0.532
# 33    DQN     255.477837                  48.0          0.916           0.527
# 34    DQN     281.652815                  18.0          0.924           0.547
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.286       0.302      0.673   0.863  0.756
# 31          0.365       0.216      0.640   0.930  0.758
# 32          0.296       0.294      0.618   0.901  0.733
# 33          0.291       0.328      0.628   0.872  0.730
# 34          0.324       0.333      0.661   0.890  0.759

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
