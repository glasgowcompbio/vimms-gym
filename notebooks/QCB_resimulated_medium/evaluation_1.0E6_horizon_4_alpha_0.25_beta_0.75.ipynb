# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.25
env_beta = 0.75
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-14 10:12:17.029 | INFO     | vimms_gym.experiments:get_samplers:295 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fce760b1750>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fce77d6ae90>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fce77d8c070>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.25,
#    'beta': 0.75}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fce760b1750>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fce77d6ae90>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fce77d8c070>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fce760b1750>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fce77d6ae90>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fce77d8c070>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.75}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        # fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -493.80212991405733
# steps	 1000 	total rewards	 -963.3078837017247
# steps	 1500 	total rewards	 -1432.8558917083717
# Finished after 1991 timesteps (1.320296049118042 seconds) with total reward -1890.8831874309833
# {'coverage_prop': '0.310', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.005', 'efficiency': '0.067', 'TP': '21', 'FP': '111', 'FN': '294', 'precision': '0.159', 'recall': '0.067', 'f1': '0.094', 'total_rewards': -1890.8831874309835, 'invalid_action_count': 1911, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -485.26675484076463
# steps	 1000 	total rewards	 -968.6015052925788
# steps	 1500 	total rewards	 -1443.9640379265295
# Finished after 1989 timesteps (0.7758409976959229 seconds) with total reward -1899.3193646192262
# {'coverage_prop': '0.286', 'intensity_prop': '0.056', 'ms1ms2_ratio': '0.006', 'efficiency': '0.038', 'TP': '11', 'FP': '64', 'FN': '187', 'precision': '0.147', 'recall': '0.056', 'f1': '0.081', 'total_rewards': -1899.3193646192265, 'invalid_action_count': 1918, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -476.202501572727
# steps	 1000 	total rewards	 -929.3741017679621
# steps	 1500 	total rewards	 -1368.0167246224348
# Finished after 1985 timesteps (1.0139708518981934 seconds) with total reward -1835.400227466064
# {'coverage_prop': '0.409', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.008', 'efficiency': '0.082', 'TP': '35', 'FP': '126', 'FN': '233', 'precision': '0.217', 'recall': '0.131', 'f1': '0.163', 'total_rewards': -1835.4002274660636, 'invalid_action_count': 1865, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -474.53754499177813
# steps	 1000 	total rewards	 -941.685296344951
# steps	 1500 	total rewards	 -1380.1429106630553
# Finished after 1985 timesteps (1.0411510467529297 seconds) with total reward -1822.4339841631252
# {'coverage_prop': '0.398', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.008', 'efficiency': '0.091', 'TP': '44', 'FP': '136', 'FN': '272', 'precision': '0.244', 'recall': '0.139', 'f1': '0.177', 'total_rewards': -1822.4339841631256, 'invalid_action_count': 1856, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -488.3471681877177
# steps	 1000 	total rewards	 -957.231470941972
# steps	 1500 	total rewards	 -1421.3362102768456
# Finished after 1996 timesteps (1.0314538478851318 seconds) with total reward -1908.3905149350935
# {'coverage_prop': '0.245', 'intensity_prop': '0.040', 'ms1ms2_ratio': '0.002', 'efficiency': '0.054', 'TP': '15', 'FP': '92', 'FN': '330', 'precision': '0.140', 'recall': '0.043', 'f1': '0.066', 'total_rewards': -1908.3905149350933, 'invalid_action_count': 1927, 'num_ms1_scans': 4, 'num_ms2_scans': 1992}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -496.59783542996456
# steps	 1000 	total rewards	 -972.5964228625097
# steps	 1500 	total rewards	 -1449.3985783888502
# Finished after 1988 timesteps (0.7345991134643555 seconds) with total reward -1915.58817655141
# {'coverage_prop': '0.325', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.006', 'efficiency': '0.033', 'TP': '15', 'FP': '50', 'FN': '135', 'precision': '0.231', 'recall': '0.100', 'f1': '0.140', 'total_rewards': -1915.5881765514096, 'invalid_action_count': 1929, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -474.8672460209595
# steps	 1000 	total rewards	 -946.4980519037999
# steps	 1500 	total rewards	 -1380.3730384295043
# Finished after 1987 timesteps (1.529055118560791 seconds) with total reward -1835.6265382574293
# {'coverage_prop': '0.379', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.007', 'efficiency': '0.092', 'TP': '52', 'FP': '129', 'FN': '297', 'precision': '0.287', 'recall': '0.149', 'f1': '0.196', 'total_rewards': -1835.6265382574297, 'invalid_action_count': 1864, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -484.12597955824253
# steps	 1000 	total rewards	 -944.3374324871503
# steps	 1500 	total rewards	 -1409.9447002163354
# Finished after 1985 timesteps (0.7263290882110596 seconds) with total reward -1883.1761164110653
# {'coverage_prop': '0.368', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.008', 'efficiency': '0.038', 'TP': '19', 'FP': '56', 'FN': '129', 'precision': '0.253', 'recall': '0.128', 'f1': '0.170', 'total_rewards': -1883.176116411065, 'invalid_action_count': 1902, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -489.47614920663364
# steps	 1000 	total rewards	 -975.2477562986917
# steps	 1500 	total rewards	 -1467.553494324746
# Finished after 1995 timesteps (0.9970130920410156 seconds) with total reward -1919.3341673747398
# {'coverage_prop': '0.200', 'intensity_prop': '0.032', 'ms1ms2_ratio': '0.003', 'efficiency': '0.043', 'TP': '9', 'FP': '76', 'FN': '339', 'precision': '0.106', 'recall': '0.026', 'f1': '0.042', 'total_rewards': -1919.3341673747395, 'invalid_action_count': 1937, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -494.9619464429063
# steps	 1000 	total rewards	 -942.6297068820295
# steps	 1500 	total rewards	 -1385.529808482169
# Finished after 1989 timesteps (0.9415690898895264 seconds) with total reward -1839.1827090279862
# {'coverage_prop': '0.393', 'intensity_prop': '0.114', 'ms1ms2_ratio': '0.006', 'efficiency': '0.076', 'TP': '43', 'FP': '108', 'FN': '233', 'precision': '0.285', 'recall': '0.156', 'f1': '0.201', 'total_rewards': -1839.182709027986, 'invalid_action_count': 1869, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -484.92293532503743
# steps	 1000 	total rewards	 -973.0607181279285
# steps	 1500 	total rewards	 -1439.4033379106747
# Finished after 1992 timesteps (1.0643279552459717 seconds) with total reward -1884.0999471213063
# {'coverage_prop': '0.282', 'intensity_prop': '0.068', 'ms1ms2_ratio': '0.004', 'efficiency': '0.063', 'TP': '30', 'FP': '95', 'FN': '318', 'precision': '0.240', 'recall': '0.086', 'f1': '0.127', 'total_rewards': -1884.0999471213063, 'invalid_action_count': 1906, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -495.1705628410904
# steps	 1000 	total rewards	 -987.3078525506684
# steps	 1500 	total rewards	 -1467.9420313358632
# Finished after 1988 timesteps (1.2137627601623535 seconds) with total reward -1924.8996298517063
# {'coverage_prop': '0.241', 'intensity_prop': '0.058', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '11', 'FP': '49', 'FN': '189', 'precision': '0.183', 'recall': '0.055', 'f1': '0.085', 'total_rewards': -1924.8996298517059, 'invalid_action_count': 1936, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -490.7892202204861
# steps	 1000 	total rewards	 -956.8694793591746
# steps	 1500 	total rewards	 -1418.5155687723225
# Finished after 1987 timesteps (0.8638119697570801 seconds) with total reward -1868.1747046651262
# {'coverage_prop': '0.398', 'intensity_prop': '0.113', 'ms1ms2_ratio': '0.007', 'efficiency': '0.051', 'TP': '28', 'FP': '72', 'FN': '151', 'precision': '0.280', 'recall': '0.156', 'f1': '0.201', 'total_rewards': -1868.1747046651262, 'invalid_action_count': 1892, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -485.18832121830843
# steps	 1000 	total rewards	 -964.436733382867
# steps	 1500 	total rewards	 -1408.3893523689326
# Finished after 1988 timesteps (0.9103760719299316 seconds) with total reward -1848.5035408964595
# {'coverage_prop': '0.437', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.006', 'efficiency': '0.066', 'TP': '30', 'FP': '101', 'FN': '169', 'precision': '0.229', 'recall': '0.151', 'f1': '0.182', 'total_rewards': -1848.5035408964598, 'invalid_action_count': 1875, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -484.5223086709391
# steps	 1000 	total rewards	 -955.2707032439155
# steps	 1500 	total rewards	 -1425.0815747892298
# Finished after 1985 timesteps (0.7481229305267334 seconds) with total reward -1886.572186147194
# {'coverage_prop': '0.359', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.008', 'efficiency': '0.038', 'TP': '13', 'FP': '61', 'FN': '132', 'precision': '0.176', 'recall': '0.090', 'f1': '0.119', 'total_rewards': -1886.5721861471943, 'invalid_action_count': 1906, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -485.93839622657794
# steps	 1000 	total rewards	 -942.3680606417272
# steps	 1500 	total rewards	 -1378.6543472840253
# Finished after 1991 timesteps (1.0126519203186035 seconds) with total reward -1847.0223146345156
# {'coverage_prop': '0.400', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.005', 'efficiency': '0.082', 'TP': '50', 'FP': '113', 'FN': '244', 'precision': '0.307', 'recall': '0.170', 'f1': '0.219', 'total_rewards': -1847.0223146345165, 'invalid_action_count': 1878, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -459.6219397700245
# steps	 1000 	total rewards	 -912.8768008818372
# steps	 1500 	total rewards	 -1361.3101723917516
# Finished after 1983 timesteps (1.116358995437622 seconds) with total reward -1804.2532201329932
# {'coverage_prop': '0.422', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.009', 'efficiency': '0.107', 'TP': '51', 'FP': '159', 'FN': '288', 'precision': '0.243', 'recall': '0.150', 'f1': '0.186', 'total_rewards': -1804.2532201329932, 'invalid_action_count': 1840, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -971.3837672579241
# steps	 1500 	total rewards	 -1406.7270063824008
# Finished after 1990 timesteps (0.9638922214508057 seconds) with total reward -1857.4654536569903
# {'coverage_prop': '0.387', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.005', 'efficiency': '0.073', 'TP': '34', 'FP': '110', 'FN': '228', 'precision': '0.236', 'recall': '0.130', 'f1': '0.167', 'total_rewards': -1857.4654536569908, 'invalid_action_count': 1881, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -494.8665239995815
# steps	 1000 	total rewards	 -975.8506578478434
# steps	 1500 	total rewards	 -1441.1512501629807
# Finished after 1990 timesteps (0.881450891494751 seconds) with total reward -1890.3192780130344
# {'coverage_prop': '0.305', 'intensity_prop': '0.070', 'ms1ms2_ratio': '0.005', 'efficiency': '0.046', 'TP': '16', 'FP': '76', 'FN': '210', 'precision': '0.174', 'recall': '0.071', 'f1': '0.101', 'total_rewards': -1890.319278013034, 'invalid_action_count': 1910, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -489.63283418898936
# steps	 1000 	total rewards	 -960.1984177551735
# steps	 1500 	total rewards	 -1411.5151802564249
# Finished after 1986 timesteps (0.9267630577087402 seconds) with total reward -1859.6196205097312
# {'coverage_prop': '0.358', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.007', 'efficiency': '0.048', 'TP': '21', 'FP': '74', 'FN': '170', 'precision': '0.221', 'recall': '0.110', 'f1': '0.147', 'total_rewards': -1859.619620509731, 'invalid_action_count': 1884, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -945.7765492742219
# steps	 1500 	total rewards	 -1369.5757465881095
# Finished after 1989 timesteps (1.1327338218688965 seconds) with total reward -1820.119656509791
# {'coverage_prop': '0.385', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.006', 'efficiency': '0.091', 'TP': '42', 'FP': '138', 'FN': '288', 'precision': '0.233', 'recall': '0.127', 'f1': '0.165', 'total_rewards': -1820.1196565097905, 'invalid_action_count': 1855, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -482.1291441267473
# steps	 1000 	total rewards	 -948.6541787128378
# steps	 1500 	total rewards	 -1396.39177081892
# Finished after 1982 timesteps (0.7894837856292725 seconds) with total reward -1851.7071829457293
# {'coverage_prop': '0.453', 'intensity_prop': '0.138', 'ms1ms2_ratio': '0.009', 'efficiency': '0.054', 'TP': '33', 'FP': '73', 'FN': '128', 'precision': '0.311', 'recall': '0.205', 'f1': '0.247', 'total_rewards': -1851.7071829457293, 'invalid_action_count': 1878, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -492.57722398373915
# steps	 1000 	total rewards	 -981.791089947704
# steps	 1500 	total rewards	 -1416.6720557313474
# Finished after 1989 timesteps (0.9366090297698975 seconds) with total reward -1875.7057408770056
# {'coverage_prop': '0.317', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.006', 'efficiency': '0.052', 'TP': '30', 'FP': '72', 'FN': '220', 'precision': '0.294', 'recall': '0.120', 'f1': '0.170', 'total_rewards': -1875.7057408770052, 'invalid_action_count': 1897, 'num_ms1_scans': 12, 'num_ms2_scans': 1977}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -490.84171094586003
# steps	 1000 	total rewards	 -986.1821194900162
# steps	 1500 	total rewards	 -1486.1821194900162
# Finished after 1993 timesteps (1.5129969120025635 seconds) with total reward -1946.8701182917982
# {'coverage_prop': '0.135', 'intensity_prop': '0.028', 'ms1ms2_ratio': '0.004', 'efficiency': '0.021', 'TP': '7', 'FP': '35', 'FN': '268', 'precision': '0.167', 'recall': '0.025', 'f1': '0.044', 'total_rewards': -1946.8701182917982, 'invalid_action_count': 1956, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -478.7428723325824
# steps	 1000 	total rewards	 -957.0533446097689
# steps	 1500 	total rewards	 -1403.8135222812264
# Finished after 1989 timesteps (0.9374058246612549 seconds) with total reward -1862.3202060518474
# {'coverage_prop': '0.339', 'intensity_prop': '0.085', 'ms1ms2_ratio': '0.006', 'efficiency': '0.059', 'TP': '25', 'FP': '92', 'FN': '228', 'precision': '0.214', 'recall': '0.099', 'f1': '0.135', 'total_rewards': -1862.3202060518477, 'invalid_action_count': 1889, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -485.96512676358384
# steps	 1000 	total rewards	 -984.9651267635838
# steps	 1500 	total rewards	 -1473.3349979398702
# Finished after 1990 timesteps (0.9710221290588379 seconds) with total reward -1927.7790913180938
# {'coverage_prop': '0.187', 'intensity_prop': '0.039', 'ms1ms2_ratio': '0.005', 'efficiency': '0.037', 'TP': '13', 'FP': '61', 'FN': '322', 'precision': '0.176', 'recall': '0.039', 'f1': '0.064', 'total_rewards': -1927.7790913180938, 'invalid_action_count': 1940, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -495.27861434454877
# steps	 1000 	total rewards	 -979.2019798980375
# steps	 1500 	total rewards	 -1448.3560062832091
# Finished after 1989 timesteps (0.7465860843658447 seconds) with total reward -1908.8004250624253
# {'coverage_prop': '0.365', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.006', 'efficiency': '0.037', 'TP': '16', 'FP': '58', 'FN': '129', 'precision': '0.216', 'recall': '0.110', 'f1': '0.146', 'total_rewards': -1908.8004250624251, 'invalid_action_count': 1924, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -488.72883925266456
# steps	 1000 	total rewards	 -967.8828938116442
# steps	 1500 	total rewards	 -1430.168343709107
# Finished after 1989 timesteps (0.8044791221618652 seconds) with total reward -1902.399142491342
# {'coverage_prop': '0.295', 'intensity_prop': '0.063', 'ms1ms2_ratio': '0.006', 'efficiency': '0.042', 'TP': '14', 'FP': '69', 'FN': '198', 'precision': '0.169', 'recall': '0.066', 'f1': '0.095', 'total_rewards': -1902.3991424913418, 'invalid_action_count': 1920, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -941.0831697199833
# steps	 1500 	total rewards	 -1388.0771656364373
# Finished after 1994 timesteps (1.2549729347229004 seconds) with total reward -1827.4839082265216
# {'coverage_prop': '0.375', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.003', 'efficiency': '0.093', 'TP': '42', 'FP': '143', 'FN': '308', 'precision': '0.227', 'recall': '0.120', 'f1': '0.157', 'total_rewards': -1827.483908226522, 'invalid_action_count': 1862, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -492.4289021748115
# steps	 1000 	total rewards	 -969.6973664017319
# steps	 1500 	total rewards	 -1427.6056549788984
# Finished after 1990 timesteps (0.9063611030578613 seconds) with total reward -1880.8762448746197
# {'coverage_prop': '0.352', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.005', 'efficiency': '0.054', 'TP': '25', 'FP': '82', 'FN': '197', 'precision': '0.234', 'recall': '0.113', 'f1': '0.152', 'total_rewards': -1880.8762448746204, 'invalid_action_count': 1902, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
# /opt/anaconda3/envs/vimms-gym/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:229: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.32GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 54.15733279985841
# steps	 1000 	total rewards	 109.24281689778795
# steps	 1500 	total rewards	 173.35793444427838
# Finished after 1632 timesteps (6.137428045272827 seconds) with total reward 187.22529651907922
# {'coverage_prop': '0.674', 'intensity_prop': '0.448', 'ms1ms2_ratio': '0.291', 'efficiency': '0.227', 'TP': '208', 'FP': '79', 'FN': '139', 'precision': '0.725', 'recall': '0.599', 'f1': '0.656', 'total_rewards': 187.22529651907956, 'invalid_action_count': 7, 'num_ms1_scans': 368, 'num_ms2_scans': 1264}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 50.08177656499756
# steps	 1000 	total rewards	 108.21547502535046
# steps	 1500 	total rewards	 170.2884765872982
# Finished after 1557 timesteps (5.855031728744507 seconds) with total reward 175.97406460397184
# {'coverage_prop': '0.809', 'intensity_prop': '0.608', 'ms1ms2_ratio': '0.399', 'efficiency': '0.190', 'TP': '179', 'FP': '33', 'FN': '50', 'precision': '0.844', 'recall': '0.782', 'f1': '0.812', 'total_rewards': 175.97406460397178, 'invalid_action_count': 3, 'num_ms1_scans': 444, 'num_ms2_scans': 1113}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 44.03829128730372
# steps	 1000 	total rewards	 103.83350869300483
# steps	 1500 	total rewards	 156.2750983322245
# Finished after 1616 timesteps (7.699939012527466 seconds) with total reward 168.06661676538405
# {'coverage_prop': '0.741', 'intensity_prop': '0.499', 'ms1ms2_ratio': '0.312', 'efficiency': '0.237', 'TP': '214', 'FP': '78', 'FN': '102', 'precision': '0.733', 'recall': '0.677', 'f1': '0.704', 'total_rewards': 168.06661676538394, 'invalid_action_count': 11, 'num_ms1_scans': 384, 'num_ms2_scans': 1232}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 54.77057739427587
# steps	 1000 	total rewards	 113.37579485941953
# steps	 1500 	total rewards	 161.0144453544387
# Finished after 1631 timesteps (6.121000289916992 seconds) with total reward 172.72344635923815
# {'coverage_prop': '0.730', 'intensity_prop': '0.520', 'ms1ms2_ratio': '0.292', 'efficiency': '0.261', 'TP': '258', 'FP': '72', 'FN': '122', 'precision': '0.782', 'recall': '0.679', 'f1': '0.727', 'total_rewards': 172.72344635923844, 'invalid_action_count': 4, 'num_ms1_scans': 369, 'num_ms2_scans': 1262}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 48.20616622305761
# steps	 1000 	total rewards	 108.68712702404638
# steps	 1500 	total rewards	 161.09565513509762
# Finished after 1624 timesteps (6.979765892028809 seconds) with total reward 173.986004276863
# {'coverage_prop': '0.767', 'intensity_prop': '0.526', 'ms1ms2_ratio': '0.301', 'efficiency': '0.268', 'TP': '253', 'FP': '82', 'FN': '102', 'precision': '0.755', 'recall': '0.713', 'f1': '0.733', 'total_rewards': 173.98600427686284, 'invalid_action_count': 8, 'num_ms1_scans': 376, 'num_ms2_scans': 1248}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 31.1070052403107
# steps	 1000 	total rewards	 79.8281243362288
# Finished after 1438 timesteps (5.168515682220459 seconds) with total reward 107.76312251853503
# {'coverage_prop': '0.855', 'intensity_prop': '0.679', 'ms1ms2_ratio': '0.643', 'efficiency': '0.195', 'TP': '153', 'FP': '18', 'FN': '29', 'precision': '0.895', 'recall': '0.841', 'f1': '0.867', 'total_rewards': 107.76312251853491, 'invalid_action_count': 11, 'num_ms1_scans': 563, 'num_ms2_scans': 875}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 46.73298591755771
# steps	 1000 	total rewards	 106.46650971049371
# steps	 1500 	total rewards	 148.53645277528722
# Finished after 1638 timesteps (6.5694780349731445 seconds) with total reward 163.27433521761566
# {'coverage_prop': '0.697', 'intensity_prop': '0.467', 'ms1ms2_ratio': '0.284', 'efficiency': '0.261', 'TP': '243', 'FP': '90', 'FN': '145', 'precision': '0.730', 'recall': '0.626', 'f1': '0.674', 'total_rewards': 163.27433521761546, 'invalid_action_count': 9, 'num_ms1_scans': 362, 'num_ms2_scans': 1276}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 33.15978283369282
# steps	 1000 	total rewards	 92.72210862580991
# Finished after 1454 timesteps (5.507077217102051 seconds) with total reward 135.08424574521828
# {'coverage_prop': '0.760', 'intensity_prop': '0.611', 'ms1ms2_ratio': '0.601', 'efficiency': '0.171', 'TP': '139', 'FP': '16', 'FN': '49', 'precision': '0.897', 'recall': '0.739', 'f1': '0.810', 'total_rewards': 135.0842457452183, 'invalid_action_count': 2, 'num_ms1_scans': 546, 'num_ms2_scans': 908}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 55.827334678455
# steps	 1000 	total rewards	 117.2263229106525
# steps	 1500 	total rewards	 172.5035041093246
# Finished after 1639 timesteps (6.791684865951538 seconds) with total reward 187.8218257391795
# {'coverage_prop': '0.724', 'intensity_prop': '0.487', 'ms1ms2_ratio': '0.282', 'efficiency': '0.240', 'TP': '226', 'FP': '81', 'FN': '117', 'precision': '0.736', 'recall': '0.659', 'f1': '0.695', 'total_rewards': 187.8218257391795, 'invalid_action_count': 2, 'num_ms1_scans': 361, 'num_ms2_scans': 1278}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 48.17983997481902
# steps	 1000 	total rewards	 105.9254805749842
# steps	 1500 	total rewards	 162.64509910679078
# Finished after 1621 timesteps (5.186431884765625 seconds) with total reward 176.31978531527702
# {'coverage_prop': '0.719', 'intensity_prop': '0.504', 'ms1ms2_ratio': '0.305', 'efficiency': '0.222', 'TP': '218', 'FP': '58', 'FN': '108', 'precision': '0.790', 'recall': '0.669', 'f1': '0.724', 'total_rewards': 176.31978531527702, 'invalid_action_count': 8, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 52.79623345643639
# steps	 1000 	total rewards	 113.46023753710078
# steps	 1500 	total rewards	 169.7081909360058
# Finished after 1648 timesteps (6.594515085220337 seconds) with total reward 188.80407519550855
# {'coverage_prop': '0.700', 'intensity_prop': '0.470', 'ms1ms2_ratio': '0.272', 'efficiency': '0.239', 'TP': '233', 'FP': '77', 'FN': '133', 'precision': '0.752', 'recall': '0.637', 'f1': '0.689', 'total_rewards': 188.80407519550826, 'invalid_action_count': 8, 'num_ms1_scans': 352, 'num_ms2_scans': 1296}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 44.91703949657945
# steps	 1000 	total rewards	 103.94511545464167
# steps	 1500 	total rewards	 145.9414437909553
# Finished after 1534 timesteps (6.011904001235962 seconds) with total reward 149.13055795962165
# {'coverage_prop': '0.811', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.436', 'efficiency': '0.189', 'TP': '180', 'FP': '22', 'FN': '47', 'precision': '0.891', 'recall': '0.793', 'f1': '0.839', 'total_rewards': 149.1305579596217, 'invalid_action_count': 1, 'num_ms1_scans': 466, 'num_ms2_scans': 1068}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 55.92097509882802
# steps	 1000 	total rewards	 107.72592571381583
# steps	 1500 	total rewards	 154.2129884090991
# Finished after 1556 timesteps (5.2812278270721436 seconds) with total reward 159.53385950347797
# {'coverage_prop': '0.701', 'intensity_prop': '0.509', 'ms1ms2_ratio': '0.399', 'efficiency': '0.158', 'TP': '142', 'FP': '34', 'FN': '75', 'precision': '0.807', 'recall': '0.654', 'f1': '0.723', 'total_rewards': 159.5338595034783, 'invalid_action_count': 2, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 50.08128730895662
# steps	 1000 	total rewards	 101.67284214078906
# steps	 1500 	total rewards	 150.87606212474583
# Finished after 1594 timesteps (8.636385202407837 seconds) with total reward 159.89566005512253
# {'coverage_prop': '0.713', 'intensity_prop': '0.512', 'ms1ms2_ratio': '0.343', 'efficiency': '0.180', 'TP': '170', 'FP': '44', 'FN': '86', 'precision': '0.794', 'recall': '0.664', 'f1': '0.723', 'total_rewards': 159.89566005512256, 'invalid_action_count': 3, 'num_ms1_scans': 407, 'num_ms2_scans': 1187}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 39.29995876709263
# steps	 1000 	total rewards	 95.40046361763606
# Finished after 1488 timesteps (4.517043828964233 seconds) with total reward 132.43162337744155
# {'coverage_prop': '0.796', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.525', 'efficiency': '0.168', 'TP': '138', 'FP': '26', 'FN': '42', 'precision': '0.841', 'recall': '0.767', 'f1': '0.802', 'total_rewards': 132.4316233774416, 'invalid_action_count': 3, 'num_ms1_scans': 512, 'num_ms2_scans': 976}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 43.07909714238993
# steps	 1000 	total rewards	 99.87023461012058
# steps	 1500 	total rewards	 150.97587729543096
# Finished after 1622 timesteps (6.066145181655884 seconds) with total reward 164.73689770585827
# {'coverage_prop': '0.771', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.305', 'efficiency': '0.253', 'TP': '261', 'FP': '53', 'FN': '93', 'precision': '0.831', 'recall': '0.737', 'f1': '0.781', 'total_rewards': 164.7368977058584, 'invalid_action_count': 12, 'num_ms1_scans': 379, 'num_ms2_scans': 1243}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 54.34830398105431
# steps	 1000 	total rewards	 115.61300385229279
# steps	 1500 	total rewards	 170.51118307004413
# Finished after 1636 timesteps (5.344387054443359 seconds) with total reward 183.404995133865
# {'coverage_prop': '0.711', 'intensity_prop': '0.495', 'ms1ms2_ratio': '0.287', 'efficiency': '0.279', 'TP': '275', 'FP': '79', 'FN': '144', 'precision': '0.777', 'recall': '0.656', 'f1': '0.712', 'total_rewards': 183.404995133865, 'invalid_action_count': 7, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 54.046946324259
# steps	 1000 	total rewards	 107.42101483593662
# steps	 1500 	total rewards	 165.16960904599864
# Finished after 1618 timesteps (5.226759910583496 seconds) with total reward 177.48439570578904
# {'coverage_prop': '0.723', 'intensity_prop': '0.512', 'ms1ms2_ratio': '0.309', 'efficiency': '0.218', 'TP': '209', 'FP': '60', 'FN': '103', 'precision': '0.777', 'recall': '0.670', 'f1': '0.719', 'total_rewards': 177.48439570578884, 'invalid_action_count': 3, 'num_ms1_scans': 382, 'num_ms2_scans': 1236}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 44.31799743196504
# steps	 1000 	total rewards	 103.10625878286146
# steps	 1500 	total rewards	 162.53226637438416
# Finished after 1572 timesteps (6.5221052169799805 seconds) with total reward 167.4294524753641
# {'coverage_prop': '0.805', 'intensity_prop': '0.595', 'ms1ms2_ratio': '0.374', 'efficiency': '0.212', 'TP': '202', 'FP': '41', 'FN': '59', 'precision': '0.831', 'recall': '0.774', 'f1': '0.802', 'total_rewards': 167.42945247536414, 'invalid_action_count': 7, 'num_ms1_scans': 428, 'num_ms2_scans': 1144}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 40.01766416704673
# steps	 1000 	total rewards	 103.97655999926117
# steps	 1500 	total rewards	 165.46940664493343
# Finished after 1566 timesteps (4.407928943634033 seconds) with total reward 171.77074097241098
# {'coverage_prop': '0.743', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.383', 'efficiency': '0.174', 'TP': '157', 'FP': '40', 'FN': '68', 'precision': '0.797', 'recall': '0.698', 'f1': '0.744', 'total_rewards': 171.77074097241075, 'invalid_action_count': 3, 'num_ms1_scans': 434, 'num_ms2_scans': 1132}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 53.24416456131732
# steps	 1000 	total rewards	 108.62701208155474
# steps	 1500 	total rewards	 166.0966180012344
# Finished after 1640 timesteps (5.141922950744629 seconds) with total reward 182.3741215321953
# {'coverage_prop': '0.682', 'intensity_prop': '0.470', 'ms1ms2_ratio': '0.281', 'efficiency': '0.249', 'TP': '236', 'FP': '83', 'FN': '149', 'precision': '0.740', 'recall': '0.613', 'f1': '0.670', 'total_rewards': 182.37412153219518, 'invalid_action_count': 4, 'num_ms1_scans': 360, 'num_ms2_scans': 1280}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 40.70704712093472
# steps	 1000 	total rewards	 99.77945358963984
# steps	 1500 	total rewards	 137.3058258414142
# Finished after 1501 timesteps (5.712761163711548 seconds) with total reward 137.3058258414142
# {'coverage_prop': '0.846', 'intensity_prop': '0.630', 'ms1ms2_ratio': '0.498', 'efficiency': '0.198', 'TP': '159', 'FP': '39', 'FN': '36', 'precision': '0.803', 'recall': '0.815', 'f1': '0.809', 'total_rewards': 137.30582584141428, 'invalid_action_count': 8, 'num_ms1_scans': 499, 'num_ms2_scans': 1002}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 45.92115969114276
# steps	 1000 	total rewards	 100.09350777537426
# steps	 1500 	total rewards	 159.14787904591117
# Finished after 1584 timesteps (4.595266103744507 seconds) with total reward 169.26172558715325
# {'coverage_prop': '0.767', 'intensity_prop': '0.558', 'ms1ms2_ratio': '0.356', 'efficiency': '0.211', 'TP': '202', 'FP': '45', 'FN': '75', 'precision': '0.818', 'recall': '0.729', 'f1': '0.771', 'total_rewards': 169.2617255871534, 'invalid_action_count': 1, 'num_ms1_scans': 416, 'num_ms2_scans': 1168}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 43.406325315193776
# steps	 1000 	total rewards	 99.8912879410572
# steps	 1500 	total rewards	 152.97102722444214
# Finished after 1567 timesteps (4.30416202545166 seconds) with total reward 152.65539628478984
# {'coverage_prop': '0.784', 'intensity_prop': '0.585', 'ms1ms2_ratio': '0.382', 'efficiency': '0.214', 'TP': '196', 'FP': '47', 'FN': '67', 'precision': '0.807', 'recall': '0.745', 'f1': '0.775', 'total_rewards': 152.65539628478993, 'invalid_action_count': 12, 'num_ms1_scans': 433, 'num_ms2_scans': 1134}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 50.49759954629012
# steps	 1000 	total rewards	 116.3051768690594
# steps	 1500 	total rewards	 176.22298921407432
# Finished after 1593 timesteps (6.126436948776245 seconds) with total reward 185.57101125879592
# {'coverage_prop': '0.699', 'intensity_prop': '0.484', 'ms1ms2_ratio': '0.343', 'efficiency': '0.203', 'TP': '187', 'FP': '54', 'FN': '104', 'precision': '0.776', 'recall': '0.643', 'f1': '0.703', 'total_rewards': 185.57101125879578, 'invalid_action_count': 1, 'num_ms1_scans': 407, 'num_ms2_scans': 1186}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 44.02483403761571
# steps	 1000 	total rewards	 105.05075462956523
# steps	 1500 	total rewards	 162.2567719959515
# Finished after 1614 timesteps (4.818251848220825 seconds) with total reward 173.87347931233194
# {'coverage_prop': '0.775', 'intensity_prop': '0.541', 'ms1ms2_ratio': '0.314', 'efficiency': '0.250', 'TP': '240', 'FP': '67', 'FN': '89', 'precision': '0.782', 'recall': '0.729', 'f1': '0.755', 'total_rewards': 173.8734793123318, 'invalid_action_count': 5, 'num_ms1_scans': 386, 'num_ms2_scans': 1228}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 34.64598826492545
# steps	 1000 	total rewards	 91.45136720482876
# Finished after 1457 timesteps (4.164489984512329 seconds) with total reward 124.75991436918271
# {'coverage_prop': '0.828', 'intensity_prop': '0.660', 'ms1ms2_ratio': '0.594', 'efficiency': '0.184', 'TP': '149', 'FP': '19', 'FN': '35', 'precision': '0.887', 'recall': '0.810', 'f1': '0.847', 'total_rewards': 124.75991436918247, 'invalid_action_count': 7, 'num_ms1_scans': 543, 'num_ms2_scans': 914}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 40.82037191515382
# steps	 1000 	total rewards	 97.38361610132841
# steps	 1500 	total rewards	 147.93955771374544
# Finished after 1566 timesteps (6.378436088562012 seconds) with total reward 153.8917623314159
# {'coverage_prop': '0.815', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.385', 'efficiency': '0.202', 'TP': '202', 'FP': '27', 'FN': '52', 'precision': '0.882', 'recall': '0.795', 'f1': '0.836', 'total_rewards': 153.8917623314158, 'invalid_action_count': 3, 'num_ms1_scans': 435, 'num_ms2_scans': 1131}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 56.87793652652877
# steps	 1000 	total rewards	 106.35941039025087
# steps	 1500 	total rewards	 162.34112629302973
# Finished after 1669 timesteps (6.0809221267700195 seconds) with total reward 180.99379605423542
# {'coverage_prop': '0.667', 'intensity_prop': '0.439', 'ms1ms2_ratio': '0.247', 'efficiency': '0.246', 'TP': '235', 'FP': '94', 'FN': '164', 'precision': '0.714', 'recall': '0.589', 'f1': '0.646', 'total_rewards': 180.99379605423567, 'invalid_action_count': 19, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 43.0045783335369
# steps	 1000 	total rewards	 97.31025914882628
# steps	 1500 	total rewards	 151.60934850376998
# Finished after 1588 timesteps (4.85962986946106 seconds) with total reward 159.61204794672668
# {'coverage_prop': '0.697', 'intensity_prop': '0.525', 'ms1ms2_ratio': '0.351', 'efficiency': '0.180', 'TP': '173', 'FP': '39', 'FN': '92', 'precision': '0.816', 'recall': '0.653', 'f1': '0.725', 'total_rewards': 159.61204794672673, 'invalid_action_count': 3, 'num_ms1_scans': 413, 'num_ms2_scans': 1175}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 51.65117099992698
# steps	 1000 	total rewards	 118.84586041617706
# steps	 1500 	total rewards	 181.5836690274652
# Finished after 1722 timesteps (8.47727108001709 seconds) with total reward 206.1441352489866
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 206.1441352489867, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 46.85311029469207
# steps	 1000 	total rewards	 103.09151462081203
# steps	 1500 	total rewards	 156.6928677853708
# Finished after 1556 timesteps (8.977090120315552 seconds) with total reward 161.27916819179904
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 161.2791681917992, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 44.155223780708425
# steps	 1000 	total rewards	 110.92023519474637
# steps	 1500 	total rewards	 175.9127966696605
# Finished after 1669 timesteps (8.290616273880005 seconds) with total reward 192.9012530247566
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 192.90125302475656, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 58.395992162824776
# steps	 1000 	total rewards	 124.35172750765155
# steps	 1500 	total rewards	 177.39505715762002
# Finished after 1717 timesteps (8.79063105583191 seconds) with total reward 200.13425730402844
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 200.13425730402827, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 47.82681230882862
# steps	 1000 	total rewards	 118.75408294841554
# steps	 1500 	total rewards	 181.26511567821922
# Finished after 1704 timesteps (10.336336135864258 seconds) with total reward 204.35027573900734
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 204.35027573900697, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 31.370867894729578
# steps	 1000 	total rewards	 81.78260093900248
# Finished after 1408 timesteps (6.713089227676392 seconds) with total reward 109.48011160924551
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 109.48011160924544, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 54.14621595251381
# steps	 1000 	total rewards	 125.81106181587256
# steps	 1500 	total rewards	 181.50270159110732
# Finished after 1744 timesteps (8.754445791244507 seconds) with total reward 206.96838318123415
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 206.96838318123423, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 34.12923267678717
# steps	 1000 	total rewards	 94.07782298754555
# Finished after 1468 timesteps (6.833784103393555 seconds) with total reward 134.24245617085285
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 134.24245617085293, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 52.8147660187399
# steps	 1000 	total rewards	 117.07751065398321
# steps	 1500 	total rewards	 178.48662026216843
# Finished after 1736 timesteps (9.688462734222412 seconds) with total reward 205.11397576080958
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 205.11397576080972, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 47.27318323286255
# steps	 1000 	total rewards	 115.46060577392001
# steps	 1500 	total rewards	 174.15399562262255
# Finished after 1667 timesteps (8.241715908050537 seconds) with total reward 191.47315945404029
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 191.47315945404023, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 52.86866704039748
# steps	 1000 	total rewards	 122.21683907095664
# steps	 1500 	total rewards	 185.16273061622275
# Finished after 1737 timesteps (8.787874937057495 seconds) with total reward 215.32865276655266
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 215.32865276655272, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 40.35188563915891
# steps	 1000 	total rewards	 99.26440951657858
# steps	 1500 	total rewards	 138.06415008363604
# Finished after 1530 timesteps (7.227428197860718 seconds) with total reward 139.55691751761915
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 139.5569175176193, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 44.87356069092196
# steps	 1000 	total rewards	 105.92255428869575
# steps	 1500 	total rewards	 155.74794244532328
# Finished after 1602 timesteps (11.475615978240967 seconds) with total reward 164.91103724890786
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 164.91103724890814, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 42.48924494111827
# steps	 1000 	total rewards	 102.06219786430859
# steps	 1500 	total rewards	 158.04509528543193
# Finished after 1645 timesteps (8.775293827056885 seconds) with total reward 171.18953050035282
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 171.18953050035276, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 37.74959730957396
# steps	 1000 	total rewards	 96.32066768980735
# Finished after 1497 timesteps (7.51355504989624 seconds) with total reward 135.97987089418734
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 135.97987089418737, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 46.09671309707026
# steps	 1000 	total rewards	 112.12416468711884
# steps	 1500 	total rewards	 165.33461039918143
# Finished after 1655 timesteps (9.375842809677124 seconds) with total reward 182.7044569356079
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 182.70445693560802, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 57.71362258982042
# steps	 1000 	total rewards	 127.29216403495546
# steps	 1500 	total rewards	 190.13528966797855
# Finished after 1729 timesteps (13.12251591682434 seconds) with total reward 214.43845299481245
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 214.4384529948125, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 52.2594358819915
# steps	 1000 	total rewards	 117.96993178756057
# steps	 1500 	total rewards	 176.08843013817355
# Finished after 1681 timesteps (8.443528175354004 seconds) with total reward 193.89300729205132
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 193.89300729205124, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 43.47575690462069
# steps	 1000 	total rewards	 108.48836755761869
# steps	 1500 	total rewards	 166.14561907605696
# Finished after 1621 timesteps (8.088107824325562 seconds) with total reward 176.15935043651635
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 176.15935043651675, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 43.363766622667
# steps	 1000 	total rewards	 108.34656053949263
# steps	 1500 	total rewards	 170.86991969785083
# Finished after 1634 timesteps (7.460698843002319 seconds) with total reward 184.01151298587445
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 184.01151298587433, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 56.90097433636849
# steps	 1000 	total rewards	 114.65133496051115
# steps	 1500 	total rewards	 175.46087489487672
# Finished after 1726 timesteps (11.607418060302734 seconds) with total reward 201.2355636418672
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 201.23556364186734, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 36.4394675861717
# steps	 1000 	total rewards	 93.35056950976251
# Finished after 1475 timesteps (7.238713264465332 seconds) with total reward 131.27091700856369
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 131.27091700856366, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 44.0262851482828
# steps	 1000 	total rewards	 103.3474920599275
# steps	 1500 	total rewards	 161.5032874986576
# Finished after 1636 timesteps (7.86008882522583 seconds) with total reward 174.84369426765096
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 174.8436942676509, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 46.73525847152733
# steps	 1000 	total rewards	 107.49149946933866
# steps	 1500 	total rewards	 157.8696487295171
# Finished after 1575 timesteps (7.525622129440308 seconds) with total reward 162.81060415826593
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 162.81060415826593, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 47.68606878837535
# steps	 1000 	total rewards	 117.21079005856605
# steps	 1500 	total rewards	 179.3322711548713
# Finished after 1681 timesteps (7.864680051803589 seconds) with total reward 197.64921165093534
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 197.64921165093529, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 48.119799471510284
# steps	 1000 	total rewards	 110.28403488320416
# steps	 1500 	total rewards	 175.13402948470977
# Finished after 1679 timesteps (11.487942218780518 seconds) with total reward 192.78942209856538
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 192.7894220985652, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 33.00424762352138
# steps	 1000 	total rewards	 92.6904018409183
# Finished after 1465 timesteps (7.692942142486572 seconds) with total reward 128.3011255773961
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 128.3011255773961, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 40.50926145358593
# steps	 1000 	total rewards	 100.05594455781672
# steps	 1500 	total rewards	 152.08531463202684
# Finished after 1564 timesteps (7.627691984176636 seconds) with total reward 158.75669226510237
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 158.75669226510252, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 58.2168430520744
# steps	 1000 	total rewards	 118.43683535074356
# steps	 1500 	total rewards	 185.19916823653563
# Finished after 1749 timesteps (9.761305809020996 seconds) with total reward 215.86385726818622
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 215.863857268186, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 44.96094591328844
# steps	 1000 	total rewards	 102.22228964486416
# steps	 1500 	total rewards	 158.4481570830169
# Finished after 1657 timesteps (7.676146984100342 seconds) with total reward 173.55584192782328
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 173.55584192782334, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fce760b1750>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fce77d6ae90>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fce77d8c070>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.25,
#   'beta': 0.75}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.705', 'ms1ms2_ratio': '0.794', 'efficiency': '0.539', 'TP': '359', 'FP': '58', 'FN': '9', 'precision': '0.861', 'recall': '0.976', 'f1': '0.915'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '219', 'FP': '33', 'FN': '10', 'precision': '0.869', 'recall': '0.956', 'f1': '0.911'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.713', 'ms1ms2_ratio': '0.743', 'efficiency': '0.547', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.776', 'efficiency': '0.552', 'TP': '366', 'FP': '67', 'FN': '4', 'precision': '0.845', 'recall': '0.989', 'f1': '0.912'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.716', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.679', 'efficiency': '0.540', 'TP': '396', 'FP': '62', 'FN': '20', 'precision': '0.865', 'recall': '0.952', 'f1': '0.906'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.720', 'ms1ms2_ratio': '2.067', 'efficiency': '0.503', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.815', 'efficiency': '0.531', 'TP': '350', 'FP': '54', 'FN': '20', 'precision': '0.866', 'recall': '0.946', 'f1': '0.904'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.682', 'efficiency': '0.505', 'TP': '381', 'FP': '46', 'FN': '16', 'precision': '0.892', 'recall': '0.960', 'f1': '0.925'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.667', 'ms1ms2_ratio': '1.597', 'efficiency': '0.499', 'TP': '196', 'FP': '42', 'FN': '13', 'precision': '0.824', 'recall': '0.938', 'f1': '0.877'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.687', 'ms1ms2_ratio': '1.267', 'efficiency': '0.512', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.861', 'efficiency': '0.541', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '428', 'FP': '59', 'FN': '11', 'precision': '0.879', 'recall': '0.975', 'f1': '0.924'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.984', 'efficiency': '0.534', 'TP': '307', 'FP': '53', 'FN': '12', 'precision': '0.853', 'recall': '0.962', 'f1': '0.904'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '252', 'FP': '40', 'FN': '10', 'precision': '0.863', 'recall': '0.962', 'f1': '0.910'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '221', 'FP': '39', 'FN': '5', 'precision': '0.850', 'recall': '0.978', 'f1': '0.909'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '391', 'FP': '59', 'FN': '18', 'precision': '0.869', 'recall': '0.956', 'f1': '0.910'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.714', 'ms1ms2_ratio': '1.182', 'efficiency': '0.524', 'TP': '274', 'FP': '38', 'FN': '10', 'precision': '0.878', 'recall': '0.965', 'f1': '0.919'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.717', 'ms1ms2_ratio': '0.958', 'efficiency': '0.494', 'TP': '288', 'FP': '51', 'FN': '6', 'precision': '0.850', 'recall': '0.980', 'f1': '0.910'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.851', 'efficiency': '0.528', 'TP': '339', 'FP': '52', 'FN': '5', 'precision': '0.867', 'recall': '0.985', 'f1': '0.922'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.377', 'efficiency': '0.510', 'TP': '241', 'FP': '31', 'FN': '9', 'precision': '0.886', 'recall': '0.964', 'f1': '0.923'}
#
# Episode 28 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.592', 'efficiency': '0.522', 'TP': '403', 'FP': '75', 'FN': '15', 'precision': '0.843', 'recall': '0.964', 'f1': '0.900'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.735', 'ms1ms2_ratio': '1.199', 'efficiency': '0.501', 'TP': '268', 'FP': '27', 'FN': '9', 'precision': '0.908', 'recall': '0.968', 'f1': '0.937'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1890.883187                1911.0          0.310           0.064
# 1  random   -1899.319365                1918.0          0.286           0.056
# 2  random   -1835.400227                1865.0          0.409           0.104
# 3  random   -1822.433984                1856.0          0.398           0.111
# 4  random   -1908.390515                1927.0          0.245           0.040
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.067      0.159   0.067  0.094
# 1          0.006       0.038      0.147   0.056  0.081
# 2          0.008       0.082      0.217   0.131  0.163
# 3          0.008       0.091      0.244   0.139  0.177
# 4          0.002       0.054      0.140   0.043  0.066

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     187.225297                   7.0          0.674           0.448
# 31    DQN     175.974065                   3.0          0.809           0.608
# 32    DQN     168.066617                  11.0          0.741           0.499
# 33    DQN     172.723446                   4.0          0.730           0.520
# 34    DQN     173.986004                   8.0          0.767           0.526
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.291       0.227      0.725   0.599  0.656
# 31          0.399       0.190      0.844   0.782  0.812
# 32          0.312       0.237      0.733   0.677  0.704
# 33          0.292       0.261      0.782   0.679  0.727
# 34          0.301       0.268      0.755   0.713  0.733

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
