# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.00
env_beta = 0.00
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-23 12:47:29.690 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb2a218a8f0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb2a59b6c80>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb2a59d3e20>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.0,
#    'beta': 0.0}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_5.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb2a218a8f0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb2a59b6c80>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb2a59d3e20>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb2a218a8f0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb2a59b6c80>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb2a59d3e20>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
horizon = 1
out_dir = 'evaluation_5.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, 'best_model.zip')
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E5_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 61.941009466510764
# steps	 1000 	total rewards	 144.80656569720423
# steps	 1500 	total rewards	 231.204363830607
# Finished after 1792 timesteps (2.603867769241333 seconds) with total reward 260.72495310512613
# {'coverage_prop': '0.934', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.131', 'efficiency': '0.251', 'TP': '329', 'FP': '69', 'FN': '28', 'precision': '0.827', 'recall': '0.922', 'f1': '0.872', 'total_rewards': 260.72495310512596, 'invalid_action_count': 0, 'num_ms1_scans': 208, 'num_ms2_scans': 1584}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 56.938686373112745
# steps	 1000 	total rewards	 120.65617463017193
# steps	 1500 	total rewards	 178.58398327814876
# Finished after 1710 timesteps (1.9568421840667725 seconds) with total reward 192.93634214269412
# {'coverage_prop': '0.935', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.204', 'efficiency': '0.173', 'TP': '230', 'FP': '15', 'FN': '17', 'precision': '0.939', 'recall': '0.931', 'f1': '0.935', 'total_rewards': 192.93634214269414, 'invalid_action_count': 0, 'num_ms1_scans': 290, 'num_ms2_scans': 1420}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 53.17524006157872
# steps	 1000 	total rewards	 139.24543418062288
# steps	 1500 	total rewards	 220.74631634279092
# Finished after 1760 timesteps (2.27392578125 seconds) with total reward 245.790711924362
# {'coverage_prop': '0.934', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.158', 'efficiency': '0.242', 'TP': '304', 'FP': '64', 'FN': '26', 'precision': '0.826', 'recall': '0.921', 'f1': '0.871', 'total_rewards': 245.79071192436186, 'invalid_action_count': 0, 'num_ms1_scans': 240, 'num_ms2_scans': 1520}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 66.07664166932021
# steps	 1000 	total rewards	 164.83102339617244
# steps	 1500 	total rewards	 233.4209600625099
# Finished after 1789 timesteps (2.5950729846954346 seconds) with total reward 265.9579092127038
# {'coverage_prop': '0.951', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.134', 'efficiency': '0.272', 'TP': '372', 'FP': '58', 'FN': '22', 'precision': '0.865', 'recall': '0.944', 'f1': '0.903', 'total_rewards': 265.9579092127037, 'invalid_action_count': 0, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 55.5691590847095
# steps	 1000 	total rewards	 145.1572591386149
# steps	 1500 	total rewards	 226.97313604938464
# Finished after 1779 timesteps (2.571099042892456 seconds) with total reward 254.59968358581307
# {'coverage_prop': '0.961', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.142', 'efficiency': '0.270', 'TP': '345', 'FP': '75', 'FN': '17', 'precision': '0.821', 'recall': '0.953', 'f1': '0.882', 'total_rewards': 254.59968358581307, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 34.60496708132189
# steps	 1000 	total rewards	 88.54304767196803
# steps	 1500 	total rewards	 123.28641010456353
# Finished after 1629 timesteps (2.5336079597473145 seconds) with total reward 133.6420162265315
# {'coverage_prop': '0.945', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.295', 'efficiency': '0.150', 'TP': '181', 'FP': '8', 'FN': '11', 'precision': '0.958', 'recall': '0.943', 'f1': '0.950', 'total_rewards': 133.64201622653158, 'invalid_action_count': 0, 'num_ms1_scans': 371, 'num_ms2_scans': 1258}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 72.10633672322324
# steps	 1000 	total rewards	 165.25385357425353
# steps	 1500 	total rewards	 235.98157840262672
# Finished after 1802 timesteps (2.6569809913635254 seconds) with total reward 266.8201592443718
# {'coverage_prop': '0.921', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.123', 'efficiency': '0.274', 'TP': '365', 'FP': '75', 'FN': '38', 'precision': '0.830', 'recall': '0.906', 'f1': '0.866', 'total_rewards': 266.8201592443716, 'invalid_action_count': 0, 'num_ms1_scans': 198, 'num_ms2_scans': 1604}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 33.807739218848475
# steps	 1000 	total rewards	 103.51265431594135
# steps	 1500 	total rewards	 141.12067706238008
# Finished after 1650 timesteps (2.0657079219818115 seconds) with total reward 151.1580948949089
# {'coverage_prop': '0.946', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.269', 'efficiency': '0.148', 'TP': '185', 'FP': '8', 'FN': '11', 'precision': '0.959', 'recall': '0.944', 'f1': '0.951', 'total_rewards': 151.15809489490886, 'invalid_action_count': 0, 'num_ms1_scans': 350, 'num_ms2_scans': 1300}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 67.91156000270053
# steps	 1000 	total rewards	 149.1549918397927
# steps	 1500 	total rewards	 222.4409074221465
# Finished after 1795 timesteps (2.923330783843994 seconds) with total reward 256.510549091411
# {'coverage_prop': '0.934', 'intensity_prop': '0.700', 'ms1ms2_ratio': '0.129', 'efficiency': '0.249', 'TP': '338', 'FP': '58', 'FN': '28', 'precision': '0.854', 'recall': '0.923', 'f1': '0.887', 'total_rewards': 256.510549091411, 'invalid_action_count': 0, 'num_ms1_scans': 205, 'num_ms2_scans': 1590}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 56.86153891108732
# steps	 1000 	total rewards	 137.1791093658952
# steps	 1500 	total rewards	 216.54243199687772
# Finished after 1779 timesteps (2.0362207889556885 seconds) with total reward 239.26081274859612
# {'coverage_prop': '0.948', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.142', 'efficiency': '0.234', 'TP': '317', 'FP': '47', 'FN': '20', 'precision': '0.871', 'recall': '0.941', 'f1': '0.904', 'total_rewards': 239.260812748596, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 60.897303688369284
# steps	 1000 	total rewards	 150.94760856147306
# steps	 1500 	total rewards	 249.22157516006246
# Finished after 1803 timesteps (2.7913978099823 seconds) with total reward 280.4978912452257
# {'coverage_prop': '0.946', 'intensity_prop': '0.681', 'ms1ms2_ratio': '0.123', 'efficiency': '0.261', 'TP': '336', 'FP': '83', 'FN': '24', 'precision': '0.802', 'recall': '0.933', 'f1': '0.863', 'total_rewards': 280.4978912452257, 'invalid_action_count': 0, 'num_ms1_scans': 197, 'num_ms2_scans': 1606}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 52.91070958085999
# steps	 1000 	total rewards	 115.74889214028914
# steps	 1500 	total rewards	 155.90105299121367
# Finished after 1694 timesteps (2.0077669620513916 seconds) with total reward 169.45419030173343
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.221', 'efficiency': '0.170', 'TP': '216', 'FP': '20', 'FN': '13', 'precision': '0.915', 'recall': '0.943', 'f1': '0.929', 'total_rewards': 169.4541903017335, 'invalid_action_count': 0, 'num_ms1_scans': 307, 'num_ms2_scans': 1387}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 43.60874897376682
# steps	 1000 	total rewards	 106.7843337264002
# steps	 1500 	total rewards	 155.3213340914636
# Finished after 1736 timesteps (2.7767391204833984 seconds) with total reward 172.8542079549083
# {'coverage_prop': '0.944', 'intensity_prop': '0.739', 'ms1ms2_ratio': '0.180', 'efficiency': '0.161', 'TP': '208', 'FP': '29', 'FN': '14', 'precision': '0.878', 'recall': '0.937', 'f1': '0.906', 'total_rewards': 172.85420795490842, 'invalid_action_count': 0, 'num_ms1_scans': 265, 'num_ms2_scans': 1471}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 40.448443456644576
# steps	 1000 	total rewards	 98.78885314880004
# steps	 1500 	total rewards	 170.3897944412198
# Finished after 1751 timesteps (2.1519620418548584 seconds) with total reward 189.1615023810785
# {'coverage_prop': '0.950', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.166', 'efficiency': '0.190', 'TP': '247', 'FP': '38', 'FN': '15', 'precision': '0.867', 'recall': '0.943', 'f1': '0.903', 'total_rewards': 189.16150238107832, 'invalid_action_count': 0, 'num_ms1_scans': 249, 'num_ms2_scans': 1502}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 38.60949749138459
# steps	 1000 	total rewards	 92.79923608391829
# steps	 1500 	total rewards	 137.2806580984411
# Finished after 1674 timesteps (2.6345043182373047 seconds) with total reward 149.61858455806606
# {'coverage_prop': '0.947', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.242', 'efficiency': '0.145', 'TP': '178', 'FP': '17', 'FN': '11', 'precision': '0.913', 'recall': '0.942', 'f1': '0.927', 'total_rewards': 149.61858455806626, 'invalid_action_count': 0, 'num_ms1_scans': 326, 'num_ms2_scans': 1348}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 51.80244503603636
# steps	 1000 	total rewards	 135.65617665028466
# steps	 1500 	total rewards	 217.6805005073367
# Finished after 1770 timesteps (2.2553369998931885 seconds) with total reward 251.28284770336643
# {'coverage_prop': '0.956', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.150', 'efficiency': '0.253', 'TP': '339', 'FP': '50', 'FN': '18', 'precision': '0.871', 'recall': '0.950', 'f1': '0.909', 'total_rewards': 251.2828477033666, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1539}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 76.46152683436785
# steps	 1000 	total rewards	 176.11248381405983
# steps	 1500 	total rewards	 262.905117475407
# Finished after 1802 timesteps (2.2890102863311768 seconds) with total reward 292.3195459532294
# {'coverage_prop': '0.944', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.123', 'efficiency': '0.293', 'TP': '390', 'FP': '80', 'FN': '28', 'precision': '0.830', 'recall': '0.933', 'f1': '0.878', 'total_rewards': 292.31954595322895, 'invalid_action_count': 0, 'num_ms1_scans': 198, 'num_ms2_scans': 1604}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 66.96687923864015
# steps	 1000 	total rewards	 142.33544855542448
# steps	 1500 	total rewards	 213.00581112907463
# Finished after 1773 timesteps (2.869884967803955 seconds) with total reward 237.2302011223465
# {'coverage_prop': '0.949', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.148', 'efficiency': '0.228', 'TP': '300', 'FP': '53', 'FN': '19', 'precision': '0.850', 'recall': '0.940', 'f1': '0.893', 'total_rewards': 237.23020112234678, 'invalid_action_count': 0, 'num_ms1_scans': 228, 'num_ms2_scans': 1545}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 51.341904102151744
# steps	 1000 	total rewards	 125.9319582233837
# steps	 1500 	total rewards	 187.62137272716245
# Finished after 1736 timesteps (2.253661870956421 seconds) with total reward 208.16912553719166
# {'coverage_prop': '0.950', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.179', 'efficiency': '0.195', 'TP': '256', 'FP': '31', 'FN': '15', 'precision': '0.892', 'recall': '0.945', 'f1': '0.918', 'total_rewards': 208.1691255371915, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 47.415011433640196
# steps	 1000 	total rewards	 122.83386078510658
# steps	 1500 	total rewards	 173.24640624439368
# Finished after 1742 timesteps (2.0099520683288574 seconds) with total reward 187.31293062059393
# {'coverage_prop': '0.962', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.174', 'efficiency': '0.172', 'TP': '231', 'FP': '24', 'FN': '10', 'precision': '0.906', 'recall': '0.959', 'f1': '0.931', 'total_rewards': 187.31293062059407, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 1484}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 69.85016285549774
# steps	 1000 	total rewards	 162.97571401167528
# steps	 1500 	total rewards	 235.35513633968753
# Finished after 1799 timesteps (2.28877329826355 seconds) with total reward 267.115162620884
# {'coverage_prop': '0.921', 'intensity_prop': '0.682', 'ms1ms2_ratio': '0.126', 'efficiency': '0.270', 'TP': '361', 'FP': '70', 'FN': '37', 'precision': '0.838', 'recall': '0.907', 'f1': '0.871', 'total_rewards': 267.11516262088423, 'invalid_action_count': 0, 'num_ms1_scans': 201, 'num_ms2_scans': 1598}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 41.09475717342056
# steps	 1000 	total rewards	 101.4243030128111
# steps	 1500 	total rewards	 157.91932978383383
# Finished after 1677 timesteps (2.0213279724121094 seconds) with total reward 171.29123141646227
# {'coverage_prop': '0.944', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.239', 'efficiency': '0.163', 'TP': '201', 'FP': '20', 'FN': '13', 'precision': '0.910', 'recall': '0.939', 'f1': '0.924', 'total_rewards': 171.2912314164621, 'invalid_action_count': 0, 'num_ms1_scans': 323, 'num_ms2_scans': 1354}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 51.768672168549976
# steps	 1000 	total rewards	 126.4943317033759
# steps	 1500 	total rewards	 180.86431153024705
# Finished after 1742 timesteps (3.0963921546936035 seconds) with total reward 205.61520382089884
# {'coverage_prop': '0.938', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.174', 'efficiency': '0.204', 'TP': '265', 'FP': '37', 'FN': '20', 'precision': '0.877', 'recall': '0.930', 'f1': '0.903', 'total_rewards': 205.6152038208984, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 1484}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 57.009189279587375
# steps	 1000 	total rewards	 124.27660274523181
# steps	 1500 	total rewards	 183.45940286388338
# Finished after 1700 timesteps (2.07704496383667 seconds) with total reward 201.3509851517435
# {'coverage_prop': '0.923', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.214', 'efficiency': '0.204', 'TP': '245', 'FP': '41', 'FN': '24', 'precision': '0.857', 'recall': '0.911', 'f1': '0.883', 'total_rewards': 201.3509851517436, 'invalid_action_count': 0, 'num_ms1_scans': 300, 'num_ms2_scans': 1400}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 52.6385060750832
# steps	 1000 	total rewards	 142.3605662551398
# steps	 1500 	total rewards	 202.957062570623
# Finished after 1761 timesteps (2.0440597534179688 seconds) with total reward 230.4464880436766
# {'coverage_prop': '0.971', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.157', 'efficiency': '0.220', 'TP': '295', 'FP': '40', 'FN': '10', 'precision': '0.881', 'recall': '0.967', 'f1': '0.922', 'total_rewards': 230.4464880436764, 'invalid_action_count': 0, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 55.47389563109382
# steps	 1000 	total rewards	 126.69779115464455
# steps	 1500 	total rewards	 212.6632059952156
# Finished after 1781 timesteps (4.599334001541138 seconds) with total reward 248.32945883360279
# {'coverage_prop': '0.949', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.140', 'efficiency': '0.241', 'TP': '331', 'FP': '45', 'FN': '20', 'precision': '0.880', 'recall': '0.943', 'f1': '0.911', 'total_rewards': 248.32945883360284, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 30.947123983887742
# steps	 1000 	total rewards	 96.08514224410105
# steps	 1500 	total rewards	 141.49333389595313
# Finished after 1661 timesteps (3.365126132965088 seconds) with total reward 148.50217215327433
# {'coverage_prop': '0.956', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.257', 'efficiency': '0.147', 'TP': '183', 'FP': '11', 'FN': '9', 'precision': '0.943', 'recall': '0.953', 'f1': '0.948', 'total_rewards': 148.50217215327396, 'invalid_action_count': 0, 'num_ms1_scans': 340, 'num_ms2_scans': 1321}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 42.52351160034681
# steps	 1000 	total rewards	 110.59950124362942
# steps	 1500 	total rewards	 172.62318255971198
# Finished after 1705 timesteps (2.1758549213409424 seconds) with total reward 197.3440780113504
# {'coverage_prop': '0.961', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.209', 'efficiency': '0.191', 'TP': '245', 'FP': '25', 'FN': '11', 'precision': '0.907', 'recall': '0.957', 'f1': '0.932', 'total_rewards': 197.3440780113505, 'invalid_action_count': 0, 'num_ms1_scans': 295, 'num_ms2_scans': 1410}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 71.19315854773396
# steps	 1000 	total rewards	 148.8719549360681
# steps	 1500 	total rewards	 234.11928679331498
# Finished after 1813 timesteps (2.510087251663208 seconds) with total reward 274.99366450669015
# {'coverage_prop': '0.915', 'intensity_prop': '0.636', 'ms1ms2_ratio': '0.115', 'efficiency': '0.277', 'TP': '357', 'FP': '94', 'FN': '42', 'precision': '0.792', 'recall': '0.895', 'f1': '0.840', 'total_rewards': 274.9936645066904, 'invalid_action_count': 0, 'num_ms1_scans': 187, 'num_ms2_scans': 1626}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 48.53662758615596
# steps	 1000 	total rewards	 120.86137101934312
# steps	 1500 	total rewards	 176.35462390849025
# Finished after 1736 timesteps (4.610447883605957 seconds) with total reward 194.5485617679388
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.179', 'efficiency': '0.198', 'TP': '264', 'FP': '27', 'FN': '13', 'precision': '0.907', 'recall': '0.953', 'f1': '0.930', 'total_rewards': 194.54856176793893, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# method = PPO max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 60.35851702118173
# steps	 1000 	total rewards	 137.7200235247838
# steps	 1500 	total rewards	 230.9736278876626
# Finished after 1858 timesteps (5.715950965881348 seconds) with total reward 270.59818502770173
# {'coverage_prop': '0.958', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.083', 'efficiency': '0.238', 'TP': '350', 'FP': '58', 'FN': '18', 'precision': '0.858', 'recall': '0.951', 'f1': '0.902', 'total_rewards': 270.5981850277018, 'invalid_action_count': 0, 'num_ms1_scans': 142, 'num_ms2_scans': 1716}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 55.018374706661795
# steps	 1000 	total rewards	 119.4670604856503
# steps	 1500 	total rewards	 175.27161811086583
# Finished after 1791 timesteps (5.0937819480896 seconds) with total reward 197.28807576089054
# {'coverage_prop': '0.950', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.132', 'efficiency': '0.157', 'TP': '229', 'FP': '20', 'FN': '13', 'precision': '0.920', 'recall': '0.946', 'f1': '0.933', 'total_rewards': 197.28807576089025, 'invalid_action_count': 0, 'num_ms1_scans': 209, 'num_ms2_scans': 1582}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 51.305081441193515
# steps	 1000 	total rewards	 132.57777141082693
# steps	 1500 	total rewards	 219.8538448505904
# Finished after 1837 timesteps (5.816279888153076 seconds) with total reward 256.551945814394
# {'coverage_prop': '0.957', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.097', 'efficiency': '0.225', 'TP': '316', 'FP': '61', 'FN': '17', 'precision': '0.838', 'recall': '0.949', 'f1': '0.890', 'total_rewards': 256.55194581439434, 'invalid_action_count': 0, 'num_ms1_scans': 163, 'num_ms2_scans': 1674}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 66.40685130677821
# steps	 1000 	total rewards	 156.12824044490233
# steps	 1500 	total rewards	 231.8564525876145
# Finished after 1856 timesteps (6.482280969619751 seconds) with total reward 272.10645703987336
# {'coverage_prop': '0.951', 'intensity_prop': '0.737', 'ms1ms2_ratio': '0.084', 'efficiency': '0.251', 'TP': '379', 'FP': '51', 'FN': '22', 'precision': '0.881', 'recall': '0.945', 'f1': '0.912', 'total_rewards': 272.10645703987353, 'invalid_action_count': 0, 'num_ms1_scans': 144, 'num_ms2_scans': 1712}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 55.81798156953877
# steps	 1000 	total rewards	 146.44860430890736
# steps	 1500 	total rewards	 228.56418109645915
# Finished after 1851 timesteps (5.406867980957031 seconds) with total reward 258.93509302079883
# {'coverage_prop': '0.973', 'intensity_prop': '0.718', 'ms1ms2_ratio': '0.088', 'efficiency': '0.250', 'TP': '362', 'FP': '63', 'FN': '12', 'precision': '0.852', 'recall': '0.968', 'f1': '0.906', 'total_rewards': 258.93509302079866, 'invalid_action_count': 0, 'num_ms1_scans': 150, 'num_ms2_scans': 1701}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 31.36088631770387
# steps	 1000 	total rewards	 83.02189471709193
# steps	 1500 	total rewards	 121.32828809171039
# Finished after 1737 timesteps (4.303220987319946 seconds) with total reward 134.37054516595356
# {'coverage_prop': '0.950', 'intensity_prop': '0.817', 'ms1ms2_ratio': '0.178', 'efficiency': '0.129', 'TP': '180', 'FP': '10', 'FN': '10', 'precision': '0.947', 'recall': '0.947', 'f1': '0.947', 'total_rewards': 134.37054516595364, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.49149844456524
# steps	 1000 	total rewards	 167.16358520442827
# steps	 1500 	total rewards	 248.85044816914439
# Finished after 1863 timesteps (7.036756992340088 seconds) with total reward 282.9668093013586
# {'coverage_prop': '0.956', 'intensity_prop': '0.692', 'ms1ms2_ratio': '0.079', 'efficiency': '0.265', 'TP': '375', 'FP': '82', 'FN': '21', 'precision': '0.821', 'recall': '0.947', 'f1': '0.879', 'total_rewards': 282.96680930135847, 'invalid_action_count': 0, 'num_ms1_scans': 137, 'num_ms2_scans': 1726}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 32.727452226411714
# steps	 1000 	total rewards	 94.5103789488274
# steps	 1500 	total rewards	 139.89142890833557
# Finished after 1757 timesteps (6.005505084991455 seconds) with total reward 156.12997864122968
# {'coverage_prop': '0.961', 'intensity_prop': '0.797', 'ms1ms2_ratio': '0.161', 'efficiency': '0.130', 'TP': '182', 'FP': '14', 'FN': '8', 'precision': '0.929', 'recall': '0.958', 'f1': '0.943', 'total_rewards': 156.12997864122954, 'invalid_action_count': 0, 'num_ms1_scans': 244, 'num_ms2_scans': 1513}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 63.59791825360784
# steps	 1000 	total rewards	 140.81209259566089
# steps	 1500 	total rewards	 224.51115694122836
# Finished after 1868 timesteps (7.2232208251953125 seconds) with total reward 263.3880063826918
# {'coverage_prop': '0.941', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.076', 'efficiency': '0.230', 'TP': '350', 'FP': '49', 'FN': '25', 'precision': '0.877', 'recall': '0.933', 'f1': '0.904', 'total_rewards': 263.38800638269186, 'invalid_action_count': 0, 'num_ms1_scans': 132, 'num_ms2_scans': 1736}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 54.496405542940465
# steps	 1000 	total rewards	 128.24727413397045
# steps	 1500 	total rewards	 214.26464573565994
# Finished after 1846 timesteps (4.949197053909302 seconds) with total reward 243.33156951671623
# {'coverage_prop': '0.953', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.091', 'efficiency': '0.216', 'TP': '320', 'FP': '46', 'FN': '18', 'precision': '0.874', 'recall': '0.947', 'f1': '0.909', 'total_rewards': 243.33156951671614, 'invalid_action_count': 0, 'num_ms1_scans': 154, 'num_ms2_scans': 1692}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 59.85176081378852
# steps	 1000 	total rewards	 145.87461626611986
# steps	 1500 	total rewards	 248.6270297548564
# Finished after 1875 timesteps (7.010354995727539 seconds) with total reward 287.7138194792544
# {'coverage_prop': '0.959', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.071', 'efficiency': '0.243', 'TP': '359', 'FP': '66', 'FN': '18', 'precision': '0.845', 'recall': '0.952', 'f1': '0.895', 'total_rewards': 287.7138194792548, 'invalid_action_count': 0, 'num_ms1_scans': 125, 'num_ms2_scans': 1750}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 50.169787450042485
# steps	 1000 	total rewards	 109.37056321629589
# steps	 1500 	total rewards	 153.68737985751596
# Finished after 1783 timesteps (4.345448970794678 seconds) with total reward 173.7622519655933
# {'coverage_prop': '0.956', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.139', 'efficiency': '0.152', 'TP': '218', 'FP': '20', 'FN': '11', 'precision': '0.916', 'recall': '0.952', 'f1': '0.934', 'total_rewards': 173.7622519655931, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 42.79206518985142
# steps	 1000 	total rewards	 97.87328166205475
# steps	 1500 	total rewards	 153.90595272966704
# Finished after 1824 timesteps (4.4833128452301025 seconds) with total reward 175.53848683972433
# {'coverage_prop': '0.944', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.107', 'efficiency': '0.144', 'TP': '213', 'FP': '24', 'FN': '14', 'precision': '0.899', 'recall': '0.938', 'f1': '0.918', 'total_rewards': 175.5384868397242, 'invalid_action_count': 0, 'num_ms1_scans': 176, 'num_ms2_scans': 1648}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 38.32284465130793
# steps	 1000 	total rewards	 95.3442501764448
# steps	 1500 	total rewards	 166.74957374495938
# Finished after 1832 timesteps (6.203181266784668 seconds) with total reward 188.61852471251154
# {'coverage_prop': '0.947', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.102', 'efficiency': '0.171', 'TP': '250', 'FP': '34', 'FN': '16', 'precision': '0.880', 'recall': '0.940', 'f1': '0.909', 'total_rewards': 188.618524712511, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1663}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 34.77856013622359
# steps	 1000 	total rewards	 86.75939834039036
# steps	 1500 	total rewards	 135.32475640630457
# Finished after 1777 timesteps (4.425216913223267 seconds) with total reward 151.51074420386448
# {'coverage_prop': '0.951', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.144', 'efficiency': '0.126', 'TP': '179', 'FP': '17', 'FN': '10', 'precision': '0.913', 'recall': '0.947', 'f1': '0.930', 'total_rewards': 151.51074420386476, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 49.20656531861164
# steps	 1000 	total rewards	 132.1608820633018
# steps	 1500 	total rewards	 217.01018375347746
# Finished after 1837 timesteps (4.735572099685669 seconds) with total reward 255.1202694344442
# {'coverage_prop': '0.966', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.097', 'efficiency': '0.235', 'TP': '345', 'FP': '48', 'FN': '14', 'precision': '0.878', 'recall': '0.961', 'f1': '0.918', 'total_rewards': 255.12026943444428, 'invalid_action_count': 0, 'num_ms1_scans': 163, 'num_ms2_scans': 1674}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 76.01223781208672
# steps	 1000 	total rewards	 173.3165092419318
# steps	 1500 	total rewards	 267.71556206749233
# Finished after 1865 timesteps (4.711951017379761 seconds) with total reward 308.3024351155462
# {'coverage_prop': '0.964', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.078', 'efficiency': '0.277', 'TP': '408', 'FP': '72', 'FN': '18', 'precision': '0.850', 'recall': '0.958', 'f1': '0.901', 'total_rewards': 308.302435115546, 'invalid_action_count': 0, 'num_ms1_scans': 135, 'num_ms2_scans': 1730}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 63.22244540567636
# steps	 1000 	total rewards	 141.14271421330278
# steps	 1500 	total rewards	 213.90802909419466
# Finished after 1844 timesteps (4.28550124168396 seconds) with total reward 242.24192864711503
# {'coverage_prop': '0.957', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.092', 'efficiency': '0.211', 'TP': '304', 'FP': '52', 'FN': '16', 'precision': '0.854', 'recall': '0.950', 'f1': '0.899', 'total_rewards': 242.24192864711523, 'invalid_action_count': 0, 'num_ms1_scans': 156, 'num_ms2_scans': 1688}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.23273720219767
# steps	 1000 	total rewards	 115.87823314066449
# steps	 1500 	total rewards	 179.76246496001048
# Finished after 1816 timesteps (4.238461971282959 seconds) with total reward 211.59970704929765
# {'coverage_prop': '0.967', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.113', 'efficiency': '0.179', 'TP': '258', 'FP': '34', 'FN': '10', 'precision': '0.884', 'recall': '0.963', 'f1': '0.921', 'total_rewards': 211.5997070492979, 'invalid_action_count': 0, 'num_ms1_scans': 185, 'num_ms2_scans': 1631}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 46.90235632199887
# steps	 1000 	total rewards	 117.74931700320505
# steps	 1500 	total rewards	 171.7416383057852
# Finished after 1819 timesteps (6.239410877227783 seconds) with total reward 193.24621576141152
# {'coverage_prop': '0.977', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.111', 'efficiency': '0.158', 'TP': '230', 'FP': '29', 'FN': '6', 'precision': '0.888', 'recall': '0.975', 'f1': '0.929', 'total_rewards': 193.24621576141135, 'invalid_action_count': 0, 'num_ms1_scans': 181, 'num_ms2_scans': 1638}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 68.19708911252938
# steps	 1000 	total rewards	 164.60987640852954
# steps	 1500 	total rewards	 247.48444437900082
# Finished after 1864 timesteps (5.639831781387329 seconds) with total reward 284.6451362370502
# {'coverage_prop': '0.953', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.079', 'efficiency': '0.258', 'TP': '364', 'FP': '82', 'FN': '22', 'precision': '0.816', 'recall': '0.943', 'f1': '0.875', 'total_rewards': 284.6451362370497, 'invalid_action_count': 0, 'num_ms1_scans': 136, 'num_ms2_scans': 1728}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 41.00083356651276
# steps	 1000 	total rewards	 94.33020948103753
# steps	 1500 	total rewards	 153.68162230778535
# Finished after 1762 timesteps (4.614658832550049 seconds) with total reward 171.53926197993596
# {'coverage_prop': '0.949', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.156', 'efficiency': '0.146', 'TP': '201', 'FP': '21', 'FN': '12', 'precision': '0.905', 'recall': '0.944', 'f1': '0.924', 'total_rewards': 171.53926197993607, 'invalid_action_count': 0, 'num_ms1_scans': 238, 'num_ms2_scans': 1524}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 50.4896995851728
# steps	 1000 	total rewards	 119.42647756188849
# steps	 1500 	total rewards	 180.69512260243008
# Finished after 1828 timesteps (4.539379835128784 seconds) with total reward 211.8156500107787
# {'coverage_prop': '0.953', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.104', 'efficiency': '0.185', 'TP': '274', 'FP': '33', 'FN': '15', 'precision': '0.893', 'recall': '0.948', 'f1': '0.919', 'total_rewards': 211.8156500107788, 'invalid_action_count': 0, 'num_ms1_scans': 172, 'num_ms2_scans': 1656}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 57.09058845912905
# steps	 1000 	total rewards	 122.0292520628337
# steps	 1500 	total rewards	 184.4999731834974
# Finished after 1799 timesteps (5.0080132484436035 seconds) with total reward 207.3838729636242
# {'coverage_prop': '0.945', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.126', 'efficiency': '0.183', 'TP': '260', 'FP': '33', 'FN': '17', 'precision': '0.887', 'recall': '0.939', 'f1': '0.912', 'total_rewards': 207.3838729636241, 'invalid_action_count': 0, 'num_ms1_scans': 201, 'num_ms2_scans': 1598}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 48.59992075459172
# steps	 1000 	total rewards	 132.09678508597958
# steps	 1500 	total rewards	 203.81389480225738
# Finished after 1832 timesteps (6.832520008087158 seconds) with total reward 236.613493216062
# {'coverage_prop': '0.983', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.101', 'efficiency': '0.204', 'TP': '302', 'FP': '37', 'FN': '6', 'precision': '0.891', 'recall': '0.981', 'f1': '0.934', 'total_rewards': 236.61349321606187, 'invalid_action_count': 0, 'num_ms1_scans': 168, 'num_ms2_scans': 1664}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 50.899001273327215
# steps	 1000 	total rewards	 121.57636063829729
# steps	 1500 	total rewards	 211.67445670289322
# Finished after 1855 timesteps (7.622541189193726 seconds) with total reward 255.83164129074794
# {'coverage_prop': '0.967', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.085', 'efficiency': '0.224', 'TP': '336', 'FP': '47', 'FN': '13', 'precision': '0.877', 'recall': '0.963', 'f1': '0.918', 'total_rewards': 255.83164129074817, 'invalid_action_count': 0, 'num_ms1_scans': 145, 'num_ms2_scans': 1710}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 27.73857914499439
# steps	 1000 	total rewards	 89.84220713333019
# steps	 1500 	total rewards	 134.9609632612458
# Finished after 1765 timesteps (4.188550233840942 seconds) with total reward 149.60452142334321
# {'coverage_prop': '0.956', 'intensity_prop': '0.818', 'ms1ms2_ratio': '0.154', 'efficiency': '0.127', 'TP': '187', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959', 'total_rewards': 149.60452142334282, 'invalid_action_count': 0, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 38.602903855122605
# steps	 1000 	total rewards	 102.24365417165191
# steps	 1500 	total rewards	 164.25286681906874
# Finished after 1797 timesteps (4.304480791091919 seconds) with total reward 199.21006346201398
# {'coverage_prop': '0.968', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.127', 'efficiency': '0.171', 'TP': '245', 'FP': '27', 'FN': '9', 'precision': '0.901', 'recall': '0.965', 'f1': '0.932', 'total_rewards': 199.2100634620142, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 69.1667898600598
# steps	 1000 	total rewards	 148.81320370917223
# steps	 1500 	total rewards	 242.42467613621025
# Finished after 1880 timesteps (4.674266815185547 seconds) with total reward 294.803206795502
# {'coverage_prop': '0.947', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.068', 'efficiency': '0.265', 'TP': '374', 'FP': '93', 'FN': '26', 'precision': '0.801', 'recall': '0.935', 'f1': '0.863', 'total_rewards': 294.80320679550186, 'invalid_action_count': 0, 'num_ms1_scans': 120, 'num_ms2_scans': 1760}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 47.602484270300266
# steps	 1000 	total rewards	 111.96089479365432
# steps	 1500 	total rewards	 168.9839617699762
# Finished after 1822 timesteps (4.3849263191223145 seconds) with total reward 194.9962538380302
# {'coverage_prop': '0.954', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.108', 'efficiency': '0.176', 'TP': '269', 'FP': '21', 'FN': '14', 'precision': '0.928', 'recall': '0.951', 'f1': '0.939', 'total_rewards': 194.99625383803033, 'invalid_action_count': 0, 'num_ms1_scans': 178, 'num_ms2_scans': 1644}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 67.33847302196972
# steps	 1000 	total rewards	 156.8840246520649
# steps	 1500 	total rewards	 237.96024878414585
# Finished after 1722 timesteps (10.742977619171143 seconds) with total reward 262.375726204561
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 262.3757262045606, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 69.01715621442264
# steps	 1000 	total rewards	 140.12350716627864
# steps	 1500 	total rewards	 191.85932403988878
# Finished after 1556 timesteps (10.235853910446167 seconds) with total reward 195.12980077851972
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 195.12980077851964, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 60.73116003226388
# steps	 1000 	total rewards	 149.26087619212254
# steps	 1500 	total rewards	 230.6819214577729
# Finished after 1669 timesteps (9.896809101104736 seconds) with total reward 246.02945660976837
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 246.02945660976783, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 76.36837220112281
# steps	 1000 	total rewards	 172.1656268999571
# steps	 1500 	total rewards	 239.81534317473935
# Finished after 1717 timesteps (11.725038051605225 seconds) with total reward 264.93312245738804
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 264.9331224573878, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 62.48483607996894
# steps	 1000 	total rewards	 160.1034929634551
# steps	 1500 	total rewards	 230.12030497375258
# Finished after 1704 timesteps (10.079133033752441 seconds) with total reward 253.0354948089851
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 253.03549480898462, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 42.98219445123175
# steps	 1000 	total rewards	 103.8837459932189
# Finished after 1408 timesteps (9.784822940826416 seconds) with total reward 136.79213745692658
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 136.7921374569265, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 78.61078905044548
# steps	 1000 	total rewards	 167.8341779112095
# steps	 1500 	total rewards	 237.0127491507391
# Finished after 1744 timesteps (10.774034023284912 seconds) with total reward 262.56605569253367
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 262.5660556925332, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 42.03855319462796
# steps	 1000 	total rewards	 115.58673566030313
# Finished after 1468 timesteps (8.360759735107422 seconds) with total reward 155.1481934279775
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 155.14819342797733, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 73.69034194850389
# steps	 1000 	total rewards	 158.1060779227306
# steps	 1500 	total rewards	 235.74390038056154
# Finished after 1736 timesteps (12.060354948043823 seconds) with total reward 261.3859720318102
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 261.3859720318098, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 60.436422664902715
# steps	 1000 	total rewards	 150.09505943153007
# steps	 1500 	total rewards	 221.68481512420865
# Finished after 1667 timesteps (9.60224986076355 seconds) with total reward 236.44219193656423
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 236.44219193656383, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 70.25010797589009
# steps	 1000 	total rewards	 161.61717506840972
# steps	 1500 	total rewards	 244.8781284234139
# Finished after 1737 timesteps (10.025909900665283 seconds) with total reward 267.92805502833835
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 267.9280550283378, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 59.57659213260594
# steps	 1000 	total rewards	 130.04611791770247
# steps	 1500 	total rewards	 174.84492310739918
# Finished after 1530 timesteps (8.740113019943237 seconds) with total reward 175.2543856722854
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 175.2543856722853, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 50.767549003168924
# steps	 1000 	total rewards	 121.2900737597443
# steps	 1500 	total rewards	 169.16357553260139
# Finished after 1602 timesteps (9.587475061416626 seconds) with total reward 174.53568398086364
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 174.53568398086335, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 44.4537334640258
# steps	 1000 	total rewards	 110.72796086125393
# steps	 1500 	total rewards	 171.44211074377037
# Finished after 1645 timesteps (12.049180746078491 seconds) with total reward 183.6074618629396
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 183.6074618629394, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 45.77969526627804
# steps	 1000 	total rewards	 108.4876966951858
# Finished after 1497 timesteps (8.606706857681274 seconds) with total reward 153.3010807901594
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 153.30108079015966, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 61.6061681322342
# steps	 1000 	total rewards	 151.942208252017
# steps	 1500 	total rewards	 223.34954994271394
# Finished after 1655 timesteps (10.020952224731445 seconds) with total reward 244.21855435212012
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 244.21855435212046, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 85.12487939498877
# steps	 1000 	total rewards	 174.2713931306917
# steps	 1500 	total rewards	 258.3494773505681
# Finished after 1729 timesteps (13.100932121276855 seconds) with total reward 287.6739498679345
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 287.673949867934, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 73.69135524549536
# steps	 1000 	total rewards	 155.72445602827432
# steps	 1500 	total rewards	 220.0922388120474
# Finished after 1681 timesteps (9.972576141357422 seconds) with total reward 236.59749159228573
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 236.59749159228585, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 57.707222971136915
# steps	 1000 	total rewards	 138.5707875082752
# steps	 1500 	total rewards	 203.61576904717774
# Finished after 1621 timesteps (9.608206033706665 seconds) with total reward 211.24020896038837
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 211.24020896038837, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 57.25711975451635
# steps	 1000 	total rewards	 132.33362375768297
# steps	 1500 	total rewards	 184.31525053508136
# Finished after 1634 timesteps (9.01674509048462 seconds) with total reward 194.3925477340405
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 194.39254773403988, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 78.6451004143091
# steps	 1000 	total rewards	 150.2432659944766
# steps	 1500 	total rewards	 220.34851345354403
# Finished after 1726 timesteps (12.411868810653687 seconds) with total reward 245.73722109385534
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 245.737221093855, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 49.283375403691245
# steps	 1000 	total rewards	 124.80025376625278
# Finished after 1475 timesteps (8.70386290550232 seconds) with total reward 174.38477375762454
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 174.38477375762443, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 58.454003920248525
# steps	 1000 	total rewards	 136.97484625601197
# steps	 1500 	total rewards	 198.97580126269258
# Finished after 1636 timesteps (9.896259069442749 seconds) with total reward 212.74207248347182
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 212.74207248347187, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 66.15851336955126
# steps	 1000 	total rewards	 144.36046191652656
# steps	 1500 	total rewards	 205.01282945600167
# Finished after 1575 timesteps (11.127370119094849 seconds) with total reward 210.27146504033055
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 210.27146504033044, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 59.96622713468507
# steps	 1000 	total rewards	 150.37521662051608
# steps	 1500 	total rewards	 210.21173408075958
# Finished after 1681 timesteps (9.759130716323853 seconds) with total reward 227.82344753616226
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 227.82344753616167, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 60.384139908020614
# steps	 1000 	total rewards	 145.49026810540119
# steps	 1500 	total rewards	 233.62135825057436
# Finished after 1679 timesteps (9.765743732452393 seconds) with total reward 253.9489052873549
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 253.94890528735468, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 39.38922384913947
# steps	 1000 	total rewards	 116.46510030428439
# Finished after 1465 timesteps (10.643407106399536 seconds) with total reward 152.02882853401888
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 152.02882853401886, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 52.624055742424865
# steps	 1000 	total rewards	 128.73982326464596
# steps	 1500 	total rewards	 193.9073959409036
# Finished after 1564 timesteps (12.865916967391968 seconds) with total reward 201.1510042955095
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 201.1510042955095, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 77.49765797395072
# steps	 1000 	total rewards	 143.68020997817547
# steps	 1500 	total rewards	 218.36589994257628
# Finished after 1749 timesteps (11.158559083938599 seconds) with total reward 254.34667174970483
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 254.34667174970437, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 55.173120405466925
# steps	 1000 	total rewards	 128.507981182248
# steps	 1500 	total rewards	 188.14841269318524
# Finished after 1657 timesteps (10.128852844238281 seconds) with total reward 195.9026494856978
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 195.90264948569757, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb2a218a8f0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb2a59b6c80>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb2a59d3e20>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.789', 'efficiency': '0.536', 'TP': '359', 'FP': '57', 'FN': '10', 'precision': '0.863', 'recall': '0.973', 'f1': '0.915'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.744', 'efficiency': '0.547', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.789', 'efficiency': '0.558', 'TP': '367', 'FP': '66', 'FN': '4', 'precision': '0.848', 'recall': '0.989', 'f1': '0.913'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.671', 'efficiency': '0.535', 'TP': '397', 'FP': '60', 'FN': '21', 'precision': '0.869', 'recall': '0.950', 'f1': '0.907'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.715', 'ms1ms2_ratio': '2.046', 'efficiency': '0.499', 'TP': '177', 'FP': '19', 'FN': '8', 'precision': '0.903', 'recall': '0.957', 'f1': '0.929'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.899', 'efficiency': '0.519', 'TP': '324', 'FP': '47', 'FN': '13', 'precision': '0.873', 'recall': '0.961', 'f1': '0.915'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.685', 'efficiency': '0.507', 'TP': '382', 'FP': '46', 'FN': '15', 'precision': '0.893', 'recall': '0.962', 'f1': '0.926'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.718', 'ms1ms2_ratio': '1.642', 'efficiency': '0.516', 'TP': '219', 'FP': '22', 'FN': '8', 'precision': '0.909', 'recall': '0.965', 'f1': '0.936'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.665', 'ms1ms2_ratio': '1.621', 'efficiency': '0.504', 'TP': '195', 'FP': '43', 'FN': '13', 'precision': '0.819', 'recall': '0.938', 'f1': '0.874'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.692', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '238', 'FP': '52', 'FN': '10', 'precision': '0.821', 'recall': '0.960', 'f1': '0.885'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.706', 'ms1ms2_ratio': '1.946', 'efficiency': '0.479', 'TP': '175', 'FP': '21', 'FN': '10', 'precision': '0.893', 'recall': '0.946', 'f1': '0.919'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.854', 'efficiency': '0.539', 'TP': '356', 'FP': '42', 'FN': '9', 'precision': '0.894', 'recall': '0.975', 'f1': '0.933'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '428', 'FP': '59', 'FN': '11', 'precision': '0.879', 'recall': '0.975', 'f1': '0.924'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.703', 'ms1ms2_ratio': '0.971', 'efficiency': '0.529', 'TP': '308', 'FP': '52', 'FN': '12', 'precision': '0.856', 'recall': '0.963', 'f1': '0.906'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.696', 'efficiency': '0.538', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.715', 'ms1ms2_ratio': '1.176', 'efficiency': '0.523', 'TP': '276', 'FP': '36', 'FN': '10', 'precision': '0.885', 'recall': '0.965', 'f1': '0.923'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.698', 'ms1ms2_ratio': '1.252', 'efficiency': '0.518', 'TP': '247', 'FP': '49', 'FN': '14', 'precision': '0.834', 'recall': '0.946', 'f1': '0.887'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.975', 'efficiency': '0.500', 'TP': '296', 'FP': '43', 'FN': '6', 'precision': '0.873', 'recall': '0.980', 'f1': '0.924'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.851', 'efficiency': '0.528', 'TP': '339', 'FP': '52', 'FN': '5', 'precision': '0.867', 'recall': '0.985', 'f1': '0.922'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.722', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '175', 'FP': '22', 'FN': '6', 'precision': '0.888', 'recall': '0.967', 'f1': '0.926'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.377', 'efficiency': '0.510', 'TP': '241', 'FP': '31', 'FN': '9', 'precision': '0.886', 'recall': '0.964', 'f1': '0.923'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.589', 'efficiency': '0.522', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.206', 'efficiency': '0.503', 'TP': '268', 'FP': '27', 'FN': '9', 'precision': '0.908', 'recall': '0.968', 'f1': '0.937'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random     260.724953                   0.0          0.934           0.694
# 1  random     192.936342                   0.0          0.935           0.769
# 2  random     245.790712                   0.0          0.934           0.694
# 3  random     265.957909                   0.0          0.951           0.710
# 4  random     254.599684                   0.0          0.961           0.711
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.131       0.251      0.827   0.922  0.872
# 1          0.204       0.173      0.939   0.931  0.935
# 2          0.158       0.242      0.826   0.921  0.871
# 3          0.134       0.272      0.865   0.944  0.903
# 4          0.142       0.270      0.821   0.953  0.882

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_5.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_5.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    PPO     270.598185                   0.0          0.958           0.710
# 31    PPO     197.288076                   0.0          0.950           0.775
# 32    PPO     256.551946                   0.0          0.957           0.706
# 33    PPO     272.106457                   0.0          0.951           0.737
# 34    PPO     258.935093                   0.0          0.973           0.718
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.083       0.238      0.858   0.951  0.902
# 31          0.132       0.157      0.920   0.946  0.933
# 32          0.097       0.225      0.838   0.949  0.890
# 33          0.084       0.251      0.881   0.945  0.912
# 34          0.088       0.250      0.852   0.968  0.906

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
