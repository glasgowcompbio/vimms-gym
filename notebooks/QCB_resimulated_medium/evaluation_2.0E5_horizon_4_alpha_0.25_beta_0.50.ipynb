# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.00
env_beta = 0.00
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f06a24eb7f0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f06a0ecb460>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f06a2acd070>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.0,
#    'beta': 0.0}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_2.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    # METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f06a24eb7f0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f06a0ecb460>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f06a2acd070>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 20

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f06a24eb7f0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f06a0ecb460>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f06a2acd070>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
horizon = 4
out_dir = 'evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E5_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -453.97925543513384
# steps	 1000 	total rewards	 -948.7947675526947
# steps	 1500 	total rewards	 -1368.116747884908
# Finished after 1987 timesteps (1.716399908065796 seconds) with total reward -1802.9329488397525
# {'coverage_prop': '0.347', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.007', 'efficiency': '0.075', 'TP': '33', 'FP': '115', 'FN': '278', 'precision': '0.223', 'recall': '0.106', 'f1': '0.144', 'total_rewards': -1802.932948839753, 'invalid_action_count': 1874, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -488.0777618553718
# steps	 1000 	total rewards	 -962.9304804328353
# steps	 1500 	total rewards	 -1444.8264373614877
# Finished after 1994 timesteps (1.2532217502593994 seconds) with total reward -1937.826437361488
# {'coverage_prop': '0.160', 'intensity_prop': '0.033', 'ms1ms2_ratio': '0.003', 'efficiency': '0.021', 'TP': '8', 'FP': '34', 'FN': '220', 'precision': '0.190', 'recall': '0.035', 'f1': '0.059', 'total_rewards': -1937.8264373614875, 'invalid_action_count': 1955, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -492.4500310211285
# steps	 1000 	total rewards	 -970.6159381484283
# steps	 1500 	total rewards	 -1419.7343248425618
# Finished after 1990 timesteps (2.5996484756469727 seconds) with total reward -1835.303528656761
# {'coverage_prop': '0.340', 'intensity_prop': '0.078', 'ms1ms2_ratio': '0.005', 'efficiency': '0.068', 'TP': '23', 'FP': '111', 'FN': '260', 'precision': '0.172', 'recall': '0.081', 'f1': '0.110', 'total_rewards': -1835.3035286567608, 'invalid_action_count': 1897, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -963.5293196166286
# steps	 1500 	total rewards	 -1403.6507660832222
# Finished after 1989 timesteps (1.7688381671905518 seconds) with total reward -1837.515198775393
# {'coverage_prop': '0.308', 'intensity_prop': '0.094', 'ms1ms2_ratio': '0.006', 'efficiency': '0.070', 'TP': '35', 'FP': '104', 'FN': '313', 'precision': '0.252', 'recall': '0.101', 'f1': '0.144', 'total_rewards': -1837.5151987753934, 'invalid_action_count': 1897, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -958.1916444022152
# steps	 1500 	total rewards	 -1409.33470166092
# Finished after 1993 timesteps (1.9039294719696045 seconds) with total reward -1868.2801524935053
# {'coverage_prop': '0.259', 'intensity_prop': '0.047', 'ms1ms2_ratio': '0.004', 'efficiency': '0.057', 'TP': '17', 'FP': '96', 'FN': '324', 'precision': '0.150', 'recall': '0.050', 'f1': '0.075', 'total_rewards': -1868.2801524935057, 'invalid_action_count': 1916, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -489.83366753727927
# steps	 1000 	total rewards	 -971.2646900581424
# steps	 1500 	total rewards	 -1417.8323605347632
# Finished after 1989 timesteps (1.1723926067352295 seconds) with total reward -1887.9363686912354
# {'coverage_prop': '0.375', 'intensity_prop': '0.113', 'ms1ms2_ratio': '0.006', 'efficiency': '0.038', 'TP': '19', 'FP': '56', 'FN': '125', 'precision': '0.253', 'recall': '0.132', 'f1': '0.174', 'total_rewards': -1887.9363686912352, 'invalid_action_count': 1926, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -477.2775076772707
# steps	 1000 	total rewards	 -929.132128823347
# steps	 1500 	total rewards	 -1295.5743335397137
# Finished after 1984 timesteps (1.9752256870269775 seconds) with total reward -1707.8469944675944
# {'coverage_prop': '0.418', 'intensity_prop': '0.127', 'ms1ms2_ratio': '0.008', 'efficiency': '0.102', 'TP': '47', 'FP': '153', 'FN': '278', 'precision': '0.235', 'recall': '0.145', 'f1': '0.179', 'total_rewards': -1707.8469944675935, 'invalid_action_count': 1815, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -489.5428879855065
# steps	 1000 	total rewards	 -961.4100164143763
# steps	 1500 	total rewards	 -1411.355556445722
# Finished after 1992 timesteps (1.1760408878326416 seconds) with total reward -1874.0007890535217
# {'coverage_prop': '0.368', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.004', 'efficiency': '0.038', 'TP': '22', 'FP': '53', 'FN': '129', 'precision': '0.293', 'recall': '0.146', 'f1': '0.195', 'total_rewards': -1874.0007890535217, 'invalid_action_count': 1920, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -477.43428332981625
# steps	 1000 	total rewards	 -953.0269769027909
# steps	 1500 	total rewards	 -1395.7530472825013
# Finished after 1991 timesteps (1.7657749652862549 seconds) with total reward -1828.76780258424
# {'coverage_prop': '0.321', 'intensity_prop': '0.047', 'ms1ms2_ratio': '0.005', 'efficiency': '0.069', 'TP': '11', 'FP': '125', 'FN': '288', 'precision': '0.081', 'recall': '0.037', 'f1': '0.051', 'total_rewards': -1828.767802584239, 'invalid_action_count': 1891, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -492.88725615567137
# steps	 1000 	total rewards	 -941.0799257218484
# steps	 1500 	total rewards	 -1404.5627979906449
# Finished after 1990 timesteps (1.6679518222808838 seconds) with total reward -1826.0332879808311
# {'coverage_prop': '0.341', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.005', 'efficiency': '0.066', 'TP': '27', 'FP': '104', 'FN': '253', 'precision': '0.206', 'recall': '0.096', 'f1': '0.131', 'total_rewards': -1826.0332879808311, 'invalid_action_count': 1888, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -947.6124288774774
# steps	 1500 	total rewards	 -1357.2172389534892
# Finished after 1992 timesteps (1.8182530403137207 seconds) with total reward -1799.8436103656359
# {'coverage_prop': '0.370', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.004', 'efficiency': '0.083', 'TP': '25', 'FP': '139', 'FN': '279', 'precision': '0.152', 'recall': '0.082', 'f1': '0.107', 'total_rewards': -1799.843610365636, 'invalid_action_count': 1874, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -492.60209853858254
# steps	 1000 	total rewards	 -979.1315132405737
# steps	 1500 	total rewards	 -1447.599270640354
# Finished after 1989 timesteps (1.3424530029296875 seconds) with total reward -1908.7072062394573
# {'coverage_prop': '0.253', 'intensity_prop': '0.051', 'ms1ms2_ratio': '0.006', 'efficiency': '0.032', 'TP': '9', 'FP': '54', 'FN': '186', 'precision': '0.143', 'recall': '0.046', 'f1': '0.070', 'total_rewards': -1908.707206239457, 'invalid_action_count': 1937, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -955.4977352038295
# steps	 1500 	total rewards	 -1396.2569796000857
# Finished after 1990 timesteps (1.3534226417541504 seconds) with total reward -1838.2157838209764
# {'coverage_prop': '0.398', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.005', 'efficiency': '0.051', 'TP': '20', 'FP': '80', 'FN': '151', 'precision': '0.200', 'recall': '0.117', 'f1': '0.148', 'total_rewards': -1838.2157838209773, 'invalid_action_count': 1898, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -482.98989900878485
# steps	 1000 	total rewards	 -939.2137053853204
# steps	 1500 	total rewards	 -1393.5320892100071
# Finished after 1992 timesteps (1.5583677291870117 seconds) with total reward -1834.822530894594
# {'coverage_prop': '0.413', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.004', 'efficiency': '0.062', 'TP': '30', 'FP': '94', 'FN': '176', 'precision': '0.242', 'recall': '0.146', 'f1': '0.182', 'total_rewards': -1834.8225308945935, 'invalid_action_count': 1892, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -490.3039035211283
# steps	 1000 	total rewards	 -959.9600362903642
# steps	 1500 	total rewards	 -1429.8040028070243
# Finished after 1985 timesteps (1.285902976989746 seconds) with total reward -1878.569528935504
# {'coverage_prop': '0.325', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.008', 'efficiency': '0.034', 'TP': '15', 'FP': '52', 'FN': '139', 'precision': '0.224', 'recall': '0.097', 'f1': '0.136', 'total_rewards': -1878.569528935504, 'invalid_action_count': 1916, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -481.82494545842826
# steps	 1000 	total rewards	 -924.4838887934748
# steps	 1500 	total rewards	 -1384.366732616406
# Finished after 1990 timesteps (1.7405893802642822 seconds) with total reward -1852.4485831802035
# {'coverage_prop': '0.354', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.005', 'efficiency': '0.073', 'TP': '34', 'FP': '110', 'FN': '263', 'precision': '0.236', 'recall': '0.114', 'f1': '0.154', 'total_rewards': -1852.4485831802037, 'invalid_action_count': 1906, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -472.7716894744434
# steps	 1000 	total rewards	 -895.7723174147137
# steps	 1500 	total rewards	 -1304.3702609555617
# Finished after 1990 timesteps (1.8980412483215332 seconds) with total reward -1758.0546292822266
# {'coverage_prop': '0.420', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.005', 'efficiency': '0.106', 'TP': '48', 'FP': '161', 'FN': '289', 'precision': '0.230', 'recall': '0.142', 'f1': '0.176', 'total_rewards': -1758.054629282227, 'invalid_action_count': 1847, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -980.4122821619671
# steps	 1500 	total rewards	 -1420.0964614068366
# Finished after 1993 timesteps (1.6211824417114258 seconds) with total reward -1864.6032192725627
# {'coverage_prop': '0.301', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.004', 'efficiency': '0.056', 'TP': '26', 'FP': '86', 'FN': '260', 'precision': '0.232', 'recall': '0.091', 'f1': '0.131', 'total_rewards': -1864.603219272563, 'invalid_action_count': 1913, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -494.1592357467889
# steps	 1000 	total rewards	 -960.110020147832
# steps	 1500 	total rewards	 -1400.8028053722976
# Finished after 1987 timesteps (1.5897188186645508 seconds) with total reward -1836.7924550770217
# {'coverage_prop': '0.351', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.007', 'efficiency': '0.054', 'TP': '23', 'FP': '83', 'FN': '196', 'precision': '0.217', 'recall': '0.105', 'f1': '0.142', 'total_rewards': -1836.7924550770217, 'invalid_action_count': 1894, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -481.02892966723357
# steps	 1000 	total rewards	 -959.1605251336176
# steps	 1500 	total rewards	 -1433.2382019800757
# Finished after 1991 timesteps (1.3779900074005127 seconds) with total reward -1875.9421966011905
# {'coverage_prop': '0.287', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.005', 'efficiency': '0.038', 'TP': '13', 'FP': '63', 'FN': '189', 'precision': '0.171', 'recall': '0.064', 'f1': '0.094', 'total_rewards': -1875.9421966011907, 'invalid_action_count': 1919, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -468.5238395055501
# steps	 1000 	total rewards	 -872.5175596329432
# steps	 1500 	total rewards	 -1276.8472109175952
# Finished after 1988 timesteps (1.8789451122283936 seconds) with total reward -1746.4009724926304
# {'coverage_prop': '0.419', 'intensity_prop': '0.127', 'ms1ms2_ratio': '0.006', 'efficiency': '0.099', 'TP': '60', 'FP': '136', 'FN': '272', 'precision': '0.306', 'recall': '0.181', 'f1': '0.227', 'total_rewards': -1746.4009724926302, 'invalid_action_count': 1839, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -487.6008977594629
# steps	 1000 	total rewards	 -952.4346331312795
# steps	 1500 	total rewards	 -1406.3911131004475
# Finished after 1991 timesteps (1.2615046501159668 seconds) with total reward -1884.4435016565008
# {'coverage_prop': '0.359', 'intensity_prop': '0.063', 'ms1ms2_ratio': '0.005', 'efficiency': '0.042', 'TP': '13', 'FP': '71', 'FN': '150', 'precision': '0.155', 'recall': '0.080', 'f1': '0.105', 'total_rewards': -1884.4435016565005, 'invalid_action_count': 1924, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -485.93564199495484
# steps	 1000 	total rewards	 -951.5461803525869
# steps	 1500 	total rewards	 -1380.0360803357876
# Finished after 1989 timesteps (1.478102207183838 seconds) with total reward -1834.4338759310585
# {'coverage_prop': '0.373', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.006', 'efficiency': '0.061', 'TP': '31', 'FP': '89', 'FN': '202', 'precision': '0.258', 'recall': '0.133', 'f1': '0.176', 'total_rewards': -1834.4338759310583, 'invalid_action_count': 1892, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -485.566766151233
# steps	 1000 	total rewards	 -970.4438406876184
# steps	 1500 	total rewards	 -1415.124477464844
# Finished after 1991 timesteps (1.377523422241211 seconds) with total reward -1882.5266780140037
# {'coverage_prop': '0.258', 'intensity_prop': '0.063', 'ms1ms2_ratio': '0.005', 'efficiency': '0.040', 'TP': '16', 'FP': '64', 'FN': '230', 'precision': '0.200', 'recall': '0.065', 'f1': '0.098', 'total_rewards': -1882.5266780140041, 'invalid_action_count': 1921, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -496.02536187457184
# steps	 1000 	total rewards	 -935.0565795200419
# steps	 1500 	total rewards	 -1375.991845006862
# Finished after 1988 timesteps (1.5387921333312988 seconds) with total reward -1803.9380586688744
# {'coverage_prop': '0.394', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '30', 'FP': '106', 'FN': '209', 'precision': '0.221', 'recall': '0.126', 'f1': '0.160', 'total_rewards': -1803.9380586688742, 'invalid_action_count': 1877, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -486.5484598980332
# steps	 1000 	total rewards	 -953.4793343557983
# steps	 1500 	total rewards	 -1350.1284882912346
# Finished after 1988 timesteps (3.008591413497925 seconds) with total reward -1793.9351855371613
# {'coverage_prop': '0.402', 'intensity_prop': '0.118', 'ms1ms2_ratio': '0.006', 'efficiency': '0.080', 'TP': '47', 'FP': '112', 'FN': '237', 'precision': '0.296', 'recall': '0.165', 'f1': '0.212', 'total_rewards': -1793.9351855371615, 'invalid_action_count': 1871, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -952.9873051390423
# steps	 1500 	total rewards	 -1415.1913157227514
# Finished after 1991 timesteps (1.267418384552002 seconds) with total reward -1890.7747313999816
# {'coverage_prop': '0.330', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.005', 'efficiency': '0.034', 'TP': '13', 'FP': '54', 'FN': '136', 'precision': '0.194', 'recall': '0.087', 'f1': '0.120', 'total_rewards': -1890.774731399981, 'invalid_action_count': 1929, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -969.5125221519652
# steps	 1500 	total rewards	 -1420.0765619012423
# Finished after 1996 timesteps (1.370415449142456 seconds) with total reward -1902.284982691193
# {'coverage_prop': '0.253', 'intensity_prop': '0.049', 'ms1ms2_ratio': '0.002', 'efficiency': '0.036', 'TP': '13', 'FP': '58', 'FN': '210', 'precision': '0.183', 'recall': '0.058', 'f1': '0.088', 'total_rewards': -1902.284982691193, 'invalid_action_count': 1937, 'num_ms1_scans': 4, 'num_ms2_scans': 1992}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -488.73890024966374
# steps	 1000 	total rewards	 -958.2913996198702
# steps	 1500 	total rewards	 -1391.0342595281707
# Finished after 1994 timesteps (1.9649488925933838 seconds) with total reward -1847.3753763023506
# {'coverage_prop': '0.241', 'intensity_prop': '0.058', 'ms1ms2_ratio': '0.003', 'efficiency': '0.060', 'TP': '27', 'FP': '92', 'FN': '374', 'precision': '0.227', 'recall': '0.067', 'f1': '0.104', 'total_rewards': -1847.3753763023512, 'invalid_action_count': 1903, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -924.0128263653779
# steps	 1500 	total rewards	 -1380.609429491049
# Finished after 1987 timesteps (1.5070459842681885 seconds) with total reward -1835.6190324271233
# {'coverage_prop': '0.322', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.007', 'efficiency': '0.050', 'TP': '27', 'FP': '71', 'FN': '206', 'precision': '0.276', 'recall': '0.116', 'f1': '0.163', 'total_rewards': -1835.6190324271236, 'invalid_action_count': 1894, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# method = PPO max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 357.9237302465973
# steps	 1000 	total rewards	 731.3728211713232
# steps	 1500 	total rewards	 1115.8003206294454
# Finished after 1860 timesteps (5.746374607086182 seconds) with total reward 1383.3385078675644
# {'coverage_prop': '0.944', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.081', 'efficiency': '0.234', 'TP': '347', 'FP': '55', 'FN': '24', 'precision': '0.863', 'recall': '0.935', 'f1': '0.898', 'total_rewards': 1383.3385078675635, 'invalid_action_count': 0, 'num_ms1_scans': 140, 'num_ms2_scans': 1720}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 341.7656176821139
# steps	 1000 	total rewards	 724.1415549267354
# steps	 1500 	total rewards	 1095.8273595835726
# Finished after 1802 timesteps (6.034055948257446 seconds) with total reward 1333.1171165375154
# {'coverage_prop': '0.958', 'intensity_prop': '0.805', 'ms1ms2_ratio': '0.123', 'efficiency': '0.156', 'TP': '234', 'FP': '17', 'FN': '11', 'precision': '0.932', 'recall': '0.955', 'f1': '0.944', 'total_rewards': 1333.1171165375156, 'invalid_action_count': 0, 'num_ms1_scans': 198, 'num_ms2_scans': 1604}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 352.8670577964579
# steps	 1000 	total rewards	 738.5108116694171
# steps	 1500 	total rewards	 1136.423357953658
# Finished after 1840 timesteps (5.249949216842651 seconds) with total reward 1409.1475363119487
# {'coverage_prop': '0.957', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.095', 'efficiency': '0.224', 'TP': '327', 'FP': '50', 'FN': '17', 'precision': '0.867', 'recall': '0.951', 'f1': '0.907', 'total_rewards': 1409.1475363119478, 'invalid_action_count': 0, 'num_ms1_scans': 160, 'num_ms2_scans': 1680}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 350.80571387505955
# steps	 1000 	total rewards	 730.6773789326649
# steps	 1500 	total rewards	 1103.8153237419522
# Finished after 1857 timesteps (5.317221641540527 seconds) with total reward 1371.2232161471538
# {'coverage_prop': '0.945', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.083', 'efficiency': '0.249', 'TP': '381', 'FP': '46', 'FN': '25', 'precision': '0.892', 'recall': '0.938', 'f1': '0.915', 'total_rewards': 1371.2232161471525, 'invalid_action_count': 0, 'num_ms1_scans': 143, 'num_ms2_scans': 1714}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 328.30587674334646
# steps	 1000 	total rewards	 704.5390330691037
# steps	 1500 	total rewards	 1053.3313963788273
# Finished after 1850 timesteps (5.309547424316406 seconds) with total reward 1294.6878465768596
# {'coverage_prop': '0.966', 'intensity_prop': '0.718', 'ms1ms2_ratio': '0.089', 'efficiency': '0.248', 'TP': '356', 'FP': '66', 'FN': '15', 'precision': '0.844', 'recall': '0.960', 'f1': '0.898', 'total_rewards': 1294.6878465768607, 'invalid_action_count': 0, 'num_ms1_scans': 151, 'num_ms2_scans': 1699}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 339.957439912233
# steps	 1000 	total rewards	 703.9397300417668
# steps	 1500 	total rewards	 1088.9490495170653
# Finished after 1759 timesteps (4.634520769119263 seconds) with total reward 1266.7626560310732
# {'coverage_prop': '0.955', 'intensity_prop': '0.827', 'ms1ms2_ratio': '0.159', 'efficiency': '0.126', 'TP': '182', 'FP': '9', 'FN': '9', 'precision': '0.953', 'recall': '0.953', 'f1': '0.953', 'total_rewards': 1266.7626560310725, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 343.22776690522863
# steps	 1000 	total rewards	 718.6429728380085
# steps	 1500 	total rewards	 1097.512013340314
# Finished after 1862 timesteps (5.308166265487671 seconds) with total reward 1347.2682084905055
# {'coverage_prop': '0.939', 'intensity_prop': '0.692', 'ms1ms2_ratio': '0.081', 'efficiency': '0.261', 'TP': '367', 'FP': '82', 'FN': '29', 'precision': '0.817', 'recall': '0.927', 'f1': '0.869', 'total_rewards': 1347.2682084905048, 'invalid_action_count': 0, 'num_ms1_scans': 139, 'num_ms2_scans': 1723}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 303.63264416542387
# steps	 1000 	total rewards	 681.3027469788718
# steps	 1500 	total rewards	 1072.7825712198016
# Finished after 1769 timesteps (4.233431816101074 seconds) with total reward 1270.2425309001496
# {'coverage_prop': '0.951', 'intensity_prop': '0.816', 'ms1ms2_ratio': '0.150', 'efficiency': '0.126', 'TP': '184', 'FP': '10', 'FN': '10', 'precision': '0.948', 'recall': '0.948', 'f1': '0.948', 'total_rewards': 1270.2425309001494, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 360.2237551860371
# steps	 1000 	total rewards	 736.8340618426256
# steps	 1500 	total rewards	 1117.8659944974545
# Finished after 1869 timesteps (6.58958888053894 seconds) with total reward 1395.0097600797176
# {'coverage_prop': '0.943', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.075', 'efficiency': '0.230', 'TP': '347', 'FP': '53', 'FN': '24', 'precision': '0.868', 'recall': '0.935', 'f1': '0.900', 'total_rewards': 1395.0097600797185, 'invalid_action_count': 0, 'num_ms1_scans': 131, 'num_ms2_scans': 1738}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 342.51909396450503
# steps	 1000 	total rewards	 717.7800126840453
# steps	 1500 	total rewards	 1108.3178027724057
# Finished after 1849 timesteps (5.197833061218262 seconds) with total reward 1370.9598239993143
# {'coverage_prop': '0.951', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.089', 'efficiency': '0.215', 'TP': '321', 'FP': '44', 'FN': '19', 'precision': '0.879', 'recall': '0.944', 'f1': '0.911', 'total_rewards': 1370.9598239993154, 'invalid_action_count': 0, 'num_ms1_scans': 151, 'num_ms2_scans': 1698}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 349.66229899679496
# steps	 1000 	total rewards	 738.9862947572851
# steps	 1500 	total rewards	 1114.2311633899008
# Finished after 1874 timesteps (5.284250020980835 seconds) with total reward 1393.3613573311404
# {'coverage_prop': '0.930', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.072', 'efficiency': '0.236', 'TP': '358', 'FP': '54', 'FN': '31', 'precision': '0.869', 'recall': '0.920', 'f1': '0.894', 'total_rewards': 1393.3613573311384, 'invalid_action_count': 0, 'num_ms1_scans': 126, 'num_ms2_scans': 1748}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 349.87054576173176
# steps	 1000 	total rewards	 713.799739030743
# steps	 1500 	total rewards	 1084.4554784589582
# Finished after 1797 timesteps (4.442377090454102 seconds) with total reward 1291.0067672095727
# {'coverage_prop': '0.948', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.127', 'efficiency': '0.148', 'TP': '223', 'FP': '13', 'FN': '13', 'precision': '0.945', 'recall': '0.945', 'f1': '0.945', 'total_rewards': 1291.006767209573, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 329.57083557592796
# steps	 1000 	total rewards	 708.1544780216373
# steps	 1500 	total rewards	 1090.2163560980773
# Finished after 1834 timesteps (6.450279235839844 seconds) with total reward 1333.2273182565748
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.100', 'efficiency': '0.143', 'TP': '210', 'FP': '28', 'FN': '13', 'precision': '0.882', 'recall': '0.942', 'f1': '0.911', 'total_rewards': 1333.227318256574, 'invalid_action_count': 0, 'num_ms1_scans': 167, 'num_ms2_scans': 1667}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 325.77309788008984
# steps	 1000 	total rewards	 692.6323362135731
# steps	 1500 	total rewards	 1042.9947164754287
# Finished after 1835 timesteps (4.986086368560791 seconds) with total reward 1213.5734268764218
# {'coverage_prop': '0.953', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.099', 'efficiency': '0.171', 'TP': '252', 'FP': '34', 'FN': '14', 'precision': '0.881', 'recall': '0.947', 'f1': '0.913', 'total_rewards': 1213.573426876419, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 311.65483113593956
# steps	 1000 	total rewards	 692.7900609335024
# steps	 1500 	total rewards	 1056.3505007354672
# Finished after 1791 timesteps (4.672734498977661 seconds) with total reward 1235.8867176381468
# {'coverage_prop': '0.942', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.132', 'efficiency': '0.123', 'TP': '175', 'FP': '19', 'FN': '12', 'precision': '0.902', 'recall': '0.936', 'f1': '0.919', 'total_rewards': 1235.8867176381484, 'invalid_action_count': 0, 'num_ms1_scans': 209, 'num_ms2_scans': 1582}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 335.55425185790455
# steps	 1000 	total rewards	 729.5067497469884
# steps	 1500 	total rewards	 1113.3955125815646
# Finished after 1841 timesteps (5.271397113800049 seconds) with total reward 1395.6668052094724
# {'coverage_prop': '0.963', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.095', 'efficiency': '0.233', 'TP': '348', 'FP': '44', 'FN': '15', 'precision': '0.888', 'recall': '0.959', 'f1': '0.922', 'total_rewards': 1395.6668052094706, 'invalid_action_count': 0, 'num_ms1_scans': 159, 'num_ms2_scans': 1682}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 342.59298834950334
# steps	 1000 	total rewards	 729.8036738167145
# steps	 1500 	total rewards	 1099.2006430055515
# Finished after 1865 timesteps (7.251291275024414 seconds) with total reward 1371.9091485280892
# {'coverage_prop': '0.960', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.078', 'efficiency': '0.276', 'TP': '408', 'FP': '70', 'FN': '20', 'precision': '0.854', 'recall': '0.953', 'f1': '0.901', 'total_rewards': 1371.90914852809, 'invalid_action_count': 0, 'num_ms1_scans': 135, 'num_ms2_scans': 1730}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 361.7968272042535
# steps	 1000 	total rewards	 730.8031737654917
# steps	 1500 	total rewards	 1108.7729528713837
# Finished after 1848 timesteps (4.897691488265991 seconds) with total reward 1368.9589102416335
# {'coverage_prop': '0.944', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.090', 'efficiency': '0.207', 'TP': '306', 'FP': '45', 'FN': '21', 'precision': '0.872', 'recall': '0.936', 'f1': '0.903', 'total_rewards': 1368.9589102416355, 'invalid_action_count': 0, 'num_ms1_scans': 153, 'num_ms2_scans': 1695}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 352.72557251995045
# steps	 1000 	total rewards	 735.6847676132804
# steps	 1500 	total rewards	 1114.1765096484198
# Finished after 1825 timesteps (4.631204128265381 seconds) with total reward 1368.834161855283
# {'coverage_prop': '0.957', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.106', 'efficiency': '0.175', 'TP': '267', 'FP': '22', 'FN': '13', 'precision': '0.924', 'recall': '0.954', 'f1': '0.938', 'total_rewards': 1368.8341618552834, 'invalid_action_count': 0, 'num_ms1_scans': 175, 'num_ms2_scans': 1650}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 341.49361324676624
# steps	 1000 	total rewards	 713.6146442010738
# steps	 1500 	total rewards	 1100.6809473123544
# Finished after 1831 timesteps (4.774433851242065 seconds) with total reward 1351.1982504709952
# {'coverage_prop': '0.974', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.102', 'efficiency': '0.155', 'TP': '231', 'FP': '27', 'FN': '7', 'precision': '0.895', 'recall': '0.971', 'f1': '0.931', 'total_rewards': 1351.1982504709972, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1662}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 326.6006712695833
# steps	 1000 	total rewards	 701.6881246124199
# steps	 1500 	total rewards	 1052.0221142095556
# Finished after 1862 timesteps (5.0659019947052 seconds) with total reward 1314.267940535647
# {'coverage_prop': '0.934', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.080', 'efficiency': '0.253', 'TP': '367', 'FP': '70', 'FN': '31', 'precision': '0.840', 'recall': '0.922', 'f1': '0.879', 'total_rewards': 1314.2679405356494, 'invalid_action_count': 0, 'num_ms1_scans': 138, 'num_ms2_scans': 1724}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 359.6090142335108
# steps	 1000 	total rewards	 741.6547674611934
# steps	 1500 	total rewards	 1137.096020625907
# Finished after 1781 timesteps (6.48870849609375 seconds) with total reward 1329.2266131642714
# {'coverage_prop': '0.953', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.140', 'efficiency': '0.143', 'TP': '200', 'FP': '23', 'FN': '11', 'precision': '0.897', 'recall': '0.948', 'f1': '0.922', 'total_rewards': 1329.2266131642707, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 347.59572626093
# steps	 1000 	total rewards	 734.3288923784469
# steps	 1500 	total rewards	 1090.521793797995
# Finished after 1835 timesteps (5.328489065170288 seconds) with total reward 1349.8592824516627
# {'coverage_prop': '0.963', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.099', 'efficiency': '0.186', 'TP': '277', 'FP': '33', 'FN': '12', 'precision': '0.894', 'recall': '0.958', 'f1': '0.925', 'total_rewards': 1349.8592824516584, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 338.69026358794724
# steps	 1000 	total rewards	 715.6978999363301
# steps	 1500 	total rewards	 1114.1276114610012
# Finished after 1808 timesteps (4.902468681335449 seconds) with total reward 1342.216115268824
# {'coverage_prop': '0.942', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.119', 'efficiency': '0.181', 'TP': '268', 'FP': '24', 'FN': '18', 'precision': '0.918', 'recall': '0.937', 'f1': '0.927', 'total_rewards': 1342.2161152688261, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1616}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 335.9854774582027
# steps	 1000 	total rewards	 719.9368459094865
# steps	 1500 	total rewards	 1097.218870492614
# Finished after 1836 timesteps (4.603024482727051 seconds) with total reward 1374.1711992910857
# {'coverage_prop': '0.980', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.098', 'efficiency': '0.202', 'TP': '290', 'FP': '48', 'FN': '7', 'precision': '0.858', 'recall': '0.976', 'f1': '0.913', 'total_rewards': 1374.171199291089, 'invalid_action_count': 0, 'num_ms1_scans': 164, 'num_ms2_scans': 1672}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 368.1662808151191
# steps	 1000 	total rewards	 749.2646856252447
# steps	 1500 	total rewards	 1152.1621556548941
# Finished after 1861 timesteps (4.8406126499176025 seconds) with total reward 1429.6355551030836
# {'coverage_prop': '0.967', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.081', 'efficiency': '0.223', 'TP': '339', 'FP': '44', 'FN': '13', 'precision': '0.885', 'recall': '0.963', 'f1': '0.922', 'total_rewards': 1429.6355551030827, 'invalid_action_count': 0, 'num_ms1_scans': 140, 'num_ms2_scans': 1721}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 298.46624190241715
# steps	 1000 	total rewards	 701.8147601236972
# steps	 1500 	total rewards	 1087.8759160820741
# Finished after 1777 timesteps (4.940043926239014 seconds) with total reward 1282.3392772051736
# {'coverage_prop': '0.966', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.144', 'efficiency': '0.126', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962', 'total_rewards': 1282.3392772051768, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 327.92587065082165
# steps	 1000 	total rewards	 703.6986361784843
# steps	 1500 	total rewards	 1090.1984600793799
# Finished after 1806 timesteps (4.837325572967529 seconds) with total reward 1332.153347699038
# {'coverage_prop': '0.954', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.120', 'efficiency': '0.166', 'TP': '249', 'FP': '19', 'FN': '13', 'precision': '0.929', 'recall': '0.950', 'f1': '0.940', 'total_rewards': 1332.153347699038, 'invalid_action_count': 0, 'num_ms1_scans': 194, 'num_ms2_scans': 1612}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 339.95473821900373
# steps	 1000 	total rewards	 698.695655434233
# steps	 1500 	total rewards	 1086.2151511703094
# Finished after 1878 timesteps (5.058938264846802 seconds) with total reward 1382.4341176423236
# {'coverage_prop': '0.933', 'intensity_prop': '0.667', 'ms1ms2_ratio': '0.069', 'efficiency': '0.262', 'TP': '369', 'FP': '91', 'FN': '33', 'precision': '0.802', 'recall': '0.918', 'f1': '0.856', 'total_rewards': 1382.4341176423256, 'invalid_action_count': 0, 'num_ms1_scans': 122, 'num_ms2_scans': 1756}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 312.9666937843856
# steps	 1000 	total rewards	 715.8581835623784
# steps	 1500 	total rewards	 1099.166924774685
# Finished after 1828 timesteps (4.603847980499268 seconds) with total reward 1346.4491201268763
# {'coverage_prop': '0.964', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.104', 'efficiency': '0.177', 'TP': '270', 'FP': '23', 'FN': '11', 'precision': '0.922', 'recall': '0.961', 'f1': '0.941', 'total_rewards': 1346.449120126877, 'invalid_action_count': 0, 'num_ms1_scans': 172, 'num_ms2_scans': 1656}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 284.35173691799935
# steps	 1000 	total rewards	 645.0465058244614
# steps	 1500 	total rewards	 1017.7748091847278
# Finished after 1722 timesteps (15.382047653198242 seconds) with total reward 1167.8359689934637
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 1167.8359689934623, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 237.23177572896248
# steps	 1000 	total rewards	 554.4430604815191
# steps	 1500 	total rewards	 887.0536667084407
# Finished after 1556 timesteps (12.192834377288818 seconds) with total reward 919.7290877477645
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 919.7290877477635, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 244.24078937805592
# steps	 1000 	total rewards	 617.4522393548262
# steps	 1500 	total rewards	 1002.6498139883214
# Finished after 1669 timesteps (13.048134088516235 seconds) with total reward 1130.9657429482975
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 1130.965742948297, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 306.9619922016653
# steps	 1000 	total rewards	 652.1697495515991
# steps	 1500 	total rewards	 1007.0544717885612
# Finished after 1717 timesteps (15.752055168151855 seconds) with total reward 1160.844542375401
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 1160.8445423754026, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 261.249548510777
# steps	 1000 	total rewards	 611.6011930731654
# steps	 1500 	total rewards	 947.4884069170549
# Finished after 1704 timesteps (14.208051204681396 seconds) with total reward 1083.5255881611301
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 1083.5255881611292, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 181.55898885283494
# steps	 1000 	total rewards	 488.21694418597497
# Finished after 1408 timesteps (10.789138317108154 seconds) with total reward 675.4596211493204
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 675.4596211493198, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 298.5223816529141
# steps	 1000 	total rewards	 661.1546720814175
# steps	 1500 	total rewards	 1022.0568069477519
# Finished after 1744 timesteps (17.125398635864258 seconds) with total reward 1184.7307706257739
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 1184.7307706257727, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 168.78647892758428
# steps	 1000 	total rewards	 524.8551903087605
# Finished after 1468 timesteps (10.65544867515564 seconds) with total reward 775.5140457988746
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 775.5140457988745, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 304.21794044279426
# steps	 1000 	total rewards	 659.5970891692505
# steps	 1500 	total rewards	 1012.5872292293436
# Finished after 1736 timesteps (15.968469858169556 seconds) with total reward 1183.145173544725
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 1183.1451735447267, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 247.49521883514583
# steps	 1000 	total rewards	 607.4419966049937
# steps	 1500 	total rewards	 969.8849337641245
# Finished after 1667 timesteps (16.367276191711426 seconds) with total reward 1084.5556389681337
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 1084.5556389681337, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 292.7753260621716
# steps	 1000 	total rewards	 668.7999811580942
# steps	 1500 	total rewards	 1024.0869025194186
# Finished after 1737 timesteps (15.332381248474121 seconds) with total reward 1198.1318259640402
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 1198.1318259640384, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 222.00399078124747
# steps	 1000 	total rewards	 560.5403282265054
# steps	 1500 	total rewards	 842.2491749333565
# Finished after 1530 timesteps (11.852299690246582 seconds) with total reward 856.8756710129564
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 856.8756710129577, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 225.54324442126702
# steps	 1000 	total rewards	 588.9601538388687
# steps	 1500 	total rewards	 916.148580035796
# Finished after 1602 timesteps (15.34512710571289 seconds) with total reward 971.6859057789334
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 971.6859057789343, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 240.09095914198977
# steps	 1000 	total rewards	 562.4815276754034
# steps	 1500 	total rewards	 875.4723165540549
# Finished after 1645 timesteps (13.889017105102539 seconds) with total reward 933.6353965902404
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 933.6353965902405, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 180.46419340656627
# steps	 1000 	total rewards	 536.1571167178973
# Finished after 1497 timesteps (11.59497594833374 seconds) with total reward 786.9988868412757
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 786.9988868412732, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 251.55663538505877
# steps	 1000 	total rewards	 615.6396629606827
# steps	 1500 	total rewards	 974.5454548686362
# Finished after 1655 timesteps (15.870292901992798 seconds) with total reward 1087.9559089845159
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 1087.9559089845152, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 287.5206485721802
# steps	 1000 	total rewards	 665.2471719741759
# steps	 1500 	total rewards	 1021.0528483926507
# Finished after 1729 timesteps (15.535195350646973 seconds) with total reward 1176.4516615432574
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 1176.4516615432585, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 278.86972648431293
# steps	 1000 	total rewards	 625.1561113533623
# steps	 1500 	total rewards	 978.1322409428257
# Finished after 1681 timesteps (12.737539291381836 seconds) with total reward 1091.4919579542598
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 1091.4919579542595, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 238.30635185984642
# steps	 1000 	total rewards	 591.8145618998964
# steps	 1500 	total rewards	 953.4216600906755
# Finished after 1621 timesteps (12.504488945007324 seconds) with total reward 1030.2315868383607
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 1030.231586838361, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 238.4005364962573
# steps	 1000 	total rewards	 597.8233186640654
# steps	 1500 	total rewards	 953.5207470575947
# Finished after 1634 timesteps (15.252997398376465 seconds) with total reward 1034.3859718888573
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 1034.3859718888577, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 275.67253901008155
# steps	 1000 	total rewards	 626.5444608980383
# steps	 1500 	total rewards	 967.4884599462245
# Finished after 1726 timesteps (15.19983720779419 seconds) with total reward 1128.7272082279674
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 1128.7272082279674, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 210.2548042496294
# steps	 1000 	total rewards	 556.8896863651553
# Finished after 1475 timesteps (11.326706647872925 seconds) with total reward 810.9407019987381
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 810.9407019987378, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 256.94883769352884
# steps	 1000 	total rewards	 610.6369915873785
# steps	 1500 	total rewards	 942.895199988627
# Finished after 1636 timesteps (12.244253158569336 seconds) with total reward 1027.6535572533487
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 1027.6535572533496, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 244.62591100582003
# steps	 1000 	total rewards	 599.5558570764224
# steps	 1500 	total rewards	 919.9956894688482
# Finished after 1575 timesteps (15.571932077407837 seconds) with total reward 954.7338496430982
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 954.7338496430997, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 237.8887722185019
# steps	 1000 	total rewards	 616.6015235706046
# steps	 1500 	total rewards	 980.0892895227569
# Finished after 1681 timesteps (13.471380710601807 seconds) with total reward 1119.2223628982943
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 1119.2223628982927, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 276.91120206653784
# steps	 1000 	total rewards	 622.5257442469413
# steps	 1500 	total rewards	 995.6646249836303
# Finished after 1679 timesteps (13.21577262878418 seconds) with total reward 1120.8174992408335
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 1120.8174992408346, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 190.14313877653316
# steps	 1000 	total rewards	 538.70617894609
# Finished after 1465 timesteps (11.063720464706421 seconds) with total reward 776.5190812277863
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 776.5190812277863, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 223.31819234438282
# steps	 1000 	total rewards	 566.98295970209
# steps	 1500 	total rewards	 888.3998333709135
# Finished after 1564 timesteps (15.62959909439087 seconds) with total reward 934.3745516976121
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 934.3745516976134, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 292.6601015558965
# steps	 1000 	total rewards	 632.6790823122867
# steps	 1500 	total rewards	 1009.5342874587811
# Finished after 1749 timesteps (15.207489728927612 seconds) with total reward 1198.4812643312716
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 1198.481264331275, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 252.30825969034052
# steps	 1000 	total rewards	 610.4416693816453
# steps	 1500 	total rewards	 976.196180535155
# Finished after 1657 timesteps (12.653317928314209 seconds) with total reward 1076.6770424990284
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 1076.6770424990277, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f06a24eb7f0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f06a0ecb460>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f06a2acd070>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.792', 'efficiency': '0.539', 'TP': '365', 'FP': '52', 'FN': '9', 'precision': '0.875', 'recall': '0.976', 'f1': '0.923'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.505', 'efficiency': '0.505', 'TP': '219', 'FP': '33', 'FN': '10', 'precision': '0.869', 'recall': '0.956', 'f1': '0.911'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.705', 'ms1ms2_ratio': '0.854', 'efficiency': '0.517', 'TP': '322', 'FP': '60', 'FN': '12', 'precision': '0.843', 'recall': '0.964', 'f1': '0.899'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '368', 'FP': '65', 'FN': '4', 'precision': '0.850', 'recall': '0.989', 'f1': '0.914'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.717', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.678', 'efficiency': '0.541', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.718', 'ms1ms2_ratio': '2.080', 'efficiency': '0.505', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.687', 'efficiency': '0.508', 'TP': '379', 'FP': '49', 'FN': '15', 'precision': '0.886', 'recall': '0.962', 'f1': '0.922'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.720', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.671', 'ms1ms2_ratio': '1.603', 'efficiency': '0.500', 'TP': '199', 'FP': '39', 'FN': '13', 'precision': '0.836', 'recall': '0.939', 'f1': '0.884'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.686', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.698', 'ms1ms2_ratio': '1.995', 'efficiency': '0.489', 'TP': '174', 'FP': '22', 'FN': '10', 'precision': '0.888', 'recall': '0.946', 'f1': '0.916'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.861', 'efficiency': '0.541', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.593', 'efficiency': '0.531', 'TP': '434', 'FP': '52', 'FN': '12', 'precision': '0.893', 'recall': '0.973', 'f1': '0.931'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.700', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '312', 'FP': '48', 'FN': '12', 'precision': '0.867', 'recall': '0.963', 'f1': '0.912'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.696', 'efficiency': '0.538', 'TP': '388', 'FP': '62', 'FN': '18', 'precision': '0.862', 'recall': '0.956', 'f1': '0.907'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.714', 'ms1ms2_ratio': '1.165', 'efficiency': '0.519', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.971', 'efficiency': '0.499', 'TP': '298', 'FP': '41', 'FN': '6', 'precision': '0.879', 'recall': '0.980', 'f1': '0.927'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.851', 'efficiency': '0.528', 'TP': '339', 'FP': '52', 'FN': '5', 'precision': '0.867', 'recall': '0.985', 'f1': '0.922'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.377', 'efficiency': '0.510', 'TP': '241', 'FP': '31', 'FN': '9', 'precision': '0.886', 'recall': '0.964', 'f1': '0.923'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.592', 'efficiency': '0.523', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1802.932949                1874.0          0.347           0.095
# 1  random   -1937.826437                1955.0          0.160           0.033
# 2  random   -1835.303529                1897.0          0.340           0.078
# 3  random   -1837.515199                1897.0          0.308           0.094
# 4  random   -1868.280152                1916.0          0.259           0.047
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.007       0.075      0.223   0.106  0.144
# 1          0.003       0.021      0.190   0.035  0.059
# 2          0.005       0.068      0.172   0.081  0.110
# 3          0.006       0.070      0.252   0.101  0.144
# 4          0.004       0.057      0.150   0.050  0.075

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    PPO    1383.338508                   0.0          0.944           0.720
# 31    PPO    1333.117117                   0.0          0.958           0.805
# 32    PPO    1409.147536                   0.0          0.957           0.733
# 33    PPO    1371.223216                   0.0          0.945           0.741
# 34    PPO    1294.687847                   0.0          0.966           0.718
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.081       0.234      0.863   0.935  0.898
# 31          0.123       0.156      0.932   0.955  0.944
# 32          0.095       0.224      0.867   0.951  0.907
# 33          0.083       0.249      0.892   0.938  0.915
# 34          0.089       0.248      0.844   0.960  0.898

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
