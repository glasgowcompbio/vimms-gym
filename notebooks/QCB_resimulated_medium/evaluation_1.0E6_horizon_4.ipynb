# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-18 20:43:05.392 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb9c02afdf0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb9a02846a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb9c0d29940>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'exclusion_t0': 5,
#    'exclusion_t1': 120,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb9c02afdf0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb9a02846a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb9c0d29940>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb9c02afdf0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb9a02846a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb9c0d29940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['exclusion_t0'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d exclusion_t0 = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['exclusion_t0'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -485.1255096697572
# steps	 1000 	total rewards	 -934.2629910961201
# steps	 1500 	total rewards	 -1352.2036548902543
# Finished after 1989 timesteps (4.5636279582977295 seconds) with total reward -1802.8173247836012
# {'coverage_prop': '0.404', 'intensity_prop': '0.115', 'ms1ms2_ratio': '0.006', 'efficiency': '0.087', 'TP': '42', 'FP': '130', 'FN': '254', 'precision': '0.244', 'recall': '0.142', 'f1': '0.179', 'total_rewards': -1802.817324783602, 'invalid_action_count': 1857, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -495.9779356765746
# steps	 1000 	total rewards	 -957.5689922065558
# steps	 1500 	total rewards	 -1422.491944318466
# Finished after 1990 timesteps (2.5650599002838135 seconds) with total reward -1890.2631497667323
# {'coverage_prop': '0.313', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.005', 'efficiency': '0.041', 'TP': '16', 'FP': '66', 'FN': '180', 'precision': '0.195', 'recall': '0.082', 'f1': '0.115', 'total_rewards': -1890.2631497667326, 'invalid_action_count': 1921, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -483.0910638643452
# steps	 1000 	total rewards	 -937.2494826230836
# steps	 1500 	total rewards	 -1371.8609034464823
# Finished after 1985 timesteps (3.477895736694336 seconds) with total reward -1812.206919002012
# {'coverage_prop': '0.393', 'intensity_prop': '0.116', 'ms1ms2_ratio': '0.008', 'efficiency': '0.079', 'TP': '44', 'FP': '111', 'FN': '239', 'precision': '0.284', 'recall': '0.155', 'f1': '0.201', 'total_rewards': -1812.206919002012, 'invalid_action_count': 1864, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -488.61528641172436
# steps	 1000 	total rewards	 -922.1396558353638
# steps	 1500 	total rewards	 -1388.6799534817326
# Finished after 1992 timesteps (3.6915979385375977 seconds) with total reward -1849.7183860998643
# {'coverage_prop': '0.314', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.004', 'efficiency': '0.072', 'TP': '29', 'FP': '113', 'FN': '310', 'precision': '0.204', 'recall': '0.086', 'f1': '0.121', 'total_rewards': -1849.7183860998643, 'invalid_action_count': 1891, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -930.8227779782505
# steps	 1500 	total rewards	 -1404.2861960971086
# Finished after 1989 timesteps (4.17293381690979 seconds) with total reward -1839.8125081680294
# {'coverage_prop': '0.357', 'intensity_prop': '0.078', 'ms1ms2_ratio': '0.006', 'efficiency': '0.079', 'TP': '28', 'FP': '128', 'FN': '281', 'precision': '0.179', 'recall': '0.091', 'f1': '0.120', 'total_rewards': -1839.8125081680291, 'invalid_action_count': 1886, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -487.8331673037467
# steps	 1000 	total rewards	 -963.7861945337834
# steps	 1500 	total rewards	 -1438.82495339861
# Finished after 1987 timesteps (2.234844923019409 seconds) with total reward -1899.4047054510875
# {'coverage_prop': '0.385', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.007', 'efficiency': '0.039', 'TP': '20', 'FP': '57', 'FN': '123', 'precision': '0.260', 'recall': '0.140', 'f1': '0.182', 'total_rewards': -1899.4047054510875, 'invalid_action_count': 1924, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -943.0295757474157
# steps	 1500 	total rewards	 -1336.5250536467363
# Finished after 1993 timesteps (3.733222246170044 seconds) with total reward -1785.811509022803
# {'coverage_prop': '0.416', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.004', 'efficiency': '0.100', 'TP': '45', 'FP': '154', 'FN': '279', 'precision': '0.226', 'recall': '0.139', 'f1': '0.172', 'total_rewards': -1785.8115090228032, 'invalid_action_count': 1851, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -984.652121991023
# steps	 1500 	total rewards	 -1481.1480002343978
# Finished after 1996 timesteps (2.5627079010009766 seconds) with total reward -1975.1480002343978
# {'coverage_prop': '0.083', 'intensity_prop': '0.010', 'ms1ms2_ratio': '0.002', 'efficiency': '0.009', 'TP': '2', 'FP': '15', 'FN': '187', 'precision': '0.118', 'recall': '0.011', 'f1': '0.019', 'total_rewards': -1975.1480002343978, 'invalid_action_count': 1980, 'num_ms1_scans': 4, 'num_ms2_scans': 1992}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -470.5908092451686
# steps	 1000 	total rewards	 -929.0095090752773
# steps	 1500 	total rewards	 -1378.8014100592754
# Finished after 1989 timesteps (4.042119979858398 seconds) with total reward -1826.2608154786979
# {'coverage_prop': '0.340', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.006', 'efficiency': '0.073', 'TP': '33', 'FP': '111', 'FN': '280', 'precision': '0.229', 'recall': '0.105', 'f1': '0.144', 'total_rewards': -1826.2608154786976, 'invalid_action_count': 1876, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -973.9490401940029
# steps	 1500 	total rewards	 -1442.2477687905962
# Finished after 1991 timesteps (3.039245128631592 seconds) with total reward -1875.693810880724
# {'coverage_prop': '0.271', 'intensity_prop': '0.067', 'ms1ms2_ratio': '0.005', 'efficiency': '0.052', 'TP': '23', 'FP': '81', 'FN': '280', 'precision': '0.221', 'recall': '0.076', 'f1': '0.113', 'total_rewards': -1875.6938108807244, 'invalid_action_count': 1910, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -475.44915814811327
# steps	 1000 	total rewards	 -940.9382857913615
# steps	 1500 	total rewards	 -1396.8898755730916
# Finished after 1990 timesteps (3.928539991378784 seconds) with total reward -1860.2091930118925
# {'coverage_prop': '0.316', 'intensity_prop': '0.057', 'ms1ms2_ratio': '0.005', 'efficiency': '0.071', 'TP': '24', 'FP': '116', 'FN': '303', 'precision': '0.171', 'recall': '0.073', 'f1': '0.103', 'total_rewards': -1860.2091930118925, 'invalid_action_count': 1899, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -494.46849866455574
# steps	 1000 	total rewards	 -964.6539383789716
# steps	 1500 	total rewards	 -1429.6230616417504
# Finished after 1992 timesteps (2.777101993560791 seconds) with total reward -1898.760950659024
# {'coverage_prop': '0.309', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.004', 'efficiency': '0.039', 'TP': '12', 'FP': '65', 'FN': '172', 'precision': '0.156', 'recall': '0.065', 'f1': '0.092', 'total_rewards': -1898.7609506590243, 'invalid_action_count': 1925, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -485.4798417509007
# steps	 1000 	total rewards	 -947.1878563910809
# steps	 1500 	total rewards	 -1407.1713220056922
# Finished after 1988 timesteps (3.253740072250366 seconds) with total reward -1866.582459621047
# {'coverage_prop': '0.367', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.006', 'efficiency': '0.047', 'TP': '16', 'FP': '76', 'FN': '159', 'precision': '0.174', 'recall': '0.091', 'f1': '0.120', 'total_rewards': -1866.5824596210464, 'invalid_action_count': 1901, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -486.92871189329605
# steps	 1000 	total rewards	 -947.2211573576177
# steps	 1500 	total rewards	 -1378.0147651555176
# Finished after 1986 timesteps (3.225104808807373 seconds) with total reward -1840.8114381409364
# {'coverage_prop': '0.443', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.007', 'efficiency': '0.067', 'TP': '41', 'FP': '92', 'FN': '167', 'precision': '0.308', 'recall': '0.197', 'f1': '0.240', 'total_rewards': -1840.811438140936, 'invalid_action_count': 1883, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -497.0
# steps	 1000 	total rewards	 -972.7987832930745
# steps	 1500 	total rewards	 -1434.2513472617961
# Finished after 1989 timesteps (2.3132011890411377 seconds) with total reward -1892.8547082978866
# {'coverage_prop': '0.359', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.006', 'efficiency': '0.037', 'TP': '17', 'FP': '57', 'FN': '132', 'precision': '0.230', 'recall': '0.114', 'f1': '0.152', 'total_rewards': -1892.854708297886, 'invalid_action_count': 1921, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -1000.0
# steps	 1500 	total rewards	 -1465.4480771851645
# Finished after 1994 timesteps (2.907111167907715 seconds) with total reward -1922.0618234579263
# {'coverage_prop': '0.189', 'intensity_prop': '0.046', 'ms1ms2_ratio': '0.003', 'efficiency': '0.039', 'TP': '17', 'FP': '60', 'FN': '330', 'precision': '0.221', 'recall': '0.049', 'f1': '0.080', 'total_rewards': -1922.0618234579265, 'invalid_action_count': 1945, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -495.7392759872231
# steps	 1000 	total rewards	 -929.1529988929569
# steps	 1500 	total rewards	 -1327.742698329533
# Finished after 1987 timesteps (4.06374716758728 seconds) with total reward -1762.1595312308689
# {'coverage_prop': '0.450', 'intensity_prop': '0.135', 'ms1ms2_ratio': '0.007', 'efficiency': '0.113', 'TP': '68', 'FP': '156', 'FN': '274', 'precision': '0.304', 'recall': '0.199', 'f1': '0.240', 'total_rewards': -1762.1595312308689, 'invalid_action_count': 1831, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -1000.0
# steps	 1500 	total rewards	 -1460.3909525326267
# Finished after 1993 timesteps (3.321815013885498 seconds) with total reward -1903.0445834943123
# {'coverage_prop': '0.255', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.004', 'efficiency': '0.048', 'TP': '21', 'FP': '74', 'FN': '277', 'precision': '0.221', 'recall': '0.070', 'f1': '0.107', 'total_rewards': -1903.0445834943125, 'invalid_action_count': 1929, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -478.1986173005881
# steps	 1000 	total rewards	 -954.3414406199689
# steps	 1500 	total rewards	 -1405.1223514341855
# Finished after 1988 timesteps (3.000386953353882 seconds) with total reward -1854.8284110025784
# {'coverage_prop': '0.354', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.006', 'efficiency': '0.054', 'TP': '27', 'FP': '80', 'FN': '195', 'precision': '0.252', 'recall': '0.122', 'f1': '0.164', 'total_rewards': -1854.8284110025782, 'invalid_action_count': 1894, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -487.3788707982146
# steps	 1000 	total rewards	 -951.9914673786212
# steps	 1500 	total rewards	 -1406.1400696044902
# Finished after 1990 timesteps (2.754054069519043 seconds) with total reward -1857.5733860474713
# {'coverage_prop': '0.374', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.005', 'efficiency': '0.050', 'TP': '17', 'FP': '82', 'FN': '166', 'precision': '0.172', 'recall': '0.093', 'f1': '0.121', 'total_rewards': -1857.5733860474713, 'invalid_action_count': 1896, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -465.23356159090423
# steps	 1000 	total rewards	 -905.6220523406096
# steps	 1500 	total rewards	 -1342.495271845935
# Finished after 1989 timesteps (4.149315118789673 seconds) with total reward -1803.9678363375178
# {'coverage_prop': '0.385', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.006', 'efficiency': '0.091', 'TP': '45', 'FP': '135', 'FN': '288', 'precision': '0.250', 'recall': '0.135', 'f1': '0.175', 'total_rewards': -1803.9678363375174, 'invalid_action_count': 1860, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -982.0023128123046
# steps	 1500 	total rewards	 -1435.2287744416724
# Finished after 1990 timesteps (2.611309051513672 seconds) with total reward -1903.443598576126
# {'coverage_prop': '0.295', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.005', 'efficiency': '0.035', 'TP': '19', 'FP': '50', 'FN': '165', 'precision': '0.275', 'recall': '0.103', 'f1': '0.150', 'total_rewards': -1903.4435985761259, 'invalid_action_count': 1931, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -493.4353233936355
# steps	 1000 	total rewards	 -983.9406065451637
# steps	 1500 	total rewards	 -1452.4133664479436
# Finished after 1991 timesteps (2.8913769721984863 seconds) with total reward -1902.7272980709085
# {'coverage_prop': '0.233', 'intensity_prop': '0.078', 'ms1ms2_ratio': '0.005', 'efficiency': '0.038', 'TP': '23', 'FP': '52', 'FN': '247', 'precision': '0.307', 'recall': '0.085', 'f1': '0.133', 'total_rewards': -1902.7272980709083, 'invalid_action_count': 1928, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -493.8523483034519
# steps	 1000 	total rewards	 -975.7666146078634
# steps	 1500 	total rewards	 -1467.252639389481
# Finished after 1987 timesteps (3.281193971633911 seconds) with total reward -1918.5161320567424
# {'coverage_prop': '0.203', 'intensity_prop': '0.040', 'ms1ms2_ratio': '0.007', 'efficiency': '0.032', 'TP': '9', 'FP': '54', 'FN': '247', 'precision': '0.143', 'recall': '0.035', 'f1': '0.056', 'total_rewards': -1918.5161320567422, 'invalid_action_count': 1937, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -491.0707345662503
# steps	 1000 	total rewards	 -972.9701592676564
# steps	 1500 	total rewards	 -1461.0710056456323
# Finished after 1994 timesteps (3.219595193862915 seconds) with total reward -1924.0100975481378
# {'coverage_prop': '0.159', 'intensity_prop': '0.033', 'ms1ms2_ratio': '0.003', 'efficiency': '0.028', 'TP': '8', 'FP': '47', 'FN': '290', 'precision': '0.145', 'recall': '0.027', 'f1': '0.045', 'total_rewards': -1924.0100975481375, 'invalid_action_count': 1945, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -488.950710801596
# steps	 1000 	total rewards	 -949.9528510681245
# steps	 1500 	total rewards	 -1389.5356634433292
# Finished after 1991 timesteps (3.463183879852295 seconds) with total reward -1846.2679815689557
# {'coverage_prop': '0.346', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.005', 'efficiency': '0.069', 'TP': '29', 'FP': '108', 'FN': '259', 'precision': '0.212', 'recall': '0.101', 'f1': '0.136', 'total_rewards': -1846.2679815689562, 'invalid_action_count': 1893, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -490.64115390044594
# steps	 1000 	total rewards	 -947.0554403292722
# steps	 1500 	total rewards	 -1407.7025979328391
# Finished after 1987 timesteps (2.3439769744873047 seconds) with total reward -1872.2044897173698
# {'coverage_prop': '0.404', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.007', 'efficiency': '0.042', 'TP': '18', 'FP': '64', 'FN': '121', 'precision': '0.220', 'recall': '0.129', 'f1': '0.163', 'total_rewards': -1872.2044897173698, 'invalid_action_count': 1907, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -492.7814861146468
# steps	 1000 	total rewards	 -972.5277735459938
# steps	 1500 	total rewards	 -1433.3106202043548
# Finished after 1992 timesteps (2.5755438804626465 seconds) with total reward -1895.6276872214064
# {'coverage_prop': '0.260', 'intensity_prop': '0.066', 'ms1ms2_ratio': '0.004', 'efficiency': '0.037', 'TP': '14', 'FP': '59', 'FN': '208', 'precision': '0.192', 'recall': '0.063', 'f1': '0.095', 'total_rewards': -1895.6276872214066, 'invalid_action_count': 1927, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -463.674403889825
# steps	 1000 	total rewards	 -901.8549949511519
# steps	 1500 	total rewards	 -1374.297609165629
# Finished after 1986 timesteps (4.73944616317749 seconds) with total reward -1827.8655664772634
# {'coverage_prop': '0.300', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.007', 'efficiency': '0.075', 'TP': '34', 'FP': '114', 'FN': '345', 'precision': '0.230', 'recall': '0.090', 'f1': '0.129', 'total_rewards': -1827.865566477263, 'invalid_action_count': 1875, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -495.03179776259105
# steps	 1000 	total rewards	 -980.4126850922421
# steps	 1500 	total rewards	 -1432.769742705358
# Finished after 1993 timesteps (2.925018072128296 seconds) with total reward -1898.0699773430877
# {'coverage_prop': '0.270', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.004', 'efficiency': '0.041', 'TP': '19', 'FP': '63', 'FN': '222', 'precision': '0.232', 'recall': '0.079', 'f1': '0.118', 'total_rewards': -1898.069977343087, 'invalid_action_count': 1924, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# method = DQN max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.64GB > 0.37GB
# steps	 500 	total rewards	 79.35721616230934
# steps	 1000 	total rewards	 187.46769849451232
# Finished after 1323 timesteps (6.062462091445923 seconds) with total reward 242.01491676422395
# {'coverage_prop': '0.925', 'intensity_prop': '0.594', 'ms1ms2_ratio': '1.048', 'efficiency': '0.610', 'TP': '286', 'FP': '108', 'FN': '32', 'precision': '0.726', 'recall': '0.899', 'f1': '0.803', 'total_rewards': 242.01491676422373, 'invalid_action_count': 7, 'num_ms1_scans': 677, 'num_ms2_scans': 646}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 69.09807737033837
# steps	 1000 	total rewards	 164.5799591464508
# Finished after 1275 timesteps (4.903052091598511 seconds) with total reward 186.5705127050651
# {'coverage_prop': '0.947', 'intensity_prop': '0.677', 'ms1ms2_ratio': '1.318', 'efficiency': '0.451', 'TP': '206', 'FP': '42', 'FN': '14', 'precision': '0.831', 'recall': '0.936', 'f1': '0.880', 'total_rewards': 186.57051270506514, 'invalid_action_count': 13, 'num_ms1_scans': 725, 'num_ms2_scans': 550}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 72.2844615937899
# steps	 1000 	total rewards	 168.64953527947333
# Finished after 1293 timesteps (5.962037086486816 seconds) with total reward 216.5027243545891
# {'coverage_prop': '0.896', 'intensity_prop': '0.560', 'ms1ms2_ratio': '1.206', 'efficiency': '0.602', 'TP': '244', 'FP': '109', 'FN': '41', 'precision': '0.691', 'recall': '0.856', 'f1': '0.765', 'total_rewards': 216.50272435458902, 'invalid_action_count': 9, 'num_ms1_scans': 707, 'num_ms2_scans': 586}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 79.15459726573108
# steps	 1000 	total rewards	 197.29535114104155
# Finished after 1324 timesteps (5.533716917037964 seconds) with total reward 252.2323502571232
# {'coverage_prop': '0.918', 'intensity_prop': '0.618', 'ms1ms2_ratio': '1.043', 'efficiency': '0.640', 'TP': '330', 'FP': '85', 'FN': '37', 'precision': '0.795', 'recall': '0.899', 'f1': '0.844', 'total_rewards': 252.23235025712307, 'invalid_action_count': 6, 'num_ms1_scans': 676, 'num_ms2_scans': 648}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 67.30354203664314
# steps	 1000 	total rewards	 182.40782118557937
# Finished after 1326 timesteps (6.237398862838745 seconds) with total reward 223.34079556687288
# {'coverage_prop': '0.918', 'intensity_prop': '0.598', 'ms1ms2_ratio': '1.037', 'efficiency': '0.616', 'TP': '295', 'FP': '106', 'FN': '36', 'precision': '0.736', 'recall': '0.891', 'f1': '0.806', 'total_rewards': 223.34079556687308, 'invalid_action_count': 20, 'num_ms1_scans': 675, 'num_ms2_scans': 651}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 55.186463706881526
# steps	 1000 	total rewards	 124.69890781358961
# Finished after 1236 timesteps (4.468773126602173 seconds) with total reward 147.39713318034802
# {'coverage_prop': '0.940', 'intensity_prop': '0.683', 'ms1ms2_ratio': '1.624', 'efficiency': '0.399', 'TP': '163', 'FP': '25', 'FN': '12', 'precision': '0.867', 'recall': '0.931', 'f1': '0.898', 'total_rewards': 147.39713318034802, 'invalid_action_count': 5, 'num_ms1_scans': 765, 'num_ms2_scans': 471}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 90.98382468712751
# steps	 1000 	total rewards	 199.94403040550455
# Finished after 1321 timesteps (6.456204652786255 seconds) with total reward 248.97865669905448
# {'coverage_prop': '0.908', 'intensity_prop': '0.568', 'ms1ms2_ratio': '1.061', 'efficiency': '0.677', 'TP': '304', 'FP': '130', 'FN': '44', 'precision': '0.700', 'recall': '0.874', 'f1': '0.777', 'total_rewards': 248.97865669905417, 'invalid_action_count': 11, 'num_ms1_scans': 680, 'num_ms2_scans': 641}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 44.591905541671046
# steps	 1000 	total rewards	 124.06720665686835
# Finished after 1251 timesteps (3.825374126434326 seconds) with total reward 144.56087618618886
# {'coverage_prop': '0.951', 'intensity_prop': '0.675', 'ms1ms2_ratio': '1.502', 'efficiency': '0.388', 'TP': '164', 'FP': '30', 'FN': '10', 'precision': '0.845', 'recall': '0.943', 'f1': '0.891', 'total_rewards': 144.56087618618895, 'invalid_action_count': 10, 'num_ms1_scans': 751, 'num_ms2_scans': 500}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 87.3368439813754
# steps	 1000 	total rewards	 178.45119000561232
# Finished after 1304 timesteps (6.484724998474121 seconds) with total reward 229.23828951938566
# {'coverage_prop': '0.906', 'intensity_prop': '0.571', 'ms1ms2_ratio': '1.145', 'efficiency': '0.632', 'TP': '275', 'FP': '109', 'FN': '40', 'precision': '0.716', 'recall': '0.873', 'f1': '0.787', 'total_rewards': 229.23828951938566, 'invalid_action_count': 7, 'num_ms1_scans': 696, 'num_ms2_scans': 608}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 64.10303394195803
# steps	 1000 	total rewards	 169.69060726441236
# Finished after 1309 timesteps (5.7843780517578125 seconds) with total reward 209.15714317376415
# {'coverage_prop': '0.922', 'intensity_prop': '0.600', 'ms1ms2_ratio': '1.118', 'efficiency': '0.573', 'TP': '260', 'FP': '94', 'FN': '30', 'precision': '0.734', 'recall': '0.897', 'f1': '0.807', 'total_rewards': 209.15714317376413, 'invalid_action_count': 9, 'num_ms1_scans': 691, 'num_ms2_scans': 618}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 73.41960008710744
# steps	 1000 	total rewards	 191.15585001696422
# Finished after 1361 timesteps (5.615957975387573 seconds) with total reward 248.32942507728325
# {'coverage_prop': '0.916', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.888', 'efficiency': '0.563', 'TP': '320', 'FP': '86', 'FN': '37', 'precision': '0.788', 'recall': '0.896', 'f1': '0.839', 'total_rewards': 248.32942507728316, 'invalid_action_count': 11, 'num_ms1_scans': 640, 'num_ms2_scans': 721}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 58.45427549094326
# steps	 1000 	total rewards	 132.31707587340475
# Finished after 1258 timesteps (5.244218111038208 seconds) with total reward 157.94605350927918
# {'coverage_prop': '0.920', 'intensity_prop': '0.666', 'ms1ms2_ratio': '1.443', 'efficiency': '0.445', 'TP': '193', 'FP': '36', 'FN': '20', 'precision': '0.843', 'recall': '0.906', 'f1': '0.873', 'total_rewards': 157.94605350927884, 'invalid_action_count': 9, 'num_ms1_scans': 743, 'num_ms2_scans': 515}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 58.360803941903185
# steps	 1000 	total rewards	 135.53135373329644
# Finished after 1245 timesteps (4.570268869400024 seconds) with total reward 157.8163301776479
# {'coverage_prop': '0.936', 'intensity_prop': '0.616', 'ms1ms2_ratio': '1.551', 'efficiency': '0.482', 'TP': '172', 'FP': '63', 'FN': '16', 'precision': '0.732', 'recall': '0.915', 'f1': '0.813', 'total_rewards': 157.81633017764787, 'invalid_action_count': 10, 'num_ms1_scans': 757, 'num_ms2_scans': 488}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 52.302637046375224
# steps	 1000 	total rewards	 146.28508206258599
# Finished after 1326 timesteps (6.070000886917114 seconds) with total reward 184.2453788818628
# {'coverage_prop': '0.943', 'intensity_prop': '0.619', 'ms1ms2_ratio': '1.037', 'efficiency': '0.435', 'TP': '208', 'FP': '75', 'FN': '17', 'precision': '0.735', 'recall': '0.924', 'f1': '0.819', 'total_rewards': 184.24537888186276, 'invalid_action_count': 12, 'num_ms1_scans': 675, 'num_ms2_scans': 651}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 54.24745922809538
# steps	 1000 	total rewards	 127.3993802468963
# Finished after 1273 timesteps (3.9013540744781494 seconds) with total reward 148.80112714785702
# {'coverage_prop': '0.927', 'intensity_prop': '0.638', 'ms1ms2_ratio': '1.332', 'efficiency': '0.350', 'TP': '150', 'FP': '41', 'FN': '15', 'precision': '0.785', 'recall': '0.909', 'f1': '0.843', 'total_rewards': 148.80112714785707, 'invalid_action_count': 8, 'num_ms1_scans': 727, 'num_ms2_scans': 546}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 67.17039822186905
# steps	 1000 	total rewards	 179.19029658068774
# Finished after 1316 timesteps (6.611764192581177 seconds) with total reward 235.06608253538957
# {'coverage_prop': '0.936', 'intensity_prop': '0.643', 'ms1ms2_ratio': '1.086', 'efficiency': '0.604', 'TP': '302', 'FP': '79', 'FN': '26', 'precision': '0.793', 'recall': '0.921', 'f1': '0.852', 'total_rewards': 235.06608253538957, 'invalid_action_count': 10, 'num_ms1_scans': 685, 'num_ms2_scans': 631}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 91.45353313062617
# steps	 1000 	total rewards	 201.56933885317156
# Finished after 1349 timesteps (5.706699848175049 seconds) with total reward 258.07776897147465
# {'coverage_prop': '0.912', 'intensity_prop': '0.595', 'ms1ms2_ratio': '0.933', 'efficiency': '0.650', 'TP': '345', 'FP': '109', 'FN': '44', 'precision': '0.760', 'recall': '0.887', 'f1': '0.819', 'total_rewards': 258.07776897147477, 'invalid_action_count': 21, 'num_ms1_scans': 651, 'num_ms2_scans': 698}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 79.10956625786389
# steps	 1000 	total rewards	 180.16367829519027
# Finished after 1283 timesteps (6.4217541217803955 seconds) with total reward 218.7645608371729
# {'coverage_prop': '0.922', 'intensity_prop': '0.625', 'ms1ms2_ratio': '1.267', 'efficiency': '0.606', 'TP': '274', 'FP': '69', 'FN': '29', 'precision': '0.799', 'recall': '0.904', 'f1': '0.848', 'total_rewards': 218.76456083717278, 'invalid_action_count': 5, 'num_ms1_scans': 717, 'num_ms2_scans': 566}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 60.3250594778727
# steps	 1000 	total rewards	 147.8769545315576
# Finished after 1264 timesteps (4.697853088378906 seconds) with total reward 191.20665854587372
# {'coverage_prop': '0.930', 'intensity_prop': '0.616', 'ms1ms2_ratio': '1.398', 'efficiency': '0.533', 'TP': '215', 'FP': '66', 'FN': '21', 'precision': '0.765', 'recall': '0.911', 'f1': '0.832', 'total_rewards': 191.20665854587372, 'invalid_action_count': 4, 'num_ms1_scans': 737, 'num_ms2_scans': 527}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 54.93903321955821
# steps	 1000 	total rewards	 145.81252607722558
# Finished after 1255 timesteps (6.051857948303223 seconds) with total reward 178.81197568485229
# {'coverage_prop': '0.966', 'intensity_prop': '0.646', 'ms1ms2_ratio': '1.466', 'efficiency': '0.503', 'TP': '192', 'FP': '64', 'FN': '9', 'precision': '0.750', 'recall': '0.955', 'f1': '0.840', 'total_rewards': 178.8119756848524, 'invalid_action_count': 7, 'num_ms1_scans': 746, 'num_ms2_scans': 509}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 74.9093758940092
# steps	 1000 	total rewards	 184.07661536867934
# Finished after 1338 timesteps (5.723065137863159 seconds) with total reward 232.40995424322313
# {'coverage_prop': '0.870', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.982', 'efficiency': '0.603', 'TP': '304', 'FP': '103', 'FN': '61', 'precision': '0.747', 'recall': '0.833', 'f1': '0.788', 'total_rewards': 232.40995424322324, 'invalid_action_count': 15, 'num_ms1_scans': 663, 'num_ms2_scans': 675}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 51.20990246851666
# steps	 1000 	total rewards	 134.29854452505145
# Finished after 1243 timesteps (5.69289493560791 seconds) with total reward 158.4092485571383
# {'coverage_prop': '0.927', 'intensity_prop': '0.634', 'ms1ms2_ratio': '1.568', 'efficiency': '0.448', 'TP': '166', 'FP': '51', 'FN': '17', 'precision': '0.765', 'recall': '0.907', 'f1': '0.830', 'total_rewards': 158.40924855713828, 'invalid_action_count': 6, 'num_ms1_scans': 759, 'num_ms2_scans': 484}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 68.01957430379892
# steps	 1000 	total rewards	 163.2997027011303
# Finished after 1278 timesteps (4.970607757568359 seconds) with total reward 199.67040278230192
# {'coverage_prop': '0.950', 'intensity_prop': '0.623', 'ms1ms2_ratio': '1.299', 'efficiency': '0.550', 'TP': '232', 'FP': '74', 'FN': '16', 'precision': '0.758', 'recall': '0.935', 'f1': '0.838', 'total_rewards': 199.67040278230212, 'invalid_action_count': 4, 'num_ms1_scans': 722, 'num_ms2_scans': 556}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 72.76397495649995
# steps	 1000 	total rewards	 167.07726027129755
# Finished after 1256 timesteps (4.279476881027222 seconds) with total reward 195.79916029971903
# {'coverage_prop': '0.929', 'intensity_prop': '0.654', 'ms1ms2_ratio': '1.463', 'efficiency': '0.565', 'TP': '232', 'FP': '56', 'FN': '22', 'precision': '0.806', 'recall': '0.913', 'f1': '0.856', 'total_rewards': 195.79916029971898, 'invalid_action_count': 5, 'num_ms1_scans': 746, 'num_ms2_scans': 510}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 73.28941409693265
# steps	 1000 	total rewards	 161.69068923941077
# Finished after 1299 timesteps (6.602135896682739 seconds) with total reward 207.21638531272384
# {'coverage_prop': '0.948', 'intensity_prop': '0.607', 'ms1ms2_ratio': '1.176', 'efficiency': '0.548', 'TP': '241', 'FP': '86', 'FN': '18', 'precision': '0.737', 'recall': '0.931', 'f1': '0.823', 'total_rewards': 207.2163853127237, 'invalid_action_count': 20, 'num_ms1_scans': 702, 'num_ms2_scans': 597}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 74.64817980641722
# steps	 1000 	total rewards	 174.2501320885782
# Finished after 1298 timesteps (5.216179847717285 seconds) with total reward 224.03026821362107
# {'coverage_prop': '0.927', 'intensity_prop': '0.624', 'ms1ms2_ratio': '1.178', 'efficiency': '0.616', 'TP': '281', 'FP': '86', 'FN': '29', 'precision': '0.766', 'recall': '0.906', 'f1': '0.830', 'total_rewards': 224.03026821362116, 'invalid_action_count': 10, 'num_ms1_scans': 702, 'num_ms2_scans': 596}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 44.203741205178964
# steps	 1000 	total rewards	 125.11024897033671
# Finished after 1243 timesteps (3.920261859893799 seconds) with total reward 147.43924693171377
# {'coverage_prop': '0.946', 'intensity_prop': '0.675', 'ms1ms2_ratio': '1.563', 'efficiency': '0.396', 'TP': '158', 'FP': '34', 'FN': '11', 'precision': '0.823', 'recall': '0.935', 'f1': '0.875', 'total_rewards': 147.4392469317137, 'invalid_action_count': 6, 'num_ms1_scans': 758, 'num_ms2_scans': 485}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 57.490694981222596
# steps	 1000 	total rewards	 146.77560590756065
# Finished after 1268 timesteps (6.139009952545166 seconds) with total reward 191.677666110563
# {'coverage_prop': '0.950', 'intensity_prop': '0.648', 'ms1ms2_ratio': '1.370', 'efficiency': '0.499', 'TP': '209', 'FP': '58', 'FN': '14', 'precision': '0.783', 'recall': '0.937', 'f1': '0.853', 'total_rewards': 191.67766611056297, 'invalid_action_count': 7, 'num_ms1_scans': 733, 'num_ms2_scans': 535}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 86.18538597180981
# steps	 1000 	total rewards	 172.77254422138918
# Finished after 1362 timesteps (5.733518838882446 seconds) with total reward 244.07797495447073
# {'coverage_prop': '0.858', 'intensity_prop': '0.550', 'ms1ms2_ratio': '0.881', 'efficiency': '0.584', 'TP': '307', 'FP': '116', 'FN': '70', 'precision': '0.726', 'recall': '0.814', 'f1': '0.768', 'total_rewards': 244.07797495447068, 'invalid_action_count': 18, 'num_ms1_scans': 638, 'num_ms2_scans': 724}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 69.3862514949731
# steps	 1000 	total rewards	 154.2618790565915
# Finished after 1264 timesteps (4.540112018585205 seconds) with total reward 184.59801093176566
# {'coverage_prop': '0.941', 'intensity_prop': '0.643', 'ms1ms2_ratio': '1.394', 'efficiency': '0.542', 'TP': '223', 'FP': '63', 'FN': '18', 'precision': '0.780', 'recall': '0.925', 'f1': '0.846', 'total_rewards': 184.59801093176551, 'invalid_action_count': 7, 'num_ms1_scans': 736, 'num_ms2_scans': 528}
#
# method = topN max_peaks = 200 N = 10 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 26.228181350340165
# steps	 1000 	total rewards	 49.924825648372654
# steps	 1500 	total rewards	 80.18997067812609
# Finished after 1783 timesteps (11.341014862060547 seconds) with total reward 83.64224614290413
# {'coverage_prop': '0.798', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.139', 'efficiency': '0.217', 'TP': '289', 'FP': '51', 'FN': '86', 'precision': '0.850', 'recall': '0.771', 'f1': '0.808', 'total_rewards': 83.64224614290416, 'invalid_action_count': 190, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 24.050552639406853
# steps	 1000 	total rewards	 38.64669712610797
# steps	 1500 	total rewards	 62.34776689687884
# Finished after 1754 timesteps (8.367565870285034 seconds) with total reward 79.06681323937315
# {'coverage_prop': '0.931', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.163', 'efficiency': '0.162', 'TP': '227', 'FP': '17', 'FN': '18', 'precision': '0.930', 'recall': '0.927', 'f1': '0.928', 'total_rewards': 79.06681323937316, 'invalid_action_count': 182, 'num_ms1_scans': 246, 'num_ms2_scans': 1508}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 22.75441724814904
# steps	 1000 	total rewards	 50.31400466229792
# steps	 1500 	total rewards	 69.32842151957662
# Finished after 1771 timesteps (9.603909969329834 seconds) with total reward 81.90606985396587
# {'coverage_prop': '0.812', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.149', 'efficiency': '0.208', 'TP': '264', 'FP': '56', 'FN': '74', 'precision': '0.825', 'recall': '0.781', 'f1': '0.802', 'total_rewards': 81.90606985396589, 'invalid_action_count': 191, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 15.56479316230376
# steps	 1000 	total rewards	 39.38428187710611
# steps	 1500 	total rewards	 68.44727376281782
# Finished after 1783 timesteps (9.985707998275757 seconds) with total reward 82.9161620530575
# {'coverage_prop': '0.823', 'intensity_prop': '0.611', 'ms1ms2_ratio': '0.139', 'efficiency': '0.238', 'TP': '320', 'FP': '52', 'FN': '80', 'precision': '0.860', 'recall': '0.800', 'f1': '0.829', 'total_rewards': 82.91616205305745, 'invalid_action_count': 208, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 8.886850170704307
# steps	 1000 	total rewards	 40.17851485172865
# steps	 1500 	total rewards	 85.62629761800156
# Finished after 1776 timesteps (9.946080923080444 seconds) with total reward 104.85857942913408
# {'coverage_prop': '0.872', 'intensity_prop': '0.644', 'ms1ms2_ratio': '0.144', 'efficiency': '0.245', 'TP': '321', 'FP': '60', 'FN': '56', 'precision': '0.843', 'recall': '0.851', 'f1': '0.847', 'total_rewards': 104.85857942913411, 'invalid_action_count': 201, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 21.23793803551461
# steps	 1000 	total rewards	 47.572961679200915
# steps	 1500 	total rewards	 65.03594187207844
# Finished after 1715 timesteps (8.355107069015503 seconds) with total reward 78.30159591786449
# {'coverage_prop': '0.935', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.199', 'efficiency': '0.131', 'TP': '177', 'FP': '10', 'FN': '13', 'precision': '0.947', 'recall': '0.932', 'f1': '0.939', 'total_rewards': 78.30159591786439, 'invalid_action_count': 145, 'num_ms1_scans': 285, 'num_ms2_scans': 1430}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 21.741062939383784
# steps	 1000 	total rewards	 42.44539444052348
# steps	 1500 	total rewards	 73.39062860594903
# Finished after 1777 timesteps (12.551790714263916 seconds) with total reward 82.04916161208602
# {'coverage_prop': '0.757', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.144', 'efficiency': '0.233', 'TP': '283', 'FP': '79', 'FN': '116', 'precision': '0.782', 'recall': '0.709', 'f1': '0.744', 'total_rewards': 82.04916161208595, 'invalid_action_count': 190, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 20.886818499891653
# steps	 1000 	total rewards	 40.58715370130594
# steps	 1500 	total rewards	 61.328544338834234
# Finished after 1720 timesteps (8.244155883789062 seconds) with total reward 74.6590971299181
# {'coverage_prop': '0.917', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.194', 'efficiency': '0.130', 'TP': '181', 'FP': '6', 'FN': '17', 'precision': '0.968', 'recall': '0.914', 'f1': '0.940', 'total_rewards': 74.65909712991794, 'invalid_action_count': 143, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 20.047755493718604
# steps	 1000 	total rewards	 26.70384804722123
# steps	 1500 	total rewards	 59.011883800141305
# Finished after 1794 timesteps (10.149236917495728 seconds) with total reward 77.67779420916708
# {'coverage_prop': '0.854', 'intensity_prop': '0.641', 'ms1ms2_ratio': '0.130', 'efficiency': '0.228', 'TP': '315', 'FP': '47', 'FN': '62', 'precision': '0.870', 'recall': '0.836', 'f1': '0.853', 'total_rewards': 77.67779420916702, 'invalid_action_count': 218, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 24.703567559531784
# steps	 1000 	total rewards	 46.197683749172015
# steps	 1500 	total rewards	 78.44863784161959
# Finished after 1781 timesteps (9.439120054244995 seconds) with total reward 85.01846769047108
# {'coverage_prop': '0.820', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.140', 'efficiency': '0.202', 'TP': '273', 'FP': '42', 'FN': '69', 'precision': '0.867', 'recall': '0.798', 'f1': '0.831', 'total_rewards': 85.01846769047097, 'invalid_action_count': 183, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 20.30457268343675
# steps	 1000 	total rewards	 39.06912991824037
# steps	 1500 	total rewards	 76.57139594646783
# Finished after 1790 timesteps (10.245484113693237 seconds) with total reward 93.43927497258929
# {'coverage_prop': '0.777', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.133', 'efficiency': '0.218', 'TP': '290', 'FP': '54', 'FN': '99', 'precision': '0.843', 'recall': '0.746', 'f1': '0.791', 'total_rewards': 93.43927497258933, 'invalid_action_count': 180, 'num_ms1_scans': 210, 'num_ms2_scans': 1580}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 18.540102555571412
# steps	 1000 	total rewards	 38.967095145433944
# steps	 1500 	total rewards	 46.28718350321699
# Finished after 1753 timesteps (8.839731931686401 seconds) with total reward 52.932953973848576
# {'coverage_prop': '0.916', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.164', 'efficiency': '0.151', 'TP': '217', 'FP': '11', 'FN': '21', 'precision': '0.952', 'recall': '0.912', 'f1': '0.931', 'total_rewards': 52.93295397384864, 'invalid_action_count': 175, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 24.588768578865267
# steps	 1000 	total rewards	 37.34937012496398
# steps	 1500 	total rewards	 60.226939893245316
# Finished after 1779 timesteps (11.625972986221313 seconds) with total reward 76.605277626918
# {'coverage_prop': '0.861', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.142', 'efficiency': '0.139', 'TP': '191', 'FP': '25', 'FN': '35', 'precision': '0.884', 'recall': '0.845', 'f1': '0.864', 'total_rewards': 76.60527762691801, 'invalid_action_count': 149, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 19.11106910012329
# steps	 1000 	total rewards	 40.77364209589318
# steps	 1500 	total rewards	 64.57904298463484
# Finished after 1771 timesteps (10.07466983795166 seconds) with total reward 71.53230942262259
# {'coverage_prop': '0.837', 'intensity_prop': '0.635', 'ms1ms2_ratio': '0.149', 'efficiency': '0.163', 'TP': '215', 'FP': '36', 'FN': '49', 'precision': '0.857', 'recall': '0.814', 'f1': '0.835', 'total_rewards': 71.53230942262248, 'invalid_action_count': 157, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 25.424542560876844
# steps	 1000 	total rewards	 47.44976566114961
# steps	 1500 	total rewards	 63.74416626006315
# Finished after 1748 timesteps (8.615144968032837 seconds) with total reward 73.29838922903951
# {'coverage_prop': '0.879', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.168', 'efficiency': '0.121', 'TP': '164', 'FP': '17', 'FN': '25', 'precision': '0.906', 'recall': '0.868', 'f1': '0.886', 'total_rewards': 73.29838922903956, 'invalid_action_count': 132, 'num_ms1_scans': 252, 'num_ms2_scans': 1496}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 18.271203725248014
# steps	 1000 	total rewards	 30.329247371707382
# steps	 1500 	total rewards	 52.987660447438245
# Finished after 1775 timesteps (9.840564966201782 seconds) with total reward 62.4458598423585
# {'coverage_prop': '0.870', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.145', 'efficiency': '0.228', 'TP': '313', 'FP': '41', 'FN': '53', 'precision': '0.884', 'recall': '0.855', 'f1': '0.869', 'total_rewards': 62.44585984235847, 'invalid_action_count': 226, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 18.791057009597576
# steps	 1000 	total rewards	 38.87431242583348
# steps	 1500 	total rewards	 60.47253364355874
# Finished after 1782 timesteps (10.15530014038086 seconds) with total reward 70.36723321793575
# {'coverage_prop': '0.773', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.139', 'efficiency': '0.246', 'TP': '318', 'FP': '67', 'FN': '113', 'precision': '0.826', 'recall': '0.738', 'f1': '0.779', 'total_rewards': 70.36723321793569, 'invalid_action_count': 210, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 16.81383881541623
# steps	 1000 	total rewards	 35.500745205482964
# steps	 1500 	total rewards	 57.91765619558115
# Finished after 1781 timesteps (9.293848752975464 seconds) with total reward 64.66055093238273
# {'coverage_prop': '0.831', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.140', 'efficiency': '0.198', 'TP': '259', 'FP': '50', 'FN': '63', 'precision': '0.838', 'recall': '0.804', 'f1': '0.821', 'total_rewards': 64.66055093238269, 'invalid_action_count': 186, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 25.277282840283725
# steps	 1000 	total rewards	 41.80481577480247
# steps	 1500 	total rewards	 56.6044480365449
# Finished after 1767 timesteps (9.095320701599121 seconds) with total reward 75.03969478789129
# {'coverage_prop': '0.901', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.152', 'efficiency': '0.177', 'TP': '245', 'FP': '27', 'FN': '30', 'precision': '0.901', 'recall': '0.891', 'f1': '0.896', 'total_rewards': 75.03969478789125, 'invalid_action_count': 188, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 23.086135124570895
# steps	 1000 	total rewards	 41.79229813777961
# steps	 1500 	total rewards	 59.86921644787979
# Finished after 1767 timesteps (8.935302019119263 seconds) with total reward 76.31087544110306
# {'coverage_prop': '0.902', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.152', 'efficiency': '0.156', 'TP': '214', 'FP': '25', 'FN': '26', 'precision': '0.895', 'recall': '0.892', 'f1': '0.894', 'total_rewards': 76.31087544110301, 'invalid_action_count': 160, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 24.35785560087205
# steps	 1000 	total rewards	 40.962708957661135
# steps	 1500 	total rewards	 65.24715817730895
# Finished after 1781 timesteps (12.6854567527771 seconds) with total reward 82.57179810296839
# {'coverage_prop': '0.716', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.140', 'efficiency': '0.214', 'TP': '283', 'FP': '52', 'FN': '133', 'precision': '0.845', 'recall': '0.680', 'f1': '0.754', 'total_rewards': 82.5717981029684, 'invalid_action_count': 175, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 26.65904049000865
# steps	 1000 	total rewards	 44.58041650374375
# steps	 1500 	total rewards	 60.21850233982566
# Finished after 1737 timesteps (8.7450270652771 seconds) with total reward 73.36080220512991
# {'coverage_prop': '0.940', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.179', 'efficiency': '0.149', 'TP': '196', 'FP': '24', 'FN': '14', 'precision': '0.891', 'recall': '0.933', 'f1': '0.912', 'total_rewards': 73.3608022051299, 'invalid_action_count': 161, 'num_ms1_scans': 264, 'num_ms2_scans': 1473}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 22.231495694613407
# steps	 1000 	total rewards	 37.02596881462088
# steps	 1500 	total rewards	 51.357177885462875
# Finished after 1776 timesteps (9.298036098480225 seconds) with total reward 62.85512111520411
# {'coverage_prop': '0.891', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.144', 'efficiency': '0.185', 'TP': '259', 'FP': '28', 'FN': '35', 'precision': '0.902', 'recall': '0.881', 'f1': '0.892', 'total_rewards': 62.85512111520416, 'invalid_action_count': 195, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 25.28025427468054
# steps	 1000 	total rewards	 44.080489071404784
# steps	 1500 	total rewards	 65.51834571970838
# Finished after 1755 timesteps (8.815854787826538 seconds) with total reward 75.20853628337362
# {'coverage_prop': '0.906', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.162', 'efficiency': '0.186', 'TP': '247', 'FP': '34', 'FN': '29', 'precision': '0.879', 'recall': '0.895', 'f1': '0.887', 'total_rewards': 75.20853628337352, 'invalid_action_count': 191, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 21.82326900808579
# steps	 1000 	total rewards	 39.16539583318859
# steps	 1500 	total rewards	 65.81989518696967
# Finished after 1765 timesteps (9.073909997940063 seconds) with total reward 85.2927423562369
# {'coverage_prop': '0.814', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.154', 'efficiency': '0.184', 'TP': '236', 'FP': '45', 'FN': '64', 'precision': '0.840', 'recall': '0.787', 'f1': '0.812', 'total_rewards': 85.29274235623686, 'invalid_action_count': 171, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 25.108883147983185
# steps	 1000 	total rewards	 26.58956528207183
# steps	 1500 	total rewards	 48.378787992812875
# Finished after 1795 timesteps (10.065250158309937 seconds) with total reward 65.06343794961016
# {'coverage_prop': '0.866', 'intensity_prop': '0.657', 'ms1ms2_ratio': '0.130', 'efficiency': '0.216', 'TP': '301', 'FP': '42', 'FN': '53', 'precision': '0.878', 'recall': '0.850', 'f1': '0.864', 'total_rewards': 65.06343794961013, 'invalid_action_count': 213, 'num_ms1_scans': 206, 'num_ms2_scans': 1589}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 18.509631351944577
# steps	 1000 	total rewards	 34.898733919094816
# steps	 1500 	total rewards	 51.158423079423066
# Finished after 1735 timesteps (8.764532804489136 seconds) with total reward 66.39840854291663
# {'coverage_prop': '0.961', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.180', 'efficiency': '0.133', 'TP': '185', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954', 'total_rewards': 66.39840854291667, 'invalid_action_count': 152, 'num_ms1_scans': 265, 'num_ms2_scans': 1470}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 25.93843029625546
# steps	 1000 	total rewards	 37.75684131046701
# steps	 1500 	total rewards	 67.79887667475644
# Finished after 1761 timesteps (11.698201179504395 seconds) with total reward 86.08202994903186
# {'coverage_prop': '0.922', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.157', 'efficiency': '0.170', 'TP': '239', 'FP': '20', 'FN': '22', 'precision': '0.923', 'recall': '0.916', 'f1': '0.919', 'total_rewards': 86.08202994903185, 'invalid_action_count': 185, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 26.387540588538712
# steps	 1000 	total rewards	 51.2504716862414
# steps	 1500 	total rewards	 70.96848091243277
# Finished after 1789 timesteps (10.109260082244873 seconds) with total reward 87.58432044038076
# {'coverage_prop': '0.738', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.134', 'efficiency': '0.231', 'TP': '281', 'FP': '83', 'FN': '129', 'precision': '0.772', 'recall': '0.685', 'f1': '0.726', 'total_rewards': 87.58432044038065, 'invalid_action_count': 182, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 20.37791490175073
# steps	 1000 	total rewards	 30.65377265189103
# steps	 1500 	total rewards	 44.292235087840744
# Finished after 1765 timesteps (9.128989934921265 seconds) with total reward 59.63310381598886
# {'coverage_prop': '0.852', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.154', 'efficiency': '0.169', 'TP': '232', 'FP': '27', 'FN': '45', 'precision': '0.896', 'recall': '0.838', 'f1': '0.866', 'total_rewards': 59.633103815988804, 'invalid_action_count': 180, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb9c02afdf0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb9a02846a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb9c0d29940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '209', 'FP': '198', 'FN': '19', 'precision': '0.514', 'recall': '0.917', 'f1': '0.658'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '124', 'FP': '124', 'FN': '14', 'precision': '0.500', 'recall': '0.899', 'f1': '0.642'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.503', 'ms1ms2_ratio': '1.492', 'efficiency': '0.755', 'TP': '187', 'FP': '192', 'FN': '15', 'precision': '0.493', 'recall': '0.926', 'f1': '0.644'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.531', 'ms1ms2_ratio': '1.279', 'efficiency': '0.769', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.535', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '229', 'FP': '199', 'FN': '9', 'precision': '0.535', 'recall': '0.962', 'f1': '0.688'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.518', 'ms1ms2_ratio': '1.132', 'efficiency': '0.741', 'TP': '259', 'FP': '195', 'FN': '24', 'precision': '0.570', 'recall': '0.915', 'f1': '0.703'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.485', 'ms1ms2_ratio': '1.443', 'efficiency': '0.777', 'TP': '197', 'FP': '203', 'FN': '24', 'precision': '0.492', 'recall': '0.891', 'f1': '0.634'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.524', 'ms1ms2_ratio': '1.524', 'efficiency': '0.743', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.535', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '240', 'FP': '186', 'FN': '17', 'precision': '0.563', 'recall': '0.934', 'f1': '0.703'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.478', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.953', 'efficiency': '0.699', 'TP': '151', 'FP': '134', 'FN': '15', 'precision': '0.530', 'recall': '0.910', 'f1': '0.670'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.538', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '274', 'FP': '207', 'FN': '17', 'precision': '0.570', 'recall': '0.942', 'f1': '0.710'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '148', 'FP': '143', 'FN': '11', 'precision': '0.509', 'recall': '0.931', 'f1': '0.658'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.543', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '265', 'FP': '181', 'FN': '22', 'precision': '0.594', 'recall': '0.923', 'f1': '0.723'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.473', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '136', 'FP': '155', 'FN': '19', 'precision': '0.467', 'recall': '0.877', 'f1': '0.610'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.321', 'efficiency': '0.737', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.235', 'efficiency': '0.735', 'TP': '146', 'FP': '123', 'FN': '12', 'precision': '0.543', 'recall': '0.924', 'f1': '0.684'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.521', 'ms1ms2_ratio': '1.042', 'efficiency': '0.723', 'TP': '255', 'FP': '214', 'FN': '24', 'precision': '0.544', 'recall': '0.914', 'f1': '0.682'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1802.817325                1857.0          0.404           0.115
# 1  random   -1890.263150                1921.0          0.313           0.073
# 2  random   -1812.206919                1864.0          0.393           0.116
# 3  random   -1849.718386                1891.0          0.314           0.073
# 4  random   -1839.812508                1886.0          0.357           0.078
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.087      0.244   0.142  0.179
# 1          0.005       0.041      0.195   0.082  0.115
# 2          0.008       0.079      0.284   0.155  0.201
# 3          0.004       0.072      0.204   0.086  0.121
# 4          0.006       0.079      0.179   0.091  0.120

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     242.014917                   7.0          0.925           0.594
# 31    DQN     186.570513                  13.0          0.947           0.677
# 32    DQN     216.502724                   9.0          0.896           0.560
# 33    DQN     252.232350                   6.0          0.918           0.618
# 34    DQN     223.340796                  20.0          0.918           0.598
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          1.048       0.610      0.726   0.899  0.803
# 31          1.318       0.451      0.831   0.936  0.880
# 32          1.206       0.602      0.691   0.856  0.765
# 33          1.043       0.640      0.795   0.899  0.844
# 34          1.037       0.616      0.736   0.891  0.806

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
