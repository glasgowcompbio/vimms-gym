# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-07 13:28:37.459 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe6da49dd30>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe6ee91e670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe6ee93a910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe6da49dd30>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe6ee91e670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe6ee93a910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe6da49dd30>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe6ee91e670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe6ee93a910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -364.00501314026644
# steps	 1000 	total rewards	 -635.2461791891941
# steps	 1500 	total rewards	 -1017.926567915076
# Finished after 1990 timesteps (4.433923006057739 seconds) with total reward -1194.0630609235618
# {'coverage_prop': '0.674', 'intensity_prop': '0.187', 'ms1ms2_ratio': '0.005', 'efficiency': '0.145', 'TP': '71', 'FP': '216', 'FN': '139', 'precision': '0.247', 'recall': '0.338', 'f1': '0.286', 'total_rewards': -1194.0630609235623, 'invalid_action_count': 1324, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -414.242363571613
# steps	 1000 	total rewards	 -755.3643853235415
# steps	 1500 	total rewards	 -1108.5339104328018
# Finished after 1994 timesteps (2.6840691566467285 seconds) with total reward -1497.5989463523329
# {'coverage_prop': '0.553', 'intensity_prop': '0.153', 'ms1ms2_ratio': '0.003', 'efficiency': '0.073', 'TP': '40', 'FP': '105', 'FN': '117', 'precision': '0.276', 'recall': '0.255', 'f1': '0.265', 'total_rewards': -1497.5989463523322, 'invalid_action_count': 1571, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -333.79425946813217
# steps	 1000 	total rewards	 -596.604636306773
# steps	 1500 	total rewards	 -766.6972856859536
# Finished after 1985 timesteps (3.5455079078674316 seconds) with total reward -962.3578272157997
# {'coverage_prop': '0.774', 'intensity_prop': '0.263', 'ms1ms2_ratio': '0.008', 'efficiency': '0.155', 'TP': '100', 'FP': '205', 'FN': '89', 'precision': '0.328', 'recall': '0.529', 'f1': '0.405', 'total_rewards': -962.3578272158002, 'invalid_action_count': 1117, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -333.5497383319501
# steps	 1000 	total rewards	 -489.28384725724067
# steps	 1500 	total rewards	 -720.967116545534
# Finished after 1987 timesteps (4.586634874343872 seconds) with total reward -1016.5462775825388
# {'coverage_prop': '0.788', 'intensity_prop': '0.239', 'ms1ms2_ratio': '0.007', 'efficiency': '0.180', 'TP': '100', 'FP': '256', 'FN': '96', 'precision': '0.281', 'recall': '0.510', 'f1': '0.362', 'total_rewards': -1016.5462775825383, 'invalid_action_count': 1176, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -347.6076180151464
# steps	 1000 	total rewards	 -608.3587468290057
# steps	 1500 	total rewards	 -692.7941888641458
# Finished after 1982 timesteps (3.813843250274658 seconds) with total reward -798.2069138792036
# {'coverage_prop': '0.826', 'intensity_prop': '0.262', 'ms1ms2_ratio': '0.010', 'efficiency': '0.184', 'TP': '102', 'FP': '259', 'FN': '76', 'precision': '0.283', 'recall': '0.573', 'f1': '0.378', 'total_rewards': -798.206913879202, 'invalid_action_count': 974, 'num_ms1_scans': 19, 'num_ms2_scans': 1963}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -397.2721044528871
# steps	 1000 	total rewards	 -791.9693367953233
# steps	 1500 	total rewards	 -1114.6470622335512
# Finished after 1988 timesteps (2.28694486618042 seconds) with total reward -1409.911759197369
# {'coverage_prop': '0.685', 'intensity_prop': '0.175', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '35', 'FP': '102', 'FN': '63', 'precision': '0.255', 'recall': '0.357', 'f1': '0.298', 'total_rewards': -1409.9117591973684, 'invalid_action_count': 1477, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -330.49103862289155
# steps	 1000 	total rewards	 -674.8696345438728
# steps	 1500 	total rewards	 -1167.8307492533925
# Finished after 1993 timesteps (4.156469106674194 seconds) with total reward -1391.8950565535479
# {'coverage_prop': '0.515', 'intensity_prop': '0.123', 'ms1ms2_ratio': '0.004', 'efficiency': '0.124', 'TP': '48', 'FP': '198', 'FN': '232', 'precision': '0.195', 'recall': '0.171', 'f1': '0.183', 'total_rewards': -1391.8950565535497, 'invalid_action_count': 1497, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -391.10261484213777
# steps	 1000 	total rewards	 -681.3405181815032
# steps	 1500 	total rewards	 -907.8922761978329
# Finished after 1979 timesteps (2.2302660942077637 seconds) with total reward -1185.611264878083
# {'coverage_prop': '0.755', 'intensity_prop': '0.250', 'ms1ms2_ratio': '0.011', 'efficiency': '0.079', 'TP': '54', 'FP': '100', 'FN': '50', 'precision': '0.351', 'recall': '0.519', 'f1': '0.419', 'total_rewards': -1185.6112648780843, 'invalid_action_count': 1271, 'num_ms1_scans': 21, 'num_ms2_scans': 1958}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -450.9620616647294
# steps	 1000 	total rewards	 -758.7721239393554
# steps	 1500 	total rewards	 -961.2514072158315
# Finished after 1990 timesteps (3.707242012023926 seconds) with total reward -1104.4318469789673
# {'coverage_prop': '0.698', 'intensity_prop': '0.189', 'ms1ms2_ratio': '0.005', 'efficiency': '0.149', 'TP': '72', 'FP': '224', 'FN': '128', 'precision': '0.243', 'recall': '0.360', 'f1': '0.290', 'total_rewards': -1104.4318469789682, 'invalid_action_count': 1242, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -368.8798918643855
# steps	 1000 	total rewards	 -735.6292351073675
# steps	 1500 	total rewards	 -849.6666636054216
# Finished after 1984 timesteps (3.2735700607299805 seconds) with total reward -1038.340719689166
# {'coverage_prop': '0.745', 'intensity_prop': '0.265', 'ms1ms2_ratio': '0.008', 'efficiency': '0.145', 'TP': '93', 'FP': '193', 'FN': '98', 'precision': '0.325', 'recall': '0.487', 'f1': '0.390', 'total_rewards': -1038.340719689167, 'invalid_action_count': 1176, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -378.4784138423479
# steps	 1000 	total rewards	 -689.9540691845351
# steps	 1500 	total rewards	 -860.4149327759656
# Finished after 1990 timesteps (3.7904319763183594 seconds) with total reward -1095.3936830116772
# {'coverage_prop': '0.743', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.005', 'efficiency': '0.166', 'TP': '97', 'FP': '232', 'FN': '114', 'precision': '0.295', 'recall': '0.460', 'f1': '0.359', 'total_rewards': -1095.393683011677, 'invalid_action_count': 1250, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -356.73184062320877
# steps	 1000 	total rewards	 -639.8901690566511
# steps	 1500 	total rewards	 -905.0056472301862
# Finished after 1985 timesteps (2.583750009536743 seconds) with total reward -1217.615340251288
# {'coverage_prop': '0.735', 'intensity_prop': '0.252', 'ms1ms2_ratio': '0.008', 'efficiency': '0.093', 'TP': '65', 'FP': '118', 'FN': '66', 'precision': '0.355', 'recall': '0.496', 'f1': '0.414', 'total_rewards': -1217.6153402512887, 'invalid_action_count': 1310, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -372.10680354436374
# steps	 1000 	total rewards	 -661.025917295181
# steps	 1500 	total rewards	 -1062.0211695176142
# Finished after 1991 timesteps (3.0040366649627686 seconds) with total reward -1371.1449712159197
# {'coverage_prop': '0.661', 'intensity_prop': '0.164', 'ms1ms2_ratio': '0.005', 'efficiency': '0.084', 'TP': '37', 'FP': '129', 'FN': '85', 'precision': '0.223', 'recall': '0.303', 'f1': '0.257', 'total_rewards': -1371.144971215921, 'invalid_action_count': 1453, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -382.52484276025444
# steps	 1000 	total rewards	 -684.225986408338
# steps	 1500 	total rewards	 -925.4561359658189
# Finished after 1989 timesteps (3.5538318157196045 seconds) with total reward -1188.6994125131803
# {'coverage_prop': '0.760', 'intensity_prop': '0.253', 'ms1ms2_ratio': '0.006', 'efficiency': '0.115', 'TP': '71', 'FP': '157', 'FN': '72', 'precision': '0.311', 'recall': '0.497', 'f1': '0.383', 'total_rewards': -1188.6994125131803, 'invalid_action_count': 1298, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -435.8969576622122
# steps	 1000 	total rewards	 -812.2755706047025
# steps	 1500 	total rewards	 -1105.9583778728884
# Finished after 1993 timesteps (2.4751908779144287 seconds) with total reward -1506.933421904129
# {'coverage_prop': '0.583', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.004', 'efficiency': '0.060', 'TP': '28', 'FP': '92', 'FN': '86', 'precision': '0.233', 'recall': '0.246', 'f1': '0.239', 'total_rewards': -1506.9334219041286, 'invalid_action_count': 1566, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -378.42241087807645
# steps	 1000 	total rewards	 -581.8802633339858
# steps	 1500 	total rewards	 -763.9266381108963
# Finished after 1988 timesteps (3.5335190296173096 seconds) with total reward -1031.8998253995335
# {'coverage_prop': '0.740', 'intensity_prop': '0.253', 'ms1ms2_ratio': '0.006', 'efficiency': '0.152', 'TP': '97', 'FP': '204', 'FN': '106', 'precision': '0.322', 'recall': '0.478', 'f1': '0.385', 'total_rewards': -1031.8998253995326, 'invalid_action_count': 1173, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -445.1167183530268
# steps	 1000 	total rewards	 -678.6789237026402
# steps	 1500 	total rewards	 -1053.324833112439
# Finished after 1988 timesteps (4.48650598526001 seconds) with total reward -1200.021801363266
# {'coverage_prop': '0.649', 'intensity_prop': '0.169', 'ms1ms2_ratio': '0.006', 'efficiency': '0.163', 'TP': '82', 'FP': '241', 'FN': '175', 'precision': '0.254', 'recall': '0.319', 'f1': '0.283', 'total_rewards': -1200.0218013632652, 'invalid_action_count': 1329, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -347.96965796162635
# steps	 1000 	total rewards	 -625.8142837291543
# steps	 1500 	total rewards	 -872.731609151889
# Finished after 1990 timesteps (3.474302053451538 seconds) with total reward -1120.9639935282175
# {'coverage_prop': '0.753', 'intensity_prop': '0.224', 'ms1ms2_ratio': '0.005', 'efficiency': '0.141', 'TP': '82', 'FP': '198', 'FN': '92', 'precision': '0.293', 'recall': '0.471', 'f1': '0.361', 'total_rewards': -1120.9639935282169, 'invalid_action_count': 1255, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -341.6039760734362
# steps	 1000 	total rewards	 -670.5329757537354
# steps	 1500 	total rewards	 -881.693583634263
# Finished after 1983 timesteps (2.9643452167510986 seconds) with total reward -1131.8461617380076
# {'coverage_prop': '0.768', 'intensity_prop': '0.228', 'ms1ms2_ratio': '0.009', 'efficiency': '0.118', 'TP': '63', 'FP': '169', 'FN': '70', 'precision': '0.272', 'recall': '0.474', 'f1': '0.345', 'total_rewards': -1131.8461617380071, 'invalid_action_count': 1253, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -372.52301066607026
# steps	 1000 	total rewards	 -648.0255638417052
# steps	 1500 	total rewards	 -958.2449548147284
# Finished after 1990 timesteps (2.900519847869873 seconds) with total reward -1301.035493744666
# {'coverage_prop': '0.762', 'intensity_prop': '0.205', 'ms1ms2_ratio': '0.005', 'efficiency': '0.102', 'TP': '51', 'FP': '151', 'FN': '63', 'precision': '0.252', 'recall': '0.447', 'f1': '0.323', 'total_rewards': -1301.0354937446648, 'invalid_action_count': 1404, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -353.65359126999044
# steps	 1000 	total rewards	 -520.8101444966928
# steps	 1500 	total rewards	 -664.2492276360258
# Finished after 1985 timesteps (4.061423063278198 seconds) with total reward -800.3204508824239
# {'coverage_prop': '0.814', 'intensity_prop': '0.267', 'ms1ms2_ratio': '0.008', 'efficiency': '0.193', 'TP': '121', 'FP': '260', 'FN': '87', 'precision': '0.318', 'recall': '0.582', 'f1': '0.411', 'total_rewards': -800.3204508824223, 'invalid_action_count': 984, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -406.1719537538626
# steps	 1000 	total rewards	 -768.5941623736458
# steps	 1500 	total rewards	 -1001.8007484461807
# Finished after 1989 timesteps (2.394990921020508 seconds) with total reward -1321.9927405842743
# {'coverage_prop': '0.731', 'intensity_prop': '0.188', 'ms1ms2_ratio': '0.006', 'efficiency': '0.086', 'TP': '45', 'FP': '126', 'FN': '63', 'precision': '0.263', 'recall': '0.417', 'f1': '0.323', 'total_rewards': -1321.9927405842736, 'invalid_action_count': 1411, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -362.351109713696
# steps	 1000 	total rewards	 -669.8538009979551
# steps	 1500 	total rewards	 -981.7097434517334
# Finished after 1990 timesteps (2.9168167114257812 seconds) with total reward -1238.7077983708855
# {'coverage_prop': '0.683', 'intensity_prop': '0.193', 'ms1ms2_ratio': '0.005', 'efficiency': '0.111', 'TP': '56', 'FP': '164', 'FN': '102', 'precision': '0.255', 'recall': '0.354', 'f1': '0.296', 'total_rewards': -1238.7077983708855, 'invalid_action_count': 1341, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -342.72166531729033
# steps	 1000 	total rewards	 -651.7458324018985
# steps	 1500 	total rewards	 -974.2994804235941
# Finished after 1986 timesteps (2.7759599685668945 seconds) with total reward -1203.0445415915688
# {'coverage_prop': '0.703', 'intensity_prop': '0.202', 'ms1ms2_ratio': '0.007', 'efficiency': '0.111', 'TP': '64', 'FP': '154', 'FN': '92', 'precision': '0.294', 'recall': '0.410', 'f1': '0.342', 'total_rewards': -1203.0445415915697, 'invalid_action_count': 1312, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -392.49714820425254
# steps	 1000 	total rewards	 -768.8082894664714
# steps	 1500 	total rewards	 -1065.541037627384
# Finished after 1994 timesteps (3.383397102355957 seconds) with total reward -1407.4188729813318
# {'coverage_prop': '0.623', 'intensity_prop': '0.168', 'ms1ms2_ratio': '0.003', 'efficiency': '0.108', 'TP': '52', 'FP': '163', 'FN': '130', 'precision': '0.242', 'recall': '0.286', 'f1': '0.262', 'total_rewards': -1407.418872981333, 'invalid_action_count': 1509, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -345.15785161488293
# steps	 1000 	total rewards	 -668.4256810762029
# steps	 1500 	total rewards	 -998.6829136913136
# Finished after 1992 timesteps (3.4449501037597656 seconds) with total reward -1473.6710027630272
# {'coverage_prop': '0.540', 'intensity_prop': '0.147', 'ms1ms2_ratio': '0.004', 'efficiency': '0.108', 'TP': '54', 'FP': '160', 'FN': '182', 'precision': '0.252', 'recall': '0.229', 'f1': '0.240', 'total_rewards': -1473.6710027630272, 'invalid_action_count': 1554, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -380.57921301526073
# steps	 1000 	total rewards	 -687.1358063108223
# steps	 1500 	total rewards	 -995.9625700567159
# Finished after 1988 timesteps (2.348525047302246 seconds) with total reward -1331.0479569812226
# {'coverage_prop': '0.749', 'intensity_prop': '0.222', 'ms1ms2_ratio': '0.006', 'efficiency': '0.077', 'TP': '40', 'FP': '112', 'FN': '51', 'precision': '0.263', 'recall': '0.440', 'f1': '0.329', 'total_rewards': -1331.0479569812228, 'invalid_action_count': 1411, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -368.079602391401
# steps	 1000 	total rewards	 -717.2825591305095
# steps	 1500 	total rewards	 -1026.5313435993864
# Finished after 1989 timesteps (3.2153468132019043 seconds) with total reward -1293.581779777639
# {'coverage_prop': '0.673', 'intensity_prop': '0.212', 'ms1ms2_ratio': '0.006', 'efficiency': '0.096', 'TP': '56', 'FP': '133', 'FN': '92', 'precision': '0.296', 'recall': '0.378', 'f1': '0.332', 'total_rewards': -1293.5817797776408, 'invalid_action_count': 1392, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -391.19050054349316
# steps	 1000 	total rewards	 -708.1677960005737
# steps	 1500 	total rewards	 -1047.7970998140154
# Finished after 1994 timesteps (3.825247049331665 seconds) with total reward -1291.4943659055284
# {'coverage_prop': '0.645', 'intensity_prop': '0.168', 'ms1ms2_ratio': '0.003', 'efficiency': '0.160', 'TP': '79', 'FP': '239', 'FN': '175', 'precision': '0.248', 'recall': '0.311', 'f1': '0.276', 'total_rewards': -1291.4943659055282, 'invalid_action_count': 1424, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -369.39597554682024
# steps	 1000 	total rewards	 -638.1547382461604
# steps	 1500 	total rewards	 -848.2884528802992
# Finished after 1987 timesteps (3.0934829711914062 seconds) with total reward -1064.7716662732005
# {'coverage_prop': '0.786', 'intensity_prop': '0.279', 'ms1ms2_ratio': '0.007', 'efficiency': '0.121', 'TP': '80', 'FP': '159', 'FN': '65', 'precision': '0.335', 'recall': '0.552', 'f1': '0.417', 'total_rewards': -1064.7716662732, 'invalid_action_count': 1190, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.00GB > 0.33GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 84.98463713717642
# steps	 1000 	total rewards	 191.32060184366514
# steps	 1500 	total rewards	 266.1225938379006
# Finished after 1559 timesteps (6.112948894500732 seconds) with total reward 274.25262656821064
# {'coverage_prop': '0.911', 'intensity_prop': '0.496', 'ms1ms2_ratio': '0.394', 'efficiency': '0.347', 'TP': '224', 'FP': '164', 'FN': '38', 'precision': '0.577', 'recall': '0.855', 'f1': '0.689', 'total_rewards': 274.2526265682106, 'invalid_action_count': 11, 'num_ms1_scans': 441, 'num_ms2_scans': 1118}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 86.35420200333334
# steps	 1000 	total rewards	 176.9660558731557
# Finished after 1469 timesteps (4.108426094055176 seconds) with total reward 241.57670736443882
# {'coverage_prop': '0.935', 'intensity_prop': '0.550', 'ms1ms2_ratio': '0.568', 'efficiency': '0.261', 'TP': '153', 'FP': '92', 'FN': '17', 'precision': '0.624', 'recall': '0.900', 'f1': '0.737', 'total_rewards': 241.57670736443703, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 937}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 86.89051890830606
# steps	 1000 	total rewards	 193.8112190667115
# steps	 1500 	total rewards	 277.9674027701572
# Finished after 1549 timesteps (6.086122989654541 seconds) with total reward 284.67121280386505
# {'coverage_prop': '0.924', 'intensity_prop': '0.489', 'ms1ms2_ratio': '0.411', 'efficiency': '0.332', 'TP': '197', 'FP': '167', 'FN': '30', 'precision': '0.541', 'recall': '0.868', 'f1': '0.667', 'total_rewards': 284.67121280386493, 'invalid_action_count': 3, 'num_ms1_scans': 451, 'num_ms2_scans': 1098}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 94.72924033627825
# steps	 1000 	total rewards	 198.8557730560919
# steps	 1500 	total rewards	 271.9797733941224
# Finished after 1548 timesteps (6.109930038452148 seconds) with total reward 279.7680650478922
# {'coverage_prop': '0.909', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.414', 'efficiency': '0.375', 'TP': '244', 'FP': '167', 'FN': '41', 'precision': '0.594', 'recall': '0.856', 'f1': '0.701', 'total_rewards': 279.768065047892, 'invalid_action_count': 10, 'num_ms1_scans': 453, 'num_ms2_scans': 1095}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 82.28022867294501
# steps	 1000 	total rewards	 197.53781534060903
# steps	 1500 	total rewards	 275.31782808136245
# Finished after 1549 timesteps (6.224027872085571 seconds) with total reward 283.44755542387804
# {'coverage_prop': '0.908', 'intensity_prop': '0.485', 'ms1ms2_ratio': '0.411', 'efficiency': '0.362', 'TP': '230', 'FP': '167', 'FN': '40', 'precision': '0.579', 'recall': '0.852', 'f1': '0.690', 'total_rewards': 283.4475554238786, 'invalid_action_count': 3, 'num_ms1_scans': 451, 'num_ms2_scans': 1098}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 73.42672535571808
# steps	 1000 	total rewards	 150.8432237326379
# Finished after 1433 timesteps (4.1041741371154785 seconds) with total reward 212.45118391009063
# {'coverage_prop': '0.955', 'intensity_prop': '0.640', 'ms1ms2_ratio': '0.655', 'efficiency': '0.221', 'TP': '145', 'FP': '46', 'FN': '9', 'precision': '0.759', 'recall': '0.942', 'f1': '0.841', 'total_rewards': 212.45118391008842, 'invalid_action_count': 0, 'num_ms1_scans': 567, 'num_ms2_scans': 866}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 90.39219387124706
# steps	 1000 	total rewards	 201.9507835321451
# steps	 1500 	total rewards	 292.7924876843343
# Finished after 1566 timesteps (6.614261150360107 seconds) with total reward 300.2076991708425
# {'coverage_prop': '0.891', 'intensity_prop': '0.483', 'ms1ms2_ratio': '0.383', 'efficiency': '0.376', 'TP': '250', 'FP': '176', 'FN': '52', 'precision': '0.587', 'recall': '0.828', 'f1': '0.687', 'total_rewards': 300.2076991708429, 'invalid_action_count': 0, 'num_ms1_scans': 434, 'num_ms2_scans': 1132}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 63.78824989467971
# steps	 1000 	total rewards	 152.27936231092764
# Finished after 1426 timesteps (3.7697970867156982 seconds) with total reward 204.53014394814312
# {'coverage_prop': '0.902', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.676', 'efficiency': '0.216', 'TP': '130', 'FP': '54', 'FN': '20', 'precision': '0.707', 'recall': '0.867', 'f1': '0.778', 'total_rewards': 204.53014394814107, 'invalid_action_count': 1, 'num_ms1_scans': 575, 'num_ms2_scans': 851}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 87.53901814499586
# steps	 1000 	total rewards	 184.44123317092968
# steps	 1500 	total rewards	 270.9033948381183
# Finished after 1567 timesteps (6.367757081985474 seconds) with total reward 277.0813499140479
# {'coverage_prop': '0.922', 'intensity_prop': '0.476', 'ms1ms2_ratio': '0.382', 'efficiency': '0.345', 'TP': '217', 'FP': '174', 'FN': '33', 'precision': '0.555', 'recall': '0.868', 'f1': '0.677', 'total_rewards': 277.0813499140474, 'invalid_action_count': 3, 'num_ms1_scans': 433, 'num_ms2_scans': 1134}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 86.98770139407904
# steps	 1000 	total rewards	 178.51907750116908
# steps	 1500 	total rewards	 261.1145617734288
# Finished after 1528 timesteps (5.264801025390625 seconds) with total reward 263.32360967589636
# {'coverage_prop': '0.911', 'intensity_prop': '0.515', 'ms1ms2_ratio': '0.447', 'efficiency': '0.331', 'TP': '207', 'FP': '143', 'FN': '34', 'precision': '0.591', 'recall': '0.859', 'f1': '0.701', 'total_rewards': 263.32360967589494, 'invalid_action_count': 3, 'num_ms1_scans': 472, 'num_ms2_scans': 1056}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 89.9107575409952
# steps	 1000 	total rewards	 197.25216440704733
# steps	 1500 	total rewards	 278.4489282133359
# Finished after 1563 timesteps (6.72637414932251 seconds) with total reward 284.26812216093447
# {'coverage_prop': '0.898', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.389', 'efficiency': '0.354', 'TP': '244', 'FP': '154', 'FN': '45', 'precision': '0.613', 'recall': '0.844', 'f1': '0.710', 'total_rewards': 284.2681221609349, 'invalid_action_count': 13, 'num_ms1_scans': 438, 'num_ms2_scans': 1125}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 82.55227344061419
# steps	 1000 	total rewards	 162.27709787345177
# Finished after 1472 timesteps (4.082837820053101 seconds) with total reward 217.1224023390095
# {'coverage_prop': '0.940', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.561', 'efficiency': '0.248', 'TP': '153', 'FP': '81', 'FN': '15', 'precision': '0.654', 'recall': '0.911', 'f1': '0.761', 'total_rewards': 217.1224023390078, 'invalid_action_count': 1, 'num_ms1_scans': 529, 'num_ms2_scans': 943}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 81.53261032713093
# steps	 1000 	total rewards	 164.87321669199463
# Finished after 1457 timesteps (5.615511178970337 seconds) with total reward 223.38011037699454
# {'coverage_prop': '0.936', 'intensity_prop': '0.543', 'ms1ms2_ratio': '0.594', 'efficiency': '0.257', 'TP': '146', 'FP': '89', 'FN': '16', 'precision': '0.621', 'recall': '0.901', 'f1': '0.736', 'total_rewards': 223.38011037699223, 'invalid_action_count': 1, 'num_ms1_scans': 543, 'num_ms2_scans': 914}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 78.080081303042
# steps	 1000 	total rewards	 164.88605661736776
# Finished after 1491 timesteps (4.898438215255737 seconds) with total reward 238.70575731651806
# {'coverage_prop': '0.920', 'intensity_prop': '0.532', 'ms1ms2_ratio': '0.520', 'efficiency': '0.281', 'TP': '173', 'FP': '103', 'FN': '24', 'precision': '0.627', 'recall': '0.878', 'f1': '0.732', 'total_rewards': 238.7057573165162, 'invalid_action_count': 1, 'num_ms1_scans': 510, 'num_ms2_scans': 981}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 68.86656007561707
# steps	 1000 	total rewards	 154.75109336820606
# Finished after 1442 timesteps (5.170302867889404 seconds) with total reward 208.69749580736516
# {'coverage_prop': '0.947', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.633', 'efficiency': '0.221', 'TP': '128', 'FP': '67', 'FN': '11', 'precision': '0.656', 'recall': '0.921', 'f1': '0.766', 'total_rewards': 208.6974958073631, 'invalid_action_count': 0, 'num_ms1_scans': 559, 'num_ms2_scans': 883}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 77.64153714465174
# steps	 1000 	total rewards	 180.14352591284955
# steps	 1500 	total rewards	 270.93369903462735
# Finished after 1546 timesteps (5.1565632820129395 seconds) with total reward 276.93900181509423
# {'coverage_prop': '0.929', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.416', 'efficiency': '0.346', 'TP': '236', 'FP': '142', 'FN': '29', 'precision': '0.624', 'recall': '0.891', 'f1': '0.734', 'total_rewards': 276.9390018150936, 'invalid_action_count': 2, 'num_ms1_scans': 454, 'num_ms2_scans': 1092}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 92.9032816993842
# steps	 1000 	total rewards	 196.44575427475596
# steps	 1500 	total rewards	 286.0735664726328
# Finished after 1569 timesteps (5.582221984863281 seconds) with total reward 296.2843635323078
# {'coverage_prop': '0.894', 'intensity_prop': '0.522', 'ms1ms2_ratio': '0.380', 'efficiency': '0.391', 'TP': '293', 'FP': '152', 'FN': '53', 'precision': '0.658', 'recall': '0.847', 'f1': '0.741', 'total_rewards': 296.28436353230785, 'invalid_action_count': 13, 'num_ms1_scans': 432, 'num_ms2_scans': 1137}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 94.7230589947045
# steps	 1000 	total rewards	 187.56883107867952
# steps	 1500 	total rewards	 261.72315272669096
# Finished after 1544 timesteps (6.2222583293914795 seconds) with total reward 265.00310697791235
# {'coverage_prop': '0.933', 'intensity_prop': '0.496', 'ms1ms2_ratio': '0.420', 'efficiency': '0.319', 'TP': '196', 'FP': '151', 'FN': '25', 'precision': '0.565', 'recall': '0.887', 'f1': '0.690', 'total_rewards': 265.00310697791133, 'invalid_action_count': 2, 'num_ms1_scans': 457, 'num_ms2_scans': 1087}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 83.27796915816056
# steps	 1000 	total rewards	 175.7505275291482
# steps	 1500 	total rewards	 244.1287233652917
# Finished after 1511 timesteps (4.659727096557617 seconds) with total reward 245.796574519072
# {'coverage_prop': '0.950', 'intensity_prop': '0.533', 'ms1ms2_ratio': '0.480', 'efficiency': '0.281', 'TP': '175', 'FP': '112', 'FN': '15', 'precision': '0.610', 'recall': '0.921', 'f1': '0.734', 'total_rewards': 245.79657451907025, 'invalid_action_count': 1, 'num_ms1_scans': 490, 'num_ms2_scans': 1021}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 80.4121412342187
# steps	 1000 	total rewards	 167.63221470922784
# Finished after 1490 timesteps (4.391317129135132 seconds) with total reward 242.79628659924163
# {'coverage_prop': '0.958', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.520', 'efficiency': '0.259', 'TP': '157', 'FP': '97', 'FN': '11', 'precision': '0.618', 'recall': '0.935', 'f1': '0.744', 'total_rewards': 242.79628659923978, 'invalid_action_count': 0, 'num_ms1_scans': 510, 'num_ms2_scans': 980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 88.32810373404175
# steps	 1000 	total rewards	 190.70798414898303
# steps	 1500 	total rewards	 276.265630244734
# Finished after 1558 timesteps (7.639585018157959 seconds) with total reward 281.87709467730383
# {'coverage_prop': '0.874', 'intensity_prop': '0.472', 'ms1ms2_ratio': '0.396', 'efficiency': '0.366', 'TP': '234', 'FP': '175', 'FN': '59', 'precision': '0.572', 'recall': '0.799', 'f1': '0.667', 'total_rewards': 281.87709467730366, 'invalid_action_count': 2, 'num_ms1_scans': 442, 'num_ms2_scans': 1116}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 74.0649522521
# steps	 1000 	total rewards	 161.44399873207067
# Finished after 1460 timesteps (3.9336400032043457 seconds) with total reward 218.79727781061305
# {'coverage_prop': '0.944', 'intensity_prop': '0.545', 'ms1ms2_ratio': '0.587', 'efficiency': '0.240', 'TP': '137', 'FP': '84', 'FN': '13', 'precision': '0.620', 'recall': '0.913', 'f1': '0.739', 'total_rewards': 218.7972778106112, 'invalid_action_count': 1, 'num_ms1_scans': 540, 'num_ms2_scans': 920}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 77.51812553964139
# steps	 1000 	total rewards	 174.0039682072569
# steps	 1500 	total rewards	 247.3871767899567
# Finished after 1514 timesteps (6.252146244049072 seconds) with total reward 249.05974741663593
# {'coverage_prop': '0.919', 'intensity_prop': '0.520', 'ms1ms2_ratio': '0.473', 'efficiency': '0.288', 'TP': '186', 'FP': '110', 'FN': '26', 'precision': '0.628', 'recall': '0.877', 'f1': '0.732', 'total_rewards': 249.05974741663422, 'invalid_action_count': 0, 'num_ms1_scans': 486, 'num_ms2_scans': 1028}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 82.27996069146138
# steps	 1000 	total rewards	 173.70874051645802
# steps	 1500 	total rewards	 247.15591201599875
# Finished after 1502 timesteps (4.396642208099365 seconds) with total reward 247.25591201599877
# {'coverage_prop': '0.923', 'intensity_prop': '0.518', 'ms1ms2_ratio': '0.498', 'efficiency': '0.285', 'TP': '166', 'FP': '120', 'FN': '24', 'precision': '0.580', 'recall': '0.874', 'f1': '0.697', 'total_rewards': 247.2559120159967, 'invalid_action_count': 0, 'num_ms1_scans': 499, 'num_ms2_scans': 1003}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 85.44260128306324
# steps	 1000 	total rewards	 188.0495367119339
# steps	 1500 	total rewards	 269.2353889732095
# Finished after 1516 timesteps (4.784276247024536 seconds) with total reward 270.41733234697415
# {'coverage_prop': '0.951', 'intensity_prop': '0.524', 'ms1ms2_ratio': '0.470', 'efficiency': '0.318', 'TP': '194', 'FP': '134', 'FN': '17', 'precision': '0.591', 'recall': '0.919', 'f1': '0.720', 'total_rewards': 270.41733234697307, 'invalid_action_count': 0, 'num_ms1_scans': 485, 'num_ms2_scans': 1031}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 87.67080262867537
# steps	 1000 	total rewards	 186.96739624288085
# steps	 1500 	total rewards	 266.0590331680784
# Finished after 1537 timesteps (5.171828031539917 seconds) with total reward 269.5355604603586
# {'coverage_prop': '0.932', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.432', 'efficiency': '0.344', 'TP': '219', 'FP': '150', 'FN': '27', 'precision': '0.593', 'recall': '0.890', 'f1': '0.712', 'total_rewards': 269.53556046035794, 'invalid_action_count': 0, 'num_ms1_scans': 464, 'num_ms2_scans': 1073}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 67.6425236950958
# steps	 1000 	total rewards	 153.7494564684948
# Finished after 1428 timesteps (5.717680215835571 seconds) with total reward 210.39977995134922
# {'coverage_prop': '0.951', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.670', 'efficiency': '0.226', 'TP': '120', 'FP': '73', 'FN': '10', 'precision': '0.622', 'recall': '0.923', 'f1': '0.743', 'total_rewards': 210.39977995134745, 'invalid_action_count': 0, 'num_ms1_scans': 573, 'num_ms2_scans': 855}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 84.2782762063317
# steps	 1000 	total rewards	 175.65475121926687
# Finished after 1470 timesteps (4.312527894973755 seconds) with total reward 252.02145651621709
# {'coverage_prop': '0.929', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.564', 'efficiency': '0.278', 'TP': '179', 'FP': '82', 'FN': '20', 'precision': '0.686', 'recall': '0.899', 'f1': '0.778', 'total_rewards': 252.02145651621532, 'invalid_action_count': 0, 'num_ms1_scans': 530, 'num_ms2_scans': 940}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 90.36701160633146
# steps	 1000 	total rewards	 183.91415887629643
# steps	 1500 	total rewards	 281.11939540563685
# Finished after 1547 timesteps (6.856060028076172 seconds) with total reward 287.005048606779
# {'coverage_prop': '0.860', 'intensity_prop': '0.437', 'ms1ms2_ratio': '0.415', 'efficiency': '0.388', 'TP': '224', 'FP': '200', 'FN': '69', 'precision': '0.528', 'recall': '0.765', 'f1': '0.625', 'total_rewards': 287.0050486067788, 'invalid_action_count': 5, 'num_ms1_scans': 454, 'num_ms2_scans': 1093}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 78.71396695204157
# steps	 1000 	total rewards	 165.60946816949877
# steps	 1500 	total rewards	 232.13865131699876
# Finished after 1502 timesteps (7.984774827957153 seconds) with total reward 232.13865131699876
# {'coverage_prop': '0.921', 'intensity_prop': '0.558', 'ms1ms2_ratio': '0.496', 'efficiency': '0.279', 'TP': '190', 'FP': '90', 'FN': '24', 'precision': '0.679', 'recall': '0.888', 'f1': '0.769', 'total_rewards': 232.13865131699714, 'invalid_action_count': 0, 'num_ms1_scans': 498, 'num_ms2_scans': 1004}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 92.5276178076839
# steps	 1000 	total rewards	 205.25382864627784
# steps	 1500 	total rewards	 312.7588878054987
# Finished after 1722 timesteps (11.381062746047974 seconds) with total reward 350.1583925147164
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 350.15839251471635, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.19223993264903
# steps	 1000 	total rewards	 200.01185786399162
# steps	 1500 	total rewards	 278.69251864828544
# Finished after 1556 timesteps (9.662692785263062 seconds) with total reward 286.42041452327317
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 286.42041452327345, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.09810262952533
# steps	 1000 	total rewards	 204.55175528344176
# steps	 1500 	total rewards	 311.70589197292
# Finished after 1669 timesteps (9.991228818893433 seconds) with total reward 335.8567231016701
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 335.856723101671, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.75112549735738
# steps	 1000 	total rewards	 222.260470162795
# steps	 1500 	total rewards	 321.6296912754646
# Finished after 1717 timesteps (14.29584002494812 seconds) with total reward 364.78676992745324
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 364.7867699274535, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.88207661824359
# steps	 1000 	total rewards	 225.03458447204991
# steps	 1500 	total rewards	 333.40644054419124
# Finished after 1704 timesteps (10.832239151000977 seconds) with total reward 368.54312915676854
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 368.54312915676945, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.95053041210245
# steps	 1000 	total rewards	 176.02517486243747
# Finished after 1408 timesteps (8.994147062301636 seconds) with total reward 238.71804354506358
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 238.7180435450617, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.04778207928516
# steps	 1000 	total rewards	 216.92306176316305
# steps	 1500 	total rewards	 317.03297009874126
# Finished after 1744 timesteps (15.323981285095215 seconds) with total reward 357.54143159354504
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 357.54143159354567, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.27568189026226
# steps	 1000 	total rewards	 178.89586218914897
# Finished after 1468 timesteps (16.554851770401 seconds) with total reward 248.8792687394992
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 248.87926873949786, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 102.06959352333683
# steps	 1000 	total rewards	 203.76934731050875
# steps	 1500 	total rewards	 314.6913157438472
# Finished after 1736 timesteps (11.495174884796143 seconds) with total reward 352.8683422368248
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 352.8683422368253, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 90.74138548172694
# steps	 1000 	total rewards	 200.31290144512386
# steps	 1500 	total rewards	 301.1097996085705
# Finished after 1667 timesteps (8.808932781219482 seconds) with total reward 323.768416073993
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 323.7684160739943, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.23962533608534
# steps	 1000 	total rewards	 197.16226995805556
# steps	 1500 	total rewards	 303.39580167752945
# Finished after 1737 timesteps (9.7720468044281 seconds) with total reward 344.057804535654
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 344.05780453565535, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.76014323446897
# steps	 1000 	total rewards	 182.82317997694054
# steps	 1500 	total rewards	 254.1775526296638
# Finished after 1530 timesteps (10.00438928604126 seconds) with total reward 257.90826139058424
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 257.9082613905829, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.09788008205047
# steps	 1000 	total rewards	 173.34530752343633
# steps	 1500 	total rewards	 250.4027444407447
# Finished after 1602 timesteps (8.913629293441772 seconds) with total reward 265.8130372865816
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 265.8130372865811, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 81.87979467550704
# steps	 1000 	total rewards	 176.3296676850765
# steps	 1500 	total rewards	 264.5543538505019
# Finished after 1645 timesteps (9.491204261779785 seconds) with total reward 281.66421220903726
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 281.6642122090379, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 77.69553492222708
# steps	 1000 	total rewards	 165.92205077135358
# Finished after 1497 timesteps (8.157386064529419 seconds) with total reward 238.86550329561172
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 238.86550329561047, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.05709360186964
# steps	 1000 	total rewards	 202.35383743309467
# steps	 1500 	total rewards	 309.4258646878863
# Finished after 1655 timesteps (15.13989782333374 seconds) with total reward 340.11849111963613
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 340.118491119637, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 105.80378017337763
# steps	 1000 	total rewards	 218.16501246190484
# steps	 1500 	total rewards	 323.99517148498575
# Finished after 1729 timesteps (11.352288961410522 seconds) with total reward 365.3798953710612
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 365.3798953710626, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.86888851189178
# steps	 1000 	total rewards	 210.73859611594213
# steps	 1500 	total rewards	 300.65131585356136
# Finished after 1681 timesteps (10.564306020736694 seconds) with total reward 326.453219442385
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 326.45321944238583, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.55640776019361
# steps	 1000 	total rewards	 192.1170010832405
# steps	 1500 	total rewards	 282.6369316315453
# Finished after 1621 timesteps (10.196997880935669 seconds) with total reward 301.02243270902477
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 301.022432709025, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.8961989902214
# steps	 1000 	total rewards	 183.76704030525036
# steps	 1500 	total rewards	 264.106842989171
# Finished after 1634 timesteps (9.397393703460693 seconds) with total reward 282.8349639496908
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 282.8349639496904, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.82872862229425
# steps	 1000 	total rewards	 205.4574323828516
# steps	 1500 	total rewards	 298.0440315538605
# Finished after 1726 timesteps (18.000706672668457 seconds) with total reward 339.6563370807766
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 339.65633708077706, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 78.8765952264226
# steps	 1000 	total rewards	 180.8121218448101
# Finished after 1475 timesteps (12.167527914047241 seconds) with total reward 259.5886548759064
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 259.5886548759048, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 90.37844742158512
# steps	 1000 	total rewards	 195.95932027941527
# steps	 1500 	total rewards	 283.3609709366841
# Finished after 1636 timesteps (13.979855060577393 seconds) with total reward 305.03129962834686
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 305.03129962834777, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.58010974902588
# steps	 1000 	total rewards	 199.06887434647197
# steps	 1500 	total rewards	 285.5523492877917
# Finished after 1575 timesteps (9.706840991973877 seconds) with total reward 296.6703624144893
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 296.67036241449057, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 90.58123202962977
# steps	 1000 	total rewards	 201.86616968777264
# steps	 1500 	total rewards	 295.787668388372
# Finished after 1681 timesteps (8.615236759185791 seconds) with total reward 324.2819674955664
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 324.28196749556696, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.78144021754095
# steps	 1000 	total rewards	 188.87430385569195
# steps	 1500 	total rewards	 297.86842274642567
# Finished after 1679 timesteps (11.539704084396362 seconds) with total reward 329.2116800669655
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 329.21168006696644, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 71.98194223405334
# steps	 1000 	total rewards	 170.41017366979133
# Finished after 1465 timesteps (7.747001886367798 seconds) with total reward 242.86558010739546
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 242.86558010739404, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 87.80052172308895
# steps	 1000 	total rewards	 195.50633781024922
# steps	 1500 	total rewards	 294.00010247549244
# Finished after 1564 timesteps (7.998342037200928 seconds) with total reward 304.0900195549617
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 304.09001955496166, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.17309733822901
# steps	 1000 	total rewards	 195.47739728296165
# steps	 1500 	total rewards	 298.6482177897861
# Finished after 1749 timesteps (9.618769884109497 seconds) with total reward 346.2046795612188
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 346.20467956121945, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.33998672596451
# steps	 1000 	total rewards	 192.64754247155082
# steps	 1500 	total rewards	 274.80651079438553
# Finished after 1657 timesteps (8.54929780960083 seconds) with total reward 293.02734741027416
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 293.02734741027416, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe6da49dd30>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe6ee91e670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe6ee93a910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.486', 'ms1ms2_ratio': '1.387', 'efficiency': '0.768', 'TP': '203', 'FP': '204', 'FN': '19', 'precision': '0.499', 'recall': '0.914', 'f1': '0.645'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.490', 'ms1ms2_ratio': '1.438', 'efficiency': '0.775', 'TP': '199', 'FP': '201', 'FN': '24', 'precision': '0.497', 'recall': '0.892', 'f1': '0.639'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '242', 'FP': '184', 'FN': '17', 'precision': '0.568', 'recall': '0.934', 'f1': '0.707'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.491', 'ms1ms2_ratio': '3.153', 'efficiency': '0.708', 'TP': '101', 'FP': '93', 'FN': '12', 'precision': '0.521', 'recall': '0.894', 'f1': '0.658'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.072', 'efficiency': '0.756', 'TP': '271', 'FP': '210', 'FN': '17', 'precision': '0.563', 'recall': '0.941', 'f1': '0.705'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '192', 'FP': '162', 'FN': '18', 'precision': '0.542', 'recall': '0.914', 'f1': '0.681'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.543', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '265', 'FP': '181', 'FN': '22', 'precision': '0.594', 'recall': '0.923', 'f1': '0.723'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.493', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '106', 'FP': '114', 'FN': '14', 'precision': '0.482', 'recall': '0.883', 'f1': '0.624'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.476', 'efficiency': '0.763', 'TP': '212', 'FP': '174', 'FN': '10', 'precision': '0.549', 'recall': '0.955', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.514', 'ms1ms2_ratio': '2.211', 'efficiency': '0.729', 'TP': '148', 'FP': '121', 'FN': '12', 'precision': '0.550', 'recall': '0.925', 'f1': '0.690'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.521', 'ms1ms2_ratio': '1.038', 'efficiency': '0.722', 'TP': '253', 'FP': '216', 'FN': '24', 'precision': '0.539', 'recall': '0.913', 'f1': '0.678'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1194.063061                1324.0          0.674           0.187
# 1  random   -1497.598946                1571.0          0.553           0.153
# 2  random    -962.357827                1117.0          0.774           0.263
# 3  random   -1016.546278                1176.0          0.788           0.239
# 4  random    -798.206914                 974.0          0.826           0.262
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.145      0.247   0.338  0.286
# 1          0.003       0.073      0.276   0.255  0.265
# 2          0.008       0.155      0.328   0.529  0.405
# 3          0.007       0.180      0.281   0.510  0.362
# 4          0.010       0.184      0.283   0.573  0.378

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     274.252627                  11.0          0.911           0.496
# 31    DQN     241.576707                   0.0          0.935           0.550
# 32    DQN     284.671213                   3.0          0.924           0.489
# 33    DQN     279.768065                  10.0          0.909           0.506
# 34    DQN     283.447555                   3.0          0.908           0.485
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.394       0.347      0.577   0.855  0.689
# 31          0.568       0.261      0.624   0.900  0.737
# 32          0.411       0.332      0.541   0.868  0.667
# 33          0.414       0.375      0.594   0.856  0.701
# 34          0.411       0.362      0.579   0.852  0.690

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
