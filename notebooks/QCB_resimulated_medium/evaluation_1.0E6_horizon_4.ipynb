# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-20 10:35:12.386 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7f5db2cc40>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7f184456a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7f48572940>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'exclusion_t0': 5,
#    'exclusion_t1': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7f5db2cc40>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7f184456a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7f48572940>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7f5db2cc40>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7f184456a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7f48572940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['exclusion_t0'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d exclusion_t0 = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['exclusion_t0'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -476.25411032012175
# steps	 1000 	total rewards	 -936.9668221888815
# steps	 1500 	total rewards	 -1382.3953891181889
# Finished after 1993 timesteps (4.437463998794556 seconds) with total reward -1865.590708399916
# {'coverage_prop': '0.310', 'intensity_prop': '0.070', 'ms1ms2_ratio': '0.004', 'efficiency': '0.066', 'TP': '24', 'FP': '108', 'FN': '294', 'precision': '0.182', 'recall': '0.075', 'f1': '0.107', 'total_rewards': -1865.5907083999155, 'invalid_action_count': 1904, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -979.8665239562226
# steps	 1500 	total rewards	 -1453.744997931988
# Finished after 1990 timesteps (2.4952728748321533 seconds) with total reward -1912.7891990957828
# {'coverage_prop': '0.256', 'intensity_prop': '0.054', 'ms1ms2_ratio': '0.005', 'efficiency': '0.034', 'TP': '11', 'FP': '56', 'FN': '195', 'precision': '0.164', 'recall': '0.053', 'f1': '0.081', 'total_rewards': -1912.7891990957826, 'invalid_action_count': 1933, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -482.6394042358148
# steps	 1000 	total rewards	 -948.0838024598221
# steps	 1500 	total rewards	 -1400.8031348838645
# Finished after 1988 timesteps (3.3782808780670166 seconds) with total reward -1839.557297650496
# {'coverage_prop': '0.345', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '25', 'FP': '111', 'FN': '258', 'precision': '0.184', 'recall': '0.088', 'f1': '0.119', 'total_rewards': -1839.5572976504966, 'invalid_action_count': 1883, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -482.8487700345112
# steps	 1000 	total rewards	 -933.3154921141944
# steps	 1500 	total rewards	 -1351.6841529507515
# Finished after 1990 timesteps (3.860701084136963 seconds) with total reward -1806.2886426617497
# {'coverage_prop': '0.403', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.005', 'efficiency': '0.092', 'TP': '48', 'FP': '134', 'FN': '270', 'precision': '0.264', 'recall': '0.151', 'f1': '0.192', 'total_rewards': -1806.2886426617508, 'invalid_action_count': 1862, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -475.4646696648075
# steps	 1000 	total rewards	 -938.4690581984686
# steps	 1500 	total rewards	 -1386.074148043115
# Finished after 1989 timesteps (3.790841817855835 seconds) with total reward -1836.6432024489468
# {'coverage_prop': '0.339', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.006', 'efficiency': '0.075', 'TP': '29', 'FP': '119', 'FN': '289', 'precision': '0.196', 'recall': '0.091', 'f1': '0.124', 'total_rewards': -1836.6432024489466, 'invalid_action_count': 1881, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -486.4420910767931
# steps	 1000 	total rewards	 -977.522373422328
# steps	 1500 	total rewards	 -1449.505027501461
# Finished after 1994 timesteps (2.21051287651062 seconds) with total reward -1925.3188924956419
# {'coverage_prop': '0.290', 'intensity_prop': '0.046', 'ms1ms2_ratio': '0.003', 'efficiency': '0.029', 'TP': '9', 'FP': '49', 'FN': '142', 'precision': '0.155', 'recall': '0.060', 'f1': '0.086', 'total_rewards': -1925.3188924956423, 'invalid_action_count': 1946, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -481.1446849956036
# steps	 1000 	total rewards	 -947.6670477186462
# steps	 1500 	total rewards	 -1356.9826568750516
# Finished after 1987 timesteps (3.598680019378662 seconds) with total reward -1800.9419321417604
# {'coverage_prop': '0.397', 'intensity_prop': '0.115', 'ms1ms2_ratio': '0.007', 'efficiency': '0.096', 'TP': '52', 'FP': '138', 'FN': '288', 'precision': '0.274', 'recall': '0.153', 'f1': '0.196', 'total_rewards': -1800.9419321417597, 'invalid_action_count': 1856, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -492.25162427683335
# steps	 1000 	total rewards	 -965.1834884535152
# steps	 1500 	total rewards	 -1428.5552257395802
# Finished after 1988 timesteps (2.2715487480163574 seconds) with total reward -1894.3222355918642
# {'coverage_prop': '0.319', 'intensity_prop': '0.072', 'ms1ms2_ratio': '0.006', 'efficiency': '0.033', 'TP': '11', 'FP': '54', 'FN': '139', 'precision': '0.169', 'recall': '0.073', 'f1': '0.102', 'total_rewards': -1894.322235591864, 'invalid_action_count': 1920, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -467.48039027766424
# steps	 1000 	total rewards	 -934.7255382511432
# steps	 1500 	total rewards	 -1381.5004275353972
# Finished after 1987 timesteps (3.4559669494628906 seconds) with total reward -1814.6489526508567
# {'coverage_prop': '0.361', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.007', 'efficiency': '0.078', 'TP': '23', 'FP': '130', 'FN': '271', 'precision': '0.150', 'recall': '0.078', 'f1': '0.103', 'total_rewards': -1814.6489526508572, 'invalid_action_count': 1863, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -480.13279563070716
# steps	 1000 	total rewards	 -955.5722589595484
# steps	 1500 	total rewards	 -1449.6723931622423
# Finished after 1990 timesteps (3.047234058380127 seconds) with total reward -1919.348369542096
# {'coverage_prop': '0.172', 'intensity_prop': '0.032', 'ms1ms2_ratio': '0.005', 'efficiency': '0.033', 'TP': '9', 'FP': '57', 'FN': '318', 'precision': '0.136', 'recall': '0.028', 'f1': '0.046', 'total_rewards': -1919.348369542096, 'invalid_action_count': 1939, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -487.5375305170545
# steps	 1000 	total rewards	 -949.1573636746542
# steps	 1500 	total rewards	 -1403.2725774403848
# Finished after 1990 timesteps (3.4192700386047363 seconds) with total reward -1828.994460207292
# {'coverage_prop': '0.325', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.005', 'efficiency': '0.073', 'TP': '27', 'FP': '117', 'FN': '299', 'precision': '0.188', 'recall': '0.083', 'f1': '0.115', 'total_rewards': -1828.994460207292, 'invalid_action_count': 1873, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -493.2149615178124
# steps	 1000 	total rewards	 -959.7393776739826
# steps	 1500 	total rewards	 -1430.48175932022
# Finished after 1986 timesteps (2.460094928741455 seconds) with total reward -1882.7691469633692
# {'coverage_prop': '0.325', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.007', 'efficiency': '0.041', 'TP': '21', 'FP': '60', 'FN': '168', 'precision': '0.259', 'recall': '0.111', 'f1': '0.156', 'total_rewards': -1882.769146963369, 'invalid_action_count': 1911, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -486.42358335783547
# steps	 1000 	total rewards	 -983.2156645313697
# steps	 1500 	total rewards	 -1436.0192614905409
# Finished after 1991 timesteps (2.9186060428619385 seconds) with total reward -1904.4384425871817
# {'coverage_prop': '0.287', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.005', 'efficiency': '0.036', 'TP': '16', 'FP': '56', 'FN': '179', 'precision': '0.222', 'recall': '0.082', 'f1': '0.120', 'total_rewards': -1904.4384425871813, 'invalid_action_count': 1929, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -484.5356279282667
# steps	 1000 	total rewards	 -968.7521245428851
# steps	 1500 	total rewards	 -1424.928315135768
# Finished after 1989 timesteps (2.868675947189331 seconds) with total reward -1863.2453944849394
# {'coverage_prop': '0.343', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.006', 'efficiency': '0.052', 'TP': '27', 'FP': '76', 'FN': '197', 'precision': '0.262', 'recall': '0.121', 'f1': '0.165', 'total_rewards': -1863.2453944849392, 'invalid_action_count': 1899, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -489.4160512972768
# steps	 1000 	total rewards	 -969.0740815798343
# steps	 1500 	total rewards	 -1435.9965999396886
# Finished after 1994 timesteps (2.2907698154449463 seconds) with total reward -1912.9292117285597
# {'coverage_prop': '0.306', 'intensity_prop': '0.062', 'ms1ms2_ratio': '0.003', 'efficiency': '0.032', 'TP': '11', 'FP': '52', 'FN': '143', 'precision': '0.175', 'recall': '0.071', 'f1': '0.101', 'total_rewards': -1912.9292117285595, 'invalid_action_count': 1937, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -491.62912016832576
# steps	 1000 	total rewards	 -938.8078868116991
# steps	 1500 	total rewards	 -1353.7773089418222
# Finished after 1981 timesteps (3.2656641006469727 seconds) with total reward -1787.4299048056946
# {'coverage_prop': '0.450', 'intensity_prop': '0.146', 'ms1ms2_ratio': '0.010', 'efficiency': '0.093', 'TP': '53', 'FP': '130', 'FN': '224', 'precision': '0.290', 'recall': '0.191', 'f1': '0.230', 'total_rewards': -1787.4299048056942, 'invalid_action_count': 1842, 'num_ms1_scans': 19, 'num_ms2_scans': 1962}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -484.91618044161953
# steps	 1000 	total rewards	 -911.5327820032115
# steps	 1500 	total rewards	 -1340.9538895700516
# Finished after 1988 timesteps (3.8488898277282715 seconds) with total reward -1785.723478167768
# {'coverage_prop': '0.426', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.006', 'efficiency': '0.107', 'TP': '48', 'FP': '164', 'FN': '286', 'precision': '0.226', 'recall': '0.144', 'f1': '0.176', 'total_rewards': -1785.723478167769, 'invalid_action_count': 1849, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -494.77695456356525
# steps	 1000 	total rewards	 -952.9720705729112
# steps	 1500 	total rewards	 -1397.2744233647043
# Finished after 1988 timesteps (3.1786041259765625 seconds) with total reward -1834.747234407364
# {'coverage_prop': '0.358', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.006', 'efficiency': '0.067', 'TP': '29', 'FP': '104', 'FN': '239', 'precision': '0.218', 'recall': '0.108', 'f1': '0.145', 'total_rewards': -1834.7472344073656, 'invalid_action_count': 1881, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -494.7946001884441
# steps	 1000 	total rewards	 -962.8552512186532
# steps	 1500 	total rewards	 -1428.223751502284
# Finished after 1993 timesteps (2.9805939197540283 seconds) with total reward -1895.7084331807005
# {'coverage_prop': '0.291', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.004', 'efficiency': '0.044', 'TP': '17', 'FP': '71', 'FN': '214', 'precision': '0.193', 'recall': '0.074', 'f1': '0.107', 'total_rewards': -1895.7084331807014, 'invalid_action_count': 1924, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -476.49011981194224
# steps	 1000 	total rewards	 -957.5609774900729
# steps	 1500 	total rewards	 -1423.0165781661806
# Finished after 1990 timesteps (2.6086037158966064 seconds) with total reward -1854.0544814264817
# {'coverage_prop': '0.385', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.005', 'efficiency': '0.052', 'TP': '27', 'FP': '75', 'FN': '163', 'precision': '0.265', 'recall': '0.142', 'f1': '0.185', 'total_rewards': -1854.0544814264817, 'invalid_action_count': 1894, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -478.0227273468075
# steps	 1000 	total rewards	 -917.1315599650504
# steps	 1500 	total rewards	 -1352.801469203696
# Finished after 1989 timesteps (3.8089778423309326 seconds) with total reward -1795.5667717719766
# {'coverage_prop': '0.376', 'intensity_prop': '0.115', 'ms1ms2_ratio': '0.006', 'efficiency': '0.089', 'TP': '46', 'FP': '130', 'FN': '292', 'precision': '0.261', 'recall': '0.136', 'f1': '0.179', 'total_rewards': -1795.566771771977, 'invalid_action_count': 1854, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -481.8073811947147
# steps	 1000 	total rewards	 -963.662392359148
# steps	 1500 	total rewards	 -1422.7301411619808
# Finished after 1983 timesteps (2.311875104904175 seconds) with total reward -1874.9891335358445
# {'coverage_prop': '0.359', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.009', 'efficiency': '0.043', 'TP': '26', 'FP': '58', 'FN': '150', 'precision': '0.310', 'recall': '0.148', 'f1': '0.200', 'total_rewards': -1874.9891335358443, 'invalid_action_count': 1905, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -956.6322415569081
# steps	 1500 	total rewards	 -1401.121586510505
# Finished after 1986 timesteps (3.192218065261841 seconds) with total reward -1847.992578526266
# {'coverage_prop': '0.360', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.007', 'efficiency': '0.059', 'TP': '26', 'FP': '90', 'FN': '206', 'precision': '0.224', 'recall': '0.112', 'f1': '0.149', 'total_rewards': -1847.992578526266, 'invalid_action_count': 1887, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -495.3855024983899
# steps	 1000 	total rewards	 -955.4930808447562
# steps	 1500 	total rewards	 -1422.4171992478425
# Finished after 1989 timesteps (2.615070104598999 seconds) with total reward -1876.8973062581108
# {'coverage_prop': '0.316', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.006', 'efficiency': '0.050', 'TP': '23', 'FP': '75', 'FN': '212', 'precision': '0.235', 'recall': '0.098', 'f1': '0.138', 'total_rewards': -1876.8973062581113, 'invalid_action_count': 1909, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -485.30468539670403
# steps	 1000 	total rewards	 -963.8251348880048
# steps	 1500 	total rewards	 -1400.6791345616398
# Finished after 1989 timesteps (2.9424118995666504 seconds) with total reward -1822.2560653963042
# {'coverage_prop': '0.417', 'intensity_prop': '0.115', 'ms1ms2_ratio': '0.006', 'efficiency': '0.073', 'TP': '36', 'FP': '108', 'FN': '201', 'precision': '0.250', 'recall': '0.152', 'f1': '0.189', 'total_rewards': -1822.2560653963046, 'invalid_action_count': 1873, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -943.5102613039965
# steps	 1500 	total rewards	 -1400.4718646982737
# Finished after 1991 timesteps (3.2432212829589844 seconds) with total reward -1840.5076631552652
# {'coverage_prop': '0.364', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.005', 'efficiency': '0.073', 'TP': '27', 'FP': '117', 'FN': '252', 'precision': '0.188', 'recall': '0.097', 'f1': '0.128', 'total_rewards': -1840.507663155265, 'invalid_action_count': 1887, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -486.1416382966223
# steps	 1000 	total rewards	 -972.1243588699144
# steps	 1500 	total rewards	 -1439.0787174292755
# Finished after 1985 timesteps (2.2520320415496826 seconds) with total reward -1905.9330558856825
# {'coverage_prop': '0.300', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.008', 'efficiency': '0.031', 'TP': '18', 'FP': '43', 'FN': '142', 'precision': '0.295', 'recall': '0.113', 'f1': '0.163', 'total_rewards': -1905.9330558856823, 'invalid_action_count': 1927, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -480.512049287506
# steps	 1000 	total rewards	 -957.6450625305429
# steps	 1500 	total rewards	 -1441.439096301921
# Finished after 1992 timesteps (2.4585227966308594 seconds) with total reward -1906.2372878490535
# {'coverage_prop': '0.278', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.004', 'efficiency': '0.039', 'TP': '16', 'FP': '62', 'FN': '203', 'precision': '0.205', 'recall': '0.073', 'f1': '0.108', 'total_rewards': -1906.2372878490537, 'invalid_action_count': 1933, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -477.242455094117
# steps	 1000 	total rewards	 -952.05574556327
# steps	 1500 	total rewards	 -1381.5891519568622
# Finished after 1993 timesteps (3.8485031127929688 seconds) with total reward -1819.4208642805545
# {'coverage_prop': '0.375', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.004', 'efficiency': '0.093', 'TP': '36', 'FP': '149', 'FN': '308', 'precision': '0.195', 'recall': '0.105', 'f1': '0.136', 'total_rewards': -1819.4208642805547, 'invalid_action_count': 1874, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -471.9538246234303
# steps	 1000 	total rewards	 -948.5701517746888
# steps	 1500 	total rewards	 -1409.8462913763324
# Finished after 1990 timesteps (3.129728078842163 seconds) with total reward -1874.8593545155777
# {'coverage_prop': '0.349', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.005', 'efficiency': '0.054', 'TP': '25', 'FP': '81', 'FN': '198', 'precision': '0.236', 'recall': '0.112', 'f1': '0.152', 'total_rewards': -1874.8593545155775, 'invalid_action_count': 1907, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# method = DQN max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.64GB > 0.41GB
# steps	 500 	total rewards	 64.39075170619087
# steps	 1000 	total rewards	 157.23957775748116
# Finished after 1263 timesteps (5.742980003356934 seconds) with total reward 191.6577039221769
# {'coverage_prop': '0.925', 'intensity_prop': '0.552', 'ms1ms2_ratio': '1.406', 'efficiency': '0.750', 'TP': '263', 'FP': '131', 'FN': '32', 'precision': '0.668', 'recall': '0.892', 'f1': '0.763', 'total_rewards': 191.6577039221768, 'invalid_action_count': 3, 'num_ms1_scans': 738, 'num_ms2_scans': 525}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 51.206610376532495
# steps	 1000 	total rewards	 118.6253289407849
# Finished after 1194 timesteps (4.606579780578613 seconds) with total reward 132.0574396405919
# {'coverage_prop': '0.943', 'intensity_prop': '0.614', 'ms1ms2_ratio': '2.093', 'efficiency': '0.640', 'TP': '191', 'FP': '56', 'FN': '15', 'precision': '0.773', 'recall': '0.927', 'f1': '0.843', 'total_rewards': 132.05743964059184, 'invalid_action_count': 4, 'num_ms1_scans': 808, 'num_ms2_scans': 386}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 49.20148745157377
# steps	 1000 	total rewards	 138.6472709285759
# Finished after 1234 timesteps (6.188153266906738 seconds) with total reward 167.98280589208827
# {'coverage_prop': '0.906', 'intensity_prop': '0.534', 'ms1ms2_ratio': '1.648', 'efficiency': '0.766', 'TP': '234', 'FP': '123', 'FN': '37', 'precision': '0.655', 'recall': '0.863', 'f1': '0.745', 'total_rewards': 167.98280589208827, 'invalid_action_count': 8, 'num_ms1_scans': 768, 'num_ms2_scans': 466}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 62.88044505302582
# steps	 1000 	total rewards	 160.96123468342705
# Finished after 1282 timesteps (265.23636293411255 seconds) with total reward 197.78852861857501
# {'coverage_prop': '0.920', 'intensity_prop': '0.585', 'ms1ms2_ratio': '1.273', 'efficiency': '0.738', 'TP': '303', 'FP': '113', 'FN': '36', 'precision': '0.728', 'recall': '0.894', 'f1': '0.803', 'total_rewards': 197.78852861857484, 'invalid_action_count': 7, 'num_ms1_scans': 718, 'num_ms2_scans': 564}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 58.50544199472111
# steps	 1000 	total rewards	 154.70429632300718
# Finished after 1266 timesteps (6.7349371910095215 seconds) with total reward 186.26447166065017
# {'coverage_prop': '0.934', 'intensity_prop': '0.582', 'ms1ms2_ratio': '1.380', 'efficiency': '0.767', 'TP': '274', 'FP': '134', 'FN': '29', 'precision': '0.672', 'recall': '0.904', 'f1': '0.771', 'total_rewards': 186.26447166065003, 'invalid_action_count': 6, 'num_ms1_scans': 734, 'num_ms2_scans': 532}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 38.560715562142185
# steps	 1000 	total rewards	 90.24469166034113
# Finished after 1166 timesteps (3.657932996749878 seconds) with total reward 99.62810453733871
# {'coverage_prop': '0.960', 'intensity_prop': '0.663', 'ms1ms2_ratio': '2.523', 'efficiency': '0.580', 'TP': '148', 'FP': '44', 'FN': '8', 'precision': '0.771', 'recall': '0.949', 'f1': '0.851', 'total_rewards': 99.62810453733874, 'invalid_action_count': 7, 'num_ms1_scans': 835, 'num_ms2_scans': 331}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.72552752051661
# steps	 1000 	total rewards	 156.83863669940018
# Finished after 1276 timesteps (7.32865309715271 seconds) with total reward 192.98875783130046
# {'coverage_prop': '0.885', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.312', 'efficiency': '0.766', 'TP': '285', 'FP': '138', 'FN': '55', 'precision': '0.674', 'recall': '0.838', 'f1': '0.747', 'total_rewards': 192.98875783130043, 'invalid_action_count': 7, 'num_ms1_scans': 724, 'num_ms2_scans': 552}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 42.327628644905744
# steps	 1000 	total rewards	 97.91048363215472
# Finished after 1155 timesteps (4.985346794128418 seconds) with total reward 109.4445341312431
# {'coverage_prop': '0.951', 'intensity_prop': '0.623', 'ms1ms2_ratio': '2.738', 'efficiency': '0.628', 'TP': '142', 'FP': '52', 'FN': '10', 'precision': '0.732', 'recall': '0.934', 'f1': '0.821', 'total_rewards': 109.44453413124309, 'invalid_action_count': 1, 'num_ms1_scans': 846, 'num_ms2_scans': 309}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 70.585674988108
# steps	 1000 	total rewards	 151.0226151842034
# Finished after 1256 timesteps (6.552164793014526 seconds) with total reward 183.6764022124916
# {'coverage_prop': '0.910', 'intensity_prop': '0.568', 'ms1ms2_ratio': '1.453', 'efficiency': '0.754', 'TP': '268', 'FP': '118', 'FN': '38', 'precision': '0.694', 'recall': '0.876', 'f1': '0.775', 'total_rewards': 183.67640221249158, 'invalid_action_count': 3, 'num_ms1_scans': 744, 'num_ms2_scans': 512}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 55.79233235765152
# steps	 1000 	total rewards	 143.65052883553955
# Finished after 1258 timesteps (5.334105730056763 seconds) with total reward 171.37087900904993
# {'coverage_prop': '0.935', 'intensity_prop': '0.583', 'ms1ms2_ratio': '1.438', 'efficiency': '0.696', 'TP': '252', 'FP': '107', 'FN': '25', 'precision': '0.702', 'recall': '0.910', 'f1': '0.792', 'total_rewards': 171.37087900904987, 'invalid_action_count': 3, 'num_ms1_scans': 742, 'num_ms2_scans': 516}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 62.43866806923691
# steps	 1000 	total rewards	 155.38031828021835
# Finished after 1290 timesteps (6.919668912887573 seconds) with total reward 193.5816562361173
# {'coverage_prop': '0.914', 'intensity_prop': '0.589', 'ms1ms2_ratio': '1.224', 'efficiency': '0.698', 'TP': '300', 'FP': '105', 'FN': '38', 'precision': '0.741', 'recall': '0.888', 'f1': '0.808', 'total_rewards': 193.5816562361174, 'invalid_action_count': 10, 'num_ms1_scans': 710, 'num_ms2_scans': 580}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 49.69875060027656
# steps	 1000 	total rewards	 102.31949193676687
# Finished after 1179 timesteps (4.499884843826294 seconds) with total reward 117.18204340969106
# {'coverage_prop': '0.920', 'intensity_prop': '0.606', 'ms1ms2_ratio': '2.312', 'efficiency': '0.643', 'TP': '177', 'FP': '52', 'FN': '20', 'precision': '0.773', 'recall': '0.898', 'f1': '0.831', 'total_rewards': 117.18204340969112, 'invalid_action_count': 4, 'num_ms1_scans': 823, 'num_ms2_scans': 356}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 49.08171844767313
# steps	 1000 	total rewards	 106.93944609256849
# Finished after 1178 timesteps (4.5741400718688965 seconds) with total reward 125.01867608563026
# {'coverage_prop': '0.944', 'intensity_prop': '0.551', 'ms1ms2_ratio': '2.328', 'efficiency': '0.669', 'TP': '152', 'FP': '85', 'FN': '14', 'precision': '0.641', 'recall': '0.916', 'f1': '0.754', 'total_rewards': 125.0186760856303, 'invalid_action_count': 1, 'num_ms1_scans': 824, 'num_ms2_scans': 354}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 40.665181403096526
# steps	 1000 	total rewards	 116.65568436456554
# Finished after 1222 timesteps (6.459080934524536 seconds) with total reward 138.48534758387842
# {'coverage_prop': '0.927', 'intensity_prop': '0.551', 'ms1ms2_ratio': '1.758', 'efficiency': '0.628', 'TP': '183', 'FP': '95', 'FN': '22', 'precision': '0.658', 'recall': '0.893', 'f1': '0.758', 'total_rewards': 138.48534758387854, 'invalid_action_count': 6, 'num_ms1_scans': 779, 'num_ms2_scans': 443}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 41.09675704183263
# steps	 1000 	total rewards	 94.0653236207313
# Finished after 1172 timesteps (4.176742076873779 seconds) with total reward 107.22016733730538
# {'coverage_prop': '0.917', 'intensity_prop': '0.594', 'ms1ms2_ratio': '2.427', 'efficiency': '0.553', 'TP': '139', 'FP': '50', 'FN': '17', 'precision': '0.735', 'recall': '0.891', 'f1': '0.806', 'total_rewards': 107.22016733730536, 'invalid_action_count': 1, 'num_ms1_scans': 830, 'num_ms2_scans': 342}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 48.10954797906902
# steps	 1000 	total rewards	 139.94426620910946
# Finished after 1267 timesteps (5.638705730438232 seconds) with total reward 172.43351735734595
# {'coverage_prop': '0.939', 'intensity_prop': '0.603', 'ms1ms2_ratio': '1.373', 'efficiency': '0.715', 'TP': '273', 'FP': '109', 'FN': '25', 'precision': '0.715', 'recall': '0.916', 'f1': '0.803', 'total_rewards': 172.4335173573459, 'invalid_action_count': 14, 'num_ms1_scans': 733, 'num_ms2_scans': 534}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 69.23319806784545
# steps	 1000 	total rewards	 166.7563070705483
# Finished after 1302 timesteps (6.187800884246826 seconds) with total reward 208.44729684764195
# {'coverage_prop': '0.924', 'intensity_prop': '0.569', 'ms1ms2_ratio': '1.156', 'efficiency': '0.762', 'TP': '318', 'FP': '142', 'FN': '38', 'precision': '0.691', 'recall': '0.893', 'f1': '0.779', 'total_rewards': 208.44729684764206, 'invalid_action_count': 11, 'num_ms1_scans': 698, 'num_ms2_scans': 604}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 60.57286894782001
# steps	 1000 	total rewards	 142.98545307326702
# Finished after 1234 timesteps (5.043851852416992 seconds) with total reward 171.02731199066
# {'coverage_prop': '0.930', 'intensity_prop': '0.577', 'ms1ms2_ratio': '1.642', 'efficiency': '0.741', 'TP': '246', 'FP': '100', 'FN': '26', 'precision': '0.711', 'recall': '0.904', 'f1': '0.796', 'total_rewards': 171.02731199066, 'invalid_action_count': 4, 'num_ms1_scans': 767, 'num_ms2_scans': 467}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.67631591624726
# steps	 1000 	total rewards	 122.14019148736463
# Finished after 1203 timesteps (6.195894956588745 seconds) with total reward 145.37601960286864
# {'coverage_prop': '0.950', 'intensity_prop': '0.578', 'ms1ms2_ratio': '1.978', 'efficiency': '0.710', 'TP': '190', 'FP': '97', 'FN': '15', 'precision': '0.662', 'recall': '0.927', 'f1': '0.772', 'total_rewards': 145.37601960286858, 'invalid_action_count': 3, 'num_ms1_scans': 799, 'num_ms2_scans': 404}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 47.52524091241736
# steps	 1000 	total rewards	 115.62661585525215
# Finished after 1183 timesteps (4.352133274078369 seconds) with total reward 131.0431592407886
# {'coverage_prop': '0.955', 'intensity_prop': '0.555', 'ms1ms2_ratio': '2.241', 'efficiency': '0.693', 'TP': '159', 'FP': '94', 'FN': '12', 'precision': '0.628', 'recall': '0.930', 'f1': '0.750', 'total_rewards': 131.04315924078864, 'invalid_action_count': 2, 'num_ms1_scans': 818, 'num_ms2_scans': 365}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 61.96962193651215
# steps	 1000 	total rewards	 147.90163785330412
# Finished after 1287 timesteps (7.136972904205322 seconds) with total reward 180.57980331382421
# {'coverage_prop': '0.876', 'intensity_prop': '0.551', 'ms1ms2_ratio': '1.246', 'efficiency': '0.716', 'TP': '294', 'FP': '116', 'FN': '58', 'precision': '0.717', 'recall': '0.835', 'f1': '0.772', 'total_rewards': 180.57980331382421, 'invalid_action_count': 14, 'num_ms1_scans': 714, 'num_ms2_scans': 573}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 41.60161628791009
# steps	 1000 	total rewards	 102.89775526312101
# Finished after 1165 timesteps (4.023291110992432 seconds) with total reward 114.03448301346278
# {'coverage_prop': '0.919', 'intensity_prop': '0.589', 'ms1ms2_ratio': '2.541', 'efficiency': '0.653', 'TP': '153', 'FP': '62', 'FN': '19', 'precision': '0.712', 'recall': '0.890', 'f1': '0.791', 'total_rewards': 114.03448301346279, 'invalid_action_count': 3, 'num_ms1_scans': 836, 'num_ms2_scans': 329}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 55.829790355915755
# steps	 1000 	total rewards	 132.33628067261412
# Finished after 1216 timesteps (6.204714059829712 seconds) with total reward 153.37819669682722
# {'coverage_prop': '0.938', 'intensity_prop': '0.559', 'ms1ms2_ratio': '1.821', 'efficiency': '0.701', 'TP': '204', 'FP': '98', 'FN': '20', 'precision': '0.675', 'recall': '0.911', 'f1': '0.776', 'total_rewards': 153.37819669682727, 'invalid_action_count': 1, 'num_ms1_scans': 785, 'num_ms2_scans': 431}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 55.580127001803305
# steps	 1000 	total rewards	 131.07406425931885
# Finished after 1203 timesteps (4.372589111328125 seconds) with total reward 150.9323666689146
# {'coverage_prop': '0.942', 'intensity_prop': '0.609', 'ms1ms2_ratio': '1.970', 'efficiency': '0.721', 'TP': '211', 'FP': '81', 'FN': '18', 'precision': '0.723', 'recall': '0.921', 'f1': '0.810', 'total_rewards': 150.9323666689148, 'invalid_action_count': 3, 'num_ms1_scans': 798, 'num_ms2_scans': 405}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 56.55070834687842
# steps	 1000 	total rewards	 136.48095072969636
# Finished after 1249 timesteps (4.836109161376953 seconds) with total reward 166.94350626717298
# {'coverage_prop': '0.936', 'intensity_prop': '0.567', 'ms1ms2_ratio': '1.513', 'efficiency': '0.650', 'TP': '218', 'FP': '105', 'FN': '22', 'precision': '0.675', 'recall': '0.908', 'f1': '0.774', 'total_rewards': 166.94350626717298, 'invalid_action_count': 6, 'num_ms1_scans': 752, 'num_ms2_scans': 497}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 56.52195910040848
# steps	 1000 	total rewards	 134.77627405443152
# Finished after 1251 timesteps (6.500133752822876 seconds) with total reward 170.19638522039835
# {'coverage_prop': '0.952', 'intensity_prop': '0.592', 'ms1ms2_ratio': '1.497', 'efficiency': '0.752', 'TP': '270', 'FP': '107', 'FN': '19', 'precision': '0.716', 'recall': '0.934', 'f1': '0.811', 'total_rewards': 170.19638522039813, 'invalid_action_count': 8, 'num_ms1_scans': 750, 'num_ms2_scans': 501}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 37.8738822807261
# steps	 1000 	total rewards	 95.64623357753754
# Finished after 1170 timesteps (3.8846218585968018 seconds) with total reward 108.69578699283628
# {'coverage_prop': '0.961', 'intensity_prop': '0.651', 'ms1ms2_ratio': '2.451', 'efficiency': '0.575', 'TP': '151', 'FP': '44', 'FN': '8', 'precision': '0.774', 'recall': '0.950', 'f1': '0.853', 'total_rewards': 108.69578699283623, 'invalid_action_count': 2, 'num_ms1_scans': 831, 'num_ms2_scans': 339}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 50.05678725451035
# steps	 1000 	total rewards	 121.01416059297713
# Finished after 1194 timesteps (4.182561874389648 seconds) with total reward 146.5646832729995
# {'coverage_prop': '0.950', 'intensity_prop': '0.619', 'ms1ms2_ratio': '2.093', 'efficiency': '0.692', 'TP': '195', 'FP': '72', 'FN': '14', 'precision': '0.730', 'recall': '0.933', 'f1': '0.819', 'total_rewards': 146.56468327299942, 'invalid_action_count': 0, 'num_ms1_scans': 808, 'num_ms2_scans': 386}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 70.27274275682008
# steps	 1000 	total rewards	 154.4830642719815
# Finished after 1307 timesteps (7.402817010879517 seconds) with total reward 201.39190337543914
# {'coverage_prop': '0.895', 'intensity_prop': '0.547', 'ms1ms2_ratio': '1.129', 'efficiency': '0.718', 'TP': '306', 'FP': '135', 'FN': '52', 'precision': '0.694', 'recall': '0.855', 'f1': '0.766', 'total_rewards': 201.39190337543914, 'invalid_action_count': 15, 'num_ms1_scans': 693, 'num_ms2_scans': 614}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 55.471507227019146
# steps	 1000 	total rewards	 124.63068100487916
# Finished after 1203 timesteps (4.605571985244751 seconds) with total reward 144.653417375064
# {'coverage_prop': '0.954', 'intensity_prop': '0.584', 'ms1ms2_ratio': '1.970', 'efficiency': '0.716', 'TP': '196', 'FP': '94', 'FN': '14', 'precision': '0.676', 'recall': '0.933', 'f1': '0.784', 'total_rewards': 144.65341737506404, 'invalid_action_count': 3, 'num_ms1_scans': 798, 'num_ms2_scans': 405}
#
# method = topN max_peaks = 200 N = 10 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 64.27897282132969
# steps	 1000 	total rewards	 153.0615418315449
# steps	 1500 	total rewards	 242.68506332538016
# Finished after 1722 timesteps (9.543060064315796 seconds) with total reward 274.39446443224483
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 274.39446443224455, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 56.53441275069887
# steps	 1000 	total rewards	 133.44353713101043
# steps	 1500 	total rewards	 194.26613921470476
# Finished after 1556 timesteps (7.905557870864868 seconds) with total reward 198.80142796822798
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 198.8014279682283, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 57.30827329618448
# steps	 1000 	total rewards	 142.16274804562107
# steps	 1500 	total rewards	 225.2837165391693
# Finished after 1670 timesteps (11.08686089515686 seconds) with total reward 246.21594099879326
# {'coverage_prop': '0.924', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.246', 'efficiency': '0.272', 'TP': '328', 'FP': '36', 'FN': '30', 'precision': '0.901', 'recall': '0.916', 'f1': '0.909', 'total_rewards': 246.21594099879346, 'invalid_action_count': 0, 'num_ms1_scans': 330, 'num_ms2_scans': 1340}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 71.12814612435277
# steps	 1000 	total rewards	 157.62727339419465
# steps	 1500 	total rewards	 238.78056886179576
# Finished after 1717 timesteps (9.89994764328003 seconds) with total reward 272.3235910501669
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 272.323591050167, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 61.90389809276462
# steps	 1000 	total rewards	 157.856811245934
# steps	 1500 	total rewards	 243.79212098759848
# Finished after 1704 timesteps (9.427190065383911 seconds) with total reward 273.0181148295186
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 273.0181148295187, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 39.896487753445214
# steps	 1000 	total rewards	 106.51412980303726
# Finished after 1410 timesteps (7.3506951332092285 seconds) with total reward 142.9017997307617
# {'coverage_prop': '0.960', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.720', 'efficiency': '0.234', 'TP': '184', 'FP': '8', 'FN': '8', 'precision': '0.958', 'recall': '0.958', 'f1': '0.958', 'total_rewards': 142.90179973076172, 'invalid_action_count': 0, 'num_ms1_scans': 590, 'num_ms2_scans': 820}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.22043408731386
# steps	 1000 	total rewards	 162.04397467383103
# steps	 1500 	total rewards	 244.55745713793698
# Finished after 1744 timesteps (9.886482954025269 seconds) with total reward 280.3023687938845
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 280.3023687938843, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.49031082023858
# steps	 1000 	total rewards	 115.83126130267036
# Finished after 1472 timesteps (9.444440126419067 seconds) with total reward 162.78995135881587
# {'coverage_prop': '0.966', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '186', 'FP': '11', 'FN': '7', 'precision': '0.944', 'recall': '0.964', 'f1': '0.954', 'total_rewards': 162.78995135881573, 'invalid_action_count': 0, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.46621454358737
# steps	 1000 	total rewards	 149.00350104084623
# steps	 1500 	total rewards	 234.0142896045665
# Finished after 1736 timesteps (10.202100992202759 seconds) with total reward 265.5548286824893
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 265.5548286824895, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 56.81220021632257
# steps	 1000 	total rewards	 137.61714657475966
# steps	 1500 	total rewards	 219.6394324027019
# Finished after 1668 timesteps (9.022249937057495 seconds) with total reward 237.23755641721067
# {'coverage_prop': '0.924', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.249', 'efficiency': '0.266', 'TP': '324', 'FP': '31', 'FN': '29', 'precision': '0.913', 'recall': '0.918', 'f1': '0.915', 'total_rewards': 237.2375564172111, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 1336}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 63.48883485609902
# steps	 1000 	total rewards	 148.03351769555485
# steps	 1500 	total rewards	 236.5520895809973
# Finished after 1737 timesteps (9.828704118728638 seconds) with total reward 267.3066297171516
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 267.30662971715145, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 50.64739428018553
# steps	 1000 	total rewards	 120.53245139860438
# steps	 1500 	total rewards	 172.636404345169
# Finished after 1531 timesteps (7.976321220397949 seconds) with total reward 175.30046321087713
# {'coverage_prop': '0.960', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.442', 'efficiency': '0.225', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949', 'total_rewards': 175.30046321087715, 'invalid_action_count': 0, 'num_ms1_scans': 469, 'num_ms2_scans': 1062}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 48.92994799712743
# steps	 1000 	total rewards	 119.15118054204709
# steps	 1500 	total rewards	 182.89587058315783
# Finished after 1602 timesteps (11.619833946228027 seconds) with total reward 193.71596466215053
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 193.7159646621502, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 51.102405475232786
# steps	 1000 	total rewards	 126.40211968727175
# steps	 1500 	total rewards	 196.43919744732793
# Finished after 1645 timesteps (9.012264013290405 seconds) with total reward 210.5440874069469
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 210.544087406947, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 42.10725329655742
# steps	 1000 	total rewards	 109.41532611939553
# Finished after 1497 timesteps (7.601181745529175 seconds) with total reward 161.78234703648474
# {'coverage_prop': '0.951', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.197', 'TP': '181', 'FP': '15', 'FN': '10', 'precision': '0.923', 'recall': '0.948', 'f1': '0.935', 'total_rewards': 161.78234703648477, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 56.96509366792624
# steps	 1000 	total rewards	 147.2095569715228
# steps	 1500 	total rewards	 226.3392432649163
# Finished after 1655 timesteps (9.406530141830444 seconds) with total reward 248.9212535879875
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 248.92125358798705, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.46974393432068
# steps	 1000 	total rewards	 159.8630857893615
# steps	 1500 	total rewards	 249.45187485282867
# Finished after 1729 timesteps (9.858972072601318 seconds) with total reward 282.33596729180294
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 282.33596729180283, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 65.28295924656409
# steps	 1000 	total rewards	 152.99159947570973
# steps	 1500 	total rewards	 227.85174096808055
# Finished after 1681 timesteps (8.909898042678833 seconds) with total reward 248.71724564061213
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 248.71724564061182, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.80527834803058
# steps	 1000 	total rewards	 131.25379282029033
# steps	 1500 	total rewards	 201.63169124775385
# Finished after 1621 timesteps (10.988868951797485 seconds) with total reward 213.3962276951981
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 213.39622769519795, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 51.64710716074973
# steps	 1000 	total rewards	 127.8682486554507
# steps	 1500 	total rewards	 190.93867231139512
# Finished after 1634 timesteps (8.253652095794678 seconds) with total reward 206.05567977408612
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 206.05567977408612, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.50994950851643
# steps	 1000 	total rewards	 155.90074680539868
# steps	 1500 	total rewards	 237.04838387022266
# Finished after 1726 timesteps (9.937185049057007 seconds) with total reward 269.74024806514274
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 269.7402480651435, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 42.87532685800643
# steps	 1000 	total rewards	 117.43198314660418
# Finished after 1475 timesteps (7.873782157897949 seconds) with total reward 166.9084951701829
# {'coverage_prop': '0.957', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '207', 'FP': '17', 'FN': '10', 'precision': '0.924', 'recall': '0.954', 'f1': '0.939', 'total_rewards': 166.90849517018293, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 58.07428174764222
# steps	 1000 	total rewards	 137.84913832412306
# steps	 1500 	total rewards	 209.9889884762968
# Finished after 1636 timesteps (9.305209159851074 seconds) with total reward 225.08898203089467
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 225.08898203089467, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 59.55579530112928
# steps	 1000 	total rewards	 139.27168276735108
# steps	 1500 	total rewards	 204.99301908857169
# Finished after 1575 timesteps (8.208781719207764 seconds) with total reward 212.0487707936014
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 212.04877079360148, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 55.90621614718264
# steps	 1000 	total rewards	 142.4674826906643
# steps	 1500 	total rewards	 218.74431307077577
# Finished after 1681 timesteps (11.908122062683105 seconds) with total reward 241.10125347896678
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 241.10125347896698, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 58.65795180800854
# steps	 1000 	total rewards	 136.8820258148469
# steps	 1500 	total rewards	 223.03824969963966
# Finished after 1679 timesteps (9.24259614944458 seconds) with total reward 244.79886972933062
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 244.79886972933082, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 38.93346073831778
# steps	 1000 	total rewards	 108.52782812655937
# Finished after 1465 timesteps (7.690555095672607 seconds) with total reward 154.61028044060535
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 154.61028044060512, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 51.766444526594
# steps	 1000 	total rewards	 130.46357019586054
# steps	 1500 	total rewards	 197.67932911107744
# Finished after 1562 timesteps (8.135448932647705 seconds) with total reward 205.97957200278756
# {'coverage_prop': '0.964', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.390', 'efficiency': '0.241', 'TP': '252', 'FP': '19', 'FN': '10', 'precision': '0.930', 'recall': '0.962', 'f1': '0.946', 'total_rewards': 205.9795720027877, 'invalid_action_count': 0, 'num_ms1_scans': 438, 'num_ms2_scans': 1124}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 74.33673783003661
# steps	 1000 	total rewards	 151.64147482739267
# steps	 1500 	total rewards	 238.19314377272508
# Finished after 1749 timesteps (9.88057804107666 seconds) with total reward 277.638109251984
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 277.63810925198385, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 56.98398947393331
# steps	 1000 	total rewards	 133.73469321594888
# steps	 1500 	total rewards	 202.51030010488844
# Finished after 1657 timesteps (8.536810874938965 seconds) with total reward 218.42816542635472
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 218.42816542635472, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7f5db2cc40>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7f184456a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7f48572940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '209', 'FP': '198', 'FN': '19', 'precision': '0.514', 'recall': '0.917', 'f1': '0.658'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.518', 'ms1ms2_ratio': '1.132', 'efficiency': '0.741', 'TP': '259', 'FP': '195', 'FN': '24', 'precision': '0.570', 'recall': '0.915', 'f1': '0.703'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '105', 'FP': '132', 'FN': '14', 'precision': '0.443', 'recall': '0.882', 'f1': '0.590'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.138', 'efficiency': '0.705', 'TP': '101', 'FP': '93', 'FN': '12', 'precision': '0.521', 'recall': '0.894', 'f1': '0.658'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.502', 'ms1ms2_ratio': '1.670', 'efficiency': '0.768', 'TP': '188', 'FP': '166', 'FN': '18', 'precision': '0.531', 'recall': '0.913', 'f1': '0.671'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.492', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '107', 'FP': '113', 'FN': '14', 'precision': '0.486', 'recall': '0.884', 'f1': '0.628'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.990', 'efficiency': '0.759', 'TP': '162', 'FP': '143', 'FN': '17', 'precision': '0.531', 'recall': '0.905', 'f1': '0.669'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.513', 'ms1ms2_ratio': '1.606', 'efficiency': '0.705', 'TP': '168', 'FP': '167', 'FN': '10', 'precision': '0.501', 'recall': '0.944', 'f1': '0.655'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.517', 'ms1ms2_ratio': '2.028', 'efficiency': '0.732', 'TP': '149', 'FP': '141', 'FN': '14', 'precision': '0.514', 'recall': '0.914', 'f1': '0.658'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1865.590708                1904.0          0.310           0.070
# 1  random   -1912.789199                1933.0          0.256           0.054
# 2  random   -1839.557298                1883.0          0.345           0.076
# 3  random   -1806.288643                1862.0          0.403           0.112
# 4  random   -1836.643202                1881.0          0.339           0.076
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.004       0.066      0.182   0.075  0.107
# 1          0.005       0.034      0.164   0.053  0.081
# 2          0.006       0.069      0.184   0.088  0.119
# 3          0.005       0.092      0.264   0.151  0.192
# 4          0.006       0.075      0.196   0.091  0.124

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     191.657704                   3.0          0.925           0.552
# 31    DQN     132.057440                   4.0          0.943           0.614
# 32    DQN     167.982806                   8.0          0.906           0.534
# 33    DQN     197.788529                   7.0          0.920           0.585
# 34    DQN     186.264472                   6.0          0.934           0.582
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          1.406       0.750      0.668   0.892  0.763
# 31          2.093       0.640      0.773   0.927  0.843
# 32          1.648       0.766      0.655   0.863  0.745
# 33          1.273       0.738      0.728   0.894  0.803
# 34          1.380       0.767      0.672   0.904  0.771

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
