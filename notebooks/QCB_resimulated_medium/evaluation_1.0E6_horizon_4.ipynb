# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-20 16:31:24.833 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8fcd31d5b0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8f9939c6d0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8fcf608970>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8fcd31d5b0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8f9939c6d0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8fcf608970>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8fcd31d5b0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8f9939c6d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8fcf608970>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -483.26551262364717
# steps	 1000 	total rewards	 -956.365426745892
# steps	 1500 	total rewards	 -1415.2885198739214
# Finished after 1990 timesteps (1.8196032047271729 seconds) with total reward -1864.931653064353
# {'coverage_prop': '0.326', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.005', 'efficiency': '0.070', 'TP': '26', 'FP': '113', 'FN': '287', 'precision': '0.187', 'recall': '0.083', 'f1': '0.115', 'total_rewards': -1864.9316530643523, 'invalid_action_count': 1902, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -487.95337095232605
# steps	 1000 	total rewards	 -959.6172175384077
# steps	 1500 	total rewards	 -1434.3783842646758
# Finished after 1992 timesteps (1.0101101398468018 seconds) with total reward -1903.6533343724077
# {'coverage_prop': '0.267', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.004', 'efficiency': '0.035', 'TP': '22', 'FP': '48', 'FN': '192', 'precision': '0.314', 'recall': '0.103', 'f1': '0.155', 'total_rewards': -1903.6533343724068, 'invalid_action_count': 1931, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -492.23616895085115
# steps	 1000 	total rewards	 -986.4830619984725
# steps	 1500 	total rewards	 -1412.1544288573164
# Finished after 1988 timesteps (1.2698917388916016 seconds) with total reward -1845.2378588037088
# {'coverage_prop': '0.353', 'intensity_prop': '0.088', 'ms1ms2_ratio': '0.006', 'efficiency': '0.070', 'TP': '34', 'FP': '105', 'FN': '255', 'precision': '0.245', 'recall': '0.118', 'f1': '0.159', 'total_rewards': -1845.2378588037084, 'invalid_action_count': 1889, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -463.1150532344452
# steps	 1000 	total rewards	 -934.8514179898818
# steps	 1500 	total rewards	 -1354.2937262983835
# Finished after 1989 timesteps (1.3242759704589844 seconds) with total reward -1792.5071640165202
# {'coverage_prop': '0.434', 'intensity_prop': '0.114', 'ms1ms2_ratio': '0.006', 'efficiency': '0.099', 'TP': '46', 'FP': '150', 'FN': '256', 'precision': '0.235', 'recall': '0.152', 'f1': '0.185', 'total_rewards': -1792.5071640165204, 'invalid_action_count': 1852, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -482.10068068406486
# steps	 1000 	total rewards	 -952.9420476410514
# steps	 1500 	total rewards	 -1369.2004618264766
# Finished after 1991 timesteps (1.3532941341400146 seconds) with total reward -1816.4266911301752
# {'coverage_prop': '0.403', 'intensity_prop': '0.086', 'ms1ms2_ratio': '0.005', 'efficiency': '0.089', 'TP': '24', 'FP': '152', 'FN': '261', 'precision': '0.136', 'recall': '0.084', 'f1': '0.104', 'total_rewards': -1816.426691130176, 'invalid_action_count': 1870, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -491.65651689510764
# steps	 1000 	total rewards	 -961.8626068792926
# steps	 1500 	total rewards	 -1435.9210206439302
# Finished after 1990 timesteps (0.8622019290924072 seconds) with total reward -1899.563068411172
# {'coverage_prop': '0.365', 'intensity_prop': '0.072', 'ms1ms2_ratio': '0.005', 'efficiency': '0.037', 'TP': '9', 'FP': '64', 'FN': '127', 'precision': '0.123', 'recall': '0.066', 'f1': '0.086', 'total_rewards': -1899.5630684111725, 'invalid_action_count': 1925, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -488.2566556804637
# steps	 1000 	total rewards	 -915.5027507180527
# steps	 1500 	total rewards	 -1346.5593329135118
# Finished after 1987 timesteps (1.4156079292297363 seconds) with total reward -1776.085860051971
# {'coverage_prop': '0.406', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.007', 'efficiency': '0.098', 'TP': '36', 'FP': '158', 'FN': '284', 'precision': '0.186', 'recall': '0.113', 'f1': '0.140', 'total_rewards': -1776.0858600519712, 'invalid_action_count': 1839, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -488.97619395592204
# steps	 1000 	total rewards	 -979.2188565391104
# steps	 1500 	total rewards	 -1455.0772478762954
# Finished after 1994 timesteps (0.8561241626739502 seconds) with total reward -1929.3973449134362
# {'coverage_prop': '0.260', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.003', 'efficiency': '0.027', 'TP': '15', 'FP': '38', 'FN': '151', 'precision': '0.283', 'recall': '0.090', 'f1': '0.137', 'total_rewards': -1929.397344913436, 'invalid_action_count': 1947, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -478.0304657733898
# steps	 1000 	total rewards	 -931.9154576109034
# steps	 1500 	total rewards	 -1363.0420872787458
# Finished after 1992 timesteps (1.300692081451416 seconds) with total reward -1815.5713440418272
# {'coverage_prop': '0.396', 'intensity_prop': '0.092', 'ms1ms2_ratio': '0.004', 'efficiency': '0.085', 'TP': '32', 'FP': '136', 'FN': '256', 'precision': '0.190', 'recall': '0.111', 'f1': '0.140', 'total_rewards': -1815.5713440418263, 'invalid_action_count': 1869, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -491.64933366943126
# steps	 1000 	total rewards	 -958.0276443672237
# steps	 1500 	total rewards	 -1430.5649417254886
# Finished after 1994 timesteps (1.2056357860565186 seconds) with total reward -1905.188032260412
# {'coverage_prop': '0.273', 'intensity_prop': '0.058', 'ms1ms2_ratio': '0.003', 'efficiency': '0.053', 'TP': '19', 'FP': '86', 'FN': '279', 'precision': '0.181', 'recall': '0.064', 'f1': '0.094', 'total_rewards': -1905.188032260412, 'invalid_action_count': 1931, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -470.6598674557456
# steps	 1000 	total rewards	 -923.7763533210336
# steps	 1500 	total rewards	 -1342.3443701995554
# Finished after 1983 timesteps (1.407923936843872 seconds) with total reward -1775.149666184749
# {'coverage_prop': '0.377', 'intensity_prop': '0.117', 'ms1ms2_ratio': '0.009', 'efficiency': '0.085', 'TP': '49', 'FP': '118', 'FN': '276', 'precision': '0.293', 'recall': '0.151', 'f1': '0.199', 'total_rewards': -1775.1496661847482, 'invalid_action_count': 1834, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -494.22272249820105
# steps	 1000 	total rewards	 -960.310874729779
# steps	 1500 	total rewards	 -1422.7537917983047
# Finished after 1991 timesteps (0.9683687686920166 seconds) with total reward -1891.970289661589
# {'coverage_prop': '0.345', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.005', 'efficiency': '0.043', 'TP': '21', 'FP': '65', 'FN': '163', 'precision': '0.244', 'recall': '0.114', 'f1': '0.156', 'total_rewards': -1891.970289661589, 'invalid_action_count': 1921, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -479.403783021513
# steps	 1000 	total rewards	 -934.3127289786386
# steps	 1500 	total rewards	 -1381.6077758838162
# Finished after 1984 timesteps (1.0147807598114014 seconds) with total reward -1838.615534006366
# {'coverage_prop': '0.414', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.008', 'efficiency': '0.053', 'TP': '25', 'FP': '79', 'FN': '147', 'precision': '0.240', 'recall': '0.145', 'f1': '0.181', 'total_rewards': -1838.6155340063656, 'invalid_action_count': 1880, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -486.34068171788226
# steps	 1000 	total rewards	 -955.8568489073263
# steps	 1500 	total rewards	 -1389.3126032826863
# Finished after 1990 timesteps (1.135772943496704 seconds) with total reward -1842.444518566026
# {'coverage_prop': '0.423', 'intensity_prop': '0.122', 'ms1ms2_ratio': '0.005', 'efficiency': '0.064', 'TP': '33', 'FP': '94', 'FN': '173', 'precision': '0.260', 'recall': '0.160', 'f1': '0.198', 'total_rewards': -1842.4445185660256, 'invalid_action_count': 1885, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -495.7827436989764
# steps	 1000 	total rewards	 -977.3517951746276
# steps	 1500 	total rewards	 -1432.884522876182
# Finished after 1993 timesteps (0.8855948448181152 seconds) with total reward -1910.3522528198498
# {'coverage_prop': '0.311', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.004', 'efficiency': '0.032', 'TP': '16', 'FP': '48', 'FN': '142', 'precision': '0.250', 'recall': '0.101', 'f1': '0.144', 'total_rewards': -1910.35225281985, 'invalid_action_count': 1934, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -479.6867426511633
# steps	 1000 	total rewards	 -939.9270262324371
# steps	 1500 	total rewards	 -1347.3741121376254
# Finished after 1983 timesteps (1.2967119216918945 seconds) with total reward -1778.5724519798387
# {'coverage_prop': '0.462', 'intensity_prop': '0.146', 'ms1ms2_ratio': '0.009', 'efficiency': '0.096', 'TP': '63', 'FP': '125', 'FN': '219', 'precision': '0.335', 'recall': '0.223', 'f1': '0.268', 'total_rewards': -1778.5724519798391, 'invalid_action_count': 1837, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -488.68697171815325
# steps	 1000 	total rewards	 -913.8618127150401
# steps	 1500 	total rewards	 -1301.7567039808396
# Finished after 1981 timesteps (1.492384910583496 seconds) with total reward -1722.6396487557004
# {'coverage_prop': '0.472', 'intensity_prop': '0.145', 'ms1ms2_ratio': '0.010', 'efficiency': '0.120', 'TP': '62', 'FP': '173', 'FN': '263', 'precision': '0.264', 'recall': '0.191', 'f1': '0.221', 'total_rewards': -1722.6396487557006, 'invalid_action_count': 1798, 'num_ms1_scans': 19, 'num_ms2_scans': 1962}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -485.1100283075416
# steps	 1000 	total rewards	 -932.3445066382951
# steps	 1500 	total rewards	 -1364.165506617438
# Finished after 1982 timesteps (1.2398910522460938 seconds) with total reward -1790.243232013935
# {'coverage_prop': '0.414', 'intensity_prop': '0.134', 'ms1ms2_ratio': '0.009', 'efficiency': '0.078', 'TP': '49', 'FP': '105', 'FN': '218', 'precision': '0.318', 'recall': '0.184', 'f1': '0.233', 'total_rewards': -1790.2432320139353, 'invalid_action_count': 1841, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -475.4742955366675
# steps	 1000 	total rewards	 -945.8739810212141
# steps	 1500 	total rewards	 -1412.3471418070071
# Finished after 1989 timesteps (1.1059961318969727 seconds) with total reward -1872.5865368493412
# {'coverage_prop': '0.305', 'intensity_prop': '0.066', 'ms1ms2_ratio': '0.006', 'efficiency': '0.047', 'TP': '17', 'FP': '75', 'FN': '210', 'precision': '0.185', 'recall': '0.075', 'f1': '0.107', 'total_rewards': -1872.5865368493414, 'invalid_action_count': 1905, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -486.44849703260974
# steps	 1000 	total rewards	 -930.8342755904789
# steps	 1500 	total rewards	 -1377.2506519464168
# Finished after 1985 timesteps (1.6348521709442139 seconds) with total reward -1820.3838236570857
# {'coverage_prop': '0.426', 'intensity_prop': '0.128', 'ms1ms2_ratio': '0.008', 'efficiency': '0.057', 'TP': '31', 'FP': '82', 'FN': '152', 'precision': '0.274', 'recall': '0.169', 'f1': '0.209', 'total_rewards': -1820.3838236570862, 'invalid_action_count': 1866, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -487.82840348061177
# steps	 1000 	total rewards	 -942.6818663386531
# steps	 1500 	total rewards	 -1367.843406630126
# Finished after 1991 timesteps (1.4452400207519531 seconds) with total reward -1811.7549476033896
# {'coverage_prop': '0.393', 'intensity_prop': '0.097', 'ms1ms2_ratio': '0.005', 'efficiency': '0.093', 'TP': '40', 'FP': '144', 'FN': '284', 'precision': '0.217', 'recall': '0.123', 'f1': '0.157', 'total_rewards': -1811.754947603389, 'invalid_action_count': 1868, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -483.3622058032495
# steps	 1000 	total rewards	 -951.405465221809
# steps	 1500 	total rewards	 -1422.1425362196228
# Finished after 1989 timesteps (0.9469351768493652 seconds) with total reward -1880.7823497164486
# {'coverage_prop': '0.402', 'intensity_prop': '0.088', 'ms1ms2_ratio': '0.006', 'efficiency': '0.048', 'TP': '18', 'FP': '76', 'FN': '140', 'precision': '0.191', 'recall': '0.114', 'f1': '0.143', 'total_rewards': -1880.7823497164486, 'invalid_action_count': 1915, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -475.233116919703
# steps	 1000 	total rewards	 -937.196840470604
# steps	 1500 	total rewards	 -1417.716309940573
# Finished after 1992 timesteps (1.0811638832092285 seconds) with total reward -1890.842448084776
# {'coverage_prop': '0.267', 'intensity_prop': '0.067', 'ms1ms2_ratio': '0.004', 'efficiency': '0.043', 'TP': '22', 'FP': '64', 'FN': '236', 'precision': '0.256', 'recall': '0.085', 'f1': '0.128', 'total_rewards': -1890.8424480847757, 'invalid_action_count': 1921, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -487.99699948172184
# steps	 1000 	total rewards	 -949.9444550087294
# steps	 1500 	total rewards	 -1396.5837435474132
# Finished after 1991 timesteps (1.0214080810546875 seconds) with total reward -1881.4620513064938
# {'coverage_prop': '0.287', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.005', 'efficiency': '0.045', 'TP': '18', 'FP': '71', 'FN': '221', 'precision': '0.202', 'recall': '0.075', 'f1': '0.110', 'total_rewards': -1881.4620513064933, 'invalid_action_count': 1914, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -492.62688400522813
# steps	 1000 	total rewards	 -976.3659018289909
# steps	 1500 	total rewards	 -1462.980720061938
# Finished after 1995 timesteps (1.2521679401397705 seconds) with total reward -1921.8086474851323
# {'coverage_prop': '0.194', 'intensity_prop': '0.038', 'ms1ms2_ratio': '0.003', 'efficiency': '0.034', 'TP': '13', 'FP': '54', 'FN': '278', 'precision': '0.194', 'recall': '0.045', 'f1': '0.073', 'total_rewards': -1921.808647485133, 'invalid_action_count': 1944, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -484.723838763185
# steps	 1000 	total rewards	 -932.5231360747598
# steps	 1500 	total rewards	 -1423.8406670330946
# Finished after 1994 timesteps (1.9014692306518555 seconds) with total reward -1915.2894904065638
# {'coverage_prop': '0.210', 'intensity_prop': '0.042', 'ms1ms2_ratio': '0.003', 'efficiency': '0.042', 'TP': '12', 'FP': '71', 'FN': '313', 'precision': '0.145', 'recall': '0.037', 'f1': '0.059', 'total_rewards': -1915.2894904065638, 'invalid_action_count': 1938, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -492.3071097568229
# steps	 1000 	total rewards	 -974.1289636902591
# steps	 1500 	total rewards	 -1450.7234972726271
# Finished after 1989 timesteps (0.8975520133972168 seconds) with total reward -1914.1609531646166
# {'coverage_prop': '0.266', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.006', 'efficiency': '0.027', 'TP': '15', 'FP': '39', 'FN': '149', 'precision': '0.278', 'recall': '0.091', 'f1': '0.138', 'total_rewards': -1914.1609531646166, 'invalid_action_count': 1935, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -485.8828722401016
# steps	 1000 	total rewards	 -962.9470469417469
# steps	 1500 	total rewards	 -1427.3544411184075
# Finished after 1988 timesteps (0.983994722366333 seconds) with total reward -1890.9190275843034
# {'coverage_prop': '0.288', 'intensity_prop': '0.062', 'ms1ms2_ratio': '0.006', 'efficiency': '0.041', 'TP': '16', 'FP': '65', 'FN': '200', 'precision': '0.198', 'recall': '0.074', 'f1': '0.108', 'total_rewards': -1890.919027584303, 'invalid_action_count': 1920, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -931.6583145171494
# steps	 1500 	total rewards	 -1387.833808736984
# Finished after 1992 timesteps (1.5184431076049805 seconds) with total reward -1813.6851979400826
# {'coverage_prop': '0.333', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.004', 'efficiency': '0.083', 'TP': '36', 'FP': '128', 'FN': '329', 'precision': '0.220', 'recall': '0.099', 'f1': '0.136', 'total_rewards': -1813.6851979400822, 'invalid_action_count': 1867, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -490.1941669353546
# steps	 1000 	total rewards	 -966.566021060907
# steps	 1500 	total rewards	 -1462.4107873499195
# Finished after 1994 timesteps (1.1091220378875732 seconds) with total reward -1909.436270967317
# {'coverage_prop': '0.257', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.003', 'efficiency': '0.039', 'TP': '15', 'FP': '63', 'FN': '226', 'precision': '0.192', 'recall': '0.062', 'f1': '0.094', 'total_rewards': -1909.436270967317, 'invalid_action_count': 1935, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 8.35GB > 0.36GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 64.53296512516454
# steps	 1000 	total rewards	 163.98607021195227
# Finished after 1356 timesteps (5.6282970905303955 seconds) with total reward 217.3331079085316
# {'coverage_prop': '0.953', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.904', 'efficiency': '0.570', 'TP': '277', 'FP': '129', 'FN': '20', 'precision': '0.682', 'recall': '0.933', 'f1': '0.788', 'total_rewards': 217.3331079085314, 'invalid_action_count': 1, 'num_ms1_scans': 644, 'num_ms2_scans': 712}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 57.9279156350093
# steps	 1000 	total rewards	 131.84065382900047
# Finished after 1387 timesteps (4.08347487449646 seconds) with total reward 174.94945500188715
# {'coverage_prop': '0.954', 'intensity_prop': '0.671', 'ms1ms2_ratio': '0.792', 'efficiency': '0.323', 'TP': '206', 'FP': '44', 'FN': '12', 'precision': '0.824', 'recall': '0.945', 'f1': '0.880', 'total_rewards': 174.94945500188723, 'invalid_action_count': 2, 'num_ms1_scans': 613, 'num_ms2_scans': 774}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 54.18978013722733
# steps	 1000 	total rewards	 147.22559230362984
# Finished after 1316 timesteps (5.646856784820557 seconds) with total reward 192.958243104678
# {'coverage_prop': '0.931', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.082', 'efficiency': '0.581', 'TP': '238', 'FP': '129', 'FN': '27', 'precision': '0.649', 'recall': '0.898', 'f1': '0.753', 'total_rewards': 192.958243104678, 'invalid_action_count': 4, 'num_ms1_scans': 684, 'num_ms2_scans': 632}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 66.61132644729348
# steps	 1000 	total rewards	 165.52144591247404
# Finished after 1370 timesteps (5.50665807723999 seconds) with total reward 215.394862324744
# {'coverage_prop': '0.938', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.851', 'efficiency': '0.573', 'TP': '303', 'FP': '121', 'FN': '28', 'precision': '0.715', 'recall': '0.915', 'f1': '0.803', 'total_rewards': 215.39486232474388, 'invalid_action_count': 6, 'num_ms1_scans': 630, 'num_ms2_scans': 740}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 53.733749390214285
# steps	 1000 	total rewards	 155.16027429817532
# Finished after 1348 timesteps (7.964076995849609 seconds) with total reward 202.5736544578463
# {'coverage_prop': '0.950', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.937', 'efficiency': '0.596', 'TP': '290', 'FP': '125', 'FN': '22', 'precision': '0.699', 'recall': '0.929', 'f1': '0.798', 'total_rewards': 202.57365445784643, 'invalid_action_count': 8, 'num_ms1_scans': 652, 'num_ms2_scans': 696}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 38.344925818045965
# steps	 1000 	total rewards	 101.3787473688534
# Finished after 1341 timesteps (3.170792818069458 seconds) with total reward 130.1248977990461
# {'coverage_prop': '0.955', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.966', 'efficiency': '0.280', 'TP': '168', 'FP': '23', 'FN': '9', 'precision': '0.880', 'recall': '0.949', 'f1': '0.913', 'total_rewards': 130.1248977990461, 'invalid_action_count': 6, 'num_ms1_scans': 659, 'num_ms2_scans': 682}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 70.38413854833603
# steps	 1000 	total rewards	 171.98176894148702
# Finished after 1361 timesteps (6.121733903884888 seconds) with total reward 220.38849018841904
# {'coverage_prop': '0.914', 'intensity_prop': '0.573', 'ms1ms2_ratio': '0.885', 'efficiency': '0.605', 'TP': '298', 'FP': '139', 'FN': '41', 'precision': '0.682', 'recall': '0.879', 'f1': '0.768', 'total_rewards': 220.38849018841893, 'invalid_action_count': 4, 'num_ms1_scans': 639, 'num_ms2_scans': 722}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.51009004294616
# steps	 1000 	total rewards	 114.03286760336677
# Finished after 1408 timesteps (3.6103322505950928 seconds) with total reward 156.41094608683505
# {'coverage_prop': '0.951', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.725', 'efficiency': '0.238', 'TP': '161', 'FP': '33', 'FN': '10', 'precision': '0.830', 'recall': '0.942', 'f1': '0.882', 'total_rewards': 156.41094608683505, 'invalid_action_count': 4, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.69414502071467
# steps	 1000 	total rewards	 157.15370380682018
# Finished after 1354 timesteps (4.148311138153076 seconds) with total reward 203.1458831528798
# {'coverage_prop': '0.939', 'intensity_prop': '0.577', 'ms1ms2_ratio': '0.912', 'efficiency': '0.562', 'TP': '277', 'FP': '121', 'FN': '26', 'precision': '0.696', 'recall': '0.914', 'f1': '0.790', 'total_rewards': 203.14588315287995, 'invalid_action_count': 2, 'num_ms1_scans': 646, 'num_ms2_scans': 708}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 57.33744333548021
# steps	 1000 	total rewards	 150.86654697817357
# Finished after 1364 timesteps (4.794122219085693 seconds) with total reward 198.36307364206198
# {'coverage_prop': '0.945', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.874', 'efficiency': '0.499', 'TP': '269', 'FP': '94', 'FN': '21', 'precision': '0.741', 'recall': '0.928', 'f1': '0.824', 'total_rewards': 198.36307364206218, 'invalid_action_count': 0, 'num_ms1_scans': 636, 'num_ms2_scans': 728}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 62.82274097447213
# steps	 1000 	total rewards	 167.7204448036876
# Finished after 1383 timesteps (5.0219409465789795 seconds) with total reward 221.83401021240567
# {'coverage_prop': '0.935', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.805', 'efficiency': '0.540', 'TP': '292', 'FP': '122', 'FN': '29', 'precision': '0.705', 'recall': '0.910', 'f1': '0.795', 'total_rewards': 221.8340102124058, 'invalid_action_count': 1, 'num_ms1_scans': 617, 'num_ms2_scans': 766}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 52.48616122840076
# steps	 1000 	total rewards	 119.13132379524706
# Finished after 1375 timesteps (3.1517162322998047 seconds) with total reward 156.92718146025388
# {'coverage_prop': '0.952', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.836', 'efficiency': '0.316', 'TP': '191', 'FP': '46', 'FN': '12', 'precision': '0.806', 'recall': '0.941', 'f1': '0.868', 'total_rewards': 156.92718146025373, 'invalid_action_count': 2, 'num_ms1_scans': 626, 'num_ms2_scans': 749}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 48.21996514329455
# steps	 1000 	total rewards	 117.59786127681582
# Finished after 1342 timesteps (3.3123619556427 seconds) with total reward 153.61738389604827
# {'coverage_prop': '0.940', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.962', 'efficiency': '0.345', 'TP': '168', 'FP': '68', 'FN': '15', 'precision': '0.712', 'recall': '0.918', 'f1': '0.802', 'total_rewards': 153.61738389604827, 'invalid_action_count': 2, 'num_ms1_scans': 658, 'num_ms2_scans': 684}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 50.15414114610019
# steps	 1000 	total rewards	 127.57544075174874
# Finished after 1384 timesteps (5.321920871734619 seconds) with total reward 176.7821600875401
# {'coverage_prop': '0.960', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.802', 'efficiency': '0.375', 'TP': '190', 'FP': '98', 'FN': '12', 'precision': '0.660', 'recall': '0.941', 'f1': '0.776', 'total_rewards': 176.78216008754018, 'invalid_action_count': 1, 'num_ms1_scans': 616, 'num_ms2_scans': 768}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 45.98716254482413
# steps	 1000 	total rewards	 115.57637907916535
# Finished after 1414 timesteps (3.5273468494415283 seconds) with total reward 151.34122790764926
# {'coverage_prop': '0.942', 'intensity_prop': '0.664', 'ms1ms2_ratio': '0.708', 'efficiency': '0.234', 'TP': '154', 'FP': '40', 'FN': '12', 'precision': '0.794', 'recall': '0.928', 'f1': '0.856', 'total_rewards': 151.3412279076494, 'invalid_action_count': 3, 'num_ms1_scans': 586, 'num_ms2_scans': 828}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 54.5606387781492
# steps	 1000 	total rewards	 142.2868325877639
# Finished after 1351 timesteps (5.757274150848389 seconds) with total reward 185.69512741970098
# {'coverage_prop': '0.931', 'intensity_prop': '0.628', 'ms1ms2_ratio': '0.925', 'efficiency': '0.540', 'TP': '292', 'FP': '87', 'FN': '28', 'precision': '0.770', 'recall': '0.912', 'f1': '0.835', 'total_rewards': 185.69512741970098, 'invalid_action_count': 15, 'num_ms1_scans': 649, 'num_ms2_scans': 702}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 73.1696970154215
# steps	 1000 	total rewards	 170.66849878910125
# Finished after 1386 timesteps (5.050153017044067 seconds) with total reward 228.4823791493749
# {'coverage_prop': '0.942', 'intensity_prop': '0.603', 'ms1ms2_ratio': '0.795', 'efficiency': '0.608', 'TP': '338', 'FP': '131', 'FN': '29', 'precision': '0.721', 'recall': '0.921', 'f1': '0.809', 'total_rewards': 228.4823791493748, 'invalid_action_count': 10, 'num_ms1_scans': 614, 'num_ms2_scans': 772}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 64.61918911491306
# steps	 1000 	total rewards	 150.00601291564826
# Finished after 1335 timesteps (6.134692192077637 seconds) with total reward 190.17658242804845
# {'coverage_prop': '0.946', 'intensity_prop': '0.603', 'ms1ms2_ratio': '0.996', 'efficiency': '0.526', 'TP': '255', 'FP': '97', 'FN': '20', 'precision': '0.724', 'recall': '0.927', 'f1': '0.813', 'total_rewards': 190.17658242804868, 'invalid_action_count': 2, 'num_ms1_scans': 666, 'num_ms2_scans': 669}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 51.038106949313274
# steps	 1000 	total rewards	 129.15228381381428
# Finished after 1330 timesteps (5.206484079360962 seconds) with total reward 171.29176009586087
# {'coverage_prop': '0.960', 'intensity_prop': '0.635', 'ms1ms2_ratio': '1.015', 'efficiency': '0.439', 'TP': '212', 'FP': '78', 'FN': '12', 'precision': '0.731', 'recall': '0.946', 'f1': '0.825', 'total_rewards': 171.29176009586084, 'invalid_action_count': 2, 'num_ms1_scans': 670, 'num_ms2_scans': 660}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 48.56326538695019
# steps	 1000 	total rewards	 121.23427987736468
# Finished after 1362 timesteps (5.375801086425781 seconds) with total reward 161.46121085200738
# {'coverage_prop': '0.981', 'intensity_prop': '0.635', 'ms1ms2_ratio': '0.881', 'efficiency': '0.359', 'TP': '188', 'FP': '72', 'FN': '5', 'precision': '0.723', 'recall': '0.974', 'f1': '0.830', 'total_rewards': 161.46121085200727, 'invalid_action_count': 4, 'num_ms1_scans': 638, 'num_ms2_scans': 724}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 67.83985249713109
# steps	 1000 	total rewards	 162.66648563384896
# Finished after 1365 timesteps (4.999329090118408 seconds) with total reward 209.92734274542926
# {'coverage_prop': '0.895', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.870', 'efficiency': '0.574', 'TP': '313', 'FP': '106', 'FN': '49', 'precision': '0.747', 'recall': '0.865', 'f1': '0.802', 'total_rewards': 209.9273427454291, 'invalid_action_count': 7, 'num_ms1_scans': 635, 'num_ms2_scans': 730}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 44.811759276353854
# steps	 1000 	total rewards	 116.53483497692827
# Finished after 1351 timesteps (3.4992246627807617 seconds) with total reward 150.7957850403467
# {'coverage_prop': '0.953', 'intensity_prop': '0.637', 'ms1ms2_ratio': '0.927', 'efficiency': '0.318', 'TP': '165', 'FP': '58', 'FN': '11', 'precision': '0.740', 'recall': '0.938', 'f1': '0.827', 'total_rewards': 150.7957850403467, 'invalid_action_count': 2, 'num_ms1_scans': 650, 'num_ms2_scans': 701}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 55.34828503035348
# steps	 1000 	total rewards	 135.78779879413395
# Finished after 1356 timesteps (6.8828582763671875 seconds) with total reward 180.99288249950752
# {'coverage_prop': '0.963', 'intensity_prop': '0.629', 'ms1ms2_ratio': '0.904', 'efficiency': '0.435', 'TP': '220', 'FP': '90', 'FN': '12', 'precision': '0.710', 'recall': '0.948', 'f1': '0.812', 'total_rewards': 180.99288249950752, 'invalid_action_count': 4, 'num_ms1_scans': 644, 'num_ms2_scans': 712}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 55.874822067099636
# steps	 1000 	total rewards	 136.61624770821462
# Finished after 1336 timesteps (4.470875978469849 seconds) with total reward 171.67246830463324
# {'coverage_prop': '0.939', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.988', 'efficiency': '0.433', 'TP': '225', 'FP': '66', 'FN': '19', 'precision': '0.773', 'recall': '0.922', 'f1': '0.841', 'total_rewards': 171.67246830463333, 'invalid_action_count': 5, 'num_ms1_scans': 664, 'num_ms2_scans': 672}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 54.54491860682718
# steps	 1000 	total rewards	 142.73349886372733
# Finished after 1358 timesteps (4.01117205619812 seconds) with total reward 193.82425767240824
# {'coverage_prop': '0.965', 'intensity_prop': '0.612', 'ms1ms2_ratio': '0.897', 'efficiency': '0.465', 'TP': '242', 'FP': '91', 'FN': '12', 'precision': '0.727', 'recall': '0.953', 'f1': '0.825', 'total_rewards': 193.82425767240792, 'invalid_action_count': 6, 'num_ms1_scans': 642, 'num_ms2_scans': 716}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 62.57613734994226
# steps	 1000 	total rewards	 145.07680273071242
# Finished after 1348 timesteps (6.378692150115967 seconds) with total reward 198.05056665391362
# {'coverage_prop': '0.965', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.940', 'efficiency': '0.550', 'TP': '270', 'FP': '112', 'FN': '14', 'precision': '0.707', 'recall': '0.951', 'f1': '0.811', 'total_rewards': 198.05056665391362, 'invalid_action_count': 3, 'num_ms1_scans': 653, 'num_ms2_scans': 695}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 37.42164878338455
# steps	 1000 	total rewards	 105.88643916937811
# Finished after 1388 timesteps (3.321773052215576 seconds) with total reward 141.81768940599676
# {'coverage_prop': '0.966', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.789', 'efficiency': '0.253', 'TP': '156', 'FP': '40', 'FN': '7', 'precision': '0.796', 'recall': '0.957', 'f1': '0.869', 'total_rewards': 141.8176894059967, 'invalid_action_count': 5, 'num_ms1_scans': 612, 'num_ms2_scans': 776}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 47.61018446213214
# steps	 1000 	total rewards	 124.34703934691669
# Finished after 1337 timesteps (3.5388028621673584 seconds) with total reward 167.95402152196598
# {'coverage_prop': '0.954', 'intensity_prop': '0.650', 'ms1ms2_ratio': '0.984', 'efficiency': '0.398', 'TP': '208', 'FP': '60', 'FN': '13', 'precision': '0.776', 'recall': '0.941', 'f1': '0.851', 'total_rewards': 167.95402152196604, 'invalid_action_count': 5, 'num_ms1_scans': 663, 'num_ms2_scans': 674}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 75.22636528043554
# steps	 1000 	total rewards	 165.1253632168825
# Finished after 1368 timesteps (10.541893720626831 seconds) with total reward 220.4043736503557
# {'coverage_prop': '0.884', 'intensity_prop': '0.549', 'ms1ms2_ratio': '0.859', 'efficiency': '0.592', 'TP': '304', 'FP': '132', 'FN': '57', 'precision': '0.697', 'recall': '0.842', 'f1': '0.763', 'total_rewards': 220.40437365035552, 'invalid_action_count': 3, 'num_ms1_scans': 632, 'num_ms2_scans': 736}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 55.194783264326105
# steps	 1000 	total rewards	 131.43769121425274
# Finished after 1325 timesteps (5.454056024551392 seconds) with total reward 169.51579470688065
# {'coverage_prop': '0.964', 'intensity_prop': '0.639', 'ms1ms2_ratio': '1.042', 'efficiency': '0.451', 'TP': '212', 'FP': '81', 'FN': '11', 'precision': '0.724', 'recall': '0.951', 'f1': '0.822', 'total_rewards': 169.51579470688046, 'invalid_action_count': 1, 'num_ms1_scans': 676, 'num_ms2_scans': 649}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 64.2654546074735
# steps	 1000 	total rewards	 153.04802361768873
# steps	 1500 	total rewards	 242.67154511152393
# Finished after 1722 timesteps (11.631918668746948 seconds) with total reward 274.38094621838866
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 274.3809462183884, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 56.53441275069887
# steps	 1000 	total rewards	 133.44353713101043
# steps	 1500 	total rewards	 194.26613921470476
# Finished after 1556 timesteps (10.06092381477356 seconds) with total reward 198.80142796822798
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 198.8014279682283, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 57.86200989608058
# steps	 1000 	total rewards	 141.51209662324754
# steps	 1500 	total rewards	 225.9068017910975
# Finished after 1669 timesteps (9.349200010299683 seconds) with total reward 246.6178714019398
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 246.61787140193985, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 71.12814612435277
# steps	 1000 	total rewards	 157.62727339419465
# steps	 1500 	total rewards	 238.78056886179576
# Finished after 1717 timesteps (9.899137020111084 seconds) with total reward 272.3235910501669
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 272.323591050167, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 61.90389809276462
# steps	 1000 	total rewards	 157.856811245934
# steps	 1500 	total rewards	 243.79212098759848
# Finished after 1704 timesteps (9.578109979629517 seconds) with total reward 273.0181148295186
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 273.0181148295187, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 39.90651559499652
# steps	 1000 	total rewards	 106.83331788373015
# Finished after 1408 timesteps (7.421025991439819 seconds) with total reward 143.2474579291325
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 143.24745792913245, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.22043408731386
# steps	 1000 	total rewards	 162.04397467383103
# steps	 1500 	total rewards	 244.55745713793698
# Finished after 1744 timesteps (12.733466863632202 seconds) with total reward 280.3023687938845
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 280.3023687938843, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.4779426031164
# steps	 1000 	total rewards	 116.36859205738139
# Finished after 1468 timesteps (9.143612146377563 seconds) with total reward 161.92295578814017
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 161.92295578814014, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.46621454358737
# steps	 1000 	total rewards	 149.00350104084623
# steps	 1500 	total rewards	 234.0142896045665
# Finished after 1736 timesteps (11.521972894668579 seconds) with total reward 265.5548286824893
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 265.5548286824895, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 57.43385139963196
# steps	 1000 	total rewards	 140.79893242513924
# steps	 1500 	total rewards	 223.46853854724827
# Finished after 1667 timesteps (10.966442108154297 seconds) with total reward 241.12161582599146
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 241.1216158259913, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 63.48883485609902
# steps	 1000 	total rewards	 148.03351769555485
# steps	 1500 	total rewards	 236.5520895809973
# Finished after 1737 timesteps (12.31859803199768 seconds) with total reward 267.3066297171516
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 267.30662971715145, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 50.65368156509129
# steps	 1000 	total rewards	 120.84480189877293
# steps	 1500 	total rewards	 172.70179872343084
# Finished after 1530 timesteps (12.469544887542725 seconds) with total reward 175.162963401381
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 175.1629634013811, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 48.92835278179824
# steps	 1000 	total rewards	 119.1495853267179
# steps	 1500 	total rewards	 182.89427536782864
# Finished after 1602 timesteps (13.335923910140991 seconds) with total reward 193.71436944682134
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 193.71436944682102, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 51.102405475232786
# steps	 1000 	total rewards	 126.40211968727175
# steps	 1500 	total rewards	 196.43919744732793
# Finished after 1645 timesteps (10.815173864364624 seconds) with total reward 210.5440874069469
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 210.544087406947, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 42.10725329655742
# steps	 1000 	total rewards	 109.41532611939553
# Finished after 1497 timesteps (9.13795518875122 seconds) with total reward 162.4041913682973
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 162.40419136829735, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 56.96509366792624
# steps	 1000 	total rewards	 147.2095569715228
# steps	 1500 	total rewards	 226.3392432649163
# Finished after 1655 timesteps (13.518819093704224 seconds) with total reward 248.9212535879875
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 248.92125358798705, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.46974393432068
# steps	 1000 	total rewards	 159.8630857893615
# steps	 1500 	total rewards	 249.45187485282867
# Finished after 1729 timesteps (19.094491958618164 seconds) with total reward 282.33596729180294
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 282.33596729180283, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 65.28295924656409
# steps	 1000 	total rewards	 152.99159947570973
# steps	 1500 	total rewards	 227.85174096808055
# Finished after 1681 timesteps (10.962422132492065 seconds) with total reward 248.71724564061213
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 248.71724564061182, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.80527834803058
# steps	 1000 	total rewards	 131.25379282029033
# steps	 1500 	total rewards	 201.63169124775385
# Finished after 1621 timesteps (8.873769998550415 seconds) with total reward 213.3962276951981
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 213.39622769519795, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 51.64710716074973
# steps	 1000 	total rewards	 127.8682486554507
# steps	 1500 	total rewards	 190.93867231139512
# Finished after 1634 timesteps (8.304080247879028 seconds) with total reward 206.05567977408612
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 206.05567977408612, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.50994950851643
# steps	 1000 	total rewards	 155.90074680539868
# steps	 1500 	total rewards	 237.04838387022266
# Finished after 1726 timesteps (9.991859912872314 seconds) with total reward 269.74024806514274
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 269.7402480651435, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 42.922449440035635
# steps	 1000 	total rewards	 117.47735795416574
# Finished after 1475 timesteps (7.734036922454834 seconds) with total reward 167.46987873772915
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 167.46987873772926, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 58.07428174764222
# steps	 1000 	total rewards	 137.84913832412306
# steps	 1500 	total rewards	 209.9889884762968
# Finished after 1636 timesteps (8.643579244613647 seconds) with total reward 225.08898203089467
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 225.08898203089467, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 59.55579530112928
# steps	 1000 	total rewards	 139.27168276735108
# steps	 1500 	total rewards	 204.99301908857169
# Finished after 1575 timesteps (8.353829145431519 seconds) with total reward 212.0487707936014
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 212.04877079360148, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 55.90621614718264
# steps	 1000 	total rewards	 142.4674826906643
# steps	 1500 	total rewards	 218.74431307077577
# Finished after 1681 timesteps (8.797893047332764 seconds) with total reward 241.10125347896678
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 241.10125347896698, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 58.65795180800854
# steps	 1000 	total rewards	 136.8820258148469
# steps	 1500 	total rewards	 223.03824969963966
# Finished after 1679 timesteps (9.645657062530518 seconds) with total reward 244.79886972933062
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 244.79886972933082, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 38.93346073831778
# steps	 1000 	total rewards	 108.52782812655937
# Finished after 1465 timesteps (7.477519750595093 seconds) with total reward 154.60987323663102
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 154.60987323663082, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 51.766444526594
# steps	 1000 	total rewards	 130.46357019586054
# steps	 1500 	total rewards	 197.8870026055789
# Finished after 1564 timesteps (14.94366192817688 seconds) with total reward 206.49333367236034
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 206.4933336723603, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 74.33673783003661
# steps	 1000 	total rewards	 151.64147482739267
# steps	 1500 	total rewards	 238.19314377272508
# Finished after 1749 timesteps (12.005550146102905 seconds) with total reward 277.638109251984
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 277.63810925198385, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 56.98398947393331
# steps	 1000 	total rewards	 133.73469321594888
# steps	 1500 	total rewards	 202.51030010488844
# Finished after 1657 timesteps (10.1751389503479 seconds) with total reward 218.42816542635472
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 218.42816542635472, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f8fcd31d5b0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f8f9939c6d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f8fcf608970>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.494', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.532', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '229', 'FP': '199', 'FN': '9', 'precision': '0.535', 'recall': '0.962', 'f1': '0.688'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.206', 'efficiency': '0.727', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.508', 'ms1ms2_ratio': '1.983', 'efficiency': '0.707', 'TP': '149', 'FP': '136', 'FN': '15', 'precision': '0.523', 'recall': '0.909', 'f1': '0.664'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.490', 'ms1ms2_ratio': '2.350', 'efficiency': '0.738', 'TP': '123', 'FP': '136', 'FN': '6', 'precision': '0.475', 'recall': '0.953', 'f1': '0.634'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.159', 'efficiency': '0.740', 'TP': '266', 'FP': '180', 'FN': '22', 'precision': '0.596', 'recall': '0.924', 'f1': '0.725'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.492', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '107', 'FP': '113', 'FN': '14', 'precision': '0.486', 'recall': '0.884', 'f1': '0.628'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.516', 'ms1ms2_ratio': '1.601', 'efficiency': '0.704', 'TP': '170', 'FP': '165', 'FN': '10', 'precision': '0.507', 'recall': '0.944', 'f1': '0.660'}
#
# Episode 25 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.476', 'efficiency': '0.765', 'TP': '210', 'FP': '177', 'FN': '9', 'precision': '0.543', 'recall': '0.959', 'f1': '0.693'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.321', 'efficiency': '0.737', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.527', 'ms1ms2_ratio': '1.034', 'efficiency': '0.719', 'TP': '253', 'FP': '216', 'FN': '24', 'precision': '0.539', 'recall': '0.913', 'f1': '0.678'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.008', 'efficiency': '0.727', 'TP': '149', 'FP': '141', 'FN': '14', 'precision': '0.514', 'recall': '0.914', 'f1': '0.658'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1864.931653                1902.0          0.326           0.073
# 1  random   -1903.653334                1931.0          0.267           0.080
# 2  random   -1845.237859                1889.0          0.353           0.088
# 3  random   -1792.507164                1852.0          0.434           0.114
# 4  random   -1816.426691                1870.0          0.403           0.086
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.070      0.187   0.083  0.115
# 1          0.004       0.035      0.314   0.103  0.155
# 2          0.006       0.070      0.245   0.118  0.159
# 3          0.006       0.099      0.235   0.152  0.185
# 4          0.005       0.089      0.136   0.084  0.104

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     217.333108                   1.0          0.953           0.581
# 31    DQN     174.949455                   2.0          0.954           0.671
# 32    DQN     192.958243                   4.0          0.931           0.545
# 33    DQN     215.394862                   6.0          0.938           0.604
# 34    DQN     202.573654                   8.0          0.950           0.594
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.904       0.570      0.682   0.933  0.788
# 31          0.792       0.323      0.824   0.945  0.880
# 32          1.082       0.581      0.649   0.898  0.753
# 33          0.851       0.573      0.715   0.915  0.803
# 34          0.937       0.596      0.699   0.929  0.798

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
