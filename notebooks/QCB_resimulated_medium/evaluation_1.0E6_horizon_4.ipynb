# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-15 23:50:15.132 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc358617d60>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc358d465e0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc358d62880>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc358617d60>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc358d465e0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc358d62880>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc358617d60>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc358d465e0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc358d62880>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -385.64008326674457
# steps	 1000 	total rewards	 -711.7450151821156
# steps	 1500 	total rewards	 -920.3162213984249
# Finished after 1991 timesteps (4.343100070953369 seconds) with total reward -1091.3069951287234
# {'coverage_prop': '0.714', 'intensity_prop': '0.203', 'ms1ms2_ratio': '0.005', 'efficiency': '0.153', 'TP': '78', 'FP': '226', 'FN': '122', 'precision': '0.257', 'recall': '0.390', 'f1': '0.310', 'total_rewards': -1091.306995128724, 'invalid_action_count': 1230, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -409.1707109210228
# steps	 1000 	total rewards	 -683.1353450643016
# steps	 1500 	total rewards	 -1115.3841615937777
# Finished after 1989 timesteps (2.6477530002593994 seconds) with total reward -1343.868242279025
# {'coverage_prop': '0.676', 'intensity_prop': '0.187', 'ms1ms2_ratio': '0.006', 'efficiency': '0.089', 'TP': '48', 'FP': '129', 'FN': '85', 'precision': '0.271', 'recall': '0.361', 'f1': '0.310', 'total_rewards': -1343.8682422790248, 'invalid_action_count': 1431, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -341.46498901483517
# steps	 1000 	total rewards	 -673.0718654877716
# steps	 1500 	total rewards	 -821.4947780496902
# Finished after 1990 timesteps (3.562795877456665 seconds) with total reward -1065.1770742506146
# {'coverage_prop': '0.772', 'intensity_prop': '0.224', 'ms1ms2_ratio': '0.005', 'efficiency': '0.154', 'TP': '80', 'FP': '224', 'FN': '90', 'precision': '0.263', 'recall': '0.471', 'f1': '0.338', 'total_rewards': -1065.177074250615, 'invalid_action_count': 1211, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -364.7792216515074
# steps	 1000 	total rewards	 -540.4443525152078
# steps	 1500 	total rewards	 -815.5602640186094
# Finished after 1991 timesteps (4.558514356613159 seconds) with total reward -1286.4530340420006
# {'coverage_prop': '0.608', 'intensity_prop': '0.187', 'ms1ms2_ratio': '0.005', 'efficiency': '0.139', 'TP': '79', 'FP': '196', 'FN': '177', 'precision': '0.287', 'recall': '0.309', 'f1': '0.298', 'total_rewards': -1286.4530340420008, 'invalid_action_count': 1408, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -396.6281300082408
# steps	 1000 	total rewards	 -720.2942336572971
# steps	 1500 	total rewards	 -1097.4209804344925
# Finished after 1994 timesteps (4.193345785140991 seconds) with total reward -1338.8127841875448
# {'coverage_prop': '0.625', 'intensity_prop': '0.155', 'ms1ms2_ratio': '0.003', 'efficiency': '0.137', 'TP': '55', 'FP': '218', 'FN': '164', 'precision': '0.201', 'recall': '0.251', 'f1': '0.224', 'total_rewards': -1338.8127841875466, 'invalid_action_count': 1452, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -378.1132845645527
# steps	 1000 	total rewards	 -840.743403306959
# steps	 1500 	total rewards	 -1339.2429045271429
# Finished after 1992 timesteps (2.146291971206665 seconds) with total reward -1652.8574127389393
# {'coverage_prop': '0.425', 'intensity_prop': '0.121', 'ms1ms2_ratio': '0.004', 'efficiency': '0.043', 'TP': '24', 'FP': '61', 'FN': '115', 'precision': '0.282', 'recall': '0.173', 'f1': '0.214', 'total_rewards': -1652.8574127389409, 'invalid_action_count': 1692, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -375.71422589785453
# steps	 1000 	total rewards	 -610.8042565547546
# steps	 1500 	total rewards	 -677.7121238444347
# Finished after 1988 timesteps (3.92781400680542 seconds) with total reward -814.1565800904716
# {'coverage_prop': '0.808', 'intensity_prop': '0.273', 'ms1ms2_ratio': '0.006', 'efficiency': '0.195', 'TP': '124', 'FP': '262', 'FN': '92', 'precision': '0.321', 'recall': '0.574', 'f1': '0.412', 'total_rewards': -814.1565800904731, 'invalid_action_count': 1005, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -415.01845541674106
# steps	 1000 	total rewards	 -776.9436906591543
# steps	 1500 	total rewards	 -1078.7818961581165
# Finished after 1993 timesteps (2.9793312549591064 seconds) with total reward -1543.0489344846021
# {'coverage_prop': '0.613', 'intensity_prop': '0.124', 'ms1ms2_ratio': '0.004', 'efficiency': '0.063', 'TP': '17', 'FP': '108', 'FN': '79', 'precision': '0.136', 'recall': '0.177', 'f1': '0.154', 'total_rewards': -1543.0489344846012, 'invalid_action_count': 1602, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -374.6093659310436
# steps	 1000 	total rewards	 -648.2290882712323
# steps	 1500 	total rewards	 -833.4734952192692
# Finished after 1991 timesteps (3.662860155105591 seconds) with total reward -1088.5965052481918
# {'coverage_prop': '0.762', 'intensity_prop': '0.220', 'ms1ms2_ratio': '0.005', 'efficiency': '0.163', 'TP': '96', 'FP': '227', 'FN': '101', 'precision': '0.297', 'recall': '0.487', 'f1': '0.369', 'total_rewards': -1088.5965052481913, 'invalid_action_count': 1242, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -454.49843932781926
# steps	 1000 	total rewards	 -831.3300810348405
# steps	 1500 	total rewards	 -950.1262495165253
# Finished after 1987 timesteps (3.2700510025024414 seconds) with total reward -1145.6818963101364
# {'coverage_prop': '0.688', 'intensity_prop': '0.250', 'ms1ms2_ratio': '0.007', 'efficiency': '0.134', 'TP': '97', 'FP': '167', 'FN': '120', 'precision': '0.367', 'recall': '0.447', 'f1': '0.403', 'total_rewards': -1145.6818963101373, 'invalid_action_count': 1268, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -455.8695025366571
# steps	 1000 	total rewards	 -664.0850374945248
# steps	 1500 	total rewards	 -713.7609052480746
# Finished after 1984 timesteps (3.8902900218963623 seconds) with total reward -864.9793726735834
# {'coverage_prop': '0.779', 'intensity_prop': '0.278', 'ms1ms2_ratio': '0.008', 'efficiency': '0.175', 'TP': '122', 'FP': '223', 'FN': '98', 'precision': '0.354', 'recall': '0.555', 'f1': '0.432', 'total_rewards': -864.9793726735827, 'invalid_action_count': 1041, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -451.49273514707255
# steps	 1000 	total rewards	 -829.6784942726099
# steps	 1500 	total rewards	 -1170.6093308302547
# Finished after 1992 timesteps (3.0776681900024414 seconds) with total reward -1418.4626935057254
# {'coverage_prop': '0.631', 'intensity_prop': '0.161', 'ms1ms2_ratio': '0.005', 'efficiency': '0.079', 'TP': '38', 'FP': '119', 'FN': '92', 'precision': '0.242', 'recall': '0.292', 'f1': '0.265', 'total_rewards': -1418.4626935057265, 'invalid_action_count': 1493, 'num_ms1_scans': 9, 'num_ms2_scans': 1983}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -455.48797318502795
# steps	 1000 	total rewards	 -719.2659502357988
# steps	 1500 	total rewards	 -974.3835885682959
# Finished after 1990 timesteps (2.782918930053711 seconds) with total reward -1273.5149032217212
# {'coverage_prop': '0.705', 'intensity_prop': '0.216', 'ms1ms2_ratio': '0.005', 'efficiency': '0.089', 'TP': '45', 'FP': '132', 'FN': '74', 'precision': '0.254', 'recall': '0.378', 'f1': '0.304', 'total_rewards': -1273.5149032217196, 'invalid_action_count': 1366, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -324.00791380112946
# steps	 1000 	total rewards	 -644.777668256054
# steps	 1500 	total rewards	 -799.2344651269966
# Finished after 1983 timesteps (3.3984949588775635 seconds) with total reward -1051.7975600745317
# {'coverage_prop': '0.820', 'intensity_prop': '0.301', 'ms1ms2_ratio': '0.009', 'efficiency': '0.125', 'TP': '92', 'FP': '154', 'FN': '54', 'precision': '0.374', 'recall': '0.630', 'f1': '0.469', 'total_rewards': -1051.7975600745312, 'invalid_action_count': 1175, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -450.8914145633106
# steps	 1000 	total rewards	 -948.8914145633106
# steps	 1500 	total rewards	 -1255.6832375765848
# Finished after 1995 timesteps (2.707918882369995 seconds) with total reward -1638.5817719016272
# {'coverage_prop': '0.505', 'intensity_prop': '0.114', 'ms1ms2_ratio': '0.003', 'efficiency': '0.052', 'TP': '19', 'FP': '85', 'FN': '102', 'precision': '0.183', 'recall': '0.157', 'f1': '0.169', 'total_rewards': -1638.581771901628, 'invalid_action_count': 1686, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -370.8745763705321
# steps	 1000 	total rewards	 -690.0613368574138
# steps	 1500 	total rewards	 -874.3870116233306
# Finished after 1988 timesteps (3.877207040786743 seconds) with total reward -1088.777157652742
# {'coverage_prop': '0.740', 'intensity_prop': '0.249', 'ms1ms2_ratio': '0.006', 'efficiency': '0.152', 'TP': '103', 'FP': '198', 'FN': '106', 'precision': '0.342', 'recall': '0.493', 'f1': '0.404', 'total_rewards': -1088.7771576527416, 'invalid_action_count': 1231, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -436.45241245765226
# steps	 1000 	total rewards	 -521.708955950488
# steps	 1500 	total rewards	 -652.2269155078859
# Finished after 1987 timesteps (4.564094066619873 seconds) with total reward -791.4610196946638
# {'coverage_prop': '0.771', 'intensity_prop': '0.282', 'ms1ms2_ratio': '0.007', 'efficiency': '0.195', 'TP': '148', 'FP': '236', 'FN': '114', 'precision': '0.385', 'recall': '0.565', 'f1': '0.458', 'total_rewards': -791.4610196946628, 'invalid_action_count': 979, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -398.15985015810315
# steps	 1000 	total rewards	 -652.8024315016479
# steps	 1500 	total rewards	 -787.2361938285947
# Finished after 1988 timesteps (3.4875237941741943 seconds) with total reward -1021.5418064447081
# {'coverage_prop': '0.745', 'intensity_prop': '0.251', 'ms1ms2_ratio': '0.006', 'efficiency': '0.140', 'TP': '91', 'FP': '186', 'FN': '95', 'precision': '0.329', 'recall': '0.489', 'f1': '0.393', 'total_rewards': -1021.541806444707, 'invalid_action_count': 1158, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -368.7586631518403
# steps	 1000 	total rewards	 -708.6856841959636
# steps	 1500 	total rewards	 -926.2138284248264
# Finished after 1987 timesteps (3.3193492889404297 seconds) with total reward -1230.5168579360188
# {'coverage_prop': '0.725', 'intensity_prop': '0.209', 'ms1ms2_ratio': '0.007', 'efficiency': '0.111', 'TP': '62', 'FP': '157', 'FN': '83', 'precision': '0.283', 'recall': '0.428', 'f1': '0.341', 'total_rewards': -1230.5168579360195, 'invalid_action_count': 1338, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -372.4686483786578
# steps	 1000 	total rewards	 -679.0890022378325
# steps	 1500 	total rewards	 -909.471067631679
# Finished after 1989 timesteps (2.742466926574707 seconds) with total reward -1196.3820233004287
# {'coverage_prop': '0.796', 'intensity_prop': '0.231', 'ms1ms2_ratio': '0.006', 'efficiency': '0.107', 'TP': '52', 'FP': '159', 'FN': '54', 'precision': '0.246', 'recall': '0.491', 'f1': '0.328', 'total_rewards': -1196.3820233004274, 'invalid_action_count': 1305, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -381.3328075650402
# steps	 1000 	total rewards	 -636.3669124798297
# steps	 1500 	total rewards	 -885.4279395960075
# Finished after 1990 timesteps (4.0117881298065186 seconds) with total reward -1151.2075179803896
# {'coverage_prop': '0.682', 'intensity_prop': '0.210', 'ms1ms2_ratio': '0.005', 'efficiency': '0.161', 'TP': '99', 'FP': '220', 'FN': '149', 'precision': '0.310', 'recall': '0.399', 'f1': '0.349', 'total_rewards': -1151.207517980392, 'invalid_action_count': 1298, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -341.49015461303696
# steps	 1000 	total rewards	 -717.4679391750599
# steps	 1500 	total rewards	 -1071.2227714833994
# Finished after 1989 timesteps (3.1642160415649414 seconds) with total reward -1384.6514115525745
# {'coverage_prop': '0.675', 'intensity_prop': '0.165', 'ms1ms2_ratio': '0.006', 'efficiency': '0.080', 'TP': '36', 'FP': '122', 'FN': '76', 'precision': '0.228', 'recall': '0.321', 'f1': '0.267', 'total_rewards': -1384.6514115525754, 'invalid_action_count': 1461, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -455.1537526957688
# steps	 1000 	total rewards	 -914.8710554378573
# steps	 1500 	total rewards	 -1145.2639363597968
# Finished after 1997 timesteps (3.169687271118164 seconds) with total reward -1573.583039912939
# {'coverage_prop': '0.522', 'intensity_prop': '0.144', 'ms1ms2_ratio': '0.002', 'efficiency': '0.084', 'TP': '42', 'FP': '126', 'FN': '154', 'precision': '0.250', 'recall': '0.214', 'f1': '0.231', 'total_rewards': -1573.5830399129402, 'invalid_action_count': 1647, 'num_ms1_scans': 3, 'num_ms2_scans': 1994}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -398.3791379909277
# steps	 1000 	total rewards	 -838.4437047033282
# steps	 1500 	total rewards	 -1092.268311764215
# Finished after 1992 timesteps (2.933526039123535 seconds) with total reward -1418.2613879083733
# {'coverage_prop': '0.555', 'intensity_prop': '0.144', 'ms1ms2_ratio': '0.004', 'efficiency': '0.087', 'TP': '41', 'FP': '131', 'FN': '138', 'precision': '0.238', 'recall': '0.229', 'f1': '0.234', 'total_rewards': -1418.2613879083744, 'invalid_action_count': 1499, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -349.6597116276897
# steps	 1000 	total rewards	 -593.2553964677086
# steps	 1500 	total rewards	 -712.7863156162178
# Finished after 1982 timesteps (3.1971819400787354 seconds) with total reward -949.591659455665
# {'coverage_prop': '0.826', 'intensity_prop': '0.283', 'ms1ms2_ratio': '0.009', 'efficiency': '0.145', 'TP': '98', 'FP': '187', 'FN': '60', 'precision': '0.344', 'recall': '0.620', 'f1': '0.442', 'total_rewards': -949.5916594556647, 'invalid_action_count': 1102, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -380.76218358128176
# steps	 1000 	total rewards	 -733.7711453299017
# steps	 1500 	total rewards	 -874.4296107039468
# Finished after 1988 timesteps (3.4708499908447266 seconds) with total reward -1154.9045730475027
# {'coverage_prop': '0.720', 'intensity_prop': '0.222', 'ms1ms2_ratio': '0.006', 'efficiency': '0.144', 'TP': '73', 'FP': '212', 'FN': '111', 'precision': '0.256', 'recall': '0.397', 'f1': '0.311', 'total_rewards': -1154.904573047503, 'invalid_action_count': 1285, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -394.9142587584515
# steps	 1000 	total rewards	 -715.8162371799501
# steps	 1500 	total rewards	 -1019.7417416693497
# Finished after 1989 timesteps (2.5844638347625732 seconds) with total reward -1408.5155615333756
# {'coverage_prop': '0.690', 'intensity_prop': '0.199', 'ms1ms2_ratio': '0.006', 'efficiency': '0.071', 'TP': '38', 'FP': '102', 'FN': '63', 'precision': '0.271', 'recall': '0.376', 'f1': '0.315', 'total_rewards': -1408.5155615333763, 'invalid_action_count': 1478, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -457.45764390907675
# steps	 1000 	total rewards	 -847.5282462664615
# steps	 1500 	total rewards	 -1192.8482856804349
# Finished after 1994 timesteps (2.5524919033050537 seconds) with total reward -1496.3768679829604
# {'coverage_prop': '0.559', 'intensity_prop': '0.161', 'ms1ms2_ratio': '0.003', 'efficiency': '0.079', 'TP': '46', 'FP': '111', 'FN': '124', 'precision': '0.293', 'recall': '0.271', 'f1': '0.281', 'total_rewards': -1496.3768679829598, 'invalid_action_count': 1572, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -393.92530778951283
# steps	 1000 	total rewards	 -687.677066372567
# steps	 1500 	total rewards	 -868.0904683317048
# Finished after 1989 timesteps (3.9139058589935303 seconds) with total reward -1069.5086689551158
# {'coverage_prop': '0.728', 'intensity_prop': '0.207', 'ms1ms2_ratio': '0.006', 'efficiency': '0.181', 'TP': '102', 'FP': '257', 'FN': '134', 'precision': '0.284', 'recall': '0.432', 'f1': '0.343', 'total_rewards': -1069.5086689551144, 'invalid_action_count': 1229, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -395.9463915184315
# steps	 1000 	total rewards	 -629.0042514997024
# steps	 1500 	total rewards	 -869.8950658072517
# Finished after 1984 timesteps (3.088805913925171 seconds) with total reward -1149.9568956091716
# {'coverage_prop': '0.770', 'intensity_prop': '0.257', 'ms1ms2_ratio': '0.008', 'efficiency': '0.119', 'TP': '76', 'FP': '158', 'FN': '70', 'precision': '0.325', 'recall': '0.521', 'f1': '0.400', 'total_rewards': -1149.9568956091719, 'invalid_action_count': 1270, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 8.36GB > 0.32GB
# steps	 500 	total rewards	 92.0446352077528
# steps	 1000 	total rewards	 211.68027711609602
# Finished after 1462 timesteps (6.170061826705933 seconds) with total reward 297.2157448135706
# {'coverage_prop': '0.965', 'intensity_prop': '0.562', 'ms1ms2_ratio': '0.582', 'efficiency': '0.445', 'TP': '264', 'FP': '147', 'FN': '15', 'precision': '0.642', 'recall': '0.946', 'f1': '0.765', 'total_rewards': 297.2157448135708, 'invalid_action_count': 12, 'num_ms1_scans': 538, 'num_ms2_scans': 924}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 91.50857938914204
# steps	 1000 	total rewards	 192.31866986202033
# Finished after 1371 timesteps (5.173368692398071 seconds) with total reward 245.66596384367483
# {'coverage_prop': '0.977', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.848', 'efficiency': '0.345', 'TP': '154', 'FP': '102', 'FN': '6', 'precision': '0.602', 'recall': '0.963', 'f1': '0.740', 'total_rewards': 245.66596384367242, 'invalid_action_count': 1, 'num_ms1_scans': 629, 'num_ms2_scans': 742}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 91.46017655570083
# steps	 1000 	total rewards	 203.16389370528574
# Finished after 1445 timesteps (5.643893003463745 seconds) with total reward 275.1008964995931
# {'coverage_prop': '0.949', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.624', 'efficiency': '0.420', 'TP': '221', 'FP': '153', 'FN': '20', 'precision': '0.591', 'recall': '0.917', 'f1': '0.719', 'total_rewards': 275.10089649959264, 'invalid_action_count': 16, 'num_ms1_scans': 555, 'num_ms2_scans': 890}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 96.23232777261174
# steps	 1000 	total rewards	 206.51424989923004
# Finished after 1462 timesteps (6.4404919147491455 seconds) with total reward 286.8569136383238
# {'coverage_prop': '0.949', 'intensity_prop': '0.544', 'ms1ms2_ratio': '0.584', 'efficiency': '0.465', 'TP': '275', 'FP': '154', 'FN': '23', 'precision': '0.641', 'recall': '0.923', 'f1': '0.757', 'total_rewards': 286.8569136383235, 'invalid_action_count': 19, 'num_ms1_scans': 539, 'num_ms2_scans': 923}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 94.70670838708699
# steps	 1000 	total rewards	 209.88862859862826
# Finished after 1454 timesteps (6.507872104644775 seconds) with total reward 275.86225166296185
# {'coverage_prop': '0.934', 'intensity_prop': '0.519', 'ms1ms2_ratio': '0.601', 'efficiency': '0.449', 'TP': '247', 'FP': '161', 'FN': '29', 'precision': '0.605', 'recall': '0.895', 'f1': '0.722', 'total_rewards': 275.8622516629614, 'invalid_action_count': 21, 'num_ms1_scans': 546, 'num_ms2_scans': 908}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 78.76398959205875
# steps	 1000 	total rewards	 169.3790994273375
# Finished after 1356 timesteps (4.443967342376709 seconds) with total reward 221.63423324106918
# {'coverage_prop': '0.985', 'intensity_prop': '0.642', 'ms1ms2_ratio': '0.904', 'efficiency': '0.277', 'TP': '144', 'FP': '53', 'FN': '3', 'precision': '0.731', 'recall': '0.980', 'f1': '0.837', 'total_rewards': 221.63423324106702, 'invalid_action_count': 1, 'num_ms1_scans': 644, 'num_ms2_scans': 712}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 95.54652322964733
# steps	 1000 	total rewards	 197.00805655919316
# Finished after 1472 timesteps (5.856078863143921 seconds) with total reward 277.9529773038613
# {'coverage_prop': '0.918', 'intensity_prop': '0.504', 'ms1ms2_ratio': '0.559', 'efficiency': '0.465', 'TP': '250', 'FP': '189', 'FN': '39', 'precision': '0.569', 'recall': '0.865', 'f1': '0.687', 'total_rewards': 277.95297730386073, 'invalid_action_count': 30, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 65.61883179964107
# steps	 1000 	total rewards	 166.498553950531
# Finished after 1363 timesteps (4.98444128036499 seconds) with total reward 217.24485431899112
# {'coverage_prop': '0.985', 'intensity_prop': '0.621', 'ms1ms2_ratio': '0.877', 'efficiency': '0.277', 'TP': '142', 'FP': '59', 'FN': '3', 'precision': '0.706', 'recall': '0.979', 'f1': '0.821', 'total_rewards': 217.24485431898904, 'invalid_action_count': 0, 'num_ms1_scans': 637, 'num_ms2_scans': 726}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 97.70731396707822
# steps	 1000 	total rewards	 188.41588800259763
# Finished after 1461 timesteps (5.951060056686401 seconds) with total reward 278.0668163540256
# {'coverage_prop': '0.953', 'intensity_prop': '0.511', 'ms1ms2_ratio': '0.586', 'efficiency': '0.439', 'TP': '231', 'FP': '173', 'FN': '20', 'precision': '0.572', 'recall': '0.920', 'f1': '0.705', 'total_rewards': 278.06681635402504, 'invalid_action_count': 17, 'num_ms1_scans': 540, 'num_ms2_scans': 921}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 83.84931648487564
# steps	 1000 	total rewards	 190.58560714465528
# Finished after 1428 timesteps (6.061534881591797 seconds) with total reward 258.90735372055053
# {'coverage_prop': '0.951', 'intensity_prop': '0.512', 'ms1ms2_ratio': '0.668', 'efficiency': '0.426', 'TP': '211', 'FP': '154', 'FN': '19', 'precision': '0.578', 'recall': '0.917', 'f1': '0.709', 'total_rewards': 258.90735372054877, 'invalid_action_count': 12, 'num_ms1_scans': 572, 'num_ms2_scans': 856}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 94.00327381489528
# steps	 1000 	total rewards	 165.6663690020911
# Finished after 1477 timesteps (5.373819828033447 seconds) with total reward 244.38875463701817
# {'coverage_prop': '0.912', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.548', 'efficiency': '0.423', 'TP': '257', 'FP': '147', 'FN': '39', 'precision': '0.636', 'recall': '0.868', 'f1': '0.734', 'total_rewards': 244.3887546370161, 'invalid_action_count': 55, 'num_ms1_scans': 523, 'num_ms2_scans': 954}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 86.34246847128895
# steps	 1000 	total rewards	 179.86472487915836
# Finished after 1382 timesteps (5.5970518589019775 seconds) with total reward 233.204797590491
# {'coverage_prop': '0.976', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.809', 'efficiency': '0.318', 'TP': '161', 'FP': '82', 'FN': '6', 'precision': '0.663', 'recall': '0.964', 'f1': '0.785', 'total_rewards': 233.2047975904886, 'invalid_action_count': 1, 'num_ms1_scans': 618, 'num_ms2_scans': 764}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 83.52005733184869
# steps	 1000 	total rewards	 167.68921132834805
# Finished after 1383 timesteps (4.629124164581299 seconds) with total reward 227.98811129275674
# {'coverage_prop': '0.960', 'intensity_prop': '0.565', 'ms1ms2_ratio': '0.805', 'efficiency': '0.315', 'TP': '153', 'FP': '88', 'FN': '10', 'precision': '0.635', 'recall': '0.939', 'f1': '0.757', 'total_rewards': 227.9881112927544, 'invalid_action_count': 3, 'num_ms1_scans': 617, 'num_ms2_scans': 766}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 75.39277176671283
# steps	 1000 	total rewards	 168.0081587931095
# Finished after 1405 timesteps (6.529700040817261 seconds) with total reward 230.651692997736
# {'coverage_prop': '0.960', 'intensity_prop': '0.546', 'ms1ms2_ratio': '0.737', 'efficiency': '0.356', 'TP': '172', 'FP': '116', 'FN': '12', 'precision': '0.597', 'recall': '0.935', 'f1': '0.729', 'total_rewards': 230.65169299773385, 'invalid_action_count': 7, 'num_ms1_scans': 596, 'num_ms2_scans': 809}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 74.516205722367
# steps	 1000 	total rewards	 172.2730309844036
# Finished after 1364 timesteps (3.7532730102539062 seconds) with total reward 218.99355169707084
# {'coverage_prop': '0.976', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.874', 'efficiency': '0.276', 'TP': '137', 'FP': '64', 'FN': '5', 'precision': '0.682', 'recall': '0.965', 'f1': '0.799', 'total_rewards': 218.9935516970686, 'invalid_action_count': 0, 'num_ms1_scans': 636, 'num_ms2_scans': 728}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 85.36583714744185
# steps	 1000 	total rewards	 181.61736297080552
# Finished after 1453 timesteps (6.64693021774292 seconds) with total reward 257.2312670715199
# {'coverage_prop': '0.939', 'intensity_prop': '0.535', 'ms1ms2_ratio': '0.604', 'efficiency': '0.422', 'TP': '238', 'FP': '144', 'FN': '25', 'precision': '0.623', 'recall': '0.905', 'f1': '0.738', 'total_rewards': 257.23126707151795, 'invalid_action_count': 22, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 104.76882818530156
# steps	 1000 	total rewards	 200.63456525995826
# Finished after 1485 timesteps (6.074732065200806 seconds) with total reward 287.713981268153
# {'coverage_prop': '0.940', 'intensity_prop': '0.532', 'ms1ms2_ratio': '0.531', 'efficiency': '0.482', 'TP': '297', 'FP': '171', 'FN': '30', 'precision': '0.635', 'recall': '0.908', 'f1': '0.747', 'total_rewards': 287.71398126815296, 'invalid_action_count': 33, 'num_ms1_scans': 515, 'num_ms2_scans': 970}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 97.59447637706938
# steps	 1000 	total rewards	 211.45621563596046
# Finished after 1430 timesteps (9.876004934310913 seconds) with total reward 275.3982381562849
# {'coverage_prop': '0.968', 'intensity_prop': '0.548', 'ms1ms2_ratio': '0.665', 'efficiency': '0.419', 'TP': '218', 'FP': '142', 'FN': '12', 'precision': '0.606', 'recall': '0.948', 'f1': '0.739', 'total_rewards': 275.39823815628426, 'invalid_action_count': 5, 'num_ms1_scans': 571, 'num_ms2_scans': 859}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 83.80950804794935
# steps	 1000 	total rewards	 193.10177305290458
# Finished after 1400 timesteps (5.238278865814209 seconds) with total reward 251.3525418929365
# {'coverage_prop': '0.997', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.750', 'efficiency': '0.376', 'TP': '168', 'FP': '133', 'FN': '1', 'precision': '0.558', 'recall': '0.994', 'f1': '0.715', 'total_rewards': 251.3525418929344, 'invalid_action_count': 3, 'num_ms1_scans': 600, 'num_ms2_scans': 800}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 84.04854384234818
# steps	 1000 	total rewards	 180.74869169557613
# Finished after 1407 timesteps (4.218261003494263 seconds) with total reward 241.61371006593038
# {'coverage_prop': '0.981', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.731', 'efficiency': '0.320', 'TP': '145', 'FP': '115', 'FN': '5', 'precision': '0.558', 'recall': '0.967', 'f1': '0.707', 'total_rewards': 241.61371006592807, 'invalid_action_count': 3, 'num_ms1_scans': 594, 'num_ms2_scans': 813}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 94.88983488324747
# steps	 1000 	total rewards	 183.2752089240979
# Finished after 1480 timesteps (7.1318278312683105 seconds) with total reward 256.37932147465995
# {'coverage_prop': '0.912', 'intensity_prop': '0.519', 'ms1ms2_ratio': '0.542', 'efficiency': '0.445', 'TP': '269', 'FP': '158', 'FN': '41', 'precision': '0.630', 'recall': '0.868', 'f1': '0.730', 'total_rewards': 256.37932147465807, 'invalid_action_count': 48, 'num_ms1_scans': 520, 'num_ms2_scans': 960}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 73.27385659942689
# steps	 1000 	total rewards	 172.58688198018734
# Finished after 1369 timesteps (4.217339277267456 seconds) with total reward 225.8033394213986
# {'coverage_prop': '0.970', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.855', 'efficiency': '0.308', 'TP': '142', 'FP': '85', 'FN': '7', 'precision': '0.626', 'recall': '0.953', 'f1': '0.755', 'total_rewards': 225.80333942139626, 'invalid_action_count': 1, 'num_ms1_scans': 631, 'num_ms2_scans': 738}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 86.27237101715288
# steps	 1000 	total rewards	 189.29481660261285
# Finished after 1419 timesteps (5.950700044631958 seconds) with total reward 251.5183648978715
# {'coverage_prop': '0.969', 'intensity_prop': '0.544', 'ms1ms2_ratio': '0.693', 'efficiency': '0.372', 'TP': '183', 'FP': '129', 'FN': '10', 'precision': '0.587', 'recall': '0.948', 'f1': '0.725', 'total_rewards': 251.51836489786908, 'invalid_action_count': 7, 'num_ms1_scans': 581, 'num_ms2_scans': 838}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.06954954791055
# steps	 1000 	total rewards	 194.26360041077734
# Finished after 1408 timesteps (4.2408530712127686 seconds) with total reward 261.5789010016467
# {'coverage_prop': '0.968', 'intensity_prop': '0.598', 'ms1ms2_ratio': '0.725', 'efficiency': '0.368', 'TP': '204', 'FP': '96', 'FN': '10', 'precision': '0.680', 'recall': '0.953', 'f1': '0.794', 'total_rewards': 261.5789010016449, 'invalid_action_count': 3, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 94.921599421043
# steps	 1000 	total rewards	 200.44529252910905
# Finished after 1422 timesteps (4.628566026687622 seconds) with total reward 265.511485175836
# {'coverage_prop': '0.968', 'intensity_prop': '0.526', 'ms1ms2_ratio': '0.685', 'efficiency': '0.396', 'TP': '197', 'FP': '137', 'FN': '11', 'precision': '0.590', 'recall': '0.947', 'f1': '0.727', 'total_rewards': 265.51148517583493, 'invalid_action_count': 8, 'num_ms1_scans': 578, 'num_ms2_scans': 844}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 95.24885261376143
# steps	 1000 	total rewards	 202.54187239664236
# Finished after 1443 timesteps (6.862928152084351 seconds) with total reward 281.2272365358813
# {'coverage_prop': '0.972', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.629', 'efficiency': '0.435', 'TP': '248', 'FP': '137', 'FN': '11', 'precision': '0.644', 'recall': '0.958', 'f1': '0.770', 'total_rewards': 281.2272365358813, 'invalid_action_count': 13, 'num_ms1_scans': 557, 'num_ms2_scans': 886}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 69.74009781792458
# steps	 1000 	total rewards	 167.18298886332795
# Finished after 1362 timesteps (3.813530921936035 seconds) with total reward 218.08732394689764
# {'coverage_prop': '0.985', 'intensity_prop': '0.633', 'ms1ms2_ratio': '0.884', 'efficiency': '0.277', 'TP': '142', 'FP': '58', 'FN': '3', 'precision': '0.710', 'recall': '0.979', 'f1': '0.823', 'total_rewards': 218.08732394689537, 'invalid_action_count': 0, 'num_ms1_scans': 639, 'num_ms2_scans': 723}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 81.89458276222618
# steps	 1000 	total rewards	 192.57306980959754
# Finished after 1395 timesteps (4.005212783813477 seconds) with total reward 257.2988248670451
# {'coverage_prop': '0.982', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.766', 'efficiency': '0.349', 'TP': '183', 'FP': '93', 'FN': '5', 'precision': '0.663', 'recall': '0.973', 'f1': '0.789', 'total_rewards': 257.2988248670428, 'invalid_action_count': 2, 'num_ms1_scans': 605, 'num_ms2_scans': 790}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 100.62438722192385
# steps	 1000 	total rewards	 178.62826685177725
# Finished after 1474 timesteps (7.351929187774658 seconds) with total reward 268.40875161102497
# {'coverage_prop': '0.919', 'intensity_prop': '0.493', 'ms1ms2_ratio': '0.555', 'efficiency': '0.478', 'TP': '257', 'FP': '196', 'FN': '40', 'precision': '0.567', 'recall': '0.865', 'f1': '0.685', 'total_rewards': 268.4087516110239, 'invalid_action_count': 43, 'num_ms1_scans': 526, 'num_ms2_scans': 948}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 84.60569290402512
# steps	 1000 	total rewards	 176.24698855408639
# Finished after 1414 timesteps (4.639816999435425 seconds) with total reward 236.83224414781156
# {'coverage_prop': '0.977', 'intensity_prop': '0.536', 'ms1ms2_ratio': '0.710', 'efficiency': '0.359', 'TP': '173', 'FP': '124', 'FN': '7', 'precision': '0.582', 'recall': '0.961', 'f1': '0.725', 'total_rewards': 236.8322441478092, 'invalid_action_count': 10, 'num_ms1_scans': 587, 'num_ms2_scans': 827}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 96.2947472112688
# steps	 1000 	total rewards	 210.15683842109235
# steps	 1500 	total rewards	 314.798634056055
# Finished after 1708 timesteps (9.915504932403564 seconds) with total reward 349.6966282125401
# {'coverage_prop': '0.932', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.206', 'efficiency': '0.280', 'TP': '354', 'FP': '43', 'FN': '29', 'precision': '0.892', 'recall': '0.924', 'f1': '0.908', 'total_rewards': 349.6966282125408, 'invalid_action_count': 0, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.71672116839305
# steps	 1000 	total rewards	 202.23560506519314
# steps	 1500 	total rewards	 283.18536291001726
# Finished after 1542 timesteps (7.871917963027954 seconds) with total reward 288.5472310775797
# {'coverage_prop': '0.962', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.424', 'efficiency': '0.233', 'TP': '237', 'FP': '15', 'FN': '10', 'precision': '0.940', 'recall': '0.960', 'f1': '0.950', 'total_rewards': 288.5472310775799, 'invalid_action_count': 0, 'num_ms1_scans': 459, 'num_ms2_scans': 1083}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.62128539259734
# steps	 1000 	total rewards	 209.44701077429943
# steps	 1500 	total rewards	 315.09467642816026
# Finished after 1657 timesteps (9.225428104400635 seconds) with total reward 337.7852727539003
# {'coverage_prop': '0.924', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.261', 'efficiency': '0.277', 'TP': '329', 'FP': '35', 'FN': '30', 'precision': '0.904', 'recall': '0.916', 'f1': '0.910', 'total_rewards': 337.78527275390053, 'invalid_action_count': 0, 'num_ms1_scans': 343, 'num_ms2_scans': 1314}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 104.41605033421533
# steps	 1000 	total rewards	 220.61543523078416
# steps	 1500 	total rewards	 321.7969920978544
# Finished after 1704 timesteps (11.564102172851562 seconds) with total reward 360.2671640277904
# {'coverage_prop': '0.925', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.210', 'efficiency': '0.297', 'TP': '386', 'FP': '32', 'FN': '34', 'precision': '0.923', 'recall': '0.919', 'f1': '0.921', 'total_rewards': 360.26716402779084, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 94.83696526824527
# steps	 1000 	total rewards	 230.4353747798644
# steps	 1500 	total rewards	 341.20598376036196
# Finished after 1691 timesteps (9.436824798583984 seconds) with total reward 373.00301431907974
# {'coverage_prop': '0.961', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.224', 'efficiency': '0.304', 'TP': '368', 'FP': '52', 'FN': '17', 'precision': '0.876', 'recall': '0.956', 'f1': '0.914', 'total_rewards': 373.00301431908053, 'invalid_action_count': 0, 'num_ms1_scans': 309, 'num_ms2_scans': 1382}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.96535245459845
# steps	 1000 	total rewards	 177.0309816592628
# Finished after 1398 timesteps (7.166700839996338 seconds) with total reward 239.4026520560644
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.758', 'efficiency': '0.242', 'TP': '180', 'FP': '12', 'FN': '8', 'precision': '0.938', 'recall': '0.957', 'f1': '0.947', 'total_rewards': 239.40265205606244, 'invalid_action_count': 0, 'num_ms1_scans': 603, 'num_ms2_scans': 795}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 105.43142187016116
# steps	 1000 	total rewards	 217.16234875580517
# steps	 1500 	total rewards	 317.53882861089824
# Finished after 1728 timesteps (9.765366077423096 seconds) with total reward 356.0813403930652
# {'coverage_prop': '0.883', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.187', 'efficiency': '0.290', 'TP': '364', 'FP': '58', 'FN': '56', 'precision': '0.863', 'recall': '0.867', 'f1': '0.865', 'total_rewards': 356.08134039306697, 'invalid_action_count': 0, 'num_ms1_scans': 272, 'num_ms2_scans': 1456}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.26121603810041
# steps	 1000 	total rewards	 179.87909305623398
# Finished after 1458 timesteps (9.293955087661743 seconds) with total reward 248.2539839548109
# {'coverage_prop': '0.961', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.592', 'efficiency': '0.214', 'TP': '187', 'FP': '9', 'FN': '8', 'precision': '0.954', 'recall': '0.959', 'f1': '0.957', 'total_rewards': 248.2539839548094, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 916}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 101.73075787582624
# steps	 1000 	total rewards	 202.63638040748515
# steps	 1500 	total rewards	 318.35490928225283
# Finished after 1723 timesteps (10.380170822143555 seconds) with total reward 356.04648908095874
# {'coverage_prop': '0.939', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.192', 'efficiency': '0.275', 'TP': '363', 'FP': '35', 'FN': '26', 'precision': '0.912', 'recall': '0.933', 'f1': '0.922', 'total_rewards': 356.04648908096, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1445}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 91.08268938564159
# steps	 1000 	total rewards	 203.1460220195836
# steps	 1500 	total rewards	 302.55484646418915
# Finished after 1647 timesteps (8.969488143920898 seconds) with total reward 323.3439747097695
# {'coverage_prop': '0.945', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.273', 'efficiency': '0.281', 'TP': '325', 'FP': '38', 'FN': '21', 'precision': '0.895', 'recall': '0.939', 'f1': '0.917', 'total_rewards': 323.34397470977063, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 92.89177994740865
# steps	 1000 	total rewards	 200.33780966885
# steps	 1500 	total rewards	 308.44066178823545
# Finished after 1722 timesteps (9.862671852111816 seconds) with total reward 346.27603435685785
# {'coverage_prop': '0.898', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '358', 'FP': '40', 'FN': '45', 'precision': '0.899', 'recall': '0.888', 'f1': '0.894', 'total_rewards': 346.27603435685813, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.66797281187884
# steps	 1000 	total rewards	 184.53222725829215
# steps	 1500 	total rewards	 256.3446714108332
# Finished after 1518 timesteps (10.095212936401367 seconds) with total reward 258.1259622000612
# {'coverage_prop': '0.960', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.467', 'efficiency': '0.231', 'TP': '228', 'FP': '11', 'FN': '10', 'precision': '0.954', 'recall': '0.958', 'f1': '0.956', 'total_rewards': 258.12596220006, 'invalid_action_count': 0, 'num_ms1_scans': 483, 'num_ms2_scans': 1035}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.17262365571366
# steps	 1000 	total rewards	 179.03752773958183
# steps	 1500 	total rewards	 257.1736312003494
# Finished after 1583 timesteps (8.995866060256958 seconds) with total reward 268.1257663511901
# {'coverage_prop': '0.948', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.359', 'efficiency': '0.204', 'TP': '219', 'FP': '19', 'FN': '13', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 268.1257663511893, 'invalid_action_count': 0, 'num_ms1_scans': 418, 'num_ms2_scans': 1165}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 80.6116798332078
# steps	 1000 	total rewards	 173.60201913423703
# steps	 1500 	total rewards	 262.64695811092656
# Finished after 1630 timesteps (9.210564851760864 seconds) with total reward 277.80967508193527
# {'coverage_prop': '0.937', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.294', 'efficiency': '0.223', 'TP': '248', 'FP': '33', 'FN': '19', 'precision': '0.883', 'recall': '0.929', 'f1': '0.905', 'total_rewards': 277.8096750819356, 'invalid_action_count': 0, 'num_ms1_scans': 370, 'num_ms2_scans': 1260}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 78.05105674125915
# steps	 1000 	total rewards	 168.53435625126963
# Finished after 1478 timesteps (7.37639594078064 seconds) with total reward 239.10890213610804
# {'coverage_prop': '0.951', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.546', 'efficiency': '0.205', 'TP': '183', 'FP': '13', 'FN': '10', 'precision': '0.934', 'recall': '0.948', 'f1': '0.941', 'total_rewards': 239.10890213610625, 'invalid_action_count': 0, 'num_ms1_scans': 522, 'num_ms2_scans': 956}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.24788449900285
# steps	 1000 	total rewards	 201.71725751361183
# steps	 1500 	total rewards	 309.1326060834659
# Finished after 1647 timesteps (9.28524112701416 seconds) with total reward 341.7556904214264
# {'coverage_prop': '0.941', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.273', 'efficiency': '0.296', 'TP': '344', 'FP': '39', 'FN': '24', 'precision': '0.898', 'recall': '0.935', 'f1': '0.916', 'total_rewards': 341.7556904214272, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 109.4689156831942
# steps	 1000 	total rewards	 222.9984511917354
# steps	 1500 	total rewards	 327.33892555353907
# Finished after 1717 timesteps (12.364413976669312 seconds) with total reward 367.5454464599467
# {'coverage_prop': '0.910', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.197', 'efficiency': '0.316', 'TP': '409', 'FP': '44', 'FN': '45', 'precision': '0.903', 'recall': '0.901', 'f1': '0.902', 'total_rewards': 367.54544645994855, 'invalid_action_count': 0, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.66449307716269
# steps	 1000 	total rewards	 208.2255550813367
# steps	 1500 	total rewards	 298.09584404674365
# Finished after 1669 timesteps (9.130797147750854 seconds) with total reward 320.7417873236513
# {'coverage_prop': '0.938', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.248', 'efficiency': '0.261', 'TP': '320', 'FP': '29', 'FN': '23', 'precision': '0.917', 'recall': '0.933', 'f1': '0.925', 'total_rewards': 320.7417873236517, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 1337}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 86.58222225646823
# steps	 1000 	total rewards	 193.83662787853737
# steps	 1500 	total rewards	 283.52631003777475
# Finished after 1605 timesteps (8.54062008857727 seconds) with total reward 298.66096748916345
# {'coverage_prop': '0.947', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.328', 'efficiency': '0.237', 'TP': '262', 'FP': '24', 'FN': '16', 'precision': '0.916', 'recall': '0.942', 'f1': '0.929', 'total_rewards': 298.6609674891638, 'invalid_action_count': 0, 'num_ms1_scans': 396, 'num_ms2_scans': 1209}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.801418530762
# steps	 1000 	total rewards	 187.14255144611414
# steps	 1500 	total rewards	 271.3242882690306
# Finished after 1602 timesteps (8.208541870117188 seconds) with total reward 281.7817604944602
# {'coverage_prop': '0.977', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.332', 'efficiency': '0.215', 'TP': '237', 'FP': '22', 'FN': '6', 'precision': '0.915', 'recall': '0.975', 'f1': '0.944', 'total_rewards': 281.7817604944603, 'invalid_action_count': 0, 'num_ms1_scans': 399, 'num_ms2_scans': 1203}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.64570324480422
# steps	 1000 	total rewards	 209.8538266334351
# steps	 1500 	total rewards	 302.50968702007094
# Finished after 1712 timesteps (9.586567878723145 seconds) with total reward 343.4124818881533
# {'coverage_prop': '0.874', 'intensity_prop': '0.677', 'ms1ms2_ratio': '0.202', 'efficiency': '0.287', 'TP': '360', 'FP': '49', 'FN': '59', 'precision': '0.880', 'recall': '0.859', 'f1': '0.870', 'total_rewards': 343.4124818881536, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 79.34995801371568
# steps	 1000 	total rewards	 185.05815954422587
# Finished after 1459 timesteps (10.464203119277954 seconds) with total reward 260.9168005156736
# {'coverage_prop': '0.957', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.591', 'efficiency': '0.244', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 260.9168005156723, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 917}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 91.16098210415569
# steps	 1000 	total rewards	 198.46979716592637
# steps	 1500 	total rewards	 285.75298617886926
# Finished after 1620 timesteps (8.819381952285767 seconds) with total reward 305.9567725268008
# {'coverage_prop': '0.960', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.306', 'efficiency': '0.249', 'TP': '283', 'FP': '26', 'FN': '13', 'precision': '0.916', 'recall': '0.956', 'f1': '0.936', 'total_rewards': 305.956772526802, 'invalid_action_count': 0, 'num_ms1_scans': 380, 'num_ms2_scans': 1240}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 95.11617971055398
# steps	 1000 	total rewards	 204.85149167720783
# steps	 1500 	total rewards	 291.49540729766466
# Finished after 1557 timesteps (8.128023862838745 seconds) with total reward 300.47640370637237
# {'coverage_prop': '0.948', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.398', 'efficiency': '0.264', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927', 'total_rewards': 300.4764037063734, 'invalid_action_count': 0, 'num_ms1_scans': 443, 'num_ms2_scans': 1114}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 93.89340790301048
# steps	 1000 	total rewards	 205.42243398475907
# steps	 1500 	total rewards	 299.97419106939174
# Finished after 1655 timesteps (8.79027271270752 seconds) with total reward 325.3669482550192
# {'coverage_prop': '0.948', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.263', 'efficiency': '0.250', 'TP': '301', 'FP': '26', 'FN': '18', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 325.3669482550196, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 92.46389424693754
# steps	 1000 	total rewards	 194.83826945588413
# steps	 1500 	total rewards	 303.0523187043243
# Finished after 1658 timesteps (8.997545957565308 seconds) with total reward 330.86551958049847
# {'coverage_prop': '0.957', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.260', 'efficiency': '0.288', 'TP': '344', 'FP': '35', 'FN': '17', 'precision': '0.908', 'recall': '0.953', 'f1': '0.930', 'total_rewards': 330.8655195804994, 'invalid_action_count': 0, 'num_ms1_scans': 342, 'num_ms2_scans': 1316}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 72.1469507255527
# steps	 1000 	total rewards	 171.47678380953522
# Finished after 1453 timesteps (7.449176788330078 seconds) with total reward 239.9201738382847
# {'coverage_prop': '0.966', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.604', 'efficiency': '0.216', 'TP': '184', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.963', 'f1': '0.951', 'total_rewards': 239.92017383828332, 'invalid_action_count': 0, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 88.31235132594269
# steps	 1000 	total rewards	 195.74792284704353
# steps	 1500 	total rewards	 294.01215539849073
# Finished after 1539 timesteps (10.994962930679321 seconds) with total reward 299.6239201087449
# {'coverage_prop': '0.957', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.429', 'efficiency': '0.250', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 299.62392010874515, 'invalid_action_count': 0, 'num_ms1_scans': 462, 'num_ms2_scans': 1077}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.85875030891819
# steps	 1000 	total rewards	 197.99866949790092
# steps	 1500 	total rewards	 300.4205818023136
# Finished after 1734 timesteps (9.799683809280396 seconds) with total reward 347.5622303363375
# {'coverage_prop': '0.856', 'intensity_prop': '0.645', 'ms1ms2_ratio': '0.181', 'efficiency': '0.287', 'TP': '358', 'FP': '64', 'FN': '71', 'precision': '0.848', 'recall': '0.834', 'f1': '0.841', 'total_rewards': 347.5622303363379, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1468}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.32388476353701
# steps	 1000 	total rewards	 195.74111008357096
# steps	 1500 	total rewards	 278.7575512609741
# Finished after 1628 timesteps (8.433458805084229 seconds) with total reward 293.7826477847459
# {'coverage_prop': '0.954', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.296', 'efficiency': '0.231', 'TP': '271', 'FP': '19', 'FN': '14', 'precision': '0.934', 'recall': '0.951', 'f1': '0.943', 'total_rewards': 293.78264778474596, 'invalid_action_count': 0, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc358617d60>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc358d465e0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc358d62880>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.534', 'ms1ms2_ratio': '3.263', 'efficiency': '0.726', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.428', 'efficiency': '0.771', 'TP': '206', 'FP': '194', 'FN': '24', 'precision': '0.515', 'recall': '0.896', 'f1': '0.654'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '122', 'FP': '117', 'FN': '10', 'precision': '0.510', 'recall': '0.924', 'f1': '0.658'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.478', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '108', 'FP': '129', 'FN': '14', 'precision': '0.456', 'recall': '0.885', 'f1': '0.602'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.509', 'ms1ms2_ratio': '1.978', 'efficiency': '0.705', 'TP': '149', 'FP': '136', 'FN': '15', 'precision': '0.523', 'recall': '0.909', 'f1': '0.664'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.504', 'ms1ms2_ratio': '2.080', 'efficiency': '0.750', 'TP': '142', 'FP': '149', 'FN': '11', 'precision': '0.488', 'recall': '0.928', 'f1': '0.640'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.350', 'efficiency': '0.738', 'TP': '125', 'FP': '134', 'FN': '6', 'precision': '0.483', 'recall': '0.954', 'f1': '0.641'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.539', 'ms1ms2_ratio': '1.159', 'efficiency': '0.740', 'TP': '262', 'FP': '184', 'FN': '22', 'precision': '0.587', 'recall': '0.923', 'f1': '0.718'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '108', 'FP': '112', 'FN': '14', 'precision': '0.491', 'recall': '0.885', 'f1': '0.632'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.247', 'efficiency': '0.719', 'TP': '92', 'FP': '100', 'FN': '11', 'precision': '0.479', 'recall': '0.893', 'f1': '0.624'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.518', 'ms1ms2_ratio': '2.241', 'efficiency': '0.737', 'TP': '146', 'FP': '123', 'FN': '12', 'precision': '0.543', 'recall': '0.924', 'f1': '0.684'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1091.306995                1230.0          0.714           0.203
# 1  random   -1343.868242                1431.0          0.676           0.187
# 2  random   -1065.177074                1211.0          0.772           0.224
# 3  random   -1286.453034                1408.0          0.608           0.187
# 4  random   -1338.812784                1452.0          0.625           0.155
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.153      0.257   0.390  0.310
# 1          0.006       0.089      0.271   0.361  0.310
# 2          0.005       0.154      0.263   0.471  0.338
# 3          0.005       0.139      0.287   0.309  0.298
# 4          0.003       0.137      0.201   0.251  0.224

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     297.215745                  12.0          0.965           0.562
# 31    DQN     245.665964                   1.0          0.977           0.567
# 32    DQN     275.100896                  16.0          0.949           0.527
# 33    DQN     286.856914                  19.0          0.949           0.544
# 34    DQN     275.862252                  21.0          0.934           0.519
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.582       0.445      0.642   0.946  0.765
# 31          0.848       0.345      0.602   0.963  0.740
# 32          0.624       0.420      0.591   0.917  0.719
# 33          0.584       0.465      0.641   0.923  0.757
# 34          0.601       0.449      0.605   0.895  0.722

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
