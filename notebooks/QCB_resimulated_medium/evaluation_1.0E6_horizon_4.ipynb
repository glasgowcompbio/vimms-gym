# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-20 12:41:24.364 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fde98966fd0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fde9969d670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fdebe0ba910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'exclusion_t0': 5,
#    'exclusion_t1': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fde98966fd0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fde9969d670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fdebe0ba910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fde98966fd0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fde9969d670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fdebe0ba910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['exclusion_t0'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d exclusion_t0 = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['exclusion_t0'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -984.8091738562173
# steps	 1500 	total rewards	 -1413.8129494054206
# Finished after 1994 timesteps (4.163794040679932 seconds) with total reward -1886.3059973657028
# {'coverage_prop': '0.308', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.003', 'efficiency': '0.066', 'TP': '24', 'FP': '107', 'FN': '295', 'precision': '0.183', 'recall': '0.075', 'f1': '0.107', 'total_rewards': -1886.3059973657023, 'invalid_action_count': 1916, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -490.05794859273493
# steps	 1000 	total rewards	 -986.4995538306846
# steps	 1500 	total rewards	 -1457.976800734386
# Finished after 1991 timesteps (2.5233261585235596 seconds) with total reward -1920.8346798506523
# {'coverage_prop': '0.206', 'intensity_prop': '0.045', 'ms1ms2_ratio': '0.005', 'efficiency': '0.027', 'TP': '8', 'FP': '46', 'FN': '208', 'precision': '0.148', 'recall': '0.037', 'f1': '0.059', 'total_rewards': -1920.8346798506525, 'invalid_action_count': 1941, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -491.0031041278162
# steps	 1000 	total rewards	 -946.0481053179099
# steps	 1500 	total rewards	 -1365.5309337759854
# Finished after 1991 timesteps (3.488389730453491 seconds) with total reward -1809.0456220069586
# {'coverage_prop': '0.454', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.005', 'efficiency': '0.090', 'TP': '33', 'FP': '146', 'FN': '215', 'precision': '0.184', 'recall': '0.133', 'f1': '0.155', 'total_rewards': -1809.0456220069582, 'invalid_action_count': 1867, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -476.8823713917744
# steps	 1000 	total rewards	 -929.6930108087479
# steps	 1500 	total rewards	 -1379.0642567626205
# Finished after 1986 timesteps (3.539606809616089 seconds) with total reward -1821.8517468066166
# {'coverage_prop': '0.365', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.007', 'efficiency': '0.084', 'TP': '36', 'FP': '129', 'FN': '287', 'precision': '0.218', 'recall': '0.111', 'f1': '0.148', 'total_rewards': -1821.851746806617, 'invalid_action_count': 1871, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -479.53712007007476
# steps	 1000 	total rewards	 -954.0148421261017
# steps	 1500 	total rewards	 -1396.854793368414
# Finished after 1991 timesteps (3.9481747150421143 seconds) with total reward -1858.8908806649433
# {'coverage_prop': '0.311', 'intensity_prop': '0.085', 'ms1ms2_ratio': '0.005', 'efficiency': '0.069', 'TP': '34', 'FP': '102', 'FN': '301', 'precision': '0.250', 'recall': '0.101', 'f1': '0.144', 'total_rewards': -1858.8908806649436, 'invalid_action_count': 1895, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -486.9681768616741
# steps	 1000 	total rewards	 -958.6894231094543
# steps	 1500 	total rewards	 -1436.7428406489116
# Finished after 1988 timesteps (2.3147780895233154 seconds) with total reward -1887.8155489501737
# {'coverage_prop': '0.385', 'intensity_prop': '0.082', 'ms1ms2_ratio': '0.006', 'efficiency': '0.039', 'TP': '15', 'FP': '62', 'FN': '123', 'precision': '0.195', 'recall': '0.109', 'f1': '0.140', 'total_rewards': -1887.8155489501746, 'invalid_action_count': 1918, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -493.2644988304276
# steps	 1000 	total rewards	 -972.7931369766206
# steps	 1500 	total rewards	 -1409.5124060347775
# Finished after 1990 timesteps (5.662002801895142 seconds) with total reward -1853.6979048254075
# {'coverage_prop': '0.268', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.005', 'efficiency': '0.065', 'TP': '33', 'FP': '95', 'FN': '350', 'precision': '0.258', 'recall': '0.086', 'f1': '0.129', 'total_rewards': -1853.6979048254075, 'invalid_action_count': 1893, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -493.17548371233727
# steps	 1000 	total rewards	 -973.5631526945971
# steps	 1500 	total rewards	 -1456.6700730634873
# Finished after 1992 timesteps (3.2639753818511963 seconds) with total reward -1929.7376756686745
# {'coverage_prop': '0.211', 'intensity_prop': '0.056', 'ms1ms2_ratio': '0.004', 'efficiency': '0.022', 'TP': '7', 'FP': '36', 'FN': '161', 'precision': '0.163', 'recall': '0.042', 'f1': '0.066', 'total_rewards': -1929.7376756686751, 'invalid_action_count': 1947, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -470.08793054269864
# steps	 1000 	total rewards	 -929.5806457486626
# steps	 1500 	total rewards	 -1368.2915979459124
# Finished after 1987 timesteps (4.209723949432373 seconds) with total reward -1818.4694883816433
# {'coverage_prop': '0.344', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.007', 'efficiency': '0.074', 'TP': '32', 'FP': '114', 'FN': '278', 'precision': '0.219', 'recall': '0.103', 'f1': '0.140', 'total_rewards': -1818.4694883816437, 'invalid_action_count': 1864, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -478.7695339713818
# steps	 1000 	total rewards	 -976.2255709380279
# steps	 1500 	total rewards	 -1397.9794824664239
# Finished after 1987 timesteps (3.3937909603118896 seconds) with total reward -1840.3803101035721
# {'coverage_prop': '0.378', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.007', 'efficiency': '0.073', 'TP': '34', 'FP': '111', 'FN': '239', 'precision': '0.234', 'recall': '0.125', 'f1': '0.163', 'total_rewards': -1840.380310103573, 'invalid_action_count': 1884, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -470.0627516574695
# steps	 1000 	total rewards	 -927.8576012342139
# steps	 1500 	total rewards	 -1368.2456332738593
# Finished after 1987 timesteps (4.249901056289673 seconds) with total reward -1814.8842642196687
# {'coverage_prop': '0.354', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.007', 'efficiency': '0.080', 'TP': '42', 'FP': '115', 'FN': '286', 'precision': '0.268', 'recall': '0.128', 'f1': '0.173', 'total_rewards': -1814.8842642196682, 'invalid_action_count': 1865, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -484.2496052517701
# steps	 1000 	total rewards	 -963.9662843664332
# steps	 1500 	total rewards	 -1431.999572865715
# Finished after 1989 timesteps (2.901487112045288 seconds) with total reward -1893.1073927990321
# {'coverage_prop': '0.341', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.006', 'efficiency': '0.043', 'TP': '22', 'FP': '63', 'FN': '164', 'precision': '0.259', 'recall': '0.118', 'f1': '0.162', 'total_rewards': -1893.1073927990321, 'invalid_action_count': 1920, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -486.8140402296071
# steps	 1000 	total rewards	 -955.5187130157863
# steps	 1500 	total rewards	 -1431.522992918396
# Finished after 1987 timesteps (3.1797382831573486 seconds) with total reward -1887.260321615664
# {'coverage_prop': '0.303', 'intensity_prop': '0.087', 'ms1ms2_ratio': '0.007', 'efficiency': '0.039', 'TP': '20', 'FP': '56', 'FN': '175', 'precision': '0.263', 'recall': '0.103', 'f1': '0.148', 'total_rewards': -1887.2603216156642, 'invalid_action_count': 1915, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -482.11122342340934
# steps	 1000 	total rewards	 -952.4082338510636
# steps	 1500 	total rewards	 -1369.8895060296786
# Finished after 1984 timesteps (3.12447190284729 seconds) with total reward -1811.1589769030393
# {'coverage_prop': '0.480', 'intensity_prop': '0.143', 'ms1ms2_ratio': '0.008', 'efficiency': '0.073', 'TP': '41', 'FP': '103', 'FN': '156', 'precision': '0.285', 'recall': '0.208', 'f1': '0.240', 'total_rewards': -1811.1589769030397, 'invalid_action_count': 1859, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -495.81078951360973
# steps	 1000 	total rewards	 -968.5458155276237
# steps	 1500 	total rewards	 -1435.648117856485
# Finished after 1992 timesteps (2.3157970905303955 seconds) with total reward -1907.409239001955
# {'coverage_prop': '0.330', 'intensity_prop': '0.068', 'ms1ms2_ratio': '0.004', 'efficiency': '0.034', 'TP': '11', 'FP': '57', 'FN': '138', 'precision': '0.162', 'recall': '0.074', 'f1': '0.101', 'total_rewards': -1907.4092390019553, 'invalid_action_count': 1931, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -481.90300104006485
# steps	 1000 	total rewards	 -943.1829906533476
# steps	 1500 	total rewards	 -1353.48680960124
# Finished after 1987 timesteps (3.513068914413452 seconds) with total reward -1809.1916752483821
# {'coverage_prop': '0.447', 'intensity_prop': '0.139', 'ms1ms2_ratio': '0.007', 'efficiency': '0.092', 'TP': '52', 'FP': '130', 'FN': '225', 'precision': '0.286', 'recall': '0.188', 'f1': '0.227', 'total_rewards': -1809.1916752483826, 'invalid_action_count': 1863, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -488.498270216181
# steps	 1000 	total rewards	 -986.891879649623
# steps	 1500 	total rewards	 -1423.335488535555
# Finished after 1991 timesteps (3.6365058422088623 seconds) with total reward -1856.2153594995057
# {'coverage_prop': '0.303', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.005', 'efficiency': '0.076', 'TP': '35', 'FP': '116', 'FN': '347', 'precision': '0.232', 'recall': '0.092', 'f1': '0.131', 'total_rewards': -1856.215359499506, 'invalid_action_count': 1897, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -466.009532132981
# steps	 1000 	total rewards	 -938.9633104918455
# steps	 1500 	total rewards	 -1386.3012217155508
# Finished after 1982 timesteps (3.7075703144073486 seconds) with total reward -1816.5003430332176
# {'coverage_prop': '0.376', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.009', 'efficiency': '0.071', 'TP': '31', 'FP': '109', 'FN': '232', 'precision': '0.221', 'recall': '0.118', 'f1': '0.154', 'total_rewards': -1816.5003430332176, 'invalid_action_count': 1865, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -983.4068722483271
# steps	 1500 	total rewards	 -1483.406872248327
# Finished after 1995 timesteps (2.9539871215820312 seconds) with total reward -1960.6054138903403
# {'coverage_prop': '0.103', 'intensity_prop': '0.026', 'ms1ms2_ratio': '0.003', 'efficiency': '0.016', 'TP': '7', 'FP': '24', 'FN': '271', 'precision': '0.226', 'recall': '0.025', 'f1': '0.045', 'total_rewards': -1960.6054138903403, 'invalid_action_count': 1970, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -480.0557119988937
# steps	 1000 	total rewards	 -948.8191028347018
# steps	 1500 	total rewards	 -1389.990820559971
# Finished after 1986 timesteps (2.75099515914917 seconds) with total reward -1824.584439747938
# {'coverage_prop': '0.415', 'intensity_prop': '0.119', 'ms1ms2_ratio': '0.007', 'efficiency': '0.056', 'TP': '26', 'FP': '84', 'FN': '155', 'precision': '0.236', 'recall': '0.144', 'f1': '0.179', 'total_rewards': -1824.5844397479384, 'invalid_action_count': 1872, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -475.8048367342129
# steps	 1000 	total rewards	 -900.5646486879729
# steps	 1500 	total rewards	 -1339.5900131696314
# Finished after 1989 timesteps (3.9158432483673096 seconds) with total reward -1792.383563198781
# {'coverage_prop': '0.410', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.006', 'efficiency': '0.097', 'TP': '46', 'FP': '146', 'FN': '276', 'precision': '0.240', 'recall': '0.143', 'f1': '0.179', 'total_rewards': -1792.3835631987815, 'invalid_action_count': 1850, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -481.07429993300116
# steps	 1000 	total rewards	 -959.6579159065661
# steps	 1500 	total rewards	 -1436.8218008738227
# Finished after 1988 timesteps (2.5849931240081787 seconds) with total reward -1912.4713643114449
# {'coverage_prop': '0.252', 'intensity_prop': '0.051', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '11', 'FP': '48', 'FN': '175', 'precision': '0.186', 'recall': '0.059', 'f1': '0.090', 'total_rewards': -1912.4713643114446, 'invalid_action_count': 1933, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -475.9938085580841
# steps	 1000 	total rewards	 -928.7455517376011
# steps	 1500 	total rewards	 -1378.2926470724278
# Finished after 1986 timesteps (2.8333399295806885 seconds) with total reward -1836.5282655252297
# {'coverage_prop': '0.360', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.007', 'efficiency': '0.059', 'TP': '26', 'FP': '90', 'FN': '206', 'precision': '0.224', 'recall': '0.112', 'f1': '0.149', 'total_rewards': -1836.5282655252295, 'invalid_action_count': 1881, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -497.4260895524985
# steps	 1000 	total rewards	 -945.58670718784
# steps	 1500 	total rewards	 -1412.9323867817911
# Finished after 1991 timesteps (3.366474151611328 seconds) with total reward -1877.7156068094478
# {'coverage_prop': '0.329', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.005', 'efficiency': '0.051', 'TP': '23', 'FP': '79', 'FN': '208', 'precision': '0.225', 'recall': '0.100', 'f1': '0.138', 'total_rewards': -1877.7156068094478, 'invalid_action_count': 1910, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -487.8907906821231
# steps	 1000 	total rewards	 -968.3735764120702
# steps	 1500 	total rewards	 -1372.7953125678264
# Finished after 1989 timesteps (3.2082419395446777 seconds) with total reward -1823.2826264241114
# {'coverage_prop': '0.383', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.006', 'efficiency': '0.067', 'TP': '32', 'FP': '100', 'FN': '213', 'precision': '0.242', 'recall': '0.131', 'f1': '0.170', 'total_rewards': -1823.2826264241114, 'invalid_action_count': 1873, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -489.71245497119344
# steps	 1000 	total rewards	 -970.7304918439114
# steps	 1500 	total rewards	 -1450.3647626658724
# Finished after 1992 timesteps (3.310966968536377 seconds) with total reward -1907.8941327581347
# {'coverage_prop': '0.189', 'intensity_prop': '0.036', 'ms1ms2_ratio': '0.004', 'efficiency': '0.038', 'TP': '13', 'FP': '62', 'FN': '321', 'precision': '0.173', 'recall': '0.039', 'f1': '0.064', 'total_rewards': -1907.894132758135, 'invalid_action_count': 1932, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -494.27141586535924
# steps	 1000 	total rewards	 -960.3391609511924
# steps	 1500 	total rewards	 -1416.2554547856544
# Finished after 1985 timesteps (2.2720799446105957 seconds) with total reward -1867.9411042525637
# {'coverage_prop': '0.448', 'intensity_prop': '0.129', 'ms1ms2_ratio': '0.008', 'efficiency': '0.046', 'TP': '26', 'FP': '65', 'FN': '112', 'precision': '0.286', 'recall': '0.188', 'f1': '0.227', 'total_rewards': -1867.9411042525637, 'invalid_action_count': 1902, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -472.7114868674614
# steps	 1000 	total rewards	 -928.7367835042269
# steps	 1500 	total rewards	 -1360.7878901172096
# Finished after 1983 timesteps (2.520693063735962 seconds) with total reward -1810.3962607511337
# {'coverage_prop': '0.431', 'intensity_prop': '0.128', 'ms1ms2_ratio': '0.009', 'efficiency': '0.062', 'TP': '35', 'FP': '86', 'FN': '160', 'precision': '0.289', 'recall': '0.179', 'f1': '0.222', 'total_rewards': -1810.3962607511346, 'invalid_action_count': 1861, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -495.8013242485636
# steps	 1000 	total rewards	 -977.4853811697296
# steps	 1500 	total rewards	 -1367.6933667202002
# Finished after 1988 timesteps (3.429774045944214 seconds) with total reward -1766.4119109853111
# {'coverage_prop': '0.416', 'intensity_prop': '0.131', 'ms1ms2_ratio': '0.006', 'efficiency': '0.104', 'TP': '63', 'FP': '142', 'FN': '288', 'precision': '0.307', 'recall': '0.179', 'f1': '0.227', 'total_rewards': -1766.411910985311, 'invalid_action_count': 1830, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -481.8393652694015
# steps	 1000 	total rewards	 -939.8909167122695
# steps	 1500 	total rewards	 -1393.062263871489
# Finished after 1986 timesteps (3.611280918121338 seconds) with total reward -1831.8972258707188
# {'coverage_prop': '0.434', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.007', 'efficiency': '0.067', 'TP': '28', 'FP': '104', 'FN': '172', 'precision': '0.212', 'recall': '0.140', 'f1': '0.169', 'total_rewards': -1831.897225870718, 'invalid_action_count': 1877, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# method = DQN max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.64GB > 0.36GB
# steps	 500 	total rewards	 65.8847879467954
# steps	 1000 	total rewards	 161.61209118072986
# Finished after 1399 timesteps (6.844512939453125 seconds) with total reward 220.58855369429216
# {'coverage_prop': '0.948', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.753', 'efficiency': '0.506', 'TP': '291', 'FP': '113', 'FN': '22', 'precision': '0.720', 'recall': '0.930', 'f1': '0.812', 'total_rewards': 220.58855369429213, 'invalid_action_count': 6, 'num_ms1_scans': 601, 'num_ms2_scans': 798}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 55.067853192795035
# steps	 1000 	total rewards	 126.09356005904714
# Finished after 1316 timesteps (5.242614030838013 seconds) with total reward 158.17426232267596
# {'coverage_prop': '0.954', 'intensity_prop': '0.617', 'ms1ms2_ratio': '1.082', 'efficiency': '0.396', 'TP': '185', 'FP': '65', 'FN': '12', 'precision': '0.740', 'recall': '0.939', 'f1': '0.828', 'total_rewards': 158.17426232267573, 'invalid_action_count': 3, 'num_ms1_scans': 684, 'num_ms2_scans': 632}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 54.96002841233422
# steps	 1000 	total rewards	 149.93848673183928
# Finished after 1360 timesteps (5.5595080852508545 seconds) with total reward 203.76557890754853
# {'coverage_prop': '0.949', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.892', 'efficiency': '0.520', 'TP': '263', 'FP': '111', 'FN': '20', 'precision': '0.703', 'recall': '0.929', 'f1': '0.801', 'total_rewards': 203.76557890754867, 'invalid_action_count': 6, 'num_ms1_scans': 641, 'num_ms2_scans': 719}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 66.94476896545375
# steps	 1000 	total rewards	 172.2026014909602
# Finished after 1406 timesteps (7.096752882003784 seconds) with total reward 227.53644262094426
# {'coverage_prop': '0.945', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.732', 'efficiency': '0.526', 'TP': '324', 'FP': '103', 'FN': '25', 'precision': '0.759', 'recall': '0.928', 'f1': '0.835', 'total_rewards': 227.53644262094434, 'invalid_action_count': 2, 'num_ms1_scans': 594, 'num_ms2_scans': 812}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 60.253287916563245
# steps	 1000 	total rewards	 165.33199250047247
# Finished after 1392 timesteps (6.626850128173828 seconds) with total reward 220.65995220537678
# {'coverage_prop': '0.968', 'intensity_prop': '0.616', 'ms1ms2_ratio': '0.776', 'efficiency': '0.540', 'TP': '303', 'FP': '120', 'FN': '14', 'precision': '0.716', 'recall': '0.956', 'f1': '0.819', 'total_rewards': 220.6599522053767, 'invalid_action_count': 3, 'num_ms1_scans': 608, 'num_ms2_scans': 784}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 41.007262693206584
# steps	 1000 	total rewards	 100.61611678121193
# Finished after 1242 timesteps (1.5132341384887695 seconds) with total reward 119.54035406689786
# {'coverage_prop': '0.955', 'intensity_prop': '0.690', 'ms1ms2_ratio': '1.571', 'efficiency': '0.395', 'TP': '161', 'FP': '30', 'FN': '9', 'precision': '0.843', 'recall': '0.947', 'f1': '0.892', 'total_rewards': 119.54035406689789, 'invalid_action_count': 2, 'num_ms1_scans': 759, 'num_ms2_scans': 483}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 70.21708986608517
# steps	 1000 	total rewards	 174.08065491781264
# Finished after 1410 timesteps (7.821359872817993 seconds) with total reward 230.58828285294067
# {'coverage_prop': '0.921', 'intensity_prop': '0.590', 'ms1ms2_ratio': '0.722', 'efficiency': '0.537', 'TP': '316', 'FP': '124', 'FN': '38', 'precision': '0.718', 'recall': '0.893', 'f1': '0.796', 'total_rewards': 230.5882828529406, 'invalid_action_count': 2, 'num_ms1_scans': 591, 'num_ms2_scans': 819}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 41.280266568474524
# steps	 1000 	total rewards	 107.73521341793315
# Finished after 1278 timesteps (4.104445934295654 seconds) with total reward 132.01871071632007
# {'coverage_prop': '0.951', 'intensity_prop': '0.668', 'ms1ms2_ratio': '1.299', 'efficiency': '0.349', 'TP': '152', 'FP': '42', 'FN': '10', 'precision': '0.784', 'recall': '0.938', 'f1': '0.854', 'total_rewards': 132.01871071632007, 'invalid_action_count': 2, 'num_ms1_scans': 722, 'num_ms2_scans': 556}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 70.72017277277641
# steps	 1000 	total rewards	 159.28984470400735
# Finished after 1387 timesteps (7.23987889289856 seconds) with total reward 213.53756465415898
# {'coverage_prop': '0.943', 'intensity_prop': '0.590', 'ms1ms2_ratio': '0.792', 'efficiency': '0.517', 'TP': '283', 'FP': '117', 'FN': '24', 'precision': '0.708', 'recall': '0.922', 'f1': '0.801', 'total_rewards': 213.53756465415915, 'invalid_action_count': 4, 'num_ms1_scans': 613, 'num_ms2_scans': 774}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 51.47161463359234
# steps	 1000 	total rewards	 145.90034403430866
# Finished after 1377 timesteps (6.141705274581909 seconds) with total reward 195.8950473004207
# {'coverage_prop': '0.956', 'intensity_prop': '0.610', 'ms1ms2_ratio': '0.826', 'efficiency': '0.487', 'TP': '265', 'FP': '102', 'FN': '17', 'precision': '0.722', 'recall': '0.940', 'f1': '0.817', 'total_rewards': 195.89504730042077, 'invalid_action_count': 5, 'num_ms1_scans': 623, 'num_ms2_scans': 754}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 60.35376246324345
# steps	 1000 	total rewards	 165.65849850626404
# Finished after 1426 timesteps (6.883770227432251 seconds) with total reward 224.637504045963
# {'coverage_prop': '0.941', 'intensity_prop': '0.588', 'ms1ms2_ratio': '0.674', 'efficiency': '0.489', 'TP': '287', 'FP': '130', 'FN': '26', 'precision': '0.688', 'recall': '0.917', 'f1': '0.786', 'total_rewards': 224.63750404596288, 'invalid_action_count': 6, 'num_ms1_scans': 574, 'num_ms2_scans': 852}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 51.74039134914369
# steps	 1000 	total rewards	 114.91850217097794
# Finished after 1300 timesteps (4.439317941665649 seconds) with total reward 138.62349813031128
# {'coverage_prop': '0.960', 'intensity_prop': '0.633', 'ms1ms2_ratio': '1.167', 'efficiency': '0.398', 'TP': '176', 'FP': '63', 'FN': '10', 'precision': '0.736', 'recall': '0.946', 'f1': '0.828', 'total_rewards': 138.6234981303112, 'invalid_action_count': 7, 'num_ms1_scans': 700, 'num_ms2_scans': 600}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 47.70049764889821
# steps	 1000 	total rewards	 117.96681066057991
# Finished after 1315 timesteps (6.578546047210693 seconds) with total reward 147.96764935003898
# {'coverage_prop': '0.944', 'intensity_prop': '0.587', 'ms1ms2_ratio': '1.091', 'efficiency': '0.377', 'TP': '163', 'FP': '74', 'FN': '14', 'precision': '0.688', 'recall': '0.921', 'f1': '0.787', 'total_rewards': 147.96764935003895, 'invalid_action_count': 2, 'num_ms1_scans': 686, 'num_ms2_scans': 629}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 47.07573194213594
# steps	 1000 	total rewards	 128.64765514711698
# Finished after 1363 timesteps (4.965074777603149 seconds) with total reward 172.15013129039642
# {'coverage_prop': '0.957', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.877', 'efficiency': '0.395', 'TP': '204', 'FP': '83', 'FN': '13', 'precision': '0.711', 'recall': '0.940', 'f1': '0.810', 'total_rewards': 172.1501312903964, 'invalid_action_count': 3, 'num_ms1_scans': 637, 'num_ms2_scans': 726}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 44.255812450090026
# steps	 1000 	total rewards	 107.32640806356831
# Finished after 1276 timesteps (5.263413906097412 seconds) with total reward 128.41050851768472
# {'coverage_prop': '0.942', 'intensity_prop': '0.618', 'ms1ms2_ratio': '1.312', 'efficiency': '0.351', 'TP': '142', 'FP': '52', 'FN': '12', 'precision': '0.732', 'recall': '0.922', 'f1': '0.816', 'total_rewards': 128.41050851768463, 'invalid_action_count': 1, 'num_ms1_scans': 724, 'num_ms2_scans': 552}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 52.53170740076085
# steps	 1000 	total rewards	 157.95718801627675
# Finished after 1385 timesteps (5.321837902069092 seconds) with total reward 209.35111008909516
# {'coverage_prop': '0.961', 'intensity_prop': '0.641', 'ms1ms2_ratio': '0.801', 'efficiency': '0.508', 'TP': '302', 'FP': '89', 'FN': '16', 'precision': '0.772', 'recall': '0.950', 'f1': '0.852', 'total_rewards': 209.35111008909536, 'invalid_action_count': 6, 'num_ms1_scans': 616, 'num_ms2_scans': 769}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.8756761660747
# steps	 1000 	total rewards	 173.25157151573273
# Finished after 1433 timesteps (8.173723220825195 seconds) with total reward 240.68379923532024
# {'coverage_prop': '0.956', 'intensity_prop': '0.615', 'ms1ms2_ratio': '0.657', 'efficiency': '0.550', 'TP': '359', 'FP': '117', 'FN': '22', 'precision': '0.754', 'recall': '0.942', 'f1': '0.838', 'total_rewards': 240.6837992353203, 'invalid_action_count': 7, 'num_ms1_scans': 568, 'num_ms2_scans': 865}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 62.25671629988035
# steps	 1000 	total rewards	 153.89015210022922
# Finished after 1356 timesteps (6.161221027374268 seconds) with total reward 195.9033716942203
# {'coverage_prop': '0.957', 'intensity_prop': '0.623', 'ms1ms2_ratio': '0.904', 'efficiency': '0.500', 'TP': '259', 'FP': '97', 'FN': '16', 'precision': '0.728', 'recall': '0.942', 'f1': '0.821', 'total_rewards': 195.90337169422017, 'invalid_action_count': 1, 'num_ms1_scans': 644, 'num_ms2_scans': 712}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.11971814087621
# steps	 1000 	total rewards	 127.8725137302063
# Finished after 1320 timesteps (6.290076971054077 seconds) with total reward 167.07825453090234
# {'coverage_prop': '0.967', 'intensity_prop': '0.619', 'ms1ms2_ratio': '1.062', 'efficiency': '0.456', 'TP': '213', 'FP': '79', 'FN': '10', 'precision': '0.729', 'recall': '0.955', 'f1': '0.827', 'total_rewards': 167.07825453090226, 'invalid_action_count': 3, 'num_ms1_scans': 680, 'num_ms2_scans': 640}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 45.57769272537776
# steps	 1000 	total rewards	 118.57596260209334
# Finished after 1300 timesteps (5.1986730098724365 seconds) with total reward 148.47198309905596
# {'coverage_prop': '0.977', 'intensity_prop': '0.600', 'ms1ms2_ratio': '1.170', 'efficiency': '0.432', 'TP': '168', 'FP': '91', 'FN': '6', 'precision': '0.649', 'recall': '0.966', 'f1': '0.776', 'total_rewards': 148.47198309905593, 'invalid_action_count': 6, 'num_ms1_scans': 701, 'num_ms2_scans': 599}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 65.55736803223962
# steps	 1000 	total rewards	 164.62296886403448
# Finished after 1419 timesteps (8.430296182632446 seconds) with total reward 223.77717379901088
# {'coverage_prop': '0.908', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.693', 'efficiency': '0.507', 'TP': '311', 'FP': '114', 'FN': '43', 'precision': '0.732', 'recall': '0.879', 'f1': '0.798', 'total_rewards': 223.77717379901085, 'invalid_action_count': 8, 'num_ms1_scans': 581, 'num_ms2_scans': 838}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 44.76961691958856
# steps	 1000 	total rewards	 109.44370339556707
# Finished after 1266 timesteps (4.813683271408081 seconds) with total reward 135.33051396018712
# {'coverage_prop': '0.944', 'intensity_prop': '0.624', 'ms1ms2_ratio': '1.384', 'efficiency': '0.416', 'TP': '158', 'FP': '63', 'FN': '13', 'precision': '0.715', 'recall': '0.924', 'f1': '0.806', 'total_rewards': 135.33051396018712, 'invalid_action_count': 3, 'num_ms1_scans': 735, 'num_ms2_scans': 531}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 53.97893559202411
# steps	 1000 	total rewards	 136.01652894803433
# Finished after 1334 timesteps (4.908194065093994 seconds) with total reward 176.34866999418034
# {'coverage_prop': '0.957', 'intensity_prop': '0.579', 'ms1ms2_ratio': '1.000', 'efficiency': '0.462', 'TP': '200', 'FP': '108', 'FN': '14', 'precision': '0.649', 'recall': '0.935', 'f1': '0.766', 'total_rewards': 176.34866999418009, 'invalid_action_count': 3, 'num_ms1_scans': 667, 'num_ms2_scans': 667}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 57.78955295958227
# steps	 1000 	total rewards	 138.44272590288827
# Finished after 1301 timesteps (6.189711093902588 seconds) with total reward 168.1331857009261
# {'coverage_prop': '0.948', 'intensity_prop': '0.618', 'ms1ms2_ratio': '1.161', 'efficiency': '0.488', 'TP': '220', 'FP': '74', 'FN': '16', 'precision': '0.748', 'recall': '0.932', 'f1': '0.830', 'total_rewards': 168.13318570092594, 'invalid_action_count': 2, 'num_ms1_scans': 699, 'num_ms2_scans': 602}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 61.297101495438525
# steps	 1000 	total rewards	 147.68827421232965
# Finished after 1358 timesteps (4.827507972717285 seconds) with total reward 197.14124650438725
# {'coverage_prop': '0.971', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.899', 'efficiency': '0.469', 'TP': '230', 'FP': '105', 'FN': '10', 'precision': '0.687', 'recall': '0.958', 'f1': '0.800', 'total_rewards': 197.14124650438742, 'invalid_action_count': 1, 'num_ms1_scans': 643, 'num_ms2_scans': 715}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 61.55184194844126
# steps	 1000 	total rewards	 150.5493815682549
# Finished after 1373 timesteps (7.094918966293335 seconds) with total reward 203.27142417242868
# {'coverage_prop': '0.977', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.840', 'efficiency': '0.519', 'TP': '286', 'FP': '101', 'FN': '9', 'precision': '0.739', 'recall': '0.969', 'f1': '0.839', 'total_rewards': 203.2714241724288, 'invalid_action_count': 2, 'num_ms1_scans': 627, 'num_ms2_scans': 746}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 37.6380587739148
# steps	 1000 	total rewards	 98.64924021946884
# Finished after 1260 timesteps (4.025564908981323 seconds) with total reward 119.35955595956563
# {'coverage_prop': '0.956', 'intensity_prop': '0.635', 'ms1ms2_ratio': '1.432', 'efficiency': '0.375', 'TP': '142', 'FP': '52', 'FN': '9', 'precision': '0.732', 'recall': '0.940', 'f1': '0.823', 'total_rewards': 119.3595559595656, 'invalid_action_count': 4, 'num_ms1_scans': 742, 'num_ms2_scans': 518}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 46.0297671283714
# steps	 1000 	total rewards	 121.361001962113
# Finished after 1282 timesteps (4.186538934707642 seconds) with total reward 147.6132404245804
# {'coverage_prop': '0.940', 'intensity_prop': '0.627', 'ms1ms2_ratio': '1.273', 'efficiency': '0.468', 'TP': '202', 'FP': '62', 'FN': '17', 'precision': '0.765', 'recall': '0.922', 'f1': '0.836', 'total_rewards': 147.61324042458045, 'invalid_action_count': 13, 'num_ms1_scans': 718, 'num_ms2_scans': 564}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 70.95348003273375
# steps	 1000 	total rewards	 163.37574594165451
# Finished after 1444 timesteps (7.719735860824585 seconds) with total reward 239.28319549034092
# {'coverage_prop': '0.929', 'intensity_prop': '0.579', 'ms1ms2_ratio': '0.628', 'efficiency': '0.516', 'TP': '321', 'FP': '137', 'FN': '35', 'precision': '0.701', 'recall': '0.902', 'f1': '0.789', 'total_rewards': 239.28319549034103, 'invalid_action_count': 10, 'num_ms1_scans': 557, 'num_ms2_scans': 887}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 57.41298644233876
# steps	 1000 	total rewards	 134.59473367475834
# Finished after 1313 timesteps (5.342900991439819 seconds) with total reward 168.14522961844705
# {'coverage_prop': '0.964', 'intensity_prop': '0.605', 'ms1ms2_ratio': '1.101', 'efficiency': '0.469', 'TP': '188', 'FP': '105', 'FN': '11', 'precision': '0.642', 'recall': '0.945', 'f1': '0.764', 'total_rewards': 168.14522961844716, 'invalid_action_count': 2, 'num_ms1_scans': 688, 'num_ms2_scans': 625}
#
# method = topN max_peaks = 200 N = 10 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 64.27897282132969
# steps	 1000 	total rewards	 153.0615418315449
# steps	 1500 	total rewards	 242.68506332538016
# Finished after 1722 timesteps (9.678985118865967 seconds) with total reward 274.39446443224483
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 274.39446443224455, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 56.53441275069887
# steps	 1000 	total rewards	 133.44353713101043
# steps	 1500 	total rewards	 194.26613921470476
# Finished after 1556 timesteps (8.088603258132935 seconds) with total reward 198.80142796822798
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 198.8014279682283, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 57.30827329618448
# steps	 1000 	total rewards	 142.16274804562107
# steps	 1500 	total rewards	 225.2837165391693
# Finished after 1670 timesteps (9.321026086807251 seconds) with total reward 246.21594099879326
# {'coverage_prop': '0.924', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.246', 'efficiency': '0.272', 'TP': '328', 'FP': '36', 'FN': '30', 'precision': '0.901', 'recall': '0.916', 'f1': '0.909', 'total_rewards': 246.21594099879346, 'invalid_action_count': 0, 'num_ms1_scans': 330, 'num_ms2_scans': 1340}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 71.12814612435277
# steps	 1000 	total rewards	 157.62727339419465
# steps	 1500 	total rewards	 238.78056886179576
# Finished after 1717 timesteps (11.679445028305054 seconds) with total reward 272.3235910501669
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 272.323591050167, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 61.90389809276462
# steps	 1000 	total rewards	 157.856811245934
# steps	 1500 	total rewards	 243.79212098759848
# Finished after 1704 timesteps (10.178401947021484 seconds) with total reward 273.0181148295186
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 273.0181148295187, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 39.896487753445214
# steps	 1000 	total rewards	 106.51412980303726
# Finished after 1410 timesteps (7.702270030975342 seconds) with total reward 142.9017997307617
# {'coverage_prop': '0.960', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.720', 'efficiency': '0.234', 'TP': '184', 'FP': '8', 'FN': '8', 'precision': '0.958', 'recall': '0.958', 'f1': '0.958', 'total_rewards': 142.90179973076172, 'invalid_action_count': 0, 'num_ms1_scans': 590, 'num_ms2_scans': 820}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.22043408731386
# steps	 1000 	total rewards	 162.04397467383103
# steps	 1500 	total rewards	 244.55745713793698
# Finished after 1744 timesteps (9.870798826217651 seconds) with total reward 280.3023687938845
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 280.3023687938843, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.49031082023858
# steps	 1000 	total rewards	 115.83126130267036
# Finished after 1472 timesteps (12.55096173286438 seconds) with total reward 162.78995135881587
# {'coverage_prop': '0.966', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '186', 'FP': '11', 'FN': '7', 'precision': '0.944', 'recall': '0.964', 'f1': '0.954', 'total_rewards': 162.78995135881573, 'invalid_action_count': 0, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 69.46621454358737
# steps	 1000 	total rewards	 149.00350104084623
# steps	 1500 	total rewards	 234.0142896045665
# Finished after 1736 timesteps (10.397439002990723 seconds) with total reward 265.5548286824893
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 265.5548286824895, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 56.81220021632257
# steps	 1000 	total rewards	 137.61714657475966
# steps	 1500 	total rewards	 219.6394324027019
# Finished after 1668 timesteps (9.279530048370361 seconds) with total reward 237.23755641721067
# {'coverage_prop': '0.924', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.249', 'efficiency': '0.266', 'TP': '324', 'FP': '31', 'FN': '29', 'precision': '0.913', 'recall': '0.918', 'f1': '0.915', 'total_rewards': 237.2375564172111, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 1336}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 63.48883485609902
# steps	 1000 	total rewards	 148.03351769555485
# steps	 1500 	total rewards	 236.5520895809973
# Finished after 1737 timesteps (10.18897294998169 seconds) with total reward 267.3066297171516
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 267.30662971715145, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 50.64739428018553
# steps	 1000 	total rewards	 120.53245139860438
# steps	 1500 	total rewards	 172.636404345169
# Finished after 1531 timesteps (9.370897054672241 seconds) with total reward 175.30046321087713
# {'coverage_prop': '0.960', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.442', 'efficiency': '0.225', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949', 'total_rewards': 175.30046321087715, 'invalid_action_count': 0, 'num_ms1_scans': 469, 'num_ms2_scans': 1062}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 48.92994799712743
# steps	 1000 	total rewards	 119.15118054204709
# steps	 1500 	total rewards	 182.89587058315783
# Finished after 1602 timesteps (11.547432899475098 seconds) with total reward 193.71596466215053
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 193.7159646621502, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 51.102405475232786
# steps	 1000 	total rewards	 126.40211968727175
# steps	 1500 	total rewards	 196.43919744732793
# Finished after 1645 timesteps (9.321415185928345 seconds) with total reward 210.5440874069469
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 210.544087406947, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 42.10725329655742
# steps	 1000 	total rewards	 109.41532611939553
# Finished after 1497 timesteps (7.721198797225952 seconds) with total reward 161.78234703648474
# {'coverage_prop': '0.951', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.197', 'TP': '181', 'FP': '15', 'FN': '10', 'precision': '0.923', 'recall': '0.948', 'f1': '0.935', 'total_rewards': 161.78234703648477, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 56.96509366792624
# steps	 1000 	total rewards	 147.2095569715228
# steps	 1500 	total rewards	 226.3392432649163
# Finished after 1655 timesteps (9.443418025970459 seconds) with total reward 248.9212535879875
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 248.92125358798705, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 71.46974393432068
# steps	 1000 	total rewards	 159.8630857893615
# steps	 1500 	total rewards	 249.45187485282867
# Finished after 1729 timesteps (9.940768003463745 seconds) with total reward 282.33596729180294
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 282.33596729180283, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 65.28295924656409
# steps	 1000 	total rewards	 152.99159947570973
# steps	 1500 	total rewards	 227.85174096808055
# Finished after 1681 timesteps (9.001901865005493 seconds) with total reward 248.71724564061213
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 248.71724564061182, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 50.80527834803058
# steps	 1000 	total rewards	 131.25379282029033
# steps	 1500 	total rewards	 201.63169124775385
# Finished after 1621 timesteps (11.4290189743042 seconds) with total reward 213.3962276951981
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 213.39622769519795, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 51.64710716074973
# steps	 1000 	total rewards	 127.8682486554507
# steps	 1500 	total rewards	 190.93867231139512
# Finished after 1634 timesteps (8.381057024002075 seconds) with total reward 206.05567977408612
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 206.05567977408612, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 70.50994950851643
# steps	 1000 	total rewards	 155.90074680539868
# steps	 1500 	total rewards	 237.04838387022266
# Finished after 1726 timesteps (10.063256025314331 seconds) with total reward 269.74024806514274
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 269.7402480651435, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 42.87532685800643
# steps	 1000 	total rewards	 117.43198314660418
# Finished after 1475 timesteps (8.070618152618408 seconds) with total reward 166.9084951701829
# {'coverage_prop': '0.957', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '207', 'FP': '17', 'FN': '10', 'precision': '0.924', 'recall': '0.954', 'f1': '0.939', 'total_rewards': 166.90849517018293, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 58.07428174764222
# steps	 1000 	total rewards	 137.84913832412306
# steps	 1500 	total rewards	 209.9889884762968
# Finished after 1636 timesteps (8.910018920898438 seconds) with total reward 225.08898203089467
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 225.08898203089467, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 59.55579530112928
# steps	 1000 	total rewards	 139.27168276735108
# steps	 1500 	total rewards	 204.99301908857169
# Finished after 1575 timesteps (11.165121078491211 seconds) with total reward 212.0487707936014
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 212.04877079360148, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 55.90621614718264
# steps	 1000 	total rewards	 142.4674826906643
# steps	 1500 	total rewards	 218.74431307077577
# Finished after 1681 timesteps (9.057594776153564 seconds) with total reward 241.10125347896678
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 241.10125347896698, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 58.65795180800854
# steps	 1000 	total rewards	 136.8820258148469
# steps	 1500 	total rewards	 223.03824969963966
# Finished after 1679 timesteps (9.3765549659729 seconds) with total reward 244.79886972933062
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 244.79886972933082, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 38.93346073831778
# steps	 1000 	total rewards	 108.52782812655937
# Finished after 1465 timesteps (7.565717935562134 seconds) with total reward 154.61028044060535
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 154.61028044060512, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 51.766444526594
# steps	 1000 	total rewards	 130.46357019586054
# steps	 1500 	total rewards	 197.67932911107744
# Finished after 1562 timesteps (8.135905027389526 seconds) with total reward 205.97957200278756
# {'coverage_prop': '0.964', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.390', 'efficiency': '0.241', 'TP': '252', 'FP': '19', 'FN': '10', 'precision': '0.930', 'recall': '0.962', 'f1': '0.946', 'total_rewards': 205.9795720027877, 'invalid_action_count': 0, 'num_ms1_scans': 438, 'num_ms2_scans': 1124}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 74.33673783003661
# steps	 1000 	total rewards	 151.64147482739267
# steps	 1500 	total rewards	 238.19314377272508
# Finished after 1749 timesteps (9.85535216331482 seconds) with total reward 277.638109251984
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 277.63810925198385, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 56.98398947393331
# steps	 1000 	total rewards	 133.73469321594888
# steps	 1500 	total rewards	 202.51030010488844
# Finished after 1657 timesteps (11.705193996429443 seconds) with total reward 218.42816542635472
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 218.42816542635472, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fde98966fd0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fde9969d670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fdebe0ba910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.492', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '208', 'FP': '199', 'FN': '19', 'precision': '0.511', 'recall': '0.916', 'f1': '0.656'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.473', 'efficiency': '0.748', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '104', 'FP': '86', 'FN': '10', 'precision': '0.547', 'recall': '0.912', 'f1': '0.684'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.122', 'efficiency': '0.736', 'TP': '261', 'FP': '193', 'FN': '24', 'precision': '0.575', 'recall': '0.916', 'f1': '0.706'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.524', 'ms1ms2_ratio': '3.321', 'efficiency': '0.737', 'TP': '114', 'FP': '79', 'FN': '11', 'precision': '0.591', 'recall': '0.912', 'f1': '0.717'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.490', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.218', 'efficiency': '0.732', 'TP': '242', 'FP': '184', 'FN': '17', 'precision': '0.568', 'recall': '0.934', 'f1': '0.707'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.479', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '109', 'FP': '128', 'FN': '14', 'precision': '0.460', 'recall': '0.886', 'f1': '0.606'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.493', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '96', 'FP': '98', 'FN': '12', 'precision': '0.495', 'recall': '0.889', 'f1': '0.636'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.548', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '217', 'FP': '176', 'FN': '14', 'precision': '0.552', 'recall': '0.939', 'f1': '0.696'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '276', 'FP': '205', 'FN': '17', 'precision': '0.574', 'recall': '0.942', 'f1': '0.713'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.542', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '265', 'FP': '181', 'FN': '22', 'precision': '0.594', 'recall': '0.923', 'f1': '0.723'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '1.995', 'efficiency': '0.761', 'TP': '160', 'FP': '145', 'FN': '17', 'precision': '0.525', 'recall': '0.904', 'f1': '0.664'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.472', 'ms1ms2_ratio': '2.154', 'efficiency': '0.772', 'TP': '135', 'FP': '156', 'FN': '19', 'precision': '0.464', 'recall': '0.877', 'f1': '0.607'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.250', 'efficiency': '0.739', 'TP': '146', 'FP': '123', 'FN': '12', 'precision': '0.543', 'recall': '0.924', 'f1': '0.684'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.514', 'ms1ms2_ratio': '2.002', 'efficiency': '0.725', 'TP': '152', 'FP': '138', 'FN': '14', 'precision': '0.524', 'recall': '0.916', 'f1': '0.667'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1886.305997                1916.0          0.308           0.076
# 1  random   -1920.834680                1941.0          0.206           0.045
# 2  random   -1809.045622                1867.0          0.454           0.100
# 3  random   -1821.851747                1871.0          0.365           0.090
# 4  random   -1858.890881                1895.0          0.311           0.085
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.003       0.066      0.183   0.075  0.107
# 1          0.005       0.027      0.148   0.037  0.059
# 2          0.005       0.090      0.184   0.133  0.155
# 3          0.007       0.084      0.218   0.111  0.148
# 4          0.005       0.069      0.250   0.101  0.144

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     220.588554                   6.0          0.948           0.600
# 31    DQN     158.174262                   3.0          0.954           0.617
# 32    DQN     203.765579                   6.0          0.949           0.600
# 33    DQN     227.536443                   2.0          0.945           0.616
# 34    DQN     220.659952                   3.0          0.968           0.616
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.753       0.506      0.720   0.930  0.812
# 31          1.082       0.396      0.740   0.939  0.828
# 32          0.892       0.520      0.703   0.929  0.801
# 33          0.732       0.526      0.759   0.928  0.835
# 34          0.776       0.540      0.716   0.956  0.819

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
