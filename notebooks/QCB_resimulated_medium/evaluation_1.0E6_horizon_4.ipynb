# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-19 23:25:55.228 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb6d1d4cd00>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb6d791c6d0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb6d7939970>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'exclusion_t0': 5,
#    'exclusion_t1': 120,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb6d1d4cd00>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb6d791c6d0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb6d7939970>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb6d1d4cd00>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb6d791c6d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb6d7939970>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['exclusion_t0'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d exclusion_t0 = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['exclusion_t0'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -491.60034493464025
# steps	 1000 	total rewards	 -960.1989017555609
# steps	 1500 	total rewards	 -1371.4136156879292
# Finished after 1990 timesteps (4.542897939682007 seconds) with total reward -1804.7092959748056
# {'coverage_prop': '0.423', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.005', 'efficiency': '0.091', 'TP': '32', 'FP': '148', 'FN': '246', 'precision': '0.178', 'recall': '0.115', 'f1': '0.140', 'total_rewards': -1804.7092959748059, 'invalid_action_count': 1860, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -485.97811813638805
# steps	 1000 	total rewards	 -980.4285577204384
# steps	 1500 	total rewards	 -1453.9508642316841
# Finished after 1992 timesteps (2.831663131713867 seconds) with total reward -1918.5620971469707
# {'coverage_prop': '0.218', 'intensity_prop': '0.045', 'ms1ms2_ratio': '0.004', 'efficiency': '0.029', 'TP': '11', 'FP': '46', 'FN': '205', 'precision': '0.193', 'recall': '0.051', 'f1': '0.081', 'total_rewards': -1918.5620971469707, 'invalid_action_count': 1940, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -485.5368598031498
# steps	 1000 	total rewards	 -950.1984200596778
# steps	 1500 	total rewards	 -1399.260981738893
# Finished after 1986 timesteps (3.730501174926758 seconds) with total reward -1820.730724107317
# {'coverage_prop': '0.383', 'intensity_prop': '0.092', 'ms1ms2_ratio': '0.007', 'efficiency': '0.077', 'TP': '29', 'FP': '122', 'FN': '243', 'precision': '0.192', 'recall': '0.107', 'f1': '0.137', 'total_rewards': -1820.730724107317, 'invalid_action_count': 1866, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -963.5235418809859
# steps	 1500 	total rewards	 -1427.5216915678575
# Finished after 1994 timesteps (3.7408361434936523 seconds) with total reward -1882.9558343809542
# {'coverage_prop': '0.288', 'intensity_prop': '0.069', 'ms1ms2_ratio': '0.003', 'efficiency': '0.065', 'TP': '29', 'FP': '101', 'FN': '322', 'precision': '0.223', 'recall': '0.083', 'f1': '0.121', 'total_rewards': -1882.9558343809542, 'invalid_action_count': 1917, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -479.5897461502028
# steps	 1000 	total rewards	 -944.80640697119
# steps	 1500 	total rewards	 -1376.8580858174319
# Finished after 1989 timesteps (3.9089038372039795 seconds) with total reward -1830.71168662506
# {'coverage_prop': '0.375', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.006', 'efficiency': '0.083', 'TP': '33', 'FP': '131', 'FN': '273', 'precision': '0.201', 'recall': '0.108', 'f1': '0.140', 'total_rewards': -1830.7116866250606, 'invalid_action_count': 1879, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -479.5201563885993
# steps	 1000 	total rewards	 -939.8513835252518
# steps	 1500 	total rewards	 -1401.8450586178758
# Finished after 1979 timesteps (2.347884178161621 seconds) with total reward -1858.0105240086195
# {'coverage_prop': '0.470', 'intensity_prop': '0.151', 'ms1ms2_ratio': '0.011', 'efficiency': '0.048', 'TP': '26', 'FP': '68', 'FN': '106', 'precision': '0.277', 'recall': '0.197', 'f1': '0.230', 'total_rewards': -1858.0105240086193, 'invalid_action_count': 1890, 'num_ms1_scans': 21, 'num_ms2_scans': 1958}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -495.7872310928866
# steps	 1000 	total rewards	 -922.137615166619
# steps	 1500 	total rewards	 -1377.5876197554726
# Finished after 1990 timesteps (4.194084167480469 seconds) with total reward -1819.8678338958562
# {'coverage_prop': '0.356', 'intensity_prop': '0.082', 'ms1ms2_ratio': '0.005', 'efficiency': '0.086', 'TP': '35', 'FP': '135', 'FN': '308', 'precision': '0.206', 'recall': '0.102', 'f1': '0.136', 'total_rewards': -1819.867833895856, 'invalid_action_count': 1873, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -491.17809859303225
# steps	 1000 	total rewards	 -960.1430599348682
# steps	 1500 	total rewards	 -1425.8334213229123
# Finished after 1988 timesteps (2.859354257583618 seconds) with total reward -1888.5391980307202
# {'coverage_prop': '0.333', 'intensity_prop': '0.106', 'ms1ms2_ratio': '0.006', 'efficiency': '0.034', 'TP': '20', 'FP': '48', 'FN': '136', 'precision': '0.294', 'recall': '0.128', 'f1': '0.179', 'total_rewards': -1888.53919803072, 'invalid_action_count': 1916, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -475.52027480578226
# steps	 1000 	total rewards	 -936.2686428541695
# steps	 1500 	total rewards	 -1389.529473592711
# Finished after 1986 timesteps (3.883371114730835 seconds) with total reward -1812.9566092785603
# {'coverage_prop': '0.366', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.007', 'efficiency': '0.079', 'TP': '33', 'FP': '122', 'FN': '269', 'precision': '0.213', 'recall': '0.109', 'f1': '0.144', 'total_rewards': -1812.9566092785594, 'invalid_action_count': 1864, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -490.7267338393635
# steps	 1000 	total rewards	 -943.938979811953
# steps	 1500 	total rewards	 -1383.2070483507373
# Finished after 1988 timesteps (3.7026491165161133 seconds) with total reward -1839.3468092722305
# {'coverage_prop': '0.352', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.006', 'efficiency': '0.068', 'TP': '43', 'FP': '92', 'FN': '249', 'precision': '0.319', 'recall': '0.147', 'f1': '0.201', 'total_rewards': -1839.3468092722305, 'invalid_action_count': 1883, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -482.71133448039467
# steps	 1000 	total rewards	 -918.0841762261725
# steps	 1500 	total rewards	 -1332.7253284275794
# Finished after 1990 timesteps (3.946974039077759 seconds) with total reward -1776.7420960723384
# {'coverage_prop': '0.447', 'intensity_prop': '0.125', 'ms1ms2_ratio': '0.005', 'efficiency': '0.100', 'TP': '51', 'FP': '147', 'FN': '245', 'precision': '0.258', 'recall': '0.172', 'f1': '0.206', 'total_rewards': -1776.742096072338, 'invalid_action_count': 1836, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -492.28059971315025
# steps	 1000 	total rewards	 -963.9922615821088
# steps	 1500 	total rewards	 -1447.8866797831329
# Finished after 1991 timesteps (2.5968360900878906 seconds) with total reward -1911.9286907869287
# {'coverage_prop': '0.261', 'intensity_prop': '0.049', 'ms1ms2_ratio': '0.005', 'efficiency': '0.033', 'TP': '9', 'FP': '56', 'FN': '184', 'precision': '0.138', 'recall': '0.047', 'f1': '0.070', 'total_rewards': -1911.9286907869287, 'invalid_action_count': 1934, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -481.1673702640163
# steps	 1000 	total rewards	 -952.8354831466994
# steps	 1500 	total rewards	 -1396.1504301182804
# Finished after 1990 timesteps (3.2180490493774414 seconds) with total reward -1852.0966710086298
# {'coverage_prop': '0.422', 'intensity_prop': '0.128', 'ms1ms2_ratio': '0.005', 'efficiency': '0.054', 'TP': '31', 'FP': '75', 'FN': '145', 'precision': '0.292', 'recall': '0.176', 'f1': '0.220', 'total_rewards': -1852.0966710086298, 'invalid_action_count': 1892, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -482.2720588723514
# steps	 1000 	total rewards	 -968.7644747885604
# steps	 1500 	total rewards	 -1397.7414064852683
# Finished after 1984 timesteps (3.1912341117858887 seconds) with total reward -1819.1284922613431
# {'coverage_prop': '0.450', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.008', 'efficiency': '0.069', 'TP': '34', 'FP': '101', 'FN': '165', 'precision': '0.252', 'recall': '0.171', 'f1': '0.204', 'total_rewards': -1819.1284922613434, 'invalid_action_count': 1864, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -493.34273164493675
# steps	 1000 	total rewards	 -958.2585016091647
# steps	 1500 	total rewards	 -1407.4656778757007
# Finished after 1986 timesteps (2.4284636974334717 seconds) with total reward -1872.0958800043863
# {'coverage_prop': '0.369', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.007', 'efficiency': '0.039', 'TP': '17', 'FP': '59', 'FN': '130', 'precision': '0.224', 'recall': '0.116', 'f1': '0.152', 'total_rewards': -1872.0958800043863, 'invalid_action_count': 1903, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -498.0
# steps	 1000 	total rewards	 -958.2374540847392
# steps	 1500 	total rewards	 -1415.5812883964466
# Finished after 1990 timesteps (3.7372241020202637 seconds) with total reward -1867.636663024283
# {'coverage_prop': '0.324', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.005', 'efficiency': '0.067', 'TP': '27', 'FP': '105', 'FN': '275', 'precision': '0.205', 'recall': '0.089', 'f1': '0.124', 'total_rewards': -1867.6366630242837, 'invalid_action_count': 1904, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -475.9524101474334
# steps	 1000 	total rewards	 -963.0168396993242
# steps	 1500 	total rewards	 -1402.7389129760923
# Finished after 1989 timesteps (4.006132125854492 seconds) with total reward -1823.0266365312823
# {'coverage_prop': '0.353', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.006', 'efficiency': '0.089', 'TP': '50', 'FP': '126', 'FN': '322', 'precision': '0.284', 'recall': '0.134', 'f1': '0.182', 'total_rewards': -1823.0266365312823, 'invalid_action_count': 1871, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -471.03024978442187
# steps	 1000 	total rewards	 -924.2687746980096
# steps	 1500 	total rewards	 -1388.931603437516
# Finished after 1990 timesteps (3.577747106552124 seconds) with total reward -1823.2606309932166
# {'coverage_prop': '0.387', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.005', 'efficiency': '0.073', 'TP': '28', 'FP': '116', 'FN': '228', 'precision': '0.194', 'recall': '0.109', 'f1': '0.140', 'total_rewards': -1823.2606309932173, 'invalid_action_count': 1872, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -489.01777820007266
# steps	 1000 	total rewards	 -985.4740256463672
# steps	 1500 	total rewards	 -1438.392958946612
# Finished after 1990 timesteps (3.0917019844055176 seconds) with total reward -1892.5302340458861
# {'coverage_prop': '0.281', 'intensity_prop': '0.063', 'ms1ms2_ratio': '0.005', 'efficiency': '0.043', 'TP': '17', 'FP': '68', 'FN': '217', 'precision': '0.200', 'recall': '0.073', 'f1': '0.107', 'total_rewards': -1892.5302340458852, 'invalid_action_count': 1921, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -487.02108295728965
# steps	 1000 	total rewards	 -952.9333254719138
# steps	 1500 	total rewards	 -1420.818746349293
# Finished after 1987 timesteps (2.992637872695923 seconds) with total reward -1866.4483278311739
# {'coverage_prop': '0.332', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.007', 'efficiency': '0.045', 'TP': '21', 'FP': '67', 'FN': '177', 'precision': '0.239', 'recall': '0.106', 'f1': '0.147', 'total_rewards': -1866.4483278311734, 'invalid_action_count': 1902, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -487.9642760467433
# steps	 1000 	total rewards	 -915.2246319659992
# steps	 1500 	total rewards	 -1381.9224229485199
# Finished after 1992 timesteps (4.56452488899231 seconds) with total reward -1834.3740885054608
# {'coverage_prop': '0.316', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.004', 'efficiency': '0.075', 'TP': '39', 'FP': '109', 'FN': '320', 'precision': '0.264', 'recall': '0.109', 'f1': '0.154', 'total_rewards': -1834.3740885054603, 'invalid_action_count': 1882, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -487.98361650053903
# steps	 1000 	total rewards	 -975.0215135839959
# steps	 1500 	total rewards	 -1440.955867531873
# Finished after 1988 timesteps (2.603114128112793 seconds) with total reward -1907.7509666924725
# {'coverage_prop': '0.308', 'intensity_prop': '0.048', 'ms1ms2_ratio': '0.006', 'efficiency': '0.036', 'TP': '9', 'FP': '63', 'FN': '162', 'precision': '0.125', 'recall': '0.053', 'f1': '0.074', 'total_rewards': -1907.7509666924725, 'invalid_action_count': 1931, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -482.7144843056958
# steps	 1000 	total rewards	 -949.3928455350467
# steps	 1500 	total rewards	 -1374.587504170474
# Finished after 1988 timesteps (4.052227973937988 seconds) with total reward -1831.8896815749947
# {'coverage_prop': '0.404', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.006', 'efficiency': '0.066', 'TP': '31', 'FP': '99', 'FN': '192', 'precision': '0.238', 'recall': '0.139', 'f1': '0.176', 'total_rewards': -1831.8896815749956, 'invalid_action_count': 1877, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -984.8653220727138
# steps	 1500 	total rewards	 -1424.4629221173366
# Finished after 1991 timesteps (2.8318960666656494 seconds) with total reward -1885.3933637481268
# {'coverage_prop': '0.287', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.005', 'efficiency': '0.045', 'TP': '21', 'FP': '68', 'FN': '221', 'precision': '0.236', 'recall': '0.087', 'f1': '0.127', 'total_rewards': -1885.3933637481277, 'invalid_action_count': 1916, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -975.8836441130275
# steps	 1500 	total rewards	 -1394.714440337853
# Finished after 1992 timesteps (3.516819953918457 seconds) with total reward -1852.6953859472503
# {'coverage_prop': '0.357', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.004', 'efficiency': '0.062', 'TP': '31', 'FP': '92', 'FN': '222', 'precision': '0.252', 'recall': '0.123', 'f1': '0.165', 'total_rewards': -1852.695385947251, 'invalid_action_count': 1895, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -483.6253001688982
# steps	 1000 	total rewards	 -931.8115446343286
# steps	 1500 	total rewards	 -1385.8061388538094
# Finished after 1991 timesteps (3.7299022674560547 seconds) with total reward -1839.7766823528884
# {'coverage_prop': '0.394', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.005', 'efficiency': '0.079', 'TP': '33', 'FP': '123', 'FN': '240', 'precision': '0.212', 'recall': '0.121', 'f1': '0.154', 'total_rewards': -1839.7766823528877, 'invalid_action_count': 1889, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -493.7663065432723
# steps	 1000 	total rewards	 -968.7932792579118
# steps	 1500 	total rewards	 -1445.323636054296
# Finished after 1990 timesteps (2.5427749156951904 seconds) with total reward -1913.4657119561052
# {'coverage_prop': '0.335', 'intensity_prop': '0.069', 'ms1ms2_ratio': '0.005', 'efficiency': '0.034', 'TP': '11', 'FP': '57', 'FN': '135', 'precision': '0.162', 'recall': '0.075', 'f1': '0.103', 'total_rewards': -1913.4657119561057, 'invalid_action_count': 1936, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -494.7403317916205
# steps	 1000 	total rewards	 -986.4008371466123
# steps	 1500 	total rewards	 -1451.468344685627
# Finished after 1991 timesteps (2.588656187057495 seconds) with total reward -1915.6911917726418
# {'coverage_prop': '0.214', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.005', 'efficiency': '0.030', 'TP': '15', 'FP': '45', 'FN': '221', 'precision': '0.250', 'recall': '0.064', 'f1': '0.101', 'total_rewards': -1915.691191772642, 'invalid_action_count': 1938, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -470.13698922650434
# steps	 1000 	total rewards	 -914.3950359770768
# steps	 1500 	total rewards	 -1325.845449879825
# Finished after 1983 timesteps (4.9494102001190186 seconds) with total reward -1730.9568279121322
# {'coverage_prop': '0.452', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.009', 'efficiency': '0.113', 'TP': '68', 'FP': '155', 'FN': '270', 'precision': '0.305', 'recall': '0.201', 'f1': '0.242', 'total_rewards': -1730.9568279121318, 'invalid_action_count': 1803, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -485.6513809578332
# steps	 1000 	total rewards	 -941.9370174788739
# steps	 1500 	total rewards	 -1387.3114928904297
# Finished after 1985 timesteps (3.149799108505249 seconds) with total reward -1842.1791233951149
# {'coverage_prop': '0.391', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.008', 'efficiency': '0.060', 'TP': '29', 'FP': '90', 'FN': '185', 'precision': '0.244', 'recall': '0.136', 'f1': '0.174', 'total_rewards': -1842.1791233951153, 'invalid_action_count': 1884, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# method = DQN max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.64GB > 0.40GB
# steps	 500 	total rewards	 62.77963199957691
# steps	 1000 	total rewards	 153.27514853397463
# Finished after 1339 timesteps (6.439269781112671 seconds) with total reward 200.1520633943034
# {'coverage_prop': '0.906', 'intensity_prop': '0.568', 'ms1ms2_ratio': '0.978', 'efficiency': '0.570', 'TP': '271', 'FP': '115', 'FN': '40', 'precision': '0.702', 'recall': '0.871', 'f1': '0.778', 'total_rewards': 200.15206339430335, 'invalid_action_count': 4, 'num_ms1_scans': 662, 'num_ms2_scans': 677}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 54.405340012154085
# steps	 1000 	total rewards	 122.56457884298457
# Finished after 1317 timesteps (5.310781955718994 seconds) with total reward 151.55624922687167
# {'coverage_prop': '0.927', 'intensity_prop': '0.644', 'ms1ms2_ratio': '1.077', 'efficiency': '0.383', 'TP': '199', 'FP': '44', 'FN': '19', 'precision': '0.819', 'recall': '0.913', 'f1': '0.863', 'total_rewards': 151.5562492268717, 'invalid_action_count': 8, 'num_ms1_scans': 683, 'num_ms2_scans': 634}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 51.388186023858744
# steps	 1000 	total rewards	 140.4296719966871
# Finished after 1313 timesteps (6.533182859420776 seconds) with total reward 180.3405088932077
# {'coverage_prop': '0.898', 'intensity_prop': '0.583', 'ms1ms2_ratio': '1.097', 'efficiency': '0.565', 'TP': '257', 'FP': '97', 'FN': '40', 'precision': '0.726', 'recall': '0.865', 'f1': '0.790', 'total_rewards': 180.34050889320767, 'invalid_action_count': 9, 'num_ms1_scans': 687, 'num_ms2_scans': 626}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 60.822900647459456
# steps	 1000 	total rewards	 150.20254179382462
# Finished after 1345 timesteps (6.12305474281311 seconds) with total reward 197.48211707081987
# {'coverage_prop': '0.900', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.952', 'efficiency': '0.591', 'TP': '313', 'FP': '94', 'FN': '45', 'precision': '0.769', 'recall': '0.874', 'f1': '0.818', 'total_rewards': 197.48211707081975, 'invalid_action_count': 10, 'num_ms1_scans': 656, 'num_ms2_scans': 689}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 55.46433081446992
# steps	 1000 	total rewards	 143.6360172348954
# Finished after 1354 timesteps (6.596234083175659 seconds) with total reward 190.59869012277858
# {'coverage_prop': '0.929', 'intensity_prop': '0.604', 'ms1ms2_ratio': '0.912', 'efficiency': '0.573', 'TP': '296', 'FP': '110', 'FN': '31', 'precision': '0.729', 'recall': '0.905', 'f1': '0.808', 'total_rewards': 190.59869012277872, 'invalid_action_count': 16, 'num_ms1_scans': 646, 'num_ms2_scans': 708}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 38.20678167598979
# steps	 1000 	total rewards	 95.82322547877719
# Finished after 1278 timesteps (5.078250885009766 seconds) with total reward 121.04445171914557
# {'coverage_prop': '0.950', 'intensity_prop': '0.698', 'ms1ms2_ratio': '1.299', 'efficiency': '0.342', 'TP': '164', 'FP': '26', 'FN': '10', 'precision': '0.863', 'recall': '0.943', 'f1': '0.901', 'total_rewards': 121.04445171914557, 'invalid_action_count': 6, 'num_ms1_scans': 722, 'num_ms2_scans': 556}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 71.47664749256508
# steps	 1000 	total rewards	 156.70427813795823
# Finished after 1362 timesteps (7.662668704986572 seconds) with total reward 207.4086471199211
# {'coverage_prop': '0.900', 'intensity_prop': '0.576', 'ms1ms2_ratio': '0.884', 'efficiency': '0.595', 'TP': '313', 'FP': '117', 'FN': '48', 'precision': '0.728', 'recall': '0.867', 'f1': '0.791', 'total_rewards': 207.40864711992143, 'invalid_action_count': 13, 'num_ms1_scans': 639, 'num_ms2_scans': 723}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 40.02283787505471
# steps	 1000 	total rewards	 106.17411401499717
# Finished after 1297 timesteps (4.377890110015869 seconds) with total reward 135.28109065078394
# {'coverage_prop': '0.941', 'intensity_prop': '0.627', 'ms1ms2_ratio': '1.184', 'efficiency': '0.323', 'TP': '149', 'FP': '43', 'FN': '12', 'precision': '0.776', 'recall': '0.925', 'f1': '0.844', 'total_rewards': 135.28109065078385, 'invalid_action_count': 5, 'num_ms1_scans': 703, 'num_ms2_scans': 594}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 66.03224446274409
# steps	 1000 	total rewards	 148.38324237087724
# Finished after 1338 timesteps (7.490652084350586 seconds) with total reward 194.55838487988078
# {'coverage_prop': '0.908', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.979', 'efficiency': '0.570', 'TP': '272', 'FP': '113', 'FN': '39', 'precision': '0.706', 'recall': '0.875', 'f1': '0.782', 'total_rewards': 194.5583848798809, 'invalid_action_count': 7, 'num_ms1_scans': 662, 'num_ms2_scans': 676}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 56.28280972205221
# steps	 1000 	total rewards	 146.18455211225375
# Finished after 1325 timesteps (7.221014022827148 seconds) with total reward 180.2172560726438
# {'coverage_prop': '0.930', 'intensity_prop': '0.608', 'ms1ms2_ratio': '1.038', 'efficiency': '0.549', 'TP': '264', 'FP': '93', 'FN': '27', 'precision': '0.739', 'recall': '0.907', 'f1': '0.815', 'total_rewards': 180.2172560726439, 'invalid_action_count': 6, 'num_ms1_scans': 675, 'num_ms2_scans': 650}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 58.24828407285682
# steps	 1000 	total rewards	 146.1552087340016
# Finished after 1371 timesteps (6.208268165588379 seconds) with total reward 195.2833356570718
# {'coverage_prop': '0.898', 'intensity_prop': '0.583', 'ms1ms2_ratio': '0.850', 'efficiency': '0.537', 'TP': '295', 'FP': '103', 'FN': '45', 'precision': '0.741', 'recall': '0.868', 'f1': '0.799', 'total_rewards': 195.28333565707206, 'invalid_action_count': 16, 'num_ms1_scans': 630, 'num_ms2_scans': 741}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 47.41567686075924
# steps	 1000 	total rewards	 105.54381450648151
# Finished after 1312 timesteps (6.2117180824279785 seconds) with total reward 134.02397847220885
# {'coverage_prop': '0.948', 'intensity_prop': '0.666', 'ms1ms2_ratio': '1.106', 'efficiency': '0.379', 'TP': '192', 'FP': '44', 'FN': '13', 'precision': '0.814', 'recall': '0.937', 'f1': '0.871', 'total_rewards': 134.02397847220897, 'invalid_action_count': 13, 'num_ms1_scans': 689, 'num_ms2_scans': 623}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 47.07844848588493
# steps	 1000 	total rewards	 118.15108961739148
# Finished after 1313 timesteps (5.217801809310913 seconds) with total reward 148.12320788710633
# {'coverage_prop': '0.940', 'intensity_prop': '0.612', 'ms1ms2_ratio': '1.097', 'efficiency': '0.377', 'TP': '168', 'FP': '68', 'FN': '15', 'precision': '0.712', 'recall': '0.918', 'f1': '0.802', 'total_rewards': 148.12320788710625, 'invalid_action_count': 3, 'num_ms1_scans': 687, 'num_ms2_scans': 626}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 45.743418079256074
# steps	 1000 	total rewards	 122.81197233699311
# Finished after 1331 timesteps (7.194972038269043 seconds) with total reward 158.86726206640066
# {'coverage_prop': '0.923', 'intensity_prop': '0.592', 'ms1ms2_ratio': '1.014', 'efficiency': '0.419', 'TP': '203', 'FP': '74', 'FN': '23', 'precision': '0.733', 'recall': '0.898', 'f1': '0.807', 'total_rewards': 158.86726206640046, 'invalid_action_count': 3, 'num_ms1_scans': 670, 'num_ms2_scans': 661}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 44.290677925237375
# steps	 1000 	total rewards	 110.77371136576856
# Finished after 1319 timesteps (4.9263129234313965 seconds) with total reward 134.8515611433844
# {'coverage_prop': '0.937', 'intensity_prop': '0.600', 'ms1ms2_ratio': '1.071', 'efficiency': '0.303', 'TP': '140', 'FP': '53', 'FN': '13', 'precision': '0.725', 'recall': '0.915', 'f1': '0.809', 'total_rewards': 134.85156114338432, 'invalid_action_count': 3, 'num_ms1_scans': 682, 'num_ms2_scans': 637}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 57.1941479909799
# steps	 1000 	total rewards	 149.8759432299789
# Finished after 1332 timesteps (7.851078033447266 seconds) with total reward 191.03097443749968
# {'coverage_prop': '0.936', 'intensity_prop': '0.614', 'ms1ms2_ratio': '1.006', 'efficiency': '0.574', 'TP': '270', 'FP': '111', 'FN': '26', 'precision': '0.709', 'recall': '0.912', 'f1': '0.798', 'total_rewards': 191.03097443749976, 'invalid_action_count': 7, 'num_ms1_scans': 668, 'num_ms2_scans': 664}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 69.44582615325412
# steps	 1000 	total rewards	 162.5833155204672
# Finished after 1381 timesteps (6.600465774536133 seconds) with total reward 220.8970056267533
# {'coverage_prop': '0.908', 'intensity_prop': '0.600', 'ms1ms2_ratio': '0.812', 'efficiency': '0.593', 'TP': '340', 'FP': '112', 'FN': '46', 'precision': '0.752', 'recall': '0.881', 'f1': '0.811', 'total_rewards': 220.8970056267532, 'invalid_action_count': 11, 'num_ms1_scans': 619, 'num_ms2_scans': 762}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 64.03264426406594
# steps	 1000 	total rewards	 148.8012359715905
# Finished after 1319 timesteps (6.036912202835083 seconds) with total reward 184.60816595652517
# {'coverage_prop': '0.925', 'intensity_prop': '0.613', 'ms1ms2_ratio': '1.067', 'efficiency': '0.539', 'TP': '264', 'FP': '80', 'FN': '28', 'precision': '0.767', 'recall': '0.904', 'f1': '0.830', 'total_rewards': 184.60816595652497, 'invalid_action_count': 3, 'num_ms1_scans': 681, 'num_ms2_scans': 638}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 49.53786807363737
# steps	 1000 	total rewards	 124.35915057544236
# Finished after 1309 timesteps (5.463959693908691 seconds) with total reward 165.5507437453444
# {'coverage_prop': '0.950', 'intensity_prop': '0.625', 'ms1ms2_ratio': '1.118', 'efficiency': '0.464', 'TP': '210', 'FP': '77', 'FN': '15', 'precision': '0.732', 'recall': '0.933', 'f1': '0.820', 'total_rewards': 165.5507437453443, 'invalid_action_count': 3, 'num_ms1_scans': 691, 'num_ms2_scans': 618}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 48.05823035139554
# steps	 1000 	total rewards	 116.18511913796426
# Finished after 1323 timesteps (5.177879095077515 seconds) with total reward 148.40541276642065
# {'coverage_prop': '0.958', 'intensity_prop': '0.630', 'ms1ms2_ratio': '1.048', 'efficiency': '0.393', 'TP': '186', 'FP': '68', 'FN': '11', 'precision': '0.732', 'recall': '0.944', 'f1': '0.825', 'total_rewards': 148.40541276642057, 'invalid_action_count': 7, 'num_ms1_scans': 677, 'num_ms2_scans': 646}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 67.135991420166
# steps	 1000 	total rewards	 139.748645360129
# Finished after 1365 timesteps (8.767112970352173 seconds) with total reward 185.09941785002133
# {'coverage_prop': '0.870', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.872', 'efficiency': '0.558', 'TP': '312', 'FP': '95', 'FN': '61', 'precision': '0.767', 'recall': '0.836', 'f1': '0.800', 'total_rewards': 185.09941785002144, 'invalid_action_count': 27, 'num_ms1_scans': 636, 'num_ms2_scans': 729}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 41.62890950236406
# steps	 1000 	total rewards	 109.34207364629441
# Finished after 1281 timesteps (4.752717733383179 seconds) with total reward 134.38206920426285
# {'coverage_prop': '0.923', 'intensity_prop': '0.634', 'ms1ms2_ratio': '1.279', 'efficiency': '0.384', 'TP': '165', 'FP': '51', 'FN': '18', 'precision': '0.764', 'recall': '0.902', 'f1': '0.827', 'total_rewards': 134.38206920426285, 'invalid_action_count': 4, 'num_ms1_scans': 719, 'num_ms2_scans': 562}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 52.993615354264364
# steps	 1000 	total rewards	 133.43151047699928
# Finished after 1317 timesteps (5.3934080600738525 seconds) with total reward 167.98851607495675
# {'coverage_prop': '0.932', 'intensity_prop': '0.622', 'ms1ms2_ratio': '1.077', 'efficiency': '0.473', 'TP': '230', 'FP': '70', 'FN': '22', 'precision': '0.767', 'recall': '0.913', 'f1': '0.833', 'total_rewards': 167.9885160749568, 'invalid_action_count': 7, 'num_ms1_scans': 683, 'num_ms2_scans': 634}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 56.900772666771644
# steps	 1000 	total rewards	 135.92914545658806
# Finished after 1291 timesteps (6.67135214805603 seconds) with total reward 161.72181218431408
# {'coverage_prop': '0.942', 'intensity_prop': '0.640', 'ms1ms2_ratio': '1.218', 'efficiency': '0.502', 'TP': '221', 'FP': '71', 'FN': '18', 'precision': '0.757', 'recall': '0.925', 'f1': '0.832', 'total_rewards': 161.72181218431402, 'invalid_action_count': 7, 'num_ms1_scans': 709, 'num_ms2_scans': 582}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 53.943231069743746
# steps	 1000 	total rewards	 131.11473190173876
# Finished after 1326 timesteps (5.803301095962524 seconds) with total reward 177.59231083117209
# {'coverage_prop': '0.925', 'intensity_prop': '0.594', 'ms1ms2_ratio': '1.034', 'efficiency': '0.489', 'TP': '239', 'FP': '80', 'FN': '26', 'precision': '0.749', 'recall': '0.902', 'f1': '0.818', 'total_rewards': 177.59231083117214, 'invalid_action_count': 8, 'num_ms1_scans': 674, 'num_ms2_scans': 652}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 61.429985218386705
# steps	 1000 	total rewards	 141.41910773231308
# Finished after 1327 timesteps (8.153594732284546 seconds) with total reward 186.27248936800493
# {'coverage_prop': '0.942', 'intensity_prop': '0.611', 'ms1ms2_ratio': '1.029', 'efficiency': '0.570', 'TP': '272', 'FP': '101', 'FN': '23', 'precision': '0.729', 'recall': '0.922', 'f1': '0.814', 'total_rewards': 186.27248936800487, 'invalid_action_count': 7, 'num_ms1_scans': 673, 'num_ms2_scans': 654}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 36.36350160393838
# steps	 1000 	total rewards	 99.1715367722857
# Finished after 1298 timesteps (4.6492578983306885 seconds) with total reward 124.12355986486216
# {'coverage_prop': '0.931', 'intensity_prop': '0.636', 'ms1ms2_ratio': '1.182', 'efficiency': '0.318', 'TP': '145', 'FP': '44', 'FN': '14', 'precision': '0.767', 'recall': '0.912', 'f1': '0.833', 'total_rewards': 124.12355986486219, 'invalid_action_count': 4, 'num_ms1_scans': 703, 'num_ms2_scans': 595}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 45.60809899400121
# steps	 1000 	total rewards	 112.33362070113611
# Finished after 1289 timesteps (4.640428066253662 seconds) with total reward 147.00490216702534
# {'coverage_prop': '0.918', 'intensity_prop': '0.620', 'ms1ms2_ratio': '1.230', 'efficiency': '0.446', 'TP': '200', 'FP': '58', 'FN': '23', 'precision': '0.775', 'recall': '0.897', 'f1': '0.832', 'total_rewards': 147.00490216702525, 'invalid_action_count': 9, 'num_ms1_scans': 711, 'num_ms2_scans': 578}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 67.21482571972675
# steps	 1000 	total rewards	 150.03457433759334
# Finished after 1371 timesteps (9.039614915847778 seconds) with total reward 212.374389602159
# {'coverage_prop': '0.888', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.850', 'efficiency': '0.591', 'TP': '289', 'FP': '149', 'FN': '55', 'precision': '0.660', 'recall': '0.840', 'f1': '0.739', 'total_rewards': 212.37438960215877, 'invalid_action_count': 14, 'num_ms1_scans': 630, 'num_ms2_scans': 741}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 54.182491620484626
# steps	 1000 	total rewards	 128.73001711071117
# Finished after 1309 timesteps (5.292419195175171 seconds) with total reward 166.21179116046295
# {'coverage_prop': '0.957', 'intensity_prop': '0.655', 'ms1ms2_ratio': '1.118', 'efficiency': '0.471', 'TP': '224', 'FP': '67', 'FN': '13', 'precision': '0.770', 'recall': '0.945', 'f1': '0.848', 'total_rewards': 166.21179116046287, 'invalid_action_count': 4, 'num_ms1_scans': 691, 'num_ms2_scans': 618}
#
# method = topN max_peaks = 200 N = 10 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 66.83527593483919
# steps	 1000 	total rewards	 145.9663808950428
# steps	 1500 	total rewards	 223.29340420434136
# Finished after 1783 timesteps (11.766120910644531 seconds) with total reward 262.03776894784494
# {'coverage_prop': '0.798', 'intensity_prop': '0.613', 'ms1ms2_ratio': '0.139', 'efficiency': '0.217', 'TP': '291', 'FP': '49', 'FN': '86', 'precision': '0.856', 'recall': '0.772', 'f1': '0.812', 'total_rewards': 262.03776894784477, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 59.66338701436514
# steps	 1000 	total rewards	 131.54424869171592
# steps	 1500 	total rewards	 203.05407738858372
# Finished after 1754 timesteps (9.730966091156006 seconds) with total reward 234.3849609910814
# {'coverage_prop': '0.931', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.163', 'efficiency': '0.162', 'TP': '229', 'FP': '15', 'FN': '18', 'precision': '0.939', 'recall': '0.927', 'f1': '0.933', 'total_rewards': 234.38496099108102, 'invalid_action_count': 0, 'num_ms1_scans': 246, 'num_ms2_scans': 1508}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 60.016242663465
# steps	 1000 	total rewards	 136.09375399879838
# steps	 1500 	total rewards	 204.70717234131746
# Finished after 1771 timesteps (11.052387237548828 seconds) with total reward 244.8867498143538
# {'coverage_prop': '0.812', 'intensity_prop': '0.618', 'ms1ms2_ratio': '0.149', 'efficiency': '0.208', 'TP': '266', 'FP': '54', 'FN': '74', 'precision': '0.831', 'recall': '0.782', 'f1': '0.806', 'total_rewards': 244.88674981435392, 'invalid_action_count': 0, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 71.26105894147236
# steps	 1000 	total rewards	 147.8176259125537
# steps	 1500 	total rewards	 224.6860924623389
# Finished after 1783 timesteps (11.524280071258545 seconds) with total reward 262.47417524858497
# {'coverage_prop': '0.825', 'intensity_prop': '0.637', 'ms1ms2_ratio': '0.139', 'efficiency': '0.238', 'TP': '326', 'FP': '47', 'FN': '79', 'precision': '0.874', 'recall': '0.805', 'f1': '0.838', 'total_rewards': 262.4741752485851, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 63.04013315307423
# steps	 1000 	total rewards	 149.33348371076698
# steps	 1500 	total rewards	 230.31093043687827
# Finished after 1776 timesteps (13.66493272781372 seconds) with total reward 268.94768987812125
# {'coverage_prop': '0.872', 'intensity_prop': '0.659', 'ms1ms2_ratio': '0.144', 'efficiency': '0.245', 'TP': '324', 'FP': '57', 'FN': '56', 'precision': '0.850', 'recall': '0.853', 'f1': '0.852', 'total_rewards': 268.94768987812114, 'invalid_action_count': 0, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 48.95610145909636
# steps	 1000 	total rewards	 115.83007093587088
# steps	 1500 	total rewards	 172.25406205556888
# Finished after 1715 timesteps (10.023793935775757 seconds) with total reward 193.06425809099017
# {'coverage_prop': '0.935', 'intensity_prop': '0.805', 'ms1ms2_ratio': '0.199', 'efficiency': '0.131', 'TP': '178', 'FP': '9', 'FN': '13', 'precision': '0.952', 'recall': '0.932', 'f1': '0.942', 'total_rewards': 193.0642580909904, 'invalid_action_count': 0, 'num_ms1_scans': 285, 'num_ms2_scans': 1430}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 65.61534533611456
# steps	 1000 	total rewards	 146.40283996652232
# steps	 1500 	total rewards	 218.61775615026022
# Finished after 1777 timesteps (11.993981838226318 seconds) with total reward 256.04604136401065
# {'coverage_prop': '0.757', 'intensity_prop': '0.549', 'ms1ms2_ratio': '0.144', 'efficiency': '0.233', 'TP': '287', 'FP': '75', 'FN': '116', 'precision': '0.793', 'recall': '0.712', 'f1': '0.750', 'total_rewards': 256.0460413640109, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 48.109684672135074
# steps	 1000 	total rewards	 118.60891863386344
# steps	 1500 	total rewards	 178.93456176880528
# Finished after 1720 timesteps (9.386143922805786 seconds) with total reward 204.31724654734595
# {'coverage_prop': '0.917', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.194', 'efficiency': '0.130', 'TP': '181', 'FP': '6', 'FN': '17', 'precision': '0.968', 'recall': '0.914', 'f1': '0.940', 'total_rewards': 204.31724654734603, 'invalid_action_count': 0, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 73.88245500376209
# steps	 1000 	total rewards	 148.65108080309042
# steps	 1500 	total rewards	 226.1363874874564
# Finished after 1794 timesteps (11.980539083480835 seconds) with total reward 265.8775730320965
# {'coverage_prop': '0.854', 'intensity_prop': '0.661', 'ms1ms2_ratio': '0.130', 'efficiency': '0.228', 'TP': '316', 'FP': '46', 'FN': '62', 'precision': '0.873', 'recall': '0.836', 'f1': '0.854', 'total_rewards': 265.87757303209645, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 62.62020259464846
# steps	 1000 	total rewards	 135.7498128572761
# steps	 1500 	total rewards	 212.7982267660529
# Finished after 1781 timesteps (11.041187763214111 seconds) with total reward 247.2686311033123
# {'coverage_prop': '0.820', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.140', 'efficiency': '0.202', 'TP': '277', 'FP': '38', 'FN': '69', 'precision': '0.879', 'recall': '0.801', 'f1': '0.838', 'total_rewards': 247.26863110331232, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 64.30885632015526
# steps	 1000 	total rewards	 137.0723897915379
# steps	 1500 	total rewards	 219.91170145128518
# Finished after 1790 timesteps (14.25968313217163 seconds) with total reward 255.80518004198802
# {'coverage_prop': '0.779', 'intensity_prop': '0.595', 'ms1ms2_ratio': '0.133', 'efficiency': '0.218', 'TP': '293', 'FP': '52', 'FN': '98', 'precision': '0.849', 'recall': '0.749', 'f1': '0.796', 'total_rewards': 255.80518004198834, 'invalid_action_count': 0, 'num_ms1_scans': 210, 'num_ms2_scans': 1580}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 57.823544426073425
# steps	 1000 	total rewards	 123.33522508149852
# steps	 1500 	total rewards	 183.73992749195077
# Finished after 1753 timesteps (10.138336181640625 seconds) with total reward 212.06710277149742
# {'coverage_prop': '0.916', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.164', 'efficiency': '0.151', 'TP': '217', 'FP': '11', 'FN': '21', 'precision': '0.952', 'recall': '0.912', 'f1': '0.931', 'total_rewards': 212.0671027714971, 'invalid_action_count': 0, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 58.85879188327654
# steps	 1000 	total rewards	 114.87903467354019
# steps	 1500 	total rewards	 179.4466688148381
# Finished after 1779 timesteps (11.076646089553833 seconds) with total reward 216.0466542436297
# {'coverage_prop': '0.861', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.142', 'efficiency': '0.139', 'TP': '196', 'FP': '20', 'FN': '35', 'precision': '0.907', 'recall': '0.848', 'f1': '0.877', 'total_rewards': 216.04665424362972, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 55.210333536102226
# steps	 1000 	total rewards	 124.57836272120093
# steps	 1500 	total rewards	 189.2984756441914
# Finished after 1771 timesteps (11.688813924789429 seconds) with total reward 218.8698613083086
# {'coverage_prop': '0.837', 'intensity_prop': '0.649', 'ms1ms2_ratio': '0.149', 'efficiency': '0.163', 'TP': '217', 'FP': '34', 'FN': '49', 'precision': '0.865', 'recall': '0.816', 'f1': '0.839', 'total_rewards': 218.8698613083084, 'invalid_action_count': 0, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 51.31391728958329
# steps	 1000 	total rewards	 114.10049853230826
# steps	 1500 	total rewards	 172.43806702675738
# Finished after 1748 timesteps (10.004477977752686 seconds) with total reward 200.09024812150102
# {'coverage_prop': '0.879', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.168', 'efficiency': '0.121', 'TP': '166', 'FP': '15', 'FN': '25', 'precision': '0.917', 'recall': '0.869', 'f1': '0.892', 'total_rewards': 200.09024812150096, 'invalid_action_count': 0, 'num_ms1_scans': 252, 'num_ms2_scans': 1496}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 58.87786928204107
# steps	 1000 	total rewards	 133.8250210436093
# steps	 1500 	total rewards	 214.9332240735686
# Finished after 1775 timesteps (11.554283857345581 seconds) with total reward 254.6298495793062
# {'coverage_prop': '0.870', 'intensity_prop': '0.695', 'ms1ms2_ratio': '0.145', 'efficiency': '0.228', 'TP': '315', 'FP': '39', 'FN': '53', 'precision': '0.890', 'recall': '0.856', 'f1': '0.873', 'total_rewards': 254.62984957930627, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 65.2546703814731
# steps	 1000 	total rewards	 144.34201013409813
# steps	 1500 	total rewards	 220.26044578699702
# Finished after 1782 timesteps (11.69951581954956 seconds) with total reward 263.6744694041253
# {'coverage_prop': '0.773', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.139', 'efficiency': '0.246', 'TP': '321', 'FP': '64', 'FN': '113', 'precision': '0.834', 'recall': '0.740', 'f1': '0.784', 'total_rewards': 263.67446940412543, 'invalid_action_count': 0, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 68.35124594139745
# steps	 1000 	total rewards	 138.038174848802
# steps	 1500 	total rewards	 208.52954810066902
# Finished after 1781 timesteps (14.192986011505127 seconds) with total reward 241.45103945445126
# {'coverage_prop': '0.831', 'intensity_prop': '0.625', 'ms1ms2_ratio': '0.140', 'efficiency': '0.198', 'TP': '260', 'FP': '49', 'FN': '63', 'precision': '0.841', 'recall': '0.805', 'f1': '0.823', 'total_rewards': 241.45103945445135, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 60.263853177461826
# steps	 1000 	total rewards	 128.91315789235196
# steps	 1500 	total rewards	 196.46310929913793
# Finished after 1767 timesteps (10.755877017974854 seconds) with total reward 234.747501897017
# {'coverage_prop': '0.901', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.152', 'efficiency': '0.177', 'TP': '248', 'FP': '24', 'FN': '30', 'precision': '0.912', 'recall': '0.892', 'f1': '0.902', 'total_rewards': 234.74750189701683, 'invalid_action_count': 0, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 54.66981524670882
# steps	 1000 	total rewards	 126.27167397858113
# steps	 1500 	total rewards	 187.61961632022857
# Finished after 1767 timesteps (10.650512218475342 seconds) with total reward 219.22631542034236
# {'coverage_prop': '0.902', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.152', 'efficiency': '0.156', 'TP': '216', 'FP': '23', 'FN': '26', 'precision': '0.904', 'recall': '0.893', 'f1': '0.898', 'total_rewards': 219.2263154203426, 'invalid_action_count': 0, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 68.37121317230275
# steps	 1000 	total rewards	 142.2720264931392
# steps	 1500 	total rewards	 213.5625588780716
# Finished after 1781 timesteps (12.031492948532104 seconds) with total reward 252.0832600801506
# {'coverage_prop': '0.716', 'intensity_prop': '0.538', 'ms1ms2_ratio': '0.140', 'efficiency': '0.214', 'TP': '283', 'FP': '52', 'FN': '133', 'precision': '0.845', 'recall': '0.680', 'f1': '0.754', 'total_rewards': 252.08326008015084, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 54.39783015521277
# steps	 1000 	total rewards	 121.34674738031833
# steps	 1500 	total rewards	 186.76722738505606
# Finished after 1737 timesteps (10.210675954818726 seconds) with total reward 210.81607496265013
# {'coverage_prop': '0.940', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.179', 'efficiency': '0.149', 'TP': '197', 'FP': '23', 'FN': '14', 'precision': '0.895', 'recall': '0.934', 'f1': '0.914', 'total_rewards': 210.8160749626503, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1473}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 62.51375535624341
# steps	 1000 	total rewards	 140.3273092695067
# steps	 1500 	total rewards	 208.6342658079538
# Finished after 1776 timesteps (10.479102373123169 seconds) with total reward 243.6890344163065
# {'coverage_prop': '0.891', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.144', 'efficiency': '0.185', 'TP': '260', 'FP': '27', 'FN': '35', 'precision': '0.906', 'recall': '0.881', 'f1': '0.893', 'total_rewards': 243.68903441630667, 'invalid_action_count': 0, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 63.15831057682183
# steps	 1000 	total rewards	 137.9070518943397
# steps	 1500 	total rewards	 211.68088113528722
# Finished after 1755 timesteps (9.99651312828064 seconds) with total reward 243.21556589996038
# {'coverage_prop': '0.906', 'intensity_prop': '0.717', 'ms1ms2_ratio': '0.162', 'efficiency': '0.186', 'TP': '248', 'FP': '33', 'FN': '29', 'precision': '0.883', 'recall': '0.895', 'f1': '0.889', 'total_rewards': 243.21556589996047, 'invalid_action_count': 0, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 60.48059523397252
# steps	 1000 	total rewards	 136.20336873815572
# steps	 1500 	total rewards	 202.02117599735658
# Finished after 1765 timesteps (13.81410527229309 seconds) with total reward 235.09851194029855
# {'coverage_prop': '0.814', 'intensity_prop': '0.623', 'ms1ms2_ratio': '0.154', 'efficiency': '0.184', 'TP': '240', 'FP': '41', 'FN': '64', 'precision': '0.854', 'recall': '0.789', 'f1': '0.821', 'total_rewards': 235.09851194029864, 'invalid_action_count': 0, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 60.231708687043735
# steps	 1000 	total rewards	 133.94192906128046
# steps	 1500 	total rewards	 206.3748089091438
# Finished after 1795 timesteps (12.099483966827393 seconds) with total reward 249.59619521762426
# {'coverage_prop': '0.866', 'intensity_prop': '0.679', 'ms1ms2_ratio': '0.130', 'efficiency': '0.216', 'TP': '302', 'FP': '41', 'FN': '53', 'precision': '0.880', 'recall': '0.851', 'f1': '0.865', 'total_rewards': 249.59619521762423, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1589}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 47.93547438314475
# steps	 1000 	total rewards	 114.94944338484753
# steps	 1500 	total rewards	 175.47180504950694
# Finished after 1735 timesteps (11.026005983352661 seconds) with total reward 200.3351451821072
# {'coverage_prop': '0.961', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.180', 'efficiency': '0.133', 'TP': '187', 'FP': '8', 'FN': '8', 'precision': '0.959', 'recall': '0.959', 'f1': '0.959', 'total_rewards': 200.3351451821072, 'invalid_action_count': 0, 'num_ms1_scans': 265, 'num_ms2_scans': 1470}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 55.119140590610975
# steps	 1000 	total rewards	 125.6731723194959
# steps	 1500 	total rewards	 196.99873774588315
# Finished after 1761 timesteps (10.422322988510132 seconds) with total reward 235.10028507492254
# {'coverage_prop': '0.922', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.157', 'efficiency': '0.170', 'TP': '241', 'FP': '18', 'FN': '22', 'precision': '0.931', 'recall': '0.916', 'f1': '0.923', 'total_rewards': 235.10028507492268, 'invalid_action_count': 0, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 73.34630240898605
# steps	 1000 	total rewards	 145.6089211355656
# steps	 1500 	total rewards	 212.05096804828693
# Finished after 1789 timesteps (11.871400833129883 seconds) with total reward 259.630297932601
# {'coverage_prop': '0.738', 'intensity_prop': '0.521', 'ms1ms2_ratio': '0.134', 'efficiency': '0.231', 'TP': '285', 'FP': '79', 'FN': '129', 'precision': '0.783', 'recall': '0.688', 'f1': '0.733', 'total_rewards': 259.63029793260074, 'invalid_action_count': 0, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 57.54808066483305
# steps	 1000 	total rewards	 131.70009748091275
# steps	 1500 	total rewards	 192.72687011293306
# Finished after 1765 timesteps (10.277826070785522 seconds) with total reward 225.8431827781682
# {'coverage_prop': '0.852', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.154', 'efficiency': '0.169', 'TP': '232', 'FP': '27', 'FN': '45', 'precision': '0.896', 'recall': '0.838', 'f1': '0.866', 'total_rewards': 225.843182778168, 'invalid_action_count': 0, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fb6d1d4cd00>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fb6d791c6d0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fb6d7939970>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.476', 'efficiency': '0.749', 'TP': '191', 'FP': '188', 'FN': '15', 'precision': '0.504', 'recall': '0.927', 'f1': '0.653'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.530', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '245', 'FP': '187', 'FN': '20', 'precision': '0.567', 'recall': '0.925', 'f1': '0.703'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.122', 'efficiency': '0.736', 'TP': '264', 'FP': '190', 'FN': '24', 'precision': '0.581', 'recall': '0.917', 'f1': '0.712'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.524', 'ms1ms2_ratio': '1.521', 'efficiency': '0.741', 'TP': '201', 'FP': '166', 'FN': '17', 'precision': '0.548', 'recall': '0.922', 'f1': '0.687'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.535', 'ms1ms2_ratio': '1.218', 'efficiency': '0.732', 'TP': '237', 'FP': '189', 'FN': '17', 'precision': '0.556', 'recall': '0.933', 'f1': '0.697'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.676', 'efficiency': '0.759', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.475', 'ms1ms2_ratio': '2.552', 'efficiency': '0.723', 'TP': '107', 'FP': '130', 'FN': '14', 'precision': '0.451', 'recall': '0.884', 'f1': '0.598'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.958', 'efficiency': '0.700', 'TP': '145', 'FP': '140', 'FN': '15', 'precision': '0.509', 'recall': '0.906', 'f1': '0.652'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '97', 'FP': '97', 'FN': '12', 'precision': '0.500', 'recall': '0.890', 'f1': '0.640'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.543', 'ms1ms2_ratio': '1.159', 'efficiency': '0.740', 'TP': '269', 'FP': '177', 'FN': '22', 'precision': '0.603', 'recall': '0.924', 'f1': '0.730'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.990', 'efficiency': '0.759', 'TP': '162', 'FP': '143', 'FN': '17', 'precision': '0.531', 'recall': '0.905', 'f1': '0.669'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '144', 'FP': '125', 'FN': '12', 'precision': '0.535', 'recall': '0.923', 'f1': '0.678'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '150', 'FP': '140', 'FN': '14', 'precision': '0.517', 'recall': '0.915', 'f1': '0.661'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1804.709296                1860.0          0.423           0.103
# 1  random   -1918.562097                1940.0          0.218           0.045
# 2  random   -1820.730724                1866.0          0.383           0.092
# 3  random   -1882.955834                1917.0          0.288           0.069
# 4  random   -1830.711687                1879.0          0.375           0.093
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.091      0.178   0.115  0.140
# 1          0.004       0.029      0.193   0.051  0.081
# 2          0.007       0.077      0.192   0.107  0.137
# 3          0.003       0.065      0.223   0.083  0.121
# 4          0.006       0.083      0.201   0.108  0.140

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     200.152063                   4.0          0.906           0.568
# 31    DQN     151.556249                   8.0          0.927           0.644
# 32    DQN     180.340509                   9.0          0.898           0.583
# 33    DQN     197.482117                  10.0          0.900           0.596
# 34    DQN     190.598690                  16.0          0.929           0.604
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.978       0.570      0.702   0.871  0.778
# 31          1.077       0.383      0.819   0.913  0.863
# 32          1.097       0.565      0.726   0.865  0.790
# 33          0.952       0.591      0.769   0.874  0.818
# 34          0.912       0.573      0.729   0.905  0.808

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
