# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-15 16:17:34.090 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe8d4d24400>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe8e2055580>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe8e2071820>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe8d4d24400>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe8e2055580>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe8e2071820>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe8d4d24400>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe8e2055580>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe8e2071820>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -332.09796511667236
# steps	 1000 	total rewards	 -702.9292927218976
# steps	 1500 	total rewards	 -883.9922392424602
# Finished after 1988 timesteps (4.618629217147827 seconds) with total reward -1074.6393217300026
# {'coverage_prop': '0.721', 'intensity_prop': '0.223', 'ms1ms2_ratio': '0.006', 'efficiency': '0.155', 'TP': '93', 'FP': '214', 'FN': '119', 'precision': '0.303', 'recall': '0.439', 'f1': '0.358', 'total_rewards': -1074.6393217300003, 'invalid_action_count': 1223, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -391.58885654106905
# steps	 1000 	total rewards	 -740.3014077815822
# steps	 1500 	total rewards	 -998.7304204077178
# Finished after 1990 timesteps (2.6353180408477783 seconds) with total reward -1346.7593982216008
# {'coverage_prop': '0.656', 'intensity_prop': '0.156', 'ms1ms2_ratio': '0.005', 'efficiency': '0.087', 'TP': '38', 'FP': '134', 'FN': '90', 'precision': '0.221', 'recall': '0.297', 'f1': '0.253', 'total_rewards': -1346.7593982216017, 'invalid_action_count': 1433, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -427.0730961631382
# steps	 1000 	total rewards	 -709.4824041343204
# steps	 1500 	total rewards	 -827.6973770438311
# Finished after 1988 timesteps (3.8223719596862793 seconds) with total reward -1031.9560529062687
# {'coverage_prop': '0.746', 'intensity_prop': '0.221', 'ms1ms2_ratio': '0.006', 'efficiency': '0.149', 'TP': '83', 'FP': '211', 'FN': '100', 'precision': '0.282', 'recall': '0.454', 'f1': '0.348', 'total_rewards': -1031.9560529062692, 'invalid_action_count': 1173, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -384.73792539955286
# steps	 1000 	total rewards	 -815.7650346125199
# steps	 1500 	total rewards	 -910.7853490413194
# Finished after 1990 timesteps (4.510921955108643 seconds) with total reward -1108.1297445805426
# {'coverage_prop': '0.699', 'intensity_prop': '0.224', 'ms1ms2_ratio': '0.005', 'efficiency': '0.160', 'TP': '98', 'FP': '218', 'FN': '136', 'precision': '0.310', 'recall': '0.419', 'f1': '0.356', 'total_rewards': -1108.1297445805433, 'invalid_action_count': 1254, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -334.2166216467141
# steps	 1000 	total rewards	 -662.0893138808137
# steps	 1500 	total rewards	 -840.0329975815278
# Finished after 1992 timesteps (6.730123996734619 seconds) with total reward -1164.836543713341
# {'coverage_prop': '0.744', 'intensity_prop': '0.211', 'ms1ms2_ratio': '0.004', 'efficiency': '0.164', 'TP': '88', 'FP': '237', 'FN': '112', 'precision': '0.271', 'recall': '0.440', 'f1': '0.335', 'total_rewards': -1164.8365437133411, 'invalid_action_count': 1306, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -357.2552741401832
# steps	 1000 	total rewards	 -692.4039034054085
# steps	 1500 	total rewards	 -1052.844477893629
# Finished after 1987 timesteps (2.296710252761841 seconds) with total reward -1439.8618758896134
# {'coverage_prop': '0.690', 'intensity_prop': '0.225', 'ms1ms2_ratio': '0.007', 'efficiency': '0.070', 'TP': '45', 'FP': '93', 'FN': '62', 'precision': '0.326', 'recall': '0.421', 'f1': '0.367', 'total_rewards': -1439.8618758896127, 'invalid_action_count': 1510, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -354.2464335224727
# steps	 1000 	total rewards	 -625.8263585283544
# steps	 1500 	total rewards	 -737.4412370562407
# Finished after 1991 timesteps (3.9398820400238037 seconds) with total reward -996.7219967229457
# {'coverage_prop': '0.730', 'intensity_prop': '0.245', 'ms1ms2_ratio': '0.005', 'efficiency': '0.176', 'TP': '116', 'FP': '233', 'FN': '129', 'precision': '0.332', 'recall': '0.473', 'f1': '0.391', 'total_rewards': -996.7219967229449, 'invalid_action_count': 1162, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -375.14573212521697
# steps	 1000 	total rewards	 -690.1723773114749
# steps	 1500 	total rewards	 -985.7346449689584
# Finished after 1984 timesteps (3.2399768829345703 seconds) with total reward -1287.6936493731178
# {'coverage_prop': '0.730', 'intensity_prop': '0.251', 'ms1ms2_ratio': '0.008', 'efficiency': '0.076', 'TP': '48', 'FP': '101', 'FN': '55', 'precision': '0.322', 'recall': '0.466', 'f1': '0.381', 'total_rewards': -1287.6936493731175, 'invalid_action_count': 1369, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -361.4912881005733
# steps	 1000 	total rewards	 -817.5419099485555
# steps	 1500 	total rewards	 -1112.836637068974
# Finished after 1994 timesteps (3.6526358127593994 seconds) with total reward -1403.4825616183236
# {'coverage_prop': '0.613', 'intensity_prop': '0.132', 'ms1ms2_ratio': '0.003', 'efficiency': '0.131', 'TP': '47', 'FP': '213', 'FN': '164', 'precision': '0.181', 'recall': '0.223', 'f1': '0.200', 'total_rewards': -1403.4825616183243, 'invalid_action_count': 1514, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -337.7217119454658
# steps	 1000 	total rewards	 -726.1887339230108
# steps	 1500 	total rewards	 -856.765267720366
# Finished after 1988 timesteps (3.545659065246582 seconds) with total reward -1133.146413611791
# {'coverage_prop': '0.766', 'intensity_prop': '0.225', 'ms1ms2_ratio': '0.006', 'efficiency': '0.149', 'TP': '80', 'FP': '214', 'FN': '90', 'precision': '0.272', 'recall': '0.471', 'f1': '0.345', 'total_rewards': -1133.1464136117902, 'invalid_action_count': 1268, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -324.25963439640554
# steps	 1000 	total rewards	 -589.7949000870741
# steps	 1500 	total rewards	 -765.0579457224117
# Finished after 1990 timesteps (3.960615873336792 seconds) with total reward -993.7315438906821
# {'coverage_prop': '0.770', 'intensity_prop': '0.246', 'ms1ms2_ratio': '0.005', 'efficiency': '0.172', 'TP': '105', 'FP': '236', 'FN': '102', 'precision': '0.308', 'recall': '0.507', 'f1': '0.383', 'total_rewards': -993.7315438906838, 'invalid_action_count': 1161, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -365.8062824462147
# steps	 1000 	total rewards	 -660.1117341755557
# steps	 1500 	total rewards	 -900.7582413131254
# Finished after 1985 timesteps (3.152742862701416 seconds) with total reward -1188.4199265900136
# {'coverage_prop': '0.759', 'intensity_prop': '0.250', 'ms1ms2_ratio': '0.008', 'efficiency': '0.096', 'TP': '59', 'FP': '130', 'FN': '60', 'precision': '0.312', 'recall': '0.496', 'f1': '0.383', 'total_rewards': -1188.4199265900127, 'invalid_action_count': 1279, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -381.5910878530959
# steps	 1000 	total rewards	 -792.7026782569058
# steps	 1500 	total rewards	 -1091.4588500679536
# Finished after 1993 timesteps (2.970539093017578 seconds) with total reward -1449.2522982443538
# {'coverage_prop': '0.618', 'intensity_prop': '0.140', 'ms1ms2_ratio': '0.004', 'efficiency': '0.078', 'TP': '34', 'FP': '121', 'FN': '96', 'precision': '0.219', 'recall': '0.262', 'f1': '0.239', 'total_rewards': -1449.2522982443534, 'invalid_action_count': 1524, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -413.5633542272807
# steps	 1000 	total rewards	 -769.6538136186814
# steps	 1500 	total rewards	 -938.715392078458
# Finished after 1989 timesteps (3.6471970081329346 seconds) with total reward -1229.2224547566739
# {'coverage_prop': '0.770', 'intensity_prop': '0.247', 'ms1ms2_ratio': '0.006', 'efficiency': '0.117', 'TP': '72', 'FP': '159', 'FN': '69', 'precision': '0.312', 'recall': '0.511', 'f1': '0.387', 'total_rewards': -1229.2224547566725, 'invalid_action_count': 1338, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -377.6796404338809
# steps	 1000 	total rewards	 -685.599811382994
# steps	 1500 	total rewards	 -1053.2224424520905
# Finished after 1991 timesteps (2.848483085632324 seconds) with total reward -1534.1979798341224
# {'coverage_prop': '0.573', 'intensity_prop': '0.129', 'ms1ms2_ratio': '0.005', 'efficiency': '0.060', 'TP': '22', 'FP': '96', 'FN': '88', 'precision': '0.186', 'recall': '0.200', 'f1': '0.193', 'total_rewards': -1534.197979834122, 'invalid_action_count': 1588, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -363.4059216668654
# steps	 1000 	total rewards	 -552.9659360758332
# steps	 1500 	total rewards	 -627.1211890350705
# Finished after 1986 timesteps (4.380190134048462 seconds) with total reward -911.0077652070413
# {'coverage_prop': '0.794', 'intensity_prop': '0.316', 'ms1ms2_ratio': '0.007', 'efficiency': '0.164', 'TP': '127', 'FP': '196', 'FN': '84', 'precision': '0.393', 'recall': '0.602', 'f1': '0.476', 'total_rewards': -911.007765207041, 'invalid_action_count': 1070, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -343.7522319317452
# steps	 1000 	total rewards	 -793.9893107902046
# steps	 1500 	total rewards	 -1292.9890027431932
# Finished after 1994 timesteps (6.716042995452881 seconds) with total reward -1481.5393619863662
# {'coverage_prop': '0.458', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.003', 'efficiency': '0.115', 'TP': '34', 'FP': '194', 'FN': '270', 'precision': '0.149', 'recall': '0.112', 'f1': '0.128', 'total_rewards': -1481.5393619863667, 'invalid_action_count': 1567, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -353.5553387816673
# steps	 1000 	total rewards	 -560.1117850941412
# steps	 1500 	total rewards	 -722.8210306925835
# Finished after 1986 timesteps (5.210384845733643 seconds) with total reward -989.4012918447114
# {'coverage_prop': '0.790', 'intensity_prop': '0.261', 'ms1ms2_ratio': '0.007', 'efficiency': '0.149', 'TP': '90', 'FP': '204', 'FN': '78', 'precision': '0.306', 'recall': '0.536', 'f1': '0.390', 'total_rewards': -989.4012918447113, 'invalid_action_count': 1133, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -380.4046578094451
# steps	 1000 	total rewards	 -704.3971820683852
# steps	 1500 	total rewards	 -984.0941328840413
# Finished after 1988 timesteps (3.4150540828704834 seconds) with total reward -1200.8747918784197
# {'coverage_prop': '0.725', 'intensity_prop': '0.204', 'ms1ms2_ratio': '0.006', 'efficiency': '0.111', 'TP': '52', 'FP': '167', 'FN': '83', 'precision': '0.237', 'recall': '0.385', 'f1': '0.294', 'total_rewards': -1200.874791878418, 'invalid_action_count': 1309, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -453.4869823433625
# steps	 1000 	total rewards	 -770.8934454251771
# steps	 1500 	total rewards	 -974.9328244409246
# Finished after 1991 timesteps (3.151766061782837 seconds) with total reward -1308.9657606169085
# {'coverage_prop': '0.672', 'intensity_prop': '0.191', 'ms1ms2_ratio': '0.005', 'efficiency': '0.090', 'TP': '49', 'FP': '129', 'FN': '87', 'precision': '0.275', 'recall': '0.360', 'f1': '0.312', 'total_rewards': -1308.9657606169078, 'invalid_action_count': 1404, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -318.2821252462996
# steps	 1000 	total rewards	 -594.5171148679065
# steps	 1500 	total rewards	 -774.3761392977085
# Finished after 1987 timesteps (4.309887170791626 seconds) with total reward -1060.9059622419675
# {'coverage_prop': '0.726', 'intensity_prop': '0.237', 'ms1ms2_ratio': '0.007', 'efficiency': '0.172', 'TP': '101', 'FP': '239', 'FN': '128', 'precision': '0.297', 'recall': '0.441', 'f1': '0.355', 'total_rewards': -1060.9059622419672, 'invalid_action_count': 1216, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -365.90187989014794
# steps	 1000 	total rewards	 -778.1838262512997
# steps	 1500 	total rewards	 -1092.0681329537556
# Finished after 1991 timesteps (4.130044937133789 seconds) with total reward -1505.6040573972377
# {'coverage_prop': '0.590', 'intensity_prop': '0.144', 'ms1ms2_ratio': '0.005', 'efficiency': '0.070', 'TP': '31', 'FP': '107', 'FN': '96', 'precision': '0.225', 'recall': '0.244', 'f1': '0.234', 'total_rewards': -1505.604057397239, 'invalid_action_count': 1571, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -456.0
# steps	 1000 	total rewards	 -826.9526300364162
# steps	 1500 	total rewards	 -1153.2751986012559
# Finished after 1994 timesteps (5.063587665557861 seconds) with total reward -1452.602780959706
# {'coverage_prop': '0.627', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.003', 'efficiency': '0.102', 'TP': '40', 'FP': '162', 'FN': '120', 'precision': '0.198', 'recall': '0.250', 'f1': '0.221', 'total_rewards': -1452.6027809597058, 'invalid_action_count': 1544, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -437.99650064168594
# steps	 1000 	total rewards	 -624.2203542969947
# steps	 1500 	total rewards	 -973.5306968229722
# Finished after 1985 timesteps (5.4806067943573 seconds) with total reward -1332.7835764238644
# {'coverage_prop': '0.645', 'intensity_prop': '0.192', 'ms1ms2_ratio': '0.008', 'efficiency': '0.102', 'TP': '58', 'FP': '142', 'FN': '110', 'precision': '0.290', 'recall': '0.345', 'f1': '0.315', 'total_rewards': -1332.7835764238635, 'invalid_action_count': 1426, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -367.3096750365341
# steps	 1000 	total rewards	 -631.8208439821735
# steps	 1500 	total rewards	 -797.443813048555
# Finished after 1985 timesteps (5.316989898681641 seconds) with total reward -1045.7401673040422
# {'coverage_prop': '0.774', 'intensity_prop': '0.263', 'ms1ms2_ratio': '0.008', 'efficiency': '0.136', 'TP': '90', 'FP': '177', 'FN': '78', 'precision': '0.337', 'recall': '0.536', 'f1': '0.414', 'total_rewards': -1045.7401673040413, 'invalid_action_count': 1186, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -376.4183456426008
# steps	 1000 	total rewards	 -615.9483912179888
# steps	 1500 	total rewards	 -803.5377131643783
# Finished after 1986 timesteps (5.8381030559539795 seconds) with total reward -955.211689320555
# {'coverage_prop': '0.785', 'intensity_prop': '0.252', 'ms1ms2_ratio': '0.007', 'efficiency': '0.158', 'TP': '102', 'FP': '209', 'FN': '85', 'precision': '0.328', 'recall': '0.545', 'f1': '0.410', 'total_rewards': -955.2116893205562, 'invalid_action_count': 1101, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -399.013672675183
# steps	 1000 	total rewards	 -788.0122906106112
# steps	 1500 	total rewards	 -999.1957579092469
# Finished after 1985 timesteps (2.9157068729400635 seconds) with total reward -1296.2435598773286
# {'coverage_prop': '0.724', 'intensity_prop': '0.218', 'ms1ms2_ratio': '0.008', 'efficiency': '0.075', 'TP': '38', 'FP': '109', 'FN': '56', 'precision': '0.259', 'recall': '0.404', 'f1': '0.315', 'total_rewards': -1296.2435598773295, 'invalid_action_count': 1376, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -401.83983142425654
# steps	 1000 	total rewards	 -666.3366729051686
# steps	 1500 	total rewards	 -858.9016519428939
# Finished after 1983 timesteps (4.186445951461792 seconds) with total reward -1132.2748324275158
# {'coverage_prop': '0.762', 'intensity_prop': '0.231', 'ms1ms2_ratio': '0.009', 'efficiency': '0.109', 'TP': '58', 'FP': '156', 'FN': '67', 'precision': '0.271', 'recall': '0.464', 'f1': '0.342', 'total_rewards': -1132.2748324275146, 'invalid_action_count': 1251, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -349.2232898553939
# steps	 1000 	total rewards	 -527.4110841856708
# steps	 1500 	total rewards	 -648.39456798392
# Finished after 1989 timesteps (4.945495128631592 seconds) with total reward -892.7403559293566
# {'coverage_prop': '0.748', 'intensity_prop': '0.251', 'ms1ms2_ratio': '0.006', 'efficiency': '0.187', 'TP': '117', 'FP': '252', 'FN': '124', 'precision': '0.317', 'recall': '0.485', 'f1': '0.384', 'total_rewards': -892.7403559293567, 'invalid_action_count': 1071, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -338.1762437052755
# steps	 1000 	total rewards	 -604.0635858601337
# steps	 1500 	total rewards	 -805.7457362284608
# Finished after 1988 timesteps (3.8730030059814453 seconds) with total reward -1223.0446310109915
# {'coverage_prop': '0.707', 'intensity_prop': '0.252', 'ms1ms2_ratio': '0.006', 'efficiency': '0.109', 'TP': '72', 'FP': '143', 'FN': '89', 'precision': '0.335', 'recall': '0.447', 'f1': '0.383', 'total_rewards': -1223.0446310109917, 'invalid_action_count': 1330, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 8.36GB > 0.31GB
# steps	 500 	total rewards	 92.16137301777283
# steps	 1000 	total rewards	 169.99695312159213
# Finished after 1469 timesteps (8.831866025924683 seconds) with total reward 214.8370833807535
# {'coverage_prop': '0.908', 'intensity_prop': '0.472', 'ms1ms2_ratio': '0.566', 'efficiency': '0.413', 'TP': '211', 'FP': '176', 'FN': '39', 'precision': '0.545', 'recall': '0.844', 'f1': '0.662', 'total_rewards': 214.8370833807518, 'invalid_action_count': 65, 'num_ms1_scans': 531, 'num_ms2_scans': 938}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 86.98123713832251
# steps	 1000 	total rewards	 191.09829183534583
# Finished after 1366 timesteps (6.259758949279785 seconds) with total reward 238.06158748504566
# {'coverage_prop': '0.981', 'intensity_prop': '0.510', 'ms1ms2_ratio': '0.866', 'efficiency': '0.351', 'TP': '138', 'FP': '119', 'FN': '5', 'precision': '0.537', 'recall': '0.965', 'f1': '0.690', 'total_rewards': 238.06158748504333, 'invalid_action_count': 1, 'num_ms1_scans': 634, 'num_ms2_scans': 732}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 90.63193782804906
# steps	 1000 	total rewards	 178.1720178745622
# Finished after 1452 timesteps (7.708312749862671 seconds) with total reward 237.7471075397507
# {'coverage_prop': '0.929', 'intensity_prop': '0.463', 'ms1ms2_ratio': '0.606', 'efficiency': '0.405', 'TP': '199', 'FP': '167', 'FN': '28', 'precision': '0.544', 'recall': '0.877', 'f1': '0.671', 'total_rewards': 237.7471075397485, 'invalid_action_count': 33, 'num_ms1_scans': 548, 'num_ms2_scans': 904}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 96.51868975293854
# steps	 1000 	total rewards	 174.63538991308928
# Finished after 1476 timesteps (10.547973155975342 seconds) with total reward 228.74626706227798
# {'coverage_prop': '0.931', 'intensity_prop': '0.477', 'ms1ms2_ratio': '0.552', 'efficiency': '0.443', 'TP': '229', 'FP': '192', 'FN': '31', 'precision': '0.544', 'recall': '0.881', 'f1': '0.673', 'total_rewards': 228.74626706227605, 'invalid_action_count': 58, 'num_ms1_scans': 525, 'num_ms2_scans': 951}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.74287550758443
# steps	 1000 	total rewards	 160.0768744316561
# Finished after 1462 timesteps (12.049041032791138 seconds) with total reward 218.81378954841728
# {'coverage_prop': '0.922', 'intensity_prop': '0.452', 'ms1ms2_ratio': '0.582', 'efficiency': '0.436', 'TP': '208', 'FP': '195', 'FN': '34', 'precision': '0.516', 'recall': '0.860', 'f1': '0.645', 'total_rewards': 218.81378954841512, 'invalid_action_count': 59, 'num_ms1_scans': 538, 'num_ms2_scans': 924}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 76.79446795460186
# steps	 1000 	total rewards	 156.79959488897458
# Finished after 1358 timesteps (6.119098663330078 seconds) with total reward 210.51341849474323
# {'coverage_prop': '1.000', 'intensity_prop': '0.628', 'ms1ms2_ratio': '0.897', 'efficiency': '0.279', 'TP': '138', 'FP': '62', 'FN': '0', 'precision': '0.690', 'recall': '1.000', 'f1': '0.817', 'total_rewards': 210.5134184947406, 'invalid_action_count': 3, 'num_ms1_scans': 642, 'num_ms2_scans': 716}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 100.82362931220803
# steps	 1000 	total rewards	 166.94805649530642
# Finished after 1481 timesteps (7.052794933319092 seconds) with total reward 225.46651819384027
# {'coverage_prop': '0.916', 'intensity_prop': '0.460', 'ms1ms2_ratio': '0.540', 'efficiency': '0.455', 'TP': '234', 'FP': '204', 'FN': '40', 'precision': '0.534', 'recall': '0.854', 'f1': '0.657', 'total_rewards': 225.46651819383814, 'invalid_action_count': 67, 'num_ms1_scans': 519, 'num_ms2_scans': 962}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 60.607701028050336
# steps	 1000 	total rewards	 157.48809467402555
# Finished after 1344 timesteps (6.713127136230469 seconds) with total reward 202.53921791124873
# {'coverage_prop': '0.980', 'intensity_prop': '0.561', 'ms1ms2_ratio': '0.953', 'efficiency': '0.291', 'TP': '125', 'FP': '75', 'FN': '4', 'precision': '0.625', 'recall': '0.969', 'f1': '0.760', 'total_rewards': 202.5392179112465, 'invalid_action_count': 3, 'num_ms1_scans': 656, 'num_ms2_scans': 688}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 100.19067524852959
# steps	 1000 	total rewards	 188.47988559253054
# Finished after 1449 timesteps (8.756784915924072 seconds) with total reward 255.07340016824605
# {'coverage_prop': '0.953', 'intensity_prop': '0.471', 'ms1ms2_ratio': '0.614', 'efficiency': '0.450', 'TP': '200', 'FP': '204', 'FN': '20', 'precision': '0.495', 'recall': '0.909', 'f1': '0.641', 'total_rewards': 255.07340016824404, 'invalid_action_count': 25, 'num_ms1_scans': 551, 'num_ms2_scans': 898}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 84.22186012545981
# steps	 1000 	total rewards	 157.25907155661287
# Finished after 1436 timesteps (9.529303073883057 seconds) with total reward 224.43122743806452
# {'coverage_prop': '0.919', 'intensity_prop': '0.486', 'ms1ms2_ratio': '0.647', 'efficiency': '0.405', 'TP': '190', 'FP': '163', 'FN': '31', 'precision': '0.538', 'recall': '0.860', 'f1': '0.662', 'total_rewards': 224.43122743806225, 'invalid_action_count': 33, 'num_ms1_scans': 564, 'num_ms2_scans': 872}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.9543677461364
# steps	 1000 	total rewards	 162.36996339862242
# Finished after 1464 timesteps (10.907594919204712 seconds) with total reward 234.82529674371582
# {'coverage_prop': '0.894', 'intensity_prop': '0.461', 'ms1ms2_ratio': '0.578', 'efficiency': '0.427', 'TP': '223', 'FP': '173', 'FN': '47', 'precision': '0.563', 'recall': '0.826', 'f1': '0.670', 'total_rewards': 234.82529674371398, 'invalid_action_count': 42, 'num_ms1_scans': 536, 'num_ms2_scans': 928}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 81.79068363225333
# steps	 1000 	total rewards	 174.8645998861415
# Finished after 1367 timesteps (7.876782655715942 seconds) with total reward 226.23645091533376
# {'coverage_prop': '0.976', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.862', 'efficiency': '0.331', 'TP': '159', 'FP': '84', 'FN': '6', 'precision': '0.654', 'recall': '0.964', 'f1': '0.779', 'total_rewards': 226.23645091533132, 'invalid_action_count': 2, 'num_ms1_scans': 633, 'num_ms2_scans': 734}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 81.6976820947751
# steps	 1000 	total rewards	 170.77574214247173
# Finished after 1389 timesteps (6.982324838638306 seconds) with total reward 226.65022151582616
# {'coverage_prop': '0.968', 'intensity_prop': '0.541', 'ms1ms2_ratio': '0.785', 'efficiency': '0.312', 'TP': '139', 'FP': '104', 'FN': '8', 'precision': '0.572', 'recall': '0.946', 'f1': '0.713', 'total_rewards': 226.65022151582394, 'invalid_action_count': 2, 'num_ms1_scans': 611, 'num_ms2_scans': 778}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 73.79296393990938
# steps	 1000 	total rewards	 141.69675924651156
# Finished after 1427 timesteps (7.429224967956543 seconds) with total reward 195.97977594488896
# {'coverage_prop': '0.927', 'intensity_prop': '0.500', 'ms1ms2_ratio': '0.673', 'efficiency': '0.326', 'TP': '157', 'FP': '121', 'FN': '22', 'precision': '0.565', 'recall': '0.877', 'f1': '0.687', 'total_rewards': 195.97977594488677, 'invalid_action_count': 28, 'num_ms1_scans': 574, 'num_ms2_scans': 853}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 71.38289231191544
# steps	 1000 	total rewards	 163.77588979359237
# Finished after 1356 timesteps (5.332830190658569 seconds) with total reward 205.70938375574906
# {'coverage_prop': '0.971', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.904', 'efficiency': '0.281', 'TP': '130', 'FP': '70', 'FN': '6', 'precision': '0.650', 'recall': '0.956', 'f1': '0.774', 'total_rewards': 205.70938375574687, 'invalid_action_count': 2, 'num_ms1_scans': 644, 'num_ms2_scans': 712}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 87.5506442289413
# steps	 1000 	total rewards	 186.98640381997785
# Finished after 1453 timesteps (7.806257963180542 seconds) with total reward 251.89606513550282
# {'coverage_prop': '0.934', 'intensity_prop': '0.497', 'ms1ms2_ratio': '0.604', 'efficiency': '0.419', 'TP': '215', 'FP': '165', 'FN': '27', 'precision': '0.566', 'recall': '0.888', 'f1': '0.691', 'total_rewards': 251.89606513550078, 'invalid_action_count': 26, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 100.30991874251515
# steps	 1000 	total rewards	 188.93365998489094
# Finished after 1465 timesteps (7.288440227508545 seconds) with total reward 262.86585125557974
# {'coverage_prop': '0.908', 'intensity_prop': '0.450', 'ms1ms2_ratio': '0.575', 'efficiency': '0.486', 'TP': '230', 'FP': '222', 'FN': '46', 'precision': '0.509', 'recall': '0.833', 'f1': '0.632', 'total_rewards': 262.8658512555781, 'invalid_action_count': 30, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 95.63000334462687
# steps	 1000 	total rewards	 193.6972276910402
# Finished after 1428 timesteps (8.267560958862305 seconds) with total reward 259.4462075784557
# {'coverage_prop': '0.946', 'intensity_prop': '0.488', 'ms1ms2_ratio': '0.670', 'efficiency': '0.412', 'TP': '192', 'FP': '160', 'FN': '20', 'precision': '0.545', 'recall': '0.906', 'f1': '0.681', 'total_rewards': 259.44620757845377, 'invalid_action_count': 12, 'num_ms1_scans': 573, 'num_ms2_scans': 855}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 82.64870376134176
# steps	 1000 	total rewards	 175.9510888394878
# Finished after 1431 timesteps (6.926181077957153 seconds) with total reward 227.65620669521016
# {'coverage_prop': '0.977', 'intensity_prop': '0.523', 'ms1ms2_ratio': '0.660', 'efficiency': '0.342', 'TP': '168', 'FP': '127', 'FN': '7', 'precision': '0.569', 'recall': '0.960', 'f1': '0.715', 'total_rewards': 227.65620669520797, 'invalid_action_count': 20, 'num_ms1_scans': 569, 'num_ms2_scans': 862}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 82.2751533657883
# steps	 1000 	total rewards	 178.49391209145608
# Finished after 1410 timesteps (6.470871210098267 seconds) with total reward 238.1660434870292
# {'coverage_prop': '0.992', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.720', 'efficiency': '0.321', 'TP': '159', 'FP': '104', 'FN': '2', 'precision': '0.605', 'recall': '0.988', 'f1': '0.750', 'total_rewards': 238.16604348702674, 'invalid_action_count': 4, 'num_ms1_scans': 590, 'num_ms2_scans': 820}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 95.41994064782276
# steps	 1000 	total rewards	 176.5915796224317
# Finished after 1466 timesteps (9.802014112472534 seconds) with total reward 239.6829993004564
# {'coverage_prop': '0.900', 'intensity_prop': '0.457', 'ms1ms2_ratio': '0.573', 'efficiency': '0.452', 'TP': '228', 'FP': '193', 'FN': '47', 'precision': '0.542', 'recall': '0.829', 'f1': '0.655', 'total_rewards': 239.68299930045453, 'invalid_action_count': 43, 'num_ms1_scans': 534, 'num_ms2_scans': 932}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 75.29051059542806
# steps	 1000 	total rewards	 171.6300465401078
# Finished after 1360 timesteps (11.857807874679565 seconds) with total reward 219.037457310124
# {'coverage_prop': '0.974', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.892', 'efficiency': '0.317', 'TP': '124', 'FP': '104', 'FN': '6', 'precision': '0.544', 'recall': '0.954', 'f1': '0.693', 'total_rewards': 219.03745731012145, 'invalid_action_count': 1, 'num_ms1_scans': 641, 'num_ms2_scans': 719}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 88.4002213071069
# steps	 1000 	total rewards	 177.4897083841828
# Finished after 1430 timesteps (9.751361846923828 seconds) with total reward 237.16162150785982
# {'coverage_prop': '0.975', 'intensity_prop': '0.547', 'ms1ms2_ratio': '0.663', 'efficiency': '0.365', 'TP': '191', 'FP': '123', 'FN': '8', 'precision': '0.608', 'recall': '0.960', 'f1': '0.745', 'total_rewards': 237.16162150785797, 'invalid_action_count': 21, 'num_ms1_scans': 570, 'num_ms2_scans': 860}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 84.96127699274807
# steps	 1000 	total rewards	 185.2377447058392
# Finished after 1393 timesteps (7.3232738971710205 seconds) with total reward 249.79474932157575
# {'coverage_prop': '0.968', 'intensity_prop': '0.536', 'ms1ms2_ratio': '0.772', 'efficiency': '0.382', 'TP': '174', 'FP': '126', 'FN': '10', 'precision': '0.580', 'recall': '0.946', 'f1': '0.719', 'total_rewards': 249.79474932157348, 'invalid_action_count': 5, 'num_ms1_scans': 607, 'num_ms2_scans': 786}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 84.17430532493864
# steps	 1000 	total rewards	 177.04479903485108
# Finished after 1434 timesteps (9.113202095031738 seconds) with total reward 236.93613964952783
# {'coverage_prop': '0.942', 'intensity_prop': '0.494', 'ms1ms2_ratio': '0.652', 'efficiency': '0.374', 'TP': '179', 'FP': '146', 'FN': '20', 'precision': '0.551', 'recall': '0.899', 'f1': '0.683', 'total_rewards': 236.93613964952587, 'invalid_action_count': 22, 'num_ms1_scans': 566, 'num_ms2_scans': 868}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 91.8888320276085
# steps	 1000 	total rewards	 176.22827694771684
# Finished after 1450 timesteps (19.507649183273315 seconds) with total reward 223.96801193364513
# {'coverage_prop': '0.952', 'intensity_prop': '0.504', 'ms1ms2_ratio': '0.611', 'efficiency': '0.419', 'TP': '215', 'FP': '162', 'FN': '19', 'precision': '0.570', 'recall': '0.919', 'f1': '0.704', 'total_rewards': 223.9680119336431, 'invalid_action_count': 44, 'num_ms1_scans': 550, 'num_ms2_scans': 900}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 68.42195096633802
# steps	 1000 	total rewards	 158.63429604660075
# Finished after 1359 timesteps (9.200002908706665 seconds) with total reward 206.37246447082723
# {'coverage_prop': '0.990', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.893', 'efficiency': '0.280', 'TP': '122', 'FP': '79', 'FN': '2', 'precision': '0.607', 'recall': '0.984', 'f1': '0.751', 'total_rewards': 206.37246447082512, 'invalid_action_count': 1, 'num_ms1_scans': 641, 'num_ms2_scans': 718}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 80.73938298862916
# steps	 1000 	total rewards	 182.34400808613182
# Finished after 1396 timesteps (9.828079223632812 seconds) with total reward 250.44723065400865
# {'coverage_prop': '0.982', 'intensity_prop': '0.571', 'ms1ms2_ratio': '0.765', 'efficiency': '0.349', 'TP': '171', 'FP': '105', 'FN': '5', 'precision': '0.620', 'recall': '0.972', 'f1': '0.757', 'total_rewards': 250.44723065400646, 'invalid_action_count': 6, 'num_ms1_scans': 605, 'num_ms2_scans': 791}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 106.52454583572123
# steps	 1000 	total rewards	 193.41366455653255
# Finished after 1453 timesteps (20.627315998077393 seconds) with total reward 264.65605032528845
# {'coverage_prop': '0.870', 'intensity_prop': '0.446', 'ms1ms2_ratio': '0.604', 'efficiency': '0.474', 'TP': '249', 'FP': '180', 'FN': '64', 'precision': '0.580', 'recall': '0.796', 'f1': '0.671', 'total_rewards': 264.6560503252873, 'invalid_action_count': 32, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 83.90042365535534
# steps	 1000 	total rewards	 169.88568035654265
# Finished after 1422 timesteps (14.618607997894287 seconds) with total reward 230.88331986947912
# {'coverage_prop': '0.974', 'intensity_prop': '0.540', 'ms1ms2_ratio': '0.685', 'efficiency': '0.351', 'TP': '173', 'FP': '123', 'FN': '8', 'precision': '0.584', 'recall': '0.956', 'f1': '0.725', 'total_rewards': 230.88331986947702, 'invalid_action_count': 14, 'num_ms1_scans': 578, 'num_ms2_scans': 844}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 96.2947472112688
# steps	 1000 	total rewards	 210.15683842109235
# steps	 1500 	total rewards	 314.798634056055
# Finished after 1708 timesteps (31.57590389251709 seconds) with total reward 349.6966282125401
# {'coverage_prop': '0.932', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.206', 'efficiency': '0.280', 'TP': '354', 'FP': '43', 'FN': '29', 'precision': '0.892', 'recall': '0.924', 'f1': '0.908', 'total_rewards': 349.6966282125408, 'invalid_action_count': 0, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.71672116839305
# steps	 1000 	total rewards	 202.23560506519314
# steps	 1500 	total rewards	 283.18536291001726
# Finished after 1542 timesteps (17.902974843978882 seconds) with total reward 288.5472310775797
# {'coverage_prop': '0.962', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.424', 'efficiency': '0.233', 'TP': '237', 'FP': '15', 'FN': '10', 'precision': '0.940', 'recall': '0.960', 'f1': '0.950', 'total_rewards': 288.5472310775799, 'invalid_action_count': 0, 'num_ms1_scans': 459, 'num_ms2_scans': 1083}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.62128539259734
# steps	 1000 	total rewards	 209.44701077429943
# steps	 1500 	total rewards	 315.09467642816026
# Finished after 1657 timesteps (19.046507120132446 seconds) with total reward 337.7852727539003
# {'coverage_prop': '0.924', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.261', 'efficiency': '0.277', 'TP': '329', 'FP': '35', 'FN': '30', 'precision': '0.904', 'recall': '0.916', 'f1': '0.910', 'total_rewards': 337.78527275390053, 'invalid_action_count': 0, 'num_ms1_scans': 343, 'num_ms2_scans': 1314}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 104.41605033421533
# steps	 1000 	total rewards	 220.61543523078416
# steps	 1500 	total rewards	 321.7969920978544
# Finished after 1704 timesteps (14.98066520690918 seconds) with total reward 360.2671640277904
# {'coverage_prop': '0.925', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.210', 'efficiency': '0.297', 'TP': '386', 'FP': '32', 'FN': '34', 'precision': '0.923', 'recall': '0.919', 'f1': '0.921', 'total_rewards': 360.26716402779084, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 94.83696526824527
# steps	 1000 	total rewards	 230.4353747798644
# steps	 1500 	total rewards	 341.20598376036196
# Finished after 1691 timesteps (9.922936916351318 seconds) with total reward 373.00301431907974
# {'coverage_prop': '0.961', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.224', 'efficiency': '0.304', 'TP': '368', 'FP': '52', 'FN': '17', 'precision': '0.876', 'recall': '0.956', 'f1': '0.914', 'total_rewards': 373.00301431908053, 'invalid_action_count': 0, 'num_ms1_scans': 309, 'num_ms2_scans': 1382}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.96535245459845
# steps	 1000 	total rewards	 177.0309816592628
# Finished after 1398 timesteps (7.562474012374878 seconds) with total reward 239.4026520560644
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.758', 'efficiency': '0.242', 'TP': '180', 'FP': '12', 'FN': '8', 'precision': '0.938', 'recall': '0.957', 'f1': '0.947', 'total_rewards': 239.40265205606244, 'invalid_action_count': 0, 'num_ms1_scans': 603, 'num_ms2_scans': 795}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 105.43142187016116
# steps	 1000 	total rewards	 217.16234875580517
# steps	 1500 	total rewards	 317.53882861089824
# Finished after 1728 timesteps (10.488082885742188 seconds) with total reward 356.0813403930652
# {'coverage_prop': '0.883', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.187', 'efficiency': '0.290', 'TP': '364', 'FP': '58', 'FN': '56', 'precision': '0.863', 'recall': '0.867', 'f1': '0.865', 'total_rewards': 356.08134039306697, 'invalid_action_count': 0, 'num_ms1_scans': 272, 'num_ms2_scans': 1456}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.26121603810041
# steps	 1000 	total rewards	 179.87909305623398
# Finished after 1458 timesteps (10.873498916625977 seconds) with total reward 248.2539839548109
# {'coverage_prop': '0.961', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.592', 'efficiency': '0.214', 'TP': '187', 'FP': '9', 'FN': '8', 'precision': '0.954', 'recall': '0.959', 'f1': '0.957', 'total_rewards': 248.2539839548094, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 916}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 101.73075787582624
# steps	 1000 	total rewards	 202.63638040748515
# steps	 1500 	total rewards	 318.35490928225283
# Finished after 1723 timesteps (14.714637994766235 seconds) with total reward 356.04648908095874
# {'coverage_prop': '0.939', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.192', 'efficiency': '0.275', 'TP': '363', 'FP': '35', 'FN': '26', 'precision': '0.912', 'recall': '0.933', 'f1': '0.922', 'total_rewards': 356.04648908096, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1445}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 91.08268938564159
# steps	 1000 	total rewards	 203.1460220195836
# steps	 1500 	total rewards	 302.55484646418915
# Finished after 1647 timesteps (13.399119138717651 seconds) with total reward 323.3439747097695
# {'coverage_prop': '0.945', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.273', 'efficiency': '0.281', 'TP': '325', 'FP': '38', 'FN': '21', 'precision': '0.895', 'recall': '0.939', 'f1': '0.917', 'total_rewards': 323.34397470977063, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 92.89177994740865
# steps	 1000 	total rewards	 200.33780966885
# steps	 1500 	total rewards	 308.44066178823545
# Finished after 1722 timesteps (14.429903984069824 seconds) with total reward 346.27603435685785
# {'coverage_prop': '0.898', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '358', 'FP': '40', 'FN': '45', 'precision': '0.899', 'recall': '0.888', 'f1': '0.894', 'total_rewards': 346.27603435685813, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.66797281187884
# steps	 1000 	total rewards	 184.53222725829215
# steps	 1500 	total rewards	 256.3446714108332
# Finished after 1518 timesteps (24.269893884658813 seconds) with total reward 258.1259622000612
# {'coverage_prop': '0.960', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.467', 'efficiency': '0.231', 'TP': '228', 'FP': '11', 'FN': '10', 'precision': '0.954', 'recall': '0.958', 'f1': '0.956', 'total_rewards': 258.12596220006, 'invalid_action_count': 0, 'num_ms1_scans': 483, 'num_ms2_scans': 1035}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.17262365571366
# steps	 1000 	total rewards	 179.03752773958183
# steps	 1500 	total rewards	 257.1736312003494
# Finished after 1583 timesteps (12.390007019042969 seconds) with total reward 268.1257663511901
# {'coverage_prop': '0.948', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.359', 'efficiency': '0.204', 'TP': '219', 'FP': '19', 'FN': '13', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 268.1257663511893, 'invalid_action_count': 0, 'num_ms1_scans': 418, 'num_ms2_scans': 1165}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 80.6116798332078
# steps	 1000 	total rewards	 173.60201913423703
# steps	 1500 	total rewards	 262.64695811092656
# Finished after 1630 timesteps (15.600521326065063 seconds) with total reward 277.80967508193527
# {'coverage_prop': '0.937', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.294', 'efficiency': '0.223', 'TP': '248', 'FP': '33', 'FN': '19', 'precision': '0.883', 'recall': '0.929', 'f1': '0.905', 'total_rewards': 277.8096750819356, 'invalid_action_count': 0, 'num_ms1_scans': 370, 'num_ms2_scans': 1260}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 78.05105674125915
# steps	 1000 	total rewards	 168.53435625126963
# Finished after 1478 timesteps (20.75913715362549 seconds) with total reward 239.10890213610804
# {'coverage_prop': '0.951', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.546', 'efficiency': '0.205', 'TP': '183', 'FP': '13', 'FN': '10', 'precision': '0.934', 'recall': '0.948', 'f1': '0.941', 'total_rewards': 239.10890213610625, 'invalid_action_count': 0, 'num_ms1_scans': 522, 'num_ms2_scans': 956}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.24788449900285
# steps	 1000 	total rewards	 201.71725751361183
# steps	 1500 	total rewards	 309.1326060834659
# Finished after 1647 timesteps (22.72864603996277 seconds) with total reward 341.7556904214264
# {'coverage_prop': '0.941', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.273', 'efficiency': '0.296', 'TP': '344', 'FP': '39', 'FN': '24', 'precision': '0.898', 'recall': '0.935', 'f1': '0.916', 'total_rewards': 341.7556904214272, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 109.4689156831942
# steps	 1000 	total rewards	 222.9984511917354
# steps	 1500 	total rewards	 327.33892555353907
# Finished after 1717 timesteps (28.077157974243164 seconds) with total reward 367.5454464599467
# {'coverage_prop': '0.910', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.197', 'efficiency': '0.316', 'TP': '409', 'FP': '44', 'FN': '45', 'precision': '0.903', 'recall': '0.901', 'f1': '0.902', 'total_rewards': 367.54544645994855, 'invalid_action_count': 0, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.66449307716269
# steps	 1000 	total rewards	 208.2255550813367
# steps	 1500 	total rewards	 298.09584404674365
# Finished after 1669 timesteps (24.71664524078369 seconds) with total reward 320.7417873236513
# {'coverage_prop': '0.938', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.248', 'efficiency': '0.261', 'TP': '320', 'FP': '29', 'FN': '23', 'precision': '0.917', 'recall': '0.933', 'f1': '0.925', 'total_rewards': 320.7417873236517, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 1337}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 86.58222225646823
# steps	 1000 	total rewards	 193.83662787853737
# steps	 1500 	total rewards	 283.52631003777475
# Finished after 1605 timesteps (10.184251070022583 seconds) with total reward 298.66096748916345
# {'coverage_prop': '0.947', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.328', 'efficiency': '0.237', 'TP': '262', 'FP': '24', 'FN': '16', 'precision': '0.916', 'recall': '0.942', 'f1': '0.929', 'total_rewards': 298.6609674891638, 'invalid_action_count': 0, 'num_ms1_scans': 396, 'num_ms2_scans': 1209}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.801418530762
# steps	 1000 	total rewards	 187.14255144611414
# steps	 1500 	total rewards	 271.3242882690306
# Finished after 1602 timesteps (8.434891939163208 seconds) with total reward 281.7817604944602
# {'coverage_prop': '0.977', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.332', 'efficiency': '0.215', 'TP': '237', 'FP': '22', 'FN': '6', 'precision': '0.915', 'recall': '0.975', 'f1': '0.944', 'total_rewards': 281.7817604944603, 'invalid_action_count': 0, 'num_ms1_scans': 399, 'num_ms2_scans': 1203}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.64570324480422
# steps	 1000 	total rewards	 209.8538266334351
# steps	 1500 	total rewards	 302.50968702007094
# Finished after 1712 timesteps (10.625908136367798 seconds) with total reward 343.4124818881533
# {'coverage_prop': '0.874', 'intensity_prop': '0.677', 'ms1ms2_ratio': '0.202', 'efficiency': '0.287', 'TP': '360', 'FP': '49', 'FN': '59', 'precision': '0.880', 'recall': '0.859', 'f1': '0.870', 'total_rewards': 343.4124818881536, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 79.34995801371568
# steps	 1000 	total rewards	 185.05815954422587
# Finished after 1459 timesteps (8.41629695892334 seconds) with total reward 260.9168005156736
# {'coverage_prop': '0.957', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.591', 'efficiency': '0.244', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 260.9168005156723, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 917}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 91.16098210415569
# steps	 1000 	total rewards	 198.46979716592637
# steps	 1500 	total rewards	 285.75298617886926
# Finished after 1620 timesteps (8.972277402877808 seconds) with total reward 305.9567725268008
# {'coverage_prop': '0.960', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.306', 'efficiency': '0.249', 'TP': '283', 'FP': '26', 'FN': '13', 'precision': '0.916', 'recall': '0.956', 'f1': '0.936', 'total_rewards': 305.956772526802, 'invalid_action_count': 0, 'num_ms1_scans': 380, 'num_ms2_scans': 1240}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 95.11617971055398
# steps	 1000 	total rewards	 204.85149167720783
# steps	 1500 	total rewards	 291.49540729766466
# Finished after 1557 timesteps (8.428670167922974 seconds) with total reward 300.47640370637237
# {'coverage_prop': '0.948', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.398', 'efficiency': '0.264', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927', 'total_rewards': 300.4764037063734, 'invalid_action_count': 0, 'num_ms1_scans': 443, 'num_ms2_scans': 1114}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 93.89340790301048
# steps	 1000 	total rewards	 205.42243398475907
# steps	 1500 	total rewards	 299.97419106939174
# Finished after 1655 timesteps (8.992286920547485 seconds) with total reward 325.3669482550192
# {'coverage_prop': '0.948', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.263', 'efficiency': '0.250', 'TP': '301', 'FP': '26', 'FN': '18', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 325.3669482550196, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 92.46389424693754
# steps	 1000 	total rewards	 194.83826945588413
# steps	 1500 	total rewards	 303.0523187043243
# Finished after 1658 timesteps (9.842849016189575 seconds) with total reward 330.86551958049847
# {'coverage_prop': '0.957', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.260', 'efficiency': '0.288', 'TP': '344', 'FP': '35', 'FN': '17', 'precision': '0.908', 'recall': '0.953', 'f1': '0.930', 'total_rewards': 330.8655195804994, 'invalid_action_count': 0, 'num_ms1_scans': 342, 'num_ms2_scans': 1316}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 72.1469507255527
# steps	 1000 	total rewards	 171.47678380953522
# Finished after 1453 timesteps (7.527789115905762 seconds) with total reward 239.9201738382847
# {'coverage_prop': '0.966', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.604', 'efficiency': '0.216', 'TP': '184', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.963', 'f1': '0.951', 'total_rewards': 239.92017383828332, 'invalid_action_count': 0, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 88.31235132594269
# steps	 1000 	total rewards	 195.74792284704353
# steps	 1500 	total rewards	 294.01215539849073
# Finished after 1539 timesteps (12.55889081954956 seconds) with total reward 299.6239201087449
# {'coverage_prop': '0.957', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.429', 'efficiency': '0.250', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 299.62392010874515, 'invalid_action_count': 0, 'num_ms1_scans': 462, 'num_ms2_scans': 1077}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.85875030891819
# steps	 1000 	total rewards	 197.99866949790092
# steps	 1500 	total rewards	 300.4205818023136
# Finished after 1734 timesteps (10.10745906829834 seconds) with total reward 347.5622303363375
# {'coverage_prop': '0.856', 'intensity_prop': '0.645', 'ms1ms2_ratio': '0.181', 'efficiency': '0.287', 'TP': '358', 'FP': '64', 'FN': '71', 'precision': '0.848', 'recall': '0.834', 'f1': '0.841', 'total_rewards': 347.5622303363379, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1468}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.32388476353701
# steps	 1000 	total rewards	 195.74111008357096
# steps	 1500 	total rewards	 278.7575512609741
# Finished after 1628 timesteps (9.018850088119507 seconds) with total reward 293.7826477847459
# {'coverage_prop': '0.954', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.296', 'efficiency': '0.231', 'TP': '271', 'FP': '19', 'FN': '14', 'precision': '0.934', 'recall': '0.951', 'f1': '0.943', 'total_rewards': 293.78264778474596, 'invalid_action_count': 0, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe8d4d24400>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe8e2055580>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe8e2071820>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.485', 'ms1ms2_ratio': '2.462', 'efficiency': '0.734', 'TP': '121', 'FP': '127', 'FN': '14', 'precision': '0.488', 'recall': '0.896', 'f1': '0.632'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.476', 'efficiency': '0.749', 'TP': '188', 'FP': '191', 'FN': '15', 'precision': '0.496', 'recall': '0.926', 'f1': '0.646'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.530', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '245', 'FP': '187', 'FN': '20', 'precision': '0.567', 'recall': '0.925', 'f1': '0.703'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '198', 'FP': '202', 'FN': '24', 'precision': '0.495', 'recall': '0.892', 'f1': '0.637'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.531', 'ms1ms2_ratio': '1.210', 'efficiency': '0.728', 'TP': '233', 'FP': '193', 'FN': '17', 'precision': '0.547', 'recall': '0.932', 'f1': '0.689'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.978', 'efficiency': '0.705', 'TP': '148', 'FP': '137', 'FN': '15', 'precision': '0.519', 'recall': '0.908', 'f1': '0.661'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.548', 'ms1ms2_ratio': '1.391', 'efficiency': '0.743', 'TP': '217', 'FP': '176', 'FN': '14', 'precision': '0.552', 'recall': '0.939', 'f1': '0.696'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '191', 'FP': '163', 'FN': '18', 'precision': '0.540', 'recall': '0.914', 'f1': '0.679'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.350', 'efficiency': '0.738', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.493', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '108', 'FP': '112', 'FN': '14', 'precision': '0.491', 'recall': '0.885', 'f1': '0.632'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '136', 'FP': '155', 'FN': '19', 'precision': '0.467', 'recall': '0.877', 'f1': '0.610'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.509', 'ms1ms2_ratio': '2.250', 'efficiency': '0.739', 'TP': '143', 'FP': '126', 'FN': '12', 'precision': '0.532', 'recall': '0.923', 'f1': '0.675'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.514', 'ms1ms2_ratio': '2.015', 'efficiency': '0.729', 'TP': '149', 'FP': '141', 'FN': '14', 'precision': '0.514', 'recall': '0.914', 'f1': '0.658'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1074.639322                1223.0          0.721           0.223
# 1  random   -1346.759398                1433.0          0.656           0.156
# 2  random   -1031.956053                1173.0          0.746           0.221
# 3  random   -1108.129745                1254.0          0.699           0.224
# 4  random   -1164.836544                1306.0          0.744           0.211
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.155      0.303   0.439  0.358
# 1          0.005       0.087      0.221   0.297  0.253
# 2          0.006       0.149      0.282   0.454  0.348
# 3          0.005       0.160      0.310   0.419  0.356
# 4          0.004       0.164      0.271   0.440  0.335

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     214.837083                  65.0          0.908           0.472
# 31    DQN     238.061587                   1.0          0.981           0.510
# 32    DQN     237.747108                  33.0          0.929           0.463
# 33    DQN     228.746267                  58.0          0.931           0.477
# 34    DQN     218.813790                  59.0          0.922           0.452
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.566       0.413      0.545   0.844  0.662
# 31          0.866       0.351      0.537   0.965  0.690
# 32          0.606       0.405      0.544   0.877  0.671
# 33          0.552       0.443      0.544   0.881  0.673
# 34          0.582       0.436      0.516   0.860  0.645

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
