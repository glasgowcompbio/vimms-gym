# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-15 10:21:26.783 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fbc35ebcd30>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fbbf097f850>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fbc10babaf0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fbc35ebcd30>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fbbf097f850>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fbc10babaf0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fbc35ebcd30>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fbbf097f850>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fbc10babaf0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -314.6263396234757
# steps	 1000 	total rewards	 -583.1278673934825
# steps	 1500 	total rewards	 -736.4204605226637
# Finished after 1988 timesteps (4.10323691368103 seconds) with total reward -905.02110535856
# {'coverage_prop': '0.772', 'intensity_prop': '0.263', 'ms1ms2_ratio': '0.006', 'efficiency': '0.166', 'TP': '101', 'FP': '228', 'FN': '97', 'precision': '0.307', 'recall': '0.510', 'f1': '0.383', 'total_rewards': -905.0211053585588, 'invalid_action_count': 1064, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -398.1373223616107
# steps	 1000 	total rewards	 -751.4134293870743
# steps	 1500 	total rewards	 -1026.935075789461
# Finished after 1990 timesteps (2.6173551082611084 seconds) with total reward -1296.9343556157748
# {'coverage_prop': '0.679', 'intensity_prop': '0.167', 'ms1ms2_ratio': '0.005', 'efficiency': '0.090', 'TP': '38', 'FP': '140', 'FN': '84', 'precision': '0.213', 'recall': '0.311', 'f1': '0.253', 'total_rewards': -1296.934355615775, 'invalid_action_count': 1390, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -409.3662740094762
# steps	 1000 	total rewards	 -620.8503129569575
# steps	 1500 	total rewards	 -779.4249975740851
# Finished after 1986 timesteps (3.606574773788452 seconds) with total reward -968.7129592252659
# {'coverage_prop': '0.784', 'intensity_prop': '0.255', 'ms1ms2_ratio': '0.007', 'efficiency': '0.157', 'TP': '89', 'FP': '220', 'FN': '85', 'precision': '0.288', 'recall': '0.511', 'f1': '0.369', 'total_rewards': -968.7129592252661, 'invalid_action_count': 1120, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -293.7453833211807
# steps	 1000 	total rewards	 -522.2465131583403
# steps	 1500 	total rewards	 -646.4068827482905
# Finished after 1984 timesteps (4.2540178298950195 seconds) with total reward -824.8584917724068
# {'coverage_prop': '0.814', 'intensity_prop': '0.312', 'ms1ms2_ratio': '0.008', 'efficiency': '0.187', 'TP': '142', 'FP': '226', 'FN': '84', 'precision': '0.386', 'recall': '0.628', 'f1': '0.478', 'total_rewards': -824.8584917724065, 'invalid_action_count': 1003, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -369.1981576821009
# steps	 1000 	total rewards	 -721.5367531433953
# steps	 1500 	total rewards	 -808.9470848315541
# Finished after 1986 timesteps (3.762788772583008 seconds) with total reward -973.2596870502391
# {'coverage_prop': '0.769', 'intensity_prop': '0.261', 'ms1ms2_ratio': '0.007', 'efficiency': '0.170', 'TP': '105', 'FP': '231', 'FN': '101', 'precision': '0.312', 'recall': '0.510', 'f1': '0.387', 'total_rewards': -973.2596870502393, 'invalid_action_count': 1136, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -395.85061960166286
# steps	 1000 	total rewards	 -732.9775487234598
# steps	 1500 	total rewards	 -1017.7398194252138
# Finished after 1985 timesteps (2.2683498859405518 seconds) with total reward -1280.8279723607372
# {'coverage_prop': '0.810', 'intensity_prop': '0.257', 'ms1ms2_ratio': '0.008', 'efficiency': '0.082', 'TP': '47', 'FP': '115', 'FN': '38', 'precision': '0.290', 'recall': '0.553', 'f1': '0.381', 'total_rewards': -1280.8279723607384, 'invalid_action_count': 1367, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -459.38541187825774
# steps	 1000 	total rewards	 -949.3854118782577
# steps	 1500 	total rewards	 -1232.7113498597735
# Finished after 1997 timesteps (3.883636951446533 seconds) with total reward -1518.7626167538428
# {'coverage_prop': '0.467', 'intensity_prop': '0.103', 'ms1ms2_ratio': '0.002', 'efficiency': '0.112', 'TP': '43', 'FP': '180', 'FN': '255', 'precision': '0.193', 'recall': '0.144', 'f1': '0.165', 'total_rewards': -1518.7626167538424, 'invalid_action_count': 1602, 'num_ms1_scans': 3, 'num_ms2_scans': 1994}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -384.4127950759758
# steps	 1000 	total rewards	 -699.1300637821096
# steps	 1500 	total rewards	 -977.854867349831
# Finished after 1987 timesteps (2.327169895172119 seconds) with total reward -1334.6528105063699
# {'coverage_prop': '0.755', 'intensity_prop': '0.221', 'ms1ms2_ratio': '0.007', 'efficiency': '0.078', 'TP': '41', 'FP': '113', 'FN': '50', 'precision': '0.266', 'recall': '0.451', 'f1': '0.335', 'total_rewards': -1334.6528105063694, 'invalid_action_count': 1418, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -401.37191995996534
# steps	 1000 	total rewards	 -750.8896822131765
# steps	 1500 	total rewards	 -1045.173382654176
# Finished after 1993 timesteps (3.9305191040039062 seconds) with total reward -1402.679671593456
# {'coverage_prop': '0.634', 'intensity_prop': '0.137', 'ms1ms2_ratio': '0.004', 'efficiency': '0.135', 'TP': '52', 'FP': '217', 'FN': '155', 'precision': '0.193', 'recall': '0.251', 'f1': '0.218', 'total_rewards': -1402.6796715934554, 'invalid_action_count': 1515, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -372.1940454627189
# steps	 1000 	total rewards	 -641.8708675344865
# steps	 1500 	total rewards	 -878.902149518034
# Finished after 1991 timesteps (3.3174450397491455 seconds) with total reward -1163.5250290914755
# {'coverage_prop': '0.724', 'intensity_prop': '0.241', 'ms1ms2_ratio': '0.005', 'efficiency': '0.140', 'TP': '84', 'FP': '194', 'FN': '106', 'precision': '0.302', 'recall': '0.442', 'f1': '0.359', 'total_rewards': -1163.5250290914748, 'invalid_action_count': 1295, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -418.6298829948177
# steps	 1000 	total rewards	 -804.546790489901
# steps	 1500 	total rewards	 -1082.4665675335832
# Finished after 1997 timesteps (4.4147772789001465 seconds) with total reward -1546.9185090727929
# {'coverage_prop': '0.528', 'intensity_prop': '0.114', 'ms1ms2_ratio': '0.002', 'efficiency': '0.117', 'TP': '44', 'FP': '190', 'FN': '209', 'precision': '0.188', 'recall': '0.174', 'f1': '0.181', 'total_rewards': -1546.918509072793, 'invalid_action_count': 1632, 'num_ms1_scans': 3, 'num_ms2_scans': 1994}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -404.9509202098471
# steps	 1000 	total rewards	 -765.841505666405
# steps	 1500 	total rewards	 -1129.5714083145554
# Finished after 1992 timesteps (2.4960949420928955 seconds) with total reward -1415.4352265828236
# {'coverage_prop': '0.643', 'intensity_prop': '0.187', 'ms1ms2_ratio': '0.004', 'efficiency': '0.081', 'TP': '50', 'FP': '110', 'FN': '89', 'precision': '0.312', 'recall': '0.360', 'f1': '0.334', 'total_rewards': -1415.4352265828234, 'invalid_action_count': 1488, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -357.47916080924705
# steps	 1000 	total rewards	 -632.8870225571825
# steps	 1500 	total rewards	 -907.7210827656847
# Finished after 1985 timesteps (2.7278990745544434 seconds) with total reward -1181.2622057123367
# {'coverage_prop': '0.761', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.008', 'efficiency': '0.097', 'TP': '59', 'FP': '132', 'FN': '60', 'precision': '0.309', 'recall': '0.496', 'f1': '0.381', 'total_rewards': -1181.2622057123365, 'invalid_action_count': 1284, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -367.21875772995134
# steps	 1000 	total rewards	 -688.608359750302
# steps	 1500 	total rewards	 -898.5632840634911
# Finished after 1990 timesteps (3.2201437950134277 seconds) with total reward -1184.5071955104756
# {'coverage_prop': '0.783', 'intensity_prop': '0.243', 'ms1ms2_ratio': '0.005', 'efficiency': '0.119', 'TP': '67', 'FP': '168', 'FN': '65', 'precision': '0.285', 'recall': '0.508', 'f1': '0.365', 'total_rewards': -1184.5071955104754, 'invalid_action_count': 1296, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -350.16250233101005
# steps	 1000 	total rewards	 -706.7278447897398
# steps	 1500 	total rewards	 -978.9263533541853
# Finished after 1986 timesteps (2.3427393436431885 seconds) with total reward -1258.7877917652252
# {'coverage_prop': '0.782', 'intensity_prop': '0.259', 'ms1ms2_ratio': '0.007', 'efficiency': '0.082', 'TP': '55', 'FP': '106', 'FN': '45', 'precision': '0.342', 'recall': '0.550', 'f1': '0.421', 'total_rewards': -1258.787791765226, 'invalid_action_count': 1347, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -395.0543822525867
# steps	 1000 	total rewards	 -674.9812770979654
# steps	 1500 	total rewards	 -1137.3736982575394
# Finished after 1989 timesteps (3.276287078857422 seconds) with total reward -1373.72608790461
# {'coverage_prop': '0.602', 'intensity_prop': '0.164', 'ms1ms2_ratio': '0.006', 'efficiency': '0.124', 'TP': '62', 'FP': '183', 'FN': '162', 'precision': '0.253', 'recall': '0.277', 'f1': '0.264', 'total_rewards': -1373.7260879046105, 'invalid_action_count': 1478, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -283.1912190997448
# steps	 1000 	total rewards	 -510.89116948829286
# steps	 1500 	total rewards	 -541.9812387878917
# Finished after 1987 timesteps (4.649868965148926 seconds) with total reward -843.6526240544276
# {'coverage_prop': '0.773', 'intensity_prop': '0.294', 'ms1ms2_ratio': '0.007', 'efficiency': '0.195', 'TP': '142', 'FP': '243', 'FN': '113', 'precision': '0.369', 'recall': '0.557', 'f1': '0.444', 'total_rewards': -843.6526240544272, 'invalid_action_count': 1023, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -414.4637464786383
# steps	 1000 	total rewards	 -638.7642103576914
# steps	 1500 	total rewards	 -814.4569316121036
# Finished after 1989 timesteps (3.3406729698181152 seconds) with total reward -1069.7063277052405
# {'coverage_prop': '0.758', 'intensity_prop': '0.256', 'ms1ms2_ratio': '0.006', 'efficiency': '0.143', 'TP': '94', 'FP': '188', 'FN': '90', 'precision': '0.333', 'recall': '0.511', 'f1': '0.403', 'total_rewards': -1069.7063277052405, 'invalid_action_count': 1207, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -397.9661162091155
# steps	 1000 	total rewards	 -683.3660521983579
# steps	 1500 	total rewards	 -866.5932349909768
# Finished after 1991 timesteps (3.1648881435394287 seconds) with total reward -1176.45713816629
# {'coverage_prop': '0.781', 'intensity_prop': '0.221', 'ms1ms2_ratio': '0.005', 'efficiency': '0.119', 'TP': '63', 'FP': '173', 'FN': '66', 'precision': '0.267', 'recall': '0.488', 'f1': '0.345', 'total_rewards': -1176.4571381662895, 'invalid_action_count': 1295, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -444.3873731361806
# steps	 1000 	total rewards	 -810.6346428614188
# steps	 1500 	total rewards	 -1184.9424932954462
# Finished after 1993 timesteps (2.7657270431518555 seconds) with total reward -1496.1149576071261
# {'coverage_prop': '0.634', 'intensity_prop': '0.190', 'ms1ms2_ratio': '0.004', 'efficiency': '0.085', 'TP': '49', 'FP': '119', 'FN': '97', 'precision': '0.292', 'recall': '0.336', 'f1': '0.312', 'total_rewards': -1496.1149576071252, 'invalid_action_count': 1577, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -337.1267052110538
# steps	 1000 	total rewards	 -467.79142687049347
# steps	 1500 	total rewards	 -548.4519146477963
# Finished after 1987 timesteps (4.083956003189087 seconds) with total reward -904.1574274891672
# {'coverage_prop': '0.771', 'intensity_prop': '0.293', 'ms1ms2_ratio': '0.007', 'efficiency': '0.183', 'TP': '141', 'FP': '220', 'FN': '107', 'precision': '0.391', 'recall': '0.569', 'f1': '0.463', 'total_rewards': -904.1574274891666, 'invalid_action_count': 1072, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -425.27039780065115
# steps	 1000 	total rewards	 -822.660798427206
# steps	 1500 	total rewards	 -1138.4286415925026
# Finished after 1993 timesteps (3.186394214630127 seconds) with total reward -1468.8133197466536
# {'coverage_prop': '0.679', 'intensity_prop': '0.134', 'ms1ms2_ratio': '0.004', 'efficiency': '0.080', 'TP': '28', 'FP': '131', 'FN': '75', 'precision': '0.176', 'recall': '0.272', 'f1': '0.214', 'total_rewards': -1468.8133197466545, 'invalid_action_count': 1544, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -401.1660065466559
# steps	 1000 	total rewards	 -770.0020864330754
# steps	 1500 	total rewards	 -985.3173161808425
# Finished after 1992 timesteps (3.0065290927886963 seconds) with total reward -1254.5452339337985
# {'coverage_prop': '0.677', 'intensity_prop': '0.176', 'ms1ms2_ratio': '0.004', 'efficiency': '0.110', 'TP': '49', 'FP': '169', 'FN': '104', 'precision': '0.225', 'recall': '0.320', 'f1': '0.264', 'total_rewards': -1254.5452339337994, 'invalid_action_count': 1363, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -337.3875267202912
# steps	 1000 	total rewards	 -672.7795429928203
# steps	 1500 	total rewards	 -1028.4470232997292
# Finished after 1990 timesteps (2.940915107727051 seconds) with total reward -1396.2851475436082
# {'coverage_prop': '0.581', 'intensity_prop': '0.149', 'ms1ms2_ratio': '0.005', 'efficiency': '0.091', 'TP': '43', 'FP': '137', 'FN': '130', 'precision': '0.239', 'recall': '0.249', 'f1': '0.244', 'total_rewards': -1396.2851475436084, 'invalid_action_count': 1479, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -340.53838634596434
# steps	 1000 	total rewards	 -628.3011097170048
# steps	 1500 	total rewards	 -982.8635838860057
# Finished after 1991 timesteps (3.265346050262451 seconds) with total reward -1243.0689057861325
# {'coverage_prop': '0.701', 'intensity_prop': '0.166', 'ms1ms2_ratio': '0.005', 'efficiency': '0.122', 'TP': '51', 'FP': '191', 'FN': '103', 'precision': '0.211', 'recall': '0.331', 'f1': '0.258', 'total_rewards': -1243.0689057861337, 'invalid_action_count': 1360, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -437.76592314561515
# steps	 1000 	total rewards	 -733.5275078079841
# steps	 1500 	total rewards	 -860.2540549848783
# Finished after 1991 timesteps (3.36995792388916 seconds) with total reward -1139.3986718217548
# {'coverage_prop': '0.725', 'intensity_prop': '0.213', 'ms1ms2_ratio': '0.005', 'efficiency': '0.145', 'TP': '79', 'FP': '208', 'FN': '109', 'precision': '0.275', 'recall': '0.420', 'f1': '0.333', 'total_rewards': -1139.3986718217554, 'invalid_action_count': 1267, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -409.92784890723976
# steps	 1000 	total rewards	 -708.8014362794731
# steps	 1500 	total rewards	 -1039.631569025917
# Finished after 1993 timesteps (2.4670121669769287 seconds) with total reward -1405.075566224906
# {'coverage_prop': '0.719', 'intensity_prop': '0.192', 'ms1ms2_ratio': '0.004', 'efficiency': '0.074', 'TP': '37', 'FP': '109', 'FN': '57', 'precision': '0.253', 'recall': '0.394', 'f1': '0.308', 'total_rewards': -1405.0755662249057, 'invalid_action_count': 1482, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -360.42930502557124
# steps	 1000 	total rewards	 -799.800455215594
# steps	 1500 	total rewards	 -983.7950322204874
# Finished after 1989 timesteps (2.550603151321411 seconds) with total reward -1298.364903351365
# {'coverage_prop': '0.680', 'intensity_prop': '0.196', 'ms1ms2_ratio': '0.006', 'efficiency': '0.097', 'TP': '52', 'FP': '139', 'FN': '90', 'precision': '0.272', 'recall': '0.366', 'f1': '0.312', 'total_rewards': -1298.3649033513664, 'invalid_action_count': 1399, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -327.9311558678644
# steps	 1000 	total rewards	 -486.4798482543471
# steps	 1500 	total rewards	 -624.1834150657518
# Finished after 1987 timesteps (3.9906890392303467 seconds) with total reward -783.8642048972324
# {'coverage_prop': '0.787', 'intensity_prop': '0.271', 'ms1ms2_ratio': '0.007', 'efficiency': '0.197', 'TP': '136', 'FP': '252', 'FN': '105', 'precision': '0.351', 'recall': '0.564', 'f1': '0.432', 'total_rewards': -783.8642048972333, 'invalid_action_count': 973, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -452.4430859331801
# steps	 1000 	total rewards	 -792.6019634198801
# steps	 1500 	total rewards	 -1082.9886831427457
# Finished after 1993 timesteps (3.02447509765625 seconds) with total reward -1365.1717860800275
# {'coverage_prop': '0.651', 'intensity_prop': '0.190', 'ms1ms2_ratio': '0.004', 'efficiency': '0.100', 'TP': '55', 'FP': '143', 'FN': '106', 'precision': '0.278', 'recall': '0.342', 'f1': '0.306', 'total_rewards': -1365.1717860800286, 'invalid_action_count': 1457, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 8.36GB > 0.33GB
# steps	 500 	total rewards	 91.8845422464382
# steps	 1000 	total rewards	 194.29492697054806
# steps	 1500 	total rewards	 288.36458349462674
# Finished after 1548 timesteps (5.968999147415161 seconds) with total reward 295.8624852919381
# {'coverage_prop': '0.913', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.412', 'efficiency': '0.355', 'TP': '271', 'FP': '118', 'FN': '37', 'precision': '0.697', 'recall': '0.880', 'f1': '0.778', 'total_rewards': 295.8624852919383, 'invalid_action_count': 19, 'num_ms1_scans': 452, 'num_ms2_scans': 1096}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 83.2954837035378
# steps	 1000 	total rewards	 180.82983435949316
# Finished after 1493 timesteps (4.282785654067993 seconds) with total reward 256.66405249311765
# {'coverage_prop': '0.939', 'intensity_prop': '0.620', 'ms1ms2_ratio': '0.516', 'efficiency': '0.250', 'TP': '178', 'FP': '68', 'FN': '16', 'precision': '0.724', 'recall': '0.918', 'f1': '0.809', 'total_rewards': 256.6640524931157, 'invalid_action_count': 1, 'num_ms1_scans': 508, 'num_ms2_scans': 985}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 87.40134063581701
# steps	 1000 	total rewards	 185.30468124361397
# steps	 1500 	total rewards	 281.06188770940514
# Finished after 1537 timesteps (6.186404228210449 seconds) with total reward 288.4778509089772
# {'coverage_prop': '0.911', 'intensity_prop': '0.562', 'ms1ms2_ratio': '0.431', 'efficiency': '0.334', 'TP': '238', 'FP': '121', 'FN': '35', 'precision': '0.663', 'recall': '0.872', 'f1': '0.753', 'total_rewards': 288.477850908977, 'invalid_action_count': 18, 'num_ms1_scans': 463, 'num_ms2_scans': 1074}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 100.08983273230002
# steps	 1000 	total rewards	 190.4539631395797
# steps	 1500 	total rewards	 275.29498405422305
# Finished after 1565 timesteps (6.118146896362305 seconds) with total reward 287.20524094811657
# {'coverage_prop': '0.914', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.386', 'efficiency': '0.366', 'TP': '291', 'FP': '122', 'FN': '39', 'precision': '0.705', 'recall': '0.882', 'f1': '0.783', 'total_rewards': 287.20524094811617, 'invalid_action_count': 34, 'num_ms1_scans': 436, 'num_ms2_scans': 1129}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 89.49704050965033
# steps	 1000 	total rewards	 197.976443139713
# steps	 1500 	total rewards	 284.95827884176657
# Finished after 1536 timesteps (5.60208797454834 seconds) with total reward 289.04839837925147
# {'coverage_prop': '0.895', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.433', 'efficiency': '0.365', 'TP': '267', 'FP': '124', 'FN': '46', 'precision': '0.683', 'recall': '0.853', 'f1': '0.759', 'total_rewards': 289.0483983792521, 'invalid_action_count': 17, 'num_ms1_scans': 464, 'num_ms2_scans': 1072}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 71.08657340389422
# steps	 1000 	total rewards	 163.46518819139953
# Finished after 1460 timesteps (3.720913887023926 seconds) with total reward 230.76571070799335
# {'coverage_prop': '0.990', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.589', 'efficiency': '0.215', 'TP': '152', 'FP': '46', 'FN': '2', 'precision': '0.768', 'recall': '0.987', 'f1': '0.864', 'total_rewards': 230.7657107079915, 'invalid_action_count': 0, 'num_ms1_scans': 541, 'num_ms2_scans': 919}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 94.49141705357292
# steps	 1000 	total rewards	 207.41759375355588
# steps	 1500 	total rewards	 305.86527180607493
# Finished after 1548 timesteps (6.6225361824035645 seconds) with total reward 312.6384306245018
# {'coverage_prop': '0.879', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.412', 'efficiency': '0.383', 'TP': '290', 'FP': '130', 'FN': '58', 'precision': '0.690', 'recall': '0.833', 'f1': '0.755', 'total_rewards': 312.638430624503, 'invalid_action_count': 13, 'num_ms1_scans': 452, 'num_ms2_scans': 1096}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 61.922335320987344
# steps	 1000 	total rewards	 164.1513717312689
# Finished after 1467 timesteps (3.7349672317504883 seconds) with total reward 227.64999660281538
# {'coverage_prop': '0.956', 'intensity_prop': '0.651', 'ms1ms2_ratio': '0.571', 'efficiency': '0.209', 'TP': '146', 'FP': '49', 'FN': '9', 'precision': '0.749', 'recall': '0.942', 'f1': '0.834', 'total_rewards': 227.64999660281325, 'invalid_action_count': 0, 'num_ms1_scans': 533, 'num_ms2_scans': 934}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 101.58785531424343
# steps	 1000 	total rewards	 193.72938178644966
# steps	 1500 	total rewards	 286.07578438528583
# Finished after 1550 timesteps (6.689265251159668 seconds) with total reward 292.36397741830183
# {'coverage_prop': '0.915', 'intensity_prop': '0.557', 'ms1ms2_ratio': '0.409', 'efficiency': '0.353', 'TP': '254', 'FP': '134', 'FN': '36', 'precision': '0.655', 'recall': '0.876', 'f1': '0.749', 'total_rewards': 292.36397741830183, 'invalid_action_count': 16, 'num_ms1_scans': 450, 'num_ms2_scans': 1100}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 84.08744925263275
# steps	 1000 	total rewards	 184.7212898975116
# steps	 1500 	total rewards	 274.6957138781918
# Finished after 1526 timesteps (4.889810085296631 seconds) with total reward 278.0661940243342
# {'coverage_prop': '0.932', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.451', 'efficiency': '0.340', 'TP': '250', 'FP': '108', 'FN': '26', 'precision': '0.698', 'recall': '0.906', 'f1': '0.789', 'total_rewards': 278.066194024333, 'invalid_action_count': 14, 'num_ms1_scans': 474, 'num_ms2_scans': 1052}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.14540854018159
# steps	 1000 	total rewards	 169.95936031690127
# steps	 1500 	total rewards	 265.59042953568644
# Finished after 1559 timesteps (6.466263771057129 seconds) with total reward 272.757331352596
# {'coverage_prop': '0.887', 'intensity_prop': '0.583', 'ms1ms2_ratio': '0.394', 'efficiency': '0.352', 'TP': '281', 'FP': '112', 'FN': '50', 'precision': '0.715', 'recall': '0.849', 'f1': '0.776', 'total_rewards': 272.75733135259566, 'invalid_action_count': 39, 'num_ms1_scans': 441, 'num_ms2_scans': 1118}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 82.19112887261034
# steps	 1000 	total rewards	 171.39854317766793
# Finished after 1495 timesteps (4.28292989730835 seconds) with total reward 236.2364281056162
# {'coverage_prop': '0.956', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.510', 'efficiency': '0.240', 'TP': '178', 'FP': '60', 'FN': '11', 'precision': '0.748', 'recall': '0.942', 'f1': '0.834', 'total_rewards': 236.23642810561444, 'invalid_action_count': 0, 'num_ms1_scans': 505, 'num_ms2_scans': 990}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 77.3647703444326
# steps	 1000 	total rewards	 169.7190250790086
# Finished after 1486 timesteps (5.587907791137695 seconds) with total reward 241.39041363565912
# {'coverage_prop': '0.928', 'intensity_prop': '0.598', 'ms1ms2_ratio': '0.529', 'efficiency': '0.240', 'TP': '162', 'FP': '71', 'FN': '18', 'precision': '0.695', 'recall': '0.900', 'f1': '0.785', 'total_rewards': 241.39041363565744, 'invalid_action_count': 4, 'num_ms1_scans': 514, 'num_ms2_scans': 972}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 79.68004110535912
# steps	 1000 	total rewards	 167.87280386184563
# Finished after 1495 timesteps (5.040679931640625 seconds) with total reward 249.79203833506102
# {'coverage_prop': '0.927', 'intensity_prop': '0.588', 'ms1ms2_ratio': '0.510', 'efficiency': '0.281', 'TP': '194', 'FP': '84', 'FN': '22', 'precision': '0.698', 'recall': '0.898', 'f1': '0.785', 'total_rewards': 249.792038335059, 'invalid_action_count': 10, 'num_ms1_scans': 505, 'num_ms2_scans': 990}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 69.37424942542773
# steps	 1000 	total rewards	 156.1598015690127
# Finished after 1464 timesteps (3.7988569736480713 seconds) with total reward 222.68954805958901
# {'coverage_prop': '0.932', 'intensity_prop': '0.651', 'ms1ms2_ratio': '0.578', 'efficiency': '0.207', 'TP': '151', 'FP': '41', 'FN': '14', 'precision': '0.786', 'recall': '0.915', 'f1': '0.846', 'total_rewards': 222.68954805958717, 'invalid_action_count': 0, 'num_ms1_scans': 536, 'num_ms2_scans': 928}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 83.08223570934558
# steps	 1000 	total rewards	 187.88641650570037
# steps	 1500 	total rewards	 285.1118861758493
# Finished after 1546 timesteps (9.053080797195435 seconds) with total reward 292.77295407050104
# {'coverage_prop': '0.916', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.417', 'efficiency': '0.342', 'TP': '264', 'FP': '109', 'FN': '34', 'precision': '0.708', 'recall': '0.886', 'f1': '0.787', 'total_rewards': 292.7729540705008, 'invalid_action_count': 10, 'num_ms1_scans': 455, 'num_ms2_scans': 1091}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 102.01370757670537
# steps	 1000 	total rewards	 186.8797326669246
# steps	 1500 	total rewards	 294.741197996584
# Finished after 1567 timesteps (6.849529981613159 seconds) with total reward 303.05307944407383
# {'coverage_prop': '0.882', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.383', 'efficiency': '0.387', 'TP': '326', 'FP': '113', 'FN': '59', 'precision': '0.743', 'recall': '0.847', 'f1': '0.791', 'total_rewards': 303.0530794440744, 'invalid_action_count': 32, 'num_ms1_scans': 434, 'num_ms2_scans': 1133}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 95.47556923728472
# steps	 1000 	total rewards	 202.36126568661862
# steps	 1500 	total rewards	 286.65384961467134
# Finished after 1532 timesteps (6.548442125320435 seconds) with total reward 290.65078804703904
# {'coverage_prop': '0.949', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.440', 'efficiency': '0.332', 'TP': '248', 'FP': '105', 'FN': '19', 'precision': '0.703', 'recall': '0.929', 'f1': '0.800', 'total_rewards': 290.6507880470395, 'invalid_action_count': 11, 'num_ms1_scans': 468, 'num_ms2_scans': 1064}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.36079788011676
# steps	 1000 	total rewards	 176.68149763510849
# steps	 1500 	total rewards	 254.26020026819927
# Finished after 1514 timesteps (4.884579658508301 seconds) with total reward 255.45990422969942
# {'coverage_prop': '0.921', 'intensity_prop': '0.583', 'ms1ms2_ratio': '0.473', 'efficiency': '0.270', 'TP': '188', 'FP': '90', 'FN': '24', 'precision': '0.676', 'recall': '0.887', 'f1': '0.767', 'total_rewards': 255.45990422969734, 'invalid_action_count': 5, 'num_ms1_scans': 486, 'num_ms2_scans': 1028}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 78.5705200358764
# steps	 1000 	total rewards	 175.33719938120305
# steps	 1500 	total rewards	 261.4115789969812
# Finished after 1510 timesteps (4.2259979248046875 seconds) with total reward 262.11549091600386
# {'coverage_prop': '0.947', 'intensity_prop': '0.637', 'ms1ms2_ratio': '0.482', 'efficiency': '0.246', 'TP': '184', 'FP': '67', 'FN': '14', 'precision': '0.733', 'recall': '0.929', 'f1': '0.820', 'total_rewards': 262.1154909160024, 'invalid_action_count': 1, 'num_ms1_scans': 491, 'num_ms2_scans': 1019}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 97.1214410395227
# steps	 1000 	total rewards	 190.5421945643575
# steps	 1500 	total rewards	 281.5732758441913
# Finished after 1552 timesteps (7.9227211475372314 seconds) with total reward 288.0912717906541
# {'coverage_prop': '0.855', 'intensity_prop': '0.554', 'ms1ms2_ratio': '0.406', 'efficiency': '0.362', 'TP': '278', 'FP': '122', 'FN': '68', 'precision': '0.695', 'recall': '0.803', 'f1': '0.745', 'total_rewards': 288.0912717906535, 'invalid_action_count': 21, 'num_ms1_scans': 448, 'num_ms2_scans': 1104}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 72.72316155099891
# steps	 1000 	total rewards	 164.96542485418558
# Finished after 1486 timesteps (4.2361578941345215 seconds) with total reward 234.78535290905108
# {'coverage_prop': '0.970', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.529', 'efficiency': '0.234', 'TP': '146', 'FP': '81', 'FN': '7', 'precision': '0.643', 'recall': '0.954', 'f1': '0.768', 'total_rewards': 234.78535290904884, 'invalid_action_count': 0, 'num_ms1_scans': 514, 'num_ms2_scans': 972}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 88.47766560814301
# steps	 1000 	total rewards	 183.33892511453558
# steps	 1500 	total rewards	 268.574863322573
# Finished after 1521 timesteps (4.834569931030273 seconds) with total reward 272.67115429552894
# {'coverage_prop': '0.935', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.460', 'efficiency': '0.289', 'TP': '211', 'FP': '90', 'FN': '21', 'precision': '0.701', 'recall': '0.909', 'f1': '0.792', 'total_rewards': 272.67115429552797, 'invalid_action_count': 4, 'num_ms1_scans': 479, 'num_ms2_scans': 1042}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 80.04782633476997
# steps	 1000 	total rewards	 180.23819436970604
# steps	 1500 	total rewards	 260.0143510791265
# Finished after 1516 timesteps (6.125765085220337 seconds) with total reward 261.7445190543431
# {'coverage_prop': '0.942', 'intensity_prop': '0.585', 'ms1ms2_ratio': '0.469', 'efficiency': '0.283', 'TP': '194', 'FP': '98', 'FN': '18', 'precision': '0.664', 'recall': '0.915', 'f1': '0.770', 'total_rewards': 261.74451905434177, 'invalid_action_count': 4, 'num_ms1_scans': 484, 'num_ms2_scans': 1032}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 91.61298094502285
# steps	 1000 	total rewards	 191.12718624801067
# steps	 1500 	total rewards	 277.6326809118385
# Finished after 1526 timesteps (4.981867074966431 seconds) with total reward 280.4773368497319
# {'coverage_prop': '0.910', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.452', 'efficiency': '0.299', 'TP': '219', 'FP': '95', 'FN': '31', 'precision': '0.697', 'recall': '0.876', 'f1': '0.777', 'total_rewards': 280.47733684973105, 'invalid_action_count': 11, 'num_ms1_scans': 475, 'num_ms2_scans': 1051}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.68248457521639
# steps	 1000 	total rewards	 187.52284363963236
# steps	 1500 	total rewards	 271.757917434354
# Finished after 1537 timesteps (5.010478973388672 seconds) with total reward 278.46978382919565
# {'coverage_prop': '0.909', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.431', 'efficiency': '0.335', 'TP': '240', 'FP': '120', 'FN': '36', 'precision': '0.667', 'recall': '0.870', 'f1': '0.755', 'total_rewards': 278.46978382919525, 'invalid_action_count': 11, 'num_ms1_scans': 463, 'num_ms2_scans': 1074}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 63.7992361765179
# steps	 1000 	total rewards	 155.56598236583363
# Finished after 1458 timesteps (8.773422002792358 seconds) with total reward 215.64343145406906
# {'coverage_prop': '0.961', 'intensity_prop': '0.639', 'ms1ms2_ratio': '0.593', 'efficiency': '0.213', 'TP': '141', 'FP': '54', 'FN': '8', 'precision': '0.723', 'recall': '0.946', 'f1': '0.820', 'total_rewards': 215.64343145406718, 'invalid_action_count': 0, 'num_ms1_scans': 543, 'num_ms2_scans': 915}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 79.44556803598363
# steps	 1000 	total rewards	 182.83325985320596
# steps	 1500 	total rewards	 273.2805882007609
# Finished after 1511 timesteps (5.553430080413818 seconds) with total reward 274.51977167207804
# {'coverage_prop': '0.954', 'intensity_prop': '0.638', 'ms1ms2_ratio': '0.480', 'efficiency': '0.262', 'TP': '200', 'FP': '68', 'FN': '13', 'precision': '0.746', 'recall': '0.939', 'f1': '0.832', 'total_rewards': 274.5197716720772, 'invalid_action_count': 2, 'num_ms1_scans': 490, 'num_ms2_scans': 1021}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 99.99067189191426
# steps	 1000 	total rewards	 186.65822621757545
# steps	 1500 	total rewards	 291.11435252461916
# Finished after 1551 timesteps (6.016578197479248 seconds) with total reward 298.90052418319834
# {'coverage_prop': '0.836', 'intensity_prop': '0.519', 'ms1ms2_ratio': '0.407', 'efficiency': '0.374', 'TP': '288', 'FP': '124', 'FN': '81', 'precision': '0.699', 'recall': '0.780', 'f1': '0.738', 'total_rewards': 298.9005241831984, 'invalid_action_count': 20, 'num_ms1_scans': 449, 'num_ms2_scans': 1102}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 82.52362831371585
# steps	 1000 	total rewards	 175.28211087941986
# steps	 1500 	total rewards	 258.8220976843148
# Finished after 1513 timesteps (7.301090955734253 seconds) with total reward 261.2738545577557
# {'coverage_prop': '0.944', 'intensity_prop': '0.610', 'ms1ms2_ratio': '0.475', 'efficiency': '0.280', 'TP': '202', 'FP': '85', 'FN': '17', 'precision': '0.704', 'recall': '0.922', 'f1': '0.798', 'total_rewards': 261.2738545577545, 'invalid_action_count': 1, 'num_ms1_scans': 487, 'num_ms2_scans': 1026}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 96.2947472112688
# steps	 1000 	total rewards	 210.15683842109235
# steps	 1500 	total rewards	 314.798634056055
# Finished after 1708 timesteps (9.936299085617065 seconds) with total reward 349.6966282125401
# {'coverage_prop': '0.932', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.206', 'efficiency': '0.280', 'TP': '354', 'FP': '43', 'FN': '29', 'precision': '0.892', 'recall': '0.924', 'f1': '0.908', 'total_rewards': 349.6966282125408, 'invalid_action_count': 0, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.71672116839305
# steps	 1000 	total rewards	 202.23560506519314
# steps	 1500 	total rewards	 283.18536291001726
# Finished after 1542 timesteps (7.971755027770996 seconds) with total reward 288.5472310775797
# {'coverage_prop': '0.962', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.424', 'efficiency': '0.233', 'TP': '237', 'FP': '15', 'FN': '10', 'precision': '0.940', 'recall': '0.960', 'f1': '0.950', 'total_rewards': 288.5472310775799, 'invalid_action_count': 0, 'num_ms1_scans': 459, 'num_ms2_scans': 1083}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.62128539259734
# steps	 1000 	total rewards	 209.44701077429943
# steps	 1500 	total rewards	 315.09467642816026
# Finished after 1657 timesteps (9.23270297050476 seconds) with total reward 337.7852727539003
# {'coverage_prop': '0.924', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.261', 'efficiency': '0.277', 'TP': '329', 'FP': '35', 'FN': '30', 'precision': '0.904', 'recall': '0.916', 'f1': '0.910', 'total_rewards': 337.78527275390053, 'invalid_action_count': 0, 'num_ms1_scans': 343, 'num_ms2_scans': 1314}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 104.41605033421533
# steps	 1000 	total rewards	 220.61543523078416
# steps	 1500 	total rewards	 321.7969920978544
# Finished after 1704 timesteps (11.055789232254028 seconds) with total reward 360.2671640277904
# {'coverage_prop': '0.925', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.210', 'efficiency': '0.297', 'TP': '386', 'FP': '32', 'FN': '34', 'precision': '0.923', 'recall': '0.919', 'f1': '0.921', 'total_rewards': 360.26716402779084, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 94.83696526824527
# steps	 1000 	total rewards	 230.4353747798644
# steps	 1500 	total rewards	 341.20598376036196
# Finished after 1691 timesteps (9.608584880828857 seconds) with total reward 373.00301431907974
# {'coverage_prop': '0.961', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.224', 'efficiency': '0.304', 'TP': '368', 'FP': '52', 'FN': '17', 'precision': '0.876', 'recall': '0.956', 'f1': '0.914', 'total_rewards': 373.00301431908053, 'invalid_action_count': 0, 'num_ms1_scans': 309, 'num_ms2_scans': 1382}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.96535245459845
# steps	 1000 	total rewards	 177.0309816592628
# Finished after 1398 timesteps (7.4805121421813965 seconds) with total reward 239.4026520560644
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.758', 'efficiency': '0.242', 'TP': '180', 'FP': '12', 'FN': '8', 'precision': '0.938', 'recall': '0.957', 'f1': '0.947', 'total_rewards': 239.40265205606244, 'invalid_action_count': 0, 'num_ms1_scans': 603, 'num_ms2_scans': 795}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 105.43142187016116
# steps	 1000 	total rewards	 217.16234875580517
# steps	 1500 	total rewards	 317.53882861089824
# Finished after 1728 timesteps (10.496476888656616 seconds) with total reward 356.0813403930652
# {'coverage_prop': '0.883', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.187', 'efficiency': '0.290', 'TP': '364', 'FP': '58', 'FN': '56', 'precision': '0.863', 'recall': '0.867', 'f1': '0.865', 'total_rewards': 356.08134039306697, 'invalid_action_count': 0, 'num_ms1_scans': 272, 'num_ms2_scans': 1456}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.26121603810041
# steps	 1000 	total rewards	 179.87909305623398
# Finished after 1458 timesteps (9.991187810897827 seconds) with total reward 248.2539839548109
# {'coverage_prop': '0.961', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.592', 'efficiency': '0.214', 'TP': '187', 'FP': '9', 'FN': '8', 'precision': '0.954', 'recall': '0.959', 'f1': '0.957', 'total_rewards': 248.2539839548094, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 916}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 101.73075787582624
# steps	 1000 	total rewards	 202.63638040748515
# steps	 1500 	total rewards	 318.35490928225283
# Finished after 1723 timesteps (9.720470905303955 seconds) with total reward 356.04648908095874
# {'coverage_prop': '0.939', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.192', 'efficiency': '0.275', 'TP': '363', 'FP': '35', 'FN': '26', 'precision': '0.912', 'recall': '0.933', 'f1': '0.922', 'total_rewards': 356.04648908096, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1445}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 91.08268938564159
# steps	 1000 	total rewards	 203.1460220195836
# steps	 1500 	total rewards	 302.55484646418915
# Finished after 1647 timesteps (9.042097806930542 seconds) with total reward 323.3439747097695
# {'coverage_prop': '0.945', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.273', 'efficiency': '0.281', 'TP': '325', 'FP': '38', 'FN': '21', 'precision': '0.895', 'recall': '0.939', 'f1': '0.917', 'total_rewards': 323.34397470977063, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 92.89177994740865
# steps	 1000 	total rewards	 200.33780966885
# steps	 1500 	total rewards	 308.44066178823545
# Finished after 1722 timesteps (9.864475965499878 seconds) with total reward 346.27603435685785
# {'coverage_prop': '0.898', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '358', 'FP': '40', 'FN': '45', 'precision': '0.899', 'recall': '0.888', 'f1': '0.894', 'total_rewards': 346.27603435685813, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.66797281187884
# steps	 1000 	total rewards	 184.53222725829215
# steps	 1500 	total rewards	 256.3446714108332
# Finished after 1518 timesteps (7.9538490772247314 seconds) with total reward 258.1259622000612
# {'coverage_prop': '0.960', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.467', 'efficiency': '0.231', 'TP': '228', 'FP': '11', 'FN': '10', 'precision': '0.954', 'recall': '0.958', 'f1': '0.956', 'total_rewards': 258.12596220006, 'invalid_action_count': 0, 'num_ms1_scans': 483, 'num_ms2_scans': 1035}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.17262365571366
# steps	 1000 	total rewards	 179.03752773958183
# steps	 1500 	total rewards	 257.1736312003494
# Finished after 1583 timesteps (11.708523035049438 seconds) with total reward 268.1257663511901
# {'coverage_prop': '0.948', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.359', 'efficiency': '0.204', 'TP': '219', 'FP': '19', 'FN': '13', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 268.1257663511893, 'invalid_action_count': 0, 'num_ms1_scans': 418, 'num_ms2_scans': 1165}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 80.6116798332078
# steps	 1000 	total rewards	 173.60201913423703
# steps	 1500 	total rewards	 262.64695811092656
# Finished after 1630 timesteps (9.649571895599365 seconds) with total reward 277.80967508193527
# {'coverage_prop': '0.937', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.294', 'efficiency': '0.223', 'TP': '248', 'FP': '33', 'FN': '19', 'precision': '0.883', 'recall': '0.929', 'f1': '0.905', 'total_rewards': 277.8096750819356, 'invalid_action_count': 0, 'num_ms1_scans': 370, 'num_ms2_scans': 1260}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 78.05105674125915
# steps	 1000 	total rewards	 168.53435625126963
# Finished after 1478 timesteps (7.45037579536438 seconds) with total reward 239.10890213610804
# {'coverage_prop': '0.951', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.546', 'efficiency': '0.205', 'TP': '183', 'FP': '13', 'FN': '10', 'precision': '0.934', 'recall': '0.948', 'f1': '0.941', 'total_rewards': 239.10890213610625, 'invalid_action_count': 0, 'num_ms1_scans': 522, 'num_ms2_scans': 956}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.24788449900285
# steps	 1000 	total rewards	 201.71725751361183
# steps	 1500 	total rewards	 309.1326060834659
# Finished after 1647 timesteps (9.26235318183899 seconds) with total reward 341.7556904214264
# {'coverage_prop': '0.941', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.273', 'efficiency': '0.296', 'TP': '344', 'FP': '39', 'FN': '24', 'precision': '0.898', 'recall': '0.935', 'f1': '0.916', 'total_rewards': 341.7556904214272, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 109.4689156831942
# steps	 1000 	total rewards	 222.9984511917354
# steps	 1500 	total rewards	 327.33892555353907
# Finished after 1717 timesteps (12.662304162979126 seconds) with total reward 367.5454464599467
# {'coverage_prop': '0.910', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.197', 'efficiency': '0.316', 'TP': '409', 'FP': '44', 'FN': '45', 'precision': '0.903', 'recall': '0.901', 'f1': '0.902', 'total_rewards': 367.54544645994855, 'invalid_action_count': 0, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.66449307716269
# steps	 1000 	total rewards	 208.2255550813367
# steps	 1500 	total rewards	 298.09584404674365
# Finished after 1669 timesteps (9.129142045974731 seconds) with total reward 320.7417873236513
# {'coverage_prop': '0.938', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.248', 'efficiency': '0.261', 'TP': '320', 'FP': '29', 'FN': '23', 'precision': '0.917', 'recall': '0.933', 'f1': '0.925', 'total_rewards': 320.7417873236517, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 1337}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 86.58222225646823
# steps	 1000 	total rewards	 193.83662787853737
# steps	 1500 	total rewards	 283.52631003777475
# Finished after 1605 timesteps (8.543883085250854 seconds) with total reward 298.66096748916345
# {'coverage_prop': '0.947', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.328', 'efficiency': '0.237', 'TP': '262', 'FP': '24', 'FN': '16', 'precision': '0.916', 'recall': '0.942', 'f1': '0.929', 'total_rewards': 298.6609674891638, 'invalid_action_count': 0, 'num_ms1_scans': 396, 'num_ms2_scans': 1209}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.801418530762
# steps	 1000 	total rewards	 187.14255144611414
# steps	 1500 	total rewards	 271.3242882690306
# Finished after 1602 timesteps (8.251176118850708 seconds) with total reward 281.7817604944602
# {'coverage_prop': '0.977', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.332', 'efficiency': '0.215', 'TP': '237', 'FP': '22', 'FN': '6', 'precision': '0.915', 'recall': '0.975', 'f1': '0.944', 'total_rewards': 281.7817604944603, 'invalid_action_count': 0, 'num_ms1_scans': 399, 'num_ms2_scans': 1203}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.64570324480422
# steps	 1000 	total rewards	 209.8538266334351
# steps	 1500 	total rewards	 302.50968702007094
# Finished after 1712 timesteps (10.10639500617981 seconds) with total reward 343.4124818881533
# {'coverage_prop': '0.874', 'intensity_prop': '0.677', 'ms1ms2_ratio': '0.202', 'efficiency': '0.287', 'TP': '360', 'FP': '49', 'FN': '59', 'precision': '0.880', 'recall': '0.859', 'f1': '0.870', 'total_rewards': 343.4124818881536, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 79.34995801371568
# steps	 1000 	total rewards	 185.05815954422587
# Finished after 1459 timesteps (10.829639911651611 seconds) with total reward 260.9168005156736
# {'coverage_prop': '0.957', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.591', 'efficiency': '0.244', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 260.9168005156723, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 917}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 91.16098210415569
# steps	 1000 	total rewards	 198.46979716592637
# steps	 1500 	total rewards	 285.75298617886926
# Finished after 1620 timesteps (8.799997806549072 seconds) with total reward 305.9567725268008
# {'coverage_prop': '0.960', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.306', 'efficiency': '0.249', 'TP': '283', 'FP': '26', 'FN': '13', 'precision': '0.916', 'recall': '0.956', 'f1': '0.936', 'total_rewards': 305.956772526802, 'invalid_action_count': 0, 'num_ms1_scans': 380, 'num_ms2_scans': 1240}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 95.11617971055398
# steps	 1000 	total rewards	 204.85149167720783
# steps	 1500 	total rewards	 291.49540729766466
# Finished after 1557 timesteps (8.548850774765015 seconds) with total reward 300.47640370637237
# {'coverage_prop': '0.948', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.398', 'efficiency': '0.264', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927', 'total_rewards': 300.4764037063734, 'invalid_action_count': 0, 'num_ms1_scans': 443, 'num_ms2_scans': 1114}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 93.89340790301048
# steps	 1000 	total rewards	 205.42243398475907
# steps	 1500 	total rewards	 299.97419106939174
# Finished after 1655 timesteps (9.215060949325562 seconds) with total reward 325.3669482550192
# {'coverage_prop': '0.948', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.263', 'efficiency': '0.250', 'TP': '301', 'FP': '26', 'FN': '18', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 325.3669482550196, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 92.46389424693754
# steps	 1000 	total rewards	 194.83826945588413
# steps	 1500 	total rewards	 303.0523187043243
# Finished after 1658 timesteps (9.266266107559204 seconds) with total reward 330.86551958049847
# {'coverage_prop': '0.957', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.260', 'efficiency': '0.288', 'TP': '344', 'FP': '35', 'FN': '17', 'precision': '0.908', 'recall': '0.953', 'f1': '0.930', 'total_rewards': 330.8655195804994, 'invalid_action_count': 0, 'num_ms1_scans': 342, 'num_ms2_scans': 1316}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 72.1469507255527
# steps	 1000 	total rewards	 171.47678380953522
# Finished after 1453 timesteps (11.270675897598267 seconds) with total reward 239.9201738382847
# {'coverage_prop': '0.966', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.604', 'efficiency': '0.216', 'TP': '184', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.963', 'f1': '0.951', 'total_rewards': 239.92017383828332, 'invalid_action_count': 0, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 88.31235132594269
# steps	 1000 	total rewards	 195.74792284704353
# steps	 1500 	total rewards	 294.01215539849073
# Finished after 1539 timesteps (8.106023073196411 seconds) with total reward 299.6239201087449
# {'coverage_prop': '0.957', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.429', 'efficiency': '0.250', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 299.62392010874515, 'invalid_action_count': 0, 'num_ms1_scans': 462, 'num_ms2_scans': 1077}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.85875030891819
# steps	 1000 	total rewards	 197.99866949790092
# steps	 1500 	total rewards	 300.4205818023136
# Finished after 1734 timesteps (11.10420823097229 seconds) with total reward 347.5622303363375
# {'coverage_prop': '0.856', 'intensity_prop': '0.645', 'ms1ms2_ratio': '0.181', 'efficiency': '0.287', 'TP': '358', 'FP': '64', 'FN': '71', 'precision': '0.848', 'recall': '0.834', 'f1': '0.841', 'total_rewards': 347.5622303363379, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1468}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.32388476353701
# steps	 1000 	total rewards	 195.74111008357096
# steps	 1500 	total rewards	 278.7575512609741
# Finished after 1628 timesteps (8.564743041992188 seconds) with total reward 293.7826477847459
# {'coverage_prop': '0.954', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.296', 'efficiency': '0.231', 'TP': '271', 'FP': '19', 'FN': '14', 'precision': '0.934', 'recall': '0.951', 'f1': '0.943', 'total_rewards': 293.78264778474596, 'invalid_action_count': 0, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fbc35ebcd30>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fbbf097f850>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fbc10babaf0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.494', 'ms1ms2_ratio': '1.373', 'efficiency': '0.762', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.292', 'efficiency': '0.767', 'TP': '229', 'FP': '199', 'FN': '9', 'precision': '0.535', 'recall': '0.962', 'f1': '0.688'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.488', 'ms1ms2_ratio': '1.420', 'efficiency': '0.768', 'TP': '199', 'FP': '201', 'FN': '24', 'precision': '0.497', 'recall': '0.892', 'f1': '0.639'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '240', 'FP': '186', 'FN': '17', 'precision': '0.563', 'recall': '0.934', 'f1': '0.703'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.676', 'efficiency': '0.759', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '108', 'FP': '129', 'FN': '14', 'precision': '0.456', 'recall': '0.885', 'f1': '0.602'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.990', 'efficiency': '0.709', 'TP': '149', 'FP': '136', 'FN': '15', 'precision': '0.523', 'recall': '0.909', 'f1': '0.664'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.475', 'ms1ms2_ratio': '2.154', 'efficiency': '0.772', 'TP': '136', 'FP': '155', 'FN': '19', 'precision': '0.467', 'recall': '0.877', 'f1': '0.610'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.235', 'efficiency': '0.735', 'TP': '146', 'FP': '123', 'FN': '12', 'precision': '0.543', 'recall': '0.924', 'f1': '0.684'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.525', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '259', 'FP': '210', 'FN': '24', 'precision': '0.552', 'recall': '0.915', 'f1': '0.689'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    -905.021105                1064.0          0.772           0.263
# 1  random   -1296.934356                1390.0          0.679           0.167
# 2  random    -968.712959                1120.0          0.784           0.255
# 3  random    -824.858492                1003.0          0.814           0.312
# 4  random    -973.259687                1136.0          0.769           0.261
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.166      0.307   0.510  0.383
# 1          0.005       0.090      0.213   0.311  0.253
# 2          0.007       0.157      0.288   0.511  0.369
# 3          0.008       0.187      0.386   0.628  0.478
# 4          0.007       0.170      0.312   0.510  0.387

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     295.862485                  19.0          0.913           0.564
# 31    DQN     256.664052                   1.0          0.939           0.620
# 32    DQN     288.477851                  18.0          0.911           0.562
# 33    DQN     287.205241                  34.0          0.914           0.580
# 34    DQN     289.048398                  17.0          0.895           0.551
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.412       0.355      0.697   0.880  0.778
# 31          0.516       0.250      0.724   0.918  0.809
# 32          0.431       0.334      0.663   0.872  0.753
# 33          0.386       0.366      0.705   0.882  0.783
# 34          0.433       0.365      0.683   0.853  0.759

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
