# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-19 00:25:24.646 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc09dafefd0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc0681456a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc058032940>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'exclusion_t0': 5,
#    'exclusion_t1': 120,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc09dafefd0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc0681456a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc058032940>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc09dafefd0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc0681456a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc058032940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['exclusion_t0'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d exclusion_t0 = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['exclusion_t0'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -481.66430326685844
# steps	 1000 	total rewards	 -942.0288762842517
# steps	 1500 	total rewards	 -1393.3782273510585
# Finished after 1991 timesteps (4.0132951736450195 seconds) with total reward -1827.5345016595593
# {'coverage_prop': '0.345', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.005', 'efficiency': '0.074', 'TP': '24', 'FP': '123', 'FN': '279', 'precision': '0.163', 'recall': '0.079', 'f1': '0.107', 'total_rewards': -1827.5345016595597, 'invalid_action_count': 1877, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -486.9202793746666
# steps	 1000 	total rewards	 -971.0721156940645
# steps	 1500 	total rewards	 -1432.7329196665123
# Finished after 1992 timesteps (2.6542820930480957 seconds) with total reward -1904.9449504668673
# {'coverage_prop': '0.237', 'intensity_prop': '0.044', 'ms1ms2_ratio': '0.004', 'efficiency': '0.031', 'TP': '10', 'FP': '52', 'FN': '200', 'precision': '0.161', 'recall': '0.048', 'f1': '0.074', 'total_rewards': -1904.9449504668678, 'invalid_action_count': 1930, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -486.66241934349284
# steps	 1000 	total rewards	 -938.2626178288549
# steps	 1500 	total rewards	 -1398.8794910298056
# Finished after 1988 timesteps (3.705069065093994 seconds) with total reward -1846.3219432629614
# {'coverage_prop': '0.315', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.006', 'efficiency': '0.063', 'TP': '28', 'FP': '96', 'FN': '270', 'precision': '0.226', 'recall': '0.094', 'f1': '0.133', 'total_rewards': -1846.3219432629603, 'invalid_action_count': 1887, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -478.09933678040414
# steps	 1000 	total rewards	 -917.0459605391993
# steps	 1500 	total rewards	 -1346.6682066366598
# Finished after 1982 timesteps (3.9410476684570312 seconds) with total reward -1775.3728618446385
# {'coverage_prop': '0.416', 'intensity_prop': '0.129', 'ms1ms2_ratio': '0.009', 'efficiency': '0.096', 'TP': '56', 'FP': '132', 'FN': '264', 'precision': '0.298', 'recall': '0.175', 'f1': '0.220', 'total_rewards': -1775.3728618446382, 'invalid_action_count': 1836, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -952.6205838781927
# steps	 1500 	total rewards	 -1414.7668245000225
# Finished after 1992 timesteps (3.989114999771118 seconds) with total reward -1865.8793077516912
# {'coverage_prop': '0.357', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.004', 'efficiency': '0.079', 'TP': '34', 'FP': '122', 'FN': '281', 'precision': '0.218', 'recall': '0.108', 'f1': '0.144', 'total_rewards': -1865.879307751692, 'invalid_action_count': 1905, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -481.67628202830053
# steps	 1000 	total rewards	 -960.343266009527
# steps	 1500 	total rewards	 -1433.8267311711738
# Finished after 1988 timesteps (2.3086140155792236 seconds) with total reward -1902.4570598770679
# {'coverage_prop': '0.355', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.006', 'efficiency': '0.036', 'TP': '17', 'FP': '54', 'FN': '129', 'precision': '0.239', 'recall': '0.116', 'f1': '0.157', 'total_rewards': -1902.4570598770676, 'invalid_action_count': 1926, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -476.1924933721816
# steps	 1000 	total rewards	 -911.4044512859346
# steps	 1500 	total rewards	 -1364.971557812763
# Finished after 1992 timesteps (4.2006072998046875 seconds) with total reward -1798.5401258534712
# {'coverage_prop': '0.385', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.004', 'efficiency': '0.093', 'TP': '38', 'FP': '146', 'FN': '294', 'precision': '0.207', 'recall': '0.114', 'f1': '0.147', 'total_rewards': -1798.5401258534716, 'invalid_action_count': 1856, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -496.39011328220823
# steps	 1000 	total rewards	 -980.1228731156514
# steps	 1500 	total rewards	 -1437.1891464419543
# Finished after 1990 timesteps (2.571796178817749 seconds) with total reward -1910.0647587108042
# {'coverage_prop': '0.279', 'intensity_prop': '0.068', 'ms1ms2_ratio': '0.005', 'efficiency': '0.029', 'TP': '14', 'FP': '43', 'FN': '147', 'precision': '0.246', 'recall': '0.087', 'f1': '0.128', 'total_rewards': -1910.064758710804, 'invalid_action_count': 1933, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -484.7133477295987
# steps	 1000 	total rewards	 -952.8730775870315
# steps	 1500 	total rewards	 -1398.2574948567576
# Finished after 1988 timesteps (3.538654327392578 seconds) with total reward -1845.1062472384901
# {'coverage_prop': '0.321', 'intensity_prop': '0.078', 'ms1ms2_ratio': '0.006', 'efficiency': '0.069', 'TP': '25', 'FP': '111', 'FN': '288', 'precision': '0.184', 'recall': '0.080', 'f1': '0.111', 'total_rewards': -1845.1062472384906, 'invalid_action_count': 1887, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -487.95536421704026
# steps	 1000 	total rewards	 -969.0607562064827
# steps	 1500 	total rewards	 -1430.7619018199266
# Finished after 1992 timesteps (3.1938819885253906 seconds) with total reward -1874.914854713836
# {'coverage_prop': '0.315', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.004', 'efficiency': '0.061', 'TP': '14', 'FP': '107', 'FN': '263', 'precision': '0.116', 'recall': '0.051', 'f1': '0.070', 'total_rewards': -1874.9148547138366, 'invalid_action_count': 1910, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -482.1347078224445
# steps	 1000 	total rewards	 -977.4246755875902
# steps	 1500 	total rewards	 -1401.5105758481336
# Finished after 1994 timesteps (3.7801249027252197 seconds) with total reward -1866.1061959293127
# {'coverage_prop': '0.278', 'intensity_prop': '0.054', 'ms1ms2_ratio': '0.003', 'efficiency': '0.062', 'TP': '20', 'FP': '103', 'FN': '320', 'precision': '0.163', 'recall': '0.059', 'f1': '0.086', 'total_rewards': -1866.1061959293127, 'invalid_action_count': 1905, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -484.27342631180187
# steps	 1000 	total rewards	 -964.1313296074926
# steps	 1500 	total rewards	 -1415.4053347377367
# Finished after 1989 timesteps (2.6215178966522217 seconds) with total reward -1884.2802045631302
# {'coverage_prop': '0.333', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.006', 'efficiency': '0.042', 'TP': '17', 'FP': '66', 'FN': '166', 'precision': '0.205', 'recall': '0.093', 'f1': '0.128', 'total_rewards': -1884.2802045631304, 'invalid_action_count': 1914, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -487.2975904971867
# steps	 1000 	total rewards	 -960.6916905700532
# steps	 1500 	total rewards	 -1449.3300021767336
# Finished after 1995 timesteps (2.807298183441162 seconds) with total reward -1922.2455925988668
# {'coverage_prop': '0.275', 'intensity_prop': '0.057', 'ms1ms2_ratio': '0.003', 'efficiency': '0.035', 'TP': '12', 'FP': '57', 'FN': '182', 'precision': '0.174', 'recall': '0.062', 'f1': '0.091', 'total_rewards': -1922.245592598867, 'invalid_action_count': 1943, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -484.88042262094183
# steps	 1000 	total rewards	 -943.8917002617211
# steps	 1500 	total rewards	 -1383.920671601495
# Finished after 1990 timesteps (3.209506034851074 seconds) with total reward -1819.555449221456
# {'coverage_prop': '0.460', 'intensity_prop': '0.132', 'ms1ms2_ratio': '0.005', 'efficiency': '0.070', 'TP': '34', 'FP': '104', 'FN': '162', 'precision': '0.246', 'recall': '0.173', 'f1': '0.204', 'total_rewards': -1819.5554492214553, 'invalid_action_count': 1869, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -488.10417547685404
# steps	 1000 	total rewards	 -976.6294041636938
# steps	 1500 	total rewards	 -1434.010996355007
# Finished after 1987 timesteps (2.271719217300415 seconds) with total reward -1894.9435852727315
# {'coverage_prop': '0.311', 'intensity_prop': '0.072', 'ms1ms2_ratio': '0.007', 'efficiency': '0.032', 'TP': '12', 'FP': '52', 'FN': '142', 'precision': '0.188', 'recall': '0.078', 'f1': '0.110', 'total_rewards': -1894.9435852727318, 'invalid_action_count': 1921, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -489.1461818374689
# steps	 1000 	total rewards	 -943.0470718609417
# steps	 1500 	total rewards	 -1413.4115909154539
# Finished after 1990 timesteps (3.5521528720855713 seconds) with total reward -1871.6640554956305
# {'coverage_prop': '0.349', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.005', 'efficiency': '0.072', 'TP': '32', 'FP': '110', 'FN': '265', 'precision': '0.225', 'recall': '0.108', 'f1': '0.146', 'total_rewards': -1871.66405549563, 'invalid_action_count': 1907, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -482.6536765877553
# steps	 1000 	total rewards	 -966.1205088735818
# steps	 1500 	total rewards	 -1366.8273458591125
# Finished after 1990 timesteps (3.980778932571411 seconds) with total reward -1806.7304965582257
# {'coverage_prop': '0.412', 'intensity_prop': '0.102', 'ms1ms2_ratio': '0.005', 'efficiency': '0.104', 'TP': '46', 'FP': '159', 'FN': '293', 'precision': '0.224', 'recall': '0.136', 'f1': '0.169', 'total_rewards': -1806.730496558228, 'invalid_action_count': 1863, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -476.0916318795214
# steps	 1000 	total rewards	 -930.1545534629796
# steps	 1500 	total rewards	 -1378.2723847735294
# Finished after 1986 timesteps (3.8473451137542725 seconds) with total reward -1837.7822658199877
# {'coverage_prop': '0.374', 'intensity_prop': '0.094', 'ms1ms2_ratio': '0.007', 'efficiency': '0.070', 'TP': '31', 'FP': '108', 'FN': '233', 'precision': '0.223', 'recall': '0.117', 'f1': '0.154', 'total_rewards': -1837.7822658199887, 'invalid_action_count': 1882, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -495.4440571081076
# steps	 1000 	total rewards	 -978.6653473296727
# steps	 1500 	total rewards	 -1428.2443538662678
# Finished after 1989 timesteps (2.998544931411743 seconds) with total reward -1861.475117388125
# {'coverage_prop': '0.321', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.006', 'efficiency': '0.049', 'TP': '22', 'FP': '75', 'FN': '205', 'precision': '0.227', 'recall': '0.097', 'f1': '0.136', 'total_rewards': -1861.4751173881245, 'invalid_action_count': 1897, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -476.81313972928336
# steps	 1000 	total rewards	 -931.7607046026906
# steps	 1500 	total rewards	 -1382.2256085103497
# Finished after 1990 timesteps (3.0243399143218994 seconds) with total reward -1867.6182240423918
# {'coverage_prop': '0.321', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.005', 'efficiency': '0.043', 'TP': '24', 'FP': '61', 'FN': '180', 'precision': '0.282', 'recall': '0.118', 'f1': '0.166', 'total_rewards': -1867.6182240423914, 'invalid_action_count': 1902, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -482.8984298105005
# steps	 1000 	total rewards	 -960.5642824979545
# steps	 1500 	total rewards	 -1415.6508463719533
# Finished after 1994 timesteps (4.119863033294678 seconds) with total reward -1894.7554693225281
# {'coverage_prop': '0.244', 'intensity_prop': '0.067', 'ms1ms2_ratio': '0.003', 'efficiency': '0.057', 'TP': '30', 'FP': '84', 'FN': '354', 'precision': '0.263', 'recall': '0.078', 'f1': '0.120', 'total_rewards': -1894.755469322528, 'invalid_action_count': 1921, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -483.32753951460666
# steps	 1000 	total rewards	 -953.6252633250224
# steps	 1500 	total rewards	 -1434.7745719946129
# Finished after 1991 timesteps (2.6330087184906006 seconds) with total reward -1909.6770265345342
# {'coverage_prop': '0.244', 'intensity_prop': '0.040', 'ms1ms2_ratio': '0.005', 'efficiency': '0.029', 'TP': '9', 'FP': '48', 'FN': '177', 'precision': '0.158', 'recall': '0.048', 'f1': '0.074', 'total_rewards': -1909.6770265345344, 'invalid_action_count': 1933, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -490.93887022503725
# steps	 1000 	total rewards	 -949.6928931637075
# steps	 1500 	total rewards	 -1430.3400868331626
# Finished after 1994 timesteps (3.1303839683532715 seconds) with total reward -1908.65680836198
# {'coverage_prop': '0.276', 'intensity_prop': '0.066', 'ms1ms2_ratio': '0.003', 'efficiency': '0.045', 'TP': '16', 'FP': '73', 'FN': '233', 'precision': '0.180', 'recall': '0.064', 'f1': '0.095', 'total_rewards': -1908.6568083619793, 'invalid_action_count': 1935, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -479.1434975101041
# steps	 1000 	total rewards	 -931.5580574444627
# steps	 1500 	total rewards	 -1395.746407283602
# Finished after 1985 timesteps (2.917435884475708 seconds) with total reward -1843.6621696256325
# {'coverage_prop': '0.323', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.008', 'efficiency': '0.051', 'TP': '27', 'FP': '73', 'FN': '210', 'precision': '0.270', 'recall': '0.114', 'f1': '0.160', 'total_rewards': -1843.662169625632, 'invalid_action_count': 1882, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -484.19899716903865
# steps	 1000 	total rewards	 -924.4974141217856
# steps	 1500 	total rewards	 -1373.3614119009694
# Finished after 1987 timesteps (3.24838924407959 seconds) with total reward -1813.6200260919213
# {'coverage_prop': '0.417', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.007', 'efficiency': '0.073', 'TP': '35', 'FP': '109', 'FN': '201', 'precision': '0.243', 'recall': '0.148', 'f1': '0.184', 'total_rewards': -1813.6200260919209, 'invalid_action_count': 1867, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -484.92360566549314
# steps	 1000 	total rewards	 -930.3579142862766
# steps	 1500 	total rewards	 -1385.474173339365
# Finished after 1984 timesteps (3.5454208850860596 seconds) with total reward -1831.6728154393772
# {'coverage_prop': '0.366', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.008', 'efficiency': '0.074', 'TP': '35', 'FP': '110', 'FN': '251', 'precision': '0.241', 'recall': '0.122', 'f1': '0.162', 'total_rewards': -1831.6728154393768, 'invalid_action_count': 1877, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -487.014875244016
# steps	 1000 	total rewards	 -946.3391740565025
# steps	 1500 	total rewards	 -1414.8005566016843
# Finished after 1991 timesteps (2.5641028881073 seconds) with total reward -1892.8925970153255
# {'coverage_prop': '0.360', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.005', 'efficiency': '0.037', 'TP': '15', 'FP': '58', 'FN': '130', 'precision': '0.205', 'recall': '0.103', 'f1': '0.138', 'total_rewards': -1892.8925970153255, 'invalid_action_count': 1919, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -489.5593889023553
# steps	 1000 	total rewards	 -959.9026474414165
# steps	 1500 	total rewards	 -1422.8208149569946
# Finished after 1988 timesteps (2.585163116455078 seconds) with total reward -1863.1941477806113
# {'coverage_prop': '0.338', 'intensity_prop': '0.085', 'ms1ms2_ratio': '0.006', 'efficiency': '0.048', 'TP': '23', 'FP': '72', 'FN': '186', 'precision': '0.242', 'recall': '0.110', 'f1': '0.151', 'total_rewards': -1863.1941477806113, 'invalid_action_count': 1900, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -489.42679724995276
# steps	 1000 	total rewards	 -929.0542755222862
# steps	 1500 	total rewards	 -1344.4547127946005
# Finished after 1992 timesteps (4.205972909927368 seconds) with total reward -1809.3343256143498
# {'coverage_prop': '0.375', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.004', 'efficiency': '0.093', 'TP': '37', 'FP': '148', 'FN': '308', 'precision': '0.200', 'recall': '0.107', 'f1': '0.140', 'total_rewards': -1809.3343256143505, 'invalid_action_count': 1861, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -484.81350361900365
# steps	 1000 	total rewards	 -945.9912137684857
# steps	 1500 	total rewards	 -1427.2032202528683
# Finished after 1990 timesteps (2.9536049365997314 seconds) with total reward -1866.9238696471
# {'coverage_prop': '0.339', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.005', 'efficiency': '0.052', 'TP': '28', 'FP': '75', 'FN': '201', 'precision': '0.272', 'recall': '0.122', 'f1': '0.169', 'total_rewards': -1866.9238696471004, 'invalid_action_count': 1903, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# method = DQN max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.64GB > 0.37GB
# steps	 500 	total rewards	 62.62985973383939
# steps	 1000 	total rewards	 145.47262798149916
# Finished after 1340 timesteps (5.854741096496582 seconds) with total reward 194.70236386526088
# {'coverage_prop': '0.920', 'intensity_prop': '0.585', 'ms1ms2_ratio': '0.971', 'efficiency': '0.576', 'TP': '278', 'FP': '114', 'FN': '34', 'precision': '0.709', 'recall': '0.891', 'f1': '0.790', 'total_rewards': 194.702363865261, 'invalid_action_count': 12, 'num_ms1_scans': 660, 'num_ms2_scans': 680}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 55.167471148089305
# steps	 1000 	total rewards	 115.07592510510365
# Finished after 1321 timesteps (4.821616888046265 seconds) with total reward 144.07212699052872
# {'coverage_prop': '0.927', 'intensity_prop': '0.648', 'ms1ms2_ratio': '1.058', 'efficiency': '0.379', 'TP': '201', 'FP': '42', 'FN': '19', 'precision': '0.827', 'recall': '0.914', 'f1': '0.868', 'total_rewards': 144.07212699052866, 'invalid_action_count': 16, 'num_ms1_scans': 679, 'num_ms2_scans': 642}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 56.714841076479175
# steps	 1000 	total rewards	 143.08547816089688
# Finished after 1310 timesteps (5.868550062179565 seconds) with total reward 180.95403898937099
# {'coverage_prop': '0.919', 'intensity_prop': '0.585', 'ms1ms2_ratio': '1.113', 'efficiency': '0.584', 'TP': '255', 'FP': '107', 'FN': '32', 'precision': '0.704', 'recall': '0.889', 'f1': '0.786', 'total_rewards': 180.95403898937093, 'invalid_action_count': 12, 'num_ms1_scans': 690, 'num_ms2_scans': 620}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 60.57986330262243
# steps	 1000 	total rewards	 151.10200014819617
# Finished after 1359 timesteps (5.446279764175415 seconds) with total reward 202.26839741594486
# {'coverage_prop': '0.914', 'intensity_prop': '0.598', 'ms1ms2_ratio': '0.893', 'efficiency': '0.575', 'TP': '316', 'FP': '97', 'FN': '39', 'precision': '0.765', 'recall': '0.890', 'f1': '0.823', 'total_rewards': 202.26839741594478, 'invalid_action_count': 15, 'num_ms1_scans': 641, 'num_ms2_scans': 718}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 58.65477671384543
# steps	 1000 	total rewards	 142.9787627154946
# Finished after 1347 timesteps (6.427680015563965 seconds) with total reward 186.14968081285696
# {'coverage_prop': '0.938', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.941', 'efficiency': '0.591', 'TP': '303', 'FP': '107', 'FN': '27', 'precision': '0.739', 'recall': '0.918', 'f1': '0.819', 'total_rewards': 186.1496808128569, 'invalid_action_count': 22, 'num_ms1_scans': 653, 'num_ms2_scans': 694}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 40.098365198961886
# steps	 1000 	total rewards	 96.69530040670429
# Finished after 1281 timesteps (4.524859189987183 seconds) with total reward 119.15697014340367
# {'coverage_prop': '0.945', 'intensity_prop': '0.670', 'ms1ms2_ratio': '1.283', 'efficiency': '0.337', 'TP': '153', 'FP': '36', 'FN': '11', 'precision': '0.810', 'recall': '0.933', 'f1': '0.867', 'total_rewards': 119.15697014340371, 'invalid_action_count': 8, 'num_ms1_scans': 720, 'num_ms2_scans': 561}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 68.34593159648908
# steps	 1000 	total rewards	 151.88841859386136
# Finished after 1370 timesteps (6.564825057983398 seconds) with total reward 201.45142920801527
# {'coverage_prop': '0.891', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.854', 'efficiency': '0.576', 'TP': '308', 'FP': '118', 'FN': '52', 'precision': '0.723', 'recall': '0.856', 'f1': '0.784', 'total_rewards': 201.45142920801547, 'invalid_action_count': 19, 'num_ms1_scans': 631, 'num_ms2_scans': 739}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 41.24291887399757
# steps	 1000 	total rewards	 106.03749440497961
# Finished after 1297 timesteps (3.998047113418579 seconds) with total reward 135.66110901946715
# {'coverage_prop': '0.936', 'intensity_prop': '0.631', 'ms1ms2_ratio': '1.187', 'efficiency': '0.322', 'TP': '152', 'FP': '39', 'FN': '13', 'precision': '0.796', 'recall': '0.921', 'f1': '0.854', 'total_rewards': 135.66110901946718, 'invalid_action_count': 4, 'num_ms1_scans': 704, 'num_ms2_scans': 593}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 68.89735783917804
# steps	 1000 	total rewards	 149.83152141426552
# Finished after 1334 timesteps (6.54388689994812 seconds) with total reward 193.41317701171272
# {'coverage_prop': '0.908', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.997', 'efficiency': '0.576', 'TP': '262', 'FP': '123', 'FN': '39', 'precision': '0.681', 'recall': '0.870', 'f1': '0.764', 'total_rewards': 193.41317701171246, 'invalid_action_count': 7, 'num_ms1_scans': 666, 'num_ms2_scans': 668}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 52.94854392311214
# steps	 1000 	total rewards	 146.55110226896312
# Finished after 1331 timesteps (5.899155139923096 seconds) with total reward 183.89207477916986
# {'coverage_prop': '0.906', 'intensity_prop': '0.588', 'ms1ms2_ratio': '1.014', 'efficiency': '0.526', 'TP': '247', 'FP': '101', 'FN': '36', 'precision': '0.710', 'recall': '0.873', 'f1': '0.783', 'total_rewards': 183.89207477916966, 'invalid_action_count': 3, 'num_ms1_scans': 670, 'num_ms2_scans': 661}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 58.97299039971041
# steps	 1000 	total rewards	 153.8354159201941
# Finished after 1361 timesteps (5.65535569190979 seconds) with total reward 199.2338946908572
# {'coverage_prop': '0.912', 'intensity_prop': '0.594', 'ms1ms2_ratio': '0.885', 'efficiency': '0.560', 'TP': '303', 'FP': '101', 'FN': '39', 'precision': '0.750', 'recall': '0.886', 'f1': '0.812', 'total_rewards': 199.23389469085726, 'invalid_action_count': 14, 'num_ms1_scans': 639, 'num_ms2_scans': 722}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 48.74523275005504
# steps	 1000 	total rewards	 108.25115093182828
# Finished after 1304 timesteps (5.211652994155884 seconds) with total reward 136.47861172488018
# {'coverage_prop': '0.924', 'intensity_prop': '0.635', 'ms1ms2_ratio': '1.145', 'efficiency': '0.378', 'TP': '186', 'FP': '44', 'FN': '19', 'precision': '0.809', 'recall': '0.907', 'f1': '0.855', 'total_rewards': 136.47861172488027, 'invalid_action_count': 8, 'num_ms1_scans': 696, 'num_ms2_scans': 608}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 43.87484345594281
# steps	 1000 	total rewards	 113.08135705076691
# Finished after 1296 timesteps (4.401777029037476 seconds) with total reward 141.35378903329996
# {'coverage_prop': '0.932', 'intensity_prop': '0.615', 'ms1ms2_ratio': '1.189', 'efficiency': '0.395', 'TP': '170', 'FP': '64', 'FN': '17', 'precision': '0.726', 'recall': '0.909', 'f1': '0.808', 'total_rewards': 141.35378903330002, 'invalid_action_count': 5, 'num_ms1_scans': 704, 'num_ms2_scans': 592}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 47.01915436631528
# steps	 1000 	total rewards	 124.90461790844842
# Finished after 1329 timesteps (6.1350321769714355 seconds) with total reward 160.63879927270244
# {'coverage_prop': '0.927', 'intensity_prop': '0.604', 'ms1ms2_ratio': '1.020', 'efficiency': '0.422', 'TP': '198', 'FP': '80', 'FN': '22', 'precision': '0.712', 'recall': '0.900', 'f1': '0.795', 'total_rewards': 160.63879927270264, 'invalid_action_count': 4, 'num_ms1_scans': 671, 'num_ms2_scans': 658}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 44.05982199765848
# steps	 1000 	total rewards	 105.8678511008842
# Finished after 1325 timesteps (3.9158239364624023 seconds) with total reward 126.55958482767231
# {'coverage_prop': '0.937', 'intensity_prop': '0.627', 'ms1ms2_ratio': '1.038', 'efficiency': '0.297', 'TP': '148', 'FP': '45', 'FN': '13', 'precision': '0.767', 'recall': '0.919', 'f1': '0.836', 'total_rewards': 126.5595848276723, 'invalid_action_count': 11, 'num_ms1_scans': 675, 'num_ms2_scans': 650}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 53.77252824053579
# steps	 1000 	total rewards	 148.99611666949548
# Finished after 1342 timesteps (6.458452939987183 seconds) with total reward 190.77459205722485
# {'coverage_prop': '0.931', 'intensity_prop': '0.628', 'ms1ms2_ratio': '0.962', 'efficiency': '0.554', 'TP': '298', 'FP': '81', 'FN': '28', 'precision': '0.786', 'recall': '0.914', 'f1': '0.845', 'total_rewards': 190.77459205722494, 'invalid_action_count': 12, 'num_ms1_scans': 658, 'num_ms2_scans': 684}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 69.07597021739511
# steps	 1000 	total rewards	 149.3654875600388
# Finished after 1380 timesteps (5.870482921600342 seconds) with total reward 200.98134611230603
# {'coverage_prop': '0.906', 'intensity_prop': '0.585', 'ms1ms2_ratio': '0.818', 'efficiency': '0.594', 'TP': '336', 'FP': '115', 'FN': '47', 'precision': '0.745', 'recall': '0.877', 'f1': '0.806', 'total_rewards': 200.98134611230614, 'invalid_action_count': 25, 'num_ms1_scans': 621, 'num_ms2_scans': 759}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 64.95528174291977
# steps	 1000 	total rewards	 148.7053006765456
# Finished after 1309 timesteps (6.53256893157959 seconds) with total reward 181.528430983345
# {'coverage_prop': '0.927', 'intensity_prop': '0.595', 'ms1ms2_ratio': '1.118', 'efficiency': '0.558', 'TP': '250', 'FP': '95', 'FN': '27', 'precision': '0.725', 'recall': '0.903', 'f1': '0.804', 'total_rewards': 181.52843098334503, 'invalid_action_count': 4, 'num_ms1_scans': 691, 'num_ms2_scans': 618}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 49.957653409882255
# steps	 1000 	total rewards	 120.95386102582607
# Finished after 1302 timesteps (4.673321008682251 seconds) with total reward 159.45454033096632
# {'coverage_prop': '0.940', 'intensity_prop': '0.630', 'ms1ms2_ratio': '1.159', 'efficiency': '0.471', 'TP': '217', 'FP': '67', 'FN': '18', 'precision': '0.764', 'recall': '0.923', 'f1': '0.836', 'total_rewards': 159.45454033096632, 'invalid_action_count': 8, 'num_ms1_scans': 699, 'num_ms2_scans': 603}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 46.7638583639209
# steps	 1000 	total rewards	 119.41965257900958
# Finished after 1318 timesteps (4.485532999038696 seconds) with total reward 150.28092163129293
# {'coverage_prop': '0.958', 'intensity_prop': '0.626', 'ms1ms2_ratio': '1.072', 'efficiency': '0.399', 'TP': '189', 'FP': '65', 'FN': '11', 'precision': '0.744', 'recall': '0.945', 'f1': '0.833', 'total_rewards': 150.280921631293, 'invalid_action_count': 5, 'num_ms1_scans': 682, 'num_ms2_scans': 636}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 63.14732138503986
# steps	 1000 	total rewards	 156.06763267158158
# Finished after 1358 timesteps (6.141154050827026 seconds) with total reward 202.27189440039558
# {'coverage_prop': '0.889', 'intensity_prop': '0.592', 'ms1ms2_ratio': '0.897', 'efficiency': '0.581', 'TP': '313', 'FP': '103', 'FN': '52', 'precision': '0.752', 'recall': '0.858', 'f1': '0.802', 'total_rewards': 202.2718944003957, 'invalid_action_count': 13, 'num_ms1_scans': 642, 'num_ms2_scans': 716}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 42.61249462780782
# steps	 1000 	total rewards	 105.21841942020458
# Finished after 1292 timesteps (4.101891279220581 seconds) with total reward 132.4016440242118
# {'coverage_prop': '0.932', 'intensity_prop': '0.623', 'ms1ms2_ratio': '1.212', 'efficiency': '0.373', 'TP': '158', 'FP': '60', 'FN': '16', 'precision': '0.725', 'recall': '0.908', 'f1': '0.806', 'total_rewards': 132.40164402421203, 'invalid_action_count': 9, 'num_ms1_scans': 708, 'num_ms2_scans': 584}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 55.78130665408494
# steps	 1000 	total rewards	 136.94322237318568
# Finished after 1332 timesteps (6.2678070068359375 seconds) with total reward 175.53374122276216
# {'coverage_prop': '0.944', 'intensity_prop': '0.633', 'ms1ms2_ratio': '1.006', 'efficiency': '0.458', 'TP': '230', 'FP': '74', 'FN': '18', 'precision': '0.757', 'recall': '0.927', 'f1': '0.833', 'total_rewards': 175.53374122276227, 'invalid_action_count': 6, 'num_ms1_scans': 668, 'num_ms2_scans': 664}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 54.88812492146555
# steps	 1000 	total rewards	 130.74978795743453
# Finished after 1294 timesteps (4.403539180755615 seconds) with total reward 158.04498422860166
# {'coverage_prop': '0.919', 'intensity_prop': '0.624', 'ms1ms2_ratio': '1.201', 'efficiency': '0.485', 'TP': '219', 'FP': '66', 'FN': '25', 'precision': '0.768', 'recall': '0.898', 'f1': '0.828', 'total_rewards': 158.04498422860166, 'invalid_action_count': 8, 'num_ms1_scans': 706, 'num_ms2_scans': 588}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 53.42973515554323
# steps	 1000 	total rewards	 126.1940953759271
# Finished after 1328 timesteps (5.039582967758179 seconds) with total reward 167.35756486813767
# {'coverage_prop': '0.928', 'intensity_prop': '0.595', 'ms1ms2_ratio': '1.024', 'efficiency': '0.488', 'TP': '234', 'FP': '86', 'FN': '25', 'precision': '0.731', 'recall': '0.903', 'f1': '0.808', 'total_rewards': 167.35756486813776, 'invalid_action_count': 17, 'num_ms1_scans': 672, 'num_ms2_scans': 656}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 60.46127278997477
# steps	 1000 	total rewards	 141.93032722367207
# Finished after 1331 timesteps (6.924166917800903 seconds) with total reward 188.02707474045326
# {'coverage_prop': '0.955', 'intensity_prop': '0.619', 'ms1ms2_ratio': '1.011', 'efficiency': '0.571', 'TP': '278', 'FP': '100', 'FN': '18', 'precision': '0.735', 'recall': '0.939', 'f1': '0.825', 'total_rewards': 188.02707474045343, 'invalid_action_count': 5, 'num_ms1_scans': 669, 'num_ms2_scans': 662}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 39.02561864127355
# steps	 1000 	total rewards	 101.44853944905469
# Finished after 1295 timesteps (4.074692010879517 seconds) with total reward 124.55294877097202
# {'coverage_prop': '0.936', 'intensity_prop': '0.630', 'ms1ms2_ratio': '1.195', 'efficiency': '0.322', 'TP': '148', 'FP': '42', 'FN': '13', 'precision': '0.779', 'recall': '0.919', 'f1': '0.843', 'total_rewards': 124.55294877097198, 'invalid_action_count': 4, 'num_ms1_scans': 705, 'num_ms2_scans': 590}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 47.722099419797104
# steps	 1000 	total rewards	 115.84662833673723
# Finished after 1286 timesteps (4.238648891448975 seconds) with total reward 150.06957831076755
# {'coverage_prop': '0.929', 'intensity_prop': '0.639', 'ms1ms2_ratio': '1.252', 'efficiency': '0.457', 'TP': '208', 'FP': '53', 'FN': '20', 'precision': '0.797', 'recall': '0.912', 'f1': '0.851', 'total_rewards': 150.06957831076755, 'invalid_action_count': 11, 'num_ms1_scans': 715, 'num_ms2_scans': 571}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 67.2912152362634
# steps	 1000 	total rewards	 150.0103459245188
# Finished after 1381 timesteps (7.612725019454956 seconds) with total reward 205.41363160438584
# {'coverage_prop': '0.884', 'intensity_prop': '0.543', 'ms1ms2_ratio': '0.815', 'efficiency': '0.573', 'TP': '295', 'FP': '141', 'FN': '57', 'precision': '0.677', 'recall': '0.838', 'f1': '0.749', 'total_rewards': 205.4136316043859, 'invalid_action_count': 20, 'num_ms1_scans': 620, 'num_ms2_scans': 761}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 52.82976427720489
# steps	 1000 	total rewards	 127.61831033133652
# Finished after 1302 timesteps (4.568300247192383 seconds) with total reward 161.0843785080375
# {'coverage_prop': '0.947', 'intensity_prop': '0.636', 'ms1ms2_ratio': '1.159', 'efficiency': '0.478', 'TP': '216', 'FP': '72', 'FN': '16', 'precision': '0.750', 'recall': '0.931', 'f1': '0.831', 'total_rewards': 161.08437850803753, 'invalid_action_count': 5, 'num_ms1_scans': 699, 'num_ms2_scans': 603}
#
# method = topN max_peaks = 200 N = 10 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 14.344756562456844
# steps	 1000 	total rewards	 28.579584425977504
# steps	 1500 	total rewards	 53.07218297939193
# Finished after 1783 timesteps (9.777559041976929 seconds) with total reward 54.95542202573651
# {'coverage_prop': '0.798', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.139', 'efficiency': '0.217', 'TP': '289', 'FP': '51', 'FN': '86', 'precision': '0.850', 'recall': '0.771', 'f1': '0.808', 'total_rewards': 54.95542202573647, 'invalid_action_count': 190, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 9.273759830922057
# steps	 1000 	total rewards	 8.497333534030812
# steps	 1500 	total rewards	 25.568059987713603
# Finished after 1754 timesteps (8.44935917854309 seconds) with total reward 36.569131248326855
# {'coverage_prop': '0.931', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.163', 'efficiency': '0.162', 'TP': '227', 'FP': '17', 'FN': '18', 'precision': '0.930', 'recall': '0.927', 'f1': '0.928', 'total_rewards': 36.56913124832684, 'invalid_action_count': 182, 'num_ms1_scans': 246, 'num_ms2_scans': 1508}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 6.0881628193892645
# steps	 1000 	total rewards	 17.617947018718347
# steps	 1500 	total rewards	 28.61202832331745
# Finished after 1771 timesteps (9.613263130187988 seconds) with total reward 37.60389833545209
# {'coverage_prop': '0.812', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.149', 'efficiency': '0.208', 'TP': '264', 'FP': '56', 'FN': '74', 'precision': '0.825', 'recall': '0.781', 'f1': '0.802', 'total_rewards': 37.60389833545214, 'invalid_action_count': 191, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 1.1625973018910014
# steps	 1000 	total rewards	 7.740103611022422
# steps	 1500 	total rewards	 28.52111287930716
# Finished after 1783 timesteps (9.888967990875244 seconds) with total reward 37.500932724076534
# {'coverage_prop': '0.823', 'intensity_prop': '0.611', 'ms1ms2_ratio': '0.139', 'efficiency': '0.238', 'TP': '320', 'FP': '52', 'FN': '80', 'precision': '0.860', 'recall': '0.800', 'f1': '0.829', 'total_rewards': 37.50093272407651, 'invalid_action_count': 208, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -4.226881246706827
# steps	 1000 	total rewards	 6.198846072974805
# steps	 1500 	total rewards	 36.33732240549364
# Finished after 1776 timesteps (9.873209238052368 seconds) with total reward 50.88125683585475
# {'coverage_prop': '0.872', 'intensity_prop': '0.644', 'ms1ms2_ratio': '0.144', 'efficiency': '0.245', 'TP': '321', 'FP': '60', 'FN': '56', 'precision': '0.843', 'recall': '0.851', 'f1': '0.847', 'total_rewards': 50.881256835854664, 'invalid_action_count': 201, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 7.516425925357106
# steps	 1000 	total rewards	 18.607424155132016
# steps	 1500 	total rewards	 24.9489900669033
# Finished after 1715 timesteps (8.289765119552612 seconds) with total reward 35.987121060589295
# {'coverage_prop': '0.935', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.199', 'efficiency': '0.131', 'TP': '177', 'FP': '10', 'FN': '13', 'precision': '0.947', 'recall': '0.932', 'f1': '0.939', 'total_rewards': 35.98712106058935, 'invalid_action_count': 145, 'num_ms1_scans': 285, 'num_ms2_scans': 1430}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 6.818456307863762
# steps	 1000 	total rewards	 15.162946807926986
# steps	 1500 	total rewards	 42.381838469391944
# Finished after 1777 timesteps (10.367006063461304 seconds) with total reward 49.60790459190967
# {'coverage_prop': '0.757', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.144', 'efficiency': '0.233', 'TP': '283', 'FP': '79', 'FN': '116', 'precision': '0.782', 'recall': '0.709', 'f1': '0.744', 'total_rewards': 49.60790459190965, 'invalid_action_count': 190, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 17.61040326804966
# steps	 1000 	total rewards	 27.195335694260734
# steps	 1500 	total rewards	 36.40753293652189
# Finished after 1720 timesteps (8.323699235916138 seconds) with total reward 48.70358277943673
# {'coverage_prop': '0.917', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.194', 'efficiency': '0.130', 'TP': '181', 'FP': '6', 'FN': '17', 'precision': '0.968', 'recall': '0.914', 'f1': '0.940', 'total_rewards': 48.70358277943679, 'invalid_action_count': 143, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 5.173792090903818
# steps	 1000 	total rewards	 1.9997623593472595
# steps	 1500 	total rewards	 16.843160210348586
# Finished after 1794 timesteps (10.044590711593628 seconds) with total reward 28.51556135633543
# {'coverage_prop': '0.854', 'intensity_prop': '0.641', 'ms1ms2_ratio': '0.130', 'efficiency': '0.228', 'TP': '315', 'FP': '47', 'FN': '62', 'precision': '0.870', 'recall': '0.836', 'f1': '0.853', 'total_rewards': 28.515561356335425, 'invalid_action_count': 218, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 9.55765831134537
# steps	 1000 	total rewards	 18.71405434666108
# steps	 1500 	total rewards	 42.15986482311896
# Finished after 1781 timesteps (9.410327911376953 seconds) with total reward 47.81880316100924
# {'coverage_prop': '0.820', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.140', 'efficiency': '0.202', 'TP': '273', 'FP': '42', 'FN': '69', 'precision': '0.867', 'recall': '0.798', 'f1': '0.831', 'total_rewards': 47.81880316100922, 'invalid_action_count': 183, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 6.685145961017955
# steps	 1000 	total rewards	 16.485229212859718
# steps	 1500 	total rewards	 46.74187233271065
# Finished after 1790 timesteps (10.372720003128052 seconds) with total reward 59.80767038716853
# {'coverage_prop': '0.777', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.133', 'efficiency': '0.218', 'TP': '290', 'FP': '54', 'FN': '99', 'precision': '0.843', 'recall': '0.746', 'f1': '0.791', 'total_rewards': 59.807670387168564, 'invalid_action_count': 180, 'num_ms1_scans': 210, 'num_ms2_scans': 1580}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 3.2787444192444752
# steps	 1000 	total rewards	 17.035903413919126
# steps	 1500 	total rewards	 18.423565654306625
# Finished after 1753 timesteps (8.891985893249512 seconds) with total reward 22.432978652921417
# {'coverage_prop': '0.916', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.164', 'efficiency': '0.151', 'TP': '217', 'FP': '11', 'FN': '21', 'precision': '0.952', 'recall': '0.912', 'f1': '0.931', 'total_rewards': 22.432978652921424, 'invalid_action_count': 175, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 13.156570645194993
# steps	 1000 	total rewards	 19.54304277151883
# steps	 1500 	total rewards	 38.077282185965835
# Finished after 1779 timesteps (9.283742904663086 seconds) with total reward 54.050320184216616
# {'coverage_prop': '0.861', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.142', 'efficiency': '0.139', 'TP': '191', 'FP': '25', 'FN': '35', 'precision': '0.884', 'recall': '0.845', 'f1': '0.864', 'total_rewards': 54.050320184216616, 'invalid_action_count': 149, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 7.5474621371415935
# steps	 1000 	total rewards	 20.83237740104031
# steps	 1500 	total rewards	 39.67184067175111
# Finished after 1771 timesteps (9.863962173461914 seconds) with total reward 48.941177165001285
# {'coverage_prop': '0.837', 'intensity_prop': '0.635', 'ms1ms2_ratio': '0.149', 'efficiency': '0.163', 'TP': '215', 'FP': '36', 'FN': '49', 'precision': '0.857', 'recall': '0.814', 'f1': '0.835', 'total_rewards': 48.9411771650013, 'invalid_action_count': 157, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 19.60657893013078
# steps	 1000 	total rewards	 33.077180155924864
# steps	 1500 	total rewards	 48.313502750653115
# Finished after 1748 timesteps (8.540251970291138 seconds) with total reward 56.270741851431055
# {'coverage_prop': '0.879', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.168', 'efficiency': '0.121', 'TP': '164', 'FP': '17', 'FN': '25', 'precision': '0.906', 'recall': '0.868', 'f1': '0.886', 'total_rewards': 56.27074185143104, 'invalid_action_count': 132, 'num_ms1_scans': 252, 'num_ms2_scans': 1496}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 5.569987451895377
# steps	 1000 	total rewards	 8.235916650657478
# steps	 1500 	total rewards	 10.890578346674678
# Finished after 1775 timesteps (12.158469915390015 seconds) with total reward 9.75920979784498
# {'coverage_prop': '0.870', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.145', 'efficiency': '0.228', 'TP': '313', 'FP': '41', 'FN': '53', 'precision': '0.884', 'recall': '0.855', 'f1': '0.869', 'total_rewards': 9.759209797844974, 'invalid_action_count': 226, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 2.4067992159495075
# steps	 1000 	total rewards	 13.490644292643887
# steps	 1500 	total rewards	 33.60284216975457
# Finished after 1782 timesteps (10.091951847076416 seconds) with total reward 37.59242109226099
# {'coverage_prop': '0.773', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.139', 'efficiency': '0.246', 'TP': '318', 'FP': '67', 'FN': '113', 'precision': '0.826', 'recall': '0.738', 'f1': '0.779', 'total_rewards': 37.5924210922609, 'invalid_action_count': 210, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 2.894000872228831
# steps	 1000 	total rewards	 12.833128586744108
# steps	 1500 	total rewards	 32.61507235508286
# Finished after 1781 timesteps (9.338693141937256 seconds) with total reward 39.332654486880145
# {'coverage_prop': '0.831', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.140', 'efficiency': '0.198', 'TP': '259', 'FP': '50', 'FN': '63', 'precision': '0.838', 'recall': '0.804', 'f1': '0.821', 'total_rewards': 39.33265448688013, 'invalid_action_count': 186, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 11.505763986259158
# steps	 1000 	total rewards	 19.341056540174026
# steps	 1500 	total rewards	 21.59940597765239
# Finished after 1767 timesteps (9.23871111869812 seconds) with total reward 30.84538714218545
# {'coverage_prop': '0.901', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.152', 'efficiency': '0.177', 'TP': '245', 'FP': '27', 'FN': '30', 'precision': '0.901', 'recall': '0.891', 'f1': '0.896', 'total_rewards': 30.84538714218546, 'invalid_action_count': 188, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 16.521470687513975
# steps	 1000 	total rewards	 22.517318362990462
# steps	 1500 	total rewards	 30.806722029467345
# Finished after 1767 timesteps (9.027492046356201 seconds) with total reward 45.09881000111574
# {'coverage_prop': '0.902', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.152', 'efficiency': '0.156', 'TP': '214', 'FP': '25', 'FN': '26', 'precision': '0.895', 'recall': '0.892', 'f1': '0.894', 'total_rewards': 45.0988100011157, 'invalid_action_count': 160, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 10.733303373691122
# steps	 1000 	total rewards	 24.732905312785924
# steps	 1500 	total rewards	 50.169187854191144
# Finished after 1781 timesteps (10.073828220367432 seconds) with total reward 61.560054390265854
# {'coverage_prop': '0.716', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.140', 'efficiency': '0.214', 'TP': '283', 'FP': '52', 'FN': '133', 'precision': '0.845', 'recall': '0.680', 'f1': '0.754', 'total_rewards': 61.5600543902658, 'invalid_action_count': 175, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 15.954895191022842
# steps	 1000 	total rewards	 24.109511608130106
# steps	 1500 	total rewards	 24.635808174201756
# Finished after 1737 timesteps (8.840047121047974 seconds) with total reward 35.7907172683126
# {'coverage_prop': '0.940', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.179', 'efficiency': '0.149', 'TP': '196', 'FP': '24', 'FN': '14', 'precision': '0.891', 'recall': '0.933', 'f1': '0.912', 'total_rewards': 35.79071726831257, 'invalid_action_count': 161, 'num_ms1_scans': 264, 'num_ms2_scans': 1473}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 12.130339826715616
# steps	 1000 	total rewards	 13.444657850541345
# steps	 1500 	total rewards	 21.37075592753976
# Finished after 1776 timesteps (9.105469942092896 seconds) with total reward 31.430679573940406
# {'coverage_prop': '0.891', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.144', 'efficiency': '0.185', 'TP': '259', 'FP': '28', 'FN': '35', 'precision': '0.902', 'recall': '0.881', 'f1': '0.892', 'total_rewards': 31.430679573940388, 'invalid_action_count': 195, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 10.69027551236375
# steps	 1000 	total rewards	 17.428587517876213
# steps	 1500 	total rewards	 30.046179323868657
# Finished after 1755 timesteps (11.821314096450806 seconds) with total reward 35.70294086499651
# {'coverage_prop': '0.906', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.162', 'efficiency': '0.186', 'TP': '247', 'FP': '34', 'FN': '29', 'precision': '0.879', 'recall': '0.895', 'f1': '0.887', 'total_rewards': 35.702940864996506, 'invalid_action_count': 191, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 5.840528296240149
# steps	 1000 	total rewards	 11.021369936304673
# steps	 1500 	total rewards	 32.48528999947018
# Finished after 1765 timesteps (9.162709951400757 seconds) with total reward 49.17253196393395
# {'coverage_prop': '0.814', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.154', 'efficiency': '0.184', 'TP': '236', 'FP': '45', 'FN': '64', 'precision': '0.840', 'recall': '0.787', 'f1': '0.812', 'total_rewards': 49.17253196393391, 'invalid_action_count': 171, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 13.922764181245968
# steps	 1000 	total rewards	 2.6712854840686084
# steps	 1500 	total rewards	 11.888987185929132
# Finished after 1795 timesteps (10.288808107376099 seconds) with total reward 21.09645881305948
# {'coverage_prop': '0.866', 'intensity_prop': '0.657', 'ms1ms2_ratio': '0.130', 'efficiency': '0.216', 'TP': '301', 'FP': '42', 'FN': '53', 'precision': '0.878', 'recall': '0.850', 'f1': '0.864', 'total_rewards': 21.0964588130595, 'invalid_action_count': 213, 'num_ms1_scans': 206, 'num_ms2_scans': 1589}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 15.459057587454478
# steps	 1000 	total rewards	 17.65282753775836
# steps	 1500 	total rewards	 22.79000052095943
# Finished after 1735 timesteps (8.87909197807312 seconds) with total reward 35.76018443330635
# {'coverage_prop': '0.961', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.180', 'efficiency': '0.133', 'TP': '185', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954', 'total_rewards': 35.76018443330635, 'invalid_action_count': 152, 'num_ms1_scans': 265, 'num_ms2_scans': 1470}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 14.645228395889834
# steps	 1000 	total rewards	 15.107386881387438
# steps	 1500 	total rewards	 24.841496346518635
# Finished after 1761 timesteps (8.784850120544434 seconds) with total reward 34.47941101893679
# {'coverage_prop': '0.922', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.157', 'efficiency': '0.170', 'TP': '239', 'FP': '20', 'FN': '22', 'precision': '0.923', 'recall': '0.916', 'f1': '0.919', 'total_rewards': 34.4794110189368, 'invalid_action_count': 185, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 13.22544538826469
# steps	 1000 	total rewards	 34.33322317196415
# steps	 1500 	total rewards	 52.38795136623014
# Finished after 1789 timesteps (9.976973056793213 seconds) with total reward 61.74329191139517
# {'coverage_prop': '0.738', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.134', 'efficiency': '0.231', 'TP': '281', 'FP': '83', 'FN': '129', 'precision': '0.772', 'recall': '0.685', 'f1': '0.726', 'total_rewards': 61.743291911394984, 'invalid_action_count': 182, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 5.32267909029062
# steps	 1000 	total rewards	 1.4483265512335501
# steps	 1500 	total rewards	 15.340504199695053
# Finished after 1765 timesteps (8.954910039901733 seconds) with total reward 30.146071678272683
# {'coverage_prop': '0.852', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.154', 'efficiency': '0.169', 'TP': '232', 'FP': '27', 'FN': '45', 'precision': '0.896', 'recall': '0.838', 'f1': '0.866', 'total_rewards': 30.146071678272683, 'invalid_action_count': 180, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc09dafefd0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc0681456a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc058032940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.490', 'ms1ms2_ratio': '1.406', 'efficiency': '0.762', 'TP': '207', 'FP': '193', 'FN': '24', 'precision': '0.517', 'recall': '0.896', 'f1': '0.656'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.210', 'efficiency': '0.728', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.475', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '105', 'FP': '132', 'FN': '14', 'precision': '0.443', 'recall': '0.882', 'f1': '0.590'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.502', 'ms1ms2_ratio': '1.990', 'efficiency': '0.709', 'TP': '146', 'FP': '139', 'FN': '15', 'precision': '0.512', 'recall': '0.907', 'f1': '0.655'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.501', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '186', 'FP': '168', 'FN': '18', 'precision': '0.525', 'recall': '0.912', 'f1': '0.667'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '150', 'FP': '141', 'FN': '11', 'precision': '0.515', 'recall': '0.932', 'f1': '0.664'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.540', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '262', 'FP': '184', 'FN': '22', 'precision': '0.587', 'recall': '0.923', 'f1': '0.718'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.488', 'ms1ms2_ratio': '2.976', 'efficiency': '0.764', 'TP': '106', 'FP': '114', 'FN': '14', 'precision': '0.482', 'recall': '0.883', 'f1': '0.624'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '1.995', 'efficiency': '0.761', 'TP': '160', 'FP': '145', 'FN': '17', 'precision': '0.525', 'recall': '0.904', 'f1': '0.664'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.476', 'efficiency': '0.761', 'TP': '215', 'FP': '170', 'FN': '11', 'precision': '0.558', 'recall': '0.951', 'f1': '0.704'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1827.534502                1877.0          0.345           0.075
# 1  random   -1904.944950                1930.0          0.237           0.044
# 2  random   -1846.321943                1887.0          0.315           0.077
# 3  random   -1775.372862                1836.0          0.416           0.129
# 4  random   -1865.879308                1905.0          0.357           0.089
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.005       0.074      0.163   0.079  0.107
# 1          0.004       0.031      0.161   0.048  0.074
# 2          0.006       0.063      0.226   0.094  0.133
# 3          0.009       0.096      0.298   0.175  0.220
# 4          0.004       0.079      0.218   0.108  0.144

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     194.702364                  12.0          0.920           0.585
# 31    DQN     144.072127                  16.0          0.927           0.648
# 32    DQN     180.954039                  12.0          0.919           0.585
# 33    DQN     202.268397                  15.0          0.914           0.598
# 34    DQN     186.149681                  22.0          0.938           0.619
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.971       0.576      0.709   0.891  0.790
# 31          1.058       0.379      0.827   0.914  0.868
# 32          1.113       0.584      0.704   0.889  0.786
# 33          0.893       0.575      0.765   0.890  0.823
# 34          0.941       0.591      0.739   0.918  0.819

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
