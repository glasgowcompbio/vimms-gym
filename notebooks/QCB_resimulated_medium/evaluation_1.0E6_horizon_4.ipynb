# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-18 09:32:48.274 | INFO     | experiments:get_samplers:260 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9e2e1e92e0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9e00d4c6a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9e18ad1940>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9e2e1e92e0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9e00d4c6a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9e18ad1940>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9e2e1e92e0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9e00d4c6a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9e18ad1940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -469.40907366317043
# steps	 1000 	total rewards	 -929.1706620141283
# steps	 1500 	total rewards	 -1345.9312929119808
# Finished after 1985 timesteps (4.124549150466919 seconds) with total reward -1776.7538596106083
# {'coverage_prop': '0.404', 'intensity_prop': '0.119', 'ms1ms2_ratio': '0.008', 'efficiency': '0.087', 'TP': '46', 'FP': '126', 'FN': '254', 'precision': '0.267', 'recall': '0.153', 'f1': '0.195', 'total_rewards': -1776.7538596106085, 'invalid_action_count': 1837, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -487.0400381040821
# steps	 1000 	total rewards	 -958.1639314873944
# steps	 1500 	total rewards	 -1413.6332307722305
# Finished after 1991 timesteps (2.572493076324463 seconds) with total reward -1884.3022999542432
# {'coverage_prop': '0.298', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.005', 'efficiency': '0.039', 'TP': '16', 'FP': '62', 'FN': '184', 'precision': '0.205', 'recall': '0.080', 'f1': '0.115', 'total_rewards': -1884.302299954243, 'invalid_action_count': 1916, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -485.5778834640738
# steps	 1000 	total rewards	 -926.2145133585004
# steps	 1500 	total rewards	 -1336.2308391182505
# Finished after 1980 timesteps (3.480668783187866 seconds) with total reward -1757.463129291384
# {'coverage_prop': '0.467', 'intensity_prop': '0.128', 'ms1ms2_ratio': '0.010', 'efficiency': '0.094', 'TP': '44', 'FP': '140', 'FN': '210', 'precision': '0.239', 'recall': '0.173', 'f1': '0.201', 'total_rewards': -1757.4631292913846, 'invalid_action_count': 1826, 'num_ms1_scans': 20, 'num_ms2_scans': 1960}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -482.4991850661204
# steps	 1000 	total rewards	 -933.0932261506238
# steps	 1500 	total rewards	 -1419.9034157721846
# Finished after 1993 timesteps (4.378576993942261 seconds) with total reward -1892.1011065204075
# {'coverage_prop': '0.252', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.004', 'efficiency': '0.057', 'TP': '25', 'FP': '89', 'FN': '338', 'precision': '0.219', 'recall': '0.069', 'f1': '0.105', 'total_rewards': -1892.1011065204082, 'invalid_action_count': 1925, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -473.41488474950165
# steps	 1000 	total rewards	 -926.4397728152929
# steps	 1500 	total rewards	 -1343.5627327409502
# Finished after 1987 timesteps (3.835236072540283 seconds) with total reward -1775.1356869516478
# {'coverage_prop': '0.460', 'intensity_prop': '0.123', 'ms1ms2_ratio': '0.007', 'efficiency': '0.102', 'TP': '47', 'FP': '154', 'FN': '236', 'precision': '0.234', 'recall': '0.166', 'f1': '0.194', 'total_rewards': -1775.1356869516485, 'invalid_action_count': 1844, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -484.708019692786
# steps	 1000 	total rewards	 -949.8213970032564
# steps	 1500 	total rewards	 -1419.8259301662235
# Finished after 1985 timesteps (2.223505973815918 seconds) with total reward -1885.322292732375
# {'coverage_prop': '0.375', 'intensity_prop': '0.102', 'ms1ms2_ratio': '0.008', 'efficiency': '0.038', 'TP': '17', 'FP': '58', 'FN': '125', 'precision': '0.227', 'recall': '0.120', 'f1': '0.157', 'total_rewards': -1885.3222927323754, 'invalid_action_count': 1915, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -469.96498957888855
# steps	 1000 	total rewards	 -932.7175917904221
# steps	 1500 	total rewards	 -1339.9912235442084
# Finished after 1988 timesteps (4.002048969268799 seconds) with total reward -1772.861907835912
# {'coverage_prop': '0.425', 'intensity_prop': '0.117', 'ms1ms2_ratio': '0.006', 'efficiency': '0.103', 'TP': '54', 'FP': '149', 'FN': '275', 'precision': '0.266', 'recall': '0.164', 'f1': '0.203', 'total_rewards': -1772.8619078359125, 'invalid_action_count': 1840, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -485.38309999350486
# steps	 1000 	total rewards	 -977.7991095001237
# steps	 1500 	total rewards	 -1467.3854759725873
# Finished after 1992 timesteps (2.828810930252075 seconds) with total reward -1944.7889298162258
# {'coverage_prop': '0.157', 'intensity_prop': '0.023', 'ms1ms2_ratio': '0.004', 'efficiency': '0.016', 'TP': '2', 'FP': '30', 'FN': '172', 'precision': '0.062', 'recall': '0.011', 'f1': '0.019', 'total_rewards': -1944.7889298162256, 'invalid_action_count': 1957, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -498.9
# steps	 1000 	total rewards	 -946.5342493333715
# steps	 1500 	total rewards	 -1388.7241188793619
# Finished after 1983 timesteps (3.5997629165649414 seconds) with total reward -1803.537172215988
# {'coverage_prop': '0.384', 'intensity_prop': '0.093', 'ms1ms2_ratio': '0.009', 'efficiency': '0.083', 'TP': '35', 'FP': '128', 'FN': '261', 'precision': '0.215', 'recall': '0.118', 'f1': '0.153', 'total_rewards': -1803.5371722159875, 'invalid_action_count': 1859, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -488.011244355999
# steps	 1000 	total rewards	 -983.9993135964535
# steps	 1500 	total rewards	 -1437.65887356459
# Finished after 1989 timesteps (3.1237001419067383 seconds) with total reward -1878.7712973671064
# {'coverage_prop': '0.328', 'intensity_prop': '0.071', 'ms1ms2_ratio': '0.006', 'efficiency': '0.064', 'TP': '24', 'FP': '102', 'FN': '258', 'precision': '0.190', 'recall': '0.085', 'f1': '0.118', 'total_rewards': -1878.7712973671069, 'invalid_action_count': 1911, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -492.1581440182646
# steps	 1000 	total rewards	 -936.4611658544256
# steps	 1500 	total rewards	 -1399.5007812707745
# Finished after 1987 timesteps (3.859205722808838 seconds) with total reward -1820.911048110268
# {'coverage_prop': '0.354', 'intensity_prop': '0.098', 'ms1ms2_ratio': '0.007', 'efficiency': '0.080', 'TP': '39', 'FP': '118', 'FN': '286', 'precision': '0.248', 'recall': '0.120', 'f1': '0.162', 'total_rewards': -1820.9110481102693, 'invalid_action_count': 1869, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -493.07556069555375
# steps	 1000 	total rewards	 -963.2601713781592
# steps	 1500 	total rewards	 -1435.1804597158566
# Finished after 1989 timesteps (3.3014678955078125 seconds) with total reward -1912.873636823971
# {'coverage_prop': '0.241', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.006', 'efficiency': '0.030', 'TP': '15', 'FP': '45', 'FN': '189', 'precision': '0.250', 'recall': '0.074', 'f1': '0.114', 'total_rewards': -1912.873636823971, 'invalid_action_count': 1935, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -485.2002404521735
# steps	 1000 	total rewards	 -948.2023183236747
# steps	 1500 	total rewards	 -1413.220834466133
# Finished after 1992 timesteps (2.7223727703094482 seconds) with total reward -1866.4465931455748
# {'coverage_prop': '0.371', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.004', 'efficiency': '0.047', 'TP': '17', 'FP': '76', 'FN': '158', 'precision': '0.183', 'recall': '0.097', 'f1': '0.127', 'total_rewards': -1866.4465931455757, 'invalid_action_count': 1904, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -493.5231858748426
# steps	 1000 	total rewards	 -967.3745508330735
# steps	 1500 	total rewards	 -1424.766123873839
# Finished after 1989 timesteps (2.946686029434204 seconds) with total reward -1868.7406187571514
# {'coverage_prop': '0.347', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.006', 'efficiency': '0.053', 'TP': '31', 'FP': '73', 'FN': '196', 'precision': '0.298', 'recall': '0.137', 'f1': '0.187', 'total_rewards': -1868.7406187571526, 'invalid_action_count': 1904, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -485.18446928036246
# steps	 1000 	total rewards	 -968.0239748559952
# steps	 1500 	total rewards	 -1448.1479302776165
# Finished after 1989 timesteps (2.4072930812835693 seconds) with total reward -1917.45874122706
# {'coverage_prop': '0.262', 'intensity_prop': '0.056', 'ms1ms2_ratio': '0.006', 'efficiency': '0.027', 'TP': '9', 'FP': '45', 'FN': '152', 'precision': '0.167', 'recall': '0.056', 'f1': '0.084', 'total_rewards': -1917.4587412270603, 'invalid_action_count': 1938, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -473.1382258388442
# steps	 1000 	total rewards	 -909.1186458310804
# steps	 1500 	total rewards	 -1321.4504750034162
# Finished after 1982 timesteps (3.355210065841675 seconds) with total reward -1759.3377031610826
# {'coverage_prop': '0.499', 'intensity_prop': '0.153', 'ms1ms2_ratio': '0.009', 'efficiency': '0.103', 'TP': '61', 'FP': '142', 'FN': '204', 'precision': '0.300', 'recall': '0.230', 'f1': '0.261', 'total_rewards': -1759.3377031610828, 'invalid_action_count': 1828, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -945.5765522068561
# steps	 1500 	total rewards	 -1375.8088290069663
# Finished after 1996 timesteps (4.296427011489868 seconds) with total reward -1868.9702686922606
# {'coverage_prop': '0.317', 'intensity_prop': '0.082', 'ms1ms2_ratio': '0.002', 'efficiency': '0.079', 'TP': '40', 'FP': '118', 'FN': '340', 'precision': '0.253', 'recall': '0.105', 'f1': '0.149', 'total_rewards': -1868.9702686922603, 'invalid_action_count': 1910, 'num_ms1_scans': 4, 'num_ms2_scans': 1992}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -477.5723785895998
# steps	 1000 	total rewards	 -916.3022311069358
# steps	 1500 	total rewards	 -1346.7114872117531
# Finished after 1983 timesteps (3.300455093383789 seconds) with total reward -1777.5020824616558
# {'coverage_prop': '0.487', 'intensity_prop': '0.137', 'ms1ms2_ratio': '0.009', 'efficiency': '0.092', 'TP': '47', 'FP': '134', 'FN': '191', 'precision': '0.260', 'recall': '0.197', 'f1': '0.224', 'total_rewards': -1777.5020824616556, 'invalid_action_count': 1840, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -491.55760568724736
# steps	 1000 	total rewards	 -965.3112690839329
# steps	 1500 	total rewards	 -1409.851668059081
# Finished after 1989 timesteps (2.968461275100708 seconds) with total reward -1872.6286112447317
# {'coverage_prop': '0.341', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.006', 'efficiency': '0.052', 'TP': '20', 'FP': '83', 'FN': '199', 'precision': '0.194', 'recall': '0.091', 'f1': '0.124', 'total_rewards': -1872.628611244732, 'invalid_action_count': 1908, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -485.94877998100696
# steps	 1000 	total rewards	 -941.0830906067404
# steps	 1500 	total rewards	 -1385.7512388056916
# Finished after 1986 timesteps (2.74422025680542 seconds) with total reward -1832.5163762999325
# {'coverage_prop': '0.370', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.007', 'efficiency': '0.050', 'TP': '18', 'FP': '80', 'FN': '167', 'precision': '0.184', 'recall': '0.097', 'f1': '0.127', 'total_rewards': -1832.5163762999337, 'invalid_action_count': 1877, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -461.83836383370135
# steps	 1000 	total rewards	 -885.109802884596
# steps	 1500 	total rewards	 -1301.248097845503
# Finished after 1982 timesteps (3.7685840129852295 seconds) with total reward -1747.2595033079087
# {'coverage_prop': '0.429', 'intensity_prop': '0.131', 'ms1ms2_ratio': '0.009', 'efficiency': '0.102', 'TP': '58', 'FP': '143', 'FN': '267', 'precision': '0.289', 'recall': '0.178', 'f1': '0.221', 'total_rewards': -1747.2595033079094, 'invalid_action_count': 1815, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -480.57424011687203
# steps	 1000 	total rewards	 -956.8137165812511
# steps	 1500 	total rewards	 -1419.4416817280871
# Finished after 1989 timesteps (2.4231948852539062 seconds) with total reward -1877.162597297945
# {'coverage_prop': '0.385', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.006', 'efficiency': '0.046', 'TP': '22', 'FP': '68', 'FN': '144', 'precision': '0.244', 'recall': '0.133', 'f1': '0.172', 'total_rewards': -1877.1625972979457, 'invalid_action_count': 1910, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -486.2647931481071
# steps	 1000 	total rewards	 -944.2478319507234
# steps	 1500 	total rewards	 -1392.0120005268082
# Finished after 1988 timesteps (3.5112969875335693 seconds) with total reward -1854.3123838419974
# {'coverage_prop': '0.332', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.006', 'efficiency': '0.054', 'TP': '23', 'FP': '84', 'FN': '215', 'precision': '0.215', 'recall': '0.097', 'f1': '0.133', 'total_rewards': -1854.3123838419979, 'invalid_action_count': 1895, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -484.3459994706651
# steps	 1000 	total rewards	 -966.1803021589863
# steps	 1500 	total rewards	 -1424.8507447716515
# Finished after 1991 timesteps (2.888253927230835 seconds) with total reward -1891.8491935136808
# {'coverage_prop': '0.281', 'intensity_prop': '0.067', 'ms1ms2_ratio': '0.005', 'efficiency': '0.044', 'TP': '17', 'FP': '70', 'FN': '223', 'precision': '0.195', 'recall': '0.071', 'f1': '0.104', 'total_rewards': -1891.8491935136803, 'invalid_action_count': 1922, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -473.39421507112496
# steps	 1000 	total rewards	 -941.2459191908383
# steps	 1500 	total rewards	 -1411.6424251719495
# Finished after 1994 timesteps (3.673603057861328 seconds) with total reward -1904.6424251719495
# {'coverage_prop': '0.197', 'intensity_prop': '0.047', 'ms1ms2_ratio': '0.003', 'efficiency': '0.034', 'TP': '13', 'FP': '55', 'FN': '277', 'precision': '0.191', 'recall': '0.045', 'f1': '0.073', 'total_rewards': -1904.6424251719488, 'invalid_action_count': 1931, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -474.27772565491523
# steps	 1000 	total rewards	 -945.1734851450394
# steps	 1500 	total rewards	 -1407.0062907608176
# Finished after 1987 timesteps (3.2910311222076416 seconds) with total reward -1840.9455002403488
# {'coverage_prop': '0.366', 'intensity_prop': '0.081', 'ms1ms2_ratio': '0.007', 'efficiency': '0.073', 'TP': '32', 'FP': '113', 'FN': '251', 'precision': '0.221', 'recall': '0.113', 'f1': '0.150', 'total_rewards': -1840.9455002403495, 'invalid_action_count': 1886, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -491.8049319039702
# steps	 1000 	total rewards	 -971.7394169696508
# steps	 1500 	total rewards	 -1433.5712142711905
# Finished after 1986 timesteps (2.2562789916992188 seconds) with total reward -1895.9296253238094
# {'coverage_prop': '0.355', 'intensity_prop': '0.085', 'ms1ms2_ratio': '0.007', 'efficiency': '0.037', 'TP': '14', 'FP': '58', 'FN': '131', 'precision': '0.194', 'recall': '0.097', 'f1': '0.129', 'total_rewards': -1895.9296253238103, 'invalid_action_count': 1924, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -489.11121674570927
# steps	 1000 	total rewards	 -986.6105342372878
# steps	 1500 	total rewards	 -1447.5303199765326
# Finished after 1994 timesteps (2.583773136138916 seconds) with total reward -1918.1627176700563
# {'coverage_prop': '0.210', 'intensity_prop': '0.052', 'ms1ms2_ratio': '0.003', 'efficiency': '0.030', 'TP': '14', 'FP': '45', 'FN': '222', 'precision': '0.237', 'recall': '0.059', 'f1': '0.095', 'total_rewards': -1918.1627176700576, 'invalid_action_count': 1941, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -483.0365048190039
# steps	 1000 	total rewards	 -941.8870432689674
# steps	 1500 	total rewards	 -1343.5305445097777
# Finished after 1985 timesteps (4.522349119186401 seconds) with total reward -1758.3160691555424
# {'coverage_prop': '0.430', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.008', 'efficiency': '0.108', 'TP': '42', 'FP': '170', 'FN': '281', 'precision': '0.198', 'recall': '0.130', 'f1': '0.157', 'total_rewards': -1758.3160691555422, 'invalid_action_count': 1826, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -497.8
# steps	 1000 	total rewards	 -969.8931885464931
# steps	 1500 	total rewards	 -1435.5130245449682
# Finished after 1991 timesteps (2.946773052215576 seconds) with total reward -1905.0586835251331
# {'coverage_prop': '0.266', 'intensity_prop': '0.076', 'ms1ms2_ratio': '0.005', 'efficiency': '0.041', 'TP': '21', 'FP': '60', 'FN': '223', 'precision': '0.259', 'recall': '0.086', 'f1': '0.129', 'total_rewards': -1905.0586835251343, 'invalid_action_count': 1932, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.00GB > 0.35GB
# steps	 500 	total rewards	 108.30750929312279
# steps	 1000 	total rewards	 237.41575137136635
# Finished after 1323 timesteps (6.111624002456665 seconds) with total reward 304.93869393271797
# {'coverage_prop': '0.899', 'intensity_prop': '0.568', 'ms1ms2_ratio': '1.048', 'efficiency': '0.593', 'TP': '272', 'FP': '111', 'FN': '43', 'precision': '0.710', 'recall': '0.863', 'f1': '0.779', 'total_rewards': 304.9386939327185, 'invalid_action_count': 7, 'num_ms1_scans': 677, 'num_ms2_scans': 646}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 102.1128891158385
# steps	 1000 	total rewards	 222.81059666796247
# Finished after 1210 timesteps (4.692825794219971 seconds) with total reward 257.324952760152
# {'coverage_prop': '0.943', 'intensity_prop': '0.627', 'ms1ms2_ratio': '1.888', 'efficiency': '0.589', 'TP': '184', 'FP': '63', 'FN': '15', 'precision': '0.745', 'recall': '0.925', 'f1': '0.825', 'total_rewards': 257.32495276014924, 'invalid_action_count': 5, 'num_ms1_scans': 791, 'num_ms2_scans': 419}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 101.40864790872799
# steps	 1000 	total rewards	 -86.13942825609242
# Finished after 1376 timesteps (6.39091420173645 seconds) with total reward -1.8446382035985067
# {'coverage_prop': '0.810', 'intensity_prop': '0.479', 'ms1ms2_ratio': '0.830', 'efficiency': '0.424', 'TP': '212', 'FP': '107', 'FN': '75', 'precision': '0.665', 'recall': '0.739', 'f1': '0.700', 'total_rewards': -1.8446382035996631, 'invalid_action_count': 262, 'num_ms1_scans': 624, 'num_ms2_scans': 752}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 112.3339160026014
# steps	 1000 	total rewards	 253.03747039595348
# Finished after 1326 timesteps (6.3356311321258545 seconds) with total reward 322.9815169512011
# {'coverage_prop': '0.923', 'intensity_prop': '0.608', 'ms1ms2_ratio': '1.034', 'efficiency': '0.640', 'TP': '324', 'FP': '93', 'FN': '35', 'precision': '0.777', 'recall': '0.903', 'f1': '0.835', 'total_rewards': 322.9815169512033, 'invalid_action_count': 3, 'num_ms1_scans': 674, 'num_ms2_scans': 652}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 87.29899553642556
# steps	 1000 	total rewards	 229.74026930247362
# Finished after 1321 timesteps (5.504410266876221 seconds) with total reward 294.1696885215083
# {'coverage_prop': '0.906', 'intensity_prop': '0.580', 'ms1ms2_ratio': '1.058', 'efficiency': '0.617', 'TP': '282', 'FP': '114', 'FN': '41', 'precision': '0.712', 'recall': '0.873', 'f1': '0.784', 'total_rewards': 294.16968852150853, 'invalid_action_count': 15, 'num_ms1_scans': 679, 'num_ms2_scans': 642}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 91.91596294854818
# steps	 1000 	total rewards	 188.38577847709274
# Finished after 1179 timesteps (4.567756175994873 seconds) with total reward 217.87766839800386
# {'coverage_prop': '0.935', 'intensity_prop': '0.650', 'ms1ms2_ratio': '2.303', 'efficiency': '0.524', 'TP': '151', 'FP': '36', 'FN': '13', 'precision': '0.807', 'recall': '0.921', 'f1': '0.860', 'total_rewards': 217.87766839800108, 'invalid_action_count': 3, 'num_ms1_scans': 822, 'num_ms2_scans': 357}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 111.99110690097854
# steps	 1000 	total rewards	 247.1395889700251
# Finished after 1336 timesteps (6.704117059707642 seconds) with total reward 314.4896871432219
# {'coverage_prop': '0.887', 'intensity_prop': '0.540', 'ms1ms2_ratio': '0.988', 'efficiency': '0.631', 'TP': '289', 'FP': '135', 'FN': '54', 'precision': '0.682', 'recall': '0.843', 'f1': '0.754', 'total_rewards': 314.4896871432236, 'invalid_action_count': 11, 'num_ms1_scans': 664, 'num_ms2_scans': 672}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 83.20139460281494
# steps	 1000 	total rewards	 187.95770237027682
# Finished after 1188 timesteps (4.6481499671936035 seconds) with total reward 219.00818636711944
# {'coverage_prop': '0.907', 'intensity_prop': '0.625', 'ms1ms2_ratio': '2.168', 'efficiency': '0.493', 'TP': '150', 'FP': '35', 'FN': '19', 'precision': '0.811', 'recall': '0.888', 'f1': '0.847', 'total_rewards': 219.00818636711725, 'invalid_action_count': 5, 'num_ms1_scans': 813, 'num_ms2_scans': 375}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 116.047334536971
# steps	 1000 	total rewards	 233.66162628453708
# Finished after 1313 timesteps (5.445649862289429 seconds) with total reward 302.6503014987844
# {'coverage_prop': '0.908', 'intensity_prop': '0.560', 'ms1ms2_ratio': '1.097', 'efficiency': '0.615', 'TP': '271', 'FP': '114', 'FN': '39', 'precision': '0.704', 'recall': '0.874', 'f1': '0.780', 'total_rewards': 302.65030149878487, 'invalid_action_count': 5, 'num_ms1_scans': 687, 'num_ms2_scans': 626}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 95.75801445608758
# steps	 1000 	total rewards	 211.78778099298205
# Finished after 1291 timesteps (5.874878883361816 seconds) with total reward 268.84980434146644
# {'coverage_prop': '0.891', 'intensity_prop': '0.575', 'ms1ms2_ratio': '1.222', 'efficiency': '0.589', 'TP': '252', 'FP': '90', 'FN': '42', 'precision': '0.737', 'recall': '0.857', 'f1': '0.792', 'total_rewards': 268.8498043414656, 'invalid_action_count': 9, 'num_ms1_scans': 710, 'num_ms2_scans': 581}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 104.75333063837385
# steps	 1000 	total rewards	 236.9510643422098
# Finished after 1313 timesteps (6.900890111923218 seconds) with total reward 304.0268519609559
# {'coverage_prop': '0.894', 'intensity_prop': '0.552', 'ms1ms2_ratio': '1.097', 'efficiency': '0.633', 'TP': '272', 'FP': '124', 'FN': '47', 'precision': '0.687', 'recall': '0.853', 'f1': '0.761', 'total_rewards': 304.0268519609569, 'invalid_action_count': 6, 'num_ms1_scans': 687, 'num_ms2_scans': 626}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 101.13013503152662
# steps	 1000 	total rewards	 195.72444915057838
# Finished after 1216 timesteps (4.084417104721069 seconds) with total reward 230.78014123281906
# {'coverage_prop': '0.912', 'intensity_prop': '0.622', 'ms1ms2_ratio': '1.821', 'efficiency': '0.527', 'TP': '176', 'FP': '51', 'FN': '22', 'precision': '0.775', 'recall': '0.889', 'f1': '0.828', 'total_rewards': 230.78014123281633, 'invalid_action_count': 7, 'num_ms1_scans': 785, 'num_ms2_scans': 431}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 95.81950628159856
# steps	 1000 	total rewards	 201.2724589304556
# Finished after 1205 timesteps (5.550877809524536 seconds) with total reward 236.48412083945854
# {'coverage_prop': '0.928', 'intensity_prop': '0.577', 'ms1ms2_ratio': '1.953', 'efficiency': '0.571', 'TP': '164', 'FP': '69', 'FN': '18', 'precision': '0.704', 'recall': '0.901', 'f1': '0.790', 'total_rewards': 236.48412083945567, 'invalid_action_count': 1, 'num_ms1_scans': 797, 'num_ms2_scans': 408}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 89.09806905584897
# steps	 1000 	total rewards	 206.54137175177283
# Finished after 1273 timesteps (4.710378170013428 seconds) with total reward 254.89518917083652
# {'coverage_prop': '0.920', 'intensity_prop': '0.588', 'ms1ms2_ratio': '1.332', 'efficiency': '0.505', 'TP': '196', 'FP': '80', 'FN': '24', 'precision': '0.710', 'recall': '0.891', 'f1': '0.790', 'total_rewards': 254.89518917083433, 'invalid_action_count': 4, 'num_ms1_scans': 727, 'num_ms2_scans': 546}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 84.1765842602961
# steps	 1000 	total rewards	 183.43792207276744
# Finished after 1191 timesteps (5.316204786300659 seconds) with total reward 213.59281990006093
# {'coverage_prop': '0.927', 'intensity_prop': '0.596', 'ms1ms2_ratio': '2.126', 'efficiency': '0.501', 'TP': '137', 'FP': '54', 'FN': '15', 'precision': '0.717', 'recall': '0.901', 'f1': '0.799', 'total_rewards': 213.5928199000581, 'invalid_action_count': 6, 'num_ms1_scans': 810, 'num_ms2_scans': 381}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 100.9720374508261
# steps	 1000 	total rewards	 232.9630699066677
# Finished after 1305 timesteps (5.135664939880371 seconds) with total reward 295.02511716099656
# {'coverage_prop': '0.907', 'intensity_prop': '0.584', 'ms1ms2_ratio': '1.139', 'efficiency': '0.605', 'TP': '272', 'FP': '97', 'FN': '38', 'precision': '0.737', 'recall': '0.877', 'f1': '0.801', 'total_rewards': 295.0251171609966, 'invalid_action_count': 11, 'num_ms1_scans': 695, 'num_ms2_scans': 610}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 121.19845165205894
# steps	 1000 	total rewards	 107.17517900959977
# Finished after 1387 timesteps (7.393224000930786 seconds) with total reward 192.66167838056916
# {'coverage_prop': '0.867', 'intensity_prop': '0.553', 'ms1ms2_ratio': '0.794', 'efficiency': '0.559', 'TP': '318', 'FP': '114', 'FN': '66', 'precision': '0.736', 'recall': '0.828', 'f1': '0.779', 'total_rewards': 192.6616783805667, 'invalid_action_count': 126, 'num_ms1_scans': 614, 'num_ms2_scans': 773}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 106.55708334256458
# steps	 1000 	total rewards	 230.3144197124901
# Finished after 1269 timesteps (5.1024558544158936 seconds) with total reward 282.42019490035625
# {'coverage_prop': '0.890', 'intensity_prop': '0.577', 'ms1ms2_ratio': '1.363', 'efficiency': '0.616', 'TP': '252', 'FP': '79', 'FN': '41', 'precision': '0.761', 'recall': '0.860', 'f1': '0.808', 'total_rewards': 282.4201949003559, 'invalid_action_count': 3, 'num_ms1_scans': 732, 'num_ms2_scans': 537}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 97.61227703773643
# steps	 1000 	total rewards	 208.68153511796802
# Finished after 1248 timesteps (6.187000036239624 seconds) with total reward 260.8556526622017
# {'coverage_prop': '0.924', 'intensity_prop': '0.604', 'ms1ms2_ratio': '1.516', 'efficiency': '0.562', 'TP': '201', 'FP': '78', 'FN': '23', 'precision': '0.720', 'recall': '0.897', 'f1': '0.799', 'total_rewards': 260.8556526621995, 'invalid_action_count': 7, 'num_ms1_scans': 752, 'num_ms2_scans': 496}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 85.29695374044233
# steps	 1000 	total rewards	 198.81298709470528
# Finished after 1230 timesteps (4.246302843093872 seconds) with total reward 243.0422177327634
# {'coverage_prop': '0.958', 'intensity_prop': '0.595', 'ms1ms2_ratio': '1.680', 'efficiency': '0.553', 'TP': '174', 'FP': '80', 'FN': '11', 'precision': '0.685', 'recall': '0.941', 'f1': '0.793', 'total_rewards': 243.04221773276043, 'invalid_action_count': 9, 'num_ms1_scans': 771, 'num_ms2_scans': 459}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 109.97531971955537
# steps	 1000 	total rewards	 41.34492016169219
# Finished after 1369 timesteps (8.286601066589355 seconds) with total reward 121.42622043132579
# {'coverage_prop': '0.810', 'intensity_prop': '0.499', 'ms1ms2_ratio': '0.855', 'efficiency': '0.514', 'TP': '255', 'FP': '124', 'FN': '89', 'precision': '0.673', 'recall': '0.741', 'f1': '0.705', 'total_rewards': 121.42622043132462, 'invalid_action_count': 159, 'num_ms1_scans': 631, 'num_ms2_scans': 738}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 92.58371661311851
# steps	 1000 	total rewards	 192.89086899440042
# Finished after 1206 timesteps (3.982221841812134 seconds) with total reward 225.6414999987981
# {'coverage_prop': '0.927', 'intensity_prop': '0.596', 'ms1ms2_ratio': '1.934', 'efficiency': '0.528', 'TP': '150', 'FP': '67', 'FN': '17', 'precision': '0.691', 'recall': '0.898', 'f1': '0.781', 'total_rewards': 225.64149999879564, 'invalid_action_count': 11, 'num_ms1_scans': 795, 'num_ms2_scans': 411}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 94.3881017955695
# steps	 1000 	total rewards	 213.57022885613065
# Finished after 1237 timesteps (4.602859973907471 seconds) with total reward 261.18533014442164
# {'coverage_prop': '0.932', 'intensity_prop': '0.584', 'ms1ms2_ratio': '1.615', 'efficiency': '0.634', 'TP': '214', 'FP': '86', 'FN': '22', 'precision': '0.713', 'recall': '0.907', 'f1': '0.799', 'total_rewards': 261.1853301444193, 'invalid_action_count': 10, 'num_ms1_scans': 764, 'num_ms2_scans': 473}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 103.75605888479659
# steps	 1000 	total rewards	 219.5730778113586
# Finished after 1225 timesteps (6.149679183959961 seconds) with total reward 262.2381598183965
# {'coverage_prop': '0.919', 'intensity_prop': '0.575', 'ms1ms2_ratio': '1.734', 'efficiency': '0.636', 'TP': '195', 'FP': '90', 'FN': '25', 'precision': '0.684', 'recall': '0.886', 'f1': '0.772', 'total_rewards': 262.23815981839437, 'invalid_action_count': 4, 'num_ms1_scans': 777, 'num_ms2_scans': 448}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 103.29951115669893
# steps	 1000 	total rewards	 229.42907808524444
# Finished after 1266 timesteps (4.807881832122803 seconds) with total reward 287.9454906171402
# {'coverage_prop': '0.945', 'intensity_prop': '0.573', 'ms1ms2_ratio': '1.380', 'efficiency': '0.613', 'TP': '214', 'FP': '112', 'FN': '19', 'precision': '0.656', 'recall': '0.918', 'f1': '0.766', 'total_rewards': 287.9454906171405, 'invalid_action_count': 4, 'num_ms1_scans': 734, 'num_ms2_scans': 532}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 96.60990769541499
# steps	 1000 	total rewards	 207.77509405194067
# Finished after 1296 timesteps (5.0472190380096436 seconds) with total reward 270.53873274408886
# {'coverage_prop': '0.912', 'intensity_prop': '0.562', 'ms1ms2_ratio': '1.189', 'efficiency': '0.610', 'TP': '247', 'FP': '114', 'FN': '35', 'precision': '0.684', 'recall': '0.876', 'f1': '0.768', 'total_rewards': 270.5387327440875, 'invalid_action_count': 13, 'num_ms1_scans': 704, 'num_ms2_scans': 592}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 78.96334562384934
# steps	 1000 	total rewards	 181.74545761332104
# Finished after 1185 timesteps (5.679816961288452 seconds) with total reward 211.49571848618893
# {'coverage_prop': '0.931', 'intensity_prop': '0.638', 'ms1ms2_ratio': '2.211', 'efficiency': '0.512', 'TP': '138', 'FP': '51', 'FN': '14', 'precision': '0.730', 'recall': '0.908', 'f1': '0.809', 'total_rewards': 211.49571848618638, 'invalid_action_count': 10, 'num_ms1_scans': 816, 'num_ms2_scans': 369}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 91.63484349054715
# steps	 1000 	total rewards	 202.70328617158347
# Finished after 1241 timesteps (4.136473894119263 seconds) with total reward 256.69428688769665
# {'coverage_prop': '0.932', 'intensity_prop': '0.607', 'ms1ms2_ratio': '1.580', 'efficiency': '0.545', 'TP': '192', 'FP': '70', 'FN': '19', 'precision': '0.733', 'recall': '0.910', 'f1': '0.812', 'total_rewards': 256.6942868876939, 'invalid_action_count': 11, 'num_ms1_scans': 760, 'num_ms2_scans': 481}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 114.27781950816609
# steps	 1000 	total rewards	 236.0531020788129
# Finished after 1330 timesteps (7.670155048370361 seconds) with total reward 312.13011922163764
# {'coverage_prop': '0.850', 'intensity_prop': '0.526', 'ms1ms2_ratio': '1.015', 'efficiency': '0.635', 'TP': '298', 'FP': '121', 'FN': '74', 'precision': '0.711', 'recall': '0.801', 'f1': '0.753', 'total_rewards': 312.1301192216384, 'invalid_action_count': 6, 'num_ms1_scans': 670, 'num_ms2_scans': 660}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 101.60623037325362
# steps	 1000 	total rewards	 208.22250545328154
# Finished after 1246 timesteps (4.644999027252197 seconds) with total reward 251.34417215658772
# {'coverage_prop': '0.928', 'intensity_prop': '0.602', 'ms1ms2_ratio': '1.533', 'efficiency': '0.573', 'TP': '199', 'FP': '83', 'FN': '22', 'precision': '0.706', 'recall': '0.900', 'f1': '0.791', 'total_rewards': 251.3441721565854, 'invalid_action_count': 7, 'num_ms1_scans': 754, 'num_ms2_scans': 492}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 96.2947472112688
# steps	 1000 	total rewards	 210.15683842109235
# steps	 1500 	total rewards	 314.798634056055
# Finished after 1708 timesteps (9.402448892593384 seconds) with total reward 349.6966282125401
# {'coverage_prop': '0.932', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.206', 'efficiency': '0.280', 'TP': '354', 'FP': '43', 'FN': '29', 'precision': '0.892', 'recall': '0.924', 'f1': '0.908', 'total_rewards': 349.6966282125408, 'invalid_action_count': 0, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.71672116839305
# steps	 1000 	total rewards	 202.23560506519314
# steps	 1500 	total rewards	 283.18536291001726
# Finished after 1542 timesteps (7.637001991271973 seconds) with total reward 288.5472310775797
# {'coverage_prop': '0.962', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.424', 'efficiency': '0.233', 'TP': '237', 'FP': '15', 'FN': '10', 'precision': '0.940', 'recall': '0.960', 'f1': '0.950', 'total_rewards': 288.5472310775799, 'invalid_action_count': 0, 'num_ms1_scans': 459, 'num_ms2_scans': 1083}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.62128539259734
# steps	 1000 	total rewards	 209.44701077429943
# steps	 1500 	total rewards	 315.09467642816026
# Finished after 1657 timesteps (8.92913293838501 seconds) with total reward 337.7852727539003
# {'coverage_prop': '0.924', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.261', 'efficiency': '0.277', 'TP': '329', 'FP': '35', 'FN': '30', 'precision': '0.904', 'recall': '0.916', 'f1': '0.910', 'total_rewards': 337.78527275390053, 'invalid_action_count': 0, 'num_ms1_scans': 343, 'num_ms2_scans': 1314}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 104.41605033421533
# steps	 1000 	total rewards	 220.61543523078416
# steps	 1500 	total rewards	 321.7969920978544
# Finished after 1704 timesteps (11.402141094207764 seconds) with total reward 360.2671640277904
# {'coverage_prop': '0.925', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.210', 'efficiency': '0.297', 'TP': '386', 'FP': '32', 'FN': '34', 'precision': '0.923', 'recall': '0.919', 'f1': '0.921', 'total_rewards': 360.26716402779084, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 94.83696526824527
# steps	 1000 	total rewards	 230.4353747798644
# steps	 1500 	total rewards	 341.20598376036196
# Finished after 1691 timesteps (9.23237681388855 seconds) with total reward 373.00301431907974
# {'coverage_prop': '0.961', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.224', 'efficiency': '0.304', 'TP': '368', 'FP': '52', 'FN': '17', 'precision': '0.876', 'recall': '0.956', 'f1': '0.914', 'total_rewards': 373.00301431908053, 'invalid_action_count': 0, 'num_ms1_scans': 309, 'num_ms2_scans': 1382}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.96535245459845
# steps	 1000 	total rewards	 177.0309816592628
# Finished after 1398 timesteps (7.197579860687256 seconds) with total reward 239.4026520560644
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.758', 'efficiency': '0.242', 'TP': '180', 'FP': '12', 'FN': '8', 'precision': '0.938', 'recall': '0.957', 'f1': '0.947', 'total_rewards': 239.40265205606244, 'invalid_action_count': 0, 'num_ms1_scans': 603, 'num_ms2_scans': 795}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 105.43142187016116
# steps	 1000 	total rewards	 217.16234875580517
# steps	 1500 	total rewards	 317.53882861089824
# Finished after 1728 timesteps (9.808151960372925 seconds) with total reward 356.0813403930652
# {'coverage_prop': '0.883', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.187', 'efficiency': '0.290', 'TP': '364', 'FP': '58', 'FN': '56', 'precision': '0.863', 'recall': '0.867', 'f1': '0.865', 'total_rewards': 356.08134039306697, 'invalid_action_count': 0, 'num_ms1_scans': 272, 'num_ms2_scans': 1456}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.26121603810041
# steps	 1000 	total rewards	 179.87909305623398
# Finished after 1458 timesteps (7.171186208724976 seconds) with total reward 248.2539839548109
# {'coverage_prop': '0.961', 'intensity_prop': '0.796', 'ms1ms2_ratio': '0.592', 'efficiency': '0.214', 'TP': '187', 'FP': '9', 'FN': '8', 'precision': '0.954', 'recall': '0.959', 'f1': '0.957', 'total_rewards': 248.2539839548094, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 916}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 101.73075787582624
# steps	 1000 	total rewards	 202.63638040748515
# steps	 1500 	total rewards	 318.35490928225283
# Finished after 1723 timesteps (11.72754716873169 seconds) with total reward 356.04648908095874
# {'coverage_prop': '0.939', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.192', 'efficiency': '0.275', 'TP': '363', 'FP': '35', 'FN': '26', 'precision': '0.912', 'recall': '0.933', 'f1': '0.922', 'total_rewards': 356.04648908096, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1445}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 91.08268938564159
# steps	 1000 	total rewards	 203.1460220195836
# steps	 1500 	total rewards	 302.55484646418915
# Finished after 1647 timesteps (9.299801111221313 seconds) with total reward 323.3439747097695
# {'coverage_prop': '0.945', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.273', 'efficiency': '0.281', 'TP': '325', 'FP': '38', 'FN': '21', 'precision': '0.895', 'recall': '0.939', 'f1': '0.917', 'total_rewards': 323.34397470977063, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 92.89177994740865
# steps	 1000 	total rewards	 200.33780966885
# steps	 1500 	total rewards	 308.44066178823545
# Finished after 1722 timesteps (10.173902034759521 seconds) with total reward 346.27603435685785
# {'coverage_prop': '0.898', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '358', 'FP': '40', 'FN': '45', 'precision': '0.899', 'recall': '0.888', 'f1': '0.894', 'total_rewards': 346.27603435685813, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.66797281187884
# steps	 1000 	total rewards	 184.53222725829215
# steps	 1500 	total rewards	 256.3446714108332
# Finished after 1518 timesteps (8.170161008834839 seconds) with total reward 258.1259622000612
# {'coverage_prop': '0.960', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.467', 'efficiency': '0.231', 'TP': '228', 'FP': '11', 'FN': '10', 'precision': '0.954', 'recall': '0.958', 'f1': '0.956', 'total_rewards': 258.12596220006, 'invalid_action_count': 0, 'num_ms1_scans': 483, 'num_ms2_scans': 1035}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.17262365571366
# steps	 1000 	total rewards	 179.03752773958183
# steps	 1500 	total rewards	 257.1736312003494
# Finished after 1583 timesteps (8.718437194824219 seconds) with total reward 268.1257663511901
# {'coverage_prop': '0.948', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.359', 'efficiency': '0.204', 'TP': '219', 'FP': '19', 'FN': '13', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 268.1257663511893, 'invalid_action_count': 0, 'num_ms1_scans': 418, 'num_ms2_scans': 1165}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 80.6116798332078
# steps	 1000 	total rewards	 173.60201913423703
# steps	 1500 	total rewards	 262.64695811092656
# Finished after 1630 timesteps (11.564559698104858 seconds) with total reward 277.80967508193527
# {'coverage_prop': '0.937', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.294', 'efficiency': '0.223', 'TP': '248', 'FP': '33', 'FN': '19', 'precision': '0.883', 'recall': '0.929', 'f1': '0.905', 'total_rewards': 277.8096750819356, 'invalid_action_count': 0, 'num_ms1_scans': 370, 'num_ms2_scans': 1260}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 78.05105674125915
# steps	 1000 	total rewards	 168.53435625126963
# Finished after 1478 timesteps (7.4024529457092285 seconds) with total reward 239.10890213610804
# {'coverage_prop': '0.951', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.546', 'efficiency': '0.205', 'TP': '183', 'FP': '13', 'FN': '10', 'precision': '0.934', 'recall': '0.948', 'f1': '0.941', 'total_rewards': 239.10890213610625, 'invalid_action_count': 0, 'num_ms1_scans': 522, 'num_ms2_scans': 956}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.24788449900285
# steps	 1000 	total rewards	 201.71725751361183
# steps	 1500 	total rewards	 309.1326060834659
# Finished after 1647 timesteps (9.302226066589355 seconds) with total reward 341.7556904214264
# {'coverage_prop': '0.941', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.273', 'efficiency': '0.296', 'TP': '344', 'FP': '39', 'FN': '24', 'precision': '0.898', 'recall': '0.935', 'f1': '0.916', 'total_rewards': 341.7556904214272, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 109.4689156831942
# steps	 1000 	total rewards	 222.9984511917354
# steps	 1500 	total rewards	 327.33892555353907
# Finished after 1717 timesteps (9.780427932739258 seconds) with total reward 367.5454464599467
# {'coverage_prop': '0.910', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.197', 'efficiency': '0.316', 'TP': '409', 'FP': '44', 'FN': '45', 'precision': '0.903', 'recall': '0.901', 'f1': '0.902', 'total_rewards': 367.54544645994855, 'invalid_action_count': 0, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.66449307716269
# steps	 1000 	total rewards	 208.2255550813367
# steps	 1500 	total rewards	 298.09584404674365
# Finished after 1669 timesteps (8.767401933670044 seconds) with total reward 320.7417873236513
# {'coverage_prop': '0.938', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.248', 'efficiency': '0.261', 'TP': '320', 'FP': '29', 'FN': '23', 'precision': '0.917', 'recall': '0.933', 'f1': '0.925', 'total_rewards': 320.7417873236517, 'invalid_action_count': 0, 'num_ms1_scans': 332, 'num_ms2_scans': 1337}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 86.58222225646823
# steps	 1000 	total rewards	 193.83662787853737
# steps	 1500 	total rewards	 283.52631003777475
# Finished after 1605 timesteps (11.070750951766968 seconds) with total reward 298.66096748916345
# {'coverage_prop': '0.947', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.328', 'efficiency': '0.237', 'TP': '262', 'FP': '24', 'FN': '16', 'precision': '0.916', 'recall': '0.942', 'f1': '0.929', 'total_rewards': 298.6609674891638, 'invalid_action_count': 0, 'num_ms1_scans': 396, 'num_ms2_scans': 1209}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.801418530762
# steps	 1000 	total rewards	 187.14255144611414
# steps	 1500 	total rewards	 271.3242882690306
# Finished after 1602 timesteps (8.151989936828613 seconds) with total reward 281.7817604944602
# {'coverage_prop': '0.977', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.332', 'efficiency': '0.215', 'TP': '237', 'FP': '22', 'FN': '6', 'precision': '0.915', 'recall': '0.975', 'f1': '0.944', 'total_rewards': 281.7817604944603, 'invalid_action_count': 0, 'num_ms1_scans': 399, 'num_ms2_scans': 1203}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.64570324480422
# steps	 1000 	total rewards	 209.8538266334351
# steps	 1500 	total rewards	 302.50968702007094
# Finished after 1712 timesteps (9.618757963180542 seconds) with total reward 343.4124818881533
# {'coverage_prop': '0.874', 'intensity_prop': '0.677', 'ms1ms2_ratio': '0.202', 'efficiency': '0.287', 'TP': '360', 'FP': '49', 'FN': '59', 'precision': '0.880', 'recall': '0.859', 'f1': '0.870', 'total_rewards': 343.4124818881536, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 79.34995801371568
# steps	 1000 	total rewards	 185.05815954422587
# Finished after 1459 timesteps (7.647523880004883 seconds) with total reward 260.9168005156736
# {'coverage_prop': '0.957', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.591', 'efficiency': '0.244', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927', 'total_rewards': 260.9168005156723, 'invalid_action_count': 0, 'num_ms1_scans': 542, 'num_ms2_scans': 917}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 91.16098210415569
# steps	 1000 	total rewards	 198.46979716592637
# steps	 1500 	total rewards	 285.75298617886926
# Finished after 1620 timesteps (8.323068857192993 seconds) with total reward 305.9567725268008
# {'coverage_prop': '0.960', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.306', 'efficiency': '0.249', 'TP': '283', 'FP': '26', 'FN': '13', 'precision': '0.916', 'recall': '0.956', 'f1': '0.936', 'total_rewards': 305.956772526802, 'invalid_action_count': 0, 'num_ms1_scans': 380, 'num_ms2_scans': 1240}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 95.11617971055398
# steps	 1000 	total rewards	 204.85149167720783
# steps	 1500 	total rewards	 291.49540729766466
# Finished after 1557 timesteps (7.882549047470093 seconds) with total reward 300.47640370637237
# {'coverage_prop': '0.948', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.398', 'efficiency': '0.264', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927', 'total_rewards': 300.4764037063734, 'invalid_action_count': 0, 'num_ms1_scans': 443, 'num_ms2_scans': 1114}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 93.89340790301048
# steps	 1000 	total rewards	 205.42243398475907
# steps	 1500 	total rewards	 299.97419106939174
# Finished after 1655 timesteps (11.291530847549438 seconds) with total reward 325.3669482550192
# {'coverage_prop': '0.948', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.263', 'efficiency': '0.250', 'TP': '301', 'FP': '26', 'FN': '18', 'precision': '0.920', 'recall': '0.944', 'f1': '0.932', 'total_rewards': 325.3669482550196, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 92.46389424693754
# steps	 1000 	total rewards	 194.83826945588413
# steps	 1500 	total rewards	 303.0523187043243
# Finished after 1658 timesteps (8.97276520729065 seconds) with total reward 330.86551958049847
# {'coverage_prop': '0.957', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.260', 'efficiency': '0.288', 'TP': '344', 'FP': '35', 'FN': '17', 'precision': '0.908', 'recall': '0.953', 'f1': '0.930', 'total_rewards': 330.8655195804994, 'invalid_action_count': 0, 'num_ms1_scans': 342, 'num_ms2_scans': 1316}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 72.1469507255527
# steps	 1000 	total rewards	 171.47678380953522
# Finished after 1453 timesteps (7.410362243652344 seconds) with total reward 239.9201738382847
# {'coverage_prop': '0.966', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.604', 'efficiency': '0.216', 'TP': '184', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.963', 'f1': '0.951', 'total_rewards': 239.92017383828332, 'invalid_action_count': 0, 'num_ms1_scans': 547, 'num_ms2_scans': 906}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 88.31235132594269
# steps	 1000 	total rewards	 195.74792284704353
# steps	 1500 	total rewards	 294.01215539849073
# Finished after 1539 timesteps (7.860447883605957 seconds) with total reward 299.6239201087449
# {'coverage_prop': '0.957', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.429', 'efficiency': '0.250', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 299.62392010874515, 'invalid_action_count': 0, 'num_ms1_scans': 462, 'num_ms2_scans': 1077}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.85875030891819
# steps	 1000 	total rewards	 197.99866949790092
# steps	 1500 	total rewards	 300.4205818023136
# Finished after 1734 timesteps (9.648364782333374 seconds) with total reward 347.5622303363375
# {'coverage_prop': '0.856', 'intensity_prop': '0.645', 'ms1ms2_ratio': '0.181', 'efficiency': '0.287', 'TP': '358', 'FP': '64', 'FN': '71', 'precision': '0.848', 'recall': '0.834', 'f1': '0.841', 'total_rewards': 347.5622303363379, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1468}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.32388476353701
# steps	 1000 	total rewards	 195.74111008357096
# steps	 1500 	total rewards	 278.7575512609741
# Finished after 1628 timesteps (8.241811990737915 seconds) with total reward 293.7826477847459
# {'coverage_prop': '0.954', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.296', 'efficiency': '0.231', 'TP': '271', 'FP': '19', 'FN': '14', 'precision': '0.934', 'recall': '0.951', 'f1': '0.943', 'total_rewards': 293.78264778474596, 'invalid_action_count': 0, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9e2e1e92e0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f9e00d4c6a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f9e18ad1940>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.489', 'ms1ms2_ratio': '1.387', 'efficiency': '0.768', 'TP': '206', 'FP': '201', 'FN': '19', 'precision': '0.506', 'recall': '0.916', 'f1': '0.652'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.532', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '228', 'FP': '200', 'FN': '9', 'precision': '0.533', 'recall': '0.962', 'f1': '0.686'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.132', 'efficiency': '0.741', 'TP': '257', 'FP': '197', 'FN': '24', 'precision': '0.566', 'recall': '0.915', 'f1': '0.699'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.490', 'ms1ms2_ratio': '1.420', 'efficiency': '0.768', 'TP': '206', 'FP': '194', 'FN': '24', 'precision': '0.515', 'recall': '0.896', 'f1': '0.654'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.488', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '111', 'FP': '126', 'FN': '14', 'precision': '0.468', 'recall': '0.888', 'f1': '0.613'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.540', 'ms1ms2_ratio': '1.087', 'efficiency': '0.763', 'TP': '281', 'FP': '200', 'FN': '17', 'precision': '0.584', 'recall': '0.943', 'f1': '0.721'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '188', 'FP': '166', 'FN': '18', 'precision': '0.531', 'recall': '0.913', 'f1': '0.671'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '150', 'FP': '141', 'FN': '11', 'precision': '0.515', 'recall': '0.932', 'f1': '0.664'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '1.990', 'efficiency': '0.759', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.513', 'ms1ms2_ratio': '1.606', 'efficiency': '0.705', 'TP': '167', 'FP': '168', 'FN': '10', 'precision': '0.499', 'recall': '0.944', 'f1': '0.652'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.521', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '256', 'FP': '213', 'FN': '24', 'precision': '0.546', 'recall': '0.914', 'f1': '0.684'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.002', 'efficiency': '0.725', 'TP': '150', 'FP': '140', 'FN': '14', 'precision': '0.517', 'recall': '0.915', 'f1': '0.661'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1776.753860                1837.0          0.404           0.119
# 1  random   -1884.302300                1916.0          0.298           0.073
# 2  random   -1757.463129                1826.0          0.467           0.128
# 3  random   -1892.101107                1925.0          0.252           0.061
# 4  random   -1775.135687                1844.0          0.460           0.123
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.008       0.087      0.267   0.153  0.195
# 1          0.005       0.039      0.205   0.080  0.115
# 2          0.010       0.094      0.239   0.173  0.201
# 3          0.004       0.057      0.219   0.069  0.105
# 4          0.007       0.102      0.234   0.166  0.194

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     304.938694                   7.0          0.899           0.568
# 31    DQN     257.324953                   5.0          0.943           0.627
# 32    DQN      -1.844638                 262.0          0.810           0.479
# 33    DQN     322.981517                   3.0          0.923           0.608
# 34    DQN     294.169689                  15.0          0.906           0.580
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          1.048       0.593      0.710   0.863  0.779
# 31          1.888       0.589      0.745   0.925  0.825
# 32          0.830       0.424      0.665   0.739  0.700
# 33          1.034       0.640      0.777   0.903  0.835
# 34          1.058       0.617      0.712   0.873  0.784

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
