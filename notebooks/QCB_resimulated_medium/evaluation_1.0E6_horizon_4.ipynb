# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-18 13:48:38.128 | INFO     | experiments:get_samplers:262 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc78df89be0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc74873c670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc758a41910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'exclusion_t0': 5,
#    'exclusion_t1': 120,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc78df89be0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc74873c670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc758a41910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc78df89be0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc74873c670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc758a41910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E6', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['exclusion_t0'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d exclusion_t0 = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['exclusion_t0'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -477.9916775754119
# steps	 1000 	total rewards	 -926.2478573639494
# steps	 1500 	total rewards	 -1356.6458220799832
# Finished after 1986 timesteps (4.73229718208313 seconds) with total reward -1815.6258071744992
# {'coverage_prop': '0.357', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.007', 'efficiency': '0.077', 'TP': '30', 'FP': '122', 'FN': '274', 'precision': '0.197', 'recall': '0.099', 'f1': '0.132', 'total_rewards': -1815.6258071745, 'invalid_action_count': 1867, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -498.9
# steps	 1000 	total rewards	 -966.0169511610436
# steps	 1500 	total rewards	 -1396.8822087790033
# Finished after 1989 timesteps (2.7930290699005127 seconds) with total reward -1854.0026096876913
# {'coverage_prop': '0.370', 'intensity_prop': '0.102', 'ms1ms2_ratio': '0.006', 'efficiency': '0.049', 'TP': '24', 'FP': '73', 'FN': '165', 'precision': '0.247', 'recall': '0.127', 'f1': '0.168', 'total_rewards': -1854.0026096876916, 'invalid_action_count': 1898, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -491.7877774177383
# steps	 1000 	total rewards	 -960.9765353454268
# steps	 1500 	total rewards	 -1412.6697808491367
# Finished after 1990 timesteps (3.8617100715637207 seconds) with total reward -1859.114194561816
# {'coverage_prop': '0.302', 'intensity_prop': '0.063', 'ms1ms2_ratio': '0.005', 'efficiency': '0.060', 'TP': '20', 'FP': '99', 'FN': '275', 'precision': '0.168', 'recall': '0.068', 'f1': '0.097', 'total_rewards': -1859.1141945618167, 'invalid_action_count': 1897, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -472.3761924145924
# steps	 1000 	total rewards	 -935.0609006138371
# steps	 1500 	total rewards	 -1367.1014431118415
# Finished after 1989 timesteps (4.229327917098999 seconds) with total reward -1799.1572426966031
# {'coverage_prop': '0.396', 'intensity_prop': '0.116', 'ms1ms2_ratio': '0.006', 'efficiency': '0.090', 'TP': '48', 'FP': '131', 'FN': '273', 'precision': '0.268', 'recall': '0.150', 'f1': '0.192', 'total_rewards': -1799.1572426966031, 'invalid_action_count': 1857, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -478.0532525409236
# steps	 1000 	total rewards	 -940.7120121124524
# steps	 1500 	total rewards	 -1345.3341005943707
# Finished after 1990 timesteps (4.281808137893677 seconds) with total reward -1793.765989782386
# {'coverage_prop': '0.455', 'intensity_prop': '0.118', 'ms1ms2_ratio': '0.005', 'efficiency': '0.101', 'TP': '41', 'FP': '158', 'FN': '238', 'precision': '0.206', 'recall': '0.147', 'f1': '0.172', 'total_rewards': -1793.7659897823853, 'invalid_action_count': 1858, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -480.9627870792019
# steps	 1000 	total rewards	 -959.2009874791352
# steps	 1500 	total rewards	 -1423.8683470784072
# Finished after 1984 timesteps (2.2653861045837402 seconds) with total reward -1880.6378775873827
# {'coverage_prop': '0.400', 'intensity_prop': '0.109', 'ms1ms2_ratio': '0.008', 'efficiency': '0.041', 'TP': '19', 'FP': '61', 'FN': '120', 'precision': '0.237', 'recall': '0.137', 'f1': '0.174', 'total_rewards': -1880.6378775873839, 'invalid_action_count': 1908, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -469.90860231180966
# steps	 1000 	total rewards	 -921.8623254053599
# steps	 1500 	total rewards	 -1340.7228696987167
# Finished after 1992 timesteps (4.44138765335083 seconds) with total reward -1816.160084680154
# {'coverage_prop': '0.381', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.004', 'efficiency': '0.092', 'TP': '27', 'FP': '155', 'FN': '296', 'precision': '0.148', 'recall': '0.084', 'f1': '0.107', 'total_rewards': -1816.1600846801543, 'invalid_action_count': 1870, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -483.77331009567877
# steps	 1000 	total rewards	 -937.1440415154154
# steps	 1500 	total rewards	 -1391.1050509513784
# Finished after 1985 timesteps (2.7481820583343506 seconds) with total reward -1841.071500612325
# {'coverage_prop': '0.466', 'intensity_prop': '0.126', 'ms1ms2_ratio': '0.008', 'efficiency': '0.048', 'TP': '22', 'FP': '73', 'FN': '109', 'precision': '0.232', 'recall': '0.168', 'f1': '0.195', 'total_rewards': -1841.0715006123257, 'invalid_action_count': 1883, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -476.14430537424585
# steps	 1000 	total rewards	 -918.8251427506143
# steps	 1500 	total rewards	 -1345.718090658542
# Finished after 1989 timesteps (3.75380802154541 seconds) with total reward -1798.1453840273261
# {'coverage_prop': '0.408', 'intensity_prop': '0.121', 'ms1ms2_ratio': '0.006', 'efficiency': '0.087', 'TP': '47', 'FP': '126', 'FN': '251', 'precision': '0.272', 'recall': '0.158', 'f1': '0.200', 'total_rewards': -1798.1453840273255, 'invalid_action_count': 1859, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -482.239229865093
# steps	 1000 	total rewards	 -943.3188884105798
# steps	 1500 	total rewards	 -1365.9266365823887
# Finished after 1986 timesteps (3.4854211807250977 seconds) with total reward -1787.1519786567585
# {'coverage_prop': '0.430', 'intensity_prop': '0.144', 'ms1ms2_ratio': '0.007', 'efficiency': '0.084', 'TP': '55', 'FP': '110', 'FN': '219', 'precision': '0.333', 'recall': '0.201', 'f1': '0.251', 'total_rewards': -1787.15197865676, 'invalid_action_count': 1849, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -972.0631652050937
# steps	 1500 	total rewards	 -1422.800491320354
# Finished after 1995 timesteps (3.7759180068969727 seconds) with total reward -1874.9438101797714
# {'coverage_prop': '0.273', 'intensity_prop': '0.056', 'ms1ms2_ratio': '0.003', 'efficiency': '0.061', 'TP': '19', 'FP': '102', 'FN': '322', 'precision': '0.157', 'recall': '0.056', 'f1': '0.082', 'total_rewards': -1874.9438101797712, 'invalid_action_count': 1911, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -486.6084274233348
# steps	 1000 	total rewards	 -970.5250840294973
# steps	 1500 	total rewards	 -1437.2591214007462
# Finished after 1994 timesteps (2.855018138885498 seconds) with total reward -1916.5741276387066
# {'coverage_prop': '0.253', 'intensity_prop': '0.050', 'ms1ms2_ratio': '0.003', 'efficiency': '0.032', 'TP': '11', 'FP': '52', 'FN': '186', 'precision': '0.175', 'recall': '0.056', 'f1': '0.085', 'total_rewards': -1916.5741276387062, 'invalid_action_count': 1939, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -469.9885003308185
# steps	 1000 	total rewards	 -949.2575426418218
# steps	 1500 	total rewards	 -1401.2315100382511
# Finished after 1987 timesteps (3.2535197734832764 seconds) with total reward -1869.4695893408925
# {'coverage_prop': '0.343', 'intensity_prop': '0.089', 'ms1ms2_ratio': '0.007', 'efficiency': '0.044', 'TP': '21', 'FP': '65', 'FN': '165', 'precision': '0.244', 'recall': '0.113', 'f1': '0.154', 'total_rewards': -1869.4695893408932, 'invalid_action_count': 1903, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -483.00065922601414
# steps	 1000 	total rewards	 -959.6787030279673
# steps	 1500 	total rewards	 -1399.7698044924887
# Finished after 1990 timesteps (3.32735013961792 seconds) with total reward -1857.2689156939418
# {'coverage_prop': '0.407', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.005', 'efficiency': '0.062', 'TP': '35', 'FP': '87', 'FN': '178', 'precision': '0.287', 'recall': '0.164', 'f1': '0.209', 'total_rewards': -1857.2689156939423, 'invalid_action_count': 1895, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -970.1494972738793
# steps	 1500 	total rewards	 -1451.2099831713317
# Finished after 1994 timesteps (2.6598470211029053 seconds) with total reward -1935.933115942321
# {'coverage_prop': '0.189', 'intensity_prop': '0.051', 'ms1ms2_ratio': '0.003', 'efficiency': '0.020', 'TP': '10', 'FP': '29', 'FN': '167', 'precision': '0.256', 'recall': '0.056', 'f1': '0.093', 'total_rewards': -1935.9331159423207, 'invalid_action_count': 1952, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -470.64841793722223
# steps	 1000 	total rewards	 -938.6699671049294
# steps	 1500 	total rewards	 -1422.8463642690558
# Finished after 1992 timesteps (4.443225860595703 seconds) with total reward -1912.33438966512
# {'coverage_prop': '0.219', 'intensity_prop': '0.056', 'ms1ms2_ratio': '0.004', 'efficiency': '0.045', 'TP': '21', 'FP': '68', 'FN': '318', 'precision': '0.236', 'recall': '0.062', 'f1': '0.098', 'total_rewards': -1912.3343896651202, 'invalid_action_count': 1934, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -982.0434972883705
# steps	 1500 	total rewards	 -1430.4332532830401
# Finished after 1995 timesteps (4.00062894821167 seconds) with total reward -1878.0721931585845
# {'coverage_prop': '0.281', 'intensity_prop': '0.048', 'ms1ms2_ratio': '0.003', 'efficiency': '0.070', 'TP': '16', 'FP': '124', 'FN': '358', 'precision': '0.114', 'recall': '0.043', 'f1': '0.062', 'total_rewards': -1878.0721931585854, 'invalid_action_count': 1914, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -498.9
# steps	 1000 	total rewards	 -980.2448347707104
# steps	 1500 	total rewards	 -1440.9302464215789
# Finished after 1991 timesteps (3.824394941329956 seconds) with total reward -1880.0370093423426
# {'coverage_prop': '0.301', 'intensity_prop': '0.070', 'ms1ms2_ratio': '0.005', 'efficiency': '0.057', 'TP': '20', 'FP': '92', 'FN': '260', 'precision': '0.179', 'recall': '0.071', 'f1': '0.102', 'total_rewards': -1880.037009342344, 'invalid_action_count': 1917, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -494.0660199926007
# steps	 1000 	total rewards	 -969.4450457559597
# steps	 1500 	total rewards	 -1422.7933544278285
# Finished after 1990 timesteps (3.1496851444244385 seconds) with total reward -1872.2556452546191
# {'coverage_prop': '0.281', 'intensity_prop': '0.094', 'ms1ms2_ratio': '0.005', 'efficiency': '0.043', 'TP': '27', 'FP': '58', 'FN': '217', 'precision': '0.318', 'recall': '0.111', 'f1': '0.164', 'total_rewards': -1872.2556452546203, 'invalid_action_count': 1910, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -494.2966854558033
# steps	 1000 	total rewards	 -972.7986474796938
# steps	 1500 	total rewards	 -1427.00221706466
# Finished after 1993 timesteps (2.9675610065460205 seconds) with total reward -1898.6081288901773
# {'coverage_prop': '0.272', 'intensity_prop': '0.059', 'ms1ms2_ratio': '0.004', 'efficiency': '0.036', 'TP': '8', 'FP': '64', 'FN': '193', 'precision': '0.111', 'recall': '0.040', 'f1': '0.059', 'total_rewards': -1898.6081288901773, 'invalid_action_count': 1927, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -941.254268905476
# steps	 1500 	total rewards	 -1369.1194504652492
# Finished after 1994 timesteps (4.216813087463379 seconds) with total reward -1831.361529961795
# {'coverage_prop': '0.372', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.003', 'efficiency': '0.088', 'TP': '41', 'FP': '133', 'FN': '294', 'precision': '0.236', 'recall': '0.122', 'f1': '0.161', 'total_rewards': -1831.3615299617948, 'invalid_action_count': 1883, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -485.14425825339805
# steps	 1000 	total rewards	 -947.8326123273796
# steps	 1500 	total rewards	 -1395.50701466973
# Finished after 1986 timesteps (2.503683090209961 seconds) with total reward -1865.5714341209587
# {'coverage_prop': '0.385', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.007', 'efficiency': '0.046', 'TP': '26', 'FP': '64', 'FN': '144', 'precision': '0.289', 'recall': '0.153', 'f1': '0.200', 'total_rewards': -1865.571434120959, 'invalid_action_count': 1902, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -494.1941686153698
# steps	 1000 	total rewards	 -952.9180457338131
# steps	 1500 	total rewards	 -1411.0956129614465
# Finished after 1989 timesteps (3.0342888832092285 seconds) with total reward -1865.1576068279373
# {'coverage_prop': '0.320', 'intensity_prop': '0.099', 'ms1ms2_ratio': '0.006', 'efficiency': '0.052', 'TP': '31', 'FP': '72', 'FN': '219', 'precision': '0.301', 'recall': '0.124', 'f1': '0.176', 'total_rewards': -1865.1576068279364, 'invalid_action_count': 1905, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -498.9
# steps	 1000 	total rewards	 -974.9712595986819
# steps	 1500 	total rewards	 -1428.1825801215332
# Finished after 1991 timesteps (3.332275390625 seconds) with total reward -1885.3092417883054
# {'coverage_prop': '0.306', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.005', 'efficiency': '0.048', 'TP': '19', 'FP': '76', 'FN': '215', 'precision': '0.200', 'recall': '0.081', 'f1': '0.116', 'total_rewards': -1885.3092417883054, 'invalid_action_count': 1916, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -483.8502911677929
# steps	 1000 	total rewards	 -931.2397906658796
# steps	 1500 	total rewards	 -1415.0672259428898
# Finished after 1992 timesteps (3.4468319416046143 seconds) with total reward -1868.5173524806066
# {'coverage_prop': '0.287', 'intensity_prop': '0.052', 'ms1ms2_ratio': '0.004', 'efficiency': '0.050', 'TP': '11', 'FP': '88', 'FN': '246', 'precision': '0.111', 'recall': '0.043', 'f1': '0.062', 'total_rewards': -1868.517352480607, 'invalid_action_count': 1908, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -481.12031738924736
# steps	 1000 	total rewards	 -980.1203173892474
# steps	 1500 	total rewards	 -1458.3230830141679
# Finished after 1993 timesteps (3.1784110069274902 seconds) with total reward -1901.13244659735
# {'coverage_prop': '0.207', 'intensity_prop': '0.046', 'ms1ms2_ratio': '0.004', 'efficiency': '0.041', 'TP': '18', 'FP': '64', 'FN': '314', 'precision': '0.220', 'recall': '0.054', 'f1': '0.087', 'total_rewards': -1901.13244659735, 'invalid_action_count': 1931, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -483.6786650589926
# steps	 1000 	total rewards	 -961.109377752144
# steps	 1500 	total rewards	 -1435.577060611583
# Finished after 1986 timesteps (2.4555230140686035 seconds) with total reward -1895.0119089250175
# {'coverage_prop': '0.315', 'intensity_prop': '0.106', 'ms1ms2_ratio': '0.007', 'efficiency': '0.032', 'TP': '21', 'FP': '43', 'FN': '139', 'precision': '0.328', 'recall': '0.131', 'f1': '0.188', 'total_rewards': -1895.0119089250175, 'invalid_action_count': 1919, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -484.8837797380309
# steps	 1000 	total rewards	 -954.0974981893323
# steps	 1500 	total rewards	 -1415.686026327985
# Finished after 1990 timesteps (2.709444761276245 seconds) with total reward -1874.1226050557725
# {'coverage_prop': '0.320', 'intensity_prop': '0.082', 'ms1ms2_ratio': '0.005', 'efficiency': '0.045', 'TP': '19', 'FP': '71', 'FN': '191', 'precision': '0.211', 'recall': '0.090', 'f1': '0.127', 'total_rewards': -1874.1226050557727, 'invalid_action_count': 1910, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -493.3528453399963
# steps	 1000 	total rewards	 -946.3629052066716
# steps	 1500 	total rewards	 -1349.181789840459
# Finished after 1986 timesteps (3.948741912841797 seconds) with total reward -1759.6275845609705
# {'coverage_prop': '0.387', 'intensity_prop': '0.113', 'ms1ms2_ratio': '0.007', 'efficiency': '0.097', 'TP': '60', 'FP': '131', 'FN': '302', 'precision': '0.314', 'recall': '0.166', 'f1': '0.217', 'total_rewards': -1759.627584560971, 'invalid_action_count': 1826, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -487.3791091660041
# steps	 1000 	total rewards	 -947.7342614557357
# steps	 1500 	total rewards	 -1405.8593085511984
# Finished after 1984 timesteps (3.6713578701019287 seconds) with total reward -1846.9962176774116
# {'coverage_prop': '0.372', 'intensity_prop': '0.123', 'ms1ms2_ratio': '0.008', 'efficiency': '0.057', 'TP': '35', 'FP': '78', 'FN': '191', 'precision': '0.310', 'recall': '0.155', 'f1': '0.206', 'total_rewards': -1846.9962176774125, 'invalid_action_count': 1888, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# method = DQN max_peaks = 200 N = 0 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.64GB > 0.33GB
# steps	 500 	total rewards	 113.5428350490584
# steps	 1000 	total rewards	 236.07617940913724
# Finished after 1230 timesteps (5.975062131881714 seconds) with total reward 290.156967991446
# {'coverage_prop': '0.876', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.680', 'efficiency': '0.813', 'TP': '263', 'FP': '110', 'FN': '53', 'precision': '0.705', 'recall': '0.832', 'f1': '0.763', 'total_rewards': 290.15696799144564, 'invalid_action_count': 9, 'num_ms1_scans': 771, 'num_ms2_scans': 459}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 107.10860996728057
# steps	 1000 	total rewards	 216.83806670565488
# Finished after 1162 timesteps (4.835194110870361 seconds) with total reward 245.230346589158
# {'coverage_prop': '0.916', 'intensity_prop': '0.602', 'ms1ms2_ratio': '2.609', 'efficiency': '0.745', 'TP': '179', 'FP': '61', 'FN': '22', 'precision': '0.746', 'recall': '0.891', 'f1': '0.812', 'total_rewards': 245.23034658915483, 'invalid_action_count': 2, 'num_ms1_scans': 840, 'num_ms2_scans': 322}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 105.4532130725359
# steps	 1000 	total rewards	 238.12666851674456
# Finished after 1203 timesteps (5.967664957046509 seconds) with total reward 280.96180175001166
# {'coverage_prop': '0.865', 'intensity_prop': '0.515', 'ms1ms2_ratio': '1.978', 'efficiency': '0.844', 'TP': '229', 'FP': '112', 'FN': '53', 'precision': '0.672', 'recall': '0.812', 'f1': '0.735', 'total_rewards': 280.9618017500112, 'invalid_action_count': 3, 'num_ms1_scans': 799, 'num_ms2_scans': 404}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 117.05741555653978
# steps	 1000 	total rewards	 240.93674649824487
# Finished after 1241 timesteps (6.246787786483765 seconds) with total reward 295.0085133474598
# {'coverage_prop': '0.892', 'intensity_prop': '0.541', 'ms1ms2_ratio': '1.580', 'efficiency': '0.838', 'TP': '278', 'FP': '125', 'FN': '49', 'precision': '0.690', 'recall': '0.850', 'f1': '0.762', 'total_rewards': 295.00851334746, 'invalid_action_count': 11, 'num_ms1_scans': 760, 'num_ms2_scans': 481}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 104.57983858396638
# steps	 1000 	total rewards	 236.0734419647284
# Finished after 1219 timesteps (6.3688530921936035 seconds) with total reward 279.23143585586644
# {'coverage_prop': '0.867', 'intensity_prop': '0.513', 'ms1ms2_ratio': '1.789', 'efficiency': '0.867', 'TP': '253', 'FP': '126', 'FN': '58', 'precision': '0.668', 'recall': '0.814', 'f1': '0.733', 'total_rewards': 279.2314358558653, 'invalid_action_count': 7, 'num_ms1_scans': 782, 'num_ms2_scans': 437}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 92.64282065553036
# steps	 1000 	total rewards	 181.53279208323232
# Finished after 1121 timesteps (4.419398069381714 seconds) with total reward 203.56586376283843
# {'coverage_prop': '0.910', 'intensity_prop': '0.589', 'ms1ms2_ratio': '3.671', 'efficiency': '0.758', 'TP': '143', 'FP': '39', 'FN': '18', 'precision': '0.786', 'recall': '0.888', 'f1': '0.834', 'total_rewards': 203.56586376283556, 'invalid_action_count': 0, 'num_ms1_scans': 881, 'num_ms2_scans': 240}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 120.66759822051822
# steps	 1000 	total rewards	 243.2412518659755
# Finished after 1255 timesteps (5.86112904548645 seconds) with total reward 293.417151341467
# {'coverage_prop': '0.849', 'intensity_prop': '0.524', 'ms1ms2_ratio': '1.461', 'efficiency': '0.796', 'TP': '282', 'FP': '124', 'FN': '72', 'precision': '0.695', 'recall': '0.797', 'f1': '0.742', 'total_rewards': 293.4171513414678, 'invalid_action_count': 12, 'num_ms1_scans': 745, 'num_ms2_scans': 510}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 93.90097440888964
# steps	 1000 	total rewards	 193.04046529852445
# Finished after 1130 timesteps (4.745975732803345 seconds) with total reward 214.6823062075074
# {'coverage_prop': '0.902', 'intensity_prop': '0.604', 'ms1ms2_ratio': '3.363', 'efficiency': '0.710', 'TP': '146', 'FP': '38', 'FN': '20', 'precision': '0.793', 'recall': '0.880', 'f1': '0.834', 'total_rewards': 214.68230620750478, 'invalid_action_count': 2, 'num_ms1_scans': 871, 'num_ms2_scans': 259}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 119.10196982273598
# steps	 1000 	total rewards	 241.86825542664627
# Finished after 1221 timesteps (6.833855867385864 seconds) with total reward 288.0379619403902
# {'coverage_prop': '0.875', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.775', 'efficiency': '0.843', 'TP': '253', 'FP': '118', 'FN': '53', 'precision': '0.682', 'recall': '0.827', 'f1': '0.747', 'total_rewards': 288.03796194039006, 'invalid_action_count': 6, 'num_ms1_scans': 781, 'num_ms2_scans': 440}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 103.76238538602695
# steps	 1000 	total rewards	 230.14599016131456
# Finished after 1206 timesteps (5.209460973739624 seconds) with total reward 269.1948047668476
# {'coverage_prop': '0.891', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.934', 'efficiency': '0.832', 'TP': '223', 'FP': '119', 'FN': '42', 'precision': '0.652', 'recall': '0.842', 'f1': '0.735', 'total_rewards': 269.19480476684635, 'invalid_action_count': 3, 'num_ms1_scans': 795, 'num_ms2_scans': 411}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 106.87531511182513
# steps	 1000 	total rewards	 216.7355926877374
# Finished after 1254 timesteps (6.993693113327026 seconds) with total reward 274.8616606100561
# {'coverage_prop': '0.874', 'intensity_prop': '0.538', 'ms1ms2_ratio': '1.469', 'efficiency': '0.762', 'TP': '270', 'FP': '117', 'FN': '56', 'precision': '0.698', 'recall': '0.828', 'f1': '0.757', 'total_rewards': 274.86166061005486, 'invalid_action_count': 27, 'num_ms1_scans': 746, 'num_ms2_scans': 508}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 103.67584692374854
# steps	 1000 	total rewards	 202.04898406355335
# Finished after 1155 timesteps (5.270497798919678 seconds) with total reward 226.9328908234293
# {'coverage_prop': '0.912', 'intensity_prop': '0.586', 'ms1ms2_ratio': '2.738', 'efficiency': '0.735', 'TP': '167', 'FP': '60', 'FN': '22', 'precision': '0.736', 'recall': '0.884', 'f1': '0.803', 'total_rewards': 226.93289082342605, 'invalid_action_count': 2, 'num_ms1_scans': 846, 'num_ms2_scans': 309}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 94.68365719729495
# steps	 1000 	total rewards	 199.16791630522354
# Finished after 1143 timesteps (4.402331352233887 seconds) with total reward 226.5083996573457
# {'coverage_prop': '0.900', 'intensity_prop': '0.538', 'ms1ms2_ratio': '3.011', 'efficiency': '0.793', 'TP': '146', 'FP': '80', 'FN': '25', 'precision': '0.646', 'recall': '0.854', 'f1': '0.736', 'total_rewards': 226.50839965734255, 'invalid_action_count': 2, 'num_ms1_scans': 858, 'num_ms2_scans': 285}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 95.27651091709333
# steps	 1000 	total rewards	 212.75021376254017
# Finished after 1200 timesteps (6.205234050750732 seconds) with total reward 245.78446230054377
# {'coverage_prop': '0.917', 'intensity_prop': '0.549', 'ms1ms2_ratio': '2.008', 'efficiency': '0.689', 'TP': '174', 'FP': '101', 'FN': '25', 'precision': '0.633', 'recall': '0.874', 'f1': '0.734', 'total_rewards': 245.7844623005411, 'invalid_action_count': 5, 'num_ms1_scans': 801, 'num_ms2_scans': 399}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 90.29099078482665
# steps	 1000 	total rewards	 190.71992479944504
# Finished after 1126 timesteps (4.027328968048096 seconds) with total reward 214.94207677678736
# {'coverage_prop': '0.908', 'intensity_prop': '0.576', 'ms1ms2_ratio': '3.504', 'efficiency': '0.748', 'TP': '135', 'FP': '52', 'FN': '19', 'precision': '0.722', 'recall': '0.877', 'f1': '0.792', 'total_rewards': 214.94207677678432, 'invalid_action_count': 0, 'num_ms1_scans': 876, 'num_ms2_scans': 250}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 101.53598469909414
# steps	 1000 	total rewards	 228.96965026001908
# Finished after 1222 timesteps (6.764654159545898 seconds) with total reward 279.5890229487824
# {'coverage_prop': '0.907', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.765', 'efficiency': '0.835', 'TP': '252', 'FP': '117', 'FN': '38', 'precision': '0.683', 'recall': '0.869', 'f1': '0.765', 'total_rewards': 279.5890229487815, 'invalid_action_count': 6, 'num_ms1_scans': 780, 'num_ms2_scans': 442}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 116.10343624376455
# steps	 1000 	total rewards	 243.65155970738365
# Finished after 1277 timesteps (5.973836183547974 seconds) with total reward 298.0076703010718
# {'coverage_prop': '0.869', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.305', 'efficiency': '0.782', 'TP': '306', 'FP': '127', 'FN': '65', 'precision': '0.707', 'recall': '0.825', 'f1': '0.761', 'total_rewards': 298.0076703010729, 'invalid_action_count': 17, 'num_ms1_scans': 723, 'num_ms2_scans': 554}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 114.70135612795278
# steps	 1000 	total rewards	 236.70253545666964
# Finished after 1196 timesteps (6.625126838684082 seconds) with total reward 271.5041832436535
# {'coverage_prop': '0.911', 'intensity_prop': '0.549', 'ms1ms2_ratio': '2.059', 'efficiency': '0.867', 'TP': '234', 'FP': '105', 'FN': '33', 'precision': '0.690', 'recall': '0.876', 'f1': '0.772', 'total_rewards': 271.5041832436519, 'invalid_action_count': 3, 'num_ms1_scans': 805, 'num_ms2_scans': 391}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 101.81175266328182
# steps	 1000 	total rewards	 217.96037893934738
# Finished after 1176 timesteps (4.7247068881988525 seconds) with total reward 252.25831842787304
# {'coverage_prop': '0.901', 'intensity_prop': '0.557', 'ms1ms2_ratio': '2.350', 'efficiency': '0.775', 'TP': '189', 'FP': '83', 'FN': '30', 'precision': '0.695', 'recall': '0.863', 'f1': '0.770', 'total_rewards': 252.25831842786994, 'invalid_action_count': 1, 'num_ms1_scans': 825, 'num_ms2_scans': 351}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 96.20002857640728
# steps	 1000 	total rewards	 206.2682206847329
# Finished after 1167 timesteps (5.931167125701904 seconds) with total reward 236.0463644884714
# {'coverage_prop': '0.913', 'intensity_prop': '0.528', 'ms1ms2_ratio': '2.515', 'efficiency': '0.729', 'TP': '156', 'FP': '86', 'FN': '23', 'precision': '0.645', 'recall': '0.872', 'f1': '0.741', 'total_rewards': 236.04636448846838, 'invalid_action_count': 1, 'num_ms1_scans': 835, 'num_ms2_scans': 332}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 118.2697708496409
# steps	 1000 	total rewards	 229.46435950647418
# Finished after 1244 timesteps (5.874491930007935 seconds) with total reward 280.1255014558505
# {'coverage_prop': '0.833', 'intensity_prop': '0.518', 'ms1ms2_ratio': '1.554', 'efficiency': '0.801', 'TP': '274', 'FP': '116', 'FN': '78', 'precision': '0.703', 'recall': '0.778', 'f1': '0.739', 'total_rewards': 280.1255014558493, 'invalid_action_count': 16, 'num_ms1_scans': 757, 'num_ms2_scans': 487}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 92.93155887701153
# steps	 1000 	total rewards	 200.4202058998229
# Finished after 1136 timesteps (4.0294458866119385 seconds) with total reward 222.6057892915319
# {'coverage_prop': '0.910', 'intensity_prop': '0.577', 'ms1ms2_ratio': '3.207', 'efficiency': '0.789', 'TP': '148', 'FP': '65', 'FN': '21', 'precision': '0.695', 'recall': '0.876', 'f1': '0.775', 'total_rewards': 222.60578929152894, 'invalid_action_count': 1, 'num_ms1_scans': 866, 'num_ms2_scans': 270}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 107.54933572442303
# steps	 1000 	total rewards	 220.52579877850889
# Finished after 1187 timesteps (4.819401025772095 seconds) with total reward 256.998723177238
# {'coverage_prop': '0.904', 'intensity_prop': '0.547', 'ms1ms2_ratio': '2.191', 'efficiency': '0.782', 'TP': '201', 'FP': '90', 'FN': '31', 'precision': '0.691', 'recall': '0.866', 'f1': '0.769', 'total_rewards': 256.99872317723515, 'invalid_action_count': 2, 'num_ms1_scans': 815, 'num_ms2_scans': 372}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 110.01276877593395
# steps	 1000 	total rewards	 223.6422773676212
# Finished after 1174 timesteps (4.431164979934692 seconds) with total reward 258.55623047055735
# {'coverage_prop': '0.894', 'intensity_prop': '0.567', 'ms1ms2_ratio': '2.393', 'efficiency': '0.801', 'TP': '201', 'FP': '76', 'FN': '33', 'precision': '0.726', 'recall': '0.859', 'f1': '0.787', 'total_rewards': 258.5562304705545, 'invalid_action_count': 0, 'num_ms1_scans': 828, 'num_ms2_scans': 346}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 106.93433727394003
# steps	 1000 	total rewards	 223.4902337349492
# Finished after 1201 timesteps (6.7558979988098145 seconds) with total reward 269.2001662458976
# {'coverage_prop': '0.899', 'intensity_prop': '0.531', 'ms1ms2_ratio': '2.002', 'efficiency': '0.775', 'TP': '208', 'FP': '102', 'FN': '35', 'precision': '0.671', 'recall': '0.856', 'f1': '0.752', 'total_rewards': 269.2001662458963, 'invalid_action_count': 6, 'num_ms1_scans': 801, 'num_ms2_scans': 400}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 107.5527860546435
# steps	 1000 	total rewards	 225.14395517133846
# Finished after 1207 timesteps (5.230410814285278 seconds) with total reward 269.0535446431169
# {'coverage_prop': '0.876', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.923', 'efficiency': '0.840', 'TP': '235', 'FP': '112', 'FN': '49', 'precision': '0.677', 'recall': '0.827', 'f1': '0.745', 'total_rewards': 269.05354464311546, 'invalid_action_count': 7, 'num_ms1_scans': 794, 'num_ms2_scans': 413}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 84.68538498832368
# steps	 1000 	total rewards	 190.41008228866662
# Finished after 1130 timesteps (3.8122761249542236 seconds) with total reward 208.2801165324508
# {'coverage_prop': '0.916', 'intensity_prop': '0.595', 'ms1ms2_ratio': '3.380', 'efficiency': '0.721', 'TP': '134', 'FP': '52', 'FN': '17', 'precision': '0.720', 'recall': '0.887', 'f1': '0.795', 'total_rewards': 208.280116532448, 'invalid_action_count': 1, 'num_ms1_scans': 872, 'num_ms2_scans': 258}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 98.42208285142827
# steps	 1000 	total rewards	 220.4282404781652
# Finished after 1162 timesteps (6.068928956985474 seconds) with total reward 257.70618923070947
# {'coverage_prop': '0.900', 'intensity_prop': '0.568', 'ms1ms2_ratio': '2.609', 'efficiency': '0.786', 'TP': '172', 'FP': '81', 'FN': '28', 'precision': '0.680', 'recall': '0.860', 'f1': '0.759', 'total_rewards': 257.7061892307068, 'invalid_action_count': 1, 'num_ms1_scans': 840, 'num_ms2_scans': 322}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 118.30825975955716
# steps	 1000 	total rewards	 224.82703751250722
# Finished after 1254 timesteps (5.9200921058654785 seconds) with total reward 284.8567370582131
# {'coverage_prop': '0.832', 'intensity_prop': '0.468', 'ms1ms2_ratio': '1.469', 'efficiency': '0.807', 'TP': '249', 'FP': '161', 'FN': '83', 'precision': '0.607', 'recall': '0.750', 'f1': '0.671', 'total_rewards': 284.8567370582125, 'invalid_action_count': 17, 'num_ms1_scans': 746, 'num_ms2_scans': 508}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 106.82085243590865
# steps	 1000 	total rewards	 217.04443376489556
# Finished after 1177 timesteps (4.674294948577881 seconds) with total reward 250.37074574865161
# {'coverage_prop': '0.914', 'intensity_prop': '0.568', 'ms1ms2_ratio': '2.334', 'efficiency': '0.788', 'TP': '186', 'FP': '92', 'FN': '26', 'precision': '0.669', 'recall': '0.877', 'f1': '0.759', 'total_rewards': 250.37074574864852, 'invalid_action_count': 2, 'num_ms1_scans': 824, 'num_ms2_scans': 353}
#
# method = topN max_peaks = 200 N = 10 exclusion_t0 = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 36.22818135034017
# steps	 1000 	total rewards	 64.42482564837266
# steps	 1500 	total rewards	 99.28997067812608
# Finished after 1783 timesteps (11.981503963470459 seconds) with total reward 105.24224614290414
# {'coverage_prop': '0.798', 'intensity_prop': '0.596', 'ms1ms2_ratio': '0.139', 'efficiency': '0.217', 'TP': '289', 'FP': '51', 'FN': '86', 'precision': '0.850', 'recall': '0.771', 'f1': '0.808', 'total_rewards': 105.24224614290378, 'invalid_action_count': 190, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 36.95055263940686
# steps	 1000 	total rewards	 56.24669712610799
# steps	 1500 	total rewards	 84.54776689687884
# Finished after 1754 timesteps (8.5055410861969 seconds) with total reward 103.56681323937316
# {'coverage_prop': '0.931', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.163', 'efficiency': '0.162', 'TP': '227', 'FP': '17', 'FN': '18', 'precision': '0.930', 'recall': '0.927', 'f1': '0.928', 'total_rewards': 103.56681323937299, 'invalid_action_count': 182, 'num_ms1_scans': 246, 'num_ms2_scans': 1508}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 33.85441724814904
# steps	 1000 	total rewards	 66.11400466229793
# steps	 1500 	total rewards	 89.62842151957662
# Finished after 1771 timesteps (9.864897012710571 seconds) with total reward 104.70606985396589
# {'coverage_prop': '0.812', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.149', 'efficiency': '0.208', 'TP': '264', 'FP': '56', 'FN': '74', 'precision': '0.825', 'recall': '0.781', 'f1': '0.802', 'total_rewards': 104.70606985396556, 'invalid_action_count': 191, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 25.36479316230376
# steps	 1000 	total rewards	 53.884281877106105
# steps	 1500 	total rewards	 87.44727376281782
# Finished after 1783 timesteps (10.11473298072815 seconds) with total reward 104.51616205305751
# {'coverage_prop': '0.823', 'intensity_prop': '0.611', 'ms1ms2_ratio': '0.139', 'efficiency': '0.238', 'TP': '320', 'FP': '52', 'FN': '80', 'precision': '0.860', 'recall': '0.800', 'f1': '0.829', 'total_rewards': 104.51616205305736, 'invalid_action_count': 208, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 19.486850170704304
# steps	 1000 	total rewards	 55.37851485172865
# steps	 1500 	total rewards	 105.42629761800157
# Finished after 1776 timesteps (10.199659824371338 seconds) with total reward 127.1585794291341
# {'coverage_prop': '0.872', 'intensity_prop': '0.644', 'ms1ms2_ratio': '0.144', 'efficiency': '0.245', 'TP': '321', 'FP': '60', 'FN': '56', 'precision': '0.843', 'recall': '0.851', 'f1': '0.847', 'total_rewards': 127.15857942913375, 'invalid_action_count': 201, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 34.63793803551461
# steps	 1000 	total rewards	 67.07296167920092
# steps	 1500 	total rewards	 89.83594187207845
# Finished after 1715 timesteps (8.429214239120483 seconds) with total reward 106.7015959178645
# {'coverage_prop': '0.935', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.199', 'efficiency': '0.131', 'TP': '177', 'FP': '10', 'FN': '13', 'precision': '0.947', 'recall': '0.932', 'f1': '0.939', 'total_rewards': 106.70159591786394, 'invalid_action_count': 145, 'num_ms1_scans': 285, 'num_ms2_scans': 1430}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 32.34106293938378
# steps	 1000 	total rewards	 57.54539444052348
# steps	 1500 	total rewards	 93.09062860594904
# Finished after 1777 timesteps (10.57442593574524 seconds) with total reward 104.24916161208603
# {'coverage_prop': '0.757', 'intensity_prop': '0.529', 'ms1ms2_ratio': '0.144', 'efficiency': '0.233', 'TP': '283', 'FP': '79', 'FN': '116', 'precision': '0.782', 'recall': '0.709', 'f1': '0.744', 'total_rewards': 104.24916161208573, 'invalid_action_count': 190, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 36.486818499891655
# steps	 1000 	total rewards	 61.087153701305944
# steps	 1500 	total rewards	 86.42854433883424
# Finished after 1720 timesteps (10.652346849441528 seconds) with total reward 102.5590971299181
# {'coverage_prop': '0.917', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.194', 'efficiency': '0.130', 'TP': '181', 'FP': '6', 'FN': '17', 'precision': '0.968', 'recall': '0.914', 'f1': '0.940', 'total_rewards': 102.55909712991786, 'invalid_action_count': 143, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 28.7477554937186
# steps	 1000 	total rewards	 40.00384804722122
# steps	 1500 	total rewards	 76.8118838001413
# Finished after 1794 timesteps (10.598098039627075 seconds) with total reward 98.17779420916709
# {'coverage_prop': '0.854', 'intensity_prop': '0.641', 'ms1ms2_ratio': '0.130', 'efficiency': '0.228', 'TP': '315', 'FP': '47', 'FN': '62', 'precision': '0.870', 'recall': '0.836', 'f1': '0.853', 'total_rewards': 98.1777942091669, 'invalid_action_count': 218, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 34.803567559531785
# steps	 1000 	total rewards	 60.89768374917202
# steps	 1500 	total rewards	 97.74863784161958
# Finished after 1781 timesteps (9.717313051223755 seconds) with total reward 106.81846769047108
# {'coverage_prop': '0.820', 'intensity_prop': '0.624', 'ms1ms2_ratio': '0.140', 'efficiency': '0.202', 'TP': '273', 'FP': '42', 'FN': '69', 'precision': '0.867', 'recall': '0.798', 'f1': '0.831', 'total_rewards': 106.81846769047078, 'invalid_action_count': 183, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 29.504572683436752
# steps	 1000 	total rewards	 52.869129918240375
# steps	 1500 	total rewards	 94.87139594646786
# Finished after 1790 timesteps (10.669004917144775 seconds) with total reward 114.33927497258928
# {'coverage_prop': '0.777', 'intensity_prop': '0.574', 'ms1ms2_ratio': '0.133', 'efficiency': '0.218', 'TP': '290', 'FP': '54', 'FN': '99', 'precision': '0.843', 'recall': '0.746', 'f1': '0.791', 'total_rewards': 114.33927497258922, 'invalid_action_count': 180, 'num_ms1_scans': 210, 'num_ms2_scans': 1580}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 30.440102555571414
# steps	 1000 	total rewards	 56.36709514543395
# steps	 1500 	total rewards	 68.48718350321698
# Finished after 1753 timesteps (8.90287733078003 seconds) with total reward 77.53295397384858
# {'coverage_prop': '0.916', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.164', 'efficiency': '0.151', 'TP': '217', 'FP': '11', 'FN': '21', 'precision': '0.952', 'recall': '0.912', 'f1': '0.931', 'total_rewards': 77.53295397384827, 'invalid_action_count': 175, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 34.58876857886527
# steps	 1000 	total rewards	 52.049370124963986
# steps	 1500 	total rewards	 79.42693989324532
# Finished after 1779 timesteps (9.718055009841919 seconds) with total reward 98.605277626918
# {'coverage_prop': '0.861', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.142', 'efficiency': '0.139', 'TP': '191', 'FP': '25', 'FN': '35', 'precision': '0.884', 'recall': '0.845', 'f1': '0.864', 'total_rewards': 98.60527762691795, 'invalid_action_count': 149, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 30.31106910012329
# steps	 1000 	total rewards	 56.573642095893184
# steps	 1500 	total rewards	 84.87904298463485
# Finished after 1771 timesteps (10.131422996520996 seconds) with total reward 94.3323094226226
# {'coverage_prop': '0.837', 'intensity_prop': '0.635', 'ms1ms2_ratio': '0.149', 'efficiency': '0.163', 'TP': '215', 'FP': '36', 'FN': '49', 'precision': '0.857', 'recall': '0.814', 'f1': '0.835', 'total_rewards': 94.33230942262243, 'invalid_action_count': 157, 'num_ms1_scans': 229, 'num_ms2_scans': 1542}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 37.72454256087685
# steps	 1000 	total rewards	 64.74976566114961
# steps	 1500 	total rewards	 86.04416626006316
# Finished after 1748 timesteps (11.21358323097229 seconds) with total reward 98.39838922903951
# {'coverage_prop': '0.879', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.168', 'efficiency': '0.121', 'TP': '164', 'FP': '17', 'FN': '25', 'precision': '0.906', 'recall': '0.868', 'f1': '0.886', 'total_rewards': 98.39838922903924, 'invalid_action_count': 132, 'num_ms1_scans': 252, 'num_ms2_scans': 1496}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 28.971203725248017
# steps	 1000 	total rewards	 45.62924737170738
# steps	 1500 	total rewards	 72.88766044743825
# Finished after 1775 timesteps (10.040997743606567 seconds) with total reward 84.84585984235851
# {'coverage_prop': '0.870', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.145', 'efficiency': '0.228', 'TP': '313', 'FP': '41', 'FN': '53', 'precision': '0.884', 'recall': '0.855', 'f1': '0.869', 'total_rewards': 84.84585984235832, 'invalid_action_count': 226, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 28.79105700959758
# steps	 1000 	total rewards	 53.47431242583349
# steps	 1500 	total rewards	 79.57253364355874
# Finished after 1782 timesteps (10.414017677307129 seconds) with total reward 92.06723321793575
# {'coverage_prop': '0.773', 'intensity_prop': '0.564', 'ms1ms2_ratio': '0.139', 'efficiency': '0.246', 'TP': '318', 'FP': '67', 'FN': '113', 'precision': '0.826', 'recall': '0.738', 'f1': '0.779', 'total_rewards': 92.06723321793545, 'invalid_action_count': 210, 'num_ms1_scans': 218, 'num_ms2_scans': 1564}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 26.913838815416234
# steps	 1000 	total rewards	 50.20074520548297
# steps	 1500 	total rewards	 77.11765619558116
# Finished after 1781 timesteps (9.591681003570557 seconds) with total reward 86.46055093238273
# {'coverage_prop': '0.831', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.140', 'efficiency': '0.198', 'TP': '259', 'FP': '50', 'FN': '63', 'precision': '0.838', 'recall': '0.804', 'f1': '0.821', 'total_rewards': 86.46055093238245, 'invalid_action_count': 186, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 36.17728284028373
# steps	 1000 	total rewards	 57.90481577480248
# steps	 1500 	total rewards	 77.2044480365449
# Finished after 1767 timesteps (9.389601945877075 seconds) with total reward 98.2396947878913
# {'coverage_prop': '0.901', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.152', 'efficiency': '0.177', 'TP': '245', 'FP': '27', 'FN': '30', 'precision': '0.901', 'recall': '0.891', 'f1': '0.896', 'total_rewards': 98.23969478789084, 'invalid_action_count': 188, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 34.78613512457089
# steps	 1000 	total rewards	 57.99229813777961
# steps	 1500 	total rewards	 80.6692164478798
# Finished after 1767 timesteps (9.14716124534607 seconds) with total reward 99.51087544110308
# {'coverage_prop': '0.902', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.152', 'efficiency': '0.156', 'TP': '214', 'FP': '25', 'FN': '26', 'precision': '0.895', 'recall': '0.892', 'f1': '0.894', 'total_rewards': 99.51087544110301, 'invalid_action_count': 160, 'num_ms1_scans': 233, 'num_ms2_scans': 1534}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 34.457855600872044
# steps	 1000 	total rewards	 55.66270895766113
# steps	 1500 	total rewards	 84.44715817730895
# Finished after 1781 timesteps (10.298618078231812 seconds) with total reward 104.37179810296838
# {'coverage_prop': '0.716', 'intensity_prop': '0.527', 'ms1ms2_ratio': '0.140', 'efficiency': '0.214', 'TP': '283', 'FP': '52', 'FN': '133', 'precision': '0.845', 'recall': '0.680', 'f1': '0.754', 'total_rewards': 104.37179810296816, 'invalid_action_count': 175, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 37.75904049000865
# steps	 1000 	total rewards	 61.080416503743756
# steps	 1500 	total rewards	 81.41850233982566
# Finished after 1737 timesteps (9.611846923828125 seconds) with total reward 99.66080220512994
# {'coverage_prop': '0.940', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.179', 'efficiency': '0.149', 'TP': '196', 'FP': '24', 'FN': '14', 'precision': '0.891', 'recall': '0.933', 'f1': '0.912', 'total_rewards': 99.66080220512951, 'invalid_action_count': 161, 'num_ms1_scans': 264, 'num_ms2_scans': 1473}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 32.63149569461341
# steps	 1000 	total rewards	 52.12596881462089
# steps	 1500 	total rewards	 70.95717788546287
# Finished after 1776 timesteps (12.16428804397583 seconds) with total reward 85.15512111520411
# {'coverage_prop': '0.891', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.144', 'efficiency': '0.185', 'TP': '259', 'FP': '28', 'FN': '35', 'precision': '0.902', 'recall': '0.881', 'f1': '0.892', 'total_rewards': 85.15512111520403, 'invalid_action_count': 195, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 37.38025427468054
# steps	 1000 	total rewards	 60.78048907140479
# steps	 1500 	total rewards	 87.11834571970839
# Finished after 1755 timesteps (8.9045991897583 seconds) with total reward 99.60853628337364
# {'coverage_prop': '0.906', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.162', 'efficiency': '0.186', 'TP': '247', 'FP': '34', 'FN': '29', 'precision': '0.879', 'recall': '0.895', 'f1': '0.887', 'total_rewards': 99.60853628337321, 'invalid_action_count': 191, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 33.72326900808579
# steps	 1000 	total rewards	 55.66539583318859
# steps	 1500 	total rewards	 86.81989518696967
# Finished after 1765 timesteps (9.27389121055603 seconds) with total reward 108.69274235623689
# {'coverage_prop': '0.814', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.154', 'efficiency': '0.184', 'TP': '236', 'FP': '45', 'FN': '64', 'precision': '0.840', 'recall': '0.787', 'f1': '0.812', 'total_rewards': 108.69274235623654, 'invalid_action_count': 171, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 33.70888314798318
# steps	 1000 	total rewards	 39.789565282071834
# steps	 1500 	total rewards	 66.17878799281289
# Finished after 1795 timesteps (10.53127908706665 seconds) with total reward 85.56343794961016
# {'coverage_prop': '0.866', 'intensity_prop': '0.657', 'ms1ms2_ratio': '0.130', 'efficiency': '0.216', 'TP': '301', 'FP': '42', 'FN': '53', 'precision': '0.878', 'recall': '0.850', 'f1': '0.864', 'total_rewards': 85.56343794961006, 'invalid_action_count': 213, 'num_ms1_scans': 206, 'num_ms2_scans': 1589}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 31.80963135194458
# steps	 1000 	total rewards	 52.99873391909482
# steps	 1500 	total rewards	 74.65842307942307
# Finished after 1735 timesteps (9.168285846710205 seconds) with total reward 92.79840854291663
# {'coverage_prop': '0.961', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.180', 'efficiency': '0.133', 'TP': '185', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954', 'total_rewards': 92.79840854291648, 'invalid_action_count': 152, 'num_ms1_scans': 265, 'num_ms2_scans': 1470}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 37.33843029625546
# steps	 1000 	total rewards	 53.956841310467006
# steps	 1500 	total rewards	 89.19887667475643
# Finished after 1761 timesteps (9.061099767684937 seconds) with total reward 109.88202994903187
# {'coverage_prop': '0.922', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.157', 'efficiency': '0.170', 'TP': '239', 'FP': '20', 'FN': '22', 'precision': '0.923', 'recall': '0.916', 'f1': '0.919', 'total_rewards': 109.8820299490316, 'invalid_action_count': 185, 'num_ms1_scans': 239, 'num_ms2_scans': 1522}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 35.68754058853871
# steps	 1000 	total rewards	 65.05047168624141
# steps	 1500 	total rewards	 89.36848091243277
# Finished after 1789 timesteps (10.20677900314331 seconds) with total reward 108.58432044038078
# {'coverage_prop': '0.738', 'intensity_prop': '0.506', 'ms1ms2_ratio': '0.134', 'efficiency': '0.231', 'TP': '281', 'FP': '83', 'FN': '129', 'precision': '0.772', 'recall': '0.685', 'f1': '0.726', 'total_rewards': 108.5843204403805, 'invalid_action_count': 182, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 32.277914901750734
# steps	 1000 	total rewards	 47.15377265189103
# steps	 1500 	total rewards	 65.29223508784077
# Finished after 1765 timesteps (9.13226318359375 seconds) with total reward 83.03310381598887
# {'coverage_prop': '0.852', 'intensity_prop': '0.669', 'ms1ms2_ratio': '0.154', 'efficiency': '0.169', 'TP': '232', 'FP': '27', 'FN': '45', 'precision': '0.896', 'recall': '0.838', 'f1': '0.866', 'total_rewards': 83.0331038159887, 'invalid_action_count': 180, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fc78df89be0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fc74873c670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fc758a41910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'exclusion_t0': 5,
#   'exclusion_t1': 120,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.487', 'ms1ms2_ratio': '1.394', 'efficiency': '0.771', 'TP': '202', 'FP': '205', 'FN': '19', 'precision': '0.496', 'recall': '0.914', 'f1': '0.643'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.508', 'ms1ms2_ratio': '1.476', 'efficiency': '0.749', 'TP': '192', 'FP': '187', 'FN': '15', 'precision': '0.507', 'recall': '0.928', 'f1': '0.655'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '243', 'FP': '189', 'FN': '20', 'precision': '0.562', 'recall': '0.924', 'f1': '0.699'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.518', 'ms1ms2_ratio': '1.132', 'efficiency': '0.741', 'TP': '255', 'FP': '199', 'FN': '24', 'precision': '0.562', 'recall': '0.914', 'f1': '0.696'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.431', 'efficiency': '0.772', 'TP': '197', 'FP': '203', 'FN': '24', 'precision': '0.492', 'recall': '0.891', 'f1': '0.634'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.541', 'efficiency': '0.749', 'TP': '194', 'FP': '173', 'FN': '17', 'precision': '0.529', 'recall': '0.919', 'f1': '0.671'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.212', 'efficiency': '0.729', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.483', 'ms1ms2_ratio': '2.515', 'efficiency': '0.714', 'TP': '113', 'FP': '124', 'FN': '14', 'precision': '0.477', 'recall': '0.890', 'f1': '0.621'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.503', 'ms1ms2_ratio': '1.978', 'efficiency': '0.705', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.548', 'ms1ms2_ratio': '1.391', 'efficiency': '0.743', 'TP': '217', 'FP': '176', 'FN': '14', 'precision': '0.552', 'recall': '0.939', 'f1': '0.696'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.344', 'efficiency': '0.736', 'TP': '126', 'FP': '133', 'FN': '6', 'precision': '0.486', 'recall': '0.955', 'f1': '0.645'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.488', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '108', 'FP': '112', 'FN': '14', 'precision': '0.491', 'recall': '0.885', 'f1': '0.632'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.983', 'efficiency': '0.757', 'TP': '158', 'FP': '147', 'FN': '17', 'precision': '0.518', 'recall': '0.903', 'f1': '0.658'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.511', 'ms1ms2_ratio': '1.615', 'efficiency': '0.708', 'TP': '165', 'FP': '170', 'FN': '10', 'precision': '0.493', 'recall': '0.943', 'f1': '0.647'}
#
# Episode 25 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.476', 'efficiency': '0.763', 'TP': '212', 'FP': '174', 'FN': '10', 'precision': '0.549', 'recall': '0.955', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.008', 'efficiency': '0.727', 'TP': '149', 'FP': '141', 'FN': '14', 'precision': '0.514', 'recall': '0.914', 'f1': '0.658'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1815.625807                1867.0          0.357           0.091
# 1  random   -1854.002610                1898.0          0.370           0.102
# 2  random   -1859.114195                1897.0          0.302           0.063
# 3  random   -1799.157243                1857.0          0.396           0.116
# 4  random   -1793.765990                1858.0          0.455           0.118
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.007       0.077      0.197   0.099  0.132
# 1          0.006       0.049      0.247   0.127  0.168
# 2          0.005       0.060      0.168   0.068  0.097
# 3          0.006       0.090      0.268   0.150  0.192
# 4          0.005       0.101      0.206   0.147  0.172

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     290.156968                   9.0          0.876           0.533
# 31    DQN     245.230347                   2.0          0.916           0.602
# 32    DQN     280.961802                   3.0          0.865           0.515
# 33    DQN     295.008513                  11.0          0.892           0.541
# 34    DQN     279.231436                   7.0          0.867           0.513
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          1.680       0.813      0.705   0.832  0.763
# 31          2.609       0.745      0.746   0.891  0.812
# 32          1.978       0.844      0.672   0.812  0.735
# 33          1.580       0.838      0.690   0.850  0.762
# 34          1.789       0.867      0.668   0.814  0.733

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
