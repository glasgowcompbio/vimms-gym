# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-14 12:26:11.611 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fcbadbcfcd0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fcb686bd670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fcb9842a910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fcbadbcfcd0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fcb686bd670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fcb9842a910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fcbadbcfcd0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fcb686bd670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fcb9842a910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E8_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_1.0E8', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -423.83729966476517
# steps	 1000 	total rewards	 -754.7173999014186
# steps	 1500 	total rewards	 -889.06704680647
# Finished after 1987 timesteps (3.9641060829162598 seconds) with total reward -1034.4971144188764
# {'coverage_prop': '0.692', 'intensity_prop': '0.228', 'ms1ms2_ratio': '0.007', 'efficiency': '0.149', 'TP': '92', 'FP': '203', 'FN': '131', 'precision': '0.312', 'recall': '0.413', 'f1': '0.355', 'total_rewards': -1034.497114418876, 'invalid_action_count': 1173, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -388.40145126761684
# steps	 1000 	total rewards	 -689.3045236835276
# steps	 1500 	total rewards	 -964.9645483685799
# Finished after 1987 timesteps (2.563767671585083 seconds) with total reward -1255.975599592029
# {'coverage_prop': '0.733', 'intensity_prop': '0.198', 'ms1ms2_ratio': '0.007', 'efficiency': '0.097', 'TP': '47', 'FP': '145', 'FN': '70', 'precision': '0.245', 'recall': '0.402', 'f1': '0.304', 'total_rewards': -1255.9755995920289, 'invalid_action_count': 1353, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -383.9251048201046
# steps	 1000 	total rewards	 -605.5180762993377
# steps	 1500 	total rewards	 -736.8594710481116
# Finished after 1987 timesteps (3.62674880027771 seconds) with total reward -970.5557844804363
# {'coverage_prop': '0.772', 'intensity_prop': '0.258', 'ms1ms2_ratio': '0.007', 'efficiency': '0.154', 'TP': '94', 'FP': '210', 'FN': '90', 'precision': '0.309', 'recall': '0.511', 'f1': '0.385', 'total_rewards': -970.5557844804367, 'invalid_action_count': 1124, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -406.8775601091195
# steps	 1000 	total rewards	 -782.2203663326388
# steps	 1500 	total rewards	 -969.1125940543536
# Finished after 1991 timesteps (3.91512393951416 seconds) with total reward -1184.73382577058
# {'coverage_prop': '0.659', 'intensity_prop': '0.211', 'ms1ms2_ratio': '0.005', 'efficiency': '0.150', 'TP': '93', 'FP': '205', 'FN': '154', 'precision': '0.312', 'recall': '0.377', 'f1': '0.341', 'total_rewards': -1184.733825770581, 'invalid_action_count': 1316, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -339.34181812482745
# steps	 1000 	total rewards	 -557.0115463539144
# steps	 1500 	total rewards	 -914.8149203788194
# Finished after 1988 timesteps (3.8611369132995605 seconds) with total reward -1078.9004033424058
# {'coverage_prop': '0.709', 'intensity_prop': '0.204', 'ms1ms2_ratio': '0.006', 'efficiency': '0.157', 'TP': '77', 'FP': '233', 'FN': '127', 'precision': '0.248', 'recall': '0.377', 'f1': '0.300', 'total_rewards': -1078.9004033424058, 'invalid_action_count': 1226, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -397.22268587254285
# steps	 1000 	total rewards	 -697.4699348766567
# steps	 1500 	total rewards	 -1116.790948390129
# Finished after 1991 timesteps (2.2578537464141846 seconds) with total reward -1434.2638290977616
# {'coverage_prop': '0.660', 'intensity_prop': '0.193', 'ms1ms2_ratio': '0.005', 'efficiency': '0.067', 'TP': '36', 'FP': '96', 'FN': '68', 'precision': '0.273', 'recall': '0.346', 'f1': '0.305', 'total_rewards': -1434.2638290977625, 'invalid_action_count': 1500, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -367.3502654381596
# steps	 1000 	total rewards	 -702.7175751979172
# steps	 1500 	total rewards	 -994.0848825656732
# Finished after 1990 timesteps (3.911715030670166 seconds) with total reward -1124.413002877728
# {'coverage_prop': '0.667', 'intensity_prop': '0.195', 'ms1ms2_ratio': '0.005', 'efficiency': '0.161', 'TP': '83', 'FP': '236', 'FN': '159', 'precision': '0.260', 'recall': '0.343', 'f1': '0.296', 'total_rewards': -1124.4130028777272, 'invalid_action_count': 1268, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -395.8189099628799
# steps	 1000 	total rewards	 -813.9458153679044
# steps	 1500 	total rewards	 -1117.0511312358158
# Finished after 1991 timesteps (2.271888017654419 seconds) with total reward -1443.9244395240225
# {'coverage_prop': '0.647', 'intensity_prop': '0.190', 'ms1ms2_ratio': '0.005', 'efficiency': '0.067', 'TP': '39', 'FP': '93', 'FN': '72', 'precision': '0.295', 'recall': '0.351', 'f1': '0.321', 'total_rewards': -1443.9244395240232, 'invalid_action_count': 1512, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -303.8183205816219
# steps	 1000 	total rewards	 -495.79497269342585
# steps	 1500 	total rewards	 -726.5764960324498
# Finished after 1984 timesteps (3.6388840675354004 seconds) with total reward -898.9371967217622
# {'coverage_prop': '0.823', 'intensity_prop': '0.258', 'ms1ms2_ratio': '0.008', 'efficiency': '0.177', 'TP': '95', 'FP': '254', 'FN': '75', 'precision': '0.272', 'recall': '0.559', 'f1': '0.366', 'total_rewards': -898.9371967217619, 'invalid_action_count': 1070, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -345.20668766997983
# steps	 1000 	total rewards	 -650.2394963591737
# steps	 1500 	total rewards	 -849.3161923585243
# Finished after 1983 timesteps (3.6514978408813477 seconds) with total reward -1203.5292049416985
# {'coverage_prop': '0.685', 'intensity_prop': '0.219', 'ms1ms2_ratio': '0.009', 'efficiency': '0.134', 'TP': '77', 'FP': '186', 'FN': '121', 'precision': '0.293', 'recall': '0.389', 'f1': '0.334', 'total_rewards': -1203.5292049416994, 'invalid_action_count': 1319, 'num_ms1_scans': 17, 'num_ms2_scans': 1966}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -308.33387466808927
# steps	 1000 	total rewards	 -617.0801043578308
# steps	 1500 	total rewards	 -763.1929030319457
# Finished after 1985 timesteps (3.851436138153076 seconds) with total reward -893.3520566996172
# {'coverage_prop': '0.772', 'intensity_prop': '0.260', 'ms1ms2_ratio': '0.008', 'efficiency': '0.174', 'TP': '109', 'FP': '233', 'FN': '101', 'precision': '0.319', 'recall': '0.519', 'f1': '0.395', 'total_rewards': -893.3520566996168, 'invalid_action_count': 1064, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -400.6767778263745
# steps	 1000 	total rewards	 -776.5062855541523
# steps	 1500 	total rewards	 -1213.6561948784342
# Finished after 1994 timesteps (3.026264190673828 seconds) with total reward -1506.6355820736176
# {'coverage_prop': '0.578', 'intensity_prop': '0.142', 'ms1ms2_ratio': '0.003', 'efficiency': '0.072', 'TP': '32', 'FP': '112', 'FN': '105', 'precision': '0.222', 'recall': '0.234', 'f1': '0.228', 'total_rewards': -1506.6355820736173, 'invalid_action_count': 1570, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -366.84012179775436
# steps	 1000 	total rewards	 -655.0150202030903
# steps	 1500 	total rewards	 -930.5602545549045
# Finished after 1990 timesteps (2.7212748527526855 seconds) with total reward -1276.747774229696
# {'coverage_prop': '0.745', 'intensity_prop': '0.179', 'ms1ms2_ratio': '0.005', 'efficiency': '0.094', 'TP': '37', 'FP': '150', 'FN': '64', 'precision': '0.198', 'recall': '0.366', 'f1': '0.257', 'total_rewards': -1276.7477742296958, 'invalid_action_count': 1371, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -396.9797309168268
# steps	 1000 	total rewards	 -686.8108521859765
# steps	 1500 	total rewards	 -892.3454518004403
# Finished after 1989 timesteps (3.242662191390991 seconds) with total reward -1139.3298673568493
# {'coverage_prop': '0.773', 'intensity_prop': '0.277', 'ms1ms2_ratio': '0.006', 'efficiency': '0.117', 'TP': '85', 'FP': '147', 'FN': '68', 'precision': '0.366', 'recall': '0.556', 'f1': '0.442', 'total_rewards': -1139.3298673568502, 'invalid_action_count': 1253, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -389.9911224397233
# steps	 1000 	total rewards	 -776.8814359799479
# steps	 1500 	total rewards	 -1037.4022796375025
# Finished after 1986 timesteps (2.354832887649536 seconds) with total reward -1290.2299465031797
# {'coverage_prop': '0.748', 'intensity_prop': '0.219', 'ms1ms2_ratio': '0.007', 'efficiency': '0.078', 'TP': '41', 'FP': '113', 'FN': '52', 'precision': '0.266', 'recall': '0.441', 'f1': '0.332', 'total_rewards': -1290.2299465031801, 'invalid_action_count': 1373, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -376.6920124066146
# steps	 1000 	total rewards	 -778.9665892398073
# steps	 1500 	total rewards	 -894.14881591891
# Finished after 1987 timesteps (3.4017012119293213 seconds) with total reward -1097.193790049612
# {'coverage_prop': '0.717', 'intensity_prop': '0.255', 'ms1ms2_ratio': '0.007', 'efficiency': '0.148', 'TP': '103', 'FP': '189', 'FN': '115', 'precision': '0.353', 'recall': '0.472', 'f1': '0.404', 'total_rewards': -1097.1937900496105, 'invalid_action_count': 1231, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -327.680544433317
# steps	 1000 	total rewards	 -546.4335185914183
# steps	 1500 	total rewards	 -703.7146042323567
# Finished after 1989 timesteps (4.729061126708984 seconds) with total reward -1017.200143642492
# {'coverage_prop': '0.745', 'intensity_prop': '0.251', 'ms1ms2_ratio': '0.006', 'efficiency': '0.188', 'TP': '123', 'FP': '248', 'FN': '127', 'precision': '0.332', 'recall': '0.492', 'f1': '0.396', 'total_rewards': -1017.2001436424924, 'invalid_action_count': 1184, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -335.9272638466023
# steps	 1000 	total rewards	 -720.0083244481796
# steps	 1500 	total rewards	 -1081.2249049034363
# Finished after 1993 timesteps (3.3392558097839355 seconds) with total reward -1380.8338876447829
# {'coverage_prop': '0.581', 'intensity_prop': '0.164', 'ms1ms2_ratio': '0.004', 'efficiency': '0.109', 'TP': '57', 'FP': '159', 'FN': '156', 'precision': '0.264', 'recall': '0.268', 'f1': '0.266', 'total_rewards': -1380.8338876447838, 'invalid_action_count': 1480, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -434.37224800141985
# steps	 1000 	total rewards	 -832.7506188115661
# steps	 1500 	total rewards	 -1085.6827717258593
# Finished after 1991 timesteps (3.0835189819335938 seconds) with total reward -1316.7182311501554
# {'coverage_prop': '0.659', 'intensity_prop': '0.174', 'ms1ms2_ratio': '0.005', 'efficiency': '0.100', 'TP': '47', 'FP': '152', 'FN': '103', 'precision': '0.236', 'recall': '0.313', 'f1': '0.269', 'total_rewards': -1316.7182311501542, 'invalid_action_count': 1415, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -387.92920423395844
# steps	 1000 	total rewards	 -734.6100112919132
# steps	 1500 	total rewards	 -945.7365161900248
# Finished after 1990 timesteps (2.829373836517334 seconds) with total reward -1241.6500487198446
# {'coverage_prop': '0.747', 'intensity_prop': '0.227', 'ms1ms2_ratio': '0.005', 'efficiency': '0.100', 'TP': '56', 'FP': '142', 'FN': '67', 'precision': '0.283', 'recall': '0.455', 'f1': '0.349', 'total_rewards': -1241.6500487198448, 'invalid_action_count': 1346, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -323.0801139383435
# steps	 1000 	total rewards	 -606.5643859240789
# steps	 1500 	total rewards	 -712.305534961306
# Finished after 1986 timesteps (3.9306082725524902 seconds) with total reward -859.2807359086614
# {'coverage_prop': '0.795', 'intensity_prop': '0.276', 'ms1ms2_ratio': '0.007', 'efficiency': '0.189', 'TP': '128', 'FP': '244', 'FN': '96', 'precision': '0.344', 'recall': '0.571', 'f1': '0.430', 'total_rewards': -859.2807359086606, 'invalid_action_count': 1035, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -375.0059393897956
# steps	 1000 	total rewards	 -729.0921503771019
# steps	 1500 	total rewards	 -974.4837400954638
# Finished after 1987 timesteps (2.9876039028167725 seconds) with total reward -1217.3319690221642
# {'coverage_prop': '0.756', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.007', 'efficiency': '0.090', 'TP': '43', 'FP': '134', 'FN': '57', 'precision': '0.243', 'recall': '0.430', 'f1': '0.310', 'total_rewards': -1217.331969022164, 'invalid_action_count': 1309, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -412.5825651669001
# steps	 1000 	total rewards	 -688.2268328312864
# steps	 1500 	total rewards	 -848.9554158401655
# Finished after 1986 timesteps (3.0453879833221436 seconds) with total reward -1086.4149048417976
# {'coverage_prop': '0.724', 'intensity_prop': '0.220', 'ms1ms2_ratio': '0.007', 'efficiency': '0.118', 'TP': '69', 'FP': '164', 'FN': '89', 'precision': '0.296', 'recall': '0.437', 'f1': '0.353', 'total_rewards': -1086.4149048417971, 'invalid_action_count': 1202, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -335.1656261278963
# steps	 1000 	total rewards	 -704.755403965268
# steps	 1500 	total rewards	 -1038.1084451841866
# Finished after 1991 timesteps (2.806086301803589 seconds) with total reward -1360.5383673682518
# {'coverage_prop': '0.671', 'intensity_prop': '0.188', 'ms1ms2_ratio': '0.005', 'efficiency': '0.105', 'TP': '54', 'FP': '154', 'FN': '102', 'precision': '0.260', 'recall': '0.346', 'f1': '0.297', 'total_rewards': -1360.538367368253, 'invalid_action_count': 1456, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -367.0498420721792
# steps	 1000 	total rewards	 -829.389418947641
# steps	 1500 	total rewards	 -1295.5854838508187
# Finished after 1994 timesteps (2.993701696395874 seconds) with total reward -1533.099691816616
# {'coverage_prop': '0.487', 'intensity_prop': '0.087', 'ms1ms2_ratio': '0.003', 'efficiency': '0.085', 'TP': '27', 'FP': '141', 'FN': '177', 'precision': '0.161', 'recall': '0.132', 'f1': '0.145', 'total_rewards': -1533.0996918166163, 'invalid_action_count': 1611, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -407.3807567456459
# steps	 1000 	total rewards	 -604.3493368832783
# steps	 1500 	total rewards	 -684.1026585787079
# Finished after 1981 timesteps (3.438775062561035 seconds) with total reward -938.1382277914798
# {'coverage_prop': '0.773', 'intensity_prop': '0.259', 'ms1ms2_ratio': '0.010', 'efficiency': '0.156', 'TP': '103', 'FP': '203', 'FN': '90', 'precision': '0.337', 'recall': '0.534', 'f1': '0.413', 'total_rewards': -938.1382277914778, 'invalid_action_count': 1087, 'num_ms1_scans': 19, 'num_ms2_scans': 1962}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -391.2334357343185
# steps	 1000 	total rewards	 -773.0995635031659
# steps	 1500 	total rewards	 -1091.7965288478185
# Finished after 1990 timesteps (2.412494659423828 seconds) with total reward -1431.031795340477
# {'coverage_prop': '0.670', 'intensity_prop': '0.185', 'ms1ms2_ratio': '0.005', 'efficiency': '0.069', 'TP': '33', 'FP': '103', 'FN': '67', 'precision': '0.243', 'recall': '0.330', 'f1': '0.280', 'total_rewards': -1431.0317953404763, 'invalid_action_count': 1501, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -402.7825873225671
# steps	 1000 	total rewards	 -682.3933276271505
# steps	 1500 	total rewards	 -984.5368576715554
# Finished after 1990 timesteps (3.42988920211792 seconds) with total reward -1320.6437453761027
# {'coverage_prop': '0.669', 'intensity_prop': '0.184', 'ms1ms2_ratio': '0.005', 'efficiency': '0.095', 'TP': '52', 'FP': '136', 'FN': '93', 'precision': '0.277', 'recall': '0.359', 'f1': '0.312', 'total_rewards': -1320.6437453761012, 'invalid_action_count': 1419, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -373.1345440120578
# steps	 1000 	total rewards	 -625.7290905992295
# steps	 1500 	total rewards	 -844.4791487675925
# Finished after 1988 timesteps (3.9459033012390137 seconds) with total reward -934.1645200452135
# {'coverage_prop': '0.714', 'intensity_prop': '0.225', 'ms1ms2_ratio': '0.006', 'efficiency': '0.178', 'TP': '100', 'FP': '252', 'FN': '141', 'precision': '0.284', 'recall': '0.415', 'f1': '0.337', 'total_rewards': -934.1645200452137, 'invalid_action_count': 1101, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -375.3112777395864
# steps	 1000 	total rewards	 -754.9700341559665
# steps	 1500 	total rewards	 -1201.775936529012
# Finished after 1992 timesteps (2.774214029312134 seconds) with total reward -1445.8925504121985
# {'coverage_prop': '0.586', 'intensity_prop': '0.126', 'ms1ms2_ratio': '0.004', 'efficiency': '0.090', 'TP': '30', 'FP': '148', 'FN': '126', 'precision': '0.169', 'recall': '0.192', 'f1': '0.180', 'total_rewards': -1445.8925504121987, 'invalid_action_count': 1520, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 9.00GB > 0.36GB
# steps	 500 	total rewards	 91.63421450923491
# steps	 1000 	total rewards	 215.5294005224368
# steps	 1500 	total rewards	 315.72958952467997
# Finished after 1706 timesteps (5.298375368118286 seconds) with total reward 349.5385557509005
# {'coverage_prop': '0.984', 'intensity_prop': '0.666', 'ms1ms2_ratio': '0.208', 'efficiency': '0.297', 'TP': '313', 'FP': '106', 'FN': '7', 'precision': '0.747', 'recall': '0.978', 'f1': '0.847', 'total_rewards': 349.5385557509019, 'invalid_action_count': 0, 'num_ms1_scans': 294, 'num_ms2_scans': 1412}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 90.00693052680157
# steps	 1000 	total rewards	 180.99543397595684
# steps	 1500 	total rewards	 262.25060543931625
# Finished after 1717 timesteps (4.257311105728149 seconds) with total reward 293.94331520132096
# {'coverage_prop': '0.977', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.197', 'efficiency': '0.179', 'TP': '197', 'FP': '59', 'FN': '6', 'precision': '0.770', 'recall': '0.970', 'f1': '0.858', 'total_rewards': 293.94331520132124, 'invalid_action_count': 0, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 90.03221482397518
# steps	 1000 	total rewards	 208.33311855015944
# steps	 1500 	total rewards	 316.46740457067426
# Finished after 1708 timesteps (5.198269844055176 seconds) with total reward 343.17444257790794
# {'coverage_prop': '0.985', 'intensity_prop': '0.658', 'ms1ms2_ratio': '0.206', 'efficiency': '0.274', 'TP': '289', 'FP': '99', 'FN': '6', 'precision': '0.745', 'recall': '0.980', 'f1': '0.846', 'total_rewards': 343.1744425779091, 'invalid_action_count': 3, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.82177875871577
# steps	 1000 	total rewards	 224.06380115135792
# steps	 1500 	total rewards	 319.322064728667
# Finished after 1697 timesteps (5.416898727416992 seconds) with total reward 354.917094304231
# {'coverage_prop': '0.967', 'intensity_prop': '0.654', 'ms1ms2_ratio': '0.217', 'efficiency': '0.313', 'TP': '327', 'FP': '110', 'FN': '15', 'precision': '0.748', 'recall': '0.956', 'f1': '0.840', 'total_rewards': 354.91709430423174, 'invalid_action_count': 1, 'num_ms1_scans': 303, 'num_ms2_scans': 1394}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 97.37678505427812
# steps	 1000 	total rewards	 216.08452731983962
# steps	 1500 	total rewards	 319.60643872811454
# Finished after 1697 timesteps (5.404270172119141 seconds) with total reward 349.9583541486013
# {'coverage_prop': '0.984', 'intensity_prop': '0.652', 'ms1ms2_ratio': '0.217', 'efficiency': '0.308', 'TP': '321', 'FP': '109', 'FN': '7', 'precision': '0.747', 'recall': '0.979', 'f1': '0.847', 'total_rewards': 349.9583541486026, 'invalid_action_count': 1, 'num_ms1_scans': 303, 'num_ms2_scans': 1394}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 73.65651662469101
# steps	 1000 	total rewards	 156.12809495393952
# steps	 1500 	total rewards	 227.40017960817258
# Finished after 1722 timesteps (3.9108641147613525 seconds) with total reward 240.69198259792168
# {'coverage_prop': '0.990', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.193', 'efficiency': '0.137', 'TP': '168', 'FP': '30', 'FN': '2', 'precision': '0.848', 'recall': '0.988', 'f1': '0.913', 'total_rewards': 240.691982597921, 'invalid_action_count': 12, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.97674938798649
# steps	 1000 	total rewards	 232.03775572748162
# steps	 1500 	total rewards	 334.06177968572183
# Finished after 1705 timesteps (5.480856657028198 seconds) with total reward 369.11516471298086
# {'coverage_prop': '0.950', 'intensity_prop': '0.642', 'ms1ms2_ratio': '0.209', 'efficiency': '0.322', 'TP': '334', 'FP': '120', 'FN': '24', 'precision': '0.736', 'recall': '0.933', 'f1': '0.823', 'total_rewards': 369.1151647129826, 'invalid_action_count': 2, 'num_ms1_scans': 295, 'num_ms2_scans': 1410}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 64.67041720084843
# steps	 1000 	total rewards	 165.56640506456
# steps	 1500 	total rewards	 228.9681249957436
# Finished after 1694 timesteps (4.864392995834351 seconds) with total reward 248.26315090064912
# {'coverage_prop': '0.985', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.220', 'efficiency': '0.145', 'TP': '160', 'FP': '41', 'FN': '3', 'precision': '0.796', 'recall': '0.982', 'f1': '0.879', 'total_rewards': 248.2631509006478, 'invalid_action_count': 1, 'num_ms1_scans': 306, 'num_ms2_scans': 1388}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 98.98181869298794
# steps	 1000 	total rewards	 201.97740129399702
# steps	 1500 	total rewards	 310.90096399821624
# Finished after 1713 timesteps (5.4147117137908936 seconds) with total reward 345.4444809611149
# {'coverage_prop': '0.967', 'intensity_prop': '0.659', 'ms1ms2_ratio': '0.201', 'efficiency': '0.288', 'TP': '309', 'FP': '101', 'FN': '14', 'precision': '0.754', 'recall': '0.957', 'f1': '0.843', 'total_rewards': 345.44448096111626, 'invalid_action_count': 1, 'num_ms1_scans': 287, 'num_ms2_scans': 1426}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 89.81174658384258
# steps	 1000 	total rewards	 195.85595644485323
# steps	 1500 	total rewards	 300.65133996965085
# Finished after 1717 timesteps (5.989506006240845 seconds) with total reward 328.35613768426447
# {'coverage_prop': '0.977', 'intensity_prop': '0.678', 'ms1ms2_ratio': '0.197', 'efficiency': '0.262', 'TP': '286', 'FP': '89', 'FN': '9', 'precision': '0.763', 'recall': '0.969', 'f1': '0.854', 'total_rewards': 328.35613768426526, 'invalid_action_count': 1, 'num_ms1_scans': 283, 'num_ms2_scans': 1434}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 95.98698809601194
# steps	 1000 	total rewards	 213.54171592964374
# steps	 1500 	total rewards	 330.77548163463774
# Finished after 1704 timesteps (5.63078498840332 seconds) with total reward 362.3382051127509
# {'coverage_prop': '0.966', 'intensity_prop': '0.655', 'ms1ms2_ratio': '0.210', 'efficiency': '0.304', 'TP': '324', 'FP': '104', 'FN': '15', 'precision': '0.757', 'recall': '0.956', 'f1': '0.845', 'total_rewards': 362.3382051127519, 'invalid_action_count': 2, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 87.7716722102716
# steps	 1000 	total rewards	 172.1720452484022
# steps	 1500 	total rewards	 241.0987851898738
# Finished after 1720 timesteps (4.269539833068848 seconds) with total reward 268.29699027767714
# {'coverage_prop': '0.976', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.195', 'efficiency': '0.169', 'TP': '193', 'FP': '50', 'FN': '6', 'precision': '0.794', 'recall': '0.970', 'f1': '0.873', 'total_rewards': 268.29699027767646, 'invalid_action_count': 0, 'num_ms1_scans': 281, 'num_ms2_scans': 1439}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 83.80295285806781
# steps	 1000 	total rewards	 165.29853963983217
# steps	 1500 	total rewards	 235.36929892424072
# Finished after 1693 timesteps (5.764422178268433 seconds) with total reward 263.63315832301066
# {'coverage_prop': '0.964', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.222', 'efficiency': '0.175', 'TP': '173', 'FP': '69', 'FN': '9', 'precision': '0.715', 'recall': '0.951', 'f1': '0.816', 'total_rewards': 263.63315832300975, 'invalid_action_count': 0, 'num_ms1_scans': 307, 'num_ms2_scans': 1386}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 77.85126434298232
# steps	 1000 	total rewards	 168.75660462329137
# steps	 1500 	total rewards	 261.7282189369293
# Finished after 1682 timesteps (4.939181089401245 seconds) with total reward 280.774001650571
# {'coverage_prop': '0.967', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.233', 'efficiency': '0.213', 'TP': '221', 'FP': '69', 'FN': '10', 'precision': '0.762', 'recall': '0.957', 'f1': '0.848', 'total_rewards': 280.7740016505707, 'invalid_action_count': 0, 'num_ms1_scans': 318, 'num_ms2_scans': 1364}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 78.45458435840419
# steps	 1000 	total rewards	 163.12158930406733
# steps	 1500 	total rewards	 227.7494641453163
# Finished after 1683 timesteps (4.007454872131348 seconds) with total reward 250.46003289456863
# {'coverage_prop': '0.985', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.232', 'efficiency': '0.149', 'TP': '163', 'FP': '40', 'FN': '3', 'precision': '0.803', 'recall': '0.982', 'f1': '0.883', 'total_rewards': 250.4600328945678, 'invalid_action_count': 3, 'num_ms1_scans': 317, 'num_ms2_scans': 1366}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 83.45443975673544
# steps	 1000 	total rewards	 195.44353842765793
# steps	 1500 	total rewards	 305.7273258418811
# Finished after 1701 timesteps (6.381345987319946 seconds) with total reward 340.06369451249105
# {'coverage_prop': '0.978', 'intensity_prop': '0.664', 'ms1ms2_ratio': '0.214', 'efficiency': '0.284', 'TP': '300', 'FP': '98', 'FN': '9', 'precision': '0.754', 'recall': '0.971', 'f1': '0.849', 'total_rewards': 340.0636945124917, 'invalid_action_count': 0, 'num_ms1_scans': 300, 'num_ms2_scans': 1401}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 107.50706272090548
# steps	 1000 	total rewards	 235.52533082325442
# steps	 1500 	total rewards	 352.9038939493576
# Finished after 1708 timesteps (5.699678897857666 seconds) with total reward 381.538656348059
# {'coverage_prop': '0.966', 'intensity_prop': '0.679', 'ms1ms2_ratio': '0.206', 'efficiency': '0.340', 'TP': '377', 'FP': '104', 'FN': '17', 'precision': '0.784', 'recall': '0.957', 'f1': '0.862', 'total_rewards': 381.53865634806016, 'invalid_action_count': 0, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 95.5063146977703
# steps	 1000 	total rewards	 210.16086543910376
# steps	 1500 	total rewards	 303.210644178332
# Finished after 1708 timesteps (4.9708757400512695 seconds) with total reward 329.43589150489123
# {'coverage_prop': '0.973', 'intensity_prop': '0.675', 'ms1ms2_ratio': '0.206', 'efficiency': '0.256', 'TP': '279', 'FP': '83', 'FN': '10', 'precision': '0.771', 'recall': '0.965', 'f1': '0.857', 'total_rewards': 329.43589150489225, 'invalid_action_count': 2, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 87.03501391221437
# steps	 1000 	total rewards	 184.78737206509314
# steps	 1500 	total rewards	 279.1989309431295
# Finished after 1719 timesteps (5.886479139328003 seconds) with total reward 307.1454105179938
# {'coverage_prop': '0.993', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.195', 'efficiency': '0.209', 'TP': '236', 'FP': '64', 'FN': '2', 'precision': '0.787', 'recall': '0.992', 'f1': '0.877', 'total_rewards': 307.1454105179939, 'invalid_action_count': 4, 'num_ms1_scans': 281, 'num_ms2_scans': 1438}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 82.8823476923078
# steps	 1000 	total rewards	 183.56987525652553
# steps	 1500 	total rewards	 266.46529799980874
# Finished after 1689 timesteps (4.3597571849823 seconds) with total reward 294.513886120688
# {'coverage_prop': '0.996', 'intensity_prop': '0.687', 'ms1ms2_ratio': '0.226', 'efficiency': '0.192', 'TP': '196', 'FP': '68', 'FN': '1', 'precision': '0.742', 'recall': '0.995', 'f1': '0.850', 'total_rewards': 294.5138861206879, 'invalid_action_count': 1, 'num_ms1_scans': 311, 'num_ms2_scans': 1378}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 104.85122340196025
# steps	 1000 	total rewards	 225.31600127589687
# steps	 1500 	total rewards	 318.038228896326
# Finished after 1696 timesteps (5.668545961380005 seconds) with total reward 356.52271820991353
# {'coverage_prop': '0.932', 'intensity_prop': '0.640', 'ms1ms2_ratio': '0.218', 'efficiency': '0.313', 'TP': '345', 'FP': '91', 'FN': '32', 'precision': '0.791', 'recall': '0.915', 'f1': '0.849', 'total_rewards': 356.52271820991456, 'invalid_action_count': 3, 'num_ms1_scans': 304, 'num_ms2_scans': 1392}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 76.75820747031968
# steps	 1000 	total rewards	 159.76382320144506
# steps	 1500 	total rewards	 236.15976330728677
# Finished after 1737 timesteps (5.692970037460327 seconds) with total reward 255.64527816564203
# {'coverage_prop': '0.987', 'intensity_prop': '0.677', 'ms1ms2_ratio': '0.178', 'efficiency': '0.157', 'TP': '172', 'FP': '59', 'FN': '3', 'precision': '0.745', 'recall': '0.983', 'f1': '0.847', 'total_rewards': 255.64527816564114, 'invalid_action_count': 4, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 84.43716002776128
# steps	 1000 	total rewards	 190.51911185996798
# steps	 1500 	total rewards	 269.0432617149386
# Finished after 1724 timesteps (4.5709638595581055 seconds) with total reward 302.0847395660927
# {'coverage_prop': '0.975', 'intensity_prop': '0.673', 'ms1ms2_ratio': '0.191', 'efficiency': '0.217', 'TP': '240', 'FP': '74', 'FN': '8', 'precision': '0.764', 'recall': '0.968', 'f1': '0.854', 'total_rewards': 302.08473956609294, 'invalid_action_count': 0, 'num_ms1_scans': 276, 'num_ms2_scans': 1448}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 91.03313695218266
# steps	 1000 	total rewards	 187.69729072121083
# steps	 1500 	total rewards	 271.9387686818229
# Finished after 1729 timesteps (4.397284984588623 seconds) with total reward 303.2844340622505
# {'coverage_prop': '0.981', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.186', 'efficiency': '0.209', 'TP': '239', 'FP': '65', 'FN': '6', 'precision': '0.786', 'recall': '0.976', 'f1': '0.871', 'total_rewards': 303.2844340622506, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 94.77726346921678
# steps	 1000 	total rewards	 203.5353576625049
# steps	 1500 	total rewards	 300.5645036202029
# Finished after 1682 timesteps (4.763046026229858 seconds) with total reward 326.36566659276957
# {'coverage_prop': '0.983', 'intensity_prop': '0.660', 'ms1ms2_ratio': '0.233', 'efficiency': '0.249', 'TP': '247', 'FP': '92', 'FN': '6', 'precision': '0.729', 'recall': '0.976', 'f1': '0.834', 'total_rewards': 326.36566659277076, 'invalid_action_count': 1, 'num_ms1_scans': 318, 'num_ms2_scans': 1364}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.87413397016657
# steps	 1000 	total rewards	 186.8174577930956
# steps	 1500 	total rewards	 301.0334621159282
# Finished after 1716 timesteps (6.838174819946289 seconds) with total reward 335.09694585108025
# {'coverage_prop': '0.992', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.198', 'efficiency': '0.274', 'TP': '296', 'FP': '97', 'FN': '3', 'precision': '0.753', 'recall': '0.990', 'f1': '0.855', 'total_rewards': 335.0969458510802, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1432}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 66.99464716644428
# steps	 1000 	total rewards	 157.69389780680237
# steps	 1500 	total rewards	 227.97647347860533
# Finished after 1702 timesteps (3.905444860458374 seconds) with total reward 238.09223790780644
# {'coverage_prop': '0.985', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.212', 'efficiency': '0.142', 'TP': '170', 'FP': '30', 'FN': '3', 'precision': '0.850', 'recall': '0.983', 'f1': '0.912', 'total_rewards': 238.09223790780578, 'invalid_action_count': 11, 'num_ms1_scans': 298, 'num_ms2_scans': 1404}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 85.83196004523228
# steps	 1000 	total rewards	 186.73723399809262
# steps	 1500 	total rewards	 277.8149172147916
# Finished after 1711 timesteps (4.119246006011963 seconds) with total reward 310.4182979237608
# {'coverage_prop': '0.989', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.203', 'efficiency': '0.195', 'TP': '222', 'FP': '56', 'FN': '3', 'precision': '0.799', 'recall': '0.987', 'f1': '0.883', 'total_rewards': 310.4182979237608, 'invalid_action_count': 1, 'num_ms1_scans': 289, 'num_ms2_scans': 1422}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 106.57704121992509
# steps	 1000 	total rewards	 219.41049707089002
# steps	 1500 	total rewards	 342.1871324732524
# Finished after 1661 timesteps (5.922368049621582 seconds) with total reward 367.58480572614695
# {'coverage_prop': '0.925', 'intensity_prop': '0.602', 'ms1ms2_ratio': '0.256', 'efficiency': '0.345', 'TP': '327', 'FP': '129', 'FN': '37', 'precision': '0.717', 'recall': '0.898', 'f1': '0.798', 'total_rewards': 367.58480572614815, 'invalid_action_count': 0, 'num_ms1_scans': 339, 'num_ms2_scans': 1322}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 86.09235398614715
# steps	 1000 	total rewards	 186.5804417890351
# steps	 1500 	total rewards	 263.2022755815739
# Finished after 1712 timesteps (6.262487888336182 seconds) with total reward 291.12650570767255
# {'coverage_prop': '0.984', 'intensity_prop': '0.700', 'ms1ms2_ratio': '0.202', 'efficiency': '0.210', 'TP': '229', 'FP': '70', 'FN': '5', 'precision': '0.766', 'recall': '0.979', 'f1': '0.859', 'total_rewards': 291.12650570767266, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 92.5276178076839
# steps	 1000 	total rewards	 205.25382864627784
# steps	 1500 	total rewards	 312.7588878054987
# Finished after 1722 timesteps (9.290210008621216 seconds) with total reward 350.1583925147164
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 350.15839251471635, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.19223993264903
# steps	 1000 	total rewards	 200.01185786399162
# steps	 1500 	total rewards	 278.69251864828544
# Finished after 1556 timesteps (8.03603720664978 seconds) with total reward 286.42041452327317
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 286.42041452327345, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.09810262952533
# steps	 1000 	total rewards	 204.55175528344176
# steps	 1500 	total rewards	 311.70589197292
# Finished after 1669 timesteps (8.931009769439697 seconds) with total reward 335.8567231016701
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 335.856723101671, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.75112549735738
# steps	 1000 	total rewards	 222.260470162795
# steps	 1500 	total rewards	 321.6296912754646
# Finished after 1717 timesteps (11.902125835418701 seconds) with total reward 364.78676992745324
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 364.7867699274535, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.88207661824359
# steps	 1000 	total rewards	 225.03458447204991
# steps	 1500 	total rewards	 333.40644054419124
# Finished after 1704 timesteps (9.27272081375122 seconds) with total reward 368.54312915676854
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 368.54312915676945, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.95053041210245
# steps	 1000 	total rewards	 176.02517486243747
# Finished after 1408 timesteps (7.054314136505127 seconds) with total reward 238.71804354506358
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 238.7180435450617, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.04778207928516
# steps	 1000 	total rewards	 216.92306176316305
# steps	 1500 	total rewards	 317.03297009874126
# Finished after 1744 timesteps (11.27332615852356 seconds) with total reward 357.54143159354504
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 357.54143159354567, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.27568189026226
# steps	 1000 	total rewards	 178.89586218914897
# Finished after 1468 timesteps (7.218538045883179 seconds) with total reward 248.8792687394992
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 248.87926873949786, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 102.06959352333683
# steps	 1000 	total rewards	 203.76934731050875
# steps	 1500 	total rewards	 314.6913157438472
# Finished after 1736 timesteps (10.097336053848267 seconds) with total reward 352.8683422368248
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 352.8683422368253, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 90.74138548172694
# steps	 1000 	total rewards	 200.31290144512386
# steps	 1500 	total rewards	 301.1097996085705
# Finished after 1667 timesteps (10.498085021972656 seconds) with total reward 323.768416073993
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 323.7684160739943, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.23962533608534
# steps	 1000 	total rewards	 197.16226995805556
# steps	 1500 	total rewards	 303.39580167752945
# Finished after 1737 timesteps (9.583570957183838 seconds) with total reward 344.057804535654
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 344.05780453565535, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.76014323446897
# steps	 1000 	total rewards	 182.82317997694054
# steps	 1500 	total rewards	 254.1775526296638
# Finished after 1530 timesteps (7.9017229080200195 seconds) with total reward 257.90826139058424
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 257.9082613905829, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.09788008205047
# steps	 1000 	total rewards	 173.34530752343633
# steps	 1500 	total rewards	 250.4027444407447
# Finished after 1602 timesteps (8.78212308883667 seconds) with total reward 265.8130372865816
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 265.8130372865811, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 81.87979467550704
# steps	 1000 	total rewards	 176.3296676850765
# steps	 1500 	total rewards	 264.5543538505019
# Finished after 1645 timesteps (11.066256046295166 seconds) with total reward 281.66421220903726
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 281.6642122090379, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 77.69553492222708
# steps	 1000 	total rewards	 165.92205077135358
# Finished after 1497 timesteps (7.735269069671631 seconds) with total reward 238.86550329561172
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 238.86550329561047, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.05709360186964
# steps	 1000 	total rewards	 202.35383743309467
# steps	 1500 	total rewards	 309.4258646878863
# Finished after 1655 timesteps (9.195266246795654 seconds) with total reward 340.11849111963613
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 340.118491119637, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 105.80378017337763
# steps	 1000 	total rewards	 218.16501246190484
# steps	 1500 	total rewards	 323.99517148498575
# Finished after 1729 timesteps (11.688903093338013 seconds) with total reward 365.3798953710612
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 365.3798953710626, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.86888851189178
# steps	 1000 	total rewards	 210.73859611594213
# steps	 1500 	total rewards	 300.65131585356136
# Finished after 1681 timesteps (9.159843921661377 seconds) with total reward 326.453219442385
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 326.45321944238583, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.55640776019361
# steps	 1000 	total rewards	 192.1170010832405
# steps	 1500 	total rewards	 282.6369316315453
# Finished after 1621 timesteps (8.394825220108032 seconds) with total reward 301.02243270902477
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 301.022432709025, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.8961989902214
# steps	 1000 	total rewards	 183.76704030525036
# steps	 1500 	total rewards	 264.106842989171
# Finished after 1634 timesteps (8.09661316871643 seconds) with total reward 282.8349639496908
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 282.8349639496904, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.82872862229425
# steps	 1000 	total rewards	 205.4574323828516
# steps	 1500 	total rewards	 298.0440315538605
# Finished after 1726 timesteps (9.786468267440796 seconds) with total reward 339.6563370807766
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 339.65633708077706, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 78.8765952264226
# steps	 1000 	total rewards	 180.8121218448101
# Finished after 1475 timesteps (7.861936092376709 seconds) with total reward 259.5886548759064
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 259.5886548759048, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 90.37844742158512
# steps	 1000 	total rewards	 195.95932027941527
# steps	 1500 	total rewards	 283.3609709366841
# Finished after 1636 timesteps (8.775251865386963 seconds) with total reward 305.03129962834686
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 305.03129962834777, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.58010974902588
# steps	 1000 	total rewards	 199.06887434647197
# steps	 1500 	total rewards	 285.5523492877917
# Finished after 1575 timesteps (8.028850078582764 seconds) with total reward 296.6703624144893
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 296.67036241449057, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 90.58123202962977
# steps	 1000 	total rewards	 201.86616968777264
# steps	 1500 	total rewards	 295.787668388372
# Finished after 1681 timesteps (8.584741115570068 seconds) with total reward 324.2819674955664
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 324.28196749556696, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.78144021754095
# steps	 1000 	total rewards	 188.87430385569195
# steps	 1500 	total rewards	 297.86842274642567
# Finished after 1679 timesteps (11.456135988235474 seconds) with total reward 329.2116800669655
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 329.21168006696644, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 71.98194223405334
# steps	 1000 	total rewards	 170.41017366979133
# Finished after 1465 timesteps (7.434619188308716 seconds) with total reward 242.86558010739546
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 242.86558010739404, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 87.80052172308895
# steps	 1000 	total rewards	 195.50633781024922
# steps	 1500 	total rewards	 294.00010247549244
# Finished after 1564 timesteps (8.10376501083374 seconds) with total reward 304.0900195549617
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 304.09001955496166, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.17309733822901
# steps	 1000 	total rewards	 195.47739728296165
# steps	 1500 	total rewards	 298.6482177897861
# Finished after 1749 timesteps (9.604144096374512 seconds) with total reward 346.2046795612188
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 346.20467956121945, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.33998672596451
# steps	 1000 	total rewards	 192.64754247155082
# steps	 1500 	total rewards	 274.80651079438553
# Finished after 1657 timesteps (10.867799043655396 seconds) with total reward 293.02734741027416
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 293.02734741027416, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fcbadbcfcd0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fcb686bd670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fcb9842a910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.487', 'ms1ms2_ratio': '1.387', 'efficiency': '0.768', 'TP': '208', 'FP': '199', 'FN': '19', 'precision': '0.511', 'recall': '0.916', 'f1': '0.656'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.504', 'ms1ms2_ratio': '1.476', 'efficiency': '0.749', 'TP': '190', 'FP': '189', 'FN': '15', 'precision': '0.501', 'recall': '0.927', 'f1': '0.651'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.526', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.275', 'efficiency': '0.728', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.489', 'ms1ms2_ratio': '1.420', 'efficiency': '0.768', 'TP': '204', 'FP': '196', 'FN': '24', 'precision': '0.510', 'recall': '0.895', 'f1': '0.650'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.517', 'ms1ms2_ratio': '1.546', 'efficiency': '0.751', 'TP': '197', 'FP': '170', 'FN': '17', 'precision': '0.537', 'recall': '0.921', 'f1': '0.678'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.535', 'ms1ms2_ratio': '1.210', 'efficiency': '0.728', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.476', 'ms1ms2_ratio': '2.560', 'efficiency': '0.725', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.077', 'efficiency': '0.759', 'TP': '272', 'FP': '209', 'FN': '17', 'precision': '0.565', 'recall': '0.941', 'f1': '0.706'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.504', 'ms1ms2_ratio': '1.657', 'efficiency': '0.763', 'TP': '185', 'FP': '169', 'FN': '18', 'precision': '0.523', 'recall': '0.911', 'f1': '0.664'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.059', 'efficiency': '0.744', 'TP': '150', 'FP': '141', 'FN': '11', 'precision': '0.515', 'recall': '0.932', 'f1': '0.664'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '1.995', 'efficiency': '0.761', 'TP': '162', 'FP': '143', 'FN': '17', 'precision': '0.531', 'recall': '0.905', 'f1': '0.669'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.148', 'efficiency': '0.770', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '213', 'FP': '172', 'FN': '11', 'precision': '0.553', 'recall': '0.951', 'f1': '0.700'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.043', 'efficiency': '0.724', 'TP': '252', 'FP': '217', 'FN': '24', 'precision': '0.537', 'recall': '0.913', 'f1': '0.677'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1034.497114                1173.0          0.692           0.228
# 1  random   -1255.975600                1353.0          0.733           0.198
# 2  random    -970.555784                1124.0          0.772           0.258
# 3  random   -1184.733826                1316.0          0.659           0.211
# 4  random   -1078.900403                1226.0          0.709           0.204
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.007       0.149      0.312   0.413  0.355
# 1          0.007       0.097      0.245   0.402  0.304
# 2          0.007       0.154      0.309   0.511  0.385
# 3          0.005       0.150      0.312   0.377  0.341
# 4          0.006       0.157      0.248   0.377  0.300

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E8_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E8_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     349.538556                   0.0          0.984           0.666
# 31    DQN     293.943315                   0.0          0.977           0.699
# 32    DQN     343.174443                   3.0          0.985           0.658
# 33    DQN     354.917094                   1.0          0.967           0.654
# 34    DQN     349.958354                   1.0          0.984           0.652
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.208       0.297      0.747   0.978  0.847
# 31          0.197       0.179      0.770   0.970  0.858
# 32          0.206       0.274      0.745   0.980  0.846
# 33          0.217       0.313      0.748   0.956  0.840
# 34          0.217       0.308      0.747   0.979  0.847

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
