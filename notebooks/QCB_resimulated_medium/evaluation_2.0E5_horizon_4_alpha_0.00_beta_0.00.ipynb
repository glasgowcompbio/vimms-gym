# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.00
env_beta = 0.00
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-21 11:42:06.523 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa4ae7457b0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa46915ecb0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa46917be50>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.0,
#    'beta': 0.0}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_2.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa4ae7457b0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa46915ecb0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa46917be50>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa4ae7457b0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa46915ecb0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa46917be50>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
horizon = 1
out_dir = 'evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E5_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 336.30556962032347
# steps	 1000 	total rewards	 699.2219315891891
# steps	 1500 	total rewards	 1077.8996652721448
# Finished after 1801 timesteps (2.466200828552246 seconds) with total reward 1293.844151085149
# {'coverage_prop': '0.944', 'intensity_prop': '0.704', 'ms1ms2_ratio': '0.124', 'efficiency': '0.251', 'TP': '345', 'FP': '57', 'FN': '24', 'precision': '0.858', 'recall': '0.935', 'f1': '0.895', 'total_rewards': 1293.8441510851517, 'invalid_action_count': 0, 'num_ms1_scans': 199, 'num_ms2_scans': 1602}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 312.01748215704674
# steps	 1000 	total rewards	 665.2697981754527
# steps	 1500 	total rewards	 1021.9946306442456
# Finished after 1712 timesteps (1.8718490600585938 seconds) with total reward 1181.0837723140273
# {'coverage_prop': '0.950', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.202', 'efficiency': '0.175', 'TP': '228', 'FP': '21', 'FN': '13', 'precision': '0.916', 'recall': '0.946', 'f1': '0.931', 'total_rewards': 1181.0837723140273, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 318.8934762398691
# steps	 1000 	total rewards	 693.7220741128504
# steps	 1500 	total rewards	 1079.6187911858324
# Finished after 1763 timesteps (2.1854002475738525 seconds) with total reward 1282.3626221434056
# {'coverage_prop': '0.939', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.155', 'efficiency': '0.242', 'TP': '306', 'FP': '64', 'FN': '24', 'precision': '0.827', 'recall': '0.927', 'f1': '0.874', 'total_rewards': 1282.3626221434058, 'invalid_action_count': 0, 'num_ms1_scans': 237, 'num_ms2_scans': 1526}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 332.5621270996668
# steps	 1000 	total rewards	 690.5450789807638
# steps	 1500 	total rewards	 1054.5425474510625
# Finished after 1790 timesteps (2.813523769378662 seconds) with total reward 1267.3762874686295
# {'coverage_prop': '0.949', 'intensity_prop': '0.704', 'ms1ms2_ratio': '0.133', 'efficiency': '0.272', 'TP': '367', 'FP': '62', 'FN': '23', 'precision': '0.855', 'recall': '0.941', 'f1': '0.896', 'total_rewards': 1267.3762874686306, 'invalid_action_count': 0, 'num_ms1_scans': 210, 'num_ms2_scans': 1580}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 305.70051681961786
# steps	 1000 	total rewards	 663.5774630925999
# steps	 1500 	total rewards	 1000.2606424334291
# Finished after 1780 timesteps (2.2697670459747314 seconds) with total reward 1186.8275265555785
# {'coverage_prop': '0.936', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.141', 'efficiency': '0.262', 'TP': '349', 'FP': '60', 'FN': '28', 'precision': '0.853', 'recall': '0.926', 'f1': '0.888', 'total_rewards': 1186.8275265555767, 'invalid_action_count': 0, 'num_ms1_scans': 220, 'num_ms2_scans': 1560}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 305.4124719705176
# steps	 1000 	total rewards	 637.0408425600394
# steps	 1500 	total rewards	 997.728423713577
# Finished after 1658 timesteps (2.3001747131347656 seconds) with total reward 1100.2488539975009
# {'coverage_prop': '0.955', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.260', 'efficiency': '0.145', 'TP': '181', 'FP': '10', 'FN': '9', 'precision': '0.948', 'recall': '0.953', 'f1': '0.950', 'total_rewards': 1100.2488539975009, 'invalid_action_count': 0, 'num_ms1_scans': 342, 'num_ms2_scans': 1316}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 328.88520862180224
# steps	 1000 	total rewards	 691.6963886146659
# steps	 1500 	total rewards	 1060.5545019018473
# Finished after 1812 timesteps (2.4329090118408203 seconds) with total reward 1270.6282999244715
# {'coverage_prop': '0.925', 'intensity_prop': '0.671', 'ms1ms2_ratio': '0.116', 'efficiency': '0.272', 'TP': '362', 'FP': '80', 'FN': '36', 'precision': '0.819', 'recall': '0.910', 'f1': '0.862', 'total_rewards': 1270.6282999244713, 'invalid_action_count': 0, 'num_ms1_scans': 188, 'num_ms2_scans': 1624}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 260.8125288867599
# steps	 1000 	total rewards	 622.873438389819
# steps	 1500 	total rewards	 976.2225092203848
# Finished after 1651 timesteps (1.8607618808746338 seconds) with total reward 1078.646713387383
# {'coverage_prop': '0.946', 'intensity_prop': '0.797', 'ms1ms2_ratio': '0.268', 'efficiency': '0.148', 'TP': '185', 'FP': '8', 'FN': '11', 'precision': '0.959', 'recall': '0.944', 'f1': '0.951', 'total_rewards': 1078.6467133873834, 'invalid_action_count': 0, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 341.37034119920287
# steps	 1000 	total rewards	 693.82117003651
# steps	 1500 	total rewards	 1052.5785384938172
# Finished after 1804 timesteps (2.4307198524475098 seconds) with total reward 1272.9558505172722
# {'coverage_prop': '0.932', 'intensity_prop': '0.704', 'ms1ms2_ratio': '0.122', 'efficiency': '0.246', 'TP': '344', 'FP': '51', 'FN': '29', 'precision': '0.871', 'recall': '0.922', 'f1': '0.896', 'total_rewards': 1272.9558505172731, 'invalid_action_count': 0, 'num_ms1_scans': 196, 'num_ms2_scans': 1608}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 310.51204964063174
# steps	 1000 	total rewards	 677.1988733450796
# steps	 1500 	total rewards	 1056.028982498927
# Finished after 1777 timesteps (1.9656059741973877 seconds) with total reward 1256.469881210946
# {'coverage_prop': '0.945', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.144', 'efficiency': '0.234', 'TP': '311', 'FP': '52', 'FN': '21', 'precision': '0.857', 'recall': '0.937', 'f1': '0.895', 'total_rewards': 1256.469881210946, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 326.2472642374785
# steps	 1000 	total rewards	 696.8699852379983
# steps	 1500 	total rewards	 1058.7051126137349
# Finished after 1802 timesteps (2.6504600048065186 seconds) with total reward 1275.0662370601049
# {'coverage_prop': '0.937', 'intensity_prop': '0.686', 'ms1ms2_ratio': '0.124', 'efficiency': '0.259', 'TP': '345', 'FP': '70', 'FN': '28', 'precision': '0.831', 'recall': '0.925', 'f1': '0.876', 'total_rewards': 1275.066237060106, 'invalid_action_count': 0, 'num_ms1_scans': 199, 'num_ms2_scans': 1603}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 315.899710273854
# steps	 1000 	total rewards	 654.948245863199
# steps	 1500 	total rewards	 997.8542474816857
# Finished after 1699 timesteps (2.050654888153076 seconds) with total reward 1131.5526809598678
# {'coverage_prop': '0.948', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.215', 'efficiency': '0.169', 'TP': '216', 'FP': '20', 'FN': '13', 'precision': '0.915', 'recall': '0.943', 'f1': '0.929', 'total_rewards': 1131.5526809598664, 'invalid_action_count': 0, 'num_ms1_scans': 301, 'num_ms2_scans': 1398}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 293.78594607991386
# steps	 1000 	total rewards	 657.4695637312876
# steps	 1500 	total rewards	 1011.7705430663661
# Finished after 1726 timesteps (2.6352620124816895 seconds) with total reward 1167.4715581760743
# {'coverage_prop': '0.936', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.189', 'efficiency': '0.162', 'TP': '200', 'FP': '35', 'FN': '16', 'precision': '0.851', 'recall': '0.926', 'f1': '0.887', 'total_rewards': 1167.4715581760743, 'invalid_action_count': 0, 'num_ms1_scans': 274, 'num_ms2_scans': 1452}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 295.570137765466
# steps	 1000 	total rewards	 644.7878228337986
# steps	 1500 	total rewards	 981.9150574743766
# Finished after 1746 timesteps (2.174577236175537 seconds) with total reward 1088.8692620301395
# {'coverage_prop': '0.930', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.170', 'efficiency': '0.187', 'TP': '241', 'FP': '38', 'FN': '21', 'precision': '0.864', 'recall': '0.920', 'f1': '0.891', 'total_rewards': 1088.8692620301395, 'invalid_action_count': 0, 'num_ms1_scans': 254, 'num_ms2_scans': 1492}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 278.96314736778436
# steps	 1000 	total rewards	 630.7363954047805
# steps	 1500 	total rewards	 958.9357067224207
# Finished after 1684 timesteps (1.876068115234375 seconds) with total reward 1073.1570193952155
# {'coverage_prop': '0.942', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.231', 'efficiency': '0.142', 'TP': '172', 'FP': '22', 'FN': '12', 'precision': '0.887', 'recall': '0.935', 'f1': '0.910', 'total_rewards': 1073.1570193952143, 'invalid_action_count': 0, 'num_ms1_scans': 316, 'num_ms2_scans': 1368}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 313.3577814686465
# steps	 1000 	total rewards	 693.244695570963
# steps	 1500 	total rewards	 1064.959789699808
# Finished after 1758 timesteps (3.0201430320739746 seconds) with total reward 1262.945247242343
# {'coverage_prop': '0.958', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.160', 'efficiency': '0.257', 'TP': '336', 'FP': '54', 'FN': '17', 'precision': '0.862', 'recall': '0.952', 'f1': '0.904', 'total_rewards': 1262.9452472423413, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 321.01582381356104
# steps	 1000 	total rewards	 706.5808308820691
# steps	 1500 	total rewards	 1056.843363610249
# Finished after 1809 timesteps (2.133629083633423 seconds) with total reward 1277.3997123919667
# {'coverage_prop': '0.950', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.118', 'efficiency': '0.292', 'TP': '398', 'FP': '75', 'FN': '25', 'precision': '0.841', 'recall': '0.941', 'f1': '0.888', 'total_rewards': 1277.3997123919676, 'invalid_action_count': 0, 'num_ms1_scans': 191, 'num_ms2_scans': 1618}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 333.96671285353244
# steps	 1000 	total rewards	 681.124669248275
# steps	 1500 	total rewards	 1040.8239150475338
# Finished after 1758 timesteps (2.912885904312134 seconds) with total reward 1218.7354716503303
# {'coverage_prop': '0.944', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.160', 'efficiency': '0.232', 'TP': '309', 'FP': '42', 'FN': '21', 'precision': '0.880', 'recall': '0.936', 'f1': '0.907', 'total_rewards': 1218.7354716503323, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 318.5362660656445
# steps	 1000 	total rewards	 681.3337939437923
# steps	 1500 	total rewards	 1041.7708069329951
# Finished after 1735 timesteps (2.0257580280303955 seconds) with total reward 1217.7137209345242
# {'coverage_prop': '0.964', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.181', 'efficiency': '0.198', 'TP': '253', 'FP': '38', 'FN': '11', 'precision': '0.869', 'recall': '0.958', 'f1': '0.912', 'total_rewards': 1217.713720934522, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1469}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 311.49752046808817
# steps	 1000 	total rewards	 668.8858060995517
# steps	 1500 	total rewards	 1037.7932417632887
# Finished after 1742 timesteps (1.845167875289917 seconds) with total reward 1207.2338779592528
# {'coverage_prop': '0.962', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.174', 'efficiency': '0.172', 'TP': '226', 'FP': '29', 'FN': '10', 'precision': '0.886', 'recall': '0.958', 'f1': '0.921', 'total_rewards': 1207.2338779592549, 'invalid_action_count': 0, 'num_ms1_scans': 258, 'num_ms2_scans': 1484}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 299.7629244045029
# steps	 1000 	total rewards	 661.7356169017038
# steps	 1500 	total rewards	 999.8421428990252
# Finished after 1794 timesteps (3.1848719120025635 seconds) with total reward 1208.4538166644093
# {'coverage_prop': '0.919', 'intensity_prop': '0.652', 'ms1ms2_ratio': '0.130', 'efficiency': '0.271', 'TP': '343', 'FP': '87', 'FN': '38', 'precision': '0.798', 'recall': '0.900', 'f1': '0.846', 'total_rewards': 1208.4538166644109, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 321.42441177227533
# steps	 1000 	total rewards	 677.2595460744382
# steps	 1500 	total rewards	 1039.5034308785634
# Finished after 1662 timesteps (2.0222201347351074 seconds) with total reward 1126.5504847121415
# {'coverage_prop': '0.940', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.255', 'efficiency': '0.166', 'TP': '201', 'FP': '19', 'FN': '14', 'precision': '0.914', 'recall': '0.935', 'f1': '0.924', 'total_rewards': 1126.5504847121415, 'invalid_action_count': 0, 'num_ms1_scans': 338, 'num_ms2_scans': 1324}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 322.11348038232296
# steps	 1000 	total rewards	 681.0074949200082
# steps	 1500 	total rewards	 1020.3632328887002
# Finished after 1748 timesteps (1.9870309829711914 seconds) with total reward 1204.6963664486987
# {'coverage_prop': '0.947', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.168', 'efficiency': '0.204', 'TP': '268', 'FP': '37', 'FN': '17', 'precision': '0.879', 'recall': '0.940', 'f1': '0.908', 'total_rewards': 1204.696366448699, 'invalid_action_count': 0, 'num_ms1_scans': 252, 'num_ms2_scans': 1496}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 309.87154077241985
# steps	 1000 	total rewards	 675.3956149838676
# steps	 1500 	total rewards	 1048.7332126318033
# Finished after 1719 timesteps (2.1683530807495117 seconds) with total reward 1205.0091210386909
# {'coverage_prop': '0.935', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.195', 'efficiency': '0.202', 'TP': '259', 'FP': '31', 'FN': '20', 'precision': '0.893', 'recall': '0.928', 'f1': '0.910', 'total_rewards': 1205.0091210386884, 'invalid_action_count': 0, 'num_ms1_scans': 281, 'num_ms2_scans': 1438}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 296.67694367917807
# steps	 1000 	total rewards	 670.7856345802504
# steps	 1500 	total rewards	 1032.2248223716433
# Finished after 1747 timesteps (1.9729218482971191 seconds) with total reward 1225.7544822980853
# {'coverage_prop': '0.974', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.169', 'efficiency': '0.225', 'TP': '294', 'FP': '42', 'FN': '9', 'precision': '0.875', 'recall': '0.970', 'f1': '0.920', 'total_rewards': 1225.754482298085, 'invalid_action_count': 0, 'num_ms1_scans': 253, 'num_ms2_scans': 1494}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 332.35236718604654
# steps	 1000 	total rewards	 694.5531615538483
# steps	 1500 	total rewards	 1083.643362024642
# Finished after 1778 timesteps (1.9972190856933594 seconds) with total reward 1288.1648246900857
# {'coverage_prop': '0.960', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.143', 'efficiency': '0.244', 'TP': '327', 'FP': '53', 'FN': '16', 'precision': '0.861', 'recall': '0.953', 'f1': '0.905', 'total_rewards': 1288.1648246900854, 'invalid_action_count': 0, 'num_ms1_scans': 222, 'num_ms2_scans': 1556}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 267.77964486449287
# steps	 1000 	total rewards	 646.1444653255217
# steps	 1500 	total rewards	 998.5146414184597
# Finished after 1663 timesteps (2.979043960571289 seconds) with total reward 1099.3703509971097
# {'coverage_prop': '0.951', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.146', 'TP': '180', 'FP': '13', 'FN': '10', 'precision': '0.933', 'recall': '0.947', 'f1': '0.940', 'total_rewards': 1099.3703509971106, 'invalid_action_count': 0, 'num_ms1_scans': 337, 'num_ms2_scans': 1326}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 296.39236233995126
# steps	 1000 	total rewards	 649.7429684731928
# steps	 1500 	total rewards	 1018.8851499731758
# Finished after 1708 timesteps (1.8557407855987549 seconds) with total reward 1171.9489129666867
# {'coverage_prop': '0.943', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.206', 'efficiency': '0.187', 'TP': '248', 'FP': '17', 'FN': '16', 'precision': '0.936', 'recall': '0.939', 'f1': '0.938', 'total_rewards': 1171.9489129666872, 'invalid_action_count': 0, 'num_ms1_scans': 292, 'num_ms2_scans': 1416}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 320.3074279321372
# steps	 1000 	total rewards	 665.9698550361909
# steps	 1500 	total rewards	 1043.7404871799895
# Finished after 1826 timesteps (2.1088991165161133 seconds) with total reward 1288.2031315181034
# {'coverage_prop': '0.915', 'intensity_prop': '0.646', 'ms1ms2_ratio': '0.105', 'efficiency': '0.273', 'TP': '365', 'FP': '86', 'FN': '42', 'precision': '0.809', 'recall': '0.897', 'f1': '0.851', 'total_rewards': 1288.203131518107, 'invalid_action_count': 0, 'num_ms1_scans': 174, 'num_ms2_scans': 1652}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 290.9922725718021
# steps	 1000 	total rewards	 679.8009721321285
# steps	 1500 	total rewards	 1051.431243770962
# Finished after 1753 timesteps (3.1258301734924316 seconds) with total reward 1224.8095269318273
# {'coverage_prop': '0.954', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.164', 'efficiency': '0.193', 'TP': '263', 'FP': '27', 'FN': '14', 'precision': '0.907', 'recall': '0.949', 'f1': '0.928', 'total_rewards': 1224.809526931827, 'invalid_action_count': 0, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# method = PPO max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 358.81592197886005
# steps	 1000 	total rewards	 731.8053407561578
# steps	 1500 	total rewards	 1115.951252390872
# Finished after 1863 timesteps (4.649872064590454 seconds) with total reward 1386.2228201900375
# {'coverage_prop': '0.951', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.079', 'efficiency': '0.235', 'TP': '351', 'FP': '54', 'FN': '21', 'precision': '0.867', 'recall': '0.944', 'f1': '0.903', 'total_rewards': 1386.2228201900364, 'invalid_action_count': 0, 'num_ms1_scans': 137, 'num_ms2_scans': 1726}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 341.8349370780895
# steps	 1000 	total rewards	 722.772256701395
# steps	 1500 	total rewards	 1096.568758023252
# Finished after 1802 timesteps (4.228539943695068 seconds) with total reward 1334.3555632287075
# {'coverage_prop': '0.958', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.123', 'efficiency': '0.156', 'TP': '236', 'FP': '15', 'FN': '11', 'precision': '0.940', 'recall': '0.955', 'f1': '0.948', 'total_rewards': 1334.355563228706, 'invalid_action_count': 0, 'num_ms1_scans': 198, 'num_ms2_scans': 1604}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 352.49742402360323
# steps	 1000 	total rewards	 738.602352454814
# steps	 1500 	total rewards	 1134.9354751592762
# Finished after 1843 timesteps (4.38981294631958 seconds) with total reward 1412.053476658064
# {'coverage_prop': '0.954', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.093', 'efficiency': '0.223', 'TP': '324', 'FP': '52', 'FN': '18', 'precision': '0.862', 'recall': '0.947', 'f1': '0.903', 'total_rewards': 1412.0534766580658, 'invalid_action_count': 0, 'num_ms1_scans': 157, 'num_ms2_scans': 1686}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 350.88141596436475
# steps	 1000 	total rewards	 727.2457139980991
# steps	 1500 	total rewards	 1104.2680012405176
# Finished after 1859 timesteps (4.342592000961304 seconds) with total reward 1372.00967787597
# {'coverage_prop': '0.954', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.082', 'efficiency': '0.251', 'TP': '386', 'FP': '45', 'FN': '21', 'precision': '0.896', 'recall': '0.948', 'f1': '0.921', 'total_rewards': 1372.0096778759698, 'invalid_action_count': 0, 'num_ms1_scans': 141, 'num_ms2_scans': 1718}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 329.3912056356413
# steps	 1000 	total rewards	 706.6168245663448
# steps	 1500 	total rewards	 1055.1286363335564
# Finished after 1851 timesteps (4.079009056091309 seconds) with total reward 1298.1562870355124
# {'coverage_prop': '0.966', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.088', 'efficiency': '0.248', 'TP': '355', 'FP': '67', 'FN': '15', 'precision': '0.841', 'recall': '0.959', 'f1': '0.896', 'total_rewards': 1298.156287035513, 'invalid_action_count': 0, 'num_ms1_scans': 149, 'num_ms2_scans': 1702}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 339.6476209043525
# steps	 1000 	total rewards	 704.2844470300336
# steps	 1500 	total rewards	 1088.3631478483132
# Finished after 1759 timesteps (4.446233034133911 seconds) with total reward 1266.894129762763
# {'coverage_prop': '0.955', 'intensity_prop': '0.823', 'ms1ms2_ratio': '0.159', 'efficiency': '0.126', 'TP': '184', 'FP': '7', 'FN': '9', 'precision': '0.963', 'recall': '0.953', 'f1': '0.958', 'total_rewards': 1266.8941297627637, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 342.32569683476254
# steps	 1000 	total rewards	 718.9695844584664
# steps	 1500 	total rewards	 1091.0839121995614
# Finished after 1864 timesteps (5.1288721561431885 seconds) with total reward 1347.1109960471313
# {'coverage_prop': '0.950', 'intensity_prop': '0.685', 'ms1ms2_ratio': '0.079', 'efficiency': '0.263', 'TP': '364', 'FP': '90', 'FN': '24', 'precision': '0.802', 'recall': '0.938', 'f1': '0.865', 'total_rewards': 1347.1109960471322, 'invalid_action_count': 0, 'num_ms1_scans': 136, 'num_ms2_scans': 1728}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 304.0381861143124
# steps	 1000 	total rewards	 681.5064636172033
# steps	 1500 	total rewards	 1072.562518999114
# Finished after 1769 timesteps (4.202524900436401 seconds) with total reward 1270.2157609576461
# {'coverage_prop': '0.951', 'intensity_prop': '0.811', 'ms1ms2_ratio': '0.150', 'efficiency': '0.126', 'TP': '182', 'FP': '12', 'FN': '10', 'precision': '0.938', 'recall': '0.948', 'f1': '0.943', 'total_rewards': 1270.2157609576495, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 362.19791202395453
# steps	 1000 	total rewards	 739.9581863613021
# steps	 1500 	total rewards	 1117.5002938822568
# Finished after 1871 timesteps (4.967478036880493 seconds) with total reward 1395.4881002379084
# {'coverage_prop': '0.934', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.074', 'efficiency': '0.227', 'TP': '352', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.926', 'f1': '0.907', 'total_rewards': 1395.4881002379054, 'invalid_action_count': 0, 'num_ms1_scans': 129, 'num_ms2_scans': 1742}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 342.54179767372716
# steps	 1000 	total rewards	 720.7339009203561
# steps	 1500 	total rewards	 1111.1032331830806
# Finished after 1851 timesteps (4.405310869216919 seconds) with total reward 1374.8191084769087
# {'coverage_prop': '0.948', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.088', 'efficiency': '0.214', 'TP': '324', 'FP': '40', 'FN': '20', 'precision': '0.890', 'recall': '0.942', 'f1': '0.915', 'total_rewards': 1374.8191084769073, 'invalid_action_count': 0, 'num_ms1_scans': 149, 'num_ms2_scans': 1702}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 350.23145674218426
# steps	 1000 	total rewards	 740.0485957690706
# steps	 1500 	total rewards	 1112.6494111305615
# Finished after 1876 timesteps (4.766372919082642 seconds) with total reward 1393.7458928791045
# {'coverage_prop': '0.955', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.071', 'efficiency': '0.241', 'TP': '365', 'FP': '58', 'FN': '20', 'precision': '0.863', 'recall': '0.948', 'f1': '0.903', 'total_rewards': 1393.7458928791057, 'invalid_action_count': 0, 'num_ms1_scans': 124, 'num_ms2_scans': 1752}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 350.12739957657095
# steps	 1000 	total rewards	 714.3451128622319
# steps	 1500 	total rewards	 1083.5253399633727
# Finished after 1797 timesteps (4.111196041107178 seconds) with total reward 1294.204585794649
# {'coverage_prop': '0.952', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.127', 'efficiency': '0.149', 'TP': '220', 'FP': '17', 'FN': '12', 'precision': '0.928', 'recall': '0.948', 'f1': '0.938', 'total_rewards': 1294.204585794653, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 329.1531352518597
# steps	 1000 	total rewards	 710.5704898779646
# steps	 1500 	total rewards	 1093.260683303284
# Finished after 1834 timesteps (3.8176801204681396 seconds) with total reward 1334.5213645570702
# {'coverage_prop': '0.948', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.100', 'efficiency': '0.143', 'TP': '214', 'FP': '24', 'FN': '13', 'precision': '0.899', 'recall': '0.943', 'f1': '0.920', 'total_rewards': 1334.521364557071, 'invalid_action_count': 0, 'num_ms1_scans': 167, 'num_ms2_scans': 1667}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 325.643831513556
# steps	 1000 	total rewards	 691.8715015426159
# steps	 1500 	total rewards	 1046.4193772437366
# Finished after 1837 timesteps (3.6505470275878906 seconds) with total reward 1217.9550987405707
# {'coverage_prop': '0.957', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.097', 'efficiency': '0.171', 'TP': '255', 'FP': '32', 'FN': '13', 'precision': '0.889', 'recall': '0.951', 'f1': '0.919', 'total_rewards': 1217.955098740571, 'invalid_action_count': 0, 'num_ms1_scans': 163, 'num_ms2_scans': 1674}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 311.5482503966025
# steps	 1000 	total rewards	 692.1235674702028
# steps	 1500 	total rewards	 1056.6293181209126
# Finished after 1791 timesteps (6.963640213012695 seconds) with total reward 1236.602920570186
# {'coverage_prop': '0.947', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.132', 'efficiency': '0.123', 'TP': '173', 'FP': '22', 'FN': '11', 'precision': '0.887', 'recall': '0.940', 'f1': '0.913', 'total_rewards': 1236.602920570187, 'invalid_action_count': 0, 'num_ms1_scans': 209, 'num_ms2_scans': 1582}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 336.3504975553717
# steps	 1000 	total rewards	 731.554978472282
# steps	 1500 	total rewards	 1114.8472482814002
# Finished after 1842 timesteps (4.230672121047974 seconds) with total reward 1398.9539121246294
# {'coverage_prop': '0.975', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.094', 'efficiency': '0.236', 'TP': '346', 'FP': '51', 'FN': '10', 'precision': '0.872', 'recall': '0.972', 'f1': '0.919', 'total_rewards': 1398.9539121246303, 'invalid_action_count': 0, 'num_ms1_scans': 158, 'num_ms2_scans': 1684}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 342.65221163813715
# steps	 1000 	total rewards	 732.8108459835942
# steps	 1500 	total rewards	 1103.6302414241582
# Finished after 1868 timesteps (4.163242816925049 seconds) with total reward 1375.272859570512
# {'coverage_prop': '0.970', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.076', 'efficiency': '0.278', 'TP': '407', 'FP': '76', 'FN': '15', 'precision': '0.843', 'recall': '0.964', 'f1': '0.899', 'total_rewards': 1375.272859570508, 'invalid_action_count': 0, 'num_ms1_scans': 132, 'num_ms2_scans': 1736}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 362.07916918700636
# steps	 1000 	total rewards	 730.2568199102164
# steps	 1500 	total rewards	 1107.075621745727
# Finished after 1850 timesteps (3.9627039432525635 seconds) with total reward 1368.8525998208988
# {'coverage_prop': '0.949', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.088', 'efficiency': '0.208', 'TP': '314', 'FP': '39', 'FN': '19', 'precision': '0.890', 'recall': '0.943', 'f1': '0.915', 'total_rewards': 1368.852599820898, 'invalid_action_count': 0, 'num_ms1_scans': 150, 'num_ms2_scans': 1700}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 352.5533625607857
# steps	 1000 	total rewards	 735.238083954807
# steps	 1500 	total rewards	 1112.2182812851897
# Finished after 1825 timesteps (4.139430999755859 seconds) with total reward 1366.0913076157872
# {'coverage_prop': '0.960', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.106', 'efficiency': '0.176', 'TP': '261', 'FP': '29', 'FN': '12', 'precision': '0.900', 'recall': '0.956', 'f1': '0.927', 'total_rewards': 1366.0913076157897, 'invalid_action_count': 0, 'num_ms1_scans': 175, 'num_ms2_scans': 1650}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 342.20442104441014
# steps	 1000 	total rewards	 714.2145678361888
# steps	 1500 	total rewards	 1102.4273234415666
# Finished after 1830 timesteps (3.6652159690856934 seconds) with total reward 1348.7152555079654
# {'coverage_prop': '0.974', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.102', 'efficiency': '0.155', 'TP': '233', 'FP': '25', 'FN': '7', 'precision': '0.903', 'recall': '0.971', 'f1': '0.936', 'total_rewards': 1348.7152555079685, 'invalid_action_count': 0, 'num_ms1_scans': 170, 'num_ms2_scans': 1660}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 324.583154856193
# steps	 1000 	total rewards	 696.4417573738152
# steps	 1500 	total rewards	 1045.0318962590131
# Finished after 1865 timesteps (5.462433815002441 seconds) with total reward 1305.1326683121194
# {'coverage_prop': '0.932', 'intensity_prop': '0.695', 'ms1ms2_ratio': '0.078', 'efficiency': '0.252', 'TP': '361', 'FP': '75', 'FN': '32', 'precision': '0.828', 'recall': '0.919', 'f1': '0.871', 'total_rewards': 1305.1326683121176, 'invalid_action_count': 0, 'num_ms1_scans': 135, 'num_ms2_scans': 1730}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 359.34960630784235
# steps	 1000 	total rewards	 741.401311205291
# steps	 1500 	total rewards	 1138.4958321708268
# Finished after 1781 timesteps (3.7324020862579346 seconds) with total reward 1330.2026690332032
# {'coverage_prop': '0.953', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.140', 'efficiency': '0.143', 'TP': '205', 'FP': '18', 'FN': '11', 'precision': '0.919', 'recall': '0.949', 'f1': '0.934', 'total_rewards': 1330.2026690332027, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 347.55631571482337
# steps	 1000 	total rewards	 736.1546924884914
# steps	 1500 	total rewards	 1093.8392161246911
# Finished after 1835 timesteps (4.549973011016846 seconds) with total reward 1351.8638065772334
# {'coverage_prop': '0.966', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.099', 'efficiency': '0.186', 'TP': '274', 'FP': '37', 'FN': '11', 'precision': '0.881', 'recall': '0.961', 'f1': '0.919', 'total_rewards': 1351.8638065772334, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 338.06445604172774
# steps	 1000 	total rewards	 715.4626261859798
# steps	 1500 	total rewards	 1114.0131761297025
# Finished after 1808 timesteps (3.83742618560791 seconds) with total reward 1342.013775022116
# {'coverage_prop': '0.948', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.119', 'efficiency': '0.182', 'TP': '266', 'FP': '28', 'FN': '16', 'precision': '0.905', 'recall': '0.943', 'f1': '0.924', 'total_rewards': 1342.0137750221159, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1616}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 335.08619052049124
# steps	 1000 	total rewards	 720.3213508722121
# steps	 1500 	total rewards	 1096.9972201602495
# Finished after 1838 timesteps (3.688480854034424 seconds) with total reward 1375.9415321797287
# {'coverage_prop': '0.980', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.097', 'efficiency': '0.202', 'TP': '297', 'FP': '41', 'FN': '7', 'precision': '0.879', 'recall': '0.977', 'f1': '0.925', 'total_rewards': 1375.941532179727, 'invalid_action_count': 0, 'num_ms1_scans': 162, 'num_ms2_scans': 1676}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 366.7129389921863
# steps	 1000 	total rewards	 744.1259182463501
# steps	 1500 	total rewards	 1149.0025194711434
# Finished after 1863 timesteps (3.826913833618164 seconds) with total reward 1431.7419205548974
# {'coverage_prop': '0.967', 'intensity_prop': '0.740', 'ms1ms2_ratio': '0.079', 'efficiency': '0.222', 'TP': '330', 'FP': '53', 'FN': '13', 'precision': '0.862', 'recall': '0.962', 'f1': '0.909', 'total_rewards': 1431.7419205548983, 'invalid_action_count': 0, 'num_ms1_scans': 137, 'num_ms2_scans': 1726}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 299.43582808158635
# steps	 1000 	total rewards	 703.815288877746
# steps	 1500 	total rewards	 1090.8948102495942
# Finished after 1777 timesteps (5.39719295501709 seconds) with total reward 1285.9762625058333
# {'coverage_prop': '0.966', 'intensity_prop': '0.827', 'ms1ms2_ratio': '0.144', 'efficiency': '0.126', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962', 'total_rewards': 1285.9762625058338, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 328.0738983854298
# steps	 1000 	total rewards	 705.2232867107639
# steps	 1500 	total rewards	 1095.4568400974904
# Finished after 1808 timesteps (3.302475929260254 seconds) with total reward 1338.2128525814014
# {'coverage_prop': '0.964', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.119', 'efficiency': '0.168', 'TP': '245', 'FP': '26', 'FN': '10', 'precision': '0.904', 'recall': '0.961', 'f1': '0.932', 'total_rewards': 1338.2128525813991, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1616}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 339.24702678896745
# steps	 1000 	total rewards	 695.2359269113983
# steps	 1500 	total rewards	 1081.653282707622
# Finished after 1880 timesteps (3.5943570137023926 seconds) with total reward 1378.4745325132867
# {'coverage_prop': '0.929', 'intensity_prop': '0.662', 'ms1ms2_ratio': '0.068', 'efficiency': '0.260', 'TP': '364', 'FP': '94', 'FN': '35', 'precision': '0.795', 'recall': '0.912', 'f1': '0.849', 'total_rewards': 1378.4745325132867, 'invalid_action_count': 0, 'num_ms1_scans': 120, 'num_ms2_scans': 1760}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 312.2241978321649
# steps	 1000 	total rewards	 715.593744651859
# steps	 1500 	total rewards	 1099.7197666729207
# Finished after 1828 timesteps (3.8480608463287354 seconds) with total reward 1345.4552290673096
# {'coverage_prop': '0.961', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.104', 'efficiency': '0.176', 'TP': '271', 'FP': '21', 'FN': '12', 'precision': '0.928', 'recall': '0.958', 'f1': '0.943', 'total_rewards': 1345.4552290673096, 'invalid_action_count': 0, 'num_ms1_scans': 172, 'num_ms2_scans': 1656}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 284.35173691799935
# steps	 1000 	total rewards	 645.0465058244614
# steps	 1500 	total rewards	 1017.7748091847278
# Finished after 1722 timesteps (9.645117044448853 seconds) with total reward 1167.8359689934637
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 1167.8359689934623, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 237.23177572896248
# steps	 1000 	total rewards	 554.4430604815191
# steps	 1500 	total rewards	 887.0536667084407
# Finished after 1556 timesteps (10.376563310623169 seconds) with total reward 919.7290877477645
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 919.7290877477635, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 244.24078937805592
# steps	 1000 	total rewards	 617.4522393548262
# steps	 1500 	total rewards	 1002.6498139883214
# Finished after 1669 timesteps (9.938150882720947 seconds) with total reward 1130.9657429482975
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 1130.965742948297, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 306.9619922016653
# steps	 1000 	total rewards	 652.1697495515991
# steps	 1500 	total rewards	 1007.0544717885612
# Finished after 1717 timesteps (9.610376834869385 seconds) with total reward 1160.844542375401
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 1160.8445423754026, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 261.249548510777
# steps	 1000 	total rewards	 611.6011930731654
# steps	 1500 	total rewards	 947.4884069170549
# Finished after 1704 timesteps (10.56745719909668 seconds) with total reward 1083.5255881611301
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 1083.5255881611292, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 181.55898885283494
# steps	 1000 	total rewards	 488.21694418597497
# Finished after 1408 timesteps (7.811277151107788 seconds) with total reward 675.4596211493204
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 675.4596211493198, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 298.5223816529141
# steps	 1000 	total rewards	 661.1546720814175
# steps	 1500 	total rewards	 1022.0568069477519
# Finished after 1744 timesteps (11.025163888931274 seconds) with total reward 1184.7307706257739
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 1184.7307706257727, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 168.78647892758428
# steps	 1000 	total rewards	 524.8551903087605
# Finished after 1468 timesteps (8.015844821929932 seconds) with total reward 775.5140457988746
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 775.5140457988745, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 304.21794044279426
# steps	 1000 	total rewards	 659.5970891692505
# steps	 1500 	total rewards	 1012.5872292293436
# Finished after 1736 timesteps (11.714480876922607 seconds) with total reward 1183.145173544725
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 1183.1451735447267, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 247.49521883514583
# steps	 1000 	total rewards	 607.4419966049937
# steps	 1500 	total rewards	 969.8849337641245
# Finished after 1667 timesteps (9.556005001068115 seconds) with total reward 1084.5556389681337
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 1084.5556389681337, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 292.7753260621716
# steps	 1000 	total rewards	 668.7999811580942
# steps	 1500 	total rewards	 1024.0869025194186
# Finished after 1737 timesteps (9.487802028656006 seconds) with total reward 1198.1318259640402
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 1198.1318259640384, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 222.00399078124747
# steps	 1000 	total rewards	 560.5403282265054
# steps	 1500 	total rewards	 842.2491749333565
# Finished after 1530 timesteps (10.138315916061401 seconds) with total reward 856.8756710129564
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 856.8756710129577, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 225.54324442126702
# steps	 1000 	total rewards	 588.9601538388687
# steps	 1500 	total rewards	 916.148580035796
# Finished after 1602 timesteps (9.195235013961792 seconds) with total reward 971.6859057789334
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 971.6859057789343, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 240.09095914198977
# steps	 1000 	total rewards	 562.4815276754034
# steps	 1500 	total rewards	 875.4723165540549
# Finished after 1645 timesteps (8.953988790512085 seconds) with total reward 933.6353965902404
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 933.6353965902405, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 180.46419340656627
# steps	 1000 	total rewards	 536.1571167178973
# Finished after 1497 timesteps (9.716205835342407 seconds) with total reward 786.9988868412757
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 786.9988868412732, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 251.55663538505877
# steps	 1000 	total rewards	 615.6396629606827
# steps	 1500 	total rewards	 974.5454548686362
# Finished after 1655 timesteps (9.359802722930908 seconds) with total reward 1087.9559089845159
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 1087.9559089845152, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 287.5206485721802
# steps	 1000 	total rewards	 665.2471719741759
# steps	 1500 	total rewards	 1021.0528483926507
# Finished after 1729 timesteps (10.060338973999023 seconds) with total reward 1176.4516615432574
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 1176.4516615432585, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 278.86972648431293
# steps	 1000 	total rewards	 625.1561113533623
# steps	 1500 	total rewards	 978.1322409428257
# Finished after 1681 timesteps (10.955599069595337 seconds) with total reward 1091.4919579542598
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 1091.4919579542595, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 238.30635185984642
# steps	 1000 	total rewards	 591.8145618998964
# steps	 1500 	total rewards	 953.4216600906755
# Finished after 1621 timesteps (8.716629981994629 seconds) with total reward 1030.2315868383607
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 1030.231586838361, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 238.4005364962573
# steps	 1000 	total rewards	 597.8233186640654
# steps	 1500 	total rewards	 953.5207470575947
# Finished after 1634 timesteps (8.53273868560791 seconds) with total reward 1034.3859718888573
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 1034.3859718888577, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 275.67253901008155
# steps	 1000 	total rewards	 626.5444608980383
# steps	 1500 	total rewards	 967.4884599462245
# Finished after 1726 timesteps (10.511817216873169 seconds) with total reward 1128.7272082279674
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 1128.7272082279674, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 210.2548042496294
# steps	 1000 	total rewards	 556.8896863651553
# Finished after 1475 timesteps (10.753446102142334 seconds) with total reward 810.9407019987381
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 810.9407019987378, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 256.94883769352884
# steps	 1000 	total rewards	 610.6369915873785
# steps	 1500 	total rewards	 942.895199988627
# Finished after 1636 timesteps (9.585287809371948 seconds) with total reward 1027.6535572533487
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 1027.6535572533496, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 244.62591100582003
# steps	 1000 	total rewards	 599.5558570764224
# steps	 1500 	total rewards	 919.9956894688482
# Finished after 1575 timesteps (8.501431941986084 seconds) with total reward 954.7338496430982
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 954.7338496430997, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 237.8887722185019
# steps	 1000 	total rewards	 616.6015235706046
# steps	 1500 	total rewards	 980.0892895227569
# Finished after 1681 timesteps (11.177031993865967 seconds) with total reward 1119.2223628982943
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 1119.2223628982927, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 276.91120206653784
# steps	 1000 	total rewards	 622.5257442469413
# steps	 1500 	total rewards	 995.6646249836303
# Finished after 1679 timesteps (9.513692855834961 seconds) with total reward 1120.8174992408335
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 1120.8174992408346, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 190.14313877653316
# steps	 1000 	total rewards	 538.70617894609
# Finished after 1465 timesteps (9.221827745437622 seconds) with total reward 776.5190812277863
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 776.5190812277863, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 223.31819234438282
# steps	 1000 	total rewards	 566.98295970209
# steps	 1500 	total rewards	 888.3998333709135
# Finished after 1564 timesteps (11.04912781715393 seconds) with total reward 934.3745516976121
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 934.3745516976134, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 292.6601015558965
# steps	 1000 	total rewards	 632.6790823122867
# steps	 1500 	total rewards	 1009.5342874587811
# Finished after 1749 timesteps (9.911198139190674 seconds) with total reward 1198.4812643312716
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 1198.481264331275, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 252.30825969034052
# steps	 1000 	total rewards	 610.4416693816453
# steps	 1500 	total rewards	 976.196180535155
# Finished after 1657 timesteps (8.699728727340698 seconds) with total reward 1076.6770424990284
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 1076.6770424990277, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fa4ae7457b0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fa46915ecb0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fa46917be50>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.795', 'efficiency': '0.539', 'TP': '360', 'FP': '56', 'FN': '10', 'precision': '0.865', 'recall': '0.973', 'f1': '0.916'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '368', 'FP': '65', 'FN': '4', 'precision': '0.850', 'recall': '0.989', 'f1': '0.914'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.713', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '168', 'FP': '23', 'FN': '9', 'precision': '0.880', 'recall': '0.949', 'f1': '0.913'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.679', 'efficiency': '0.541', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.720', 'ms1ms2_ratio': '2.067', 'efficiency': '0.503', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.687', 'efficiency': '0.508', 'TP': '384', 'FP': '44', 'FN': '15', 'precision': '0.897', 'recall': '0.962', 'f1': '0.929'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.666', 'ms1ms2_ratio': '1.630', 'efficiency': '0.506', 'TP': '196', 'FP': '42', 'FN': '13', 'precision': '0.824', 'recall': '0.938', 'f1': '0.877'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.686', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.861', 'efficiency': '0.541', 'TP': '354', 'FP': '44', 'FN': '9', 'precision': '0.889', 'recall': '0.975', 'f1': '0.930'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '428', 'FP': '59', 'FN': '11', 'precision': '0.879', 'recall': '0.975', 'f1': '0.924'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '310', 'FP': '50', 'FN': '12', 'precision': '0.861', 'recall': '0.963', 'f1': '0.909'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.696', 'efficiency': '0.538', 'TP': '391', 'FP': '59', 'FN': '18', 'precision': '0.869', 'recall': '0.956', 'f1': '0.910'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.693', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.961', 'efficiency': '0.495', 'TP': '295', 'FP': '44', 'FN': '6', 'precision': '0.870', 'recall': '0.980', 'f1': '0.922'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.859', 'efficiency': '0.531', 'TP': '337', 'FP': '54', 'FN': '5', 'precision': '0.862', 'recall': '0.985', 'f1': '0.920'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.724', 'ms1ms2_ratio': '2.046', 'efficiency': '0.501', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.729', 'ms1ms2_ratio': '1.370', 'efficiency': '0.508', 'TP': '243', 'FP': '29', 'FN': '9', 'precision': '0.893', 'recall': '0.964', 'f1': '0.927'}
#
# Episode 28 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.585', 'efficiency': '0.517', 'TP': '409', 'FP': '68', 'FN': '16', 'precision': '0.857', 'recall': '0.962', 'f1': '0.907'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    1293.844151                   0.0          0.944           0.704
# 1  random    1181.083772                   0.0          0.950           0.771
# 2  random    1282.362622                   0.0          0.939           0.691
# 3  random    1267.376287                   0.0          0.949           0.704
# 4  random    1186.827527                   0.0          0.936           0.702
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.124       0.251      0.858   0.935  0.895
# 1          0.202       0.175      0.916   0.946  0.931
# 2          0.155       0.242      0.827   0.927  0.874
# 3          0.133       0.272      0.855   0.941  0.896
# 4          0.141       0.262      0.853   0.926  0.888

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    PPO    1386.222820                   0.0          0.951           0.724
# 31    PPO    1334.355563                   0.0          0.958           0.801
# 32    PPO    1412.053477                   0.0          0.954           0.727
# 33    PPO    1372.009678                   0.0          0.954           0.745
# 34    PPO    1298.156287                   0.0          0.966           0.721
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.079       0.235      0.867   0.944  0.903
# 31          0.123       0.156      0.940   0.955  0.948
# 32          0.093       0.223      0.862   0.947  0.903
# 33          0.082       0.251      0.896   0.948  0.921
# 34          0.088       0.248      0.841   0.959  0.896

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
