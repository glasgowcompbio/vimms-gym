# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.00
env_beta = 0.00
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-19 08:26:42.590 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9244239510>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f923256a560>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f92325bbf40>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.0,
#    'beta': 0.0}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_2.0E5'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9244239510>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f923256a560>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f92325bbf40>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9244239510>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f923256a560>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f92325bbf40>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
horizon = 4
out_dir = 'evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E5_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 325.47493450034585
# steps	 1000 	total rewards	 692.7167257788419
# steps	 1500 	total rewards	 1068.0572231195597
# Finished after 1789 timesteps (2.1414380073547363 seconds) with total reward 1273.5285169615522
# {'coverage_prop': '0.939', 'intensity_prop': '0.695', 'ms1ms2_ratio': '0.134', 'efficiency': '0.253', 'TP': '337', 'FP': '63', 'FN': '26', 'precision': '0.843', 'recall': '0.928', 'f1': '0.883', 'total_rewards': 1273.528516961552, 'invalid_action_count': 0, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 313.1547054739645
# steps	 1000 	total rewards	 667.3241259634221
# steps	 1500 	total rewards	 1021.2053623389361
# Finished after 1714 timesteps (1.2987651824951172 seconds) with total reward 1182.4675817406037
# {'coverage_prop': '0.950', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.200', 'efficiency': '0.174', 'TP': '225', 'FP': '24', 'FN': '13', 'precision': '0.904', 'recall': '0.945', 'f1': '0.924', 'total_rewards': 1182.4675817406046, 'invalid_action_count': 0, 'num_ms1_scans': 286, 'num_ms2_scans': 1428}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 322.50541836640264
# steps	 1000 	total rewards	 694.9006134627397
# steps	 1500 	total rewards	 1078.8147105056737
# Finished after 1765 timesteps (1.6017847061157227 seconds) with total reward 1284.3841610667946
# {'coverage_prop': '0.931', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.154', 'efficiency': '0.240', 'TP': '311', 'FP': '56', 'FN': '27', 'precision': '0.847', 'recall': '0.920', 'f1': '0.882', 'total_rewards': 1284.384161066792, 'invalid_action_count': 0, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 335.5183903257894
# steps	 1000 	total rewards	 696.533654163027
# steps	 1500 	total rewards	 1057.5719850651567
# Finished after 1794 timesteps (2.0243980884552 seconds) with total reward 1267.8253360394008
# {'coverage_prop': '0.940', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.130', 'efficiency': '0.268', 'TP': '367', 'FP': '58', 'FN': '27', 'precision': '0.864', 'recall': '0.931', 'f1': '0.896', 'total_rewards': 1267.8253360394012, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 314.42631446700307
# steps	 1000 	total rewards	 669.3342767795303
# steps	 1500 	total rewards	 1001.3498553186788
# Finished after 1783 timesteps (1.7571539878845215 seconds) with total reward 1190.9449367783395
# {'coverage_prop': '0.950', 'intensity_prop': '0.697', 'ms1ms2_ratio': '0.139', 'efficiency': '0.265', 'TP': '338', 'FP': '77', 'FN': '22', 'precision': '0.814', 'recall': '0.939', 'f1': '0.872', 'total_rewards': 1190.9449367783404, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 295.98443980258884
# steps	 1000 	total rewards	 635.3904716410309
# steps	 1500 	total rewards	 987.4933067872457
# Finished after 1647 timesteps (1.6482837200164795 seconds) with total reward 1078.5061285976028
# {'coverage_prop': '0.955', 'intensity_prop': '0.816', 'ms1ms2_ratio': '0.274', 'efficiency': '0.148', 'TP': '184', 'FP': '7', 'FN': '9', 'precision': '0.963', 'recall': '0.953', 'f1': '0.958', 'total_rewards': 1078.5061285976024, 'invalid_action_count': 0, 'num_ms1_scans': 354, 'num_ms2_scans': 1293}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 324.3068380204056
# steps	 1000 	total rewards	 679.0775693324076
# steps	 1500 	total rewards	 1043.3690482990041
# Finished after 1801 timesteps (2.05299711227417 seconds) with total reward 1245.5464531867783
# {'coverage_prop': '0.927', 'intensity_prop': '0.664', 'ms1ms2_ratio': '0.124', 'efficiency': '0.277', 'TP': '361', 'FP': '82', 'FN': '35', 'precision': '0.815', 'recall': '0.912', 'f1': '0.861', 'total_rewards': 1245.546453186779, 'invalid_action_count': 0, 'num_ms1_scans': 199, 'num_ms2_scans': 1602}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 252.07050222780003
# steps	 1000 	total rewards	 618.6121210738111
# steps	 1500 	total rewards	 979.4454536981682
# Finished after 1656 timesteps (1.2542731761932373 seconds) with total reward 1080.9030388288184
# {'coverage_prop': '0.946', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.262', 'efficiency': '0.147', 'TP': '180', 'FP': '13', 'FN': '11', 'precision': '0.933', 'recall': '0.942', 'f1': '0.937', 'total_rewards': 1080.9030388288197, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1312}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 331.63169780564397
# steps	 1000 	total rewards	 683.2166769815262
# steps	 1500 	total rewards	 1043.8128522290936
# Finished after 1790 timesteps (2.0575990676879883 seconds) with total reward 1248.6084013586972
# {'coverage_prop': '0.943', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.133', 'efficiency': '0.253', 'TP': '337', 'FP': '63', 'FN': '24', 'precision': '0.843', 'recall': '0.934', 'f1': '0.886', 'total_rewards': 1248.6084013586965, 'invalid_action_count': 0, 'num_ms1_scans': 210, 'num_ms2_scans': 1580}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 319.10189741526517
# steps	 1000 	total rewards	 685.1783497562126
# steps	 1500 	total rewards	 1062.4028460187246
# Finished after 1775 timesteps (1.5061161518096924 seconds) with total reward 1260.0109725026707
# {'coverage_prop': '0.948', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.145', 'efficiency': '0.235', 'TP': '323', 'FP': '41', 'FN': '20', 'precision': '0.887', 'recall': '0.942', 'f1': '0.914', 'total_rewards': 1260.0109725026716, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 322.0021217703098
# steps	 1000 	total rewards	 692.7718422366422
# steps	 1500 	total rewards	 1054.3381154478882
# Finished after 1799 timesteps (2.272918939590454 seconds) with total reward 1275.9445407244436
# {'coverage_prop': '0.941', 'intensity_prop': '0.687', 'ms1ms2_ratio': '0.126', 'efficiency': '0.261', 'TP': '346', 'FP': '71', 'FN': '26', 'precision': '0.830', 'recall': '0.930', 'f1': '0.877', 'total_rewards': 1275.944540724443, 'invalid_action_count': 0, 'num_ms1_scans': 201, 'num_ms2_scans': 1598}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 306.90879410482273
# steps	 1000 	total rewards	 645.6394570128668
# steps	 1500 	total rewards	 984.6323303031955
# Finished after 1688 timesteps (1.3613338470458984 seconds) with total reward 1113.9262116637515
# {'coverage_prop': '0.948', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.227', 'efficiency': '0.172', 'TP': '217', 'FP': '19', 'FN': '13', 'precision': '0.919', 'recall': '0.943', 'f1': '0.931', 'total_rewards': 1113.926211663753, 'invalid_action_count': 0, 'num_ms1_scans': 312, 'num_ms2_scans': 1376}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 301.95030008361755
# steps	 1000 	total rewards	 661.5670214387708
# steps	 1500 	total rewards	 1016.898245967614
# Finished after 1734 timesteps (1.9030227661132812 seconds) with total reward 1180.9260064947605
# {'coverage_prop': '0.936', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.181', 'efficiency': '0.160', 'TP': '207', 'FP': '28', 'FN': '16', 'precision': '0.881', 'recall': '0.928', 'f1': '0.904', 'total_rewards': 1180.9260064947603, 'invalid_action_count': 0, 'num_ms1_scans': 266, 'num_ms2_scans': 1468}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 301.5835808900674
# steps	 1000 	total rewards	 648.7649188848188
# steps	 1500 	total rewards	 994.4987735385005
# Finished after 1760 timesteps (1.5531370639801025 seconds) with total reward 1103.5249946594386
# {'coverage_prop': '0.947', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.158', 'efficiency': '0.187', 'TP': '241', 'FP': '43', 'FN': '16', 'precision': '0.849', 'recall': '0.938', 'f1': '0.891', 'total_rewards': 1103.5249946594372, 'invalid_action_count': 0, 'num_ms1_scans': 240, 'num_ms2_scans': 1520}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 279.77838370897285
# steps	 1000 	total rewards	 643.9257580374147
# steps	 1500 	total rewards	 974.8334824075819
# Finished after 1696 timesteps (1.9635939598083496 seconds) with total reward 1098.6075920185647
# {'coverage_prop': '0.922', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.218', 'efficiency': '0.136', 'TP': '176', 'FP': '14', 'FN': '16', 'precision': '0.926', 'recall': '0.917', 'f1': '0.921', 'total_rewards': 1098.6075920185622, 'invalid_action_count': 0, 'num_ms1_scans': 304, 'num_ms2_scans': 1392}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 306.26302277865983
# steps	 1000 	total rewards	 684.5065200070427
# steps	 1500 	total rewards	 1059.2323399868958
# Finished after 1757 timesteps (1.6972029209136963 seconds) with total reward 1257.3572825226818
# {'coverage_prop': '0.956', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.161', 'efficiency': '0.257', 'TP': '336', 'FP': '53', 'FN': '18', 'precision': '0.864', 'recall': '0.949', 'f1': '0.904', 'total_rewards': 1257.3572825226836, 'invalid_action_count': 0, 'num_ms1_scans': 243, 'num_ms2_scans': 1514}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 322.6773416698082
# steps	 1000 	total rewards	 706.4205936919304
# steps	 1500 	total rewards	 1062.5191580862243
# Finished after 1808 timesteps (1.7010622024536133 seconds) with total reward 1285.9263723676577
# {'coverage_prop': '0.946', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.119', 'efficiency': '0.291', 'TP': '404', 'FP': '67', 'FN': '27', 'precision': '0.858', 'recall': '0.937', 'f1': '0.896', 'total_rewards': 1285.9263723676577, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1616}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 334.8954590874473
# steps	 1000 	total rewards	 682.2336198101063
# steps	 1500 	total rewards	 1043.7167708850664
# Finished after 1768 timesteps (2.502340078353882 seconds) with total reward 1233.4078484002275
# {'coverage_prop': '0.935', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.151', 'efficiency': '0.227', 'TP': '302', 'FP': '46', 'FN': '24', 'precision': '0.868', 'recall': '0.926', 'f1': '0.896', 'total_rewards': 1233.407848400229, 'invalid_action_count': 0, 'num_ms1_scans': 232, 'num_ms2_scans': 1536}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 316.2876981928811
# steps	 1000 	total rewards	 679.8024554600902
# steps	 1500 	total rewards	 1043.4539291156632
# Finished after 1731 timesteps (1.4977941513061523 seconds) with total reward 1216.2259841508076
# {'coverage_prop': '0.957', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.184', 'efficiency': '0.198', 'TP': '260', 'FP': '29', 'FN': '13', 'precision': '0.900', 'recall': '0.952', 'f1': '0.925', 'total_rewards': 1216.2259841508107, 'invalid_action_count': 0, 'num_ms1_scans': 269, 'num_ms2_scans': 1462}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 305.49858408164266
# steps	 1000 	total rewards	 664.5533094262496
# steps	 1500 	total rewards	 1032.0068900105139
# Finished after 1741 timesteps (2.2269959449768066 seconds) with total reward 1201.6657084705057
# {'coverage_prop': '0.966', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.175', 'efficiency': '0.173', 'TP': '228', 'FP': '28', 'FN': '9', 'precision': '0.891', 'recall': '0.962', 'f1': '0.925', 'total_rewards': 1201.6657084705043, 'invalid_action_count': 0, 'num_ms1_scans': 259, 'num_ms2_scans': 1482}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 300.7545535010884
# steps	 1000 	total rewards	 659.2578270367972
# steps	 1500 	total rewards	 1005.6334503762508
# Finished after 1796 timesteps (1.809417963027954 seconds) with total reward 1213.954404254716
# {'coverage_prop': '0.927', 'intensity_prop': '0.678', 'ms1ms2_ratio': '0.128', 'efficiency': '0.273', 'TP': '362', 'FP': '72', 'FN': '34', 'precision': '0.834', 'recall': '0.914', 'f1': '0.872', 'total_rewards': 1213.954404254716, 'invalid_action_count': 0, 'num_ms1_scans': 204, 'num_ms2_scans': 1592}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 308.99453526397497
# steps	 1000 	total rewards	 662.1110660441706
# steps	 1500 	total rewards	 1028.0176696081012
# Finished after 1663 timesteps (1.3965179920196533 seconds) with total reward 1122.9521237572592
# {'coverage_prop': '0.936', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.255', 'efficiency': '0.165', 'TP': '197', 'FP': '22', 'FN': '15', 'precision': '0.900', 'recall': '0.929', 'f1': '0.914', 'total_rewards': 1122.9521237572617, 'invalid_action_count': 0, 'num_ms1_scans': 338, 'num_ms2_scans': 1325}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 308.3879754174725
# steps	 1000 	total rewards	 672.5760681326597
# steps	 1500 	total rewards	 1012.375380308129
# Finished after 1740 timesteps (2.6478168964385986 seconds) with total reward 1191.3931748441105
# {'coverage_prop': '0.938', 'intensity_prop': '0.719', 'ms1ms2_ratio': '0.176', 'efficiency': '0.204', 'TP': '271', 'FP': '31', 'FN': '20', 'precision': '0.897', 'recall': '0.931', 'f1': '0.914', 'total_rewards': 1191.3931748441103, 'invalid_action_count': 0, 'num_ms1_scans': 260, 'num_ms2_scans': 1480}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 299.148397521494
# steps	 1000 	total rewards	 666.5620027229785
# steps	 1500 	total rewards	 1039.9930876068483
# Finished after 1715 timesteps (1.4362058639526367 seconds) with total reward 1191.8219705624656
# {'coverage_prop': '0.939', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.199', 'efficiency': '0.203', 'TP': '259', 'FP': '32', 'FN': '19', 'precision': '0.890', 'recall': '0.932', 'f1': '0.910', 'total_rewards': 1191.8219705624638, 'invalid_action_count': 0, 'num_ms1_scans': 285, 'num_ms2_scans': 1430}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 302.73485635572314
# steps	 1000 	total rewards	 668.8111084857219
# steps	 1500 	total rewards	 1040.9986184993481
# Finished after 1758 timesteps (1.4986398220062256 seconds) with total reward 1245.6320034841885
# {'coverage_prop': '0.971', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.160', 'efficiency': '0.221', 'TP': '289', 'FP': '46', 'FN': '10', 'precision': '0.863', 'recall': '0.967', 'f1': '0.912', 'total_rewards': 1245.6320034841879, 'invalid_action_count': 0, 'num_ms1_scans': 242, 'num_ms2_scans': 1516}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 338.1314808753842
# steps	 1000 	total rewards	 692.8872003390264
# steps	 1500 	total rewards	 1089.2472559136295
# Finished after 1783 timesteps (2.6801507472991943 seconds) with total reward 1297.413643137084
# {'coverage_prop': '0.962', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.139', 'efficiency': '0.243', 'TP': '330', 'FP': '51', 'FN': '15', 'precision': '0.866', 'recall': '0.957', 'f1': '0.909', 'total_rewards': 1297.4136431370844, 'invalid_action_count': 0, 'num_ms1_scans': 217, 'num_ms2_scans': 1566}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 276.31470517321486
# steps	 1000 	total rewards	 653.0580284391187
# steps	 1500 	total rewards	 1004.4370286318763
# Finished after 1663 timesteps (1.384964942932129 seconds) with total reward 1106.7874465956795
# {'coverage_prop': '0.961', 'intensity_prop': '0.806', 'ms1ms2_ratio': '0.254', 'efficiency': '0.147', 'TP': '188', 'FP': '7', 'FN': '8', 'precision': '0.964', 'recall': '0.959', 'f1': '0.962', 'total_rewards': 1106.7874465956788, 'invalid_action_count': 0, 'num_ms1_scans': 337, 'num_ms2_scans': 1326}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 292.21079737058085
# steps	 1000 	total rewards	 655.7275157793213
# steps	 1500 	total rewards	 1026.8772258281783
# Finished after 1719 timesteps (1.3667471408843994 seconds) with total reward 1190.3041681318139
# {'coverage_prop': '0.957', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.195', 'efficiency': '0.187', 'TP': '244', 'FP': '25', 'FN': '12', 'precision': '0.907', 'recall': '0.953', 'f1': '0.930', 'total_rewards': 1190.304168131813, 'invalid_action_count': 0, 'num_ms1_scans': 281, 'num_ms2_scans': 1438}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 320.00250761706945
# steps	 1000 	total rewards	 671.2168503392143
# steps	 1500 	total rewards	 1050.4904763219067
# Finished after 1825 timesteps (1.6750328540802002 seconds) with total reward 1294.434051173907
# {'coverage_prop': '0.929', 'intensity_prop': '0.658', 'ms1ms2_ratio': '0.107', 'efficiency': '0.278', 'TP': '365', 'FP': '93', 'FN': '35', 'precision': '0.797', 'recall': '0.912', 'f1': '0.851', 'total_rewards': 1294.4340511739083, 'invalid_action_count': 0, 'num_ms1_scans': 176, 'num_ms2_scans': 1649}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 293.263186900666
# steps	 1000 	total rewards	 675.6559314623778
# steps	 1500 	total rewards	 1046.5092218303578
# Finished after 1752 timesteps (2.868870973587036 seconds) with total reward 1226.861677970983
# {'coverage_prop': '0.954', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.165', 'efficiency': '0.193', 'TP': '260', 'FP': '30', 'FN': '14', 'precision': '0.897', 'recall': '0.949', 'f1': '0.922', 'total_rewards': 1226.8616779709812, 'invalid_action_count': 0, 'num_ms1_scans': 248, 'num_ms2_scans': 1504}
#
# method = PPO max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 357.94998696310404
# steps	 1000 	total rewards	 731.7557356530974
# steps	 1500 	total rewards	 1117.8055796676476
# Finished after 1860 timesteps (4.5522239208221436 seconds) with total reward 1385.965551779805
# {'coverage_prop': '0.946', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.081', 'efficiency': '0.234', 'TP': '349', 'FP': '54', 'FN': '23', 'precision': '0.866', 'recall': '0.938', 'f1': '0.901', 'total_rewards': 1385.9655517798037, 'invalid_action_count': 0, 'num_ms1_scans': 140, 'num_ms2_scans': 1720}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 342.03267017734714
# steps	 1000 	total rewards	 725.1346426705065
# steps	 1500 	total rewards	 1100.238634759678
# Finished after 1802 timesteps (4.283110857009888 seconds) with total reward 1336.993036069691
# {'coverage_prop': '0.958', 'intensity_prop': '0.805', 'ms1ms2_ratio': '0.123', 'efficiency': '0.156', 'TP': '236', 'FP': '15', 'FN': '11', 'precision': '0.940', 'recall': '0.955', 'f1': '0.948', 'total_rewards': 1336.993036069692, 'invalid_action_count': 0, 'num_ms1_scans': 198, 'num_ms2_scans': 1604}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 353.21002576180297
# steps	 1000 	total rewards	 737.7591797370713
# steps	 1500 	total rewards	 1134.9914213735187
# Finished after 1841 timesteps (4.443691968917847 seconds) with total reward 1408.54509692388
# {'coverage_prop': '0.954', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.095', 'efficiency': '0.224', 'TP': '323', 'FP': '53', 'FN': '18', 'precision': '0.859', 'recall': '0.947', 'f1': '0.901', 'total_rewards': 1408.5450969238798, 'invalid_action_count': 0, 'num_ms1_scans': 160, 'num_ms2_scans': 1681}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 351.62345910270955
# steps	 1000 	total rewards	 729.8131293373783
# steps	 1500 	total rewards	 1104.1256349527337
# Finished after 1857 timesteps (11.269438982009888 seconds) with total reward 1369.967668908359
# {'coverage_prop': '0.954', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.083', 'efficiency': '0.251', 'TP': '388', 'FP': '43', 'FN': '21', 'precision': '0.900', 'recall': '0.949', 'f1': '0.924', 'total_rewards': 1369.9676689083567, 'invalid_action_count': 0, 'num_ms1_scans': 143, 'num_ms2_scans': 1714}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 328.0321668797204
# steps	 1000 	total rewards	 705.5440872001652
# steps	 1500 	total rewards	 1056.1296569213291
# Finished after 1850 timesteps (4.91193699836731 seconds) with total reward 1296.876968200078
# {'coverage_prop': '0.963', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.088', 'efficiency': '0.248', 'TP': '350', 'FP': '71', 'FN': '16', 'precision': '0.831', 'recall': '0.956', 'f1': '0.889', 'total_rewards': 1296.8769682000773, 'invalid_action_count': 0, 'num_ms1_scans': 150, 'num_ms2_scans': 1700}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 340.0161292002716
# steps	 1000 	total rewards	 704.1185515442376
# steps	 1500 	total rewards	 1088.7837427041907
# Finished after 1759 timesteps (4.194318056106567 seconds) with total reward 1266.6063506043542
# {'coverage_prop': '0.955', 'intensity_prop': '0.828', 'ms1ms2_ratio': '0.159', 'efficiency': '0.126', 'TP': '182', 'FP': '9', 'FN': '9', 'precision': '0.953', 'recall': '0.953', 'f1': '0.953', 'total_rewards': 1266.6063506043545, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 342.98867092150033
# steps	 1000 	total rewards	 721.7658928955801
# steps	 1500 	total rewards	 1097.7430207552047
# Finished after 1861 timesteps (4.951741933822632 seconds) with total reward 1346.7551939712234
# {'coverage_prop': '0.935', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.081', 'efficiency': '0.260', 'TP': '370', 'FP': '77', 'FN': '31', 'precision': '0.828', 'recall': '0.923', 'f1': '0.873', 'total_rewards': 1346.7551939712225, 'invalid_action_count': 0, 'num_ms1_scans': 139, 'num_ms2_scans': 1722}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 303.82453812575585
# steps	 1000 	total rewards	 681.019419588244
# steps	 1500 	total rewards	 1072.4770011551027
# Finished after 1769 timesteps (4.041794061660767 seconds) with total reward 1270.1161351470337
# {'coverage_prop': '0.951', 'intensity_prop': '0.807', 'ms1ms2_ratio': '0.150', 'efficiency': '0.126', 'TP': '183', 'FP': '11', 'FN': '10', 'precision': '0.943', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 1270.1161351470325, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 359.4952021799283
# steps	 1000 	total rewards	 738.7874173562768
# steps	 1500 	total rewards	 1117.4140818063895
# Finished after 1870 timesteps (6.86692214012146 seconds) with total reward 1396.1094799334783
# {'coverage_prop': '0.943', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.075', 'efficiency': '0.230', 'TP': '355', 'FP': '45', 'FN': '24', 'precision': '0.887', 'recall': '0.937', 'f1': '0.911', 'total_rewards': 1396.1094799334778, 'invalid_action_count': 0, 'num_ms1_scans': 130, 'num_ms2_scans': 1740}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 342.4489274171503
# steps	 1000 	total rewards	 717.7061486381863
# steps	 1500 	total rewards	 1104.5869358555378
# Finished after 1850 timesteps (4.7815260887146 seconds) with total reward 1366.9680926372982
# {'coverage_prop': '0.964', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.088', 'efficiency': '0.218', 'TP': '326', 'FP': '44', 'FN': '14', 'precision': '0.881', 'recall': '0.959', 'f1': '0.918', 'total_rewards': 1366.968092637298, 'invalid_action_count': 0, 'num_ms1_scans': 150, 'num_ms2_scans': 1700}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 349.924050470068
# steps	 1000 	total rewards	 738.2363222890399
# steps	 1500 	total rewards	 1109.8104109151814
# Finished after 1874 timesteps (5.399712085723877 seconds) with total reward 1391.425332007509
# {'coverage_prop': '0.950', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.072', 'efficiency': '0.241', 'TP': '360', 'FP': '61', 'FN': '22', 'precision': '0.855', 'recall': '0.942', 'f1': '0.897', 'total_rewards': 1391.4253320075077, 'invalid_action_count': 0, 'num_ms1_scans': 126, 'num_ms2_scans': 1748}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 349.9098769737767
# steps	 1000 	total rewards	 714.1184169354696
# steps	 1500 	total rewards	 1084.391145773751
# Finished after 1797 timesteps (4.374846935272217 seconds) with total reward 1290.8656201206304
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.127', 'efficiency': '0.149', 'TP': '221', 'FP': '17', 'FN': '11', 'precision': '0.929', 'recall': '0.953', 'f1': '0.940', 'total_rewards': 1290.8656201206288, 'invalid_action_count': 0, 'num_ms1_scans': 203, 'num_ms2_scans': 1594}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 329.54054456666313
# steps	 1000 	total rewards	 707.7381601071544
# steps	 1500 	total rewards	 1088.4769575828504
# Finished after 1834 timesteps (4.334243059158325 seconds) with total reward 1332.1214221567052
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.100', 'efficiency': '0.143', 'TP': '212', 'FP': '26', 'FN': '13', 'precision': '0.891', 'recall': '0.942', 'f1': '0.916', 'total_rewards': 1332.121422156704, 'invalid_action_count': 0, 'num_ms1_scans': 167, 'num_ms2_scans': 1667}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 325.7703206812271
# steps	 1000 	total rewards	 695.0748453853535
# steps	 1500 	total rewards	 1055.4147659808323
# Finished after 1834 timesteps (7.818934917449951 seconds) with total reward 1226.1420100089413
# {'coverage_prop': '0.950', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.100', 'efficiency': '0.171', 'TP': '244', 'FP': '41', 'FN': '15', 'precision': '0.856', 'recall': '0.942', 'f1': '0.897', 'total_rewards': 1226.1420100089395, 'invalid_action_count': 0, 'num_ms1_scans': 166, 'num_ms2_scans': 1668}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 312.267092657934
# steps	 1000 	total rewards	 693.0107993793196
# steps	 1500 	total rewards	 1058.1331422070662
# Finished after 1791 timesteps (4.402436017990112 seconds) with total reward 1237.296534462199
# {'coverage_prop': '0.937', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.132', 'efficiency': '0.122', 'TP': '179', 'FP': '14', 'FN': '13', 'precision': '0.927', 'recall': '0.932', 'f1': '0.930', 'total_rewards': 1237.2965344622005, 'invalid_action_count': 0, 'num_ms1_scans': 209, 'num_ms2_scans': 1582}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 335.8693046432112
# steps	 1000 	total rewards	 730.30632142635
# steps	 1500 	total rewards	 1112.153628674339
# Finished after 1841 timesteps (4.938327074050903 seconds) with total reward 1393.959711666911
# {'coverage_prop': '0.968', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.095', 'efficiency': '0.234', 'TP': '350', 'FP': '44', 'FN': '13', 'precision': '0.888', 'recall': '0.964', 'f1': '0.925', 'total_rewards': 1393.959711666911, 'invalid_action_count': 0, 'num_ms1_scans': 159, 'num_ms2_scans': 1682}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 341.6926970981745
# steps	 1000 	total rewards	 734.031820147178
# steps	 1500 	total rewards	 1103.688756255799
# Finished after 1865 timesteps (5.689012050628662 seconds) with total reward 1378.3457976535376
# {'coverage_prop': '0.960', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.078', 'efficiency': '0.276', 'TP': '416', 'FP': '62', 'FN': '20', 'precision': '0.870', 'recall': '0.954', 'f1': '0.910', 'total_rewards': 1378.3457976535376, 'invalid_action_count': 0, 'num_ms1_scans': 135, 'num_ms2_scans': 1730}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 361.16883262360466
# steps	 1000 	total rewards	 730.3864479938406
# steps	 1500 	total rewards	 1107.2361462899498
# Finished after 1848 timesteps (4.957276105880737 seconds) with total reward 1365.669913040829
# {'coverage_prop': '0.938', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.090', 'efficiency': '0.206', 'TP': '306', 'FP': '43', 'FN': '23', 'precision': '0.877', 'recall': '0.930', 'f1': '0.903', 'total_rewards': 1365.6699130408288, 'invalid_action_count': 0, 'num_ms1_scans': 152, 'num_ms2_scans': 1696}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 352.71723481890467
# steps	 1000 	total rewards	 734.6970580357339
# steps	 1500 	total rewards	 1115.5050715411917
# Finished after 1825 timesteps (4.737957000732422 seconds) with total reward 1369.5695322732627
# {'coverage_prop': '0.960', 'intensity_prop': '0.782', 'ms1ms2_ratio': '0.106', 'efficiency': '0.176', 'TP': '264', 'FP': '26', 'FN': '12', 'precision': '0.910', 'recall': '0.957', 'f1': '0.933', 'total_rewards': 1369.5695322732654, 'invalid_action_count': 0, 'num_ms1_scans': 175, 'num_ms2_scans': 1650}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 341.4948596196173
# steps	 1000 	total rewards	 714.6046716753733
# steps	 1500 	total rewards	 1102.452500537323
# Finished after 1831 timesteps (13.190685987472534 seconds) with total reward 1352.6722088037573
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.102', 'efficiency': '0.155', 'TP': '233', 'FP': '25', 'FN': '7', 'precision': '0.903', 'recall': '0.971', 'f1': '0.936', 'total_rewards': 1352.672208803758, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1662}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 326.50628294646936
# steps	 1000 	total rewards	 699.2646807341471
# steps	 1500 	total rewards	 1052.8908402451925
# Finished after 1863 timesteps (6.061089038848877 seconds) with total reward 1311.9046726237693
# {'coverage_prop': '0.932', 'intensity_prop': '0.695', 'ms1ms2_ratio': '0.079', 'efficiency': '0.253', 'TP': '369', 'FP': '67', 'FN': '32', 'precision': '0.846', 'recall': '0.920', 'f1': '0.882', 'total_rewards': 1311.9046726237698, 'invalid_action_count': 0, 'num_ms1_scans': 137, 'num_ms2_scans': 1726}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 359.61043708011886
# steps	 1000 	total rewards	 741.8164134255524
# steps	 1500 	total rewards	 1135.3655207533957
# Finished after 1781 timesteps (4.369066953659058 seconds) with total reward 1327.4485182638887
# {'coverage_prop': '0.953', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.140', 'efficiency': '0.143', 'TP': '202', 'FP': '21', 'FN': '11', 'precision': '0.906', 'recall': '0.948', 'f1': '0.927', 'total_rewards': 1327.4485182638884, 'invalid_action_count': 0, 'num_ms1_scans': 219, 'num_ms2_scans': 1562}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 347.1842931219179
# steps	 1000 	total rewards	 734.4965153531314
# steps	 1500 	total rewards	 1091.8138566524594
# Finished after 1835 timesteps (4.6890480518341064 seconds) with total reward 1351.394573934434
# {'coverage_prop': '0.950', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.099', 'efficiency': '0.183', 'TP': '276', 'FP': '30', 'FN': '16', 'precision': '0.902', 'recall': '0.945', 'f1': '0.923', 'total_rewards': 1351.3945739344347, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 338.59482738330803
# steps	 1000 	total rewards	 715.6826619829108
# steps	 1500 	total rewards	 1114.4800067496608
# Finished after 1808 timesteps (4.765304088592529 seconds) with total reward 1342.1285211361628
# {'coverage_prop': '0.945', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.119', 'efficiency': '0.181', 'TP': '269', 'FP': '24', 'FN': '17', 'precision': '0.918', 'recall': '0.941', 'f1': '0.929', 'total_rewards': 1342.1285211361646, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1616}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 336.4616729149619
# steps	 1000 	total rewards	 723.8018245898018
# steps	 1500 	total rewards	 1101.2217261706166
# Finished after 1837 timesteps (4.855133056640625 seconds) with total reward 1380.004141130476
# {'coverage_prop': '0.977', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.097', 'efficiency': '0.201', 'TP': '297', 'FP': '40', 'FN': '8', 'precision': '0.881', 'recall': '0.974', 'f1': '0.925', 'total_rewards': 1380.0041411304767, 'invalid_action_count': 0, 'num_ms1_scans': 163, 'num_ms2_scans': 1674}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 368.5275286409691
# steps	 1000 	total rewards	 747.0707707364312
# steps	 1500 	total rewards	 1148.4056048842237
# Finished after 1860 timesteps (8.983378887176514 seconds) with total reward 1427.9422536593
# {'coverage_prop': '0.962', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.081', 'efficiency': '0.222', 'TP': '338', 'FP': '43', 'FN': '15', 'precision': '0.887', 'recall': '0.958', 'f1': '0.921', 'total_rewards': 1427.9422536593004, 'invalid_action_count': 0, 'num_ms1_scans': 140, 'num_ms2_scans': 1720}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 298.5033395478228
# steps	 1000 	total rewards	 701.8431360503439
# steps	 1500 	total rewards	 1087.9267153562855
# Finished after 1777 timesteps (4.343549966812134 seconds) with total reward 1282.377028671343
# {'coverage_prop': '0.966', 'intensity_prop': '0.829', 'ms1ms2_ratio': '0.144', 'efficiency': '0.126', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962', 'total_rewards': 1282.3770286713445, 'invalid_action_count': 0, 'num_ms1_scans': 223, 'num_ms2_scans': 1554}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 327.4976918383885
# steps	 1000 	total rewards	 704.1911722508637
# steps	 1500 	total rewards	 1091.247694950062
# Finished after 1806 timesteps (4.603643178939819 seconds) with total reward 1332.9181347443782
# {'coverage_prop': '0.957', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.120', 'efficiency': '0.167', 'TP': '250', 'FP': '19', 'FN': '12', 'precision': '0.929', 'recall': '0.954', 'f1': '0.942', 'total_rewards': 1332.9181347443764, 'invalid_action_count': 0, 'num_ms1_scans': 194, 'num_ms2_scans': 1612}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 339.15365282989956
# steps	 1000 	total rewards	 692.4553315553128
# steps	 1500 	total rewards	 1081.6068746633764
# Finished after 1878 timesteps (5.52016806602478 seconds) with total reward 1380.4684305766596
# {'coverage_prop': '0.917', 'intensity_prop': '0.667', 'ms1ms2_ratio': '0.069', 'efficiency': '0.257', 'TP': '377', 'FP': '75', 'FN': '41', 'precision': '0.834', 'recall': '0.902', 'f1': '0.867', 'total_rewards': 1380.4684305766598, 'invalid_action_count': 0, 'num_ms1_scans': 122, 'num_ms2_scans': 1756}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 312.93864828050073
# steps	 1000 	total rewards	 714.6493818697195
# steps	 1500 	total rewards	 1095.8691666677537
# Finished after 1828 timesteps (4.633883953094482 seconds) with total reward 1342.3558431571657
# {'coverage_prop': '0.957', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.104', 'efficiency': '0.176', 'TP': '268', 'FP': '23', 'FN': '13', 'precision': '0.921', 'recall': '0.954', 'f1': '0.937', 'total_rewards': 1342.3558431571632, 'invalid_action_count': 0, 'num_ms1_scans': 172, 'num_ms2_scans': 1656}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 284.35173691799935
# steps	 1000 	total rewards	 645.0465058244614
# steps	 1500 	total rewards	 1017.7748091847278
# Finished after 1722 timesteps (9.882372856140137 seconds) with total reward 1167.8359689934637
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 1167.8359689934623, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 237.23177572896248
# steps	 1000 	total rewards	 554.4430604815191
# steps	 1500 	total rewards	 887.0536667084407
# Finished after 1556 timesteps (10.914258003234863 seconds) with total reward 919.7290877477645
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 919.7290877477635, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 244.24078937805592
# steps	 1000 	total rewards	 617.4522393548262
# steps	 1500 	total rewards	 1002.6498139883214
# Finished after 1669 timesteps (9.23441195487976 seconds) with total reward 1130.9657429482975
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 1130.965742948297, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 306.9619922016653
# steps	 1000 	total rewards	 652.1697495515991
# steps	 1500 	total rewards	 1007.0544717885612
# Finished after 1717 timesteps (9.904551982879639 seconds) with total reward 1160.844542375401
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 1160.8445423754026, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 261.249548510777
# steps	 1000 	total rewards	 611.6011930731654
# steps	 1500 	total rewards	 947.4884069170549
# Finished after 1704 timesteps (9.682161092758179 seconds) with total reward 1083.5255881611301
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 1083.5255881611292, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 181.55898885283494
# steps	 1000 	total rewards	 488.21694418597497
# Finished after 1408 timesteps (7.300083160400391 seconds) with total reward 675.4596211493204
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 675.4596211493198, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 298.5223816529141
# steps	 1000 	total rewards	 661.1546720814175
# steps	 1500 	total rewards	 1022.0568069477519
# Finished after 1744 timesteps (13.209969997406006 seconds) with total reward 1184.7307706257739
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 1184.7307706257727, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 168.78647892758428
# steps	 1000 	total rewards	 524.8551903087605
# Finished after 1468 timesteps (7.9493958950042725 seconds) with total reward 775.5140457988746
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 775.5140457988745, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 304.21794044279426
# steps	 1000 	total rewards	 659.5970891692505
# steps	 1500 	total rewards	 1012.5872292293436
# Finished after 1736 timesteps (10.605527639389038 seconds) with total reward 1183.145173544725
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 1183.1451735447267, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 247.49521883514583
# steps	 1000 	total rewards	 607.4419966049937
# steps	 1500 	total rewards	 969.8849337641245
# Finished after 1667 timesteps (11.037053108215332 seconds) with total reward 1084.5556389681337
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 1084.5556389681337, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 292.7753260621716
# steps	 1000 	total rewards	 668.7999811580942
# steps	 1500 	total rewards	 1024.0869025194186
# Finished after 1737 timesteps (9.807129859924316 seconds) with total reward 1198.1318259640402
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 1198.1318259640384, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 222.00399078124747
# steps	 1000 	total rewards	 560.5403282265054
# steps	 1500 	total rewards	 842.2491749333565
# Finished after 1530 timesteps (10.242871761322021 seconds) with total reward 856.8756710129564
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 856.8756710129577, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 225.54324442126702
# steps	 1000 	total rewards	 588.9601538388687
# steps	 1500 	total rewards	 916.148580035796
# Finished after 1602 timesteps (9.539650917053223 seconds) with total reward 971.6859057789334
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 971.6859057789343, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 240.09095914198977
# steps	 1000 	total rewards	 562.4815276754034
# steps	 1500 	total rewards	 875.4723165540549
# Finished after 1645 timesteps (9.018710136413574 seconds) with total reward 933.6353965902404
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 933.6353965902405, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 180.46419340656627
# steps	 1000 	total rewards	 536.1571167178973
# Finished after 1497 timesteps (7.491068124771118 seconds) with total reward 786.9988868412757
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 786.9988868412732, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 251.55663538505877
# steps	 1000 	total rewards	 615.6396629606827
# steps	 1500 	total rewards	 974.5454548686362
# Finished after 1655 timesteps (8.971014022827148 seconds) with total reward 1087.9559089845159
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 1087.9559089845152, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 287.5206485721802
# steps	 1000 	total rewards	 665.2471719741759
# steps	 1500 	total rewards	 1021.0528483926507
# Finished after 1729 timesteps (9.950062036514282 seconds) with total reward 1176.4516615432574
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 1176.4516615432585, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 278.86972648431293
# steps	 1000 	total rewards	 625.1561113533623
# steps	 1500 	total rewards	 978.1322409428257
# Finished after 1681 timesteps (8.931807041168213 seconds) with total reward 1091.4919579542598
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 1091.4919579542595, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 238.30635185984642
# steps	 1000 	total rewards	 591.8145618998964
# steps	 1500 	total rewards	 953.4216600906755
# Finished after 1621 timesteps (11.175487041473389 seconds) with total reward 1030.2315868383607
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 1030.231586838361, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 238.4005364962573
# steps	 1000 	total rewards	 597.8233186640654
# steps	 1500 	total rewards	 953.5207470575947
# Finished after 1634 timesteps (8.563313245773315 seconds) with total reward 1034.3859718888573
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 1034.3859718888577, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 275.67253901008155
# steps	 1000 	total rewards	 626.5444608980383
# steps	 1500 	total rewards	 967.4884599462245
# Finished after 1726 timesteps (9.904961109161377 seconds) with total reward 1128.7272082279674
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 1128.7272082279674, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 210.2548042496294
# steps	 1000 	total rewards	 556.8896863651553
# Finished after 1475 timesteps (10.152196884155273 seconds) with total reward 810.9407019987381
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 810.9407019987378, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 256.94883769352884
# steps	 1000 	total rewards	 610.6369915873785
# steps	 1500 	total rewards	 942.895199988627
# Finished after 1636 timesteps (8.748976230621338 seconds) with total reward 1027.6535572533487
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 1027.6535572533496, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 244.62591100582003
# steps	 1000 	total rewards	 599.5558570764224
# steps	 1500 	total rewards	 919.9956894688482
# Finished after 1575 timesteps (8.0904860496521 seconds) with total reward 954.7338496430982
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 954.7338496430997, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 237.8887722185019
# steps	 1000 	total rewards	 616.6015235706046
# steps	 1500 	total rewards	 980.0892895227569
# Finished after 1681 timesteps (8.743750810623169 seconds) with total reward 1119.2223628982943
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 1119.2223628982927, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 276.91120206653784
# steps	 1000 	total rewards	 622.5257442469413
# steps	 1500 	total rewards	 995.6646249836303
# Finished after 1679 timesteps (11.744752168655396 seconds) with total reward 1120.8174992408335
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 1120.8174992408346, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 190.14313877653316
# steps	 1000 	total rewards	 538.70617894609
# Finished after 1465 timesteps (7.555928945541382 seconds) with total reward 776.5190812277863
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 776.5190812277863, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 223.31819234438282
# steps	 1000 	total rewards	 566.98295970209
# steps	 1500 	total rewards	 888.3998333709135
# Finished after 1564 timesteps (8.08863115310669 seconds) with total reward 934.3745516976121
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 934.3745516976134, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 292.6601015558965
# steps	 1000 	total rewards	 632.6790823122867
# steps	 1500 	total rewards	 1009.5342874587811
# Finished after 1749 timesteps (9.978318691253662 seconds) with total reward 1198.4812643312716
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 1198.481264331275, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 252.30825969034052
# steps	 1000 	total rewards	 610.4416693816453
# steps	 1500 	total rewards	 976.196180535155
# Finished after 1657 timesteps (11.631736755371094 seconds) with total reward 1076.6770424990284
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 1076.6770424990277, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f9244239510>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f923256a560>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f92325bbf40>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.795', 'efficiency': '0.539', 'TP': '359', 'FP': '57', 'FN': '10', 'precision': '0.863', 'recall': '0.973', 'f1': '0.915'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.715', 'ms1ms2_ratio': '0.789', 'efficiency': '0.558', 'TP': '367', 'FP': '66', 'FN': '4', 'precision': '0.848', 'recall': '0.989', 'f1': '0.913'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.722', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '171', 'FP': '20', 'FN': '9', 'precision': '0.895', 'recall': '0.950', 'f1': '0.922'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.676', 'efficiency': '0.540', 'TP': '399', 'FP': '60', 'FN': '19', 'precision': '0.869', 'recall': '0.955', 'f1': '0.910'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.718', 'ms1ms2_ratio': '2.080', 'efficiency': '0.505', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.822', 'efficiency': '0.534', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.685', 'efficiency': '0.507', 'TP': '385', 'FP': '43', 'FN': '15', 'precision': '0.900', 'recall': '0.963', 'f1': '0.930'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.667', 'ms1ms2_ratio': '1.612', 'efficiency': '0.502', 'TP': '197', 'FP': '41', 'FN': '13', 'precision': '0.828', 'recall': '0.938', 'f1': '0.879'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.687', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '234', 'FP': '56', 'FN': '10', 'precision': '0.807', 'recall': '0.959', 'f1': '0.876'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.700', 'ms1ms2_ratio': '1.970', 'efficiency': '0.486', 'TP': '175', 'FP': '22', 'FN': '9', 'precision': '0.888', 'recall': '0.951', 'f1': '0.919'}
#
# Episode 15 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.732', 'ms1ms2_ratio': '0.850', 'efficiency': '0.536', 'TP': '355', 'FP': '42', 'FN': '10', 'precision': '0.894', 'recall': '0.973', 'f1': '0.932'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '428', 'FP': '59', 'FN': '11', 'precision': '0.879', 'recall': '0.975', 'f1': '0.924'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.701', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '310', 'FP': '50', 'FN': '12', 'precision': '0.861', 'recall': '0.963', 'f1': '0.909'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.715', 'ms1ms2_ratio': '1.242', 'efficiency': '0.509', 'TP': '254', 'FP': '38', 'FN': '10', 'precision': '0.870', 'recall': '0.962', 'f1': '0.914'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.473', 'efficiency': '0.513', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.692', 'efficiency': '0.535', 'TP': '390', 'FP': '59', 'FN': '19', 'precision': '0.869', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.702', 'ms1ms2_ratio': '1.252', 'efficiency': '0.518', 'TP': '249', 'FP': '47', 'FN': '14', 'precision': '0.841', 'recall': '0.947', 'f1': '0.891'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.721', 'ms1ms2_ratio': '0.975', 'efficiency': '0.500', 'TP': '294', 'FP': '45', 'FN': '6', 'precision': '0.867', 'recall': '0.980', 'f1': '0.920'}
#
# Episode 25 finished
# {'coverage_prop': '0.990', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.859', 'efficiency': '0.533', 'TP': '337', 'FP': '55', 'FN': '4', 'precision': '0.860', 'recall': '0.988', 'f1': '0.920'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.377', 'efficiency': '0.510', 'TP': '241', 'FP': '31', 'FN': '9', 'precision': '0.886', 'recall': '0.964', 'f1': '0.923'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.589', 'efficiency': '0.522', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '269', 'FP': '26', 'FN': '9', 'precision': '0.912', 'recall': '0.968', 'f1': '0.939'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    1273.528517                   0.0          0.939           0.695
# 1  random    1182.467582                   0.0          0.950           0.767
# 2  random    1284.384161                   0.0          0.931           0.690
# 3  random    1267.825336                   0.0          0.940           0.715
# 4  random    1190.944937                   0.0          0.950           0.697
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.134       0.253      0.843   0.928  0.883
# 1          0.200       0.174      0.904   0.945  0.924
# 2          0.154       0.240      0.847   0.920  0.882
# 3          0.130       0.268      0.864   0.931  0.896
# 4          0.139       0.265      0.814   0.939  0.872

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    PPO    1385.965552                   0.0          0.946           0.723
# 31    PPO    1336.993036                   0.0          0.958           0.805
# 32    PPO    1408.545097                   0.0          0.954           0.727
# 33    PPO    1369.967669                   0.0          0.954           0.743
# 34    PPO    1296.876968                   0.0          0.963           0.715
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.081       0.234      0.866   0.938  0.901
# 31          0.123       0.156      0.940   0.955  0.948
# 32          0.095       0.224      0.859   0.947  0.901
# 33          0.083       0.251      0.900   0.949  0.924
# 34          0.088       0.248      0.831   0.956  0.889

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
