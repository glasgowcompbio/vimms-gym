# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.50
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-02-10 12:02:16.203 | INFO     | experiments:get_samplers:249 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fad49128af0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fad33bd5670>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fad28cca910>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.5,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = 'DQN'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fad49128af0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fad33bd5670>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fad28cca910>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fad49128af0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fad33bd5670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fad28cca910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
horizon = 8
out_dir = 'evaluation_2.0E7_horizon_%d' % horizon

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        model_dir = os.path.join(in_dir)
        fname = os.path.join('DQN_2.0E7', '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -382.04658074123915
# steps	 1000 	total rewards	 -634.796259166266
# steps	 1500 	total rewards	 -922.471409947428
# Finished after 1992 timesteps (4.734724044799805 seconds) with total reward -1124.752379423819
# {'coverage_prop': '0.697', 'intensity_prop': '0.214', 'ms1ms2_ratio': '0.004', 'efficiency': '0.150', 'TP': '84', 'FP': '213', 'FN': '129', 'precision': '0.283', 'recall': '0.394', 'f1': '0.329', 'total_rewards': -1124.7523794238186, 'invalid_action_count': 1264, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -360.25563576318933
# steps	 1000 	total rewards	 -616.452665358202
# steps	 1500 	total rewards	 -920.604666784691
# Finished after 1984 timesteps (3.276738166809082 seconds) with total reward -1174.8061576789314
# {'coverage_prop': '0.740', 'intensity_prop': '0.206', 'ms1ms2_ratio': '0.008', 'efficiency': '0.099', 'TP': '46', 'FP': '148', 'FN': '68', 'precision': '0.237', 'recall': '0.404', 'f1': '0.299', 'total_rewards': -1174.80615767893, 'invalid_action_count': 1278, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -446.37614515363
# steps	 1000 	total rewards	 -769.0114356141473
# steps	 1500 	total rewards	 -1089.4592025407733
# Finished after 1993 timesteps (4.059150695800781 seconds) with total reward -1282.7133400412115
# {'coverage_prop': '0.660', 'intensity_prop': '0.166', 'ms1ms2_ratio': '0.004', 'efficiency': '0.131', 'TP': '56', 'FP': '204', 'FN': '134', 'precision': '0.215', 'recall': '0.295', 'f1': '0.249', 'total_rewards': -1282.7133400412117, 'invalid_action_count': 1396, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -390.2741918140413
# steps	 1000 	total rewards	 -681.9338243240996
# steps	 1500 	total rewards	 -978.9009321180234
# Finished after 1991 timesteps (4.544214725494385 seconds) with total reward -1159.8669201947105
# {'coverage_prop': '0.710', 'intensity_prop': '0.213', 'ms1ms2_ratio': '0.005', 'efficiency': '0.162', 'TP': '92', 'FP': '229', 'FN': '131', 'precision': '0.287', 'recall': '0.413', 'f1': '0.338', 'total_rewards': -1159.8669201947102, 'invalid_action_count': 1299, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -339.2401166448259
# steps	 1000 	total rewards	 -562.3346332746248
# steps	 1500 	total rewards	 -942.1235843313277
# Finished after 1991 timesteps (5.184934854507446 seconds) with total reward -1219.118323676677
# {'coverage_prop': '0.709', 'intensity_prop': '0.203', 'ms1ms2_ratio': '0.005', 'efficiency': '0.156', 'TP': '76', 'FP': '234', 'FN': '127', 'precision': '0.245', 'recall': '0.374', 'f1': '0.296', 'total_rewards': -1219.1183236766772, 'invalid_action_count': 1353, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -420.5583497742949
# steps	 1000 	total rewards	 -755.0091252142194
# steps	 1500 	total rewards	 -1032.687995684714
# Finished after 1989 timesteps (2.9379770755767822 seconds) with total reward -1382.06500147914
# {'coverage_prop': '0.690', 'intensity_prop': '0.220', 'ms1ms2_ratio': '0.006', 'efficiency': '0.070', 'TP': '45', 'FP': '93', 'FN': '62', 'precision': '0.326', 'recall': '0.421', 'f1': '0.367', 'total_rewards': -1382.0650014791404, 'invalid_action_count': 1453, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -335.45081768183815
# steps	 1000 	total rewards	 -607.5701829574534
# steps	 1500 	total rewards	 -735.5616428303206
# Finished after 1989 timesteps (4.786726951599121 seconds) with total reward -944.0848435337056
# {'coverage_prop': '0.747', 'intensity_prop': '0.270', 'ms1ms2_ratio': '0.006', 'efficiency': '0.180', 'TP': '125', 'FP': '232', 'FN': '121', 'precision': '0.350', 'recall': '0.508', 'f1': '0.415', 'total_rewards': -944.0848435337065, 'invalid_action_count': 1115, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -381.0795932886001
# steps	 1000 	total rewards	 -705.7337831869529
# steps	 1500 	total rewards	 -1071.8836574641991
# Finished after 1988 timesteps (3.174926996231079 seconds) with total reward -1324.7806559964097
# {'coverage_prop': '0.686', 'intensity_prop': '0.189', 'ms1ms2_ratio': '0.006', 'efficiency': '0.071', 'TP': '35', 'FP': '105', 'FN': '64', 'precision': '0.250', 'recall': '0.354', 'f1': '0.293', 'total_rewards': -1324.7806559964115, 'invalid_action_count': 1397, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -416.34809753806803
# steps	 1000 	total rewards	 -632.7109853610528
# steps	 1500 	total rewards	 -853.3125146917182
# Finished after 1993 timesteps (4.588243007659912 seconds) with total reward -1201.9599122780414
# {'coverage_prop': '0.672', 'intensity_prop': '0.177', 'ms1ms2_ratio': '0.004', 'efficiency': '0.144', 'TP': '68', 'FP': '217', 'FN': '139', 'precision': '0.239', 'recall': '0.329', 'f1': '0.276', 'total_rewards': -1201.9599122780414, 'invalid_action_count': 1332, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -331.0353196106994
# steps	 1000 	total rewards	 -602.469427333481
# steps	 1500 	total rewards	 -764.4845095518997
# Finished after 1987 timesteps (4.117950916290283 seconds) with total reward -992.6808250385959
# {'coverage_prop': '0.792', 'intensity_prop': '0.291', 'ms1ms2_ratio': '0.007', 'efficiency': '0.154', 'TP': '110', 'FP': '194', 'FN': '80', 'precision': '0.362', 'recall': '0.579', 'f1': '0.445', 'total_rewards': -992.6808250385943, 'invalid_action_count': 1143, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -377.45200102610823
# steps	 1000 	total rewards	 -567.207157709326
# steps	 1500 	total rewards	 -683.522505288597
# Finished after 1985 timesteps (4.809020042419434 seconds) with total reward -895.1226040598241
# {'coverage_prop': '0.788', 'intensity_prop': '0.270', 'ms1ms2_ratio': '0.008', 'efficiency': '0.177', 'TP': '121', 'FP': '228', 'FN': '94', 'precision': '0.347', 'recall': '0.563', 'f1': '0.429', 'total_rewards': -895.122604059825, 'invalid_action_count': 1066, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -453.5699111355125
# steps	 1000 	total rewards	 -793.4326977298144
# steps	 1500 	total rewards	 -1053.0550138950298
# Finished after 1992 timesteps (3.646920919418335 seconds) with total reward -1354.228815681407
# {'coverage_prop': '0.631', 'intensity_prop': '0.190', 'ms1ms2_ratio': '0.004', 'efficiency': '0.079', 'TP': '48', 'FP': '109', 'FN': '92', 'precision': '0.306', 'recall': '0.343', 'f1': '0.323', 'total_rewards': -1354.2288156814068, 'invalid_action_count': 1428, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -351.5145794979637
# steps	 1000 	total rewards	 -728.1070195198847
# steps	 1500 	total rewards	 -1089.8509285656196
# Finished after 1991 timesteps (3.306919813156128 seconds) with total reward -1403.3282691238567
# {'coverage_prop': '0.657', 'intensity_prop': '0.152', 'ms1ms2_ratio': '0.005', 'efficiency': '0.083', 'TP': '33', 'FP': '132', 'FN': '86', 'precision': '0.200', 'recall': '0.277', 'f1': '0.232', 'total_rewards': -1403.3282691238585, 'invalid_action_count': 1484, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -454.0
# steps	 1000 	total rewards	 -770.6020745220063
# steps	 1500 	total rewards	 -1003.8718137396073
# Finished after 1992 timesteps (3.935059070587158 seconds) with total reward -1255.6292677193899
# {'coverage_prop': '0.743', 'intensity_prop': '0.248', 'ms1ms2_ratio': '0.004', 'efficiency': '0.112', 'TP': '79', 'FP': '144', 'FN': '77', 'precision': '0.354', 'recall': '0.506', 'f1': '0.417', 'total_rewards': -1255.6292677193896, 'invalid_action_count': 1362, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -446.3981913085197
# steps	 1000 	total rewards	 -796.9250207077267
# steps	 1500 	total rewards	 -1105.3064289506178
# Finished after 1990 timesteps (2.7858870029449463 seconds) with total reward -1400.6573932217098
# {'coverage_prop': '0.704', 'intensity_prop': '0.177', 'ms1ms2_ratio': '0.005', 'efficiency': '0.073', 'TP': '35', 'FP': '110', 'FN': '61', 'precision': '0.241', 'recall': '0.365', 'f1': '0.290', 'total_rewards': -1400.6573932217107, 'invalid_action_count': 1477, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -400.75489853180875
# steps	 1000 	total rewards	 -865.0724614273797
# steps	 1500 	total rewards	 -1047.7473147148587
# Finished after 1991 timesteps (4.237776041030884 seconds) with total reward -1202.3787312215957
# {'coverage_prop': '0.686', 'intensity_prop': '0.223', 'ms1ms2_ratio': '0.005', 'efficiency': '0.141', 'TP': '92', 'FP': '187', 'FN': '128', 'precision': '0.330', 'recall': '0.418', 'f1': '0.369', 'total_rewards': -1202.3787312215984, 'invalid_action_count': 1330, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -387.0768062229225
# steps	 1000 	total rewards	 -713.1440073620325
# steps	 1500 	total rewards	 -995.4563061104528
# Finished after 1993 timesteps (6.715970039367676 seconds) with total reward -1286.950224283706
# {'coverage_prop': '0.635', 'intensity_prop': '0.191', 'ms1ms2_ratio': '0.004', 'efficiency': '0.159', 'TP': '95', 'FP': '221', 'FN': '182', 'precision': '0.301', 'recall': '0.343', 'f1': '0.320', 'total_rewards': -1286.9502242837066, 'invalid_action_count': 1417, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -441.71208260642163
# steps	 1000 	total rewards	 -791.4581144765993
# steps	 1500 	total rewards	 -971.380738125994
# Finished after 1991 timesteps (3.8995907306671143 seconds) with total reward -1193.9911199775222
# {'coverage_prop': '0.699', 'intensity_prop': '0.201', 'ms1ms2_ratio': '0.005', 'efficiency': '0.131', 'TP': '72', 'FP': '188', 'FN': '112', 'precision': '0.277', 'recall': '0.391', 'f1': '0.324', 'total_rewards': -1193.9911199775224, 'invalid_action_count': 1316, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -352.57935233974075
# steps	 1000 	total rewards	 -812.5823256989806
# steps	 1500 	total rewards	 -1093.9010884920312
# Finished after 1994 timesteps (3.56048583984375 seconds) with total reward -1473.562756077178
# {'coverage_prop': '0.563', 'intensity_prop': '0.138', 'ms1ms2_ratio': '0.003', 'efficiency': '0.086', 'TP': '34', 'FP': '136', 'FN': '132', 'precision': '0.200', 'recall': '0.205', 'f1': '0.202', 'total_rewards': -1473.562756077179, 'invalid_action_count': 1552, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -409.1482839289167
# steps	 1000 	total rewards	 -750.3039314612615
# steps	 1500 	total rewards	 -1155.790886489382
# Finished after 1994 timesteps (3.000657081604004 seconds) with total reward -1404.4872162936017
# {'coverage_prop': '0.645', 'intensity_prop': '0.171', 'ms1ms2_ratio': '0.003', 'efficiency': '0.086', 'TP': '43', 'FP': '128', 'FN': '94', 'precision': '0.251', 'recall': '0.314', 'f1': '0.279', 'total_rewards': -1404.4872162936024, 'invalid_action_count': 1489, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -350.06089351792843
# steps	 1000 	total rewards	 -632.600262563816
# steps	 1500 	total rewards	 -819.5349203194598
# Finished after 1989 timesteps (4.231888771057129 seconds) with total reward -1032.1914952626591
# {'coverage_prop': '0.712', 'intensity_prop': '0.213', 'ms1ms2_ratio': '0.006', 'efficiency': '0.168', 'TP': '95', 'FP': '238', 'FN': '135', 'precision': '0.285', 'recall': '0.413', 'f1': '0.337', 'total_rewards': -1032.1914952626598, 'invalid_action_count': 1185, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -365.30230606269765
# steps	 1000 	total rewards	 -708.5988539505256
# steps	 1500 	total rewards	 -998.8516023916127
# Finished after 1988 timesteps (2.6494362354278564 seconds) with total reward -1330.242543844531
# {'coverage_prop': '0.739', 'intensity_prop': '0.214', 'ms1ms2_ratio': '0.006', 'efficiency': '0.088', 'TP': '45', 'FP': '128', 'FN': '61', 'precision': '0.260', 'recall': '0.425', 'f1': '0.323', 'total_rewards': -1330.2425438445312, 'invalid_action_count': 1418, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -346.9022919967935
# steps	 1000 	total rewards	 -631.8675320830191
# steps	 1500 	total rewards	 -1102.1475569085662
# Finished after 1990 timesteps (3.185338020324707 seconds) with total reward -1390.7564874620416
# {'coverage_prop': '0.571', 'intensity_prop': '0.131', 'ms1ms2_ratio': '0.005', 'efficiency': '0.093', 'TP': '34', 'FP': '150', 'FN': '138', 'precision': '0.185', 'recall': '0.198', 'f1': '0.191', 'total_rewards': -1390.756487462042, 'invalid_action_count': 1477, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -368.90941140686095
# steps	 1000 	total rewards	 -686.5904897738703
# steps	 1500 	total rewards	 -906.5435337183807
# Finished after 1990 timesteps (3.2430450916290283 seconds) with total reward -1263.6513308066255
# {'coverage_prop': '0.687', 'intensity_prop': '0.219', 'ms1ms2_ratio': '0.005', 'efficiency': '0.108', 'TP': '71', 'FP': '142', 'FN': '97', 'precision': '0.333', 'recall': '0.423', 'f1': '0.373', 'total_rewards': -1263.651330806623, 'invalid_action_count': 1366, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -362.4031513249971
# steps	 1000 	total rewards	 -574.7646255029572
# steps	 1500 	total rewards	 -751.3342127224196
# Finished after 1987 timesteps (3.9267539978027344 seconds) with total reward -1181.9429752752505
# {'coverage_prop': '0.704', 'intensity_prop': '0.223', 'ms1ms2_ratio': '0.007', 'efficiency': '0.123', 'TP': '70', 'FP': '173', 'FN': '102', 'precision': '0.288', 'recall': '0.407', 'f1': '0.337', 'total_rewards': -1181.94297527525, 'invalid_action_count': 1303, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -406.42167933964294
# steps	 1000 	total rewards	 -777.4424790580159
# steps	 1500 	total rewards	 -1015.7433019475188
# Finished after 1991 timesteps (3.562424898147583 seconds) with total reward -1299.8164360689125
# {'coverage_prop': '0.699', 'intensity_prop': '0.214', 'ms1ms2_ratio': '0.005', 'efficiency': '0.140', 'TP': '84', 'FP': '193', 'FN': '119', 'precision': '0.303', 'recall': '0.414', 'f1': '0.350', 'total_rewards': -1299.8164360689116, 'invalid_action_count': 1422, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -418.05152422164065
# steps	 1000 	total rewards	 -911.5509494403168
# steps	 1500 	total rewards	 -1290.885979293308
# Finished after 1996 timesteps (2.399172067642212 seconds) with total reward -1673.808142139122
# {'coverage_prop': '0.498', 'intensity_prop': '0.104', 'ms1ms2_ratio': '0.002', 'efficiency': '0.051', 'TP': '19', 'FP': '82', 'FN': '102', 'precision': '0.188', 'recall': '0.157', 'f1': '0.171', 'total_rewards': -1673.8081421391223, 'invalid_action_count': 1720, 'num_ms1_scans': 4, 'num_ms2_scans': 1992}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -355.5319416455596
# steps	 1000 	total rewards	 -764.8979969321246
# steps	 1500 	total rewards	 -1076.9586697087625
# Finished after 1992 timesteps (2.9541001319885254 seconds) with total reward -1390.3369239719316
# {'coverage_prop': '0.669', 'intensity_prop': '0.138', 'ms1ms2_ratio': '0.004', 'efficiency': '0.095', 'TP': '34', 'FP': '154', 'FN': '93', 'precision': '0.181', 'recall': '0.268', 'f1': '0.216', 'total_rewards': -1390.3369239719318, 'invalid_action_count': 1484, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -440.52585421857316
# steps	 1000 	total rewards	 -592.2097510058137
# steps	 1500 	total rewards	 -698.4921230676592
# Finished after 1986 timesteps (4.750610113143921 seconds) with total reward -969.1887349579384
# {'coverage_prop': '0.700', 'intensity_prop': '0.240', 'ms1ms2_ratio': '0.007', 'efficiency': '0.175', 'TP': '116', 'FP': '229', 'FN': '148', 'precision': '0.336', 'recall': '0.439', 'f1': '0.381', 'total_rewards': -969.1887349579374, 'invalid_action_count': 1133, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -410.96372382647814
# steps	 1000 	total rewards	 -760.5534010083891
# steps	 1500 	total rewards	 -1066.555642622788
# Finished after 1991 timesteps (3.747365951538086 seconds) with total reward -1348.4217089644806
# {'coverage_prop': '0.681', 'intensity_prop': '0.186', 'ms1ms2_ratio': '0.005', 'efficiency': '0.104', 'TP': '51', 'FP': '156', 'FN': '97', 'precision': '0.246', 'recall': '0.345', 'f1': '0.287', 'total_rewards': -1348.4217089644824, 'invalid_action_count': 1446, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 17.99GB > 0.32GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 88.7453065482265
# steps	 1000 	total rewards	 199.9008539663419
# steps	 1500 	total rewards	 283.7292760596788
# Finished after 1618 timesteps (8.336085081100464 seconds) with total reward 301.01682811547755
# {'coverage_prop': '0.948', 'intensity_prop': '0.565', 'ms1ms2_ratio': '0.309', 'efficiency': '0.327', 'TP': '258', 'FP': '146', 'FN': '22', 'precision': '0.639', 'recall': '0.921', 'f1': '0.754', 'total_rewards': 301.01682811547784, 'invalid_action_count': 10, 'num_ms1_scans': 382, 'num_ms2_scans': 1236}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 82.89544463800647
# steps	 1000 	total rewards	 174.96803919638597
# steps	 1500 	total rewards	 254.21781294494127
# Finished after 1606 timesteps (5.824472665786743 seconds) with total reward 265.3325478777431
# {'coverage_prop': '0.973', 'intensity_prop': '0.650', 'ms1ms2_ratio': '0.326', 'efficiency': '0.211', 'TP': '188', 'FP': '67', 'FN': '7', 'precision': '0.737', 'recall': '0.964', 'f1': '0.836', 'total_rewards': 265.3325478777427, 'invalid_action_count': 4, 'num_ms1_scans': 395, 'num_ms2_scans': 1211}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 84.10416848370629
# steps	 1000 	total rewards	 174.1574877426201
# steps	 1500 	total rewards	 256.6872080197976
# Finished after 1623 timesteps (7.6897499561309814 seconds) with total reward 274.5595243268801
# {'coverage_prop': '0.929', 'intensity_prop': '0.536', 'ms1ms2_ratio': '0.304', 'efficiency': '0.294', 'TP': '228', 'FP': '138', 'FN': '28', 'precision': '0.623', 'recall': '0.891', 'f1': '0.733', 'total_rewards': 274.5595243268796, 'invalid_action_count': 22, 'num_ms1_scans': 378, 'num_ms2_scans': 1245}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 97.01666676030027
# steps	 1000 	total rewards	 191.32307447388416
# steps	 1500 	total rewards	 271.8690024685545
# Finished after 1635 timesteps (6.407142877578735 seconds) with total reward 298.3836731369628
# {'coverage_prop': '0.949', 'intensity_prop': '0.563', 'ms1ms2_ratio': '0.288', 'efficiency': '0.338', 'TP': '280', 'FP': '149', 'FN': '23', 'precision': '0.653', 'recall': '0.924', 'f1': '0.765', 'total_rewards': 298.38367313696244, 'invalid_action_count': 16, 'num_ms1_scans': 366, 'num_ms2_scans': 1269}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 84.30831611052454
# steps	 1000 	total rewards	 184.86117157907708
# steps	 1500 	total rewards	 262.8605912597771
# Finished after 1643 timesteps (7.538964033126831 seconds) with total reward 280.9968955672359
# {'coverage_prop': '0.959', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.278', 'efficiency': '0.326', 'TP': '271', 'FP': '148', 'FN': '18', 'precision': '0.647', 'recall': '0.938', 'f1': '0.766', 'total_rewards': 280.99689556723564, 'invalid_action_count': 22, 'num_ms1_scans': 357, 'num_ms2_scans': 1286}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 66.16738975749624
# steps	 1000 	total rewards	 148.06852608421082
# steps	 1500 	total rewards	 203.1308203834663
# Finished after 1584 timesteps (4.463910818099976 seconds) with total reward 211.39578236686975
# {'coverage_prop': '0.985', 'intensity_prop': '0.702', 'ms1ms2_ratio': '0.357', 'efficiency': '0.169', 'TP': '157', 'FP': '40', 'FN': '3', 'precision': '0.797', 'recall': '0.981', 'f1': '0.880', 'total_rewards': 211.39578236686813, 'invalid_action_count': 14, 'num_ms1_scans': 417, 'num_ms2_scans': 1167}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 91.21123929831798
# steps	 1000 	total rewards	 185.664903761327
# steps	 1500 	total rewards	 262.19270715687
# Finished after 1653 timesteps (6.820292949676514 seconds) with total reward 285.47423039022783
# {'coverage_prop': '0.927', 'intensity_prop': '0.528', 'ms1ms2_ratio': '0.266', 'efficiency': '0.339', 'TP': '271', 'FP': '172', 'FN': '35', 'precision': '0.612', 'recall': '0.886', 'f1': '0.724', 'total_rewards': 285.47423039022766, 'invalid_action_count': 32, 'num_ms1_scans': 347, 'num_ms2_scans': 1306}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 56.37172471164215
# steps	 1000 	total rewards	 157.53495007784952
# steps	 1500 	total rewards	 223.89023337203963
# Finished after 1540 timesteps (4.976046085357666 seconds) with total reward 228.87848985586808
# {'coverage_prop': '0.980', 'intensity_prop': '0.684', 'ms1ms2_ratio': '0.426', 'efficiency': '0.185', 'TP': '160', 'FP': '40', 'FN': '4', 'precision': '0.800', 'recall': '0.976', 'f1': '0.879', 'total_rewards': 228.87848985586677, 'invalid_action_count': 5, 'num_ms1_scans': 460, 'num_ms2_scans': 1080}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 94.76661130119902
# steps	 1000 	total rewards	 185.51990420503205
# steps	 1500 	total rewards	 274.72323060245026
# Finished after 1651 timesteps (9.357200860977173 seconds) with total reward 292.79822611536935
# {'coverage_prop': '0.962', 'intensity_prop': '0.546', 'ms1ms2_ratio': '0.268', 'efficiency': '0.313', 'TP': '254', 'FP': '154', 'FN': '16', 'precision': '0.623', 'recall': '0.941', 'f1': '0.749', 'total_rewards': 292.7982261153696, 'invalid_action_count': 15, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 86.54051554729432
# steps	 1000 	total rewards	 178.64794351907707
# steps	 1500 	total rewards	 263.9230967967899
# Finished after 1624 timesteps (7.577046632766724 seconds) with total reward 276.7443891968668
# {'coverage_prop': '0.945', 'intensity_prop': '0.556', 'ms1ms2_ratio': '0.301', 'efficiency': '0.291', 'TP': '230', 'FP': '133', 'FN': '21', 'precision': '0.634', 'recall': '0.916', 'f1': '0.749', 'total_rewards': 276.74438919686656, 'invalid_action_count': 8, 'num_ms1_scans': 376, 'num_ms2_scans': 1248}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 86.33511190131911
# steps	 1000 	total rewards	 186.99255842259777
# steps	 1500 	total rewards	 261.2149559162967
# Finished after 1651 timesteps (9.715849876403809 seconds) with total reward 280.77474789563826
# {'coverage_prop': '0.921', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.268', 'efficiency': '0.313', 'TP': '285', 'FP': '123', 'FN': '35', 'precision': '0.699', 'recall': '0.891', 'f1': '0.783', 'total_rewards': 280.774747895638, 'invalid_action_count': 30, 'num_ms1_scans': 349, 'num_ms2_scans': 1302}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 81.02413922801458
# steps	 1000 	total rewards	 162.53410002856828
# steps	 1500 	total rewards	 219.8456317758206
# Finished after 1603 timesteps (6.105679035186768 seconds) with total reward 232.8682658707044
# {'coverage_prop': '0.968', 'intensity_prop': '0.646', 'ms1ms2_ratio': '0.329', 'efficiency': '0.200', 'TP': '180', 'FP': '61', 'FN': '8', 'precision': '0.747', 'recall': '0.957', 'f1': '0.839', 'total_rewards': 232.868265870703, 'invalid_action_count': 3, 'num_ms1_scans': 397, 'num_ms2_scans': 1206}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 81.08435525741208
# steps	 1000 	total rewards	 163.31893754305975
# steps	 1500 	total rewards	 227.85652568950053
# Finished after 1599 timesteps (6.979452848434448 seconds) with total reward 238.76514293135432
# {'coverage_prop': '0.964', 'intensity_prop': '0.640', 'ms1ms2_ratio': '0.335', 'efficiency': '0.202', 'TP': '178', 'FP': '64', 'FN': '9', 'precision': '0.736', 'recall': '0.952', 'f1': '0.830', 'total_rewards': 238.76514293135267, 'invalid_action_count': 8, 'num_ms1_scans': 401, 'num_ms2_scans': 1198}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 72.53988152589153
# steps	 1000 	total rewards	 149.93159922360056
# steps	 1500 	total rewards	 219.35830937931107
# Finished after 1598 timesteps (6.041335105895996 seconds) with total reward 230.8938828919559
# {'coverage_prop': '0.960', 'intensity_prop': '0.559', 'ms1ms2_ratio': '0.336', 'efficiency': '0.241', 'TP': '179', 'FP': '109', 'FN': '12', 'precision': '0.622', 'recall': '0.937', 'f1': '0.747', 'total_rewards': 230.89388289195443, 'invalid_action_count': 15, 'num_ms1_scans': 402, 'num_ms2_scans': 1196}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 64.16839379799575
# steps	 1000 	total rewards	 147.40329311286553
# steps	 1500 	total rewards	 213.25601130642897
# Finished after 1552 timesteps (4.205798864364624 seconds) with total reward 220.3757189291567
# {'coverage_prop': '0.961', 'intensity_prop': '0.680', 'ms1ms2_ratio': '0.406', 'efficiency': '0.179', 'TP': '156', 'FP': '42', 'FN': '8', 'precision': '0.788', 'recall': '0.951', 'f1': '0.862', 'total_rewards': 220.37571892915508, 'invalid_action_count': 4, 'num_ms1_scans': 448, 'num_ms2_scans': 1104}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 82.99539303710506
# steps	 1000 	total rewards	 179.78023269866873
# steps	 1500 	total rewards	 264.50500349661274
# Finished after 1628 timesteps (7.042262077331543 seconds) with total reward 284.1704992844093
# {'coverage_prop': '0.951', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.296', 'efficiency': '0.308', 'TP': '258', 'FP': '129', 'FN': '20', 'precision': '0.667', 'recall': '0.928', 'f1': '0.776', 'total_rewards': 284.17049928440935, 'invalid_action_count': 14, 'num_ms1_scans': 372, 'num_ms2_scans': 1256}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 94.34446061163388
# steps	 1000 	total rewards	 200.20029714085308
# steps	 1500 	total rewards	 270.9242447379594
# Finished after 1670 timesteps (6.320947885513306 seconds) with total reward 295.960316021007
# {'coverage_prop': '0.938', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.246', 'efficiency': '0.349', 'TP': '302', 'FP': '165', 'FN': '31', 'precision': '0.647', 'recall': '0.907', 'f1': '0.755', 'total_rewards': 295.9603160210074, 'invalid_action_count': 31, 'num_ms1_scans': 330, 'num_ms2_scans': 1340}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 91.90895250069049
# steps	 1000 	total rewards	 182.16052738844894
# steps	 1500 	total rewards	 258.7056182180279
# Finished after 1632 timesteps (7.529191970825195 seconds) with total reward 272.04495522834765
# {'coverage_prop': '0.941', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.292', 'efficiency': '0.277', 'TP': '235', 'FP': '115', 'FN': '22', 'precision': '0.671', 'recall': '0.914', 'f1': '0.774', 'total_rewards': 272.04495522834713, 'invalid_action_count': 19, 'num_ms1_scans': 369, 'num_ms2_scans': 1263}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 79.56191140712875
# steps	 1000 	total rewards	 160.2162467524438
# steps	 1500 	total rewards	 243.64852272292558
# Finished after 1631 timesteps (7.305370807647705 seconds) with total reward 262.3717723209197
# {'coverage_prop': '0.974', 'intensity_prop': '0.607', 'ms1ms2_ratio': '0.292', 'efficiency': '0.233', 'TP': '199', 'FP': '95', 'FN': '8', 'precision': '0.677', 'recall': '0.961', 'f1': '0.794', 'total_rewards': 262.3717723209189, 'invalid_action_count': 5, 'num_ms1_scans': 369, 'num_ms2_scans': 1262}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 74.46053210895845
# steps	 1000 	total rewards	 157.05580087039687
# steps	 1500 	total rewards	 235.1129062942805
# Finished after 1617 timesteps (8.203761100769043 seconds) with total reward 243.90391245851282
# {'coverage_prop': '0.985', 'intensity_prop': '0.640', 'ms1ms2_ratio': '0.310', 'efficiency': '0.212', 'TP': '185', 'FP': '76', 'FN': '4', 'precision': '0.709', 'recall': '0.979', 'f1': '0.822', 'total_rewards': 243.90391245851143, 'invalid_action_count': 9, 'num_ms1_scans': 383, 'num_ms2_scans': 1234}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 91.27625884003633
# steps	 1000 	total rewards	 194.79002829384547
# steps	 1500 	total rewards	 261.7050192207757
# Finished after 1645 timesteps (12.270643949508667 seconds) with total reward 285.047676868969
# {'coverage_prop': '0.919', 'intensity_prop': '0.542', 'ms1ms2_ratio': '0.275', 'efficiency': '0.333', 'TP': '271', 'FP': '159', 'FN': '38', 'precision': '0.630', 'recall': '0.877', 'f1': '0.733', 'total_rewards': 285.04767686896895, 'invalid_action_count': 27, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 71.22769590552437
# steps	 1000 	total rewards	 155.08569418943472
# steps	 1500 	total rewards	 225.3365518290205
# Finished after 1576 timesteps (8.674929857254028 seconds) with total reward 234.44616361925162
# {'coverage_prop': '0.962', 'intensity_prop': '0.628', 'ms1ms2_ratio': '0.368', 'efficiency': '0.195', 'TP': '157', 'FP': '68', 'FN': '9', 'precision': '0.698', 'recall': '0.946', 'f1': '0.803', 'total_rewards': 234.44616361925026, 'invalid_action_count': 4, 'num_ms1_scans': 424, 'num_ms2_scans': 1152}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 82.3939163237713
# steps	 1000 	total rewards	 177.224154430768
# steps	 1500 	total rewards	 258.5273964964449
# Finished after 1630 timesteps (8.742747068405151 seconds) with total reward 275.858315989027
# {'coverage_prop': '0.969', 'intensity_prop': '0.612', 'ms1ms2_ratio': '0.294', 'efficiency': '0.248', 'TP': '216', 'FP': '96', 'FN': '10', 'precision': '0.692', 'recall': '0.956', 'f1': '0.803', 'total_rewards': 275.8583159890262, 'invalid_action_count': 1, 'num_ms1_scans': 370, 'num_ms2_scans': 1260}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 86.37769870306076
# steps	 1000 	total rewards	 176.64943818188337
# steps	 1500 	total rewards	 254.86765786642093
# Finished after 1606 timesteps (8.634318113327026 seconds) with total reward 266.8506338654042
# {'coverage_prop': '0.955', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.325', 'efficiency': '0.244', 'TP': '205', 'FP': '91', 'FN': '14', 'precision': '0.693', 'recall': '0.936', 'f1': '0.796', 'total_rewards': 266.85063386540315, 'invalid_action_count': 2, 'num_ms1_scans': 394, 'num_ms2_scans': 1212}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 89.43335664488411
# steps	 1000 	total rewards	 184.12016782467896
# steps	 1500 	total rewards	 270.7694823424029
# Finished after 1617 timesteps (9.490752935409546 seconds) with total reward 285.3519619384907
# {'coverage_prop': '0.968', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.311', 'efficiency': '0.271', 'TP': '209', 'FP': '125', 'FN': '11', 'precision': '0.626', 'recall': '0.950', 'f1': '0.755', 'total_rewards': 285.3519619384902, 'invalid_action_count': 3, 'num_ms1_scans': 384, 'num_ms2_scans': 1233}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 87.07280293797601
# steps	 1000 	total rewards	 177.29302598562782
# steps	 1500 	total rewards	 270.4895083997723
# Finished after 1631 timesteps (9.479191064834595 seconds) with total reward 285.7569516679331
# {'coverage_prop': '0.957', 'intensity_prop': '0.569', 'ms1ms2_ratio': '0.292', 'efficiency': '0.300', 'TP': '242', 'FP': '137', 'FN': '17', 'precision': '0.639', 'recall': '0.934', 'f1': '0.759', 'total_rewards': 285.75695166793315, 'invalid_action_count': 4, 'num_ms1_scans': 369, 'num_ms2_scans': 1262}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 60.657466848794094
# steps	 1000 	total rewards	 146.5950542566028
# steps	 1500 	total rewards	 219.1287663879419
# Finished after 1573 timesteps (7.245814085006714 seconds) with total reward 228.60847833672966
# {'coverage_prop': '0.990', 'intensity_prop': '0.683', 'ms1ms2_ratio': '0.373', 'efficiency': '0.175', 'TP': '149', 'FP': '52', 'FN': '2', 'precision': '0.741', 'recall': '0.987', 'f1': '0.847', 'total_rewards': 228.6084783367284, 'invalid_action_count': 7, 'num_ms1_scans': 427, 'num_ms2_scans': 1146}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 78.33687121551287
# steps	 1000 	total rewards	 165.1082564472547
# steps	 1500 	total rewards	 249.08430763514224
# Finished after 1606 timesteps (9.667816877365112 seconds) with total reward 257.3141443904565
# {'coverage_prop': '0.982', 'intensity_prop': '0.601', 'ms1ms2_ratio': '0.325', 'efficiency': '0.228', 'TP': '184', 'FP': '92', 'FN': '5', 'precision': '0.667', 'recall': '0.974', 'f1': '0.791', 'total_rewards': 257.31414439045517, 'invalid_action_count': 8, 'num_ms1_scans': 394, 'num_ms2_scans': 1212}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 98.24053051241413
# steps	 1000 	total rewards	 179.14441584293832
# steps	 1500 	total rewards	 274.79316846515314
# Finished after 1634 timesteps (10.124864101409912 seconds) with total reward 293.28985132126684
# {'coverage_prop': '0.895', 'intensity_prop': '0.493', 'ms1ms2_ratio': '0.289', 'efficiency': '0.348', 'TP': '266', 'FP': '175', 'FN': '52', 'precision': '0.603', 'recall': '0.836', 'f1': '0.701', 'total_rewards': 293.28985132126684, 'invalid_action_count': 30, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 83.78277060252226
# steps	 1000 	total rewards	 178.1077418406103
# steps	 1500 	total rewards	 250.28446565946408
# Finished after 1625 timesteps (7.802072048187256 seconds) with total reward 259.0296747001454
# {'coverage_prop': '0.967', 'intensity_prop': '0.637', 'ms1ms2_ratio': '0.300', 'efficiency': '0.235', 'TP': '212', 'FP': '82', 'FN': '10', 'precision': '0.721', 'recall': '0.955', 'f1': '0.822', 'total_rewards': 259.0296747001442, 'invalid_action_count': 5, 'num_ms1_scans': 375, 'num_ms2_scans': 1250}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 92.5276178076839
# steps	 1000 	total rewards	 205.25382864627784
# steps	 1500 	total rewards	 312.7588878054987
# Finished after 1722 timesteps (15.342144012451172 seconds) with total reward 350.1583925147164
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 350.15839251471635, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 95.19223993264903
# steps	 1000 	total rewards	 200.01185786399162
# steps	 1500 	total rewards	 278.69251864828544
# Finished after 1556 timesteps (14.103376150131226 seconds) with total reward 286.42041452327317
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 286.42041452327345, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 94.09810262952533
# steps	 1000 	total rewards	 204.55175528344176
# steps	 1500 	total rewards	 311.70589197292
# Finished after 1669 timesteps (9.756747961044312 seconds) with total reward 335.8567231016701
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 335.856723101671, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 103.75112549735738
# steps	 1000 	total rewards	 222.260470162795
# steps	 1500 	total rewards	 321.6296912754646
# Finished after 1717 timesteps (10.335416793823242 seconds) with total reward 364.78676992745324
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 364.7867699274535, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 92.88207661824359
# steps	 1000 	total rewards	 225.03458447204991
# steps	 1500 	total rewards	 333.40644054419124
# Finished after 1704 timesteps (16.784861087799072 seconds) with total reward 368.54312915676854
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 368.54312915676945, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 81.95053041210245
# steps	 1000 	total rewards	 176.02517486243747
# Finished after 1408 timesteps (11.39522385597229 seconds) with total reward 238.71804354506358
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 238.7180435450617, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 103.04778207928516
# steps	 1000 	total rewards	 216.92306176316305
# steps	 1500 	total rewards	 317.03297009874126
# Finished after 1744 timesteps (14.843722820281982 seconds) with total reward 357.54143159354504
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 357.54143159354567, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 73.27568189026226
# steps	 1000 	total rewards	 178.89586218914897
# Finished after 1468 timesteps (11.544240713119507 seconds) with total reward 248.8792687394992
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 248.87926873949786, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 102.06959352333683
# steps	 1000 	total rewards	 203.76934731050875
# steps	 1500 	total rewards	 314.6913157438472
# Finished after 1736 timesteps (12.48028016090393 seconds) with total reward 352.8683422368248
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 352.8683422368253, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 90.74138548172694
# steps	 1000 	total rewards	 200.31290144512386
# steps	 1500 	total rewards	 301.1097996085705
# Finished after 1667 timesteps (12.819944858551025 seconds) with total reward 323.768416073993
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 323.7684160739943, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 91.23962533608534
# steps	 1000 	total rewards	 197.16226995805556
# steps	 1500 	total rewards	 303.39580167752945
# Finished after 1737 timesteps (13.153401136398315 seconds) with total reward 344.057804535654
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 344.05780453565535, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 88.76014323446897
# steps	 1000 	total rewards	 182.82317997694054
# steps	 1500 	total rewards	 254.1775526296638
# Finished after 1530 timesteps (10.180747985839844 seconds) with total reward 257.90826139058424
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 257.9082613905829, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 84.09788008205047
# steps	 1000 	total rewards	 173.34530752343633
# steps	 1500 	total rewards	 250.4027444407447
# Finished after 1602 timesteps (10.287744998931885 seconds) with total reward 265.8130372865816
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 265.8130372865811, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 81.87979467550704
# steps	 1000 	total rewards	 176.3296676850765
# steps	 1500 	total rewards	 264.5543538505019
# Finished after 1645 timesteps (9.129880905151367 seconds) with total reward 281.66421220903726
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 281.6642122090379, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 77.69553492222708
# steps	 1000 	total rewards	 165.92205077135358
# Finished after 1497 timesteps (7.732874870300293 seconds) with total reward 238.86550329561172
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 238.86550329561047, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 89.05709360186964
# steps	 1000 	total rewards	 202.35383743309467
# steps	 1500 	total rewards	 309.4258646878863
# Finished after 1655 timesteps (11.620840072631836 seconds) with total reward 340.11849111963613
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 340.118491119637, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 105.80378017337763
# steps	 1000 	total rewards	 218.16501246190484
# steps	 1500 	total rewards	 323.99517148498575
# Finished after 1729 timesteps (10.180851936340332 seconds) with total reward 365.3798953710612
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 365.3798953710626, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 100.86888851189178
# steps	 1000 	total rewards	 210.73859611594213
# steps	 1500 	total rewards	 300.65131585356136
# Finished after 1681 timesteps (9.093614101409912 seconds) with total reward 326.453219442385
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 326.45321944238583, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 85.55640776019361
# steps	 1000 	total rewards	 192.1170010832405
# steps	 1500 	total rewards	 282.6369316315453
# Finished after 1621 timesteps (10.014287233352661 seconds) with total reward 301.02243270902477
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 301.022432709025, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 83.8961989902214
# steps	 1000 	total rewards	 183.76704030525036
# steps	 1500 	total rewards	 264.106842989171
# Finished after 1634 timesteps (8.688493728637695 seconds) with total reward 282.8349639496908
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 282.8349639496904, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 103.82872862229425
# steps	 1000 	total rewards	 205.4574323828516
# steps	 1500 	total rewards	 298.0440315538605
# Finished after 1726 timesteps (12.748517990112305 seconds) with total reward 339.6563370807766
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 339.65633708077706, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 78.8765952264226
# steps	 1000 	total rewards	 180.8121218448101
# Finished after 1475 timesteps (8.681862115859985 seconds) with total reward 259.5886548759064
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 259.5886548759048, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 90.37844742158512
# steps	 1000 	total rewards	 195.95932027941527
# steps	 1500 	total rewards	 283.3609709366841
# Finished after 1636 timesteps (8.557416915893555 seconds) with total reward 305.03129962834686
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 305.03129962834777, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 92.58010974902588
# steps	 1000 	total rewards	 199.06887434647197
# steps	 1500 	total rewards	 285.5523492877917
# Finished after 1575 timesteps (8.195449829101562 seconds) with total reward 296.6703624144893
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 296.67036241449057, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 90.58123202962977
# steps	 1000 	total rewards	 201.86616968777264
# steps	 1500 	total rewards	 295.787668388372
# Finished after 1681 timesteps (8.962548971176147 seconds) with total reward 324.2819674955664
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 324.28196749556696, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 88.78144021754095
# steps	 1000 	total rewards	 188.87430385569195
# steps	 1500 	total rewards	 297.86842274642567
# Finished after 1679 timesteps (10.39804220199585 seconds) with total reward 329.2116800669655
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 329.21168006696644, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 71.98194223405334
# steps	 1000 	total rewards	 170.41017366979133
# Finished after 1465 timesteps (7.617989778518677 seconds) with total reward 242.86558010739546
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 242.86558010739404, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 87.80052172308895
# steps	 1000 	total rewards	 195.50633781024922
# steps	 1500 	total rewards	 294.00010247549244
# Finished after 1564 timesteps (8.00623893737793 seconds) with total reward 304.0900195549617
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 304.09001955496166, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 104.17309733822901
# steps	 1000 	total rewards	 195.47739728296165
# steps	 1500 	total rewards	 298.6482177897861
# Finished after 1749 timesteps (10.27048921585083 seconds) with total reward 346.2046795612188
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 346.20467956121945, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 90.33998672596451
# steps	 1000 	total rewards	 192.64754247155082
# steps	 1500 	total rewards	 274.80651079438553
# Finished after 1657 timesteps (8.517616748809814 seconds) with total reward 293.02734741027416
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 293.02734741027416, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fad49128af0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fad33bd5670>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fad28cca910>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.5,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.493', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '210', 'FP': '197', 'FN': '19', 'precision': '0.516', 'recall': '0.917', 'f1': '0.660'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.444', 'efficiency': '0.729', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.506', 'ms1ms2_ratio': '1.469', 'efficiency': '0.746', 'TP': '193', 'FP': '186', 'FN': '15', 'precision': '0.509', 'recall': '0.928', 'f1': '0.658'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.531', 'ms1ms2_ratio': '1.279', 'efficiency': '0.769', 'TP': '247', 'FP': '185', 'FN': '20', 'precision': '0.572', 'recall': '0.925', 'f1': '0.707'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.534', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '229', 'FP': '199', 'FN': '9', 'precision': '0.535', 'recall': '0.962', 'f1': '0.688'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.517', 'ms1ms2_ratio': '1.132', 'efficiency': '0.741', 'TP': '255', 'FP': '199', 'FN': '24', 'precision': '0.562', 'recall': '0.914', 'f1': '0.696'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.491', 'ms1ms2_ratio': '1.438', 'efficiency': '0.775', 'TP': '202', 'FP': '198', 'FN': '24', 'precision': '0.505', 'recall': '0.894', 'f1': '0.645'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.524', 'ms1ms2_ratio': '1.524', 'efficiency': '0.743', 'TP': '201', 'FP': '166', 'FN': '17', 'precision': '0.548', 'recall': '0.922', 'f1': '0.687'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.534', 'ms1ms2_ratio': '1.206', 'efficiency': '0.727', 'TP': '238', 'FP': '188', 'FN': '17', 'precision': '0.559', 'recall': '0.933', 'f1': '0.699'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.518', 'ms1ms2_ratio': '2.676', 'efficiency': '0.759', 'TP': '124', 'FP': '115', 'FN': '10', 'precision': '0.519', 'recall': '0.925', 'f1': '0.665'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.482', 'ms1ms2_ratio': '2.541', 'efficiency': '0.720', 'TP': '110', 'FP': '127', 'FN': '14', 'precision': '0.464', 'recall': '0.887', 'f1': '0.609'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.511', 'ms1ms2_ratio': '2.002', 'efficiency': '0.713', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.546', 'ms1ms2_ratio': '1.398', 'efficiency': '0.746', 'TP': '216', 'FP': '177', 'FN': '14', 'precision': '0.550', 'recall': '0.939', 'f1': '0.693'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.537', 'ms1ms2_ratio': '1.087', 'efficiency': '0.763', 'TP': '274', 'FP': '207', 'FN': '17', 'precision': '0.570', 'recall': '0.942', 'f1': '0.710'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.507', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '143', 'FP': '148', 'FN': '11', 'precision': '0.491', 'recall': '0.929', 'f1': '0.643'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.492', 'ms1ms2_ratio': '2.350', 'efficiency': '0.738', 'TP': '125', 'FP': '134', 'FN': '6', 'precision': '0.483', 'recall': '0.954', 'f1': '0.641'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.542', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '266', 'FP': '180', 'FN': '22', 'precision': '0.596', 'recall': '0.924', 'f1': '0.725'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.488', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '108', 'FP': '112', 'FN': '14', 'precision': '0.491', 'recall': '0.885', 'f1': '0.632'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '163', 'FP': '142', 'FN': '17', 'precision': '0.534', 'recall': '0.906', 'f1': '0.672'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.528', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '212', 'FP': '173', 'FN': '11', 'precision': '0.551', 'recall': '0.951', 'f1': '0.697'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.265', 'efficiency': '0.743', 'TP': '145', 'FP': '124', 'FN': '12', 'precision': '0.539', 'recall': '0.924', 'f1': '0.681'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.517', 'ms1ms2_ratio': '1.051', 'efficiency': '0.727', 'TP': '248', 'FP': '221', 'FN': '24', 'precision': '0.529', 'recall': '0.912', 'f1': '0.669'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1124.752379                1264.0          0.697           0.214
# 1  random   -1174.806158                1278.0          0.740           0.206
# 2  random   -1282.713340                1396.0          0.660           0.166
# 3  random   -1159.866920                1299.0          0.710           0.213
# 4  random   -1219.118324                1353.0          0.709           0.203
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.004       0.150      0.283   0.394  0.329
# 1          0.008       0.099      0.237   0.404  0.299
# 2          0.004       0.131      0.215   0.295  0.249
# 3          0.005       0.162      0.287   0.413  0.338
# 4          0.005       0.156      0.245   0.374  0.296

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_2.0E7_horizon_%d.p' % horizon)

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_2.0E7_horizon_%d.p' % horizon)

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     301.016828                  10.0          0.948           0.565
# 31    DQN     265.332548                   4.0          0.973           0.650
# 32    DQN     274.559524                  22.0          0.929           0.536
# 33    DQN     298.383673                  16.0          0.949           0.563
# 34    DQN     280.996896                  22.0          0.959           0.575
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.309       0.327      0.639   0.921  0.754
# 31          0.326       0.211      0.737   0.964  0.836
# 32          0.304       0.294      0.623   0.891  0.733
# 33          0.288       0.338      0.653   0.924  0.765
# 34          0.278       0.326      0.647   0.938  0.766

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
