# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
alpha = 0.08786850144151409
beta = 0.37578310050749153
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=alpha, beta=beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2022-08-30 09:54:28.095 | INFO     | experiments:get_samplers:244 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ccda2f610>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7c8866e070>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ca8cc2310>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'mz_tol': 10,
#    'rt_tol': 120,
#    'alpha': 0.08786850144151409,
#    'beta': 0.37578310050749153}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200
in_dir = '../../tune/QCB_resimulated_medium'
out_dir = 'evaluation_1.0E6'
methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 265
# 352
# 460
# 402
# 456
# 494
# 450
# 228
# 442
# 354
# 299
# 264
# 335
# 295
# 416
# 334
# 275
# 244
# 392
# 290
# 441
# 411
# 433
# 386
# 245
# 261
# 436
# 494
# 246
# 256

# %% [markdown]
# Generate new chemicals if not found

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    min_mz = mz_range[0]
    max_mz = mz_range[1]
    min_rt = rt_range[0]
    max_rt = rt_range[1]
    min_log_intensity = np.log(intensity_range[0])
    max_log_intensity = np.log(intensity_range[1])
    
    mzml_filename = '../fullscan_QCB.mzML'
    samplers_pickle = 'samplers_QCB_medium.p'
    if exists(samplers_pickle):
        logger.info('Loaded %s' % samplers_pickle)
        samplers = load_obj(samplers_pickle)
        mz_sampler = samplers['mz']
        ri_sampler = samplers['rt_intensity']
        cr_sampler = samplers['chromatogram']
    else:
        logger.info('Creating samplers from %s' % mzml_filename)
        mz_sampler = MZMLFormulaSampler(mzml_filename, min_mz=min_mz, max_mz=max_mz)
        ri_sampler = MZMLRTandIntensitySampler(mzml_filename, min_rt=min_rt, max_rt=max_rt,
                                               min_log_intensity=min_log_intensity,
                                               max_log_intensity=max_log_intensity)
        roi_params = RoiBuilderParams(min_roi_length=3, at_least_one_point_above=5E5)
        cr_sampler = MZMLChromatogramSampler(mzml_filename, roi_params=roi_params)
        samplers = {
            'mz': mz_sampler,
            'rt_intensity': ri_sampler,
            'chromatogram': cr_sampler
        }
        save_obj(samplers, samplers_pickle)
    
    chemical_creator_params = {
        'mz_range': mz_range,
        'rt_range': rt_range,
        'intensity_range': intensity_range,
        'n_chemicals': n_chemicals,
        'mz_sampler': mz_sampler,
        'ri_sampler': ri_sampler,
        'cr_sampler': cr_sampler
    }

    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ccda2f610>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7c8866e070>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ca8cc2310>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 120,
#   'alpha': 0.08786850144151409,
#   'beta': 0.37578310050749153}}

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = dict(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        alpha = 0.08786850144151409
        beta = 0.37578310050749153
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_1000000_alpha_auto_beta_auto', METHOD_DQN)
        fname = os.path.join(model_dir, 'best_model.zip')
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO:
        alpha = 0.25
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_1000000_alpha_auto_beta_auto', METHOD_PPO)
        fname = os.path.join(model_dir, 'best_model.zip')
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    elif method == METHOD_PPO_RECURRENT:
        alpha = 0.25
        beta = 0.75
        model_dir = os.path.join(in_dir, 'metric_f1_timesteps_1000000_alpha_auto_beta_auto', METHOD_PPO_RECURRENT)        
        fname = os.path.join(model_dir, 'best_model.zip')
        model = RecurrentPPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = alpha
        copy_params['env']['beta'] = beta                
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)        
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (265 chemicals)
# steps	 500 	total rewards	 -377.9913606438123
# steps	 1000 	total rewards	 -679.9031211395868
# steps	 1500 	total rewards	 -904.9254652078816
# Finished after 1987 timesteps with total reward -1219.3297193948888
# {'coverage_prop': '0.747', 'intensity_prop': '0.255', 'ms1ms2_ratio': '0.007', 'efficiency': '0.100', 'TP': '62', 'FP': '136', 'FN': '67', 'precision': '0.313', 'recall': '0.481', 'f1': '0.379', 'total_rewards': -1219.329719394889, 'invalid_action_count': 1270}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 -402.9838630679891
# steps	 1000 	total rewards	 -635.1508112873274
# steps	 1500 	total rewards	 -890.7114773957371
# Finished after 1985 timesteps with total reward -1136.1480484942942
# {'coverage_prop': '0.747', 'intensity_prop': '0.245', 'ms1ms2_ratio': '0.008', 'efficiency': '0.134', 'TP': '80', 'FP': '183', 'FN': '89', 'precision': '0.304', 'recall': '0.473', 'f1': '0.370', 'total_rewards': -1136.1480484942954, 'invalid_action_count': 1197}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 -388.87128886442866
# steps	 1000 	total rewards	 -615.7572622016368
# steps	 1500 	total rewards	 -752.9649578228602
# Finished after 1987 timesteps with total reward -933.111404653359
# {'coverage_prop': '0.783', 'intensity_prop': '0.285', 'ms1ms2_ratio': '0.007', 'efficiency': '0.182', 'TP': '128', 'FP': '232', 'FN': '100', 'precision': '0.356', 'recall': '0.561', 'f1': '0.435', 'total_rewards': -933.1114046533581, 'invalid_action_count': 1015}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 -375.5985169729825
# steps	 1000 	total rewards	 -660.4467990266095
# steps	 1500 	total rewards	 -891.0734483322069
# Finished after 1987 timesteps with total reward -1092.8420827464583
# {'coverage_prop': '0.756', 'intensity_prop': '0.265', 'ms1ms2_ratio': '0.007', 'efficiency': '0.154', 'TP': '106', 'FP': '198', 'FN': '98', 'precision': '0.349', 'recall': '0.520', 'f1': '0.417', 'total_rewards': -1092.8420827464577, 'invalid_action_count': 1161}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 -375.6346412989482
# steps	 1000 	total rewards	 -748.9612263383731
# steps	 1500 	total rewards	 -1140.343880213899
# Finished after 1993 timesteps with total reward -1415.1212121915016
# {'coverage_prop': '0.664', 'intensity_prop': '0.188', 'ms1ms2_ratio': '0.004', 'efficiency': '0.153', 'TP': '82', 'FP': '221', 'FN': '153', 'precision': '0.271', 'recall': '0.349', 'f1': '0.305', 'total_rewards': -1415.1212121915028, 'invalid_action_count': 1465}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 -335.6012474325305
# steps	 1000 	total rewards	 -560.3499746257709
# steps	 1500 	total rewards	 -758.1399296969266
# Finished after 1989 timesteps with total reward -1062.8467339224849
# {'coverage_prop': '0.777', 'intensity_prop': '0.254', 'ms1ms2_ratio': '0.006', 'efficiency': '0.194', 'TP': '124', 'FP': '260', 'FN': '110', 'precision': '0.323', 'recall': '0.530', 'f1': '0.401', 'total_rewards': -1062.846733922484, 'invalid_action_count': 1135}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 -357.4731437401789
# steps	 1000 	total rewards	 -699.3590640536203
# steps	 1500 	total rewards	 -956.8540736689292
# Finished after 1992 timesteps with total reward -1281.525551224599
# {'coverage_prop': '0.640', 'intensity_prop': '0.192', 'ms1ms2_ratio': '0.004', 'efficiency': '0.145', 'TP': '79', 'FP': '209', 'FN': '162', 'precision': '0.274', 'recall': '0.328', 'f1': '0.299', 'total_rewards': -1281.525551224599, 'invalid_action_count': 1341}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 -378.3183863948477
# steps	 1000 	total rewards	 -852.015350643569
# steps	 1500 	total rewards	 -1231.3110295035476
# Finished after 1993 timesteps with total reward -1579.8091968264941
# {'coverage_prop': '0.605', 'intensity_prop': '0.155', 'ms1ms2_ratio': '0.004', 'efficiency': '0.069', 'TP': '31', 'FP': '107', 'FN': '90', 'precision': '0.225', 'recall': '0.256', 'f1': '0.239', 'total_rewards': -1579.8091968264935, 'invalid_action_count': 1608}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 -401.9568356648767
# steps	 1000 	total rewards	 -724.0818182083594
# steps	 1500 	total rewards	 -1028.3038082305761
# Finished after 1992 timesteps with total reward -1314.7100802495452
# {'coverage_prop': '0.674', 'intensity_prop': '0.195', 'ms1ms2_ratio': '0.004', 'efficiency': '0.150', 'TP': '85', 'FP': '213', 'FN': '144', 'precision': '0.285', 'recall': '0.371', 'f1': '0.323', 'total_rewards': -1314.7100802495452, 'invalid_action_count': 1366}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 -398.82087723307154
# steps	 1000 	total rewards	 -803.5665370038477
# steps	 1500 	total rewards	 -992.0885317934019
# Finished after 1991 timesteps with total reward -1272.5765010725768
# {'coverage_prop': '0.706', 'intensity_prop': '0.231', 'ms1ms2_ratio': '0.005', 'efficiency': '0.126', 'TP': '77', 'FP': '173', 'FN': '104', 'precision': '0.308', 'recall': '0.425', 'f1': '0.357', 'total_rewards': -1272.5765010725768, 'invalid_action_count': 1328}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 -370.6138417794869
# steps	 1000 	total rewards	 -636.4433993067737
# steps	 1500 	total rewards	 -891.6197640613682
# Finished after 1984 timesteps with total reward -1199.5354715390445
# {'coverage_prop': '0.746', 'intensity_prop': '0.215', 'ms1ms2_ratio': '0.008', 'efficiency': '0.113', 'TP': '63', 'FP': '160', 'FN': '76', 'precision': '0.283', 'recall': '0.453', 'f1': '0.348', 'total_rewards': -1199.5354715390451, 'invalid_action_count': 1251}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 -431.2816507910652
# steps	 1000 	total rewards	 -776.0761441282274
# steps	 1500 	total rewards	 -1054.4539718660947
# Finished after 1992 timesteps with total reward -1432.5956504290634
# {'coverage_prop': '0.697', 'intensity_prop': '0.230', 'ms1ms2_ratio': '0.004', 'efficiency': '0.093', 'TP': '60', 'FP': '124', 'FN': '80', 'precision': '0.326', 'recall': '0.429', 'f1': '0.370', 'total_rewards': -1432.5956504290634, 'invalid_action_count': 1472}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 -453.9018984000573
# steps	 1000 	total rewards	 -764.5922769395954
# steps	 1500 	total rewards	 -1015.6100686131101
# Finished after 1991 timesteps with total reward -1327.8743129679924
# {'coverage_prop': '0.696', 'intensity_prop': '0.192', 'ms1ms2_ratio': '0.005', 'efficiency': '0.118', 'TP': '61', 'FP': '172', 'FN': '102', 'precision': '0.262', 'recall': '0.374', 'f1': '0.308', 'total_rewards': -1327.8743129679915, 'invalid_action_count': 1369}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 -355.80403878372687
# steps	 1000 	total rewards	 -661.2609721500044
# steps	 1500 	total rewards	 -1044.0083156455166
# Finished after 1987 timesteps with total reward -1328.9328743296437
# {'coverage_prop': '0.719', 'intensity_prop': '0.210', 'ms1ms2_ratio': '0.007', 'efficiency': '0.107', 'TP': '55', 'FP': '157', 'FN': '83', 'precision': '0.259', 'recall': '0.399', 'f1': '0.314', 'total_rewards': -1328.932874329645, 'invalid_action_count': 1378}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 -342.9243789451203
# steps	 1000 	total rewards	 -635.9515321036451
# steps	 1500 	total rewards	 -903.2596780328649
# Finished after 1991 timesteps with total reward -1321.5468761691482
# {'coverage_prop': '0.661', 'intensity_prop': '0.183', 'ms1ms2_ratio': '0.005', 'efficiency': '0.139', 'TP': '67', 'FP': '208', 'FN': '141', 'precision': '0.244', 'recall': '0.322', 'f1': '0.277', 'total_rewards': -1321.5468761691484, 'invalid_action_count': 1375}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 -363.0311005215245
# steps	 1000 	total rewards	 -650.2064057431955
# steps	 1500 	total rewards	 -882.311542989605
# Finished after 1991 timesteps with total reward -1174.5565067783466
# {'coverage_prop': '0.799', 'intensity_prop': '0.281', 'ms1ms2_ratio': '0.005', 'efficiency': '0.135', 'TP': '85', 'FP': '182', 'FN': '67', 'precision': '0.318', 'recall': '0.559', 'f1': '0.406', 'total_rewards': -1174.5565067783461, 'invalid_action_count': 1230}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 -412.4550428568152
# steps	 1000 	total rewards	 -802.2569198758194
# steps	 1500 	total rewards	 -1097.7184168117046
# Finished after 1990 timesteps with total reward -1367.4524480997406
# {'coverage_prop': '0.702', 'intensity_prop': '0.199', 'ms1ms2_ratio': '0.005', 'efficiency': '0.097', 'TP': '49', 'FP': '144', 'FN': '82', 'precision': '0.254', 'recall': '0.374', 'f1': '0.302', 'total_rewards': -1367.452448099741, 'invalid_action_count': 1411}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 -440.35149846342176
# steps	 1000 	total rewards	 -761.5051019712732
# steps	 1500 	total rewards	 -989.3415656852285
# Finished after 1985 timesteps with total reward -1342.052208724384
# {'coverage_prop': '0.738', 'intensity_prop': '0.229', 'ms1ms2_ratio': '0.008', 'efficiency': '0.091', 'TP': '48', 'FP': '132', 'FN': '64', 'precision': '0.267', 'recall': '0.429', 'f1': '0.329', 'total_rewards': -1342.0522087243833, 'invalid_action_count': 1387}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 -383.21513072224496
# steps	 1000 	total rewards	 -668.0295350890682
# steps	 1500 	total rewards	 -822.8066046650346
# Finished after 1989 timesteps with total reward -1082.550403999021
# {'coverage_prop': '0.798', 'intensity_prop': '0.301', 'ms1ms2_ratio': '0.006', 'efficiency': '0.158', 'TP': '121', 'FP': '192', 'FN': '79', 'precision': '0.387', 'recall': '0.605', 'f1': '0.472', 'total_rewards': -1082.5504039990221, 'invalid_action_count': 1146}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 -383.9833200665291
# steps	 1000 	total rewards	 -767.5203549851899
# steps	 1500 	total rewards	 -1032.4798548432727
# Finished after 1989 timesteps with total reward -1327.2675314728222
# {'coverage_prop': '0.714', 'intensity_prop': '0.198', 'ms1ms2_ratio': '0.006', 'efficiency': '0.105', 'TP': '52', 'FP': '155', 'FN': '83', 'precision': '0.251', 'recall': '0.385', 'f1': '0.304', 'total_rewards': -1327.267531472821, 'invalid_action_count': 1374}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 -373.35124273124006
# steps	 1000 	total rewards	 -620.1509280801203
# steps	 1500 	total rewards	 -968.3449304123681
# Finished after 1988 timesteps with total reward -1164.8009170687164
# {'coverage_prop': '0.737', 'intensity_prop': '0.197', 'ms1ms2_ratio': '0.006', 'efficiency': '0.164', 'TP': '77', 'FP': '248', 'FN': '116', 'precision': '0.237', 'recall': '0.399', 'f1': '0.297', 'total_rewards': -1164.8009170687171, 'invalid_action_count': 1227}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 -349.24083543457937
# steps	 1000 	total rewards	 -682.8072071590855
# steps	 1500 	total rewards	 -825.918907677672
# Finished after 1989 timesteps with total reward -1130.8461529807446
# {'coverage_prop': '0.740', 'intensity_prop': '0.216', 'ms1ms2_ratio': '0.006', 'efficiency': '0.154', 'TP': '81', 'FP': '223', 'FN': '107', 'precision': '0.266', 'recall': '0.431', 'f1': '0.329', 'total_rewards': -1130.8461529807455, 'invalid_action_count': 1194}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 -323.1639174934014
# steps	 1000 	total rewards	 -722.3997324381986
# steps	 1500 	total rewards	 -821.635045230473
# Finished after 1987 timesteps with total reward -1088.0272303856163
# {'coverage_prop': '0.681', 'intensity_prop': '0.214', 'ms1ms2_ratio': '0.007', 'efficiency': '0.149', 'TP': '86', 'FP': '209', 'FN': '138', 'precision': '0.292', 'recall': '0.384', 'f1': '0.331', 'total_rewards': -1088.0272303856166, 'invalid_action_count': 1149}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 -358.4003723028163
# steps	 1000 	total rewards	 -592.5179196245401
# steps	 1500 	total rewards	 -771.5710922994481
# Finished after 1990 timesteps with total reward -1154.2488403837435
# {'coverage_prop': '0.780', 'intensity_prop': '0.239', 'ms1ms2_ratio': '0.005', 'efficiency': '0.152', 'TP': '91', 'FP': '210', 'FN': '85', 'precision': '0.302', 'recall': '0.517', 'f1': '0.382', 'total_rewards': -1154.248840383744, 'invalid_action_count': 1220}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 -452.90984617376245
# steps	 1000 	total rewards	 -790.2727824777996
# steps	 1500 	total rewards	 -1152.4523685726526
# Finished after 1989 timesteps with total reward -1424.4768512852079
# {'coverage_prop': '0.678', 'intensity_prop': '0.164', 'ms1ms2_ratio': '0.006', 'efficiency': '0.084', 'TP': '33', 'FP': '133', 'FN': '79', 'precision': '0.199', 'recall': '0.295', 'f1': '0.237', 'total_rewards': -1424.4768512852086, 'invalid_action_count': 1457}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 -411.382859421721
# steps	 1000 	total rewards	 -896.8600611168802
# steps	 1500 	total rewards	 -1282.3494319619826
# Finished after 1996 timesteps with total reward -1686.2347500272535
# {'coverage_prop': '0.502', 'intensity_prop': '0.108', 'ms1ms2_ratio': '0.002', 'efficiency': '0.066', 'TP': '25', 'FP': '106', 'FN': '130', 'precision': '0.191', 'recall': '0.161', 'f1': '0.175', 'total_rewards': -1686.234750027255, 'invalid_action_count': 1708}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 -403.4609212274112
# steps	 1000 	total rewards	 -545.9245600699901
# steps	 1500 	total rewards	 -963.1127766959542
# Finished after 1988 timesteps with total reward -1385.8486286841473
# {'coverage_prop': '0.589', 'intensity_prop': '0.177', 'ms1ms2_ratio': '0.006', 'efficiency': '0.130', 'TP': '73', 'FP': '184', 'FN': '179', 'precision': '0.284', 'recall': '0.290', 'f1': '0.287', 'total_rewards': -1385.8486286841467, 'invalid_action_count': 1437}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 -429.0191615380403
# steps	 1000 	total rewards	 -714.9182519032992
# steps	 1500 	total rewards	 -934.7300526892668
# Finished after 1992 timesteps with total reward -1224.955369233634
# {'coverage_prop': '0.678', 'intensity_prop': '0.197', 'ms1ms2_ratio': '0.004', 'efficiency': '0.169', 'TP': '84', 'FP': '251', 'FN': '159', 'precision': '0.251', 'recall': '0.346', 'f1': '0.291', 'total_rewards': -1224.9553692336349, 'invalid_action_count': 1291}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 -392.9484828626921
# steps	 1000 	total rewards	 -743.9575369563923
# steps	 1500 	total rewards	 -1045.9423244224101
# Finished after 1986 timesteps with total reward -1297.4158640395626
# {'coverage_prop': '0.760', 'intensity_prop': '0.209', 'ms1ms2_ratio': '0.007', 'efficiency': '0.095', 'TP': '44', 'FP': '143', 'FN': '59', 'precision': '0.235', 'recall': '0.427', 'f1': '0.303', 'total_rewards': -1297.4158640395622, 'invalid_action_count': 1338}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 -398.77344474456544
# steps	 1000 	total rewards	 -823.7647377639378
# steps	 1500 	total rewards	 -1036.3293965942137
# Finished after 1988 timesteps with total reward -1341.0253822904392
# {'coverage_prop': '0.707', 'intensity_prop': '0.227', 'ms1ms2_ratio': '0.006', 'efficiency': '0.092', 'TP': '57', 'FP': '124', 'FN': '75', 'precision': '0.315', 'recall': '0.432', 'f1': '0.364', 'total_rewards': -1341.025382290439, 'invalid_action_count': 1385}
#
# method = DQN max_peaks = 200 N = 0 rt_tol = 120
#
#
# Episode 0 (265 chemicals)
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 6.44GB > 0.32GB
# steps	 500 	total rewards	 121.49533716216786
# steps	 1000 	total rewards	 237.65532073279968
# steps	 1500 	total rewards	 354.6157546326489
# Finished after 1543 timesteps with total reward 366.50707613483837
# {'coverage_prop': '0.932', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.421', 'efficiency': '0.227', 'TP': '225', 'FP': '22', 'FN': '18', 'precision': '0.911', 'recall': '0.926', 'f1': '0.918', 'total_rewards': 366.5070761348404, 'invalid_action_count': 0}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 106.43417971500187
# steps	 1000 	total rewards	 237.2445697166838
# steps	 1500 	total rewards	 359.93527322878026
# Finished after 1529 timesteps with total reward 368.24952065942693
# {'coverage_prop': '0.923', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.445', 'efficiency': '0.307', 'TP': '278', 'FP': '47', 'FN': '27', 'precision': '0.855', 'recall': '0.911', 'f1': '0.883', 'total_rewards': 368.2495206594295, 'invalid_action_count': 0}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 119.73763245828187
# steps	 1000 	total rewards	 242.3972192164774
# Finished after 1490 timesteps with total reward 337.7457988900369
# {'coverage_prop': '0.878', 'intensity_prop': '0.614', 'ms1ms2_ratio': '0.520', 'efficiency': '0.412', 'TP': '317', 'FP': '87', 'FN': '56', 'precision': '0.785', 'recall': '0.850', 'f1': '0.816', 'total_rewards': 337.7457988900393, 'invalid_action_count': 0}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 116.29407817044758
# steps	 1000 	total rewards	 235.03382787322994
# steps	 1500 	total rewards	 342.37988012228345
# Finished after 1520 timesteps with total reward 346.6359826784628
# {'coverage_prop': '0.915', 'intensity_prop': '0.674', 'ms1ms2_ratio': '0.462', 'efficiency': '0.354', 'TP': '301', 'FP': '67', 'FN': '34', 'precision': '0.818', 'recall': '0.899', 'f1': '0.856', 'total_rewards': 346.6359826784646, 'invalid_action_count': 2}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 118.91643674976626
# steps	 1000 	total rewards	 240.56763756243294
# steps	 1500 	total rewards	 346.60199060064167
# Finished after 1513 timesteps with total reward 350.2126234367594
# {'coverage_prop': '0.873', 'intensity_prop': '0.615', 'ms1ms2_ratio': '0.475', 'efficiency': '0.388', 'TP': '318', 'FP': '80', 'FN': '58', 'precision': '0.799', 'recall': '0.846', 'f1': '0.822', 'total_rewards': 350.2126234367617, 'invalid_action_count': 4}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 124.36950914325415
# steps	 1000 	total rewards	 252.1814729338688
# steps	 1500 	total rewards	 368.64494887586847
# Finished after 1514 timesteps with total reward 371.2711400579757
# {'coverage_prop': '0.881', 'intensity_prop': '0.633', 'ms1ms2_ratio': '0.473', 'efficiency': '0.423', 'TP': '350', 'FP': '85', 'FN': '59', 'precision': '0.805', 'recall': '0.856', 'f1': '0.829', 'total_rewards': 371.2711400579783, 'invalid_action_count': 0}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 134.36061997682128
# steps	 1000 	total rewards	 270.3982410621373
# steps	 1500 	total rewards	 383.0224398298063
# Finished after 1521 timesteps with total reward 387.51411194657913
# {'coverage_prop': '0.891', 'intensity_prop': '0.653', 'ms1ms2_ratio': '0.461', 'efficiency': '0.385', 'TP': '335', 'FP': '66', 'FN': '49', 'precision': '0.835', 'recall': '0.872', 'f1': '0.854', 'total_rewards': 387.5141119465835, 'invalid_action_count': 1}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 115.30178796633963
# steps	 1000 	total rewards	 233.84381350926213
# steps	 1500 	total rewards	 323.8420369339865
# Finished after 1538 timesteps with total reward 333.6827507950981
# {'coverage_prop': '0.917', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.429', 'efficiency': '0.194', 'TP': '188', 'FP': '21', 'FN': '19', 'precision': '0.900', 'recall': '0.908', 'f1': '0.904', 'total_rewards': 333.6827507950995, 'invalid_action_count': 2}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 120.55097537478929
# steps	 1000 	total rewards	 226.74298040023825
# steps	 1500 	total rewards	 336.8166577011509
# Finished after 1517 timesteps with total reward 339.33233694395585
# {'coverage_prop': '0.898', 'intensity_prop': '0.646', 'ms1ms2_ratio': '0.467', 'efficiency': '0.384', 'TP': '321', 'FP': '76', 'FN': '45', 'precision': '0.809', 'recall': '0.877', 'f1': '0.841', 'total_rewards': 339.33233694395784, 'invalid_action_count': 0}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 134.3501869094692
# steps	 1000 	total rewards	 266.57196253956454
# steps	 1500 	total rewards	 374.4412111225355
# Finished after 1537 timesteps with total reward 384.44526926069534
# {'coverage_prop': '0.932', 'intensity_prop': '0.698', 'ms1ms2_ratio': '0.431', 'efficiency': '0.307', 'TP': '282', 'FP': '48', 'FN': '24', 'precision': '0.855', 'recall': '0.922', 'f1': '0.887', 'total_rewards': 384.44526926069807, 'invalid_action_count': 1}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 127.30666500103258
# steps	 1000 	total rewards	 254.769655727194
# steps	 1500 	total rewards	 380.87154707995677
# Finished after 1561 timesteps with total reward 390.22602491615635
# {'coverage_prop': '0.940', 'intensity_prop': '0.716', 'ms1ms2_ratio': '0.393', 'efficiency': '0.251', 'TP': '242', 'FP': '39', 'FN': '18', 'precision': '0.861', 'recall': '0.931', 'f1': '0.895', 'total_rewards': 390.2260249161592, 'invalid_action_count': 2}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 115.91471126579933
# steps	 1000 	total rewards	 235.31546866400777
# steps	 1500 	total rewards	 346.52028882576957
# Finished after 1525 timesteps with total reward 352.4422922408089
# {'coverage_prop': '0.924', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.454', 'efficiency': '0.233', 'TP': '210', 'FP': '34', 'FN': '20', 'precision': '0.861', 'recall': '0.913', 'f1': '0.886', 'total_rewards': 352.44229224081033, 'invalid_action_count': 1}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 135.66472674386569
# steps	 1000 	total rewards	 251.3708884430267
# steps	 1500 	total rewards	 368.1548473116653
# Finished after 1528 timesteps with total reward 376.94604028240536
# {'coverage_prop': '0.946', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.447', 'efficiency': '0.300', 'TP': '282', 'FP': '35', 'FN': '18', 'precision': '0.890', 'recall': '0.940', 'f1': '0.914', 'total_rewards': 376.9460402824083, 'invalid_action_count': 2}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 135.60549692739826
# steps	 1000 	total rewards	 257.4706713919079
# steps	 1500 	total rewards	 363.56200477540995
# Finished after 1542 timesteps with total reward 372.1534738523892
# {'coverage_prop': '0.963', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.423', 'efficiency': '0.262', 'TP': '242', 'FP': '42', 'FN': '11', 'precision': '0.852', 'recall': '0.957', 'f1': '0.901', 'total_rewards': 372.15347385239176, 'invalid_action_count': 0}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 110.3243893386838
# steps	 1000 	total rewards	 219.84467019649384
# steps	 1500 	total rewards	 334.50212267778903
# Finished after 1507 timesteps with total reward 335.57925991589093
# {'coverage_prop': '0.889', 'intensity_prop': '0.632', 'ms1ms2_ratio': '0.486', 'efficiency': '0.365', 'TP': '298', 'FP': '72', 'FN': '46', 'precision': '0.805', 'recall': '0.866', 'f1': '0.835', 'total_rewards': 335.57925991589207, 'invalid_action_count': 3}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 113.14962072314607
# steps	 1000 	total rewards	 224.50648419320058
# steps	 1500 	total rewards	 323.54115915867294
# Finished after 1511 timesteps with total reward 325.4058823173159
# {'coverage_prop': '0.913', 'intensity_prop': '0.663', 'ms1ms2_ratio': '0.478', 'efficiency': '0.298', 'TP': '252', 'FP': '53', 'FN': '29', 'precision': '0.826', 'recall': '0.897', 'f1': '0.860', 'total_rewards': 325.4058823173166, 'invalid_action_count': 0}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 133.74141920903742
# steps	 1000 	total rewards	 259.0707147363788
# steps	 1500 	total rewards	 395.39195441535827
# Finished after 1557 timesteps with total reward 405.16184542466294
# {'coverage_prop': '0.945', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.398', 'efficiency': '0.233', 'TP': '236', 'FP': '24', 'FN': '15', 'precision': '0.908', 'recall': '0.940', 'f1': '0.924', 'total_rewards': 405.161845424666, 'invalid_action_count': 0}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 97.43950585000772
# steps	 1000 	total rewards	 216.31247666226318
# steps	 1500 	total rewards	 342.6697585887335
# Finished after 1557 timesteps with total reward 358.30923662620506
# {'coverage_prop': '0.955', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.398', 'efficiency': '0.209', 'TP': '200', 'FP': '33', 'FN': '11', 'precision': '0.858', 'recall': '0.948', 'f1': '0.901', 'total_rewards': 358.3092366262061, 'invalid_action_count': 0}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 115.65011123353618
# steps	 1000 	total rewards	 224.08412662359981
# steps	 1500 	total rewards	 332.94430284534354
# Finished after 1513 timesteps with total reward 335.7186836390467
# {'coverage_prop': '0.913', 'intensity_prop': '0.688', 'ms1ms2_ratio': '0.476', 'efficiency': '0.349', 'TP': '305', 'FP': '53', 'FN': '34', 'precision': '0.852', 'recall': '0.900', 'f1': '0.875', 'total_rewards': 335.71868363904804, 'invalid_action_count': 0}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 114.47125467680101
# steps	 1000 	total rewards	 235.954546899108
# steps	 1500 	total rewards	 355.5281973217818
# Finished after 1554 timesteps with total reward 367.27017375241337
# {'coverage_prop': '0.955', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.403', 'efficiency': '0.250', 'TP': '245', 'FP': '32', 'FN': '13', 'precision': '0.884', 'recall': '0.950', 'f1': '0.916', 'total_rewards': 367.2701737524156, 'invalid_action_count': 0}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 141.81835640801455
# steps	 1000 	total rewards	 254.6276318317257
# steps	 1500 	total rewards	 364.83532222758106
# Finished after 1515 timesteps with total reward 366.33774416788793
# {'coverage_prop': '0.916', 'intensity_prop': '0.644', 'ms1ms2_ratio': '0.472', 'efficiency': '0.393', 'TP': '321', 'FP': '83', 'FN': '37', 'precision': '0.795', 'recall': '0.897', 'f1': '0.843', 'total_rewards': 366.33774416789083, 'invalid_action_count': 1}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 120.8261258152968
# steps	 1000 	total rewards	 234.5126413704054
# Finished after 1495 timesteps with total reward 335.7317920359242
# {'coverage_prop': '0.927', 'intensity_prop': '0.671', 'ms1ms2_ratio': '0.512', 'efficiency': '0.385', 'TP': '309', 'FP': '72', 'FN': '30', 'precision': '0.811', 'recall': '0.912', 'f1': '0.858', 'total_rewards': 335.731792035926, 'invalid_action_count': 1}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 137.56167576992345
# steps	 1000 	total rewards	 266.3138219007738
# steps	 1500 	total rewards	 375.86214457384574
# Finished after 1506 timesteps with total reward 377.0658878614325
# {'coverage_prop': '0.905', 'intensity_prop': '0.639', 'ms1ms2_ratio': '0.488', 'efficiency': '0.387', 'TP': '314', 'FP': '78', 'FN': '41', 'precision': '0.801', 'recall': '0.885', 'f1': '0.841', 'total_rewards': 377.0658878614361, 'invalid_action_count': 2}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 125.2773162852416
# steps	 1000 	total rewards	 262.155849867832
# steps	 1500 	total rewards	 381.41559681148095
# Finished after 1505 timesteps with total reward 382.7466221505508
# {'coverage_prop': '0.927', 'intensity_prop': '0.694', 'ms1ms2_ratio': '0.490', 'efficiency': '0.354', 'TP': '305', 'FP': '53', 'FN': '28', 'precision': '0.852', 'recall': '0.916', 'f1': '0.883', 'total_rewards': 382.74662215055395, 'invalid_action_count': 0}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 98.50331382132865
# steps	 1000 	total rewards	 223.9841609861002
# steps	 1500 	total rewards	 329.6384758783691
# Finished after 1550 timesteps with total reward 338.3899030131794
# {'coverage_prop': '0.959', 'intensity_prop': '0.737', 'ms1ms2_ratio': '0.409', 'efficiency': '0.214', 'TP': '201', 'FP': '34', 'FN': '10', 'precision': '0.855', 'recall': '0.953', 'f1': '0.901', 'total_rewards': 338.38990301318006, 'invalid_action_count': 1}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 118.49123386407163
# steps	 1000 	total rewards	 234.24372401815987
# steps	 1500 	total rewards	 340.84987022680207
# Finished after 1544 timesteps with total reward 351.05582480056387
# {'coverage_prop': '0.954', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.419', 'efficiency': '0.229', 'TP': '205', 'FP': '44', 'FN': '12', 'precision': '0.823', 'recall': '0.945', 'f1': '0.880', 'total_rewards': 351.05582480056535, 'invalid_action_count': 1}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 124.39590767070223
# steps	 1000 	total rewards	 241.94511685045268
# steps	 1500 	total rewards	 357.3394224341081
# Finished after 1519 timesteps with total reward 360.3427481579247
# {'coverage_prop': '0.901', 'intensity_prop': '0.647', 'ms1ms2_ratio': '0.463', 'efficiency': '0.379', 'TP': '316', 'FP': '77', 'FN': '43', 'precision': '0.804', 'recall': '0.880', 'f1': '0.840', 'total_rewards': 360.3427481579272, 'invalid_action_count': 0}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 118.59121711097194
# steps	 1000 	total rewards	 243.8407438744358
# steps	 1500 	total rewards	 344.98092410974004
# Finished after 1504 timesteps with total reward 345.40636769716724
# {'coverage_prop': '0.860', 'intensity_prop': '0.572', 'ms1ms2_ratio': '0.492', 'efficiency': '0.422', 'TP': '323', 'FP': '102', 'FN': '69', 'precision': '0.760', 'recall': '0.824', 'f1': '0.791', 'total_rewards': 345.40636769716957, 'invalid_action_count': 2}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 122.32508640151009
# steps	 1000 	total rewards	 251.2458274610397
# steps	 1500 	total rewards	 350.58387771262744
# Finished after 1556 timesteps with total reward 365.65334177500904
# {'coverage_prop': '0.923', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.399', 'efficiency': '0.204', 'TP': '201', 'FP': '26', 'FN': '19', 'precision': '0.885', 'recall': '0.914', 'f1': '0.899', 'total_rewards': 365.653341775012, 'invalid_action_count': 2}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 119.17859109826674
# steps	 1000 	total rewards	 245.81698615951825
# steps	 1500 	total rewards	 351.78776526830563
# Finished after 1539 timesteps with total reward 359.85244595699
# {'coverage_prop': '0.980', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.429', 'efficiency': '0.233', 'TP': '223', 'FP': '28', 'FN': '5', 'precision': '0.888', 'recall': '0.978', 'f1': '0.931', 'total_rewards': 359.85244595699174, 'invalid_action_count': 2}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (265 chemicals)
# steps	 500 	total rewards	 98.83306417791826
# steps	 1000 	total rewards	 214.00392306203787
# steps	 1500 	total rewards	 323.8912159901639
# Finished after 1625 timesteps with total reward 340.65995120113587
# {'coverage_prop': '0.947', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.300', 'efficiency': '0.201', 'TP': '231', 'FP': '20', 'FN': '14', 'precision': '0.920', 'recall': '0.943', 'f1': '0.931', 'total_rewards': 340.6599512011375, 'invalid_action_count': 0}
#
# Episode 1 (352 chemicals)
# steps	 500 	total rewards	 102.47849397677268
# steps	 1000 	total rewards	 232.03329643545675
# steps	 1500 	total rewards	 349.27400454630924
# Finished after 1671 timesteps with total reward 387.8738928606812
# {'coverage_prop': '0.955', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.245', 'efficiency': '0.250', 'TP': '306', 'FP': '30', 'FN': '16', 'precision': '0.911', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 387.8738928606827, 'invalid_action_count': 0}
#
# Episode 2 (460 chemicals)
# steps	 500 	total rewards	 113.72045262280756
# steps	 1000 	total rewards	 249.66726737984877
# steps	 1500 	total rewards	 345.30086583414675
# Finished after 1736 timesteps with total reward 396.8751586212546
# {'coverage_prop': '0.920', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.180', 'efficiency': '0.288', 'TP': '375', 'FP': '48', 'FN': '37', 'precision': '0.887', 'recall': '0.910', 'f1': '0.898', 'total_rewards': 396.87515862125593, 'invalid_action_count': 0}
#
# Episode 3 (402 chemicals)
# steps	 500 	total rewards	 104.9508841291367
# steps	 1000 	total rewards	 223.00242779962335
# steps	 1500 	total rewards	 321.4800281280201
# Finished after 1696 timesteps with total reward 369.03935416597403
# {'coverage_prop': '0.928', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.218', 'efficiency': '0.268', 'TP': '347', 'FP': '26', 'FN': '29', 'precision': '0.930', 'recall': '0.923', 'f1': '0.927', 'total_rewards': 369.03935416597517, 'invalid_action_count': 0}
#
# Episode 4 (456 chemicals)
# steps	 500 	total rewards	 106.5355306261659
# steps	 1000 	total rewards	 232.90979112766243
# steps	 1500 	total rewards	 348.8509713213721
# Finished after 1739 timesteps with total reward 399.46144865347264
# {'coverage_prop': '0.877', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.177', 'efficiency': '0.271', 'TP': '361', 'FP': '39', 'FN': '56', 'precision': '0.902', 'recall': '0.866', 'f1': '0.884', 'total_rewards': 399.4614486534731, 'invalid_action_count': 0}
#
# Episode 5 (494 chemicals)
# steps	 500 	total rewards	 114.66828313011695
# steps	 1000 	total rewards	 239.04519984923695
# steps	 1500 	total rewards	 354.6808088973942
# Finished after 1746 timesteps with total reward 402.7969176209633
# {'coverage_prop': '0.887', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.170', 'efficiency': '0.294', 'TP': '397', 'FP': '41', 'FN': '56', 'precision': '0.906', 'recall': '0.876', 'f1': '0.891', 'total_rewards': 402.7969176209645, 'invalid_action_count': 0}
#
# Episode 6 (450 chemicals)
# steps	 500 	total rewards	 117.1330168253613
# steps	 1000 	total rewards	 258.8907392939435
# steps	 1500 	total rewards	 381.69585294005816
# Finished after 1713 timesteps with total reward 421.03450648627444
# {'coverage_prop': '0.913', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.201', 'efficiency': '0.288', 'TP': '375', 'FP': '36', 'FN': '39', 'precision': '0.912', 'recall': '0.906', 'f1': '0.909', 'total_rewards': 421.03450648627637, 'invalid_action_count': 0}
#
# Episode 7 (228 chemicals)
# steps	 500 	total rewards	 89.40025150711332
# steps	 1000 	total rewards	 194.66210164617462
# steps	 1500 	total rewards	 284.1112962552927
# Finished after 1608 timesteps with total reward 297.84078558691954
# {'coverage_prop': '0.961', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.322', 'efficiency': '0.180', 'TP': '198', 'FP': '21', 'FN': '9', 'precision': '0.904', 'recall': '0.957', 'f1': '0.930', 'total_rewards': 297.84078558692033, 'invalid_action_count': 0}
#
# Episode 8 (442 chemicals)
# steps	 500 	total rewards	 115.52146805244637
# steps	 1000 	total rewards	 241.13230976128196
# steps	 1500 	total rewards	 358.592692043115
# Finished after 1722 timesteps with total reward 401.9137268435315
# {'coverage_prop': '0.930', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.193', 'efficiency': '0.285', 'TP': '378', 'FP': '33', 'FN': '31', 'precision': '0.920', 'recall': '0.924', 'f1': '0.922', 'total_rewards': 401.91372684353314, 'invalid_action_count': 0}
#
# Episode 9 (354 chemicals)
# steps	 500 	total rewards	 113.25286626784253
# steps	 1000 	total rewards	 249.31185022927497
# steps	 1500 	total rewards	 352.55503755089296
# Finished after 1688 timesteps with total reward 389.50188542457374
# {'coverage_prop': '0.963', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.228', 'efficiency': '0.248', 'TP': '310', 'FP': '31', 'FN': '13', 'precision': '0.909', 'recall': '0.960', 'f1': '0.934', 'total_rewards': 389.50188542457516, 'invalid_action_count': 0}
#
# Episode 10 (299 chemicals)
# steps	 500 	total rewards	 98.09565721529515
# steps	 1000 	total rewards	 216.83048741025453
# steps	 1500 	total rewards	 336.05471290274875
# Finished after 1564 timesteps with total reward 345.3160639556131
# {'coverage_prop': '0.953', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.387', 'efficiency': '0.253', 'TP': '267', 'FP': '18', 'FN': '14', 'precision': '0.937', 'recall': '0.950', 'f1': '0.943', 'total_rewards': 345.3160639556157, 'invalid_action_count': 0}
#
# Episode 11 (264 chemicals)
# steps	 500 	total rewards	 92.76536066545889
# steps	 1000 	total rewards	 199.34707139940636
# steps	 1500 	total rewards	 286.984331466035
# Finished after 1604 timesteps with total reward 307.95085476225887
# {'coverage_prop': '0.951', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.328', 'efficiency': '0.208', 'TP': '233', 'FP': '18', 'FN': '13', 'precision': '0.928', 'recall': '0.947', 'f1': '0.938', 'total_rewards': 307.95085476226006, 'invalid_action_count': 0}
#
# Episode 12 (335 chemicals)
# steps	 500 	total rewards	 112.30306945033732
# steps	 1000 	total rewards	 227.3962859128594
# steps	 1500 	total rewards	 331.2589009726807
# Finished after 1630 timesteps with total reward 363.39482489414473
# {'coverage_prop': '0.961', 'intensity_prop': '0.787', 'ms1ms2_ratio': '0.294', 'efficiency': '0.256', 'TP': '301', 'FP': '21', 'FN': '13', 'precision': '0.935', 'recall': '0.959', 'f1': '0.947', 'total_rewards': 363.39482489414644, 'invalid_action_count': 0}
#
# Episode 13 (295 chemicals)
# steps	 500 	total rewards	 105.26983408950542
# steps	 1000 	total rewards	 218.94178699989942
# steps	 1500 	total rewards	 305.0431906473436
# Finished after 1626 timesteps with total reward 333.1372357873721
# {'coverage_prop': '0.969', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.300', 'efficiency': '0.229', 'TP': '262', 'FP': '24', 'FN': '9', 'precision': '0.916', 'recall': '0.967', 'f1': '0.941', 'total_rewards': 333.13723578737324, 'invalid_action_count': 0}
#
# Episode 14 (416 chemicals)
# steps	 500 	total rewards	 107.90062963191545
# steps	 1000 	total rewards	 230.06446703852723
# steps	 1500 	total rewards	 342.91158900515296
# Finished after 1699 timesteps with total reward 379.90840134443414
# {'coverage_prop': '0.916', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.215', 'efficiency': '0.273', 'TP': '346', 'FP': '35', 'FN': '35', 'precision': '0.908', 'recall': '0.908', 'f1': '0.908', 'total_rewards': 379.90840134443556, 'invalid_action_count': 0}
#
# Episode 15 (334 chemicals)
# steps	 500 	total rewards	 93.25896841687359
# steps	 1000 	total rewards	 211.7657324326463
# steps	 1500 	total rewards	 306.003861245141
# Finished after 1686 timesteps with total reward 334.35002525785035
# {'coverage_prop': '0.928', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.229', 'efficiency': '0.226', 'TP': '288', 'FP': '22', 'FN': '24', 'precision': '0.929', 'recall': '0.923', 'f1': '0.926', 'total_rewards': 334.3500252578519, 'invalid_action_count': 0}
#
# Episode 16 (275 chemicals)
# steps	 500 	total rewards	 99.71348219481409
# steps	 1000 	total rewards	 218.49961858199924
# steps	 1500 	total rewards	 334.16925777002905
# Finished after 1562 timesteps with total reward 344.22420201427195
# {'coverage_prop': '0.953', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.390', 'efficiency': '0.233', 'TP': '239', 'FP': '23', 'FN': '13', 'precision': '0.912', 'recall': '0.948', 'f1': '0.930', 'total_rewards': 344.22420201427343, 'invalid_action_count': 0}
#
# Episode 17 (244 chemicals)
# steps	 500 	total rewards	 83.57995484640576
# steps	 1000 	total rewards	 197.13542847599484
# Finished after 1489 timesteps with total reward 302.0185371542928
# {'coverage_prop': '0.963', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.524', 'efficiency': '0.241', 'TP': '214', 'FP': '21', 'FN': '9', 'precision': '0.911', 'recall': '0.960', 'f1': '0.934', 'total_rewards': 302.01853715429337, 'invalid_action_count': 0}
#
# Episode 18 (392 chemicals)
# steps	 500 	total rewards	 107.69808686129255
# steps	 1000 	total rewards	 217.38569309405136
# steps	 1500 	total rewards	 323.21732472232054
# Finished after 1706 timesteps with total reward 359.4531639628499
# {'coverage_prop': '0.949', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.209', 'efficiency': '0.264', 'TP': '342', 'FP': '30', 'FN': '20', 'precision': '0.919', 'recall': '0.945', 'f1': '0.932', 'total_rewards': 359.45316396285045, 'invalid_action_count': 0}
#
# Episode 19 (290 chemicals)
# steps	 500 	total rewards	 100.2324422801082
# steps	 1000 	total rewards	 211.392675895335
# steps	 1500 	total rewards	 319.5337781264924
# Finished after 1611 timesteps with total reward 340.19004969751575
# {'coverage_prop': '0.969', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.318', 'efficiency': '0.230', 'TP': '256', 'FP': '25', 'FN': '9', 'precision': '0.911', 'recall': '0.966', 'f1': '0.938', 'total_rewards': 340.1900496975169, 'invalid_action_count': 0}
#
# Episode 20 (441 chemicals)
# steps	 500 	total rewards	 123.39798166081027
# steps	 1000 	total rewards	 253.57808922586074
# steps	 1500 	total rewards	 372.5126459750618
# Finished after 1707 timesteps with total reward 413.02176587585643
# {'coverage_prop': '0.934', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.207', 'efficiency': '0.291', 'TP': '369', 'FP': '43', 'FN': '29', 'precision': '0.896', 'recall': '0.927', 'f1': '0.911', 'total_rewards': 413.0217658758584, 'invalid_action_count': 0}
#
# Episode 21 (411 chemicals)
# steps	 500 	total rewards	 119.97275862481669
# steps	 1000 	total rewards	 240.43347135349165
# steps	 1500 	total rewards	 349.42655286827966
# Finished after 1718 timesteps with total reward 390.20753565229404
# {'coverage_prop': '0.939', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.196', 'efficiency': '0.269', 'TP': '353', 'FP': '33', 'FN': '25', 'precision': '0.915', 'recall': '0.934', 'f1': '0.924', 'total_rewards': 390.20753565229535, 'invalid_action_count': 0}
#
# Episode 22 (433 chemicals)
# steps	 500 	total rewards	 118.41840491000202
# steps	 1000 	total rewards	 247.63314836585008
# steps	 1500 	total rewards	 363.6128914685985
# Finished after 1718 timesteps with total reward 414.1214386473764
# {'coverage_prop': '0.938', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.196', 'efficiency': '0.283', 'TP': '361', 'FP': '45', 'FN': '27', 'precision': '0.889', 'recall': '0.930', 'f1': '0.909', 'total_rewards': 414.121438647378, 'invalid_action_count': 0}
#
# Episode 23 (386 chemicals)
# steps	 500 	total rewards	 109.16148322066701
# steps	 1000 	total rewards	 249.77599418629217
# steps	 1500 	total rewards	 369.1176458872888
# Finished after 1734 timesteps with total reward 407.4402267403229
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.181', 'efficiency': '0.254', 'TP': '343', 'FP': '30', 'FN': '13', 'precision': '0.920', 'recall': '0.963', 'f1': '0.941', 'total_rewards': 407.44022674032385, 'invalid_action_count': 0}
#
# Episode 24 (245 chemicals)
# steps	 500 	total rewards	 91.62900994606548
# steps	 1000 	total rewards	 197.9559079058199
# steps	 1500 	total rewards	 282.0373480526797
# Finished after 1552 timesteps with total reward 290.55166324598565
# {'coverage_prop': '0.955', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.407', 'efficiency': '0.212', 'TP': '212', 'FP': '22', 'FN': '11', 'precision': '0.906', 'recall': '0.951', 'f1': '0.928', 'total_rewards': 290.5516632459864, 'invalid_action_count': 0}
#
# Episode 25 (261 chemicals)
# steps	 500 	total rewards	 99.78284579513104
# steps	 1000 	total rewards	 200.21577037971542
# steps	 1500 	total rewards	 292.767671758509
# Finished after 1620 timesteps with total reward 311.06970923039
# {'coverage_prop': '0.966', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.306', 'efficiency': '0.203', 'TP': '228', 'FP': '24', 'FN': '9', 'precision': '0.905', 'recall': '0.962', 'f1': '0.933', 'total_rewards': 311.0697092303907, 'invalid_action_count': 0}
#
# Episode 26 (436 chemicals)
# steps	 500 	total rewards	 111.40349710549773
# steps	 1000 	total rewards	 233.0230366005933
# steps	 1500 	total rewards	 350.47817285386094
# Finished after 1735 timesteps with total reward 402.47075041767755
# {'coverage_prop': '0.922', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.180', 'efficiency': '0.273', 'TP': '365', 'FP': '37', 'FN': '34', 'precision': '0.908', 'recall': '0.915', 'f1': '0.911', 'total_rewards': 402.47075041767783, 'invalid_action_count': 0}
#
# Episode 27 (494 chemicals)
# steps	 500 	total rewards	 109.42875099730382
# steps	 1000 	total rewards	 232.86372125181975
# steps	 1500 	total rewards	 352.9813014357692
# Finished after 1738 timesteps with total reward 403.7509343731561
# {'coverage_prop': '0.891', 'intensity_prop': '0.692', 'ms1ms2_ratio': '0.178', 'efficiency': '0.298', 'TP': '392', 'FP': '48', 'FN': '54', 'precision': '0.891', 'recall': '0.879', 'f1': '0.885', 'total_rewards': 403.7509343731573, 'invalid_action_count': 0}
#
# Episode 28 (246 chemicals)
# steps	 500 	total rewards	 95.61001733813539
# steps	 1000 	total rewards	 215.9834738763492
# steps	 1500 	total rewards	 309.5818801020903
# Finished after 1541 timesteps with total reward 316.97046912818365
# {'coverage_prop': '0.943', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.426', 'efficiency': '0.215', 'TP': '218', 'FP': '14', 'FN': '14', 'precision': '0.940', 'recall': '0.940', 'f1': '0.940', 'total_rewards': 316.9704691281847, 'invalid_action_count': 0}
#
# Episode 29 (256 chemicals)
# steps	 500 	total rewards	 93.4162363100375
# steps	 1000 	total rewards	 210.70689678341503
# steps	 1500 	total rewards	 295.0813224915385
# Finished after 1528 timesteps with total reward 298.7120166278371
# {'coverage_prop': '0.973', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.447', 'efficiency': '0.236', 'TP': '226', 'FP': '23', 'FN': '7', 'precision': '0.908', 'recall': '0.970', 'f1': '0.938', 'total_rewards': 298.712016627839, 'invalid_action_count': 0}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ccda2f610>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7c8866e070>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ca8cc2310>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'alpha': 0.08786850144151409,
#   'beta': 0.37578310050749153}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.342', 'efficiency': '0.214', 'TP': '235', 'FP': '19', 'FN': '11', 'precision': '0.925', 'recall': '0.955', 'f1': '0.940'}
#
# Episode 1 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.284', 'efficiency': '0.265', 'TP': '306', 'FP': '32', 'FN': '14', 'precision': '0.905', 'recall': '0.956', 'f1': '0.930'}
#
# Episode 2 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.212', 'efficiency': '0.313', 'TP': '400', 'FP': '39', 'FN': '21', 'precision': '0.911', 'recall': '0.950', 'f1': '0.930'}
#
# Episode 3 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.240', 'efficiency': '0.287', 'TP': '359', 'FP': '29', 'FN': '14', 'precision': '0.925', 'recall': '0.962', 'f1': '0.943'}
#
# Episode 4 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.199', 'efficiency': '0.303', 'TP': '396', 'FP': '37', 'FN': '23', 'precision': '0.915', 'recall': '0.945', 'f1': '0.930'}
#
# Episode 5 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.193', 'efficiency': '0.320', 'TP': '421', 'FP': '40', 'FN': '33', 'precision': '0.913', 'recall': '0.927', 'f1': '0.920'}
#
# Episode 6 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.226', 'efficiency': '0.307', 'TP': '395', 'FP': '28', 'FN': '27', 'precision': '0.934', 'recall': '0.936', 'f1': '0.935'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.376', 'efficiency': '0.192', 'TP': '198', 'FP': '21', 'FN': '9', 'precision': '0.904', 'recall': '0.957', 'f1': '0.930'}
#
# Episode 8 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.223', 'efficiency': '0.304', 'TP': '386', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.948', 'f1': '0.932'}
#
# Episode 9 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.266', 'efficiency': '0.265', 'TP': '315', 'FP': '31', 'FN': '8', 'precision': '0.910', 'recall': '0.975', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.424', 'efficiency': '0.267', 'TP': '273', 'FP': '16', 'FN': '10', 'precision': '0.945', 'recall': '0.965', 'f1': '0.955'}
#
# Episode 11 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.364', 'efficiency': '0.221', 'TP': '238', 'FP': '18', 'FN': '8', 'precision': '0.930', 'recall': '0.967', 'f1': '0.948'}
#
# Episode 12 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.335', 'efficiency': '0.271', 'TP': '306', 'FP': '19', 'FN': '10', 'precision': '0.942', 'recall': '0.968', 'f1': '0.955'}
#
# Episode 13 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.332', 'efficiency': '0.241', 'TP': '268', 'FP': '22', 'FN': '5', 'precision': '0.924', 'recall': '0.982', 'f1': '0.952'}
#
# Episode 14 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.232', 'efficiency': '0.294', 'TP': '372', 'FP': '29', 'FN': '15', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}
#
# Episode 15 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.258', 'efficiency': '0.243', 'TP': '299', 'FP': '22', 'FN': '13', 'precision': '0.931', 'recall': '0.958', 'f1': '0.945'}
#
# Episode 16 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.433', 'efficiency': '0.247', 'TP': '247', 'FP': '18', 'FN': '10', 'precision': '0.932', 'recall': '0.961', 'f1': '0.946'}
#
# Episode 17 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.592', 'efficiency': '0.257', 'TP': '215', 'FP': '20', 'FN': '9', 'precision': '0.915', 'recall': '0.960', 'f1': '0.937'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.246', 'efficiency': '0.283', 'TP': '351', 'FP': '28', 'FN': '13', 'precision': '0.926', 'recall': '0.964', 'f1': '0.945'}
#
# Episode 19 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.367', 'efficiency': '0.244', 'TP': '258', 'FP': '23', 'FN': '9', 'precision': '0.918', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 20 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.742', 'ms1ms2_ratio': '0.235', 'efficiency': '0.313', 'TP': '378', 'FP': '48', 'FN': '15', 'precision': '0.887', 'recall': '0.962', 'f1': '0.923'}
#
# Episode 21 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.217', 'efficiency': '0.283', 'TP': '362', 'FP': '32', 'FN': '17', 'precision': '0.919', 'recall': '0.955', 'f1': '0.937'}
#
# Episode 22 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.226', 'efficiency': '0.302', 'TP': '382', 'FP': '34', 'FN': '17', 'precision': '0.918', 'recall': '0.957', 'f1': '0.937'}
#
# Episode 23 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.204', 'efficiency': '0.266', 'TP': '347', 'FP': '31', 'FN': '8', 'precision': '0.918', 'recall': '0.977', 'f1': '0.947'}
#
# Episode 24 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.456', 'efficiency': '0.227', 'TP': '215', 'FP': '22', 'FN': '8', 'precision': '0.907', 'recall': '0.964', 'f1': '0.935'}
#
# Episode 25 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.353', 'efficiency': '0.215', 'TP': '228', 'FP': '24', 'FN': '9', 'precision': '0.905', 'recall': '0.962', 'f1': '0.933'}
#
# Episode 26 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '385', 'FP': '34', 'FN': '17', 'precision': '0.919', 'recall': '0.958', 'f1': '0.938'}
#
# Episode 27 finished
# {'coverage_prop': '0.941', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.192', 'efficiency': '0.322', 'TP': '421', 'FP': '44', 'FN': '29', 'precision': '0.905', 'recall': '0.936', 'f1': '0.920'}
#
# Episode 28 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.492', 'efficiency': '0.230', 'TP': '215', 'FP': '17', 'FN': '14', 'precision': '0.927', 'recall': '0.939', 'f1': '0.933'}
#
# Episode 29 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.496', 'efficiency': '0.250', 'TP': '227', 'FP': '24', 'FN': '5', 'precision': '0.904', 'recall': '0.978', 'f1': '0.940'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.538', 'ms1ms2_ratio': '1.349', 'efficiency': '0.466', 'TP': '143', 'FP': '109', 'FN': '13', 'precision': '0.567', 'recall': '0.917', 'f1': '0.701'}
#
# Episode 1 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.540', 'ms1ms2_ratio': '1.118', 'efficiency': '0.540', 'TP': '195', 'FP': '139', 'FN': '18', 'precision': '0.584', 'recall': '0.915', 'f1': '0.713'}
#
# Episode 2 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.567', 'ms1ms2_ratio': '0.749', 'efficiency': '0.553', 'TP': '274', 'FP': '169', 'FN': '17', 'precision': '0.619', 'recall': '0.942', 'f1': '0.747'}
#
# Episode 3 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.541', 'ms1ms2_ratio': '0.876', 'efficiency': '0.532', 'TP': '228', 'FP': '159', 'FN': '15', 'precision': '0.589', 'recall': '0.938', 'f1': '0.724'}
#
# Episode 4 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.663', 'efficiency': '0.506', 'TP': '290', 'FP': '145', 'FN': '21', 'precision': '0.667', 'recall': '0.932', 'f1': '0.777'}
#
# Episode 5 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.575', 'ms1ms2_ratio': '0.662', 'efficiency': '0.545', 'TP': '302', 'FP': '167', 'FN': '25', 'precision': '0.644', 'recall': '0.924', 'f1': '0.759'}
#
# Episode 6 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.788', 'efficiency': '0.550', 'TP': '263', 'FP': '164', 'FN': '23', 'precision': '0.616', 'recall': '0.920', 'f1': '0.738'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.580', 'efficiency': '0.453', 'TP': '122', 'FP': '96', 'FN': '10', 'precision': '0.560', 'recall': '0.924', 'f1': '0.697'}
#
# Episode 8 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.560', 'ms1ms2_ratio': '0.832', 'efficiency': '0.565', 'TP': '267', 'FP': '157', 'FN': '18', 'precision': '0.630', 'recall': '0.937', 'f1': '0.753'}
#
# Episode 9 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.547', 'ms1ms2_ratio': '1.051', 'efficiency': '0.535', 'TP': '202', 'FP': '143', 'FN': '9', 'precision': '0.586', 'recall': '0.957', 'f1': '0.727'}
#
# Episode 10 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.495', 'ms1ms2_ratio': '1.549', 'efficiency': '0.582', 'TP': '154', 'FP': '130', 'FN': '15', 'precision': '0.542', 'recall': '0.911', 'f1': '0.680'}
#
# Episode 11 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.561', 'ms1ms2_ratio': '1.366', 'efficiency': '0.474', 'TP': '158', 'FP': '96', 'FN': '10', 'precision': '0.622', 'recall': '0.940', 'f1': '0.749'}
#
# Episode 12 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.236', 'efficiency': '0.559', 'TP': '192', 'FP': '130', 'FN': '13', 'precision': '0.596', 'recall': '0.937', 'f1': '0.729'}
#
# Episode 13 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.545', 'ms1ms2_ratio': '1.305', 'efficiency': '0.520', 'TP': '167', 'FP': '121', 'FN': '7', 'precision': '0.580', 'recall': '0.960', 'f1': '0.723'}
#
# Episode 14 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.578', 'ms1ms2_ratio': '0.818', 'efficiency': '0.536', 'TP': '258', 'FP': '149', 'FN': '9', 'precision': '0.634', 'recall': '0.966', 'f1': '0.766'}
#
# Episode 15 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.564', 'ms1ms2_ratio': '1.029', 'efficiency': '0.486', 'TP': '205', 'FP': '113', 'FN': '16', 'precision': '0.645', 'recall': '0.928', 'f1': '0.761'}
#
# Episode 16 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.540', 'ms1ms2_ratio': '1.533', 'efficiency': '0.539', 'TP': '149', 'FP': '116', 'FN': '10', 'precision': '0.562', 'recall': '0.937', 'f1': '0.703'}
#
# Episode 17 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.504', 'ms1ms2_ratio': '2.112', 'efficiency': '0.606', 'TP': '121', 'FP': '111', 'FN': '12', 'precision': '0.522', 'recall': '0.910', 'f1': '0.663'}
#
# Episode 18 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.551', 'ms1ms2_ratio': '0.993', 'efficiency': '0.560', 'TP': '224', 'FP': '151', 'FN': '17', 'precision': '0.597', 'recall': '0.929', 'f1': '0.727'}
#
# Episode 19 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.504', 'ms1ms2_ratio': '1.481', 'efficiency': '0.549', 'TP': '155', 'FP': '122', 'FN': '13', 'precision': '0.560', 'recall': '0.923', 'f1': '0.697'}
#
# Episode 20 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.539', 'ms1ms2_ratio': '0.830', 'efficiency': '0.566', 'TP': '248', 'FP': '178', 'FN': '15', 'precision': '0.582', 'recall': '0.943', 'f1': '0.720'}
#
# Episode 21 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.538', 'ms1ms2_ratio': '0.907', 'efficiency': '0.551', 'TP': '237', 'FP': '155', 'FN': '19', 'precision': '0.605', 'recall': '0.926', 'f1': '0.731'}
#
# Episode 22 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.836', 'efficiency': '0.555', 'TP': '239', 'FP': '177', 'FN': '17', 'precision': '0.575', 'recall': '0.934', 'f1': '0.711'}
#
# Episode 23 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.865', 'efficiency': '0.516', 'TP': '228', 'FP': '150', 'FN': '8', 'precision': '0.603', 'recall': '0.966', 'f1': '0.743'}
#
# Episode 24 finished
# {'coverage_prop': '0.959', 'intensity_prop': '0.510', 'ms1ms2_ratio': '1.670', 'efficiency': '0.510', 'TP': '119', 'FP': '116', 'FN': '10', 'precision': '0.506', 'recall': '0.922', 'f1': '0.654'}
#
# Episode 25 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.482', 'ms1ms2_ratio': '1.508', 'efficiency': '0.496', 'TP': '118', 'FP': '129', 'FN': '14', 'precision': '0.478', 'recall': '0.894', 'f1': '0.623'}
#
# Episode 26 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.570', 'ms1ms2_ratio': '0.768', 'efficiency': '0.531', 'TP': '265', 'FP': '154', 'FN': '17', 'precision': '0.632', 'recall': '0.940', 'f1': '0.756'}
#
# Episode 27 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.565', 'ms1ms2_ratio': '0.647', 'efficiency': '0.541', 'TP': '302', 'FP': '170', 'FN': '22', 'precision': '0.640', 'recall': '0.932', 'f1': '0.759'}
#
# Episode 28 finished
# {'coverage_prop': '0.927', 'intensity_prop': '0.494', 'ms1ms2_ratio': '1.811', 'efficiency': '0.527', 'TP': '121', 'FP': '107', 'FN': '18', 'precision': '0.531', 'recall': '0.871', 'f1': '0.659'}
#
# Episode 29 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.517', 'ms1ms2_ratio': '1.709', 'efficiency': '0.547', 'TP': '134', 'FP': '114', 'FN': '8', 'precision': '0.540', 'recall': '0.944', 'f1': '0.687'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.215', 'efficiency': '0.181', 'TP': '235', 'FP': '18', 'FN': '12', 'precision': '0.929', 'recall': '0.951', 'f1': '0.940'}
#
# Episode 1 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.189', 'efficiency': '0.236', 'TP': '313', 'FP': '29', 'FN': '10', 'precision': '0.915', 'recall': '0.969', 'f1': '0.941'}
#
# Episode 2 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.155', 'efficiency': '0.292', 'TP': '406', 'FP': '39', 'FN': '15', 'precision': '0.912', 'recall': '0.964', 'f1': '0.938'}
#
# Episode 3 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.176', 'efficiency': '0.261', 'TP': '363', 'FP': '24', 'FN': '15', 'precision': '0.938', 'recall': '0.960', 'f1': '0.949'}
#
# Episode 4 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.145', 'efficiency': '0.279', 'TP': '395', 'FP': '37', 'FN': '24', 'precision': '0.914', 'recall': '0.943', 'f1': '0.928'}
#
# Episode 5 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.145', 'efficiency': '0.302', 'TP': '425', 'FP': '43', 'FN': '26', 'precision': '0.908', 'recall': '0.942', 'f1': '0.925'}
#
# Episode 6 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.161', 'efficiency': '0.282', 'TP': '389', 'FP': '37', 'FN': '24', 'precision': '0.913', 'recall': '0.942', 'f1': '0.927'}
#
# Episode 7 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.205', 'efficiency': '0.156', 'TP': '197', 'FP': '24', 'FN': '7', 'precision': '0.891', 'recall': '0.966', 'f1': '0.927'}
#
# Episode 8 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.161', 'efficiency': '0.282', 'TP': '395', 'FP': '32', 'FN': '15', 'precision': '0.925', 'recall': '0.963', 'f1': '0.944'}
#
# Episode 9 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.184', 'efficiency': '0.237', 'TP': '320', 'FP': '27', 'FN': '7', 'precision': '0.922', 'recall': '0.979', 'f1': '0.950'}
#
# Episode 10 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.780', 'ms1ms2_ratio': '0.252', 'efficiency': '0.216', 'TP': '271', 'FP': '17', 'FN': '11', 'precision': '0.941', 'recall': '0.961', 'f1': '0.951'}
#
# Episode 11 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.251', 'efficiency': '0.192', 'TP': '241', 'FP': '15', 'FN': '8', 'precision': '0.941', 'recall': '0.968', 'f1': '0.954'}
#
# Episode 12 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.205', 'efficiency': '0.229', 'TP': '307', 'FP': '18', 'FN': '10', 'precision': '0.945', 'recall': '0.968', 'f1': '0.956'}
#
# Episode 13 finished
# {'coverage_prop': '0.976', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.214', 'efficiency': '0.206', 'TP': '267', 'FP': '21', 'FN': '7', 'precision': '0.927', 'recall': '0.974', 'f1': '0.950'}
#
# Episode 14 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.168', 'efficiency': '0.270', 'TP': '380', 'FP': '24', 'FN': '12', 'precision': '0.941', 'recall': '0.969', 'f1': '0.955'}
#
# Episode 15 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.174', 'efficiency': '0.216', 'TP': '296', 'FP': '24', 'FN': '14', 'precision': '0.925', 'recall': '0.955', 'f1': '0.940'}
#
# Episode 16 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.797', 'ms1ms2_ratio': '0.263', 'efficiency': '0.202', 'TP': '252', 'FP': '13', 'FN': '10', 'precision': '0.951', 'recall': '0.962', 'f1': '0.956'}
#
# Episode 17 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.335', 'efficiency': '0.198', 'TP': '222', 'FP': '15', 'FN': '7', 'precision': '0.937', 'recall': '0.969', 'f1': '0.953'}
#
# Episode 18 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.161', 'efficiency': '0.251', 'TP': '350', 'FP': '30', 'FN': '12', 'precision': '0.921', 'recall': '0.967', 'f1': '0.943'}
#
# Episode 19 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.223', 'efficiency': '0.204', 'TP': '257', 'FP': '25', 'FN': '8', 'precision': '0.911', 'recall': '0.970', 'f1': '0.940'}
#
# Episode 20 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.168', 'efficiency': '0.286', 'TP': '387', 'FP': '41', 'FN': '13', 'precision': '0.904', 'recall': '0.968', 'f1': '0.935'}
#
# Episode 21 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.160', 'efficiency': '0.261', 'TP': '364', 'FP': '32', 'FN': '15', 'precision': '0.919', 'recall': '0.960', 'f1': '0.939'}
#
# Episode 22 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.154', 'efficiency': '0.273', 'TP': '382', 'FP': '35', 'FN': '16', 'precision': '0.916', 'recall': '0.960', 'f1': '0.937'}
#
# Episode 23 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.153', 'efficiency': '0.247', 'TP': '353', 'FP': '25', 'FN': '8', 'precision': '0.934', 'recall': '0.978', 'f1': '0.955'}
#
# Episode 24 finished
# {'coverage_prop': '0.963', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.266', 'efficiency': '0.181', 'TP': '217', 'FP': '19', 'FN': '9', 'precision': '0.919', 'recall': '0.960', 'f1': '0.939'}
#
# Episode 25 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.198', 'efficiency': '0.175', 'TP': '226', 'FP': '24', 'FN': '11', 'precision': '0.904', 'recall': '0.954', 'f1': '0.928'}
#
# Episode 26 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.158', 'efficiency': '0.278', 'TP': '390', 'FP': '32', 'FN': '14', 'precision': '0.924', 'recall': '0.965', 'f1': '0.944'}
#
# Episode 27 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.152', 'efficiency': '0.306', 'TP': '424', 'FP': '46', 'FN': '24', 'precision': '0.902', 'recall': '0.946', 'f1': '0.924'}
#
# Episode 28 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.292', 'efficiency': '0.184', 'TP': '221', 'FP': '11', 'FN': '14', 'precision': '0.953', 'recall': '0.940', 'f1': '0.946'}
#
# Episode 29 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.305', 'efficiency': '0.201', 'TP': '229', 'FP': '21', 'FN': '6', 'precision': '0.916', 'recall': '0.974', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1219.329719                1270.0          0.747           0.255
# 1  random   -1136.148048                1197.0          0.747           0.245
# 2  random    -933.111405                1015.0          0.783           0.285
# 3  random   -1092.842083                1161.0          0.756           0.265
# 4  random   -1415.121212                1465.0          0.664           0.188
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.007       0.100      0.313   0.481  0.379
# 1          0.008       0.134      0.304   0.473  0.370
# 2          0.007       0.182      0.356   0.561  0.435
# 3          0.007       0.154      0.349   0.520  0.417
# 4          0.004       0.153      0.271   0.349  0.305

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6.p')

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6.p')

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     366.507076                   0.0          0.932           0.725
# 31    DQN     368.249521                   0.0          0.923           0.691
# 32    DQN     337.745799                   0.0          0.878           0.614
# 33    DQN     346.635983                   2.0          0.915           0.674
# 34    DQN     350.212623                   4.0          0.873           0.615
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.421       0.227      0.911   0.926  0.918
# 31          0.445       0.307      0.855   0.911  0.883
# 32          0.520       0.412      0.785   0.850  0.816
# 33          0.462       0.354      0.818   0.899  0.856
# 34          0.475       0.388      0.799   0.846  0.822

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
