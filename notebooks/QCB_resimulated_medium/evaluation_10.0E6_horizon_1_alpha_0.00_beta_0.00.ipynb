# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO, MaskablePPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.00
env_beta = 0.00
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-04-03 17:59:06.300 | INFO     | vimms_gym.experiments:get_samplers:303 - Loaded /Users/joewandy/Work/git/vimms-gym.old/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe07fb7b2e0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe07fbe0c40>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe07fbfdde0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.0,
#    'beta': 0.0}},
#  30)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 30

dqn_in_dir = 'DQN_1.0E6'

# ppo_in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')
ppo_in_dir = 'PPO_10.0E6'

methods = [
    METHOD_RANDOM,
    METHOD_PPO,
    # METHOD_DQN,        
    METHOD_TOPN,
]
valid_random = True
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe07fb7b2e0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe07fbe0c40>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe07fbfdde0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe07fb7b2e0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe07fbe0c40>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe07fbfdde0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
horizon = 1
out_dir = 'evaluation_2.0E5_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(dqn_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(dqn_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(ppo_in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(ppo_in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = MaskablePPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon, valid_random=valid_random)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 331.6026689159926
# steps	 1000 	total rewards	 696.0741160585703
# steps	 1500 	total rewards	 1077.8572099029564
# Finished after 1787 timesteps (2.043158769607544 seconds) with total reward 1273.496954958856
# {'coverage_prop': '0.955', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.135', 'efficiency': '0.259', 'TP': '341', 'FP': '66', 'FN': '19', 'precision': '0.838', 'recall': '0.947', 'f1': '0.889', 'total_rewards': 1273.496954958858, 'invalid_action_count': 0, 'num_ms1_scans': 213, 'num_ms2_scans': 1574}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 309.10026456873493
# steps	 1000 	total rewards	 647.9098549816542
# steps	 1500 	total rewards	 995.3254272563652
# Finished after 1696 timesteps (1.3993549346923828 seconds) with total reward 1147.5923200880475
# {'coverage_prop': '0.924', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.218', 'efficiency': '0.174', 'TP': '220', 'FP': '22', 'FN': '20', 'precision': '0.909', 'recall': '0.917', 'f1': '0.913', 'total_rewards': 1147.5923200880484, 'invalid_action_count': 0, 'num_ms1_scans': 304, 'num_ms2_scans': 1392}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 320.14745294121974
# steps	 1000 	total rewards	 690.9495324626048
# steps	 1500 	total rewards	 1078.941812884635
# Finished after 1759 timesteps (1.7145991325378418 seconds) with total reward 1279.733936103058
# {'coverage_prop': '0.949', 'intensity_prop': '0.700', 'ms1ms2_ratio': '0.159', 'efficiency': '0.246', 'TP': '303', 'FP': '71', 'FN': '20', 'precision': '0.810', 'recall': '0.938', 'f1': '0.869', 'total_rewards': 1279.7339361030574, 'invalid_action_count': 0, 'num_ms1_scans': 241, 'num_ms2_scans': 1518}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 336.4177398524258
# steps	 1000 	total rewards	 698.0943807752752
# steps	 1500 	total rewards	 1061.9424694965148
# Finished after 1788 timesteps (1.9974868297576904 seconds) with total reward 1270.4184948184534
# {'coverage_prop': '0.942', 'intensity_prop': '0.718', 'ms1ms2_ratio': '0.135', 'efficiency': '0.270', 'TP': '376', 'FP': '50', 'FN': '26', 'precision': '0.883', 'recall': '0.935', 'f1': '0.908', 'total_rewards': 1270.4184948184568, 'invalid_action_count': 0, 'num_ms1_scans': 212, 'num_ms2_scans': 1576}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 298.1385639373528
# steps	 1000 	total rewards	 667.5822379312341
# steps	 1500 	total rewards	 1002.9321384186261
# Finished after 1776 timesteps (1.6946310997009277 seconds) with total reward 1187.846447150664
# {'coverage_prop': '0.938', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.144', 'efficiency': '0.264', 'TP': '336', 'FP': '74', 'FN': '27', 'precision': '0.820', 'recall': '0.926', 'f1': '0.869', 'total_rewards': 1187.8464471506647, 'invalid_action_count': 0, 'num_ms1_scans': 224, 'num_ms2_scans': 1552}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 296.66731562978856
# steps	 1000 	total rewards	 632.1713292992443
# steps	 1500 	total rewards	 964.4814034422112
# Finished after 1623 timesteps (1.8044960498809814 seconds) with total reward 1042.3662723030493
# {'coverage_prop': '0.950', 'intensity_prop': '0.803', 'ms1ms2_ratio': '0.303', 'efficiency': '0.152', 'TP': '178', 'FP': '12', 'FN': '10', 'precision': '0.937', 'recall': '0.947', 'f1': '0.942', 'total_rewards': 1042.366272303048, 'invalid_action_count': 0, 'num_ms1_scans': 377, 'num_ms2_scans': 1246}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 320.40915192643035
# steps	 1000 	total rewards	 684.2250816632368
# steps	 1500 	total rewards	 1041.176505141049
# Finished after 1788 timesteps (2.0939242839813232 seconds) with total reward 1231.1136765115682
# {'coverage_prop': '0.906', 'intensity_prop': '0.665', 'ms1ms2_ratio': '0.135', 'efficiency': '0.275', 'TP': '355', 'FP': '78', 'FN': '45', 'precision': '0.820', 'recall': '0.887', 'f1': '0.852', 'total_rewards': 1231.1136765115687, 'invalid_action_count': 0, 'num_ms1_scans': 212, 'num_ms2_scans': 1576}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 254.74998313782874
# steps	 1000 	total rewards	 610.5187380443077
# steps	 1500 	total rewards	 961.1730323416203
# Finished after 1642 timesteps (2.0563011169433594 seconds) with total reward 1057.151185524609
# {'coverage_prop': '0.941', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.279', 'efficiency': '0.150', 'TP': '183', 'FP': '9', 'FN': '12', 'precision': '0.953', 'recall': '0.938', 'f1': '0.946', 'total_rewards': 1057.1511855246085, 'invalid_action_count': 0, 'num_ms1_scans': 358, 'num_ms2_scans': 1284}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 338.8424422417718
# steps	 1000 	total rewards	 691.7140546879014
# steps	 1500 	total rewards	 1048.5279918053575
# Finished after 1793 timesteps (2.2422399520874023 seconds) with total reward 1266.7474279526505
# {'coverage_prop': '0.929', 'intensity_prop': '0.703', 'ms1ms2_ratio': '0.131', 'efficiency': '0.248', 'TP': '340', 'FP': '54', 'FN': '30', 'precision': '0.863', 'recall': '0.919', 'f1': '0.890', 'total_rewards': 1266.7474279526498, 'invalid_action_count': 0, 'num_ms1_scans': 207, 'num_ms2_scans': 1586}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 309.9351069781739
# steps	 1000 	total rewards	 675.7153558274734
# steps	 1500 	total rewards	 1046.4968275715855
# Finished after 1765 timesteps (1.5199029445648193 seconds) with total reward 1233.459850676115
# {'coverage_prop': '0.945', 'intensity_prop': '0.709', 'ms1ms2_ratio': '0.154', 'efficiency': '0.237', 'TP': '309', 'FP': '54', 'FN': '21', 'precision': '0.851', 'recall': '0.936', 'f1': '0.892', 'total_rewards': 1233.4598506761126, 'invalid_action_count': 0, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 332.47906170917906
# steps	 1000 	total rewards	 706.8811771615517
# steps	 1500 	total rewards	 1069.572451491932
# Finished after 1805 timesteps (2.703197956085205 seconds) with total reward 1287.0963064829111
# {'coverage_prop': '0.932', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.121', 'efficiency': '0.257', 'TP': '353', 'FP': '60', 'FN': '30', 'precision': '0.855', 'recall': '0.922', 'f1': '0.887', 'total_rewards': 1287.0963064829104, 'invalid_action_count': 0, 'num_ms1_scans': 195, 'num_ms2_scans': 1610}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 319.78424699320624
# steps	 1000 	total rewards	 654.3553148767184
# steps	 1500 	total rewards	 999.313606287821
# Finished after 1698 timesteps (1.475694179534912 seconds) with total reward 1131.272154172618
# {'coverage_prop': '0.948', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.216', 'efficiency': '0.169', 'TP': '218', 'FP': '18', 'FN': '13', 'precision': '0.924', 'recall': '0.944', 'f1': '0.934', 'total_rewards': 1131.2721541726178, 'invalid_action_count': 0, 'num_ms1_scans': 302, 'num_ms2_scans': 1396}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 306.22549683318664
# steps	 1000 	total rewards	 672.5572781048304
# steps	 1500 	total rewards	 1030.7390047566216
# Finished after 1740 timesteps (1.4302542209625244 seconds) with total reward 1196.9618636985892
# {'coverage_prop': '0.944', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.176', 'efficiency': '0.160', 'TP': '212', 'FP': '25', 'FN': '14', 'precision': '0.895', 'recall': '0.938', 'f1': '0.916', 'total_rewards': 1196.9618636985892, 'invalid_action_count': 0, 'num_ms1_scans': 260, 'num_ms2_scans': 1480}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 303.3985251497041
# steps	 1000 	total rewards	 644.7216525324097
# steps	 1500 	total rewards	 990.5775947782274
# Finished after 1753 timesteps (1.5961289405822754 seconds) with total reward 1106.7723119870293
# {'coverage_prop': '0.927', 'intensity_prop': '0.722', 'ms1ms2_ratio': '0.164', 'efficiency': '0.185', 'TP': '239', 'FP': '39', 'FN': '22', 'precision': '0.860', 'recall': '0.916', 'f1': '0.887', 'total_rewards': 1106.7723119870307, 'invalid_action_count': 0, 'num_ms1_scans': 247, 'num_ms2_scans': 1506}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 277.40130704295024
# steps	 1000 	total rewards	 642.6325716549388
# steps	 1500 	total rewards	 962.2214976967632
# Finished after 1681 timesteps (1.371009111404419 seconds) with total reward 1066.3704734768496
# {'coverage_prop': '0.942', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.142', 'TP': '174', 'FP': '20', 'FN': '12', 'precision': '0.897', 'recall': '0.935', 'f1': '0.916', 'total_rewards': 1066.3704734768505, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 310.10895445529945
# steps	 1000 	total rewards	 682.0336065959743
# steps	 1500 	total rewards	 1059.6801068941586
# Finished after 1755 timesteps (2.179218292236328 seconds) with total reward 1258.4414433804504
# {'coverage_prop': '0.943', 'intensity_prop': '0.737', 'ms1ms2_ratio': '0.162', 'efficiency': '0.254', 'TP': '342', 'FP': '42', 'FN': '23', 'precision': '0.891', 'recall': '0.937', 'f1': '0.913', 'total_rewards': 1258.4414433804482, 'invalid_action_count': 0, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 325.42212736477904
# steps	 1000 	total rewards	 705.7584303280315
# steps	 1500 	total rewards	 1066.7046957221226
# Finished after 1797 timesteps (1.8214681148529053 seconds) with total reward 1278.6795521648137
# {'coverage_prop': '0.942', 'intensity_prop': '0.713', 'ms1ms2_ratio': '0.128', 'efficiency': '0.294', 'TP': '408', 'FP': '61', 'FN': '29', 'precision': '0.870', 'recall': '0.934', 'f1': '0.901', 'total_rewards': 1278.6795521648157, 'invalid_action_count': 0, 'num_ms1_scans': 204, 'num_ms2_scans': 1593}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 329.74263749560856
# steps	 1000 	total rewards	 677.3343720301725
# steps	 1500 	total rewards	 1044.929319051367
# Finished after 1766 timesteps (1.527235984802246 seconds) with total reward 1231.7010852634985
# {'coverage_prop': '0.941', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.153', 'efficiency': '0.228', 'TP': '296', 'FP': '54', 'FN': '22', 'precision': '0.846', 'recall': '0.931', 'f1': '0.886', 'total_rewards': 1231.7010852634996, 'invalid_action_count': 0, 'num_ms1_scans': 234, 'num_ms2_scans': 1532}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 315.1857154235074
# steps	 1000 	total rewards	 680.6735214514604
# steps	 1500 	total rewards	 1043.1287067292114
# Finished after 1726 timesteps (1.5649099349975586 seconds) with total reward 1208.3996354408673
# {'coverage_prop': '0.960', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.189', 'efficiency': '0.200', 'TP': '249', 'FP': '41', 'FN': '12', 'precision': '0.859', 'recall': '0.954', 'f1': '0.904', 'total_rewards': 1208.3996354408691, 'invalid_action_count': 0, 'num_ms1_scans': 274, 'num_ms2_scans': 1452}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 305.685953256148
# steps	 1000 	total rewards	 670.0569795853054
# steps	 1500 	total rewards	 1038.1029890447296
# Finished after 1743 timesteps (1.4760823249816895 seconds) with total reward 1210.0950022868478
# {'coverage_prop': '0.958', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.173', 'efficiency': '0.171', 'TP': '228', 'FP': '26', 'FN': '11', 'precision': '0.898', 'recall': '0.954', 'f1': '0.925', 'total_rewards': 1210.0950022868492, 'invalid_action_count': 0, 'num_ms1_scans': 257, 'num_ms2_scans': 1486}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 307.1398655484116
# steps	 1000 	total rewards	 659.8014350386975
# steps	 1500 	total rewards	 999.4283085254281
# Finished after 1789 timesteps (2.638451099395752 seconds) with total reward 1205.1761301495462
# {'coverage_prop': '0.900', 'intensity_prop': '0.674', 'ms1ms2_ratio': '0.134', 'efficiency': '0.267', 'TP': '358', 'FP': '63', 'FN': '47', 'precision': '0.850', 'recall': '0.884', 'f1': '0.867', 'total_rewards': 1205.1761301495467, 'invalid_action_count': 0, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 312.0547708424849
# steps	 1000 	total rewards	 671.7414159215608
# steps	 1500 	total rewards	 1037.7069230583509
# Finished after 1664 timesteps (1.5349631309509277 seconds) with total reward 1130.203852877641
# {'coverage_prop': '0.944', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.254', 'efficiency': '0.167', 'TP': '201', 'FP': '20', 'FN': '13', 'precision': '0.910', 'recall': '0.939', 'f1': '0.924', 'total_rewards': 1130.2038528776409, 'invalid_action_count': 0, 'num_ms1_scans': 337, 'num_ms2_scans': 1327}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 310.7491752940059
# steps	 1000 	total rewards	 676.3349867251852
# steps	 1500 	total rewards	 1018.3708490544138
# Finished after 1750 timesteps (1.4897081851959229 seconds) with total reward 1207.8159984506403
# {'coverage_prop': '0.947', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.167', 'efficiency': '0.203', 'TP': '275', 'FP': '30', 'FN': '17', 'precision': '0.902', 'recall': '0.942', 'f1': '0.921', 'total_rewards': 1207.8159984506408, 'invalid_action_count': 0, 'num_ms1_scans': 250, 'num_ms2_scans': 1500}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 303.1150449532034
# steps	 1000 	total rewards	 661.2462757107932
# steps	 1500 	total rewards	 1026.9038967327638
# Finished after 1703 timesteps (2.6078341007232666 seconds) with total reward 1173.2154447541964
# {'coverage_prop': '0.945', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.211', 'efficiency': '0.208', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 1173.2154447541975, 'invalid_action_count': 0, 'num_ms1_scans': 297, 'num_ms2_scans': 1406}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 309.22065060126
# steps	 1000 	total rewards	 680.3187343037991
# steps	 1500 	total rewards	 1045.2828775074481
# Finished after 1765 timesteps (1.4655961990356445 seconds) with total reward 1259.740710220236
# {'coverage_prop': '0.959', 'intensity_prop': '0.733', 'ms1ms2_ratio': '0.154', 'efficiency': '0.216', 'TP': '297', 'FP': '34', 'FN': '14', 'precision': '0.897', 'recall': '0.955', 'f1': '0.925', 'total_rewards': 1259.7407102202376, 'invalid_action_count': 0, 'num_ms1_scans': 235, 'num_ms2_scans': 1530}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 330.6881575168562
# steps	 1000 	total rewards	 691.5035019093153
# steps	 1500 	total rewards	 1079.6723649763953
# Finished after 1766 timesteps (1.5809848308563232 seconds) with total reward 1275.603589981545
# {'coverage_prop': '0.955', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.153', 'efficiency': '0.247', 'TP': '330', 'FP': '48', 'FN': '18', 'precision': '0.873', 'recall': '0.948', 'f1': '0.909', 'total_rewards': 1275.603589981544, 'invalid_action_count': 0, 'num_ms1_scans': 234, 'num_ms2_scans': 1532}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 271.22416447521005
# steps	 1000 	total rewards	 637.9214410150614
# steps	 1500 	total rewards	 990.6337510405508
# Finished after 1660 timesteps (2.303375005722046 seconds) with total reward 1091.474241659861
# {'coverage_prop': '0.951', 'intensity_prop': '0.803', 'ms1ms2_ratio': '0.258', 'efficiency': '0.146', 'TP': '184', 'FP': '9', 'FN': '10', 'precision': '0.953', 'recall': '0.948', 'f1': '0.951', 'total_rewards': 1091.4742416598613, 'invalid_action_count': 0, 'num_ms1_scans': 340, 'num_ms2_scans': 1320}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 294.80827218530453
# steps	 1000 	total rewards	 639.6184078973715
# steps	 1500 	total rewards	 998.7721121684001
# Finished after 1692 timesteps (1.459723711013794 seconds) with total reward 1144.3811914573946
# {'coverage_prop': '0.947', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.223', 'efficiency': '0.192', 'TP': '241', 'FP': '25', 'FN': '15', 'precision': '0.906', 'recall': '0.941', 'f1': '0.923', 'total_rewards': 1144.3811914573937, 'invalid_action_count': 0, 'num_ms1_scans': 308, 'num_ms2_scans': 1384}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 316.17819265771976
# steps	 1000 	total rewards	 662.4414103562459
# steps	 1500 	total rewards	 1048.4845751158136
# Finished after 1812 timesteps (1.7502830028533936 seconds) with total reward 1278.685680385046
# {'coverage_prop': '0.876', 'intensity_prop': '0.642', 'ms1ms2_ratio': '0.116', 'efficiency': '0.266', 'TP': '360', 'FP': '72', 'FN': '61', 'precision': '0.833', 'recall': '0.855', 'f1': '0.844', 'total_rewards': 1278.6856803850455, 'invalid_action_count': 0, 'num_ms1_scans': 188, 'num_ms2_scans': 1624}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 286.8810660753269
# steps	 1000 	total rewards	 655.834487918032
# steps	 1500 	total rewards	 1021.913673270255
# Finished after 1726 timesteps (1.5478150844573975 seconds) with total reward 1178.8757999002344
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.190', 'efficiency': '0.201', 'TP': '253', 'FP': '38', 'FN': '13', 'precision': '0.869', 'recall': '0.951', 'f1': '0.908', 'total_rewards': 1178.8757999002341, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# method = PPO max_peaks = 30 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 359.112218326517
# steps	 1000 	total rewards	 729.059429235524
# steps	 1500 	total rewards	 1116.0059107408954
# Finished after 1861 timesteps (3.5065557956695557 seconds) with total reward 1383.2704635727068
# {'coverage_prop': '0.953', 'intensity_prop': '0.718', 'ms1ms2_ratio': '0.081', 'efficiency': '0.236', 'TP': '346', 'FP': '60', 'FN': '20', 'precision': '0.852', 'recall': '0.945', 'f1': '0.896', 'total_rewards': 1383.2704635727057, 'invalid_action_count': 0, 'num_ms1_scans': 139, 'num_ms2_scans': 1722}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 342.7696392421338
# steps	 1000 	total rewards	 721.0794983855219
# steps	 1500 	total rewards	 1090.1263765040524
# Finished after 1801 timesteps (1.8784589767456055 seconds) with total reward 1327.6001265389039
# {'coverage_prop': '0.950', 'intensity_prop': '0.804', 'ms1ms2_ratio': '0.124', 'efficiency': '0.155', 'TP': '234', 'FP': '15', 'FN': '13', 'precision': '0.940', 'recall': '0.947', 'f1': '0.944', 'total_rewards': 1327.600126538902, 'invalid_action_count': 0, 'num_ms1_scans': 199, 'num_ms2_scans': 1602}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 352.3278063172412
# steps	 1000 	total rewards	 738.7754416020265
# steps	 1500 	total rewards	 1137.3539357081766
# Finished after 1842 timesteps (2.100720167160034 seconds) with total reward 1413.0120045472854
# {'coverage_prop': '0.959', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.094', 'efficiency': '0.224', 'TP': '326', 'FP': '52', 'FN': '16', 'precision': '0.862', 'recall': '0.953', 'f1': '0.906', 'total_rewards': 1413.0120045472845, 'invalid_action_count': 0, 'num_ms1_scans': 158, 'num_ms2_scans': 1684}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 352.6310688792715
# steps	 1000 	total rewards	 728.0972252875426
# steps	 1500 	total rewards	 1103.1907525399786
# Finished after 1859 timesteps (2.0982699394226074 seconds) with total reward 1372.9593598540978
# {'coverage_prop': '0.947', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.082', 'efficiency': '0.249', 'TP': '376', 'FP': '52', 'FN': '24', 'precision': '0.879', 'recall': '0.940', 'f1': '0.908', 'total_rewards': 1372.9593598540969, 'invalid_action_count': 0, 'num_ms1_scans': 141, 'num_ms2_scans': 1718}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 327.29796805173646
# steps	 1000 	total rewards	 702.4067241237274
# steps	 1500 	total rewards	 1060.5444434509886
# Finished after 1852 timesteps (2.143793821334839 seconds) with total reward 1303.7624398754874
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.087', 'efficiency': '0.249', 'TP': '358', 'FP': '66', 'FN': '13', 'precision': '0.844', 'recall': '0.965', 'f1': '0.901', 'total_rewards': 1303.7624398754858, 'invalid_action_count': 0, 'num_ms1_scans': 148, 'num_ms2_scans': 1704}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 340.11760448069543
# steps	 1000 	total rewards	 703.9412938522856
# steps	 1500 	total rewards	 1089.7114920372273
# Finished after 1755 timesteps (3.620361089706421 seconds) with total reward 1263.4794728023073
# {'coverage_prop': '0.950', 'intensity_prop': '0.823', 'ms1ms2_ratio': '0.162', 'efficiency': '0.126', 'TP': '181', 'FP': '9', 'FN': '10', 'precision': '0.953', 'recall': '0.948', 'f1': '0.950', 'total_rewards': 1263.479472802307, 'invalid_action_count': 0, 'num_ms1_scans': 245, 'num_ms2_scans': 1510}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 341.4341144470882
# steps	 1000 	total rewards	 719.0530576272348
# steps	 1500 	total rewards	 1095.8904846741734
# Finished after 1862 timesteps (2.1570210456848145 seconds) with total reward 1344.3642597622816
# {'coverage_prop': '0.944', 'intensity_prop': '0.697', 'ms1ms2_ratio': '0.080', 'efficiency': '0.262', 'TP': '375', 'FP': '76', 'FN': '27', 'precision': '0.831', 'recall': '0.933', 'f1': '0.879', 'total_rewards': 1344.3642597622809, 'invalid_action_count': 0, 'num_ms1_scans': 138, 'num_ms2_scans': 1724}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 301.50428318069714
# steps	 1000 	total rewards	 679.6519454173487
# steps	 1500 	total rewards	 1073.2228309540133
# Finished after 1769 timesteps (1.7613239288330078 seconds) with total reward 1269.7259600303987
# {'coverage_prop': '0.951', 'intensity_prop': '0.816', 'ms1ms2_ratio': '0.150', 'efficiency': '0.126', 'TP': '188', 'FP': '6', 'FN': '10', 'precision': '0.969', 'recall': '0.949', 'f1': '0.959', 'total_rewards': 1269.725960030399, 'invalid_action_count': 0, 'num_ms1_scans': 231, 'num_ms2_scans': 1538}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 359.73423264028025
# steps	 1000 	total rewards	 735.4749631208908
# steps	 1500 	total rewards	 1116.7923707672362
# Finished after 1871 timesteps (2.0279831886291504 seconds) with total reward 1394.2266093184471
# {'coverage_prop': '0.943', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.074', 'efficiency': '0.230', 'TP': '350', 'FP': '50', 'FN': '24', 'precision': '0.875', 'recall': '0.936', 'f1': '0.904', 'total_rewards': 1394.226609318451, 'invalid_action_count': 0, 'num_ms1_scans': 129, 'num_ms2_scans': 1742}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 342.7078378433903
# steps	 1000 	total rewards	 720.6841408120536
# steps	 1500 	total rewards	 1111.0665362621571
# Finished after 1851 timesteps (1.9633049964904785 seconds) with total reward 1374.9151686797716
# {'coverage_prop': '0.958', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.088', 'efficiency': '0.216', 'TP': '331', 'FP': '37', 'FN': '16', 'precision': '0.899', 'recall': '0.954', 'f1': '0.926', 'total_rewards': 1374.9151686797697, 'invalid_action_count': 0, 'num_ms1_scans': 149, 'num_ms2_scans': 1702}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 349.76483892974125
# steps	 1000 	total rewards	 741.0756814911624
# steps	 1500 	total rewards	 1124.225179969902
# Finished after 1875 timesteps (2.2165751457214355 seconds) with total reward 1404.6133365375067
# {'coverage_prop': '0.946', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.071', 'efficiency': '0.239', 'TP': '368', 'FP': '51', 'FN': '24', 'precision': '0.878', 'recall': '0.939', 'f1': '0.908', 'total_rewards': 1404.6133365375067, 'invalid_action_count': 0, 'num_ms1_scans': 125, 'num_ms2_scans': 1750}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 351.1362369105345
# steps	 1000 	total rewards	 713.9541129387674
# steps	 1500 	total rewards	 1082.1494481133627
# Finished after 1794 timesteps (6.417745113372803 seconds) with total reward 1288.038185654184
# {'coverage_prop': '0.948', 'intensity_prop': '0.798', 'ms1ms2_ratio': '0.130', 'efficiency': '0.149', 'TP': '222', 'FP': '14', 'FN': '13', 'precision': '0.941', 'recall': '0.945', 'f1': '0.943', 'total_rewards': 1288.038185654184, 'invalid_action_count': 0, 'num_ms1_scans': 206, 'num_ms2_scans': 1588}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 326.54071975819863
# steps	 1000 	total rewards	 706.8628484133011
# steps	 1500 	total rewards	 1087.3721459172057
# Finished after 1834 timesteps (1.8779950141906738 seconds) with total reward 1327.7541288203902
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.100', 'efficiency': '0.143', 'TP': '211', 'FP': '27', 'FN': '13', 'precision': '0.887', 'recall': '0.942', 'f1': '0.913', 'total_rewards': 1327.7541288203915, 'invalid_action_count': 0, 'num_ms1_scans': 167, 'num_ms2_scans': 1667}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 327.01052455597903
# steps	 1000 	total rewards	 695.163348994143
# steps	 1500 	total rewards	 1052.6986809525235
# Finished after 1835 timesteps (2.008958101272583 seconds) with total reward 1227.4206779800863
# {'coverage_prop': '0.940', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.099', 'efficiency': '0.169', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 1227.4206779800857, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 310.8106127131667
# steps	 1000 	total rewards	 689.6306394236994
# steps	 1500 	total rewards	 1053.3650119883719
# Finished after 1789 timesteps (1.962925910949707 seconds) with total reward 1231.8258226173512
# {'coverage_prop': '0.947', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.134', 'efficiency': '0.124', 'TP': '176', 'FP': '19', 'FN': '11', 'precision': '0.903', 'recall': '0.941', 'f1': '0.921', 'total_rewards': 1231.82582261735, 'invalid_action_count': 0, 'num_ms1_scans': 211, 'num_ms2_scans': 1578}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 337.1814382516727
# steps	 1000 	total rewards	 730.206971825241
# steps	 1500 	total rewards	 1115.0021350624454
# Finished after 1840 timesteps (2.103384256362915 seconds) with total reward 1395.3782249616402
# {'coverage_prop': '0.966', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.095', 'efficiency': '0.234', 'TP': '348', 'FP': '45', 'FN': '14', 'precision': '0.885', 'recall': '0.961', 'f1': '0.922', 'total_rewards': 1395.3782249616393, 'invalid_action_count': 0, 'num_ms1_scans': 160, 'num_ms2_scans': 1680}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 340.8360862499079
# steps	 1000 	total rewards	 732.2225473614135
# steps	 1500 	total rewards	 1106.3519063337935
# Finished after 1865 timesteps (4.239201068878174 seconds) with total reward 1377.8291904883995
# {'coverage_prop': '0.958', 'intensity_prop': '0.730', 'ms1ms2_ratio': '0.078', 'efficiency': '0.276', 'TP': '421', 'FP': '56', 'FN': '21', 'precision': '0.883', 'recall': '0.952', 'f1': '0.916', 'total_rewards': 1377.829190488399, 'invalid_action_count': 0, 'num_ms1_scans': 135, 'num_ms2_scans': 1730}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 362.6782684733958
# steps	 1000 	total rewards	 732.9044081119656
# steps	 1500 	total rewards	 1109.3932679614195
# Finished after 1850 timesteps (1.9563510417938232 seconds) with total reward 1371.9784847089925
# {'coverage_prop': '0.946', 'intensity_prop': '0.741', 'ms1ms2_ratio': '0.088', 'efficiency': '0.207', 'TP': '314', 'FP': '38', 'FN': '20', 'precision': '0.892', 'recall': '0.940', 'f1': '0.915', 'total_rewards': 1371.9784847089913, 'invalid_action_count': 0, 'num_ms1_scans': 150, 'num_ms2_scans': 1700}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 352.36782544447243
# steps	 1000 	total rewards	 736.1635571104566
# steps	 1500 	total rewards	 1115.5323084630645
# Finished after 1826 timesteps (1.9106559753417969 seconds) with total reward 1369.0227803243743
# {'coverage_prop': '0.960', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.105', 'efficiency': '0.176', 'TP': '267', 'FP': '23', 'FN': '12', 'precision': '0.921', 'recall': '0.957', 'f1': '0.938', 'total_rewards': 1369.0227803243745, 'invalid_action_count': 0, 'num_ms1_scans': 174, 'num_ms2_scans': 1652}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 341.5111923100569
# steps	 1000 	total rewards	 713.6258201719967
# steps	 1500 	total rewards	 1103.962410087273
# Finished after 1831 timesteps (2.348479986190796 seconds) with total reward 1350.9730975918565
# {'coverage_prop': '0.974', 'intensity_prop': '0.793', 'ms1ms2_ratio': '0.102', 'efficiency': '0.155', 'TP': '234', 'FP': '24', 'FN': '7', 'precision': '0.907', 'recall': '0.971', 'f1': '0.938', 'total_rewards': 1350.973097591856, 'invalid_action_count': 0, 'num_ms1_scans': 169, 'num_ms2_scans': 1662}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 328.82320790042775
# steps	 1000 	total rewards	 695.7903691563718
# steps	 1500 	total rewards	 1047.228648746808
# Finished after 1862 timesteps (2.538252592086792 seconds) with total reward 1308.1623916283224
# {'coverage_prop': '0.934', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.080', 'efficiency': '0.253', 'TP': '380', 'FP': '57', 'FN': '31', 'precision': '0.870', 'recall': '0.925', 'f1': '0.896', 'total_rewards': 1308.1623916283247, 'invalid_action_count': 0, 'num_ms1_scans': 138, 'num_ms2_scans': 1724}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 359.1922199152878
# steps	 1000 	total rewards	 742.2919541881116
# steps	 1500 	total rewards	 1137.066664124098
# Finished after 1779 timesteps (1.8966560363769531 seconds) with total reward 1327.8482776955948
# {'coverage_prop': '0.944', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.142', 'efficiency': '0.142', 'TP': '203', 'FP': '18', 'FN': '13', 'precision': '0.919', 'recall': '0.940', 'f1': '0.929', 'total_rewards': 1327.8482776955934, 'invalid_action_count': 0, 'num_ms1_scans': 221, 'num_ms2_scans': 1558}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 347.1335283587124
# steps	 1000 	total rewards	 732.6135675324898
# steps	 1500 	total rewards	 1090.8414685596226
# Finished after 1835 timesteps (1.980071783065796 seconds) with total reward 1349.9451365954933
# {'coverage_prop': '0.957', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.099', 'efficiency': '0.184', 'TP': '279', 'FP': '29', 'FN': '14', 'precision': '0.906', 'recall': '0.952', 'f1': '0.928', 'total_rewards': 1349.9451365954942, 'invalid_action_count': 0, 'num_ms1_scans': 165, 'num_ms2_scans': 1670}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 337.921536744603
# steps	 1000 	total rewards	 715.1741589678275
# steps	 1500 	total rewards	 1113.8689197657159
# Finished after 1809 timesteps (4.163616180419922 seconds) with total reward 1344.1662199881334
# {'coverage_prop': '0.939', 'intensity_prop': '0.752', 'ms1ms2_ratio': '0.119', 'efficiency': '0.180', 'TP': '264', 'FP': '27', 'FN': '19', 'precision': '0.907', 'recall': '0.933', 'f1': '0.920', 'total_rewards': 1344.166219988135, 'invalid_action_count': 0, 'num_ms1_scans': 192, 'num_ms2_scans': 1617}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 334.1441987257906
# steps	 1000 	total rewards	 720.7694056271059
# steps	 1500 	total rewards	 1100.3055104531013
# Finished after 1838 timesteps (1.9148609638214111 seconds) with total reward 1381.0732946632206
# {'coverage_prop': '0.977', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.097', 'efficiency': '0.201', 'TP': '296', 'FP': '41', 'FN': '8', 'precision': '0.878', 'recall': '0.974', 'f1': '0.924', 'total_rewards': 1381.073294663221, 'invalid_action_count': 0, 'num_ms1_scans': 162, 'num_ms2_scans': 1676}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 367.57638029247727
# steps	 1000 	total rewards	 745.0717717709206
# steps	 1500 	total rewards	 1148.7467592075986
# Finished after 1863 timesteps (2.0308501720428467 seconds) with total reward 1429.7828170110822
# {'coverage_prop': '0.972', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.079', 'efficiency': '0.223', 'TP': '337', 'FP': '48', 'FN': '11', 'precision': '0.875', 'recall': '0.968', 'f1': '0.920', 'total_rewards': 1429.782817011085, 'invalid_action_count': 0, 'num_ms1_scans': 137, 'num_ms2_scans': 1726}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 298.3611355914739
# steps	 1000 	total rewards	 700.0646274456017
# steps	 1500 	total rewards	 1084.0801570053648
# Finished after 1775 timesteps (1.806689977645874 seconds) with total reward 1278.9604822850179
# {'coverage_prop': '0.956', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.145', 'efficiency': '0.125', 'TP': '189', 'FP': '5', 'FN': '9', 'precision': '0.974', 'recall': '0.955', 'f1': '0.964', 'total_rewards': 1278.96048228502, 'invalid_action_count': 0, 'num_ms1_scans': 225, 'num_ms2_scans': 1550}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 325.7633947745666
# steps	 1000 	total rewards	 702.989671412377
# steps	 1500 	total rewards	 1090.062620064826
# Finished after 1806 timesteps (1.7950961589813232 seconds) with total reward 1332.2821596108947
# {'coverage_prop': '0.957', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.120', 'efficiency': '0.167', 'TP': '252', 'FP': '17', 'FN': '12', 'precision': '0.937', 'recall': '0.955', 'f1': '0.946', 'total_rewards': 1332.2821596108963, 'invalid_action_count': 0, 'num_ms1_scans': 194, 'num_ms2_scans': 1612}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 337.5624581840991
# steps	 1000 	total rewards	 697.9860338334117
# steps	 1500 	total rewards	 1087.3110197708215
# Finished after 1876 timesteps (2.14041805267334 seconds) with total reward 1380.5021441883969
# {'coverage_prop': '0.927', 'intensity_prop': '0.674', 'ms1ms2_ratio': '0.071', 'efficiency': '0.261', 'TP': '382', 'FP': '75', 'FN': '36', 'precision': '0.836', 'recall': '0.914', 'f1': '0.873', 'total_rewards': 1380.5021441883957, 'invalid_action_count': 0, 'num_ms1_scans': 124, 'num_ms2_scans': 1752}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 312.6529677847492
# steps	 1000 	total rewards	 715.4046579640456
# steps	 1500 	total rewards	 1099.6123647681015
# Finished after 1830 timesteps (1.912627935409546 seconds) with total reward 1348.5411964572586
# {'coverage_prop': '0.957', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.102', 'efficiency': '0.175', 'TP': '272', 'FP': '19', 'FN': '13', 'precision': '0.935', 'recall': '0.954', 'f1': '0.944', 'total_rewards': 1348.541196457257, 'invalid_action_count': 0, 'num_ms1_scans': 170, 'num_ms2_scans': 1660}
#
# method = topN max_peaks = 30 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 273.95025783299354
# steps	 1000 	total rewards	 632.1464291944101
# steps	 1500 	total rewards	 996.3654258348306
# Finished after 1700 timesteps (6.26281213760376 seconds) with total reward 1129.8846891815397
# {'coverage_prop': '0.960', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.214', 'efficiency': '0.292', 'TP': '369', 'FP': '40', 'FN': '17', 'precision': '0.902', 'recall': '0.956', 'f1': '0.928', 'total_rewards': 1129.8846891815394, 'invalid_action_count': 0, 'num_ms1_scans': 300, 'num_ms2_scans': 1400}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 229.41260629078988
# steps	 1000 	total rewards	 537.8172837978411
# steps	 1500 	total rewards	 857.5694138380727
# Finished after 1529 timesteps (5.928452730178833 seconds) with total reward 872.2558659388384
# {'coverage_prop': '0.962', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.447', 'efficiency': '0.238', 'TP': '238', 'FP': '14', 'FN': '10', 'precision': '0.944', 'recall': '0.960', 'f1': '0.952', 'total_rewards': 872.2558659388383, 'invalid_action_count': 0, 'num_ms1_scans': 472, 'num_ms2_scans': 1057}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 232.52164002907313
# steps	 1000 	total rewards	 603.3526935269456
# steps	 1500 	total rewards	 980.4194615427019
# Finished after 1647 timesteps (6.332236051559448 seconds) with total reward 1088.0457206383016
# {'coverage_prop': '0.967', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.273', 'efficiency': '0.294', 'TP': '346', 'FP': '35', 'FN': '13', 'precision': '0.908', 'recall': '0.964', 'f1': '0.935', 'total_rewards': 1088.0457206383016, 'invalid_action_count': 0, 'num_ms1_scans': 353, 'num_ms2_scans': 1294}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 293.01178590688176
# steps	 1000 	total rewards	 633.0618939387339
# steps	 1500 	total rewards	 973.8004080911539
# Finished after 1690 timesteps (6.326735019683838 seconds) with total reward 1106.633292921459
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933', 'total_rewards': 1106.6332929214584, 'invalid_action_count': 0, 'num_ms1_scans': 311, 'num_ms2_scans': 1379}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 250.48286926358855
# steps	 1000 	total rewards	 600.4263149930786
# steps	 1500 	total rewards	 926.2631525526672
# Finished after 1678 timesteps (6.384968996047974 seconds) with total reward 1040.1407112553427
# {'coverage_prop': '0.982', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.237', 'efficiency': '0.316', 'TP': '380', 'FP': '49', 'FN': '8', 'precision': '0.886', 'recall': '0.979', 'f1': '0.930', 'total_rewards': 1040.140711255342, 'invalid_action_count': 0, 'num_ms1_scans': 322, 'num_ms2_scans': 1356}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 180.3370440427603
# steps	 1000 	total rewards	 472.83849707742047
# Finished after 1385 timesteps (5.483127117156982 seconds) with total reward 636.8991051429923
# {'coverage_prop': '0.955', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.799', 'efficiency': '0.248', 'TP': '182', 'FP': '9', 'FN': '9', 'precision': '0.953', 'recall': '0.953', 'f1': '0.953', 'total_rewards': 636.8991051429923, 'invalid_action_count': 0, 'num_ms1_scans': 615, 'num_ms2_scans': 770}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 284.891380941045
# steps	 1000 	total rewards	 644.9266081713737
# steps	 1500 	total rewards	 992.7860122617468
# Finished after 1720 timesteps (8.287446022033691 seconds) with total reward 1132.8708905277754
# {'coverage_prop': '0.935', 'intensity_prop': '0.729', 'ms1ms2_ratio': '0.194', 'efficiency': '0.310', 'TP': '396', 'FP': '51', 'FN': '31', 'precision': '0.886', 'recall': '0.927', 'f1': '0.906', 'total_rewards': 1132.8708905277742, 'invalid_action_count': 0, 'num_ms1_scans': 280, 'num_ms2_scans': 1440}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 166.2177974106953
# steps	 1000 	total rewards	 507.3518810033895
# Finished after 1444 timesteps (5.603071212768555 seconds) with total reward 734.5859627054797
# {'coverage_prop': '0.966', 'intensity_prop': '0.790', 'ms1ms2_ratio': '0.626', 'efficiency': '0.222', 'TP': '187', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.957', 'total_rewards': 734.5859627054798, 'invalid_action_count': 0, 'num_ms1_scans': 556, 'num_ms2_scans': 888}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 290.07035162729187
# steps	 1000 	total rewards	 640.511504451742
# steps	 1500 	total rewards	 983.8297958372451
# Finished after 1706 timesteps (6.769622802734375 seconds) with total reward 1124.8872199096352
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931', 'total_rewards': 1124.8872199096359, 'invalid_action_count': 0, 'num_ms1_scans': 294, 'num_ms2_scans': 1412}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 238.12785645170604
# steps	 1000 	total rewards	 596.13722191973
# steps	 1500 	total rewards	 950.0954401152339
# Finished after 1644 timesteps (7.546439170837402 seconds) with total reward 1045.903318093565
# {'coverage_prop': '0.958', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.276', 'efficiency': '0.286', 'TP': '339', 'FP': '29', 'FN': '16', 'precision': '0.921', 'recall': '0.955', 'f1': '0.938', 'total_rewards': 1045.9033180935662, 'invalid_action_count': 0, 'num_ms1_scans': 356, 'num_ms2_scans': 1288}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 284.1591672431688
# steps	 1000 	total rewards	 653.0562093628018
# steps	 1500 	total rewards	 1002.3775053829545
# Finished after 1723 timesteps (6.165427923202515 seconds) with total reward 1163.867126499591
# {'coverage_prop': '0.948', 'intensity_prop': '0.748', 'ms1ms2_ratio': '0.192', 'efficiency': '0.290', 'TP': '380', 'FP': '40', 'FN': '23', 'precision': '0.905', 'recall': '0.943', 'f1': '0.923', 'total_rewards': 1163.8671264995883, 'invalid_action_count': 0, 'num_ms1_scans': 277, 'num_ms2_scans': 1446}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 210.37332353275934
# steps	 1000 	total rewards	 539.1517887473158
# steps	 1500 	total rewards	 807.1142419038486
# Finished after 1501 timesteps (7.1076061725616455 seconds) with total reward 807.1142419038486
# {'coverage_prop': '0.960', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '226', 'FP': '13', 'FN': '10', 'precision': '0.946', 'recall': '0.958', 'f1': '0.952', 'total_rewards': 807.1142419038486, 'invalid_action_count': 0, 'num_ms1_scans': 500, 'num_ms2_scans': 1001}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 219.41816350422033
# steps	 1000 	total rewards	 576.6797588123295
# steps	 1500 	total rewards	 891.252989739042
# Finished after 1577 timesteps (5.8642659187316895 seconds) with total reward 930.0356347364732
# {'coverage_prop': '0.948', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.367', 'efficiency': '0.206', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925', 'total_rewards': 930.0356347364731, 'invalid_action_count': 0, 'num_ms1_scans': 423, 'num_ms2_scans': 1154}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 232.1765634650393
# steps	 1000 	total rewards	 553.2634871041186
# steps	 1500 	total rewards	 858.020606957378
# Finished after 1624 timesteps (6.0103538036346436 seconds) with total reward 909.3144896541211
# {'coverage_prop': '0.967', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.301', 'efficiency': '0.232', 'TP': '261', 'FP': '29', 'FN': '10', 'precision': '0.900', 'recall': '0.963', 'f1': '0.930', 'total_rewards': 909.3144896541208, 'invalid_action_count': 0, 'num_ms1_scans': 376, 'num_ms2_scans': 1248}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 176.08797885875697
# steps	 1000 	total rewards	 520.029015774475
# Finished after 1472 timesteps (5.511244058609009 seconds) with total reward 747.5458008746018
# {'coverage_prop': '0.956', 'intensity_prop': '0.774', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941', 'total_rewards': 747.545800874601, 'invalid_action_count': 0, 'num_ms1_scans': 528, 'num_ms2_scans': 944}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 243.13516317494003
# steps	 1000 	total rewards	 600.7239929707055
# steps	 1500 	total rewards	 949.7149874737602
# Finished after 1627 timesteps (7.772131681442261 seconds) with total reward 1041.3075304875135
# {'coverage_prop': '0.966', 'intensity_prop': '0.776', 'ms1ms2_ratio': '0.297', 'efficiency': '0.313', 'TP': '366', 'FP': '27', 'FN': '14', 'precision': '0.931', 'recall': '0.963', 'f1': '0.947', 'total_rewards': 1041.3075304875122, 'invalid_action_count': 0, 'num_ms1_scans': 373, 'num_ms2_scans': 1254}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 277.9967487857566
# steps	 1000 	total rewards	 654.8257650120039
# steps	 1500 	total rewards	 1003.7400374273435
# Finished after 1712 timesteps (6.252764940261841 seconds) with total reward 1144.4501385053047
# {'coverage_prop': '0.958', 'intensity_prop': '0.757', 'ms1ms2_ratio': '0.202', 'efficiency': '0.335', 'TP': '437', 'FP': '40', 'FN': '21', 'precision': '0.916', 'recall': '0.954', 'f1': '0.935', 'total_rewards': 1144.450138505306, 'invalid_action_count': 0, 'num_ms1_scans': 288, 'num_ms2_scans': 1424}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 267.7540753310658
# steps	 1000 	total rewards	 610.2446564076422
# steps	 1500 	total rewards	 956.9775708597356
# Finished after 1654 timesteps (5.960093021392822 seconds) with total reward 1047.8539761522024
# {'coverage_prop': '0.965', 'intensity_prop': '0.775', 'ms1ms2_ratio': '0.265', 'efficiency': '0.274', 'TP': '329', 'FP': '30', 'FN': '13', 'precision': '0.916', 'recall': '0.962', 'f1': '0.939', 'total_rewards': 1047.8539761522013, 'invalid_action_count': 0, 'num_ms1_scans': 346, 'num_ms2_scans': 1308}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 227.4007235814671
# steps	 1000 	total rewards	 570.3505749848631
# steps	 1500 	total rewards	 914.706255719945
# Finished after 1583 timesteps (7.693636178970337 seconds) with total reward 960.295527772403
# {'coverage_prop': '0.967', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.358', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940', 'total_rewards': 960.295527772403, 'invalid_action_count': 0, 'num_ms1_scans': 417, 'num_ms2_scans': 1166}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 231.13276137982427
# steps	 1000 	total rewards	 581.2849058827447
# steps	 1500 	total rewards	 928.304292431227
# Finished after 1604 timesteps (5.900529861450195 seconds) with total reward 984.9455122971697
# {'coverage_prop': '0.977', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.329', 'efficiency': '0.215', 'TP': '238', 'FP': '21', 'FN': '6', 'precision': '0.919', 'recall': '0.975', 'f1': '0.946', 'total_rewards': 984.9455122971709, 'invalid_action_count': 0, 'num_ms1_scans': 397, 'num_ms2_scans': 1207}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 263.19832220624
# steps	 1000 	total rewards	 607.5243904646977
# steps	 1500 	total rewards	 933.9685347030809
# Finished after 1704 timesteps (6.2098400592803955 seconds) with total reward 1075.5987760844168
# {'coverage_prop': '0.923', 'intensity_prop': '0.734', 'ms1ms2_ratio': '0.210', 'efficiency': '0.307', 'TP': '400', 'FP': '32', 'FN': '36', 'precision': '0.926', 'recall': '0.917', 'f1': '0.922', 'total_rewards': 1075.5987760844155, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 200.0228694404588
# steps	 1000 	total rewards	 533.0305776365959
# Finished after 1444 timesteps (7.5194079875946045 seconds) with total reward 756.0739368260317
# {'coverage_prop': '0.957', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.628', 'efficiency': '0.253', 'TP': '204', 'FP': '20', 'FN': '10', 'precision': '0.911', 'recall': '0.953', 'f1': '0.932', 'total_rewards': 756.0739368260321, 'invalid_action_count': 0, 'num_ms1_scans': 557, 'num_ms2_scans': 887}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 247.2113048677188
# steps	 1000 	total rewards	 592.3884848395044
# steps	 1500 	total rewards	 916.7489256144869
# Finished after 1609 timesteps (5.938819885253906 seconds) with total reward 980.7288185819509
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949', 'total_rewards': 980.7288185819507, 'invalid_action_count': 0, 'num_ms1_scans': 392, 'num_ms2_scans': 1217}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 236.12529755345412
# steps	 1000 	total rewards	 582.8692972464917
# steps	 1500 	total rewards	 884.1165320688208
# Finished after 1544 timesteps (5.7824671268463135 seconds) with total reward 903.7980074800669
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935', 'total_rewards': 903.7980074800685, 'invalid_action_count': 0, 'num_ms1_scans': 457, 'num_ms2_scans': 1087}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 227.45483048867385
# steps	 1000 	total rewards	 605.0559360870084
# steps	 1500 	total rewards	 962.8709139421753
# Finished after 1655 timesteps (5.786811113357544 seconds) with total reward 1076.1736103169426
# {'coverage_prop': '0.980', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.264', 'efficiency': '0.258', 'TP': '314', 'FP': '24', 'FN': '7', 'precision': '0.929', 'recall': '0.978', 'f1': '0.953', 'total_rewards': 1076.173610316944, 'invalid_action_count': 0, 'num_ms1_scans': 346, 'num_ms2_scans': 1309}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 268.9181255070283
# steps	 1000 	total rewards	 606.431335732239
# steps	 1500 	total rewards	 971.9742005483918
# Finished after 1649 timesteps (8.695564031600952 seconds) with total reward 1073.9913779072194
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944', 'total_rewards': 1073.9913779072178, 'invalid_action_count': 0, 'num_ms1_scans': 351, 'num_ms2_scans': 1298}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 185.20689384030436
# steps	 1000 	total rewards	 519.7076100107786
# Finished after 1434 timesteps (5.665604829788208 seconds) with total reward 724.3396458355842
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.652', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948', 'total_rewards': 724.3396458355841, 'invalid_action_count': 0, 'num_ms1_scans': 566, 'num_ms2_scans': 868}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 215.59085943539807
# steps	 1000 	total rewards	 549.1684160021534
# steps	 1500 	total rewards	 852.854824248654
# Finished after 1527 timesteps (5.797114133834839 seconds) with total reward 871.4582136011659
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948', 'total_rewards': 871.4582136011664, 'invalid_action_count': 0, 'num_ms1_scans': 473, 'num_ms2_scans': 1054}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 281.5979299404295
# steps	 1000 	total rewards	 619.2953424014826
# steps	 1500 	total rewards	 991.6026523485504
# Finished after 1729 timesteps (6.223984956741333 seconds) with total reward 1160.7733475079287
# {'coverage_prop': '0.933', 'intensity_prop': '0.707', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902', 'total_rewards': 1160.7733475079267, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 235.17939026197917
# steps	 1000 	total rewards	 586.6139463625948
# steps	 1500 	total rewards	 938.3909389232779
# Finished after 1612 timesteps (8.385459899902344 seconds) with total reward 1004.2240914801285
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950', 'total_rewards': 1004.2240914801279, 'invalid_action_count': 0, 'num_ms1_scans': 388, 'num_ms2_scans': 1224}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7fe07fb7b2e0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7fe07fbe0c40>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7fe07fbfdde0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.0,
#   'beta': 0.0}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.706', 'ms1ms2_ratio': '0.801', 'efficiency': '0.541', 'TP': '360', 'FP': '56', 'FN': '10', 'precision': '0.865', 'recall': '0.973', 'f1': '0.916'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.779', 'efficiency': '0.554', 'TP': '368', 'FP': '65', 'FN': '4', 'precision': '0.850', 'recall': '0.989', 'f1': '0.914'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.722', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '173', 'FP': '18', 'FN': '9', 'precision': '0.906', 'recall': '0.951', 'f1': '0.928'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.679', 'efficiency': '0.541', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.724', 'ms1ms2_ratio': '2.028', 'efficiency': '0.495', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.691', 'ms1ms2_ratio': '0.818', 'efficiency': '0.534', 'TP': '350', 'FP': '55', 'FN': '19', 'precision': '0.864', 'recall': '0.949', 'f1': '0.904'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '323', 'FP': '48', 'FN': '13', 'precision': '0.871', 'recall': '0.961', 'f1': '0.914'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.728', 'ms1ms2_ratio': '0.687', 'efficiency': '0.508', 'TP': '384', 'FP': '44', 'FN': '15', 'precision': '0.897', 'recall': '0.962', 'f1': '0.929'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.728', 'ms1ms2_ratio': '1.606', 'efficiency': '0.507', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.665', 'ms1ms2_ratio': '1.621', 'efficiency': '0.504', 'TP': '195', 'FP': '43', 'FN': '13', 'precision': '0.819', 'recall': '0.938', 'f1': '0.874'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.685', 'ms1ms2_ratio': '1.273', 'efficiency': '0.514', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.695', 'ms1ms2_ratio': '1.958', 'efficiency': '0.482', 'TP': '169', 'FP': '27', 'FN': '10', 'precision': '0.862', 'recall': '0.944', 'f1': '0.901'}
#
# Episode 15 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.861', 'efficiency': '0.540', 'TP': '353', 'FP': '44', 'FN': '10', 'precision': '0.889', 'recall': '0.972', 'f1': '0.929'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '428', 'FP': '59', 'FN': '11', 'precision': '0.879', 'recall': '0.975', 'f1': '0.924'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.699', 'ms1ms2_ratio': '0.982', 'efficiency': '0.533', 'TP': '306', 'FP': '54', 'FN': '12', 'precision': '0.850', 'recall': '0.962', 'f1': '0.903'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.712', 'ms1ms2_ratio': '1.252', 'efficiency': '0.511', 'TP': '253', 'FP': '39', 'FN': '10', 'precision': '0.866', 'recall': '0.962', 'f1': '0.912'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.476', 'efficiency': '0.514', 'TP': '219', 'FP': '41', 'FN': '5', 'precision': '0.842', 'recall': '0.978', 'f1': '0.905'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.711', 'ms1ms2_ratio': '0.699', 'efficiency': '0.540', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.694', 'ms1ms2_ratio': '1.839', 'efficiency': '0.521', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.708', 'ms1ms2_ratio': '1.182', 'efficiency': '0.524', 'TP': '269', 'FP': '43', 'FN': '10', 'precision': '0.862', 'recall': '0.964', 'f1': '0.910'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '244', 'FP': '52', 'FN': '14', 'precision': '0.824', 'recall': '0.946', 'f1': '0.881'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.969', 'efficiency': '0.498', 'TP': '296', 'FP': '43', 'FN': '6', 'precision': '0.873', 'recall': '0.980', 'f1': '0.924'}
#
# Episode 25 finished
# {'coverage_prop': '0.990', 'intensity_prop': '0.720', 'ms1ms2_ratio': '0.859', 'efficiency': '0.533', 'TP': '331', 'FP': '61', 'FN': '4', 'precision': '0.844', 'recall': '0.988', 'f1': '0.911'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.716', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.726', 'ms1ms2_ratio': '1.370', 'efficiency': '0.508', 'TP': '243', 'FP': '29', 'FN': '9', 'precision': '0.893', 'recall': '0.964', 'f1': '0.927'}
#
# Episode 28 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.592', 'efficiency': '0.521', 'TP': '414', 'FP': '63', 'FN': '16', 'precision': '0.868', 'recall': '0.963', 'f1': '0.913'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.731', 'ms1ms2_ratio': '1.210', 'efficiency': '0.504', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    1273.496955                   0.0          0.955           0.706
# 1  random    1147.592320                   0.0          0.924           0.752
# 2  random    1279.733936                   0.0          0.949           0.700
# 3  random    1270.418495                   0.0          0.942           0.718
# 4  random    1187.846447                   0.0          0.938           0.691
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.135       0.259      0.838   0.947  0.889
# 1          0.218       0.174      0.909   0.917  0.913
# 2          0.159       0.246      0.810   0.938  0.869
# 3          0.135       0.270      0.883   0.935  0.908
# 4          0.144       0.264      0.820   0.926  0.869

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'DQN'

# %%
df = pd.read_pickle('evaluation_10.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'DQN']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random    1273.496955                   0.0          0.955           0.706
# 1  random    1147.592320                   0.0          0.924           0.752
# 2  random    1279.733936                   0.0          0.949           0.700
# 3  random    1270.418495                   0.0          0.942           0.718
# 4  random    1187.846447                   0.0          0.938           0.691
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.135       0.259      0.838   0.947  0.889
# 1          0.218       0.174      0.909   0.917  0.913
# 2          0.159       0.246      0.810   0.938  0.869
# 3          0.135       0.270      0.883   0.935  0.908
# 4          0.144       0.264      0.820   0.926  0.869

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
