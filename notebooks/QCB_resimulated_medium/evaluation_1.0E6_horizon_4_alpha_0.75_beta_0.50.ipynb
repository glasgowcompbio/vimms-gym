# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT
from vimms_gym.experiments import preset_qcb_medium

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
env_alpha = 0.75
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-07 15:11:50.481 | INFO     | vimms_gym.experiments:get_samplers:295 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ab5c0de20>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7ab7e0f310>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ae07445b0>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.75,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
ils = 0
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ab5c0de20>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7ab7e0f310>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ae07445b0>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ab5c0de20>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7ab7e0f310>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ae07445b0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.75,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -474.45227732009164
# steps	 1000 	total rewards	 -933.1337064560186
# steps	 1500 	total rewards	 -1365.025285915072
# Finished after 1988 timesteps (1.7807772159576416 seconds) with total reward -1789.1570502884929
# {'coverage_prop': '0.408', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.006', 'efficiency': '0.088', 'TP': '38', 'FP': '136', 'FN': '252', 'precision': '0.218', 'recall': '0.131', 'f1': '0.164', 'total_rewards': -1789.157050288492, 'invalid_action_count': 1860, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -478.9849638450276
# steps	 1000 	total rewards	 -931.238008388004
# steps	 1500 	total rewards	 -1395.4485245192398
# Finished after 1990 timesteps (0.9743061065673828 seconds) with total reward -1876.0805508624392
# {'coverage_prop': '0.290', 'intensity_prop': '0.086', 'ms1ms2_ratio': '0.005', 'efficiency': '0.038', 'TP': '19', 'FP': '57', 'FN': '186', 'precision': '0.250', 'recall': '0.093', 'f1': '0.135', 'total_rewards': -1876.0805508624396, 'invalid_action_count': 1916, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -487.0817101658677
# steps	 1000 	total rewards	 -937.0691988123167
# steps	 1500 	total rewards	 -1381.7661441260675
# Finished after 1985 timesteps (1.2217600345611572 seconds) with total reward -1816.705143377189
# {'coverage_prop': '0.371', 'intensity_prop': '0.075', 'ms1ms2_ratio': '0.008', 'efficiency': '0.074', 'TP': '21', 'FP': '125', 'FN': '248', 'precision': '0.144', 'recall': '0.078', 'f1': '0.101', 'total_rewards': -1816.7051433771885, 'invalid_action_count': 1877, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -973.5070166907879
# steps	 1500 	total rewards	 -1401.633508615198
# Finished after 1991 timesteps (1.24643874168396 seconds) with total reward -1830.8196746991694
# {'coverage_prop': '0.316', 'intensity_prop': '0.090', 'ms1ms2_ratio': '0.005', 'efficiency': '0.072', 'TP': '39', 'FP': '104', 'FN': '309', 'precision': '0.273', 'recall': '0.112', 'f1': '0.159', 'total_rewards': -1830.8196746991691, 'invalid_action_count': 1890, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -971.1557005238498
# steps	 1500 	total rewards	 -1457.0433970943056
# Finished after 1995 timesteps (1.2369441986083984 seconds) with total reward -1897.3483382258623
# {'coverage_prop': '0.217', 'intensity_prop': '0.041', 'ms1ms2_ratio': '0.003', 'efficiency': '0.048', 'TP': '16', 'FP': '79', 'FN': '342', 'precision': '0.168', 'recall': '0.045', 'f1': '0.071', 'total_rewards': -1897.348338225862, 'invalid_action_count': 1933, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -493.43036852314424
# steps	 1000 	total rewards	 -985.287153910725
# steps	 1500 	total rewards	 -1445.9957721435621
# Finished after 1989 timesteps (0.8123660087585449 seconds) with total reward -1915.6887190494322
# {'coverage_prop': '0.315', 'intensity_prop': '0.091', 'ms1ms2_ratio': '0.006', 'efficiency': '0.032', 'TP': '17', 'FP': '46', 'FN': '137', 'precision': '0.270', 'recall': '0.110', 'f1': '0.157', 'total_rewards': -1915.688719049432, 'invalid_action_count': 1941, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -490.8139597783016
# steps	 1000 	total rewards	 -927.3347818301289
# steps	 1500 	total rewards	 -1313.8643501078764
# Finished after 1988 timesteps (1.335508108139038 seconds) with total reward -1728.015923754775
# {'coverage_prop': '0.429', 'intensity_prop': '0.111', 'ms1ms2_ratio': '0.006', 'efficiency': '0.104', 'TP': '43', 'FP': '162', 'FN': '273', 'precision': '0.210', 'recall': '0.136', 'f1': '0.165', 'total_rewards': -1728.0159237547732, 'invalid_action_count': 1824, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -489.803060618667
# steps	 1000 	total rewards	 -984.4850000393164
# steps	 1500 	total rewards	 -1473.5406180751957
# Finished after 1994 timesteps (0.8025379180908203 seconds) with total reward -1947.3872327879267
# {'coverage_prop': '0.186', 'intensity_prop': '0.056', 'ms1ms2_ratio': '0.003', 'efficiency': '0.019', 'TP': '12', 'FP': '26', 'FN': '166', 'precision': '0.316', 'recall': '0.067', 'f1': '0.111', 'total_rewards': -1947.3872327879267, 'invalid_action_count': 1964, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -477.8386350461975
# steps	 1000 	total rewards	 -899.0750967988153
# steps	 1500 	total rewards	 -1327.5477479045044
# Finished after 1987 timesteps (1.623668909072876 seconds) with total reward -1768.9686738195987
# {'coverage_prop': '0.399', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.007', 'efficiency': '0.086', 'TP': '37', 'FP': '132', 'FN': '255', 'precision': '0.219', 'recall': '0.127', 'f1': '0.161', 'total_rewards': -1768.9686738195978, 'invalid_action_count': 1846, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -477.34918491458075
# steps	 1000 	total rewards	 -920.1517352720479
# steps	 1500 	total rewards	 -1359.4113271105516
# Finished after 1986 timesteps (1.123425006866455 seconds) with total reward -1822.4815210638674
# {'coverage_prop': '0.396', 'intensity_prop': '0.112', 'ms1ms2_ratio': '0.007', 'efficiency': '0.077', 'TP': '37', 'FP': '115', 'FN': '232', 'precision': '0.243', 'recall': '0.138', 'f1': '0.176', 'total_rewards': -1822.4815210638674, 'invalid_action_count': 1882, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -485.4247039945833
# steps	 1000 	total rewards	 -963.7660392606322
# steps	 1500 	total rewards	 -1392.6432440118804
# Finished after 1992 timesteps (1.2759230136871338 seconds) with total reward -1822.7458836657433
# {'coverage_prop': '0.341', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.004', 'efficiency': '0.076', 'TP': '27', 'FP': '124', 'FN': '292', 'precision': '0.179', 'recall': '0.085', 'f1': '0.115', 'total_rewards': -1822.745883665743, 'invalid_action_count': 1883, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -485.2437770715438
# steps	 1000 	total rewards	 -971.7540318600534
# steps	 1500 	total rewards	 -1445.5025347722321
# Finished after 1992 timesteps (0.8984489440917969 seconds) with total reward -1905.3983609018405
# {'coverage_prop': '0.301', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.004', 'efficiency': '0.038', 'TP': '20', 'FP': '55', 'FN': '174', 'precision': '0.267', 'recall': '0.103', 'f1': '0.149', 'total_rewards': -1905.3983609018403, 'invalid_action_count': 1937, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -967.714155639331
# steps	 1500 	total rewards	 -1416.400736494788
# Finished after 1988 timesteps (0.9480001926422119 seconds) with total reward -1879.9673958805163
# {'coverage_prop': '0.327', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.006', 'efficiency': '0.041', 'TP': '11', 'FP': '71', 'FN': '169', 'precision': '0.134', 'recall': '0.061', 'f1': '0.084', 'total_rewards': -1879.9673958805167, 'invalid_action_count': 1918, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -493.6292237706516
# steps	 1000 	total rewards	 -953.5488801123297
# steps	 1500 	total rewards	 -1378.653837806809
# Finished after 1992 timesteps (1.5069949626922607 seconds) with total reward -1824.5789741872168
# {'coverage_prop': '0.433', 'intensity_prop': '0.122', 'ms1ms2_ratio': '0.004', 'efficiency': '0.066', 'TP': '32', 'FP': '98', 'FN': '170', 'precision': '0.246', 'recall': '0.158', 'f1': '0.193', 'total_rewards': -1824.5789741872163, 'invalid_action_count': 1885, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -493.4282050619291
# steps	 1000 	total rewards	 -967.1570388976149
# steps	 1500 	total rewards	 -1425.1712026664266
# Finished after 1988 timesteps (0.8446788787841797 seconds) with total reward -1891.545664033245
# {'coverage_prop': '0.306', 'intensity_prop': '0.096', 'ms1ms2_ratio': '0.006', 'efficiency': '0.032', 'TP': '18', 'FP': '45', 'FN': '143', 'precision': '0.286', 'recall': '0.112', 'f1': '0.161', 'total_rewards': -1891.5456640332447, 'invalid_action_count': 1922, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -966.4629455272783
# steps	 1500 	total rewards	 -1390.2181289762677
# Finished after 1991 timesteps (1.1817400455474854 seconds) with total reward -1832.2332028845026
# {'coverage_prop': '0.371', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.005', 'efficiency': '0.076', 'TP': '38', 'FP': '113', 'FN': '256', 'precision': '0.252', 'recall': '0.129', 'f1': '0.171', 'total_rewards': -1832.2332028845028, 'invalid_action_count': 1890, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -980.1115635585913
# steps	 1500 	total rewards	 -1416.948912827955
# Finished after 1995 timesteps (1.2916290760040283 seconds) with total reward -1864.5184788954155
# {'coverage_prop': '0.277', 'intensity_prop': '0.058', 'ms1ms2_ratio': '0.003', 'efficiency': '0.069', 'TP': '28', 'FP': '110', 'FN': '360', 'precision': '0.203', 'recall': '0.072', 'f1': '0.106', 'total_rewards': -1864.518478895416, 'invalid_action_count': 1913, 'num_ms1_scans': 5, 'num_ms2_scans': 1990}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -480.8805343218979
# steps	 1000 	total rewards	 -941.3677330636449
# steps	 1500 	total rewards	 -1406.0109143760753
# Finished after 1993 timesteps (1.0816550254821777 seconds) with total reward -1890.6355111979815
# {'coverage_prop': '0.250', 'intensity_prop': '0.061', 'ms1ms2_ratio': '0.004', 'efficiency': '0.047', 'TP': '20', 'FP': '73', 'FN': '279', 'precision': '0.215', 'recall': '0.067', 'f1': '0.102', 'total_rewards': -1890.6355111979813, 'invalid_action_count': 1928, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -490.7378905784749
# steps	 1000 	total rewards	 -930.5655081846752
# steps	 1500 	total rewards	 -1412.3209264118448
# Finished after 1992 timesteps (1.0149188041687012 seconds) with total reward -1881.387048345578
# {'coverage_prop': '0.298', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.004', 'efficiency': '0.045', 'TP': '20', 'FP': '70', 'FN': '212', 'precision': '0.222', 'recall': '0.086', 'f1': '0.124', 'total_rewards': -1881.3870483455783, 'invalid_action_count': 1922, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -466.8668183824527
# steps	 1000 	total rewards	 -935.2795874393373
# steps	 1500 	total rewards	 -1422.468482452728
# Finished after 1984 timesteps (1.4662752151489258 seconds) with total reward -1870.0952746127195
# {'coverage_prop': '0.272', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.008', 'efficiency': '0.037', 'TP': '19', 'FP': '53', 'FN': '193', 'precision': '0.264', 'recall': '0.090', 'f1': '0.134', 'total_rewards': -1870.0952746127198, 'invalid_action_count': 1906, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -487.2494603859807
# steps	 1000 	total rewards	 -940.297922117371
# steps	 1500 	total rewards	 -1370.4738448312805
# Finished after 1991 timesteps (1.3071730136871338 seconds) with total reward -1818.3832054870554
# {'coverage_prop': '0.314', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.005', 'efficiency': '0.074', 'TP': '30', 'FP': '117', 'FN': '321', 'precision': '0.204', 'recall': '0.085', 'f1': '0.120', 'total_rewards': -1818.3832054870556, 'invalid_action_count': 1879, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -480.62567498172257
# steps	 1000 	total rewards	 -956.0180139135828
# steps	 1500 	total rewards	 -1456.0180139135828
# Finished after 1994 timesteps (0.8593728542327881 seconds) with total reward -1949.0180139135828
# {'coverage_prop': '0.128', 'intensity_prop': '0.033', 'ms1ms2_ratio': '0.003', 'efficiency': '0.015', 'TP': '7', 'FP': '23', 'FN': '204', 'precision': '0.233', 'recall': '0.033', 'f1': '0.058', 'total_rewards': -1949.0180139135828, 'invalid_action_count': 1964, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -488.9999625367701
# steps	 1000 	total rewards	 -942.3290215266567
# steps	 1500 	total rewards	 -1379.3265678712935
# Finished after 1987 timesteps (1.062371015548706 seconds) with total reward -1810.3476410664387
# {'coverage_prop': '0.432', 'intensity_prop': '0.121', 'ms1ms2_ratio': '0.007', 'efficiency': '0.070', 'TP': '37', 'FP': '102', 'FN': '183', 'precision': '0.266', 'recall': '0.168', 'f1': '0.206', 'total_rewards': -1810.3476410664389, 'invalid_action_count': 1874, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -498.0
# steps	 1000 	total rewards	 -963.344902398162
# steps	 1500 	total rewards	 -1417.9339019291144
# Finished after 1988 timesteps (0.9663808345794678 seconds) with total reward -1883.7975879672763
# {'coverage_prop': '0.271', 'intensity_prop': '0.052', 'ms1ms2_ratio': '0.006', 'efficiency': '0.043', 'TP': '13', 'FP': '71', 'FN': '226', 'precision': '0.155', 'recall': '0.054', 'f1': '0.080', 'total_rewards': -1883.7975879672765, 'invalid_action_count': 1921, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -479.04371062341323
# steps	 1000 	total rewards	 -949.1552726282669
# steps	 1500 	total rewards	 -1363.9507040849285
# Finished after 1992 timesteps (1.0746800899505615 seconds) with total reward -1829.0003265652344
# {'coverage_prop': '0.362', 'intensity_prop': '0.088', 'ms1ms2_ratio': '0.004', 'efficiency': '0.063', 'TP': '26', 'FP': '99', 'FN': '220', 'precision': '0.208', 'recall': '0.106', 'f1': '0.140', 'total_rewards': -1829.0003265652347, 'invalid_action_count': 1890, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -485.472701242544
# steps	 1000 	total rewards	 -922.4229280106468
# steps	 1500 	total rewards	 -1394.2471652133236
# Finished after 1988 timesteps (1.7401740550994873 seconds) with total reward -1848.882909605059
# {'coverage_prop': '0.295', 'intensity_prop': '0.077', 'ms1ms2_ratio': '0.006', 'efficiency': '0.059', 'TP': '30', 'FP': '87', 'FN': '279', 'precision': '0.256', 'recall': '0.097', 'f1': '0.141', 'total_rewards': -1848.882909605059, 'invalid_action_count': 1898, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -488.80471346988054
# steps	 1000 	total rewards	 -965.7189977839994
# steps	 1500 	total rewards	 -1440.0543239192757
# Finished after 1989 timesteps (0.8397109508514404 seconds) with total reward -1917.6565153345691
# {'coverage_prop': '0.236', 'intensity_prop': '0.048', 'ms1ms2_ratio': '0.006', 'efficiency': '0.024', 'TP': '9', 'FP': '39', 'FN': '155', 'precision': '0.188', 'recall': '0.055', 'f1': '0.085', 'total_rewards': -1917.6565153345693, 'invalid_action_count': 1939, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -959.8130973347734
# steps	 1500 	total rewards	 -1409.795005642649
# Finished after 1987 timesteps (0.9659638404846191 seconds) with total reward -1863.4705690552905
# {'coverage_prop': '0.313', 'intensity_prop': '0.083', 'ms1ms2_ratio': '0.007', 'efficiency': '0.045', 'TP': '20', 'FP': '68', 'FN': '193', 'precision': '0.227', 'recall': '0.094', 'f1': '0.133', 'total_rewards': -1863.4705690552903, 'invalid_action_count': 1907, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -481.624508002809
# steps	 1000 	total rewards	 -904.6639750357915
# steps	 1500 	total rewards	 -1309.6318684743537
# Finished after 1988 timesteps (1.3577208518981934 seconds) with total reward -1755.878445302291
# {'coverage_prop': '0.430', 'intensity_prop': '0.120', 'ms1ms2_ratio': '0.006', 'efficiency': '0.107', 'TP': '55', 'FP': '157', 'FN': '281', 'precision': '0.259', 'recall': '0.164', 'f1': '0.201', 'total_rewards': -1755.8784453022904, 'invalid_action_count': 1841, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -490.043284403452
# steps	 1000 	total rewards	 -953.0175208282574
# steps	 1500 	total rewards	 -1391.6336507309768
# Finished after 1990 timesteps (1.0115151405334473 seconds) with total reward -1838.170947024626
# {'coverage_prop': '0.375', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.005', 'efficiency': '0.058', 'TP': '29', 'FP': '85', 'FN': '190', 'precision': '0.254', 'recall': '0.132', 'f1': '0.174', 'total_rewards': -1838.1709470246262, 'invalid_action_count': 1893, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.34GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 84.35714088096765
# steps	 1000 	total rewards	 202.9231300186447
# Finished after 1361 timesteps (5.426851987838745 seconds) with total reward 259.3255304276739
# {'coverage_prop': '0.944', 'intensity_prop': '0.582', 'ms1ms2_ratio': '0.885', 'efficiency': '0.557', 'TP': '280', 'FP': '122', 'FN': '24', 'precision': '0.697', 'recall': '0.921', 'f1': '0.793', 'total_rewards': 259.32553042767415, 'invalid_action_count': 7, 'num_ms1_scans': 639, 'num_ms2_scans': 722}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 66.57394679467663
# steps	 1000 	total rewards	 148.40754709154442
# Finished after 1201 timesteps (4.65760612487793 seconds) with total reward 167.00114756831206
# {'coverage_prop': '0.927', 'intensity_prop': '0.583', 'ms1ms2_ratio': '1.995', 'efficiency': '0.606', 'TP': '171', 'FP': '72', 'FN': '19', 'precision': '0.704', 'recall': '0.900', 'f1': '0.790', 'total_rewards': 167.00114756831232, 'invalid_action_count': 4, 'num_ms1_scans': 800, 'num_ms2_scans': 401}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 70.28879507518783
# steps	 1000 	total rewards	 194.37301680372838
# Finished after 1306 timesteps (5.625942945480347 seconds) with total reward 239.36973570205583
# {'coverage_prop': '0.937', 'intensity_prop': '0.581', 'ms1ms2_ratio': '1.137', 'efficiency': '0.604', 'TP': '245', 'FP': '124', 'FN': '25', 'precision': '0.664', 'recall': '0.907', 'f1': '0.767', 'total_rewards': 239.3697357020558, 'invalid_action_count': 6, 'num_ms1_scans': 695, 'num_ms2_scans': 611}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 85.54670614083028
# steps	 1000 	total rewards	 211.2608092012728
# Finished after 1350 timesteps (6.029991865158081 seconds) with total reward 268.02090447384785
# {'coverage_prop': '0.929', 'intensity_prop': '0.619', 'ms1ms2_ratio': '0.929', 'efficiency': '0.600', 'TP': '326', 'FP': '94', 'FN': '32', 'precision': '0.776', 'recall': '0.911', 'f1': '0.838', 'total_rewards': 268.02090447384796, 'invalid_action_count': 5, 'num_ms1_scans': 650, 'num_ms2_scans': 700}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 71.40185439857909
# steps	 1000 	total rewards	 201.8001509822771
# Finished after 1347 timesteps (6.540036201477051 seconds) with total reward 251.43138438241874
# {'coverage_prop': '0.945', 'intensity_prop': '0.627', 'ms1ms2_ratio': '0.944', 'efficiency': '0.596', 'TP': '312', 'FP': '101', 'FN': '24', 'precision': '0.755', 'recall': '0.929', 'f1': '0.833', 'total_rewards': 251.43138438241866, 'invalid_action_count': 10, 'num_ms1_scans': 654, 'num_ms2_scans': 693}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 53.25076404181182
# steps	 1000 	total rewards	 112.95659175309196
# Finished after 1146 timesteps (4.7491960525512695 seconds) with total reward 125.37763275474435
# {'coverage_prop': '0.940', 'intensity_prop': '0.607', 'ms1ms2_ratio': '2.938', 'efficiency': '0.646', 'TP': '132', 'FP': '56', 'FN': '12', 'precision': '0.702', 'recall': '0.917', 'f1': '0.795', 'total_rewards': 125.37763275474438, 'invalid_action_count': 1, 'num_ms1_scans': 855, 'num_ms2_scans': 291}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 91.62599334509497
# steps	 1000 	total rewards	 218.62836766721546
# Finished after 1389 timesteps (4.982285976409912 seconds) with total reward 282.7867722815232
# {'coverage_prop': '0.925', 'intensity_prop': '0.595', 'ms1ms2_ratio': '0.785', 'efficiency': '0.568', 'TP': '321', 'FP': '121', 'FN': '36', 'precision': '0.726', 'recall': '0.899', 'f1': '0.804', 'total_rewards': 282.7867722815232, 'invalid_action_count': 6, 'num_ms1_scans': 611, 'num_ms2_scans': 778}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 50.729719057055675
# steps	 1000 	total rewards	 117.3323807812497
# Finished after 1168 timesteps (4.664299726486206 seconds) with total reward 131.05887236357555
# {'coverage_prop': '0.931', 'intensity_prop': '0.608', 'ms1ms2_ratio': '2.487', 'efficiency': '0.567', 'TP': '148', 'FP': '42', 'FN': '14', 'precision': '0.779', 'recall': '0.914', 'f1': '0.841', 'total_rewards': 131.0588723635755, 'invalid_action_count': 5, 'num_ms1_scans': 833, 'num_ms2_scans': 335}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 93.80756336414683
# steps	 1000 	total rewards	 194.9462845577396
# Finished after 1342 timesteps (5.750478982925415 seconds) with total reward 250.27532927921445
# {'coverage_prop': '0.936', 'intensity_prop': '0.591', 'ms1ms2_ratio': '0.965', 'efficiency': '0.581', 'TP': '287', 'FP': '110', 'FN': '27', 'precision': '0.723', 'recall': '0.914', 'f1': '0.807', 'total_rewards': 250.27532927921436, 'invalid_action_count': 6, 'num_ms1_scans': 659, 'num_ms2_scans': 683}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 69.22519314702805
# steps	 1000 	total rewards	 184.7248824781848
# Finished after 1306 timesteps (4.692484140396118 seconds) with total reward 224.0070841749989
# {'coverage_prop': '0.932', 'intensity_prop': '0.599', 'ms1ms2_ratio': '1.134', 'efficiency': '0.585', 'TP': '257', 'FP': '101', 'FN': '26', 'precision': '0.718', 'recall': '0.908', 'f1': '0.802', 'total_rewards': 224.0070841749989, 'invalid_action_count': 6, 'num_ms1_scans': 694, 'num_ms2_scans': 612}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 75.16862435891846
# steps	 1000 	total rewards	 209.49515582978813
# Finished after 1380 timesteps (4.958868980407715 seconds) with total reward 269.5603658122776
# {'coverage_prop': '0.941', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.816', 'efficiency': '0.549', 'TP': '302', 'FP': '115', 'FN': '26', 'precision': '0.724', 'recall': '0.921', 'f1': '0.811', 'total_rewards': 269.56036581227755, 'invalid_action_count': 6, 'num_ms1_scans': 620, 'num_ms2_scans': 760}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 66.0764947011873
# steps	 1000 	total rewards	 136.56808314604285
# Finished after 1197 timesteps (5.190924882888794 seconds) with total reward 159.78619644300557
# {'coverage_prop': '0.944', 'intensity_prop': '0.617', 'ms1ms2_ratio': '2.046', 'efficiency': '0.598', 'TP': '171', 'FP': '64', 'FN': '14', 'precision': '0.728', 'recall': '0.924', 'f1': '0.814', 'total_rewards': 159.78619644300568, 'invalid_action_count': 0, 'num_ms1_scans': 804, 'num_ms2_scans': 393}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 61.074190022991445
# steps	 1000 	total rewards	 132.74301007730122
# Finished after 1212 timesteps (4.242679119110107 seconds) with total reward 153.19729739695634
# {'coverage_prop': '0.920', 'intensity_prop': '0.549', 'ms1ms2_ratio': '1.865', 'efficiency': '0.546', 'TP': '146', 'FP': '85', 'FN': '20', 'precision': '0.632', 'recall': '0.880', 'f1': '0.736', 'total_rewards': 153.1972973969564, 'invalid_action_count': 4, 'num_ms1_scans': 789, 'num_ms2_scans': 423}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 61.175785801833584
# steps	 1000 	total rewards	 152.22204708929968
# Finished after 1286 timesteps (5.854270935058594 seconds) with total reward 187.5198233447622
# {'coverage_prop': '0.950', 'intensity_prop': '0.604', 'ms1ms2_ratio': '1.248', 'efficiency': '0.498', 'TP': '201', 'FP': '84', 'FN': '15', 'precision': '0.705', 'recall': '0.931', 'f1': '0.802', 'total_rewards': 187.5198233447622, 'invalid_action_count': 6, 'num_ms1_scans': 714, 'num_ms2_scans': 572}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 51.564484902666116
# steps	 1000 	total rewards	 120.96762906130469
# Finished after 1182 timesteps (4.007250785827637 seconds) with total reward 138.68874558183765
# {'coverage_prop': '0.937', 'intensity_prop': '0.593', 'ms1ms2_ratio': '2.256', 'efficiency': '0.532', 'TP': '133', 'FP': '60', 'FN': '13', 'precision': '0.689', 'recall': '0.911', 'f1': '0.785', 'total_rewards': 138.6887455818376, 'invalid_action_count': 1, 'num_ms1_scans': 819, 'num_ms2_scans': 363}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 72.86909814030543
# steps	 1000 	total rewards	 195.57234464540625
# Finished after 1317 timesteps (6.040205955505371 seconds) with total reward 240.1736440433268
# {'coverage_prop': '0.941', 'intensity_prop': '0.635', 'ms1ms2_ratio': '1.077', 'efficiency': '0.604', 'TP': '299', 'FP': '84', 'FN': '24', 'precision': '0.781', 'recall': '0.926', 'f1': '0.847', 'total_rewards': 240.17364404332673, 'invalid_action_count': 7, 'num_ms1_scans': 683, 'num_ms2_scans': 634}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 87.19887201100316
# steps	 1000 	total rewards	 221.22094974224478
# Finished after 1400 timesteps (5.1514811515808105 seconds) with total reward 286.90913019743755
# {'coverage_prop': '0.936', 'intensity_prop': '0.634', 'ms1ms2_ratio': '0.750', 'efficiency': '0.583', 'TP': '356', 'FP': '110', 'FN': '32', 'precision': '0.764', 'recall': '0.918', 'f1': '0.834', 'total_rewards': 286.9091301974376, 'invalid_action_count': 8, 'num_ms1_scans': 600, 'num_ms2_scans': 800}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 78.52012143797694
# steps	 1000 	total rewards	 186.33345409313768
# Finished after 1301 timesteps (6.0126259326934814 seconds) with total reward 223.35322704336193
# {'coverage_prop': '0.938', 'intensity_prop': '0.607', 'ms1ms2_ratio': '1.165', 'efficiency': '0.581', 'TP': '258', 'FP': '91', 'FN': '23', 'precision': '0.739', 'recall': '0.918', 'f1': '0.819', 'total_rewards': 223.35322704336195, 'invalid_action_count': 9, 'num_ms1_scans': 700, 'num_ms2_scans': 601}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 67.43853556755381
# steps	 1000 	total rewards	 157.71236691213764
# Finished after 1262 timesteps (4.39238977432251 seconds) with total reward 192.04643779009692
# {'coverage_prop': '0.954', 'intensity_prop': '0.613', 'ms1ms2_ratio': '1.408', 'efficiency': '0.550', 'TP': '211', 'FP': '77', 'FN': '14', 'precision': '0.733', 'recall': '0.938', 'f1': '0.823', 'total_rewards': 192.04643779009706, 'invalid_action_count': 5, 'num_ms1_scans': 738, 'num_ms2_scans': 524}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 61.803563007917134
# steps	 1000 	total rewards	 147.64210226319864
# Finished after 1246 timesteps (4.268186807632446 seconds) with total reward 174.71126959350124
# {'coverage_prop': '0.966', 'intensity_prop': '0.617', 'ms1ms2_ratio': '1.533', 'efficiency': '0.520', 'TP': '178', 'FP': '78', 'FN': '9', 'precision': '0.695', 'recall': '0.952', 'f1': '0.804', 'total_rewards': 174.71126959350124, 'invalid_action_count': 2, 'num_ms1_scans': 754, 'num_ms2_scans': 492}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 80.87595498233568
# steps	 1000 	total rewards	 209.93330265057173
# Finished after 1365 timesteps (6.645303964614868 seconds) with total reward 263.75300103713084
# {'coverage_prop': '0.902', 'intensity_prop': '0.580', 'ms1ms2_ratio': '0.870', 'efficiency': '0.578', 'TP': '307', 'FP': '115', 'FN': '46', 'precision': '0.727', 'recall': '0.870', 'f1': '0.792', 'total_rewards': 263.7530010371307, 'invalid_action_count': 7, 'num_ms1_scans': 635, 'num_ms2_scans': 730}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 55.28908916365947
# steps	 1000 	total rewards	 129.87433453162453
# Finished after 1161 timesteps (4.17800760269165 seconds) with total reward 139.23140325195877
# {'coverage_prop': '0.915', 'intensity_prop': '0.574', 'ms1ms2_ratio': '2.628', 'efficiency': '0.669', 'TP': '142', 'FP': '72', 'FN': '20', 'precision': '0.664', 'recall': '0.877', 'f1': '0.755', 'total_rewards': 139.2314032519588, 'invalid_action_count': 3, 'num_ms1_scans': 841, 'num_ms2_scans': 320}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 75.73205632397271
# steps	 1000 	total rewards	 170.2582090753078
# Finished after 1267 timesteps (6.289736032485962 seconds) with total reward 202.1173321990011
# {'coverage_prop': '0.941', 'intensity_prop': '0.595', 'ms1ms2_ratio': '1.373', 'efficiency': '0.567', 'TP': '217', 'FP': '86', 'FN': '19', 'precision': '0.716', 'recall': '0.919', 'f1': '0.805', 'total_rewards': 202.1173321990011, 'invalid_action_count': 1, 'num_ms1_scans': 733, 'num_ms2_scans': 534}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 72.53908048818377
# steps	 1000 	total rewards	 161.45653119778075
# Finished after 1228 timesteps (4.3701019287109375 seconds) with total reward 187.0497486364498
# {'coverage_prop': '0.926', 'intensity_prop': '0.597', 'ms1ms2_ratio': '1.699', 'efficiency': '0.631', 'TP': '213', 'FP': '74', 'FN': '23', 'precision': '0.742', 'recall': '0.903', 'f1': '0.815', 'total_rewards': 187.04974863644972, 'invalid_action_count': 5, 'num_ms1_scans': 773, 'num_ms2_scans': 455}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 74.45632873766353
# steps	 1000 	total rewards	 179.1965864874598
# Finished after 1318 timesteps (4.360577821731567 seconds) with total reward 227.8895975402736
# {'coverage_prop': '0.959', 'intensity_prop': '0.612', 'ms1ms2_ratio': '1.076', 'efficiency': '0.521', 'TP': '236', 'FP': '95', 'FN': '14', 'precision': '0.713', 'recall': '0.944', 'f1': '0.812', 'total_rewards': 227.8895975402738, 'invalid_action_count': 2, 'num_ms1_scans': 683, 'num_ms2_scans': 635}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 70.93964742983061
# steps	 1000 	total rewards	 173.59941497176908
# Finished after 1308 timesteps (6.812608003616333 seconds) with total reward 225.51513134613305
# {'coverage_prop': '0.947', 'intensity_prop': '0.608', 'ms1ms2_ratio': '1.123', 'efficiency': '0.609', 'TP': '267', 'FP': '108', 'FN': '21', 'precision': '0.712', 'recall': '0.927', 'f1': '0.805', 'total_rewards': 225.5151313461331, 'invalid_action_count': 9, 'num_ms1_scans': 692, 'num_ms2_scans': 616}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 47.88977513304917
# steps	 1000 	total rewards	 117.96960115097265
# Finished after 1167 timesteps (5.568219900131226 seconds) with total reward 131.3997137956353
# {'coverage_prop': '0.941', 'intensity_prop': '0.595', 'ms1ms2_ratio': '2.515', 'efficiency': '0.575', 'TP': '129', 'FP': '62', 'FN': '12', 'precision': '0.675', 'recall': '0.915', 'f1': '0.777', 'total_rewards': 131.3997137956352, 'invalid_action_count': 2, 'num_ms1_scans': 835, 'num_ms2_scans': 332}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 63.30868038894381
# steps	 1000 	total rewards	 150.50145443456057
# Finished after 1205 timesteps (6.873801231384277 seconds) with total reward 183.14940510770919
# {'coverage_prop': '0.943', 'intensity_prop': '0.607', 'ms1ms2_ratio': '1.946', 'efficiency': '0.648', 'TP': '192', 'FP': '73', 'FN': '16', 'precision': '0.725', 'recall': '0.923', 'f1': '0.812', 'total_rewards': 183.14940510770927, 'invalid_action_count': 2, 'num_ms1_scans': 796, 'num_ms2_scans': 409}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 89.18741073718246
# steps	 1000 	total rewards	 208.5324519555466
# Finished after 1356 timesteps (7.223233938217163 seconds) with total reward 277.7298287829302
# {'coverage_prop': '0.899', 'intensity_prop': '0.552', 'ms1ms2_ratio': '0.904', 'efficiency': '0.622', 'TP': '306', 'FP': '137', 'FN': '50', 'precision': '0.691', 'recall': '0.860', 'f1': '0.766', 'total_rewards': 277.7298287829301, 'invalid_action_count': 5, 'num_ms1_scans': 644, 'num_ms2_scans': 712}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 70.07593065220121
# steps	 1000 	total rewards	 158.76509781562754
# Finished after 1273 timesteps (5.491899251937866 seconds) with total reward 194.24684802516674
# {'coverage_prop': '0.944', 'intensity_prop': '0.615', 'ms1ms2_ratio': '1.332', 'efficiency': '0.526', 'TP': '209', 'FP': '78', 'FN': '17', 'precision': '0.728', 'recall': '0.925', 'f1': '0.815', 'total_rewards': 194.24684802516663, 'invalid_action_count': 1, 'num_ms1_scans': 727, 'num_ms2_scans': 546}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 69.13272730373676
# steps	 1000 	total rewards	 167.52401180884436
# steps	 1500 	total rewards	 268.835772555762
# Finished after 1722 timesteps (21.33419919013977 seconds) with total reward 302.6904731091943
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 302.69047310919456, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 63.267206375349446
# steps	 1000 	total rewards	 147.22176856550522
# steps	 1500 	total rewards	 206.13306960735235
# Finished after 1556 timesteps (11.898690223693848 seconds) with total reward 209.90071398411402
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 209.90071398411385, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 64.43100494804028
# steps	 1000 	total rewards	 157.75604831162377
# steps	 1500 	total rewards	 252.45340089554875
# Finished after 1669 timesteps (9.65181016921997 seconds) with total reward 272.30893570096987
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 272.30893570097004, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 77.56407306217639
# steps	 1000 	total rewards	 175.3136366970973
# steps	 1500 	total rewards	 267.39028443089785
# Finished after 1717 timesteps (9.5379478931427 seconds) with total reward 303.16179552508345
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 303.1617955250836, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 67.45194904638231
# steps	 1000 	total rewards	 177.928405622967
# steps	 1500 	total rewards	 272.89606049379927
# Finished after 1704 timesteps (14.619073867797852 seconds) with total reward 302.5090574147593
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 302.50905741475964, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 42.95325779749826
# steps	 1000 	total rewards	 116.41665894186508
# Finished after 1408 timesteps (10.888214111328125 seconds) with total reward 156.12372896456625
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 156.12372896456614, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 80.61021704365692
# steps	 1000 	total rewards	 181.52198733691552
# steps	 1500 	total rewards	 274.7787285689685
# Finished after 1744 timesteps (18.191534996032715 seconds) with total reward 313.15118439694226
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 313.15118439694254, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 44.238971301558195
# steps	 1000 	total rewards	 125.1842960286907
# Finished after 1468 timesteps (8.491979837417603 seconds) with total reward 168.96147789407007
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 168.96147789407013, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 75.23310727179368
# steps	 1000 	total rewards	 162.50175052042312
# steps	 1500 	total rewards	 259.0071448022833
# Finished after 1736 timesteps (10.707321882247925 seconds) with total reward 290.77741434124465
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 290.7774143412449, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 63.21692569981598
# steps	 1000 	total rewards	 156.39946621256962
# steps	 1500 	total rewards	 247.23426927362414
# Finished after 1667 timesteps (10.28994107246399 seconds) with total reward 264.56080791299576
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 264.56080791299604, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 68.2444174280495
# steps	 1000 	total rewards	 161.01675884777742
# steps	 1500 	total rewards	 262.27604479049864
# Finished after 1737 timesteps (12.307899951934814 seconds) with total reward 292.1533148585758
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 292.1533148585763, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 56.82684078254565
# steps	 1000 	total rewards	 130.42240094938646
# steps	 1500 	total rewards	 185.85089936171542
# Finished after 1530 timesteps (13.137744903564453 seconds) with total reward 188.08148170069052
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 188.08148170069046, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 52.46417639089912
# steps	 1000 	total rewards	 126.57479266335895
# steps	 1500 	total rewards	 190.94713768391432
# Finished after 1602 timesteps (11.653450012207031 seconds) with total reward 201.35718472341065
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 201.3571847234108, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 53.05120273761639
# steps	 1000 	total rewards	 133.20105984363587
# steps	 1500 	total rewards	 208.21959872366398
# Finished after 1645 timesteps (10.210654973983765 seconds) with total reward 222.27204370347346
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 222.27204370347386, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 45.55362664827871
# steps	 1000 	total rewards	 114.20766305969778
# Finished after 1497 timesteps (7.715488910675049 seconds) with total reward 169.20209568414865
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 169.20209568414867, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 62.48254683396313
# steps	 1000 	total rewards	 165.60477848576141
# steps	 1500 	total rewards	 254.66962163245816
# Finished after 1655 timesteps (9.460103988647461 seconds) with total reward 279.4606267939937
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 279.46062679399387, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 80.23487196716034
# steps	 1000 	total rewards	 180.43154289468077
# steps	 1500 	total rewards	 282.72593742641436
# Finished after 1729 timesteps (12.916315078735352 seconds) with total reward 318.6679836459015
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 318.6679836459015, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 72.14147962328205
# steps	 1000 	total rewards	 171.49579973785487
# steps	 1500 	total rewards	 252.42587048404027
# Finished after 1681 timesteps (8.713150978088379 seconds) with total reward 272.8586228203061
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 272.8586228203064, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 54.90263917401529
# steps	 1000 	total rewards	 143.12689641014515
# steps	 1500 	total rewards	 215.81584562387692
# Finished after 1621 timesteps (8.66872501373291 seconds) with total reward 226.69811384759905
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 226.6981138475992, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 55.323553580374856
# steps	 1000 	total rewards	 137.93412432772536
# steps	 1500 	total rewards	 201.46933615569756
# Finished after 1634 timesteps (8.620047807693481 seconds) with total reward 216.02783988704306
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 216.0278398870428, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 78.75497475425821
# steps	 1000 	total rewards	 171.9503734026993
# steps	 1500 	total rewards	 261.02419193511133
# Finished after 1726 timesteps (9.885040044784546 seconds) with total reward 294.3701240325714
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 294.37012403257114, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 46.46122472001782
# steps	 1000 	total rewards	 128.23867897708288
# Finished after 1475 timesteps (7.936056852340698 seconds) with total reward 181.7349393688646
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 181.7349393688646, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 63.0371408738211
# steps	 1000 	total rewards	 151.42456916206152
# steps	 1500 	total rewards	 226.49449423814843
# Finished after 1636 timesteps (12.648778915405273 seconds) with total reward 241.04449101544736
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 241.04449101544705, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 66.77789765056464
# steps	 1000 	total rewards	 152.63584138367554
# steps	 1500 	total rewards	 224.49650954428586
# Finished after 1575 timesteps (8.29321813583374 seconds) with total reward 232.0243853968007
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 232.02438539680037, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 60.45310807359132
# steps	 1000 	total rewards	 156.73374134533213
# steps	 1500 	total rewards	 237.8721565353879
# Finished after 1681 timesteps (8.767657995223999 seconds) with total reward 259.5506267394834
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 259.55062673948333, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 63.828975904004274
# steps	 1000 	total rewards	 151.44101290742347
# steps	 1500 	total rewards	 248.51912484981983
# Finished after 1679 timesteps (8.996891021728516 seconds) with total reward 270.8994348646653
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 270.8994348646652, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 40.96673036915889
# steps	 1000 	total rewards	 116.26391406327969
# Finished after 1465 timesteps (7.517719030380249 seconds) with total reward 164.3049366183155
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 164.30493661831565, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 55.38322226329699
# steps	 1000 	total rewards	 142.73178509793024
# steps	 1500 	total rewards	 214.94350130278946
# Finished after 1564 timesteps (8.0189950466156 seconds) with total reward 224.24666683618017
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 224.24666683618045, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 81.1683689150183
# steps	 1000 	total rewards	 163.32073741369632
# steps	 1500 	total rewards	 260.09657188636254
# Finished after 1749 timesteps (13.541174173355103 seconds) with total reward 302.319054625992
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 302.3190546259921, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 61.99199473696666
# steps	 1000 	total rewards	 144.36734660797444
# steps	 1500 	total rewards	 217.2551500524442
# Finished after 1657 timesteps (9.464353084564209 seconds) with total reward 230.71408271317736
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 230.71408271317733, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7f7ab5c0de20>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7f7ab7e0f310>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7f7ae07445b0>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.75,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
smartroi_N, smartroi_dew, alpha, beta, ils
# Out:
# (10, 5, 2, 0.5, 0)

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0, dew=smartroi_dew, initial_length_seconds=ils)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.705', 'ms1ms2_ratio': '0.805', 'efficiency': '0.544', 'TP': '363', 'FP': '54', 'FN': '9', 'precision': '0.871', 'recall': '0.976', 'f1': '0.920'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.713', 'ms1ms2_ratio': '1.513', 'efficiency': '0.507', 'TP': '220', 'FP': '32', 'FN': '10', 'precision': '0.873', 'recall': '0.957', 'f1': '0.913'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.850', 'efficiency': '0.516', 'TP': '324', 'FP': '58', 'FN': '12', 'precision': '0.848', 'recall': '0.964', 'f1': '0.903'}
#
# Episode 3 finished
# {'coverage_prop': '0.973', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.746', 'efficiency': '0.548', 'TP': '377', 'FP': '63', 'FN': '12', 'precision': '0.857', 'recall': '0.969', 'f1': '0.910'}
#
# Episode 4 finished
# {'coverage_prop': '0.991', 'intensity_prop': '0.723', 'ms1ms2_ratio': '0.776', 'efficiency': '0.552', 'TP': '372', 'FP': '61', 'FN': '4', 'precision': '0.859', 'recall': '0.989', 'f1': '0.920'}
#
# Episode 5 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.716', 'ms1ms2_ratio': '2.154', 'efficiency': '0.507', 'TP': '170', 'FP': '21', 'FN': '9', 'precision': '0.890', 'recall': '0.950', 'f1': '0.919'}
#
# Episode 6 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.696', 'ms1ms2_ratio': '0.679', 'efficiency': '0.541', 'TP': '398', 'FP': '61', 'FN': '19', 'precision': '0.867', 'recall': '0.954', 'f1': '0.909'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.719', 'ms1ms2_ratio': '2.067', 'efficiency': '0.503', 'TP': '180', 'FP': '16', 'FN': '8', 'precision': '0.918', 'recall': '0.957', 'f1': '0.938'}
#
# Episode 8 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.690', 'ms1ms2_ratio': '0.818', 'efficiency': '0.532', 'TP': '351', 'FP': '53', 'FN': '20', 'precision': '0.869', 'recall': '0.946', 'f1': '0.906'}
#
# Episode 9 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.710', 'ms1ms2_ratio': '0.903', 'efficiency': '0.520', 'TP': '322', 'FP': '49', 'FN': '13', 'precision': '0.868', 'recall': '0.961', 'f1': '0.912'}
#
# Episode 10 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.688', 'efficiency': '0.508', 'TP': '384', 'FP': '44', 'FN': '15', 'precision': '0.897', 'recall': '0.962', 'f1': '0.929'}
#
# Episode 11 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.633', 'efficiency': '0.514', 'TP': '218', 'FP': '23', 'FN': '8', 'precision': '0.905', 'recall': '0.965', 'f1': '0.934'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.667', 'ms1ms2_ratio': '1.612', 'efficiency': '0.502', 'TP': '195', 'FP': '43', 'FN': '13', 'precision': '0.819', 'recall': '0.938', 'f1': '0.874'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.688', 'ms1ms2_ratio': '1.267', 'efficiency': '0.512', 'TP': '233', 'FP': '57', 'FN': '10', 'precision': '0.803', 'recall': '0.959', 'f1': '0.874'}
#
# Episode 14 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.697', 'ms1ms2_ratio': '1.983', 'efficiency': '0.486', 'TP': '170', 'FP': '26', 'FN': '10', 'precision': '0.867', 'recall': '0.944', 'f1': '0.904'}
#
# Episode 15 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.861', 'efficiency': '0.540', 'TP': '353', 'FP': '44', 'FN': '10', 'precision': '0.889', 'recall': '0.972', 'f1': '0.929'}
#
# Episode 16 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.735', 'ms1ms2_ratio': '0.601', 'efficiency': '0.536', 'TP': '429', 'FP': '58', 'FN': '11', 'precision': '0.881', 'recall': '0.975', 'f1': '0.926'}
#
# Episode 17 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.705', 'ms1ms2_ratio': '0.961', 'efficiency': '0.526', 'TP': '306', 'FP': '54', 'FN': '12', 'precision': '0.850', 'recall': '0.962', 'f1': '0.903'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.710', 'ms1ms2_ratio': '1.246', 'efficiency': '0.510', 'TP': '252', 'FP': '40', 'FN': '10', 'precision': '0.863', 'recall': '0.962', 'f1': '0.910'}
#
# Episode 19 finished
# {'coverage_prop': '0.981', 'intensity_prop': '0.709', 'ms1ms2_ratio': '1.481', 'efficiency': '0.515', 'TP': '220', 'FP': '40', 'FN': '5', 'precision': '0.846', 'recall': '0.978', 'f1': '0.907'}
#
# Episode 20 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.712', 'ms1ms2_ratio': '0.696', 'efficiency': '0.538', 'TP': '387', 'FP': '63', 'FN': '18', 'precision': '0.860', 'recall': '0.956', 'f1': '0.905'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.687', 'ms1ms2_ratio': '1.850', 'efficiency': '0.523', 'TP': '197', 'FP': '26', 'FN': '11', 'precision': '0.883', 'recall': '0.947', 'f1': '0.914'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.711', 'ms1ms2_ratio': '1.187', 'efficiency': '0.526', 'TP': '273', 'FP': '39', 'FN': '10', 'precision': '0.875', 'recall': '0.965', 'f1': '0.918'}
#
# Episode 23 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.696', 'ms1ms2_ratio': '1.265', 'efficiency': '0.522', 'TP': '246', 'FP': '50', 'FN': '14', 'precision': '0.831', 'recall': '0.946', 'f1': '0.885'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.966', 'efficiency': '0.497', 'TP': '297', 'FP': '42', 'FN': '6', 'precision': '0.876', 'recall': '0.980', 'f1': '0.925'}
#
# Episode 25 finished
# {'coverage_prop': '0.987', 'intensity_prop': '0.726', 'ms1ms2_ratio': '0.851', 'efficiency': '0.528', 'TP': '339', 'FP': '52', 'FN': '5', 'precision': '0.867', 'recall': '0.985', 'f1': '0.922'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.723', 'ms1ms2_ratio': '2.059', 'efficiency': '0.504', 'TP': '174', 'FP': '23', 'FN': '6', 'precision': '0.883', 'recall': '0.967', 'f1': '0.923'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.719', 'ms1ms2_ratio': '1.377', 'efficiency': '0.510', 'TP': '241', 'FP': '31', 'FN': '9', 'precision': '0.886', 'recall': '0.964', 'f1': '0.923'}
#
# Episode 28 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.587', 'efficiency': '0.521', 'TP': '410', 'FP': '69', 'FN': '14', 'precision': '0.856', 'recall': '0.967', 'f1': '0.908'}
#
# Episode 29 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.727', 'ms1ms2_ratio': '1.201', 'efficiency': '0.502', 'TP': '267', 'FP': '28', 'FN': '9', 'precision': '0.905', 'recall': '0.967', 'f1': '0.935'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1789.157050                1860.0          0.408           0.112
# 1  random   -1876.080551                1916.0          0.290           0.086
# 2  random   -1816.705143                1877.0          0.371           0.075
# 3  random   -1830.819675                1890.0          0.316           0.090
# 4  random   -1897.348338                1933.0          0.217           0.041
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.088      0.218   0.131  0.164
# 1          0.005       0.038      0.250   0.093  0.135
# 2          0.008       0.074      0.144   0.078  0.101
# 3          0.005       0.072      0.273   0.112  0.159
# 4          0.003       0.048      0.168   0.045  0.071

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     259.325530                   7.0          0.944           0.582
# 31    DQN     167.001148                   4.0          0.927           0.583
# 32    DQN     239.369736                   6.0          0.937           0.581
# 33    DQN     268.020904                   5.0          0.929           0.619
# 34    DQN     251.431384                  10.0          0.945           0.627
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.885       0.557      0.697   0.921  0.793
# 31          1.995       0.606      0.704   0.900  0.790
# 32          1.137       0.604      0.664   0.907  0.767
# 33          0.929       0.600      0.776   0.911  0.838
# 34          0.944       0.596      0.755   0.929  0.833

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
