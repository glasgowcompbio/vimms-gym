# %% [markdown]
# # Evaluation using QCB chemicals (medium)

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from os.path import exists
import copy

sys.path.append('../..')

# %%
import pylab as plt
import pandas as pd
import numpy as np
from loguru import logger
import seaborn as sns

from stable_baselines3 import DQN, PPO
from sb3_contrib import RecurrentPPO

# %%
from vimms.Common import POSITIVE, set_log_level_warning, load_obj, save_obj
from vimms.ChemicalSamplers import UniformRTAndIntensitySampler, GaussianChromatogramSampler, UniformMZFormulaSampler, \
    MZMLFormulaSampler, MZMLRTandIntensitySampler, MZMLChromatogramSampler
from vimms.Noise import UniformSpikeNoise
from vimms.Evaluation import evaluate_real
from vimms.Chemicals import ChemicalMixtureFromMZML
from vimms.Roi import RoiBuilderParams, SmartRoiParams

from mass_spec_utils.data_import.mzmine import load_picked_boxes

from vimms_gym.env import DDAEnv
from vimms_gym.chemicals import generate_chemicals
from vimms_gym.evaluation import evaluate, run_method
from vimms_gym.common import METHOD_RANDOM, METHOD_FULLSCAN, METHOD_TOPN, METHOD_DQN, \
    METHOD_DQN_COV, METHOD_DQN_INT, METHOD_DQN_MID, METHOD_PPO, METHOD_PPO_RECURRENT

# %% [markdown]
# # 1. Parameters

# %% [markdown]
# Parameters that will be used throughout this notebook. Should be the same as the training ones.

# %% [markdown]
# Chemical generation parameters

# %%
from experiments import preset_qcb_medium
env_alpha = 0.75
env_beta = 0.50
extract = True
params, max_peaks = preset_qcb_medium(None, alpha=env_alpha, beta=env_beta, extract_chromatograms=extract)
params, max_peaks
# Out:
# 2023-03-06 00:48:16.397 | INFO     | experiments:get_samplers:267 - Loaded /Users/joewandy/Work/git/vimms-gym/pickles/samplers_QCB_medium_extracted.p
# ({'chemical_creator': {'mz_range': (100, 600),
#    'rt_range': (400, 800),
#    'intensity_range': (10000.0, 1e+20),
#    'n_chemicals': (200, 500),
#    'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf4874ddf0>,
#    'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf5341d3a0>,
#    'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf5343a640>},
#   'noise': {'enable_spike_noise': True,
#    'noise_density': 0.1,
#    'noise_max_val': 1000.0,
#    'mz_range': (100, 600)},
#   'env': {'ionisation_mode': 'Positive',
#    'rt_range': (400, 800),
#    'isolation_window': 0.7,
#    'use_dew': False,
#    'mz_tol': 10,
#    'rt_tol': 5,
#    'min_ms1_intensity': 5000,
#    'alpha': 0.75,
#    'beta': 0.5}},
#  200)

# %%
# n_chemicals = (200, 500)
# mz_range = (100, 600)
# rt_range = (400, 800)
# intensity_range = (1E4, 1E20)

# %% [markdown]
# Evaluation parameters

# %%
env_name = 'DDAEnv'
intensity_threshold = 0.5
max_peaks = 200

in_dir = 'DQN_1.0E6'
# in_dir = os.path.join('..', '..', 'tune', 'QCB_resimulated_medium')

methods = [
    METHOD_RANDOM,
    # METHOD_PPO,
    # METHOD_PPO_RECURRENT,
    METHOD_DQN,        
    METHOD_TOPN,
]
n_eval_episodes = 30

# %%
# topN parameters
topN_N = 10
topN_rt_tol = 5
min_ms1_intensity = 5000

# smartroi parameters
alpha = 2
beta = 0.5
smartroi_N = topN_N
smartroi_dew = topN_rt_tol

# weighteddew parameters
t0 = 3
t1 = 15
weighteddew_N = 10

# %% [markdown]
# ## Generate chemical sets for evaluation

# %%
fname = 'QCB_chems_medium.p'
found = exists(fname)
if found:
    chem_list = load_obj(fname)
    for chems in chem_list:
        print(len(chems))
# Out:
# 426
# 262
# 394
# 452
# 437
# 200
# 478
# 204
# 424
# 384
# 443
# 249
# 251
# 300
# 206
# 407
# 498
# 372
# 302
# 265
# 468
# 234
# 322
# 310
# 345
# 396
# 203
# 281
# 493
# 304

# %% [markdown]
# Generate new chemicals if not found

# %%
params['chemical_creator']
# Out:
# {'mz_range': (100, 600),
#  'rt_range': (400, 800),
#  'intensity_range': (10000.0, 1e+20),
#  'n_chemicals': (200, 500),
#  'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf4874ddf0>,
#  'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf5341d3a0>,
#  'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf5343a640>}

# %%
if not found:
    repeat = 30
    logger.warning('Generating chemicals')
    
    chemical_creator_params = params['chemical_creator']
    chem_list = []
    for i in range(repeat):
        chems = generate_chemicals(chemical_creator_params)
        print(len(chems))
        chem_list.append(chems)
        
    save_obj(chem_list, fname)

# %%
chem_list = chem_list[0:n_eval_episodes]
len(chem_list)
# Out:
# 30

# %% [markdown]
# # 2. Evaluation

# %%
set_log_level_warning()
# Out:
# 1

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf4874ddf0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf5341d3a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf5343a640>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': False,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.75,
#   'beta': 0.5}}

# %%
horizon = 4
out_dir = 'evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f' % (horizon, env_alpha, env_beta)

# %%
method_eval_results = {}
for method in methods:

    N = 0
    copy_params = copy.deepcopy(params)            
    custom_objects = {
        "learning_rate": 0.0,
        "lr_schedule": lambda _: 0.0,
        "clip_range": lambda _: 0.0,
    }    
    
    if method == METHOD_DQN:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = DQN.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                

    elif method == METHOD_PPO:
        
        fname = os.path.join(in_dir, '%s_%s_alpha_%.2f_beta_%.2f_horizon_%d.zip' % (env_name, method, env_alpha, env_beta, horizon))
        # fname = os.path.join(in_dir, 'metric_reward_timesteps_1.0E6_alpha_%.2f_beta_%.2f' % (env_alpha, env_beta), method, 'best_model.zip')
        
        model = PPO.load(fname, custom_objects=custom_objects)
        copy_params['env']['alpha'] = env_alpha
        copy_params['env']['beta'] = env_beta                
        
    else:
        model = None
        if method == METHOD_TOPN:
            N = topN_N
            effective_rt_tol = topN_rt_tol
            copy_params = dict(params)
            copy_params['env']['use_dew'] = True
            copy_params['env']['rt_tol'] = effective_rt_tol                        

    banner = 'method = %s max_peaks = %d N = %d rt_tol = %d' % (method, max_peaks, N, 
                                                                                   copy_params['env']['rt_tol'])
    print(banner)
    print()            
            
    episodic_results = run_method(env_name, copy_params, max_peaks, chem_list, method, out_dir, 
                                  N=N, min_ms1_intensity=min_ms1_intensity, model=model,
                                  print_eval=True, print_reward=True, intensity_threshold=intensity_threshold,
                                  mzml_prefix=method, horizon=horizon)
    eval_results = [er.eval_res for er in episodic_results]
    method_eval_results[method] = eval_results
    print()
# Out:
# method = random max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 -467.55074518928416
# steps	 1000 	total rewards	 -924.960454379958
# steps	 1500 	total rewards	 -1332.4227402811189
# Finished after 1989 timesteps (1.9052479267120361 seconds) with total reward -1796.97575197884
# {'coverage_prop': '0.383', 'intensity_prop': '0.100', 'ms1ms2_ratio': '0.006', 'efficiency': '0.082', 'TP': '34', 'FP': '129', 'FN': '263', 'precision': '0.209', 'recall': '0.114', 'f1': '0.148', 'total_rewards': -1796.9757519788402, 'invalid_action_count': 1863, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -960.5553488058717
# steps	 1500 	total rewards	 -1433.7211732365001
# Finished after 1988 timesteps (1.0059571266174316 seconds) with total reward -1897.4263019375653
# {'coverage_prop': '0.267', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.006', 'efficiency': '0.035', 'TP': '17', 'FP': '53', 'FN': '192', 'precision': '0.243', 'recall': '0.081', 'f1': '0.122', 'total_rewards': -1897.4263019375649, 'invalid_action_count': 1927, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 -491.833704988668
# steps	 1000 	total rewards	 -978.1122741127842
# steps	 1500 	total rewards	 -1423.90987015504
# Finished after 1991 timesteps (1.2930102348327637 seconds) with total reward -1871.7987954735177
# {'coverage_prop': '0.279', 'intensity_prop': '0.060', 'ms1ms2_ratio': '0.005', 'efficiency': '0.055', 'TP': '21', 'FP': '89', 'FN': '284', 'precision': '0.191', 'recall': '0.069', 'f1': '0.101', 'total_rewards': -1871.7987954735179, 'invalid_action_count': 1913, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 -488.2104943987995
# steps	 1000 	total rewards	 -921.4421481674708
# steps	 1500 	total rewards	 -1324.4152973281111
# Finished after 1985 timesteps (1.417241096496582 seconds) with total reward -1759.0063030681417
# {'coverage_prop': '0.400', 'intensity_prop': '0.139', 'ms1ms2_ratio': '0.008', 'efficiency': '0.092', 'TP': '57', 'FP': '124', 'FN': '271', 'precision': '0.315', 'recall': '0.174', 'f1': '0.224', 'total_rewards': -1759.0063030681426, 'invalid_action_count': 1841, 'num_ms1_scans': 15, 'num_ms2_scans': 1970}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 -490.042261623194
# steps	 1000 	total rewards	 -945.562102602074
# steps	 1500 	total rewards	 -1390.7109369585535
# Finished after 1994 timesteps (1.4808769226074219 seconds) with total reward -1878.180036942264
# {'coverage_prop': '0.279', 'intensity_prop': '0.066', 'ms1ms2_ratio': '0.003', 'efficiency': '0.061', 'TP': '23', 'FP': '99', 'FN': '315', 'precision': '0.189', 'recall': '0.068', 'f1': '0.100', 'total_rewards': -1878.1800369422642, 'invalid_action_count': 1920, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 -487.7683371676725
# steps	 1000 	total rewards	 -962.3500894560893
# steps	 1500 	total rewards	 -1415.6532348208073
# Finished after 1989 timesteps (0.9182441234588623 seconds) with total reward -1877.9673591048145
# {'coverage_prop': '0.375', 'intensity_prop': '0.119', 'ms1ms2_ratio': '0.006', 'efficiency': '0.038', 'TP': '24', 'FP': '51', 'FN': '125', 'precision': '0.320', 'recall': '0.161', 'f1': '0.214', 'total_rewards': -1877.967359104814, 'invalid_action_count': 1916, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 -479.9230864985011
# steps	 1000 	total rewards	 -910.9308998333767
# steps	 1500 	total rewards	 -1328.3343938179814
# Finished after 1987 timesteps (1.5872180461883545 seconds) with total reward -1757.9313685865793
# {'coverage_prop': '0.416', 'intensity_prop': '0.094', 'ms1ms2_ratio': '0.007', 'efficiency': '0.101', 'TP': '40', 'FP': '159', 'FN': '279', 'precision': '0.201', 'recall': '0.125', 'f1': '0.154', 'total_rewards': -1757.9313685865798, 'invalid_action_count': 1839, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 -490.79845465172656
# steps	 1000 	total rewards	 -961.1131529882023
# steps	 1500 	total rewards	 -1419.0402320449632
# Finished after 1990 timesteps (0.8746519088745117 seconds) with total reward -1887.9289933300654
# {'coverage_prop': '0.319', 'intensity_prop': '0.065', 'ms1ms2_ratio': '0.005', 'efficiency': '0.033', 'TP': '11', 'FP': '54', 'FN': '139', 'precision': '0.169', 'recall': '0.073', 'f1': '0.102', 'total_rewards': -1887.9289933300652, 'invalid_action_count': 1923, 'num_ms1_scans': 10, 'num_ms2_scans': 1980}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 -460.18955483163893
# steps	 1000 	total rewards	 -923.5029494397556
# steps	 1500 	total rewards	 -1378.514585146277
# Finished after 1987 timesteps (1.8015990257263184 seconds) with total reward -1837.7092769434157
# {'coverage_prop': '0.300', 'intensity_prop': '0.073', 'ms1ms2_ratio': '0.007', 'efficiency': '0.064', 'TP': '27', 'FP': '100', 'FN': '297', 'precision': '0.213', 'recall': '0.083', 'f1': '0.120', 'total_rewards': -1837.7092769434162, 'invalid_action_count': 1887, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 -473.6648409753671
# steps	 1000 	total rewards	 -942.8411487291041
# steps	 1500 	total rewards	 -1403.6462561475241
# Finished after 1994 timesteps (1.2389140129089355 seconds) with total reward -1861.1134836150454
# {'coverage_prop': '0.362', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.003', 'efficiency': '0.070', 'TP': '32', 'FP': '107', 'FN': '245', 'precision': '0.230', 'recall': '0.116', 'f1': '0.154', 'total_rewards': -1861.1134836150459, 'invalid_action_count': 1910, 'num_ms1_scans': 6, 'num_ms2_scans': 1988}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 -472.8607462102536
# steps	 1000 	total rewards	 -937.2420166098807
# steps	 1500 	total rewards	 -1428.913502203424
# Finished after 1993 timesteps (1.3768789768218994 seconds) with total reward -1881.814839401634
# {'coverage_prop': '0.210', 'intensity_prop': '0.050', 'ms1ms2_ratio': '0.004', 'efficiency': '0.047', 'TP': '21', 'FP': '72', 'FN': '350', 'precision': '0.226', 'recall': '0.057', 'f1': '0.091', 'total_rewards': -1881.8148394016341, 'invalid_action_count': 1923, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -970.3641656551973
# steps	 1500 	total rewards	 -1431.8189748631457
# Finished after 1988 timesteps (1.067427158355713 seconds) with total reward -1888.8067371079078
# {'coverage_prop': '0.293', 'intensity_prop': '0.084', 'ms1ms2_ratio': '0.006', 'efficiency': '0.037', 'TP': '20', 'FP': '53', 'FN': '176', 'precision': '0.274', 'recall': '0.102', 'f1': '0.149', 'total_rewards': -1888.8067371079078, 'invalid_action_count': 1919, 'num_ms1_scans': 12, 'num_ms2_scans': 1976}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -976.2525929680985
# steps	 1500 	total rewards	 -1422.3513795154909
# Finished after 1991 timesteps (1.1442248821258545 seconds) with total reward -1875.8329108341638
# {'coverage_prop': '0.311', 'intensity_prop': '0.074', 'ms1ms2_ratio': '0.005', 'efficiency': '0.039', 'TP': '18', 'FP': '60', 'FN': '173', 'precision': '0.231', 'recall': '0.094', 'f1': '0.134', 'total_rewards': -1875.832910834163, 'invalid_action_count': 1914, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -956.090833273053
# steps	 1500 	total rewards	 -1417.1575508435303
# Finished after 1991 timesteps (1.8393850326538086 seconds) with total reward -1854.0241351379282
# {'coverage_prop': '0.377', 'intensity_prop': '0.101', 'ms1ms2_ratio': '0.005', 'efficiency': '0.057', 'TP': '27', 'FP': '86', 'FN': '187', 'precision': '0.239', 'recall': '0.126', 'f1': '0.165', 'total_rewards': -1854.024135137928, 'invalid_action_count': 1904, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 -486.99245472485643
# steps	 1000 	total rewards	 -960.3902675137365
# steps	 1500 	total rewards	 -1458.6149354239938
# Finished after 1992 timesteps (1.0601239204406738 seconds) with total reward -1937.6925336837403
# {'coverage_prop': '0.155', 'intensity_prop': '0.034', 'ms1ms2_ratio': '0.004', 'efficiency': '0.016', 'TP': '5', 'FP': '27', 'FN': '174', 'precision': '0.156', 'recall': '0.028', 'f1': '0.047', 'total_rewards': -1937.69253368374, 'invalid_action_count': 1956, 'num_ms1_scans': 8, 'num_ms2_scans': 1984}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 -481.450774242133
# steps	 1000 	total rewards	 -914.1348588764024
# steps	 1500 	total rewards	 -1352.7606338257801
# Finished after 1982 timesteps (1.5129671096801758 seconds) with total reward -1776.2492800211226
# {'coverage_prop': '0.437', 'intensity_prop': '0.124', 'ms1ms2_ratio': '0.009', 'efficiency': '0.091', 'TP': '48', 'FP': '130', 'FN': '229', 'precision': '0.270', 'recall': '0.173', 'f1': '0.211', 'total_rewards': -1776.2492800211223, 'invalid_action_count': 1846, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 -462.77851175289913
# steps	 1000 	total rewards	 -879.1253183589567
# steps	 1500 	total rewards	 -1341.5311166688662
# Finished after 1986 timesteps (1.7387690544128418 seconds) with total reward -1766.2789767364502
# {'coverage_prop': '0.384', 'intensity_prop': '0.107', 'ms1ms2_ratio': '0.007', 'efficiency': '0.097', 'TP': '45', 'FP': '146', 'FN': '307', 'precision': '0.236', 'recall': '0.128', 'f1': '0.166', 'total_rewards': -1766.2789767364504, 'invalid_action_count': 1844, 'num_ms1_scans': 14, 'num_ms2_scans': 1972}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 -476.9990998287125
# steps	 1000 	total rewards	 -941.5446515122821
# steps	 1500 	total rewards	 -1361.189609831022
# Finished after 1982 timesteps (1.5575380325317383 seconds) with total reward -1783.8079018315752
# {'coverage_prop': '0.374', 'intensity_prop': '0.110', 'ms1ms2_ratio': '0.009', 'efficiency': '0.071', 'TP': '42', 'FP': '97', 'FN': '233', 'precision': '0.302', 'recall': '0.153', 'f1': '0.203', 'total_rewards': -1783.8079018315743, 'invalid_action_count': 1853, 'num_ms1_scans': 18, 'num_ms2_scans': 1964}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 -484.4335609943478
# steps	 1000 	total rewards	 -960.2448111009248
# steps	 1500 	total rewards	 -1434.8030911365104
# Finished after 1989 timesteps (1.4579169750213623 seconds) with total reward -1898.6224401234317
# {'coverage_prop': '0.219', 'intensity_prop': '0.050', 'ms1ms2_ratio': '0.006', 'efficiency': '0.033', 'TP': '13', 'FP': '53', 'FN': '236', 'precision': '0.197', 'recall': '0.052', 'f1': '0.083', 'total_rewards': -1898.6224401234324, 'invalid_action_count': 1928, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 -500.0
# steps	 1000 	total rewards	 -965.3275572894302
# steps	 1500 	total rewards	 -1430.5552624845802
# Finished after 1991 timesteps (1.1413347721099854 seconds) with total reward -1892.5470548674375
# {'coverage_prop': '0.245', 'intensity_prop': '0.051', 'ms1ms2_ratio': '0.005', 'efficiency': '0.033', 'TP': '11', 'FP': '54', 'FN': '200', 'precision': '0.169', 'recall': '0.052', 'f1': '0.080', 'total_rewards': -1892.547054867438, 'invalid_action_count': 1926, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 -486.02912959960236
# steps	 1000 	total rewards	 -919.7769590288949
# steps	 1500 	total rewards	 -1340.9021102255347
# Finished after 1991 timesteps (1.6668858528137207 seconds) with total reward -1766.8219928454068
# {'coverage_prop': '0.395', 'intensity_prop': '0.114', 'ms1ms2_ratio': '0.005', 'efficiency': '0.093', 'TP': '48', 'FP': '137', 'FN': '283', 'precision': '0.259', 'recall': '0.145', 'f1': '0.186', 'total_rewards': -1766.8219928454062, 'invalid_action_count': 1848, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 -489.00813607263194
# steps	 1000 	total rewards	 -957.6675311553365
# steps	 1500 	total rewards	 -1402.906572457343
# Finished after 1989 timesteps (1.3050620555877686 seconds) with total reward -1873.6127640798497
# {'coverage_prop': '0.376', 'intensity_prop': '0.079', 'ms1ms2_ratio': '0.006', 'efficiency': '0.044', 'TP': '15', 'FP': '73', 'FN': '146', 'precision': '0.170', 'recall': '0.093', 'f1': '0.120', 'total_rewards': -1873.61276407985, 'invalid_action_count': 1914, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 -478.0873206460411
# steps	 1000 	total rewards	 -945.6880360093623
# steps	 1500 	total rewards	 -1406.6365697574379
# Finished after 1987 timesteps (1.4523451328277588 seconds) with total reward -1879.9233098160857
# {'coverage_prop': '0.286', 'intensity_prop': '0.064', 'ms1ms2_ratio': '0.007', 'efficiency': '0.047', 'TP': '18', 'FP': '74', 'FN': '230', 'precision': '0.196', 'recall': '0.073', 'f1': '0.106', 'total_rewards': -1879.923309816086, 'invalid_action_count': 1918, 'num_ms1_scans': 13, 'num_ms2_scans': 1974}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 -496.2182435630631
# steps	 1000 	total rewards	 -943.774432862472
# steps	 1500 	total rewards	 -1395.4197298570734
# Finished after 1989 timesteps (1.7779300212860107 seconds) with total reward -1863.3083160992828
# {'coverage_prop': '0.294', 'intensity_prop': '0.063', 'ms1ms2_ratio': '0.006', 'efficiency': '0.046', 'TP': '14', 'FP': '77', 'FN': '219', 'precision': '0.154', 'recall': '0.060', 'f1': '0.086', 'total_rewards': -1863.3083160992828, 'invalid_action_count': 1906, 'num_ms1_scans': 11, 'num_ms2_scans': 1978}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 -494.4179494811891
# steps	 1000 	total rewards	 -968.1778137963153
# steps	 1500 	total rewards	 -1403.2008706046945
# Finished after 1991 timesteps (1.4138460159301758 seconds) with total reward -1824.8726026401
# {'coverage_prop': '0.391', 'intensity_prop': '0.080', 'ms1ms2_ratio': '0.005', 'efficiency': '0.068', 'TP': '25', 'FP': '110', 'FN': '210', 'precision': '0.185', 'recall': '0.106', 'f1': '0.135', 'total_rewards': -1824.8726026401, 'invalid_action_count': 1888, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 -487.04512956387686
# steps	 1000 	total rewards	 -946.9637095898385
# steps	 1500 	total rewards	 -1400.7226920299022
# Finished after 1991 timesteps (2.315685987472534 seconds) with total reward -1847.8130612814202
# {'coverage_prop': '0.351', 'intensity_prop': '0.095', 'ms1ms2_ratio': '0.005', 'efficiency': '0.070', 'TP': '33', 'FP': '106', 'FN': '257', 'precision': '0.237', 'recall': '0.114', 'f1': '0.154', 'total_rewards': -1847.8130612814202, 'invalid_action_count': 1900, 'num_ms1_scans': 9, 'num_ms2_scans': 1982}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 -496.19611775510646
# steps	 1000 	total rewards	 -975.1332221786014
# steps	 1500 	total rewards	 -1410.8322773732625
# Finished after 1984 timesteps (1.3528451919555664 seconds) with total reward -1872.9016206401438
# {'coverage_prop': '0.325', 'intensity_prop': '0.094', 'ms1ms2_ratio': '0.008', 'efficiency': '0.034', 'TP': '15', 'FP': '51', 'FN': '137', 'precision': '0.227', 'recall': '0.099', 'f1': '0.138', 'total_rewards': -1872.9016206401438, 'invalid_action_count': 1911, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 -499.0
# steps	 1000 	total rewards	 -982.6860846498246
# steps	 1500 	total rewards	 -1459.5591168624883
# Finished after 1993 timesteps (1.190652847290039 seconds) with total reward -1934.4493398263803
# {'coverage_prop': '0.181', 'intensity_prop': '0.036', 'ms1ms2_ratio': '0.004', 'efficiency': '0.026', 'TP': '8', 'FP': '43', 'FN': '230', 'precision': '0.157', 'recall': '0.034', 'f1': '0.055', 'total_rewards': -1934.4493398263799, 'invalid_action_count': 1955, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 -477.31359135055544
# steps	 1000 	total rewards	 -930.7948223496289
# steps	 1500 	total rewards	 -1295.305249226348
# Finished after 1993 timesteps (2.0152969360351562 seconds) with total reward -1778.9597030368113
# {'coverage_prop': '0.379', 'intensity_prop': '0.106', 'ms1ms2_ratio': '0.004', 'efficiency': '0.094', 'TP': '50', 'FP': '137', 'FN': '306', 'precision': '0.267', 'recall': '0.140', 'f1': '0.184', 'total_rewards': -1778.959703036812, 'invalid_action_count': 1855, 'num_ms1_scans': 7, 'num_ms2_scans': 1986}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 -487.01621512209994
# steps	 1000 	total rewards	 -934.5119428752195
# steps	 1500 	total rewards	 -1395.6757050694312
# Finished after 1984 timesteps (1.4002950191497803 seconds) with total reward -1822.422349935273
# {'coverage_prop': '0.385', 'intensity_prop': '0.139', 'ms1ms2_ratio': '0.008', 'efficiency': '0.059', 'TP': '41', 'FP': '76', 'FN': '187', 'precision': '0.350', 'recall': '0.180', 'f1': '0.238', 'total_rewards': -1822.4223499352734, 'invalid_action_count': 1877, 'num_ms1_scans': 16, 'num_ms2_scans': 1968}
# /opt/anaconda3/envs/vimms-gym/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:228: UserWarning:
#
# This system does not have apparently enough memory to store the complete replay buffer 1.67GB > 0.32GB
# method = DQN max_peaks = 200 N = 0 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 82.99500704332362
# steps	 1000 	total rewards	 208.78323385898202
# Finished after 1345 timesteps (7.4111487865448 seconds) with total reward 261.1482931849981
# {'coverage_prop': '0.948', 'intensity_prop': '0.586', 'ms1ms2_ratio': '0.952', 'efficiency': '0.586', 'TP': '276', 'FP': '128', 'FN': '22', 'precision': '0.683', 'recall': '0.926', 'f1': '0.786', 'total_rewards': 261.1482931849979, 'invalid_action_count': 8, 'num_ms1_scans': 656, 'num_ms2_scans': 689}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 66.86291433286048
# steps	 1000 	total rewards	 152.16902036603352
# Finished after 1209 timesteps (6.799662113189697 seconds) with total reward 171.824847085501
# {'coverage_prop': '0.943', 'intensity_prop': '0.593', 'ms1ms2_ratio': '1.906', 'efficiency': '0.594', 'TP': '173', 'FP': '74', 'FN': '15', 'precision': '0.700', 'recall': '0.920', 'f1': '0.795', 'total_rewards': 171.8248470855009, 'invalid_action_count': 1, 'num_ms1_scans': 793, 'num_ms2_scans': 416}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 69.93510580251922
# steps	 1000 	total rewards	 196.03805342010054
# Finished after 1299 timesteps (8.179803848266602 seconds) with total reward 242.72282145741508
# {'coverage_prop': '0.931', 'intensity_prop': '0.576', 'ms1ms2_ratio': '1.172', 'efficiency': '0.614', 'TP': '249', 'FP': '118', 'FN': '27', 'precision': '0.678', 'recall': '0.902', 'f1': '0.774', 'total_rewards': 242.722821457415, 'invalid_action_count': 3, 'num_ms1_scans': 701, 'num_ms2_scans': 598}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 83.32593405474191
# steps	 1000 	total rewards	 212.39015060597225
# Finished after 1465 timesteps (10.089487075805664 seconds) with total reward -172.77485494533718
# {'coverage_prop': '0.821', 'intensity_prop': '0.531', 'ms1ms2_ratio': '0.575', 'efficiency': '0.399', 'TP': '274', 'FP': '97', 'FN': '81', 'precision': '0.739', 'recall': '0.772', 'f1': '0.755', 'total_rewards': -172.77485494533713, 'invalid_action_count': 397, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 72.53310320398971
# steps	 1000 	total rewards	 204.4961561175515
# Finished after 1342 timesteps (7.822129249572754 seconds) with total reward 244.53293410467413
# {'coverage_prop': '0.950', 'intensity_prop': '0.627', 'ms1ms2_ratio': '0.962', 'efficiency': '0.607', 'TP': '294', 'FP': '121', 'FN': '22', 'precision': '0.708', 'recall': '0.930', 'f1': '0.804', 'total_rewards': 244.5329341046741, 'invalid_action_count': 15, 'num_ms1_scans': 658, 'num_ms2_scans': 684}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 51.80671530423336
# steps	 1000 	total rewards	 114.06867513652625
# Finished after 1152 timesteps (7.290495157241821 seconds) with total reward 123.39026667398466
# {'coverage_prop': '0.940', 'intensity_prop': '0.613', 'ms1ms2_ratio': '2.802', 'efficiency': '0.620', 'TP': '137', 'FP': '51', 'FN': '12', 'precision': '0.729', 'recall': '0.919', 'f1': '0.813', 'total_rewards': 123.39026667398463, 'invalid_action_count': 4, 'num_ms1_scans': 849, 'num_ms2_scans': 303}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 96.72712421016303
# steps	 1000 	total rewards	 223.6444270713153
# Finished after 1376 timesteps (7.73250412940979 seconds) with total reward 283.8816424082396
# {'coverage_prop': '0.921', 'intensity_prop': '0.587', 'ms1ms2_ratio': '0.830', 'efficiency': '0.585', 'TP': '304', 'FP': '136', 'FN': '38', 'precision': '0.691', 'recall': '0.889', 'f1': '0.777', 'total_rewards': 283.88164240823943, 'invalid_action_count': 1, 'num_ms1_scans': 624, 'num_ms2_scans': 752}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 50.117866670226626
# steps	 1000 	total rewards	 119.76013362664115
# Finished after 1171 timesteps (7.261448860168457 seconds) with total reward 129.8124920473161
# {'coverage_prop': '0.936', 'intensity_prop': '0.609', 'ms1ms2_ratio': '2.444', 'efficiency': '0.562', 'TP': '142', 'FP': '49', 'FN': '13', 'precision': '0.743', 'recall': '0.916', 'f1': '0.821', 'total_rewards': 129.81249204731617, 'invalid_action_count': 6, 'num_ms1_scans': 831, 'num_ms2_scans': 340}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 86.6437779922405
# steps	 1000 	total rewards	 194.26931034214113
# Finished after 1333 timesteps (8.811102390289307 seconds) with total reward 249.23702917318553
# {'coverage_prop': '0.936', 'intensity_prop': '0.599', 'ms1ms2_ratio': '1.002', 'efficiency': '0.596', 'TP': '290', 'FP': '107', 'FN': '27', 'precision': '0.730', 'recall': '0.915', 'f1': '0.812', 'total_rewards': 249.23702917318565, 'invalid_action_count': 5, 'num_ms1_scans': 667, 'num_ms2_scans': 666}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 63.7030983120745
# steps	 1000 	total rewards	 179.00263426020754
# Finished after 1286 timesteps (6.513136863708496 seconds) with total reward 214.63408523420625
# {'coverage_prop': '0.922', 'intensity_prop': '0.595', 'ms1ms2_ratio': '1.248', 'efficiency': '0.619', 'TP': '246', 'FP': '108', 'FN': '30', 'precision': '0.695', 'recall': '0.891', 'f1': '0.781', 'total_rewards': 214.63408523420622, 'invalid_action_count': 9, 'num_ms1_scans': 714, 'num_ms2_scans': 572}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 75.99830525161443
# steps	 1000 	total rewards	 206.73944046701436
# Finished after 1384 timesteps (9.57162880897522 seconds) with total reward 260.5777240492657
# {'coverage_prop': '0.921', 'intensity_prop': '0.615', 'ms1ms2_ratio': '0.802', 'efficiency': '0.531', 'TP': '306', 'FP': '102', 'FN': '35', 'precision': '0.750', 'recall': '0.897', 'f1': '0.817', 'total_rewards': 260.57772404926556, 'invalid_action_count': 9, 'num_ms1_scans': 616, 'num_ms2_scans': 768}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 64.02838421022253
# steps	 1000 	total rewards	 130.8155264265463
# Finished after 1207 timesteps (7.901872158050537 seconds) with total reward 155.58066630875084
# {'coverage_prop': '0.936', 'intensity_prop': '0.614', 'ms1ms2_ratio': '1.923', 'efficiency': '0.564', 'TP': '176', 'FP': '57', 'FN': '16', 'precision': '0.755', 'recall': '0.917', 'f1': '0.828', 'total_rewards': 155.58066630875095, 'invalid_action_count': 1, 'num_ms1_scans': 794, 'num_ms2_scans': 413}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 64.43184088482305
# steps	 1000 	total rewards	 135.9085330719979
# Finished after 1222 timesteps (6.1011528968811035 seconds) with total reward 157.3644433851592
# {'coverage_prop': '0.936', 'intensity_prop': '0.560', 'ms1ms2_ratio': '1.765', 'efficiency': '0.532', 'TP': '150', 'FP': '85', 'FN': '16', 'precision': '0.638', 'recall': '0.904', 'f1': '0.748', 'total_rewards': 157.36444338515923, 'invalid_action_count': 3, 'num_ms1_scans': 780, 'num_ms2_scans': 442}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 55.63773242360142
# steps	 1000 	total rewards	 151.60689988841114
# Finished after 1288 timesteps (8.7547447681427 seconds) with total reward 187.94191595433094
# {'coverage_prop': '0.943', 'intensity_prop': '0.591', 'ms1ms2_ratio': '1.236', 'efficiency': '0.491', 'TP': '193', 'FP': '90', 'FN': '17', 'precision': '0.682', 'recall': '0.919', 'f1': '0.783', 'total_rewards': 187.941915954331, 'invalid_action_count': 6, 'num_ms1_scans': 712, 'num_ms2_scans': 576}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 50.09647485970453
# steps	 1000 	total rewards	 118.41589554170416
# Finished after 1176 timesteps (6.342488050460815 seconds) with total reward 135.08679263383615
# {'coverage_prop': '0.937', 'intensity_prop': '0.604', 'ms1ms2_ratio': '2.350', 'efficiency': '0.550', 'TP': '141', 'FP': '52', 'FN': '13', 'precision': '0.731', 'recall': '0.916', 'f1': '0.813', 'total_rewards': 135.08679263383607, 'invalid_action_count': 4, 'num_ms1_scans': 825, 'num_ms2_scans': 351}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 74.0337671354294
# steps	 1000 	total rewards	 194.06535412901593
# Finished after 1302 timesteps (16.2185959815979 seconds) with total reward 241.98075171472738
# {'coverage_prop': '0.943', 'intensity_prop': '0.628', 'ms1ms2_ratio': '1.159', 'efficiency': '0.637', 'TP': '289', 'FP': '95', 'FN': '23', 'precision': '0.753', 'recall': '0.926', 'f1': '0.830', 'total_rewards': 241.9807517147272, 'invalid_action_count': 4, 'num_ms1_scans': 699, 'num_ms2_scans': 603}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 92.58274190827458
# steps	 1000 	total rewards	 225.5245338441001
# Finished after 1396 timesteps (8.447966814041138 seconds) with total reward 281.0637600385352
# {'coverage_prop': '0.944', 'intensity_prop': '0.606', 'ms1ms2_ratio': '0.763', 'efficiency': '0.593', 'TP': '340', 'FP': '130', 'FN': '28', 'precision': '0.723', 'recall': '0.924', 'f1': '0.811', 'total_rewards': 281.0637600385354, 'invalid_action_count': 18, 'num_ms1_scans': 604, 'num_ms2_scans': 792}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 74.19531351975203
# steps	 1000 	total rewards	 182.52771087950578
# Finished after 1279 timesteps (13.164204597473145 seconds) with total reward 221.26534033489403
# {'coverage_prop': '0.922', 'intensity_prop': '0.583', 'ms1ms2_ratio': '1.296', 'efficiency': '0.616', 'TP': '246', 'FP': '97', 'FN': '29', 'precision': '0.717', 'recall': '0.895', 'f1': '0.796', 'total_rewards': 221.2653403348941, 'invalid_action_count': 3, 'num_ms1_scans': 722, 'num_ms2_scans': 557}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 65.42855756155055
# steps	 1000 	total rewards	 154.55215301419508
# Finished after 1257 timesteps (6.472131252288818 seconds) with total reward 189.01901697027984
# {'coverage_prop': '0.940', 'intensity_prop': '0.609', 'ms1ms2_ratio': '1.450', 'efficiency': '0.554', 'TP': '204', 'FP': '80', 'FN': '18', 'precision': '0.718', 'recall': '0.919', 'f1': '0.806', 'total_rewards': 189.0190169702799, 'invalid_action_count': 5, 'num_ms1_scans': 744, 'num_ms2_scans': 513}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 62.248402974713024
# steps	 1000 	total rewards	 146.15557783430964
# Finished after 1228 timesteps (5.804331064224243 seconds) with total reward 171.69095484910758
# {'coverage_prop': '0.947', 'intensity_prop': '0.588', 'ms1ms2_ratio': '1.705', 'efficiency': '0.553', 'TP': '171', 'FP': '80', 'FN': '14', 'precision': '0.681', 'recall': '0.924', 'f1': '0.784', 'total_rewards': 171.69095484910767, 'invalid_action_count': 3, 'num_ms1_scans': 774, 'num_ms2_scans': 454}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 86.48287648012084
# steps	 1000 	total rewards	 214.58348637388997
# Finished after 1357 timesteps (13.90175199508667 seconds) with total reward 266.90937274877354
# {'coverage_prop': '0.902', 'intensity_prop': '0.581', 'ms1ms2_ratio': '0.901', 'efficiency': '0.591', 'TP': '310', 'FP': '112', 'FN': '46', 'precision': '0.735', 'recall': '0.871', 'f1': '0.797', 'total_rewards': 266.9093727487736, 'invalid_action_count': 5, 'num_ms1_scans': 643, 'num_ms2_scans': 714}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 59.2561053567693
# steps	 1000 	total rewards	 137.6992751754741
# Finished after 1179 timesteps (7.9193010330200195 seconds) with total reward 151.36534554235539
# {'coverage_prop': '0.940', 'intensity_prop': '0.593', 'ms1ms2_ratio': '2.312', 'efficiency': '0.618', 'TP': '154', 'FP': '66', 'FN': '14', 'precision': '0.700', 'recall': '0.917', 'f1': '0.794', 'total_rewards': 151.36534554235536, 'invalid_action_count': 1, 'num_ms1_scans': 823, 'num_ms2_scans': 356}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 72.62311298537246
# steps	 1000 	total rewards	 170.06715627404384
# Finished after 1272 timesteps (11.181276082992554 seconds) with total reward 199.22700777249963
# {'coverage_prop': '0.935', 'intensity_prop': '0.611', 'ms1ms2_ratio': '1.338', 'efficiency': '0.553', 'TP': '227', 'FP': '74', 'FN': '21', 'precision': '0.754', 'recall': '0.915', 'f1': '0.827', 'total_rewards': 199.22700777249955, 'invalid_action_count': 4, 'num_ms1_scans': 728, 'num_ms2_scans': 544}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 71.62745602874294
# steps	 1000 	total rewards	 160.51448536101452
# Finished after 1234 timesteps (7.852552890777588 seconds) with total reward 185.57411809865042
# {'coverage_prop': '0.932', 'intensity_prop': '0.597', 'ms1ms2_ratio': '1.642', 'efficiency': '0.619', 'TP': '211', 'FP': '78', 'FN': '21', 'precision': '0.730', 'recall': '0.909', 'f1': '0.810', 'total_rewards': 185.57411809865042, 'invalid_action_count': 7, 'num_ms1_scans': 767, 'num_ms2_scans': 467}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 67.86041688696511
# steps	 1000 	total rewards	 172.44010016018586
# Finished after 1314 timesteps (8.096570014953613 seconds) with total reward 219.76284935359712
# {'coverage_prop': '0.939', 'intensity_prop': '0.604', 'ms1ms2_ratio': '1.092', 'efficiency': '0.516', 'TP': '234', 'FP': '90', 'FN': '21', 'precision': '0.722', 'recall': '0.918', 'f1': '0.808', 'total_rewards': 219.76284935359723, 'invalid_action_count': 4, 'num_ms1_scans': 686, 'num_ms2_scans': 628}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 68.1915850600786
# steps	 1000 	total rewards	 184.7943211437988
# Finished after 1301 timesteps (9.934107780456543 seconds) with total reward 239.88070041605118
# {'coverage_prop': '0.960', 'intensity_prop': '0.619', 'ms1ms2_ratio': '1.161', 'efficiency': '0.631', 'TP': '268', 'FP': '112', 'FN': '16', 'precision': '0.705', 'recall': '0.944', 'f1': '0.807', 'total_rewards': 239.88070041605116, 'invalid_action_count': 2, 'num_ms1_scans': 699, 'num_ms2_scans': 602}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 47.14111101256381
# steps	 1000 	total rewards	 116.65980610824361
# Finished after 1168 timesteps (5.412621974945068 seconds) with total reward 129.1200516800635
# {'coverage_prop': '0.936', 'intensity_prop': '0.584', 'ms1ms2_ratio': '2.497', 'efficiency': '0.569', 'TP': '138', 'FP': '52', 'FN': '13', 'precision': '0.726', 'recall': '0.914', 'f1': '0.809', 'total_rewards': 129.1200516800635, 'invalid_action_count': 5, 'num_ms1_scans': 834, 'num_ms2_scans': 334}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 61.60920977574979
# steps	 1000 	total rewards	 152.75268272617996
# Finished after 1204 timesteps (9.655548334121704 seconds) with total reward 186.4866050897936
# {'coverage_prop': '0.947', 'intensity_prop': '0.595', 'ms1ms2_ratio': '1.966', 'efficiency': '0.655', 'TP': '190', 'FP': '76', 'FN': '15', 'precision': '0.714', 'recall': '0.927', 'f1': '0.807', 'total_rewards': 186.48660508979376, 'invalid_action_count': 1, 'num_ms1_scans': 798, 'num_ms2_scans': 406}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 87.98210227271451
# steps	 1000 	total rewards	 218.6683725042161
# Finished after 1366 timesteps (8.267612934112549 seconds) with total reward 289.4453049046782
# {'coverage_prop': '0.911', 'intensity_prop': '0.566', 'ms1ms2_ratio': '0.866', 'efficiency': '0.613', 'TP': '309', 'FP': '140', 'FN': '44', 'precision': '0.688', 'recall': '0.875', 'f1': '0.771', 'total_rewards': 289.4453049046784, 'invalid_action_count': 6, 'num_ms1_scans': 634, 'num_ms2_scans': 732}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 72.16319508377008
# steps	 1000 	total rewards	 160.26418404512026
# Finished after 1258 timesteps (6.965052843093872 seconds) with total reward 194.77461838458356
# {'coverage_prop': '0.951', 'intensity_prop': '0.647', 'ms1ms2_ratio': '1.443', 'efficiency': '0.561', 'TP': '217', 'FP': '72', 'FN': '15', 'precision': '0.751', 'recall': '0.935', 'f1': '0.833', 'total_rewards': 194.7746183845836, 'invalid_action_count': 0, 'num_ms1_scans': 743, 'num_ms2_scans': 515}
#
# method = topN max_peaks = 200 N = 10 rt_tol = 5
#
#
# Episode 0 (426 chemicals)
# steps	 500 	total rewards	 69.13272730373676
# steps	 1000 	total rewards	 167.52401180884436
# steps	 1500 	total rewards	 268.835772555762
# Finished after 1722 timesteps (14.592321872711182 seconds) with total reward 302.6904731091943
# {'coverage_prop': '0.934', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.193', 'efficiency': '0.276', 'TP': '354', 'FP': '44', 'FN': '28', 'precision': '0.889', 'recall': '0.927', 'f1': '0.908', 'total_rewards': 302.69047310919456, 'invalid_action_count': 0, 'num_ms1_scans': 278, 'num_ms2_scans': 1444}
#
# Episode 1 (262 chemicals)
# steps	 500 	total rewards	 63.267206375349446
# steps	 1000 	total rewards	 147.22176856550522
# steps	 1500 	total rewards	 206.13306960735235
# Finished after 1556 timesteps (16.161852836608887 seconds) with total reward 209.90071398411402
# {'coverage_prop': '0.950', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.399', 'efficiency': '0.224', 'TP': '235', 'FP': '14', 'FN': '13', 'precision': '0.944', 'recall': '0.948', 'f1': '0.946', 'total_rewards': 209.90071398411385, 'invalid_action_count': 0, 'num_ms1_scans': 444, 'num_ms2_scans': 1112}
#
# Episode 2 (394 chemicals)
# steps	 500 	total rewards	 64.43100494804028
# steps	 1000 	total rewards	 157.75604831162377
# steps	 1500 	total rewards	 252.45340089554875
# Finished after 1669 timesteps (14.085133790969849 seconds) with total reward 272.30893570096987
# {'coverage_prop': '0.926', 'intensity_prop': '0.727', 'ms1ms2_ratio': '0.247', 'efficiency': '0.273', 'TP': '325', 'FP': '40', 'FN': '29', 'precision': '0.890', 'recall': '0.918', 'f1': '0.904', 'total_rewards': 272.30893570097004, 'invalid_action_count': 0, 'num_ms1_scans': 331, 'num_ms2_scans': 1338}
#
# Episode 3 (452 chemicals)
# steps	 500 	total rewards	 77.56407306217639
# steps	 1000 	total rewards	 175.3136366970973
# steps	 1500 	total rewards	 267.39028443089785
# Finished after 1717 timesteps (14.157504081726074 seconds) with total reward 303.16179552508345
# {'coverage_prop': '0.929', 'intensity_prop': '0.754', 'ms1ms2_ratio': '0.198', 'efficiency': '0.293', 'TP': '391', 'FP': '29', 'FN': '32', 'precision': '0.931', 'recall': '0.924', 'f1': '0.928', 'total_rewards': 303.1617955250836, 'invalid_action_count': 0, 'num_ms1_scans': 284, 'num_ms2_scans': 1433}
#
# Episode 4 (437 chemicals)
# steps	 500 	total rewards	 67.45194904638231
# steps	 1000 	total rewards	 177.928405622967
# steps	 1500 	total rewards	 272.89606049379927
# Finished after 1704 timesteps (14.000662088394165 seconds) with total reward 302.5090574147593
# {'coverage_prop': '0.961', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.210', 'efficiency': '0.298', 'TP': '370', 'FP': '50', 'FN': '17', 'precision': '0.881', 'recall': '0.956', 'f1': '0.917', 'total_rewards': 302.50905741475964, 'invalid_action_count': 0, 'num_ms1_scans': 296, 'num_ms2_scans': 1408}
#
# Episode 5 (200 chemicals)
# steps	 500 	total rewards	 42.95325779749826
# steps	 1000 	total rewards	 116.41665894186508
# Finished after 1408 timesteps (10.772622108459473 seconds) with total reward 156.12372896456625
# {'coverage_prop': '0.960', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.725', 'efficiency': '0.235', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953', 'total_rewards': 156.12372896456614, 'invalid_action_count': 0, 'num_ms1_scans': 592, 'num_ms2_scans': 816}
#
# Episode 6 (478 chemicals)
# steps	 500 	total rewards	 80.61021704365692
# steps	 1000 	total rewards	 181.52198733691552
# steps	 1500 	total rewards	 274.7787285689685
# Finished after 1744 timesteps (14.124528169631958 seconds) with total reward 313.15118439694226
# {'coverage_prop': '0.895', 'intensity_prop': '0.689', 'ms1ms2_ratio': '0.172', 'efficiency': '0.288', 'TP': '369', 'FP': '59', 'FN': '50', 'precision': '0.862', 'recall': '0.881', 'f1': '0.871', 'total_rewards': 313.15118439694254, 'invalid_action_count': 0, 'num_ms1_scans': 256, 'num_ms2_scans': 1488}
#
# Episode 7 (204 chemicals)
# steps	 500 	total rewards	 44.238971301558195
# steps	 1000 	total rewards	 125.1842960286907
# Finished after 1468 timesteps (11.866950988769531 seconds) with total reward 168.96147789407007
# {'coverage_prop': '0.966', 'intensity_prop': '0.799', 'ms1ms2_ratio': '0.568', 'efficiency': '0.210', 'TP': '185', 'FP': '12', 'FN': '7', 'precision': '0.939', 'recall': '0.964', 'f1': '0.951', 'total_rewards': 168.96147789407013, 'invalid_action_count': 0, 'num_ms1_scans': 532, 'num_ms2_scans': 936}
#
# Episode 8 (424 chemicals)
# steps	 500 	total rewards	 75.23310727179368
# steps	 1000 	total rewards	 162.50175052042312
# steps	 1500 	total rewards	 259.0071448022833
# Finished after 1736 timesteps (16.753768920898438 seconds) with total reward 290.77741434124465
# {'coverage_prop': '0.936', 'intensity_prop': '0.751', 'ms1ms2_ratio': '0.179', 'efficiency': '0.270', 'TP': '364', 'FP': '33', 'FN': '27', 'precision': '0.917', 'recall': '0.931', 'f1': '0.924', 'total_rewards': 290.7774143412449, 'invalid_action_count': 0, 'num_ms1_scans': 264, 'num_ms2_scans': 1472}
#
# Episode 9 (384 chemicals)
# steps	 500 	total rewards	 63.21692569981598
# steps	 1000 	total rewards	 156.39946621256962
# steps	 1500 	total rewards	 247.23426927362414
# Finished after 1667 timesteps (12.992465019226074 seconds) with total reward 264.56080791299576
# {'coverage_prop': '0.940', 'intensity_prop': '0.756', 'ms1ms2_ratio': '0.250', 'efficiency': '0.271', 'TP': '326', 'FP': '35', 'FN': '23', 'precision': '0.903', 'recall': '0.934', 'f1': '0.918', 'total_rewards': 264.56080791299604, 'invalid_action_count': 0, 'num_ms1_scans': 333, 'num_ms2_scans': 1334}
#
# Episode 10 (443 chemicals)
# steps	 500 	total rewards	 68.2444174280495
# steps	 1000 	total rewards	 161.01675884777742
# steps	 1500 	total rewards	 262.27604479049864
# Finished after 1737 timesteps (14.562350988388062 seconds) with total reward 292.1533148585758
# {'coverage_prop': '0.896', 'intensity_prop': '0.725', 'ms1ms2_ratio': '0.178', 'efficiency': '0.269', 'TP': '363', 'FP': '34', 'FN': '46', 'precision': '0.914', 'recall': '0.888', 'f1': '0.901', 'total_rewards': 292.1533148585763, 'invalid_action_count': 0, 'num_ms1_scans': 263, 'num_ms2_scans': 1474}
#
# Episode 11 (249 chemicals)
# steps	 500 	total rewards	 56.82684078254565
# steps	 1000 	total rewards	 130.42240094938646
# steps	 1500 	total rewards	 185.85089936171542
# Finished after 1530 timesteps (21.704090118408203 seconds) with total reward 188.08148170069052
# {'coverage_prop': '0.956', 'intensity_prop': '0.802', 'ms1ms2_ratio': '0.443', 'efficiency': '0.225', 'TP': '225', 'FP': '13', 'FN': '11', 'precision': '0.945', 'recall': '0.953', 'f1': '0.949', 'total_rewards': 188.08148170069046, 'invalid_action_count': 0, 'num_ms1_scans': 470, 'num_ms2_scans': 1060}
#
# Episode 12 (251 chemicals)
# steps	 500 	total rewards	 52.46417639089912
# steps	 1000 	total rewards	 126.57479266335895
# steps	 1500 	total rewards	 190.94713768391432
# Finished after 1602 timesteps (16.973135948181152 seconds) with total reward 201.35718472341065
# {'coverage_prop': '0.944', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.331', 'efficiency': '0.197', 'TP': '219', 'FP': '18', 'FN': '14', 'precision': '0.924', 'recall': '0.940', 'f1': '0.932', 'total_rewards': 201.3571847234108, 'invalid_action_count': 0, 'num_ms1_scans': 398, 'num_ms2_scans': 1204}
#
# Episode 13 (300 chemicals)
# steps	 500 	total rewards	 53.05120273761639
# steps	 1000 	total rewards	 133.20105984363587
# steps	 1500 	total rewards	 208.21959872366398
# Finished after 1645 timesteps (15.329730987548828 seconds) with total reward 222.27204370347346
# {'coverage_prop': '0.940', 'intensity_prop': '0.747', 'ms1ms2_ratio': '0.275', 'efficiency': '0.219', 'TP': '254', 'FP': '28', 'FN': '18', 'precision': '0.901', 'recall': '0.934', 'f1': '0.917', 'total_rewards': 222.27204370347386, 'invalid_action_count': 0, 'num_ms1_scans': 355, 'num_ms2_scans': 1290}
#
# Episode 14 (206 chemicals)
# steps	 500 	total rewards	 45.55362664827871
# steps	 1000 	total rewards	 114.20766305969778
# Finished after 1497 timesteps (15.74514889717102 seconds) with total reward 169.20209568414865
# {'coverage_prop': '0.956', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.506', 'efficiency': '0.198', 'TP': '181', 'FP': '16', 'FN': '9', 'precision': '0.919', 'recall': '0.953', 'f1': '0.935', 'total_rewards': 169.20209568414867, 'invalid_action_count': 0, 'num_ms1_scans': 503, 'num_ms2_scans': 994}
#
# Episode 15 (407 chemicals)
# steps	 500 	total rewards	 62.48254683396313
# steps	 1000 	total rewards	 165.60477848576141
# steps	 1500 	total rewards	 254.66962163245816
# Finished after 1655 timesteps (16.111545085906982 seconds) with total reward 279.4606267939937
# {'coverage_prop': '0.943', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.263', 'efficiency': '0.293', 'TP': '349', 'FP': '35', 'FN': '23', 'precision': '0.909', 'recall': '0.938', 'f1': '0.923', 'total_rewards': 279.46062679399387, 'invalid_action_count': 0, 'num_ms1_scans': 345, 'num_ms2_scans': 1310}
#
# Episode 16 (498 chemicals)
# steps	 500 	total rewards	 80.23487196716034
# steps	 1000 	total rewards	 180.43154289468077
# steps	 1500 	total rewards	 282.72593742641436
# Finished after 1729 timesteps (29.151031017303467 seconds) with total reward 318.6679836459015
# {'coverage_prop': '0.912', 'intensity_prop': '0.714', 'ms1ms2_ratio': '0.186', 'efficiency': '0.311', 'TP': '403', 'FP': '51', 'FN': '44', 'precision': '0.888', 'recall': '0.902', 'f1': '0.895', 'total_rewards': 318.6679836459015, 'invalid_action_count': 0, 'num_ms1_scans': 271, 'num_ms2_scans': 1458}
#
# Episode 17 (372 chemicals)
# steps	 500 	total rewards	 72.14147962328205
# steps	 1000 	total rewards	 171.49579973785487
# steps	 1500 	total rewards	 252.42587048404027
# Finished after 1681 timesteps (15.933368921279907 seconds) with total reward 272.8586228203061
# {'coverage_prop': '0.952', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.234', 'efficiency': '0.260', 'TP': '323', 'FP': '31', 'FN': '18', 'precision': '0.912', 'recall': '0.947', 'f1': '0.929', 'total_rewards': 272.8586228203064, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 18 (302 chemicals)
# steps	 500 	total rewards	 54.90263917401529
# steps	 1000 	total rewards	 143.12689641014515
# steps	 1500 	total rewards	 215.81584562387692
# Finished after 1621 timesteps (15.615598201751709 seconds) with total reward 226.69811384759905
# {'coverage_prop': '0.957', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.305', 'efficiency': '0.233', 'TP': '268', 'FP': '21', 'FN': '13', 'precision': '0.927', 'recall': '0.954', 'f1': '0.940', 'total_rewards': 226.6981138475992, 'invalid_action_count': 0, 'num_ms1_scans': 379, 'num_ms2_scans': 1242}
#
# Episode 19 (265 chemicals)
# steps	 500 	total rewards	 55.323553580374856
# steps	 1000 	total rewards	 137.93412432772536
# steps	 1500 	total rewards	 201.46933615569756
# Finished after 1634 timesteps (15.183713912963867 seconds) with total reward 216.02783988704306
# {'coverage_prop': '0.981', 'intensity_prop': '0.801', 'ms1ms2_ratio': '0.289', 'efficiency': '0.205', 'TP': '241', 'FP': '19', 'FN': '5', 'precision': '0.927', 'recall': '0.980', 'f1': '0.953', 'total_rewards': 216.0278398870428, 'invalid_action_count': 0, 'num_ms1_scans': 366, 'num_ms2_scans': 1268}
#
# Episode 20 (468 chemicals)
# steps	 500 	total rewards	 78.75497475425821
# steps	 1000 	total rewards	 171.9503734026993
# steps	 1500 	total rewards	 261.02419193511133
# Finished after 1726 timesteps (16.877599954605103 seconds) with total reward 294.3701240325714
# {'coverage_prop': '0.855', 'intensity_prop': '0.668', 'ms1ms2_ratio': '0.190', 'efficiency': '0.276', 'TP': '354', 'FP': '46', 'FN': '68', 'precision': '0.885', 'recall': '0.839', 'f1': '0.861', 'total_rewards': 294.37012403257114, 'invalid_action_count': 0, 'num_ms1_scans': 275, 'num_ms2_scans': 1451}
#
# Episode 21 (234 chemicals)
# steps	 500 	total rewards	 46.46122472001782
# steps	 1000 	total rewards	 128.23867897708288
# Finished after 1475 timesteps (14.74898099899292 seconds) with total reward 181.7349393688646
# {'coverage_prop': '0.957', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.554', 'efficiency': '0.236', 'TP': '206', 'FP': '18', 'FN': '10', 'precision': '0.920', 'recall': '0.954', 'f1': '0.936', 'total_rewards': 181.7349393688646, 'invalid_action_count': 0, 'num_ms1_scans': 526, 'num_ms2_scans': 949}
#
# Episode 22 (322 chemicals)
# steps	 500 	total rewards	 63.0371408738211
# steps	 1000 	total rewards	 151.42456916206152
# steps	 1500 	total rewards	 226.49449423814843
# Finished after 1636 timesteps (28.3679461479187 seconds) with total reward 241.04449101544736
# {'coverage_prop': '0.957', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.287', 'efficiency': '0.242', 'TP': '283', 'FP': '25', 'FN': '14', 'precision': '0.919', 'recall': '0.953', 'f1': '0.936', 'total_rewards': 241.04449101544705, 'invalid_action_count': 0, 'num_ms1_scans': 365, 'num_ms2_scans': 1271}
#
# Episode 23 (310 chemicals)
# steps	 500 	total rewards	 66.77789765056464
# steps	 1000 	total rewards	 152.63584138367554
# steps	 1500 	total rewards	 224.49650954428586
# Finished after 1575 timesteps (18.588303804397583 seconds) with total reward 232.0243853968007
# {'coverage_prop': '0.945', 'intensity_prop': '0.749', 'ms1ms2_ratio': '0.370', 'efficiency': '0.255', 'TP': '264', 'FP': '29', 'FN': '17', 'precision': '0.901', 'recall': '0.940', 'f1': '0.920', 'total_rewards': 232.02438539680037, 'invalid_action_count': 0, 'num_ms1_scans': 425, 'num_ms2_scans': 1150}
#
# Episode 24 (345 chemicals)
# steps	 500 	total rewards	 60.45310807359132
# steps	 1000 	total rewards	 156.73374134533213
# steps	 1500 	total rewards	 237.8721565353879
# Finished after 1681 timesteps (16.758100986480713 seconds) with total reward 259.5506267394834
# {'coverage_prop': '0.951', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.234', 'efficiency': '0.241', 'TP': '299', 'FP': '29', 'FN': '17', 'precision': '0.912', 'recall': '0.946', 'f1': '0.929', 'total_rewards': 259.55062673948333, 'invalid_action_count': 0, 'num_ms1_scans': 319, 'num_ms2_scans': 1362}
#
# Episode 25 (396 chemicals)
# steps	 500 	total rewards	 63.828975904004274
# steps	 1000 	total rewards	 151.44101290742347
# steps	 1500 	total rewards	 248.51912484981983
# Finished after 1679 timesteps (16.047178030014038 seconds) with total reward 270.8994348646653
# {'coverage_prop': '0.957', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.236', 'efficiency': '0.279', 'TP': '339', 'FP': '40', 'FN': '17', 'precision': '0.894', 'recall': '0.952', 'f1': '0.922', 'total_rewards': 270.8994348646652, 'invalid_action_count': 0, 'num_ms1_scans': 321, 'num_ms2_scans': 1358}
#
# Episode 26 (203 chemicals)
# steps	 500 	total rewards	 40.96673036915889
# steps	 1000 	total rewards	 116.26391406327969
# Finished after 1465 timesteps (16.30586814880371 seconds) with total reward 164.3049366183155
# {'coverage_prop': '0.966', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.575', 'efficiency': '0.211', 'TP': '186', 'FP': '10', 'FN': '7', 'precision': '0.949', 'recall': '0.964', 'f1': '0.956', 'total_rewards': 164.30493661831565, 'invalid_action_count': 0, 'num_ms1_scans': 535, 'num_ms2_scans': 930}
#
# Episode 27 (281 chemicals)
# steps	 500 	total rewards	 55.38322226329699
# steps	 1000 	total rewards	 142.73178509793024
# steps	 1500 	total rewards	 214.94350130278946
# Finished after 1564 timesteps (26.251545906066895 seconds) with total reward 224.24666683618017
# {'coverage_prop': '0.964', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.387', 'efficiency': '0.240', 'TP': '251', 'FP': '20', 'FN': '10', 'precision': '0.926', 'recall': '0.962', 'f1': '0.944', 'total_rewards': 224.24666683618045, 'invalid_action_count': 0, 'num_ms1_scans': 436, 'num_ms2_scans': 1128}
#
# Episode 28 (493 chemicals)
# steps	 500 	total rewards	 81.1683689150183
# steps	 1000 	total rewards	 163.32073741369632
# steps	 1500 	total rewards	 260.09657188636254
# Finished after 1749 timesteps (22.85170292854309 seconds) with total reward 302.319054625992
# {'coverage_prop': '0.858', 'intensity_prop': '0.643', 'ms1ms2_ratio': '0.168', 'efficiency': '0.282', 'TP': '357', 'FP': '66', 'FN': '70', 'precision': '0.844', 'recall': '0.836', 'f1': '0.840', 'total_rewards': 302.3190546259921, 'invalid_action_count': 0, 'num_ms1_scans': 251, 'num_ms2_scans': 1498}
#
# Episode 29 (304 chemicals)
# steps	 500 	total rewards	 61.99199473696666
# steps	 1000 	total rewards	 144.36734660797444
# steps	 1500 	total rewards	 217.2551500524442
# Finished after 1657 timesteps (18.61584186553955 seconds) with total reward 230.71408271317736
# {'coverage_prop': '0.954', 'intensity_prop': '0.771', 'ms1ms2_ratio': '0.262', 'efficiency': '0.221', 'TP': '264', 'FP': '26', 'FN': '14', 'precision': '0.910', 'recall': '0.950', 'f1': '0.930', 'total_rewards': 230.71408271317733, 'invalid_action_count': 0, 'num_ms1_scans': 344, 'num_ms2_scans': 1313}

# %% [markdown]
# #### Test classic controllers in ViMMS

# %%
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import TopNController, TopN_SmartRoiController, WeightedDEWController
from vimms.Environment import Environment

# %% [markdown]
# Run Top-N Controller

# %%
params
# Out:
# {'chemical_creator': {'mz_range': (100, 600),
#   'rt_range': (400, 800),
#   'intensity_range': (10000.0, 1e+20),
#   'n_chemicals': (200, 500),
#   'mz_sampler': <vimms.ChemicalSamplers.MZMLFormulaSampler at 0x7faf4874ddf0>,
#   'ri_sampler': <vimms.ChemicalSamplers.MZMLRTandIntensitySampler at 0x7faf5341d3a0>,
#   'cr_sampler': <vimms.ChemicalSamplers.MZMLChromatogramSampler at 0x7faf5343a640>},
#  'noise': {'enable_spike_noise': True,
#   'noise_density': 0.1,
#   'noise_max_val': 1000.0,
#   'mz_range': (100, 600)},
#  'env': {'ionisation_mode': 'Positive',
#   'rt_range': (400, 800),
#   'isolation_window': 0.7,
#   'use_dew': True,
#   'mz_tol': 10,
#   'rt_tol': 5,
#   'min_ms1_intensity': 5000,
#   'alpha': 0.75,
#   'beta': 0.5}}

# %%
enable_spike_noise = params['noise']['enable_spike_noise']
ionisation_mode = params['env']['ionisation_mode']
isolation_window = params['env']['isolation_window']
mz_tol = params['env']['mz_tol']
rt_range = params['chemical_creator']['rt_range']

# %%
method = 'TopN_Controller'
print('method = %s' % method)
print()

effective_rt_tol = topN_rt_tol
effective_N = topN_N
eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    controller = TopNController(ionisation_mode, effective_N, isolation_window, mz_tol, effective_rt_tol,
                                min_ms1_intensity)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()
    
method_eval_results[method] = eval_results
# Out:
# method = TopN_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.215', 'efficiency': '0.293', 'TP': '366', 'FP': '43', 'FN': '17', 'precision': '0.895', 'recall': '0.956', 'f1': '0.924'}
#
# Episode 1 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.442', 'efficiency': '0.237', 'TP': '236', 'FP': '16', 'FN': '10', 'precision': '0.937', 'recall': '0.959', 'f1': '0.948'}
#
# Episode 2 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.750', 'ms1ms2_ratio': '0.273', 'efficiency': '0.295', 'TP': '344', 'FP': '38', 'FN': '12', 'precision': '0.901', 'recall': '0.966', 'f1': '0.932'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.226', 'efficiency': '0.313', 'TP': '395', 'FP': '37', 'FN': '20', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 4 finished
# {'coverage_prop': '0.975', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.234', 'efficiency': '0.313', 'TP': '384', 'FP': '42', 'FN': '11', 'precision': '0.901', 'recall': '0.972', 'f1': '0.935'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.788', 'ms1ms2_ratio': '0.791', 'efficiency': '0.248', 'TP': '182', 'FP': '10', 'FN': '8', 'precision': '0.948', 'recall': '0.958', 'f1': '0.953'}
#
# Episode 6 finished
# {'coverage_prop': '0.929', 'intensity_prop': '0.724', 'ms1ms2_ratio': '0.193', 'efficiency': '0.307', 'TP': '394', 'FP': '50', 'FN': '34', 'precision': '0.887', 'recall': '0.921', 'f1': '0.904'}
#
# Episode 7 finished
# {'coverage_prop': '0.961', 'intensity_prop': '0.789', 'ms1ms2_ratio': '0.620', 'efficiency': '0.219', 'TP': '186', 'FP': '10', 'FN': '8', 'precision': '0.949', 'recall': '0.959', 'f1': '0.954'}
#
# Episode 8 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.744', 'ms1ms2_ratio': '0.208', 'efficiency': '0.285', 'TP': '369', 'FP': '33', 'FN': '22', 'precision': '0.918', 'recall': '0.944', 'f1': '0.931'}
#
# Episode 9 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.276', 'efficiency': '0.287', 'TP': '333', 'FP': '37', 'FN': '14', 'precision': '0.900', 'recall': '0.960', 'f1': '0.929'}
#
# Episode 10 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.759', 'ms1ms2_ratio': '0.191', 'efficiency': '0.292', 'TP': '387', 'FP': '35', 'FN': '21', 'precision': '0.917', 'recall': '0.949', 'f1': '0.933'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.783', 'ms1ms2_ratio': '0.500', 'efficiency': '0.239', 'TP': '225', 'FP': '14', 'FN': '10', 'precision': '0.941', 'recall': '0.957', 'f1': '0.949'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.746', 'ms1ms2_ratio': '0.368', 'efficiency': '0.207', 'TP': '216', 'FP': '22', 'FN': '13', 'precision': '0.908', 'recall': '0.943', 'f1': '0.925'}
#
# Episode 13 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.300', 'efficiency': '0.232', 'TP': '263', 'FP': '27', 'FN': '10', 'precision': '0.907', 'recall': '0.963', 'f1': '0.934'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.768', 'ms1ms2_ratio': '0.559', 'efficiency': '0.209', 'TP': '180', 'FP': '17', 'FN': '9', 'precision': '0.914', 'recall': '0.952', 'f1': '0.933'}
#
# Episode 15 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.298', 'efficiency': '0.315', 'TP': '365', 'FP': '30', 'FN': '12', 'precision': '0.924', 'recall': '0.968', 'f1': '0.946'}
#
# Episode 16 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.758', 'ms1ms2_ratio': '0.201', 'efficiency': '0.336', 'TP': '437', 'FP': '42', 'FN': '19', 'precision': '0.912', 'recall': '0.958', 'f1': '0.935'}
#
# Episode 17 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.262', 'efficiency': '0.273', 'TP': '332', 'FP': '26', 'FN': '14', 'precision': '0.927', 'recall': '0.960', 'f1': '0.943'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.767', 'ms1ms2_ratio': '0.356', 'efficiency': '0.250', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.326', 'efficiency': '0.214', 'TP': '242', 'FP': '17', 'FN': '6', 'precision': '0.934', 'recall': '0.976', 'f1': '0.955'}
#
# Episode 20 finished
# {'coverage_prop': '0.921', 'intensity_prop': '0.731', 'ms1ms2_ratio': '0.209', 'efficiency': '0.306', 'TP': '397', 'FP': '34', 'FN': '37', 'precision': '0.921', 'recall': '0.915', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.633', 'efficiency': '0.254', 'TP': '202', 'FP': '22', 'FN': '10', 'precision': '0.902', 'recall': '0.953', 'f1': '0.927'}
#
# Episode 22 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.770', 'ms1ms2_ratio': '0.322', 'efficiency': '0.256', 'TP': '291', 'FP': '20', 'FN': '11', 'precision': '0.936', 'recall': '0.964', 'f1': '0.949'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.766', 'ms1ms2_ratio': '0.420', 'efficiency': '0.270', 'TP': '272', 'FP': '22', 'FN': '16', 'precision': '0.925', 'recall': '0.944', 'f1': '0.935'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.261', 'efficiency': '0.258', 'TP': '315', 'FP': '24', 'FN': '6', 'precision': '0.929', 'recall': '0.981', 'f1': '0.955'}
#
# Episode 25 finished
# {'coverage_prop': '0.980', 'intensity_prop': '0.773', 'ms1ms2_ratio': '0.270', 'efficiency': '0.299', 'TP': '354', 'FP': '34', 'FN': '8', 'precision': '0.912', 'recall': '0.978', 'f1': '0.944'}
#
# Episode 26 finished
# {'coverage_prop': '0.970', 'intensity_prop': '0.786', 'ms1ms2_ratio': '0.651', 'efficiency': '0.227', 'TP': '183', 'FP': '14', 'FN': '6', 'precision': '0.929', 'recall': '0.968', 'f1': '0.948'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.795', 'ms1ms2_ratio': '0.449', 'efficiency': '0.258', 'TP': '253', 'FP': '19', 'FN': '9', 'precision': '0.930', 'recall': '0.966', 'f1': '0.948'}
#
# Episode 28 finished
# {'coverage_prop': '0.933', 'intensity_prop': '0.708', 'ms1ms2_ratio': '0.186', 'efficiency': '0.316', 'TP': '405', 'FP': '55', 'FN': '33', 'precision': '0.880', 'recall': '0.925', 'f1': '0.902'}
#
# Episode 29 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.317', 'efficiency': '0.240', 'TP': '275', 'FP': '19', 'FN': '10', 'precision': '0.935', 'recall': '0.965', 'f1': '0.950'}

# %% [markdown]
# Run SmartROI Controller

# %%
method = 'SmartROI_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    roi_params = RoiBuilderParams(min_roi_intensity=0, min_roi_length=0)    
    smartroi_params = SmartRoiParams(intensity_increase_factor=alpha, drop_perc=beta/100.0)
    controller = TopN_SmartRoiController(ionisation_mode, isolation_window, smartroi_N, mz_tol, smartroi_dew,
                                min_ms1_intensity, roi_params, smartroi_params)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = SmartROI_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.494', 'ms1ms2_ratio': '1.380', 'efficiency': '0.765', 'TP': '212', 'FP': '195', 'FN': '19', 'precision': '0.521', 'recall': '0.918', 'f1': '0.665'}
#
# Episode 1 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.487', 'ms1ms2_ratio': '2.469', 'efficiency': '0.736', 'TP': '123', 'FP': '125', 'FN': '14', 'precision': '0.496', 'recall': '0.898', 'f1': '0.639'}
#
# Episode 2 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.476', 'efficiency': '0.749', 'TP': '189', 'FP': '190', 'FN': '15', 'precision': '0.499', 'recall': '0.926', 'f1': '0.648'}
#
# Episode 3 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.529', 'ms1ms2_ratio': '1.286', 'efficiency': '0.771', 'TP': '244', 'FP': '188', 'FN': '20', 'precision': '0.565', 'recall': '0.924', 'f1': '0.701'}
#
# Episode 4 finished
# {'coverage_prop': '0.979', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.299', 'efficiency': '0.770', 'TP': '230', 'FP': '198', 'FN': '9', 'precision': '0.537', 'recall': '0.962', 'f1': '0.690'}
#
# Episode 5 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.528', 'ms1ms2_ratio': '3.333', 'efficiency': '0.728', 'TP': '105', 'FP': '85', 'FN': '10', 'precision': '0.553', 'recall': '0.913', 'f1': '0.689'}
#
# Episode 6 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.519', 'ms1ms2_ratio': '1.127', 'efficiency': '0.738', 'TP': '260', 'FP': '194', 'FN': '24', 'precision': '0.573', 'recall': '0.915', 'f1': '0.705'}
#
# Episode 7 finished
# {'coverage_prop': '0.946', 'intensity_prop': '0.529', 'ms1ms2_ratio': '3.292', 'efficiency': '0.731', 'TP': '119', 'FP': '74', 'FN': '11', 'precision': '0.617', 'recall': '0.915', 'f1': '0.737'}
#
# Episode 8 finished
# {'coverage_prop': '0.943', 'intensity_prop': '0.492', 'ms1ms2_ratio': '1.435', 'efficiency': '0.774', 'TP': '199', 'FP': '201', 'FN': '24', 'precision': '0.497', 'recall': '0.892', 'f1': '0.639'}
#
# Episode 9 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.523', 'ms1ms2_ratio': '1.529', 'efficiency': '0.744', 'TP': '200', 'FP': '167', 'FN': '17', 'precision': '0.545', 'recall': '0.922', 'f1': '0.685'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.533', 'ms1ms2_ratio': '1.224', 'efficiency': '0.734', 'TP': '239', 'FP': '187', 'FN': '17', 'precision': '0.561', 'recall': '0.934', 'f1': '0.701'}
#
# Episode 11 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.515', 'ms1ms2_ratio': '2.696', 'efficiency': '0.764', 'TP': '121', 'FP': '118', 'FN': '10', 'precision': '0.506', 'recall': '0.924', 'f1': '0.654'}
#
# Episode 12 finished
# {'coverage_prop': '0.944', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.578', 'efficiency': '0.729', 'TP': '106', 'FP': '131', 'FN': '14', 'precision': '0.447', 'recall': '0.883', 'f1': '0.594'}
#
# Episode 13 finished
# {'coverage_prop': '0.950', 'intensity_prop': '0.513', 'ms1ms2_ratio': '1.990', 'efficiency': '0.709', 'TP': '150', 'FP': '135', 'FN': '15', 'precision': '0.526', 'recall': '0.909', 'f1': '0.667'}
#
# Episode 14 finished
# {'coverage_prop': '0.942', 'intensity_prop': '0.489', 'ms1ms2_ratio': '3.180', 'efficiency': '0.713', 'TP': '99', 'FP': '95', 'FN': '12', 'precision': '0.510', 'recall': '0.892', 'f1': '0.649'}
#
# Episode 15 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.551', 'ms1ms2_ratio': '1.406', 'efficiency': '0.749', 'TP': '221', 'FP': '172', 'FN': '14', 'precision': '0.562', 'recall': '0.940', 'f1': '0.704'}
#
# Episode 16 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.536', 'ms1ms2_ratio': '1.082', 'efficiency': '0.761', 'TP': '273', 'FP': '208', 'FN': '17', 'precision': '0.568', 'recall': '0.941', 'f1': '0.708'}
#
# Episode 17 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.505', 'ms1ms2_ratio': '1.661', 'efficiency': '0.765', 'TP': '189', 'FP': '165', 'FN': '18', 'precision': '0.534', 'recall': '0.913', 'f1': '0.674'}
#
# Episode 18 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.512', 'ms1ms2_ratio': '2.067', 'efficiency': '0.746', 'TP': '149', 'FP': '142', 'FN': '11', 'precision': '0.512', 'recall': '0.931', 'f1': '0.661'}
#
# Episode 19 finished
# {'coverage_prop': '0.977', 'intensity_prop': '0.491', 'ms1ms2_ratio': '2.360', 'efficiency': '0.740', 'TP': '124', 'FP': '135', 'FN': '6', 'precision': '0.479', 'recall': '0.954', 'f1': '0.638'}
#
# Episode 20 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.544', 'ms1ms2_ratio': '1.165', 'efficiency': '0.742', 'TP': '268', 'FP': '178', 'FN': '22', 'precision': '0.601', 'recall': '0.924', 'f1': '0.728'}
#
# Episode 21 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.494', 'ms1ms2_ratio': '2.905', 'efficiency': '0.748', 'TP': '109', 'FP': '111', 'FN': '14', 'precision': '0.495', 'recall': '0.886', 'f1': '0.636'}
#
# Episode 22 finished
# {'coverage_prop': '0.947', 'intensity_prop': '0.486', 'ms1ms2_ratio': '2.002', 'efficiency': '0.762', 'TP': '162', 'FP': '143', 'FN': '17', 'precision': '0.531', 'recall': '0.905', 'f1': '0.669'}
#
# Episode 23 finished
# {'coverage_prop': '0.939', 'intensity_prop': '0.474', 'ms1ms2_ratio': '2.162', 'efficiency': '0.774', 'TP': '137', 'FP': '154', 'FN': '19', 'precision': '0.471', 'recall': '0.878', 'f1': '0.613'}
#
# Episode 24 finished
# {'coverage_prop': '0.971', 'intensity_prop': '0.507', 'ms1ms2_ratio': '1.619', 'efficiency': '0.710', 'TP': '163', 'FP': '172', 'FN': '10', 'precision': '0.487', 'recall': '0.942', 'f1': '0.642'}
#
# Episode 25 finished
# {'coverage_prop': '0.972', 'intensity_prop': '0.532', 'ms1ms2_ratio': '1.484', 'efficiency': '0.764', 'TP': '214', 'FP': '171', 'FN': '11', 'precision': '0.556', 'recall': '0.951', 'f1': '0.702'}
#
# Episode 26 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.490', 'ms1ms2_ratio': '3.333', 'efficiency': '0.739', 'TP': '93', 'FP': '100', 'FN': '10', 'precision': '0.482', 'recall': '0.903', 'f1': '0.628'}
#
# Episode 27 finished
# {'coverage_prop': '0.957', 'intensity_prop': '0.507', 'ms1ms2_ratio': '2.250', 'efficiency': '0.739', 'TP': '143', 'FP': '126', 'FN': '12', 'precision': '0.532', 'recall': '0.923', 'f1': '0.675'}
#
# Episode 28 finished
# {'coverage_prop': '0.951', 'intensity_prop': '0.520', 'ms1ms2_ratio': '1.029', 'efficiency': '0.717', 'TP': '251', 'FP': '218', 'FN': '24', 'precision': '0.535', 'recall': '0.913', 'f1': '0.675'}
#
# Episode 29 finished
# {'coverage_prop': '0.954', 'intensity_prop': '0.513', 'ms1ms2_ratio': '2.033', 'efficiency': '0.734', 'TP': '148', 'FP': '142', 'FN': '14', 'precision': '0.510', 'recall': '0.914', 'f1': '0.655'}

# %% [markdown]
# Run WeightedDEW Controller

# %%
method = 'WeightedDEW_Controller'
print('method = %s' % method)
print()

eval_results = []
for i in range(len(chem_list)):
    
    spike_noise = None
    if enable_spike_noise:
        noise_params = params['noise']
        noise_density = noise_params['noise_density']
        noise_max_val = noise_params['noise_max_val']
        noise_min_mz = noise_params['mz_range'][0]
        noise_max_mz = noise_params['mz_range'][1]
        spike_noise = UniformSpikeNoise(noise_density, noise_max_val, min_mz=noise_min_mz,
                                        max_mz=noise_max_mz)

    chems = chem_list[i]
    mass_spec = IndependentMassSpectrometer(ionisation_mode, chems, spike_noise=spike_noise)
    
    controller = WeightedDEWController(ionisation_mode, weighteddew_N, isolation_window, mz_tol, t1,
                                min_ms1_intensity, exclusion_t_0=t0)
    env = Environment(mass_spec, controller, rt_range[0], rt_range[1], progress_bar=False, out_dir=out_dir,
                      out_file='%s_%d.mzML' % (method, i), save_eval=True)
    env.run()
    
    eval_res = evaluate(env, intensity_threshold)
    # eval_res['total_rewards'] = 0
    eval_results.append(eval_res)
    print('Episode %d finished' % i)
    print(eval_res)
    print()    
    
method_eval_results[method] = eval_results
# Out:
# method = WeightedDEW_Controller
#
# Episode 0 finished
# {'coverage_prop': '0.965', 'intensity_prop': '0.743', 'ms1ms2_ratio': '0.159', 'efficiency': '0.271', 'TP': '368', 'FP': '43', 'FN': '15', 'precision': '0.895', 'recall': '0.961', 'f1': '0.927'}
#
# Episode 1 finished
# {'coverage_prop': '0.958', 'intensity_prop': '0.791', 'ms1ms2_ratio': '0.242', 'efficiency': '0.186', 'TP': '238', 'FP': '13', 'FN': '11', 'precision': '0.948', 'recall': '0.956', 'f1': '0.952'}
#
# Episode 2 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.198', 'efficiency': '0.265', 'TP': '343', 'FP': '37', 'FN': '14', 'precision': '0.903', 'recall': '0.961', 'f1': '0.931'}
#
# Episode 3 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.762', 'ms1ms2_ratio': '0.158', 'efficiency': '0.288', 'TP': '404', 'FP': '34', 'FN': '14', 'precision': '0.922', 'recall': '0.967', 'f1': '0.944'}
#
# Episode 4 finished
# {'coverage_prop': '0.984', 'intensity_prop': '0.761', 'ms1ms2_ratio': '0.178', 'efficiency': '0.292', 'TP': '389', 'FP': '41', 'FN': '7', 'precision': '0.905', 'recall': '0.982', 'f1': '0.942'}
#
# Episode 5 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.815', 'ms1ms2_ratio': '0.421', 'efficiency': '0.177', 'TP': '186', 'FP': '6', 'FN': '8', 'precision': '0.969', 'recall': '0.959', 'f1': '0.964'}
#
# Episode 6 finished
# {'coverage_prop': '0.952', 'intensity_prop': '0.745', 'ms1ms2_ratio': '0.156', 'efficiency': '0.299', 'TP': '410', 'FP': '45', 'FN': '23', 'precision': '0.901', 'recall': '0.947', 'f1': '0.923'}
#
# Episode 7 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.810', 'ms1ms2_ratio': '0.349', 'efficiency': '0.165', 'TP': '188', 'FP': '7', 'FN': '9', 'precision': '0.964', 'recall': '0.954', 'f1': '0.959'}
#
# Episode 8 finished
# {'coverage_prop': '0.955', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.147', 'efficiency': '0.262', 'TP': '362', 'FP': '43', 'FN': '19', 'precision': '0.894', 'recall': '0.950', 'f1': '0.921'}
#
# Episode 9 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.765', 'ms1ms2_ratio': '0.185', 'efficiency': '0.255', 'TP': '342', 'FP': '30', 'FN': '12', 'precision': '0.919', 'recall': '0.966', 'f1': '0.942'}
#
# Episode 10 finished
# {'coverage_prop': '0.962', 'intensity_prop': '0.753', 'ms1ms2_ratio': '0.155', 'efficiency': '0.279', 'TP': '390', 'FP': '36', 'FN': '17', 'precision': '0.915', 'recall': '0.958', 'f1': '0.936'}
#
# Episode 11 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.794', 'ms1ms2_ratio': '0.274', 'efficiency': '0.184', 'TP': '229', 'FP': '9', 'FN': '11', 'precision': '0.962', 'recall': '0.954', 'f1': '0.958'}
#
# Episode 12 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.763', 'ms1ms2_ratio': '0.219', 'efficiency': '0.171', 'TP': '217', 'FP': '21', 'FN': '13', 'precision': '0.912', 'recall': '0.943', 'f1': '0.927'}
#
# Episode 13 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.755', 'ms1ms2_ratio': '0.194', 'efficiency': '0.200', 'TP': '254', 'FP': '34', 'FN': '12', 'precision': '0.882', 'recall': '0.955', 'f1': '0.917'}
#
# Episode 14 finished
# {'coverage_prop': '0.956', 'intensity_prop': '0.779', 'ms1ms2_ratio': '0.326', 'efficiency': '0.163', 'TP': '183', 'FP': '14', 'FN': '9', 'precision': '0.929', 'recall': '0.953', 'f1': '0.941'}
#
# Episode 15 finished
# {'coverage_prop': '0.978', 'intensity_prop': '0.784', 'ms1ms2_ratio': '0.187', 'efficiency': '0.273', 'TP': '368', 'FP': '30', 'FN': '9', 'precision': '0.925', 'recall': '0.976', 'f1': '0.950'}
#
# Episode 16 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.760', 'ms1ms2_ratio': '0.162', 'efficiency': '0.321', 'TP': '445', 'FP': '40', 'FN': '13', 'precision': '0.918', 'recall': '0.972', 'f1': '0.944'}
#
# Episode 17 finished
# {'coverage_prop': '0.960', 'intensity_prop': '0.764', 'ms1ms2_ratio': '0.173', 'efficiency': '0.240', 'TP': '329', 'FP': '28', 'FN': '15', 'precision': '0.922', 'recall': '0.956', 'f1': '0.939'}
#
# Episode 18 finished
# {'coverage_prop': '0.967', 'intensity_prop': '0.778', 'ms1ms2_ratio': '0.220', 'efficiency': '0.210', 'TP': '268', 'FP': '24', 'FN': '10', 'precision': '0.918', 'recall': '0.964', 'f1': '0.940'}
#
# Episode 19 finished
# {'coverage_prop': '0.974', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.214', 'efficiency': '0.184', 'TP': '240', 'FP': '18', 'FN': '7', 'precision': '0.930', 'recall': '0.972', 'f1': '0.950'}
#
# Episode 20 finished
# {'coverage_prop': '0.940', 'intensity_prop': '0.736', 'ms1ms2_ratio': '0.163', 'efficiency': '0.292', 'TP': '397', 'FP': '43', 'FN': '28', 'precision': '0.902', 'recall': '0.934', 'f1': '0.918'}
#
# Episode 21 finished
# {'coverage_prop': '0.953', 'intensity_prop': '0.785', 'ms1ms2_ratio': '0.353', 'efficiency': '0.190', 'TP': '209', 'FP': '14', 'FN': '11', 'precision': '0.937', 'recall': '0.950', 'f1': '0.944'}
#
# Episode 22 finished
# {'coverage_prop': '0.969', 'intensity_prop': '0.772', 'ms1ms2_ratio': '0.201', 'efficiency': '0.219', 'TP': '287', 'FP': '25', 'FN': '10', 'precision': '0.920', 'recall': '0.966', 'f1': '0.943'}
#
# Episode 23 finished
# {'coverage_prop': '0.948', 'intensity_prop': '0.769', 'ms1ms2_ratio': '0.249', 'efficiency': '0.220', 'TP': '268', 'FP': '26', 'FN': '16', 'precision': '0.912', 'recall': '0.944', 'f1': '0.927'}
#
# Episode 24 finished
# {'coverage_prop': '0.983', 'intensity_prop': '0.777', 'ms1ms2_ratio': '0.192', 'efficiency': '0.234', 'TP': '312', 'FP': '27', 'FN': '6', 'precision': '0.920', 'recall': '0.981', 'f1': '0.950'}
#
# Episode 25 finished
# {'coverage_prop': '0.982', 'intensity_prop': '0.781', 'ms1ms2_ratio': '0.183', 'efficiency': '0.266', 'TP': '356', 'FP': '33', 'FN': '7', 'precision': '0.915', 'recall': '0.981', 'f1': '0.947'}
#
# Episode 26 finished
# {'coverage_prop': '0.966', 'intensity_prop': '0.825', 'ms1ms2_ratio': '0.358', 'efficiency': '0.168', 'TP': '188', 'FP': '8', 'FN': '7', 'precision': '0.959', 'recall': '0.964', 'f1': '0.962'}
#
# Episode 27 finished
# {'coverage_prop': '0.968', 'intensity_prop': '0.800', 'ms1ms2_ratio': '0.254', 'efficiency': '0.205', 'TP': '260', 'FP': '12', 'FN': '9', 'precision': '0.956', 'recall': '0.967', 'f1': '0.961'}
#
# Episode 28 finished
# {'coverage_prop': '0.949', 'intensity_prop': '0.738', 'ms1ms2_ratio': '0.147', 'efficiency': '0.303', 'TP': '424', 'FP': '44', 'FN': '25', 'precision': '0.906', 'recall': '0.944', 'f1': '0.925'}
#
# Episode 29 finished
# {'coverage_prop': '0.964', 'intensity_prop': '0.792', 'ms1ms2_ratio': '0.203', 'efficiency': '0.206', 'TP': '272', 'FP': '21', 'FN': '11', 'precision': '0.928', 'recall': '0.961', 'f1': '0.944'}

# %% [markdown]
# #### Plotting

# %% [markdown]
# Flatten data into dataframe

# %%
data = []
for method in method_eval_results:
    eval_results = method_eval_results[method]
    for eval_res in eval_results:
        try:
            total_rewards = float(eval_res['total_rewards'])       
        except KeyError:
            total_rewards = 0.0

        try:
            invalid_action_count = float(eval_res['invalid_action_count'])       
        except KeyError:
            invalid_action_count = 0.0

        row = (
            method, 
            total_rewards, 
            invalid_action_count,
            float(eval_res['coverage_prop']), 
            float(eval_res['intensity_prop']), 
            float(eval_res['ms1ms2_ratio']), 
            float(eval_res['efficiency']),
            float(eval_res['precision']),
            float(eval_res['recall']),
            float(eval_res['f1']),            
        )
        data.append(row)
        
df = pd.DataFrame(data, columns=['method', 'total_rewards', 'invalid_action_count', 
    'coverage_prop', 'intensity_prop', 'ms1/ms2_ratio', 'efficiency', 
    'precision', 'recall', 'f1'])
# df.set_index('method', inplace=True)
df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 0  random   -1796.975752                1863.0          0.383           0.100
# 1  random   -1897.426302                1927.0          0.267           0.073
# 2  random   -1871.798795                1913.0          0.279           0.060
# 3  random   -1759.006303                1841.0          0.400           0.139
# 4  random   -1878.180037                1920.0          0.279           0.066
#
#    ms1/ms2_ratio  efficiency  precision  recall     f1
# 0          0.006       0.082      0.209   0.114  0.148
# 1          0.006       0.035      0.243   0.081  0.122
# 2          0.005       0.055      0.191   0.069  0.101
# 3          0.008       0.092      0.315   0.174  0.224
# 4          0.003       0.061      0.189   0.068  0.100

# %%
sns.set_context("poster")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='total_rewards')
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='invalid_action_count')
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='efficiency')
plt.xticks(rotation=90)
plt.title('Efficiency')
# Out:
# Text(0.5, 1.0, 'Efficiency')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')

# %%
df.to_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %% [markdown]
# ### Without 'random'

# %%
df = pd.read_pickle('evaluation_1.0E6_horizon_%d_alpha_%.2f_beta_%.2f.p' % (horizon, env_alpha, env_beta))

# %%
new_df = df[df.method != 'random']
new_df.head()
# Out:
#    method  total_rewards  invalid_action_count  coverage_prop  intensity_prop  \
# 30    DQN     261.148293                   8.0          0.948           0.586
# 31    DQN     171.824847                   1.0          0.943           0.593
# 32    DQN     242.722821                   3.0          0.931           0.576
# 33    DQN    -172.774855                 397.0          0.821           0.531
# 34    DQN     244.532934                  15.0          0.950           0.627
#
#     ms1/ms2_ratio  efficiency  precision  recall     f1
# 30          0.952       0.586      0.683   0.926  0.786
# 31          1.906       0.594      0.700   0.920  0.795
# 32          1.172       0.614      0.678   0.902  0.774
# 33          0.575       0.399      0.739   0.772  0.755
# 34          0.962       0.607      0.708   0.930  0.804

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='total_rewards', showfliers=False)
plt.xticks(rotation=90)
plt.title('Total Rewards')
# Out:
# Text(0.5, 1.0, 'Total Rewards')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='invalid_action_count', showfliers=False)
plt.xticks(rotation=90)
plt.title('Invalid Action Count')
# Out:
# Text(0.5, 1.0, 'Invalid Action Count')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='coverage_prop')
plt.xticks(rotation=90)
plt.title('Coverage Proportion')
# Out:
# Text(0.5, 1.0, 'Coverage Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='intensity_prop')
plt.xticks(rotation=90)
plt.title('Intensity Proportion')
# Out:
# Text(0.5, 1.0, 'Intensity Proportion')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='ms1/ms2_ratio')
plt.xticks(rotation=90)
plt.title('MS1/MS2 Ratio')
# Out:
# Text(0.5, 1.0, 'MS1/MS2 Ratio')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='precision')
plt.xticks(rotation=90)
plt.title('Precision')
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='recall')
plt.xticks(rotation=90)
plt.title('Recall')
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=new_df, x='method', y='f1')
plt.xticks(rotation=90)
plt.title('F1')
# Out:
# Text(0.5, 1.0, 'F1')
